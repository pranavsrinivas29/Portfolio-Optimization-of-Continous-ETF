# %%
#!pip install pyperclip

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler, Normalizer
import pandas_ta as ta
from pandas.tseries.offsets import MonthEnd, BDay, Week
from itertools import product
from sklearn.metrics import mean_absolute_error


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from datetime import datetime, timedelta
import time
import pyperclip

# %%
# Function for loading ETF data
def data_loading(ticker_symbol, start_date, end_date):
    etf_data = yf.Ticker(ticker_symbol)
    etf_history = etf_data.history(start=start_date, end=end_date)
    etf_history.index = etf_history.index.tz_localize(None)
    return etf_history, etf_data

#Function to derive the predictor columns
def etf_predictors(etf_history,  start_date, end_date, etf_data, benchmark_ticker = '^GSPC' ):
    
    # Calculate Daily Returns
    etf_history['Daily Return'] = etf_history['Close'].pct_change()

    # Calculate 21-Day Volatility (standard deviation of daily returns, annualized)
    etf_history['Volatility'] = etf_history['Daily Return'].rolling(window=21).std() * np.sqrt(252)
    #etf_history['Volatility_ta'] = ta.volatility(etf_history['Close'], window=21, annualize=True)
   
    # Get the ETF info
    etf_info = etf_data.info

    # Retrieve the net asset value price (NAV) and total net assets
    nav_price = etf_info['navPrice']
    total_assets = etf_info['totalAssets']

    # Calculate the number of shares outstanding
    shares_outstanding = total_assets / nav_price

    # Calculate Market Capitalization for each day
    # Market Capitalization = Closing Price * Total Number of Shares Outstanding
    etf_history['Market Cap'] = etf_history['Close'] * shares_outstanding

    total_assets = etf_info['totalAssets']
    total_liabilities = etf_info.get('totalLiabilities', 0)  # Handle the case where total liabilities might not be present
    
    # Calculate Book Value per Share
    book_value_per_share = (total_assets - total_liabilities) / shares_outstanding
    
    # Calculate Price to Book (P/B) Ratio
    etf_history['P/B Ratio'] = etf_history['Close'] / book_value_per_share
    
    # Calculate 1-Month Momentum (21 trading days)
    
    etf_history['Momentum'] = ta.mom(etf_history['Close'], length=21)
    
    benchmark_data = yf.download(benchmark_ticker, start=start_date, end=end_date)
    benchmark_data['Daily Return'] = benchmark_data['Close'].pct_change()
    #benchmark_data_history = benchmark_data.dropna()
    benchmark_data.head(10)
    
    # Ensure the indices are time zone-naive
    benchmark_data.index = benchmark_data.index.tz_localize(None)
    combined_data = etf_history[['Close']].join(benchmark_data[['Close']], lsuffix='_ETF', rsuffix='_Benchmark')
    combined_data = combined_data.dropna()
    
    # Calculate rolling beta with a 30-day window
    rolling_beta_21 = rolling_beta(combined_data, window=21)

    # Add the rolling beta to the dataframe
    combined_data.loc[:, 'Rolling Beta 21-day'] = rolling_beta_21
    etf_history['Rolling Beta']=combined_data['Rolling Beta 21-day']
    
    # Calculate daily profitability
    daily_profitabilities = []
    previous_nav = None
    for index, row in etf_history.iterrows():
        current_nav = row['Close']  # Current day's NAV
        #print(current_nav)
        if previous_nav is not None:
            daily_profitability = (current_nav - previous_nav) / previous_nav * 100
            daily_profitabilities.append(daily_profitability)
        else:
            daily_profitabilities.append(None)
        previous_nav = current_nav  # Update previous_nav for the next iteration

    # Add daily profitabilities to ETF dataset
    etf_history['Daily Profitability (%)'] = daily_profitabilities
    
    # Calculate the dividend yield for each day
    dividend_yields = []

    for index, row in etf_history.iterrows():
        # Get the dividend payment for the day
        dividend_payment = row['Dividends']

        # Get the current market price of the ETF for the day
        current_price = row['Close']

        # Calculate the dividend yield for the day
        dividend_yield = (dividend_payment / current_price) * 100

        # Append the dividend yield to the list
        dividend_yields.append(dividend_yield)
      
    etf_history['Div yield'] = dividend_yields

    #Volatility
    etf_history['ATR'] = ta.atr(etf_history['High'], etf_history['Low'], etf_history['Close'], length=21)    
    
    # Compute the Relative Volatility Index (RVI)
    rvi = ta.rvi(etf_history['Close'],length=21)
    etf_history['RVI'] = rvi
    
    #Momentum
    rsi_window = 14  # Window size for RSI calculation
    roc_window = 12  # Window size for ROC calculation
    #rsi_window = 21  
    #roc_window = 21  

    

    etf_history['RSI'] = ta.rsi(etf_history['Close'],length=rsi_window)
    # Calculate Rate of Change (ROC)
    etf_history['ROC'] = ta.roc(etf_history['Close'], length=roc_window)
        
    etf_history['log_returns'] = np.log(etf_history['Close'] / etf_history['Close'].shift(1))

    return etf_history

# Function to calculate rolling beta
def rolling_beta(df, window):
    rolling_cov = df['Close_Benchmark'].rolling(window=window).cov(df['Close_ETF'])
    rolling_var = df['Close_Benchmark'].rolling(window=window).var()
    rolling_beta = rolling_cov / rolling_var
    return rolling_beta

# %%
def pre_processing(
    etf_history, 
    train_start_date,
    train_end_date,
    #test_start_date,
    #test_end_date,
    prediction_dates_monthly,
    prediction_dates_weekly,
    feature_columns=None,
    scaling_strategy='StandardScaler', 
    final_end_date='2025-01-01'
):
    """
    Preprocess ETF history data and prepare train/test splits along with 
    dynamically scaled forecast data for both weekly & monthly horizons,
    stored in separate dictionaries.

    Parameters
    ----------
    etf_history : pd.DataFrame
        Full historical data with at least 'log_returns' column plus other features.
    train_start_date : str
        Start date (YYYY-MM-DD) for training data.
    train_end_date : str
        End date (YYYY-MM-DD) for training data.
    
    prediction_dates_monthly : list of str
        List of start dates for each monthly forecast window.
    prediction_dates_weekly : list of str
        List of start dates for each weekly forecast window.
    feature_columns : list of str, optional
        Columns to be used as features. If None, defaults are used.
    scaling_strategy : str, optional
        'StandardScaler' or 'Normalizer'. Defaults to 'StandardScaler'.
    final_end_date : str, optional
        The final end date (YYYY-MM-DD) for the last forecast window.
        Defaults to '2025-01-01'.

    Returns
    -------
    dict
        A dictionary containing:
        - 'train_data_scaled': np.ndarray
        - 'test_data_scaled': np.ndarray
        - 'y_train': pd.Series
        - 'y_test': pd.Series
        - 'scaler': scaler object
        - 'X': pd.DataFrame (all feature columns before splitting)
        - 'etf_history': pd.DataFrame (original data with missing values handled)
        - 'forecast_data_weekly': dict of weekly forecast DataFrame slices
        - 'forecast_data_monthly': dict of monthly forecast DataFrame slices
        - 'forecast_data_weekly_scaled': dict of scaled weekly forecast slices
        - 'forecast_data_monthly_scaled': dict of scaled monthly forecast slices
    """

    # 1. Handle missing values and infinite values
    etf_history.fillna(etf_history.median(), inplace=True)
    etf_history.replace([np.inf, -np.inf], 0, inplace=True)

    # 2. Default feature columns if none are provided
    if feature_columns is None:
        feature_columns = [
            'Volatility', 'Volume', 'Daily Return', 'Market Cap', 
            'P/B Ratio', 'Momentum', 'Rolling Beta', 
            'Daily Profitability (%)', 'ATR', 'RVI', 'RSI', 'ROC'
        ]

    # 3. Select features (X) and target (y)
    X = etf_history.loc[:, feature_columns]
    y = etf_history['log_returns']

    # 4. Split train and test data
    train_data = X.loc[train_start_date : train_end_date]
    #test_data  = X.loc[test_start_date  : test_end_date]
    y_train = y.loc[train_start_date : train_end_date]
    #y_test  = y.loc[test_start_date  : test_end_date]
    
    #print(train_data.head(5))
    #print(train_data.tail(5))
    # 5. Initialize and fit scaler
    if scaling_strategy == 'StandardScaler':
        scaler = StandardScaler()
    elif scaling_strategy == 'Normalizer':
        scaler = Normalizer()
    else:
        raise ValueError(f"Unsupported scaling strategy: {scaling_strategy}")

    train_data_scaled = scaler.fit_transform(train_data)
    #test_data_scaled  = scaler.transform(test_data)

    # 6. Create separate dictionaries for weekly and monthly
    forecast_data_weekly = {}
    forecast_data_monthly = {}

    # ---- Weekly Forecast Slices ----
    for i, start_date in enumerate(prediction_dates_weekly):
        if i < len(prediction_dates_weekly) - 1:
            weekly_end = (pd.to_datetime(start_date) + Week(1) - pd.Timedelta(days=1)).strftime('%Y-%m-%d')
        else:
            weekly_end = final_end_date
        
        w_key = f'forecast_data_{i+1}w'
        forecast_data_weekly[w_key] = X.loc[start_date : weekly_end]

    # ---- Monthly Forecast Slices ----
    for i, start_date in enumerate(prediction_dates_monthly):
        if i < len(prediction_dates_monthly) - 1:
            monthly_end = (pd.to_datetime(start_date) + MonthEnd(0)).strftime('%Y-%m-%d')
        else:
            monthly_end = final_end_date
        
        m_key = f'forecast_data_{i+1}m'
        forecast_data_monthly[m_key] = X.loc[start_date : monthly_end]

    # 7. Scale forecast data (weekly & monthly) and add intercept
    forecast_data_weekly_scaled = {}
    for period_key, period_data in forecast_data_weekly.items():
        if not period_data.empty:
            data_scaled = scaler.transform(period_data)
            forecast_data_weekly_scaled[period_key] = sm.add_constant(data_scaled)

    forecast_data_monthly_scaled = {}
    for period_key, period_data in forecast_data_monthly.items():
        if not period_data.empty:
            data_scaled = scaler.transform(period_data)
            forecast_data_monthly_scaled[period_key] = sm.add_constant(data_scaled)

    # 8. Add a constant to train and test data
    train_data_scaled = sm.add_constant(train_data_scaled)
    #test_data_scaled  = sm.add_constant(test_data_scaled)

    # 9. Return all objects in a dictionary
    return {
        'train_data_scaled': train_data_scaled,
        #'test_data_scaled': test_data_scaled,
        'y_train': y_train,
        #'y_test': y_test,
        'scaler': scaler,
        'X': X,
        'etf_history': etf_history,
        'forecast_data_weekly': forecast_data_weekly,
        'forecast_data_monthly': forecast_data_monthly,
        'forecast_data_weekly_scaled': forecast_data_weekly_scaled,
        'forecast_data_monthly_scaled': forecast_data_monthly_scaled
    }

# %%
# Function to train the model
def model_training(train_data_scaled, y_train):
    best_model = None
    best_score = float('-inf')
    hyperparameters = {
        'cov_type': ['HC0', 'HC1'],
        'use_t': [True, False],
        'method': ['pinv', 'qr']
    }

    for params in product(*hyperparameters.values()):
        try:
            model = sm.OLS(y_train, train_data_scaled)
            fitted_model = model.fit(cov_type=params[0], use_t=params[1], method=params[2])
            if fitted_model.rsquared_adj > best_score:
                best_model = fitted_model
                best_score = fitted_model.rsquared_adj
        except Exception as e:
            print(f"Error with params {params}: {e}")

    return best_model
"""def eval_model(best_model,test_data_scaled,y_test,y_train):
    
    test_predictions = best_model.predict((test_data_scaled))
    mae = mean_absolute_error(y_test, test_predictions)
    # Mean Absolute Scaled Error (MASE) - Example calculation assuming seasonal period m=1
    seasonal_naive = np.roll(y_test, 1)  # Shift y_test by 1 for seasonal naive forecast
    #seasonal_mae = np.mean(np.abs(y_test - seasonal_naive))
    seasonal_mae = np.mean(np.abs(y_test[1:] - seasonal_naive[1:]))
    mase = mae / seasonal_mae

    # Mean Absolute Percentage Error (MAPE)
    #mape = np.mean(np.abs((y_test - test_predictions) / y_test)) * 100

    #n = y_test.shape[0]
    #d = np.abs(  np.diff( y_test) ).sum()/(n-1)
    
    #errors = np.abs(y_test - test_predictions )
    #mase_value = errors.mean()/d

    print("Mean Absolute Error (MAE):", mae)
    print("Mean Absolute Scaled Error (MASE):", mase)
    #print("Mean Absolute Scaled Error-2 (MASE-2):", mase_value)
    #print("Mean Absolute Percentage Error (MAPE):", mape)
    
    return mae, mase"""

# Function to make predictions
def predictions(model, forecast_data_scaled):
    forecast_results = {}
    for key, data in forecast_data_scaled.items():
        # Extract the index from the original forecast data
        original_index = forecast_data_scaled[key][:, 1]  # Assuming the index is preserved here
        predictions = model.predict(data)
        forecast_results[key] = pd.DataFrame(
            predictions, 
            columns=["log_returns"], 
            index=original_index
        )
    return forecast_results

# %%
def combined_workflow(
    tickers,
    start_date, 
    end_date, 
    train_start_date, 
    train_end_date, 
    #test_start_date, 
    #test_end_date,
    prediction_dates_monthly, 
    prediction_dates_weekly
):
    etf_results = {}
    
    for ticker in tickers:
        # 1. Load and preprocess data
        etf_history, etf_data = data_loading(ticker, start_date, end_date)
        etf_history = etf_predictors(etf_history, start_date, end_date, etf_data)

        # 2. Single call to pre_processing for training/testing & both forecast horizons
        preprocessed = pre_processing(
            etf_history=etf_history, 
            train_start_date=train_start_date, 
            train_end_date=train_end_date,
            #test_start_date=test_start_date, 
            #test_end_date=test_end_date,
            prediction_dates_monthly=prediction_dates_monthly,
            prediction_dates_weekly=prediction_dates_weekly
        )
        
        # Track the start time
        start_time = time.time()
        
        # 3. Train the model
        model = model_training(preprocessed['train_data_scaled'], preprocessed['y_train'])
        
        # Calculate time consumed
        time_consumed = time.time() - start_time

        # Print the time consumed
        print(f"Time consumed for training: {time_consumed:.2f} seconds")
        
        # 4. Evaluate the model
        """mae, mase = eval_model(
            model, 
            preprocessed['test_data_scaled'], 
            preprocessed['y_test'], 
            preprocessed['y_train']
        )"""
        
        # 5. Generate predictions for monthly forecasts
        monthly_forecast_results = predictions(
            model, 
            preprocessed['forecast_data_monthly_scaled']
        )
        
        # 6. Generate predictions for weekly forecasts (optional)
        weekly_forecast_results = predictions(
            model, 
            preprocessed['forecast_data_weekly_scaled']
        )

        # ---------------------------------------------------------------------
        # 7. Build your final dictionary in the desired format
        # ---------------------------------------------------------------------

        # A. Basic structure
        dict_data = {
            "etf_history": etf_history,              # The full ETF dataframe (with predictors, etc.)
            "X": preprocessed["X"],                 # All feature columns used
            "y_train_values": preprocessed["y_train"],  # Training target values

            # Store model performance
            #model results": {
            #    "mae": mae,
            #    "mase": mase,
            #    "time": time_consumed
            #},
        }

        # B. Store monthly forecast predictions in separate keys
        #    Suppose you want up to 12 monthly periods; adjust as needed
        for i_m in range(1, 13):
            # The keys produced by predictions(...) might look like 'forecast_data_1m', 'forecast_data_2m', etc.
            forecast_key = f"forecast_data_{i_m}m"

            if forecast_key in monthly_forecast_results:
                # monthly_forecast_results[forecast_key] might be a DataFrame with 'log_returns'
                df_forecast = monthly_forecast_results[forecast_key]
                
                # e.g. store array of predicted 'log_returns' (or your final target variable)
                dict_data[f"forecast_predictions_df_{i_m}m"] = df_forecast["log_returns"].values
            
            # If a given month's key doesn't exist, you might skip it or handle differently

        # C. Store weekly forecast predictions similarly, if desired
        #    For example, suppose you do up to 48 weekly windows
        # C. Store weekly forecast predictions similarly, if desired
        # For example, suppose you do up to 52 weekly windows
        for i_w in range(1, 53):
            forecast_key = f"forecast_data_{i_w}w"
            if forecast_key in weekly_forecast_results:
                df_forecast = weekly_forecast_results[forecast_key]
                dict_data[f"forecast_predictions_df_{i_w}w"] = df_forecast["log_returns"].values


        # Finally, store this dictionary per ticker
        etf_results[ticker] = dict_data
    
    return etf_results

# %%
import pandas as pd

# Example usage
tickers = ['SMH', 'SOXX', 'PSI', 'XSD', 'IYW', 'XLK', 'VGT', 'FTEC', 'IGM', 'IXN', 
          ]
start_date, end_date = '2000-01-01', '2024-12-31'
"""train_start_date, train_end_date, test_start_date, test_end_date = (
    start_date,         # train_start_date
    '2014-01-01',       # train_end_date
    '2014-01-01',       # test_start_date
    '2024-01-01'        # test_end_date
)"""
train_start_date, train_end_date = (
    start_date,         # train_start_date
    '2024-01-01'        # train_end_date
)

# Generate prediction dates for monthly & weekly
prediction_dates_monthly = pd.date_range(
    start='2024-01-01', 
    periods=12, 
    freq='MS'
).strftime('%Y-%m-%d').tolist()

prediction_dates_weekly = pd.date_range(
    start='2024-01-01', 
    periods=52, 
    freq='W-MON'
).strftime('%Y-%m-%d').tolist()


# Run the workflow
results = combined_workflow(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date,
    train_start_date=train_start_date,
    train_end_date=train_end_date,
    #test_start_date=test_start_date,
    #test_end_date=test_end_date,
    prediction_dates_monthly=prediction_dates_monthly,
    prediction_dates_weekly=prediction_dates_weekly
)

# The 'results' object is a dictionary keyed by ticker.
# For each ticker (e.g. 'SMH' or 'SOXX'),to inspect:
#   results[ticker]["etf_history"]
#   results[ticker]["X"]
#   results[ticker]["y_train_values"]
#   results[ticker]["model results"]
#   results[ticker]["forecast_predictions_df_1m"], etc.
#
# Example:
# results['SMH']['forecast_predictions_df_1m']
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2000-06-05    0.255419  296800      0.000656  3.663359e+09   0.157510
# 2000-06-06    0.255419  445600     -0.041165  3.512556e+09   0.151026
# 2000-06-07    0.255419  431000      0.016513  3.570557e+09   0.153520
# 2000-06-08    0.255419  390400      0.004549  3.586798e+09   0.154218
# 2000-06-09    0.255419  195000      0.020698  3.661039e+09   0.157410
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2000-06-05  0.289615      0.020275                 0.065598  0.445106
# 2000-06-06  0.289615      0.020275                -4.116532  0.445106
# 2000-06-07  0.289615      0.020275                 1.651258  0.445106
# 2000-06-08  0.289615      0.020275                 0.454858  0.445106
# 2000-06-09  0.289615      0.020275                 2.069840  0.445106
#
#                   RVI        RSI       ROC
# Date
# 2000-06-05  51.343504  53.082717  0.789602
# 2000-06-06  51.343504  53.082717  0.789602
# 2000-06-07  51.343504  53.082717  0.789602
# 2000-06-08  51.343504  53.082717  0.789602
# 2000-06-09  51.343504  53.082717  0.789602
#             Volatility   Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.208578  4088100      0.000116  1.503601e+10   0.646488
# 2023-12-26    0.210370  4829200      0.013793  1.524339e+10   0.655405
# 2023-12-27    0.209950  5113400      0.001082  1.525988e+10   0.656114
# 2023-12-28    0.207445  4033500     -0.000227  1.525641e+10   0.655965
# 2023-12-29    0.209565  5390000     -0.005403  1.517397e+10   0.652420
#
#              Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  12.077820      0.074554                 0.011553  3.121524
# 2023-12-26  14.813538      0.075788                 1.379263  3.116528
# 2023-12-27  15.101639      0.077357                 0.108158  3.041606
# 2023-12-28  15.982193      0.078068                -0.022738  2.945124
# 2023-12-29  13.571716      0.080821                -0.540330  2.933359
#
#                   RVI        RSI        ROC
# Date
# 2023-12-22  70.049491  68.795579  10.682204
# 2023-12-26  73.482972  71.631335   9.701345
# 2023-12-27  76.550251  71.850349   8.887258
# 2023-12-28  67.786221  71.724849   6.310727
# 2023-12-29  60.157132  68.656565   4.629510
# Time consumed for training: 0.08 seconds
# [*********************100%%**********************]  1 of 1 completed
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2001-07-13    0.255681  603300      0.000999  1.175550e+09   0.085174
# 2001-07-16    0.255681  180000     -0.057949  1.107428e+09   0.080238
# 2001-07-17    0.255681  287100      0.041057  1.152896e+09   0.083533
# 2001-07-18    0.255681  301800     -0.041404  1.105162e+09   0.080074
# 2001-07-19    0.255681  405000      0.042459  1.152087e+09   0.083474
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2001-07-13   0.37056      0.021972                 0.099936  0.459673
# 2001-07-16   0.37056      0.021972                -5.794873  0.459673
# 2001-07-17   0.37056      0.021972                 4.105748  0.459673
# 2001-07-18   0.37056      0.021972                -4.140351  0.459673
# 2001-07-19   0.37056      0.021972                 4.245930  0.459673
#
#                   RVI        RSI       ROC
# Date
# 2001-07-13  52.782751  53.538697  0.945228
# 2001-07-16  52.782751  53.538697  0.945228
# 2001-07-17  52.782751  53.538697  0.945228
# 2001-07-18  52.782751  53.538697  0.945228
# 2001-07-19  52.782751  53.538697  0.945228
#             Volatility   Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.240664  2363400      0.003204  1.106927e+10   0.802018
# 2023-12-26    0.243978  1906500      0.017670  1.126486e+10   0.816190
# 2023-12-27    0.242880  1877400      0.002569  1.129380e+10   0.818287
# 2023-12-28    0.240814  1053000     -0.001875  1.127263e+10   0.816753
# 2023-12-29    0.244619  1452300     -0.007340  1.118989e+10   0.810758
#
#              Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  18.494217      0.101829                 0.320369  3.622452
# 2023-12-26  21.707458      0.103322                 1.767012  3.645070
# 2023-12-27  22.439041      0.105150                 0.256906  3.556040
# 2023-12-28  23.073059      0.105561                -0.187456  3.454689
# 2023-12-29  19.827240      0.108228                -0.734016  3.426461
#
#                   RVI        RSI        ROC
# Date
# 2023-12-22  67.599982  70.609836  13.240165
# 2023-12-26  71.513233  73.558914  12.231947
# 2023-12-27  74.962320  73.975017  11.638410
# 2023-12-28  66.059835  73.069118   7.753787
# 2023-12-29  58.422041  69.487517   6.197364
# Time consumed for training: 0.05 seconds
# [*********************100%%**********************]  1 of 1 completed
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2005-06-23    0.251514   85500      0.001206  5.177258e+07   0.070702
# 2005-06-24    0.251514    4800     -0.018704  5.080424e+07   0.069380
# 2005-06-27    0.251514   13800     -0.023826  4.959376e+07   0.067727
# 2005-06-28    0.251514    5400      0.015342  5.035461e+07   0.068766
# 2005-06-29    0.251514    3600     -0.005494  5.007795e+07   0.068388
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2005-06-23  0.135756      0.006516                 0.120596  0.145595
# 2005-06-24  0.135756      0.006516                -1.870385  0.145595
# 2005-06-27  0.135756      0.006516                -2.382634  0.145595
# 2005-06-28  0.135756      0.006516                 1.534175  0.145595
# 2005-06-29  0.135756      0.006516                -0.549424  0.145595
#
#                   RVI        RSI       ROC
# Date
# 2005-06-23  53.788842  54.001029  1.153836
# 2005-06-24  53.788842  54.001029  1.153836
# 2005-06-27  53.788842  54.001029  1.153836
# 2005-06-28  53.788842  54.001029  1.153836
# 2005-06-29  53.788842  54.001029  1.153836
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.254337  115600      0.005111  5.566394e+08   0.760162
# 2023-12-26    0.257141   64700      0.017901  5.666037e+08   0.773769
# 2023-12-27    0.257221   60900      0.000400  5.668302e+08   0.774079
# 2023-12-28    0.253190   47100     -0.002797  5.652449e+08   0.771914
# 2023-12-29    0.258241   72000     -0.008413  5.604893e+08   0.765419
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  5.229805      0.027796                 0.511140  0.920883
# 2023-12-26  6.088631      0.028610                 1.790072  0.926961
# 2023-12-27  6.078674      0.029458                 0.039971  0.901366
# 2023-12-28  6.347855      0.029783                -0.279673  0.875562
# 2023-12-29  5.529434      0.030655                -0.841342  0.869058
#
#                   RVI        RSI        ROC
# Date
# 2023-12-22  63.643252  72.026185  14.715026
# 2023-12-26  68.315491  74.752293  14.238756
# 2023-12-27  72.400301  74.812376  13.405127
# 2023-12-28  63.263996  73.494006   9.615189
# 2023-12-29  55.527158  69.535247   7.958858
# [*********************100%%**********************]  1 of 1 completed
# Time consumed for training: 0.06 seconds
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2006-02-06    0.258495  180000      0.001234  1.230621e+08   0.088796
# 2006-02-07    0.258495  460000      0.004118  1.235689e+08   0.089161
# 2006-02-08    0.258495  475800      0.019015  1.259185e+08   0.090857
# 2006-02-09    0.258495  164200     -0.005854  1.251814e+08   0.090325
# 2006-02-10    0.258495  763800     -0.006625  1.243521e+08   0.089726
#
#             Momentum  Rolling Beta  Daily Profitability (%)      ATR  \
# Date
# 2006-02-06   0.58091       0.03189                 0.123427  0.75791
# 2006-02-07   0.58091       0.03189                 0.411792  0.75791
# 2006-02-08   0.58091       0.03189                 1.901515  0.75791
# 2006-02-09   0.58091       0.03189                -0.585397  0.75791
# 2006-02-10   0.58091       0.03189                -0.662505  0.75791
#
#                   RVI        RSI       ROC
# Date
# 2006-02-06  53.497309  53.607663  0.996935
# 2006-02-07  53.497309  53.607663  0.996935
# 2006-02-08  53.497309  53.607663  0.996935
# 2006-02-09  53.497309  53.607663  0.996935
# 2006-02-10  53.497309  53.607663  0.996935
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.268074   29900      0.005526  1.155738e+09   0.833924
# 2023-12-26    0.269766   59400      0.016176  1.174433e+09   0.847414
# 2023-12-27    0.269689   25600     -0.001003  1.173255e+09   0.846564
# 2023-12-28    0.269552   42000     -0.003449  1.169209e+09   0.843644
# 2023-12-29    0.278694   22300     -0.015245  1.151384e+09   0.830783
#
#              Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  27.382980      0.133568                 0.552590  4.769789
# 2023-12-26  30.556793      0.134423                 1.617616  4.769328
# 2023-12-27  30.566544      0.134712                -0.100309  4.658167
# 2023-12-28  30.516052      0.133262                -0.344880  4.525213
# 2023-12-29  24.191635      0.133827                -1.524512  4.482701
#
#                   RVI        RSI        ROC
# Date
# 2023-12-22  63.309002  70.652909  14.166803
# 2023-12-26  67.538864  73.030706  13.147854
# 2023-12-27  59.783213  72.631356  11.408436
# 2023-12-28  53.092162  71.191394   8.524422
# 2023-12-29  47.356022  65.071231   7.098878
# Time consumed for training: 0.05 seconds
# [*********************100%%**********************]  1 of 1 completed
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2000-05-19    0.190593   80000      0.001161  2.784847e+09   0.142139
# 2000-05-22    0.190593     400     -0.034168  2.689694e+09   0.137283
# 2000-05-23    0.190593  104000      0.022405  2.749958e+09   0.140359
# 2000-05-24    0.190593   96400     -0.010380  2.721413e+09   0.138902
# 2000-05-25    0.190593   64800     -0.013986  2.683350e+09   0.136959
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2000-05-19  0.297983      0.015405                 0.116093  0.302254
# 2000-05-22  0.297983      0.015405                -3.416796  0.302254
# 2000-05-23  0.297983      0.015405                 2.240548  0.302254
# 2000-05-24  0.297983      0.015405                -1.038044  0.302254
# 2000-05-25  0.297983      0.015405                -1.398624  0.302254
#
#                   RVI        RSI       ROC
# Date
# 2000-05-19  54.445298  54.457145  1.001365
# 2000-05-22  54.445298  54.457145  1.001365
# 2000-05-23  54.445298  54.457145  1.001365
# 2000-05-24  54.445298  54.457145  1.001365
# 2000-05-25  54.445298  54.457145  1.001365
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.116445  322300      0.001307  1.442311e+10   0.736160
# 2023-12-26    0.115401  373800      0.005302  1.449958e+10   0.740063
# 2023-12-27    0.115114  379700      0.000000  1.449958e+10   0.740063
# 2023-12-28    0.115358  517900      0.000487  1.450663e+10   0.740423
# 2023-12-29    0.117901  371400     -0.004541  1.444075e+10   0.737061
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  5.543411      0.029070                 0.130667  1.579338
# 2023-12-26  6.520149      0.029526                 0.530182  1.543566
# 2023-12-27  6.619606      0.029884                 0.000000  1.509498
# 2023-12-28  6.351257      0.030406                 0.048677  1.459948
# 2023-12-29  5.643326      0.031199                -0.454136  1.455519
#
#                   RVI        RSI       ROC
# Date
# 2023-12-22  68.966700  71.355273  6.285612
# 2023-12-26  71.837301  72.969747  5.060581
# 2023-12-27  71.837301  72.969747  4.307238
# 2023-12-28  74.816021  73.131850  3.780191
# 2023-12-29  67.010183  68.973877  2.705753
# Time consumed for training: 0.03 seconds
# [*********************100%%**********************]  1 of 1 completed
#             Volatility   Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2000-01-03     0.17984   938100      0.000976  1.250297e+10   0.171824
# 2000-01-04     0.17984   545500     -0.050733  1.186865e+10   0.163107
# 2000-01-05     0.17984  1906000     -0.014845  1.169246e+10   0.160686
# 2000-01-06     0.17984  1670000     -0.033153  1.130483e+10   0.155358
# 2000-01-07     0.17984   686000      0.017457  1.150217e+10   0.158070
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2000-01-03  0.411993      0.021687                 0.097571  0.446625
# 2000-01-04  0.411993      0.021687                -5.073298  0.446625
# 2000-01-05  0.411993      0.021687                -1.484521  0.446625
# 2000-01-06  0.411993      0.021687                -3.315252  0.446625
# 2000-01-07  0.411993      0.021687                 1.745659  0.446625
#
#                   RVI        RSI       ROC
# Date
# 2000-01-03  54.153561  54.526858  0.961854
# 2000-01-04  54.153561  54.526858  0.961854
# 2000-01-05  54.153561  54.526858  0.961854
# 2000-01-06  54.153561  54.526858  0.961854
# 2000-01-07  54.153561  54.526858  0.961854
#             Volatility   Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.113293  5107500      0.001303  5.738116e+10   0.788570
# 2023-12-26    0.112605  3103800      0.004166  5.762019e+10   0.791855
# 2023-12-27    0.112604  5882300     -0.000052  5.761720e+10   0.791814
# 2023-12-28    0.112660  4807700      0.001193  5.768592e+10   0.792758
# 2023-12-29    0.114053  6094900     -0.003056  5.750964e+10   0.790336
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  7.634399      0.042308                 0.130349  2.391777
# 2023-12-26  8.785721      0.041946                 0.416561  2.334636
# 2023-12-27  8.785675      0.041661                -0.005194  2.281163
# 2023-12-28  8.667282      0.041739                 0.119281  2.214156
# 2023-12-29  7.942551      0.042264                -0.305590  2.205201
#
#                   RVI        RSI       ROC
# Date
# 2023-12-22  71.767372  68.573570  5.257414
# 2023-12-26  74.221872  70.012512  4.428063
# 2023-12-27  67.658319  69.969312  3.538754
# 2023-12-28  70.550848  70.420662  2.764879
# 2023-12-29  64.285000  67.613598  1.775177
# Time consumed for training: 0.06 seconds
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2004-01-30    0.171227  117600      0.001185  6.342309e+09   0.063842
# 2004-02-02    0.171227   65400      0.000815  6.347478e+09   0.063894
# 2004-02-03    0.171227  231100     -0.006108  6.308709e+09   0.063504
# 2004-02-04    0.171227   51000     -0.030111  6.118750e+09   0.061592
# 2004-02-05    0.171227    2600      0.005069  6.149763e+09   0.061904
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2004-01-30  1.419128      0.056784                 0.118544  1.116291
# 2004-02-02  1.419128      0.056784                 0.081504  1.116291
# 2004-02-03  1.419128      0.056784                -0.610770  1.116291
# 2004-02-04  1.419128      0.056784                -3.011070  1.116291
# 2004-02-05  1.419128      0.056784                 0.506864  1.116291
#
#                   RVI        RSI       ROC
# Date
# 2004-01-30  55.801892  55.825115  1.158998
# 2004-02-02  55.801892  55.825115  1.158998
# 2004-02-03  55.801892  55.825115  1.158998
# 2004-02-04  55.801892  55.825115  1.158998
# 2004-02-05  55.801892  55.825115  1.158998
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.113194  395100      0.000973  7.386382e+10   0.743521
# 2023-12-26    0.112738  319200      0.004942  7.422885e+10   0.747195
# 2023-12-27    0.112311  638900      0.000967  7.430064e+10   0.747918
# 2023-12-28    0.112517  320500      0.000658  7.434951e+10   0.748410
# 2023-12-29    0.116180  532900     -0.005731  7.392338e+10   0.744120
#
#              Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  23.951630      0.122500                 0.097276  6.017622
# 2023-12-26  26.822266      0.121118                 0.494202  5.895241
# 2023-12-27  27.527283      0.119996                 0.096710  5.754560
# 2023-12-28  27.002106      0.119288                 0.065779  5.551028
# 2023-12-29  22.454468      0.119959                -0.573146  5.555900
#
#                   RVI        RSI       ROC
# Date
# 2023-12-22  74.604692  70.507089  5.675675
# 2023-12-26  76.911230  72.066692  5.063389
# 2023-12-27  79.031232  72.376059  4.233651
# 2023-12-28  80.959314  72.598567  3.588706
# 2023-12-29  73.626142  67.493834  2.383772
# Time consumed for training: 0.03 seconds
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2013-10-24    0.173304   17700      0.001389  1.552456e+09   0.116775
# 2013-10-25    0.173304   41700      0.002793  1.556793e+09   0.117101
# 2013-10-28    0.173304   50600      0.000796  1.558031e+09   0.117194
# 2013-10-29    0.173304   44800      0.004772  1.565466e+09   0.117753
# 2013-10-30    0.173304  186500     -0.004749  1.558031e+09   0.117194
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2013-10-24  1.012989      0.027298                 0.138865  0.952189
# 2013-10-25  1.012989      0.027298                 0.279323  0.952189
# 2013-10-28  1.012989      0.027298                 0.079584  0.952189
# 2013-10-29  1.012989      0.027298                 0.477169  0.952189
# 2013-10-30  1.012989      0.027298                -0.474903  0.952189
#
#                   RVI        RSI       ROC
# Date
# 2013-10-24  57.078077  57.209537  1.432231
# 2013-10-25  57.078077  57.209537  1.432231
# 2013-10-28  57.078077  57.209537  1.432231
# 2013-10-29  57.078077  57.209537  1.432231
# 2013-10-30  57.078077  57.209537  1.432231
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.112701  212100      0.001535  9.874940e+09   0.742787
# 2023-12-26    0.112476  161900      0.004737  9.921722e+09   0.746306
# 2023-12-27    0.112238  236300      0.000624  9.927914e+09   0.746771
# 2023-12-28    0.112512  181700      0.000416  9.932041e+09   0.747082
# 2023-12-29    0.115629  278300     -0.005056  9.881821e+09   0.743304
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  7.107727      0.035738                 0.153487  1.757124
# 2023-12-26  7.833710      0.035363                 0.473744  1.716556
# 2023-12-27  7.952988      0.035051                 0.062405  1.677919
# 2023-12-28  7.725067      0.034876                 0.041574  1.620280
# 2023-12-29  6.602295      0.035082                -0.505638  1.620805
#
#                   RVI        RSI       ROC
# Date
# 2023-12-22  75.647076  70.610333  5.632709
# 2023-12-26  77.847941  72.113468  5.008325
# 2023-12-27  79.873683  72.315285  4.143991
# 2023-12-28  81.719121  72.458374  3.479999
# 2023-12-29  74.334230  67.862354  2.284325
# Time consumed for training: 0.05 seconds
# [*********************100%%**********************]  1 of 1 completed
#             Volatility   Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2001-03-19    0.185876      600      0.001115  4.269476e+08   0.074002
# 2001-03-20    0.185876   301800     -0.023617  4.168643e+08   0.072255
# 2001-03-21    0.185876   483000      0.027644  4.283881e+08   0.074252
# 2001-03-22    0.185876  1875000      0.032132  4.421530e+08   0.076638
# 2001-03-23    0.185876   199800      0.016290  4.493556e+08   0.077886
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2001-03-19  0.217263      0.009966                 0.111467  0.179441
# 2001-03-20  0.217263      0.009966                -2.361724  0.179441
# 2001-03-21  0.217263      0.009966                 2.764423  0.179441
# 2001-03-22  0.217263      0.009966                 3.213170  0.179441
# 2001-03-23  0.217263      0.009966                 1.628978  0.179441
#
#                   RVI        RSI       ROC
# Date
# 2001-03-19  54.557551  55.239963  1.096871
# 2001-03-20  54.557551  55.239963  1.096871
# 2001-03-21  54.557551  55.239963  1.096871
# 2001-03-22  54.557551  55.239963  1.096871
# 2001-03-23  54.557551  55.239963  1.096871
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.126677   63600      0.002037  3.997732e+09   0.692922
# 2023-12-26    0.125603   91200      0.006413  4.023368e+09   0.697366
# 2023-12-27    0.125155  106800      0.000111  4.023815e+09   0.697443
# 2023-12-28    0.125394   70800      0.000533  4.025959e+09   0.697815
# 2023-12-29    0.128993   99600     -0.005635  4.003271e+09   0.693882
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  4.014305      0.021344                 0.203722  0.921500
# 2023-12-26  4.697311      0.021813                 0.641264  0.906440
# 2023-12-27  4.783653      0.022226                 0.011114  0.885684
# 2023-12-28  4.704063      0.022670                 0.053271  0.856019
# 2023-12-29  4.140656      0.023346                -0.563542  0.851916
#
#                   RVI        RSI       ROC
# Date
# 2023-12-22  74.468431  72.475272  7.632636
# 2023-12-26  77.106737  74.177209  6.515236
# 2023-12-27  79.523308  74.207167  5.674011
# 2023-12-28  81.703307  74.360722  4.841674
# 2023-12-29  73.108615  69.635185  3.482037
# Time consumed for training: 0.05 seconds
# [*********************100%%**********************]  1 of 1 completed
#             Volatility  Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2001-11-26    0.176995       0      0.000904  4.676695e+08   0.089025
# 2001-11-27    0.176995     600      0.005036  4.700248e+08   0.089473
# 2001-11-28    0.176995       0      0.000000  4.700248e+08   0.089473
# 2001-11-29    0.176995       0      0.000000  4.700248e+08   0.089473
# 2001-11-30    0.176995       0      0.000000  4.700248e+08   0.089473
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2001-11-26  0.186977      0.009128                 0.090418  0.157558
# 2001-11-27  0.186977      0.009128                 0.503632  0.157558
# 2001-11-28  0.186977      0.009128                 0.000000  0.157558
# 2001-11-29  0.186977      0.009128                 0.000000  0.157558
# 2001-11-30  0.186977      0.009128                 0.000000  0.157558
#
#                   RVI        RSI       ROC
# Date
# 2001-11-26  54.586117  54.941011  1.049222
# 2001-11-27  54.586117  54.941011  1.049222
# 2001-11-28  54.586117  54.941011  1.049222
# 2001-11-29  54.586117  54.941011  1.049222
# 2001-11-30  54.586117  54.941011  1.049222
#             Volatility   Volume  Daily Return    Market Cap  P/B Ratio  \
# Date
# 2023-12-22    0.107488  1521700      0.000737  4.044166e+09   0.769839
# 2023-12-26    0.106863    49100      0.005305  4.065621e+09   0.773923
# 2023-12-27    0.106693   117900      0.002052  4.073964e+09   0.775511
# 2023-12-28    0.106795   232200      0.001024  4.078136e+09   0.776305
# 2023-12-29    0.108761    89800     -0.003653  4.063237e+09   0.773469
#
#             Momentum  Rolling Beta  Daily Profitability (%)       ATR  \
# Date
# 2023-12-22  2.652023      0.014428                 0.073742  0.813807
# 2023-12-26  3.169312      0.014396                 0.530514  0.798762
# 2023-12-27  3.268997      0.014510                 0.205216  0.779692
# 2023-12-28  3.189796      0.014725                 0.102392  0.754891
# 2023-12-29  2.841614      0.015085                -0.365335  0.751660
#
#                   RVI        RSI       ROC
# Date
# 2023-12-22  76.762605  70.144789  5.146425
# 2023-12-26  78.722421  71.988206  4.461788
# 2023-12-27  80.575796  72.694286  3.851818
# 2023-12-28  82.308243  73.059917  3.238939
# 2023-12-29  74.950902  69.481336  2.231378
# Time consumed for training: 0.05 seconds

# %%
def print_results_with_metrics(results):
    """
    Print out results (model summary, evaluation metrics, and some forecast predictions)
    from the results dictionary returned by combined_workflow.
    """
    for ticker, data in results.items():
        print(f"Ticker: {ticker}")
        print("=" * 50)
        
        # 1. Print model summary (if the model is a statsmodels object)
        if "model" in data and hasattr(data["model"], "summary"):
            print("Model Summary:")
            print(data["model"].summary())
            print("\n")
        else:
            print("No statsmodels summary available for this model.\n")
        
        
        
        # 3. Print monthly forecast predictions
        """print("Monthly Forecast Predictions (first 5 values for each period):")
        for i_m in range(1, 13):  # Up to 12 months
            key_m = f"forecast_predictions_df_{i_m}m"
            if key_m in data:
                preds_array = data[key_m]
                print(f"{key_m}: {preds_array[:5]}")  # Print first 5 predictions
        print("\n")

        # 4. Print weekly forecast predictions (first 5 values)
        print("Weekly Forecast Predictions (first 5 values for each period):")
        for i_w in range(1, 53):  # Adjusted for 52 weeks
            key_w = f"forecast_predictions_df_{i_w}w"
            if key_w in data:
                preds_array = data[key_w]
                print(f"{key_w}: {preds_array[:5]}")  # Print first 5 predictions
        print("\n")
        
        print("=" * 50)
        print("\n")"""

print_results_with_metrics(results)
# Out:
# Ticker: SMH
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.03379044 -0.01793496 -0.00611308  0.00637002  0.03509515]
# forecast_predictions_df_2m: [ 0.00907586  0.0194657   0.01952133 -0.0113266   0.02010973]
# forecast_predictions_df_3m: [ 0.04037552  0.01602794 -0.01534989  0.02566416  0.03456612]
# forecast_predictions_df_4m: [ 0.01288486 -0.01302769  0.00376922 -0.02679309  0.01222277]
# forecast_predictions_df_5m: [-0.02947139  0.01963992  0.0265572   0.02241913 -0.00885838]
# forecast_predictions_df_6m: [ 0.01255522 -0.0035406   0.04862239 -0.00777894 -0.00075844]
# forecast_predictions_df_7m: [0.00103275 0.00988207 0.02254365 0.00025149 0.01644997]
# forecast_predictions_df_8m: [-0.06551226 -0.05541491 -0.02452666  0.01829897 -0.02866478]
# forecast_predictions_df_9m: [-0.07507518 -0.0026145  -0.00204154 -0.0415247   0.02214629]
# forecast_predictions_df_10m: [-0.02706084  0.01439151  0.00923894  0.01344553  0.00182475]
# forecast_predictions_df_11m: [ 0.01249607 -0.00219852  0.01625485  0.02585728  0.02408737]
# forecast_predictions_df_12m: [ 0.02351864  0.00207909  0.0168433  -0.01723594  0.00103925]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.03379044 -0.01793496 -0.00611308  0.00637002]
# forecast_predictions_df_2w: [ 0.03509515  0.00251342  0.00072631  0.00545636 -0.00375789]
# forecast_predictions_df_3w: [ 0.01559181 -0.00629741  0.03208944  0.03780148]
# forecast_predictions_df_4w: [ 4.50513457e-03  5.08379516e-03  1.77198412e-02 -5.32961969e-05
#  -2.13760131e-02]
# forecast_predictions_df_5w: [ 0.01160291 -0.01003313 -0.01454665  0.00907586  0.0194657 ]
# forecast_predictions_df_6w: [ 0.01952133 -0.0113266   0.02010973  0.01420913  0.02213358]
# forecast_predictions_df_7w: [-0.00385631 -0.01844832  0.02002112 -0.00330816 -0.00427054]
# forecast_predictions_df_8w: [-0.01968334 -0.00652734  0.06791434 -0.00640131]
# forecast_predictions_df_9w: [ 0.00807484 -0.0030625  -0.01133669  0.02163853  0.04037552]
# forecast_predictions_df_10w: [ 0.01602794 -0.01534989  0.02566416  0.03456612 -0.03909752]
# forecast_predictions_df_11w: [-0.01798016  0.03137722 -0.01994208 -0.01807067 -0.00763852]
# forecast_predictions_df_12w: [ 0.00172946 -0.00254108  0.01570183  0.02245426  0.00567352]
# forecast_predictions_df_13w: [-0.00269118 -0.00948779 -0.00055094  0.00023482]
# forecast_predictions_df_14w: [ 0.01288486 -0.01302769  0.00376922 -0.02679309  0.01222277]
# forecast_predictions_df_15w: [ 0.00158532  0.00448613 -0.00881962  0.02300734 -0.02922281]
# forecast_predictions_df_16w: [-0.01511381  0.00816728 -0.03096301 -0.01794729 -0.04545958]
# forecast_predictions_df_17w: [0.01865304 0.02305437 0.00075785 0.01958285 0.02525177]
# forecast_predictions_df_18w: [ 0.00305661 -0.01995775 -0.02947139  0.01963992  0.0265572 ]
# forecast_predictions_df_19w: [ 0.02241913 -0.00885838  0.00281263 -0.00666055  0.01477172]
# forecast_predictions_df_20w: [-0.00041576  0.01685362  0.02976347 -0.00731804 -0.00837131]
# forecast_predictions_df_21w: [ 0.02078518 -0.00128561  0.00821242  0.0137277   0.01859145]
# forecast_predictions_df_22w: [ 0.02289739 -0.01660962 -0.01363095 -0.00721013]
# forecast_predictions_df_23w: [ 0.01255522 -0.0035406   0.04862239 -0.00777894 -0.00075844]
# forecast_predictions_df_24w: [ 0.01451871 -0.00146376  0.02976448  0.01566207  0.00258128]
# forecast_predictions_df_25w: [ 0.01723473  0.0159156  -0.02812759 -0.01486449]
# forecast_predictions_df_26w: [-0.03442325  0.02324415 -0.00343165 -0.00808808  0.00692045]
# forecast_predictions_df_27w: [0.00103275 0.00988207 0.02254365 0.00025149]
# forecast_predictions_df_28w: [ 0.01644997  0.00211882  0.02345285 -0.03638917  0.0125662 ]
# forecast_predictions_df_29w: [-0.00236475 -0.00058561 -0.07143202  0.00472039 -0.0294668 ]
# forecast_predictions_df_30w: [ 0.03798755 -0.01156782 -0.05490119 -0.01900091  0.0151011 ]
# forecast_predictions_df_31w: [-0.00775948 -0.03897475  0.07532172 -0.06551226 -0.05541491]
# forecast_predictions_df_32w: [-0.02452666  0.01829897 -0.02866478  0.06218364 -0.0012671 ]
# forecast_predictions_df_33w: [ 8.37038232e-03  3.96054906e-02 -7.26195670e-05  4.15959553e-02
#   7.52147763e-04]
# forecast_predictions_df_34w: [ 0.01832992 -0.01341992  0.0100056  -0.0329183   0.02444703]
# forecast_predictions_df_35w: [-0.02369391  0.00973717 -0.01701249 -0.01275103  0.0231457 ]
# forecast_predictions_df_36w: [-0.07507518 -0.0026145  -0.00204154 -0.0415247 ]
# forecast_predictions_df_37w: [0.02214629 0.00910365 0.05115359 0.00180129 0.01248643]
# forecast_predictions_df_38w: [-0.01350736 -0.00077092 -0.01188668  0.04295999 -0.01356387]
# forecast_predictions_df_39w: [ 0.00413983  0.01836921  0.00861634  0.02862314 -0.01947673]
# forecast_predictions_df_40w: [-0.00944707 -0.02706084  0.01439151  0.00923894  0.01344553]
# forecast_predictions_df_41w: [ 0.00182475  0.01749793  0.01060538 -0.00182382  0.00810166]
# forecast_predictions_df_42w: [ 0.01790019 -0.05392805  0.0006154   0.01726593 -0.00027213]
# forecast_predictions_df_43w: [ 0.00530791 -0.0045631  -0.01071876  0.0040538   0.01137117]
# forecast_predictions_df_44w: [-0.00705475  0.02254564 -0.02431445 -0.03595735  0.01249607]
# forecast_predictions_df_45w: [-0.00219852  0.01625485  0.02585728  0.02408737 -0.00663472]
# forecast_predictions_df_46w: [-0.02263989 -0.00695645 -0.01692213  0.00200388 -0.03337327]
# forecast_predictions_df_47w: [ 0.0063643   0.01063937 -0.00696838  0.0143993  -0.00630798]
# forecast_predictions_df_48w: [-0.00431302 -0.00956458 -0.01352315  0.01591956]
# forecast_predictions_df_49w: [ 0.02351864  0.00207909  0.0168433  -0.01723594  0.00103925]
# forecast_predictions_df_50w: [-0.01044846 -0.02540955  0.02416503 -0.00989336  0.02492526]
# forecast_predictions_df_51w: [ 0.01492993 -0.0129753  -0.03195046 -0.01309291  0.01581471]
# forecast_predictions_df_52w: [ 0.0311033   0.00846129 -0.0018858  -0.01016099 -0.01516413]
#
#
# ==================================================
#
#
# Ticker: SOXX
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.03618099 -0.02177019 -0.00871407  0.00525224  0.03229167]
# forecast_predictions_df_2m: [ 0.00481763  0.01264215  0.01352984 -0.01181143  0.01505578]
# forecast_predictions_df_3m: [ 0.04233131  0.00957119 -0.01986881  0.02438838  0.0342868 ]
# forecast_predictions_df_4m: [ 0.01031749 -0.01558796  0.00263716 -0.02850616  0.01169548]
# forecast_predictions_df_5m: [-0.03423588  0.02213111  0.02227701  0.02064074 -0.00896352]
# forecast_predictions_df_6m: [ 0.00172354 -0.00773675  0.04367773 -0.0081897  -0.00298319]
# forecast_predictions_df_7m: [-0.0001681   0.01398201  0.01657637  0.00187542  0.01882996]
# forecast_predictions_df_8m: [-0.07295756 -0.05436    -0.01869612  0.00813252 -0.0287626 ]
# forecast_predictions_df_9m: [-0.07669209  0.00299571 -0.00568491 -0.04320743  0.01937255]
# forecast_predictions_df_10m: [-0.02831501  0.01351559  0.00364679  0.01374877 -0.00257592]
# forecast_predictions_df_11m: [ 0.01050772 -0.00589011  0.0114977   0.02890681  0.02064298]
# forecast_predictions_df_12m: [ 0.02613612 -0.00572904  0.0131838  -0.0189943   0.00593974]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.03618099 -0.02177019 -0.00871407  0.00525224]
# forecast_predictions_df_2w: [ 0.03229167  0.00014403 -0.00360438  0.00340704 -0.00466453]
# forecast_predictions_df_3w: [ 0.01380095 -0.00954454  0.03264404  0.03873579]
# forecast_predictions_df_4w: [ 0.00299979  0.00655332  0.01434499 -0.00292117 -0.02721851]
# forecast_predictions_df_5w: [ 0.01023343 -0.01563213 -0.01483292  0.00481763  0.01264215]
# forecast_predictions_df_6w: [ 0.01352984 -0.01181143  0.01505578  0.01706485  0.01977875]
# forecast_predictions_df_7w: [-0.00197768 -0.02078977  0.02247318 -0.0010295  -0.00578049]
# forecast_predictions_df_8w: [-0.01701588 -0.0024736   0.04891394 -0.01103363]
# forecast_predictions_df_9w: [ 0.00964333 -0.00120299 -0.01144891  0.02692494  0.04233131]
# forecast_predictions_df_10w: [ 0.00957119 -0.01986881  0.02438838  0.0342868  -0.04077463]
# forecast_predictions_df_11w: [-0.01349405  0.02059576 -0.02455471 -0.01730034 -0.00743063]
# forecast_predictions_df_12w: [-0.00106275 -0.00871779  0.01671381  0.0222042   0.00097214]
# forecast_predictions_df_13w: [-0.00416323 -0.0078597   0.01223065  0.00084562]
# forecast_predictions_df_14w: [ 0.01031749 -0.01558796  0.00263716 -0.02850616  0.01169548]
# forecast_predictions_df_15w: [ 0.00240774  0.01060052 -0.01836845  0.02247633 -0.03290044]
# forecast_predictions_df_16w: [-0.01276202  0.00748418 -0.03058169 -0.01801805 -0.04030613]
# forecast_predictions_df_17w: [0.01610941 0.02054253 0.01262109 0.01826581 0.02087135]
# forecast_predictions_df_18w: [ 0.0073278  -0.0211196  -0.03423588  0.02213111  0.02227701]
# forecast_predictions_df_19w: [ 0.02064074 -0.00896352  0.00076703 -0.00389457  0.00956972]
# forecast_predictions_df_20w: [ 0.00194756  0.01650544  0.02787785 -0.00495628 -0.00560382]
# forecast_predictions_df_21w: [ 0.02213218 -0.00312858  0.01172342 -0.00564903  0.0198724 ]
# forecast_predictions_df_22w: [ 0.01694845 -0.0206044  -0.00689396 -0.00803331]
# forecast_predictions_df_23w: [ 0.00172354 -0.00773675  0.04367773 -0.0081897  -0.00298319]
# forecast_predictions_df_24w: [ 0.01442033  0.00088295  0.02814117  0.01079544 -0.00362221]
# forecast_predictions_df_25w: [ 0.01578575  0.0127833  -0.02718402 -0.00975867]
# forecast_predictions_df_26w: [-0.02870999  0.01524257 -0.00397037 -0.00530286  0.00991116]
# forecast_predictions_df_27w: [-0.0001681   0.01398201  0.01657637  0.00187542]
# forecast_predictions_df_28w: [ 0.01882996 -0.00050472  0.02314504 -0.03298002  0.01216561]
# forecast_predictions_df_29w: [ 0.00106991  0.00616385 -0.07161075  0.00261526 -0.03098384]
# forecast_predictions_df_30w: [ 0.04100696 -0.01521151 -0.05368376 -0.023007    0.02092586]
# forecast_predictions_df_31w: [-0.00253057 -0.03705689  0.06628011 -0.07295756 -0.05436   ]
# forecast_predictions_df_32w: [-0.01869612  0.00813252 -0.0287626   0.06794172 -0.00665202]
# forecast_predictions_df_33w: [ 0.00498422  0.03979826 -0.0032964   0.04753192 -0.00273657]
# forecast_predictions_df_34w: [ 0.01662114 -0.01357573  0.01391264 -0.03440502  0.02661276]
# forecast_predictions_df_35w: [-0.02537413  0.01076715 -0.01832994 -0.00329809  0.02599666]
# forecast_predictions_df_36w: [-0.07669209  0.00299571 -0.00568491 -0.04320743]
# forecast_predictions_df_37w: [ 0.01937255  0.01030955  0.04599151 -0.00474583  0.01745327]
# forecast_predictions_df_38w: [-0.01357811  0.00097113 -0.01148646  0.04226963 -0.01491639]
# forecast_predictions_df_39w: [ 0.00373475  0.01193183  0.00682534  0.03547635 -0.01600006]
# forecast_predictions_df_40w: [-0.0091493  -0.02831501  0.01351559  0.00364679  0.01374877]
# forecast_predictions_df_41w: [-0.00257592  0.00996449  0.01060034 -0.00689038  0.00837309]
# forecast_predictions_df_42w: [ 1.84846174e-02 -5.20431342e-02 -9.88311351e-05  7.87032879e-03
#   9.40522178e-04]
# forecast_predictions_df_43w: [-0.0018694  -0.00374466 -0.00901001  0.00544082  0.00991665]
# forecast_predictions_df_44w: [ 0.00057379  0.02444528 -0.03541842 -0.03905467  0.01050772]
# forecast_predictions_df_45w: [-0.00589011  0.0114977   0.02890681  0.02064298 -0.0076125 ]
# forecast_predictions_df_46w: [-0.02532276 -0.01122555 -0.0214208  -0.00082287 -0.0325392 ]
# forecast_predictions_df_47w: [ 0.01271747  0.00169158 -0.00795063  0.01549328  0.00012216]
# forecast_predictions_df_48w: [ 0.00944191 -0.01327721 -0.01375017  0.01312314]
# forecast_predictions_df_49w: [ 0.02613612 -0.00572904  0.0131838  -0.0189943   0.00593974]
# forecast_predictions_df_50w: [-0.00488201 -0.02391092  0.02499088 -0.00791389  0.02774459]
# forecast_predictions_df_51w: [ 0.01839291 -0.01410172 -0.03715009 -0.0169412   0.01319613]
# forecast_predictions_df_52w: [ 0.03010669  0.01024366 -0.0003757  -0.00851142 -0.01980062]
#
#
# ==================================================
#
#
# Ticker: PSI
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.03638336 -0.02398447 -0.0146825   0.00104961  0.02826301]
# forecast_predictions_df_2m: [ 0.00783427  0.01128646  0.00873649 -0.01384866  0.00648346]
# forecast_predictions_df_3m: [ 0.04194615  0.00304843 -0.02647134  0.0237303   0.02840839]
# forecast_predictions_df_4m: [ 0.01007279 -0.01053907  0.00996252 -0.02544956  0.01248477]
# forecast_predictions_df_5m: [-0.03345427  0.02905     0.02177967  0.02189679 -0.00517224]
# forecast_predictions_df_6m: [ 0.000335   -0.01038697  0.04585974 -0.00846889 -0.00987657]
# forecast_predictions_df_7m: [-0.00100147  0.01370301  0.01196956  0.00232778  0.01552007]
# forecast_predictions_df_8m: [-0.07981592 -0.05040843 -0.01577007  0.00607267 -0.01710561]
# forecast_predictions_df_9m: [-0.08125868  0.00577567 -0.00782878 -0.04141777  0.01070618]
# forecast_predictions_df_10m: [-0.03701707  0.01790217 -0.00676957  0.02074553  0.00039326]
# forecast_predictions_df_11m: [ 0.00584824 -0.00795146  0.02761727  0.03351134  0.02425826]
# forecast_predictions_df_12m: [ 0.01784247  0.01494176  0.01208443 -0.03011595  0.01725532]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.03638336 -0.02398447 -0.0146825   0.00104961]
# forecast_predictions_df_2w: [ 0.02826301  0.00168412 -0.00471925  0.00269555 -0.00560389]
# forecast_predictions_df_3w: [ 0.01373183 -0.01183756  0.03218197  0.03841752]
# forecast_predictions_df_4w: [ 0.00871777  0.00303902  0.01067725 -0.00130579 -0.02847339]
# forecast_predictions_df_5w: [ 0.0114053  -0.01457151 -0.02018918  0.00783427  0.01128646]
# forecast_predictions_df_6w: [ 0.00873649 -0.01384866  0.00648346  0.01863453  0.03103981]
# forecast_predictions_df_7w: [ 0.00098696 -0.0276992   0.03092149  0.00482317 -0.00064071]
# forecast_predictions_df_8w: [-0.02767107 -0.01160319  0.0432046  -0.01109955]
# forecast_predictions_df_9w: [ 0.01294685 -0.00298263  0.00317143  0.01802153  0.04194615]
# forecast_predictions_df_10w: [ 0.00304843 -0.02647134  0.0237303   0.02840839 -0.03832276]
# forecast_predictions_df_11w: [-0.01562939  0.01649372 -0.02582811 -0.01584096 -0.00922531]
# forecast_predictions_df_12w: [ 0.00644814 -0.00691944  0.0242713   0.02870944  0.00115433]
# forecast_predictions_df_13w: [-0.00101863 -0.00684733  0.01089234 -0.00132271]
# forecast_predictions_df_14w: [ 0.01007279 -0.01053907  0.00996252 -0.02544956  0.01248477]
# forecast_predictions_df_15w: [ 0.00214787  0.00805163 -0.0212662   0.02613976 -0.03328019]
# forecast_predictions_df_16w: [-0.01484185  0.01091287 -0.03281432 -0.0200034  -0.03990339]
# forecast_predictions_df_17w: [0.01548519 0.0232826  0.00851714 0.01644381 0.02126285]
# forecast_predictions_df_18w: [ 0.00811607 -0.02196389 -0.03345427  0.02905     0.02177967]
# forecast_predictions_df_19w: [ 0.02189679 -0.00517224 -0.00056819  0.00122474  0.00588099]
# forecast_predictions_df_20w: [-0.00109238  0.01569457  0.02634124 -0.00850871 -0.00573017]
# forecast_predictions_df_21w: [ 2.10697445e-02  1.96802454e-07  1.14765872e-03 -3.27761855e-03
#   1.68406810e-02]
# forecast_predictions_df_22w: [ 0.01455377 -0.01544004 -0.00238098 -0.0117524 ]
# forecast_predictions_df_23w: [ 0.000335   -0.01038697  0.04585974 -0.00846889 -0.00987657]
# forecast_predictions_df_24w: [ 0.0198431  -0.00057994  0.0283196   0.00786858 -0.00850365]
# forecast_predictions_df_25w: [ 0.02038764  0.01408273 -0.02863748 -0.01182679]
# forecast_predictions_df_26w: [-0.02339837  0.02176634 -0.00256992  0.0014293   0.01228067]
# forecast_predictions_df_27w: [-0.00100147  0.01370301  0.01196956  0.00232778]
# forecast_predictions_df_28w: [ 0.01552007  0.00037863  0.01645947 -0.02931626  0.01154659]
# forecast_predictions_df_29w: [ 0.01157711  0.00721407 -0.08181786 -0.01015281 -0.02616907]
# forecast_predictions_df_30w: [ 0.04141932 -0.00886931 -0.05612919 -0.03065819  0.01582282]
# forecast_predictions_df_31w: [-0.00501292 -0.04742637  0.06336855 -0.07981592 -0.05040843]
# forecast_predictions_df_32w: [-0.01577007  0.00607267 -0.01710561  0.07085912  0.00302933]
# forecast_predictions_df_33w: [ 0.00268761  0.03644145 -0.00220296  0.05145239 -0.00594391]
# forecast_predictions_df_34w: [ 0.0128456  -0.0154449   0.02205123 -0.03196292  0.0264577 ]
# forecast_predictions_df_35w: [-0.02742359  0.01079184 -0.01525538  0.00553554  0.01205951]
# forecast_predictions_df_36w: [-0.08125868  0.00577567 -0.00782878 -0.04141777]
# forecast_predictions_df_37w: [ 0.01070618  0.00692312  0.04089393 -0.0086783   0.02254824]
# forecast_predictions_df_38w: [-0.02285041  0.00718061 -0.01114216  0.04302666 -0.0132121 ]
# forecast_predictions_df_39w: [ 0.00389689  0.01134349  0.0062102   0.04917443 -0.016834  ]
# forecast_predictions_df_40w: [-0.00708446 -0.03701707  0.01790217 -0.00676957  0.02074553]
# forecast_predictions_df_41w: [ 0.00039326  0.00268225  0.01470995 -0.0018536   0.01640731]
# forecast_predictions_df_42w: [ 0.01775679 -0.05600724  0.00150134  0.00193085 -0.00072779]
# forecast_predictions_df_43w: [-0.00316921 -0.00604381 -0.00839941  0.0022426   0.01525604]
# forecast_predictions_df_44w: [-0.00127564  0.02083282 -0.02447433 -0.04413446  0.00584824]
# forecast_predictions_df_45w: [-0.00795146  0.02761727  0.03351134  0.02425826 -0.00448461]
# forecast_predictions_df_46w: [-0.02226634 -0.01287934 -0.02174799 -0.00243037 -0.03934603]
# forecast_predictions_df_47w: [ 1.47972038e-02  8.46255006e-03 -2.26779670e-04  3.37000201e-02
#   3.88423962e-05]
# forecast_predictions_df_48w: [ 0.01313967 -0.0085923  -0.01801349  0.02003281]
# forecast_predictions_df_49w: [ 0.01784247  0.01494176  0.01208443 -0.03011595  0.01725532]
# forecast_predictions_df_50w: [ 0.00860002 -0.02525763  0.02814548 -0.01065231  0.01951275]
# forecast_predictions_df_51w: [ 0.01918843 -0.01265935 -0.03489057 -0.01621784  0.01310641]
# forecast_predictions_df_52w: [ 0.02249614  0.01134709  0.00585422 -0.0139215  -0.02107682]
#
#
# ==================================================
#
#
# Ticker: XSD
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.02970857 -0.03081858 -0.01769076  0.00222209  0.03133071]
# forecast_predictions_df_2m: [-0.00085902  0.00083522  0.00780001 -0.00892792  0.01810443]
# forecast_predictions_df_3m: [ 0.03757212 -0.00131131 -0.02381271  0.02482652  0.03510873]
# forecast_predictions_df_4m: [ 0.0073664  -0.02228825  0.0091178  -0.01580812  0.00508258]
# forecast_predictions_df_5m: [-0.03234496  0.01725936  0.0223232   0.01704427 -0.00358643]
# forecast_predictions_df_6m: [-0.00059287 -0.01507476  0.03884745 -0.00881736 -0.0194879 ]
# forecast_predictions_df_7m: [-0.00386824  0.02011682  0.00947422  0.00478189  0.02126576]
# forecast_predictions_df_8m: [-0.06618479 -0.0606961  -0.03007399  0.00320534 -0.03109285]
# forecast_predictions_df_9m: [-0.07493653  0.00337909 -0.00978763 -0.04243985  0.01674867]
# forecast_predictions_df_10m: [-0.0351453   0.01078777 -0.00212346  0.01797576 -0.00625839]
# forecast_predictions_df_11m: [ 0.0212983  -0.00528171  0.01552657  0.04169477  0.01104502]
# forecast_predictions_df_12m: [ 0.01954213  0.0202638   0.00400272 -0.0213685   0.01741275]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.02970857 -0.03081858 -0.01769076  0.00222209]
# forecast_predictions_df_2w: [ 0.03133071 -0.00201452 -0.00712301 -0.00571968 -0.00941449]
# forecast_predictions_df_3w: [ 0.00072002 -0.01191096  0.03033824  0.03082042]
# forecast_predictions_df_4w: [ 0.01666684  0.00930816 -0.00813528 -0.01049092 -0.02726591]
# forecast_predictions_df_5w: [ 0.01651628 -0.02483347 -0.02008758 -0.00085902  0.00083522]
# forecast_predictions_df_6w: [ 0.00780001 -0.00892792  0.01810443  0.0283101   0.02395192]
# forecast_predictions_df_7w: [ 0.00309271 -0.03663183  0.0242889  -0.0009272  -0.016775  ]
# forecast_predictions_df_8w: [-0.01085537 -0.00227463  0.02226664 -0.01656703]
# forecast_predictions_df_9w: [ 0.01160723 -0.00333603 -0.00726526  0.02329111  0.03757212]
# forecast_predictions_df_10w: [-0.00131131 -0.02381271  0.02482652  0.03510873 -0.02983849]
# forecast_predictions_df_11w: [-0.00672385  0.00816038 -0.02797665 -0.0242327  -0.00800246]
# forecast_predictions_df_12w: [-0.00132513 -0.00680205  0.02311726  0.02205396 -0.00728247]
# forecast_predictions_df_13w: [-0.00202344 -0.00486415  0.0268472   0.00330792]
# forecast_predictions_df_14w: [ 0.0073664  -0.02228825  0.0091178  -0.01580812  0.00508258]
# forecast_predictions_df_15w: [ 0.00850853  0.02170412 -0.03967534  0.02329363 -0.03587323]
# forecast_predictions_df_16w: [-0.02035658  0.00223124 -0.02213437 -0.02023882 -0.03172857]
# forecast_predictions_df_17w: [0.01457522 0.01943881 0.02265205 0.02327055 0.01812847]
# forecast_predictions_df_18w: [ 0.0172734  -0.01844264 -0.03234496  0.01725936  0.0223232 ]
# forecast_predictions_df_19w: [ 0.01704427 -0.00358643  0.00376497  0.00322525 -0.00608157]
# forecast_predictions_df_20w: [ 0.00513154  0.01748345  0.02048553 -0.00499587  0.00062592]
# forecast_predictions_df_21w: [ 0.01315403 -0.00352491  0.02022862 -0.02160953  0.02245489]
# forecast_predictions_df_22w: [ 0.01369356 -0.01898712  0.00492568  0.00043348]
# forecast_predictions_df_23w: [-0.00059287 -0.01507476  0.03884745 -0.00881736 -0.0194879 ]
# forecast_predictions_df_24w: [ 0.0154763   0.00435521  0.02748508 -0.00277266 -0.01691746]
# forecast_predictions_df_25w: [ 0.00728435  0.00109465 -0.02197774  0.00084779]
# forecast_predictions_df_26w: [-0.02010459  0.00866063  0.00061669 -0.00231439  0.01066666]
# forecast_predictions_df_27w: [-0.00386824  0.02011682  0.00947422  0.00478189]
# forecast_predictions_df_28w: [ 0.02126576 -0.00587917  0.02766815 -0.0126682   0.01177741]
# forecast_predictions_df_29w: [ 0.01018282  0.01931208 -0.05621435 -0.00854488 -0.02968247]
# forecast_predictions_df_30w: [ 0.03864337 -0.01615107 -0.04596714 -0.02539376  0.02131451]
# forecast_predictions_df_31w: [-0.00035609 -0.04152386  0.04382553 -0.06618479 -0.0606961 ]
# forecast_predictions_df_32w: [-0.03007399  0.00320534 -0.03109285  0.06843174 -0.00618216]
# forecast_predictions_df_33w: [ 5.15752210e-05  3.96724847e-02 -1.26584565e-02  5.31908175e-02
#  -3.65930365e-03]
# forecast_predictions_df_34w: [ 0.01344088 -0.00979815  0.02209501 -0.02994987  0.03323184]
# forecast_predictions_df_35w: [-0.01824905  0.00613901 -0.01296571  0.01549145  0.01393185]
# forecast_predictions_df_36w: [-0.07493653  0.00337909 -0.00978763 -0.04243985]
# forecast_predictions_df_37w: [ 0.01674867  0.00284915  0.03988693 -0.00711196  0.02181154]
# forecast_predictions_df_38w: [-0.01235672  0.00376706 -0.00370705  0.03890113 -0.01631931]
# forecast_predictions_df_39w: [ 0.003814    0.00968749 -0.0039999   0.04507211 -0.0050313 ]
# forecast_predictions_df_40w: [-0.01022253 -0.0351453   0.01078777 -0.00212346  0.01797576]
# forecast_predictions_df_41w: [-0.00625839  0.00422225  0.01300534 -0.00529619  0.02019348]
# forecast_predictions_df_42w: [ 0.01107667 -0.02713259  0.00619063  0.00344902 -0.00018657]
# forecast_predictions_df_43w: [-3.42295010e-03 -3.19767210e-05 -9.20890426e-03  4.72572821e-03
#   1.11322739e-02]
# forecast_predictions_df_44w: [ 0.0119176   0.02291089 -0.04276097 -0.05100901  0.0212983 ]
# forecast_predictions_df_45w: [-0.00528171  0.01552657  0.04169477  0.01104502  0.00761958]
# forecast_predictions_df_46w: [-0.02809351 -0.01972547 -0.02221486 -0.00836818 -0.03291774]
# forecast_predictions_df_47w: [0.01497298 0.00941689 0.00017681 0.02792085 0.014932  ]
# forecast_predictions_df_48w: [ 0.03163911 -0.01162865 -0.01160121  0.01858343]
# forecast_predictions_df_49w: [ 0.01954213  0.0202638   0.00400272 -0.0213685   0.01741275]
# forecast_predictions_df_50w: [ 0.00669958 -0.02521502  0.02758531 -0.00992376  0.02032698]
# forecast_predictions_df_51w: [ 0.009214   -0.02219315 -0.04466836 -0.01113352  0.01348236]
# forecast_predictions_df_52w: [ 0.0253268   0.01169304  0.0079421  -0.01410218 -0.02320628]
#
#
# ==================================================
#
#
# Ticker: IYW
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.02629491 -0.010173   -0.00691569  0.00091307  0.02633865]
# forecast_predictions_df_2m: [ 0.01204045  0.01867193  0.00094812 -0.00369354  0.01510323]
# forecast_predictions_df_3m: [ 0.01580929 -0.00281612 -0.02354391  0.00880557  0.01769936]
# forecast_predictions_df_4m: [ 0.00352465 -0.00790011  0.00201107 -0.01675148  0.01393836]
# forecast_predictions_df_5m: [-0.00972926  0.01593047  0.02425433  0.01541076 -0.00447354]
# forecast_predictions_df_6m: [ 0.007828    0.00148514  0.02678065 -0.00294656  0.00129691]
# forecast_predictions_df_7m: [0.0100516  0.00681698 0.01100503 0.00913977 0.00503664]
# forecast_predictions_df_8m: [-0.03155901 -0.0257655  -0.03565609  0.00893613 -0.01119398]
# forecast_predictions_df_9m: [-0.04186569 -0.00390316 -0.00016197 -0.02379227  0.01217997]
# forecast_predictions_df_10m: [-0.02303962  0.00613013  0.0044512   0.01304533 -0.00849588]
# forecast_predictions_df_11m: [ 0.00666091 -0.00208407  0.01459451  0.02786829  0.02075978]
# forecast_predictions_df_12m: [ 0.0105472   0.00674389  0.02109407 -0.00575055  0.00520869]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.02629491 -0.010173   -0.00691569  0.00091307]
# forecast_predictions_df_2w: [0.02633865 0.00305774 0.00944982 0.0042949  0.00247542]
# forecast_predictions_df_3w: [ 0.00164972 -0.00546731  0.01905015  0.02360484]
# forecast_predictions_df_4w: [ 0.00417664  0.00412584  0.00719007  0.00440935 -0.00928887]
# forecast_predictions_df_5w: [ 0.01080817 -0.00853    -0.02586587  0.01204045  0.01867193]
# forecast_predictions_df_6w: [ 0.00094812 -0.00369354  0.01510323  0.00436938  0.01495471]
# forecast_predictions_df_7w: [-0.00783005 -0.01739768  0.01232578 -0.00222325 -0.01109829]
# forecast_predictions_df_8w: [-0.01005442 -0.00782415  0.03327444 -0.00216242]
# forecast_predictions_df_9w: [-0.00258439  0.00231273 -0.00690607  0.01109021  0.01580929]
# forecast_predictions_df_10w: [-0.00281612 -0.02354391  0.00880557  0.01769936 -0.01414791]
# forecast_predictions_df_11w: [-0.00434941  0.01971434 -0.00890602  0.00066665 -0.01564506]
# forecast_predictions_df_12w: [0.00811812 0.00440134 0.01260892 0.0026722  0.00324256]
# forecast_predictions_df_13w: [-0.00512409 -0.00512905  0.00088922 -0.00215722]
# forecast_predictions_df_14w: [ 0.00352465 -0.00790011  0.00201107 -0.01675148  0.01393836]
# forecast_predictions_df_15w: [-0.00187552  0.00194366 -0.00719061  0.02106526 -0.0170462 ]
# forecast_predictions_df_16w: [-0.02104087  0.00173453 -0.01562765 -0.00732686 -0.02867818]
# forecast_predictions_df_17w: [ 0.01167039  0.01776035  0.00226731 -0.00519131  0.02117338]
# forecast_predictions_df_18w: [ 0.00045421 -0.02209998 -0.00972926  0.01593047  0.02425433]
# forecast_predictions_df_19w: [ 0.01541076 -0.00447354  0.00018223 -0.00119536  0.00304655]
# forecast_predictions_df_20w: [ 0.00353598  0.00874583  0.0223625  -0.00251201 -0.00235326]
# forecast_predictions_df_21w: [0.01296606 0.00119975 0.00029466 0.00187201 0.00915677]
# forecast_predictions_df_22w: [ 0.0109057  -0.00511974 -0.02545559 -0.0004702 ]
# forecast_predictions_df_23w: [ 0.007828    0.00148514  0.02678065 -0.00294656  0.00129691]
# forecast_predictions_df_24w: [0.00325537 0.01469736 0.02249169 0.00654801 0.00557693]
# forecast_predictions_df_25w: [ 0.01118396  0.00469186 -0.01371507 -0.00635382]
# forecast_predictions_df_26w: [-0.01702464  0.01696139  0.003424    0.00159882 -0.00403159]
# forecast_predictions_df_27w: [0.0100516  0.00681698 0.01100503 0.00913977]
# forecast_predictions_df_28w: [ 0.00503664 -0.00195745  0.01329502 -0.02433845  0.00683283]
# forecast_predictions_df_29w: [ 0.00492473 -0.00289217 -0.03771195 -0.00488054 -0.01101824]
# forecast_predictions_df_30w: [ 0.02007041 -0.00213282 -0.04304163 -0.00948202  0.0107074 ]
# forecast_predictions_df_31w: [-0.00310811 -0.01942933  0.0344132  -0.03155901 -0.0257655 ]
# forecast_predictions_df_32w: [-0.03565609  0.00893613 -0.01119398  0.03503854  0.0064828 ]
# forecast_predictions_df_33w: [0.00517101 0.02754737 0.00306586 0.02488799 0.00153206]
# forecast_predictions_df_34w: [ 0.0134329  -0.00328555  0.00565581 -0.02010237  0.01369637]
# forecast_predictions_df_35w: [-0.00955094  0.00410521 -0.01261161 -0.00423534  0.01119796]
# forecast_predictions_df_36w: [-0.04186569 -0.00390316 -0.00016197 -0.02379227]
# forecast_predictions_df_37w: [0.01217997 0.01085361 0.02784224 0.00845532 0.00516553]
# forecast_predictions_df_38w: [-0.00627479  0.00031253 -0.0048546   0.03047269 -0.00323716]
# forecast_predictions_df_39w: [-0.00114418  0.00705756  0.00340498  0.00966642 -0.00787516]
# forecast_predictions_df_40w: [ 0.00393455 -0.02303962  0.00613013  0.0044512   0.01304533]
# forecast_predictions_df_41w: [-0.00849588  0.01855316  0.00898021  0.00067787  0.0024659 ]
# forecast_predictions_df_42w: [ 0.01293056 -0.01809496  0.00012697  0.00295965  0.0037136 ]
# forecast_predictions_df_43w: [ 0.0067246   0.00022381 -0.01581703  0.003853    0.0063918 ]
# forecast_predictions_df_44w: [ 0.00162939  0.01347392 -0.01188478 -0.03326447  0.00666091]
# forecast_predictions_df_45w: [-0.00208407  0.01459451  0.02786829  0.02075978 -0.00160885]
# forecast_predictions_df_46w: [-0.0046072   0.00348652 -0.00492622 -0.00336349 -0.02534545]
# forecast_predictions_df_47w: [ 0.00419256  0.01235116 -0.00154741  0.006618    0.00037618]
# forecast_predictions_df_48w: [-3.94384505e-05  4.66774952e-03 -1.20336544e-02  8.61470529e-03]
# forecast_predictions_df_49w: [ 0.0105472   0.00674389  0.02109407 -0.00575055  0.00520869]
# forecast_predictions_df_50w: [-0.00775177 -0.01100288  0.01752407 -0.00555704 -0.000131  ]
# forecast_predictions_df_51w: [ 0.01174859 -0.00592729 -0.03376484 -0.00043479  0.01537893]
# forecast_predictions_df_52w: [ 0.01029794  0.00995517  0.00028457 -0.01491411 -0.01211278]
#
#
# ==================================================
#
#
# Ticker: XLK
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.02616821 -0.01021874 -0.00736029 -0.000343    0.02493133]
# forecast_predictions_df_2m: [ 0.0125696   0.01039974  0.0023479  -0.00458184  0.01322639]
# forecast_predictions_df_3m: [ 1.82175106e-02 -4.45859142e-05 -2.45850221e-02  7.83336056e-03
#   1.57283786e-02]
# forecast_predictions_df_4m: [ 0.00274268 -0.00964986  0.00261425 -0.01579679  0.0114101 ]
# forecast_predictions_df_5m: [-0.01039787  0.01423114  0.02769195  0.01167288 -0.00327994]
# forecast_predictions_df_6m: [ 0.00254676  0.00214507  0.02220481 -0.00331094  0.00235864]
# forecast_predictions_df_7m: [0.00755875 0.00500663 0.01348785 0.00308866 0.00683447]
# forecast_predictions_df_8m: [-0.03764261 -0.02851067 -0.03382247  0.01301156 -0.01674032]
# forecast_predictions_df_9m: [-0.04597766 -0.00266584 -0.00165312 -0.02605645  0.01613263]
# forecast_predictions_df_10m: [-0.02442355  0.00744172  0.0042107   0.01118306 -0.00675051]
# forecast_predictions_df_11m: [ 0.00744622 -0.00079883  0.01398758  0.02833465  0.01734439]
# forecast_predictions_df_12m: [ 0.00949885  0.00362531  0.018336   -0.00498082  0.00394719]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.02616821 -0.01021874 -0.00736029 -0.000343  ]
# forecast_predictions_df_2w: [0.02493133 0.00155222 0.00842548 0.00501117 0.00315745]
# forecast_predictions_df_3w: [ 0.00241142 -0.00500376  0.02010617  0.0229337 ]
# forecast_predictions_df_4w: [ 0.00437183  0.00405817  0.00691244  0.00421349 -0.01147285]
# forecast_predictions_df_5w: [ 0.00916932 -0.00824219 -0.0209931   0.0125696   0.01039974]
# forecast_predictions_df_6w: [ 0.0023479  -0.00458184  0.01322639  0.0031596   0.01347447]
# forecast_predictions_df_7w: [-0.00757229 -0.01696924  0.01040629 -0.0020834  -0.00914047]
# forecast_predictions_df_8w: [-0.01018817 -0.00634374  0.03254228 -0.00238292]
# forecast_predictions_df_9w: [ 0.00085661  0.00080361 -0.00481371  0.01103366  0.01821751]
# forecast_predictions_df_10w: [-4.45859142e-05 -2.45850221e-02  7.83336056e-03  1.57283786e-02
#  -1.48447959e-02]
# forecast_predictions_df_11w: [-0.0028339   0.02035139 -0.0108621   0.00012455 -0.01513531]
# forecast_predictions_df_12w: [0.00478787 0.00508178 0.01109344 0.00070506 0.00034156]
# forecast_predictions_df_13w: [-0.00665661 -0.00410986  0.00508051 -0.00220847]
# forecast_predictions_df_14w: [ 0.00274268 -0.00964986  0.00261425 -0.01579679  0.0114101 ]
# forecast_predictions_df_15w: [-0.001188    0.00503011 -0.01224919  0.01988221 -0.01619254]
# forecast_predictions_df_16w: [-0.01901598  0.00115797 -0.01446624 -0.01148531 -0.02076242]
# forecast_predictions_df_17w: [ 0.00877581  0.01462332  0.00443194 -0.00230638  0.01114675]
# forecast_predictions_df_18w: [ 0.00417808 -0.02215519 -0.01039787  0.01423114  0.02769195]
# forecast_predictions_df_19w: [ 0.01167288 -0.00327994  0.00279388 -0.00036004  0.00363671]
# forecast_predictions_df_20w: [ 0.00466966  0.00883652  0.02247537 -0.0034001  -0.00211098]
# forecast_predictions_df_21w: [ 0.01190033  0.00172579  0.00228355 -0.00802426  0.00851309]
# forecast_predictions_df_22w: [ 0.00429048 -0.00627353 -0.02272192  0.00164432]
# forecast_predictions_df_23w: [ 0.00254676  0.00214507  0.02220481 -0.00331094  0.00235864]
# forecast_predictions_df_24w: [0.00257285 0.0185627  0.02206774 0.00792492 0.00378801]
# forecast_predictions_df_25w: [ 0.01523918  0.00139319 -0.01111627 -0.00169154]
# forecast_predictions_df_26w: [-0.0244743   0.01830563 -0.00114093  0.00050357 -0.00059712]
# forecast_predictions_df_27w: [0.00755875 0.00500663 0.01348785 0.00308866]
# forecast_predictions_df_28w: [ 0.00683447 -0.00076906  0.01452223 -0.02489168  0.00892998]
# forecast_predictions_df_29w: [ 1.83668555e-03 -3.30431026e-03 -3.88810051e-02 -1.29767637e-05
#  -1.57313438e-02]
# forecast_predictions_df_30w: [ 0.0234778  -0.00412446 -0.04151482 -0.01099148  0.01238108]
# forecast_predictions_df_31w: [-0.00468135 -0.02541804  0.0418706  -0.03764261 -0.02851067]
# forecast_predictions_df_32w: [-0.03382247  0.01301156 -0.01674032  0.03667329  0.00406383]
# forecast_predictions_df_33w: [0.00776287 0.03026645 0.00511467 0.02851011 0.00143262]
# forecast_predictions_df_34w: [ 0.01629657 -0.00361355  0.00583312 -0.02295137  0.01623567]
# forecast_predictions_df_35w: [-0.0125668   0.00600017 -0.01378438 -0.00914671  0.01321841]
# forecast_predictions_df_36w: [-0.04597766 -0.00266584 -0.00165312 -0.02605645]
# forecast_predictions_df_37w: [0.01613263 0.01477968 0.03389072 0.00813828 0.00488451]
# forecast_predictions_df_38w: [-0.00392096 -0.00207853 -0.00930779  0.02952304 -0.00496573]
# forecast_predictions_df_39w: [-0.0002292   0.00683074  0.00285411  0.01317917 -0.00936741]
# forecast_predictions_df_40w: [ 0.00289761 -0.02442355  0.00744172  0.0042107   0.01118306]
# forecast_predictions_df_41w: [-0.00675051  0.01873029  0.01129429 -0.00015581  0.00178209]
# forecast_predictions_df_42w: [ 0.01305384 -0.02193526  0.003145    0.00317785  0.00365588]
# forecast_predictions_df_43w: [ 0.00476523 -0.00094968 -0.0142312   0.00294401  0.00519245]
# forecast_predictions_df_44w: [-0.00031492  0.01342022 -0.01582494 -0.03205542  0.00744622]
# forecast_predictions_df_45w: [-0.00079883  0.01398758  0.02833465  0.01734439 -0.00111391]
# forecast_predictions_df_46w: [-0.00555974  0.00121425 -0.00348467 -0.00343202 -0.02484671]
# forecast_predictions_df_47w: [ 0.00318926  0.00814973 -0.00091571  0.01009118  0.00045369]
# forecast_predictions_df_48w: [-0.00015706  0.00490519 -0.01360996  0.00919678]
# forecast_predictions_df_49w: [ 0.00949885  0.00362531  0.018336   -0.00498082  0.00394719]
# forecast_predictions_df_50w: [-0.00645856 -0.01385988  0.0144597  -0.00558071  0.00425699]
# forecast_predictions_df_51w: [ 0.01002049 -0.00593801 -0.03220214  0.00106768  0.01483877]
# forecast_predictions_df_52w: [ 0.01053356  0.01030049  0.00067423 -0.01327164 -0.01271992]
#
#
# ==================================================
#
#
# Ticker: VGT
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.02631886 -0.01352865 -0.00609158  0.00018069  0.02533946]
# forecast_predictions_df_2m: [ 0.01289457  0.00980641  0.00050784 -0.0017143   0.0128913 ]
# forecast_predictions_df_3m: [ 0.01851742  0.00179467 -0.02412745  0.01104765  0.01678336]
# forecast_predictions_df_4m: [ 0.00200726 -0.01134398  0.00204039 -0.01616788  0.01212407]
# forecast_predictions_df_5m: [-0.01095004  0.01356321  0.02693897  0.01443011 -0.00416123]
# forecast_predictions_df_6m: [ 5.24919991e-03  6.56635548e-04  2.54974109e-02 -2.84022986e-03
#  -7.85673665e-05]
# forecast_predictions_df_7m: [0.00979069 0.00664381 0.01155678 0.00507138 0.00669352]
# forecast_predictions_df_8m: [-0.0364988  -0.02487462 -0.035465    0.00954559 -0.01206038]
# forecast_predictions_df_9m: [-0.0442353  -0.00226992 -0.0023843  -0.02422873  0.01331599]
# forecast_predictions_df_10m: [-0.0252693   0.00631804  0.00395258  0.01286785 -0.00716317]
# forecast_predictions_df_11m: [ 0.00711572 -0.00103448  0.01444269  0.03123658  0.02041711]
# forecast_predictions_df_12m: [ 0.00981008  0.00519115  0.02034083 -0.0049452   0.0052296 ]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.02631886 -0.01352865 -0.00609158  0.00018069]
# forecast_predictions_df_2w: [0.02533946 0.00171269 0.00838263 0.00339398 0.00212478]
# forecast_predictions_df_3w: [ 0.00137923 -0.00556357  0.0193579   0.02166042]
# forecast_predictions_df_4w: [ 0.00650965  0.00421699  0.00481634  0.00239955 -0.01038298]
# forecast_predictions_df_5w: [ 0.01165861 -0.0096606  -0.02083491  0.01289457  0.00980641]
# forecast_predictions_df_6w: [ 0.00050784 -0.0017143   0.0128913   0.00502331  0.01514153]
# forecast_predictions_df_7w: [-0.00629061 -0.01963455  0.01328574 -0.00081083 -0.01060424]
# forecast_predictions_df_8w: [-0.01185485 -0.0086229   0.03240248 -0.00346297]
# forecast_predictions_df_9w: [ 0.0025119   0.00135903 -0.00478084  0.00939622  0.01851742]
# forecast_predictions_df_10w: [ 0.00179467 -0.02412745  0.01104765  0.01678336 -0.01639033]
# forecast_predictions_df_11w: [-0.00438503  0.02060194 -0.01067609 -0.00383228 -0.01323243]
# forecast_predictions_df_12w: [0.00458531 0.00411107 0.0134542  0.00276239 0.00156055]
# forecast_predictions_df_13w: [-0.00411435 -0.00444242  0.00232546 -0.00148812]
# forecast_predictions_df_14w: [ 0.00200726 -0.01134398  0.00204039 -0.01616788  0.01212407]
# forecast_predictions_df_15w: [-0.00147888  0.00224352 -0.00913027  0.01926298 -0.0178203 ]
# forecast_predictions_df_16w: [-0.01910146  0.00054281 -0.01491272 -0.00957447 -0.02670331]
# forecast_predictions_df_17w: [0.01348937 0.01626847 0.00146729 0.00025843 0.01704934]
# forecast_predictions_df_18w: [ 0.00382558 -0.02229822 -0.01095004  0.01356321  0.02693897]
# forecast_predictions_df_19w: [ 0.01443011 -0.00416123  0.00145276 -0.0010369   0.00256953]
# forecast_predictions_df_20w: [ 0.00485311  0.01025906  0.02287359 -0.00420017 -0.00235267]
# forecast_predictions_df_21w: [1.28018641e-02 1.02372756e-03 2.43026752e-04 8.60177313e-05
#  9.78409809e-03]
# forecast_predictions_df_22w: [ 0.00865673 -0.00344835 -0.02354478 -0.00084737]
# forecast_predictions_df_23w: [ 5.24919991e-03  6.56635548e-04  2.54974109e-02 -2.84022986e-03
#  -7.85673665e-05]
# forecast_predictions_df_24w: [0.00346738 0.01400594 0.02149033 0.00987287 0.00389041]
# forecast_predictions_df_25w: [ 0.01228754  0.00409646 -0.01364023 -0.00510088]
# forecast_predictions_df_26w: [-0.0183476   0.01435587  0.00201133  0.00198318 -0.00036691]
# forecast_predictions_df_27w: [0.00979069 0.00664381 0.01155678 0.00507138]
# forecast_predictions_df_28w: [ 0.00669352 -0.00211583  0.0137803  -0.01922307  0.00931574]
# forecast_predictions_df_29w: [ 0.00516088  0.00122884 -0.03609903 -0.00533185 -0.01196923]
# forecast_predictions_df_30w: [ 0.01980777 -0.00196015 -0.03946198 -0.00962092  0.01160061]
# forecast_predictions_df_31w: [-0.00386586 -0.01933224  0.03474725 -0.0364988  -0.02487462]
# forecast_predictions_df_32w: [-0.035465    0.00954559 -0.01206038  0.03422249  0.00606262]
# forecast_predictions_df_33w: [0.00491571 0.02858593 0.00412611 0.02674368 0.00207242]
# forecast_predictions_df_34w: [ 0.01379967 -0.00342905  0.00569415 -0.02093849  0.01789407]
# forecast_predictions_df_35w: [-0.0094818   0.0046288  -0.01323382 -0.00278212  0.01034489]
# forecast_predictions_df_36w: [-0.0442353  -0.00226992 -0.0023843  -0.02422873]
# forecast_predictions_df_37w: [0.01331599 0.00998751 0.02865613 0.00755043 0.00578611]
# forecast_predictions_df_38w: [-0.00598424 -0.00061563 -0.00477227  0.02950757 -0.00354021]
# forecast_predictions_df_39w: [-0.00037588  0.00907795  0.00068561  0.01238548 -0.00746581]
# forecast_predictions_df_40w: [ 0.00260425 -0.0252693   0.00631804  0.00395258  0.01286785]
# forecast_predictions_df_41w: [-0.00716317  0.01827934  0.0112192   0.00091026  0.00312814]
# forecast_predictions_df_42w: [ 0.0124125  -0.01802579  0.00372955  0.00403131  0.00352882]
# forecast_predictions_df_43w: [ 0.00565982 -0.00065317 -0.01549214  0.00342036  0.00471094]
# forecast_predictions_df_44w: [ 0.00202904  0.01179249 -0.01310234 -0.03329984  0.00711572]
# forecast_predictions_df_45w: [-0.00103448  0.01444269  0.03123658  0.02041711 -0.00178666]
# forecast_predictions_df_46w: [-0.00413868  0.00170302 -0.00410243 -0.00413546 -0.02442929]
# forecast_predictions_df_47w: [0.00291742 0.01229929 0.00104104 0.01051209 0.00361764]
# forecast_predictions_df_48w: [-0.00062631  0.0028915  -0.01042675  0.00881485]
# forecast_predictions_df_49w: [ 0.00981008  0.00519115  0.02034083 -0.0049452   0.0052296 ]
# forecast_predictions_df_50w: [-0.00744705 -0.01436576  0.0153253  -0.00433928  0.00472754]
# forecast_predictions_df_51w: [ 0.01181918 -0.00607279 -0.03420408  0.00076118  0.01570324]
# forecast_predictions_df_52w: [ 0.00917801  0.01092062  0.00167061 -0.01564648 -0.01256241]
#
#
# ==================================================
#
#
# Ticker: FTEC
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.02691178 -0.01197819 -0.00752998  0.00052317  0.02527843]
# forecast_predictions_df_2m: [ 0.01276118  0.00994099  0.00095443 -0.00263936  0.01303951]
# forecast_predictions_df_3m: [ 0.01940847  0.00078864 -0.0234898   0.01077125  0.01703014]
# forecast_predictions_df_4m: [ 0.00040787 -0.00971039  0.00197369 -0.01597905  0.01194034]
# forecast_predictions_df_5m: [-0.01163328  0.01471756  0.02625359  0.0160071  -0.00550996]
# forecast_predictions_df_6m: [ 0.00636464  0.00140283  0.0263582  -0.00397787 -0.00069171]
# forecast_predictions_df_7m: [0.00935117 0.00684794 0.01105796 0.00494073 0.00857885]
# forecast_predictions_df_8m: [-0.03569984 -0.02669833 -0.03462033  0.00945461 -0.01302123]
# forecast_predictions_df_9m: [-0.04347814 -0.0032413  -0.00155101 -0.02367474  0.01238921]
# forecast_predictions_df_10m: [-0.02577976  0.00674244  0.00401389  0.01239619 -0.0066612 ]
# forecast_predictions_df_11m: [ 0.00776561 -0.00131831  0.01476681  0.0310454   0.02077298]
# forecast_predictions_df_12m: [ 0.00923503  0.00467704  0.02050941 -0.00493933  0.00510743]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.02691178 -0.01197819 -0.00752998  0.00052317]
# forecast_predictions_df_2w: [0.02527843 0.00125378 0.00868836 0.00417298 0.00240419]
# forecast_predictions_df_3w: [ 0.0011852  -0.00573015  0.01946517  0.02219757]
# forecast_predictions_df_4w: [ 0.00643753  0.00410777  0.00461762  0.00241793 -0.01009764]
# forecast_predictions_df_5w: [ 0.01127636 -0.00847293 -0.02181645  0.01276118  0.00994099]
# forecast_predictions_df_6w: [ 0.00095443 -0.00263936  0.01303951  0.00554889  0.01489599]
# forecast_predictions_df_7w: [-0.00661134 -0.01946247  0.01303835 -0.00177987 -0.01018552]
# forecast_predictions_df_8w: [-0.01098987 -0.00899455  0.03287572 -0.00318012]
# forecast_predictions_df_9w: [ 0.00202423  0.00058776 -0.00418011  0.00917834  0.01940847]
# forecast_predictions_df_10w: [ 0.00078864 -0.0234898   0.01077125  0.01703014 -0.01638512]
# forecast_predictions_df_11w: [-0.00451269  0.02032801 -0.01023347 -0.00380727 -0.01400687]
# forecast_predictions_df_12w: [0.00493191 0.00461064 0.01285714 0.0023752  0.00199709]
# forecast_predictions_df_13w: [-0.00444939 -0.00550172  0.00327994 -0.0019048 ]
# forecast_predictions_df_14w: [ 0.00040787 -0.00971039  0.00197369 -0.01597905  0.01194034]
# forecast_predictions_df_15w: [-0.00160658  0.00367606 -0.01105963  0.02079374 -0.01801679]
# forecast_predictions_df_16w: [-0.02154587  0.00263264 -0.01628312 -0.00893767 -0.02722926]
# forecast_predictions_df_17w: [0.01211054 0.01796339 0.00213044 0.00176663 0.01623476]
# forecast_predictions_df_18w: [ 0.00254568 -0.02187368 -0.01163328  0.01471756  0.02625359]
# forecast_predictions_df_19w: [ 0.0160071  -0.00550996  0.00070156 -0.00037965  0.00314171]
# forecast_predictions_df_20w: [ 0.00477686  0.00943888  0.02374535 -0.00373442 -0.00332453]
# forecast_predictions_df_21w: [0.01258562 0.00136352 0.00100142 0.00019497 0.00956591]
# forecast_predictions_df_22w: [ 0.00978685 -0.00530012 -0.0235558  -0.00220953]
# forecast_predictions_df_23w: [ 0.00636464  0.00140283  0.0263582  -0.00397787 -0.00069171]
# forecast_predictions_df_24w: [0.00431064 0.01353357 0.02337481 0.00901789 0.00377585]
# forecast_predictions_df_25w: [ 0.01197184  0.00399122 -0.01327216 -0.0053664 ]
# forecast_predictions_df_26w: [-0.01845592  0.01414183  0.00348036  0.00204046 -0.00155074]
# forecast_predictions_df_27w: [0.00935117 0.00684794 0.01105796 0.00494073]
# forecast_predictions_df_28w: [ 0.00857885 -0.00377496  0.0135119  -0.02050141  0.01110586]
# forecast_predictions_df_29w: [ 0.00463678  0.00151356 -0.0361773  -0.00511522 -0.01200326]
# forecast_predictions_df_30w: [ 0.01892005 -0.00138446 -0.03912194 -0.01003131  0.01076081]
# forecast_predictions_df_31w: [-0.00402875 -0.01994549  0.03597696 -0.03569984 -0.02669833]
# forecast_predictions_df_32w: [-0.03462033  0.00945461 -0.01302123  0.03543848  0.00391978]
# forecast_predictions_df_33w: [0.00587719 0.029021   0.00394726 0.026695   0.00209812]
# forecast_predictions_df_34w: [ 0.0133693  -0.00369769  0.00641502 -0.01923367  0.01671312]
# forecast_predictions_df_35w: [-0.01055773  0.00500407 -0.01268352 -0.00347754  0.00962439]
# forecast_predictions_df_36w: [-0.04347814 -0.0032413  -0.00155101 -0.02367474]
# forecast_predictions_df_37w: [0.01238921 0.01092157 0.02852399 0.00749005 0.0062413 ]
# forecast_predictions_df_38w: [-0.00721505  0.00058513 -0.00616064  0.0310417  -0.00350083]
# forecast_predictions_df_39w: [-0.00124826  0.00792851  0.0018839   0.0128484  -0.00793781]
# forecast_predictions_df_40w: [ 0.0034947  -0.02577976  0.00674244  0.00401389  0.01239619]
# forecast_predictions_df_41w: [-0.0066612   0.01740111  0.01141707  0.00160884  0.00316318]
# forecast_predictions_df_42w: [ 0.01219643 -0.0165555   0.0018493   0.00322004  0.00411751]
# forecast_predictions_df_43w: [ 0.00564248 -0.0012712  -0.01479145  0.00339329  0.0052526 ]
# forecast_predictions_df_44w: [ 0.00092088  0.01300896 -0.01483678 -0.03311853  0.00776561]
# forecast_predictions_df_45w: [-0.00131831  0.01476681  0.0310454   0.02077298 -0.00113987]
# forecast_predictions_df_46w: [-0.00409372  0.00081392 -0.00423504 -0.00418565 -0.0237044 ]
# forecast_predictions_df_47w: [0.00271355 0.012491   0.00063119 0.01095426 0.00336697]
# forecast_predictions_df_48w: [-0.00012415  0.00308362 -0.01139801  0.00991954]
# forecast_predictions_df_49w: [ 0.00923503  0.00467704  0.02050941 -0.00493933  0.00510743]
# forecast_predictions_df_50w: [-0.00752373 -0.01407536  0.01487423 -0.00406715  0.00468964]
# forecast_predictions_df_51w: [ 0.01183179 -0.00638473 -0.0335567   0.00046505  0.0159292 ]
# forecast_predictions_df_52w: [ 0.00857882  0.01060147  0.001844   -0.01529313 -0.0125491 ]
#
#
# ==================================================
#
#
# Ticker: IGM
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.02647922 -0.0119413  -0.00410443  0.00226313  0.02769425]
# forecast_predictions_df_2m: [ 0.01160076  0.02818058  0.00145151 -0.00533274  0.01557641]
# forecast_predictions_df_3m: [ 0.02126757  0.00115984 -0.02029099  0.01230945  0.02106783]
# forecast_predictions_df_4m: [ 0.00544604 -0.0077225   0.00385971 -0.0170914   0.01321317]
# forecast_predictions_df_5m: [-0.00827176  0.01532306  0.02084098  0.01627232 -0.00126479]
# forecast_predictions_df_6m: [ 0.00467496  0.0023727   0.02630595 -0.00258811 -0.00147937]
# forecast_predictions_df_7m: [0.00658156 0.00727402 0.00931796 0.01139574 0.0026564 ]
# forecast_predictions_df_8m: [-0.02628583 -0.02979454 -0.03157977  0.01168704 -0.00974242]
# forecast_predictions_df_9m: [-3.88836959e-02 -2.10043944e-03 -1.07385021e-05 -2.68964555e-02
#   1.04865675e-02]
# forecast_predictions_df_10m: [-0.01835219  0.00519004  0.00496259  0.01347457 -0.0100058 ]
# forecast_predictions_df_11m: [ 0.00597571 -0.00302054  0.01418889  0.02960496  0.02166849]
# forecast_predictions_df_12m: [ 0.01158273  0.00629724  0.0193088  -0.00684202  0.00888318]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.02647922 -0.0119413  -0.00410443  0.00226313]
# forecast_predictions_df_2w: [0.02769425 0.00341123 0.00992575 0.00554354 0.00179658]
# forecast_predictions_df_3w: [ 0.00187697 -0.00565442  0.01761206  0.02511468]
# forecast_predictions_df_4w: [ 0.00463342  0.0048456   0.00998622  0.00557378 -0.00903127]
# forecast_predictions_df_5w: [ 0.01330483 -0.00739759 -0.02486364  0.01160076  0.02818058]
# forecast_predictions_df_6w: [ 0.00145151 -0.00533274  0.01557641  0.0054981   0.01502456]
# forecast_predictions_df_7w: [-0.00504994 -0.01811678  0.01765335 -0.00068325 -0.01203252]
# forecast_predictions_df_8w: [-0.01421346 -0.01065037  0.04306162 -0.00232819]
# forecast_predictions_df_9w: [ 0.00089502  0.00170547 -0.00705385  0.01249132  0.02126757]
# forecast_predictions_df_10w: [ 0.00115984 -0.02029099  0.01230945  0.02106783 -0.01964058]
# forecast_predictions_df_11w: [-0.0076222   0.02233497 -0.00934356 -0.00604336 -0.01463585]
# forecast_predictions_df_12w: [0.0107541  0.00171121 0.01357249 0.00267767 0.00337846]
# forecast_predictions_df_13w: [-0.00493612 -0.00389432  0.00073525 -0.00196597]
# forecast_predictions_df_14w: [ 0.00544604 -0.0077225   0.00385971 -0.0170914   0.01321317]
# forecast_predictions_df_15w: [-0.00057668  0.00364867 -0.00933566  0.01747158 -0.0182228 ]
# forecast_predictions_df_16w: [-0.02057816  0.00219113 -0.01335552 -0.00519018 -0.02803544]
# forecast_predictions_df_17w: [ 0.01048146  0.01943006  0.00028807 -0.00977628  0.02364243]
# forecast_predictions_df_18w: [-0.0038053  -0.01976711 -0.00827176  0.01532306  0.02084098]
# forecast_predictions_df_19w: [ 0.01627232 -0.00126479 -0.00093338 -0.00153542  0.00243038]
# forecast_predictions_df_20w: [ 0.00153831  0.00880145  0.02356047 -0.00340388 -0.00101047]
# forecast_predictions_df_21w: [ 0.01099002 -0.00087155  0.00134435 -0.00327118  0.00900573]
# forecast_predictions_df_22w: [ 0.00828183 -0.00540708 -0.02471107 -0.00088623]
# forecast_predictions_df_23w: [ 0.00467496  0.0023727   0.02630595 -0.00258811 -0.00147937]
# forecast_predictions_df_24w: [0.00585706 0.01037202 0.0184714  0.00502557 0.00639524]
# forecast_predictions_df_25w: [ 0.01023072  0.0027826  -0.00982483 -0.00378277]
# forecast_predictions_df_26w: [-0.01480323  0.01495882  0.00039721  0.00537666 -0.00342973]
# forecast_predictions_df_27w: [0.00658156 0.00727402 0.00931796 0.01139574]
# forecast_predictions_df_28w: [ 0.0026564  -0.00304122  0.0108002  -0.02217404  0.00569552]
# forecast_predictions_df_29w: [ 0.00524513 -0.00033234 -0.03754495 -0.00376677 -0.01075405]
# forecast_predictions_df_30w: [ 0.0195021  -0.00187445 -0.03974176 -0.00978196  0.01197637]
# forecast_predictions_df_31w: [-0.00367795 -0.0159973   0.03126196 -0.02628583 -0.02979454]
# forecast_predictions_df_32w: [-0.03157977  0.01168704 -0.00974242  0.03559068  0.00685246]
# forecast_predictions_df_33w: [0.00078732 0.02597017 0.00063481 0.02553006 0.00038724]
# forecast_predictions_df_34w: [ 0.01284268 -0.00185386  0.00607403 -0.01803277  0.01270308]
# forecast_predictions_df_35w: [-0.00987825  0.00376885 -0.01303665 -0.00037115  0.01053325]
# forecast_predictions_df_36w: [-3.88836959e-02 -2.10043944e-03 -1.07385021e-05 -2.68964555e-02]
# forecast_predictions_df_37w: [0.01048657 0.00973308 0.02449715 0.00963034 0.00637985]
# forecast_predictions_df_38w: [-0.00176237  0.00082682 -0.00493921  0.02912801 -0.00137805]
# forecast_predictions_df_39w: [ 0.00066511  0.00619841  0.00096812  0.01172096 -0.00701903]
# forecast_predictions_df_40w: [ 0.00326913 -0.01835219  0.00519004  0.00496259  0.01347457]
# forecast_predictions_df_41w: [-0.0100058   0.01711357  0.00807796 -0.00038542  0.00390258]
# forecast_predictions_df_42w: [ 0.00987587 -0.01714238 -0.00022737  0.000636    0.00514151]
# forecast_predictions_df_43w: [ 3.26716057e-03  7.74378475e-05 -1.58772426e-02  3.04203472e-03
#   6.20362769e-03]
# forecast_predictions_df_44w: [ 0.00249654  0.01544984 -0.01088663 -0.02882968  0.00597571]
# forecast_predictions_df_45w: [-0.00302054  0.01418889  0.02960496  0.02166849 -0.00230141]
# forecast_predictions_df_46w: [-0.00212634  0.00334193 -0.00426134 -0.00715841 -0.02474162]
# forecast_predictions_df_47w: [0.00559164 0.01099859 0.00012471 0.00612687 0.00068195]
# forecast_predictions_df_48w: [ 0.0023259   0.00310181 -0.0107035   0.00851557]
# forecast_predictions_df_49w: [ 0.01158273  0.00629724  0.0193088  -0.00684202  0.00888318]
# forecast_predictions_df_50w: [-0.00876211 -0.00799011  0.02061143 -0.00628268  0.00309469]
# forecast_predictions_df_51w: [ 0.01451271 -0.00835262 -0.03551431 -0.00077849  0.0127091 ]
# forecast_predictions_df_52w: [ 0.01024876  0.01136802  0.00011388 -0.01350564 -0.01353406]
#
#
# ==================================================
#
#
# Ticker: IXN
# ==================================================
# No statsmodels summary available for this model.
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-2.74874117e-02 -1.18378321e-02 -5.86543184e-03 -7.20021095e-05
#   2.47721717e-02]
# forecast_predictions_df_2m: [ 0.01290735  0.01025052  0.00243483 -0.00250222  0.01342624]
# forecast_predictions_df_3m: [ 0.01848972  0.00181163 -0.02251718  0.01057627  0.01712654]
# forecast_predictions_df_4m: [ 0.00309123 -0.0081164   0.00205722 -0.0165409   0.0117809 ]
# forecast_predictions_df_5m: [-0.00942765  0.01453981  0.02808787  0.01374957 -0.00345537]
# forecast_predictions_df_6m: [ 0.00972512  0.00237384  0.02619597 -0.00173937  0.00065512]
# forecast_predictions_df_7m: [0.00967606 0.00588086 0.01548211 0.00515862 0.00803083]
# forecast_predictions_df_8m: [-0.03800646 -0.02854851 -0.03368915  0.01205974 -0.01182785]
# forecast_predictions_df_9m: [-0.04629913 -0.00296266 -0.00250439 -0.02769065  0.01587638]
# forecast_predictions_df_10m: [-0.02103482  0.00467587  0.00047703  0.00924064 -0.00950018]
# forecast_predictions_df_11m: [ 0.00326358 -0.0019633   0.01401729  0.01746194  0.01967712]
# forecast_predictions_df_12m: [ 0.01191694  0.00411715  0.01484603 -0.00148292  0.00313248]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-2.74874117e-02 -1.18378321e-02 -5.86543184e-03 -7.20021095e-05]
# forecast_predictions_df_2w: [ 0.02477217 -0.00098101  0.008584    0.00390399  0.00373333]
# forecast_predictions_df_3w: [-0.00030085 -0.00543478  0.02122365  0.02273347]
# forecast_predictions_df_4w: [ 0.00422651  0.00384382  0.00791281  0.00458102 -0.00960744]
# forecast_predictions_df_5w: [ 0.00854094 -0.00769398 -0.01969578  0.01290735  0.01025052]
# forecast_predictions_df_6w: [ 0.00243483 -0.00250222  0.01342624  0.00497181  0.01152987]
# forecast_predictions_df_7w: [-0.00835787 -0.0178358   0.01152345 -0.00071731 -0.00897905]
# forecast_predictions_df_8w: [-9.93895102e-03 -5.85220316e-03  3.22519338e-02  2.65963561e-05]
# forecast_predictions_df_9w: [ 0.0006836  -0.00108937 -0.00441068  0.00935531  0.01848972]
# forecast_predictions_df_10w: [ 0.00181163 -0.02251718  0.01057627  0.01712654 -0.01452561]
# forecast_predictions_df_11w: [-0.00672782  0.02144935 -0.00981179 -0.00074891 -0.01513496]
# forecast_predictions_df_12w: [0.00588047 0.00394064 0.01460716 0.0024841  0.00218925]
# forecast_predictions_df_13w: [-0.00593203 -0.00500921  0.00206668 -0.00197903]
# forecast_predictions_df_14w: [ 0.00309123 -0.0081164   0.00205722 -0.0165409   0.0117809 ]
# forecast_predictions_df_15w: [-0.00213497  0.004777   -0.01149888  0.0208307  -0.01805332]
# forecast_predictions_df_16w: [-0.01828245  0.0015673  -0.01763331 -0.01025846 -0.02671803]
# forecast_predictions_df_17w: [ 0.00940031  0.01606686  0.0044785  -0.00147893  0.01465285]
# forecast_predictions_df_18w: [ 0.00326518 -0.02202276 -0.00942765  0.01453981  0.02808787]
# forecast_predictions_df_19w: [ 0.01374957 -0.00345537  0.00248992 -0.00268442  0.00353478]
# forecast_predictions_df_20w: [ 0.00329599  0.01046055  0.02157941 -0.00428073 -0.0040059 ]
# forecast_predictions_df_21w: [0.01251995 0.0012447  0.00094355 0.00198858 0.00964677]
# forecast_predictions_df_22w: [ 0.01020355 -0.00745814 -0.0200321  -0.00254139]
# forecast_predictions_df_23w: [ 0.00972512  0.00237384  0.02619597 -0.00173937  0.00065512]
# forecast_predictions_df_24w: [0.00306259 0.01366862 0.02694766 0.00695723 0.00257829]
# forecast_predictions_df_25w: [ 0.01358114  0.00501705 -0.01227414 -0.0062363 ]
# forecast_predictions_df_26w: [-0.02078148  0.01684198  0.00025776  0.00096403 -0.00170054]
# forecast_predictions_df_27w: [0.00967606 0.00588086 0.01548211 0.00515862]
# forecast_predictions_df_28w: [ 0.00803083 -0.00102553  0.01578409 -0.02420845  0.00607792]
# forecast_predictions_df_29w: [ 3.38747638e-04 -2.44338102e-05 -4.11801504e-02 -4.03514899e-03
#  -1.39257204e-02]
# forecast_predictions_df_30w: [ 0.01912461 -0.00165257 -0.04164464 -0.01179523  0.01128469]
# forecast_predictions_df_31w: [-0.00484134 -0.02100645  0.04402748 -0.03800646 -0.02854851]
# forecast_predictions_df_32w: [-0.03368915  0.01205974 -0.01182785  0.03443147  0.00468921]
# forecast_predictions_df_33w: [0.00652276 0.03038154 0.00362863 0.02676034 0.00313098]
# forecast_predictions_df_34w: [ 0.01499889 -0.00366768  0.00629638 -0.0225474   0.01687391]
# forecast_predictions_df_35w: [-0.0152294   0.00777101 -0.01154567 -0.00758384  0.01048582]
# forecast_predictions_df_36w: [-0.04629913 -0.00296266 -0.00250439 -0.02769065]
# forecast_predictions_df_37w: [0.01587638 0.01068477 0.03287259 0.0081139  0.00454647]
# forecast_predictions_df_38w: [-0.00540224 -0.00281764 -0.00587207  0.02949788 -0.0066261 ]
# forecast_predictions_df_39w: [ 0.00086734  0.00557246  0.00017568  0.0162632  -0.01092853]
# forecast_predictions_df_40w: [ 0.00071591 -0.02103482  0.00467587  0.00047703  0.00924064]
# forecast_predictions_df_41w: [-0.00950018  0.01812463  0.01187323 -0.00347521  0.00298246]
# forecast_predictions_df_42w: [ 1.07239295e-02 -1.96870846e-02  7.57420521e-05  6.52631903e-03
#   3.70959627e-03]
# forecast_predictions_df_43w: [ 0.00359352 -0.00013267 -0.01550254  0.00260208  0.00473713]
# forecast_predictions_df_44w: [-0.00078157  0.01230691 -0.01463697 -0.02885846  0.00326358]
# forecast_predictions_df_45w: [-0.0019633   0.01401729  0.01746194  0.01967712 -0.00409066]
# forecast_predictions_df_46w: [-0.00826633  0.00021584 -0.0035489  -0.00203765 -0.02084821]
# forecast_predictions_df_47w: [ 0.00552337  0.00512036 -0.00203955  0.0069352   0.00264434]
# forecast_predictions_df_48w: [ 0.00247891  0.00295925 -0.01112824  0.010247  ]
# forecast_predictions_df_49w: [ 0.01191694  0.00411715  0.01484603 -0.00148292  0.00313248]
# forecast_predictions_df_50w: [-0.00324454 -0.00999021  0.01170985 -0.00359688  0.00871446]
# forecast_predictions_df_51w: [ 0.01144191 -0.0035461  -0.03139919 -0.00040287  0.01247562]
# forecast_predictions_df_52w: [ 0.01278796  0.00985938 -0.00074958 -0.01137967 -0.01163791]
#
#
# ==================================================

# %%
ols_metrics_clipboard={}
for ticker,data in results.items():
    if "model results" in data:
            metrics_dict = data["model results"]
            ols_metrics_clipboard[ticker]=metrics_dict
            #mae = metrics_dict.get("mae", None)
            #mase = metrics_dict.get("mase", None)

for key,value in ols_metrics_clipboard.items():
    print(key)
    print(value)

# %%
"""ols_metrics_clipboard=[]
for ticker, data in results.items():
    if "model results" in data:
        # This is the dictionary containing the metrics: e.g. {'mae': 1.23, 'mase': 0.45, ...}
        ols_metrics_clipboard = data["model results"]

        # Create a new dict that includes the ticker so we know which row it belongs to
        row_dict = {'ticker': ticker}
        
        # Add all metrics keys/values to row_dict
        row_dict.update(metrics_dict)
        
        # Append to the list
        ols_metrics_clipboard.append(row_dict)"""

# %%
ols_metrics_dataframe = pd.DataFrame(ols_metrics_clipboard).T
ols_metrics_dataframe.reset_index(inplace=True)
ols_metrics_dataframe.rename(columns={'index':'ticker'}, inplace=True)
ols_metrics_dataframe

# %%
ols_metrics_dataframe.to_clipboard(index=False,sep=',')

# %% [markdown]
# ### Ratios

# %%
def calculate_sharpe_ratio(returns, annual_risk_free_rate=0.1,period='daily'):
    #excess_returns = rate_of_return(returns) - risk_free_rate
    
    # Convert annual risk-free rate to daily rate
    daily_risk_free_rate = (1 + annual_risk_free_rate) ** (1/252) - 1
    
    # Calculate mean daily log return
    mean_return = np.mean(returns)
    
    # Calculate excess daily log return
    excess_return = mean_return - daily_risk_free_rate
    
    # Calculate standard deviation of daily log returns
    std_return = np.std(returns)
    
    # Print diagnostic information
    #print(f"Mean Daily Log Return: {mean_return}")
    #print(f"Excess Daily Log Return: {excess_return}")
    #print(f"Standard Deviation of Daily Log Returns: {std_return}")
    
    # Check for zero standard deviation to avoid division by zero
    if std_return == 0:
        return 0
    
    # Calculate Sharpe ratio
    sharpe_ratio = (excess_return / std_return) * np.sqrt(252)  # Annualize the Sharpe ratio
    return sharpe_ratio
    #return excess_returns / np.std(returns)


def calculate_rachev_ratio(returns, lower_percentile=5, upper_percentile=95):
    # Step 1: Sort the returns
    sorted_returns = np.sort(returns)
    
    # Step 2: Determine the percentiles
    lower_threshold = np.percentile(sorted_returns, lower_percentile)
    upper_threshold = np.percentile(sorted_returns, upper_percentile)
    
    # Step 3: Calculate Expected Shortfall (ES)
    es = np.mean(sorted_returns[sorted_returns <= lower_threshold])
    
    # Step 4: Calculate Expected Gain (EG)
    eg = np.mean(sorted_returns[sorted_returns >= upper_threshold])
    
    # Step 5: Compute the Rachev Ratio
    rachev_ratio = eg / -es
    return rachev_ratio


"""def calculate_volatility_clustering(returns):
    squared_returns = returns ** 2
    n = len(squared_returns)
    
    # Mean of squared returns
    mean_squared_returns = np.mean(squared_returns)
    
    # Calculate the numerator and denominator for autocorrelation at lag 1
    numerator = np.sum((squared_returns[:-1] - mean_squared_returns) * (squared_returns[1:] - mean_squared_returns))
    denominator = np.sum((squared_returns - mean_squared_returns) ** 2)
    
    if denominator == 0:
        return 0  # Avoid division by zero
    
    rho_1 = numerator / denominator
    return rho_1"""
def calculate_volatility_clustering(returns):
    # Ensure returns is a NumPy array
    returns = np.array(returns)
    squared_returns = returns ** 2
    n = len(squared_returns)

    # Mean of squared returns
    mean_squared = np.mean(squared_returns)
    clustering = np.sum((squared_returns - mean_squared) ** 2) / (n - 1 if n > 1 else 1)
    return clustering

def calculate_sortino_ratio(log_returns, target_log_return=0.0):
    """
    Calculate the Sortino Ratio using log returns.
    
    Parameters:
    - log_returns (array-like): Array or list of log returns for the period.
    - target_log_return (float): The target log return. Default is 0, which is often used as a benchmark.
    
    Returns:
    - float: The Sortino Ratio.
    """
    # Convert input to a NumPy array for easier calculations
    log_returns = np.array(log_returns)
    
    # Calculate the average period log return (R)
    avg_log_return = np.mean(log_returns)
    
    # Calculate the Target Downside Deviation (TDD)
    downside_deviation = np.sqrt(
        np.mean(np.square(np.maximum(0, target_log_return - log_returns)))
    )
    
    # Calculate Sortino Ratio
    #sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
    epsilon = 1e-8
    
    # Add epsilon to downside_deviation to prevent division by zero
    #if downside_deviation == 0:
     #   return np.nan  # Return NaN if downside deviation is zero
    
    # Calculate Sortino Ratio
    sortino_ratio_value = (avg_log_return - target_log_return) / (downside_deviation + epsilon)
    
    return sortino_ratio_value

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, volatility_clustering, 
    mean_forecast, std_forecast, mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
    mean_volatility_clustering, std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    # Normalize the components with epsilon
    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    return score

def calculate_smoothing(data, alpha=0.1):
    if len(data) == 0:  # Explicitly check if the data is empty
        return []
    smoothed_data = []
    previous_value = data[0]
    for value in data:
        smoothed_value = alpha * value + (1 - alpha) * previous_value
        smoothed_data.append(smoothed_value)
        previous_value = smoothed_value
    return smoothed_data



def process_etf_data_weekly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = {}

    # Determine the forecast periods dynamically from the etf_dict
    sample_etf = next(iter(etf_dict.values()))
    forecast_periods = [key.split('_')[-1] for key in sample_etf.keys() if key.startswith('forecast_predictions_df')]

    for etf_name in tickers:
        etf_pred_dict[etf_name] = {
            f"returns_{period}": etf_dict[etf_name][f"forecast_predictions_df_{period}"]
            for period in forecast_periods
        }

        for period in forecast_periods:
            returns = etf_pred_dict[etf_name][f"returns_{period}"]

            if smoothing:
                # Apply smoothing to returns
                smoothed_returns = calculate_smoothing(returns)
                etf_pred_dict[etf_name][f"smoothed_returns_{period}"] = smoothed_returns

                # Calculate metrics using smoothed returns
                etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(smoothed_returns)
            else:
                # Calculate metrics using raw returns
                etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
                etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
                etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
                etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict


def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )


def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

    return scores


def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()


def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []

    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)

    return week_ranges




def gather_etf_data_for_weeks(selected_tickers, week_ranges):
    # Download all data for each ticker once
    print("Fetching full-year data for all tickers...")
    full_year_data = {}
    for ticker in selected_tickers:
        print(f"Downloading data for {ticker} for the entire year...")
        full_year_data[ticker] = yf.download(ticker, start=week_ranges[0][0], end=week_ranges[-1][1], progress=False)

    # Slice data into weekly ranges
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in selected_tickers:
            if ticker in full_year_data and not full_year_data[ticker].empty:
                # Slice the full-year data for the given week
                weekly_data = full_year_data[ticker].loc[start_date:end_date]
                if not weekly_data.empty:
                    etf_histories[week][ticker] = weekly_data
                else:
                    print(f"No data found for {ticker} in {week}")
            else:
                print(f"No data available for {ticker} in the full-year download.")
    return etf_histories




def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]

    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)

        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]

            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.9975) / price_on_first_trading_day
            ticker_shares[ticker] = num_shares
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares


def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"\nTop 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.9975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.9975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

def main_weekly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict, smoothing=smoothing)

    risk_percentage = 0.10
    weekly_scores = {}

    # Calculate scores for all weeks (1 to 52)
    for week in range(1, 53):  # Updated range for 52 weeks
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores

    # Convert scores to DataFrames
    weekly_scores_dfs = {}
    for week_key, scores in weekly_scores.items():
        weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    # Select top ETFs for each week
    top_etfs_weekly = {}
    for week_key, df_scores in weekly_scores_dfs.items():
        top_etfs_weekly[week_key] = df_scores.nlargest(2, 'Score')

    # Generate week ranges for ETF data gathering
    week_ranges = generate_week_ranges('2024-01-01', '2024-12-31')  # Full year for 52 weeks

    # Gather ETF historical data
    etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)

    # Map week keys to date ranges
    week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

    # Align top ETFs with historical data
    aligned_top_etfs_weekly = {}
    for week_key, df_scores in weekly_scores_dfs.items():
        forecast_period = week_key_mapping.get(week_key, None)
        if forecast_period:
            aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

    # Initialize and manage portfolio
    ticker_shares = {}
    ticker_shares_per_week = {}
    for i, week_range in enumerate(etf_histories.keys()):
        current_week_key = week_range
        if i == 0:
            # Initialize shares for the first week
            ticker_shares = initialize_shares_for_first_week(
                aligned_top_etfs_weekly.get(current_week_key, []),  # Fallback to empty list if key is missing
                etf_histories,
                current_week_key
            )
            ticker_shares_per_week[current_week_key] = ticker_shares.copy()
        else:
            # Manage portfolio for subsequent weeks
            prev_week_key = list(etf_histories.keys())[i - 1]
            if current_week_key not in aligned_top_etfs_weekly:
                print(f"Warning: Missing alignment for {current_week_key}. Skipping week.")
                continue

            ticker_shares = manage_etf_portfolio_weekly(
                aligned_top_etfs_weekly.get(prev_week_key, []),  # Fallback to empty list
                aligned_top_etfs_weekly[current_week_key],
                prev_week_key,
                current_week_key,
                ticker_shares,
                etf_histories
            )
            ticker_shares_per_week[current_week_key] = ticker_shares.copy()


    # Define the first trading day of the 53rd week
    first_trading_day_53w = '2025-01-01'

    # Identify the 52nd week date ranges
    week_52_range = list(ticker_shares_per_week.keys())[-1]
    week_53_start = first_trading_day_53w
    print(f"Using data for the 52nd week: {week_52_range}")
    print(f"Fetching data starting from the first trading day of the 53rd week: {week_53_start}")

    week_53_end = '2025-01-06'
    etf_values_53w = {}

    # Ensure 52nd week data exists
    if week_52_range in ticker_shares_per_week:
        ticker_shares_52w = ticker_shares_per_week[week_52_range]

        # Fetch the first trading day price of the 53rd week for each ETF
        for ticker, shares in ticker_shares_52w.items():
            print(f"Fetching data for ticker {ticker} starting from {week_53_start}...")
            data = yf.download(ticker, start=week_53_start, end=week_53_end)

            if not data.empty:
                closing_price_53w = data['Close'].iloc[0]
                total_value = shares * closing_price_53w
                etf_values_53w[ticker] = total_value
                print(f"{ticker}: {shares:.2f} shares at ${closing_price_53w:.2f} each, total value: ${total_value:.2f}")
            else:
                print(f"{ticker}: No data available for the 53rd week's first trading day.")
    else:
        print(f"No data available in ticker_shares_per_week for the 52nd week: {week_52_range}")

    # Display total portfolio value for the 53rd week's first trading day
    if etf_values_53w:
        print("\nETF values on the 53rd week's first trading day:")
        total_value = sum(etf_values_53w.values())
        print(f"Total portfolio value: {total_value:.2f}")
        for ticker, value in etf_values_53w.items():
            print(f"{ticker}: {value:.2f}")
    else:
        print("No values could be calculated for the 53rd week's first trading day.")

    return ticker_shares_per_week

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_week = main_weekly(tickers, results, smoothing=False)
# Out:
# Fetching full-year data for all tickers...
# Downloading data for SMH for the entire year...
# Downloading data for SOXX for the entire year...
# Downloading data for PSI for the entire year...
# Downloading data for XSD for the entire year...
# Downloading data for IYW for the entire year...
# Downloading data for XLK for the entire year...
# Downloading data for VGT for the entire year...
# Downloading data for FTEC for the entire year...
# Downloading data for IGM for the entire year...
# Downloading data for IXN for the entire year...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1  2.383421
# 1  SOXX   1w             0.1 -0.934373
# 2   PSI   1w             0.1 -5.821312
# 3   XSD   1w             0.1 -5.651678
# 4   IYW   1w             0.1  2.126326
# Top ETFs for 2024-01-01 to 2024-01-07: ['IGM', 'SMH']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1 -3.204944
# 1  SOXX   2w             0.1 -3.735241
# 2   PSI   2w             0.1 -3.197570
# 3   XSD   2w             0.1 -5.931185
# 4   IYW   2w             0.1  3.356081
# Top ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'IYW']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  5.034531
# 1  SOXX   3w             0.1  1.434208
# 2   PSI   3w             0.1  0.109259
# 3   XSD   3w             0.1 -3.018084
# 4   IYW   3w             0.1 -0.493572
# Top ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1 -0.590457
# 1  SOXX   4w             0.1 -4.120562
# 2   PSI   4w             0.1 -4.633493
# 3   XSD   4w             0.1 -6.549022
# 4   IYW   4w             0.1  3.001398
# Top ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IYW']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1  4.204509
# 1  SOXX   5w             0.1 -0.754101
# 2   PSI   5w             0.1 -1.187516
# 3   XSD   5w             0.1 -7.889693
# 4   IYW   5w             0.1  0.449246
# Top ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'IGM']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  2.471110
# 1  SOXX   6w             0.1  0.745887
# 2   PSI   6w             0.1 -4.174829
# 3   XSD   6w             0.1  1.757683
# 4   IYW   6w             0.1 -0.975804
# Top ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'VGT']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1  2.283329
# 1  SOXX   7w             0.1  2.983535
# 2   PSI   7w             0.1  5.242397
# 3   XSD   7w             0.1 -2.355060
# 4   IYW   7w             0.1 -2.033440
# Top ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SOXX']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1  1.535073
# 1  SOXX   8w             0.1  0.930465
# 2   PSI   8w             0.1 -4.450679
# 3   XSD   8w             0.1 -4.814898
# 4   IYW   8w             0.1  1.386952
# Top ETFs for 2024-02-19 to 2024-02-25: ['IXN', 'XLK']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1 -0.950508
# 1  SOXX   9w             0.1 -0.048802
# 2   PSI   9w             0.1  5.211428
# 3   XSD   9w             0.1  1.353153
# 4   IYW   9w             0.1 -2.526951
# Top ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  5.112148
# 1  SOXX  10w             0.1  1.423284
# 2   PSI  10w             0.1 -1.429047
# 3   XSD  10w             0.1  2.049886
# 4   IYW  10w             0.1 -2.254123
# Top ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'XSD']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1 -2.084976
# 1  SOXX  11w             0.1 -2.443838
# 2   PSI  11w             0.1 -3.944665
# 3   XSD  11w             0.1 -7.126820
# 4   IYW  11w             0.1  3.348677
# Top ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1 -0.684663
# 1  SOXX  12w             0.1 -3.235855
# 2   PSI  12w             0.1 -1.631976
# 3   XSD  12w             0.1 -3.955834
# 4   IYW  12w             0.1  3.053359
# Top ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IGM']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1 -1.476734
# 1  SOXX  13w             0.1  2.087932
# 2   PSI  13w             0.1  2.289610
# 3   XSD  13w             0.1  4.726101
# 4   IYW  13w             0.1 -2.203415
# Top ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1 -0.456504
# 1  SOXX  14w             0.1 -5.406242
# 2   PSI  14w             0.1  3.994611
# 3   XSD  14w             0.1 -3.456286
# 4   IYW  14w             0.1  2.785291
# Top ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'PSI']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1  0.663705
# 1  SOXX  15w             0.1 -3.686824
# 2   PSI  15w             0.1 -5.235783
# 3   XSD  15w             0.1 -6.127665
# 4   IYW  15w             0.1  5.190145
# Top ETFs for 2024-04-08 to 2024-04-14: ['IYW', 'XLK']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1 -1.476388
# 1  SOXX  16w             0.1 -0.055068
# 2   PSI  16w             0.1  0.309454
# 3   XSD  16w             0.1 -3.171433
# 4   IYW  16w             0.1  1.338672
# Top ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'IYW']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1  0.856596
# 1  SOXX  17w             0.1  4.457128
# 2   PSI  17w             0.1  2.147625
# 3   XSD  17w             0.1  5.160678
# 4   IYW  17w             0.1 -2.974176
# Top ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'SOXX']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1 -3.906949
# 1  SOXX  18w             0.1 -6.369007
# 2   PSI  18w             0.1 -3.361998
# 3   XSD  18w             0.1 -0.838864
# 4   IYW  18w             0.1  1.910315
# Top ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'XLK']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1  0.362344
# 1  SOXX  19w             0.1 -2.082216
# 2   PSI  19w             0.1  2.878584
# 3   XSD  19w             0.1 -2.262063
# 4   IYW  19w             0.1 -1.700957
# Top ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'PSI']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1 -4.822446
# 1  SOXX  20w             0.1 -0.534040
# 2   PSI  20w             0.1 -4.832082
# 3   XSD  20w             0.1  5.715112
# 4   IYW  20w             0.1  1.690790
# Top ETFs for 2024-05-13 to 2024-05-19: ['XSD', 'IYW']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  3.172705
# 1  SOXX  21w             0.1 -0.837755
# 2   PSI  21w             0.1 -1.578233
# 3   XSD  21w             0.1 -3.183415
# 4   IYW  21w             0.1  1.868407
# Top ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IXN']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1  1.876992
# 1  SOXX  22w             0.1  0.223813
# 2   PSI  22w             0.1  1.589522
# 3   XSD  22w             0.1  8.628286
# 4   IYW  22w             0.1 -1.750714
# Top ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'SMH']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1 -0.432956
# 1  SOXX  23w             0.1 -2.615176
# 2   PSI  23w             0.1 -4.290409
# 3   XSD  23w             0.1 -5.846677
# 4   IYW  23w             0.1  2.720270
# Top ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1 -1.590968
# 1  SOXX  24w             0.1 -2.659917
# 2   PSI  24w             0.1 -3.667176
# 3   XSD  24w             0.1 -6.303292
# 4   IYW  24w             0.1  2.465730
# Top ETFs for 2024-06-10 to 2024-06-16: ['VGT', 'IGM']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1 -2.890799
# 1  SOXX  25w             0.1 -2.726262
# 2   PSI  25w             0.1 -1.563963
# 3   XSD  25w             0.1 -6.108733
# 4   IYW  25w             0.1 -0.219007
# Top ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1 -6.848147
# 1  SOXX  26w             0.1 -4.616722
# 2   PSI  26w             0.1  5.596636
# 3   XSD  26w             0.1  0.484506
# 4   IYW  26w             0.1  2.146222
# Top ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'IGM']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1 -1.304406
# 1  SOXX  27w             0.1 -2.883405
# 2   PSI  27w             0.1 -4.136106
# 3   XSD  27w             0.1 -3.932425
# 4   IYW  27w             0.1  4.949885
# Top ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IGM']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1 -1.409674
# 1  SOXX  28w             0.1  0.222252
# 2   PSI  28w             0.1  0.232250
# 3   XSD  28w             0.1  7.443341
# 4   IYW  28w             0.1 -2.222431
# Top ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'VGT']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1 -3.573312
# 1  SOXX  29w             0.1 -1.390363
# 2   PSI  29w             0.1 -2.168024
# 3   XSD  29w             0.1  4.544380
# 4   IYW  29w             0.1 -0.135104
# Top ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'IGM']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1 -3.424283
# 1  SOXX  30w             0.1  0.189599
# 2   PSI  30w             0.1 -6.882626
# 3   XSD  30w             0.1  1.865288
# 4   IYW  30w             0.1 -0.757384
# Top ETFs for 2024-07-22 to 2024-07-28: ['VGT', 'XLK']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1 -0.508420
# 1  SOXX  31w             0.1 -1.730709
# 2   PSI  31w             0.1 -4.812138
# 3   XSD  31w             0.1 -7.047989
# 4   IYW  31w             0.1  2.516010
# Top ETFs for 2024-07-29 to 2024-08-04: ['IXN', 'IYW']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1  1.773625
# 1  SOXX  32w             0.1  0.254032
# 2   PSI  32w             0.1  5.584469
# 3   XSD  32w             0.1 -3.083559
# 4   IYW  32w             0.1 -1.051447
# Top ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1 -0.224706
# 1  SOXX  33w             0.1 -1.791903
# 2   PSI  33w             0.1 -2.933213
# 3   XSD  33w             0.1 -4.450758
# 4   IYW  33w             0.1  1.177168
# Top ETFs for 2024-08-12 to 2024-08-18: ['XLK', 'IXN']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1 -5.377457
# 1  SOXX  34w             0.1 -4.587305
# 2   PSI  34w             0.1 -1.494764
# 3   XSD  34w             0.1  4.989251
# 4   IYW  34w             0.1 -0.357691
# Top ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'FTEC']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1 -2.515402
# 1  SOXX  35w             0.1  0.319940
# 2   PSI  35w             0.1 -0.926277
# 3   XSD  35w             0.1  7.948340
# 4   IYW  35w             0.1 -0.471969
# Top ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'IGM']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1 -0.955007
# 1  SOXX  36w             0.1  0.106002
# 2   PSI  36w             0.1  1.100718
# 3   XSD  36w             0.1 -2.159563
# 4   IYW  36w             0.1  0.697154
# Top ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'PSI']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1  0.644755
# 1  SOXX  37w             0.1 -2.219288
# 2   PSI  37w             0.1 -3.503420
# 3   XSD  37w             0.1 -3.057671
# 4   IYW  37w             0.1  1.093253
# Top ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'IGM']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1 -4.644182
# 1  SOXX  38w             0.1 -4.394577
# 2   PSI  38w             0.1 -4.490106
# 3   XSD  38w             0.1 -1.397326
# 4   IYW  38w             0.1  3.139812
# Top ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1  1.977129
# 1  SOXX  39w             0.1  1.997929
# 2   PSI  39w             0.1  0.841427
# 3   XSD  39w             0.1  3.866198
# 4   IYW  39w             0.1 -1.714646
# Top ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'SOXX']
# Processing scores for 2024-09-30 to 2024-10-06:
#     ETF Week  RiskPercentage     Score
# 0   SMH  40w             0.1  1.361248
# 1  SOXX  40w             0.1 -1.582535
# 2   PSI  40w             0.1 -5.069675
# 3   XSD  40w             0.1 -7.038540
# 4   IYW  40w             0.1  3.340488
# Top ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IYW']
# Processing scores for 2024-10-07 to 2024-10-13:
#     ETF Week  RiskPercentage     Score
# 0   SMH  41w             0.1  6.421446
# 1  SOXX  41w             0.1 -1.013578
# 2   PSI  41w             0.1  4.133106
# 3   XSD  41w             0.1 -1.494828
# 4   IYW  41w             0.1 -1.844180
# Top ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'PSI']
# Processing scores for 2024-10-14 to 2024-10-20:
#     ETF Week  RiskPercentage     Score
# 0   SMH  42w             0.1 -3.587115
# 1  SOXX  42w             0.1 -4.870226
# 2   PSI  42w             0.1 -7.517024
# 3   XSD  42w             0.1 -0.237963
# 4   IYW  42w             0.1  2.440188
# Top ETFs for 2024-10-14 to 2024-10-20: ['VGT', 'FTEC']
# Processing scores for 2024-10-21 to 2024-10-27:
#     ETF Week  RiskPercentage     Score
# 0   SMH  43w             0.1  6.180296
# 1  SOXX  43w             0.1  1.363828
# 2   PSI  43w             0.1 -0.128041
# 3   XSD  43w             0.1  4.098742
# 4   IYW  43w             0.1  1.410261
# Top ETFs for 2024-10-21 to 2024-10-27: ['SMH', 'XSD']
# Processing scores for 2024-10-28 to 2024-11-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH  44w             0.1 -0.069658
# 1  SOXX  44w             0.1 -1.876535
# 2   PSI  44w             0.1 -5.110286
# 3   XSD  44w             0.1 -0.622654
# 4   IYW  44w             0.1  2.194357
# Top ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IYW']
# Processing scores for 2024-11-04 to 2024-11-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  45w             0.1 -1.132463
# 1  SOXX  45w             0.1 -4.585804
# 2   PSI  45w             0.1 -0.226722
# 3   XSD  45w             0.1 -1.673201
# 4   IYW  45w             0.1  1.379911
# Top ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'FTEC']
# Processing scores for 2024-11-11 to 2024-11-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  46w             0.1 -2.073303
# 1  SOXX  46w             0.1 -3.386918
# 2   PSI  46w             0.1 -5.280679
# 3   XSD  46w             0.1 -5.987092
# 4   IYW  46w             0.1  3.035441
# Top ETFs for 2024-11-11 to 2024-11-17: ['IYW', 'IGM']
# Processing scores for 2024-11-18 to 2024-11-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  47w             0.1 -2.919763
# 1  SOXX  47w             0.1 -2.441831
# 2   PSI  47w             0.1 -1.984972
# 3   XSD  47w             0.1  5.756203
# 4   IYW  47w             0.1 -1.272740
# Top ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'VGT']
# Processing scores for 2024-11-25 to 2024-12-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  48w             0.1 -4.863919
# 1  SOXX  48w             0.1 -2.054104
# 2   PSI  48w             0.1  1.087196
# 3   XSD  48w             0.1  4.511516
# 4   IYW  48w             0.1 -0.123342
# Top ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'IXN']
# Processing scores for 2024-12-02 to 2024-12-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  49w             0.1 -3.448753
# 1  SOXX  49w             0.1 -5.525177
# 2   PSI  49w             0.1 -3.640800
# 3   XSD  49w             0.1  0.183444
# 4   IYW  49w             0.1  1.854107
# Top ETFs for 2024-12-02 to 2024-12-08: ['IXN', 'IGM']
# Processing scores for 2024-12-09 to 2024-12-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  50w             0.1 -0.324622
# 1  SOXX  50w             0.1  2.106516
# 2   PSI  50w             0.1  3.446863
# 3   XSD  50w             0.1  3.252136
# 4   IYW  50w             0.1 -2.835854
# Top ETFs for 2024-12-09 to 2024-12-15: ['PSI', 'XSD']
# Processing scores for 2024-12-16 to 2024-12-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  51w             0.1 -0.715318
# 1  SOXX  51w             0.1 -3.120669
# 2   PSI  51w             0.1 -1.815207
# 3   XSD  51w             0.1 -9.082492
# 4   IYW  51w             0.1  2.405509
# Top ETFs for 2024-12-16 to 2024-12-22: ['IXN', 'FTEC']
# Processing scores for 2024-12-23 to 2024-12-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  52w             0.1  2.988822
# 1  SOXX  52w             0.1  2.815612
# 2   PSI  52w             0.1  1.780265
# 3   XSD  52w             0.1  2.332337
# 4   IYW  52w             0.1 -2.255670
# Top ETFs for 2024-12-23 to 2024-12-29: ['SMH', 'SOXX']
#
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['IGM', 'SMH']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'IYW']
# Sell SMH: 295.17 shares at 171.96. Total value: 50630.67
# Buy IYW: 418.29 shares at 120.74.
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'IGM': 685.8026957229545, 'IYW': 418.28799442127826}
#
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'IYW']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Sell IGM: 685.80 shares at 75.45. Total value: 51613.31
# Buy SMH: 293.02 shares at 175.70.
# Sell IYW: 418.29 shares at 123.36. Total value: 51471.01
# Buy SOXX: 272.47 shares at 188.43.
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'SMH': 293.0237996553952, 'SOXX': 272.4742965906847}
#
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IYW']
# Sell SMH: 293.02 shares at 188.05. Total value: 54965.37
# Buy IGM: 697.13 shares at 78.65.
# Sell SOXX: 272.47 shares at 201.07. Total value: 54648.53
# Buy IYW: 423.99 shares at 128.57.
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'IGM': 697.1280216874455, 'IYW': 423.9862339830566}
#
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IYW']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'IGM']
# Sell IYW: 423.99 shares at 130.81. Total value: 55322.98
# Buy SMH: 289.71 shares at 190.48.
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'IGM': 697.1280216874455, 'SMH': 289.71376477357035}
#
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'IGM']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'VGT']
# Sell IGM: 697.13 shares at 81.27. Total value: 56511.64
# Buy VGT: 111.54 shares at 505.40.
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'SMH': 289.71376477357035, 'VGT': 111.53613265335666}
#
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'VGT']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SOXX']
# Sell SMH: 289.71 shares at 203.06. Total value: 58682.20
# Buy PSI: 1111.15 shares at 52.68.
# Sell VGT: 111.54 shares at 518.19. Total value: 57652.42
# Buy SOXX: 274.59 shares at 209.43.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'PSI': 1111.15218924933, 'SOXX': 274.594315759716}
#
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SOXX']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['IXN', 'XLK']
# Sell PSI: 1111.15 shares at 51.59. Total value: 57181.03
# Buy IXN: 801.43 shares at 71.17.
# Sell SOXX: 274.59 shares at 204.87. Total value: 56114.58
# Buy XLK: 279.16 shares at 200.51.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'IXN': 801.4343072848367, 'XLK': 279.159641559087}
#
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['IXN', 'XLK']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Sell IXN: 801.43 shares at 73.12. Total value: 58454.38
# Buy PSI: 1093.55 shares at 53.32.
# Sell XLK: 279.16 shares at 205.49. Total value: 57221.10
# Buy XSD: 258.59 shares at 220.73.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'PSI': 1093.552905951632, 'XSD': 258.5876560915674}
#
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'XSD']
# Sell PSI: 1093.55 shares at 56.78. Total value: 61936.70
# Buy SMH: 275.70 shares at 224.09.
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'XSD': 258.5876560915674, 'SMH': 275.70111154416463}
#
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'XSD']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Sell SMH: 275.70 shares at 220.98. Total value: 60772.12
# Buy XLK: 293.16 shares at 206.78.
# Sell XSD: 258.59 shares at 231.52. Total value: 59718.54
# Buy IYW: 448.06 shares at 132.95.
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'XLK': 293.1627306045397, 'IYW': 448.0575382521104}
#
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IGM']
# Sell XLK: 293.16 shares at 206.30. Total value: 60328.27
# Buy IGM: 706.39 shares at 85.19.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'IYW': 448.0575382521104, 'IGM': 706.3910215917388}
#
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IGM']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Sell IYW: 448.06 shares at 135.90. Total value: 60738.79
# Buy XSD: 267.85 shares at 226.20.
# Sell IGM: 706.39 shares at 86.60. Total value: 61020.53
# Buy PSI: 1082.29 shares at 56.24.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'XSD': 267.84678610267434, 'PSI': 1082.2897333315054}
#
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'PSI']
# Sell XSD: 267.85 shares at 233.86. Total value: 62482.05
# Buy IGM: 719.20 shares at 86.66.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'PSI': 1082.2897333315054, 'IGM': 719.1996904156093}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'PSI']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['IYW', 'XLK']
# Sell IGM: 719.20 shares at 85.96. Total value: 61667.85
# Buy IYW: 458.61 shares at 134.13.
# Sell PSI: 1082.29 shares at 56.38. Total value: 60866.95
# Buy XLK: 294.43 shares at 206.21.
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'IYW': 458.6123675295741, 'XLK': 294.43178427190895}
#
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['IYW', 'XLK']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'IYW']
# Sell XLK: 294.43 shares at 201.52. Total value: 59185.56
# Buy IGM: 705.77 shares at 83.65.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'IYW': 458.6123675295741, 'IGM': 705.769213535243}
#
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'IYW']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'SOXX']
# Sell IGM: 705.77 shares at 80.88. Total value: 56939.91
# Buy XSD: 274.89 shares at 206.62.
# Sell IYW: 458.61 shares at 126.24. Total value: 57750.49
# Buy SOXX: 285.66 shares at 201.66.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'XSD': 274.88896089716684, 'SOXX': 285.65957043925835}
#
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'SOXX']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'XLK']
# Sell XSD: 274.89 shares at 228.64. Total value: 62693.49
# Buy IXN: 867.96 shares at 72.05.
# Sell SOXX: 285.66 shares at 218.55. Total value: 62274.82
# Buy XLK: 309.53 shares at 200.69.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'IXN': 867.9632055517163, 'XLK': 309.52780372090916}
#
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'XLK']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'PSI']
# Sell IXN: 867.96 shares at 73.87. Total value: 63956.15
# Buy PSI: 1139.42 shares at 55.99.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'XLK': 309.52780372090916, 'PSI': 1139.422414206857}
#
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'PSI']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['XSD', 'IYW']
# Sell XLK: 309.53 shares at 206.51. Total value: 63760.78
# Buy XSD: 275.65 shares at 230.73.
# Sell PSI: 1139.42 shares at 56.06. Total value: 63716.33
# Buy IYW: 472.68 shares at 134.46.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'XSD': 275.6528531281582, 'IYW': 472.68360885223996}
#
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['XSD', 'IYW']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IXN']
# Sell XSD: 275.65 shares at 241.73. Total value: 66466.98
# Buy SMH: 282.13 shares at 235.00.
# Sell IYW: 472.68 shares at 139.80. Total value: 65915.97
# Buy IXN: 855.69 shares at 76.84.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'SMH': 282.13111341990503, 'IXN': 855.6894879125388}
#
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IXN']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'SMH']
# Sell IXN: 855.69 shares at 78.68. Total value: 67157.34
# Buy XSD: 268.79 shares at 249.23.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'SMH': 282.13111341990503, 'XSD': 268.7856311757301}
#
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'SMH']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Sell XSD: 268.79 shares at 245.69. Total value: 65872.85
# Buy IXN: 852.69 shares at 77.06.
# Sell SMH: 282.13 shares at 243.48. Total value: 68521.55
# Buy IYW: 489.19 shares at 139.72.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'IXN': 852.6883919903944, 'IYW': 489.1944218042303}
#
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['VGT', 'IGM']
# Sell IXN: 852.69 shares at 79.41. Total value: 67542.71
# Buy VGT: 122.11 shares at 551.75.
# Sell IYW: 489.19 shares at 143.93. Total value: 70233.73
# Buy IGM: 774.12 shares at 90.50.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'VGT': 122.10938212753868, 'IGM': 774.1231034310939}
#
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['VGT', 'IGM']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Sell VGT: 122.11 shares at 586.47. Total value: 71434.45
# Buy XLK: 308.31 shares at 231.12.
# Sell IGM: 774.12 shares at 95.12. Total value: 73450.51
# Buy IXN: 868.19 shares at 84.39.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'XLK': 308.3067991511337, 'IXN': 868.1938560497362}
#
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'IGM']
# Sell XLK: 308.31 shares at 222.42. Total value: 68402.16
# Buy PSI: 1122.96 shares at 60.76.
# Sell IXN: 868.19 shares at 81.49. Total value: 70572.24
# Buy IGM: 759.48 shares at 92.69.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'PSI': 1122.961820013084, 'IGM': 759.4757819100171}
#
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'IGM']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IGM']
# Sell PSI: 1122.96 shares at 62.76. Total value: 70300.89
# Buy IYW: 461.29 shares at 152.02.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'IGM': 759.4757819100171, 'IYW': 461.28887672934223}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IGM']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'VGT']
# Sell IYW: 461.29 shares at 156.96. Total value: 72222.90
# Buy XSD: 276.35 shares at 260.69.
# Sell IGM: 759.48 shares at 97.87. Total value: 74144.07
# Buy VGT: 123.28 shares at 599.91.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 276.3525164457637, 'VGT': 123.28301786912546}
#
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'VGT']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'IGM']
# Sell VGT: 123.28 shares at 603.78. Total value: 74249.73
# Buy IGM: 759.71 shares at 97.49.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'XSD': 276.3525164457637, 'IGM': 759.7098355414893}
#
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'IGM']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['VGT', 'XLK']
# Sell XSD: 276.35 shares at 258.59. Total value: 71283.34
# Buy VGT: 121.71 shares at 584.23.
# Sell IGM: 759.71 shares at 94.30. Total value: 71461.54
# Buy XLK: 315.27 shares at 226.10.
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'VGT': 121.70743585432658, 'XLK': 315.27148359441475}
#
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['VGT', 'XLK']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IXN', 'IYW']
# Sell VGT: 121.71 shares at 559.49. Total value: 67923.86
# Buy IXN: 858.62 shares at 78.91.
# Sell XLK: 315.27 shares at 215.32. Total value: 67714.55
# Buy IYW: 468.61 shares at 144.14.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'IXN': 858.6243071955334, 'IYW': 468.60872366111363}
#
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IXN', 'IYW']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Sell IXN: 858.62 shares at 73.00. Total value: 62522.88
# Buy PSI: 1257.90 shares at 49.58.
# Sell IYW: 468.61 shares at 133.32. Total value: 62318.73
# Buy SMH: 291.42 shares at 213.31.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'PSI': 1257.8976602906075, 'SMH': 291.42063221628433}
#
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['XLK', 'IXN']
# Sell PSI: 1257.90 shares at 53.06. Total value: 66577.19
# Buy XLK: 320.35 shares at 207.31.
# Sell SMH: 291.42 shares at 226.96. Total value: 65975.48
# Buy IXN: 859.48 shares at 76.57.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'XLK': 320.3451317205239, 'IXN': 859.4820183311689}
#
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['XLK', 'IXN']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'FTEC']
# Sell XLK: 320.35 shares at 225.05. Total value: 71913.44
# Buy XSD: 305.31 shares at 234.95.
# Sell IXN: 859.48 shares at 82.91. Total value: 71081.51
# Buy FTEC: 410.89 shares at 172.56.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'XSD': 305.31456064764683, 'FTEC': 410.89363338510617}
#
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'IGM']
# Sell FTEC: 410.89 shares at 170.72. Total value: 69972.39
# Buy IGM: 750.35 shares at 93.02.
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'XSD': 305.31456064764683, 'IGM': 750.3489972855381}
#
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'IGM']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'PSI']
# Sell XSD: 305.31 shares at 222.36. Total value: 67720.02
# Buy PSI: 1274.54 shares at 53.00.
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'IGM': 750.3489972855381, 'PSI': 1274.5419145926794}
#
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'PSI']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'IGM']
# Sell PSI: 1274.54 shares at 51.35. Total value: 65284.11
# Buy XLK: 314.20 shares at 207.26.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'IGM': 750.3489972855381, 'XLK': 314.19906164682203}
#
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'IGM']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Sell XLK: 314.20 shares at 219.60. Total value: 68825.62
# Buy IYW: 470.10 shares at 146.04.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'IGM': 750.3489972855381, 'IYW': 470.1010659442921}
#
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'SOXX']
# Sell IGM: 750.35 shares at 94.58. Total value: 70790.59
# Buy XSD: 304.58 shares at 231.84.
# Sell IYW: 470.10 shares at 149.26. Total value: 69991.86
# Buy SOXX: 310.93 shares at 224.54.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'XSD': 304.57908106871884, 'SOXX': 310.932959566129}
#
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'SOXX']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IYW']
# Sell XSD: 304.58 shares at 240.25. Total value: 72992.19
# Buy IGM: 758.91 shares at 95.94.
# Sell SOXX: 310.93 shares at 230.59. Total value: 71518.78
# Buy IYW: 470.52 shares at 151.62.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'IGM': 758.9087356404814, 'IYW': 470.51833707812375}
#
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IYW']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'PSI']
# Sell IGM: 758.91 shares at 95.46. Total value: 72264.31
# Buy SMH: 290.40 shares at 248.22.
# Sell IYW: 470.52 shares at 150.36. Total value: 70570.27
# Buy PSI: 1229.59 shares at 57.25.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'SMH': 290.4022742035959, 'PSI': 1229.5867935826398}
#
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'PSI']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['VGT', 'FTEC']
# Sell SMH: 290.40 shares at 261.28. Total value: 75686.62
# Buy VGT: 124.20 shares at 607.88.
# Sell PSI: 1229.59 shares at 60.18. Total value: 73811.54
# Buy FTEC: 407.16 shares at 180.83.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'VGT': 124.197864612506, 'FTEC': 407.16149243918755}
#
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['VGT', 'FTEC']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['SMH', 'XSD']
# Sell VGT: 124.20 shares at 606.93. Total value: 75190.96
# Buy SMH: 296.64 shares at 252.84.
# Sell FTEC: 407.16 shares at 180.45. Total value: 73288.61
# Buy XSD: 301.80 shares at 242.23.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'SMH': 296.64208282692704, 'XSD': 301.80154856541685}
#
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['SMH', 'XSD']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IYW']
# Sell SMH: 296.64 shares at 251.21. Total value: 74333.16
# Buy IGM: 756.99 shares at 97.95.
# Sell XSD: 301.80 shares at 246.83. Total value: 74307.44
# Buy IYW: 476.21 shares at 155.65.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'IGM': 756.9916322333108, 'IYW': 476.20736841060676}
#
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IYW']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'FTEC']
# Sell IGM: 756.99 shares at 95.86. Total value: 72383.81
# Buy XLK: 322.71 shares at 223.74.
# Sell IYW: 476.21 shares at 151.41. Total value: 71922.30
# Buy FTEC: 412.01 shares at 174.13.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'XLK': 322.7086975784364, 'FTEC': 412.0053708565429}
#
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'FTEC']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IYW', 'IGM']
# Sell XLK: 322.71 shares at 235.85. Total value: 75920.57
# Buy IYW: 472.52 shares at 160.27.
# Sell FTEC: 412.01 shares at 185.07. Total value: 76059.21
# Buy IGM: 744.84 shares at 101.86.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'IYW': 472.51992092121475, 'IGM': 744.8366770459132}
#
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IYW', 'IGM']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'VGT']
# Sell IYW: 472.52 shares at 156.19. Total value: 73618.38
# Buy XSD: 321.25 shares at 228.59.
# Sell IGM: 744.84 shares at 99.13. Total value: 73651.07
# Buy VGT: 121.49 shares at 604.72.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'XSD': 321.24911679768604, 'VGT': 121.48919250756043}
#
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'VGT']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'IXN']
# Sell VGT: 121.49 shares at 621.29. Total value: 75291.32
# Buy IXN: 898.36 shares at 83.60.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'XSD': 321.24911679768604, 'IXN': 898.3623298536731}
#
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'IXN']
# Top 2 ETFs for 2024-12-02 to 2024-12-08: ['IXN', 'IGM']
# Sell XSD: 321.25 shares at 252.68. Total value: 80970.29
# Buy IGM: 787.90 shares at 102.51.
# Updated ticker shares after 2024-12-02 to 2024-12-08: {'IXN': 898.3623298536731, 'IGM': 787.902292524192}
#
# Top 2 ETFs for 2024-12-02 to 2024-12-08: ['IXN', 'IGM']
# Top 2 ETFs for 2024-12-09 to 2024-12-15: ['PSI', 'XSD']
# Sell IXN: 898.36 shares at 86.27. Total value: 77307.96
# Buy PSI: 1303.71 shares at 59.15.
# Sell IGM: 787.90 shares at 104.44. Total value: 82082.80
# Buy XSD: 315.52 shares at 259.50.
# Updated ticker shares after 2024-12-09 to 2024-12-15: {'PSI': 1303.714099767372, 'XSD': 315.52057445578265}
#
# Top 2 ETFs for 2024-12-09 to 2024-12-15: ['PSI', 'XSD']
# Top 2 ETFs for 2024-12-16 to 2024-12-22: ['IXN', 'FTEC']
# Sell PSI: 1303.71 shares at 60.98. Total value: 79301.73
# Buy IXN: 900.54 shares at 87.84.
# Sell XSD: 315.52 shares at 265.16. Total value: 83454.28
# Buy FTEC: 431.82 shares at 192.78.
# Updated ticker shares after 2024-12-16 to 2024-12-22: {'IXN': 900.5405618954563, 'FTEC': 431.8168011120174}
#
# Top 2 ETFs for 2024-12-16 to 2024-12-22: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-12-23 to 2024-12-29: ['SMH', 'SOXX']
# Sell IXN: 900.54 shares at 86.71. Total value: 77890.66
# Buy SMH: 311.76 shares at 249.22.
# Sell FTEC: 431.82 shares at 189.61. Total value: 81672.09
# Buy SOXX: 368.10 shares at 221.32.
# Updated ticker shares after 2024-12-23 to 2024-12-29: {'SMH': 311.7563983513831, 'SOXX': 368.100076977461}
# Warning: Missing alignment for 2024-12-30 to 2024-12-31. Skipping week.
# Using data for the 52nd week: 2024-12-23 to 2024-12-29
# Fetching data starting from the first trading day of the 53rd week: 2025-01-01
# Fetching data for ticker SMH starting from 2025-01-01...
# SMH: 311.76 shares at $244.79 each, total value: $76314.85
# Fetching data for ticker SOXX starting from 2025-01-01...
# SOXX: 368.10 shares at $216.82 each, total value: $79811.46
#
# ETF values on the 53rd week's first trading day:
# Total portfolio value: 156126.31
# SMH: 76314.85
# SOXX: 79811.46

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_week = main_weekly(tickers, results, smoothing=True)
# Out:
# Fetching full-year data for all tickers...
# Downloading data for SMH for the entire year...
# Downloading data for SOXX for the entire year...
# Downloading data for PSI for the entire year...
# Downloading data for XSD for the entire year...
# Downloading data for IYW for the entire year...
# Downloading data for XLK for the entire year...
# Downloading data for VGT for the entire year...
# Downloading data for FTEC for the entire year...
# Downloading data for IGM for the entire year...
# Downloading data for IXN for the entire year...
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1  1.218634
# 1  SOXX   1w             0.1 -1.098848
# 2   PSI   1w             0.1 -4.241914
# 3   XSD   1w             0.1 -6.263587
# 4   IYW   1w             0.1  2.021063
# Top ETFs for 2024-01-01 to 2024-01-07: ['IGM', 'IYW']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1  0.967082
# 1  SOXX   2w             0.1 -1.242046
# 2   PSI   2w             0.1 -2.419493
# 3   XSD   2w             0.1 -4.569912
# 4   IYW   2w             0.1  1.718178
# Top ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'IYW']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  5.141279
# 1  SOXX   3w             0.1  4.025096
# 2   PSI   3w             0.1  3.766788
# 3   XSD   3w             0.1 -1.952930
# 4   IYW   3w             0.1 -1.671692
# Top ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1 -0.971168
# 1  SOXX   4w             0.1 -3.331910
# 2   PSI   4w             0.1 -1.220534
# 3   XSD   4w             0.1 -1.081041
# 4   IYW   4w             0.1  1.042395
# Top ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IXN']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1  3.425376
# 1  SOXX   5w             0.1 -1.894328
# 2   PSI   5w             0.1 -1.494017
# 3   XSD   5w             0.1 -2.514079
# 4   IYW   5w             0.1 -0.182518
# Top ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'SMH']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  5.577573
# 1  SOXX   6w             0.1  3.559031
# 2   PSI   6w             0.1  0.988541
# 3   XSD   6w             0.1  2.102205
# 4   IYW   6w             0.1 -2.145754
# Top ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1  0.596546
# 1  SOXX   7w             0.1  1.409293
# 2   PSI   7w             0.1  5.254398
# 3   XSD   7w             0.1  3.111551
# 4   IYW   7w             0.1 -2.168221
# Top ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'XSD']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1  3.754980
# 1  SOXX   8w             0.1  1.036363
# 2   PSI   8w             0.1 -6.642323
# 3   XSD   8w             0.1 -4.691188
# 4   IYW   8w             0.1  1.642242
# Top ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'IXN']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1  1.714226
# 1  SOXX   9w             0.1  2.812309
# 2   PSI   9w             0.1  5.069485
# 3   XSD   9w             0.1  3.601431
# 4   IYW   9w             0.1 -3.786336
# Top ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  6.728982
# 1  SOXX  10w             0.1  3.536062
# 2   PSI  10w             0.1 -0.076266
# 3   XSD  10w             0.1 -0.203809
# 4   IYW  10w             0.1 -2.849316
# Top ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1 -1.935058
# 1  SOXX  11w             0.1 -3.118233
# 2   PSI  11w             0.1 -4.374900
# 3   XSD  11w             0.1 -1.893292
# 4   IYW  11w             0.1  2.155878
# Top ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1 -0.339687
# 1  SOXX  12w             0.1 -3.427197
# 2   PSI  12w             0.1  2.477461
# 3   XSD  12w             0.1 -3.477895
# 4   IYW  12w             0.1  2.251768
# Top ETFs for 2024-03-18 to 2024-03-24: ['PSI', 'IYW']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1 -1.945228
# 1  SOXX  13w             0.1  1.205021
# 2   PSI  13w             0.1  2.330430
# 3   XSD  13w             0.1  7.158291
# 4   IYW  13w             0.1 -2.217982
# Top ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1  2.436729
# 1  SOXX  14w             0.1 -0.405432
# 2   PSI  14w             0.1  3.649001
# 3   XSD  14w             0.1 -0.513094
# 4   IYW  14w             0.1  0.451580
# Top ETFs for 2024-04-01 to 2024-04-07: ['PSI', 'SMH']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1  0.555890
# 1  SOXX  15w             0.1 -0.349955
# 2   PSI  15w             0.1 -0.863097
# 3   XSD  15w             0.1  2.815034
# 4   IYW  15w             0.1 -0.035678
# Top ETFs for 2024-04-08 to 2024-04-14: ['XSD', 'SMH']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1  0.649719
# 1  SOXX  16w             0.1  2.293527
# 2   PSI  16w             0.1  1.020821
# 3   XSD  16w             0.1 -3.136700
# 4   IYW  16w             0.1 -0.009873
# Top ETFs for 2024-04-15 to 2024-04-21: ['SOXX', 'PSI']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1  2.778415
# 1  SOXX  17w             0.1  4.497389
# 2   PSI  17w             0.1  3.154677
# 3   XSD  17w             0.1  2.082981
# 4   IYW  17w             0.1 -1.855312
# Top ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'PSI']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1 -2.139517
# 1  SOXX  18w             0.1 -0.875523
# 2   PSI  18w             0.1  0.857850
# 3   XSD  18w             0.1  3.917098
# 4   IYW  18w             0.1 -1.040952
# Top ETFs for 2024-04-29 to 2024-05-05: ['XSD', 'XLK']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1  2.964153
# 1  SOXX  19w             0.1 -0.026649
# 2   PSI  19w             0.1  3.671503
# 3   XSD  19w             0.1  0.367306
# 4   IYW  19w             0.1 -2.135323
# Top ETFs for 2024-05-06 to 2024-05-12: ['PSI', 'SMH']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1 -3.671795
# 1  SOXX  20w             0.1  0.734204
# 2   PSI  20w             0.1 -4.781866
# 3   XSD  20w             0.1  4.480236
# 4   IYW  20w             0.1  0.318486
# Top ETFs for 2024-05-13 to 2024-05-19: ['XSD', 'VGT']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  6.326567
# 1  SOXX  21w             0.1  2.538308
# 2   PSI  21w             0.1  0.875554
# 3   XSD  21w             0.1 -0.792001
# 4   IYW  21w             0.1 -0.794232
# Top ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1  2.491608
# 1  SOXX  22w             0.1  1.135617
# 2   PSI  22w             0.1  1.657105
# 3   XSD  22w             0.1  5.033065
# 4   IYW  22w             0.1 -0.838853
# Top ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'SMH']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1  4.083697
# 1  SOXX  23w             0.1 -1.547230
# 2   PSI  23w             0.1 -3.643236
# 3   XSD  23w             0.1 -5.425885
# 4   IYW  23w             0.1  2.352027
# Top ETFs for 2024-06-03 to 2024-06-09: ['SMH', 'IXN']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1  4.260063
# 1  SOXX  24w             0.1  2.312424
# 2   PSI  24w             0.1  1.633608
# 3   XSD  24w             0.1 -1.990938
# 4   IYW  24w             0.1 -1.261789
# Top ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'SOXX']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1 -1.018621
# 1  SOXX  25w             0.1 -0.914565
# 2   PSI  25w             0.1  0.710276
# 3   XSD  25w             0.1 -5.515679
# 4   IYW  25w             0.1 -0.457279
# Top ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1 -6.509715
# 1  SOXX  26w             0.1 -4.925440
# 2   PSI  26w             0.1  4.063954
# 3   XSD  26w             0.1 -0.450342
# 4   IYW  26w             0.1  2.892941
# Top ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'IGM']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1 -1.195253
# 1  SOXX  27w             0.1 -2.734003
# 2   PSI  27w             0.1 -4.286957
# 3   XSD  27w             0.1 -3.122056
# 4   IYW  27w             0.1  4.690124
# Top ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IXN']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1  1.451685
# 1  SOXX  28w             0.1  2.007708
# 2   PSI  28w             0.1  1.097496
# 3   XSD  28w             0.1  5.971634
# 4   IYW  28w             0.1 -2.758313
# Top ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SOXX']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1 -3.969211
# 1  SOXX  29w             0.1 -2.473937
# 2   PSI  29w             0.1 -1.185505
# 3   XSD  29w             0.1  3.887719
# 4   IYW  29w             0.1  0.976220
# Top ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'VGT']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1 -0.007249
# 1  SOXX  30w             0.1  0.537932
# 2   PSI  30w             0.1 -1.624730
# 3   XSD  30w             0.1  1.282762
# 4   IYW  30w             0.1 -0.757321
# Top ETFs for 2024-07-22 to 2024-07-28: ['XSD', 'XLK']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1 -1.556014
# 1  SOXX  31w             0.1  2.094647
# 2   PSI  31w             0.1 -1.490003
# 3   XSD  31w             0.1  2.365023
# 4   IYW  31w             0.1  0.595787
# Top ETFs for 2024-07-29 to 2024-08-04: ['XSD', 'SOXX']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1  2.639609
# 1  SOXX  32w             0.1  3.727914
# 2   PSI  32w             0.1  8.514914
# 3   XSD  32w             0.1 -0.965646
# 4   IYW  32w             0.1 -2.851625
# Top ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SOXX']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1  3.867609
# 1  SOXX  33w             0.1  1.064380
# 2   PSI  33w             0.1 -0.723808
# 3   XSD  33w             0.1 -2.435655
# 4   IYW  33w             0.1 -0.592341
# Top ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'XLK']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1 -0.948261
# 1  SOXX  34w             0.1 -1.142770
# 2   PSI  34w             0.1 -1.749166
# 3   XSD  34w             0.1  4.421164
# 4   IYW  34w             0.1 -1.408851
# Top ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'XLK']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1 -2.078687
# 1  SOXX  35w             0.1  0.960590
# 2   PSI  35w             0.1 -0.090966
# 3   XSD  35w             0.1  7.099902
# 4   IYW  35w             0.1 -0.845595
# Top ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'SOXX']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1 -0.429768
# 1  SOXX  36w             0.1 -0.357457
# 2   PSI  36w             0.1  0.879552
# 3   XSD  36w             0.1 -3.007025
# 4   IYW  36w             0.1  1.520123
# Top ETFs for 2024-09-02 to 2024-09-08: ['IYW', 'FTEC']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1  3.983038
# 1  SOXX  37w             0.1  2.253627
# 2   PSI  37w             0.1 -3.539079
# 3   XSD  37w             0.1 -0.219220
# 4   IYW  37w             0.1 -1.220015
# Top ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1 -2.613362
# 1  SOXX  38w             0.1 -2.624256
# 2   PSI  38w             0.1 -4.476008
# 3   XSD  38w             0.1 -0.881768
# 4   IYW  38w             0.1  1.410106
# Top ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1  3.732589
# 1  SOXX  39w             0.1  3.198861
# 2   PSI  39w             0.1  3.674544
# 3   XSD  39w             0.1  3.278692
# 4   IYW  39w             0.1 -3.329042
# Top ETFs for 2024-09-23 to 2024-09-29: ['SMH', 'PSI']
# Processing scores for 2024-09-30 to 2024-10-06:
#     ETF Week  RiskPercentage     Score
# 0   SMH  40w             0.1 -1.439208
# 1  SOXX  40w             0.1 -2.533890
# 2   PSI  40w             0.1 -3.141547
# 3   XSD  40w             0.1 -4.464898
# 4   IYW  40w             0.1  3.746144
# Top ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IYW']
# Processing scores for 2024-10-07 to 2024-10-13:
#     ETF Week  RiskPercentage     Score
# 0   SMH  41w             0.1  7.250498
# 1  SOXX  41w             0.1 -1.493352
# 2   PSI  41w             0.1  3.924801
# 3   XSD  41w             0.1 -0.835948
# 4   IYW  41w             0.1 -1.747943
# Top ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'PSI']
# Processing scores for 2024-10-14 to 2024-10-20:
#     ETF Week  RiskPercentage     Score
# 0   SMH  42w             0.1 -0.786108
# 1  SOXX  42w             0.1 -1.369226
# 2   PSI  42w             0.1 -3.223649
# 3   XSD  42w             0.1 -1.169105
# 4   IYW  42w             0.1  1.527667
# Top ETFs for 2024-10-14 to 2024-10-20: ['VGT', 'FTEC']
# Processing scores for 2024-10-21 to 2024-10-27:
#     ETF Week  RiskPercentage     Score
# 0   SMH  43w             0.1  3.670190
# 1  SOXX  43w             0.1 -2.498274
# 2   PSI  43w             0.1 -2.963135
# 3   XSD  43w             0.1 -1.880158
# 4   IYW  43w             0.1  2.890321
# Top ETFs for 2024-10-21 to 2024-10-27: ['SMH', 'IYW']
# Processing scores for 2024-10-28 to 2024-11-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH  44w             0.1 -3.108513
# 1  SOXX  44w             0.1 -1.401353
# 2   PSI  44w             0.1 -2.376363
# 3   XSD  44w             0.1  3.314203
# 4   IYW  44w             0.1  0.969024
# Top ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IGM']
# Processing scores for 2024-11-04 to 2024-11-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  45w             0.1 -0.114093
# 1  SOXX  45w             0.1 -4.185265
# 2   PSI  45w             0.1 -0.863115
# 3   XSD  45w             0.1 -0.322516
# 4   IYW  45w             0.1  0.246975
# Top ETFs for 2024-11-04 to 2024-11-10: ['VGT', 'XLK']
# Processing scores for 2024-11-11 to 2024-11-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  46w             0.1 -1.747752
# 1  SOXX  46w             0.1 -2.642572
# 2   PSI  46w             0.1 -3.411976
# 3   XSD  46w             0.1 -4.113921
# 4   IYW  46w             0.1  1.796071
# Top ETFs for 2024-11-11 to 2024-11-17: ['IGM', 'VGT']
# Processing scores for 2024-11-18 to 2024-11-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  47w             0.1 -1.758788
# 1  SOXX  47w             0.1 -0.565805
# 2   PSI  47w             0.1  4.154520
# 3   XSD  47w             0.1  5.828380
# 4   IYW  47w             0.1 -1.023964
# Top ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'PSI']
# Processing scores for 2024-11-25 to 2024-12-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  48w             0.1 -3.833101
# 1  SOXX  48w             0.1  0.491976
# 2   PSI  48w             0.1  2.354675
# 3   XSD  48w             0.1  5.184781
# 4   IYW  48w             0.1 -1.227381
# Top ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'PSI']
# Processing scores for 2024-12-02 to 2024-12-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  49w             0.1 -1.290466
# 1  SOXX  49w             0.1 -2.667542
# 2   PSI  49w             0.1 -0.871999
# 3   XSD  49w             0.1  0.969535
# 4   IYW  49w             0.1  1.271882
# Top ETFs for 2024-12-02 to 2024-12-08: ['IGM', 'IYW']
# Processing scores for 2024-12-09 to 2024-12-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  50w             0.1 -1.104118
# 1  SOXX  50w             0.1  0.663381
# 2   PSI  50w             0.1  6.127159
# 3   XSD  50w             0.1  5.198031
# 4   IYW  50w             0.1 -2.218631
# Top ETFs for 2024-12-09 to 2024-12-15: ['PSI', 'XSD']
# Processing scores for 2024-12-16 to 2024-12-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  51w             0.1  0.106692
# 1  SOXX  51w             0.1 -0.357984
# 2   PSI  51w             0.1  0.593620
# 3   XSD  51w             0.1 -7.740398
# 4   IYW  51w             0.1  1.135777
# Top ETFs for 2024-12-16 to 2024-12-22: ['IGM', 'IXN']
# Processing scores for 2024-12-23 to 2024-12-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  52w             0.1  3.018671
# 1  SOXX  52w             0.1  3.074443
# 2   PSI  52w             0.1  1.900957
# 3   XSD  52w             0.1  2.534755
# 4   IYW  52w             0.1 -2.064533
# Top ETFs for 2024-12-23 to 2024-12-29: ['SOXX', 'SMH']
#
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['IGM', 'IYW']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'IYW']
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'IGM': 685.8026957229545, 'IYW': 417.29418842728313}
#
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'IYW']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Sell IGM: 685.80 shares at 75.45. Total value: 51613.31
# Buy SMH: 293.02 shares at 175.70.
# Sell IYW: 417.29 shares at 123.36. Total value: 51348.72
# Buy SOXX: 271.83 shares at 188.43.
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'SMH': 293.0237996553952, 'SOXX': 271.82692780943125}
#
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IXN']
# Sell SMH: 293.02 shares at 188.05. Total value: 54965.37
# Buy IGM: 697.13 shares at 78.65.
# Sell SOXX: 271.83 shares at 201.07. Total value: 54518.70
# Buy IXN: 768.55 shares at 70.76.
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'IGM': 697.1280216874455, 'IXN': 768.5471635439258}
#
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IXN']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'SMH']
# Sell IXN: 768.55 shares at 71.84. Total value: 55074.39
# Buy SMH: 288.41 shares at 190.48.
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'IGM': 697.1280216874455, 'SMH': 288.41195714671915}
#
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'SMH']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Sell IGM: 697.13 shares at 81.27. Total value: 56511.64
# Buy SOXX: 279.70 shares at 201.54.
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'SMH': 288.41195714671915, 'SOXX': 279.6981375414314}
#
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'XSD']
# Sell SMH: 288.41 shares at 203.06. Total value: 58418.52
# Buy PSI: 1106.16 shares at 52.68.
# Sell SOXX: 279.70 shares at 209.43. Total value: 58430.74
# Buy XSD: 257.30 shares at 226.52.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'PSI': 1106.1593081009742, 'XSD': 257.30468837317613}
#
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'XSD']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'IXN']
# Sell PSI: 1106.16 shares at 51.59. Total value: 56924.09
# Buy SMH: 287.10 shares at 197.78.
# Sell XSD: 257.30 shares at 217.39. Total value: 55795.63
# Buy IXN: 782.02 shares at 71.17.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'SMH': 287.0956724494324, 'IXN': 782.0168574783601}
#
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'IXN']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Sell SMH: 287.10 shares at 210.35. Total value: 60239.60
# Buy PSI: 1126.95 shares at 53.32.
# Sell IXN: 782.02 shares at 73.12. Total value: 57038.12
# Buy XSD: 257.76 shares at 220.73.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'PSI': 1126.9505130306022, 'XSD': 257.76073880237243}
#
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Sell PSI: 1126.95 shares at 56.78. Total value: 63828.28
# Buy SMH: 284.12 shares at 224.09.
# Sell XSD: 257.76 shares at 231.79. Total value: 59596.99
# Buy SOXX: 259.78 shares at 228.84.
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'SMH': 284.12114988385025, 'SOXX': 259.77976963354223}
#
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Sell SMH: 284.12 shares at 220.98. Total value: 62628.13
# Buy XLK: 302.12 shares at 206.78.
# Sell SOXX: 259.78 shares at 225.10. Total value: 58330.24
# Buy IYW: 437.64 shares at 132.95.
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'XLK': 302.1160547954787, 'IYW': 437.6413118065322}
#
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['PSI', 'IYW']
# Sell XLK: 302.12 shares at 206.30. Total value: 62170.73
# Buy PSI: 1155.71 shares at 53.66.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'IYW': 437.6413118065322, 'PSI': 1155.7081630339512}
#
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['PSI', 'IYW']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Sell IYW: 437.64 shares at 135.90. Total value: 59326.76
# Buy XSD: 261.62 shares at 226.20.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'PSI': 1155.7081630339512, 'XSD': 261.62001266716976}
#
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['PSI', 'SMH']
# Sell XSD: 261.62 shares at 233.86. Total value: 61029.50
# Buy SMH: 267.07 shares at 227.94.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'PSI': 1155.7081630339512, 'SMH': 267.07434315490667}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['PSI', 'SMH']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['XSD', 'SMH']
# Sell PSI: 1155.71 shares at 56.38. Total value: 64995.93
# Buy XSD: 281.44 shares at 230.36.
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'SMH': 267.07434315490667, 'XSD': 281.444002430301}
#
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['XSD', 'SMH']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['SOXX', 'PSI']
# Sell XSD: 281.44 shares at 218.68. Total value: 61392.31
# Buy SOXX: 284.42 shares at 215.31.
# Sell SMH: 267.07 shares at 217.36. Total value: 57906.15
# Buy PSI: 1061.79 shares at 54.40.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'SOXX': 284.4216566165832, 'PSI': 1061.7901506348705}
#
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['SOXX', 'PSI']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'PSI']
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'SOXX': 284.4216566165832, 'PSI': 1061.7901506348705}
#
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'PSI']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['XSD', 'XLK']
# Sell SOXX: 284.42 shares at 218.55. Total value: 62004.95
# Buy XSD: 270.51 shares at 228.64.
# Sell PSI: 1061.79 shares at 55.04. Total value: 58294.83
# Buy XLK: 289.75 shares at 200.69.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'XSD': 270.5123373830136, 'XLK': 289.7458306699716}
#
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['XSD', 'XLK']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['PSI', 'SMH']
# Sell XSD: 270.51 shares at 230.00. Total value: 62062.29
# Buy PSI: 1105.68 shares at 55.99.
# Sell XLK: 289.75 shares at 204.93. Total value: 59229.17
# Buy SMH: 265.33 shares at 222.67.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'PSI': 1105.6820042103434, 'SMH': 265.3302847179818}
#
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['PSI', 'SMH']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['XSD', 'VGT']
# Sell PSI: 1105.68 shares at 56.06. Total value: 61829.57
# Buy XSD: 267.30 shares at 230.73.
# Sell SMH: 265.33 shares at 223.26. Total value: 59089.54
# Buy VGT: 113.62 shares at 518.78.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'XSD': 267.3037773435158, 'VGT': 113.61620846163642}
#
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['XSD', 'VGT']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Sell XSD: 267.30 shares at 241.73. Total value: 64453.80
# Buy SMH: 273.59 shares at 235.00.
# Sell VGT: 113.62 shares at 539.30. Total value: 61120.04
# Buy SOXX: 261.37 shares at 233.26.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'SMH': 273.5858216864174, 'SOXX': 261.3703083710694}
#
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'SMH']
# Sell SOXX: 261.37 shares at 242.59. Total value: 63247.31
# Buy XSD: 253.14 shares at 249.23.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'SMH': 273.5858216864174, 'XSD': 253.13642181006355}
#
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'SMH']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['SMH', 'IXN']
# Sell XSD: 253.14 shares at 245.69. Total value: 62037.61
# Buy IXN: 803.04 shares at 77.06.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'SMH': 273.5858216864174, 'IXN': 803.0432561564515}
#
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['SMH', 'IXN']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'SOXX']
# Sell IXN: 803.04 shares at 79.41. Total value: 63610.24
# Buy SOXX: 260.60 shares at 243.48.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'SMH': 273.5858216864174, 'SOXX': 260.60136046693185}
#
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Sell SMH: 273.59 shares at 272.48. Total value: 74360.30
# Buy XLK: 320.93 shares at 231.12.
# Sell SOXX: 260.60 shares at 256.02. Total value: 66552.36
# Buy IXN: 786.66 shares at 84.39.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'XLK': 320.9345874180558, 'IXN': 786.6569395822337}
#
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'IGM']
# Sell XLK: 320.93 shares at 222.42. Total value: 71203.81
# Buy PSI: 1168.96 shares at 60.76.
# Sell IXN: 786.66 shares at 81.49. Total value: 63944.41
# Buy IGM: 688.15 shares at 92.69.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'PSI': 1168.9566671394084, 'IGM': 688.1491847944292}
#
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'IGM']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IXN']
# Sell PSI: 1168.96 shares at 62.76. Total value: 73180.31
# Buy IYW: 480.18 shares at 152.02.
# Sell IGM: 688.15 shares at 94.93. Total value: 65162.69
# Buy IXN: 777.32 shares at 83.62.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'IYW': 480.18258352161126, 'IXN': 777.3233492401471}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IXN']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SOXX']
# Sell IYW: 480.18 shares at 156.96. Total value: 75181.04
# Buy XSD: 287.67 shares at 260.69.
# Sell IXN: 777.32 shares at 86.54. Total value: 67101.39
# Buy SOXX: 257.84 shares at 259.59.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 287.6715047856788, 'SOXX': 257.8436646910561}
#
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SOXX']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'VGT']
# Sell SOXX: 257.84 shares at 260.18. Total value: 66918.05
# Buy VGT: 110.55 shares at 603.78.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'XSD': 287.6715047856788, 'VGT': 110.55475508292776}
#
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'VGT']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['XSD', 'XLK']
# Sell VGT: 110.55 shares at 584.23. Total value: 64427.93
# Buy XLK: 284.24 shares at 226.10.
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'XSD': 287.6715047856788, 'XLK': 284.24085510707084}
#
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['XSD', 'XLK']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['XSD', 'SOXX']
# Sell XLK: 284.24 shares at 215.32. Total value: 61049.74
# Buy SOXX: 266.05 shares at 228.89.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'XSD': 287.6715047856788, 'SOXX': 266.0540520250317}
#
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['XSD', 'SOXX']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SOXX']
# Sell XSD: 287.67 shares at 206.84. Total value: 59353.22
# Buy PSI: 1194.13 shares at 49.58.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'SOXX': 266.0540520250317, 'PSI': 1194.127326184392}
#
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SOXX']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'XLK']
# Sell PSI: 1194.13 shares at 53.06. Total value: 63202.00
# Buy SMH: 277.78 shares at 226.96.
# Sell SOXX: 266.05 shares at 213.00. Total value: 56527.84
# Buy XLK: 271.99 shares at 207.31.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'SMH': 277.77577421980595, 'XLK': 271.99131910869306}
#
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'XLK']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'XLK']
# Sell SMH: 277.78 shares at 251.34. Total value: 69641.62
# Buy XSD: 295.67 shares at 234.95.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'XLK': 271.99131910869306, 'XSD': 295.66937015581715}
#
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'XLK']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'SOXX']
# Sell XLK: 271.99 shares at 221.15. Total value: 60000.50
# Buy SOXX: 263.04 shares at 227.53.
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'XSD': 295.66937015581715, 'SOXX': 263.04443560001084}
#
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'SOXX']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IYW', 'FTEC']
# Sell XSD: 295.67 shares at 222.36. Total value: 65580.68
# Buy IYW: 462.05 shares at 141.58.
# Sell SOXX: 263.04 shares at 213.50. Total value: 56019.59
# Buy FTEC: 342.61 shares at 163.10.
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'IYW': 462.04779052226127, 'FTEC': 342.6090495058147}
#
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Sell IYW: 462.05 shares at 139.41. Total value: 64253.05
# Buy SMH: 291.51 shares at 219.86.
# Sell FTEC: 342.61 shares at 160.54. Total value: 54864.95
# Buy SOXX: 263.16 shares at 207.96.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'SMH': 291.51467369250304, 'SOXX': 263.1649559212387}
#
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Sell SMH: 291.51 shares at 233.80. Total value: 67985.74
# Buy IGM: 734.81 shares at 92.29.
# Sell SOXX: 263.16 shares at 219.88. Total value: 57720.05
# Buy IYW: 394.25 shares at 146.04.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'IGM': 734.8117482287025, 'IYW': 394.24645669234064}
#
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['SMH', 'PSI']
# Sell IGM: 734.81 shares at 94.58. Total value: 69324.75
# Buy SMH: 289.40 shares at 238.95.
# Sell IYW: 394.25 shares at 149.26. Total value: 58698.11
# Buy PSI: 1062.45 shares at 55.11.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'SMH': 289.39710926662224, 'PSI': 1062.4453815028428}
#
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['SMH', 'PSI']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IYW']
# Sell SMH: 289.40 shares at 245.45. Total value: 70854.94
# Buy IGM: 736.69 shares at 95.94.
# Sell PSI: 1062.45 shares at 57.52. Total value: 60959.08
# Buy IYW: 401.05 shares at 151.62.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'IGM': 736.6875040971947, 'IYW': 401.0465864898657}
#
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IYW']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'PSI']
# Sell IGM: 736.69 shares at 95.46. Total value: 70148.38
# Buy SMH: 281.90 shares at 248.22.
# Sell IYW: 401.05 shares at 150.36. Total value: 60150.61
# Buy PSI: 1048.04 shares at 57.25.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'SMH': 281.8991487647655, 'PSI': 1048.0390401393856}
#
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'PSI']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['VGT', 'FTEC']
# Sell SMH: 281.90 shares at 261.28. Total value: 73470.47
# Buy VGT: 120.56 shares at 607.88.
# Sell PSI: 1048.04 shares at 60.18. Total value: 62913.31
# Buy FTEC: 347.04 shares at 180.83.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'VGT': 120.56128833247791, 'FTEC': 347.04434200561883}
#
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['VGT', 'FTEC']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['SMH', 'IYW']
# Sell VGT: 120.56 shares at 606.93. Total value: 72989.33
# Buy SMH: 287.96 shares at 252.84.
# Sell FTEC: 347.04 shares at 180.45. Total value: 62467.59
# Buy IYW: 398.82 shares at 156.24.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'SMH': 287.9562526362693, 'IYW': 398.8186054384528}
#
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['SMH', 'IYW']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IGM']
# Sell SMH: 287.96 shares at 251.21. Total value: 72156.65
# Buy XSD: 291.60 shares at 246.83.
# Sell IYW: 398.82 shares at 155.65. Total value: 61920.92
# Buy IGM: 630.59 shares at 97.95.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'XSD': 291.60254536585, 'IGM': 630.5882882582973}
#
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IGM']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['VGT', 'XLK']
# Sell XSD: 291.60 shares at 233.24. Total value: 67843.35
# Buy VGT: 115.50 shares at 585.90.
# Sell IGM: 630.59 shares at 95.86. Total value: 60297.07
# Buy XLK: 268.82 shares at 223.74.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'VGT': 115.50389938596659, 'XLK': 268.8224235870174}
#
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['VGT', 'XLK']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IGM', 'VGT']
# Sell XLK: 268.82 shares at 235.85. Total value: 63243.27
# Buy IGM: 619.33 shares at 101.86.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'VGT': 115.50389938596659, 'IGM': 619.3319976005781}
#
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IGM', 'VGT']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'PSI']
# Sell IGM: 619.33 shares at 99.13. Total value: 61240.89
# Buy XSD: 267.24 shares at 228.59.
# Sell VGT: 115.50 shares at 604.72. Total value: 69672.90
# Buy PSI: 1285.58 shares at 54.06.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'XSD': 267.23737704412406, 'PSI': 1285.5847551054221}
#
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'PSI']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'PSI']
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'XSD': 267.23737704412406, 'PSI': 1285.5847551054221}
#
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'PSI']
# Top 2 ETFs for 2024-12-02 to 2024-12-08: ['IGM', 'IYW']
# Sell XSD: 267.24 shares at 252.68. Total value: 67356.72
# Buy IGM: 655.43 shares at 102.51.
# Sell PSI: 1285.58 shares at 57.84. Total value: 74172.33
# Buy IYW: 459.49 shares at 161.02.
# Updated ticker shares after 2024-12-02 to 2024-12-08: {'IGM': 655.431971673934, 'IYW': 459.48884669635464}
#
# Top 2 ETFs for 2024-12-02 to 2024-12-08: ['IGM', 'IYW']
# Top 2 ETFs for 2024-12-09 to 2024-12-15: ['PSI', 'XSD']
# Sell IGM: 655.43 shares at 104.44. Total value: 68282.18
# Buy PSI: 1151.50 shares at 59.15.
# Sell IYW: 459.49 shares at 164.15. Total value: 75236.53
# Buy XSD: 289.20 shares at 259.50.
# Updated ticker shares after 2024-12-09 to 2024-12-15: {'PSI': 1151.5042470729645, 'XSD': 289.2039974205274}
#
# Top 2 ETFs for 2024-12-09 to 2024-12-15: ['PSI', 'XSD']
# Top 2 ETFs for 2024-12-16 to 2024-12-22: ['IGM', 'IXN']
# Sell PSI: 1151.50 shares at 60.98. Total value: 70043.18
# Buy IGM: 653.28 shares at 106.95.
# Sell XSD: 289.20 shares at 265.16. Total value: 76493.62
# Buy IXN: 868.65 shares at 87.84.
# Updated ticker shares after 2024-12-16 to 2024-12-22: {'IGM': 653.2779399513279, 'IXN': 868.6519673779368}
#
# Top 2 ETFs for 2024-12-16 to 2024-12-22: ['IGM', 'IXN']
# Top 2 ETFs for 2024-12-23 to 2024-12-29: ['SOXX', 'SMH']
# Sell IGM: 653.28 shares at 104.55. Total value: 68129.46
# Buy SOXX: 307.06 shares at 221.32.
# Sell IXN: 868.65 shares at 86.71. Total value: 75132.51
# Buy SMH: 300.72 shares at 249.22.
# Updated ticker shares after 2024-12-23 to 2024-12-29: {'SOXX': 307.06277873577164, 'SMH': 300.71694738612644}
# Warning: Missing alignment for 2024-12-30 to 2024-12-31. Skipping week.
# Using data for the 52nd week: 2024-12-23 to 2024-12-29
# Fetching data starting from the first trading day of the 53rd week: 2025-01-01
# Fetching data for ticker SOXX starting from 2025-01-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# SOXX: 307.06 shares at $216.82 each, total value: $66577.35
# Fetching data for ticker SMH starting from 2025-01-01...
# SMH: 300.72 shares at $244.79 each, total value: $73612.50
#
# ETF values on the 53rd week's first trading day:
# Total portfolio value: 140189.85
# SOXX: 66577.35
# SMH: 73612.50

# %%
def process_etf_data_monthly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = {}

    # Determine forecast periods dynamically from the etf_dict
    sample_etf = next(iter(etf_dict.values()))
    forecast_periods = [key.split('_')[-1] for key in sample_etf.keys() if key.startswith('forecast_predictions_df')]

    for etf_name in tickers:
        etf_pred_dict[etf_name] = {
            f"returns_{period}": etf_dict[etf_name][f"forecast_predictions_df_{period}"]
            for period in forecast_periods
        }

        for period in forecast_periods:
            returns = etf_pred_dict[etf_name][f"returns_{period}"]

            if smoothing:
                # Apply smoothing
                smoothed_returns = calculate_smoothing(returns)
                etf_pred_dict[etf_name][f"smoothed_returns_{period}"] = smoothed_returns

                # Calculate metrics using smoothed returns
                etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(smoothed_returns)
            else:
                # Calculate metrics using raw returns
                etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
                etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
                etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
                etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict


def calculate_means_and_stds_monthly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    print(f"\nDebug: Forecast Period = {forecast_period}")
    print(f"All Returns Means: {[np.mean(returns) for returns in returns_list]}")
    print(f"Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Rachev Ratios: {rachev_ratios}")
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sharpe Ratios: {sharpe_ratios}")
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sortino Ratios: {sortino_ratios}")
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Volatility Clustering: {volatility_clustering}")
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    print(f"Mean Rachev = {mean_rachev}, Std Rachev = {std_rachev}")
    print(f"Mean Sharpe = {mean_sharpe}, Std Sharpe = {std_sharpe}")
    print(f"Mean Sortino = {mean_sortino}, Std Sortino = {std_sortino}")
    print(f"Mean Volatility Clustering = {mean_volatility_clustering}, Std Volatility Clustering = {std_volatility_clustering}")

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )

def calculate_scores_for_etfs_monthly(etf_pred_dict, forecast_period, risk_percentage, smoothing = True):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_monthly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Debugging: Log inputs to composite score calculation
        print(f"\nDebug: ETF = {etf}, Forecast Period = {forecast_period}")
        print(f"Forecasted Values Mean: {np.mean(forecasted_values)}")
        print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
        print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")
        print(f"Means and Stds: Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")
        
        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Month': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

        # Debugging: Log the calculated score
        print(f"Calculated Score for {etf} ({forecast_period}): {score}")

    return scores

def select_top_etfs_monthly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()


def generate_month_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    month_ranges = []

    while start < end:
        month_start = start
        month_end = (start + timedelta(days=31)).replace(day=1) - timedelta(days=1)
        if month_end > end:
            month_end = end
        month_ranges.append((month_start.strftime('%Y-%m-%d'), month_end.strftime('%Y-%m-%d')))
        start = month_end + timedelta(days=1)

    return month_ranges

def gather_etf_data_for_months(tickers, month_ranges):
    etf_histories = {}
    for start_date, end_date in month_ranges:
        month = f"{start_date} to {end_date}"
        etf_histories[month] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date, progress=False)
            if etf_data.empty:
                print(f"No data found for {ticker} in {month}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[month][ticker] = etf_data
    return etf_histories

# Function to initialize shares for the first month
def initialize_shares_for_first_month(top_etfs_1m, etf_histories, month, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = month.split(" to ")[0]

    for ticker in top_etfs_1m:
        etf_history = etf_histories.get(month, {}).get(ticker)

        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]

            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.9975) / price_on_first_trading_day
            print(f"Shares 1st month: ({investment_amount} * 0.9975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {month}")
    return ticker_shares


def manage_etf_portfolio_monthly(
    top_etfs_previous, top_etfs_current, previous_month, current_month, ticker_shares, gathered_data_per_month
):
    etf_histories_for_current_month = gathered_data_per_month.get(current_month, {})

    # Extract ETFs as lists to preserve order
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_month}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_month}: {top2etfs_current}")

    # Step 1: Identify common ETFs (present in both months)
    etfs_common = [etf for etf in top2etfs_previous if etf in top2etfs_current]

    # Step 2: Identify ETFs to sell (present in the previous month but not in the current month)
    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]

    # Step 3: Identify ETFs to buy (present in the current month but not in the previous month)
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Step 4: Sell ETFs that are no longer in the current top ETFs
    selling_values = {}  # Track selling values for each ETF being sold
    for etf in etfs_to_sell:
        no_of_shares = ticker_shares.get(etf, 0)
        if no_of_shares > 0:
            # Check if data for the ETF is available in the current month
            if etf in etf_histories_for_current_month:
                first_trading_day_current_month = etf_histories_for_current_month[etf].loc[
                    etf_histories_for_current_month[etf].index[0], 'Close'
                ]
                
                selling_value = no_of_shares * first_trading_day_current_month * 0.9975
                selling_values[etf] = selling_value  # Store selling value for this ETF
                print(f"Formula: {no_of_shares} * {first_trading_day_current_month} * 0.9975")
                print(f"Sell {etf}: {no_of_shares:.2f} shares at {first_trading_day_current_month:.2f}. Total value: {selling_value:.2f}\n")
                del ticker_shares[etf]
            else:
                print(f"Data for {etf} is missing for {current_month}. Skipping sale.")
        else:
            print(f"No shares found for {etf} to sell.")

    # Step 5: Buy new ETFs that were not in the previous month's top ETFs
    for etf_to_buy, etf_to_sell in zip(etfs_to_buy, etfs_to_sell):
        selling_value = selling_values.get(etf_to_sell, 0)
        if selling_value > 0 and etf_to_buy in etf_histories_for_current_month:
            first_trading_day_new_etf = etf_histories_for_current_month[etf_to_buy].loc[
                etf_histories_for_current_month[etf_to_buy].index[0], 'Close'
            ]
            new_shares = (selling_value * 0.9975) / first_trading_day_new_etf
            print(f"Formula: ({selling_value} * 0.9975) / {first_trading_day_new_etf}")
            print(f"Buy {etf_to_buy}: {new_shares:.2f} shares at {first_trading_day_new_etf:.2f}.\n")
            ticker_shares[etf_to_buy] = new_shares
        else:
            print(f"Data for {etf_to_buy} is missing or no selling value available. Skipping purchase of {etf_to_buy}.")

    # Step 6: Maintain the order of ETFs in the ticker_shares dictionary based on the current top 2 ETFs
    ordered_ticker_shares = {etf: ticker_shares[etf] for etf in top2etfs_current if etf in ticker_shares}

    print(f"Updated ticker shares after {current_month}: {ordered_ticker_shares}")
    print("")
    return ordered_ticker_shares



def main_monthly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = process_etf_data_monthly(tickers, etf_dict, smoothing=smoothing)

    risk_percentage = 0.10
    monthly_scores = {}

    # Calculate scores for all months
    for month in range(1, 13):
        month_key = f"{month}m"
        if any(f"returns_{month_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, month_key, risk_percentage)  # Reusing weekly function
            monthly_scores[month_key] = scores

    # Convert scores to DataFrames
    monthly_scores_dfs = {}
    for month_key, scores in monthly_scores.items():
        monthly_scores_dfs[month_key] = pd.DataFrame(scores)

    # Select top ETFs for each month
    top_etfs_monthly = {}
    for month_key, df_scores in monthly_scores_dfs.items():
        top_etfs_monthly[month_key] = df_scores.nlargest(2, 'Score')

    # Generate month ranges for ETF data gathering
    month_ranges = generate_month_ranges('2024-01-01', '2025-01-01')

    # Gather ETF historical data
    etf_histories = gather_etf_data_for_weeks(tickers, month_ranges)

    # Map month keys to date ranges
    month_key_mapping = {f"{i+1}m": month_range for i, month_range in enumerate(etf_histories.keys())}

    # Align top ETFs with historical data
    aligned_top_etfs_monthly = {}
    for month_key, df_scores in monthly_scores_dfs.items():
        forecast_period = month_key_mapping.get(month_key, None)
        if forecast_period:
            aligned_top_etfs_monthly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

    # Initialize and manage portfolio
    ticker_shares = {}
    ticker_shares_per_month = {}
    for i, month_range in enumerate(etf_histories.keys()):
        current_month_key = month_range
        if i == 0:
            # Initialize shares for the first month
            ticker_shares = initialize_shares_for_first_week(
                aligned_top_etfs_monthly[current_month_key],
                etf_histories,
                current_month_key
            )
            ticker_shares_per_month[current_month_key] = ticker_shares.copy()
        else:
            # Manage portfolio for subsequent months
            prev_month_key = list(etf_histories.keys())[i - 1]
            ticker_shares = manage_etf_portfolio_monthly(
                aligned_top_etfs_monthly[prev_month_key],
                aligned_top_etfs_monthly[current_month_key],
                prev_month_key,
                current_month_key,
                ticker_shares,
                etf_histories
            )
            ticker_shares_per_month[current_month_key] = ticker_shares.copy()

    # Define the first trading day of the 13th month
    first_trading_day_13m = '2025-01-01'

    # Identify the 12th and 13th month date ranges
    month_12_range = list(ticker_shares_per_month.keys())[-1]
    month_13_start = first_trading_day_13m
    print(f"Using data for the 12th month: {month_12_range}")
    print(f"Fetching data starting from the first trading day of the 13th month: {month_13_start}")

    month_13_end = '2025-01-06'
    etf_values_13m = {}

    # Ensure 12th month data exists
    if month_12_range in ticker_shares_per_month:
        ticker_shares_12m = ticker_shares_per_month[month_12_range]

        # Fetch the first trading day price of the 13th month for each ETF
        for ticker, shares in ticker_shares_12m.items():
            print(f"Fetching data for ticker {ticker} starting from {month_13_start}...")
            data = yf.download(ticker, start=month_13_start, end=month_13_end)

            if not data.empty:
                closing_price_13m = data['Close'].iloc[0]
                total_value = shares * closing_price_13m
                etf_values_13m[ticker] = total_value
                print(f"{ticker}: {shares:.2f} shares at ${closing_price_13m:.2f} each, total value: ${total_value:.2f}")
            else:
                print(f"{ticker}: No data available for the 13th month's first trading day.")
    else:
        print(f"No data available in ticker_shares_per_month for the 12th month: {month_12_range}")

    # Display total portfolio value for the 13th month's first trading day
    if etf_values_13m:
        print("\nETF values on the 13th month's first trading day:")
        total_value = sum(etf_values_13m.values())
        print(f"Total portfolio value: {total_value:.2f}")
        for ticker, value in etf_values_13m.items():
            print(f"{ticker}: {value:.2f}")
    else:
        print("No values could be calculated for the 13th month's first trading day.")

    return ticker_shares_per_month

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_month = main_monthly(tickers, results,False)
# Out:
# Fetching full-year data for all tickers...
# Downloading data for SMH for the entire year...
# Downloading data for SOXX for the entire year...
# Downloading data for PSI for the entire year...
# Downloading data for XSD for the entire year...
# Downloading data for IYW for the entire year...
# Downloading data for XLK for the entire year...
# Downloading data for VGT for the entire year...
# Downloading data for FTEC for the entire year...
# Downloading data for IGM for the entire year...
# Downloading data for IXN for the entire year...
# Processing scores for 2024-01-01 to 2024-01-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1m             0.1  2.339117
# 1  SOXX   1m             0.1 -2.001962
# 2   PSI   1m             0.1 -3.945536
# 3   XSD   1m             0.1 -7.751658
# 4   IYW   1m             0.1  1.910427
# Top ETFs for 2024-01-01 to 2024-01-31: ['IGM', 'SMH']
# Processing scores for 2024-02-01 to 2024-02-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2m             0.1  3.238280
# 1  SOXX   2m             0.1  3.379093
# 2   PSI   2m             0.1  1.905457
# 3   XSD   2m             0.1 -2.366676
# 4   IYW   2m             0.1 -0.985318
# Top ETFs for 2024-02-01 to 2024-02-29: ['SOXX', 'SMH']
# Processing scores for 2024-03-01 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3m             0.1  5.451300
# 1  SOXX   3m             0.1  0.464849
# 2   PSI   3m             0.1  0.344338
# 3   XSD   3m             0.1  0.752191
# 4   IYW   3m             0.1 -1.748412
# Top ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'IGM']
# Processing scores for 2024-04-01 to 2024-04-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4m             0.1  0.615632
# 1  SOXX   4m             0.1  0.539607
# 2   PSI   4m             0.1  2.194542
# 3   XSD   4m             0.1  5.516894
# 4   IYW   4m             0.1 -0.309073
# Top ETFs for 2024-04-01 to 2024-04-30: ['XSD', 'PSI']
# Processing scores for 2024-05-01 to 2024-05-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5m             0.1  4.115143
# 1  SOXX   5m             0.1 -3.148118
# 2   PSI   5m             0.1 -3.297481
# 3   XSD   5m             0.1 -1.732313
# 4   IYW   5m             0.1  1.342565
# Top ETFs for 2024-05-01 to 2024-05-31: ['SMH', 'IXN']
# Processing scores for 2024-06-01 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6m             0.1 -2.366699
# 1  SOXX   6m             0.1 -3.547738
# 2   PSI   6m             0.1 -2.827654
# 3   XSD   6m             0.1 -7.226254
# 4   IYW   6m             0.1  2.935039
# Top ETFs for 2024-06-01 to 2024-06-30: ['IGM', 'IYW']
# Processing scores for 2024-07-01 to 2024-07-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7m             0.1 -3.285753
# 1  SOXX   7m             0.1 -1.441252
# 2   PSI   7m             0.1 -8.742282
# 3   XSD   7m             0.1  3.898144
# 4   IYW   7m             0.1  0.479624
# Top ETFs for 2024-07-01 to 2024-07-31: ['VGT', 'XSD']
# Processing scores for 2024-08-01 to 2024-08-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8m             0.1 -5.097827
# 1  SOXX   8m             0.1 -6.018440
# 2   PSI   8m             0.1 -2.224687
# 3   XSD   8m             0.1 -4.292792
# 4   IYW   8m             0.1  2.498235
# Top ETFs for 2024-08-01 to 2024-08-31: ['IGM', 'VGT']
# Processing scores for 2024-09-01 to 2024-09-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9m             0.1 -3.064596
# 1  SOXX   9m             0.1 -4.393469
# 2   PSI   9m             0.1 -5.717675
# 3   XSD   9m             0.1 -4.588422
# 4   IYW   9m             0.1  3.555979
# Top ETFs for 2024-09-01 to 2024-09-30: ['IGM', 'IYW']
# Processing scores for 2024-10-01 to 2024-10-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10m             0.1  1.325089
# 1  SOXX  10m             0.1 -5.232915
# 2   PSI  10m             0.1 -6.387614
# 3   XSD  10m             0.1 -4.094805
# 4   IYW  10m             0.1  3.467055
# Top ETFs for 2024-10-01 to 2024-10-31: ['IGM', 'IYW']
# Processing scores for 2024-11-01 to 2024-11-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11m             0.1 -4.478437
# 1  SOXX  11m             0.1 -5.804323
# 2   PSI  11m             0.1 -2.654840
# 3   XSD  11m             0.1 -0.506970
# 4   IYW  11m             0.1  2.022900
# Top ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'VGT']
# Processing scores for 2024-12-01 to 2024-12-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12m             0.1 -0.605564
# 1  SOXX  12m             0.1 -2.726052
# 2   PSI  12m             0.1  3.658372
# 3   XSD  12m             0.1 -3.932420
# 4   IYW  12m             0.1 -0.613882
# Top ETFs for 2024-12-01 to 2024-12-31: ['IXN', 'PSI']
# Top 2 ETFs for 2024-01-01 to 2024-01-31: ['IGM', 'SMH']
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['SOXX', 'SMH']
# Formula: 685.8026957229545 * 78.93000030517578 * 0.9975
# Sell IGM: 685.80 shares at 78.93. Total value: 53995.08
#
# Formula: (53995.080965246416 * 0.9975) / 196.31666564941406
# Buy SOXX: 274.35 shares at 196.32.
#
# Updated ticker shares after 2024-02-01 to 2024-02-29: {'SOXX': 274.35313800111936, 'SMH': 295.17073823568774}
#
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['SOXX', 'SMH']
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'IGM']
# Formula: 274.35313800111936 * 226.6133270263672 * 0.9975
# Sell SOXX: 274.35 shares at 226.61. Total value: 62016.65
#
# Formula: (62016.64718910132 * 0.9975) / 86.03666687011719
# Buy IGM: 719.01 shares at 86.04.
#
# Updated ticker shares after 2024-03-01 to 2024-03-31: {'SMH': 295.17073823568774, 'IGM': 719.0144367693392}
#
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'IGM']
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['XSD', 'PSI']
# Formula: 295.17073823568774 * 227.94000244140625 * 0.9975
# Sell SMH: 295.17 shares at 227.94. Total value: 67113.02
#
# Formula: 719.0144367693392 * 86.66000366210938 * 0.9975
# Sell IGM: 719.01 shares at 86.66. Total value: 62154.02
#
# Formula: (67113.01574708916 * 0.9975) / 233.86000061035156
# Buy XSD: 286.26 shares at 233.86.
#
# Formula: (62154.019239231595 * 0.9975) / 57.0099983215332
# Buy PSI: 1087.50 shares at 57.01.
#
# Updated ticker shares after 2024-04-01 to 2024-04-30: {'XSD': 286.2620073248994, 'PSI': 1087.5045784331494}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['XSD', 'PSI']
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['SMH', 'IXN']
# Formula: 286.2620073248994 * 217.32000732421875 * 0.9975
# Sell XSD: 286.26 shares at 217.32. Total value: 62054.94
#
# Formula: 1087.5045784331494 * 52.06999969482422 * 0.9975
# Sell PSI: 1087.50 shares at 52.07. Total value: 56484.80
#
# Formula: (62054.93537467147 * 0.9975) / 207.85000610351562
# Buy SMH: 297.81 shares at 207.85.
#
# Formula: (56484.797159466194 * 0.9975) / 69.83000183105469
# Buy IXN: 806.87 shares at 69.83.
#
# Updated ticker shares after 2024-05-01 to 2024-05-31: {'SMH': 297.80994091194214, 'IXN': 806.8678746834931}
#
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['SMH', 'IXN']
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IGM', 'IYW']
# Formula: 297.80994091194214 * 243.47999572753906 * 0.9975
# Sell SMH: 297.81 shares at 243.48. Total value: 72329.49
#
# Formula: 806.8678746834931 * 77.05999755859375 * 0.9975
# Sell IXN: 806.87 shares at 77.06. Total value: 62021.79
#
# Formula: (72329.48623300619 * 0.9975) / 87.80000305175781
# Buy IGM: 821.74 shares at 87.80.
#
# Formula: (62021.79336208467 * 0.9975) / 139.72000122070312
# Buy IYW: 442.79 shares at 139.72.
#
# Updated ticker shares after 2024-06-01 to 2024-06-30: {'IGM': 821.7387244837826, 'IYW': 442.7908555551337}
#
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IGM', 'IYW']
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['VGT', 'XSD']
# Formula: 821.7387244837826 * 94.93000030517578 * 0.9975
# Sell IGM: 821.74 shares at 94.93. Total value: 77812.64
#
# Formula: 442.7908555551337 * 152.02000427246094 * 0.9975
# Sell IYW: 442.79 shares at 152.02. Total value: 67144.79
#
# Formula: (77812.6382226052 * 0.9975) / 582.25
# Buy VGT: 133.31 shares at 582.25.
#
# Formula: (67144.78508391482 * 0.9975) / 246.57000732421875
# Buy XSD: 271.63 shares at 246.57.
#
# Updated ticker shares after 2024-07-01 to 2024-07-31: {'VGT': 133.30718184121716, 'XSD': 271.6345100040332}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['VGT', 'XSD']
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['IGM', 'VGT']
# Formula: 271.6345100040332 * 226.58999633789062 * 0.9975
# Sell XSD: 271.63 shares at 226.59. Total value: 61395.79
#
# Formula: (61395.788470490945 * 0.9975) / 89.36000061035156
# Buy IGM: 685.34 shares at 89.36.
#
# Updated ticker shares after 2024-08-01 to 2024-08-31: {'IGM': 685.3435382835074, 'VGT': 133.30718184121716}
#
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['IGM', 'VGT']
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['IGM', 'IYW']
# Formula: 133.30718184121716 * 548.6900024414062 * 0.9975
# Sell VGT: 133.31 shares at 548.69. Total value: 72961.46
#
# Formula: (72961.45713508964 * 0.9975) / 141.5800018310547
# Buy IYW: 514.05 shares at 141.58.
#
# Updated ticker shares after 2024-09-01 to 2024-09-30: {'IGM': 685.3435382835074, 'IYW': 514.0489656095505}
#
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['IGM', 'IYW']
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['IGM', 'IYW']
# Updated ticker shares after 2024-10-01 to 2024-10-31: {'IGM': 685.3435382835074, 'IYW': 514.0489656095505}
#
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['IGM', 'IYW']
# Top 2 ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'VGT']
# Formula: 685.3435382835074 * 96.13999938964844 * 0.9975
# Sell IGM: 685.34 shares at 96.14. Total value: 65724.21
#
# Formula: 514.0489656095505 * 151.7100067138672 * 0.9975
# Sell IYW: 514.05 shares at 151.71. Total value: 77791.41
#
# Formula: (65724.20503389521 * 0.9975) / 174.35000610351562
# Buy FTEC: 376.02 shares at 174.35.
#
# Formula: (77791.40609382169 * 0.9975) / 586.469970703125
# Buy VGT: 132.31 shares at 586.47.
#
# Updated ticker shares after 2024-11-01 to 2024-11-30: {'FTEC': 376.0246184470223, 'VGT': 132.31185133921755}
#
# Top 2 ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-12-01 to 2024-12-31: ['IXN', 'PSI']
# Formula: 376.0246184470223 * 186.99000549316406 * 0.9975
# Sell FTEC: 376.02 shares at 186.99. Total value: 70137.06
#
# Formula: 132.31185133921755 * 628.3699951171875 * 0.9975
# Sell VGT: 132.31 shares at 628.37. Total value: 82932.95
#
# Formula: (70137.0633553012 * 0.9975) / 84.80000305175781
# Buy IXN: 825.02 shares at 84.80.
#
# Formula: (82932.94538652025 * 0.9975) / 57.84000015258789
# Buy PSI: 1430.25 shares at 57.84.
#
# Updated ticker shares after 2024-12-01 to 2024-12-31: {'IXN': 825.020261546591, 'PSI': 1430.2491840389912}
#
# Using data for the 12th month: 2024-12-01 to 2024-12-31
# Fetching data starting from the first trading day of the 13th month: 2025-01-01
# Fetching data for ticker IXN starting from 2025-01-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# IXN: 825.02 shares at $84.51 each, total value: $69722.46
# Fetching data for ticker PSI starting from 2025-01-01...
# PSI: 1430.25 shares at $58.64 each, total value: $83869.81
#
# ETF values on the 13th month's first trading day:
# Total portfolio value: 153592.28
# IXN: 69722.46
# PSI: 83869.81

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_month = main_monthly(tickers, results,True)
# Out:
# Fetching full-year data for all tickers...
# Downloading data for SMH for the entire year...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Downloading data for SOXX for the entire year...
# Downloading data for PSI for the entire year...
# Downloading data for XSD for the entire year...
# Downloading data for IYW for the entire year...
# Downloading data for XLK for the entire year...
# Downloading data for VGT for the entire year...
# Downloading data for FTEC for the entire year...
# Downloading data for IGM for the entire year...
# Downloading data for IXN for the entire year...
# Processing scores for 2024-01-01 to 2024-01-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1m             0.1  2.907780
# 1  SOXX   1m             0.1 -1.969981
# 2   PSI   1m             0.1 -3.992486
# 3   XSD   1m             0.1 -7.242502
# 4   IYW   1m             0.1  2.123973
# Top ETFs for 2024-01-01 to 2024-01-31: ['IGM', 'SMH']
# Processing scores for 2024-02-01 to 2024-02-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2m             0.1  4.508127
# 1  SOXX   2m             0.1  2.186948
# 2   PSI   2m             0.1  2.377647
# 3   XSD   2m             0.1 -5.375883
# 4   IYW   2m             0.1 -0.734270
# Top ETFs for 2024-02-01 to 2024-02-29: ['SMH', 'PSI']
# Processing scores for 2024-03-01 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3m             0.1  2.868770
# 1  SOXX   3m             0.1 -0.684637
# 2   PSI   3m             0.1 -0.162167
# 3   XSD   3m             0.1 -0.945450
# 4   IYW   3m             0.1  0.327477
# Top ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'IGM']
# Processing scores for 2024-04-01 to 2024-04-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4m             0.1  3.321135
# 1  SOXX   4m             0.1  1.376359
# 2   PSI   4m             0.1  2.772869
# 3   XSD   4m             0.1  3.193606
# 4   IYW   4m             0.1 -0.548270
# Top ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'XSD']
# Processing scores for 2024-05-01 to 2024-05-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5m             0.1  0.467242
# 1  SOXX   5m             0.1 -3.204496
# 2   PSI   5m             0.1 -3.235391
# 3   XSD   5m             0.1 -2.922123
# 4   IYW   5m             0.1  1.990224
# Top ETFs for 2024-05-01 to 2024-05-31: ['IXN', 'IYW']
# Processing scores for 2024-06-01 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6m             0.1  1.977086
# 1  SOXX   6m             0.1 -3.076426
# 2   PSI   6m             0.1 -2.575763
# 3   XSD   6m             0.1 -6.349261
# 4   IYW   6m             0.1  2.267660
# Top ETFs for 2024-06-01 to 2024-06-30: ['IXN', 'IYW']
# Processing scores for 2024-07-01 to 2024-07-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7m             0.1 -2.749914
# 1  SOXX   7m             0.1 -2.499253
# 2   PSI   7m             0.1 -5.226016
# 3   XSD   7m             0.1 -1.339748
# 4   IYW   7m             0.1  1.906380
# Top ETFs for 2024-07-01 to 2024-07-31: ['VGT', 'FTEC']
# Processing scores for 2024-08-01 to 2024-08-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8m             0.1 -4.087828
# 1  SOXX   8m             0.1 -5.748062
# 2   PSI   8m             0.1 -4.202385
# 3   XSD   8m             0.1 -3.807023
# 4   IYW   8m             0.1  3.053235
# Top ETFs for 2024-08-01 to 2024-08-31: ['IGM', 'IYW']
# Processing scores for 2024-09-01 to 2024-09-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9m             0.1 -2.548757
# 1  SOXX   9m             0.1 -4.399799
# 2   PSI   9m             0.1 -6.327398
# 3   XSD   9m             0.1 -4.690583
# 4   IYW   9m             0.1  3.485358
# Top ETFs for 2024-09-01 to 2024-09-30: ['IGM', 'IYW']
# Processing scores for 2024-10-01 to 2024-10-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10m             0.1  0.975023
# 1  SOXX  10m             0.1 -5.034417
# 2   PSI  10m             0.1 -6.890503
# 3   XSD  10m             0.1 -3.015046
# 4   IYW  10m             0.1  3.110244
# Top ETFs for 2024-10-01 to 2024-10-31: ['IGM', 'IYW']
# Processing scores for 2024-11-01 to 2024-11-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11m             0.1 -4.133950
# 1  SOXX  11m             0.1 -5.064523
# 2   PSI  11m             0.1 -2.453049
# 3   XSD  11m             0.1  2.242761
# 4   IYW  11m             0.1  1.584048
# Top ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'VGT']
# Processing scores for 2024-12-01 to 2024-12-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12m             0.1  0.947944
# 1  SOXX  12m             0.1  0.675126
# 2   PSI  12m             0.1  4.026258
# 3   XSD  12m             0.1 -0.614713
# 4   IYW  12m             0.1 -1.405586
# Top ETFs for 2024-12-01 to 2024-12-31: ['PSI', 'IXN']
# Top 2 ETFs for 2024-01-01 to 2024-01-31: ['IGM', 'SMH']
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['SMH', 'PSI']
# Formula: 685.8026957229545 * 78.93000030517578 * 0.9975
# Sell IGM: 685.80 shares at 78.93. Total value: 53995.08
#
# Formula: (53995.080965246416 * 0.9975) / 49.45000076293945
# Buy PSI: 1089.18 shares at 49.45.
#
# Updated ticker shares after 2024-02-01 to 2024-02-29: {'SMH': 295.17073823568774, 'PSI': 1089.182860098134}
#
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['SMH', 'PSI']
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'IGM']
# Formula: 1089.182860098134 * 56.599998474121094 * 0.9975
# Sell PSI: 1089.18 shares at 56.60. Total value: 61493.63
#
# Formula: (61493.62884904425 * 0.9975) / 86.03666687011719
# Buy IGM: 712.95 shares at 86.04.
#
# Updated ticker shares after 2024-03-01 to 2024-03-31: {'SMH': 295.17073823568774, 'IGM': 712.9506175491629}
#
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'IGM']
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'XSD']
# Formula: 712.9506175491629 * 86.66000366210938 * 0.9975
# Sell IGM: 712.95 shares at 86.66. Total value: 61629.84
#
# Formula: (61629.842369894315 * 0.9975) / 233.86000061035156
# Buy XSD: 262.87 shares at 233.86.
#
# Updated ticker shares after 2024-04-01 to 2024-04-30: {'SMH': 295.17073823568774, 'XSD': 262.87423075140634}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'XSD']
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['IXN', 'IYW']
# Formula: 295.17073823568774 * 207.85000610351562 * 0.9975
# Sell SMH: 295.17 shares at 207.85. Total value: 61197.86
#
# Formula: 262.87423075140634 * 217.32000732421875 * 0.9975
# Sell XSD: 262.87 shares at 217.32. Total value: 56985.01
#
# Formula: (61197.86164450724 * 0.9975) / 69.83000183105469
# Buy IXN: 874.19 shares at 69.83.
#
# Formula: (56985.01017786339 * 0.9975) / 126.94999694824219
# Buy IYW: 447.76 shares at 126.95.
#
# Updated ticker shares after 2024-05-01 to 2024-05-31: {'IXN': 874.1925446040616, 'IYW': 447.7554077893643}
#
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['IXN', 'IYW']
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IXN', 'IYW']
# Updated ticker shares after 2024-06-01 to 2024-06-30: {'IXN': 874.1925446040616, 'IYW': 447.7554077893643}
#
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IXN', 'IYW']
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['VGT', 'FTEC']
# Formula: 874.1925446040616 * 83.62000274658203 * 0.9975
# Sell IXN: 874.19 shares at 83.62. Total value: 72917.23
#
# Formula: 447.7554077893643 * 152.02000427246094 * 0.9975
# Sell IYW: 447.76 shares at 152.02. Total value: 67897.61
#
# Formula: (72917.2330233811 * 0.9975) / 582.25
# Buy VGT: 124.92 shares at 582.25.
#
# Formula: (67897.60955764377 * 0.9975) / 173.1300048828125
# Buy FTEC: 391.20 shares at 173.13.
#
# Updated ticker shares after 2024-07-01 to 2024-07-31: {'VGT': 124.9204636166984, 'FTEC': 391.1965784301399}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['VGT', 'FTEC']
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['IGM', 'IYW']
# Formula: 124.9204636166984 * 547.47998046875 * 0.9975
# Sell VGT: 124.92 shares at 547.48. Total value: 68220.47
#
# Formula: 391.1965784301399 * 163.02000427246094 * 0.9975
# Sell FTEC: 391.20 shares at 163.02. Total value: 63613.44
#
# Formula: (68220.4743485647 * 0.9975) / 89.36000061035156
# Buy IGM: 761.53 shares at 89.36.
#
# Formula: (63613.43571733587 * 0.9975) / 141.77000427246094
# Buy IYW: 447.59 shares at 141.77.
#
# Updated ticker shares after 2024-08-01 to 2024-08-31: {'IGM': 761.5255449630148, 'IYW': 447.586938109225}
#
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['IGM', 'IYW']
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['IGM', 'IYW']
# Updated ticker shares after 2024-09-01 to 2024-09-30: {'IGM': 761.5255449630148, 'IYW': 447.586938109225}
#
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['IGM', 'IYW']
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['IGM', 'IYW']
# Updated ticker shares after 2024-10-01 to 2024-10-31: {'IGM': 761.5255449630148, 'IYW': 447.586938109225}
#
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['IGM', 'IYW']
# Top 2 ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'VGT']
# Formula: 761.5255449630148 * 96.13999938964844 * 0.9975
# Sell IGM: 761.53 shares at 96.14. Total value: 73030.03
#
# Formula: 447.586938109225 * 151.7100067138672 * 0.9975
# Sell IYW: 447.59 shares at 151.71. Total value: 67733.66
#
# Formula: (73030.03276437608 * 0.9975) / 174.35000610351562
# Buy FTEC: 417.82 shares at 174.35.
#
# Formula: (67733.6588421258 * 0.9975) / 586.469970703125
# Buy VGT: 115.21 shares at 586.47.
#
# Updated ticker shares after 2024-11-01 to 2024-11-30: {'FTEC': 417.82308650573793, 'VGT': 115.20508818894326}
#
# Top 2 ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-12-01 to 2024-12-31: ['PSI', 'IXN']
# Formula: 417.82308650573793 * 186.99000549316406 * 0.9975
# Sell FTEC: 417.82 shares at 186.99. Total value: 77933.42
#
# Formula: 115.20508818894326 * 628.3699951171875 * 0.9975
# Sell VGT: 115.21 shares at 628.37. Total value: 72210.44
#
# Formula: (77933.4193877765 * 0.9975) / 57.84000015258789
# Buy PSI: 1344.03 shares at 57.84.
#
# Formula: (72210.44215100454 * 0.9975) / 84.80000305175781
# Buy IXN: 849.41 shares at 84.80.
#
# Updated ticker shares after 2024-12-01 to 2024-12-31: {'PSI': 1344.0281057092782, 'IXN': 849.4093567622098}
#
# Using data for the 12th month: 2024-12-01 to 2024-12-31
# Fetching data starting from the first trading day of the 13th month: 2025-01-01
# Fetching data for ticker PSI starting from 2025-01-01...
# PSI: 1344.03 shares at $58.64 each, total value: $78813.81
# Fetching data for ticker IXN starting from 2025-01-01...
# IXN: 849.41 shares at $84.51 each, total value: $71783.59
#
# ETF values on the 13th month's first trading day:
# Total portfolio value: 150597.39
# PSI: 78813.81
# IXN: 71783.59
