# %%
import yfinance as yf

# %%
import sys
import importlib

# List of libraries to check
libraries = [
    "numpy", "pandas", "tensorflow", "sklearn", "skopt", "xgboost", "yfinance",
    "matplotlib", "scipy"
]

# Function to print installed version
for lib in libraries:
    try:
        module = importlib.import_module(lib)
        print(f"{lib}: {module.__version__}")
    except Exception as e:
        print(f"{lib}: Not installed or failed to import ({e})")
# Out:
# numpy: 1.26.4
# pandas: 2.2.2
# tensorflow: 2.15.0
# sklearn: 1.4.2
# skopt: 0.10.2
# xgboost: 3.0.0
# yfinance: 0.2.59
# matplotlib: 3.8.4
# scipy: 1.13.0
