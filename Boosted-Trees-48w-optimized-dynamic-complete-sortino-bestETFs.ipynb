# %%
#pip install xgboost

# %% [markdown]
# Use log returns in formulas

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split,GridSearchCV
from skopt import BayesSearchCV

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tabulate import tabulate
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler,MinMaxScaler,Normalizer
import statsmodels.api as sm
import itertools
from xgboost import XGBRegressor

from pandas.tseries.offsets import MonthEnd
from pandas.tseries.offsets import BDay

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

from pandas.tseries.offsets import Week
from datetime import datetime, timedelta

# %%
#tickers = ['SPY', 'QQQ', 'VTI', 'IWM', 'EFA', 'EEM', 'GLD', 'SLV', 'USO', 'XLF']
#tickers = ['SPY', 'QQQ', 'VTI']
"""tickers = 'SPY'

start_date, end_date = '2000-01-01', '2024-02-01'
train_start_date, train_end_date, test_start_date, test_end_date, prediction_start_date = start_date,'2015-01-01', '2015-01-01', '2024-01-01', '2024-01-01'
"""
# Out:
# "tickers = 'SPY'\n\nstart_date, end_date = '2000-01-01', '2024-02-01'\ntrain_start_date, train_end_date, test_start_date, test_end_date, prediction_start_date = start_date,'2015-01-01', '2015-01-01', '2024-01-01', '2024-01-01'\n"

# %%
"""etf_data = yf.Ticker(tickers)
etf_history = etf_data.history(start=start_date, end=end_date)
etf_history.index = etf_history.index.tz_localize(None)"""
# Out:
# 'etf_data = yf.Ticker(tickers)\netf_history = etf_data.history(start=start_date, end=end_date)\netf_history.index = etf_history.index.tz_localize(None)'

# %%
def data_loading(ticker_symbol, start_date, end_date):
    # Fetch the ETF data from Yahoo Finance for the period from 2010-01-01 to 2024-01-01
    etf_data = yf.Ticker(ticker_symbol)
    etf_history = etf_data.history(start=start_date, end=end_date)
    etf_history.index = etf_history.index.tz_localize(None)
    return etf_history, etf_data

# %%
#Function to derive the predictor columns
def etf_predictors(etf_history,  start_date, end_date, etf_data, benchmark_ticker = '^GSPC' ):
    
    # Calculate Daily Returns
    etf_history['Daily Return'] = etf_history['Close'].pct_change()

    # Calculate 21-Day Volatility (standard deviation of daily returns, annualized)
    etf_history['Volatility'] = etf_history['Daily Return'].rolling(window=21).std() * np.sqrt(252)
    #etf_history['Volatility_ta'] = ta.volatility(etf_history['Close'], window=21, annualize=True)
   
    # Get the ETF info
    etf_info = etf_data.info

    # Retrieve the net asset value price (NAV) and total net assets
    nav_price = etf_info['navPrice']
    total_assets = etf_info['totalAssets']

    # Calculate the number of shares outstanding
    shares_outstanding = total_assets / nav_price

    # Calculate Market Capitalization for each day
    # Market Capitalization = Closing Price * Total Number of Shares Outstanding
    etf_history['Market Cap'] = etf_history['Close'] * shares_outstanding

    total_assets = etf_info['totalAssets']
    total_liabilities = etf_info.get('totalLiabilities', 0)  # Handle the case where total liabilities might not be present
    
    # Calculate Book Value per Share
    book_value_per_share = (total_assets - total_liabilities) / shares_outstanding
    
    # Calculate Price to Book (P/B) Ratio
    etf_history['P/B Ratio'] = etf_history['Close'] / book_value_per_share
    
    # Calculate 1-Month Momentum (21 trading days)
    
    etf_history['Momentum'] = ta.mom(etf_history['Close'], length=21)
    
    benchmark_data = yf.download(benchmark_ticker, start=start_date, end=end_date)
    benchmark_data['Daily Return'] = benchmark_data['Close'].pct_change()
    #benchmark_data_history = benchmark_data.dropna()
    benchmark_data.head(10)
    
    # Ensure the indices are time zone-naive
    benchmark_data.index = benchmark_data.index.tz_localize(None)
    combined_data = etf_history[['Close']].join(benchmark_data[['Close']], lsuffix='_ETF', rsuffix='_Benchmark')
    combined_data = combined_data.dropna()
    
    # Calculate rolling beta with a 30-day window
    rolling_beta_21 = rolling_beta(combined_data, window=21)

    # Add the rolling beta to the dataframe
    combined_data.loc[:, 'Rolling Beta 21-day'] = rolling_beta_21
    etf_history['Rolling Beta']=combined_data['Rolling Beta 21-day']
    
    # Calculate daily profitability
    daily_profitabilities = []
    previous_nav = None
    for index, row in etf_history.iterrows():
        current_nav = row['Close']  # Current day's NAV
        #print(current_nav)
        if previous_nav is not None:
            daily_profitability = (current_nav - previous_nav) / previous_nav * 100
            daily_profitabilities.append(daily_profitability)
        else:
            daily_profitabilities.append(None)
        previous_nav = current_nav  # Update previous_nav for the next iteration

    # Add daily profitabilities to ETF dataset
    etf_history['Daily Profitability (%)'] = daily_profitabilities
    
    # Calculate the dividend yield for each day
    dividend_yields = []

    for index, row in etf_history.iterrows():
        # Get the dividend payment for the day
        dividend_payment = row['Dividends']

        # Get the current market price of the ETF for the day
        current_price = row['Close']

        # Calculate the dividend yield for the day
        dividend_yield = (dividend_payment / current_price) * 100

        # Append the dividend yield to the list
        dividend_yields.append(dividend_yield)
      
    etf_history['Div yield'] = dividend_yields

    #Volatility
    etf_history['ATR'] = ta.atr(etf_history['High'], etf_history['Low'], etf_history['Close'], length=21)    
    
    # Compute the Relative Volatility Index (RVI)
    rvi = ta.rvi(etf_history['Close'],length=21)
    etf_history['RVI'] = rvi
    
    #Momentum
    rsi_window = 14  # Window size for RSI calculation
    roc_window = 12  # Window size for ROC calculation
    #rsi_window = 21  
    #roc_window = 21  

    

    etf_history['RSI'] = ta.rsi(etf_history['Close'],length=rsi_window)
    # Calculate Rate of Change (ROC)
    etf_history['ROC'] = ta.roc(etf_history['Close'], length=roc_window)
        
    etf_history['log_returns'] = np.log(etf_history['Close'] / etf_history['Close'].shift(1))

    return etf_history

# Function to calculate rolling beta
def rolling_beta(df, window):
    rolling_cov = df['Close_Benchmark'].rolling(window=window).cov(df['Close_ETF'])
    rolling_var = df['Close_Benchmark'].rolling(window=window).var()
    rolling_beta = rolling_cov / rolling_var
    return rolling_beta

# %%
#etf_history = etf_predictors(etf_history,  start_date, end_date, etf_data,benchmark_ticker = '^GSPC' )
#etf_history.head(10)

# %%
def pre_processing(etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_dates, feature_columns=None, scaling_strategy='StandardScaler', final_end_date='2024-12-01'):
    # Handle missing values and inf replacements
    etf_history.fillna(etf_history.median(), inplace=True)
    etf_history = etf_history.replace(-np.inf, 0)

    # Default feature columns if none are provided
    if feature_columns is None:
        feature_columns = ['Volatility', 'Volume', 'Daily Return', 'Market Cap', 'P/B Ratio', 'Momentum', 
                           'Rolling Beta', 'Daily Profitability (%)', 'ATR', 'RVI', 'RSI', 'ROC']

    # Selecting the features (X) and the target (y)
    X = etf_history.loc[:, feature_columns]
    y = etf_history['log_returns']

    # Split train and test data
    train_data = X.loc[train_start_date:train_end_date]
    test_data = X.loc[test_start_date:test_end_date]
    y_train = y.loc[train_start_date:train_end_date]
    y_test = y.loc[test_start_date:test_end_date]

    # Scaling strategy based on input parameter
    if scaling_strategy == 'StandardScaler':
        scaler = StandardScaler()
    elif scaling_strategy == 'Normalizer':
        scaler = Normalizer()
    else:
        raise ValueError(f"Unsupported scaling strategy: {scaling_strategy}")
    
    # Scaling the train and test data
    train_data_scaled = scaler.fit_transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    # Create a dictionary to store forecast data for each weekly prediction period
    forecast_data = {}
    for i, start_date in enumerate(prediction_dates):
        # Determine the end date for each forecast week
        if i < len(prediction_dates) - 1:
            end_date = (pd.to_datetime(start_date) + Week(1) - pd.Timedelta(days=1)).strftime('%Y-%m-%d')
        else:
            end_date = final_end_date  # The final end date provided or default

        # Store the forecast data for each week
        forecast_data[f'forecast_data_{i+1}w'] = X.loc[start_date:end_date]

    # Scale the forecast data dynamically
    forecast_data_scaled = {}
    for period_key, period_data in forecast_data.items():
        if not period_data.empty:
            forecast_data_scaled[period_key] = sm.add_constant(scaler.transform(period_data))

    # Add constant to scaled train and test data
    train_data_scaled = sm.add_constant(train_data_scaled)
    test_data_scaled = sm.add_constant(test_data_scaled)

    #print(f"Weekly forecast data keys: {forecast_data.keys()}")

    # Dynamically return the scaled forecast data along with train and test data
    return {
        'train_data_scaled': train_data_scaled,
        'test_data_scaled': test_data_scaled,
        'y_train': y_train,
        'y_test': y_test,
        'scaler': scaler,
        'X': X,
        'etf_history': etf_history,
        'forecast_data_scaled': forecast_data_scaled,
        'forecast_data': forecast_data
    }

# %%
#model = sm.OLS(endog=y_train, exog=sm.add_constant(train_data_scaled))

# %%
def model_training(train_data_scaled, y_train):
    param_space = {
        'n_estimators': (100, 300),
        'max_depth': (3, 10),
        'learning_rate': (0.01, 0.3, 'log-uniform'),
        'gamma': (0, 0.5),
        'min_child_weight': (1, 10),
        'subsample': (0.5, 1.0),
        'colsample_bytree': (0.5, 1.0),
        'reg_alpha': (0, 1.0),
        'reg_lambda': (0, 1.0)
    }

    xgb_model = XGBRegressor(objective='reg:squarederror',random_state=42)

    bayes_search = BayesSearchCV(
        estimator=xgb_model,
        search_spaces=param_space,
        n_iter=50,
        cv=5,
        n_jobs=-1,
        verbose=0,
        scoring='neg_mean_squared_error',
        random_state=42
    )

    bayes_search.fit(train_data_scaled, y_train)
    best_model = bayes_search.best_estimator_

    print("Best Model Parameters:")
    print(bayes_search.best_params_)

    return best_model

# %%
# Display the best model parameters
#print("Best Model Parameters:")
#print(best_params)

# %%
def eval_model(best_model,test_data_scaled,y_test,y_train):
    
    test_predictions = best_model.predict((test_data_scaled))
    mae = mean_absolute_error(y_test, test_predictions)
    # Mean Absolute Scaled Error (MASE) - Example calculation assuming seasonal period m=1
    seasonal_naive = np.roll(y_test, 1)  # Shift y_test by 1 for seasonal naive forecast
    #seasonal_mae = np.mean(np.abs(y_test - seasonal_naive))
    seasonal_mae = np.mean(np.abs(y_test[1:] - seasonal_naive[1:]))
    mase = mae / seasonal_mae

    # Mean Absolute Percentage Error (MAPE)
    #mape = np.mean(np.abs((y_test - test_predictions) / y_test)) * 100

    #n = y_test.shape[0]
    #d = np.abs(  np.diff( y_test) ).sum()/(n-1)
    
    #errors = np.abs(y_test - test_predictions )
    #mase_value = errors.mean()/d

    print("Mean Absolute Error (MAE):", mae)
    print("Mean Absolute Scaled Error (MASE):", mase)
    #print("Mean Absolute Scaled Error-2 (MASE-2):", mase_value)
    #print("Mean Absolute Percentage Error (MAPE):", mape)
    
    return mae, mase

# %%
# Ensured consistent feature handling and forecasting in predictions
def predictions(model, forecast_data_scaled, forecast_data):
    predictions_forecast = model.predict(forecast_data_scaled)
    forecast_predictions_df = pd.DataFrame(predictions_forecast, columns=["log_returns"], index=forecast_data.index)
    forecast_data_with_predictions = pd.concat([forecast_data, forecast_predictions_df], axis=1)
    return forecast_predictions_df, forecast_data_with_predictions

# %%
#tickers = ['SPY', 'QQQ', 'VTI', 'IWM', 'EFA', 'EEM', 'GLD', 'SLV', 'USO', 'XLF']
#tickers = ['SMH', 'SOXX', 'PSI']

tickers = ['SMH', 'SOXX', 'PSI', 'XSD', 'IYW', 'XLK', 'VGT', 'FTEC', 'IGM', 'IXN', 
           #'FNGU','USD', 'FNGO', 'GBTC', 'ETHE', 'TECL', 'FNGS', 'TQQQ', 'ROM', 'QLD' No data available from 2000: 2019
          ]

#tickers = ['SPY', 'QQQ', 'VTI']
#tickers = ['SPY']
                                                           
start_date, end_date = '2000-01-01', '2024-12-01'
train_start_date, train_end_date, test_start_date, test_end_date, prediction_start_date = start_date,'2014-01-01', '2014-01-01', '2024-01-01', '2024-01-01'

# %%
#currently timeperiod is set to 48 weeks
prediction_dates = pd.date_range(start='2024-01-01', 
                                 periods=48, 
                                 freq='W-MON').strftime('%Y-%m-%d').tolist()

# %%
dict_data = {}
etf_dict = {}
data_with_predictors = []

# Loop through tickers
for i in tickers:
    etf_history, etf_data = data_loading(i, start_date, end_date)
    print(etf_data.info.get('longName'), ":", i)

    # Preprocess ETF data
    etf_history = etf_predictors(etf_history, start_date, end_date, etf_data, benchmark_ticker='^GSPC')
    preprocessed_data = pre_processing(
        etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_dates
    )

    # Extract components
    train_data_scaled = preprocessed_data['train_data_scaled']
    test_data_scaled = preprocessed_data['test_data_scaled']
    y_train = preprocessed_data['y_train']
    y_test = preprocessed_data['y_test']
    scaler = preprocessed_data['scaler']
    X = preprocessed_data['X']
    etf_history = preprocessed_data['etf_history']
    
    """for key in preprocessed_data['forecast_data']:
        print(key)"""  # Check if 'forecast_data_Xw' keys are present.

    # Train the model
    best_model = model_training(train_data_scaled, y_train)

    # Evaluate the model
    mae, mase = eval_model(best_model, test_data_scaled, y_test, y_train)
    print(f"Evaluation results for {i}: MAE = {mae}, MASE = {mase}")

    # Initialize dictionaries for forecast data and predictions
    # Step 5: Initialize forecast data storage
    forecast_predictions = {}
    forecast_data_dict = {}
    forecast_data_scaled_dict = {}

    # Step 6: Fetch weekly forecast data and generate predictions
    for week in range(1, 49):  # Generate weekly forecasts for up to 52 weeks
        week_key = f'forecast_data_{week}w'
        if week_key in preprocessed_data['forecast_data']:
            forecast_data = preprocessed_data['forecast_data'][week_key]
            forecast_data_scaled = preprocessed_data['forecast_data_scaled'].get(week_key)

            if forecast_data is not None and forecast_data_scaled is not None:
                try:
                    forecast_predictions_df, _ = predictions(
                        best_model, forecast_data_scaled, forecast_data
                    )
                    # Store predictions and forecast data
                    forecast_predictions[f'forecast_predictions_df_{week}w'] = forecast_predictions_df['log_returns'].values
                    forecast_data_dict[week_key] = forecast_data
                    forecast_data_scaled_dict[week_key] = forecast_data_scaled
                except Exception as e:
                    print(f"Error generating predictions for {week_key} for ETF {i}: {e}")
            else:
                print(f"Warning: Missing scaled data for {week_key} for ETF {i}")
        else:
            print(f"Warning: Missing forecast key {week_key} for ETF {i}")

    # Step 7: Construct `dict_data` for the current ETF
    dict_data = {
        "etf_history": etf_history,
        "X": X,
        "y_train_values": y_train,
        "model results": {"mae": mae, "mase": mase},
        **forecast_data_dict,  # Add raw forecast data
        **forecast_data_scaled_dict,  # Add scaled forecast data
        **forecast_predictions  # Add predictions
    }

    # Step 8: Store in the main `etf_dict`
    etf_dict[i] = dict_data

# Print completion message
print("Weekly forecast data and predictions stored successfully.")
# Out:
# VanEck Semiconductor ETF : SMH
# [*********************100%%**********************]  1 of 1 completed
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.6049493044385226), ('gamma', 0.0), ('learning_rate', 0.29999999999999993), ('max_depth', 7), ('min_child_weight', 6), ('n_estimators', 174), ('reg_alpha', 0.0), ('reg_lambda', 0.060621034233961334), ('subsample', 1.0)])
# Mean Absolute Error (MAE): 0.0005582014991168913
# Mean Absolute Scaled Error (MASE): 0.0289539161292166
# Evaluation results for SMH: MAE = 0.0005582014991168913, MASE = 0.0289539161292166
# [*********************100%%**********************]  1 of 1 completed
# iShares Semiconductor ETF : SOXX
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.5674235415359837), ('gamma', 0.0), ('learning_rate', 0.29999999999999993), ('max_depth', 5), ('min_child_weight', 10), ('n_estimators', 300), ('reg_alpha', 0.0), ('reg_lambda', 0.3808290352914212), ('subsample', 1.0)])
# Mean Absolute Error (MAE): 0.00040175841703183766
# Mean Absolute Scaled Error (MASE): 0.02059302532943796
# Evaluation results for SOXX: MAE = 0.00040175841703183766, MASE = 0.02059302532943796
# [*********************100%%**********************]  1 of 1 completed
# Invesco Semiconductors ETF : PSI
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.7610417048417311), ('gamma', 0.0), ('learning_rate', 0.29999999999999993), ('max_depth', 10), ('min_child_weight', 7), ('n_estimators', 300), ('reg_alpha', 0.011271694146000044), ('reg_lambda', 0.7637034988273363), ('subsample', 1.0)])
# Mean Absolute Error (MAE): 0.0005467169415351833
# Mean Absolute Scaled Error (MASE): 0.026771336062120645
# Evaluation results for PSI: MAE = 0.0005467169415351833, MASE = 0.026771336062120645
# [*********************100%%**********************]  1 of 1 completed
# SPDR S&P Semiconductor ETF : XSD
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.6663737318405567), ('gamma', 0.0), ('learning_rate', 0.29999999999999993), ('max_depth', 6), ('min_child_weight', 6), ('n_estimators', 300), ('reg_alpha', 0.0), ('reg_lambda', 0.029171337803277315), ('subsample', 0.7499086627581193)])
# Mean Absolute Error (MAE): 0.0008152663511605384
# Mean Absolute Scaled Error (MASE): 0.03903708930968892
# Evaluation results for XSD: MAE = 0.0008152663511605384, MASE = 0.03903708930968892
# [*********************100%%**********************]  1 of 1 completed
# iShares U.S. Technology ETF : IYW
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.5965579461667997), ('gamma', 0.0), ('learning_rate', 0.20791063757239073), ('max_depth', 10), ('min_child_weight', 4), ('n_estimators', 245), ('reg_alpha', 0.0), ('reg_lambda', 0.30851682884565906), ('subsample', 1.0)])
# Mean Absolute Error (MAE): 0.0008764466570356022
# Mean Absolute Scaled Error (MASE): 0.05880227774081138
# Evaluation results for IYW: MAE = 0.0008764466570356022, MASE = 0.05880227774081138
# [*********************100%%**********************]  1 of 1 completed
# The Technology Select Sector SPDR Fund : XLK
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.6920508680287836), ('gamma', 0.0), ('learning_rate', 0.29999999999999993), ('max_depth', 6), ('min_child_weight', 3), ('n_estimators', 300), ('reg_alpha', 0.0), ('reg_lambda', 0.8960983380666128), ('subsample', 1.0)])
# Mean Absolute Error (MAE): 0.00024674726871461833
# Mean Absolute Scaled Error (MASE): 0.017390224354753757
# Evaluation results for XLK: MAE = 0.00024674726871461833, MASE = 0.017390224354753757
# [*********************100%%**********************]  1 of 1 completed
# Vanguard Information Technology Index Fund ETF Shares : VGT
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.8639732533362898), ('gamma', 0.0), ('learning_rate', 0.29999999999999993), ('max_depth', 10), ('min_child_weight', 6), ('n_estimators', 300), ('reg_alpha', 0.0), ('reg_lambda', 0.5997813921366288), ('subsample', 0.8270561097847591)])
# Mean Absolute Error (MAE): 0.0025434876808413517
# Mean Absolute Scaled Error (MASE): 0.1759765533884938
# Evaluation results for VGT: MAE = 0.0025434876808413517, MASE = 0.1759765533884938
# [*********************100%%**********************]  1 of 1 completed
# Fidelity MSCI Information Technology Index ETF : FTEC
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.9777389931549642), ('gamma', 0.350310722310683), ('learning_rate', 0.1938811514231446), ('max_depth', 6), ('min_child_weight', 4), ('n_estimators', 142), ('reg_alpha', 6.105075267348604e-05), ('reg_lambda', 0.3706854876627044), ('subsample', 0.7971894567956928)])
# Mean Absolute Error (MAE): 0.00984386499820817
# Mean Absolute Scaled Error (MASE): 0.6807423803615418
# Evaluation results for FTEC: MAE = 0.00984386499820817, MASE = 0.6807423803615418
# [*********************100%%**********************]  1 of 1 completed
# iShares Expanded Tech Sector ETF : IGM
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.5795673196797433), ('gamma', 0.0), ('learning_rate', 0.29999999999999993), ('max_depth', 10), ('min_child_weight', 9), ('n_estimators', 117), ('reg_alpha', 0.0), ('reg_lambda', 0.7443880410940471), ('subsample', 1.0)])
# Mean Absolute Error (MAE): 0.0007782918835870685
# Mean Absolute Scaled Error (MASE): 0.053366076916348044
# Evaluation results for IGM: MAE = 0.0007782918835870685, MASE = 0.053366076916348044
# [*********************100%%**********************]  1 of 1 completed
# iShares Global Tech ETF : IXN
# Best Model Parameters:
# OrderedDict([('colsample_bytree', 0.6336087455515506), ('gamma', 0.0), ('learning_rate', 0.07087783966971721), ('max_depth', 9), ('min_child_weight', 6), ('n_estimators', 184), ('reg_alpha', 0.0), ('reg_lambda', 0.10390847418179966), ('subsample', 0.9734517864567609)])
# Mean Absolute Error (MAE): 0.000542348283332015
# Mean Absolute Scaled Error (MASE): 0.038265473792305445
# Evaluation results for IXN: MAE = 0.000542348283332015, MASE = 0.038265473792305445
# Weekly forecast data and predictions stored successfully.

# %%
def calculate_sharpe_ratio(returns, annual_risk_free_rate=0.1,period='daily'):
    #excess_returns = rate_of_return(returns) - risk_free_rate
    
    # Convert annual risk-free rate to daily rate
    daily_risk_free_rate = (1 + annual_risk_free_rate) ** (1/252) - 1
    
    # Calculate mean daily log return
    mean_return = np.mean(returns)
    
    # Calculate excess daily log return
    excess_return = mean_return - daily_risk_free_rate
    
    # Calculate standard deviation of daily log returns
    std_return = np.std(returns)
    
    # Print diagnostic information
    #print(f"Mean Daily Log Return: {mean_return}")
    #print(f"Excess Daily Log Return: {excess_return}")
    #print(f"Standard Deviation of Daily Log Returns: {std_return}")
    
    # Check for zero standard deviation to avoid division by zero
    if std_return == 0:
        return 0
    
    # Calculate Sharpe ratio
    sharpe_ratio = (excess_return / std_return) * np.sqrt(252)  # Annualize the Sharpe ratio
    return sharpe_ratio
    #return excess_returns / np.std(returns)


def calculate_rachev_ratio(returns, lower_percentile=5, upper_percentile=95):
    # Step 1: Sort the returns
    sorted_returns = np.sort(returns)
    
    # Step 2: Determine the percentiles
    lower_threshold = np.percentile(sorted_returns, lower_percentile)
    upper_threshold = np.percentile(sorted_returns, upper_percentile)
    
    # Step 3: Calculate Expected Shortfall (ES)
    es = np.mean(sorted_returns[sorted_returns <= lower_threshold])
    
    # Step 4: Calculate Expected Gain (EG)
    eg = np.mean(sorted_returns[sorted_returns >= upper_threshold])
    
    # Step 5: Compute the Rachev Ratio
    rachev_ratio = eg / -es
    return rachev_ratio


def calculate_volatility_clustering(returns):
    squared_returns = returns ** 2
    n = len(squared_returns)
    
    # Mean of squared returns
    mean_squared_returns = np.mean(squared_returns)
    
    # Calculate the numerator and denominator for autocorrelation at lag 1
    numerator = np.sum((squared_returns[:-1] - mean_squared_returns) * (squared_returns[1:] - mean_squared_returns))
    denominator = np.sum((squared_returns - mean_squared_returns) ** 2)
    
    if denominator == 0:
        return 0  # Avoid division by zero
    
    rho_1 = numerator / denominator
    return rho_1

def calculate_sortino_ratio(log_returns, target_log_return=0.0):
    """
    Calculate the Sortino Ratio using log returns.
    
    Parameters:
    - log_returns (array-like): Array or list of log returns for the period.
    - target_log_return (float): The target log return. Default is 0, which is often used as a benchmark.
    
    Returns:
    - float: The Sortino Ratio.
    """
    # Convert input to a NumPy array for easier calculations
    log_returns = np.array(log_returns)
    
    # Calculate the average period log return (R)
    avg_log_return = np.mean(log_returns)
    
    # Calculate the Target Downside Deviation (TDD)
    downside_deviation = np.sqrt(
        np.mean(np.square(np.maximum(0, target_log_return - log_returns)))
    )
    
    # Calculate Sortino Ratio
    #sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
    epsilon = 1e-8
    
    # Add epsilon to downside_deviation to prevent division by zero
    #if downside_deviation == 0:
     #   return np.nan  # Return NaN if downside deviation is zero
    
    # Calculate Sortino Ratio
    sortino_ratio_value = (avg_log_return - target_log_return) / (downside_deviation + epsilon)
    
    return sortino_ratio_value

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, volatility_clustering, 
    mean_forecast, std_forecast, mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
    mean_volatility_clustering, std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    # Debugging: Log raw input values
    print(f"\nDebug: Composite Score Calculation")
    print(f"Forecasted Mean: {forecasted_mean}, Risk Percentage: {risk_percentage}")
    print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
    print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")

    # Normalize the components with epsilon
    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Debugging: Log normalized values
    print(f"Normalized Values -> Forecasted Mean: {forecasted_mean_normalized}, Rachev: {rachev_normalized}")
    print(f"Sharpe: {sharpe_normalized}, Sortino: {sortino_normalized}, Volatility Clustering: {volatility_clustering_normalized}")

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    # Debugging: Log final score
    print(f"Final Composite Score: {score}")

    return score


def process_etf_data_weekly(tickers, etf_dict):
    etf_pred_dict = {}

    # Determine the forecast periods dynamically from the etf_dict
    sample_etf = next(iter(etf_dict.values()))
    forecast_periods = [key.split('_')[-1] for key in sample_etf.keys() if key.startswith('forecast_predictions_df')]

    for etf_name in tickers:
        etf_pred_dict[etf_name] = {
            f"returns_{period}": etf_dict[etf_name][f"forecast_predictions_df_{period}"]
            for period in forecast_periods
        }

        for period in forecast_periods:
            returns = etf_pred_dict[etf_name][f"returns_{period}"]

            # Log returns for debugging
            print(f"\nDebug: Returns for {etf_name}, Forecast Period {period}: {returns}")

            # Calculate metrics
            etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
            etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
            etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
            etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict



def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    print(f"\nDebug: Forecast Period = {forecast_period}")
    print(f"All Returns Means: {[np.mean(returns) for returns in returns_list]}")
    print(f"Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Rachev Ratios: {rachev_ratios}")
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sharpe Ratios: {sharpe_ratios}")
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sortino Ratios: {sortino_ratios}")
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Volatility Clustering: {volatility_clustering}")
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    print(f"Mean Rachev = {mean_rachev}, Std Rachev = {std_rachev}")
    print(f"Mean Sharpe = {mean_sharpe}, Std Sharpe = {std_sharpe}")
    print(f"Mean Sortino = {mean_sortino}, Std Sortino = {std_sortino}")
    print(f"Mean Volatility Clustering = {mean_volatility_clustering}, Std Volatility Clustering = {std_volatility_clustering}")

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )



def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Debugging: Log inputs to composite score calculation
        print(f"\nDebug: ETF = {etf}, Forecast Period = {forecast_period}")
        print(f"Forecasted Values Mean: {np.mean(forecasted_values)}")
        print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
        print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")
        print(f"Means and Stds: Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")
        
        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

        # Debugging: Log the calculated score
        print(f"Calculated Score for {etf} ({forecast_period}): {score}")

    return scores



def main_weekly(tickers, etf_dict):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict)
    
    risk_percentage = 0.10
    weekly_scores = {}

    # Iterate over 48 weeks
    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores
            print(f"Scores calculated for {week_key}:")
            for score in scores:
                print(score)
        else:
            print(f"Skipping score calculation for {week_key}: No ETFs have data for this week.")

    return etf_pred_dict, weekly_scores


# Example usage:
# Execute weekly scoring
etf_pred_dict, weekly_scores = main_weekly(tickers, etf_dict)
# Out:
# Debug: Returns for SMH, Forecast Period 1w: [-0.03202409 -0.0154641  -0.004719    0.00856414]
#
# Debug: Returns for SMH, Forecast Period 2w: [ 0.03812428  0.00463116  0.00089891  0.00752194 -0.00303392]
#
# Debug: Returns for SMH, Forecast Period 3w: [ 0.01694065 -0.00609958  0.0314685   0.03796531]
#
# Debug: Returns for SMH, Forecast Period 4w: [ 0.00551596  0.00603854  0.01867902  0.00020021 -0.02019114]
#
# Debug: Returns for SMH, Forecast Period 5w: [ 0.01261234 -0.00865264 -0.01316788  0.01014745  0.02036492]
#
# Debug: Returns for SMH, Forecast Period 6w: [ 0.02036492 -0.00976431  0.02063851  0.01516252  0.02297172]
#
# Debug: Returns for SMH, Forecast Period 7w: [-0.00346818 -0.01724814  0.02077546 -0.002941   -0.00371011]
#
# Debug: Returns for SMH, Forecast Period 8w: [-0.01843297 -0.00595772  0.06640472 -0.00588333]
#
# Debug: Returns for SMH, Forecast Period 9w: [ 0.00934484 -0.00249664 -0.00976431  0.02257291  0.04058891]
#
# Debug: Returns for SMH, Forecast Period 10w: [ 0.01714005 -0.01407705  0.02603656  0.03478451 -0.03834511]
#
# Debug: Returns for SMH, Forecast Period 11w: [-0.01669412  0.0307133  -0.01856992 -0.01669412 -0.00598608]
#
# Debug: Returns for SMH, Forecast Period 12w: [ 0.00225205 -0.00202005  0.01714005  0.02367958  0.00698386]
#
# Debug: Returns for SMH, Forecast Period 13w: [-0.00201211 -0.00701872 -0.00128278 -0.0003416 ]
#
# Debug: Returns for SMH, Forecast Period 14w: [ 0.01323239 -0.01254194  0.00355618 -0.02709604  0.01184344]
#
# Debug: Returns for SMH, Forecast Period 15w: [ 0.00020158  0.00413844 -0.00893642  0.02314268 -0.02872497]
#
# Debug: Returns for SMH, Forecast Period 16w: [-0.01530867  0.00781905 -0.03245699 -0.01872783 -0.04488023]
#
# Debug: Returns for SMH, Forecast Period 17w: [ 0.01862271  0.02282172 -0.0001228   0.01989256  0.02529061]
#
# Debug: Returns for SMH, Forecast Period 18w: [ 0.00370178 -0.01931587 -0.02809986  0.01989256  0.02696831]
#
# Debug: Returns for SMH, Forecast Period 19w: [ 0.02323339 -0.00785681  0.00359753 -0.00654086  0.01628868]
#
# Debug: Returns for SMH, Forecast Period 20w: [ 0.00025627  0.01868728  0.03015823 -0.00569706 -0.00695138]
#
# Debug: Returns for SMH, Forecast Period 21w: [ 0.02163808 -0.00109078  0.00925624  0.01474281  0.01951856]
#
# Debug: Returns for SMH, Forecast Period 22w: [ 0.02367958 -0.01529195 -0.01239681 -0.00598608]
#
# Debug: Returns for SMH, Forecast Period 23w: [ 0.01348685 -0.00336163  0.04741708 -0.00652254 -0.00055863]
#
# Debug: Returns for SMH, Forecast Period 24w: [ 0.01545057 -0.00122773  0.03002128  0.01649933  0.00342948]
#
# Debug: Returns for SMH, Forecast Period 25w: [ 0.0178705   0.0168037  -0.02791381 -0.01378288]
#
# Debug: Returns for SMH, Forecast Period 26w: [-0.03445055  0.02407146 -0.00290259 -0.00652254  0.00816448]
#
# Debug: Returns for SMH, Forecast Period 27w: [0.00145955 0.01116443 0.02367958 0.000738  ]
#
# Debug: Returns for SMH, Forecast Period 28w: [ 0.01762248  0.00247176  0.02420841 -0.0340109   0.01456913]
#
# Debug: Returns for SMH, Forecast Period 29w: [-0.00224807 -0.00056815 -0.07058055  0.00565359 -0.02916354]
#
# Debug: Returns for SMH, Forecast Period 30w: [ 0.03514364 -0.01051026 -0.06018678 -0.01840531  0.01541701]
#
# Debug: Returns for SMH, Forecast Period 31w: [-0.00813698 -0.03983722  0.07231167 -0.06967504 -0.06004408]
#
# Debug: Returns for SMH, Forecast Period 32w: [-0.02366678  0.01897823 -0.02778782  0.05626757 -0.00148167]
#
# Debug: Returns for SMH, Forecast Period 33w: [1.0228256e-02 3.7931260e-02 9.5499810e-05 3.9649967e-02 7.2022248e-04]
#
# Debug: Returns for SMH, Forecast Period 34w: [ 0.01987245 -0.01272964  0.01053549 -0.03233375  0.02547822]
#
# Debug: Returns for SMH, Forecast Period 35w: [-0.02264607  0.01130138 -0.0155047  -0.01170712  0.02488823]
#
# Debug: Returns for SMH, Forecast Period 36w: [-0.09080893 -0.00162578 -0.00110611 -0.04027833]
#
# Debug: Returns for SMH, Forecast Period 37w: [0.02172199 0.00946434 0.04862954 0.00175168 0.01337605]
#
# Debug: Returns for SMH, Forecast Period 38w: [-0.01272964 -0.00122303 -0.01111498  0.03945598 -0.01272964]
#
# Debug: Returns for SMH, Forecast Period 39w: [ 0.00496857  0.01863565  0.01004494  0.02923816 -0.01809826]
#
# Debug: Returns for SMH, Forecast Period 40w: [-0.00781616 -0.0263162   0.01558752  0.0102844   0.01442961]
#
# Debug: Returns for SMH, Forecast Period 41w: [ 0.00188776  0.01829443  0.0114184  -0.00176543  0.00898996]
#
# Debug: Returns for SMH, Forecast Period 42w: [ 0.01867902 -0.05441052  0.00084369  0.01843138  0.0008394 ]
#
# Debug: Returns for SMH, Forecast Period 43w: [ 0.00604688 -0.00521128 -0.01038809  0.00432236  0.01096893]
#
# Debug: Returns for SMH, Forecast Period 44w: [-0.00746077  0.02261932 -0.02422396 -0.03613283  0.01210895]
#
# Debug: Returns for SMH, Forecast Period 45w: [-0.00329122  0.01584212  0.02520428  0.02364595 -0.00703733]
#
# Debug: Returns for SMH, Forecast Period 46w: [-0.02266197 -0.00805676 -0.01716745  0.00080902 -0.03326945]
#
# Debug: Returns for SMH, Forecast Period 47w: [ 0.00636409  0.01005637 -0.00759669  0.01403529 -0.00747895]
#
# Debug: Returns for SMH, Forecast Period 48w: [-0.00649436 -0.01002639 -0.01417608  0.01519688]
#
# Debug: Returns for SOXX, Forecast Period 1w: [-0.03706532 -0.02176728 -0.00812107  0.00571173]
#
# Debug: Returns for SOXX, Forecast Period 2w: [ 0.0323147   0.00082415 -0.00316626  0.00367128 -0.00418959]
#
# Debug: Returns for SOXX, Forecast Period 3w: [ 0.0144295  -0.00950463  0.0324925   0.03937934]
#
# Debug: Returns for SOXX, Forecast Period 4w: [ 0.00355432  0.00687057  0.01458439 -0.0026465  -0.02716174]
#
# Debug: Returns for SOXX, Forecast Period 5w: [ 0.01045832 -0.0151825  -0.01473959  0.00544179  0.01300019]
#
# Debug: Returns for SOXX, Forecast Period 6w: [ 0.01339658 -0.0119708   0.01583041  0.01691182  0.02004898]
#
# Debug: Returns for SOXX, Forecast Period 7w: [-0.00154132 -0.02033937  0.02267721 -0.00047768 -0.00527871]
#
# Debug: Returns for SOXX, Forecast Period 8w: [-0.01664155 -0.00212804  0.04873264 -0.01044627]
#
# Debug: Returns for SOXX, Forecast Period 9w: [ 0.01042539 -0.00047768 -0.0108995   0.02722179  0.04192361]
#
# Debug: Returns for SOXX, Forecast Period 10w: [ 0.01042539 -0.01948714  0.02474296  0.03411257 -0.04134722]
#
# Debug: Returns for SOXX, Forecast Period 11w: [-0.01321808  0.02076716 -0.02402711 -0.01664155 -0.00697528]
#
# Debug: Returns for SOXX, Forecast Period 12w: [-0.00053885 -0.00808264  0.01655396  0.02249941  0.00153028]
#
# Debug: Returns for SOXX, Forecast Period 13w: [-0.00389706 -0.00703482  0.0120172   0.00085005]
#
# Debug: Returns for SOXX, Forecast Period 14w: [ 0.01087775 -0.01616085  0.0021014  -0.02851545  0.01199504]
#
# Debug: Returns for SOXX, Forecast Period 15w: [ 0.00303653  0.01073599 -0.01843003  0.02221783 -0.03368871]
#
# Debug: Returns for SOXX, Forecast Period 16w: [-0.01243557  0.00757678 -0.03107411 -0.017166   -0.04191658]
#
# Debug: Returns for SOXX, Forecast Period 17w: [0.01756972 0.02155608 0.01388988 0.01867719 0.02083504]
#
# Debug: Returns for SOXX, Forecast Period 18w: [ 0.00818604 -0.02042759 -0.0347132   0.0227451   0.02207883]
#
# Debug: Returns for SOXX, Forecast Period 19w: [ 0.02007721 -0.00935467  0.00138742 -0.00373541  0.01002765]
#
# Debug: Returns for SOXX, Forecast Period 20w: [ 0.0018977   0.01652403  0.02756874 -0.00464772 -0.00527871]
#
# Debug: Returns for SOXX, Forecast Period 21w: [ 0.02201244 -0.00279225  0.01164447 -0.00527871  0.02026079]
#
# Debug: Returns for SOXX, Forecast Period 22w: [ 0.01691182 -0.02033937 -0.00641655 -0.00808135]
#
# Debug: Returns for SOXX, Forecast Period 23w: [ 0.00163375 -0.00761128  0.04192361 -0.00790355 -0.00247638]
#
# Debug: Returns for SOXX, Forecast Period 24w: [ 0.01483564  0.00146811  0.02778055  0.01138732 -0.00298846]
#
# Debug: Returns for SOXX, Forecast Period 25w: [ 0.01599439  0.01296617 -0.02716174 -0.00932101]
#
# Debug: Returns for SOXX, Forecast Period 26w: [-0.0283054   0.01565261 -0.00389706 -0.00479019  0.01028052]
#
# Debug: Returns for SOXX, Forecast Period 27w: [0.00016667 0.0144295  0.01691364 0.00264264]
#
# Debug: Returns for SOXX, Forecast Period 28w: [ 0.01955466 -0.00024303  0.02362979 -0.03317809  0.01260705]
#
# Debug: Returns for SOXX, Forecast Period 29w: [ 0.0013256   0.00643823 -0.08681529  0.00303923 -0.03105839]
#
# Debug: Returns for SOXX, Forecast Period 30w: [ 0.04131775 -0.01465002 -0.05605261 -0.02193807  0.0221549 ]
#
# Debug: Returns for SOXX, Forecast Period 31w: [-0.00186854 -0.03736024  0.07231331 -0.08949111 -0.05548651]
#
# Debug: Returns for SOXX, Forecast Period 32w: [-0.01779088  0.00967039 -0.02753992  0.07380833 -0.00545553]
#
# Debug: Returns for SOXX, Forecast Period 33w: [ 0.00581515  0.03905389 -0.00263545  0.04563401 -0.00256483]
#
# Debug: Returns for SOXX, Forecast Period 34w: [ 0.01590757 -0.01316213  0.01469606 -0.03481692  0.02720983]
#
# Debug: Returns for SOXX, Forecast Period 35w: [-0.02566305  0.01109328 -0.01801105 -0.00252291  0.0254394 ]
#
# Debug: Returns for SOXX, Forecast Period 36w: [-0.0803166   0.00430937 -0.00513442 -0.04396366]
#
# Debug: Returns for SOXX, Forecast Period 37w: [ 0.02041017  0.0114184   0.04617701 -0.00475874  0.01788947]
#
# Debug: Returns for SOXX, Forecast Period 38w: [-0.01312851  0.00162739 -0.01010049  0.04252083 -0.01465002]
#
# Debug: Returns for SOXX, Forecast Period 39w: [ 0.00353411  0.01236618  0.00706281  0.03571008 -0.01579077]
#
# Debug: Returns for SOXX, Forecast Period 40w: [-0.00891697 -0.02821583  0.0134306   0.00367128  0.0134306 ]
#
# Debug: Returns for SOXX, Forecast Period 41w: [-0.00261248  0.01024759  0.01006871 -0.00659435  0.00859115]
#
# Debug: Returns for SOXX, Forecast Period 42w: [ 0.0183014  -0.05415836  0.00036614  0.00797329  0.00085478]
#
# Debug: Returns for SOXX, Forecast Period 43w: [-0.00211531 -0.00363245 -0.00989532  0.00469001  0.00993413]
#
# Debug: Returns for SOXX, Forecast Period 44w: [-5.2699881e-05  2.3843780e-02 -3.6395855e-02 -3.9744034e-02
#   1.1263254e-02]
#
# Debug: Returns for SOXX, Forecast Period 45w: [-0.00536694  0.01177559  0.028577    0.02007721 -0.00754697]
#
# Debug: Returns for SOXX, Forecast Period 46w: [-2.5067143e-02 -1.0901701e-02 -2.1814592e-02 -1.3250483e-05
#  -3.3184741e-02]
#
# Debug: Returns for SOXX, Forecast Period 47w: [ 0.01275828  0.00215138 -0.00783872  0.01550313  0.00051069]
#
# Debug: Returns for SOXX, Forecast Period 48w: [ 0.01033812 -0.01214427 -0.01297587  0.01311714]
#
# Debug: Returns for PSI, Forecast Period 1w: [-0.03786063 -0.02395659 -0.01452977  0.00122902]
#
# Debug: Returns for PSI, Forecast Period 2w: [ 0.02962338  0.00177292 -0.00436342  0.00288603 -0.00508395]
#
# Debug: Returns for PSI, Forecast Period 3w: [ 0.0139508  -0.01150108  0.03348404  0.03948674]
#
# Debug: Returns for PSI, Forecast Period 4w: [ 0.00875542  0.00288603  0.01041648 -0.00122507 -0.03024713]
#
# Debug: Returns for PSI, Forecast Period 5w: [ 0.01162832 -0.01452977 -0.02033322  0.00830509  0.01135139]
#
# Debug: Returns for PSI, Forecast Period 6w: [ 0.00863409 -0.013657    0.00655969  0.01907812  0.03230321]
#
# Debug: Returns for PSI, Forecast Period 7w: [ 0.0009616  -0.0275196   0.03230321  0.0048244  -0.00052895]
#
# Debug: Returns for PSI, Forecast Period 8w: [-0.0275196  -0.01150108  0.04280266 -0.01079938]
#
# Debug: Returns for PSI, Forecast Period 9w: [ 0.01316302 -0.0026438   0.00343536  0.017405    0.04280266]
#
# Debug: Returns for PSI, Forecast Period 10w: [ 0.00288603 -0.02650258  0.02431726  0.02962338 -0.03929047]
#
# Debug: Returns for PSI, Forecast Period 11w: [-0.01476919  0.01621491 -0.02643275 -0.01656426 -0.00923873]
#
# Debug: Returns for PSI, Forecast Period 12w: [ 0.00655969 -0.00639125  0.02632157  0.02962338  0.00122902]
#
# Debug: Returns for PSI, Forecast Period 13w: [-0.00074459 -0.00639125  0.0111675  -0.00122507]
#
# Debug: Returns for PSI, Forecast Period 14w: [ 0.01020098 -0.01079938  0.01020098 -0.02643275  0.01316302]
#
# Debug: Returns for PSI, Forecast Period 15w: [ 0.00231334  0.00830509 -0.02082083  0.02700792 -0.03336931]
#
# Debug: Returns for PSI, Forecast Period 16w: [-0.01476919  0.0111675  -0.03336931 -0.01945073 -0.03824078]
#
# Debug: Returns for PSI, Forecast Period 17w: [0.01663152 0.02428309 0.00863409 0.01618074 0.02121506]
#
# Debug: Returns for PSI, Forecast Period 18w: [ 0.00835573 -0.02260148 -0.0332021   0.02958921  0.02171105]
#
# Debug: Returns for PSI, Forecast Period 19w: [ 0.02174522 -0.00508395 -0.00052895  0.00122902  0.00596347]
#
# Debug: Returns for PSI, Forecast Period 20w: [-0.00078341  0.01580973  0.02700792 -0.00810327 -0.00573382]
#
# Debug: Returns for PSI, Forecast Period 21w: [ 2.0824786e-02  2.1367018e-06  1.2290213e-03 -3.3449775e-03
#   1.7039431e-02]
#
# Debug: Returns for PSI, Forecast Period 22w: [ 0.0139508  -0.01476919 -0.0024035  -0.01228641]
#
# Debug: Returns for PSI, Forecast Period 23w: [ 2.1367018e-06 -1.0799379e-02  4.7663737e-02 -8.1032692e-03
#  -9.6903788e-03]
#
# Debug: Returns for PSI, Forecast Period 24w: [ 0.01960009 -0.00052895  0.02962338  0.00830509 -0.00810327]
#
# Debug: Returns for PSI, Forecast Period 25w: [ 0.01960009  0.0139508  -0.03024713 -0.01228641]
#
# Debug: Returns for PSI, Forecast Period 26w: [-0.023037    0.02174522 -0.0024035   0.0016265   0.01162832]
#
# Debug: Returns for PSI, Forecast Period 27w: [-0.00078341  0.01377121  0.01162832  0.00252796]
#
# Debug: Returns for PSI, Forecast Period 28w: [ 1.5179577e-02  2.1367018e-06  1.6214915e-02 -3.0247126e-02
#   1.1628319e-02]
#
# Debug: Returns for PSI, Forecast Period 29w: [ 0.01162832  0.00711754 -0.07253202 -0.00969038 -0.02555026]
#
# Debug: Returns for PSI, Forecast Period 30w: [ 0.04247085 -0.00810327 -0.05655967 -0.02921143  0.01703671]
#
# Debug: Returns for PSI, Forecast Period 31w: [-0.00348093 -0.04832652  0.06258423 -0.07434056 -0.05053614]
#
# Debug: Returns for PSI, Forecast Period 32w: [-0.01451196  0.00772395 -0.01595833  0.06319927  0.00378795]
#
# Debug: Returns for PSI, Forecast Period 33w: [ 0.00345272  0.03721708 -0.00122393  0.05236565 -0.00508281]
#
# Debug: Returns for PSI, Forecast Period 34w: [ 0.01315099 -0.01472333  0.02262948 -0.03131142  0.02693575]
#
# Debug: Returns for PSI, Forecast Period 35w: [-0.02728735  0.01116864 -0.01472333  0.00596461  0.01162832]
#
# Debug: Returns for PSI, Forecast Period 36w: [-0.07178853  0.00596347 -0.00718693 -0.04183298]
#
# Debug: Returns for PSI, Forecast Period 37w: [ 0.01203682  0.00725802  0.04248401 -0.00810327  0.02360035]
#
# Debug: Returns for PSI, Forecast Period 38w: [-0.02244827  0.00725802 -0.01079938  0.04251355 -0.01228641]
#
# Debug: Returns for PSI, Forecast Period 39w: [ 0.00431762  0.01161515  0.00648277  0.05268494 -0.01651543]
#
# Debug: Returns for PSI, Forecast Period 40w: [-0.00697526 -0.03754021  0.017405   -0.00639125  0.02082479]
#
# Debug: Returns for PSI, Forecast Period 41w: [ 2.1367018e-06  2.7575307e-03  1.3950796e-02 -1.5969072e-03
#   1.6214915e-02]
#
# Debug: Returns for PSI, Forecast Period 42w: [ 0.017405   -0.05700508  0.00177292  0.00215145 -0.00052895]
#
# Debug: Returns for PSI, Forecast Period 43w: [-0.00334498 -0.00585732 -0.00810327  0.00252796  0.01514541]
#
# Debug: Returns for PSI, Forecast Period 44w: [-0.00078341  0.02082479 -0.02428046 -0.04235865  0.00596347]
#
# Debug: Returns for PSI, Forecast Period 45w: [-0.0079279   0.02958921  0.03604641  0.02632157 -0.00436342]
#
# Debug: Returns for PSI, Forecast Period 46w: [-0.02260148 -0.01228641 -0.02260148 -0.00223143 -0.03745943]
#
# Debug: Returns for PSI, Forecast Period 47w: [1.5145406e-02 8.6340932e-03 2.1367018e-06 3.6046412e-02 2.1367018e-06]
#
# Debug: Returns for PSI, Forecast Period 48w: [ 0.01318516 -0.00810327 -0.01808801  0.01960009]
#
# Debug: Returns for XSD, Forecast Period 1w: [-0.03009228 -0.03147347 -0.01806632  0.00191338]
#
# Debug: Returns for XSD, Forecast Period 2w: [ 0.03166605 -0.00236881 -0.00767938 -0.00682818 -0.01014771]
#
# Debug: Returns for XSD, Forecast Period 3w: [ 0.00029927 -0.01287085  0.03043181  0.03118892]
#
# Debug: Returns for XSD, Forecast Period 4w: [ 0.01688887  0.00872913 -0.00917508 -0.01149894 -0.02853933]
#
# Debug: Returns for XSD, Forecast Period 5w: [ 0.01654226 -0.0262933  -0.0212327  -0.00151408  0.00012314]
#
# Debug: Returns for XSD, Forecast Period 6w: [ 0.00735774 -0.01020665  0.01792419  0.02804547  0.02432775]
#
# Debug: Returns for XSD, Forecast Period 7w: [ 0.00270301 -0.03786182  0.02432775 -0.00163735 -0.01778955]
#
# Debug: Returns for XSD, Forecast Period 8w: [-0.01184096 -0.00289541  0.02203688 -0.01751514]
#
# Debug: Returns for XSD, Forecast Period 9w: [ 0.01089064 -0.00361345 -0.0082103   0.02376749  0.03831361]
#
# Debug: Returns for XSD, Forecast Period 10w: [-0.00188748 -0.02444638  0.02489398  0.03518082 -0.0307174 ]
#
# Debug: Returns for XSD, Forecast Period 11w: [-0.00761841  0.00760083 -0.028952   -0.02463882 -0.00894715]
#
# Debug: Returns for XSD, Forecast Period 12w: [-0.00168728 -0.00783136  0.02389148  0.02229713 -0.00802498]
#
# Debug: Returns for XSD, Forecast Period 13w: [-0.00224052 -0.00550645  0.02651304  0.00265398]
#
# Debug: Returns for XSD, Forecast Period 14w: [ 0.00678376 -0.0230316   0.00816043 -0.01684528  0.00451571]
#
# Debug: Returns for XSD, Forecast Period 15w: [ 0.00781679  0.02152101 -0.04124594  0.02341867 -0.03762412]
#
# Debug: Returns for XSD, Forecast Period 16w: [-0.02102086  0.00172806 -0.02345107 -0.0211141  -0.03280739]
#
# Debug: Returns for XSD, Forecast Period 17w: [0.01395178 0.01956294 0.02275196 0.02315429 0.01844661]
#
# Debug: Returns for XSD, Forecast Period 18w: [ 0.01767356 -0.01957812 -0.03403236  0.01723592  0.02228774]
#
# Debug: Returns for XSD, Forecast Period 19w: [ 0.01720968 -0.00432262  0.00311107  0.00270301 -0.00747167]
#
# Debug: Returns for XSD, Forecast Period 20w: [ 4.6794866e-03  1.7835604e-02  2.0781634e-02 -5.5819661e-03
#   5.2485655e-05]
#
# Debug: Returns for XSD, Forecast Period 21w: [ 0.0124999  -0.0041373   0.02030614 -0.02245476  0.02263656]
#
# Debug: Returns for XSD, Forecast Period 22w: [ 0.01297599 -0.02005248  0.00443204 -0.00023366]
#
# Debug: Returns for XSD, Forecast Period 23w: [-0.00126733 -0.01602759  0.0399932  -0.00994687 -0.02038581]
#
# Debug: Returns for XSD, Forecast Period 24w: [ 0.01493182  0.00378579  0.02738551 -0.00320309 -0.01789945]
#
# Debug: Returns for XSD, Forecast Period 25w: [ 0.00666187  0.00056791 -0.02306441  0.00042761]
#
# Debug: Returns for XSD, Forecast Period 26w: [-0.02061779  0.00813043  0.00010495 -0.00303722  0.00968144]
#
# Debug: Returns for XSD, Forecast Period 27w: [-0.00448757  0.0205789   0.0090076   0.0042293 ]
#
# Debug: Returns for XSD, Forecast Period 28w: [ 0.02172563 -0.00728635  0.02738989 -0.0136594   0.01123947]
#
# Debug: Returns for XSD, Forecast Period 29w: [ 0.00951646  0.01938473 -0.05466067 -0.00967216 -0.03082972]
#
# Debug: Returns for XSD, Forecast Period 30w: [ 0.0399932  -0.01689531 -0.04637972 -0.02617471  0.02145428]
#
# Debug: Returns for XSD, Forecast Period 31w: [-0.00098229 -0.04344065  0.04154225 -0.06785249 -0.06848913]
#
# Debug: Returns for XSD, Forecast Period 32w: [-0.03131741  0.00396153 -0.03065448  0.06490524 -0.00785781]
#
# Debug: Returns for XSD, Forecast Period 33w: [-0.0007782   0.03878554 -0.01421045  0.05017427 -0.00451652]
#
# Debug: Returns for XSD, Forecast Period 34w: [ 0.01208069 -0.01164689  0.02107836 -0.03164641  0.03246643]
#
# Debug: Returns for XSD, Forecast Period 35w: [-0.02015319  0.0047708  -0.01480324  0.01373685  0.01249094]
#
# Debug: Returns for XSD, Forecast Period 36w: [-0.08443207  0.00241524 -0.01127185 -0.04311293]
#
# Debug: Returns for XSD, Forecast Period 37w: [ 0.01599765  0.00168746  0.0393936  -0.00882323  0.0214669 ]
#
# Debug: Returns for XSD, Forecast Period 38w: [-0.01420209  0.00244894 -0.00487624  0.03868586 -0.01810056]
#
# Debug: Returns for XSD, Forecast Period 39w: [ 0.00238207  0.00861904 -0.00453717  0.04612533 -0.00640932]
#
# Debug: Returns for XSD, Forecast Period 40w: [-0.01224705 -0.03725723  0.01012679 -0.00256913  0.0183483 ]
#
# Debug: Returns for XSD, Forecast Period 41w: [-0.00722149  0.00378579  0.0124999  -0.00580365  0.02078163]
#
# Debug: Returns for XSD, Forecast Period 42w: [ 0.01052825 -0.02794371  0.00575038  0.00285672 -0.00080311]
#
# Debug: Returns for XSD, Forecast Period 43w: [-0.00379926 -0.00071014 -0.01025624  0.00401994  0.01034293]
#
# Debug: Returns for XSD, Forecast Period 44w: [ 0.01123947  0.02322336 -0.04389853 -0.05469306  0.0215051 ]
#
# Debug: Returns for XSD, Forecast Period 45w: [-0.00570042  0.01488508  0.04171991  0.01066218  0.00713274]
#
# Debug: Returns for XSD, Forecast Period 46w: [-0.028952   -0.02089107 -0.02344138 -0.00926246 -0.03404995]
#
# Debug: Returns for XSD, Forecast Period 47w: [ 0.01428366  0.00877042 -0.00030561  0.02793778  0.01446381]
#
# Debug: Returns for XSD, Forecast Period 48w: [ 0.03255966 -0.012539   -0.01260042  0.0190463 ]
#
# Debug: Returns for IYW, Forecast Period 1w: [-0.02378365 -0.00915305 -0.00406055  0.00362251]
#
# Debug: Returns for IYW, Forecast Period 2w: [0.02765851 0.0057929  0.01247163 0.00704194 0.00381901]
#
# Debug: Returns for IYW, Forecast Period 3w: [ 0.00297585 -0.00242258  0.02081324  0.0251478 ]
#
# Debug: Returns for IYW, Forecast Period 4w: [ 0.00692801  0.00692801  0.01020366  0.00721229 -0.00638357]
#
# Debug: Returns for IYW, Forecast Period 5w: [ 0.01366711 -0.00551861 -0.02275165  0.0147932   0.02007826]
#
# Debug: Returns for IYW, Forecast Period 6w: [ 0.00371294 -0.00111832  0.01642323  0.00704194  0.01642323]
#
# Debug: Returns for IYW, Forecast Period 7w: [-0.00500992 -0.01448728  0.01506978  0.00059377 -0.00843429]
#
# Debug: Returns for IYW, Forecast Period 8w: [-0.00729022 -0.00500992  0.03563775  0.00071354]
#
# Debug: Returns for IYW, Forecast Period 9w: [ 0.00046835  0.00344337 -0.00593947  0.0140578   0.0175965 ]
#
# Debug: Returns for IYW, Forecast Period 10w: [ 4.8145030e-05 -2.1106549e-02  1.1856795e-02  1.9324301e-02
#  -1.1263380e-02]
#
# Debug: Returns for IYW, Forecast Period 11w: [-0.00149099  0.02148031 -0.00596848  0.0033887  -0.01268488]
#
# Debug: Returns for IYW, Forecast Period 12w: [0.01118133 0.00714194 0.01523084 0.00533966 0.00587136]
#
# Debug: Returns for IYW, Forecast Period 13w: [-0.00232112 -0.00232112  0.00354258  0.00071354]
#
# Debug: Returns for IYW, Forecast Period 14w: [ 0.00623327 -0.00500992  0.00465535 -0.01371208  0.01659296]
#
# Debug: Returns for IYW, Forecast Period 15w: [-0.00049702  0.00465535 -0.00442794  0.02285689 -0.01397916]
#
# Debug: Returns for IYW, Forecast Period 16w: [-0.01879027  0.00362201 -0.01357423 -0.0053459  -0.02684033]
#
# Debug: Returns for IYW, Forecast Period 17w: [ 0.01370287  0.01869843  0.00441012 -0.00281051  0.02266995]
#
# Debug: Returns for IYW, Forecast Period 18w: [ 0.0035981  -0.01958319 -0.00735692  0.01778223  0.02574506]
#
# Debug: Returns for IYW, Forecast Period 19w: [ 0.01693395 -0.00171846  0.00290562  0.00166135  0.0057929 ]
#
# Debug: Returns for IYW, Forecast Period 20w: [0.00627103 0.01171618 0.02313659 0.00027644 0.00046835]
#
# Debug: Returns for IYW, Forecast Period 21w: [0.01532054 0.00383391 0.00290562 0.00445707 0.01200769]
#
# Debug: Returns for IYW, Forecast Period 22w: [ 0.01325776 -0.0022643  -0.02277976  0.00238259]
#
# Debug: Returns for IYW, Forecast Period 23w: [1.0981857e-02 4.3168450e-03 2.7445029e-02 5.2819862e-05 4.0782751e-03]
#
# Debug: Returns for IYW, Forecast Period 24w: [0.0044493  0.01674931 0.02421417 0.00957935 0.00875168]
#
# Debug: Returns for IYW, Forecast Period 25w: [ 0.01398773  0.00731229 -0.01078545 -0.00356065]
#
# Debug: Returns for IYW, Forecast Period 26w: [-0.0137932   0.01848325  0.00619393  0.00438539 -0.00104605]
#
# Debug: Returns for IYW, Forecast Period 27w: [0.01288489 0.0099206  0.01377878 0.01241855]
#
# Debug: Returns for IYW, Forecast Period 28w: [ 0.00816741  0.00095319  0.01612605 -0.02155854  0.00975025]
#
# Debug: Returns for IYW, Forecast Period 29w: [ 0.00782037 -0.00011753 -0.03549172 -0.00182793 -0.00858158]
#
# Debug: Returns for IYW, Forecast Period 30w: [ 0.02155721  0.00078284 -0.04128522 -0.00699918  0.01230543]
#
# Debug: Returns for IYW, Forecast Period 31w: [-0.00146179 -0.0167072   0.03736739 -0.0288638  -0.02362466]
#
# Debug: Returns for IYW, Forecast Period 32w: [-0.03432429  0.0118117  -0.00868792  0.03652428  0.00929292]
#
# Debug: Returns for IYW, Forecast Period 33w: [0.00896711 0.03040313 0.00639083 0.02591541 0.00423057]
#
# Debug: Returns for IYW, Forecast Period 34w: [ 0.0143044  -0.0003984   0.00871757 -0.0176171   0.01617527]
#
# Debug: Returns for IYW, Forecast Period 35w: [-0.00673125  0.00675765 -0.00975217 -0.0013041   0.01255509]
#
# Debug: Returns for IYW, Forecast Period 36w: [-0.0411757  -0.00184621  0.00180187 -0.02223391]
#
# Debug: Returns for IYW, Forecast Period 37w: [0.01424521 0.01362697 0.03020624 0.01174368 0.00653461]
#
# Debug: Returns for IYW, Forecast Period 38w: [-0.00313661  0.00323971 -0.00147444  0.03342612 -0.0004109 ]
#
# Debug: Returns for IYW, Forecast Period 39w: [ 0.00166135  0.01003331  0.00443116  0.01241286 -0.00660234]
#
# Debug: Returns for IYW, Forecast Period 40w: [ 0.00656845 -0.02034269  0.00898983  0.00544952  0.01559621]
#
# Debug: Returns for IYW, Forecast Period 41w: [-0.00570457  0.01803704  0.01035408  0.00186026  0.00361372]
#
# Debug: Returns for IYW, Forecast Period 42w: [ 0.01576656 -0.01513814  0.00121487  0.00554661  0.00467861]
#
# Debug: Returns for IYW, Forecast Period 43w: [ 0.0096627   0.00121752 -0.01497112  0.00485996  0.009409  ]
#
# Debug: Returns for IYW, Forecast Period 44w: [ 0.00430098  0.01617527 -0.01090552 -0.0311389   0.00967319]
#
# Debug: Returns for IYW, Forecast Period 45w: [0.00079089 0.01498654 0.0303267  0.02198288 0.00121606]
#
# Debug: Returns for IYW, Forecast Period 46w: [-0.00185419  0.00623327 -0.00204538 -0.00246777 -0.02221784]
#
# Debug: Returns for IYW, Forecast Period 47w: [ 0.00689669  0.01506978 -0.00053258  0.0096627   0.00156042]
#
# Debug: Returns for IYW, Forecast Period 48w: [ 0.00263693  0.00594949 -0.01090552  0.01003406]
#
# Debug: Returns for XLK, Forecast Period 1w: [-0.0268153  -0.0102829  -0.00730343 -0.00020264]
#
# Debug: Returns for XLK, Forecast Period 2w: [0.02447443 0.00169094 0.0083206  0.00508714 0.00295791]
#
# Debug: Returns for XLK, Forecast Period 3w: [ 0.00224792 -0.0049948   0.02003052  0.02252478]
#
# Debug: Returns for XLK, Forecast Period 4w: [ 0.00415516  0.00394052  0.00658321  0.00394052 -0.01182111]
#
# Debug: Returns for XLK, Forecast Period 5w: [ 0.00871278 -0.00863449 -0.02210913  0.01217685  0.01026616]
#
# Debug: Returns for XLK, Forecast Period 6w: [ 0.00215964 -0.00484885  0.01301926  0.00312444  0.01354144]
#
# Debug: Returns for XLK, Forecast Period 7w: [-0.00784998 -0.01710857  0.01047393 -0.0021738  -0.00913919]
#
# Debug: Returns for XLK, Forecast Period 8w: [-0.0102829  -0.00630636  0.03161941 -0.0021738 ]
#
# Debug: Returns for XLK, Forecast Period 9w: [ 0.00101046  0.00074341 -0.00477155  0.01121035  0.01807042]
#
# Debug: Returns for XLK, Forecast Period 10w: [-2.4953139e-05 -2.4891876e-02  7.9653114e-03  1.5609854e-02
#  -1.5091460e-02]
#
# Debug: Returns for XLK, Forecast Period 11w: [-2.7247425e-03  2.0238295e-02 -1.0543114e-02 -2.4953139e-05
#  -1.5233234e-02]
#
# Debug: Returns for XLK, Forecast Period 12w: [0.00485839 0.00512488 0.01121035 0.00074341 0.00036028]
#
# Debug: Returns for XLK, Forecast Period 13w: [-0.00648692 -0.00402508  0.00512488 -0.0021738 ]
#
# Debug: Returns for XLK, Forecast Period 14w: [ 0.00262422 -0.00966522  0.00262422 -0.01609582  0.01121035]
#
# Debug: Returns for XLK, Forecast Period 15w: [-0.00131559  0.00508714 -0.01236969  0.01985106 -0.01609582]
#
# Debug: Returns for XLK, Forecast Period 16w: [-0.0193412   0.00113862 -0.01455531 -0.01151987 -0.02114927]
#
# Debug: Returns for XLK, Forecast Period 17w: [ 0.00891551  0.0148821   0.00450046 -0.0021738   0.01121035]
#
# Debug: Returns for XLK, Forecast Period 18w: [ 0.00427696 -0.02260099 -0.0102829   0.01387787  0.02729083]
#
# Debug: Returns for XLK, Forecast Period 19w: [ 0.01146163 -0.00333553  0.00262422 -0.00020264  0.00372939]
#
# Debug: Returns for XLK, Forecast Period 20w: [ 0.00477107  0.00882204  0.02273256 -0.00350379 -0.0021738 ]
#
# Debug: Returns for XLK, Forecast Period 21w: [ 0.01146163  0.00148316  0.00215964 -0.00840206  0.00811283]
#
# Debug: Returns for XLK, Forecast Period 22w: [ 0.00394052 -0.00651413 -0.02397619  0.00148316]
#
# Debug: Returns for XLK, Forecast Period 23w: [ 0.00224792  0.00170264  0.02107536 -0.00360318  0.00215964]
#
# Debug: Returns for XLK, Forecast Period 24w: [0.00235766 0.01786265 0.02107536 0.00775754 0.00352162]
#
# Debug: Returns for XLK, Forecast Period 25w: [ 0.01480981  0.00093085 -0.01162921 -0.00198371]
#
# Debug: Returns for XLK, Forecast Period 26w: [-0.02509965  0.01786265 -0.00152336  0.00023152 -0.00088851]
#
# Debug: Returns for XLK, Forecast Period 27w: [0.00726728 0.00465062 0.01333367 0.002788  ]
#
# Debug: Returns for XLK, Forecast Period 28w: [ 0.00658321 -0.00102521  0.01387787 -0.02641425  0.00882204]
#
# Debug: Returns for XLK, Forecast Period 29w: [ 1.7279555e-03 -3.3954047e-03 -3.9911825e-02 -2.4953139e-05
#  -1.5923625e-02]
#
# Debug: Returns for XLK, Forecast Period 30w: [ 0.0235272  -0.00398287 -0.04378968 -0.01065709  0.01242829]
#
# Debug: Returns for XLK, Forecast Period 31w: [-0.0043991  -0.02636921  0.04134716 -0.03780016 -0.02893719]
#
# Debug: Returns for XLK, Forecast Period 32w: [-0.03519109  0.01363948 -0.01599449  0.03586001  0.00429269]
#
# Debug: Returns for XLK, Forecast Period 33w: [0.007824   0.03005107 0.00526368 0.02883927 0.00148316]
#
# Debug: Returns for XLK, Forecast Period 34w: [ 0.01627401 -0.00371156  0.00573188 -0.02397619  0.01590587]
#
# Debug: Returns for XLK, Forecast Period 35w: [-0.01283579  0.00586903 -0.01424203 -0.00934696  0.01301926]
#
# Debug: Returns for XLK, Forecast Period 36w: [-0.04691336 -0.00262717 -0.00147262 -0.02692927]
#
# Debug: Returns for XLK, Forecast Period 37w: [0.01652545 0.01467433 0.03358708 0.00802189 0.00487937]
#
# Debug: Returns for XLK, Forecast Period 38w: [-0.00409589 -0.00222113 -0.00934696  0.02883927 -0.0049948 ]
#
# Debug: Returns for XLK, Forecast Period 39w: [-0.00041041  0.00658321  0.002788    0.01281148 -0.009602  ]
#
# Debug: Returns for XLK, Forecast Period 40w: [ 0.002788   -0.02493784  0.00714952  0.00394052  0.01121035]
#
# Debug: Returns for XLK, Forecast Period 41w: [-0.00705833  0.01807042  0.01121035 -0.00041041  0.00152018]
#
# Debug: Returns for XLK, Forecast Period 42w: [ 0.01271558 -0.02280876  0.002788    0.002788    0.0032284 ]
#
# Debug: Returns for XLK, Forecast Period 43w: [ 0.0045633  -0.00091934 -0.01444133  0.00299577  0.00491711]
#
# Debug: Returns for XLK, Forecast Period 44w: [-0.00041041  0.01333367 -0.01609582 -0.03252207  0.00747505]
#
# Debug: Returns for XLK, Forecast Period 45w: [-0.00081744  0.01388544  0.02910793  0.01727437 -0.00131559]
#
# Debug: Returns for XLK, Forecast Period 46w: [-0.00539985  0.00126576 -0.00350379 -0.0033954  -0.02489188]
#
# Debug: Returns for XLK, Forecast Period 47w: [ 0.00316568  0.00803177 -0.00091934  0.00996618  0.00043929]
#
# Debug: Returns for XLK, Forecast Period 48w: [-0.00020264  0.00508714 -0.01385754  0.0093863 ]
#
# Debug: Returns for VGT, Forecast Period 1w: [-0.02442194 -0.01180725 -0.00426407  0.00331717]
#
# Debug: Returns for VGT, Forecast Period 2w: [0.03033014 0.0064379  0.01152657 0.00671912 0.00534567]
#
# Debug: Returns for VGT, Forecast Period 3w: [ 0.00456571 -0.00386249  0.02689391  0.02858594]
#
# Debug: Returns for VGT, Forecast Period 4w: [ 0.00961831  0.00729106  0.00782924  0.00543274 -0.00906055]
#
# Debug: Returns for VGT, Forecast Period 5w: [ 0.01379366 -0.00833283 -0.01903188  0.0153797   0.01259049]
#
# Debug: Returns for VGT, Forecast Period 6w: [0.003575   0.00138355 0.0153797  0.00818788 0.02279913]
#
# Debug: Returns for VGT, Forecast Period 7w: [-0.00462708 -0.0179705   0.01571785  0.00405848 -0.00914302]
#
# Debug: Returns for VGT, Forecast Period 8w: [-0.01057043 -0.00813568  0.03743219 -0.00103779]
#
# Debug: Returns for VGT, Forecast Period 9w: [ 0.0072963   0.00465419 -0.00291737  0.01270045  0.02541276]
#
# Debug: Returns for VGT, Forecast Period 10w: [ 0.00494564 -0.02212455  0.01319575  0.02598187 -0.01463579]
#
# Debug: Returns for VGT, Forecast Period 11w: [-0.00314348  0.02705162 -0.00914302 -0.0029792  -0.01166341]
#
# Debug: Returns for VGT, Forecast Period 12w: [0.00942765 0.00729106 0.01731626 0.00581966 0.00479114]
#
# Debug: Returns for VGT, Forecast Period 13w: [-0.00322445 -0.00110156  0.00703115  0.00746509]
#
# Debug: Returns for VGT, Forecast Period 14w: [ 0.00522165 -0.0101332   0.0049883  -0.01447389  0.01464931]
#
# Debug: Returns for VGT, Forecast Period 15w: [ 0.00926141  0.00560153 -0.00872193  0.0258536  -0.01340753]
#
# Debug: Returns for VGT, Forecast Period 16w: [-0.01461026  0.00675742 -0.01326    -0.00841086 -0.02289685]
#
# Debug: Returns for VGT, Forecast Period 17w: [0.01643694 0.02681297 0.00806208 0.00693443 0.02725325]
#
# Debug: Returns for VGT, Forecast Period 18w: [ 0.01051528 -0.01775404 -0.00739402  0.02018605  0.03230176]
#
# Debug: Returns for VGT, Forecast Period 19w: [0.02266299 0.00365867 0.00898034 0.00212422 0.01435566]
#
# Debug: Returns for VGT, Forecast Period 20w: [ 8.0706626e-03  1.9169584e-02  2.9389497e-02 -3.1434793e-03
#   6.5999273e-05]
#
# Debug: Returns for VGT, Forecast Period 21w: [0.01487312 0.00420541 0.00331717 0.00331717 0.01267897]
#
# Debug: Returns for VGT, Forecast Period 22w: [ 0.01162387 -0.00109368 -0.02212455  0.00230734]
#
# Debug: Returns for VGT, Forecast Period 23w: [ 0.00828308  0.00532319  0.03033014 -0.0019687   0.00312109]
#
# Debug: Returns for VGT, Forecast Period 24w: [0.00815331 0.01610738 0.02845798 0.01266902 0.00698659]
#
# Debug: Returns for VGT, Forecast Period 25w: [ 0.01453935  0.0071179  -0.01243378 -0.00362049]
#
# Debug: Returns for VGT, Forecast Period 26w: [-0.01682111  0.02341564  0.0051593   0.0051593   0.00283043]
#
# Debug: Returns for VGT, Forecast Period 27w: [0.01259049 0.00964521 0.01372417 0.00818788]
#
# Debug: Returns for VGT, Forecast Period 28w: [ 0.00964521 -0.00139732  0.01610738 -0.01748083  0.01201033]
#
# Debug: Returns for VGT, Forecast Period 29w: [ 0.00828308  0.0043151  -0.03224122 -0.00498272 -0.00871885]
#
# Debug: Returns for VGT, Forecast Period 30w: [ 0.02668137  0.00126753 -0.03894046 -0.00686142  0.01573651]
#
# Debug: Returns for VGT, Forecast Period 31w: [ 0.00011813 -0.01737992  0.04159488 -0.03867128 -0.02217651]
#
# Debug: Returns for VGT, Forecast Period 32w: [-0.03942124  0.01287543 -0.01243827  0.04235553  0.01230308]
#
# Debug: Returns for VGT, Forecast Period 33w: [0.01168047 0.03734145 0.01078981 0.03517155 0.00546105]
#
# Debug: Returns for VGT, Forecast Period 34w: [ 0.01610738 -0.00366234  0.01040985 -0.01914184  0.02535623]
#
# Debug: Returns for VGT, Forecast Period 35w: [-0.00800178  0.00934695 -0.01166341 -0.00186028  0.01245992]
#
# Debug: Returns for VGT, Forecast Period 36w: [-0.0426041  -0.00139732 -0.00208567 -0.02323422]
#
# Debug: Returns for VGT, Forecast Period 37w: [0.01631906 0.01237144 0.03447165 0.01067793 0.01061499]
#
# Debug: Returns for VGT, Forecast Period 38w: [-0.00513618  0.0080748  -0.00106684  0.03495461 -0.00213399]
# Debug: Returns for VGT, Forecast Period 39w: [ 0.00283043  0.01375789  0.0038658   0.01475047 -0.00415621]
#
# Debug: Returns for VGT, Forecast Period 40w: [ 0.00581966 -0.02407729  0.00952177  0.008585    0.0153797 ]
#
# Debug: Returns for VGT, Forecast Period 41w: [-0.00559641  0.02701117  0.01353912  0.00394955  0.00778531]
#
# Debug: Returns for VGT, Forecast Period 42w: [ 0.01475047 -0.01651395  0.0069344   0.00698659  0.00815331]
#
# Debug: Returns for VGT, Forecast Period 43w: [ 0.00881144  0.00246007 -0.01413865  0.00664338  0.00782924]
#
# Debug: Returns for VGT, Forecast Period 44w: [ 0.00675771  0.01379366 -0.01166341 -0.03020691  0.01010498]
#
# Debug: Returns for VGT, Forecast Period 45w: [0.00219455 0.02417292 0.03732224 0.02705162 0.00138355]
#
# Debug: Returns for VGT, Forecast Period 46w: [-0.00322445  0.00483949 -0.00311449 -0.00322445 -0.02212455]
#
# Debug: Returns for VGT, Forecast Period 47w: [0.00606922 0.01453935 0.00414944 0.01282476 0.00684591]
#
# Debug: Returns for VGT, Forecast Period 48w: [ 0.00279514  0.00611127 -0.00906055  0.01639856]
#
# Debug: Returns for FTEC, Forecast Period 1w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 2w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 3w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 4w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 5w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 6w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 7w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 8w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 9w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 10w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 11w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 12w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 13w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 14w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 15w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 16w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 17w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 18w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 19w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 20w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 21w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 22w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 23w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 24w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 25w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 26w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 27w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 28w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 29w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 30w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 31w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 32w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 33w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 34w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 35w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 36w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 37w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 38w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 39w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 40w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 41w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 42w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 43w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 44w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 45w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 46w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 47w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 48w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for IGM, Forecast Period 1w: [-0.0280139  -0.01130218 -0.00507506  0.00118798]
#
# Debug: Returns for IGM, Forecast Period 2w: [0.02642782 0.0023095  0.00796697 0.00365767 0.00023481]
#
# Debug: Returns for IGM, Forecast Period 3w: [ 0.00039435 -0.00714029  0.01493375  0.02337625]
#
# Debug: Returns for IGM, Forecast Period 4w: [ 0.00269955  0.00302499  0.00759073  0.00262018 -0.01021126]
#
# Debug: Returns for IGM, Forecast Period 5w: [ 0.01089045 -0.00893395 -0.0265019   0.00970406  0.02642782]
#
# Debug: Returns for IGM, Forecast Period 6w: [-0.00019653 -0.00694482  0.01294825  0.00365767  0.01216121]
#
# Debug: Returns for IGM, Forecast Period 7w: [-0.00669212 -0.01928974  0.01493375 -0.00225911 -0.01301594]
#
# Debug: Returns for IGM, Forecast Period 8w: [-0.01548875 -0.01169881  0.04170076 -0.00336824]
#
# Debug: Returns for IGM, Forecast Period 9w: [-0.00053272  0.00023481 -0.00814229  0.01032802  0.01950443]
#
# Debug: Returns for IGM, Forecast Period 10w: [-0.00035452 -0.02170686  0.01043177  0.01950443 -0.02107126]
#
# Debug: Returns for IGM, Forecast Period 11w: [-0.00881153  0.02077827 -0.01039652 -0.00703977 -0.01432201]
#
# Debug: Returns for IGM, Forecast Period 12w: [0.00889363 0.00035722 0.0119406  0.00128641 0.00193814]
#
# Debug: Returns for IGM, Forecast Period 13w: [-0.00620467 -0.00521247 -0.0007422  -0.00343019]
#
# Debug: Returns for IGM, Forecast Period 14w: [ 0.00370675 -0.00757469  0.00383181 -0.01711619  0.01267863]
#
# Debug: Returns for IGM, Forecast Period 15w: [-0.00051107  0.00374707 -0.00911228  0.01645501 -0.01771573]
#
# Debug: Returns for IGM, Forecast Period 16w: [-0.02073054  0.00219424 -0.0133673  -0.00521427 -0.02861815]
#
# Debug: Returns for IGM, Forecast Period 17w: [ 0.01030446  0.01831636  0.00019498 -0.00949633  0.02392199]
#
# Debug: Returns for IGM, Forecast Period 18w: [-0.00388308 -0.01979373 -0.00809188  0.01449943  0.01977566]
#
# Debug: Returns for IGM, Forecast Period 19w: [ 0.01522141 -0.00117949 -0.00050552 -0.00115276  0.00251225]
#
# Debug: Returns for IGM, Forecast Period 20w: [ 0.0015894   0.00701645  0.02180013 -0.00504669 -0.00264392]
#
# Debug: Returns for IGM, Forecast Period 21w: [ 0.00877122 -0.00250797 -0.00019653 -0.00480774  0.00693532]
#
# Debug: Returns for IGM, Forecast Period 22w: [ 0.00625983 -0.00694482 -0.02555133 -0.00215768]
#
# Debug: Returns for IGM, Forecast Period 23w: [ 0.003264    0.00081663  0.02496287 -0.00405843 -0.00280011]
#
# Debug: Returns for IGM, Forecast Period 24w: [0.0039128  0.00857724 0.01596752 0.00319514 0.00428863]
#
# Debug: Returns for IGM, Forecast Period 25w: [ 0.00799171  0.00083292 -0.01117576 -0.00533489]
#
# Debug: Returns for IGM, Forecast Period 26w: [-0.01607482  0.01237538 -0.00119842  0.00359328 -0.00480774]
#
# Debug: Returns for IGM, Forecast Period 27w: [0.0047314  0.00535298 0.00736247 0.00881523]
#
# Debug: Returns for IGM, Forecast Period 28w: [ 0.00083292 -0.00463886  0.00855705 -0.02286739  0.00373769]
#
# Debug: Returns for IGM, Forecast Period 29w: [ 0.00334778 -0.00186232 -0.04038062 -0.00379547 -0.01049791]
#
# Debug: Returns for IGM, Forecast Period 30w: [ 0.01864039 -0.00155457 -0.04342056 -0.00926847  0.01174351]
#
# Debug: Returns for IGM, Forecast Period 31w: [-0.0034955  -0.01560756  0.03175141 -0.02569775 -0.02918941]
#
# Debug: Returns for IGM, Forecast Period 32w: [-0.03260926  0.01168451 -0.00914555  0.03681382  0.00684657]
#
# Debug: Returns for IGM, Forecast Period 33w: [0.00115841 0.02613933 0.00101539 0.02604621 0.00089774]
#
# Debug: Returns for IGM, Forecast Period 34w: [ 0.01109505 -0.00132978  0.00617921 -0.01916733  0.01045044]
#
# Debug: Returns for IGM, Forecast Period 35w: [-0.01095653  0.00238022 -0.01400333 -0.00015948  0.00889363]
#
# Debug: Returns for IGM, Forecast Period 36w: [-0.04067953 -0.00323944 -0.0014557  -0.02799596]
#
# Debug: Returns for IGM, Forecast Period 37w: [0.01041857 0.00961432 0.02297032 0.00808939 0.00485382]
#
# Debug: Returns for IGM, Forecast Period 38w: [-0.00155457  0.00097475 -0.00500377  0.03072307 -0.00117949]
#
# Debug: Returns for IGM, Forecast Period 39w: [-0.00066886  0.00564948 -0.00053272  0.00970406 -0.00870563]
#
# Debug: Returns for IGM, Forecast Period 40w: [ 0.00175803 -0.01782492  0.00371875  0.00345785  0.01110462]
#
# Debug: Returns for IGM, Forecast Period 41w: [-0.01151896  0.01452525  0.00600555 -0.00197842  0.00262916]
#
# Debug: Returns for IGM, Forecast Period 42w: [ 0.00796697 -0.01856779 -0.00168442 -0.00085198  0.00384016]
#
# Debug: Returns for IGM, Forecast Period 43w: [ 0.00161703 -0.00157811 -0.01686678  0.00165745  0.00442949]
#
# Debug: Returns for IGM, Forecast Period 44w: [ 0.00137026  0.0133196  -0.01211411 -0.02810225  0.00591466]
#
# Debug: Returns for IGM, Forecast Period 45w: [-0.00289247  0.01228092  0.02944737  0.01950443 -0.00386276]
#
# Debug: Returns for IGM, Forecast Period 46w: [-0.00358972  0.00175803 -0.00580282 -0.00835535 -0.02379777]
#
# Debug: Returns for IGM, Forecast Period 47w: [ 0.00561367  0.00915181 -0.0012922   0.00442949 -0.00066886]
#
# Debug: Returns for IGM, Forecast Period 48w: [ 0.00099891  0.00173945 -0.01017388  0.00724695]
#
# Debug: Returns for IXN, Forecast Period 1w: [-0.02784162 -0.01135639 -0.00526613  0.00081999]
#
# Debug: Returns for IXN, Forecast Period 2w: [ 0.02407856 -0.00054723  0.00868966  0.0041876   0.00402659]
#
# Debug: Returns for IXN, Forecast Period 3w: [ 3.0897474e-05 -4.8046163e-03  2.1219410e-02  2.3111852e-02]
#
# Debug: Returns for IXN, Forecast Period 4w: [ 0.0045952   0.00436043  0.00804607  0.00501079 -0.00888609]
#
# Debug: Returns for IXN, Forecast Period 5w: [ 0.00887999 -0.00695099 -0.01954983  0.01319894  0.01029733]
#
# Debug: Returns for IXN, Forecast Period 6w: [ 0.00254326 -0.00218349  0.01360978  0.00547494  0.01203478]
#
# Debug: Returns for IXN, Forecast Period 7w: [-0.00771513 -0.0170658   0.01199651 -0.00048422 -0.00862832]
#
# Debug: Returns for IXN, Forecast Period 8w: [-0.00993403 -0.00525937  0.03118985  0.00036075]
#
# Debug: Returns for IXN, Forecast Period 9w: [ 0.00114569 -0.00046368 -0.00419941  0.00947668  0.01903136]
#
# Debug: Returns for IXN, Forecast Period 10w: [ 0.00259824 -0.02188523  0.01100181  0.01745803 -0.0141799 ]
#
# Debug: Returns for IXN, Forecast Period 11w: [-0.00674588  0.02197782 -0.00974822 -0.00080662 -0.01517651]
#
# Debug: Returns for IXN, Forecast Period 12w: [0.00603125 0.00400856 0.01512892 0.00291874 0.00236762]
#
# Debug: Returns for IXN, Forecast Period 13w: [-0.00544563 -0.00520572  0.00221664 -0.00218987]
#
# Debug: Returns for IXN, Forecast Period 14w: [ 0.00332976 -0.00780654  0.00257382 -0.01628666  0.01214181]
#
# Debug: Returns for IXN, Forecast Period 15w: [-0.00166232  0.0049251  -0.01102378  0.02103779 -0.01705799]
#
# Debug: Returns for IXN, Forecast Period 16w: [-0.01711723  0.00191221 -0.01706793 -0.01124366 -0.02608306]
#
# Debug: Returns for IXN, Forecast Period 17w: [0.0085572  0.01856788 0.00696429 0.00086275 0.01693615]
#
# Debug: Returns for IXN, Forecast Period 18w: [ 0.00554514 -0.02009562 -0.00867489  0.01666768  0.02702748]
#
# Debug: Returns for IXN, Forecast Period 19w: [ 0.01468367 -0.00292088  0.00314102 -0.0022354   0.00494347]
#
# Debug: Returns for IXN, Forecast Period 20w: [ 0.00367028  0.01085002  0.02228012 -0.0035034  -0.00355276]
#
# Debug: Returns for IXN, Forecast Period 21w: [0.01275721 0.0017417  0.00140027 0.00257542 0.01009258]
#
# Debug: Returns for IXN, Forecast Period 22w: [ 0.01046238 -0.00676216 -0.01924742 -0.00237954]
#
# Debug: Returns for IXN, Forecast Period 23w: [ 0.00974435  0.0024628   0.02559586 -0.00130096  0.0012142 ]
#
# ...
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0065314024686813354, Risk Percentage: 0.1
# Rachev Ratio: 28.295833587646484, Sharpe Ratio: 17.40624831773914
# Sortino Ratio: 27.421350353497164, Volatility Clustering: -0.517890989780426
# Normalized Values -> Forecasted Mean: 0.08737641403111233, Rachev: 0.33548155587739514
# Sharpe: 0.2705830562354596, Sortino: -0.5450757013555274, Volatility Clustering: -0.38671810814323454
# Final Composite Score: 0.16605372146653952
# Calculated Score for IYW (47w): 0.16605372146653952
#
# Debug: ETF = XLK, Forecast Period = 47w
# Forecasted Values Mean: 0.004136715084314346
# Rachev Ratio: 10.84054183959961, Sharpe Ratio: 14.115256955093828
# Sortino Ratio: 10.06126397028555, Volatility Clustering: -0.7714488506317139
# Means and Stds: Mean Forecast = 0.006213184911757708, Std Forecast = 0.0036419059615582228
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.004136715084314346, Risk Percentage: 0.1
# Rachev Ratio: 10.84054183959961, Sharpe Ratio: 14.115256955093828
# Sortino Ratio: 10.06126397028555, Volatility Clustering: -0.7714488506317139
# Normalized Values -> Forecasted Mean: -0.5701586333570771, Rachev: 0.3320362157184594
# Sharpe: -0.08602604089377078, Sortino: -0.5451173200101236, Volatility Clustering: -0.9792842360510154
# Final Composite Score: -0.2552213797818019
# Calculated Score for XLK (47w): -0.2552213797818019
#
# Debug: ETF = VGT, Forecast Period = 47w
# Forecasted Values Mean: 0.008885735645890236
# Rachev Ratio: -3.503932476043701, Sharpe Ratio: 33.34749928311774
# Sortino Ratio: 888573.5645890236, Volatility Clustering: -0.8169704675674438
# Means and Stds: Mean Forecast = 0.006213184911757708, Std Forecast = 0.0036419059615582228
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.008885735645890236, Risk Percentage: 0.1
# Rachev Ratio: -3.503932476043701, Sharpe Ratio: 33.34749928311774
# Sortino Ratio: 888573.5645890236, Volatility Clustering: -0.8169704675674438
# Normalized Values -> Forecasted Mean: 0.733830973131257, Rachev: 0.3292048748690714
# Sharpe: 1.997963801867278, Sortino: 1.585103504659774, Volatility Clustering: -1.0856685074482544
# Final Composite Score: 5.369646299619656
# Calculated Score for VGT (47w): 5.369646299619656
#
# Debug: ETF = FTEC, Forecast Period = 47w
# Forecasted Values Mean: 0.001885635545477271
# Rachev Ratio: -1.0, Sharpe Ratio: 0
# Sortino Ratio: 188563.5545477271, Volatility Clustering: 0.800000011920929
# Means and Stds: Mean Forecast = 0.006213184911757708, Std Forecast = 0.0036419059615582228
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.001885635545477271, Risk Percentage: 0.1
# Rachev Ratio: -1.0, Sharpe Ratio: 0
# Sortino Ratio: 188563.5545477271, Volatility Clustering: 0.800000011920929
# Normalized Values -> Forecasted Mean: -1.1882617953818746, Rachev: 0.32969910058179924
# Sharpe: -1.615543588596189, Sortino: -0.09308369894164777, Volatility Clustering: 2.6932003370632676
# Final Composite Score: -5.623059330041158
# Calculated Score for FTEC (47w): -5.623059330041158
#
# Debug: ETF = IGM, Forecast Period = 47w
# Forecasted Values Mean: 0.0034467806108295918
# Rachev Ratio: 7.082330703735352, Sharpe Ratio: 12.364191123680182
# Sortino Ratio: 5.296808927467499, Volatility Clustering: -0.17415593564510345
# Means and Stds: Mean Forecast = 0.006213184911757708, Std Forecast = 0.0036419059615582228
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0034467806108295918, Risk Percentage: 0.1
# Rachev Ratio: 7.082330703735352, Sharpe Ratio: 12.364191123680182
# Sortino Ratio: 5.296808927467499, Volatility Clustering: -0.17415593564510345
# Normalized Values -> Forecasted Mean: -0.7596013554756732, Rachev: 0.3312943952600222
# Sharpe: -0.275770083446448, Sortino: -0.5451287422003355, Volatility Clustering: 0.4165926209001912
# Final Composite Score: -2.03022224154865
# Calculated Score for IGM (47w): -2.03022224154865
#
# Debug: ETF = IXN, Forecast Period = 47w
# Forecasted Values Mean: 0.004556558094918728
# Rachev Ratio: 19.543630599975586, Sharpe Ratio: 23.52786488103799
# Sortino Ratio: 27.853537033706495, Volatility Clustering: -0.35265764594078064
# Means and Stds: Mean Forecast = 0.006213184911757708, Std Forecast = 0.0036419059615582228
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.004556558094918728, Risk Percentage: 0.1
# Rachev Ratio: 19.543630599975586, Sharpe Ratio: 23.52786488103799
# Sortino Ratio: 27.853537033706495, Volatility Clustering: -0.35265764594078064
# Normalized Values -> Forecasted Mean: -0.45487782648619346, Rachev: 0.33375403076277155
# Sharpe: 0.9339163546415118, Sortino: -0.5450746652415491, Volatility Clustering: -0.0005668666412444571
# Final Composite Score: -0.09884467352126351
# Calculated Score for IXN (47w): -0.09884467352126351
# Scores calculated for 47w:
# {'ETF': 'SMH', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -2.203583756529036}
# {'ETF': 'SOXX', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -1.4457802113834632}
# {'ETF': 'PSI', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 4.258277776276337}
# {'ETF': 'XSD', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 1.8627340708203384}
# {'ETF': 'IYW', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 0.16605372146653952}
# {'ETF': 'XLK', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -0.2552213797818019}
# {'ETF': 'VGT', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 5.369646299619656}
# {'ETF': 'FTEC', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -5.623059330041158}
# {'ETF': 'IGM', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -2.03022224154865}
# {'ETF': 'IXN', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -0.09884467352126351}
#
# Debug: Forecast Period = 48w
# All Returns Means: [-0.0038749874, -0.0004162211, 0.0016484945, 0.0066166334, 0.00192874, 0.00010331534, 0.0040611066, 0.0018856355, -4.7143316e-05, 0.001642232]
# Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
# All Rachev Ratios: [ 1.0720086   1.0108865   1.083596    2.5840132   0.9200896   0.6773426
#   1.8098866  -1.          0.71230924  1.0708276 ]
# All Sharpe Ratios: [-5.95305786 -1.03490066  1.31536292  5.00856368  3.13161296 -0.4990553
#   6.43464392  0.         -1.06768477  2.72311083]
# All Sortino Ratios: [-4.18052966e-01 -4.68391103e-02  1.66345018e-01  7.44431784e-01
#   3.53717427e-01  1.49094514e-02  8.96435352e-01  1.88563555e+05
#  -9.26750258e-03  3.31561680e-01]
# All Volatility Clustering: [ 0.29951832  0.18131708  0.13777095 -0.14034504  0.2413851  -0.02915835
#   0.09194724  0.         -0.01573857  0.28367153]
# Mean Rachev = 0.9940959811210632, Std Rachev = 0.8587917685508728
# Mean Sharpe = 1.005859570883636, Std Sharpe = 3.36488118384532
# Mean Sortino = 18856.55877888607, Std Sortino = 56568.99859079668
# Mean Volatility Clustering = 0.10503682550042867, Std Volatility Clustering = 0.14114738074312425
#
# Debug: ETF = SMH, Forecast Period = 48w
# Forecasted Values Mean: -0.0038749873638153076
# Rachev Ratio: 1.0720086097717285, Sharpe Ratio: -5.953057858195927
# Sortino Ratio: -0.4180529663571194, Volatility Clustering: 0.29951831698417664
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.0038749873638153076, Risk Percentage: 0.1
# Rachev Ratio: 1.0720086097717285, Sharpe Ratio: -5.953057858195927
# Sortino Ratio: -0.4180529663571194, Volatility Clustering: 0.29951831698417664
# Normalized Values -> Forecasted Mean: -1.9793486473993438, Rachev: 0.09072353811087389
# Sharpe: -2.068101970972428, Sortino: -0.33334471709946395, Volatility Clustering: 1.3778610462426972
# Final Composite Score: -5.76772873552502
# Calculated Score for SMH (48w): -5.76772873552502
#
# Debug: ETF = SOXX, Forecast Period = 48w
# Forecasted Values Mean: -0.00041622109711170197
# Rachev Ratio: 1.010886549949646, Sharpe Ratio: -1.0349006593097771
# Sortino Ratio: -0.04683911026917087, Volatility Clustering: 0.18131707608699799
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.00041622109711170197, Risk Percentage: 0.1
# Rachev Ratio: 1.010886549949646, Sharpe Ratio: -1.0349006593097771
# Sortino Ratio: -0.04683911026917087, Volatility Clustering: 0.18131707608699799
# Normalized Values -> Forecasted Mean: -0.6702840270448495, Rachev: 0.019551385152889105
# Sharpe: -0.6064880489469148, Sortino: -0.3333381549564999, Volatility Clustering: 0.5404297605854622
# Final Composite Score: -2.152495130049015
# Calculated Score for SOXX (48w): -2.152495130049015
#
# Debug: ETF = PSI, Forecast Period = 48w
# Forecasted Values Mean: 0.0016484945081174374
# Rachev Ratio: 1.0835959911346436, Sharpe Ratio: 1.3153629160203637
# Sortino Ratio: 0.16634501820659095, Volatility Clustering: 0.13777095079421997
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0016484945081174374, Risk Percentage: 0.1
# Rachev Ratio: 1.0835959911346436, Sharpe Ratio: 1.3153629160203637
# Sortino Ratio: 0.16634501820659095, Volatility Clustering: 0.13777095079421997
# Normalized Values -> Forecasted Mean: 0.11116404792084446, Rachev: 0.10421619331824862
# Sharpe: 0.09198046745389944, Sortino: -0.3333343863883126, Volatility Clustering: 0.23191449109650572
# Final Composite Score: -0.3725259814418993
# Calculated Score for PSI (48w): -0.3725259814418993
#
# Debug: ETF = XSD, Forecast Period = 48w
# Forecasted Values Mean: 0.006616633385419846
# Rachev Ratio: 2.5840132236480713, Sharpe Ratio: 5.00856368025837
# Sortino Ratio: 0.7444317839391156, Volatility Clustering: -0.14034503698349
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.006616633385419846, Risk Percentage: 0.1
# Rachev Ratio: 2.5840132236480713, Sharpe Ratio: 5.00856368025837
# Sortino Ratio: 0.7444317839391156, Volatility Clustering: -0.14034503698349
# Normalized Values -> Forecasted Mean: 1.9914920906644662, Rachev: 1.851341876613203
# Sharpe: 1.1895528783292713, Sortino: -0.3333241672439025, Volatility Clustering: -1.7384796218478593
# Final Composite Score: 4.401066235936374
# Calculated Score for XSD (48w): 4.401066235936374
#
# Debug: ETF = IYW, Forecast Period = 48w
# Forecasted Values Mean: 0.0019287399481981993
# Rachev Ratio: 0.920089602470398, Sharpe Ratio: 3.1316129598515183
# Sortino Ratio: 0.35371742674296747, Volatility Clustering: 0.2413851022720337
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0019287399481981993, Risk Percentage: 0.1
# Rachev Ratio: 0.920089602470398, Sharpe Ratio: 3.1316129598515183
# Sortino Ratio: 0.35371742674296747, Volatility Clustering: 0.2413851022720337
# Normalized Values -> Forecasted Mean: 0.21723059728695973, Rachev: -0.08617499666280436
# Sharpe: 0.6317469374122577, Sortino: -0.33333107410750146, Volatility Clustering: 0.9659992724891869
# Final Composite Score: -0.44173531223119056
# Calculated Score for IYW (48w): -0.44173531223119056
#
# Debug: ETF = XLK, Forecast Period = 48w
# Forecasted Values Mean: 0.0001033153384923935
# Rachev Ratio: 0.6773425936698914, Sharpe Ratio: -0.49905530438252355
# Sortino Ratio: 0.01490945135655587, Volatility Clustering: -0.029158351942896843
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0001033153384923935, Risk Percentage: 0.1
# Rachev Ratio: 0.6773425936698914, Sharpe Ratio: -0.49905530438252355
# Sortino Ratio: 0.01490945135655587, Volatility Clustering: -0.029158351942896843
# Normalized Values -> Forecasted Mean: -0.47365125764593635, Rachev: -0.3688360733793496
# Sharpe: -0.44724160782222816, Sortino: -0.3333370633946344, Volatility Clustering: -0.9507450101401369
# Final Composite Score: -0.2666013113847272
# Calculated Score for XLK (48w): -0.2666013113847272
#
# Debug: ETF = VGT, Forecast Period = 48w
# Forecasted Values Mean: 0.004061106592416763
# Rachev Ratio: 1.8098865747451782, Sharpe Ratio: 6.434643915076635
# Sortino Ratio: 0.8964353521011309, Volatility Clustering: 0.09194723516702652
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.004061106592416763, Risk Percentage: 0.1
# Rachev Ratio: 1.8098865747451782, Sharpe Ratio: 6.434643915076635
# Sortino Ratio: 0.8964353521011309, Volatility Clustering: 0.09194723516702652
# Normalized Values -> Forecasted Mean: 1.0242831017568212, Rachev: 0.949928275979402
# Sharpe: 1.6133658311986618, Sortino: -0.33332148019672214, Volatility Clustering: -0.09273703370984765
# Final Composite Score: 2.302071658870669
# Calculated Score for VGT (48w): 2.302071658870669
#
# Debug: ETF = FTEC, Forecast Period = 48w
# Forecasted Values Mean: 0.001885635545477271
# Rachev Ratio: -1.0, Sharpe Ratio: 0
# Sortino Ratio: 188563.5545477271, Volatility Clustering: 0
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.001885635545477271, Risk Percentage: 0.1
# Rachev Ratio: -1.0, Sharpe Ratio: 0
# Sortino Ratio: 188563.5545477271, Volatility Clustering: 0
# Normalized Values -> Forecasted Mean: 0.20091655750176754, Rachev: -2.3219784941240937
# Sharpe: -0.29892870295790724, Sortino: 2.9999999999367324, Volatility Clustering: -0.7441641318866914
# Final Composite Score: 3.8783498357796935
# Calculated Score for FTEC (48w): 3.8783498357796935
#
# Debug: ETF = IGM, Forecast Period = 48w
# Forecasted Values Mean: -4.714331589639187e-05
# Rachev Ratio: 0.7123092412948608, Sharpe Ratio: -1.0676847700963372
# Sortino Ratio: -0.009267502576811694, Volatility Clustering: -0.01573856547474861
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: -4.714331589639187e-05, Risk Percentage: 0.1
# Rachev Ratio: 0.7123092412948608, Sharpe Ratio: -1.0676847700963372
# Sortino Ratio: -0.009267502576811694, Volatility Clustering: -0.01573856547474861
# Normalized Values -> Forecasted Mean: -0.5305964492918321, Rachev: -0.3281199783976623
# Sharpe: -0.6162310707351804, Sortino: -0.3333374907833904, Volatility Clustering: -0.8556686052736023
# Final Composite Score: -0.5916844076970343
# Calculated Score for IGM (48w): -0.5916844076970343
#
# Debug: ETF = IXN, Forecast Period = 48w
# Forecasted Values Mean: 0.0016422319458797574
# Rachev Ratio: 1.070827603340149, Sharpe Ratio: 2.7231108296140363
# Sortino Ratio: 0.33156168045412726, Volatility Clustering: 0.2836715281009674
# Means and Stds: Mean Forecast = 0.0013547806302085519, Std Forecast = 0.0026421560905873775
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0016422319458797574, Risk Percentage: 0.1
# Rachev Ratio: 1.070827603340149, Sharpe Ratio: 2.7231108296140363
# Sortino Ratio: 0.33156168045412726, Volatility Clustering: 0.2836715281009674
# Normalized Values -> Forecasted Mean: 0.10879381000885621, Rachev: 0.08934834279452791
# Sharpe: 0.5103452870405685, Sortino: -0.33333146576630474, Volatility Clustering: 1.2655898324442858
# Final Composite Score: -0.9887170354406187
# Calculated Score for IXN (48w): -0.9887170354406187
# Scores calculated for 48w:
# {'ETF': 'SMH', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -5.76772873552502}
# {'ETF': 'SOXX', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -2.152495130049015}
# {'ETF': 'PSI', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.3725259814418993}
# {'ETF': 'XSD', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 4.401066235936374}
# {'ETF': 'IYW', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.44173531223119056}
# {'ETF': 'XLK', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.2666013113847272}
# {'ETF': 'VGT', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 2.302071658870669}
# {'ETF': 'FTEC', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 3.8783498357796935}
# {'ETF': 'IGM', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.5916844076970343}
# {'ETF': 'IXN', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.9887170354406187}

# %%
# Initialize an empty dictionary to hold DataFrames for each week
weekly_scores_dfs = {}

# Assuming weekly_scores is a dictionary with keys as week identifiers ('1w', '2w', ..., '48w') 
# and values as the respective scores
for week_key, scores in weekly_scores.items():
    # Convert scores for the current week into a DataFrame
    weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    
# Create DataFrame variables dynamically for 48 weeks
for week in range(1, 49):
    week_key = f'{week}w'
    globals()[f'df_scores_{week_key}'] = weekly_scores_dfs.get(week_key, pd.DataFrame())

# %%
# Initialize a dictionary to hold the top 2 ETFs for each week
top_etfs_weekly = {}

# Loop through the weekly DataFrames and select the top 2 ETFs for each week
for week_key, df_scores in weekly_scores_dfs.items():
    # Select the top 2 ETFs based on the 'Score' column
    top_etfs_weekly[week_key] = df_scores.nlargest(2, 'Score')
    
    # Print the results for the current week
    print(f"\nTop 2 ETFs for {week_key} forecast:")
    print(top_etfs_weekly[week_key])
# Out:
# Top 2 ETFs for 1w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   1w             0.1  9.109026
# 4   IYW   1w             0.1  1.180194
#
# Top 2 ETFs for 2w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT   2w             0.1  4.679091
# 4  IYW   2w             0.1  4.510107
#
# Top 2 ETFs for 3w forecast:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  2.292537
# 7  FTEC   3w             0.1  1.466232
#
# Top 2 ETFs for 4w forecast:
#    ETF Week  RiskPercentage     Score
# 4  IYW   4w             0.1  3.103157
# 6  VGT   4w             0.1  2.596620
#
# Top 2 ETFs for 5w forecast:
#    ETF Week  RiskPercentage     Score
# 4  IYW   5w             0.1  2.463862
# 0  SMH   5w             0.1  2.200688
#
# Top 2 ETFs for 6w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT   6w             0.1  5.039405
# 0  SMH   6w             0.1  2.990129
#
# Top 2 ETFs for 7w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   7w             0.1  3.211844
# 2   PSI   7w             0.1  2.735024
#
# Top 2 ETFs for 8w forecast:
#    ETF Week  RiskPercentage     Score
# 0  SMH   8w             0.1  2.566185
# 4  IYW   8w             0.1  1.844626
#
# Top 2 ETFs for 9w forecast:
#    ETF Week  RiskPercentage     Score
# 2  PSI   9w             0.1  3.115266
# 6  VGT   9w             0.1  1.850905
#
# Top 2 ETFs for 10w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  10w             0.1  2.612319
# 0   SMH  10w             0.1  2.403178
#
# Top 2 ETFs for 11w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  11w             0.1  3.004942
# 4   IYW  11w             0.1  2.725144
#
# Top 2 ETFs for 12w forecast:
#    ETF Week  RiskPercentage     Score
# 4  IYW  12w             0.1  5.188535
# 6  VGT  12w             0.1  4.326899
#
# Top 2 ETFs for 13w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  13w             0.1  3.811529
# 3   XSD  13w             0.1  3.347767
#
# Top 2 ETFs for 14w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  14w             0.1  3.641458
# 4   IYW  14w             0.1  1.915824
#
# Top 2 ETFs for 15w forecast:
#     ETF Week  RiskPercentage     Score
# 6   VGT  15w             0.1  4.907989
# 7  FTEC  15w             0.1  3.045445
#
# Top 2 ETFs for 16w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  16w             0.1  5.497780
# 6   VGT  16w             0.1  0.685563
#
# Top 2 ETFs for 17w forecast:
#     ETF Week  RiskPercentage     Score
# 1  SOXX  17w             0.1  5.108092
# 3   XSD  17w             0.1  3.280328
#
# Top 2 ETFs for 18w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  18w             0.1  3.702006
# 9  IXN  18w             0.1  1.647331
#
# Top 2 ETFs for 19w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  19w             0.1  9.152255
# 4  IYW  19w             0.1  1.021023
#
# Top 2 ETFs for 20w forecast:
#    ETF Week  RiskPercentage     Score
# 4  IYW  20w             0.1  6.095238
# 6  VGT  20w             0.1  2.759905
#
# Top 2 ETFs for 21w forecast:
#    ETF Week  RiskPercentage     Score
# 4  IYW  21w             0.1  3.805837
# 6  VGT  21w             0.1  3.784873
#
# Top 2 ETFs for 22w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  22w             0.1  5.810494
# 4   IYW  22w             0.1  1.839475
#
# Top 2 ETFs for 23w forecast:
#    ETF Week  RiskPercentage    Score
# 4  IYW  23w             0.1  6.48285
# 6  VGT  23w             0.1  2.06186
#
# Top 2 ETFs for 24w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  24w             0.1  4.112099
# 4  IYW  24w             0.1  3.202924
#
# Top 2 ETFs for 25w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  25w             0.1  2.425910
# 6   VGT  25w             0.1  1.851484
#
# Top 2 ETFs for 26w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  26w             0.1  4.014928
# 4  IYW  26w             0.1  2.890949
#
# Top 2 ETFs for 27w forecast:
#    ETF Week  RiskPercentage     Score
# 4  IYW  27w             0.1  6.102155
# 6  VGT  27w             0.1  4.317266
#
# Top 2 ETFs for 28w forecast:
#    ETF Week  RiskPercentage     Score
# 3  XSD  28w             0.1  4.668281
# 0  SMH  28w             0.1  1.108977
#
# Top 2 ETFs for 29w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  29w             0.1  5.081711
# 6   VGT  29w             0.1  1.011210
#
# Top 2 ETFs for 30w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  30w             0.1  4.545943
# 6   VGT  30w             0.1  3.172798
#
# Top 2 ETFs for 31w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  31w             0.1  4.527990
# 4   IYW  31w             0.1  1.770759
#
# Top 2 ETFs for 32w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI  32w             0.1  3.897198
# 1  SOXX  32w             0.1  1.637048
#
# Top 2 ETFs for 33w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  33w             0.1  4.153335
# 0  SMH  33w             0.1  2.603428
#
# Top 2 ETFs for 34w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  34w             0.1  3.312991
# 4  IYW  34w             0.1  2.331464
#
# Top 2 ETFs for 35w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  35w             0.1  3.888058
# 4   IYW  35w             0.1  2.228474
#
# Top 2 ETFs for 36w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  36w             0.1  5.666103
# 4   IYW  36w             0.1  0.277846
#
# Top 2 ETFs for 37w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  37w             0.1  2.905907
# 0  SMH  37w             0.1  2.874689
#
# Top 2 ETFs for 38w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  38w             0.1  3.650448
# 4  IYW  38w             0.1  3.067578
#
# Top 2 ETFs for 39w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  39w             0.1  3.027757
# 2  PSI  39w             0.1  1.933125
#
# Top 2 ETFs for 40w forecast:
#    ETF Week  RiskPercentage     Score
# 4  IYW  40w             0.1  3.251296
# 6  VGT  40w             0.1  2.932116
#
# Top 2 ETFs for 41w forecast:
#    ETF Week  RiskPercentage     Score
# 0  SMH  41w             0.1  3.126560
# 6  VGT  41w             0.1  3.113073
#
# Top 2 ETFs for 42w forecast:
#     ETF Week  RiskPercentage     Score
# 6   VGT  42w             0.1  2.384728
# 7  FTEC  42w             0.1  2.071877
#
# Top 2 ETFs for 43w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  43w             0.1  3.391468
# 4  IYW  43w             0.1  3.210078
#
# Top 2 ETFs for 44w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  44w             0.1  4.953757
# 4   IYW  44w             0.1  2.123451
#
# Top 2 ETFs for 45w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  45w             0.1  5.465419
# 4  IYW  45w             0.1  3.551635
#
# Top 2 ETFs for 46w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  46w             0.1  3.844901
# 4   IYW  46w             0.1  1.144777
#
# Top 2 ETFs for 47w forecast:
#    ETF Week  RiskPercentage     Score
# 6  VGT  47w             0.1  5.369646
# 2  PSI  47w             0.1  4.258278
#
# Top 2 ETFs for 48w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  48w             0.1  4.401066
# 7  FTEC  48w             0.1  3.878350

# %%
def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()

# %%
# Function to generate week ranges
def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []
    
    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)
    
    return week_ranges

# Function to gather ETF data for weeks
def gather_etf_data_for_weeks(tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date)
            if etf_data.empty:
                print(f"No data found for {ticker} in {week}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[week][ticker] = etf_data
            #print(f"Data for {ticker} in {week} gathered.")
    return etf_histories

# Function to initialize shares for the first week
def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]
    
    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)
        
        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]
            
            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st week: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares

# Function to manage ETF portfolio weekly
def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

# %%
# Generate Week Ranges
week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')
#print("Generated Week Ranges:", week_ranges)

# Assuming `tickers` is a list of ETF tickers
tickers = tickers

# Gather ETF Data
etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)
#print(f"ETF Histories Collected for {len(etf_histories)} weeks")

# Create a mapping between week numbers and date ranges
week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

# Debug: Print the week key mapping
print("Week Key Mapping:", week_key_mapping)

# Align `top_etfs_weekly` Keys with `etf_histories`
aligned_top_etfs_weekly = {}

for week_key, df_scores in weekly_scores_dfs.items():
    # Call the `select_top_etfs_weekly` function here
    forecast_period = week_key_mapping.get(week_key, None)
    if forecast_period:
        aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

# Portfolio initialization and management
ticker_shares = {}
ticker_shares_per_week = {}

for i, week_range in enumerate(etf_histories.keys()):
    current_week_key = week_range
    if i == 0:
        # First week initialization
        ticker_shares = initialize_shares_for_first_week(
            aligned_top_etfs_weekly[current_week_key],
            etf_histories,
            current_week_key
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()
    else:
        # Subsequent weeks' portfolio management
        prev_week_key = list(etf_histories.keys())[i - 1]
        ticker_shares = manage_etf_portfolio_weekly(
            aligned_top_etfs_weekly[prev_week_key],
            aligned_top_etfs_weekly[current_week_key],
            prev_week_key,
            current_week_key,
            ticker_shares,
            etf_histories
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()

print("\nFinal Ticker Shares per Week:")
for week, shares in ticker_shares_per_week.items():
    print(f"Week {week}: {shares}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Week Key Mapping: {'1w': '2024-01-01 to 2024-01-07', '2w': '2024-01-08 to 2024-01-14', '3w': '2024-01-15 to 2024-01-21', '4w': '2024-01-22 to 2024-01-28', '5w': '2024-01-29 to 2024-02-04', '6w': '2024-02-05 to 2024-02-11', '7w': '2024-02-12 to 2024-02-18', '8w': '2024-02-19 to 2024-02-25', '9w': '2024-02-26 to 2024-03-03', '10w': '2024-03-04 to 2024-03-10', '11w': '2024-03-11 to 2024-03-17', '12w': '2024-03-18 to 2024-03-24', '13w': '2024-03-25 to 2024-03-31', '14w': '2024-04-01 to 2024-04-07', '15w': '2024-04-08 to 2024-04-14', '16w': '2024-04-15 to 2024-04-21', '17w': '2024-04-22 to 2024-04-28', '18w': '2024-04-29 to 2024-05-05', '19w': '2024-05-06 to 2024-05-12', '20w': '2024-05-13 to 2024-05-19', '21w': '2024-05-20 to 2024-05-26', '22w': '2024-05-27 to 2024-06-02', '23w': '2024-06-03 to 2024-06-09', '24w': '2024-06-10 to 2024-06-16', '25w': '2024-06-17 to 2024-06-23', '26w': '2024-06-24 to 2024-06-30', '27w': '2024-07-01 to 2024-07-07', '28w': '2024-07-08 to 2024-07-14', '29w': '2024-07-15 to 2024-07-21', '30w': '2024-07-22 to 2024-07-28', '31w': '2024-07-29 to 2024-08-04', '32w': '2024-08-05 to 2024-08-11', '33w': '2024-08-12 to 2024-08-18', '34w': '2024-08-19 to 2024-08-25', '35w': '2024-08-26 to 2024-09-01', '36w': '2024-09-02 to 2024-09-08', '37w': '2024-09-09 to 2024-09-15', '38w': '2024-09-16 to 2024-09-22', '39w': '2024-09-23 to 2024-09-29', '40w': '2024-09-30 to 2024-10-06', '41w': '2024-10-07 to 2024-10-13', '42w': '2024-10-14 to 2024-10-20', '43w': '2024-10-21 to 2024-10-27', '44w': '2024-10-28 to 2024-11-03', '45w': '2024-11-04 to 2024-11-10', '46w': '2024-11-11 to 2024-11-17', '47w': '2024-11-18 to 2024-11-24', '48w': '2024-11-25 to 2024-12-01'}
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1  0.301510
# 1  SOXX   1w             0.1 -2.041216
# 2   PSI   1w             0.1 -3.666469
# 3   XSD   1w             0.1 -5.320238
# 4   IYW   1w             0.1  1.180194
# Top ETFs for 2024-01-01 to 2024-01-07: ['FTEC', 'IYW']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1 -0.089123
# 1  SOXX   2w             0.1 -1.622219
# 2   PSI   2w             0.1 -1.979150
# 3   XSD   2w             0.1 -3.725196
# 4   IYW   2w             0.1  4.510107
# Top ETFs for 2024-01-08 to 2024-01-14: ['VGT', 'IYW']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  2.292537
# 1  SOXX   3w             0.1  1.273678
# 2   PSI   3w             0.1  0.881517
# 3   XSD   3w             0.1 -1.454109
# 4   IYW   3w             0.1 -0.651226
# Top ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'FTEC']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1  0.947490
# 1  SOXX   4w             0.1 -1.655198
# 2   PSI   4w             0.1 -2.394401
# 3   XSD   4w             0.1 -4.239858
# 4   IYW   4w             0.1  3.103157
# Top ETFs for 2024-01-22 to 2024-01-28: ['IYW', 'VGT']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1  2.200688
# 1  SOXX   5w             0.1 -0.668067
# 2   PSI   5w             0.1 -1.159740
# 3   XSD   5w             0.1 -6.334050
# 4   IYW   5w             0.1  2.463862
# Top ETFs for 2024-01-29 to 2024-02-04: ['IYW', 'SMH']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  2.990129
# 1  SOXX   6w             0.1 -0.468359
# 2   PSI   6w             0.1 -0.789618
# 3   XSD   6w             0.1  0.121917
# 4   IYW   6w             0.1  1.003549
# Top ETFs for 2024-02-05 to 2024-02-11: ['VGT', 'SMH']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1  0.515901
# 1  SOXX   7w             0.1  0.841106
# 2   PSI   7w             0.1  2.735024
# 3   XSD   7w             0.1 -1.145093
# 4   IYW   7w             0.1 -0.155589
# Top ETFs for 2024-02-12 to 2024-02-18: ['FTEC', 'PSI']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1  2.566185
# 1  SOXX   8w             0.1  0.867818
# 2   PSI   8w             0.1 -1.638243
# 3   XSD   8w             0.1 -5.532460
# 4   IYW   8w             0.1  1.844626
# Top ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'IYW']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1  1.043494
# 1  SOXX   9w             0.1  1.185673
# 2   PSI   9w             0.1  3.115266
# 3   XSD   9w             0.1  0.953768
# 4   IYW   9w             0.1 -1.363214
# Top ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'VGT']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  2.403178
# 1  SOXX  10w             0.1  0.061400
# 2   PSI  10w             0.1 -1.956385
# 3   XSD  10w             0.1 -0.446522
# 4   IYW  10w             0.1  0.444692
# Top ETFs for 2024-03-04 to 2024-03-10: ['FTEC', 'SMH']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1 -0.779612
# 1  SOXX  11w             0.1 -2.486628
# 2   PSI  11w             0.1 -2.977632
# 3   XSD  11w             0.1 -4.505414
# 4   IYW  11w             0.1  2.725144
# Top ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1 -0.502269
# 1  SOXX  12w             0.1 -2.052007
# 2   PSI  12w             0.1 -0.001168
# 3   XSD  12w             0.1 -2.976262
# 4   IYW  12w             0.1  5.188535
# Top ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'VGT']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1 -1.572100
# 1  SOXX  13w             0.1  1.179877
# 2   PSI  13w             0.1  1.093969
# 3   XSD  13w             0.1  3.347767
# 4   IYW  13w             0.1  1.191772
# Top ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'XSD']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1 -0.306216
# 1  SOXX  14w             0.1 -1.791938
# 2   PSI  14w             0.1  0.644388
# 3   XSD  14w             0.1 -2.098853
# 4   IYW  14w             0.1  1.915824
# Top ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1 -1.684674
# 1  SOXX  15w             0.1 -1.888557
# 2   PSI  15w             0.1 -2.474737
# 3   XSD  15w             0.1 -1.104098
# 4   IYW  15w             0.1  2.795634
# Top ETFs for 2024-04-08 to 2024-04-14: ['VGT', 'FTEC']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1 -1.261367
# 1  SOXX  16w             0.1 -0.872435
# 2   PSI  16w             0.1 -0.629760
# 3   XSD  16w             0.1 -2.618991
# 4   IYW  16w             0.1  0.382009
# Top ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'VGT']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1 -0.567811
# 1  SOXX  17w             0.1  5.108092
# 2   PSI  17w             0.1  3.031287
# 3   XSD  17w             0.1  3.280328
# 4   IYW  17w             0.1 -1.627086
# Top ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'XSD']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1 -1.665669
# 1  SOXX  18w             0.1 -2.485586
# 2   PSI  18w             0.1 -2.231131
# 3   XSD  18w             0.1 -0.666170
# 4   IYW  18w             0.1  1.613992
# Top ETFs for 2024-04-29 to 2024-05-05: ['VGT', 'IXN']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1  0.401177
# 1  SOXX  19w             0.1 -1.354115
# 2   PSI  19w             0.1 -0.139067
# 3   XSD  19w             0.1 -1.761326
# 4   IYW  19w             0.1  1.021023
# Top ETFs for 2024-05-06 to 2024-05-12: ['VGT', 'IYW']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1 -0.156582
# 1  SOXX  20w             0.1  0.064892
# 2   PSI  20w             0.1 -1.259495
# 3   XSD  20w             0.1  0.359806
# 4   IYW  20w             0.1  6.095238
# Top ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'VGT']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  2.842632
# 1  SOXX  21w             0.1  1.107836
# 2   PSI  21w             0.1 -0.304920
# 3   XSD  21w             0.1 -2.935924
# 4   IYW  21w             0.1  3.805837
# Top ETFs for 2024-05-20 to 2024-05-26: ['IYW', 'VGT']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1 -0.999598
# 1  SOXX  22w             0.1 -2.369203
# 2   PSI  22w             0.1 -1.034586
# 3   XSD  22w             0.1  1.005958
# 4   IYW  22w             0.1  1.839475
# Top ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1  1.504824
# 1  SOXX  23w             0.1 -0.848768
# 2   PSI  23w             0.1 -1.493010
# 3   XSD  23w             0.1 -3.663653
# 4   IYW  23w             0.1  6.482850
# Top ETFs for 2024-06-03 to 2024-06-09: ['IYW', 'VGT']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1  0.162476
# 1  SOXX  24w             0.1 -0.487928
# 2   PSI  24w             0.1 -0.691351
# 3   XSD  24w             0.1 -2.250113
# 4   IYW  24w             0.1  3.202924
# Top ETFs for 2024-06-10 to 2024-06-16: ['VGT', 'IYW']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1 -0.909542
# 1  SOXX  25w             0.1 -0.886293
# 2   PSI  25w             0.1 -0.824350
# 3   XSD  25w             0.1 -3.940035
# 4   IYW  25w             0.1  1.436521
# Top ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'VGT']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1 -2.174101
# 1  SOXX  26w             0.1 -1.648918
# 2   PSI  26w             0.1  0.981906
# 3   XSD  26w             0.1 -0.269264
# 4   IYW  26w             0.1  2.890949
# Top ETFs for 2024-06-24 to 2024-06-30: ['VGT', 'IYW']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1  0.530933
# 1  SOXX  27w             0.1  0.025185
# 2   PSI  27w             0.1 -2.989258
# 3   XSD  27w             0.1 -2.506449
# 4   IYW  27w             0.1  6.102155
# Top ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'VGT']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1  1.108977
# 1  SOXX  28w             0.1  1.098597
# 2   PSI  28w             0.1  0.054683
# 3   XSD  28w             0.1  4.668281
# 4   IYW  28w             0.1 -0.340968
# Top ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1 -1.778866
# 1  SOXX  29w             0.1 -1.748370
# 2   PSI  29w             0.1 -1.131586
# 3   XSD  29w             0.1  0.072411
# 4   IYW  29w             0.1  0.679629
# Top ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'VGT']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1 -2.467436
# 1  SOXX  30w             0.1 -0.723609
# 2   PSI  30w             0.1 -1.552423
# 3   XSD  30w             0.1 -0.720771
# 4   IYW  30w             0.1  0.716768
# Top ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'VGT']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1 -1.765371
# 1  SOXX  31w             0.1 -1.423201
# 2   PSI  31w             0.1 -1.571942
# 3   XSD  31w             0.1 -3.919213
# 4   IYW  31w             0.1  1.770759
# Top ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IYW']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1  0.659924
# 1  SOXX  32w             0.1  1.637048
# 2   PSI  32w             0.1  3.897198
# 3   XSD  32w             0.1 -2.891550
# 4   IYW  32w             0.1  0.266996
# Top ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SOXX']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1  2.603428
# 1  SOXX  33w             0.1 -0.688338
# 2   PSI  33w             0.1 -0.969083
# 3   XSD  33w             0.1 -2.164449
# 4   IYW  33w             0.1  2.210288
# Top ETFs for 2024-08-12 to 2024-08-18: ['VGT', 'SMH']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1 -1.092816
# 1  SOXX  34w             0.1 -1.790483
# 2   PSI  34w             0.1 -1.082547
# 3   XSD  34w             0.1 -0.043430
# 4   IYW  34w             0.1  2.331464
# Top ETFs for 2024-08-19 to 2024-08-25: ['VGT', 'IYW']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1 -1.387750
# 1  SOXX  35w             0.1 -0.166330
# 2   PSI  35w             0.1 -1.849419
# 3   XSD  35w             0.1  1.055081
# 4   IYW  35w             0.1  2.228474
# Top ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IYW']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1 -1.824644
# 1  SOXX  36w             0.1 -1.174986
# 2   PSI  36w             0.1 -0.783255
# 3   XSD  36w             0.1 -1.774367
# 4   IYW  36w             0.1  0.277846
# Top ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1  2.874689
# 1  SOXX  37w             0.1 -0.240681
# 2   PSI  37w             0.1 -1.107843
# 3   XSD  37w             0.1 -1.405055
# 4   IYW  37w             0.1  2.129738
# Top ETFs for 2024-09-09 to 2024-09-15: ['VGT', 'SMH']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1 -2.081045
# 1  SOXX  38w             0.1 -1.439035
# 2   PSI  38w             0.1 -1.265157
# 3   XSD  38w             0.1 -1.891567
# 4   IYW  38w             0.1  3.067578
# Top ETFs for 2024-09-16 to 2024-09-22: ['VGT', 'IYW']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1  1.543182
# 1  SOXX  39w             0.1  0.978112
# 2   PSI  39w             0.1  1.933125
# 3   XSD  39w             0.1  0.991446
# 4   IYW  39w             0.1  1.250037
# Top ETFs for 2024-09-23 to 2024-09-29: ['VGT', 'PSI']
# Processing scores for 2024-09-30 to 2024-10-06:
# ...
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'VGT']
# Sell FTEC: 259.66 shares at 153.66. Total value: 38902.48
# Buy VGT: 73.23 shares at 517.98.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'IYW': 287.76576165591257, 'VGT': 73.22661164147307}
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'VGT']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'XSD']
# Sell IYW: 287.77 shares at 135.90. Total value: 38129.68
# Buy FTEC: 237.63 shares at 156.45.
# Sell VGT: 73.23 shares at 526.15. Total value: 37564.98
# Buy XSD: 161.92 shares at 226.20.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'FTEC': 237.62505476816833, 'XSD': 161.91801475065438}
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Sell XSD: 161.92 shares at 233.86. Total value: 36919.49
# Buy IYW: 265.56 shares at 135.55.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'FTEC': 237.62505476816833, 'IYW': 265.5588728031397}
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['VGT', 'FTEC']
# Sell IYW: 265.56 shares at 134.13. Total value: 34728.93
# Buy VGT: 65.41 shares at 517.63.
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'FTEC': 237.62505476816833, 'VGT': 65.4148794971869}
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['VGT', 'FTEC']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'VGT']
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'FTEC': 237.62505476816833, 'VGT': 65.4148794971869}
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'XSD']
# Sell FTEC: 237.63 shares at 144.25. Total value: 33420.48
# Buy SOXX: 161.58 shares at 201.66.
# Sell VGT: 65.41 shares at 486.46. Total value: 31026.18
# Buy XSD: 146.41 shares at 206.62.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'SOXX': 161.58368657591825, 'XSD': 146.40656725450717}
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'XSD']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['VGT', 'IXN']
# Sell SOXX: 161.58 shares at 218.55. Total value: 34431.26
# Buy VGT: 66.35 shares at 505.94.
# Sell XSD: 146.41 shares at 228.64. Total value: 32637.54
# Buy IXN: 441.66 shares at 72.05.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'VGT': 66.3526912174758, 'IXN': 441.6599267993223}
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['VGT', 'IXN']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['VGT', 'IYW']
# Sell IXN: 441.66 shares at 73.87. Total value: 31809.78
# Buy IYW: 231.06 shares at 134.23.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'VGT': 66.3526912174758, 'IYW': 231.0552103115029}
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['VGT', 'IYW']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'VGT']
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'VGT': 66.3526912174758, 'IYW': 231.0552103115029}
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'VGT']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['IYW', 'VGT']
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'VGT': 66.3526912174758, 'IYW': 231.0552103115029}
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['IYW', 'VGT']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Sell VGT: 66.35 shares at 549.92. Total value: 35576.45
# Buy FTEC: 211.80 shares at 163.77.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'IYW': 231.0552103115029, 'FTEC': 211.80339374537644}
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IYW', 'VGT']
# Sell FTEC: 211.80 shares at 159.71. Total value: 32981.44
# Buy VGT: 59.84 shares at 537.42.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'IYW': 231.0552103115029, 'VGT': 59.835711991962306}
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IYW', 'VGT']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['VGT', 'IYW']
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'IYW': 231.0552103115029, 'VGT': 59.835711991962306}
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['VGT', 'IYW']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'VGT']
# Sell IYW: 231.06 shares at 152.76. Total value: 34413.59
# Buy FTEC: 192.35 shares at 174.44.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'VGT': 59.835711991962306, 'FTEC': 192.34838655625788}
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['VGT', 'IYW']
# Sell FTEC: 192.35 shares at 168.46. Total value: 31592.94
# Buy IYW: 208.40 shares at 147.81.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'VGT': 59.835711991962306, 'IYW': 208.39667381417289}
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['VGT', 'IYW']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'VGT']
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'VGT': 59.835711991962306, 'IYW': 208.39667381417289}
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'VGT']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Sell IYW: 208.40 shares at 156.96. Total value: 31892.19
# Buy XSD: 119.28 shares at 260.69.
# Sell VGT: 59.84 shares at 599.91. Total value: 34998.64
# Buy SMH: 124.44 shares at 274.21.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 119.27918055290137, 'SMH': 124.44358135759984}
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'VGT']
# Sell XSD: 119.28 shares at 268.80. Total value: 31260.69
# Buy FTEC: 169.82 shares at 179.48.
# Sell SMH: 124.44 shares at 273.83. Total value: 33224.47
# Buy VGT: 53.65 shares at 603.78.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'FTEC': 169.81931017225133, 'VGT': 53.651762512590714}
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'VGT']
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'FTEC': 169.81931017225133, 'VGT': 53.651762512590714}
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IYW']
# Sell VGT: 53.65 shares at 559.49. Total value: 29267.18
# Buy IYW: 197.97 shares at 144.14.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'FTEC': 169.81931017225133, 'IYW': 197.97075076938717}
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SOXX']
# Sell FTEC: 169.82 shares at 153.33. Total value: 25387.44
# Buy PSI: 499.25 shares at 49.58.
# Sell IYW: 197.97 shares at 133.32. Total value: 25733.63
# Buy SOXX: 123.50 shares at 203.16.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'PSI': 499.2486580372619, 'SOXX': 123.50011964398081}
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SOXX']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['VGT', 'SMH']
# Sell PSI: 499.25 shares at 53.06. Total value: 25827.88
# Buy VGT: 46.77 shares at 538.42.
# Sell SOXX: 123.50 shares at 213.00. Total value: 25647.89
# Buy SMH: 110.18 shares at 226.96.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'VGT': 46.770522808158816, 'SMH': 110.18104257863163}
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['VGT', 'SMH']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['VGT', 'IYW']
# Sell SMH: 110.18 shares at 251.34. Total value: 27000.58
# Buy IYW: 175.50 shares at 150.00.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'VGT': 46.770522808158816, 'IYW': 175.5037717372081}
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['VGT', 'IYW']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IYW']
# Sell VGT: 46.77 shares at 574.52. Total value: 26198.84
# Buy FTEC: 149.62 shares at 170.72.
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'IYW': 175.5037717372081, 'FTEC': 149.62432952653498}
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'IYW': 175.5037717372081, 'FTEC': 149.62432952653498}
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['VGT', 'SMH']
# Sell FTEC: 149.62 shares at 160.54. Total value: 23420.17
# Buy VGT: 42.26 shares at 540.37.
# Sell IYW: 175.50 shares at 139.41. Total value: 23855.31
# Buy SMH: 105.79 shares at 219.86.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'VGT': 42.25746720140229, 'SMH': 105.78970338584664}
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['VGT', 'SMH']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['VGT', 'IYW']
# Sell SMH: 105.79 shares at 233.80. Total value: 24115.29
# Buy IYW: 161.00 shares at 146.04.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'VGT': 42.25746720140229, 'IYW': 160.99980092627385}
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['VGT', 'IYW']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['VGT', 'PSI']
# Sell IYW: 161.00 shares at 149.26. Total value: 23430.06
# Buy PSI: 414.52 shares at 55.11.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'VGT': 42.25746720140229, 'PSI': 414.52199141964184}
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['VGT', 'PSI']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'VGT']
# Sell PSI: 414.52 shares at 57.52. Total value: 23247.22
# Buy IYW: 149.49 shares at 151.62.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'VGT': 42.25746720140229, 'IYW': 149.49243289179535}
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'VGT']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'VGT']
# Sell IYW: 149.49 shares at 150.36. Total value: 21915.74
# Buy SMH: 86.08 shares at 248.22.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'VGT': 42.25746720140229, 'SMH': 86.08430679302745}
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'VGT']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['VGT', 'FTEC']
# Sell SMH: 86.08 shares at 261.28. Total value: 21929.80
# Buy FTEC: 118.24 shares at 180.83.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'VGT': 42.25746720140229, 'FTEC': 118.24121852478224}
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['VGT', 'FTEC']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['VGT', 'IYW']
# Sell FTEC: 118.24 shares at 180.45. Total value: 20803.21
# Buy IYW: 129.82 shares at 156.24.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'VGT': 42.25746720140229, 'IYW': 129.82034578169794}
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['VGT', 'IYW']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IYW']
# Sell VGT: 42.26 shares at 603.19. Total value: 24852.05
# Buy FTEC: 135.17 shares at 179.26.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'IYW': 129.82034578169794, 'FTEC': 135.17097623992527}
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['VGT', 'IYW']
# Sell FTEC: 135.17 shares at 174.13. Total value: 22948.89
# Buy VGT: 38.19 shares at 585.90.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'IYW': 129.82034578169794, 'VGT': 38.18939496398912}
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['VGT', 'IYW']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'IYW']
# Sell VGT: 38.19 shares at 621.92. Total value: 23156.98
# Buy FTEC: 122.00 shares at 185.07.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'IYW': 129.82034578169794, 'FTEC': 121.99737285386506}
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['VGT', 'PSI']
# Sell FTEC: 122.00 shares at 179.88. Total value: 21396.27
# Buy VGT: 34.50 shares at 604.72.
# Sell IYW: 129.82 shares at 156.19. Total value: 19769.72
# Buy PSI: 356.56 shares at 54.06.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'VGT': 34.49755289902312, 'PSI': 356.55716849388335}
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['VGT', 'PSI']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'FTEC']
# Sell VGT: 34.50 shares at 621.29. Total value: 20897.16
# Buy XSD: 81.90 shares at 248.77.
# Sell PSI: 356.56 shares at 57.16. Total value: 19871.29
# Buy FTEC: 104.78 shares at 184.91.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'XSD': 81.90187704909643, 'FTEC': 104.77802678584558}
#
# Final Ticker Shares per Week:
# Week 2024-01-01 to 2024-01-07: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
# Week 2024-01-08 to 2024-01-14: {'IYW': 407.8815375605023, 'VGT': 98.36601595602471}
# Week 2024-01-15 to 2024-01-21: {'SMH': 256.7325111408514, 'FTEC': 333.9050684327781}
# Week 2024-01-22 to 2024-01-28: {'IYW': 356.9634713176291, 'VGT': 94.3054035799849}
# Week 2024-01-29 to 2024-02-04: {'IYW': 356.9634713176291, 'SMH': 239.6917338463468}
# Week 2024-02-05 to 2024-02-11: {'SMH': 239.6917338463468, 'VGT': 87.5471592658702}
# Week 2024-02-12 to 2024-02-18: {'FTEC': 280.20344554004873, 'PSI': 878.2959824210886}
# Week 2024-02-19 to 2024-02-25: {'SMH': 201.27796984050985, 'IYW': 332.2589103110685}
# Week 2024-02-26 to 2024-03-03: {'PSI': 754.8451438382878, 'VGT': 81.25317698922393}
# Week 2024-03-04 to 2024-03-10: {'FTEC': 259.6640599321854, 'SMH': 182.12319468744843}
# Week 2024-03-11 to 2024-03-17: {'FTEC': 259.6640599321854, 'IYW': 287.76576165591257}
# Week 2024-03-18 to 2024-03-24: {'IYW': 287.76576165591257, 'VGT': 73.22661164147307}
# Week 2024-03-25 to 2024-03-31: {'FTEC': 237.62505476816833, 'XSD': 161.91801475065438}
# Week 2024-04-01 to 2024-04-07: {'FTEC': 237.62505476816833, 'IYW': 265.5588728031397}
# Week 2024-04-08 to 2024-04-14: {'FTEC': 237.62505476816833, 'VGT': 65.4148794971869}
# Week 2024-04-15 to 2024-04-21: {'FTEC': 237.62505476816833, 'VGT': 65.4148794971869}
# Week 2024-04-22 to 2024-04-28: {'SOXX': 161.58368657591825, 'XSD': 146.40656725450717}
# Week 2024-04-29 to 2024-05-05: {'VGT': 66.3526912174758, 'IXN': 441.6599267993223}
# Week 2024-05-06 to 2024-05-12: {'VGT': 66.3526912174758, 'IYW': 231.0552103115029}
# Week 2024-05-13 to 2024-05-19: {'VGT': 66.3526912174758, 'IYW': 231.0552103115029}
# Week 2024-05-20 to 2024-05-26: {'VGT': 66.3526912174758, 'IYW': 231.0552103115029}
# Week 2024-05-27 to 2024-06-02: {'IYW': 231.0552103115029, 'FTEC': 211.80339374537644}
# Week 2024-06-03 to 2024-06-09: {'IYW': 231.0552103115029, 'VGT': 59.835711991962306}
# Week 2024-06-10 to 2024-06-16: {'IYW': 231.0552103115029, 'VGT': 59.835711991962306}
# Week 2024-06-17 to 2024-06-23: {'VGT': 59.835711991962306, 'FTEC': 192.34838655625788}
# Week 2024-06-24 to 2024-06-30: {'VGT': 59.835711991962306, 'IYW': 208.39667381417289}
# Week 2024-07-01 to 2024-07-07: {'VGT': 59.835711991962306, 'IYW': 208.39667381417289}
# Week 2024-07-08 to 2024-07-14: {'XSD': 119.27918055290137, 'SMH': 124.44358135759984}
# Week 2024-07-15 to 2024-07-21: {'FTEC': 169.81931017225133, 'VGT': 53.651762512590714}
# Week 2024-07-22 to 2024-07-28: {'FTEC': 169.81931017225133, 'VGT': 53.651762512590714}
# Week 2024-07-29 to 2024-08-04: {'FTEC': 169.81931017225133, 'IYW': 197.97075076938717}
# Week 2024-08-05 to 2024-08-11: {'PSI': 499.2486580372619, 'SOXX': 123.50011964398081}
# Week 2024-08-12 to 2024-08-18: {'VGT': 46.770522808158816, 'SMH': 110.18104257863163}
# Week 2024-08-19 to 2024-08-25: {'VGT': 46.770522808158816, 'IYW': 175.5037717372081}
# Week 2024-08-26 to 2024-09-01: {'IYW': 175.5037717372081, 'FTEC': 149.62432952653498}
# Week 2024-09-02 to 2024-09-08: {'IYW': 175.5037717372081, 'FTEC': 149.62432952653498}
# Week 2024-09-09 to 2024-09-15: {'VGT': 42.25746720140229, 'SMH': 105.78970338584664}
# Week 2024-09-16 to 2024-09-22: {'VGT': 42.25746720140229, 'IYW': 160.99980092627385}
# Week 2024-09-23 to 2024-09-29: {'VGT': 42.25746720140229, 'PSI': 414.52199141964184}
# Week 2024-09-30 to 2024-10-06: {'VGT': 42.25746720140229, 'IYW': 149.49243289179535}
# Week 2024-10-07 to 2024-10-13: {'VGT': 42.25746720140229, 'SMH': 86.08430679302745}
# Week 2024-10-14 to 2024-10-20: {'VGT': 42.25746720140229, 'FTEC': 118.24121852478224}
# Week 2024-10-21 to 2024-10-27: {'VGT': 42.25746720140229, 'IYW': 129.82034578169794}
# Week 2024-10-28 to 2024-11-03: {'IYW': 129.82034578169794, 'FTEC': 135.17097623992527}
# Week 2024-11-04 to 2024-11-10: {'IYW': 129.82034578169794, 'VGT': 38.18939496398912}
# Week 2024-11-11 to 2024-11-17: {'IYW': 129.82034578169794, 'FTEC': 121.99737285386506}
# Week 2024-11-18 to 2024-11-24: {'VGT': 34.49755289902312, 'PSI': 356.55716849388335}
# Week 2024-11-25 to 2024-12-01: {'XSD': 81.90187704909643, 'FTEC': 104.77802678584558}

# %%
# Define the first trading day of the 48th week
first_trading_day_49w = '2024-12-01'  # Adjust this to match the actual start date of the 48th week

# Identify the 48th and 49th week date range keys
week_48_range = list(ticker_shares_per_week.keys())[-1]  # Last key corresponds to the 48th week
week_49_start = first_trading_day_49w  # Replace with the actual start of the 49th week
print(f"Using data for the 48th week: {week_48_range}")

print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

week_49_end = '2024-12-06'
# Initialize a dictionary to store the values of shares
etf_values_49w = {}

# Ensure 48th week data exists
if week_48_range in ticker_shares_per_week:
    # Fetch ETF shares from the 48th week
    ticker_shares_48w = ticker_shares_per_week[week_48_range]
    
    # Fetch the first trading day price of the 49th week for each ETF
    for ticker, shares in ticker_shares_48w.items():
        print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
        # Download historical data for the 49th week
        data = yf.download(ticker, start=week_49_start, end=week_49_end)
        
        if not data.empty:
            # Get the closing price of the first trading day of the 49th week
            closing_price_49w = data['Close'].iloc[0]
            # Calculate the value of the shares
            total_value = shares * closing_price_49w
            etf_values_49w[ticker] = total_value
            print(f"{ticker}: {shares:.2f} shares at ${closing_price_49w:.2f} each, total value: ${total_value:.2f}")
        else:
            print(f"{ticker}: No data available for the 49th week's first trading day.")
else:
    print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker XSD starting from 2024-12-01...
# XSD: 81.90 shares at $252.68 each, total value: $20694.97
# Fetching data for ticker FTEC starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# FTEC: 104.78 shares at $186.99 each, total value: $19592.44

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 40287.41
# XSD: 20694.97
# FTEC: 19592.44

# %%
from pandas.tseries.offsets import BDay

# %% [markdown]
# ### Values for 11th Month

# %% [markdown]
# ### Smoothing

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, 
    volatility_clustering, mean_forecast, std_forecast, mean_rachev, std_rachev, 
    mean_sharpe, std_sharpe, mean_sortino, std_sortino, mean_volatility_clustering, 
    std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    return score

def smooth_scores(scores, alpha=0.2):
    """
    Smooth scores using Exponential Moving Average (EMA).
    """
    if not isinstance(scores, (list, np.ndarray)):
        raise ValueError("Scores must be a list or numpy array of numerical values.")
    
    scores = np.array(scores)
    smoothed_scores = np.zeros_like(scores)
    smoothed_scores[0] = scores[0]  # Initialize EMA
    
    for t in range(1, len(scores)):
        smoothed_scores[t] = alpha * scores[t] + (1 - alpha) * smoothed_scores[t - 1]
    
    return smoothed_scores.tolist()

def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )

def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage, alpha=0.2):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    raw_scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        raw_scores.append(score)

    # Apply smoothing to the raw scores
    smoothed_scores = smooth_scores(raw_scores, alpha=alpha)

    results = []
    for idx, etf in enumerate(etf_pred_dict):
        results.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'RawScore': raw_scores[idx],
            'SmoothedScore': smoothed_scores[idx]
        })

    return results

def main_weekly(tickers, etf_dict):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict)
    risk_percentage = 0.10
    weekly_scores = {}

    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores
        else:
            print(f"Skipping score calculation for {week_key}: No ETFs have data for this week.")

    return etf_pred_dict, weekly_scores

# Select top ETFs for weekly portfolio management
def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    top_etfs = df_scores.nlargest(2, 'SmoothedScore')
    return top_etfs['ETF'].tolist()

# %%
etf_pred_dict, weekly_scores = main_weekly(tickers, etf_dict)
# Out:
# Debug: Returns for SMH, Forecast Period 1w: [-0.03202409 -0.0154641  -0.004719    0.00856414]
#
# Debug: Returns for SMH, Forecast Period 2w: [ 0.03812428  0.00463116  0.00089891  0.00752194 -0.00303392]
#
# Debug: Returns for SMH, Forecast Period 3w: [ 0.01694065 -0.00609958  0.0314685   0.03796531]
#
# Debug: Returns for SMH, Forecast Period 4w: [ 0.00551596  0.00603854  0.01867902  0.00020021 -0.02019114]
#
# Debug: Returns for SMH, Forecast Period 5w: [ 0.01261234 -0.00865264 -0.01316788  0.01014745  0.02036492]
#
# Debug: Returns for SMH, Forecast Period 6w: [ 0.02036492 -0.00976431  0.02063851  0.01516252  0.02297172]
#
# Debug: Returns for SMH, Forecast Period 7w: [-0.00346818 -0.01724814  0.02077546 -0.002941   -0.00371011]
#
# Debug: Returns for SMH, Forecast Period 8w: [-0.01843297 -0.00595772  0.06640472 -0.00588333]
#
# Debug: Returns for SMH, Forecast Period 9w: [ 0.00934484 -0.00249664 -0.00976431  0.02257291  0.04058891]
#
# Debug: Returns for SMH, Forecast Period 10w: [ 0.01714005 -0.01407705  0.02603656  0.03478451 -0.03834511]
#
# Debug: Returns for SMH, Forecast Period 11w: [-0.01669412  0.0307133  -0.01856992 -0.01669412 -0.00598608]
#
# Debug: Returns for SMH, Forecast Period 12w: [ 0.00225205 -0.00202005  0.01714005  0.02367958  0.00698386]
#
# Debug: Returns for SMH, Forecast Period 13w: [-0.00201211 -0.00701872 -0.00128278 -0.0003416 ]
#
# Debug: Returns for SMH, Forecast Period 14w: [ 0.01323239 -0.01254194  0.00355618 -0.02709604  0.01184344]
#
# Debug: Returns for SMH, Forecast Period 15w: [ 0.00020158  0.00413844 -0.00893642  0.02314268 -0.02872497]
#
# Debug: Returns for SMH, Forecast Period 16w: [-0.01530867  0.00781905 -0.03245699 -0.01872783 -0.04488023]
#
# Debug: Returns for SMH, Forecast Period 17w: [ 0.01862271  0.02282172 -0.0001228   0.01989256  0.02529061]
#
# Debug: Returns for SMH, Forecast Period 18w: [ 0.00370178 -0.01931587 -0.02809986  0.01989256  0.02696831]
#
# Debug: Returns for SMH, Forecast Period 19w: [ 0.02323339 -0.00785681  0.00359753 -0.00654086  0.01628868]
#
# Debug: Returns for SMH, Forecast Period 20w: [ 0.00025627  0.01868728  0.03015823 -0.00569706 -0.00695138]
#
# Debug: Returns for SMH, Forecast Period 21w: [ 0.02163808 -0.00109078  0.00925624  0.01474281  0.01951856]
#
# Debug: Returns for SMH, Forecast Period 22w: [ 0.02367958 -0.01529195 -0.01239681 -0.00598608]
#
# Debug: Returns for SMH, Forecast Period 23w: [ 0.01348685 -0.00336163  0.04741708 -0.00652254 -0.00055863]
#
# Debug: Returns for SMH, Forecast Period 24w: [ 0.01545057 -0.00122773  0.03002128  0.01649933  0.00342948]
#
# Debug: Returns for SMH, Forecast Period 25w: [ 0.0178705   0.0168037  -0.02791381 -0.01378288]
#
# Debug: Returns for SMH, Forecast Period 26w: [-0.03445055  0.02407146 -0.00290259 -0.00652254  0.00816448]
#
# Debug: Returns for SMH, Forecast Period 27w: [0.00145955 0.01116443 0.02367958 0.000738  ]
#
# Debug: Returns for SMH, Forecast Period 28w: [ 0.01762248  0.00247176  0.02420841 -0.0340109   0.01456913]
#
# Debug: Returns for SMH, Forecast Period 29w: [-0.00224807 -0.00056815 -0.07058055  0.00565359 -0.02916354]
#
# Debug: Returns for SMH, Forecast Period 30w: [ 0.03514364 -0.01051026 -0.06018678 -0.01840531  0.01541701]
#
# Debug: Returns for SMH, Forecast Period 31w: [-0.00813698 -0.03983722  0.07231167 -0.06967504 -0.06004408]
#
# Debug: Returns for SMH, Forecast Period 32w: [-0.02366678  0.01897823 -0.02778782  0.05626757 -0.00148167]
#
# Debug: Returns for SMH, Forecast Period 33w: [1.0228256e-02 3.7931260e-02 9.5499810e-05 3.9649967e-02 7.2022248e-04]
#
# Debug: Returns for SMH, Forecast Period 34w: [ 0.01987245 -0.01272964  0.01053549 -0.03233375  0.02547822]
#
# Debug: Returns for SMH, Forecast Period 35w: [-0.02264607  0.01130138 -0.0155047  -0.01170712  0.02488823]
#
# Debug: Returns for SMH, Forecast Period 36w: [-0.09080893 -0.00162578 -0.00110611 -0.04027833]
#
# Debug: Returns for SMH, Forecast Period 37w: [0.02172199 0.00946434 0.04862954 0.00175168 0.01337605]
#
# Debug: Returns for SMH, Forecast Period 38w: [-0.01272964 -0.00122303 -0.01111498  0.03945598 -0.01272964]
#
# Debug: Returns for SMH, Forecast Period 39w: [ 0.00496857  0.01863565  0.01004494  0.02923816 -0.01809826]
#
# Debug: Returns for SMH, Forecast Period 40w: [-0.00781616 -0.0263162   0.01558752  0.0102844   0.01442961]
#
# Debug: Returns for SMH, Forecast Period 41w: [ 0.00188776  0.01829443  0.0114184  -0.00176543  0.00898996]
#
# Debug: Returns for SMH, Forecast Period 42w: [ 0.01867902 -0.05441052  0.00084369  0.01843138  0.0008394 ]
#
# Debug: Returns for SMH, Forecast Period 43w: [ 0.00604688 -0.00521128 -0.01038809  0.00432236  0.01096893]
#
# Debug: Returns for SMH, Forecast Period 44w: [-0.00746077  0.02261932 -0.02422396 -0.03613283  0.01210895]
#
# Debug: Returns for SMH, Forecast Period 45w: [-0.00329122  0.01584212  0.02520428  0.02364595 -0.00703733]
#
# Debug: Returns for SMH, Forecast Period 46w: [-0.02266197 -0.00805676 -0.01716745  0.00080902 -0.03326945]
#
# Debug: Returns for SMH, Forecast Period 47w: [ 0.00636409  0.01005637 -0.00759669  0.01403529 -0.00747895]
#
# Debug: Returns for SMH, Forecast Period 48w: [-0.00649436 -0.01002639 -0.01417608  0.01519688]
#
# Debug: Returns for SOXX, Forecast Period 1w: [-0.03706532 -0.02176728 -0.00812107  0.00571173]
#
# Debug: Returns for SOXX, Forecast Period 2w: [ 0.0323147   0.00082415 -0.00316626  0.00367128 -0.00418959]
#
# Debug: Returns for SOXX, Forecast Period 3w: [ 0.0144295  -0.00950463  0.0324925   0.03937934]
#
# Debug: Returns for SOXX, Forecast Period 4w: [ 0.00355432  0.00687057  0.01458439 -0.0026465  -0.02716174]
#
# Debug: Returns for SOXX, Forecast Period 5w: [ 0.01045832 -0.0151825  -0.01473959  0.00544179  0.01300019]
#
# Debug: Returns for SOXX, Forecast Period 6w: [ 0.01339658 -0.0119708   0.01583041  0.01691182  0.02004898]
#
# Debug: Returns for SOXX, Forecast Period 7w: [-0.00154132 -0.02033937  0.02267721 -0.00047768 -0.00527871]
#
# Debug: Returns for SOXX, Forecast Period 8w: [-0.01664155 -0.00212804  0.04873264 -0.01044627]
#
# Debug: Returns for SOXX, Forecast Period 9w: [ 0.01042539 -0.00047768 -0.0108995   0.02722179  0.04192361]
#
# Debug: Returns for SOXX, Forecast Period 10w: [ 0.01042539 -0.01948714  0.02474296  0.03411257 -0.04134722]
#
# Debug: Returns for SOXX, Forecast Period 11w: [-0.01321808  0.02076716 -0.02402711 -0.01664155 -0.00697528]
#
# Debug: Returns for SOXX, Forecast Period 12w: [-0.00053885 -0.00808264  0.01655396  0.02249941  0.00153028]
#
# Debug: Returns for SOXX, Forecast Period 13w: [-0.00389706 -0.00703482  0.0120172   0.00085005]
#
# Debug: Returns for SOXX, Forecast Period 14w: [ 0.01087775 -0.01616085  0.0021014  -0.02851545  0.01199504]
#
# Debug: Returns for SOXX, Forecast Period 15w: [ 0.00303653  0.01073599 -0.01843003  0.02221783 -0.03368871]
#
# Debug: Returns for SOXX, Forecast Period 16w: [-0.01243557  0.00757678 -0.03107411 -0.017166   -0.04191658]
#
# Debug: Returns for SOXX, Forecast Period 17w: [0.01756972 0.02155608 0.01388988 0.01867719 0.02083504]
#
# Debug: Returns for SOXX, Forecast Period 18w: [ 0.00818604 -0.02042759 -0.0347132   0.0227451   0.02207883]
#
# Debug: Returns for SOXX, Forecast Period 19w: [ 0.02007721 -0.00935467  0.00138742 -0.00373541  0.01002765]
#
# Debug: Returns for SOXX, Forecast Period 20w: [ 0.0018977   0.01652403  0.02756874 -0.00464772 -0.00527871]
#
# Debug: Returns for SOXX, Forecast Period 21w: [ 0.02201244 -0.00279225  0.01164447 -0.00527871  0.02026079]
#
# Debug: Returns for SOXX, Forecast Period 22w: [ 0.01691182 -0.02033937 -0.00641655 -0.00808135]
#
# Debug: Returns for SOXX, Forecast Period 23w: [ 0.00163375 -0.00761128  0.04192361 -0.00790355 -0.00247638]
#
# Debug: Returns for SOXX, Forecast Period 24w: [ 0.01483564  0.00146811  0.02778055  0.01138732 -0.00298846]
#
# Debug: Returns for SOXX, Forecast Period 25w: [ 0.01599439  0.01296617 -0.02716174 -0.00932101]
#
# Debug: Returns for SOXX, Forecast Period 26w: [-0.0283054   0.01565261 -0.00389706 -0.00479019  0.01028052]
#
# Debug: Returns for SOXX, Forecast Period 27w: [0.00016667 0.0144295  0.01691364 0.00264264]
#
# Debug: Returns for SOXX, Forecast Period 28w: [ 0.01955466 -0.00024303  0.02362979 -0.03317809  0.01260705]
#
# Debug: Returns for SOXX, Forecast Period 29w: [ 0.0013256   0.00643823 -0.08681529  0.00303923 -0.03105839]
#
# Debug: Returns for SOXX, Forecast Period 30w: [ 0.04131775 -0.01465002 -0.05605261 -0.02193807  0.0221549 ]
#
# Debug: Returns for SOXX, Forecast Period 31w: [-0.00186854 -0.03736024  0.07231331 -0.08949111 -0.05548651]
#
# Debug: Returns for SOXX, Forecast Period 32w: [-0.01779088  0.00967039 -0.02753992  0.07380833 -0.00545553]
#
# Debug: Returns for SOXX, Forecast Period 33w: [ 0.00581515  0.03905389 -0.00263545  0.04563401 -0.00256483]
#
# Debug: Returns for SOXX, Forecast Period 34w: [ 0.01590757 -0.01316213  0.01469606 -0.03481692  0.02720983]
#
# Debug: Returns for SOXX, Forecast Period 35w: [-0.02566305  0.01109328 -0.01801105 -0.00252291  0.0254394 ]
#
# Debug: Returns for SOXX, Forecast Period 36w: [-0.0803166   0.00430937 -0.00513442 -0.04396366]
#
# Debug: Returns for SOXX, Forecast Period 37w: [ 0.02041017  0.0114184   0.04617701 -0.00475874  0.01788947]
#
# Debug: Returns for SOXX, Forecast Period 38w: [-0.01312851  0.00162739 -0.01010049  0.04252083 -0.01465002]
#
# Debug: Returns for SOXX, Forecast Period 39w: [ 0.00353411  0.01236618  0.00706281  0.03571008 -0.01579077]
#
# Debug: Returns for SOXX, Forecast Period 40w: [-0.00891697 -0.02821583  0.0134306   0.00367128  0.0134306 ]
#
# Debug: Returns for SOXX, Forecast Period 41w: [-0.00261248  0.01024759  0.01006871 -0.00659435  0.00859115]
#
# Debug: Returns for SOXX, Forecast Period 42w: [ 0.0183014  -0.05415836  0.00036614  0.00797329  0.00085478]
#
# Debug: Returns for SOXX, Forecast Period 43w: [-0.00211531 -0.00363245 -0.00989532  0.00469001  0.00993413]
#
# Debug: Returns for SOXX, Forecast Period 44w: [-5.2699881e-05  2.3843780e-02 -3.6395855e-02 -3.9744034e-02
#   1.1263254e-02]
#
# Debug: Returns for SOXX, Forecast Period 45w: [-0.00536694  0.01177559  0.028577    0.02007721 -0.00754697]
#
# Debug: Returns for SOXX, Forecast Period 46w: [-2.5067143e-02 -1.0901701e-02 -2.1814592e-02 -1.3250483e-05
#  -3.3184741e-02]
#
# Debug: Returns for SOXX, Forecast Period 47w: [ 0.01275828  0.00215138 -0.00783872  0.01550313  0.00051069]
#
# Debug: Returns for SOXX, Forecast Period 48w: [ 0.01033812 -0.01214427 -0.01297587  0.01311714]
#
# Debug: Returns for PSI, Forecast Period 1w: [-0.03786063 -0.02395659 -0.01452977  0.00122902]
#
# Debug: Returns for PSI, Forecast Period 2w: [ 0.02962338  0.00177292 -0.00436342  0.00288603 -0.00508395]
#
# Debug: Returns for PSI, Forecast Period 3w: [ 0.0139508  -0.01150108  0.03348404  0.03948674]
#
# Debug: Returns for PSI, Forecast Period 4w: [ 0.00875542  0.00288603  0.01041648 -0.00122507 -0.03024713]
#
# Debug: Returns for PSI, Forecast Period 5w: [ 0.01162832 -0.01452977 -0.02033322  0.00830509  0.01135139]
#
# Debug: Returns for PSI, Forecast Period 6w: [ 0.00863409 -0.013657    0.00655969  0.01907812  0.03230321]
#
# Debug: Returns for PSI, Forecast Period 7w: [ 0.0009616  -0.0275196   0.03230321  0.0048244  -0.00052895]
#
# Debug: Returns for PSI, Forecast Period 8w: [-0.0275196  -0.01150108  0.04280266 -0.01079938]
#
# Debug: Returns for PSI, Forecast Period 9w: [ 0.01316302 -0.0026438   0.00343536  0.017405    0.04280266]
#
# Debug: Returns for PSI, Forecast Period 10w: [ 0.00288603 -0.02650258  0.02431726  0.02962338 -0.03929047]
#
# Debug: Returns for PSI, Forecast Period 11w: [-0.01476919  0.01621491 -0.02643275 -0.01656426 -0.00923873]
#
# Debug: Returns for PSI, Forecast Period 12w: [ 0.00655969 -0.00639125  0.02632157  0.02962338  0.00122902]
#
# Debug: Returns for PSI, Forecast Period 13w: [-0.00074459 -0.00639125  0.0111675  -0.00122507]
#
# Debug: Returns for PSI, Forecast Period 14w: [ 0.01020098 -0.01079938  0.01020098 -0.02643275  0.01316302]
#
# Debug: Returns for PSI, Forecast Period 15w: [ 0.00231334  0.00830509 -0.02082083  0.02700792 -0.03336931]
#
# Debug: Returns for PSI, Forecast Period 16w: [-0.01476919  0.0111675  -0.03336931 -0.01945073 -0.03824078]
#
# Debug: Returns for PSI, Forecast Period 17w: [0.01663152 0.02428309 0.00863409 0.01618074 0.02121506]
#
# Debug: Returns for PSI, Forecast Period 18w: [ 0.00835573 -0.02260148 -0.0332021   0.02958921  0.02171105]
#
# Debug: Returns for PSI, Forecast Period 19w: [ 0.02174522 -0.00508395 -0.00052895  0.00122902  0.00596347]
#
# Debug: Returns for PSI, Forecast Period 20w: [-0.00078341  0.01580973  0.02700792 -0.00810327 -0.00573382]
#
# Debug: Returns for PSI, Forecast Period 21w: [ 2.0824786e-02  2.1367018e-06  1.2290213e-03 -3.3449775e-03
#   1.7039431e-02]
#
# Debug: Returns for PSI, Forecast Period 22w: [ 0.0139508  -0.01476919 -0.0024035  -0.01228641]
#
# Debug: Returns for PSI, Forecast Period 23w: [ 2.1367018e-06 -1.0799379e-02  4.7663737e-02 -8.1032692e-03
#  -9.6903788e-03]
#
# Debug: Returns for PSI, Forecast Period 24w: [ 0.01960009 -0.00052895  0.02962338  0.00830509 -0.00810327]
#
# Debug: Returns for PSI, Forecast Period 25w: [ 0.01960009  0.0139508  -0.03024713 -0.01228641]
#
# Debug: Returns for PSI, Forecast Period 26w: [-0.023037    0.02174522 -0.0024035   0.0016265   0.01162832]
#
# Debug: Returns for PSI, Forecast Period 27w: [-0.00078341  0.01377121  0.01162832  0.00252796]
#
# Debug: Returns for PSI, Forecast Period 28w: [ 1.5179577e-02  2.1367018e-06  1.6214915e-02 -3.0247126e-02
#   1.1628319e-02]
#
# Debug: Returns for PSI, Forecast Period 29w: [ 0.01162832  0.00711754 -0.07253202 -0.00969038 -0.02555026]
#
# Debug: Returns for PSI, Forecast Period 30w: [ 0.04247085 -0.00810327 -0.05655967 -0.02921143  0.01703671]
#
# Debug: Returns for PSI, Forecast Period 31w: [-0.00348093 -0.04832652  0.06258423 -0.07434056 -0.05053614]
#
# Debug: Returns for PSI, Forecast Period 32w: [-0.01451196  0.00772395 -0.01595833  0.06319927  0.00378795]
#
# Debug: Returns for PSI, Forecast Period 33w: [ 0.00345272  0.03721708 -0.00122393  0.05236565 -0.00508281]
#
# Debug: Returns for PSI, Forecast Period 34w: [ 0.01315099 -0.01472333  0.02262948 -0.03131142  0.02693575]
#
# Debug: Returns for PSI, Forecast Period 35w: [-0.02728735  0.01116864 -0.01472333  0.00596461  0.01162832]
#
# Debug: Returns for PSI, Forecast Period 36w: [-0.07178853  0.00596347 -0.00718693 -0.04183298]
#
# Debug: Returns for PSI, Forecast Period 37w: [ 0.01203682  0.00725802  0.04248401 -0.00810327  0.02360035]
#
# Debug: Returns for PSI, Forecast Period 38w: [-0.02244827  0.00725802 -0.01079938  0.04251355 -0.01228641]
#
# Debug: Returns for PSI, Forecast Period 39w: [ 0.00431762  0.01161515  0.00648277  0.05268494 -0.01651543]
#
# Debug: Returns for PSI, Forecast Period 40w: [-0.00697526 -0.03754021  0.017405   -0.00639125  0.02082479]
#
# Debug: Returns for PSI, Forecast Period 41w: [ 2.1367018e-06  2.7575307e-03  1.3950796e-02 -1.5969072e-03
#   1.6214915e-02]
#
# Debug: Returns for PSI, Forecast Period 42w: [ 0.017405   -0.05700508  0.00177292  0.00215145 -0.00052895]
#
# Debug: Returns for PSI, Forecast Period 43w: [-0.00334498 -0.00585732 -0.00810327  0.00252796  0.01514541]
#
# Debug: Returns for PSI, Forecast Period 44w: [-0.00078341  0.02082479 -0.02428046 -0.04235865  0.00596347]
#
# Debug: Returns for PSI, Forecast Period 45w: [-0.0079279   0.02958921  0.03604641  0.02632157 -0.00436342]
#
# Debug: Returns for PSI, Forecast Period 46w: [-0.02260148 -0.01228641 -0.02260148 -0.00223143 -0.03745943]
#
# Debug: Returns for PSI, Forecast Period 47w: [1.5145406e-02 8.6340932e-03 2.1367018e-06 3.6046412e-02 2.1367018e-06]
#
# Debug: Returns for PSI, Forecast Period 48w: [ 0.01318516 -0.00810327 -0.01808801  0.01960009]
#
# Debug: Returns for XSD, Forecast Period 1w: [-0.03009228 -0.03147347 -0.01806632  0.00191338]
#
# Debug: Returns for XSD, Forecast Period 2w: [ 0.03166605 -0.00236881 -0.00767938 -0.00682818 -0.01014771]
#
# Debug: Returns for XSD, Forecast Period 3w: [ 0.00029927 -0.01287085  0.03043181  0.03118892]
#
# Debug: Returns for XSD, Forecast Period 4w: [ 0.01688887  0.00872913 -0.00917508 -0.01149894 -0.02853933]
#
# Debug: Returns for XSD, Forecast Period 5w: [ 0.01654226 -0.0262933  -0.0212327  -0.00151408  0.00012314]
#
# Debug: Returns for XSD, Forecast Period 6w: [ 0.00735774 -0.01020665  0.01792419  0.02804547  0.02432775]
#
# Debug: Returns for XSD, Forecast Period 7w: [ 0.00270301 -0.03786182  0.02432775 -0.00163735 -0.01778955]
#
# Debug: Returns for XSD, Forecast Period 8w: [-0.01184096 -0.00289541  0.02203688 -0.01751514]
#
# Debug: Returns for XSD, Forecast Period 9w: [ 0.01089064 -0.00361345 -0.0082103   0.02376749  0.03831361]
#
# Debug: Returns for XSD, Forecast Period 10w: [-0.00188748 -0.02444638  0.02489398  0.03518082 -0.0307174 ]
#
# Debug: Returns for XSD, Forecast Period 11w: [-0.00761841  0.00760083 -0.028952   -0.02463882 -0.00894715]
#
# Debug: Returns for XSD, Forecast Period 12w: [-0.00168728 -0.00783136  0.02389148  0.02229713 -0.00802498]
#
# Debug: Returns for XSD, Forecast Period 13w: [-0.00224052 -0.00550645  0.02651304  0.00265398]
#
# Debug: Returns for XSD, Forecast Period 14w: [ 0.00678376 -0.0230316   0.00816043 -0.01684528  0.00451571]
#
# Debug: Returns for XSD, Forecast Period 15w: [ 0.00781679  0.02152101 -0.04124594  0.02341867 -0.03762412]
#
# Debug: Returns for XSD, Forecast Period 16w: [-0.02102086  0.00172806 -0.02345107 -0.0211141  -0.03280739]
#
# Debug: Returns for XSD, Forecast Period 17w: [0.01395178 0.01956294 0.02275196 0.02315429 0.01844661]
#
# Debug: Returns for XSD, Forecast Period 18w: [ 0.01767356 -0.01957812 -0.03403236  0.01723592  0.02228774]
#
# Debug: Returns for XSD, Forecast Period 19w: [ 0.01720968 -0.00432262  0.00311107  0.00270301 -0.00747167]
#
# Debug: Returns for XSD, Forecast Period 20w: [ 4.6794866e-03  1.7835604e-02  2.0781634e-02 -5.5819661e-03
#   5.2485655e-05]
#
# Debug: Returns for XSD, Forecast Period 21w: [ 0.0124999  -0.0041373   0.02030614 -0.02245476  0.02263656]
#
# Debug: Returns for XSD, Forecast Period 22w: [ 0.01297599 -0.02005248  0.00443204 -0.00023366]
#
# Debug: Returns for XSD, Forecast Period 23w: [-0.00126733 -0.01602759  0.0399932  -0.00994687 -0.02038581]
#
# Debug: Returns for XSD, Forecast Period 24w: [ 0.01493182  0.00378579  0.02738551 -0.00320309 -0.01789945]
#
# Debug: Returns for XSD, Forecast Period 25w: [ 0.00666187  0.00056791 -0.02306441  0.00042761]
#
# Debug: Returns for XSD, Forecast Period 26w: [-0.02061779  0.00813043  0.00010495 -0.00303722  0.00968144]
#
# Debug: Returns for XSD, Forecast Period 27w: [-0.00448757  0.0205789   0.0090076   0.0042293 ]
#
# Debug: Returns for XSD, Forecast Period 28w: [ 0.02172563 -0.00728635  0.02738989 -0.0136594   0.01123947]
#
# Debug: Returns for XSD, Forecast Period 29w: [ 0.00951646  0.01938473 -0.05466067 -0.00967216 -0.03082972]
#
# Debug: Returns for XSD, Forecast Period 30w: [ 0.0399932  -0.01689531 -0.04637972 -0.02617471  0.02145428]
#
# Debug: Returns for XSD, Forecast Period 31w: [-0.00098229 -0.04344065  0.04154225 -0.06785249 -0.06848913]
#
# Debug: Returns for XSD, Forecast Period 32w: [-0.03131741  0.00396153 -0.03065448  0.06490524 -0.00785781]
#
# Debug: Returns for XSD, Forecast Period 33w: [-0.0007782   0.03878554 -0.01421045  0.05017427 -0.00451652]
#
# Debug: Returns for XSD, Forecast Period 34w: [ 0.01208069 -0.01164689  0.02107836 -0.03164641  0.03246643]
#
# Debug: Returns for XSD, Forecast Period 35w: [-0.02015319  0.0047708  -0.01480324  0.01373685  0.01249094]
#
# Debug: Returns for XSD, Forecast Period 36w: [-0.08443207  0.00241524 -0.01127185 -0.04311293]
#
# Debug: Returns for XSD, Forecast Period 37w: [ 0.01599765  0.00168746  0.0393936  -0.00882323  0.0214669 ]
#
# Debug: Returns for XSD, Forecast Period 38w: [-0.01420209  0.00244894 -0.00487624  0.03868586 -0.01810056]
#
# Debug: Returns for XSD, Forecast Period 39w: [ 0.00238207  0.00861904 -0.00453717  0.04612533 -0.00640932]
#
# Debug: Returns for XSD, Forecast Period 40w: [-0.01224705 -0.03725723  0.01012679 -0.00256913  0.0183483 ]
#
# Debug: Returns for XSD, Forecast Period 41w: [-0.00722149  0.00378579  0.0124999  -0.00580365  0.02078163]
#
# Debug: Returns for XSD, Forecast Period 42w: [ 0.01052825 -0.02794371  0.00575038  0.00285672 -0.00080311]
#
# Debug: Returns for XSD, Forecast Period 43w: [-0.00379926 -0.00071014 -0.01025624  0.00401994  0.01034293]
#
# Debug: Returns for XSD, Forecast Period 44w: [ 0.01123947  0.02322336 -0.04389853 -0.05469306  0.0215051 ]
#
# Debug: Returns for XSD, Forecast Period 45w: [-0.00570042  0.01488508  0.04171991  0.01066218  0.00713274]
#
# Debug: Returns for XSD, Forecast Period 46w: [-0.028952   -0.02089107 -0.02344138 -0.00926246 -0.03404995]
#
# Debug: Returns for XSD, Forecast Period 47w: [ 0.01428366  0.00877042 -0.00030561  0.02793778  0.01446381]
#
# Debug: Returns for XSD, Forecast Period 48w: [ 0.03255966 -0.012539   -0.01260042  0.0190463 ]
#
# Debug: Returns for IYW, Forecast Period 1w: [-0.02378365 -0.00915305 -0.00406055  0.00362251]
#
# Debug: Returns for IYW, Forecast Period 2w: [0.02765851 0.0057929  0.01247163 0.00704194 0.00381901]
#
# Debug: Returns for IYW, Forecast Period 3w: [ 0.00297585 -0.00242258  0.02081324  0.0251478 ]
#
# Debug: Returns for IYW, Forecast Period 4w: [ 0.00692801  0.00692801  0.01020366  0.00721229 -0.00638357]
#
# Debug: Returns for IYW, Forecast Period 5w: [ 0.01366711 -0.00551861 -0.02275165  0.0147932   0.02007826]
#
# Debug: Returns for IYW, Forecast Period 6w: [ 0.00371294 -0.00111832  0.01642323  0.00704194  0.01642323]
#
# Debug: Returns for IYW, Forecast Period 7w: [-0.00500992 -0.01448728  0.01506978  0.00059377 -0.00843429]
#
# Debug: Returns for IYW, Forecast Period 8w: [-0.00729022 -0.00500992  0.03563775  0.00071354]
#
# Debug: Returns for IYW, Forecast Period 9w: [ 0.00046835  0.00344337 -0.00593947  0.0140578   0.0175965 ]
#
# Debug: Returns for IYW, Forecast Period 10w: [ 4.8145030e-05 -2.1106549e-02  1.1856795e-02  1.9324301e-02
#  -1.1263380e-02]
#
# Debug: Returns for IYW, Forecast Period 11w: [-0.00149099  0.02148031 -0.00596848  0.0033887  -0.01268488]
#
# Debug: Returns for IYW, Forecast Period 12w: [0.01118133 0.00714194 0.01523084 0.00533966 0.00587136]
#
# Debug: Returns for IYW, Forecast Period 13w: [-0.00232112 -0.00232112  0.00354258  0.00071354]
#
# Debug: Returns for IYW, Forecast Period 14w: [ 0.00623327 -0.00500992  0.00465535 -0.01371208  0.01659296]
#
# Debug: Returns for IYW, Forecast Period 15w: [-0.00049702  0.00465535 -0.00442794  0.02285689 -0.01397916]
#
# Debug: Returns for IYW, Forecast Period 16w: [-0.01879027  0.00362201 -0.01357423 -0.0053459  -0.02684033]
#
# Debug: Returns for IYW, Forecast Period 17w: [ 0.01370287  0.01869843  0.00441012 -0.00281051  0.02266995]
#
# Debug: Returns for IYW, Forecast Period 18w: [ 0.0035981  -0.01958319 -0.00735692  0.01778223  0.02574506]
#
# Debug: Returns for IYW, Forecast Period 19w: [ 0.01693395 -0.00171846  0.00290562  0.00166135  0.0057929 ]
#
# Debug: Returns for IYW, Forecast Period 20w: [0.00627103 0.01171618 0.02313659 0.00027644 0.00046835]
#
# Debug: Returns for IYW, Forecast Period 21w: [0.01532054 0.00383391 0.00290562 0.00445707 0.01200769]
#
# Debug: Returns for IYW, Forecast Period 22w: [ 0.01325776 -0.0022643  -0.02277976  0.00238259]
#
# Debug: Returns for IYW, Forecast Period 23w: [1.0981857e-02 4.3168450e-03 2.7445029e-02 5.2819862e-05 4.0782751e-03]
#
# Debug: Returns for IYW, Forecast Period 24w: [0.0044493  0.01674931 0.02421417 0.00957935 0.00875168]
#
# Debug: Returns for IYW, Forecast Period 25w: [ 0.01398773  0.00731229 -0.01078545 -0.00356065]
#
# Debug: Returns for IYW, Forecast Period 26w: [-0.0137932   0.01848325  0.00619393  0.00438539 -0.00104605]
#
# Debug: Returns for IYW, Forecast Period 27w: [0.01288489 0.0099206  0.01377878 0.01241855]
#
# Debug: Returns for IYW, Forecast Period 28w: [ 0.00816741  0.00095319  0.01612605 -0.02155854  0.00975025]
#
# Debug: Returns for IYW, Forecast Period 29w: [ 0.00782037 -0.00011753 -0.03549172 -0.00182793 -0.00858158]
#
# Debug: Returns for IYW, Forecast Period 30w: [ 0.02155721  0.00078284 -0.04128522 -0.00699918  0.01230543]
#
# Debug: Returns for IYW, Forecast Period 31w: [-0.00146179 -0.0167072   0.03736739 -0.0288638  -0.02362466]
#
# Debug: Returns for IYW, Forecast Period 32w: [-0.03432429  0.0118117  -0.00868792  0.03652428  0.00929292]
#
# Debug: Returns for IYW, Forecast Period 33w: [0.00896711 0.03040313 0.00639083 0.02591541 0.00423057]
#
# Debug: Returns for IYW, Forecast Period 34w: [ 0.0143044  -0.0003984   0.00871757 -0.0176171   0.01617527]
#
# Debug: Returns for IYW, Forecast Period 35w: [-0.00673125  0.00675765 -0.00975217 -0.0013041   0.01255509]
#
# Debug: Returns for IYW, Forecast Period 36w: [-0.0411757  -0.00184621  0.00180187 -0.02223391]
#
# Debug: Returns for IYW, Forecast Period 37w: [0.01424521 0.01362697 0.03020624 0.01174368 0.00653461]
#
# Debug: Returns for IYW, Forecast Period 38w: [-0.00313661  0.00323971 -0.00147444  0.03342612 -0.0004109 ]
#
# Debug: Returns for IYW, Forecast Period 39w: [ 0.00166135  0.01003331  0.00443116  0.01241286 -0.00660234]
#
# Debug: Returns for IYW, Forecast Period 40w: [ 0.00656845 -0.02034269  0.00898983  0.00544952  0.01559621]
#
# Debug: Returns for IYW, Forecast Period 41w: [-0.00570457  0.01803704  0.01035408  0.00186026  0.00361372]
#
# Debug: Returns for IYW, Forecast Period 42w: [ 0.01576656 -0.01513814  0.00121487  0.00554661  0.00467861]
#
# Debug: Returns for IYW, Forecast Period 43w: [ 0.0096627   0.00121752 -0.01497112  0.00485996  0.009409  ]
#
# Debug: Returns for IYW, Forecast Period 44w: [ 0.00430098  0.01617527 -0.01090552 -0.0311389   0.00967319]
#
# Debug: Returns for IYW, Forecast Period 45w: [0.00079089 0.01498654 0.0303267  0.02198288 0.00121606]
#
# Debug: Returns for IYW, Forecast Period 46w: [-0.00185419  0.00623327 -0.00204538 -0.00246777 -0.02221784]
#
# Debug: Returns for IYW, Forecast Period 47w: [ 0.00689669  0.01506978 -0.00053258  0.0096627   0.00156042]
#
# Debug: Returns for IYW, Forecast Period 48w: [ 0.00263693  0.00594949 -0.01090552  0.01003406]
#
# Debug: Returns for XLK, Forecast Period 1w: [-0.0268153  -0.0102829  -0.00730343 -0.00020264]
#
# Debug: Returns for XLK, Forecast Period 2w: [0.02447443 0.00169094 0.0083206  0.00508714 0.00295791]
#
# Debug: Returns for XLK, Forecast Period 3w: [ 0.00224792 -0.0049948   0.02003052  0.02252478]
#
# Debug: Returns for XLK, Forecast Period 4w: [ 0.00415516  0.00394052  0.00658321  0.00394052 -0.01182111]
#
# Debug: Returns for XLK, Forecast Period 5w: [ 0.00871278 -0.00863449 -0.02210913  0.01217685  0.01026616]
#
# Debug: Returns for XLK, Forecast Period 6w: [ 0.00215964 -0.00484885  0.01301926  0.00312444  0.01354144]
#
# Debug: Returns for XLK, Forecast Period 7w: [-0.00784998 -0.01710857  0.01047393 -0.0021738  -0.00913919]
#
# Debug: Returns for XLK, Forecast Period 8w: [-0.0102829  -0.00630636  0.03161941 -0.0021738 ]
#
# Debug: Returns for XLK, Forecast Period 9w: [ 0.00101046  0.00074341 -0.00477155  0.01121035  0.01807042]
#
# Debug: Returns for XLK, Forecast Period 10w: [-2.4953139e-05 -2.4891876e-02  7.9653114e-03  1.5609854e-02
#  -1.5091460e-02]
#
# Debug: Returns for XLK, Forecast Period 11w: [-2.7247425e-03  2.0238295e-02 -1.0543114e-02 -2.4953139e-05
#  -1.5233234e-02]
#
# Debug: Returns for XLK, Forecast Period 12w: [0.00485839 0.00512488 0.01121035 0.00074341 0.00036028]
#
# Debug: Returns for XLK, Forecast Period 13w: [-0.00648692 -0.00402508  0.00512488 -0.0021738 ]
#
# Debug: Returns for XLK, Forecast Period 14w: [ 0.00262422 -0.00966522  0.00262422 -0.01609582  0.01121035]
#
# Debug: Returns for XLK, Forecast Period 15w: [-0.00131559  0.00508714 -0.01236969  0.01985106 -0.01609582]
#
# Debug: Returns for XLK, Forecast Period 16w: [-0.0193412   0.00113862 -0.01455531 -0.01151987 -0.02114927]
#
# Debug: Returns for XLK, Forecast Period 17w: [ 0.00891551  0.0148821   0.00450046 -0.0021738   0.01121035]
#
# Debug: Returns for XLK, Forecast Period 18w: [ 0.00427696 -0.02260099 -0.0102829   0.01387787  0.02729083]
#
# Debug: Returns for XLK, Forecast Period 19w: [ 0.01146163 -0.00333553  0.00262422 -0.00020264  0.00372939]
#
# Debug: Returns for XLK, Forecast Period 20w: [ 0.00477107  0.00882204  0.02273256 -0.00350379 -0.0021738 ]
#
# Debug: Returns for XLK, Forecast Period 21w: [ 0.01146163  0.00148316  0.00215964 -0.00840206  0.00811283]
#
# Debug: Returns for XLK, Forecast Period 22w: [ 0.00394052 -0.00651413 -0.02397619  0.00148316]
#
# Debug: Returns for XLK, Forecast Period 23w: [ 0.00224792  0.00170264  0.02107536 -0.00360318  0.00215964]
#
# Debug: Returns for XLK, Forecast Period 24w: [0.00235766 0.01786265 0.02107536 0.00775754 0.00352162]
#
# Debug: Returns for XLK, Forecast Period 25w: [ 0.01480981  0.00093085 -0.01162921 -0.00198371]
#
# Debug: Returns for XLK, Forecast Period 26w: [-0.02509965  0.01786265 -0.00152336  0.00023152 -0.00088851]
#
# Debug: Returns for XLK, Forecast Period 27w: [0.00726728 0.00465062 0.01333367 0.002788  ]
#
# Debug: Returns for XLK, Forecast Period 28w: [ 0.00658321 -0.00102521  0.01387787 -0.02641425  0.00882204]
#
# Debug: Returns for XLK, Forecast Period 29w: [ 1.7279555e-03 -3.3954047e-03 -3.9911825e-02 -2.4953139e-05
#  -1.5923625e-02]
#
# Debug: Returns for XLK, Forecast Period 30w: [ 0.0235272  -0.00398287 -0.04378968 -0.01065709  0.01242829]
#
# Debug: Returns for XLK, Forecast Period 31w: [-0.0043991  -0.02636921  0.04134716 -0.03780016 -0.02893719]
#
# Debug: Returns for XLK, Forecast Period 32w: [-0.03519109  0.01363948 -0.01599449  0.03586001  0.00429269]
#
# Debug: Returns for XLK, Forecast Period 33w: [0.007824   0.03005107 0.00526368 0.02883927 0.00148316]
#
# Debug: Returns for XLK, Forecast Period 34w: [ 0.01627401 -0.00371156  0.00573188 -0.02397619  0.01590587]
#
# Debug: Returns for XLK, Forecast Period 35w: [-0.01283579  0.00586903 -0.01424203 -0.00934696  0.01301926]
#
# Debug: Returns for XLK, Forecast Period 36w: [-0.04691336 -0.00262717 -0.00147262 -0.02692927]
#
# Debug: Returns for XLK, Forecast Period 37w: [0.01652545 0.01467433 0.03358708 0.00802189 0.00487937]
#
# Debug: Returns for XLK, Forecast Period 38w: [-0.00409589 -0.00222113 -0.00934696  0.02883927 -0.0049948 ]
#
# Debug: Returns for XLK, Forecast Period 39w: [-0.00041041  0.00658321  0.002788    0.01281148 -0.009602  ]
#
# Debug: Returns for XLK, Forecast Period 40w: [ 0.002788   -0.02493784  0.00714952  0.00394052  0.01121035]
#
# Debug: Returns for XLK, Forecast Period 41w: [-0.00705833  0.01807042  0.01121035 -0.00041041  0.00152018]
#
# Debug: Returns for XLK, Forecast Period 42w: [ 0.01271558 -0.02280876  0.002788    0.002788    0.0032284 ]
#
# Debug: Returns for XLK, Forecast Period 43w: [ 0.0045633  -0.00091934 -0.01444133  0.00299577  0.00491711]
#
# Debug: Returns for XLK, Forecast Period 44w: [-0.00041041  0.01333367 -0.01609582 -0.03252207  0.00747505]
#
# Debug: Returns for XLK, Forecast Period 45w: [-0.00081744  0.01388544  0.02910793  0.01727437 -0.00131559]
#
# Debug: Returns for XLK, Forecast Period 46w: [-0.00539985  0.00126576 -0.00350379 -0.0033954  -0.02489188]
#
# Debug: Returns for XLK, Forecast Period 47w: [ 0.00316568  0.00803177 -0.00091934  0.00996618  0.00043929]
#
# Debug: Returns for XLK, Forecast Period 48w: [-0.00020264  0.00508714 -0.01385754  0.0093863 ]
#
# Debug: Returns for VGT, Forecast Period 1w: [-0.02442194 -0.01180725 -0.00426407  0.00331717]
#
# Debug: Returns for VGT, Forecast Period 2w: [0.03033014 0.0064379  0.01152657 0.00671912 0.00534567]
#
# Debug: Returns for VGT, Forecast Period 3w: [ 0.00456571 -0.00386249  0.02689391  0.02858594]
#
# Debug: Returns for VGT, Forecast Period 4w: [ 0.00961831  0.00729106  0.00782924  0.00543274 -0.00906055]
#
# Debug: Returns for VGT, Forecast Period 5w: [ 0.01379366 -0.00833283 -0.01903188  0.0153797   0.01259049]
#
# Debug: Returns for VGT, Forecast Period 6w: [0.003575   0.00138355 0.0153797  0.00818788 0.02279913]
#
# Debug: Returns for VGT, Forecast Period 7w: [-0.00462708 -0.0179705   0.01571785  0.00405848 -0.00914302]
#
# Debug: Returns for VGT, Forecast Period 8w: [-0.01057043 -0.00813568  0.03743219 -0.00103779]
#
# Debug: Returns for VGT, Forecast Period 9w: [ 0.0072963   0.00465419 -0.00291737  0.01270045  0.02541276]
#
# Debug: Returns for VGT, Forecast Period 10w: [ 0.00494564 -0.02212455  0.01319575  0.02598187 -0.01463579]
#
# Debug: Returns for VGT, Forecast Period 11w: [-0.00314348  0.02705162 -0.00914302 -0.0029792  -0.01166341]
#
# Debug: Returns for VGT, Forecast Period 12w: [0.00942765 0.00729106 0.01731626 0.00581966 0.00479114]
#
# Debug: Returns for VGT, Forecast Period 13w: [-0.00322445 -0.00110156  0.00703115  0.00746509]
#
# Debug: Returns for VGT, Forecast Period 14w: [ 0.00522165 -0.0101332   0.0049883  -0.01447389  0.01464931]
#
# Debug: Returns for VGT, Forecast Period 15w: [ 0.00926141  0.00560153 -0.00872193  0.0258536  -0.01340753]
#
# Debug: Returns for VGT, Forecast Period 16w: [-0.01461026  0.00675742 -0.01326    -0.00841086 -0.02289685]
#
# Debug: Returns for VGT, Forecast Period 17w: [0.01643694 0.02681297 0.00806208 0.00693443 0.02725325]
#
# Debug: Returns for VGT, Forecast Period 18w: [ 0.01051528 -0.01775404 -0.00739402  0.02018605  0.03230176]
#
# Debug: Returns for VGT, Forecast Period 19w: [0.02266299 0.00365867 0.00898034 0.00212422 0.01435566]
#
# Debug: Returns for VGT, Forecast Period 20w: [ 8.0706626e-03  1.9169584e-02  2.9389497e-02 -3.1434793e-03
#   6.5999273e-05]
#
# Debug: Returns for VGT, Forecast Period 21w: [0.01487312 0.00420541 0.00331717 0.00331717 0.01267897]
#
# Debug: Returns for VGT, Forecast Period 22w: [ 0.01162387 -0.00109368 -0.02212455  0.00230734]
#
# Debug: Returns for VGT, Forecast Period 23w: [ 0.00828308  0.00532319  0.03033014 -0.0019687   0.00312109]
#
# Debug: Returns for VGT, Forecast Period 24w: [0.00815331 0.01610738 0.02845798 0.01266902 0.00698659]
#
# Debug: Returns for VGT, Forecast Period 25w: [ 0.01453935  0.0071179  -0.01243378 -0.00362049]
#
# Debug: Returns for VGT, Forecast Period 26w: [-0.01682111  0.02341564  0.0051593   0.0051593   0.00283043]
#
# Debug: Returns for VGT, Forecast Period 27w: [0.01259049 0.00964521 0.01372417 0.00818788]
#
# Debug: Returns for VGT, Forecast Period 28w: [ 0.00964521 -0.00139732  0.01610738 -0.01748083  0.01201033]
#
# Debug: Returns for VGT, Forecast Period 29w: [ 0.00828308  0.0043151  -0.03224122 -0.00498272 -0.00871885]
#
# Debug: Returns for VGT, Forecast Period 30w: [ 0.02668137  0.00126753 -0.03894046 -0.00686142  0.01573651]
#
# Debug: Returns for VGT, Forecast Period 31w: [ 0.00011813 -0.01737992  0.04159488 -0.03867128 -0.02217651]
#
# Debug: Returns for VGT, Forecast Period 32w: [-0.03942124  0.01287543 -0.01243827  0.04235553  0.01230308]
#
# Debug: Returns for VGT, Forecast Period 33w: [0.01168047 0.03734145 0.01078981 0.03517155 0.00546105]
#
# Debug: Returns for VGT, Forecast Period 34w: [ 0.01610738 -0.00366234  0.01040985 -0.01914184  0.02535623]
#
# Debug: Returns for VGT, Forecast Period 35w: [-0.00800178  0.00934695 -0.01166341 -0.00186028  0.01245992]
#
# Debug: Returns for VGT, Forecast Period 36w: [-0.0426041  -0.00139732 -0.00208567 -0.02323422]
#
# Debug: Returns for VGT, Forecast Period 37w: [0.01631906 0.01237144 0.03447165 0.01067793 0.01061499]
#
# Debug: Returns for VGT, Forecast Period 38w: [-0.00513618  0.0080748  -0.00106684  0.03495461 -0.00213399]
#
# Debug: Returns for VGT, Forecast Period 39w: [ 0.00283043  0.01375789  0.0038658   0.01475047 -0.00415621]
#
# Debug: Returns for VGT, Forecast Period 40w: [ 0.00581966 -0.02407729  0.00952177  0.008585    0.0153797 ]
#
# Debug: Returns for VGT, Forecast Period 41w: [-0.00559641  0.02701117  0.01353912  0.00394955  0.00778531]
#
# Debug: Returns for VGT, Forecast Period 42w: [ 0.01475047 -0.01651395  0.0069344   0.00698659  0.00815331]
#
# Debug: Returns for VGT, Forecast Period 43w: [ 0.00881144  0.00246007 -0.01413865  0.00664338  0.00782924]
#
# Debug: Returns for VGT, Forecast Period 44w: [ 0.00675771  0.01379366 -0.01166341 -0.03020691  0.01010498]
#
# Debug: Returns for VGT, Forecast Period 45w: [0.00219455 0.02417292 0.03732224 0.02705162 0.00138355]
#
# Debug: Returns for VGT, Forecast Period 46w: [-0.00322445  0.00483949 -0.00311449 -0.00322445 -0.02212455]
#
# Debug: Returns for VGT, Forecast Period 47w: [0.00606922 0.01453935 0.00414944 0.01282476 0.00684591]
#
# Debug: Returns for VGT, Forecast Period 48w: [ 0.00279514  0.00611127 -0.00906055  0.01639856]
#
# Debug: Returns for FTEC, Forecast Period 1w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 2w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 3w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 4w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 5w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 6w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 7w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 8w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 9w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
# Debug: Returns for FTEC, Forecast Period 10w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 11w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 12w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 13w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 14w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 15w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 16w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 17w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 18w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 19w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 20w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 21w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 22w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 23w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 24w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 25w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 26w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 27w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 28w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 29w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 30w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 31w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 32w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 33w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 34w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 35w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 36w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 37w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 38w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 39w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 40w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 41w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 42w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 43w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 44w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 45w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 46w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 47w: [0.00188564 0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for FTEC, Forecast Period 48w: [0.00188564 0.00188564 0.00188564 0.00188564]
#
# Debug: Returns for IGM, Forecast Period 1w: [-0.0280139  -0.01130218 -0.00507506  0.00118798]
#
# Debug: Returns for IGM, Forecast Period 2w: [0.02642782 0.0023095  0.00796697 0.00365767 0.00023481]
#
# Debug: Returns for IGM, Forecast Period 3w: [ 0.00039435 -0.00714029  0.01493375  0.02337625]
#
# Debug: Returns for IGM, Forecast Period 4w: [ 0.00269955  0.00302499  0.00759073  0.00262018 -0.01021126]
#
# Debug: Returns for IGM, Forecast Period 5w: [ 0.01089045 -0.00893395 -0.0265019   0.00970406  0.02642782]
#
# Debug: Returns for IGM, Forecast Period 6w: [-0.00019653 -0.00694482  0.01294825  0.00365767  0.01216121]
#
# Debug: Returns for IGM, Forecast Period 7w: [-0.00669212 -0.01928974  0.01493375 -0.00225911 -0.01301594]
#
# Debug: Returns for IGM, Forecast Period 8w: [-0.01548875 -0.01169881  0.04170076 -0.00336824]
#
# Debug: Returns for IGM, Forecast Period 9w: [-0.00053272  0.00023481 -0.00814229  0.01032802  0.01950443]
#
# Debug: Returns for IGM, Forecast Period 10w: [-0.00035452 -0.02170686  0.01043177  0.01950443 -0.02107126]
#
# Debug: Returns for IGM, Forecast Period 11w: [-0.00881153  0.02077827 -0.01039652 -0.00703977 -0.01432201]
#
# Debug: Returns for IGM, Forecast Period 12w: [0.00889363 0.00035722 0.0119406  0.00128641 0.00193814]
#
# Debug: Returns for IGM, Forecast Period 13w: [-0.00620467 -0.00521247 -0.0007422  -0.00343019]
#
# Debug: Returns for IGM, Forecast Period 14w: [ 0.00370675 -0.00757469  0.00383181 -0.01711619  0.01267863]
#
# Debug: Returns for IGM, Forecast Period 15w: [-0.00051107  0.00374707 -0.00911228  0.01645501 -0.01771573]
#
# Debug: Returns for IGM, Forecast Period 16w: [-0.02073054  0.00219424 -0.0133673  -0.00521427 -0.02861815]
#
# Debug: Returns for IGM, Forecast Period 17w: [ 0.01030446  0.01831636  0.00019498 -0.00949633  0.02392199]
#
# Debug: Returns for IGM, Forecast Period 18w: [-0.00388308 -0.01979373 -0.00809188  0.01449943  0.01977566]
#
# Debug: Returns for IGM, Forecast Period 19w: [ 0.01522141 -0.00117949 -0.00050552 -0.00115276  0.00251225]
#
# Debug: Returns for IGM, Forecast Period 20w: [ 0.0015894   0.00701645  0.02180013 -0.00504669 -0.00264392]
#
# Debug: Returns for IGM, Forecast Period 21w: [ 0.00877122 -0.00250797 -0.00019653 -0.00480774  0.00693532]
#
# Debug: Returns for IGM, Forecast Period 22w: [ 0.00625983 -0.00694482 -0.02555133 -0.00215768]
#
# Debug: Returns for IGM, Forecast Period 23w: [ 0.003264    0.00081663  0.02496287 -0.00405843 -0.00280011]
#
# Debug: Returns for IGM, Forecast Period 24w: [0.0039128  0.00857724 0.01596752 0.00319514 0.00428863]
#
# Debug: Returns for IGM, Forecast Period 25w: [ 0.00799171  0.00083292 -0.01117576 -0.00533489]
#
# Debug: Returns for IGM, Forecast Period 26w: [-0.01607482  0.01237538 -0.00119842  0.00359328 -0.00480774]
#
# Debug: Returns for IGM, Forecast Period 27w: [0.0047314  0.00535298 0.00736247 0.00881523]
#
# Debug: Returns for IGM, Forecast Period 28w: [ 0.00083292 -0.00463886  0.00855705 -0.02286739  0.00373769]
#
# Debug: Returns for IGM, Forecast Period 29w: [ 0.00334778 -0.00186232 -0.04038062 -0.00379547 -0.01049791]
#
# Debug: Returns for IGM, Forecast Period 30w: [ 0.01864039 -0.00155457 -0.04342056 -0.00926847  0.01174351]
#
# Debug: Returns for IGM, Forecast Period 31w: [-0.0034955  -0.01560756  0.03175141 -0.02569775 -0.02918941]
#
# Debug: Returns for IGM, Forecast Period 32w: [-0.03260926  0.01168451 -0.00914555  0.03681382  0.00684657]
#
# Debug: Returns for IGM, Forecast Period 33w: [0.00115841 0.02613933 0.00101539 0.02604621 0.00089774]
#
# Debug: Returns for IGM, Forecast Period 34w: [ 0.01109505 -0.00132978  0.00617921 -0.01916733  0.01045044]
#
# Debug: Returns for IGM, Forecast Period 35w: [-0.01095653  0.00238022 -0.01400333 -0.00015948  0.00889363]
#
# Debug: Returns for IGM, Forecast Period 36w: [-0.04067953 -0.00323944 -0.0014557  -0.02799596]
#
# Debug: Returns for IGM, Forecast Period 37w: [0.01041857 0.00961432 0.02297032 0.00808939 0.00485382]
#
# Debug: Returns for IGM, Forecast Period 38w: [-0.00155457  0.00097475 -0.00500377  0.03072307 -0.00117949]
#
# Debug: Returns for IGM, Forecast Period 39w: [-0.00066886  0.00564948 -0.00053272  0.00970406 -0.00870563]
#
# Debug: Returns for IGM, Forecast Period 40w: [ 0.00175803 -0.01782492  0.00371875  0.00345785  0.01110462]
#
# Debug: Returns for IGM, Forecast Period 41w: [-0.01151896  0.01452525  0.00600555 -0.00197842  0.00262916]
#
# Debug: Returns for IGM, Forecast Period 42w: [ 0.00796697 -0.01856779 -0.00168442 -0.00085198  0.00384016]
#
# Debug: Returns for IGM, Forecast Period 43w: [ 0.00161703 -0.00157811 -0.01686678  0.00165745  0.00442949]
#
# Debug: Returns for IGM, Forecast Period 44w: [ 0.00137026  0.0133196  -0.01211411 -0.02810225  0.00591466]
#
# Debug: Returns for IGM, Forecast Period 45w: [-0.00289247  0.01228092  0.02944737  0.01950443 -0.00386276]
#
# Debug: Returns for IGM, Forecast Period 46w: [-0.00358972  0.00175803 -0.00580282 -0.00835535 -0.02379777]
#
# Debug: Returns for IGM, Forecast Period 47w: [ 0.00561367  0.00915181 -0.0012922   0.00442949 -0.00066886]
#
# Debug: Returns for IGM, Forecast Period 48w: [ 0.00099891  0.00173945 -0.01017388  0.00724695]
#
# Debug: Returns for IXN, Forecast Period 1w: [-0.02784162 -0.01135639 -0.00526613  0.00081999]
#
# Debug: Returns for IXN, Forecast Period 2w: [ 0.02407856 -0.00054723  0.00868966  0.0041876   0.00402659]
#
# Debug: Returns for IXN, Forecast Period 3w: [ 3.0897474e-05 -4.8046163e-03  2.1219410e-02  2.3111852e-02]
#
# Debug: Returns for IXN, Forecast Period 4w: [ 0.0045952   0.00436043  0.00804607  0.00501079 -0.00888609]
#
# Debug: Returns for IXN, Forecast Period 5w: [ 0.00887999 -0.00695099 -0.01954983  0.01319894  0.01029733]
#
# Debug: Returns for IXN, Forecast Period 6w: [ 0.00254326 -0.00218349  0.01360978  0.00547494  0.01203478]
#
# Debug: Returns for IXN, Forecast Period 7w: [-0.00771513 -0.0170658   0.01199651 -0.00048422 -0.00862832]
#
# Debug: Returns for IXN, Forecast Period 8w: [-0.00993403 -0.00525937  0.03118985  0.00036075]
#
# Debug: Returns for IXN, Forecast Period 9w: [ 0.00114569 -0.00046368 -0.00419941  0.00947668  0.01903136]
#
# Debug: Returns for IXN, Forecast Period 10w: [ 0.00259824 -0.02188523  0.01100181  0.01745803 -0.0141799 ]
#
# Debug: Returns for IXN, Forecast Period 11w: [-0.00674588  0.02197782 -0.00974822 -0.00080662 -0.01517651]
#
# Debug: Returns for IXN, Forecast Period 12w: [0.00603125 0.00400856 0.01512892 0.00291874 0.00236762]
#
# Debug: Returns for IXN, Forecast Period 13w: [-0.00544563 -0.00520572  0.00221664 -0.00218987]
#
# Debug: Returns for IXN, Forecast Period 14w: [ 0.00332976 -0.00780654  0.00257382 -0.01628666  0.01214181]
#
# Debug: Returns for IXN, Forecast Period 15w: [-0.00166232  0.0049251  -0.01102378  0.02103779 -0.01705799]
#
# Debug: Returns for IXN, Forecast Period 16w: [-0.01711723  0.00191221 -0.01706793 -0.01124366 -0.02608306]
# Debug: Returns for IXN, Forecast Period 17w: [0.0085572  0.01856788 0.00696429 0.00086275 0.01693615]
#
# Debug: Returns for IXN, Forecast Period 18w: [ 0.00554514 -0.02009562 -0.00867489  0.01666768  0.02702748]
#
# Debug: Returns for IXN, Forecast Period 19w: [ 0.01468367 -0.00292088  0.00314102 -0.0022354   0.00494347]
#
# Debug: Returns for IXN, Forecast Period 20w: [ 0.00367028  0.01085002  0.02228012 -0.0035034  -0.00355276]
#
# Debug: Returns for IXN, Forecast Period 21w: [0.01275721 0.0017417  0.00140027 0.00257542 0.01009258]
#
# Debug: Returns for IXN, Forecast Period 22w: [ 0.01046238 -0.00676216 -0.01924742 -0.00237954]
#
# Debug: Returns for IXN, Forecast Period 23w: [ 0.00974435  0.0024628   0.02559586 -0.00130096  0.0012142 ]
#
# Debug: Returns for IXN, Forecast Period 24w: [0.00348981 0.01396206 0.02683176 0.00760694 0.0028958 ]
#
# Debug: Returns for IXN, Forecast Period 25w: [ 0.01348054  0.00515535 -0.01148284 -0.00575184]
#
# Debug: Returns for IXN, Forecast Period 26w: [-0.02010822  0.01745803  0.00099361  0.00157502 -0.00141018]
#
# Debug: Returns for IXN, Forecast Period 27w: [0.01019937 0.00623939 0.01623429 0.00577002]
#
# Debug: Returns for IXN, Forecast Period 28w: [ 0.0085625  -0.0004166   0.01610111 -0.02469714  0.00650924]
#
# Debug: Returns for IXN, Forecast Period 29w: [ 0.00058502  0.000468   -0.03852461 -0.00266172 -0.01269212]
#
# Debug: Returns for IXN, Forecast Period 30w: [ 0.01943493 -0.00097502 -0.04094249 -0.01205813  0.01317968]
#
# Debug: Returns for IXN, Forecast Period 31w: [-0.00412429 -0.02104081  0.04321603 -0.04002421 -0.02842853]
#
# Debug: Returns for IXN, Forecast Period 32w: [-0.03517929  0.01150597 -0.0122009   0.03620179  0.00746125]
#
# Debug: Returns for IXN, Forecast Period 33w: [0.00865819 0.0317564  0.0060136  0.02785216 0.00415416]
#
# Debug: Returns for IXN, Forecast Period 34w: [ 0.01553577 -0.00253936  0.00636155 -0.02198536  0.01685415]
#
# Debug: Returns for IXN, Forecast Period 35w: [-0.01457929  0.00799755 -0.01102277 -0.00711192  0.01074241]
#
# Debug: Returns for IXN, Forecast Period 36w: [-0.04936698 -0.00213842 -0.00199857 -0.02841469]
#
# Debug: Returns for IXN, Forecast Period 37w: [0.01640676 0.01129077 0.03073818 0.00828399 0.00486283]
#
# Debug: Returns for IXN, Forecast Period 38w: [-0.00489305 -0.00076054 -0.00449614  0.02985013 -0.00584387]
#
# Debug: Returns for IXN, Forecast Period 39w: [ 0.00064867  0.00577111  0.00058072  0.01657198 -0.01036452]
#
# Debug: Returns for IXN, Forecast Period 40w: [ 0.00092538 -0.0200298   0.00483639  0.00064731  0.00935729]
#
# Debug: Returns for IXN, Forecast Period 41w: [-0.00924074  0.01824394  0.01223871 -0.00331293  0.00317709]
#
# Debug: Returns for IXN, Forecast Period 42w: [ 0.01074081 -0.01929194  0.00031195  0.00654036  0.00355545]
#
# Debug: Returns for IXN, Forecast Period 43w: [ 0.00367015  0.00012869 -0.01545171  0.00277017  0.00503623]
#
# Debug: Returns for IXN, Forecast Period 44w: [-0.00044714  0.01228602 -0.01428728 -0.02813331  0.00345433]
#
# Debug: Returns for IXN, Forecast Period 45w: [-0.00167932  0.01461637  0.0177635   0.01994293 -0.00373321]
#
# Debug: Returns for IXN, Forecast Period 46w: [-0.00799059  0.00077857 -0.00356522 -0.00180324 -0.01898239]
#
# Debug: Returns for IXN, Forecast Period 47w: [ 0.00714859  0.00634619 -0.00036578  0.0064762   0.00317759]
#
# Debug: Returns for IXN, Forecast Period 48w: [ 0.00272503  0.00314228 -0.00990602  0.01060764]

# %%
# Initialize an empty dictionary to hold DataFrames for each week
weekly_scores_dfs = {}

# Assuming weekly_scores is a dictionary with keys as week identifiers ('1w', '2w', ..., '48w') 
# and values as the respective scores
for week_key, scores in weekly_scores.items():
    # Convert scores for the current week into a DataFrame
    weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    
# Create DataFrame variables dynamically for 48 weeks
for week in range(1, 49):
    week_key = f'{week}w'
    globals()[f'df_scores_{week_key}'] = weekly_scores_dfs.get(week_key, pd.DataFrame())

# %%
# Initialize a dictionary to hold the top 2 ETFs for each week
top_etfs_weekly = {}

# Loop through the weekly DataFrames and select the top 2 ETFs for each week
for week_key, df_scores in weekly_scores_dfs.items():
    # Select the top 2 ETFs based on the 'Score' column
    top_etfs_weekly[week_key] = df_scores.nlargest(2, 'SmoothedScore')
    
    # Print the results for the current week
    print(f"\nTop 2 ETFs for {week_key} forecast:")
    print(top_etfs_weekly[week_key])
# Out:
# Top 2 ETFs for 1w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC   1w             0.1  9.109026       1.243986
# 8   IGM   1w             0.1  0.193409       1.033871
#
# Top 2 ETFs for 2w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6  VGT   2w             0.1  4.679091       1.227771
# 5  XLK   2w             0.1  2.424547       0.364940
#
# Top 2 ETFs for 3w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   3w             0.1  2.292537       2.292537
# 1  SOXX   3w             0.1  1.273678       2.088765
#
# Top 2 ETFs for 4w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0  SMH   4w             0.1  0.947490       0.947490
# 9  IXN   4w             0.1  1.460691       0.546374
#
# Top 2 ETFs for 5w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   5w             0.1  2.200688       2.200688
# 1  SOXX   5w             0.1 -0.668067       1.626937
#
# Top 2 ETFs for 6w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   6w             0.1  2.990129       2.990129
# 1  SOXX   6w             0.1 -0.468359       2.298432
#
# Top 2 ETFs for 7w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 2   PSI   7w             0.1  2.735024       1.011759
# 1  SOXX   7w             0.1  0.841106       0.580942
#
# Top 2 ETFs for 8w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   8w             0.1  2.566185       2.566185
# 1  SOXX   8w             0.1  0.867818       2.226512
#
# Top 2 ETFs for 9w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 2  PSI   9w             0.1  3.115266       1.480597
# 3  XSD   9w             0.1  0.953768       1.375231
#
# Top 2 ETFs for 10w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  10w             0.1  2.403178       2.403178
# 1  SOXX  10w             0.1  0.061400       1.934822
#
# Top 2 ETFs for 11w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9   IXN  11w             0.1  1.210421        0.63229
# 7  FTEC  11w             0.1  3.004942        0.53156
#
# Top 2 ETFs for 12w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6  VGT  12w             0.1  4.326899       0.962072
# 4  IYW  12w             0.1  5.188535       0.145501
#
# Top 2 ETFs for 13w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  13w             0.1  3.811529       0.921827
# 4   IYW  13w             0.1  1.191772       0.390912
#
# Top 2 ETFs for 14w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  14w             0.1  3.641458       0.567755
# 8   IGM  14w             0.1 -0.496155       0.354973
#
# Top 2 ETFs for 15w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  15w             0.1  3.045445       0.838142
# 8   IGM  15w             0.1 -1.805745       0.309365
#
# Top 2 ETFs for 16w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  16w             0.1  5.497780       0.607373
# 8   IGM  16w             0.1  0.070545       0.500008
#
# Top 2 ETFs for 17w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3  XSD  17w             0.1  3.280328       1.504188
# 2  PSI  17w             0.1  3.031287       1.060153
#
# Top 2 ETFs for 18w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  18w             0.1  1.647331       0.339514
# 6  VGT  18w             0.1  3.702006       0.212201
#
# Top 2 ETFs for 19w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6  VGT  19w             0.1  9.152255       1.657169
# 0  SMH  19w             0.1  0.401177       0.401177
#
# Top 2 ETFs for 20w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6  VGT  20w             0.1  2.759905       1.270734
# 4  IYW  20w             0.1  6.095238       1.057910
#
# Top 2 ETFs for 21w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  21w             0.1  2.842632       2.842632
# 1  SOXX  21w             0.1  1.107836       2.495673
#
# Top 2 ETFs for 22w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  22w             0.1  5.810494       0.975846
# 8   IGM  22w             0.1 -2.945599       0.191557
#
# Top 2 ETFs for 23w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0  SMH  23w             0.1  1.504824       1.504824
# 6  VGT  23w             0.1  2.061860       1.070680
#
# Top 2 ETFs for 24w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6  VGT  24w             0.1  4.112099       1.146331
# 5  XLK  24w             0.1  1.189805       0.404889
#
# Top 2 ETFs for 25w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  25w             0.1  2.425910       0.458852
# 9   IXN  25w             0.1  1.193108       0.296377
#
# Top 2 ETFs for 26w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  26w             0.1  1.651113       0.480138
# 6   VGT  26w             0.1  4.014928       0.187394
#
# Top 2 ETFs for 27w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6  VGT  27w             0.1  4.317266       1.313679
# 4  IYW  27w             0.1  6.102155       0.656823
#
# Top 2 ETFs for 28w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3  XSD  28w             0.1  4.668281       1.650822
# 4  IYW  28w             0.1 -0.340968       1.252464
#
# Top 2 ETFs for 29w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  29w             0.1  5.081711       0.600869
# 8   IGM  29w             0.1 -0.620216       0.356652
#
# Top 2 ETFs for 30w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  30w             0.1  4.545943       0.671826
# 8   IGM  30w             0.1 -1.325187       0.272423
#
# Top 2 ETFs for 31w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  31w             0.1  0.597137       0.477506
# 9  IXN  31w             0.1  0.358008       0.453606
#
# Top 2 ETFs for 32w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 2   PSI  32w             0.1  3.897198       1.463719
# 1  SOXX  32w             0.1  1.637048       0.855349
#
# Top 2 ETFs for 33w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  33w             0.1  2.603428       2.603428
# 1  SOXX  33w             0.1 -0.688338       1.945075
#
# Top 2 ETFs for 34w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6   VGT  34w             0.1  3.312991       0.420816
# 7  FTEC  34w             0.1 -1.115956       0.113462
#
# Top 2 ETFs for 35w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  35w             0.1  3.888058       0.760069
# 8   IGM  35w             0.1 -1.708971       0.266261
#
# Top 2 ETFs for 36w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  36w             0.1  5.666103       0.470759
# 8   IGM  36w             0.1  0.274488       0.431505
#
# Top 2 ETFs for 37w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  37w             0.1  2.874689       2.874689
# 1  SOXX  37w             0.1 -0.240681       2.251615
#
# Top 2 ETFs for 38w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  38w             0.1  1.908408       0.230801
# 9  IXN  38w             0.1  0.077931       0.200227
#
# Top 2 ETFs for 39w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0  SMH  39w             0.1  1.543182       1.543182
# 2  PSI  39w             0.1  1.933125       1.530759
#
# Top 2 ETFs for 40w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  40w             0.1  0.804079       0.804079
# 7  FTEC  40w             0.1  1.248886       0.668375
#
# Top 2 ETFs for 41w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  41w             0.1  3.126560       3.126560
# 1  SOXX  41w             0.1 -0.078614       2.485526
#
# Top 2 ETFs for 42w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  42w             0.1  2.071877       0.518817
# 9   IXN  42w             0.1  0.836399       0.337385
#
# Top 2 ETFs for 43w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  43w             0.1  1.631011       1.631011
# 7  FTEC  43w             0.1  1.705746       1.194899
#
# Top 2 ETFs for 44w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  44w             0.1  4.953757       0.781877
# 8   IGM  44w             0.1  0.381742       0.701850
#
# Top 2 ETFs for 45w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6  VGT  45w             0.1  5.465419       1.417634
# 4  IYW  45w             0.1  3.551635       0.470099
#
# Top 2 ETFs for 46w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  46w             0.1  3.844901       0.487200
# 9   IXN  46w             0.1  0.394098       0.360422
#
# Top 2 ETFs for 47w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 6  VGT  47w             0.1  5.369646       0.921524
# 4  IYW  47w             0.1  0.166054      -0.174328
#
# Top 2 ETFs for 48w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  48w             0.1  3.878350       0.078331
# 8   IGM  48w             0.1 -0.591684      -0.055672

# %%
# Function to generate week ranges
def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []
    
    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)
    
    return week_ranges

# Function to gather ETF data for weeks
def gather_etf_data_for_weeks(tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date)
            if etf_data.empty:
                print(f"No data found for {ticker} in {week}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[week][ticker] = etf_data
            #print(f"Data for {ticker} in {week} gathered.")
    return etf_histories

# Function to initialize shares for the first week
def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]
    
    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)
        
        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]
            
            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st week: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares

# Function to manage ETF portfolio weekly
def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

# %%
# Generate Week Ranges
week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')
#print("Generated Week Ranges:", week_ranges)

# Assuming `tickers` is a list of ETF tickers
tickers = tickers

# Gather ETF Data
etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)
#print(f"ETF Histories Collected for {len(etf_histories)} weeks")

# Create a mapping between week numbers and date ranges
week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

# Debug: Print the week key mapping
print("Week Key Mapping:", week_key_mapping)

# Align `top_etfs_weekly` Keys with `etf_histories`
aligned_top_etfs_weekly = {}

for week_key, df_scores in weekly_scores_dfs.items():
    # Call the `select_top_etfs_weekly` function here
    forecast_period = week_key_mapping.get(week_key, None)
    if forecast_period:
        aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

# Portfolio initialization and management
ticker_shares = {}
ticker_shares_per_week = {}

for i, week_range in enumerate(etf_histories.keys()):
    current_week_key = week_range
    if i == 0:
        # First week initialization
        ticker_shares = initialize_shares_for_first_week(
            aligned_top_etfs_weekly[current_week_key],
            etf_histories,
            current_week_key
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()
    else:
        # Subsequent weeks' portfolio management
        prev_week_key = list(etf_histories.keys())[i - 1]
        ticker_shares = manage_etf_portfolio_weekly(
            aligned_top_etfs_weekly[prev_week_key],
            aligned_top_etfs_weekly[current_week_key],
            prev_week_key,
            current_week_key,
            ticker_shares,
            etf_histories
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()

print("\nFinal Ticker Shares per Week:")
for week, shares in ticker_shares_per_week.items():
    print(f"Week {week}: {shares}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Week Key Mapping: {'1w': '2024-01-01 to 2024-01-07', '2w': '2024-01-08 to 2024-01-14', '3w': '2024-01-15 to 2024-01-21', '4w': '2024-01-22 to 2024-01-28', '5w': '2024-01-29 to 2024-02-04', '6w': '2024-02-05 to 2024-02-11', '7w': '2024-02-12 to 2024-02-18', '8w': '2024-02-19 to 2024-02-25', '9w': '2024-02-26 to 2024-03-03', '10w': '2024-03-04 to 2024-03-10', '11w': '2024-03-11 to 2024-03-17', '12w': '2024-03-18 to 2024-03-24', '13w': '2024-03-25 to 2024-03-31', '14w': '2024-04-01 to 2024-04-07', '15w': '2024-04-08 to 2024-04-14', '16w': '2024-04-15 to 2024-04-21', '17w': '2024-04-22 to 2024-04-28', '18w': '2024-04-29 to 2024-05-05', '19w': '2024-05-06 to 2024-05-12', '20w': '2024-05-13 to 2024-05-19', '21w': '2024-05-20 to 2024-05-26', '22w': '2024-05-27 to 2024-06-02', '23w': '2024-06-03 to 2024-06-09', '24w': '2024-06-10 to 2024-06-16', '25w': '2024-06-17 to 2024-06-23', '26w': '2024-06-24 to 2024-06-30', '27w': '2024-07-01 to 2024-07-07', '28w': '2024-07-08 to 2024-07-14', '29w': '2024-07-15 to 2024-07-21', '30w': '2024-07-22 to 2024-07-28', '31w': '2024-07-29 to 2024-08-04', '32w': '2024-08-05 to 2024-08-11', '33w': '2024-08-12 to 2024-08-18', '34w': '2024-08-19 to 2024-08-25', '35w': '2024-08-26 to 2024-09-01', '36w': '2024-09-02 to 2024-09-08', '37w': '2024-09-09 to 2024-09-15', '38w': '2024-09-16 to 2024-09-22', '39w': '2024-09-23 to 2024-09-29', '40w': '2024-09-30 to 2024-10-06', '41w': '2024-10-07 to 2024-10-13', '42w': '2024-10-14 to 2024-10-20', '43w': '2024-10-21 to 2024-10-27', '44w': '2024-10-28 to 2024-11-03', '45w': '2024-11-04 to 2024-11-10', '46w': '2024-11-11 to 2024-11-17', '47w': '2024-11-18 to 2024-11-24', '48w': '2024-11-25 to 2024-12-01'}
# Shares 1st week: (50000 * 0.975) / 139.7899932861328
# Ticker: FTEC, First trading day: 2024-01-02, Price: 139.7899932861328, Shares: 348.74
# Shares 1st week: (50000 * 0.975) / 72.7249984741211
# Ticker: IGM, First trading day: 2024-01-02, Price: 72.7249984741211, Shares: 670.33
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['VGT', 'XLK']
# Sell FTEC: 348.74 shares at 140.66. Total value: 47827.07
# Buy VGT: 98.37 shares at 474.06.
# Sell IGM: 670.33 shares at 73.74. Total value: 48191.36
# Buy XLK: 248.95 shares at 188.74.
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'VGT': 98.36601595602471, 'XLK': 248.94869581720206}
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['VGT', 'XLK']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Sell VGT: 98.37 shares at 482.39. Total value: 46264.51
# Buy SMH: 256.73 shares at 175.70.
# Sell XLK: 248.95 shares at 192.72. Total value: 46777.96
# Buy SOXX: 242.04 shares at 188.43.
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'SMH': 256.7325111408514, 'SOXX': 242.04484931850018}
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['SMH', 'IXN']
# Sell SOXX: 242.04 shares at 201.07. Total value: 47450.47
# Buy IXN: 653.82 shares at 70.76.
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'SMH': 256.7325111408514, 'IXN': 653.8186662396529}
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['SMH', 'IXN']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'SOXX']
# Sell IXN: 653.82 shares at 71.84. Total value: 45796.07
# Buy SOXX: 221.78 shares at 201.33.
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'SMH': 256.7325111408514, 'SOXX': 221.7810068514909}
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'SMH': 256.7325111408514, 'SOXX': 221.7810068514909}
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SOXX']
# Sell SMH: 256.73 shares at 203.06. Total value: 50828.80
# Buy PSI: 940.74 shares at 52.68.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'SOXX': 221.7810068514909, 'PSI': 940.7380449608432}
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SOXX']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'SOXX']
# Sell PSI: 940.74 shares at 51.59. Total value: 47319.36
# Buy SMH: 233.27 shares at 197.78.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'SOXX': 221.7810068514909, 'SMH': 233.271186652357}
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Sell SMH: 233.27 shares at 210.35. Total value: 47841.88
# Buy PSI: 874.83 shares at 53.32.
# Sell SOXX: 221.78 shares at 214.25. Total value: 46328.67
# Buy XSD: 204.64 shares at 220.73.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'PSI': 874.8280926196389, 'XSD': 204.6411924944753}
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Sell PSI: 874.83 shares at 56.78. Total value: 48430.92
# Buy SMH: 210.72 shares at 224.09.
# Sell XSD: 204.64 shares at 231.79. Total value: 46247.94
# Buy SOXX: 197.04 shares at 228.84.
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'SMH': 210.71956518556527, 'SOXX': 197.04482798959447}
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['IXN', 'FTEC']
# Sell SMH: 210.72 shares at 220.98. Total value: 45400.69
# Buy IXN: 600.46 shares at 73.72.
# Sell SOXX: 197.04 shares at 225.10. Total value: 43245.92
# Buy FTEC: 273.26 shares at 154.30.
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'IXN': 600.4567343475169, 'FTEC': 273.26489497743927}
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['VGT', 'IYW']
# Sell IXN: 600.46 shares at 73.85. Total value: 43235.14
# Buy VGT: 81.38 shares at 517.98.
# Sell FTEC: 273.26 shares at 153.66. Total value: 40940.14
# Buy IYW: 298.93 shares at 133.53.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'VGT': 81.38202032827046, 'IYW': 298.93383185574476}
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['VGT', 'IYW']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'IYW']
# Sell VGT: 81.38 shares at 526.15. Total value: 41748.67
# Buy FTEC: 260.18 shares at 156.45.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'IYW': 298.93383185574476, 'FTEC': 260.17869701148896}
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IGM']
# Sell IYW: 298.93 shares at 135.55. Total value: 39507.47
# Buy IGM: 444.49 shares at 86.66.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'FTEC': 260.17869701148896, 'IGM': 444.49320796975337}
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IGM']
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'FTEC': 260.17869701148896, 'IGM': 444.49320796975337}
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'IGM']
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'FTEC': 260.17869701148896, 'IGM': 444.49320796975337}
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'PSI']
# Sell FTEC: 260.18 shares at 144.25. Total value: 36592.51
# Buy XSD: 172.67 shares at 206.62.
# Sell IGM: 444.49 shares at 80.88. Total value: 35051.84
# Buy PSI: 671.56 shares at 50.89.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'XSD': 172.67300247069136, 'PSI': 671.5572511014863}
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'PSI']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'VGT']
# Sell XSD: 172.67 shares at 228.64. Total value: 38492.96
# Buy IXN: 520.90 shares at 72.05.
# Sell PSI: 671.56 shares at 55.04. Total value: 36038.45
# Buy VGT: 69.45 shares at 505.94.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'IXN': 520.8970271043424, 'VGT': 69.44991012758194}
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'VGT']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['VGT', 'SMH']
# Sell IXN: 520.90 shares at 73.87. Total value: 37516.70
# Buy SMH: 164.27 shares at 222.67.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'VGT': 69.44991012758194, 'SMH': 164.27350360644922}
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['VGT', 'SMH']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['VGT', 'IYW']
# Sell SMH: 164.27 shares at 223.26. Total value: 35758.81
# Buy IYW: 259.30 shares at 134.46.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'VGT': 69.44991012758194, 'IYW': 259.2952328553218}
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['VGT', 'IYW']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Sell VGT: 69.45 shares at 539.30. Total value: 36517.98
# Buy SMH: 151.51 shares at 235.00.
# Sell IYW: 259.30 shares at 139.80. Total value: 35343.24
# Buy SOXX: 147.73 shares at 233.26.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'SMH': 151.51075684948447, 'SOXX': 147.73067547042083}
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IGM']
# Sell SMH: 151.51 shares at 249.83. Total value: 36905.63
# Buy FTEC: 219.72 shares at 163.77.
# Sell SOXX: 147.73 shares at 242.59. Total value: 34942.03
# Buy IGM: 377.78 shares at 90.18.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'FTEC': 219.71663031847783, 'IGM': 377.7831386673143}
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['SMH', 'VGT']
# Sell FTEC: 219.72 shares at 159.71. Total value: 34213.67
# Buy SMH: 137.01 shares at 243.48.
# Sell IGM: 377.78 shares at 87.80. Total value: 32340.13
# Buy VGT: 58.67 shares at 537.42.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'SMH': 137.0064469517661, 'VGT': 58.67222013444271}
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['SMH', 'VGT']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['VGT', 'XLK']
# Sell SMH: 137.01 shares at 255.86. Total value: 34178.11
# Buy XLK: 154.17 shares at 216.15.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'VGT': 58.67222013444271, 'XLK': 154.1691237804303}
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['VGT', 'XLK']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'IXN']
# Sell VGT: 58.67 shares at 586.47. Total value: 33549.26
# Buy FTEC: 187.52 shares at 174.44.
# Sell XLK: 154.17 shares at 231.12. Total value: 34740.78
# Buy IXN: 401.38 shares at 84.39.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'FTEC': 187.51734658837293, 'IXN': 401.37763660418864}
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['FTEC', 'VGT']
# Sell IXN: 401.38 shares at 81.49. Total value: 31890.56
# Buy VGT: 54.82 shares at 567.14.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'FTEC': 187.51734658837293, 'VGT': 54.82471959849439}
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['VGT', 'IYW']
# Sell FTEC: 187.52 shares at 173.13. Total value: 31653.26
# Buy IYW: 203.01 shares at 152.02.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'VGT': 54.82471959849439, 'IYW': 203.01226717556077}
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['VGT', 'IYW']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'IYW']
# Sell VGT: 54.82 shares at 599.91. Total value: 32067.65
# Buy XSD: 119.94 shares at 260.69.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'IYW': 203.01226717556077, 'XSD': 119.93539127361038}
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'IYW']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'IGM']
# Sell XSD: 119.94 shares at 268.80. Total value: 31432.67
# Buy FTEC: 170.75 shares at 179.48.
# Sell IYW: 203.01 shares at 156.68. Total value: 31012.76
# Buy IGM: 310.16 shares at 97.49.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'FTEC': 170.7535658520933, 'IGM': 310.1594332275972}
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'IGM']
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'FTEC': 170.7535658520933, 'IGM': 310.1594332275972}
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IGM', 'IXN']
# Sell FTEC: 170.75 shares at 166.34. Total value: 27693.07
# Buy IXN: 342.17 shares at 78.91.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'IGM': 310.1594332275972, 'IXN': 342.1713452885971}
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IGM', 'IXN']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SOXX']
# Sell IGM: 310.16 shares at 84.03. Total value: 25411.13
# Buy PSI: 499.71 shares at 49.58.
# Sell IXN: 342.17 shares at 73.00. Total value: 24354.05
# Buy SOXX: 116.88 shares at 203.16.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'PSI': 499.7146072250847, 'SOXX': 116.87927709868234}
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SOXX']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'SOXX']
# Sell PSI: 499.71 shares at 53.06. Total value: 25851.99
# Buy SMH: 111.06 shares at 226.96.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'SOXX': 116.87927709868234, 'SMH': 111.05783353365885}
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['VGT', 'FTEC']
# Sell SMH: 111.06 shares at 251.34. Total value: 27215.44
# Buy VGT: 45.70 shares at 580.69.
# Sell SOXX: 116.88 shares at 235.16. Total value: 26798.20
# Buy FTEC: 151.42 shares at 172.56.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'VGT': 45.69573677103249, 'FTEC': 151.41541128134514}
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['VGT', 'FTEC']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IGM']
# Sell VGT: 45.70 shares at 574.52. Total value: 25596.79
# Buy IGM: 268.30 shares at 93.02.
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'FTEC': 151.41541128134514, 'IGM': 268.2957310360013}
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'FTEC': 151.41541128134514, 'IGM': 268.2957310360013}
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Sell FTEC: 151.42 shares at 160.54. Total value: 23700.52
# Buy SMH: 105.10 shares at 219.86.
# Sell IGM: 268.30 shares at 87.89. Total value: 22991.00
# Buy SOXX: 107.79 shares at 207.96.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'SMH': 105.10329406914443, 'SOXX': 107.79103265641426}
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IXN']
# Sell SMH: 105.10 shares at 233.80. Total value: 23958.82
# Buy IGM: 253.11 shares at 92.29.
# Sell SOXX: 107.79 shares at 219.88. Total value: 23108.57
# Buy IXN: 280.62 shares at 80.29.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'IGM': 253.1135652586836, 'IXN': 280.61839673126076}
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['SMH', 'PSI']
# Sell IGM: 253.11 shares at 94.58. Total value: 23340.99
# Buy SMH: 95.24 shares at 238.95.
# Sell IXN: 280.62 shares at 81.54. Total value: 22309.58
# Buy PSI: 394.70 shares at 55.11.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'SMH': 95.23946373263576, 'PSI': 394.6986732781857}
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['SMH', 'PSI']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['SMH', 'FTEC']
# Sell PSI: 394.70 shares at 57.52. Total value: 22135.49
# Buy FTEC: 123.68 shares at 174.50.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'SMH': 95.23946373263576, 'FTEC': 123.67967846232226}
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['SMH', 'FTEC']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'SOXX']
# Sell FTEC: 123.68 shares at 172.81. Total value: 20838.76
# Buy SOXX: 88.17 shares at 230.45.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'SMH': 95.23946373263576, 'SOXX': 88.16571548539423}
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['FTEC', 'IXN']
# Sell SMH: 95.24 shares at 261.28. Total value: 24262.06
# Buy FTEC: 130.82 shares at 180.83.
# Sell SOXX: 88.17 shares at 239.80. Total value: 20613.59
# Buy IXN: 237.82 shares at 84.51.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'FTEC': 130.8162969874293, 'IXN': 237.82091147877543}
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['SMH', 'FTEC']
# Sell IXN: 237.82 shares at 84.01. Total value: 19479.85
# Buy SMH: 75.12 shares at 252.84.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'FTEC': 130.8162969874293, 'SMH': 75.11808209517909}
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['SMH', 'FTEC']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IGM']
# Sell SMH: 75.12 shares at 251.21. Total value: 18398.65
# Buy IGM: 183.14 shares at 97.95.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'FTEC': 130.8162969874293, 'IGM': 183.14127391204292}
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['VGT', 'IYW']
# Sell FTEC: 130.82 shares at 174.13. Total value: 22209.57
# Buy VGT: 36.96 shares at 585.90.
# Sell IGM: 183.14 shares at 95.86. Total value: 17117.02
# Buy IYW: 110.22 shares at 151.41.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'VGT': 36.95908228488356, 'IYW': 110.2245462355744}
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['VGT', 'IYW']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'IXN']
# Sell VGT: 36.96 shares at 621.92. Total value: 22410.95
# Buy FTEC: 118.07 shares at 185.07.
# Sell IYW: 110.22 shares at 160.27. Total value: 17224.05
# Buy IXN: 199.95 shares at 83.99.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'FTEC': 118.0670954880882, 'IXN': 199.94577394619142}
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['VGT', 'IYW']
# Sell FTEC: 118.07 shares at 179.88. Total value: 20706.96
# Buy VGT: 33.39 shares at 604.72.
# Sell IXN: 199.95 shares at 82.30. Total value: 16044.15
# Buy IYW: 100.15 shares at 156.19.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'VGT': 33.38617690655703, 'IYW': 100.15394956317303}
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['VGT', 'IYW']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['FTEC', 'IGM']
# Sell VGT: 33.39 shares at 621.29. Total value: 20223.93
# Buy FTEC: 106.64 shares at 184.91.
# Sell IYW: 100.15 shares at 159.07. Total value: 15533.20
# Buy IGM: 149.65 shares at 101.20.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'FTEC': 106.63747731889602, 'IGM': 149.65289183469548}
#
# Final Ticker Shares per Week:
# Week 2024-01-01 to 2024-01-07: {'FTEC': 348.73740855123145, 'IGM': 670.3334619848428}
# Week 2024-01-08 to 2024-01-14: {'VGT': 98.36601595602471, 'XLK': 248.94869581720206}
# Week 2024-01-15 to 2024-01-21: {'SMH': 256.7325111408514, 'SOXX': 242.04484931850018}
# Week 2024-01-22 to 2024-01-28: {'SMH': 256.7325111408514, 'IXN': 653.8186662396529}
# Week 2024-01-29 to 2024-02-04: {'SMH': 256.7325111408514, 'SOXX': 221.7810068514909}
# Week 2024-02-05 to 2024-02-11: {'SMH': 256.7325111408514, 'SOXX': 221.7810068514909}
# Week 2024-02-12 to 2024-02-18: {'SOXX': 221.7810068514909, 'PSI': 940.7380449608432}
# Week 2024-02-19 to 2024-02-25: {'SOXX': 221.7810068514909, 'SMH': 233.271186652357}
# Week 2024-02-26 to 2024-03-03: {'PSI': 874.8280926196389, 'XSD': 204.6411924944753}
# Week 2024-03-04 to 2024-03-10: {'SMH': 210.71956518556527, 'SOXX': 197.04482798959447}
# Week 2024-03-11 to 2024-03-17: {'IXN': 600.4567343475169, 'FTEC': 273.26489497743927}
# Week 2024-03-18 to 2024-03-24: {'VGT': 81.38202032827046, 'IYW': 298.93383185574476}
# Week 2024-03-25 to 2024-03-31: {'IYW': 298.93383185574476, 'FTEC': 260.17869701148896}
# Week 2024-04-01 to 2024-04-07: {'FTEC': 260.17869701148896, 'IGM': 444.49320796975337}
# Week 2024-04-08 to 2024-04-14: {'FTEC': 260.17869701148896, 'IGM': 444.49320796975337}
# Week 2024-04-15 to 2024-04-21: {'FTEC': 260.17869701148896, 'IGM': 444.49320796975337}
# Week 2024-04-22 to 2024-04-28: {'XSD': 172.67300247069136, 'PSI': 671.5572511014863}
# Week 2024-04-29 to 2024-05-05: {'IXN': 520.8970271043424, 'VGT': 69.44991012758194}
# Week 2024-05-06 to 2024-05-12: {'VGT': 69.44991012758194, 'SMH': 164.27350360644922}
# Week 2024-05-13 to 2024-05-19: {'VGT': 69.44991012758194, 'IYW': 259.2952328553218}
# Week 2024-05-20 to 2024-05-26: {'SMH': 151.51075684948447, 'SOXX': 147.73067547042083}
# Week 2024-05-27 to 2024-06-02: {'FTEC': 219.71663031847783, 'IGM': 377.7831386673143}
# Week 2024-06-03 to 2024-06-09: {'SMH': 137.0064469517661, 'VGT': 58.67222013444271}
# Week 2024-06-10 to 2024-06-16: {'VGT': 58.67222013444271, 'XLK': 154.1691237804303}
# Week 2024-06-17 to 2024-06-23: {'FTEC': 187.51734658837293, 'IXN': 401.37763660418864}
# Week 2024-06-24 to 2024-06-30: {'FTEC': 187.51734658837293, 'VGT': 54.82471959849439}
# Week 2024-07-01 to 2024-07-07: {'VGT': 54.82471959849439, 'IYW': 203.01226717556077}
# Week 2024-07-08 to 2024-07-14: {'IYW': 203.01226717556077, 'XSD': 119.93539127361038}
# Week 2024-07-15 to 2024-07-21: {'FTEC': 170.7535658520933, 'IGM': 310.1594332275972}
# Week 2024-07-22 to 2024-07-28: {'FTEC': 170.7535658520933, 'IGM': 310.1594332275972}
# Week 2024-07-29 to 2024-08-04: {'IGM': 310.1594332275972, 'IXN': 342.1713452885971}
# Week 2024-08-05 to 2024-08-11: {'PSI': 499.7146072250847, 'SOXX': 116.87927709868234}
# Week 2024-08-12 to 2024-08-18: {'SOXX': 116.87927709868234, 'SMH': 111.05783353365885}
# Week 2024-08-19 to 2024-08-25: {'VGT': 45.69573677103249, 'FTEC': 151.41541128134514}
# Week 2024-08-26 to 2024-09-01: {'FTEC': 151.41541128134514, 'IGM': 268.2957310360013}
# Week 2024-09-02 to 2024-09-08: {'FTEC': 151.41541128134514, 'IGM': 268.2957310360013}
# Week 2024-09-09 to 2024-09-15: {'SMH': 105.10329406914443, 'SOXX': 107.79103265641426}
# Week 2024-09-16 to 2024-09-22: {'IGM': 253.1135652586836, 'IXN': 280.61839673126076}
# Week 2024-09-23 to 2024-09-29: {'SMH': 95.23946373263576, 'PSI': 394.6986732781857}
# Week 2024-09-30 to 2024-10-06: {'SMH': 95.23946373263576, 'FTEC': 123.67967846232226}
# Week 2024-10-07 to 2024-10-13: {'SMH': 95.23946373263576, 'SOXX': 88.16571548539423}
# Week 2024-10-14 to 2024-10-20: {'FTEC': 130.8162969874293, 'IXN': 237.82091147877543}
# Week 2024-10-21 to 2024-10-27: {'FTEC': 130.8162969874293, 'SMH': 75.11808209517909}
# Week 2024-10-28 to 2024-11-03: {'FTEC': 130.8162969874293, 'IGM': 183.14127391204292}
# Week 2024-11-04 to 2024-11-10: {'VGT': 36.95908228488356, 'IYW': 110.2245462355744}
# Week 2024-11-11 to 2024-11-17: {'FTEC': 118.0670954880882, 'IXN': 199.94577394619142}
# Week 2024-11-18 to 2024-11-24: {'VGT': 33.38617690655703, 'IYW': 100.15394956317303}
# Week 2024-11-25 to 2024-12-01: {'FTEC': 106.63747731889602, 'IGM': 149.65289183469548}

# %%
# Define the first trading day of the 48th week
first_trading_day_49w = '2024-12-01'  # Adjust this to match the actual start date of the 48th week

# Identify the 48th and 49th week date range keys
week_48_range = list(ticker_shares_per_week.keys())[-1]  # Last key corresponds to the 48th week
week_49_start = first_trading_day_49w  # Replace with the actual start of the 49th week
print(f"Using data for the 48th week: {week_48_range}")

print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

week_49_end = '2024-12-06'
# Initialize a dictionary to store the values of shares
etf_values_49w = {}

# Ensure 48th week data exists
if week_48_range in ticker_shares_per_week:
    # Fetch ETF shares from the 48th week
    ticker_shares_48w = ticker_shares_per_week[week_48_range]
    
    # Fetch the first trading day price of the 49th week for each ETF
    for ticker, shares in ticker_shares_48w.items():
        print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
        # Download historical data for the 49th week
        data = yf.download(ticker, start=week_49_start, end=week_49_end)
        
        if not data.empty:
            # Get the closing price of the first trading day of the 49th week
            closing_price_49w = data['Close'].iloc[0]
            # Calculate the value of the shares
            total_value = shares * closing_price_49w
            etf_values_49w[ticker] = total_value
            print(f"{ticker}: {shares:.2f} shares at {closing_price_49w:.2f} each, total value: {total_value:.2f}")
        else:
            print(f"{ticker}: No data available for the 49th week's first trading day.")
else:
    print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker FTEC starting from 2024-12-01...
# FTEC: 106.64 shares at 186.99 each, total value: 19940.14
# Fetching data for ticker IGM starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# IGM: 149.65 shares at 102.51 each, total value: 15340.92

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 35281.06
# FTEC: 19940.14
# IGM: 15340.92
