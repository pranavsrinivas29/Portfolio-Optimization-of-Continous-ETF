# %%
import yfinance as yf
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tabulate import tabulate
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler,MinMaxScaler,Normalizer

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers.legacy import Adam as LegacyAdam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from skopt import gp_minimize
from skopt.space import Real, Integer
from sklearn.metrics import mean_squared_error
from bayes_opt import BayesianOptimization

import tensorflow as tf
from tensorflow.keras.optimizers.legacy import Adam
import time

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, Bidirectional

import tensorflow as tf
from keras.layers import Attention


from pandas.tseries.offsets import MonthEnd

from pandas.tseries.offsets import BDay, Week

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

from datetime import datetime, timedelta

# %%
#tickers = ['SPY', 'QQQ', 'VTI', 'IWM', 'EFA', 'EEM', 'GLD', 'SLV', 'USO', 'XLF']
#tickers = ['SPY', 'QQQ', 'VTI']
#tickers = ['SPY']

#start_date, end_date = '2000-01-01', '2024-05-01'
#train_start_date, train_end_date, test_start_date, test_end_date, prediction_start_date = start_date,'2014-01-01', '2014-01-01', '2024-01-01', '2024-01-01'
#prediction_dates=['2024-01-01','2024-02-01','2024-03-01', '2024-04-01']

# %%
def data_loading(ticker_symbol, start_date, end_date):
    # Fetch the ETF data from Yahoo Finance for the period from 2010-01-01 to 2024-01-01
    etf_data = yf.Ticker(ticker_symbol)
    etf_history = etf_data.history(start=start_date, end=end_date)
    etf_history.index = etf_history.index.tz_localize(None)
    return etf_history, etf_data
    
#etf_history,etf_data = data_loading('SPY', start_date, end_date)
#etf_history.head(10)

# %%
#etf_history.tail(10)

# %%
#Function to derive the predictor columns
def etf_predictors(etf_history,  start_date, end_date, etf_data, benchmark_ticker = '^GSPC' ):
    
    # Calculate Daily Returns
    etf_history['Daily Return'] = etf_history['Close'].pct_change()

    # Calculate 21-Day Volatility (standard deviation of daily returns, annualized)
    etf_history['Volatility'] = etf_history['Daily Return'].rolling(window=21).std() * np.sqrt(252)
    #etf_history['Volatility_ta'] = ta.volatility(etf_history['Close'], window=21, annualize=True)
   
    # Get the ETF info
    etf_info = etf_data.info

    # Retrieve the net asset value price (NAV) and total net assets
    nav_price = etf_info['navPrice']
    total_assets = etf_info['totalAssets']

    # Calculate the number of shares outstanding
    shares_outstanding = total_assets / nav_price

    # Calculate Market Capitalization for each day
    # Market Capitalization = Closing Price * Total Number of Shares Outstanding
    etf_history['Market Cap'] = etf_history['Close'] * shares_outstanding

    total_assets = etf_info['totalAssets']
    total_liabilities = etf_info.get('totalLiabilities', 0)  # Handle the case where total liabilities might not be present
    
    # Calculate Book Value per Share
    book_value_per_share = (total_assets - total_liabilities) / shares_outstanding
    
    # Calculate Price to Book (P/B) Ratio
    etf_history['P/B Ratio'] = etf_history['Close'] / book_value_per_share
    
    # Calculate 1-Month Momentum (21 trading days)
    
    etf_history['Momentum'] = ta.mom(etf_history['Close'], length=21)
    
    benchmark_data = yf.download(benchmark_ticker, start=start_date, end=end_date)
    benchmark_data['Daily Return'] = benchmark_data['Close'].pct_change()
    #benchmark_data_history = benchmark_data.dropna()
    benchmark_data.head(10)
    
    # Ensure the indices are time zone-naive
    benchmark_data.index = benchmark_data.index.tz_localize(None)
    combined_data = etf_history[['Close']].join(benchmark_data[['Close']], lsuffix='_ETF', rsuffix='_Benchmark')
    combined_data = combined_data.dropna()
    
    # Calculate rolling beta with a 30-day window
    rolling_beta_21 = rolling_beta(combined_data, window=21)

    # Add the rolling beta to the dataframe
    combined_data.loc[:, 'Rolling Beta 21-day'] = rolling_beta_21
    etf_history['Rolling Beta']=combined_data['Rolling Beta 21-day']
    
    # Calculate daily profitability
    daily_profitabilities = []
    previous_nav = None
    for index, row in etf_history.iterrows():
        current_nav = row['Close']  # Current day's NAV
        #print(current_nav)
        if previous_nav is not None:
            daily_profitability = (current_nav - previous_nav) / previous_nav * 100
            daily_profitabilities.append(daily_profitability)
        else:
            daily_profitabilities.append(None)
        previous_nav = current_nav  # Update previous_nav for the next iteration

    # Add daily profitabilities to ETF dataset
    etf_history['Daily Profitability (%)'] = daily_profitabilities
    
    # Calculate the dividend yield for each day
    dividend_yields = []

    for index, row in etf_history.iterrows():
        # Get the dividend payment for the day
        dividend_payment = row['Dividends']

        # Get the current market price of the ETF for the day
        current_price = row['Close']

        # Calculate the dividend yield for the day
        dividend_yield = (dividend_payment / current_price) * 100

        # Append the dividend yield to the list
        dividend_yields.append(dividend_yield)
      
    etf_history['Div yield'] = dividend_yields

    #Volatility
    etf_history['ATR'] = ta.atr(etf_history['High'], etf_history['Low'], etf_history['Close'], length=21)    
    
    # Compute the Relative Volatility Index (RVI)
    rvi = ta.rvi(etf_history['Close'],length=21)
    etf_history['RVI'] = rvi
    
    #Momentum
    rsi_window = 14  # Window size for RSI calculation
    roc_window = 12  # Window size for ROC calculation
    #rsi_window = 21  
    #roc_window = 21  

    

    etf_history['RSI'] = ta.rsi(etf_history['Close'],length=rsi_window)
    # Calculate Rate of Change (ROC)
    etf_history['ROC'] = ta.roc(etf_history['Close'], length=roc_window)
        
    etf_history['log_returns'] = np.log(etf_history['Close'] / etf_history['Close'].shift(1))

    return etf_history

# Function to calculate rolling beta
def rolling_beta(df, window):
    rolling_cov = df['Close_Benchmark'].rolling(window=window).cov(df['Close_ETF'])
    rolling_var = df['Close_Benchmark'].rolling(window=window).var()
    rolling_beta = rolling_cov / rolling_var
    return rolling_beta

# %%
#etf_history = etf_predictors(etf_history,  start_date, end_date, etf_data,benchmark_ticker = '^GSPC' )
#etf_history.head(10)

# %%
def pre_processing(etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_dates, feature_columns=None, scaling_strategy='StandardScaler', final_end_date='2024-12-01'):
    # Handle missing values and inf replacements
    etf_history.fillna(etf_history.median(), inplace=True)
    etf_history = etf_history.replace(-np.inf, 0)

    # Default feature columns if none are provided
    if feature_columns is None:
        feature_columns = ['Volatility', 'Volume', 'Daily Return', 'Market Cap', 'P/B Ratio', 'Momentum', 
                           'Rolling Beta', 'Daily Profitability (%)', 'ATR', 'RVI', 'RSI', 'ROC']

    # Selecting the features (X) and the target (y)
    X = etf_history.loc[:, feature_columns]
    y = etf_history['log_returns']

    # Split train and test data
    train_data = X.loc[train_start_date:train_end_date]
    test_data = X.loc[test_start_date:test_end_date]
    y_train = y.loc[train_start_date:train_end_date]
    y_test = y.loc[test_start_date:test_end_date]

    # Scaling strategy based on input parameter
    if scaling_strategy == 'StandardScaler':
        scaler = StandardScaler()
    elif scaling_strategy == 'Normalizer':
        scaler = Normalizer()
    else:
        raise ValueError(f"Unsupported scaling strategy: {scaling_strategy}")
    
    # Scaling the train and test data
    train_data_scaled = scaler.fit_transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    # Create a dictionary to store forecast data for each weekly prediction period
    forecast_data = {}
    for i, start_date in enumerate(prediction_dates):
        # Determine the end date for each forecast week
        if i < len(prediction_dates) - 1:
            end_date = (pd.to_datetime(start_date) + Week(1) - pd.Timedelta(days=1)).strftime('%Y-%m-%d')
        else:
            end_date = final_end_date  # The final end date provided or default

        # Store the forecast data for each week
        forecast_data[f'forecast_data_{i+1}w'] = X.loc[start_date:end_date]

    # Scale the forecast data dynamically
    forecast_data_scaled = {}
    for period_key, period_data in forecast_data.items():
        if not period_data.empty:
            forecast_data_scaled[period_key] = sm.add_constant(scaler.transform(period_data))

    # Add constant to scaled train and test data
    train_data_scaled = sm.add_constant(train_data_scaled)
    test_data_scaled = sm.add_constant(test_data_scaled)

    #print(f"Weekly forecast data keys: {forecast_data.keys()}")

    # Dynamically return the scaled forecast data along with train and test data
    return {
        'train_data_scaled': train_data_scaled,
        'test_data_scaled': test_data_scaled,
        'y_train': y_train,
        'y_test': y_test,
        'scaler': scaler,
        'X': X,
        'etf_history': etf_history,
        'forecast_data_scaled': forecast_data_scaled,
        'forecast_data': forecast_data
    }

# %%
#train_data_scaled, test_data_scaled, y_train, y_test, scaler, X, etf_history, forecast_data_scaled_1m, forecast_data_scaled_2m, forecast_data_scaled_3m, forecast_data_scaled_4m, forecast_data_1m, forecast_data_2m, forecast_data_3m, forecast_data_4m = pre_processing(etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_start_date, prediction_dates)

# %%
def build_and_train_lstm_model(epochs, batch_size, units, dropout_rate, learning_rate, train_data_scaled, y_train, validation_split=0.2):
    train_data_reshaped = reshape_for_lstm(train_data_scaled)
    
    model = Sequential()
    
    # First LSTM layer
    model.add(LSTM(units=int(units), return_sequences=True, input_shape=(train_data_reshaped.shape[1], train_data_reshaped.shape[2])))
    model.add(Dropout(dropout_rate))
    
    # Second LSTM layer with return_sequences=False
    model.add(LSTM(units=int(units), return_sequences=False))
    model.add(Dropout(dropout_rate))
    
    # Adding a Dense hidden layer with ReLU activation
    model.add(Dense(units=int(units/2), activation='relu'))
    model.add(Dropout(dropout_rate))
    
    # Output layer
    model.add(Dense(1))
    
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    # Early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    
     # Track the start time
    #start_time = time.time()
    
    model.fit(train_data_reshaped, y_train, 
              epochs=int(epochs), 
              batch_size=int(batch_size), 
              validation_split=validation_split, 
              callbacks=[early_stopping],
              verbose=0)
    
    # Calculate time consumed
    #time_consumed = time.time() - start_time
    
    return model



def optimize_hyperparameters(train_data_scaled, y_train, test_data_scaled, y_test):
    def objective_function(epochs, batch_size, units, dropout_rate, learning_rate):
        model = build_and_train_lstm_model(epochs, batch_size, units, dropout_rate, learning_rate, train_data_scaled, y_train)
        test_data_reshaped = reshape_for_lstm(test_data_scaled)
        test_predictions = make_predictions(model, test_data_reshaped)
        mse = mean_squared_error(y_test, test_predictions)
        return -mse  # We return the negative MSE because Bayesian Optimization tries to maximize the function

    # Reduced parameter ranges for faster search
    param_bounds = {
        'epochs': (10, 30),  # Reduce max epochs
        'batch_size': (16, 64),  # Widen batch size range for exploration
        'units': (32, 128),  # Expand LSTM unit range
        'dropout_rate': (0.2, 0.5),  # Adjust dropout for robustness
        'learning_rate': (1e-4, 5e-3)  # Widen learning rate range for exploration
    }
    
    optimizer = BayesianOptimization(
        f=objective_function,
        pbounds=param_bounds,
        verbose=2,
        random_state=42,
    )

    # Reduced the number of iterations for faster optimization
    optimizer.maximize(init_points=15, n_iter=50)  # Fewer initial points and iterations

    best_params = optimizer.max['params']
    return best_params

# %%
# Out:
# "def build_and_train_lstm_model(epochs, batch_size, units, dropout_rate, learning_rate, train_data_scaled, y_train, validation_split=0.2):\n    train_data_reshaped = reshape_for_lstm(train_data_scaled)\n    \n    model = Sequential()\n    \n    # Input layer\n    model.add(Input(shape=(train_data_reshaped.shape[1], train_data_reshaped.shape[2])))\n    \n    # First Bidirectional LSTM layer with Batch Normalization\n    lstm_output = Bidirectional(LSTM(units=int(units), return_sequences=True))(model.input)\n    lstm_output = Dropout(dropout_rate)(lstm_output)\n    lstm_output = BatchNormalization()(lstm_output)\n    \n    # Attention Layer\n    query = lstm_output\n    value = lstm_output\n    attention_output = Attention()([query, value])\n    \n    # Second LSTM layer\n    lstm_output_2 = LSTM(units=int(units), return_sequences=True)(attention_output)\n    lstm_output_2 = Dropout(dropout_rate)(lstm_output_2)\n    lstm_output_2 = BatchNormalization()(lstm_output_2)\n    \n    # Third LSTM layer\n    lstm_output_3 = LSTM(units=int(units / 2), return_sequences=False)(lstm_output_2)\n    lstm_output_3 = Dropout(dropout_rate)(lstm_output_3)\n    lstm_output_3 = BatchNormalization()(lstm_output_3)\n    \n    # Dense layers\n    dense_output = Dense(units=int(units / 2), activation='relu')(lstm_output_3)\n    dense_output = Dropout(dropout_rate)(dense_output)\n    dense_output = Dense(units=int(units / 4), activation='relu')(dense_output)\n    dense_output = Dropout(dropout_rate)(dense_output)\n    \n    # Output layer\n    final_output = Dense(1)(dense_output)\n    \n    # Assemble the model\n    model = tf.keras.Model(inputs=model.input, outputs=final_output)\n    \n    # Compile the model\n    optimizer = Adam(learning_rate=learning_rate)\n    model.compile(optimizer=optimizer, loss='mean_squared_error')\n    \n    # Early stopping to prevent overfitting\n    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)\n    \n    # Train the model\n    model.fit(train_data_reshaped, y_train, \n              epochs=int(epochs), \n              batch_size=int(batch_size), \n              validation_split=validation_split, \n              callbacks=[early_stopping],\n              verbose=0)\n    \n    return model\n\n\n\ndef optimize_hyperparameters(train_data_scaled, y_train, test_data_scaled, y_test):\n    def objective_function(epochs, batch_size, units, dropout_rate, learning_rate):\n        model = build_and_train_lstm_model(epochs, batch_size, units, dropout_rate, learning_rate, train_data_scaled, y_train)\n        test_data_reshaped = reshape_for_lstm(test_data_scaled)\n        test_predictions = make_predictions(model, test_data_reshaped)\n        mse = mean_squared_error(y_test, test_predictions)\n        return -mse  # We return the negative MSE because Bayesian Optimization tries to maximize the function\n\n    # Reduced parameter ranges for faster search\n    #param_bounds = {\n    #    'epochs': (10, 50),  # Lowered the number of epochs\n    #    'batch_size': (32, 64),  # Limited batch size range\n    #    'units': (50, 100),  # Narrowed the range of units\n    #    'dropout_rate': (0.1, 0.4),  # Lowered the dropout rate range\n    #    'learning_rate': (0.0001, 0.001)  # Narrowed learning rate range\n    #}\n    param_bounds = {\n        'epochs': (10, 30),  # Reduce max epochs\n        'batch_size': (16, 64),  # Widen batch size range for exploration\n        'units': (32, 128),  # Expand LSTM unit range\n        'dropout_rate': (0.2, 0.5),  # Adjust dropout for robustness\n        'learning_rate': (1e-4, 5e-3)  # Widen learning rate range for exploration\n    }\n        \n    optimizer = BayesianOptimization(\n        f=objective_function,\n        pbounds=param_bounds,\n        verbose=2,\n        random_state=42,\n    )\n\n    # Reduced the number of iterations for faster optimization\n    optimizer.maximize(init_points=15, n_iter=50)  # Fewer initial points and ite ...

# %%
def make_predictions(model, data_scaled):
    if len(data_scaled.shape) == 2:
        data_scaled = np.reshape(data_scaled, (data_scaled.shape[0], 1, data_scaled.shape[1]))
    elif len(data_scaled.shape) != 3:
        raise ValueError(f"Unexpected shape for input data: {data_scaled.shape}")
    
    predictions = model.predict(data_scaled)
    return predictions

def eval_model(best_model, test_data_scaled, y_test, y_train=None):
    # Reshape test data to match LSTM input requirements
    test_data_reshaped = test_data_scaled.reshape((test_data_scaled.shape[0], 1, test_data_scaled.shape[1]))
    
    # Make predictions
    test_predictions = best_model.predict(test_data_reshaped)
    
    # Calculate Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_test, test_predictions)
    
    # Calculate Mean Absolute Scaled Error (MASE) - Example calculation assuming seasonal period m=1
    naive_forecast = y_test.shift(1).fillna(method='bfill')
    mase = mae / mean_absolute_error(y_test, naive_forecast)
    print("mae: ",mae)
    print("mase: ",mase)
    return mae, mase

# %%
# Ensured consistent feature handling and forecasting in predictions
def predictions(model, forecast_data_scaled, forecast_data):
    # Make predictions using the model
    predictions_forecast = make_predictions(model, forecast_data_scaled)
    
    # Create a DataFrame for the predictions with the same index as the forecast data
    forecast_predictions_df = pd.DataFrame(predictions_forecast, columns=["log_returns"], index=forecast_data.index)
    
    # Concatenate the original forecast data with the predictions
    forecast_data_with_predictions = pd.concat([forecast_data, forecast_predictions_df], axis=1)
    
    return forecast_predictions_df, forecast_data_with_predictions

# %%
def calculate_mase(y_true, y_pred, naive_forecast):
    # Calculate the MAE of the model's predictions
    mae_model = mean_absolute_error(y_true, y_pred)
    
    # Calculate the MAE of the naive forecast
    mae_naive = mean_absolute_error(y_true, naive_forecast)
    
    # Calculate MASE
    mase = mae_model / mae_naive
    return mase

# %%
def reshape_for_lstm(data):
    return np.reshape(data, (data.shape[0], 1, data.shape[1]))  # Reshape into (samples, time_steps, features)

# %%
#etf_pred_dict, scores_1m, scores_2m, scores_3m, scores_4m = main(tickers, etf_dict)

# %%
#tickers = ['SPY', 'QQQ', 'VTI', 'IWM', 'EFA', 'EEM', 'GLD', 'SLV', 'USO', 'XLF']
#tickers = ['SMH', 'SOXX', 'PSI']

tickers = ['SMH', 'SOXX', 'PSI', 'XSD', 'IYW', 'XLK', 'VGT', 'FTEC', 'IGM', 'IXN', 
           #'FNGU','USD', 'FNGO', 'GBTC', 'ETHE', 'TECL', 'FNGS', 'TQQQ', 'ROM', 'QLD' No data available from 2000: 2019
          ]

#tickers = ['SPY', 'QQQ', 'VTI']
#tickers = ['SPY']
                                                           
start_date, end_date = '2000-01-01', '2024-12-01'
train_start_date, train_end_date, test_start_date, test_end_date, prediction_start_date = start_date,'2014-01-01', '2014-01-01', '2024-01-01', '2024-01-01'
#prediction_dates=['2024-01-01','2024-02-01','2024-03-01', '2024-04-01','2024-05-01','2024-06-01','2024-07-01','2024-08-01','2024-09-01','2024-10-01','2024-11-01']

# %%
#currently timeperiod is set to 48 weeks
prediction_dates = pd.date_range(start='2024-01-01', 
                                 periods=48, 
                                 freq='W-MON').strftime('%Y-%m-%d').tolist()

# %%
dict_data = {}
etf_dict = {}
data_with_predictors = []
for i in tickers:
    etf_history,etf_data = data_loading(i, start_date, end_date)
    
    print(etf_data.info.get('longName'), ":",i)
    
    #test_stationarity(etf_history)
    print(" ETF:",i)
    #print(etf_history.head(10))
    #print("################")
    #hist_data.append(etf_history)
    
    etf_history = etf_predictors(etf_history,  start_date, end_date, etf_data,benchmark_ticker = '^GSPC' )
    
    # Call the function
    preprocessed_data = pre_processing(etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_dates)

    # Extract individual components from the returned dictionary
    train_data_scaled = preprocessed_data['train_data_scaled']
    test_data_scaled = preprocessed_data['test_data_scaled']
    y_train = preprocessed_data['y_train']
    y_test = preprocessed_data['y_test']
    scaler = preprocessed_data['scaler']
    X = preprocessed_data['X']
    etf_history = preprocessed_data['etf_history']

    
    
    # Track the start time
    start_time = time.time()
    
    
    # Optimize hyperparameters
    # Optimize hyperparameters
    best_params = optimize_hyperparameters(train_data_scaled, y_train, test_data_scaled, y_test)
    
    # Extract the best hyperparameters
    best_epochs = int(best_params['epochs'])
    best_batch_size = int(best_params['batch_size'])
    best_units = int(best_params['units'])
    best_dropout_rate = best_params['dropout_rate']
    best_learning_rate = best_params['learning_rate']

    # Train the final model using the best hyperparameters
    best_model = build_and_train_lstm_model(
        epochs=best_epochs, 
        batch_size=best_batch_size, 
        units=best_units, 
        dropout_rate=best_dropout_rate, 
        learning_rate=best_learning_rate, 
        train_data_scaled=train_data_scaled, 
        y_train=y_train
    )
    
     
    
    # Calculate time consumed
    time_consumed = time.time() - start_time
    
    # Print the time consumed
    print(f"Time consumed for training: {time_consumed:.2f} seconds")

    # Evaluate the model
    mae, mase = eval_model(best_model, test_data_scaled, y_test)
    
    # Initialize dictionaries for forecast data and predictions
    # Step 5: Initialize forecast data storage
    forecast_predictions = {}
    forecast_data_dict = {}
    forecast_data_scaled_dict = {}

    # Step 6: Fetch weekly forecast data and generate predictions
    for week in range(1, 49):  # Generate weekly forecasts for up to 52 weeks
        week_key = f'forecast_data_{week}w'
        if week_key in preprocessed_data['forecast_data']:
            forecast_data = preprocessed_data['forecast_data'][week_key]
            forecast_data_scaled = preprocessed_data['forecast_data_scaled'].get(week_key)

            if forecast_data is not None and forecast_data_scaled is not None:
                try:
                    forecast_predictions_df, _ = predictions(
                        best_model, forecast_data_scaled, forecast_data
                    )
                    # Store predictions and forecast data
                    forecast_predictions[f'forecast_predictions_df_{week}w'] = forecast_predictions_df['log_returns'].values
                    forecast_data_dict[week_key] = forecast_data
                    forecast_data_scaled_dict[week_key] = forecast_data_scaled
                except Exception as e:
                    print(f"Error generating predictions for {week_key} for ETF {i}: {e}")
            else:
                print(f"Warning: Missing scaled data for {week_key} for ETF {i}")
        else:
            print(f"Warning: Missing forecast key {week_key} for ETF {i}")

    # Step 7: Construct `dict_data` for the current ETF
    dict_data = {
        "etf_history": etf_history,
        "X": X,
        "y_train_values": y_train,
        "model results": {"mae": mae, "mase": mase},
        **forecast_data_dict,  # Add raw forecast data
        **forecast_data_scaled_dict,  # Add scaled forecast data
        **forecast_predictions  # Add predictions
    }

    # Step 8: Store in the main `etf_dict`
    etf_dict[i] = dict_data

# Print completion message
print("Weekly forecast data and predictions stored successfully.")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# VanEck Semiconductor ETF : SMH
#  ETF: SMH
# |   iter    |  target   | batch_... | dropou... |  epochs   | learni... |   units   |
# -------------------------------------------------------------------------------------
# 79/79 [==============================] - 0s 672us/step
# | 1         | -8.9e-05  | 33.98     | 0.4852    | 24.64     | 0.003033  | 46.98     |
# 79/79 [==============================] - 0s 781us/step
# | 2         | -5.626e-0 | 23.49     | 0.2174    | 27.32     | 0.003045  | 99.97     |
# 79/79 [==============================] - 0s 702us/step
# | 3         | -5.109e-0 | 16.99     | 0.491     | 26.65     | 0.00114   | 49.46     |
# 79/79 [==============================] - 0s 673us/step
# | 4         | -6.797e-0 | 24.8      | 0.2913    | 20.5      | 0.002217  | 59.96     |
# 79/79 [==============================] - 0s 697us/step
# | 5         | -0.000132 | 45.37     | 0.2418    | 15.84     | 0.001895  | 75.78     |
# 79/79 [==============================] - 0s 873us/step
# | 6         | -0.000183 | 53.69     | 0.2599    | 20.28     | 0.003003  | 36.46     |
# 79/79 [==============================] - 0s 829us/step
# | 7         | -7.131e-0 | 45.16     | 0.2512    | 11.3      | 0.00475   | 124.7     |
# 79/79 [==============================] - 0s 770us/step
# | 8         | -5.721e-0 | 54.8      | 0.2914    | 11.95     | 0.003453  | 74.25     |
# 79/79 [==============================] - 0s 681us/step
# | 9         | -6.271e-0 | 21.86     | 0.3486    | 10.69     | 0.004556  | 56.84     |
# 79/79 [==============================] - 0s 666us/step
# | 10        | -0.000107 | 47.8      | 0.2935    | 20.4      | 0.002779  | 49.75     |
# 79/79 [==============================] - 0s 742us/step
# | 11        | -3.77e-05 | 62.54     | 0.4325    | 28.79     | 0.004485  | 89.4      |
# 79/79 [==============================] - 0s 679us/step
# | 12        | -0.000170 | 60.25     | 0.2265    | 13.92     | 0.0003216 | 63.23     |
# 79/79 [==============================] - 0s 699us/step
# | 13        | -6.952e-0 | 34.66     | 0.2814    | 26.57     | 0.001848  | 58.97     |
# 79/79 [==============================] - 0s 927us/step
# | 14        | -7.83e-05 | 42.05     | 0.2423    | 26.04     | 0.0004653 | 126.7     |
3520284570.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   naive_forecast = y_test.shift(1).fillna(method='bfill')
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# ...
# 79/79 [==============================] - 2s 2ms/step
# | 62        | -0.000108 | 20.0      | 0.4417    | 22.09     | 0.004721  | 63.01     |
# 79/79 [==============================] - 2s 1ms/step
# | 63        | -0.000184 | 34.23     | 0.3836    | 28.22     | 0.004163  | 42.62     |
# 79/79 [==============================] - 2s 1ms/step
# | 64        | -0.000295 | 27.59     | 0.4518    | 15.13     | 0.001218  | 44.62     |
# 79/79 [==============================] - 2s 2ms/step
# | 65        | -0.000266 | 51.28     | 0.465     | 13.01     | 0.0007108 | 90.08     |
# =====================================================================================
# Time consumed for training: 608.26 seconds
# 79/79 [==============================] - 2s 2ms/step
# mae:  0.012306767889818548
# mase:  0.8441880903273976
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_65124/3520284570.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   naive_forecast = y_test.shift(1).fillna(method='bfill')
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# [*********************100%%**********************]  1 of 1 completed
# iShares Global Tech ETF : IXN
#  ETF: IXN
# |   iter    |  target   | batch_... | dropou... |  epochs   | learni... |   units   |
# -------------------------------------------------------------------------------------
# 79/79 [==============================] - 2s 2ms/step
# | 1         | -0.000180 | 33.98     | 0.4852    | 24.64     | 0.003033  | 46.98     |
# 79/79 [==============================] - 2s 2ms/step
# | 2         | -0.000669 | 23.49     | 0.2174    | 27.32     | 0.003045  | 99.97     |
# 79/79 [==============================] - 2s 2ms/step
# | 3         | -8.898e-0 | 16.99     | 0.491     | 26.65     | 0.00114   | 49.46     |
# 79/79 [==============================] - 2s 2ms/step
# | 4         | -0.000330 | 24.8      | 0.2913    | 20.5      | 0.002217  | 59.96     |
# 79/79 [==============================] - 2s 2ms/step
# | 5         | -8.705e-0 | 45.37     | 0.2418    | 15.84     | 0.001895  | 75.78     |
# 79/79 [==============================] - 2s 2ms/step
# | 6         | -8.033e-0 | 53.69     | 0.2599    | 20.28     | 0.003003  | 36.46     |
# 79/79 [==============================] - 2s 2ms/step
# | 7         | -0.000549 | 45.16     | 0.2512    | 11.3      | 0.00475   | 124.7     |
# 79/79 [==============================] - 2s 2ms/step
# | 8         | -0.000115 | 54.8      | 0.2914    | 11.95     | 0.003453  | 74.25     |
# 79/79 [==============================] - 2s 2ms/step
# | 9         | -0.00012  | 21.86     | 0.3486    | 10.69     | 0.004556  | 56.84     |
# 79/79 [==============================] - 2s 2ms/step
# | 10        | -9.006e-0 | 47.8      | 0.2935    | 20.4      | 0.002779  | 49.75     |
# 79/79 [==============================] - 3s 2ms/step
# | 11        | -0.000162 | 62.54     | 0.4325    | 28.79     | 0.004485  | 89.4      |
# 79/79 [==============================] - 2s 2ms/step
# | 12        | -0.000804 | 60.25     | 0.2265    | 13.92     | 0.0003216 | 63.23     |
# 79/79 [==============================] - 2s 2ms/step
# | 13        | -0.000255 | 34.66     | 0.2814    | 26.57     | 0.001848  | 58.97     |
# 79/79 [==============================] - 2s 2ms/step
# | 14        | -0.000557 | 42.05     | 0.2423    | 26.04     | 0.0004653 | 126.7     |
# 79/79 [==============================] - 2s 2ms/step
# | 15        | -0.000114 | 53.07     | 0.2596    | 10.11     | 0.004096  | 99.86     |
# 79/79 [==============================] - 2s 2ms/step
# | 16        | -0.000244 | 52.02     | 0.2521    | 11.27     | 0.002685  | 85.14     |
# 79/79 [==============================] - 2s 2ms/step
# | 17        | -0.000395 | 54.64     | 0.3582    | 21.28     | 0.004116  | 36.27     |
# 79/79 [==============================] - 4s 2ms/step
# | 63        | -0.000133 | 34.23     | 0.3836    | 28.22     | 0.004163  | 42.62     |
# 79/79 [==============================] - 3s 2ms/step
# | 64        | -0.000164 | 27.59     | 0.4518    | 15.13     | 0.001218  | 44.62     |
# 79/79 [==============================] - 4s 3ms/step
# | 65        | -0.000162 | 33.83     | 0.3623    | 28.23     | 0.002565  | 43.78     |
# =====================================================================================
# Time consumed for training: 991.82 seconds
# 79/79 [==============================] - 3s 2ms/step
# mae:  0.021093410064443735
# mase:  1.4888410536764012
# 1/1 [==============================] - 0s 35ms/step
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_65124/3520284570.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   naive_forecast = y_test.shift(1).fillna(method='bfill')
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# Weekly forecast data and predictions stored successfully.

# %%
def calculate_sharpe_ratio(returns, annual_risk_free_rate=0.1,period='daily'):
    #excess_returns = rate_of_return(returns) - risk_free_rate
    
    # Convert annual risk-free rate to daily rate
    daily_risk_free_rate = (1 + annual_risk_free_rate) ** (1/252) - 1
    
    # Calculate mean daily log return
    mean_return = np.mean(returns)
    
    # Calculate excess daily log return
    excess_return = mean_return - daily_risk_free_rate
    
    # Calculate standard deviation of daily log returns
    std_return = np.std(returns)
    
    # Print diagnostic information
    #print(f"Mean Daily Log Return: {mean_return}")
    #print(f"Excess Daily Log Return: {excess_return}")
    #print(f"Standard Deviation of Daily Log Returns: {std_return}")
    
    # Check for zero standard deviation to avoid division by zero
    if std_return == 0:
        return 0
    
    # Calculate Sharpe ratio
    sharpe_ratio = (excess_return / std_return) * np.sqrt(252)  # Annualize the Sharpe ratio
    return sharpe_ratio
    #return excess_returns / np.std(returns)


def calculate_rachev_ratio(returns, lower_percentile=5, upper_percentile=95):
    # Step 1: Sort the returns
    sorted_returns = np.sort(returns)
    
    # Step 2: Determine the percentiles
    lower_threshold = np.percentile(sorted_returns, lower_percentile)
    upper_threshold = np.percentile(sorted_returns, upper_percentile)
    
    # Step 3: Calculate Expected Shortfall (ES)
    es = np.mean(sorted_returns[sorted_returns <= lower_threshold])
    
    # Step 4: Calculate Expected Gain (EG)
    eg = np.mean(sorted_returns[sorted_returns >= upper_threshold])
    
    # Step 5: Compute the Rachev Ratio
    rachev_ratio = eg / -es
    return rachev_ratio


def calculate_volatility_clustering(returns):
    squared_returns = returns ** 2
    n = len(squared_returns)
    
    # Mean of squared returns
    mean_squared_returns = np.mean(squared_returns)
    
    # Calculate the numerator and denominator for autocorrelation at lag 1
    numerator = np.sum((squared_returns[:-1] - mean_squared_returns) * (squared_returns[1:] - mean_squared_returns))
    denominator = np.sum((squared_returns - mean_squared_returns) ** 2)
    
    if denominator == 0:
        return 0  # Avoid division by zero
    
    rho_1 = numerator / denominator
    return rho_1

def calculate_sortino_ratio(log_returns, target_log_return=0.0):
    """
    Calculate the Sortino Ratio using log returns.
    
    Parameters:
    - log_returns (array-like): Array or list of log returns for the period.
    - target_log_return (float): The target log return. Default is 0, which is often used as a benchmark.
    
    Returns:
    - float: The Sortino Ratio.
    """
    # Convert input to a NumPy array for easier calculations
    log_returns = np.array(log_returns)
    
    # Calculate the average period log return (R)
    avg_log_return = np.mean(log_returns)
    
    # Calculate the Target Downside Deviation (TDD)
    downside_deviation = np.sqrt(
        np.mean(np.square(np.maximum(0, target_log_return - log_returns)))
    )
    
    # Calculate Sortino Ratio
    #sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
    epsilon = 1e-8
    
    # Add epsilon to downside_deviation to prevent division by zero
    #if downside_deviation == 0:
     #   return np.nan  # Return NaN if downside deviation is zero
    
    # Calculate Sortino Ratio
    sortino_ratio_value = (avg_log_return - target_log_return) / (downside_deviation + epsilon)
    
    return sortino_ratio_value

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, volatility_clustering, 
    mean_forecast, std_forecast, mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
    mean_volatility_clustering, std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    # Debugging: Log raw input values
    print(f"\nDebug: Composite Score Calculation")
    print(f"Forecasted Mean: {forecasted_mean}, Risk Percentage: {risk_percentage}")
    print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
    print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")

    # Normalize the components with epsilon
    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Debugging: Log normalized values
    print(f"Normalized Values -> Forecasted Mean: {forecasted_mean_normalized}, Rachev: {rachev_normalized}")
    print(f"Sharpe: {sharpe_normalized}, Sortino: {sortino_normalized}, Volatility Clustering: {volatility_clustering_normalized}")

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    # Debugging: Log final score
    print(f"Final Composite Score: {score}")

    return score


def process_etf_data_weekly(tickers, etf_dict):
    etf_pred_dict = {}

    # Determine the forecast periods dynamically from the etf_dict
    sample_etf = next(iter(etf_dict.values()))
    forecast_periods = [key.split('_')[-1] for key in sample_etf.keys() if key.startswith('forecast_predictions_df')]

    for etf_name in tickers:
        etf_pred_dict[etf_name] = {
            f"returns_{period}": etf_dict[etf_name][f"forecast_predictions_df_{period}"]
            for period in forecast_periods
        }

        for period in forecast_periods:
            returns = etf_pred_dict[etf_name][f"returns_{period}"]

            # Log returns for debugging
            print(f"\nDebug: Returns for {etf_name}, Forecast Period {period}: {returns}")

            # Calculate metrics
            etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
            etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
            etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
            etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict



def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    print(f"\nDebug: Forecast Period = {forecast_period}")
    print(f"All Returns Means: {[np.mean(returns) for returns in returns_list]}")
    print(f"Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Rachev Ratios: {rachev_ratios}")
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sharpe Ratios: {sharpe_ratios}")
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sortino Ratios: {sortino_ratios}")
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Volatility Clustering: {volatility_clustering}")
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    print(f"Mean Rachev = {mean_rachev}, Std Rachev = {std_rachev}")
    print(f"Mean Sharpe = {mean_sharpe}, Std Sharpe = {std_sharpe}")
    print(f"Mean Sortino = {mean_sortino}, Std Sortino = {std_sortino}")
    print(f"Mean Volatility Clustering = {mean_volatility_clustering}, Std Volatility Clustering = {std_volatility_clustering}")

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )



def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Debugging: Log inputs to composite score calculation
        print(f"\nDebug: ETF = {etf}, Forecast Period = {forecast_period}")
        print(f"Forecasted Values Mean: {np.mean(forecasted_values)}")
        print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
        print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")
        print(f"Means and Stds: Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")
        
        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

        # Debugging: Log the calculated score
        print(f"Calculated Score for {etf} ({forecast_period}): {score}")

    return scores



def main_weekly(tickers, etf_dict):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict)
    
    risk_percentage = 0.10
    weekly_scores = {}

    # Iterate over 48 weeks
    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores
            print(f"Scores calculated for {week_key}:")
            for score in scores:
                print(score)
        else:
            print(f"Skipping score calculation for {week_key}: No ETFs have data for this week.")

    return etf_pred_dict, weekly_scores


# Example usage:
# Execute weekly scoring
etf_pred_dict, weekly_scores = main_weekly(tickers, etf_dict)
# Out:
# Debug: Returns for SMH, Forecast Period 1w: [-0.02114971 -0.01641913 -0.01328753 -0.010488  ]
#
# Debug: Returns for SMH, Forecast Period 2w: [-0.00236152 -0.01116573 -0.01175923 -0.01105097 -0.01297825]
#
# Debug: Returns for SMH, Forecast Period 3w: [-0.00797619 -0.01325713 -0.00273405 -0.00242556]
#
# Debug: Returns for SMH, Forecast Period 4w: [-0.01171342 -0.01074597 -0.00792683 -0.01255071 -0.01969242]
#
# Debug: Returns for SMH, Forecast Period 5w: [-0.0102156  -0.01522117 -0.01648088 -0.00956425 -0.00606219]
#
# Debug: Returns for SMH, Forecast Period 6w: [-0.00558619 -0.01330606 -0.00610416 -0.00728405 -0.00485444]
#
# Debug: Returns for SMH, Forecast Period 7w: [-0.01057591 -0.01520299 -0.0058159  -0.01044066 -0.011452  ]
#
# Debug: Returns for SMH, Forecast Period 8w: [-0.01689423 -0.0141256   0.00472629 -0.01330351]
#
# Debug: Returns for SMH, Forecast Period 9w: [-0.01023087 -0.01121312 -0.01387803 -0.006257   -0.0012057 ]
#
# Debug: Returns for SMH, Forecast Period 10w: [-0.00638326 -0.01454497 -0.0054298  -0.00418289 -0.02243296]
#
# Debug: Returns for SMH, Forecast Period 11w: [-0.01743854 -0.00619245 -0.01804749 -0.01771773 -0.01652703]
#
# Debug: Returns for SMH, Forecast Period 12w: [-0.01417574 -0.01474176 -0.00934116 -0.00681761 -0.01264583]
#
# Debug: Returns for SMH, Forecast Period 13w: [-0.01366509 -0.01519813 -0.01382404 -0.01380284]
#
# Debug: Returns for SMH, Forecast Period 14w: [-0.01243985 -0.01526252 -0.01027388 -0.01647303 -0.00531858]
#
# Debug: Returns for SMH, Forecast Period 15w: [-0.00392187 -0.00991166 -0.01389472 -0.00452025 -0.01690965]
#
# Debug: Returns for SMH, Forecast Period 16w: [-0.01374874 -0.01030632 -0.01607954 -0.01075875 -0.01590609]
#
# Debug: Returns for SMH, Forecast Period 17w: [ 0.00013931  0.00195634 -0.00443571 -0.00148284 -0.00251436]
#
# Debug: Returns for SMH, Forecast Period 18w: [-0.00919723 -0.01028028 -0.01188399 -0.00046798 -0.00419652]
#
# Debug: Returns for SMH, Forecast Period 19w: [-0.00638811 -0.01184372 -0.0092149  -0.01156992 -0.00525169]
#
# Debug: Returns for SMH, Forecast Period 20w: [-0.01217761 -0.01111275 -0.00893203 -0.01436097 -0.01363888]
#
# Debug: Returns for SMH, Forecast Period 21w: [-0.00609489 -0.01015436 -0.00958052 -0.00854578 -0.00764326]
#
# Debug: Returns for SMH, Forecast Period 22w: [-0.00715126 -0.01534332 -0.01399757 -0.01183627]
#
# Debug: Returns for SMH, Forecast Period 23w: [-0.00864953 -0.01216669 -0.00248402 -0.01257418 -0.01084677]
#
# Debug: Returns for SMH, Forecast Period 24w: [-0.00764944 -0.01054166 -0.0046142  -0.00698887 -0.01028838]
#
# Debug: Returns for SMH, Forecast Period 25w: [-0.00738145 -0.0076356  -0.01819309 -0.01473901]
#
# Debug: Returns for SMH, Forecast Period 26w: [-0.02091941 -0.0096426  -0.01466694 -0.01567157 -0.01312987]
#
# Debug: Returns for SMH, Forecast Period 27w: [-0.01348399 -0.01177707 -0.00995894 -0.01331708]
#
# Debug: Returns for SMH, Forecast Period 28w: [-0.01219741 -0.01419552 -0.01000674 -0.02139908 -0.01347613]
#
# Debug: Returns for SMH, Forecast Period 29w: [-0.01585615 -0.01459235 -0.02176613 -0.00329409 -0.00981872]
#
# Debug: Returns for SMH, Forecast Period 30w: [ 0.00428364 -0.0097865  -0.02168949 -0.00822951 -0.00045784]
#
# Debug: Returns for SMH, Forecast Period 31w: [-0.00590001 -0.01782412  0.0215206  -0.02440027 -0.04192953]
#
# Debug: Returns for SMH, Forecast Period 32w: [-0.04157212 -0.03669675 -0.04802648 -0.02394928 -0.02393722]
#
# Debug: Returns for SMH, Forecast Period 33w: [-0.02436486 -0.00147385 -0.01172063  0.00615571 -0.0074968 ]
#
# Debug: Returns for SMH, Forecast Period 34w: [-0.00988933 -0.00767497 -0.00518646 -0.02022081 -0.01069852]
#
# Debug: Returns for SMH, Forecast Period 35w: [-0.01851086 -0.01272489 -0.019636   -0.0095105  -0.01202834]
#
# Debug: Returns for SMH, Forecast Period 36w: [-0.03011314 -0.01813764 -0.01678625 -0.02556329]
#
# Debug: Returns for SMH, Forecast Period 37w: [-0.00526668 -0.01030132 -0.00373364 -0.01232931 -0.01065077]
#
# Debug: Returns for SMH, Forecast Period 38w: [-0.01007778 -0.00416171 -0.00552045  0.00735094 -0.00555727]
#
# Debug: Returns for SMH, Forecast Period 39w: [-0.00710282 -0.00208315 -0.00996137 -0.00798219 -0.01844396]
#
# Debug: Returns for SMH, Forecast Period 40w: [-0.01600041 -0.01598415 -0.01266517 -0.01383769 -0.01292237]
#
# Debug: Returns for SMH, Forecast Period 41w: [-0.01227032 -0.00999861 -0.01091812 -0.01427995 -0.01239019]
#
# Debug: Returns for SMH, Forecast Period 42w: [-0.0107256  -0.02547377 -0.01650319 -0.0133212  -0.01499976]
#
# Debug: Returns for SMH, Forecast Period 43w: [-0.01457781 -0.01593432 -0.01649643 -0.01367385 -0.0107665 ]
#
# Debug: Returns for SMH, Forecast Period 44w: [-0.01580877 -0.0111253  -0.0185726  -0.02018713 -0.01001483]
#
# Debug: Returns for SMH, Forecast Period 45w: [-0.01130376 -0.00881165 -0.00753274 -0.00933239 -0.01553373]
#
# Debug: Returns for SMH, Forecast Period 46w: [-0.01518233 -0.00769801 -0.01542466 -0.01230972 -0.01209889]
#
# Debug: Returns for SMH, Forecast Period 47w: [-0.00465414 -0.00481714 -0.00782562 -0.00769048 -0.01036985]
#
# Debug: Returns for SMH, Forecast Period 48w: [-0.00729044 -0.00763213 -0.00452002 -0.00248012]
#
# Debug: Returns for SOXX, Forecast Period 1w: [0.02564576 0.03041519 0.03280415 0.0343366 ]
#
# Debug: Returns for SOXX, Forecast Period 2w: [0.03400894 0.03170621 0.03297779 0.03533133 0.03410917]
#
# Debug: Returns for SOXX, Forecast Period 3w: [0.03759888 0.02884762 0.04127937 0.04088899]
#
# Debug: Returns for SOXX, Forecast Period 4w: [0.03359761 0.03028348 0.03486507 0.03211905 0.02836825]
#
# Debug: Returns for SOXX, Forecast Period 5w: [0.03509597 0.0306314  0.02905478 0.03541634 0.03512003]
#
# Debug: Returns for SOXX, Forecast Period 6w: [0.03351201 0.03179084 0.03806202 0.0357461  0.03424908]
#
# Debug: Returns for SOXX, Forecast Period 7w: [0.03292957 0.03395581 0.0355982  0.03157874 0.03416698]
#
# Debug: Returns for SOXX, Forecast Period 8w: [0.0313868  0.03461811 0.04432115 0.03423636]
#
# Debug: Returns for SOXX, Forecast Period 9w: [0.03798702 0.03632884 0.03471973 0.03725027 0.0342702 ]
#
# Debug: Returns for SOXX, Forecast Period 10w: [0.03231963 0.03325417 0.034275   0.03148966 0.03218196]
#
# Debug: Returns for SOXX, Forecast Period 11w: [0.03577745 0.03801216 0.03413746 0.03565342 0.0353197 ]
#
# Debug: Returns for SOXX, Forecast Period 12w: [0.03699967 0.03676629 0.03946538 0.03763291 0.03864636]
#
# Debug: Returns for SOXX, Forecast Period 13w: [0.03798852 0.0368631  0.03912709 0.03734317]
#
# Debug: Returns for SOXX, Forecast Period 14w: [0.03882946 0.03288459 0.03584179 0.02635967 0.03442626]
#
# Debug: Returns for SOXX, Forecast Period 15w: [0.02939322 0.03718894 0.03021875 0.03919128 0.02554461]
#
# Debug: Returns for SOXX, Forecast Period 16w: [0.03092288 0.03783997 0.02279963 0.02322655 0.0117422 ]
#
# Debug: Returns for SOXX, Forecast Period 17w: [0.01840488 0.0229776  0.02446425 0.03062879 0.03257469]
#
# Debug: Returns for SOXX, Forecast Period 18w: [0.03218034 0.02102505 0.01352063 0.02719631 0.03613926]
#
# Debug: Returns for SOXX, Forecast Period 19w: [0.03743418 0.0289493  0.0300582  0.03266058 0.0331913 ]
#
# Debug: Returns for SOXX, Forecast Period 20w: [0.03601713 0.04028125 0.04127269 0.03544234 0.03288353]
#
# Debug: Returns for SOXX, Forecast Period 21w: [0.02887271 0.02894498 0.03264126 0.03408686 0.03443649]
#
# Debug: Returns for SOXX, Forecast Period 22w: [0.03497114 0.03355749 0.03286003 0.03103082]
#
# Debug: Returns for SOXX, Forecast Period 23w: [0.03367735 0.03552212 0.03953713 0.03351953 0.03401567]
#
# Debug: Returns for SOXX, Forecast Period 24w: [0.03401008 0.03423224 0.03466402 0.03455832 0.03578225]
#
# Debug: Returns for SOXX, Forecast Period 25w: [0.03544278 0.03293313 0.03496687 0.03655139]
#
# Debug: Returns for SOXX, Forecast Period 26w: [0.03599219 0.04100504 0.03821094 0.03785146 0.04148487]
#
# Debug: Returns for SOXX, Forecast Period 27w: [0.03998035 0.04104965 0.03952104 0.03775443]
#
# Debug: Returns for SOXX, Forecast Period 28w: [0.04279035 0.03956347 0.03863535 0.03562688 0.04092203]
#
# Debug: Returns for SOXX, Forecast Period 29w: [0.04001107 0.0404414  0.01305728 0.02897242 0.01701651]
#
# Debug: Returns for SOXX, Forecast Period 30w: [0.03985773 0.03079231 0.01291977 0.01228359 0.02429505]
#
# Debug: Returns for SOXX, Forecast Period 31w: [0.02020547 0.00882893 0.03178439 0.00261744 0.00080803]
#
# Debug: Returns for SOXX, Forecast Period 32w: [ 0.00355709  0.00511189 -0.00027318  0.00851031  0.00499804]
#
# Debug: Returns for SOXX, Forecast Period 33w: [0.00612208 0.00984625 0.00749161 0.02147844 0.01460339]
#
# Debug: Returns for SOXX, Forecast Period 34w: [0.02600447 0.01214085 0.02050257 0.01479564 0.02984716]
#
# Debug: Returns for SOXX, Forecast Period 35w: [0.01822162 0.02655186 0.02376896 0.01612069 0.03222784]
#
# Debug: Returns for SOXX, Forecast Period 36w: [0.01516308 0.02892849 0.0277853  0.02037836]
#
# Debug: Returns for SOXX, Forecast Period 37w: [0.02357459 0.02700379 0.03138653 0.02208389 0.02872439]
#
# Debug: Returns for SOXX, Forecast Period 38w: [0.01593814 0.01947344 0.01404887 0.02655792 0.0141307 ]
#
# Debug: Returns for SOXX, Forecast Period 39w: [0.02477301 0.02251798 0.02957589 0.03434544 0.03195596]
#
# Debug: Returns for SOXX, Forecast Period 40w: [0.03091919 0.01692762 0.03807908 0.03767832 0.03932913]
#
# Debug: Returns for SOXX, Forecast Period 41w: [0.03842045 0.0386833  0.03800297 0.03923386 0.0393365 ]
#
# Debug: Returns for SOXX, Forecast Period 42w: [0.0403253  0.02641479 0.03644928 0.03885658 0.0384357 ]
#
# Debug: Returns for SOXX, Forecast Period 43w: [0.03861003 0.03782858 0.03438224 0.03755524 0.0361497 ]
#
# Debug: Returns for SOXX, Forecast Period 44w: [0.03691074 0.04248506 0.03080089 0.01826828 0.03386218]
#
# Debug: Returns for SOXX, Forecast Period 45w: [0.02842734 0.03385842 0.03883553 0.03911466 0.03472367]
#
# Debug: Returns for SOXX, Forecast Period 46w: [0.02497109 0.02566407 0.02706411 0.03257723 0.0193585 ]
#
# Debug: Returns for SOXX, Forecast Period 47w: [0.02979602 0.0292134  0.02603917 0.03257955 0.03096703]
#
# Debug: Returns for SOXX, Forecast Period 48w: [0.03242439 0.0271786  0.02263927 0.03283319]
#
# Debug: Returns for PSI, Forecast Period 1w: [-0.02083115 -0.01008259 -0.0043965   0.00110177]
#
# Debug: Returns for PSI, Forecast Period 2w: [ 3.6260076e-03 -4.5677675e-03 -7.0268689e-03  3.9581908e-05
#  -3.6599627e-03]
#
# Debug: Returns for PSI, Forecast Period 3w: [ 0.00275858 -0.00642315  0.00835478  0.00841096]
#
# Debug: Returns for PSI, Forecast Period 4w: [-0.00596876 -0.01179144 -0.0051224  -0.01015634 -0.01470987]
#
# Debug: Returns for PSI, Forecast Period 5w: [-0.00143145 -0.01196188 -0.01254853 -0.00289099 -0.00895549]
#
# Debug: Returns for PSI, Forecast Period 6w: [-0.01334842 -0.01958755 -0.00932083 -0.00735221 -0.00722704]
#
# Debug: Returns for PSI, Forecast Period 7w: [-0.02011258 -0.02692262 -0.0055312  -0.01752308 -0.02162647]
#
# Debug: Returns for PSI, Forecast Period 8w: [-0.02443757 -0.01504023  0.00693745 -0.01752306]
#
# Debug: Returns for PSI, Forecast Period 9w: [-0.00550119 -0.01638604 -0.01079248 -0.0098323  -0.0072344 ]
#
# Debug: Returns for PSI, Forecast Period 10w: [-0.02108084 -0.02389313 -0.00893461 -0.00808284 -0.01943539]
#
# Debug: Returns for PSI, Forecast Period 11w: [-0.01203194  0.00038694 -0.01444907 -0.01073642 -0.00634037]
#
# Debug: Returns for PSI, Forecast Period 12w: [-0.00011017 -0.00538083  0.00342722 -0.00377321 -0.01168818]
#
# Debug: Returns for PSI, Forecast Period 13w: [-0.01304322 -0.01774768 -0.01221769 -0.01827879]
#
# Debug: Returns for PSI, Forecast Period 14w: [-0.01452771 -0.02144619 -0.01255398 -0.02469981 -0.00909512]
#
# Debug: Returns for PSI, Forecast Period 15w: [-0.01100005 -0.00378654 -0.01316385  0.00550554 -0.01795236]
#
# Debug: Returns for PSI, Forecast Period 16w: [-0.01199531 -0.00380958 -0.01828898 -0.01437578 -0.01668322]
#
# Debug: Returns for PSI, Forecast Period 17w: [-0.00586734 -0.00385389 -0.00623624 -0.00310238 -0.00247275]
#
# Debug: Returns for PSI, Forecast Period 18w: [-0.00229758 -0.01331697 -0.01550596 -0.00321009 -0.00026241]
#
# Debug: Returns for PSI, Forecast Period 19w: [-6.0168561e-05 -1.1534203e-02 -1.1797796e-02 -7.1330974e-03
#  -8.0259591e-03]
#
# Debug: Returns for PSI, Forecast Period 20w: [-0.00931526 -0.00474108 -0.00359428 -0.02321687 -0.02480998]
#
# Debug: Returns for PSI, Forecast Period 21w: [-0.01183714 -0.02154662 -0.02441473 -0.02499844 -0.0193994 ]
#
# Debug: Returns for PSI, Forecast Period 22w: [-0.02044643 -0.02628117 -0.02469455 -0.02559514]
#
# Debug: Returns for PSI, Forecast Period 23w: [-0.02019195 -0.0174758  -0.0008996  -0.0225226  -0.02109409]
#
# Debug: Returns for PSI, Forecast Period 24w: [-0.01401155 -0.02294919 -0.01602865 -0.02376899 -0.02489881]
#
# Debug: Returns for PSI, Forecast Period 25w: [-0.01956542 -0.02482804 -0.03036711 -0.02268371]
#
# Debug: Returns for PSI, Forecast Period 26w: [-0.02092096 -0.00534684 -0.01724806 -0.01267744 -0.01062526]
#
# Debug: Returns for PSI, Forecast Period 27w: [-0.01472405 -0.01414649 -0.01815448 -0.02312443]
#
# Debug: Returns for PSI, Forecast Period 28w: [-0.01579932 -0.02297119 -0.02251777 -0.02871014 -0.01486271]
#
# Debug: Returns for PSI, Forecast Period 29w: [-0.01328222 -0.01542383 -0.02427655 -0.01355831 -0.01610232]
#
# Debug: Returns for PSI, Forecast Period 30w: [ 0.00232082 -0.00857197 -0.01704729 -0.01288921 -0.00423665]
#
# Debug: Returns for PSI, Forecast Period 31w: [-0.0084065  -0.01381935  0.00244521 -0.01359436 -0.01142515]
#
# Debug: Returns for PSI, Forecast Period 32w: [-0.00277108  0.00074102 -0.00210402  0.01014096 -0.00638322]
#
# Debug: Returns for PSI, Forecast Period 33w: [-0.00704327 -0.0048912  -0.00918336 -0.00676272 -0.01516525]
#
# Debug: Returns for PSI, Forecast Period 34w: [-0.01326    -0.02200436 -0.01791485 -0.02624134 -0.00459999]
#
# Debug: Returns for PSI, Forecast Period 35w: [-0.02212257 -0.00995519 -0.01114114 -0.01395454 -0.00062958]
#
# Debug: Returns for PSI, Forecast Period 36w: [-0.01905107 -0.00153951 -0.00556949 -0.01240773]
#
# Debug: Returns for PSI, Forecast Period 37w: [-0.00829116 -0.0062618   0.00517696 -0.00705533  0.00363926]
#
# Debug: Returns for PSI, Forecast Period 38w: [-0.0137509  -0.00724181 -0.01174871 -0.00497589 -0.01882697]
#
# Debug: Returns for PSI, Forecast Period 39w: [-0.01435852 -0.0174583  -0.01563049  0.00142502 -0.01918552]
#
# Debug: Returns for PSI, Forecast Period 40w: [-0.01667548 -0.02453926 -0.00181314 -0.00961245 -0.00040554]
#
# Debug: Returns for PSI, Forecast Period 41w: [-0.00559547 -0.00395532 -0.00179257 -0.00303786  0.00051448]
#
# Debug: Returns for PSI, Forecast Period 42w: [ 0.00048643 -0.01587326 -0.00048445 -0.00456552 -0.00855881]
#
# Debug: Returns for PSI, Forecast Period 43w: [-0.01210005 -0.01398778 -0.01613813 -0.0126615  -0.01103877]
#
# Debug: Returns for PSI, Forecast Period 44w: [-0.01571277 -0.00478407 -0.02145869 -0.02394056 -0.0103079 ]
#
# Debug: Returns for PSI, Forecast Period 45w: [-0.01452968 -0.00313134  0.00180497 -0.0008551  -0.01426192]
#
# Debug: Returns for PSI, Forecast Period 46w: [-0.02223125 -0.01892397 -0.02201616 -0.01659964 -0.02279377]
#
# Debug: Returns for PSI, Forecast Period 47w: [-0.01316963 -0.01381398 -0.01634097 -0.00245004 -0.01191617]
#
# Debug: Returns for PSI, Forecast Period 48w: [-0.00577431 -0.01500833 -0.01925318 -0.00618092]
#
# Debug: Returns for XSD, Forecast Period 1w: [-0.01642137 -0.01727797 -0.01581688 -0.01170745]
#
# Debug: Returns for XSD, Forecast Period 2w: [-0.00668174 -0.01173772 -0.01211347 -0.01228836 -0.01210969]
#
# Debug: Returns for XSD, Forecast Period 3w: [-0.00959684 -0.02073671 -0.00556329 -0.00339895]
#
# Debug: Returns for XSD, Forecast Period 4w: [-0.00559695 -0.00648473 -0.01184431 -0.01310262 -0.02266123]
#
# Debug: Returns for XSD, Forecast Period 5w: [-0.00682942 -0.02081856 -0.01973925 -0.0107714  -0.00767633]
#
# Debug: Returns for XSD, Forecast Period 6w: [-0.00493254 -0.00716908 -0.00171437 -0.00084263 -0.00196977]
#
# Debug: Returns for XSD, Forecast Period 7w: [-0.00439683 -0.01236028 -0.00274054 -0.00524053 -0.00749655]
#
# Debug: Returns for XSD, Forecast Period 8w: [-0.00855337 -0.00854077 -0.00310096 -0.01367513]
#
# Debug: Returns for XSD, Forecast Period 9w: [-0.00507295 -0.00727201 -0.00849162 -0.00233462 -0.00291821]
#
# Debug: Returns for XSD, Forecast Period 10w: [-0.0080501  -0.01197159 -0.00479416 -0.00550818 -0.01421653]
#
# Debug: Returns for XSD, Forecast Period 11w: [-0.01046629 -0.00721012 -0.01544306 -0.01503993 -0.01360322]
#
# Debug: Returns for XSD, Forecast Period 12w: [-0.01164503 -0.01155521 -0.00463163 -0.00441126 -0.0081217 ]
#
# Debug: Returns for XSD, Forecast Period 13w: [-0.00664503 -0.00638951 -0.001391   -0.0034853 ]
#
# Debug: Returns for XSD, Forecast Period 14w: [-0.00244686 -0.00973153 -0.00323254 -0.00902619 -0.00590699]
#
# Debug: Returns for XSD, Forecast Period 15w: [-0.00682055 -0.00305399 -0.0185381  -0.0053959  -0.01748949]
#
# Debug: Returns for XSD, Forecast Period 16w: [-0.01533725 -0.01070783 -0.01556608 -0.01597719 -0.02381318]
#
# Debug: Returns for XSD, Forecast Period 17w: [-0.01631819 -0.01207331 -0.00933799 -0.00802024 -0.00879104]
#
# Debug: Returns for XSD, Forecast Period 18w: [-0.00794612 -0.01870687 -0.02189957 -0.01066282 -0.00809114]
#
# Debug: Returns for XSD, Forecast Period 19w: [-0.0082732  -0.01331414 -0.01226776 -0.00917027 -0.01207251]
#
# Debug: Returns for XSD, Forecast Period 20w: [-0.00757253 -0.00557658 -0.00516787 -0.00913219 -0.00878456]
#
# Debug: Returns for XSD, Forecast Period 21w: [-0.00969743 -0.01018249 -0.00735598 -0.0114689  -0.00513432]
#
# Debug: Returns for XSD, Forecast Period 22w: [-0.00560648 -0.00992238 -0.00643708 -0.00965803]
#
# Debug: Returns for XSD, Forecast Period 23w: [-0.01001384 -0.0120228  -0.00423415 -0.01074716 -0.01235213]
#
# Debug: Returns for XSD, Forecast Period 24w: [-0.00621103 -0.0069441  -0.00456969 -0.00723888 -0.00878205]
#
# Debug: Returns for XSD, Forecast Period 25w: [-0.00435318 -0.00383244 -0.00774505 -0.00342562]
#
# Debug: Returns for XSD, Forecast Period 26w: [-7.8960517e-03 -1.3917813e-03 -2.0638991e-03 -2.7093003e-03
#  -3.4212833e-05]
#
# Debug: Returns for XSD, Forecast Period 27w: [-1.7324978e-03  9.8919985e-04  8.8444212e-05 -3.6207074e-04]
#
# Debug: Returns for XSD, Forecast Period 28w: [ 0.00109934 -0.00174634 -0.00129333 -0.0045691  -0.00235075]
#
# Debug: Returns for XSD, Forecast Period 29w: [-0.00220237 -0.00196512 -0.0190168  -0.01221702 -0.01798338]
#
# Debug: Returns for XSD, Forecast Period 30w: [-0.00463672 -0.01461166 -0.01828965 -0.01697085 -0.01029474]
#
# Debug: Returns for XSD, Forecast Period 31w: [-0.01381276 -0.02330179 -0.00712528 -0.03575698 -0.04733691]
#
# Debug: Returns for XSD, Forecast Period 32w: [-0.04398989 -0.03905835 -0.04544701 -0.01965258 -0.03974113]
#
# Debug: Returns for XSD, Forecast Period 33w: [-0.0397359  -0.02708132 -0.0412785  -0.01154494 -0.02048025]
#
# Debug: Returns for XSD, Forecast Period 34w: [-0.01389625 -0.02281907 -0.01233271 -0.01855992 -0.00978638]
#
# Debug: Returns for XSD, Forecast Period 35w: [-0.01581578 -0.01309827 -0.01512567 -0.01226082 -0.01244743]
#
# Debug: Returns for XSD, Forecast Period 36w: [-0.02529228 -0.02013661 -0.02038324 -0.02426808]
#
# Debug: Returns for XSD, Forecast Period 37w: [-0.0168336  -0.01799338 -0.01554398 -0.01783856 -0.01594541]
#
# Debug: Returns for XSD, Forecast Period 38w: [-0.01705756 -0.01541974 -0.01600301 -0.01095382 -0.01638369]
#
# Debug: Returns for XSD, Forecast Period 39w: [-0.01453915 -0.01305488 -0.01401791 -0.00561049 -0.01357097]
#
# Debug: Returns for XSD, Forecast Period 40w: [-0.01422375 -0.01708322 -0.01371263 -0.01497684 -0.01178519]
#
# Debug: Returns for XSD, Forecast Period 41w: [-0.01749518 -0.01413192 -0.01199209 -0.01428401 -0.01054596]
#
# Debug: Returns for XSD, Forecast Period 42w: [-0.01090873 -0.01696417 -0.01132958 -0.01088924 -0.0106618 ]
#
# Debug: Returns for XSD, Forecast Period 43w: [-0.01072617 -0.00931672 -0.01120679 -0.00794092 -0.00713492]
#
# Debug: Returns for XSD, Forecast Period 44w: [-0.0062178  -0.00489844 -0.0162585  -0.01890984 -0.00945791]
#
# Debug: Returns for XSD, Forecast Period 45w: [-0.01408417 -0.00987871 -0.00457577 -0.00788882 -0.00731521]
#
# Debug: Returns for XSD, Forecast Period 46w: [-0.01446681 -0.01428787 -0.01434932 -0.01218577 -0.0178294 ]
#
# Debug: Returns for XSD, Forecast Period 47w: [-0.00900293 -0.00850882 -0.00933021 -0.00314338 -0.00388727]
#
# Debug: Returns for XSD, Forecast Period 48w: [-0.00204177 -0.0093485  -0.01204451 -0.00570327]
#
# Debug: Returns for IYW, Forecast Period 1w: [-0.02489072 -0.0174169  -0.01656511 -0.01366411]
#
# Debug: Returns for IYW, Forecast Period 2w: [-0.00116547 -0.01391829 -0.01125824 -0.01324779 -0.01391451]
#
# Debug: Returns for IYW, Forecast Period 3w: [-0.01385788 -0.01642103 -0.00589603 -0.00446772]
#
# Debug: Returns for IYW, Forecast Period 4w: [-0.01340965 -0.01395185 -0.01221267 -0.0134281  -0.01956139]
#
# Debug: Returns for IYW, Forecast Period 5w: [-0.01054486 -0.01892507 -0.02560629 -0.00970328 -0.00728013]
#
# Debug: Returns for IYW, Forecast Period 6w: [-0.0167136  -0.01911824 -0.00960701 -0.01460844 -0.00920829]
#
# Debug: Returns for IYW, Forecast Period 7w: [-0.02097798 -0.025957   -0.01095526 -0.01827417 -0.02148528]
#
# Debug: Returns for IYW, Forecast Period 8w: [-1.8388208e-02 -1.7022662e-02 -9.2738308e-05 -1.7198082e-02]
#
# Debug: Returns for IYW, Forecast Period 9w: [-0.01661099 -0.01552385 -0.01728122 -0.0118082  -0.01031568]
#
# Debug: Returns for IYW, Forecast Period 10w: [-0.01858472 -0.02368677 -0.01298853 -0.00955201 -0.02030479]
#
# Debug: Returns for IYW, Forecast Period 11w: [-0.01646534 -0.00685046 -0.01820905 -0.01449086 -0.01917545]
#
# Debug: Returns for IYW, Forecast Period 12w: [-0.01217821 -0.01507914 -0.01280184 -0.0179235  -0.01594975]
#
# Debug: Returns for IYW, Forecast Period 13w: [-0.01869489 -0.01828158 -0.0157274  -0.01712537]
#
# Debug: Returns for IYW, Forecast Period 14w: [-0.01436769 -0.01595842 -0.01305412 -0.02097275 -0.01065635]
#
# Debug: Returns for IYW, Forecast Period 15w: [-0.01450425 -0.0150699  -0.01774352 -0.00691127 -0.02033607]
#
# Debug: Returns for IYW, Forecast Period 16w: [-0.01974364 -0.0140542  -0.01747267 -0.01335576 -0.01597422]
#
# Debug: Returns for IYW, Forecast Period 17w: [ 3.1435257e-04  8.4922183e-05 -7.9096016e-03 -1.1039744e-02
#  -2.3816405e-03]
#
# Debug: Returns for IYW, Forecast Period 18w: [-0.0120317  -0.01694098 -0.01210748 -0.00262595 -0.00354889]
#
# Debug: Returns for IYW, Forecast Period 19w: [-0.00884946 -0.01561283 -0.01367519 -0.01484162 -0.01113382]
#
# Debug: Returns for IYW, Forecast Period 20w: [-0.01309959 -0.01361075 -0.00827846 -0.01940428 -0.01923762]
#
# Debug: Returns for IYW, Forecast Period 21w: [-0.01312398 -0.01809429 -0.01786713 -0.01766185 -0.0140674 ]
#
# Debug: Returns for IYW, Forecast Period 22w: [-0.01305607 -0.02031194 -0.03087385 -0.01938391]
#
# Debug: Returns for IYW, Forecast Period 23w: [-0.01528049 -0.01762088 -0.00618815 -0.01931757 -0.0176058 ]
#
# Debug: Returns for IYW, Forecast Period 24w: [-0.01678694 -0.01159467 -0.00931509 -0.01690168 -0.01591624]
#
# Debug: Returns for IYW, Forecast Period 25w: [-0.01383979 -0.01829503 -0.02491722 -0.02057317]
#
# Debug: Returns for IYW, Forecast Period 26w: [-0.02502244 -0.00965444 -0.01596491 -0.01595242 -0.01836769]
#
# Debug: Returns for IYW, Forecast Period 27w: [-0.01363176 -0.01609293 -0.01362332 -0.01528265]
#
# Debug: Returns for IYW, Forecast Period 28w: [-0.01487294 -0.0181667  -0.01116843 -0.02889929 -0.01496168]
#
# Debug: Returns for IYW, Forecast Period 29w: [-0.01554341 -0.01783498 -0.02601043 -0.01417565 -0.01440623]
#
# Debug: Returns for IYW, Forecast Period 30w: [-0.00755916 -0.0164203  -0.02872767 -0.01344579 -0.00721856]
# Debug: Returns for IYW, Forecast Period 31w: [-0.01118734 -0.01481485  0.00836619 -0.01633306 -0.00303925]
#
# Debug: Returns for IYW, Forecast Period 32w: [0.00334995 0.0297714  0.01607421 0.04427855 0.01694501]
#
# Debug: Returns for IYW, Forecast Period 33w: [ 0.01530505  0.02506191  0.00312704 -0.0033914  -0.01657383]
#
# Debug: Returns for IYW, Forecast Period 34w: [-0.01608879 -0.01713597 -0.01456202 -0.03007118 -0.01851346]
#
# Debug: Returns for IYW, Forecast Period 35w: [-0.02561922 -0.0216019  -0.02902836 -0.0206775  -0.02043002]
#
# Debug: Returns for IYW, Forecast Period 36w: [-0.04488691 -0.0307057  -0.02698626 -0.03628361]
#
# Debug: Returns for IYW, Forecast Period 37w: [-0.0177433  -0.01826184 -0.01279288 -0.01912971 -0.0201684 ]
#
# Debug: Returns for IYW, Forecast Period 38w: [-0.01974697 -0.01660769 -0.0148714  -0.0036963  -0.01805418]
#
# Debug: Returns for IYW, Forecast Period 39w: [-0.02022734 -0.01556312 -0.01869611 -0.01512938 -0.0239931 ]
#
# Debug: Returns for IYW, Forecast Period 40w: [-0.01929533 -0.02556159 -0.02099982 -0.02191276 -0.01817703]
#
# Debug: Returns for IYW, Forecast Period 41w: [-0.02909471 -0.01717029 -0.02018391 -0.02182318 -0.0200529 ]
#
# Debug: Returns for IYW, Forecast Period 42w: [-0.01545132 -0.02913503 -0.02092021 -0.02004642 -0.01775627]
#
# Debug: Returns for IYW, Forecast Period 43w: [-0.01671434 -0.0192725  -0.02341931 -0.01640857 -0.01430623]
#
# Debug: Returns for IYW, Forecast Period 44w: [-0.01714391 -0.01316463 -0.02427069 -0.02904391 -0.01475099]
#
# Debug: Returns for IYW, Forecast Period 45w: [-0.01589864 -0.01238284 -0.00638818 -0.01084333 -0.01833106]
#
# Debug: Returns for IYW, Forecast Period 46w: [-0.01940326 -0.01499273 -0.01849357 -0.01814816 -0.02322213]
#
# Debug: Returns for IYW, Forecast Period 47w: [-0.01374098 -0.01150874 -0.01606032 -0.01546131 -0.01734766]
#
# Debug: Returns for IYW, Forecast Period 48w: [-0.01698563 -0.01504965 -0.0181534  -0.01373716]
#
# Debug: Returns for XLK, Forecast Period 1w: [-0.01084182 -0.00577187 -0.00405434 -0.00251688]
#
# Debug: Returns for XLK, Forecast Period 2w: [ 0.00885255 -0.00101019  0.00181738  0.00047529  0.00249848]
#
# Debug: Returns for XLK, Forecast Period 3w: [ 0.00239367 -0.00036407  0.01083288  0.01393331]
#
# Debug: Returns for XLK, Forecast Period 4w: [0.00715355 0.00598842 0.00742609 0.00458353 0.00191822]
#
# Debug: Returns for XLK, Forecast Period 5w: [ 0.00784748  0.00205519 -0.0015031   0.00690435  0.00205679]
#
# Debug: Returns for XLK, Forecast Period 6w: [-0.00343299 -0.00659372  0.00135532 -0.00242202 -0.00055352]
#
# Debug: Returns for XLK, Forecast Period 7w: [-0.00505962 -0.00731567  0.00028398 -0.00377709 -0.00507077]
#
# Debug: Returns for XLK, Forecast Period 8w: [-0.00744732 -0.00709218  0.00726678 -0.00462667]
#
# Debug: Returns for XLK, Forecast Period 9w: [-0.00428417 -0.00277694 -0.00413932  0.00129186  0.00338546]
#
# Debug: Returns for XLK, Forecast Period 10w: [-0.0025422  -0.0096162  -0.00015727  0.0035499  -0.0063717 ]
#
# Debug: Returns for XLK, Forecast Period 11w: [-0.00387899  0.00440702 -0.00479814 -0.00169992 -0.00668136]
#
# Debug: Returns for XLK, Forecast Period 12w: [-0.00124248 -0.0012038   0.00040222 -0.0037058  -0.00391783]
#
# Debug: Returns for XLK, Forecast Period 13w: [-0.00575116 -0.00486182 -0.00308338 -0.00479073]
#
# Debug: Returns for XLK, Forecast Period 14w: [-0.00390074 -0.00748145 -0.00385538 -0.01043228 -0.00270083]
#
# Debug: Returns for XLK, Forecast Period 15w: [-0.00520615 -0.00334629 -0.00848023  0.00215099 -0.00965238]
#
# Debug: Returns for XLK, Forecast Period 16w: [-0.01212045 -0.00582376 -0.01075704 -0.01062429 -0.01514131]
#
# Debug: Returns for XLK, Forecast Period 17w: [-0.00434395 -0.00205564 -0.00498994 -0.00716063 -0.00238323]
#
# Debug: Returns for XLK, Forecast Period 18w: [-0.00384658 -0.01256855 -0.01082798 -0.00195335  0.005601  ]
#
# Debug: Returns for XLK, Forecast Period 19w: [ 0.00152318 -0.00229364 -0.00029535 -0.00084625 -0.00086211]
#
# Debug: Returns for XLK, Forecast Period 20w: [ 0.00096947  0.00233376  0.00662156 -0.00086665  0.00016055]
#
# Debug: Returns for XLK, Forecast Period 21w: [-0.00167715 -0.00487389 -0.00204973 -0.00250471  0.00088931]
#
# Debug: Returns for XLK, Forecast Period 22w: [ 0.00041039 -0.00042701 -0.00538125 -0.00073915]
#
# Debug: Returns for XLK, Forecast Period 23w: [0.00034627 0.00248636 0.00954311 0.00071404 0.00203503]
#
# Debug: Returns for XLK, Forecast Period 24w: [0.00111207 0.0049737  0.00344255 0.00027679 0.00243351]
#
# Debug: Returns for XLK, Forecast Period 25w: [ 0.0038595  -0.00054023 -0.00027716  0.0034796 ]
#
# Debug: Returns for XLK, Forecast Period 26w: [-0.00178935  0.00990323  0.00483871  0.00517927  0.00451966]
#
# Debug: Returns for XLK, Forecast Period 27w: [ 0.00270476  0.00104179  0.00149384 -0.00513109]
#
# Debug: Returns for XLK, Forecast Period 28w: [ 0.00057119 -0.00211917 -0.00019264 -0.00913754  0.00098766]
#
# Debug: Returns for XLK, Forecast Period 29w: [-0.00043778 -0.00180051 -0.01386194 -0.00728124 -0.01077028]
#
# Debug: Returns for XLK, Forecast Period 30w: [-0.00087946 -0.00608395 -0.01819624 -0.01369567 -0.00673529]
#
# Debug: Returns for XLK, Forecast Period 31w: [-0.00946407 -0.01540562  0.00438575 -0.01735847 -0.01277344]
#
# Debug: Returns for XLK, Forecast Period 32w: [-0.01476105 -0.00399928 -0.01039519  0.00238031 -0.00313767]
#
# Debug: Returns for XLK, Forecast Period 33w: [-0.00190237  0.00174389 -0.00386903 -0.00203307 -0.01059512]
#
# Debug: Returns for XLK, Forecast Period 34w: [-0.00430334 -0.00936705 -0.0056342  -0.01361093 -0.00091793]
#
# Debug: Returns for XLK, Forecast Period 35w: [-0.01071882 -0.00527389 -0.01173833 -0.01372372 -0.00346671]
#
# Debug: Returns for XLK, Forecast Period 36w: [-0.02891806 -0.01383793 -0.01265632 -0.02232224]
#
# Debug: Returns for XLK, Forecast Period 37w: [-0.00636053 -0.00465302  0.0062907  -0.00492217 -0.00421791]
#
# Debug: Returns for XLK, Forecast Period 38w: [-0.00824596 -0.00790764 -0.0118343   0.00043297 -0.00943887]
#
# Debug: Returns for XLK, Forecast Period 39w: [-0.00579276 -0.00377311 -0.00342342 -0.00010643 -0.00602197]
#
# Debug: Returns for XLK, Forecast Period 40w: [-0.00247589 -0.01310525 -0.00205851 -0.00333947 -0.0022084 ]
#
# Debug: Returns for XLK, Forecast Period 41w: [-0.01536048 -0.00418639 -0.00605798 -0.00248434 -0.00100195]
#
# Debug: Returns for XLK, Forecast Period 42w: [ 0.0021168  -0.00758086 -0.00064805 -0.00096165 -0.00050539]
#
# Debug: Returns for XLK, Forecast Period 43w: [-0.00023605 -0.0011866  -0.00477888 -0.00118017 -0.00156128]
#
# Debug: Returns for XLK, Forecast Period 44w: [-0.00115811  0.00322607 -0.00512944 -0.01206378 -0.00325901]
#
# Debug: Returns for XLK, Forecast Period 45w: [-0.00476491  0.00068285  0.00526625  0.00227447 -0.00143513]
#
# Debug: Returns for XLK, Forecast Period 46w: [-0.00271907 -0.00210564 -0.00155899 -0.00147565 -0.00884736]
#
# Debug: Returns for XLK, Forecast Period 47w: [-0.00234692 -0.00115715 -0.00316569  0.00064826 -0.00218368]
#
# Debug: Returns for XLK, Forecast Period 48w: [-0.00290618 -0.00076402 -0.00650537  0.00024283]
#
# Debug: Returns for VGT, Forecast Period 1w: [-0.02163065 -0.02005984 -0.01737528 -0.01511606]
#
# Debug: Returns for VGT, Forecast Period 2w: [-0.00585493 -0.01358092 -0.01164446 -0.01561682 -0.01451302]
#
# Debug: Returns for VGT, Forecast Period 3w: [-0.01597726 -0.01877896 -0.01027115 -0.01204113]
#
# Debug: Returns for VGT, Forecast Period 4w: [-0.01626586 -0.01721056 -0.01737224 -0.01707104 -0.01868544]
#
# Debug: Returns for VGT, Forecast Period 5w: [-0.01343267 -0.01914961 -0.02263393 -0.01214707 -0.01007409]
#
# Debug: Returns for VGT, Forecast Period 6w: [-0.01086628 -0.01148363 -0.01007716 -0.01147219 -0.00945687]
#
# Debug: Returns for VGT, Forecast Period 7w: [-0.01424802 -0.01738851 -0.01044105 -0.01236383 -0.01732765]
#
# Debug: Returns for VGT, Forecast Period 8w: [-0.02057586 -0.0216851  -0.00923422 -0.01909657]
#
# Debug: Returns for VGT, Forecast Period 9w: [-0.01836484 -0.01769918 -0.01998598 -0.01562534 -0.00947603]
#
# Debug: Returns for VGT, Forecast Period 10w: [-0.01464659 -0.02094447 -0.01470986 -0.01121026 -0.01933784]
#
# Debug: Returns for VGT, Forecast Period 11w: [-0.01878343 -0.01438778 -0.01995129 -0.01689406 -0.02141055]
#
# Debug: Returns for VGT, Forecast Period 12w: [-0.01737088 -0.01568122 -0.01081161 -0.0114262  -0.01672766]
#
# Debug: Returns for VGT, Forecast Period 13w: [-0.01763797 -0.01833363 -0.01755456 -0.01805385]
#
# Debug: Returns for VGT, Forecast Period 14w: [-0.01873524 -0.02307033 -0.02097122 -0.02130163 -0.01795096]
#
# Debug: Returns for VGT, Forecast Period 15w: [-0.02199149 -0.01882863 -0.02100231 -0.01693812 -0.02347886]
#
# Debug: Returns for VGT, Forecast Period 16w: [-0.0253933  -0.02027775 -0.02457254 -0.02585432 -0.03155039]
#
# Debug: Returns for VGT, Forecast Period 17w: [-0.02315121 -0.02040232 -0.02234926 -0.02118689 -0.01601395]
#
# Debug: Returns for VGT, Forecast Period 18w: [-0.01946333 -0.02504417 -0.02395238 -0.01789685 -0.01156581]
#
# Debug: Returns for VGT, Forecast Period 19w: [-0.01550179 -0.01950266 -0.0186727  -0.01895806 -0.0200475 ]
#
# Debug: Returns for VGT, Forecast Period 20w: [-0.01733554 -0.01418447 -0.00930319 -0.01304264 -0.01153403]
#
# Debug: Returns for VGT, Forecast Period 21w: [-0.00643018 -0.00946925 -0.0114023  -0.01136034 -0.00912531]
#
# Debug: Returns for VGT, Forecast Period 22w: [-0.01033631 -0.01352314 -0.01595695 -0.01074614]
#
# Debug: Returns for VGT, Forecast Period 23w: [-0.01077558 -0.01457814 -0.01013595 -0.01522579 -0.01497843]
#
# Debug: Returns for VGT, Forecast Period 24w: [-0.013519   -0.01087561 -0.00915503 -0.01134401 -0.01437188]
#
# Debug: Returns for VGT, Forecast Period 25w: [-0.01104501 -0.01189994 -0.01735076 -0.0157293 ]
#
# Debug: Returns for VGT, Forecast Period 26w: [-0.01935659 -0.01136405 -0.01525688 -0.01656668 -0.01678576]
#
# Debug: Returns for VGT, Forecast Period 27w: [-0.01198321 -0.01182718 -0.01107159 -0.01206244]
#
# Debug: Returns for VGT, Forecast Period 28w: [-0.01308065 -0.01409254 -0.01023126 -0.0159244  -0.01196826]
#
# Debug: Returns for VGT, Forecast Period 29w: [-0.01498532 -0.01625927 -0.02329222 -0.02304997 -0.0243997 ]
#
# Debug: Returns for VGT, Forecast Period 30w: [-0.01553364 -0.01896694 -0.02613363 -0.02512693 -0.01922765]
#
# Debug: Returns for VGT, Forecast Period 31w: [-0.02384238 -0.02648115 -0.01175806 -0.02871278 -0.03059765]
#
# Debug: Returns for VGT, Forecast Period 32w: [-0.03429133 -0.02523932 -0.02405204 -0.02261749 -0.02355035]
#
# Debug: Returns for VGT, Forecast Period 33w: [-0.02353027 -0.02264668 -0.02358816 -0.0136402  -0.01751649]
#
# Debug: Returns for VGT, Forecast Period 34w: [-0.01237662 -0.01947898 -0.01701241 -0.01659362 -0.00567175]
#
# Debug: Returns for VGT, Forecast Period 35w: [-0.01442489 -0.01065535 -0.01274987 -0.01729156 -0.00554672]
#
# Debug: Returns for VGT, Forecast Period 36w: [-0.01782325 -0.00765784 -0.00851892 -0.01451229]
#
# Debug: Returns for VGT, Forecast Period 37w: [-0.00679628 -0.00896962 -0.0024646  -0.01163648 -0.01300602]
#
# Debug: Returns for VGT, Forecast Period 38w: [-0.02082251 -0.02061998 -0.02367689 -0.01222491 -0.02079435]
#
# Debug: Returns for VGT, Forecast Period 39w: [-0.01656332 -0.01654714 -0.01623473 -0.01350299 -0.0158264 ]
#
# Debug: Returns for VGT, Forecast Period 40w: [-0.01323585 -0.02303687 -0.00740948 -0.0078885  -0.0069731 ]
#
# Debug: Returns for VGT, Forecast Period 41w: [-0.00927621 -0.00589288 -0.00717201 -0.01158828 -0.01257967]
#
# Debug: Returns for VGT, Forecast Period 42w: [-0.01120066 -0.01583741 -0.01197992 -0.0109384  -0.01523327]
#
# Debug: Returns for VGT, Forecast Period 43w: [-0.01390178 -0.01524013 -0.01882939 -0.01661731 -0.017546  ]
#
# Debug: Returns for VGT, Forecast Period 44w: [-0.01755504 -0.01507716 -0.01654376 -0.02151502 -0.01594022]
#
# Debug: Returns for VGT, Forecast Period 45w: [-0.01900793 -0.01473816 -0.01019537 -0.01202745 -0.01666446]
#
# Debug: Returns for VGT, Forecast Period 46w: [-0.01787752 -0.01867869 -0.01760775 -0.01890212 -0.02343733]
#
# Debug: Returns for VGT, Forecast Period 47w: [-0.01959457 -0.0179336  -0.01898684 -0.01521061 -0.01681633]
#
# Debug: Returns for VGT, Forecast Period 48w: [-0.01796073 -0.01812998 -0.02092603 -0.01619617]
#
# Debug: Returns for FTEC, Forecast Period 1w: [0.04891069 0.04717503 0.04653464 0.04495749]
#
# Debug: Returns for FTEC, Forecast Period 2w: [0.05095375 0.04966491 0.04973553 0.04934195 0.04833209]
#
# Debug: Returns for FTEC, Forecast Period 3w: [0.04759163 0.04589528 0.04863186 0.05185726]
#
# Debug: Returns for FTEC, Forecast Period 4w: [0.05173493 0.05431179 0.05316385 0.05314992 0.05079808]
#
# Debug: Returns for FTEC, Forecast Period 5w: [0.05325744 0.05115939 0.04781029 0.05450236 0.05713867]
#
# Debug: Returns for FTEC, Forecast Period 6w: [0.05658839 0.055872   0.0567228  0.05683159 0.05712672]
#
# Debug: Returns for FTEC, Forecast Period 7w: [0.05657745 0.05281884 0.05608286 0.0561962  0.05209038]
#
# Debug: Returns for FTEC, Forecast Period 8w: [0.04612084 0.0413718  0.04960065 0.04489682]
#
# Debug: Returns for FTEC, Forecast Period 9w: [0.04596256 0.04855618 0.04445078 0.04985379 0.0572507 ]
#
# Debug: Returns for FTEC, Forecast Period 10w: [0.05485298 0.04915281 0.0510109  0.05491067 0.04948515]
#
# Debug: Returns for FTEC, Forecast Period 11w: [0.04452741 0.04689521 0.04497108 0.04945447 0.04151507]
#
# Debug: Returns for FTEC, Forecast Period 12w: [0.04301473 0.04871298 0.0530971  0.05539535 0.05041926]
#
# Debug: Returns for FTEC, Forecast Period 13w: [0.0512213  0.04783579 0.0495393  0.0497387 ]
#
# Debug: Returns for FTEC, Forecast Period 14w: [0.04886327 0.03963099 0.03901584 0.04201259 0.04188152]
#
# Debug: Returns for FTEC, Forecast Period 15w: [0.03547451 0.04303055 0.04021611 0.04158216 0.03719864]
#
# Debug: Returns for FTEC, Forecast Period 16w: [ 0.03339054  0.03721887  0.03064362  0.02257187 -0.00692023]
#
# Debug: Returns for FTEC, Forecast Period 17w: [-0.00804392 -0.00294535  0.01400988  0.02214303  0.03002452]
#
# Debug: Returns for FTEC, Forecast Period 18w: [0.03277102 0.02143686 0.01138033 0.01363895 0.04044171]
#
# Debug: Returns for FTEC, Forecast Period 19w: [0.04136562 0.03905887 0.03902971 0.04035577 0.03701629]
#
# Debug: Returns for FTEC, Forecast Period 20w: [0.04283486 0.05221163 0.05641657 0.05672044 0.05743192]
#
# Debug: Returns for FTEC, Forecast Period 21w: [0.05655956 0.0549442  0.05786937 0.0580221  0.05731527]
#
# Debug: Returns for FTEC, Forecast Period 22w: [0.0583389  0.05776384 0.05600097 0.0569256 ]
#
# Debug: Returns for FTEC, Forecast Period 23w: [0.05587094 0.0535217  0.05662191 0.05538628 0.05529756]
#
# Debug: Returns for FTEC, Forecast Period 24w: [0.05629012 0.05782864 0.05728317 0.05790989 0.05809336]
#
# Debug: Returns for FTEC, Forecast Period 25w: [0.05899405 0.05837266 0.05704459 0.05638511]
#
# Debug: Returns for FTEC, Forecast Period 26w: [0.0518247  0.05583852 0.05493477 0.05350694 0.05357011]
#
# Debug: Returns for FTEC, Forecast Period 27w: [0.05771797 0.05770518 0.05722696 0.05681321]
#
# Debug: Returns for FTEC, Forecast Period 28w: [0.0584576  0.05854176 0.0581577  0.05668918 0.05773056]
#
# Debug: Returns for FTEC, Forecast Period 29w: [0.05453443 0.05390612 0.04717402 0.0400681  0.03344356]
#
# Debug: Returns for FTEC, Forecast Period 30w: [0.04429003 0.043654   0.04682687 0.03098447 0.0360027 ]
#
# Debug: Returns for FTEC, Forecast Period 31w: [ 0.03006127  0.01005952  0.03510125 -0.00719679 -0.00763397]
#
# Debug: Returns for FTEC, Forecast Period 32w: [ 0.0027624   0.00564688  0.00745693 -0.00321911 -0.01073022]
#
# Debug: Returns for FTEC, Forecast Period 33w: [-0.01016804 -0.01041182 -0.00914457  0.03578347  0.03590197]
#
# Debug: Returns for FTEC, Forecast Period 34w: [0.04347    0.03874106 0.04099767 0.04388864 0.05243604]
#
# Debug: Returns for FTEC, Forecast Period 35w: [0.04673374 0.04889383 0.04949158 0.03840622 0.05280523]
#
# Debug: Returns for FTEC, Forecast Period 36w: [0.04728981 0.05237301 0.05044209 0.04745766]
#
# Debug: Returns for FTEC, Forecast Period 37w: [0.04443555 0.04515323 0.05105167 0.04543834 0.04546908]
#
# Debug: Returns for FTEC, Forecast Period 38w: [0.03617084 0.03730384 0.03101581 0.04085501 0.03803413]
#
# Debug: Returns for FTEC, Forecast Period 39w: [0.04205329 0.04116049 0.04323082 0.04699798 0.0474356 ]
#
# Debug: Returns for FTEC, Forecast Period 40w: [0.05092369 0.03958572 0.05385062 0.05522668 0.05736269]
#
# Debug: Returns for FTEC, Forecast Period 41w: [0.05799107 0.05832016 0.05875816 0.05672566 0.05615982]
#
# Debug: Returns for FTEC, Forecast Period 42w: [0.05713468 0.05376474 0.05504655 0.05675546 0.05276784]
#
# Debug: Returns for FTEC, Forecast Period 43w: [0.05434644 0.05363934 0.0497609  0.05004064 0.0491168 ]
#
# Debug: Returns for FTEC, Forecast Period 44w: [0.05034131 0.05221791 0.05272366 0.04698476 0.04708447]
#
# Debug: Returns for FTEC, Forecast Period 45w: [0.04237506 0.04912229 0.0521924  0.05394742 0.05276417]
#
# Debug: Returns for FTEC, Forecast Period 46w: [0.05141097 0.04925238 0.05150257 0.05020722 0.04218867]
#
# Debug: Returns for FTEC, Forecast Period 47w: [0.04161653 0.04317322 0.04359458 0.05212583 0.0515573 ]
#
# Debug: Returns for FTEC, Forecast Period 48w: [0.05054552 0.05097064 0.04629593 0.05114231]
#
# Debug: Returns for IGM, Forecast Period 1w: [0.03649708 0.03586805 0.03575871 0.03641132]
#
# Debug: Returns for IGM, Forecast Period 2w: [0.04260304 0.03821285 0.03975449 0.04059319 0.04080815]
#
# Debug: Returns for IGM, Forecast Period 3w: [0.04049914 0.03957479 0.04078994 0.04254966]
#
# Debug: Returns for IGM, Forecast Period 4w: [0.04321576 0.04347112 0.04341774 0.04404851 0.04353504]
#
# Debug: Returns for IGM, Forecast Period 5w: [0.04377903 0.04367416 0.04008273 0.04447942 0.04690561]
#
# Debug: Returns for IGM, Forecast Period 6w: [0.04026417 0.03940704 0.0444891  0.04174684 0.04351214]
#
# Debug: Returns for IGM, Forecast Period 7w: [0.03944394 0.03671903 0.04451311 0.04010154 0.03768148]
#
# Debug: Returns for IGM, Forecast Period 8w: [0.03986958 0.03951427 0.05039497 0.04086599]
#
# Debug: Returns for IGM, Forecast Period 9w: [0.04129913 0.04098525 0.03991107 0.0429705  0.04638539]
#
# Debug: Returns for IGM, Forecast Period 10w: [0.03998629 0.03929888 0.04296185 0.0457741  0.04052456]
#
# Debug: Returns for IGM, Forecast Period 11w: [0.04179437 0.04633595 0.04183526 0.04229808 0.04097379]
#
# Debug: Returns for IGM, Forecast Period 12w: [0.04350379 0.04374515 0.04520869 0.04024467 0.04105083]
#
# Debug: Returns for IGM, Forecast Period 13w: [0.04006615 0.03967609 0.03924418 0.03785562]
#
# Debug: Returns for IGM, Forecast Period 14w: [0.03852705 0.0386736  0.03852896 0.03879318 0.03858946]
#
# Debug: Returns for IGM, Forecast Period 15w: [0.03848636 0.03946967 0.03938763 0.03958286 0.03925817]
#
# Debug: Returns for IGM, Forecast Period 16w: [0.03646957 0.03849278 0.03496411 0.03330383 0.01371758]
#
# Debug: Returns for IGM, Forecast Period 17w: [0.0224448  0.02907551 0.03011571 0.02640254 0.03408118]
#
# Debug: Returns for IGM, Forecast Period 18w: [0.03418394 0.02208957 0.02222937 0.02917349 0.03919635]
#
# Debug: Returns for IGM, Forecast Period 19w: [0.04012509 0.04022334 0.03921524 0.03984589 0.03788867]
#
# Debug: Returns for IGM, Forecast Period 20w: [0.0399189  0.04112659 0.04558216 0.04007196 0.04067018]
#
# Debug: Returns for IGM, Forecast Period 21w: [0.04266611 0.04055847 0.04082987 0.04106255 0.04472117]
#
# Debug: Returns for IGM, Forecast Period 22w: [0.04331195 0.04042238 0.03836161 0.0427026 ]
#
# Debug: Returns for IGM, Forecast Period 23w: [0.0443524  0.04457628 0.04959249 0.04514252 0.04495546]
#
# Debug: Returns for IGM, Forecast Period 24w: [0.04512363 0.04546715 0.04745233 0.04437249 0.04576613]
#
# Debug: Returns for IGM, Forecast Period 25w: [0.04586354 0.04418469 0.04421149 0.04407785]
#
# Debug: Returns for IGM, Forecast Period 26w: [0.04313161 0.04591931 0.04353416 0.04421365 0.04489394]
#
# Debug: Returns for IGM, Forecast Period 27w: [0.04625579 0.04538814 0.04495218 0.04429299]
#
# Debug: Returns for IGM, Forecast Period 28w: [0.04419126 0.04235704 0.04223864 0.03999698 0.04030454]
#
# Debug: Returns for IGM, Forecast Period 29w: [0.04037736 0.03977755 0.041648   0.03982003 0.03776185]
#
# Debug: Returns for IGM, Forecast Period 30w: [0.04028179 0.04094264 0.03542018 0.0301106  0.03394511]
#
# Debug: Returns for IGM, Forecast Period 31w: [0.03109141 0.02351028 0.03223475 0.01942559 0.00668673]
#
# Debug: Returns for IGM, Forecast Period 32w: [-0.00333067  0.00556706  0.00075522  0.01218972  0.01237479]
#
# Debug: Returns for IGM, Forecast Period 33w: [0.0105675  0.01905651 0.01788615 0.04287656 0.04360741]
#
# Debug: Returns for IGM, Forecast Period 34w: [0.04842634 0.04367722 0.04505376 0.04548234 0.04874816]
#
# Debug: Returns for IGM, Forecast Period 35w: [0.04610652 0.04748935 0.04450542 0.04562388 0.04776305]
#
# Debug: Returns for IGM, Forecast Period 36w: [0.03926803 0.04302461 0.04404498 0.03915464]
#
# Debug: Returns for IGM, Forecast Period 37w: [0.04496655 0.04580586 0.05028638 0.04892932 0.04931471]
#
# Debug: Returns for IGM, Forecast Period 38w: [0.04418758 0.04409456 0.03974896 0.04800956 0.04610872]
#
# Debug: Returns for IGM, Forecast Period 39w: [0.0477862  0.04677754 0.04692037 0.04845362 0.04657184]
#
# Debug: Returns for IGM, Forecast Period 40w: [0.04676152 0.0453673  0.04606014 0.04504731 0.04547551]
#
# Debug: Returns for IGM, Forecast Period 41w: [0.0391748  0.04535829 0.04338499 0.04570826 0.04681067]
#
# Debug: Returns for IGM, Forecast Period 42w: [0.04657055 0.04493799 0.04476205 0.04265284 0.04318602]
#
# Debug: Returns for IGM, Forecast Period 43w: [0.04231807 0.04180515 0.04293667 0.04180476 0.0419163 ]
#
# Debug: Returns for IGM, Forecast Period 44w: [0.04151218 0.04148215 0.04040129 0.04277846 0.04082643]
#
# Debug: Returns for IGM, Forecast Period 45w: [0.04091778 0.04017603 0.04297727 0.04345636 0.04161283]
#
# Debug: Returns for IGM, Forecast Period 46w: [0.04144758 0.04158207 0.04067803 0.04072973 0.04252743]
#
# Debug: Returns for IGM, Forecast Period 47w: [0.04156916 0.04165846 0.04167812 0.04146143 0.04067676]
#
# Debug: Returns for IGM, Forecast Period 48w: [0.04069608 0.04004424 0.04156635 0.03979038]
#
# Debug: Returns for IXN, Forecast Period 1w: [-0.0571769  -0.05522096 -0.05324523 -0.05243321]
#
# Debug: Returns for IXN, Forecast Period 2w: [-0.04441661 -0.04934105 -0.04903488 -0.05060289 -0.04980699]
#
# Debug: Returns for IXN, Forecast Period 3w: [-0.04656878 -0.05400863 -0.04316359 -0.0404882 ]
#
# Debug: Returns for IXN, Forecast Period 4w: [-0.043934   -0.0403836  -0.04030479 -0.03181229 -0.04970245]
#
# Debug: Returns for IXN, Forecast Period 5w: [-0.0419704  -0.04796249 -0.06084291 -0.03562437 -0.02933335]
#
# Debug: Returns for IXN, Forecast Period 6w: [-0.02715747 -0.03088839 -0.03075881 -0.02894015 -0.02788189]
#
# Debug: Returns for IXN, Forecast Period 7w: [-0.0209302  -0.04697135 -0.0354461  -0.03239078 -0.04240867]
#
# Debug: Returns for IXN, Forecast Period 8w: [-0.05586079 -0.05814736 -0.04814504 -0.05379028]
#
# Debug: Returns for IXN, Forecast Period 9w: [-0.05469315 -0.05155015 -0.05422369 -0.04954133 -0.03496485]
#
# Debug: Returns for IXN, Forecast Period 10w: [-0.03864306 -0.05730399 -0.04976888 -0.04263445 -0.05915916]
#
# Debug: Returns for IXN, Forecast Period 11w: [-0.06006164 -0.05026062 -0.05939582 -0.04935627 -0.06480473]
#
# Debug: Returns for IXN, Forecast Period 12w: [-0.05463593 -0.05044743 -0.04050388 -0.03984611 -0.05074507]
#
# Debug: Returns for IXN, Forecast Period 13w: [-0.0527179  -0.054759   -0.05311019 -0.05205771]
#
# Debug: Returns for IXN, Forecast Period 14w: [-0.05527719 -0.06144503 -0.05887331 -0.06642026 -0.05573295]
#
# Debug: Returns for IXN, Forecast Period 15w: [-0.06350233 -0.0567043  -0.06513734 -0.05207765 -0.07053428]
#
# Debug: Returns for IXN, Forecast Period 16w: [-0.06989534 -0.06184149 -0.0664851  -0.05882177 -0.04357248]
#
# Debug: Returns for IXN, Forecast Period 17w: [-0.04204152 -0.04326048 -0.04742345 -0.04972304 -0.04954771]
#
# Debug: Returns for IXN, Forecast Period 18w: [-0.0562133  -0.04927372 -0.04679301 -0.04430459 -0.04138407]
#
# Debug: Returns for IXN, Forecast Period 19w: [-0.05198865 -0.06362574 -0.06116737 -0.06317032 -0.06323855]
#
# Debug: Returns for IXN, Forecast Period 20w: [-0.05856744 -0.04952948 -0.04185473 -0.04237666 -0.0413594 ]
#
# Debug: Returns for IXN, Forecast Period 21w: [-0.02276437 -0.02853077 -0.03162027 -0.03230397 -0.02841464]
#
# Debug: Returns for IXN, Forecast Period 22w: [-0.03037934 -0.03677672 -0.0437017  -0.03410849]
#
# Debug: Returns for IXN, Forecast Period 23w: [-0.03128649 -0.04042338 -0.03460308 -0.03788589 -0.03701941]
#
# Debug: Returns for IXN, Forecast Period 24w: [-0.03575293 -0.03190977 -0.01909709 -0.02349275 -0.03268825]
#
# Debug: Returns for IXN, Forecast Period 25w: [-0.02543786 -0.02087873 -0.03412836 -0.03577517]
#
# Debug: Returns for IXN, Forecast Period 26w: [-0.0486072  -0.03503976 -0.03873093 -0.041561   -0.03954985]
#
# Debug: Returns for IXN, Forecast Period 27w: [-0.02821653 -0.02463416 -0.02283039 -0.02146573]
#
# ...
# Normalized Values -> Forecasted Mean: -0.465120656127889, Rachev: -0.010801698198883249
# Sharpe: -0.4389407003010027, Sortino: -0.6402385095601831, Volatility Clustering: 0.450925498686293
# Final Composite Score: -1.9941451948554794
# Calculated Score for IYW (47w): -1.9941451948554794
#
# Debug: ETF = XLK, Forecast Period = 47w
# Forecasted Values Mean: -0.0016410344978794456
# Rachev Ratio: 0.20477677881717682, Sharpe Ratio: -24.453212990995507
# Sortino Ratio: -0.7888634392671694, Volatility Clustering: -0.7636175155639648
# Means and Stds: Mean Forecast = -0.0005008578300476074, Std Forecast = 0.030794033780694008
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.0016410344978794456, Risk Percentage: 0.1
# Rachev Ratio: 0.20477677881717682, Sharpe Ratio: -24.453212990995507
# Sortino Ratio: -0.7888634392671694, Volatility Clustering: -0.7636175155639648
# Normalized Values -> Forecasted Mean: -0.03702588318545742, Rachev: 1.9042666729228
# Sharpe: -0.2699357173323164, Sortino: -0.640238399559661, Volatility Clustering: -2.3064323230233206
# Final Composite Score: 1.1688056556536057
# Calculated Score for XLK (47w): 1.1688056556536057
#
# Debug: ETF = VGT, Forecast Period = 47w
# Forecasted Values Mean: -0.017708387225866318
# Rachev Ratio: -0.7762669920921326, Sharpe Ratio: -183.22705785541282
# Sortino Ratio: -0.9961070510793483, Volatility Clustering: -0.021666644141077995
# Means and Stds: Mean Forecast = -0.0005008578300476074, Std Forecast = 0.030794033780694008
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.017708387225866318, Risk Percentage: 0.1
# Rachev Ratio: -0.7762669920921326, Sharpe Ratio: -183.22705785541282
# Sortino Ratio: -0.9961070510793483, Volatility Clustering: -0.021666644141077995
# Normalized Values -> Forecasted Mean: -0.5587940810361121, Rachev: -0.2597257728358059
# Sharpe: -0.5529186045213972, Sortino: -0.6402385124436424, Volatility Clustering: 0.04878538384891233
# Final Composite Score: -1.7747640045664834
# Calculated Score for VGT (47w): -1.7747640045664834
#
# Debug: ETF = FTEC, Forecast Period = 47w
# Forecasted Values Mean: 0.04641348868608475
# Rachev Ratio: -1.2525269985198975, Sharpe Ratio: 162.96451429782746
# Sortino Ratio: 4641348.868608475, Volatility Clustering: 0.3754369020462036
# Means and Stds: Mean Forecast = -0.0005008578300476074, Std Forecast = 0.030794033780694008
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.04641348868608475, Risk Percentage: 0.1
# Rachev Ratio: -1.2525269985198975, Sharpe Ratio: 162.96451429782746
# Sortino Ratio: 4641348.868608475, Volatility Clustering: 0.3754369020462036
# Normalized Values -> Forecasted Mean: 1.5234876864578855, Rachev: -1.310263070295623
# Sharpe: 0.06409920903667236, Sortino: 1.887868614474657, Volatility Clustering: 1.309334214593491
# Final Composite Score: 2.2971476024052864
# Calculated Score for FTEC (47w): 2.2971476024052864
#
# Debug: ETF = IGM, Forecast Period = 47w
# Forecasted Values Mean: 0.041408784687519073
# Rachev Ratio: -1.0246174335479736, Sharpe Ratio: 1741.7352348277902
# Sortino Ratio: 4140878.4687519073, Volatility Clustering: 0.1200919896364212
# Means and Stds: Mean Forecast = -0.0005008578300476074, Std Forecast = 0.030794033780694008
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.041408784687519073, Risk Percentage: 0.1
# Rachev Ratio: -1.0246174335479736, Sharpe Ratio: 1741.7352348277902
# Sortino Ratio: 4140878.4687519073, Volatility Clustering: 0.1200919896364212
# Normalized Values -> Forecasted Mean: 1.360965867816343, Rachev: -0.8075387280887327
# Sharpe: 2.877944884227463, Sortino: 1.6152662850731032, Volatility Clustering: 0.4987780413607145
# Final Composite Score: 5.436152868565068
# Calculated Score for IGM (47w): 5.436152868565068
#
# Debug: ETF = IXN, Forecast Period = 47w
# Forecasted Values Mean: -0.06299253553152084
# Rachev Ratio: -0.8863287568092346, Sharpe Ratio: -384.97404889738584
# Sortino Ratio: -0.9991404688965326, Volatility Clustering: -0.1658150851726532
# Means and Stds: Mean Forecast = -0.0005008578300476074, Std Forecast = 0.030794033780694008
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.06299253553152084, Risk Percentage: 0.1
# Rachev Ratio: -0.8863287568092346, Sharpe Ratio: -384.97404889738584
# Sortino Ratio: -0.9991404688965326, Volatility Clustering: -0.1658150851726532
# Normalized Values -> Forecasted Mean: -2.029343016672975, Rachev: -0.5025007010243216
# Sharpe: -0.9124926014572222, Sortino: -0.6402385140959215, Volatility Clustering: -0.40879337751100225
# Final Composite Score: -3.1230306846126843
# Calculated Score for IXN (47w): -3.1230306846126843
# Scores calculated for 47w:
# {'ETF': 'SMH', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -2.0468777921103345}
# {'ETF': 'SOXX', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 2.7944343946150134}
# {'ETF': 'PSI', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -0.6498035968384819}
# {'ETF': 'XSD', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -2.1079191728248388}
# {'ETF': 'IYW', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -1.9941451948554794}
# {'ETF': 'XLK', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 1.1688056556536057}
# {'ETF': 'VGT', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -1.7747640045664834}
# {'ETF': 'FTEC', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 2.2971476024052864}
# {'ETF': 'IGM', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 5.436152868565068}
# {'ETF': 'IXN', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -3.1230306846126843}
#
# Debug: Forecast Period = 48w
# All Returns Means: [-0.0054806764, 0.02876886, -0.011554184, -0.0072845127, -0.01598146, -0.0024831854, -0.018303229, 0.0497386, 0.040524263, -0.06339827]
# Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
# All Rachev Ratios: [-0.32495746 -1.450276   -0.29991472 -0.16951889 -0.7567263   0.03732819
#  -0.77397275 -1.1046827  -1.0446333  -0.8951908 ]
# All Sharpe Ratios: [ -44.05274389  107.74811546  -32.79029597  -32.25114913 -152.30038352
#   -17.56748005 -175.16009337  391.89016976  928.48879331 -371.33124782]
# All Sortino Ratios: [-9.33153423e-01  2.87688598e+06 -8.94436337e-01 -8.88022706e-01
#  -9.94355183e-01 -6.93058320e-01 -9.95748424e-01  4.97386009e+06
#   4.05242629e+06 -9.99076399e-01]
# All Volatility Clustering: [ 0.26532465 -0.2926123  -0.2788337  -0.20685378 -0.69117355 -0.56945366
#  -0.5199304  -0.50905716 -0.71405303 -0.47408423]
# Mean Rachev = -0.6782544851303101, Std Rachev = 0.4486984610557556
# Mean Sharpe = 60.267368478825645, Std Sharpe = 344.5410578237322
# Mean Sortino = 1190316.5961019713, Std Sortino = 1878014.3759815285
# Mean Volatility Clustering = -0.39907270669937134, Std Volatility Clustering = 0.27387192845344543
#
# Debug: ETF = SMH, Forecast Period = 48w
# Forecasted Values Mean: -0.005480676423758268
# Rachev Ratio: -0.3249574601650238, Sharpe Ratio: -44.05274389027164
# Sortino Ratio: -0.9331534225040811, Volatility Clustering: 0.2653246521949768
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.005480676423758268, Risk Percentage: 0.1
# Rachev Ratio: -0.3249574601650238, Sharpe Ratio: -44.05274389027164
# Sortino Ratio: -0.9331534225040811, Volatility Clustering: 0.2653246521949768
# Normalized Values -> Forecasted Mean: -0.15786709636908403, Rachev: 0.7873818338047898
# Sharpe: -0.30277991547654626, Sortino: -0.6338170487290749, Volatility Clustering: 2.4259417107360446
# Final Composite Score: -3.599143954691229
# Calculated Score for SMH (48w): -3.599143954691229
#
# Debug: ETF = SOXX, Forecast Period = 48w
# Forecasted Values Mean: 0.028768859803676605
# Rachev Ratio: -1.4502760171890259, Sharpe Ratio: 107.74811545988894
# Sortino Ratio: 2876885.9803676605, Volatility Clustering: -0.29261231422424316
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.028768859803676605, Risk Percentage: 0.1
# Rachev Ratio: -1.4502760171890259, Sharpe Ratio: 107.74811545988894
# Sortino Ratio: 2876885.9803676605, Volatility Clustering: -0.29261231422424316
# Normalized Values -> Forecasted Mean: 0.9376850047707767, Rachev: -1.7205798144179185
# Sharpe: 0.1378086759226717, Sortino: 0.8980598901881189, Volatility Clustering: 0.3887232590396442
# Final Composite Score: 1.756888293283715
# Calculated Score for SOXX (48w): 1.756888293283715
#
# Debug: ETF = PSI, Forecast Period = 48w
# Forecasted Values Mean: -0.01155418436974287
# Rachev Ratio: -0.29991471767425537, Sharpe Ratio: -32.790295966933826
# Sortino Ratio: -0.8944363369759041, Volatility Clustering: -0.27883368730545044
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.01155418436974287, Risk Percentage: 0.1
# Rachev Ratio: -0.29991471767425537, Sharpe Ratio: -32.790295966933826
# Sortino Ratio: -0.8944363369759041, Volatility Clustering: -0.27883368730545044
# Normalized Values -> Forecasted Mean: -0.3521425612472412, Rachev: 0.8431937968628422
# Sharpe: -0.2700916547677955, Sortino: -0.6338170281131061, Volatility Clustering: 0.439033732601122
# Final Composite Score: -1.779404356415549
# Calculated Score for PSI (48w): -1.779404356415549
#
# Debug: ETF = XSD, Forecast Period = 48w
# Forecasted Values Mean: -0.007284512743353844
# Rachev Ratio: -0.16951888799667358, Sharpe Ratio: -32.25114913071756
# Sortino Ratio: -0.8880227059074345, Volatility Clustering: -0.20685377717018127
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.007284512743353844, Risk Percentage: 0.1
# Rachev Ratio: -0.16951888799667358, Sharpe Ratio: -32.25114913071756
# Sortino Ratio: -0.8880227059074345, Volatility Clustering: -0.20685377717018127
# Normalized Values -> Forecasted Mean: -0.21556705208993276, Rachev: 1.1338028318585927
# Sharpe: -0.26852682867825456, Sortino: -0.6338170246979933, Volatility Clustering: 0.7018569723303898
# Final Composite Score: -1.9331481609824297
# Calculated Score for XSD (48w): -1.9331481609824297
#
# Debug: ETF = IYW, Forecast Period = 48w
# Forecasted Values Mean: -0.015981459990143776
# Rachev Ratio: -0.7567263245582581, Sharpe Ratio: -152.30038351857803
# Sortino Ratio: -0.9943551827777496, Volatility Clustering: -0.6911735534667969
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.015981459990143776, Risk Percentage: 0.1
# Rachev Ratio: -0.7567263245582581, Sharpe Ratio: -152.30038351857803
# Sortino Ratio: -0.9943551827777496, Volatility Clustering: -0.6911735534667969
# Normalized Values -> Forecasted Mean: -0.4937594055728942, Rachev: -0.17488769070977517
# Sharpe: -0.6169591320520763, Sortino: -0.6338170813176222, Volatility Clustering: -1.0665599711197822
# Final Composite Score: -0.6604868787518328
# Calculated Score for IYW (48w): -0.6604868787518328
#
# Debug: ETF = XLK, Forecast Period = 48w
# Forecasted Values Mean: -0.0024831853806972504
# Rachev Ratio: 0.037328194826841354, Sharpe Ratio: -17.567480047937018
# Sortino Ratio: -0.6930583199671376, Volatility Clustering: -0.5694536566734314
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.0024831853806972504, Risk Percentage: 0.1
# Rachev Ratio: 0.037328194826841354, Sharpe Ratio: -17.567480047937018
# Sortino Ratio: -0.6930583199671376, Volatility Clustering: -0.5694536566734314
# Normalized Values -> Forecasted Mean: -0.06198528872108157, Rachev: 1.5947963163270098
# Sharpe: -0.22590877562210313, Sortino: -0.6338169208838859, Volatility Clustering: -0.6221190492761001
# Final Composite Score: -0.4590715675836715
# Calculated Score for XLK (48w): -0.4590715675836715
#
# Debug: ETF = VGT, Forecast Period = 48w
# Forecasted Values Mean: -0.01830322854220867
# Rachev Ratio: -0.773972749710083, Sharpe Ratio: -175.1600933660129
# Sortino Ratio: -0.9957484240252752, Volatility Clustering: -0.5199304223060608
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.01830322854220867, Risk Percentage: 0.1
# Rachev Ratio: -0.773972749710083, Sharpe Ratio: -175.1600933660129
# Sortino Ratio: -0.9957484240252752, Volatility Clustering: -0.5199304223060608
# Normalized Values -> Forecasted Mean: -0.5680266741327769, Rachev: -0.2133242494777276
# Sharpe: -0.6833074215452446, Sortino: -0.6338170820594914, Volatility Clustering: -0.44129280381616626
# Final Composite Score: -1.4225259489735738
# Calculated Score for VGT (48w): -1.4225259489735738
#
# Debug: ETF = FTEC, Forecast Period = 48w
# Forecasted Values Mean: 0.049738600850105286
# Rachev Ratio: -1.1046826839447021, Sharpe Ratio: 391.8901697574702
# Sortino Ratio: 4973860.085010529, Volatility Clustering: -0.5090571641921997
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.049738600850105286, Risk Percentage: 0.1
# Rachev Ratio: -1.1046826839447021, Sharpe Ratio: 391.8901697574702
# Sortino Ratio: 4973860.085010529, Volatility Clustering: -0.5090571641921997
# Normalized Values -> Forecasted Mean: 1.608451590803302, Rachev: -0.9503669531367843
# Sharpe: 0.9625059009329398, Sortino: 2.0146509724831576, Volatility Clustering: -0.4015908242148155
# Final Composite Score: 5.082235983747893
# Calculated Score for FTEC (48w): 5.082235983747893
#
# Debug: ETF = IGM, Forecast Period = 48w
# Forecasted Values Mean: 0.04052426293492317
# Rachev Ratio: -1.0446332693099976, Sharpe Ratio: 928.4887933072429
# Sortino Ratio: 4052426.293492317, Volatility Clustering: -0.7140530347824097
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.04052426293492317, Risk Percentage: 0.1
# Rachev Ratio: -1.0446332693099976, Sharpe Ratio: 928.4887933072429
# Sortino Ratio: 4052426.293492317, Volatility Clustering: -0.7140530347824097
# Normalized Values -> Forecasted Mean: 1.3137092774751467, Rachev: -0.8165367341627536
# Sharpe: 2.5199360281972587, Sortino: 1.5240084069614606, Volatility Clustering: -1.1501007728711892
# Final Composite Score: 6.589408158921331
# Calculated Score for IGM (48w): 6.589408158921331
#
# Debug: ETF = IXN, Forecast Period = 48w
# Forecasted Values Mean: -0.06339827179908752
# Rachev Ratio: -0.8951907753944397, Sharpe Ratio: -371.3312478158945
# Sortino Ratio: -0.9990763993466691, Volatility Clustering: -0.4740842282772064
# Means and Stds: Mean Forecast = -0.0005453795311041176, Std Forecast = 0.031262341886758804
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.06339827179908752, Risk Percentage: 0.1
# Rachev Ratio: -0.8951907753944397, Sharpe Ratio: -371.3312478158945
# Sortino Ratio: -0.9990763993466691, Volatility Clustering: -0.4740842282772064
# Normalized Values -> Forecasted Mean: -2.010497787468578, Rachev: -0.48347900485083883
# Sharpe: -1.2526768769108498, Sortino: -0.6338170838315627, Volatility Clustering: -0.2738926886829847
# Final Composite Score: -3.5747511590429215
# Calculated Score for IXN (48w): -3.5747511590429215
# Scores calculated for 48w:
# {'ETF': 'SMH', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -3.599143954691229}
# {'ETF': 'SOXX', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 1.756888293283715}
# {'ETF': 'PSI', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -1.779404356415549}
# {'ETF': 'XSD', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -1.9331481609824297}
# {'ETF': 'IYW', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.6604868787518328}
# {'ETF': 'XLK', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.4590715675836715}
# {'ETF': 'VGT', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -1.4225259489735738}
# {'ETF': 'FTEC', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 5.082235983747893}
# {'ETF': 'IGM', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 6.589408158921331}
# {'ETF': 'IXN', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -3.5747511590429215}

# %%
# Initialize an empty dictionary to hold DataFrames for each week
weekly_scores_dfs = {}

# Assuming weekly_scores is a dictionary with keys as week identifiers ('1w', '2w', ..., '48w') 
# and values as the respective scores
for week_key, scores in weekly_scores.items():
    # Convert scores for the current week into a DataFrame
    weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    
# Create DataFrame variables dynamically for 48 weeks
for week in range(1, 49):
    week_key = f'{week}w'
    globals()[f'df_scores_{week_key}'] = weekly_scores_dfs.get(week_key, pd.DataFrame())

# %%
# Initialize a dictionary to hold the top 2 ETFs for each week
top_etfs_weekly = {}

# Loop through the weekly DataFrames and select the top 2 ETFs for each week
for week_key, df_scores in weekly_scores_dfs.items():
    # Select the top 2 ETFs based on the 'Score' column
    top_etfs_weekly[week_key] = df_scores.nlargest(2, 'Score')
    
    # Print the results for the current week
    print(f"\nTop 2 ETFs for {week_key} forecast:")
    print(top_etfs_weekly[week_key])
# Out:
# Top 2 ETFs for 1w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM   1w             0.1  7.991462
# 7  FTEC   1w             0.1  4.181336
#
# Top 2 ETFs for 2w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM   2w             0.1  5.403989
# 7  FTEC   2w             0.1  4.648313
#
# Top 2 ETFs for 3w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM   3w             0.1  4.739230
# 7  FTEC   3w             0.1  4.048963
#
# Top 2 ETFs for 4w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM   4w             0.1  5.752882
# 7  FTEC   4w             0.1  4.712484
#
# Top 2 ETFs for 5w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM   5w             0.1  4.634972
# 7  FTEC   5w             0.1  4.255123
#
# Top 2 ETFs for 6w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   6w             0.1  5.852318
# 8   IGM   6w             0.1  3.260157
#
# Top 2 ETFs for 7w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   7w             0.1  6.467252
# 1  SOXX   7w             0.1  5.228136
#
# Top 2 ETFs for 8w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   8w             0.1  7.324194
# 8   IGM   8w             0.1  4.778419
#
# Top 2 ETFs for 9w forecast:
#     ETF Week  RiskPercentage     Score
# 1  SOXX   9w             0.1  5.768083
# 7  FTEC   9w             0.1  3.935213
#
# Top 2 ETFs for 10w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  10w             0.1  6.142237
# 1  SOXX  10w             0.1  3.805603
#
# Top 2 ETFs for 11w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  11w             0.1  5.210902
# 1  SOXX  11w             0.1  4.484769
#
# Top 2 ETFs for 12w forecast:
#     ETF Week  RiskPercentage     Score
# 1  SOXX  12w             0.1  6.660799
# 8   IGM  12w             0.1  4.349683
#
# Top 2 ETFs for 13w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  13w             0.1  5.333277
# 1  SOXX  13w             0.1  5.058929
#
# Top 2 ETFs for 14w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  14w             0.1  6.346663
# 1  SOXX  14w             0.1  1.335314
#
# Top 2 ETFs for 15w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  15w             0.1  3.640377
# 1  SOXX  15w             0.1  3.561834
#
# Top 2 ETFs for 16w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  16w             0.1  4.887972
# 1  SOXX  16w             0.1  3.883153
#
# Top 2 ETFs for 17w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  17w             0.1  6.236670
# 1  SOXX  17w             0.1  3.339304
#
# Top 2 ETFs for 18w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  18w             0.1  5.056241
# 8   IGM  18w             0.1  5.050912
#
# Top 2 ETFs for 19w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  19w             0.1  4.772886
# 8   IGM  19w             0.1  4.373103
#
# Top 2 ETFs for 20w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  20w             0.1  6.600452
# 7  FTEC  20w             0.1  3.867599
#
# Top 2 ETFs for 21w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  21w             0.1  6.274315
# 8   IGM  21w             0.1  4.151958
#
# Top 2 ETFs for 22w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  22w             0.1  5.235840
# 8   IGM  22w             0.1  3.435724
#
# Top 2 ETFs for 23w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  23w             0.1  7.489546
# 8   IGM  23w             0.1  2.916804
#
# Top 2 ETFs for 24w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  24w             0.1  6.140842
# 8   IGM  24w             0.1  5.712112
#
# Top 2 ETFs for 25w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  25w             0.1  4.989730
# 7  FTEC  25w             0.1  4.204489
#
# Top 2 ETFs for 26w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  26w             0.1  6.563224
# 7  FTEC  26w             0.1  4.362985
#
# Top 2 ETFs for 27w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  27w             0.1  5.486073
# 8   IGM  27w             0.1  3.021358
#
# Top 2 ETFs for 28w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  28w             0.1  5.385580
# 1  SOXX  28w             0.1  2.216844
#
# Top 2 ETFs for 29w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  29w             0.1  5.976173
# 7  FTEC  29w             0.1  2.195476
#
# Top 2 ETFs for 30w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  30w             0.1  5.351715
# 8   IGM  30w             0.1  3.393360
#
# Top 2 ETFs for 31w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  31w             0.1  5.327746
# 1  SOXX  31w             0.1  4.154548
#
# Top 2 ETFs for 32w forecast:
#     ETF Week  RiskPercentage     Score
# 4   IYW  32w             0.1  7.418100
# 1  SOXX  32w             0.1  2.338775
#
# Top 2 ETFs for 33w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  33w             0.1  4.357749
# 1  SOXX  33w             0.1  3.270791
#
# Top 2 ETFs for 34w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  34w             0.1  5.973798
# 7  FTEC  34w             0.1  2.845664
#
# Top 2 ETFs for 35w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  35w             0.1  5.862059
# 8   IGM  35w             0.1  5.531497
#
# Top 2 ETFs for 36w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  36w             0.1  7.460212
# 8   IGM  36w             0.1  5.797093
#
# Top 2 ETFs for 37w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  37w             0.1  5.212374
# 8   IGM  37w             0.1  4.309531
#
# Top 2 ETFs for 38w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  38w             0.1  5.318994
# 7  FTEC  38w             0.1  4.996900
#
# Top 2 ETFs for 39w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  39w             0.1  7.343838
# 7  FTEC  39w             0.1  2.097305
#
# Top 2 ETFs for 40w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  40w             0.1  7.070314
# 7  FTEC  40w             0.1  2.821297
#
# Top 2 ETFs for 41w forecast:
#     ETF Week  RiskPercentage     Score
# 1  SOXX  41w             0.1  4.967837
# 7  FTEC  41w             0.1  4.410019
#
# Top 2 ETFs for 42w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  42w             0.1  6.404977
# 1  SOXX  42w             0.1  2.502073
#
# Top 2 ETFs for 43w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  43w             0.1  7.571526
# 1  SOXX  43w             0.1  3.703252
#
# Top 2 ETFs for 44w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  44w             0.1  7.753423
# 7  FTEC  44w             0.1  3.032632
#
# Top 2 ETFs for 45w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  45w             0.1  4.817903
# 7  FTEC  45w             0.1  3.131488
#
# Top 2 ETFs for 46w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  46w             0.1  5.475384
# 7  FTEC  46w             0.1  3.463934
#
# Top 2 ETFs for 47w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  47w             0.1  5.436153
# 1  SOXX  47w             0.1  2.794434
#
# Top 2 ETFs for 48w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  48w             0.1  6.589408
# 7  FTEC  48w             0.1  5.082236

# %%
def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()

# %%
# Function to generate week ranges
def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []
    
    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)
    
    return week_ranges

# Function to gather ETF data for weeks
def gather_etf_data_for_weeks(tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date)
            if etf_data.empty:
                print(f"No data found for {ticker} in {week}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[week][ticker] = etf_data
            #print(f"Data for {ticker} in {week} gathered.")
    return etf_histories

# Function to initialize shares for the first week
def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]
    
    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)
        
        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]
            
            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st week: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares

# Function to manage ETF portfolio weekly
def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

# %%
# Generate Week Ranges
week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')
#print("Generated Week Ranges:", week_ranges)

# Assuming `tickers` is a list of ETF tickers
tickers = tickers

# Gather ETF Data
etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)
#print(f"ETF Histories Collected for {len(etf_histories)} weeks")

# Create a mapping between week numbers and date ranges
week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

# Debug: Print the week key mapping
print("Week Key Mapping:", week_key_mapping)

# Align `top_etfs_weekly` Keys with `etf_histories`
aligned_top_etfs_weekly = {}

for week_key, df_scores in weekly_scores_dfs.items():
    # Call the `select_top_etfs_weekly` function here
    forecast_period = week_key_mapping.get(week_key, None)
    if forecast_period:
        aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

# Portfolio initialization and management
ticker_shares = {}
ticker_shares_per_week = {}

for i, week_range in enumerate(etf_histories.keys()):
    current_week_key = week_range
    if i == 0:
        # First week initialization
        ticker_shares = initialize_shares_for_first_week(
            aligned_top_etfs_weekly[current_week_key],
            etf_histories,
            current_week_key
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()
    else:
        # Subsequent weeks' portfolio management
        prev_week_key = list(etf_histories.keys())[i - 1]
        ticker_shares = manage_etf_portfolio_weekly(
            aligned_top_etfs_weekly[prev_week_key],
            aligned_top_etfs_weekly[current_week_key],
            prev_week_key,
            current_week_key,
            ticker_shares,
            etf_histories
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()

print("\nFinal Ticker Shares per Week:")
for week, shares in ticker_shares_per_week.items():
    print(f"Week {week}: {shares}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Week Key Mapping: {'1w': '2024-01-01 to 2024-01-07', '2w': '2024-01-08 to 2024-01-14', '3w': '2024-01-15 to 2024-01-21', '4w': '2024-01-22 to 2024-01-28', '5w': '2024-01-29 to 2024-02-04', '6w': '2024-02-05 to 2024-02-11', '7w': '2024-02-12 to 2024-02-18', '8w': '2024-02-19 to 2024-02-25', '9w': '2024-02-26 to 2024-03-03', '10w': '2024-03-04 to 2024-03-10', '11w': '2024-03-11 to 2024-03-17', '12w': '2024-03-18 to 2024-03-24', '13w': '2024-03-25 to 2024-03-31', '14w': '2024-04-01 to 2024-04-07', '15w': '2024-04-08 to 2024-04-14', '16w': '2024-04-15 to 2024-04-21', '17w': '2024-04-22 to 2024-04-28', '18w': '2024-04-29 to 2024-05-05', '19w': '2024-05-06 to 2024-05-12', '20w': '2024-05-13 to 2024-05-19', '21w': '2024-05-20 to 2024-05-26', '22w': '2024-05-27 to 2024-06-02', '23w': '2024-06-03 to 2024-06-09', '24w': '2024-06-10 to 2024-06-16', '25w': '2024-06-17 to 2024-06-23', '26w': '2024-06-24 to 2024-06-30', '27w': '2024-07-01 to 2024-07-07', '28w': '2024-07-08 to 2024-07-14', '29w': '2024-07-15 to 2024-07-21', '30w': '2024-07-22 to 2024-07-28', '31w': '2024-07-29 to 2024-08-04', '32w': '2024-08-05 to 2024-08-11', '33w': '2024-08-12 to 2024-08-18', '34w': '2024-08-19 to 2024-08-25', '35w': '2024-08-26 to 2024-09-01', '36w': '2024-09-02 to 2024-09-08', '37w': '2024-09-09 to 2024-09-15', '38w': '2024-09-16 to 2024-09-22', '39w': '2024-09-23 to 2024-09-29', '40w': '2024-09-30 to 2024-10-06', '41w': '2024-10-07 to 2024-10-13', '42w': '2024-10-14 to 2024-10-20', '43w': '2024-10-21 to 2024-10-27', '44w': '2024-10-28 to 2024-11-03', '45w': '2024-11-04 to 2024-11-10', '46w': '2024-11-11 to 2024-11-17', '47w': '2024-11-18 to 2024-11-24', '48w': '2024-11-25 to 2024-12-01'}
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1 -2.109149
# 1  SOXX   1w             0.1  1.704718
# 2   PSI   1w             0.1 -1.123788
# 3   XSD   1w             0.1 -1.401441
# 4   IYW   1w             0.1 -0.999981
# Top ETFs for 2024-01-01 to 2024-01-07: ['IGM', 'FTEC']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1 -2.036403
# 1  SOXX   2w             0.1  2.363758
# 2   PSI   2w             0.1  0.322615
# 3   XSD   2w             0.1 -2.538544
# 4   IYW   2w             0.1 -0.473315
# Top ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'FTEC']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1 -0.560980
# 1  SOXX   3w             0.1  3.798710
# 2   PSI   3w             0.1 -2.283046
# 3   XSD   3w             0.1 -0.015556
# 4   IYW   3w             0.1 -2.356149
# Top ETFs for 2024-01-15 to 2024-01-21: ['IGM', 'FTEC']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1 -2.812406
# 1  SOXX   4w             0.1  3.054029
# 2   PSI   4w             0.1 -0.902461
# 3   XSD   4w             0.1 -3.054091
# 4   IYW   4w             0.1 -2.113030
# Top ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'FTEC']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1 -2.956058
# 1  SOXX   5w             0.1  2.898543
# 2   PSI   5w             0.1 -0.158927
# 3   XSD   5w             0.1 -2.037347
# 4   IYW   5w             0.1 -1.890303
# Top ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'FTEC']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1 -0.394829
# 1  SOXX   6w             0.1  2.385910
# 2   PSI   6w             0.1 -2.771887
# 3   XSD   6w             0.1 -2.611025
# 4   IYW   6w             0.1 -1.738591
# Top ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IGM']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1 -0.920951
# 1  SOXX   7w             0.1  5.228136
# 2   PSI   7w             0.1 -2.487258
# 3   XSD   7w             0.1 -0.594075
# 4   IYW   7w             0.1 -3.152985
# Top ETFs for 2024-02-12 to 2024-02-18: ['FTEC', 'SOXX']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1 -2.657613
# 1  SOXX   8w             0.1  3.231074
# 2   PSI   8w             0.1 -2.777750
# 3   XSD   8w             0.1 -0.625613
# 4   IYW   8w             0.1 -1.298138
# Top ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IGM']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1 -2.224887
# 1  SOXX   9w             0.1  5.768083
# 2   PSI   9w             0.1 -0.495857
# 3   XSD   9w             0.1 -1.821454
# 4   IYW   9w             0.1 -2.857553
# Top ETFs for 2024-02-26 to 2024-03-03: ['SOXX', 'FTEC']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1 -1.627472
# 1  SOXX  10w             0.1  3.805603
# 2   PSI  10w             0.1 -3.421947
# 3   XSD  10w             0.1 -1.330543
# 4   IYW  10w             0.1 -2.559416
# Top ETFs for 2024-03-04 to 2024-03-10: ['FTEC', 'SOXX']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1 -1.963119
# 1  SOXX  11w             0.1  4.484769
# 2   PSI  11w             0.1 -0.883929
# 3   XSD  11w             0.1 -4.341415
# 4   IYW  11w             0.1 -1.476111
# Top ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'SOXX']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1 -2.227843
# 1  SOXX  12w             0.1  6.660799
# 2   PSI  12w             0.1 -0.499732
# 3   XSD  12w             0.1 -2.645050
# 4   IYW  12w             0.1 -0.735412
# Top ETFs for 2024-03-18 to 2024-03-24: ['SOXX', 'IGM']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1 -1.210157
# 1  SOXX  13w             0.1  5.058929
# 2   PSI  13w             0.1 -0.048022
# 3   XSD  13w             0.1 -2.344817
# 4   IYW  13w             0.1 -2.548129
# Top ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'SOXX']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1 -0.848969
# 1  SOXX  14w             0.1  1.335314
# 2   PSI  14w             0.1 -0.487218
# 3   XSD  14w             0.1  0.031470
# 4   IYW  14w             0.1 -0.944094
# Top ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'SOXX']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1 -1.819542
# 1  SOXX  15w             0.1  3.561834
# 2   PSI  15w             0.1 -1.758063
# 3   XSD  15w             0.1 -1.278675
# 4   IYW  15w             0.1 -0.643885
# Top ETFs for 2024-04-08 to 2024-04-14: ['IGM', 'SOXX']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1  0.763023
# 1  SOXX  16w             0.1  3.883153
# 2   PSI  16w             0.1 -0.150163
# 3   XSD  16w             0.1 -1.481122
# 4   IYW  16w             0.1 -0.619450
# Top ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'SOXX']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1  0.900076
# 1  SOXX  17w             0.1  3.339304
# 2   PSI  17w             0.1  0.243960
# 3   XSD  17w             0.1 -1.951429
# 4   IYW  17w             0.1 -0.237690
# Top ETFs for 2024-04-22 to 2024-04-28: ['IGM', 'SOXX']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1 -1.211585
# 1  SOXX  18w             0.1  4.134334
# 2   PSI  18w             0.1 -0.308133
# 3   XSD  18w             0.1 -0.887048
# 4   IYW  18w             0.1 -2.876762
# Top ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IGM']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1  0.491313
# 1  SOXX  19w             0.1  2.647870
# 2   PSI  19w             0.1 -1.992558
# 3   XSD  19w             0.1 -0.364076
# 4   IYW  19w             0.1 -0.624360
# Top ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'IGM']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1 -1.509562
# 1  SOXX  20w             0.1  3.126168
# 2   PSI  20w             0.1 -2.902659
# 3   XSD  20w             0.1 -2.041235
# 4   IYW  20w             0.1 -1.803069
# Top ETFs for 2024-05-13 to 2024-05-19: ['IGM', 'FTEC']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1 -1.227260
# 1  SOXX  21w             0.1  0.732716
# 2   PSI  21w             0.1 -2.514638
# 3   XSD  21w             0.1  0.402546
# 4   IYW  21w             0.1 -1.702134
# Top ETFs for 2024-05-20 to 2024-05-26: ['FTEC', 'IGM']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1 -1.390295
# 1  SOXX  22w             0.1  1.208883
# 2   PSI  22w             0.1 -1.913283
# 3   XSD  22w             0.1  0.543561
# 4   IYW  22w             0.1 -2.188851
# Top ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IGM']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1 -0.181872
# 1  SOXX  23w             0.1  1.279547
# 2   PSI  23w             0.1 -3.062543
# 3   XSD  23w             0.1 -2.034713
# 4   IYW  23w             0.1 -1.442200
# Top ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IGM']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1 -0.500954
# 1  SOXX  24w             0.1  2.160350
# 2   PSI  24w             0.1 -1.597853
# 3   XSD  24w             0.1 -2.378798
# 4   IYW  24w             0.1 -2.301788
# Top ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IGM']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1 -2.118199
# 1  SOXX  25w             0.1  3.102399
# 2   PSI  25w             0.1 -1.653620
# 3   XSD  25w             0.1  0.605739
# 4   IYW  25w             0.1 -2.479946
# Top ETFs for 2024-06-17 to 2024-06-23: ['IGM', 'FTEC']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1 -1.733939
# 1  SOXX  26w             0.1  3.458202
# 2   PSI  26w             0.1 -0.679619
# 3   XSD  26w             0.1 -3.402921
# 4   IYW  26w             0.1 -2.216547
# Top ETFs for 2024-06-24 to 2024-06-30: ['IGM', 'FTEC']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1 -1.104895
# 1  SOXX  27w             0.1  2.227501
# 2   PSI  27w             0.1 -2.661051
# 3   XSD  27w             0.1 -2.053525
# 4   IYW  27w             0.1  0.299477
# Top ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IGM']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1 -1.094055
# 1  SOXX  28w             0.1  2.216844
# 2   PSI  28w             0.1 -1.608886
# 3   XSD  28w             0.1 -1.571890
# 4   IYW  28w             0.1 -0.951783
# Top ETFs for 2024-07-08 to 2024-07-14: ['FTEC', 'SOXX']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1 -0.505689
# 1  SOXX  29w             0.1  2.138676
# 2   PSI  29w             0.1 -0.410992
# 3   XSD  29w             0.1 -0.893760
# 4   IYW  29w             0.1 -0.927368
# Top ETFs for 2024-07-15 to 2024-07-21: ['IGM', 'FTEC']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1  0.420449
# 1  SOXX  30w             0.1  1.652302
# 2   PSI  30w             0.1 -0.700683
# 3   XSD  30w             0.1 -1.350226
# 4   IYW  30w             0.1 -0.383313
# Top ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'IGM']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1 -1.842308
# 1  SOXX  31w             0.1  4.154548
# 2   PSI  31w             0.1  0.400198
# 3   XSD  31w             0.1 -3.370374
# 4   IYW  31w             0.1  0.787952
# Top ETFs for 2024-07-29 to 2024-08-04: ['IGM', 'SOXX']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1 -2.636273
# 1  SOXX  32w             0.1  2.338775
# 2   PSI  32w             0.1 -0.049018
# 3   XSD  32w             0.1 -1.552039
# 4   IYW  32w             0.1  7.418100
# Top ETFs for 2024-08-05 to 2024-08-11: ['IYW', 'SOXX']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1  0.158957
# 1  SOXX  33w             0.1  3.270791
# 2   PSI  33w             0.1 -0.822050
# 3   XSD  33w             0.1 -1.443506
# 4   IYW  33w             0.1  1.188490
# Top ETFs for 2024-08-12 to 2024-08-18: ['IGM', 'SOXX']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1 -1.481528
# 1  SOXX  34w             0.1  2.194211
# 2   PSI  34w             0.1 -0.657270
# 3   XSD  34w             0.1 -0.483955
# 4   IYW  34w             0.1 -1.882739
# Top ETFs for 2024-08-19 to 2024-08-25: ['IGM', 'FTEC']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1 -1.369602
# 1  SOXX  35w             0.1  2.356707
# 2   PSI  35w             0.1 -3.208854
# 3   XSD  35w             0.1 -3.225801
# 4   IYW  35w             0.1 -2.049596
# Top ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IGM']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1 -2.302249
# 1  SOXX  36w             0.1  2.893644
# 2   PSI  36w             0.1 -1.193600
# 3   XSD  36w             0.1 -1.714875
# 4   IYW  36w             0.1 -4.550175
# Top ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1 -0.825556
# 1  SOXX  37w             0.1  3.324075
# 2   PSI  37w             0.1 -1.031611
# 3   XSD  37w             0.1 -1.217205
# 4   IYW  37w             0.1 -2.163142
# Top ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'IGM']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1 -1.504413
# 1  SOXX  38w             0.1  3.396385
# 2   PSI  38w             0.1 -1.454041
# 3   XSD  38w             0.1 -2.488127
# 4   IYW  38w             0.1 -3.259544
# Top ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'FTEC']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1 -1.693069
# 1  SOXX  39w             0.1  0.440121
# 2   PSI  39w             0.1 -0.666270
# 3   XSD  39w             0.1 -1.016535
# 4   IYW  39w             0.1 -1.119493
# Top ETFs for 2024-09-23 to 2024-09-29: ['IGM', 'FTEC']
# ...
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'IGM': 670.3334619848428, 'FTEC': 348.73740855123145}
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'FTEC']
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'IGM': 670.3334619848428, 'FTEC': 348.73740855123145}
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'FTEC']
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'IGM': 670.3334619848428, 'FTEC': 348.73740855123145}
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IGM']
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'IGM': 670.3334619848428, 'FTEC': 348.73740855123145}
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['FTEC', 'SOXX']
# Sell IGM: 670.33 shares at 83.36. Total value: 54485.29
# Buy SOXX: 253.66 shares at 209.43.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'FTEC': 348.73740855123145, 'SOXX': 253.65591639286907}
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IGM']
# Sell SOXX: 253.66 shares at 204.87. Total value: 50666.50
# Buy IGM: 609.22 shares at 81.09.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'FTEC': 348.73740855123145, 'IGM': 609.2226876819016}
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['SOXX', 'FTEC']
# Sell IGM: 609.22 shares at 83.61. Total value: 49660.71
# Buy SOXX: 225.99 shares at 214.25.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'FTEC': 348.73740855123145, 'SOXX': 225.99391083714207}
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['SOXX', 'FTEC']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['FTEC', 'SOXX']
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'FTEC': 348.73740855123145, 'SOXX': 225.99391083714207}
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'SOXX']
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'FTEC': 348.73740855123145, 'SOXX': 225.99391083714207}
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['SOXX', 'IGM']
# Sell FTEC: 348.74 shares at 153.66. Total value: 52247.32
# Buy IGM: 597.97 shares at 85.19.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'SOXX': 225.99391083714207, 'IGM': 597.9707983463342}
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['SOXX', 'IGM']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'SOXX']
# Sell IGM: 597.97 shares at 86.60. Total value: 50489.66
# Buy FTEC: 314.65 shares at 156.45.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'SOXX': 225.99391083714207, 'FTEC': 314.65275066971975}
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'SOXX']
# Sell FTEC: 314.65 shares at 155.92. Total value: 47834.14
# Buy IGM: 538.18 shares at 86.66.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'SOXX': 225.99391083714207, 'IGM': 538.1754492522249}
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['IGM', 'SOXX']
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'SOXX': 225.99391083714207, 'IGM': 538.1754492522249}
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'SOXX']
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'SOXX': 225.99391083714207, 'IGM': 538.1754492522249}
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['IGM', 'SOXX']
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'SOXX': 225.99391083714207, 'IGM': 538.1754492522249}
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IGM']
# Sell SOXX: 225.99 shares at 218.55. Total value: 48156.20
# Buy FTEC: 312.41 shares at 150.29.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'IGM']
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IGM', 'FTEC']
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['FTEC', 'IGM']
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IGM']
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IGM']
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IGM']
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['IGM', 'FTEC']
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IGM', 'FTEC']
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IGM']
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'IGM': 538.1754492522249, 'FTEC': 312.4112905825846}
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['FTEC', 
(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

week_49_end = '2024-12-06'
# Initialize a dictionary to store the values of shares
etf_values_49w = {}

# Ensure 48th week data exists
if week_48_range in ticker_shares_per_week:
    # Fetch ETF shares from the 48th week
    ticker_shares_48w = ticker_shares_per_week[week_48_range]
    
    # Fetch the first trading day price of the 49th week for each ETF
    for ticker, shares in ticker_shares_48w.items():
        print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
        # Download historical data for the 49th week
        data = yf.download(ticker, start=week_49_start, end=week_49_end)
        
        if not data.empty:
            # Get the closing price of the first trading day of the 49th week
            closing_price_49w = data['Close'].iloc[0]
            # Calculate the value of the shares
            total_value = shares * closing_price_49w
            etf_values_49w[ticker] = total_value
            print(f"{ticker}: {shares:.2f} shares at ${closing_price_49w:.2f} each, total value: ${total_value:.2f}")
        else:
            print(f"{ticker}: No data available for the 49th week's first trading day.")
else:
    print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")
# Out:
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker IGM starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# IGM: 487.72 shares at $102.51 each, total value: $49996.61
# Fetching data for ticker FTEC starting from 2024-12-01...
# FTEC: 190.26 shares at $186.99 each, total value: $35577.59

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 85574.20
# IGM: 49996.61
# FTEC: 35577.59

# %% [markdown]
# ### Values for 7th month

# %% [markdown]
# ### Smoothing

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, 
    volatility_clustering, mean_forecast, std_forecast, mean_rachev, std_rachev, 
    mean_sharpe, std_sharpe, mean_sortino, std_sortino, mean_volatility_clustering, 
    std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    return score

def smooth_scores(scores, alpha=0.2):
    """
    Smooth scores using Exponential Moving Average (EMA).
    """
    if not isinstance(scores, (list, np.ndarray)):
        raise ValueError("Scores must be a list or numpy array of numerical values.")
    
    scores = np.array(scores)
    smoothed_scores = np.zeros_like(scores)
    smoothed_scores[0] = scores[0]  # Initialize EMA
    
    for t in range(1, len(scores)):
        smoothed_scores[t] = alpha * scores[t] + (1 - alpha) * smoothed_scores[t - 1]
    
    return smoothed_scores.tolist()

def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )

def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage, alpha=0.2):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    raw_scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        raw_scores.append(score)

    # Apply smoothing to the raw scores
    smoothed_scores = smooth_scores(raw_scores, alpha=alpha)

    results = []
    for idx, etf in enumerate(etf_pred_dict):
        results.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'RawScore': raw_scores[idx],
            'SmoothedScore': smoothed_scores[idx]
        })

    return results

def main_weekly(tickers, etf_dict):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict)
    risk_percentage = 0.10
    weekly_scores = {}

    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores
        else:
            print(f"Skipping score calculation for {week_key}: No ETFs have data for this week.")

    return etf_pred_dict, weekly_scores

# Select top ETFs for weekly portfolio management
def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    top_etfs = df_scores.nlargest(2, 'SmoothedScore')
    return top_etfs['ETF'].tolist()

# %%
etf_pred_dict, weekly_scores = main_weekly(tickers, etf_dict)
# Out:
# Debug: Returns for SMH, Forecast Period 1w: [-0.02114971 -0.01641913 -0.01328753 -0.010488  ]
#
# Debug: Returns for SMH, Forecast Period 2w: [-0.00236152 -0.01116573 -0.01175923 -0.01105097 -0.01297825]
#
# Debug: Returns for SMH, Forecast Period 3w: [-0.00797619 -0.01325713 -0.00273405 -0.00242556]
#
# Debug: Returns for SMH, Forecast Period 4w: [-0.01171342 -0.01074597 -0.00792683 -0.01255071 -0.01969242]
#
# Debug: Returns for SMH, Forecast Period 5w: [-0.0102156  -0.01522117 -0.01648088 -0.00956425 -0.00606219]
#
# Debug: Returns for SMH, Forecast Period 6w: [-0.00558619 -0.01330606 -0.00610416 -0.00728405 -0.00485444]
#
# Debug: Returns for SMH, Forecast Period 7w: [-0.01057591 -0.01520299 -0.0058159  -0.01044066 -0.011452  ]
#
# Debug: Returns for SMH, Forecast Period 8w: [-0.01689423 -0.0141256   0.00472629 -0.01330351]
#
# Debug: Returns for SMH, Forecast Period 9w: [-0.01023087 -0.01121312 -0.01387803 -0.006257   -0.0012057 ]
#
# Debug: Returns for SMH, Forecast Period 10w: [-0.00638326 -0.01454497 -0.0054298  -0.00418289 -0.02243296]
#
# Debug: Returns for SMH, Forecast Period 11w: [-0.01743854 -0.00619245 -0.01804749 -0.01771773 -0.01652703]
#
# Debug: Returns for SMH, Forecast Period 12w: [-0.01417574 -0.01474176 -0.00934116 -0.00681761 -0.01264583]
#
# Debug: Returns for SMH, Forecast Period 13w: [-0.01366509 -0.01519813 -0.01382404 -0.01380284]
#
# Debug: Returns for SMH, Forecast Period 14w: [-0.01243985 -0.01526252 -0.01027388 -0.01647303 -0.00531858]
#
# Debug: Returns for SMH, Forecast Period 15w: [-0.00392187 -0.00991166 -0.01389472 -0.00452025 -0.01690965]
#
# Debug: Returns for SMH, Forecast Period 16w: [-0.01374874 -0.01030632 -0.01607954 -0.01075875 -0.01590609]
#
# Debug: Returns for SMH, Forecast Period 17w: [ 0.00013931  0.00195634 -0.00443571 -0.00148284 -0.00251436]
#
# Debug: Returns for SMH, Forecast Period 18w: [-0.00919723 -0.01028028 -0.01188399 -0.00046798 -0.00419652]
#
# Debug: Returns for SMH, Forecast Period 19w: [-0.00638811 -0.01184372 -0.0092149  -0.01156992 -0.00525169]
#
# Debug: Returns for SMH, Forecast Period 20w: [-0.01217761 -0.01111275 -0.00893203 -0.01436097 -0.01363888]
#
# Debug: Returns for SMH, Forecast Period 21w: [-0.00609489 -0.01015436 -0.00958052 -0.00854578 -0.00764326]
#
# Debug: Returns for SMH, Forecast Period 22w: [-0.00715126 -0.01534332 -0.01399757 -0.01183627]
#
# Debug: Returns for SMH, Forecast Period 23w: [-0.00864953 -0.01216669 -0.00248402 -0.01257418 -0.01084677]
#
# Debug: Returns for SMH, Forecast Period 24w: [-0.00764944 -0.01054166 -0.0046142  -0.00698887 -0.01028838]
#
# Debug: Returns for SMH, Forecast Period 25w: [-0.00738145 -0.0076356  -0.01819309 -0.01473901]
#
# Debug: Returns for SMH, Forecast Period 26w: [-0.02091941 -0.0096426  -0.01466694 -0.01567157 -0.01312987]
#
# Debug: Returns for SMH, Forecast Period 27w: [-0.01348399 -0.01177707 -0.00995894 -0.01331708]
#
# Debug: Returns for SMH, Forecast Period 28w: [-0.01219741 -0.01419552 -0.01000674 -0.02139908 -0.01347613]
#
# Debug: Returns for SMH, Forecast Period 29w: [-0.01585615 -0.01459235 -0.02176613 -0.00329409 -0.00981872]
#
# Debug: Returns for SMH, Forecast Period 30w: [ 0.00428364 -0.0097865  -0.02168949 -0.00822951 -0.00045784]
#
# Debug: Returns for SMH, Forecast Period 31w: [-0.00590001 -0.01782412  0.0215206  -0.02440027 -0.04192953]
#
# Debug: Returns for SMH, Forecast Period 32w: [-0.04157212 -0.03669675 -0.04802648 -0.02394928 -0.02393722]
#
# Debug: Returns for SMH, Forecast Period 33w: [-0.02436486 -0.00147385 -0.01172063  0.00615571 -0.0074968 ]
#
# Debug: Returns for SMH, Forecast Period 34w: [-0.00988933 -0.00767497 -0.00518646 -0.02022081 -0.01069852]
#
# Debug: Returns for SMH, Forecast Period 35w: [-0.01851086 -0.01272489 -0.019636   -0.0095105  -0.01202834]
#
# Debug: Returns for SMH, Forecast Period 36w: [-0.03011314 -0.01813764 -0.01678625 -0.02556329]
#
# Debug: Returns for SMH, Forecast Period 37w: [-0.00526668 -0.01030132 -0.00373364 -0.01232931 -0.01065077]
#
# Debug: Returns for SMH, Forecast Period 38w: [-0.01007778 -0.00416171 -0.00552045  0.00735094 -0.00555727]
#
# Debug: Returns for SMH, Forecast Period 39w: [-0.00710282 -0.00208315 -0.00996137 -0.00798219 -0.01844396]
#
# Debug: Returns for SMH, Forecast Period 40w: [-0.01600041 -0.01598415 -0.01266517 -0.01383769 -0.01292237]
#
# Debug: Returns for SMH, Forecast Period 41w: [-0.01227032 -0.00999861 -0.01091812 -0.01427995 -0.01239019]
#
# Debug: Returns for SMH, Forecast Period 42w: [-0.0107256  -0.02547377 -0.01650319 -0.0133212  -0.01499976]
#
# Debug: Returns for SMH, Forecast Period 43w: [-0.01457781 -0.01593432 -0.01649643 -0.01367385 -0.0107665 ]
#
# Debug: Returns for SMH, Forecast Period 44w: [-0.01580877 -0.0111253  -0.0185726  -0.02018713 -0.01001483]
#
# Debug: Returns for SMH, Forecast Period 45w: [-0.01130376 -0.00881165 -0.00753274 -0.00933239 -0.01553373]
#
# Debug: Returns for SMH, Forecast Period 46w: [-0.01518233 -0.00769801 -0.01542466 -0.01230972 -0.01209889]
#
# Debug: Returns for SMH, Forecast Period 47w: [-0.00465414 -0.00481714 -0.00782562 -0.00769048 -0.01036985]
#
# Debug: Returns for SMH, Forecast Period 48w: [-0.00729044 -0.00763213 -0.00452002 -0.00248012]
#
# Debug: Returns for SOXX, Forecast Period 1w: [0.02564576 0.03041519 0.03280415 0.0343366 ]
#
# Debug: Returns for SOXX, Forecast Period 2w: [0.03400894 0.03170621 0.03297779 0.03533133 0.03410917]
#
# Debug: Returns for SOXX, Forecast Period 3w: [0.03759888 0.02884762 0.04127937 0.04088899]
#
# Debug: Returns for SOXX, Forecast Period 4w: [0.03359761 0.03028348 0.03486507 0.03211905 0.02836825]
#
# Debug: Returns for SOXX, Forecast Period 5w: [0.03509597 0.0306314  0.02905478 0.03541634 0.03512003]
#
# Debug: Returns for SOXX, Forecast Period 6w: [0.03351201 0.03179084 0.03806202 0.0357461  0.03424908]
#
# Debug: Returns for SOXX, Forecast Period 7w: [0.03292957 0.03395581 0.0355982  0.03157874 0.03416698]
#
# Debug: Returns for SOXX, Forecast Period 8w: [0.0313868  0.03461811 0.04432115 0.03423636]
#
# Debug: Returns for SOXX, Forecast Period 9w: [0.03798702 0.03632884 0.03471973 0.03725027 0.0342702 ]
#
# Debug: Returns for SOXX, Forecast Period 10w: [0.03231963 0.03325417 0.034275   0.03148966 0.03218196]
#
# Debug: Returns for SOXX, Forecast Period 11w: [0.03577745 0.03801216 0.03413746 0.03565342 0.0353197 ]
#
# Debug: Returns for SOXX, Forecast Period 12w: [0.03699967 0.03676629 0.03946538 0.03763291 0.03864636]
#
# Debug: Returns for SOXX, Forecast Period 13w: [0.03798852 0.0368631  0.03912709 0.03734317]
#
# Debug: Returns for SOXX, Forecast Period 14w: [0.03882946 0.03288459 0.03584179 0.02635967 0.03442626]
#
# Debug: Returns for SOXX, Forecast Period 15w: [0.02939322 0.03718894 0.03021875 0.03919128 0.02554461]
#
# Debug: Returns for SOXX, Forecast Period 16w: [0.03092288 0.03783997 0.02279963 0.02322655 0.0117422 ]
#
# Debug: Returns for SOXX, Forecast Period 17w: [0.01840488 0.0229776  0.02446425 0.03062879 0.03257469]
#
# Debug: Returns for SOXX, Forecast Period 18w: [0.03218034 0.02102505 0.01352063 0.02719631 0.03613926]
#
# Debug: Returns for SOXX, Forecast Period 19w: [0.03743418 0.0289493  0.0300582  0.03266058 0.0331913 ]
#
# Debug: Returns for SOXX, Forecast Period 20w: [0.03601713 0.04028125 0.04127269 0.03544234 0.03288353]
#
# Debug: Returns for SOXX, Forecast Period 21w: [0.02887271 0.02894498 0.03264126 0.03408686 0.03443649]
#
# Debug: Returns for SOXX, Forecast Period 22w: [0.03497114 0.03355749 0.03286003 0.03103082]
#
# Debug: Returns for SOXX, Forecast Period 23w: [0.03367735 0.03552212 0.03953713 0.03351953 0.03401567]
#
# Debug: Returns for SOXX, Forecast Period 24w: [0.03401008 0.03423224 0.03466402 0.03455832 0.03578225]
#
# Debug: Returns for SOXX, Forecast Period 25w: [0.03544278 0.03293313 0.03496687 0.03655139]
#
# Debug: Returns for SOXX, Forecast Period 26w: [0.03599219 0.04100504 0.03821094 0.03785146 0.04148487]
#
# Debug: Returns for SOXX, Forecast Period 27w: [0.03998035 0.04104965 0.03952104 0.03775443]
#
# Debug: Returns for SOXX, Forecast Period 28w: [0.04279035 0.03956347 0.03863535 0.03562688 0.04092203]
#
# Debug: Returns for SOXX, Forecast Period 29w: [0.04001107 0.0404414  0.01305728 0.02897242 0.01701651]
#
# Debug: Returns for SOXX, Forecast Period 30w: [0.03985773 0.03079231 0.01291977 0.01228359 0.02429505]
#
# Debug: Returns for SOXX, Forecast Period 31w: [0.02020547 0.00882893 0.03178439 0.00261744 0.00080803]
#
# Debug: Returns for SOXX, Forecast Period 32w: [ 0.00355709  0.00511189 -0.00027318  0.00851031  0.00499804]
#
# Debug: Returns for SOXX, Forecast Period 33w: [0.00612208 0.00984625 0.00749161 0.02147844 0.01460339]
#
# Debug: Returns for SOXX, Forecast Period 34w: [0.02600447 0.01214085 0.02050257 0.01479564 0.02984716]
#
# Debug: Returns for SOXX, Forecast Period 35w: [0.01822162 0.02655186 0.02376896 0.01612069 0.03222784]
#
# Debug: Returns for SOXX, Forecast Period 36w: [0.01516308 0.02892849 0.0277853  0.02037836]
#
# Debug: Returns for SOXX, Forecast Period 37w: [0.02357459 0.02700379 0.03138653 0.02208389 0.02872439]
#
# Debug: Returns for SOXX, Forecast Period 38w: [0.01593814 0.01947344 0.01404887 0.02655792 0.0141307 ]
#
# Debug: Returns for SOXX, Forecast Period 39w: [0.02477301 0.02251798 0.02957589 0.03434544 0.03195596]
#
# Debug: Returns for SOXX, Forecast Period 40w: [0.03091919 0.01692762 0.03807908 0.03767832 0.03932913]
#
# Debug: Returns for SOXX, Forecast Period 41w: [0.03842045 0.0386833  0.03800297 0.03923386 0.0393365 ]
#
# Debug: Returns for SOXX, Forecast Period 42w: [0.0403253  0.02641479 0.03644928 0.03885658 0.0384357 ]
#
# Debug: Returns for SOXX, Forecast Period 43w: [0.03861003 0.03782858 0.03438224 0.03755524 0.0361497 ]
#
# Debug: Returns for SOXX, Forecast Period 44w: [0.03691074 0.04248506 0.03080089 0.01826828 0.03386218]
#
# Debug: Returns for SOXX, Forecast Period 45w: [0.02842734 0.03385842 0.03883553 0.03911466 0.03472367]
#
# Debug: Returns for SOXX, Forecast Period 46w: [0.02497109 0.02566407 0.02706411 0.03257723 0.0193585 ]
#
# Debug: Returns for SOXX, Forecast Period 47w: [0.02979602 0.0292134  0.02603917 0.03257955 0.03096703]
#
# Debug: Returns for SOXX, Forecast Period 48w: [0.03242439 0.0271786  0.02263927 0.03283319]
#
# Debug: Returns for PSI, Forecast Period 1w: [-0.02083115 -0.01008259 -0.0043965   0.00110177]
#
# Debug: Returns for PSI, Forecast Period 2w: [ 3.6260076e-03 -4.5677675e-03 -7.0268689e-03  3.9581908e-05
#  -3.6599627e-03]
#
# Debug: Returns for PSI, Forecast Period 3w: [ 0.00275858 -0.00642315  0.00835478  0.00841096]
#
# Debug: Returns for PSI, Forecast Period 4w: [-0.00596876 -0.01179144 -0.0051224  -0.01015634 -0.01470987]
#
# Debug: Returns for PSI, Forecast Period 5w: [-0.00143145 -0.01196188 -0.01254853 -0.00289099 -0.00895549]
#
# Debug: Returns for PSI, Forecast Period 6w: [-0.01334842 -0.01958755 -0.00932083 -0.00735221 -0.00722704]
#
# Debug: Returns for PSI, Forecast Period 7w: [-0.02011258 -0.02692262 -0.0055312  -0.01752308 -0.02162647]
#
# Debug: Returns for PSI, Forecast Period 8w: [-0.02443757 -0.01504023  0.00693745 -0.01752306]
#
# Debug: Returns for PSI, Forecast Period 9w: [-0.00550119 -0.01638604 -0.01079248 -0.0098323  -0.0072344 ]
#
# Debug: Returns for PSI, Forecast Period 10w: [-0.02108084 -0.02389313 -0.00893461 -0.00808284 -0.01943539]
#
# Debug: Returns for PSI, Forecast Period 11w: [-0.01203194  0.00038694 -0.01444907 -0.01073642 -0.00634037]
#
# Debug: Returns for PSI, Forecast Period 12w: [-0.00011017 -0.00538083  0.00342722 -0.00377321 -0.01168818]
#
# Debug: Returns for PSI, Forecast Period 13w: [-0.01304322 -0.01774768 -0.01221769 -0.01827879]
#
# Debug: Returns for PSI, Forecast Period 14w: [-0.01452771 -0.02144619 -0.01255398 -0.02469981 -0.00909512]
#
# Debug: Returns for PSI, Forecast Period 15w: [-0.01100005 -0.00378654 -0.01316385  0.00550554 -0.01795236]
#
# Debug: Returns for PSI, Forecast Period 16w: [-0.01199531 -0.00380958 -0.01828898 -0.01437578 -0.01668322]
#
# Debug: Returns for PSI, Forecast Period 17w: [-0.00586734 -0.00385389 -0.00623624 -0.00310238 -0.00247275]
#
# Debug: Returns for PSI, Forecast Period 18w: [-0.00229758 -0.01331697 -0.01550596 -0.00321009 -0.00026241]
#
# Debug: Returns for PSI, Forecast Period 19w: [-6.0168561e-05 -1.1534203e-02 -1.1797796e-02 -7.1330974e-03
#  -8.0259591e-03]
#
# Debug: Returns for PSI, Forecast Period 20w: [-0.00931526 -0.00474108 -0.00359428 -0.02321687 -0.02480998]
#
# Debug: Returns for PSI, Forecast Period 21w: [-0.01183714 -0.02154662 -0.02441473 -0.02499844 -0.0193994 ]
#
# Debug: Returns for PSI, Forecast Period 22w: [-0.02044643 -0.02628117 -0.02469455 -0.02559514]
#
# Debug: Returns for PSI, Forecast Period 23w: [-0.02019195 -0.0174758  -0.0008996  -0.0225226  -0.02109409]
#
# Debug: Returns for PSI, Forecast Period 24w: [-0.01401155 -0.02294919 -0.01602865 -0.02376899 -0.02489881]
#
# Debug: Returns for PSI, Forecast Period 25w: [-0.01956542 -0.02482804 -0.03036711 -0.02268371]
#
# Debug: Returns for PSI, Forecast Period 26w: [-0.02092096 -0.00534684 -0.01724806 -0.01267744 -0.01062526]
#
# Debug: Returns for PSI, Forecast Period 27w: [-0.01472405 -0.01414649 -0.01815448 -0.02312443]
#
# Debug: Returns for PSI, Forecast Period 28w: [-0.01579932 -0.02297119 -0.02251777 -0.02871014 -0.01486271]
#
# Debug: Returns for PSI, Forecast Period 29w: [-0.01328222 -0.01542383 -0.02427655 -0.01355831 -0.01610232]
#
# Debug: Returns for PSI, Forecast Period 30w: [ 0.00232082 -0.00857197 -0.01704729 -0.01288921 -0.00423665]
#
# Debug: Returns for PSI, Forecast Period 31w: [-0.0084065  -0.01381935  0.00244521 -0.01359436 -0.01142515]
#
# Debug: Returns for PSI, Forecast Period 32w: [-0.00277108  0.00074102 -0.00210402  0.01014096 -0.00638322]
#
# Debug: Returns for PSI, Forecast Period 33w: [-0.00704327 -0.0048912  -0.00918336 -0.00676272 -0.01516525]
#
# Debug: Returns for PSI, Forecast Period 34w: [-0.01326    -0.02200436 -0.01791485 -0.02624134 -0.00459999]
#
# Debug: Returns for PSI, Forecast Period 35w: [-0.02212257 -0.00995519 -0.01114114 -0.01395454 -0.00062958]
#
# Debug: Returns for PSI, Forecast Period 36w: [-0.01905107 -0.00153951 -0.00556949 -0.01240773]
#
# Debug: Returns for PSI, Forecast Period 37w: [-0.00829116 -0.0062618   0.00517696 -0.00705533  0.00363926]
#
# Debug: Returns for PSI, Forecast Period 38w: [-0.0137509  -0.00724181 -0.01174871 -0.00497589 -0.01882697]
#
# Debug: Returns for PSI, Forecast Period 39w: [-0.01435852 -0.0174583  -0.01563049  0.00142502 -0.01918552]
#
# Debug: Returns for PSI, Forecast Period 40w: [-0.01667548 -0.02453926 -0.00181314 -0.00961245 -0.00040554]
#
# Debug: Returns for PSI, Forecast Period 41w: [-0.00559547 -0.00395532 -0.00179257 -0.00303786  0.00051448]
#
# Debug: Returns for PSI, Forecast Period 42w: [ 0.00048643 -0.01587326 -0.00048445 -0.00456552 -0.00855881]
#
# Debug: Returns for PSI, Forecast Period 43w: [-0.01210005 -0.01398778 -0.01613813 -0.0126615  -0.01103877]
#
# Debug: Returns for PSI, Forecast Period 44w: [-0.01571277 -0.00478407 -0.02145869 -0.02394056 -0.0103079 ]
#
# Debug: Returns for PSI, Forecast Period 45w: [-0.01452968 -0.00313134  0.00180497 -0.0008551  -0.01426192]
#
# Debug: Returns for PSI, Forecast Period 46w: [-0.02223125 -0.01892397 -0.02201616 -0.01659964 -0.02279377]
#
# Debug: Returns for PSI, Forecast Period 47w: [-0.01316963 -0.01381398 -0.01634097 -0.00245004 -0.01191617]
#
# Debug: Returns for PSI, Forecast Period 48w: [-0.00577431 -0.01500833 -0.01925318 -0.00618092]
#
# Debug: Returns for XSD, Forecast Period 1w: [-0.01642137 -0.01727797 -0.01581688 -0.01170745]
#
# Debug: Returns for XSD, Forecast Period 2w: [-0.00668174 -0.01173772 -0.01211347 -0.01228836 -0.01210969]
#
# Debug: Returns for XSD, Forecast Period 3w: [-0.00959684 -0.02073671 -0.00556329 -0.00339895]
#
# Debug: Returns for XSD, Forecast Period 4w: [-0.00559695 -0.00648473 -0.01184431 -0.01310262 -0.02266123]
#
# Debug: Returns for XSD, Forecast Period 5w: [-0.00682942 -0.02081856 -0.01973925 -0.0107714  -0.00767633]
#
# Debug: Returns for XSD, Forecast Period 6w: [-0.00493254 -0.00716908 -0.00171437 -0.00084263 -0.00196977]
#
# Debug: Returns for XSD, Forecast Period 7w: [-0.00439683 -0.01236028 -0.00274054 -0.00524053 -0.00749655]
#
# Debug: Returns for XSD, Forecast Period 8w: [-0.00855337 -0.00854077 -0.00310096 -0.01367513]
#
# Debug: Returns for XSD, Forecast Period 9w: [-0.00507295 -0.00727201 -0.00849162 -0.00233462 -0.00291821]
#
# Debug: Returns for XSD, Forecast Period 10w: [-0.0080501  -0.01197159 -0.00479416 -0.00550818 -0.01421653]
#
# Debug: Returns for XSD, Forecast Period 11w: [-0.01046629 -0.00721012 -0.01544306 -0.01503993 -0.01360322]
#
# Debug: Returns for XSD, Forecast Period 12w: [-0.01164503 -0.01155521 -0.00463163 -0.00441126 -0.0081217 ]
#
# Debug: Returns for XSD, Forecast Period 13w: [-0.00664503 -0.00638951 -0.001391   -0.0034853 ]
# Debug: Returns for XSD, Forecast Period 14w: [-0.00244686 -0.00973153 -0.00323254 -0.00902619 -0.00590699]
#
# Debug: Returns for XSD, Forecast Period 15w: [-0.00682055 -0.00305399 -0.0185381  -0.0053959  -0.01748949]
#
# Debug: Returns for XSD, Forecast Period 16w: [-0.01533725 -0.01070783 -0.01556608 -0.01597719 -0.02381318]
#
# Debug: Returns for XSD, Forecast Period 17w: [-0.01631819 -0.01207331 -0.00933799 -0.00802024 -0.00879104]
#
# Debug: Returns for XSD, Forecast Period 18w: [-0.00794612 -0.01870687 -0.02189957 -0.01066282 -0.00809114]
#
# Debug: Returns for XSD, Forecast Period 19w: [-0.0082732  -0.01331414 -0.01226776 -0.00917027 -0.01207251]
#
# Debug: Returns for XSD, Forecast Period 20w: [-0.00757253 -0.00557658 -0.00516787 -0.00913219 -0.00878456]
#
# Debug: Returns for XSD, Forecast Period 21w: [-0.00969743 -0.01018249 -0.00735598 -0.0114689  -0.00513432]
#
# Debug: Returns for XSD, Forecast Period 22w: [-0.00560648 -0.00992238 -0.00643708 -0.00965803]
#
# Debug: Returns for XSD, Forecast Period 23w: [-0.01001384 -0.0120228  -0.00423415 -0.01074716 -0.01235213]
#
# Debug: Returns for XSD, Forecast Period 24w: [-0.00621103 -0.0069441  -0.00456969 -0.00723888 -0.00878205]
#
# Debug: Returns for XSD, Forecast Period 25w: [-0.00435318 -0.00383244 -0.00774505 -0.00342562]
#
# Debug: Returns for XSD, Forecast Period 26w: [-7.8960517e-03 -1.3917813e-03 -2.0638991e-03 -2.7093003e-03
#  -3.4212833e-05]
#
# Debug: Returns for XSD, Forecast Period 27w: [-1.7324978e-03  9.8919985e-04  8.8444212e-05 -3.6207074e-04]
#
# Debug: Returns for XSD, Forecast Period 28w: [ 0.00109934 -0.00174634 -0.00129333 -0.0045691  -0.00235075]
#
# Debug: Returns for XSD, Forecast Period 29w: [-0.00220237 -0.00196512 -0.0190168  -0.01221702 -0.01798338]
#
# Debug: Returns for XSD, Forecast Period 30w: [-0.00463672 -0.01461166 -0.01828965 -0.01697085 -0.01029474]
#
# Debug: Returns for XSD, Forecast Period 31w: [-0.01381276 -0.02330179 -0.00712528 -0.03575698 -0.04733691]
#
# Debug: Returns for XSD, Forecast Period 32w: [-0.04398989 -0.03905835 -0.04544701 -0.01965258 -0.03974113]
#
# Debug: Returns for XSD, Forecast Period 33w: [-0.0397359  -0.02708132 -0.0412785  -0.01154494 -0.02048025]
#
# Debug: Returns for XSD, Forecast Period 34w: [-0.01389625 -0.02281907 -0.01233271 -0.01855992 -0.00978638]
#
# Debug: Returns for XSD, Forecast Period 35w: [-0.01581578 -0.01309827 -0.01512567 -0.01226082 -0.01244743]
#
# Debug: Returns for XSD, Forecast Period 36w: [-0.02529228 -0.02013661 -0.02038324 -0.02426808]
#
# Debug: Returns for XSD, Forecast Period 37w: [-0.0168336  -0.01799338 -0.01554398 -0.01783856 -0.01594541]
#
# Debug: Returns for XSD, Forecast Period 38w: [-0.01705756 -0.01541974 -0.01600301 -0.01095382 -0.01638369]
#
# Debug: Returns for XSD, Forecast Period 39w: [-0.01453915 -0.01305488 -0.01401791 -0.00561049 -0.01357097]
#
# Debug: Returns for XSD, Forecast Period 40w: [-0.01422375 -0.01708322 -0.01371263 -0.01497684 -0.01178519]
#
# Debug: Returns for XSD, Forecast Period 41w: [-0.01749518 -0.01413192 -0.01199209 -0.01428401 -0.01054596]
#
# Debug: Returns for XSD, Forecast Period 42w: [-0.01090873 -0.01696417 -0.01132958 -0.01088924 -0.0106618 ]
#
# Debug: Returns for XSD, Forecast Period 43w: [-0.01072617 -0.00931672 -0.01120679 -0.00794092 -0.00713492]
#
# Debug: Returns for XSD, Forecast Period 44w: [-0.0062178  -0.00489844 -0.0162585  -0.01890984 -0.00945791]
#
# Debug: Returns for XSD, Forecast Period 45w: [-0.01408417 -0.00987871 -0.00457577 -0.00788882 -0.00731521]
#
# Debug: Returns for XSD, Forecast Period 46w: [-0.01446681 -0.01428787 -0.01434932 -0.01218577 -0.0178294 ]
#
# Debug: Returns for XSD, Forecast Period 47w: [-0.00900293 -0.00850882 -0.00933021 -0.00314338 -0.00388727]
#
# Debug: Returns for XSD, Forecast Period 48w: [-0.00204177 -0.0093485  -0.01204451 -0.00570327]
#
# Debug: Returns for IYW, Forecast Period 1w: [-0.02489072 -0.0174169  -0.01656511 -0.01366411]
#
# Debug: Returns for IYW, Forecast Period 2w: [-0.00116547 -0.01391829 -0.01125824 -0.01324779 -0.01391451]
#
# Debug: Returns for IYW, Forecast Period 3w: [-0.01385788 -0.01642103 -0.00589603 -0.00446772]
#
# Debug: Returns for IYW, Forecast Period 4w: [-0.01340965 -0.01395185 -0.01221267 -0.0134281  -0.01956139]
#
# Debug: Returns for IYW, Forecast Period 5w: [-0.01054486 -0.01892507 -0.02560629 -0.00970328 -0.00728013]
#
# Debug: Returns for IYW, Forecast Period 6w: [-0.0167136  -0.01911824 -0.00960701 -0.01460844 -0.00920829]
#
# Debug: Returns for IYW, Forecast Period 7w: [-0.02097798 -0.025957   -0.01095526 -0.01827417 -0.02148528]
#
# Debug: Returns for IYW, Forecast Period 8w: [-1.8388208e-02 -1.7022662e-02 -9.2738308e-05 -1.7198082e-02]
#
# Debug: Returns for IYW, Forecast Period 9w: [-0.01661099 -0.01552385 -0.01728122 -0.0118082  -0.01031568]
#
# Debug: Returns for IYW, Forecast Period 10w: [-0.01858472 -0.02368677 -0.01298853 -0.00955201 -0.02030479]
#
# Debug: Returns for IYW, Forecast Period 11w: [-0.01646534 -0.00685046 -0.01820905 -0.01449086 -0.01917545]
#
# Debug: Returns for IYW, Forecast Period 12w: [-0.01217821 -0.01507914 -0.01280184 -0.0179235  -0.01594975]
#
# Debug: Returns for IYW, Forecast Period 13w: [-0.01869489 -0.01828158 -0.0157274  -0.01712537]
#
# Debug: Returns for IYW, Forecast Period 14w: [-0.01436769 -0.01595842 -0.01305412 -0.02097275 -0.01065635]
#
# Debug: Returns for IYW, Forecast Period 15w: [-0.01450425 -0.0150699  -0.01774352 -0.00691127 -0.02033607]
#
# Debug: Returns for IYW, Forecast Period 16w: [-0.01974364 -0.0140542  -0.01747267 -0.01335576 -0.01597422]
#
# Debug: Returns for IYW, Forecast Period 17w: [ 3.1435257e-04  8.4922183e-05 -7.9096016e-03 -1.1039744e-02
#  -2.3816405e-03]
#
# Debug: Returns for IYW, Forecast Period 18w: [-0.0120317  -0.01694098 -0.01210748 -0.00262595 -0.00354889]
#
# Debug: Returns for IYW, Forecast Period 19w: [-0.00884946 -0.01561283 -0.01367519 -0.01484162 -0.01113382]
#
# Debug: Returns for IYW, Forecast Period 20w: [-0.01309959 -0.01361075 -0.00827846 -0.01940428 -0.01923762]
#
# Debug: Returns for IYW, Forecast Period 21w: [-0.01312398 -0.01809429 -0.01786713 -0.01766185 -0.0140674 ]
#
# Debug: Returns for IYW, Forecast Period 22w: [-0.01305607 -0.02031194 -0.03087385 -0.01938391]
#
# Debug: Returns for IYW, Forecast Period 23w: [-0.01528049 -0.01762088 -0.00618815 -0.01931757 -0.0176058 ]
#
# Debug: Returns for IYW, Forecast Period 24w: [-0.01678694 -0.01159467 -0.00931509 -0.01690168 -0.01591624]
#
# Debug: Returns for IYW, Forecast Period 25w: [-0.01383979 -0.01829503 -0.02491722 -0.02057317]
#
# Debug: Returns for IYW, Forecast Period 26w: [-0.02502244 -0.00965444 -0.01596491 -0.01595242 -0.01836769]
#
# Debug: Returns for IYW, Forecast Period 27w: [-0.01363176 -0.01609293 -0.01362332 -0.01528265]
#
# Debug: Returns for IYW, Forecast Period 28w: [-0.01487294 -0.0181667  -0.01116843 -0.02889929 -0.01496168]
#
# Debug: Returns for IYW, Forecast Period 29w: [-0.01554341 -0.01783498 -0.02601043 -0.01417565 -0.01440623]
#
# Debug: Returns for IYW, Forecast Period 30w: [-0.00755916 -0.0164203  -0.02872767 -0.01344579 -0.00721856]
#
# Debug: Returns for IYW, Forecast Period 31w: [-0.01118734 -0.01481485  0.00836619 -0.01633306 -0.00303925]
#
# Debug: Returns for IYW, Forecast Period 32w: [0.00334995 0.0297714  0.01607421 0.04427855 0.01694501]
#
# Debug: Returns for IYW, Forecast Period 33w: [ 0.01530505  0.02506191  0.00312704 -0.0033914  -0.01657383]
#
# Debug: Returns for IYW, Forecast Period 34w: [-0.01608879 -0.01713597 -0.01456202 -0.03007118 -0.01851346]
#
# Debug: Returns for IYW, Forecast Period 35w: [-0.02561922 -0.0216019  -0.02902836 -0.0206775  -0.02043002]
#
# Debug: Returns for IYW, Forecast Period 36w: [-0.04488691 -0.0307057  -0.02698626 -0.03628361]
#
# Debug: Returns for IYW, Forecast Period 37w: [-0.0177433  -0.01826184 -0.01279288 -0.01912971 -0.0201684 ]
#
# Debug: Returns for IYW, Forecast Period 38w: [-0.01974697 -0.01660769 -0.0148714  -0.0036963  -0.01805418]
#
# Debug: Returns for IYW, Forecast Period 39w: [-0.02022734 -0.01556312 -0.01869611 -0.01512938 -0.0239931 ]
#
# Debug: Returns for IYW, Forecast Period 40w: [-0.01929533 -0.02556159 -0.02099982 -0.02191276 -0.01817703]
#
# Debug: Returns for IYW, Forecast Period 41w: [-0.02909471 -0.01717029 -0.02018391 -0.02182318 -0.0200529 ]
#
# Debug: Returns for IYW, Forecast Period 42w: [-0.01545132 -0.02913503 -0.02092021 -0.02004642 -0.01775627]
#
# Debug: Returns for IYW, Forecast Period 43w: [-0.01671434 -0.0192725  -0.02341931 -0.01640857 -0.01430623]
#
# Debug: Returns for IYW, Forecast Period 44w: [-0.01714391 -0.01316463 -0.02427069 -0.02904391 -0.01475099]
#
# Debug: Returns for IYW, Forecast Period 45w: [-0.01589864 -0.01238284 -0.00638818 -0.01084333 -0.01833106]
#
# Debug: Returns for IYW, Forecast Period 46w: [-0.01940326 -0.01499273 -0.01849357 -0.01814816 -0.02322213]
#
# Debug: Returns for IYW, Forecast Period 47w: [-0.01374098 -0.01150874 -0.01606032 -0.01546131 -0.01734766]
#
# Debug: Returns for IYW, Forecast Period 48w: [-0.01698563 -0.01504965 -0.0181534  -0.01373716]
#
# Debug: Returns for XLK, Forecast Period 1w: [-0.01084182 -0.00577187 -0.00405434 -0.00251688]
#
# Debug: Returns for XLK, Forecast Period 2w: [ 0.00885255 -0.00101019  0.00181738  0.00047529  0.00249848]
#
# Debug: Returns for XLK, Forecast Period 3w: [ 0.00239367 -0.00036407  0.01083288  0.01393331]
#
# Debug: Returns for XLK, Forecast Period 4w: [0.00715355 0.00598842 0.00742609 0.00458353 0.00191822]
#
# Debug: Returns for XLK, Forecast Period 5w: [ 0.00784748  0.00205519 -0.0015031   0.00690435  0.00205679]
#
# Debug: Returns for XLK, Forecast Period 6w: [-0.00343299 -0.00659372  0.00135532 -0.00242202 -0.00055352]
#
# Debug: Returns for XLK, Forecast Period 7w: [-0.00505962 -0.00731567  0.00028398 -0.00377709 -0.00507077]
#
# Debug: Returns for XLK, Forecast Period 8w: [-0.00744732 -0.00709218  0.00726678 -0.00462667]
#
# Debug: Returns for XLK, Forecast Period 9w: [-0.00428417 -0.00277694 -0.00413932  0.00129186  0.00338546]
#
# Debug: Returns for XLK, Forecast Period 10w: [-0.0025422  -0.0096162  -0.00015727  0.0035499  -0.0063717 ]
#
# Debug: Returns for XLK, Forecast Period 11w: [-0.00387899  0.00440702 -0.00479814 -0.00169992 -0.00668136]
#
# Debug: Returns for XLK, Forecast Period 12w: [-0.00124248 -0.0012038   0.00040222 -0.0037058  -0.00391783]
#
# Debug: Returns for XLK, Forecast Period 13w: [-0.00575116 -0.00486182 -0.00308338 -0.00479073]
#
# Debug: Returns for XLK, Forecast Period 14w: [-0.00390074 -0.00748145 -0.00385538 -0.01043228 -0.00270083]
#
# Debug: Returns for XLK, Forecast Period 15w: [-0.00520615 -0.00334629 -0.00848023  0.00215099 -0.00965238]
#
# Debug: Returns for XLK, Forecast Period 16w: [-0.01212045 -0.00582376 -0.01075704 -0.01062429 -0.01514131]
#
# Debug: Returns for XLK, Forecast Period 17w: [-0.00434395 -0.00205564 -0.00498994 -0.00716063 -0.00238323]
#
# Debug: Returns for XLK, Forecast Period 18w: [-0.00384658 -0.01256855 -0.01082798 -0.00195335  0.005601  ]
#
# Debug: Returns for XLK, Forecast Period 19w: [ 0.00152318 -0.00229364 -0.00029535 -0.00084625 -0.00086211]
#
# Debug: Returns for XLK, Forecast Period 20w: [ 0.00096947  0.00233376  0.00662156 -0.00086665  0.00016055]
#
# Debug: Returns for XLK, Forecast Period 21w: [-0.00167715 -0.00487389 -0.00204973 -0.00250471  0.00088931]
#
# Debug: Returns for XLK, Forecast Period 22w: [ 0.00041039 -0.00042701 -0.00538125 -0.00073915]
#
# Debug: Returns for XLK, Forecast Period 23w: [0.00034627 0.00248636 0.00954311 0.00071404 0.00203503]
#
# Debug: Returns for XLK, Forecast Period 24w: [0.00111207 0.0049737  0.00344255 0.00027679 0.00243351]
#
# Debug: Returns for XLK, Forecast Period 25w: [ 0.0038595  -0.00054023 -0.00027716  0.0034796 ]
#
# Debug: Returns for XLK, Forecast Period 26w: [-0.00178935  0.00990323  0.00483871  0.00517927  0.00451966]
#
# Debug: Returns for XLK, Forecast Period 27w: [ 0.00270476  0.00104179  0.00149384 -0.00513109]
#
# Debug: Returns for XLK, Forecast Period 28w: [ 0.00057119 -0.00211917 -0.00019264 -0.00913754  0.00098766]
#
# Debug: Returns for XLK, Forecast Period 29w: [-0.00043778 -0.00180051 -0.01386194 -0.00728124 -0.01077028]
#
# Debug: Returns for XLK, Forecast Period 30w: [-0.00087946 -0.00608395 -0.01819624 -0.01369567 -0.00673529]
#
# Debug: Returns for XLK, Forecast Period 31w: [-0.00946407 -0.01540562  0.00438575 -0.01735847 -0.01277344]
#
# Debug: Returns for XLK, Forecast Period 32w: [-0.01476105 -0.00399928 -0.01039519  0.00238031 -0.00313767]
#
# Debug: Returns for XLK, Forecast Period 33w: [-0.00190237  0.00174389 -0.00386903 -0.00203307 -0.01059512]
#
# Debug: Returns for XLK, Forecast Period 34w: [-0.00430334 -0.00936705 -0.0056342  -0.01361093 -0.00091793]
#
# Debug: Returns for XLK, Forecast Period 35w: [-0.01071882 -0.00527389 -0.01173833 -0.01372372 -0.00346671]
#
# Debug: Returns for XLK, Forecast Period 36w: [-0.02891806 -0.01383793 -0.01265632 -0.02232224]
#
# Debug: Returns for XLK, Forecast Period 37w: [-0.00636053 -0.00465302  0.0062907  -0.00492217 -0.00421791]
#
# Debug: Returns for XLK, Forecast Period 38w: [-0.00824596 -0.00790764 -0.0118343   0.00043297 -0.00943887]
#
# Debug: Returns for XLK, Forecast Period 39w: [-0.00579276 -0.00377311 -0.00342342 -0.00010643 -0.00602197]
#
# Debug: Returns for XLK, Forecast Period 40w: [-0.00247589 -0.01310525 -0.00205851 -0.00333947 -0.0022084 ]
#
# Debug: Returns for XLK, Forecast Period 41w: [-0.01536048 -0.00418639 -0.00605798 -0.00248434 -0.00100195]
#
# Debug: Returns for XLK, Forecast Period 42w: [ 0.0021168  -0.00758086 -0.00064805 -0.00096165 -0.00050539]
#
# Debug: Returns for XLK, Forecast Period 43w: [-0.00023605 -0.0011866  -0.00477888 -0.00118017 -0.00156128]
#
# Debug: Returns for XLK, Forecast Period 44w: [-0.00115811  0.00322607 -0.00512944 -0.01206378 -0.00325901]
#
# Debug: Returns for XLK, Forecast Period 45w: [-0.00476491  0.00068285  0.00526625  0.00227447 -0.00143513]
#
# Debug: Returns for XLK, Forecast Period 46w: [-0.00271907 -0.00210564 -0.00155899 -0.00147565 -0.00884736]
#
# Debug: Returns for XLK, Forecast Period 47w: [-0.00234692 -0.00115715 -0.00316569  0.00064826 -0.00218368]
#
# Debug: Returns for XLK, Forecast Period 48w: [-0.00290618 -0.00076402 -0.00650537  0.00024283]
#
# Debug: Returns for VGT, Forecast Period 1w: [-0.02163065 -0.02005984 -0.01737528 -0.01511606]
#
# Debug: Returns for VGT, Forecast Period 2w: [-0.00585493 -0.01358092 -0.01164446 -0.01561682 -0.01451302]
#
# Debug: Returns for VGT, Forecast Period 3w: [-0.01597726 -0.01877896 -0.01027115 -0.01204113]
# Debug: Returns for VGT, Forecast Period 4w: [-0.01626586 -0.01721056 -0.01737224 -0.01707104 -0.01868544]
#
# Debug: Returns for VGT, Forecast Period 5w: [-0.01343267 -0.01914961 -0.02263393 -0.01214707 -0.01007409]
#
# Debug: Returns for VGT, Forecast Period 6w: [-0.01086628 -0.01148363 -0.01007716 -0.01147219 -0.00945687]
#
# Debug: Returns for VGT, Forecast Period 7w: [-0.01424802 -0.01738851 -0.01044105 -0.01236383 -0.01732765]
#
# Debug: Returns for VGT, Forecast Period 8w: [-0.02057586 -0.0216851  -0.00923422 -0.01909657]
#
# Debug: Returns for VGT, Forecast Period 9w: [-0.01836484 -0.01769918 -0.01998598 -0.01562534 -0.00947603]
#
# Debug: Returns for VGT, Forecast Period 10w: [-0.01464659 -0.02094447 -0.01470986 -0.01121026 -0.01933784]
#
# Debug: Returns for VGT, Forecast Period 11w: [-0.01878343 -0.01438778 -0.01995129 -0.01689406 -0.02141055]
#
# Debug: Returns for VGT, Forecast Period 12w: [-0.01737088 -0.01568122 -0.01081161 -0.0114262  -0.01672766]
#
# Debug: Returns for VGT, Forecast Period 13w: [-0.01763797 -0.01833363 -0.01755456 -0.01805385]
#
# Debug: Returns for VGT, Forecast Period 14w: [-0.01873524 -0.02307033 -0.02097122 -0.02130163 -0.01795096]
#
# Debug: Returns for VGT, Forecast Period 15w: [-0.02199149 -0.01882863 -0.02100231 -0.01693812 -0.02347886]
#
# Debug: Returns for VGT, Forecast Period 16w: [-0.0253933  -0.02027775 -0.02457254 -0.02585432 -0.03155039]
#
# Debug: Returns for VGT, Forecast Period 17w: [-0.02315121 -0.02040232 -0.02234926 -0.02118689 -0.01601395]
#
# Debug: Returns for VGT, Forecast Period 18w: [-0.01946333 -0.02504417 -0.02395238 -0.01789685 -0.01156581]
#
# Debug: Returns for VGT, Forecast Period 19w: [-0.01550179 -0.01950266 -0.0186727  -0.01895806 -0.0200475 ]
#
# Debug: Returns for VGT, Forecast Period 20w: [-0.01733554 -0.01418447 -0.00930319 -0.01304264 -0.01153403]
#
# Debug: Returns for VGT, Forecast Period 21w: [-0.00643018 -0.00946925 -0.0114023  -0.01136034 -0.00912531]
#
# Debug: Returns for VGT, Forecast Period 22w: [-0.01033631 -0.01352314 -0.01595695 -0.01074614]
#
# Debug: Returns for VGT, Forecast Period 23w: [-0.01077558 -0.01457814 -0.01013595 -0.01522579 -0.01497843]
#
# Debug: Returns for VGT, Forecast Period 24w: [-0.013519   -0.01087561 -0.00915503 -0.01134401 -0.01437188]
#
# Debug: Returns for VGT, Forecast Period 25w: [-0.01104501 -0.01189994 -0.01735076 -0.0157293 ]
#
# Debug: Returns for VGT, Forecast Period 26w: [-0.01935659 -0.01136405 -0.01525688 -0.01656668 -0.01678576]
#
# Debug: Returns for VGT, Forecast Period 27w: [-0.01198321 -0.01182718 -0.01107159 -0.01206244]
#
# Debug: Returns for VGT, Forecast Period 28w: [-0.01308065 -0.01409254 -0.01023126 -0.0159244  -0.01196826]
#
# Debug: Returns for VGT, Forecast Period 29w: [-0.01498532 -0.01625927 -0.02329222 -0.02304997 -0.0243997 ]
#
# Debug: Returns for VGT, Forecast Period 30w: [-0.01553364 -0.01896694 -0.02613363 -0.02512693 -0.01922765]
#
# Debug: Returns for VGT, Forecast Period 31w: [-0.02384238 -0.02648115 -0.01175806 -0.02871278 -0.03059765]
#
# Debug: Returns for VGT, Forecast Period 32w: [-0.03429133 -0.02523932 -0.02405204 -0.02261749 -0.02355035]
#
# Debug: Returns for VGT, Forecast Period 33w: [-0.02353027 -0.02264668 -0.02358816 -0.0136402  -0.01751649]
#
# Debug: Returns for VGT, Forecast Period 34w: [-0.01237662 -0.01947898 -0.01701241 -0.01659362 -0.00567175]
#
# Debug: Returns for VGT, Forecast Period 35w: [-0.01442489 -0.01065535 -0.01274987 -0.01729156 -0.00554672]
#
# Debug: Returns for VGT, Forecast Period 36w: [-0.01782325 -0.00765784 -0.00851892 -0.01451229]
#
# Debug: Returns for VGT, Forecast Period 37w: [-0.00679628 -0.00896962 -0.0024646  -0.01163648 -0.01300602]
#
# Debug: Returns for VGT, Forecast Period 38w: [-0.02082251 -0.02061998 -0.02367689 -0.01222491 -0.02079435]
#
# Debug: Returns for VGT, Forecast Period 39w: [-0.01656332 -0.01654714 -0.01623473 -0.01350299 -0.0158264 ]
#
# Debug: Returns for VGT, Forecast Period 40w: [-0.01323585 -0.02303687 -0.00740948 -0.0078885  -0.0069731 ]
#
# Debug: Returns for VGT, Forecast Period 41w: [-0.00927621 -0.00589288 -0.00717201 -0.01158828 -0.01257967]
#
# Debug: Returns for VGT, Forecast Period 42w: [-0.01120066 -0.01583741 -0.01197992 -0.0109384  -0.01523327]
#
# Debug: Returns for VGT, Forecast Period 43w: [-0.01390178 -0.01524013 -0.01882939 -0.01661731 -0.017546  ]
#
# Debug: Returns for VGT, Forecast Period 44w: [-0.01755504 -0.01507716 -0.01654376 -0.02151502 -0.01594022]
#
# Debug: Returns for VGT, Forecast Period 45w: [-0.01900793 -0.01473816 -0.01019537 -0.01202745 -0.01666446]
#
# Debug: Returns for VGT, Forecast Period 46w: [-0.01787752 -0.01867869 -0.01760775 -0.01890212 -0.02343733]
#
# Debug: Returns for VGT, Forecast Period 47w: [-0.01959457 -0.0179336  -0.01898684 -0.01521061 -0.01681633]
#
# Debug: Returns for VGT, Forecast Period 48w: [-0.01796073 -0.01812998 -0.02092603 -0.01619617]
#
# Debug: Returns for FTEC, Forecast Period 1w: [0.04891069 0.04717503 0.04653464 0.04495749]
#
# Debug: Returns for FTEC, Forecast Period 2w: [0.05095375 0.04966491 0.04973553 0.04934195 0.04833209]
#
# Debug: Returns for FTEC, Forecast Period 3w: [0.04759163 0.04589528 0.04863186 0.05185726]
#
# Debug: Returns for FTEC, Forecast Period 4w: [0.05173493 0.05431179 0.05316385 0.05314992 0.05079808]
#
# Debug: Returns for FTEC, Forecast Period 5w: [0.05325744 0.05115939 0.04781029 0.05450236 0.05713867]
#
# Debug: Returns for FTEC, Forecast Period 6w: [0.05658839 0.055872   0.0567228  0.05683159 0.05712672]
#
# Debug: Returns for FTEC, Forecast Period 7w: [0.05657745 0.05281884 0.05608286 0.0561962  0.05209038]
#
# Debug: Returns for FTEC, Forecast Period 8w: [0.04612084 0.0413718  0.04960065 0.04489682]
#
# Debug: Returns for FTEC, Forecast Period 9w: [0.04596256 0.04855618 0.04445078 0.04985379 0.0572507 ]
#
# Debug: Returns for FTEC, Forecast Period 10w: [0.05485298 0.04915281 0.0510109  0.05491067 0.04948515]
#
# Debug: Returns for FTEC, Forecast Period 11w: [0.04452741 0.04689521 0.04497108 0.04945447 0.04151507]
#
# Debug: Returns for FTEC, Forecast Period 12w: [0.04301473 0.04871298 0.0530971  0.05539535 0.05041926]
#
# Debug: Returns for FTEC, Forecast Period 13w: [0.0512213  0.04783579 0.0495393  0.0497387 ]
#
# Debug: Returns for FTEC, Forecast Period 14w: [0.04886327 0.03963099 0.03901584 0.04201259 0.04188152]
#
# Debug: Returns for FTEC, Forecast Period 15w: [0.03547451 0.04303055 0.04021611 0.04158216 0.03719864]
#
# Debug: Returns for FTEC, Forecast Period 16w: [ 0.03339054  0.03721887  0.03064362  0.02257187 -0.00692023]
#
# Debug: Returns for FTEC, Forecast Period 17w: [-0.00804392 -0.00294535  0.01400988  0.02214303  0.03002452]
#
# Debug: Returns for FTEC, Forecast Period 18w: [0.03277102 0.02143686 0.01138033 0.01363895 0.04044171]
#
# Debug: Returns for FTEC, Forecast Period 19w: [0.04136562 0.03905887 0.03902971 0.04035577 0.03701629]
#
# Debug: Returns for FTEC, Forecast Period 20w: [0.04283486 0.05221163 0.05641657 0.05672044 0.05743192]
#
# Debug: Returns for FTEC, Forecast Period 21w: [0.05655956 0.0549442  0.05786937 0.0580221  0.05731527]
#
# Debug: Returns for FTEC, Forecast Period 22w: [0.0583389  0.05776384 0.05600097 0.0569256 ]
#
# Debug: Returns for FTEC, Forecast Period 23w: [0.05587094 0.0535217  0.05662191 0.05538628 0.05529756]
#
# Debug: Returns for FTEC, Forecast Period 24w: [0.05629012 0.05782864 0.05728317 0.05790989 0.05809336]
#
# Debug: Returns for FTEC, Forecast Period 25w: [0.05899405 0.05837266 0.05704459 0.05638511]
#
# Debug: Returns for FTEC, Forecast Period 26w: [0.0518247  0.05583852 0.05493477 0.05350694 0.05357011]
#
# Debug: Returns for FTEC, Forecast Period 27w: [0.05771797 0.05770518 0.05722696 0.05681321]
#
# Debug: Returns for FTEC, Forecast Period 28w: [0.0584576  0.05854176 0.0581577  0.05668918 0.05773056]
#
# Debug: Returns for FTEC, Forecast Period 29w: [0.05453443 0.05390612 0.04717402 0.0400681  0.03344356]
#
# Debug: Returns for FTEC, Forecast Period 30w: [0.04429003 0.043654   0.04682687 0.03098447 0.0360027 ]
#
# Debug: Returns for FTEC, Forecast Period 31w: [ 0.03006127  0.01005952  0.03510125 -0.00719679 -0.00763397]
#
# Debug: Returns for FTEC, Forecast Period 32w: [ 0.0027624   0.00564688  0.00745693 -0.00321911 -0.01073022]
#
# Debug: Returns for FTEC, Forecast Period 33w: [-0.01016804 -0.01041182 -0.00914457  0.03578347  0.03590197]
#
# Debug: Returns for FTEC, Forecast Period 34w: [0.04347    0.03874106 0.04099767 0.04388864 0.05243604]
#
# Debug: Returns for FTEC, Forecast Period 35w: [0.04673374 0.04889383 0.04949158 0.03840622 0.05280523]
#
# Debug: Returns for FTEC, Forecast Period 36w: [0.04728981 0.05237301 0.05044209 0.04745766]
#
# Debug: Returns for FTEC, Forecast Period 37w: [0.04443555 0.04515323 0.05105167 0.04543834 0.04546908]
#
# Debug: Returns for FTEC, Forecast Period 38w: [0.03617084 0.03730384 0.03101581 0.04085501 0.03803413]
#
# Debug: Returns for FTEC, Forecast Period 39w: [0.04205329 0.04116049 0.04323082 0.04699798 0.0474356 ]
#
# Debug: Returns for FTEC, Forecast Period 40w: [0.05092369 0.03958572 0.05385062 0.05522668 0.05736269]
#
# Debug: Returns for FTEC, Forecast Period 41w: [0.05799107 0.05832016 0.05875816 0.05672566 0.05615982]
#
# Debug: Returns for FTEC, Forecast Period 42w: [0.05713468 0.05376474 0.05504655 0.05675546 0.05276784]
#
# Debug: Returns for FTEC, Forecast Period 43w: [0.05434644 0.05363934 0.0497609  0.05004064 0.0491168 ]
#
# Debug: Returns for FTEC, Forecast Period 44w: [0.05034131 0.05221791 0.05272366 0.04698476 0.04708447]
#
# Debug: Returns for FTEC, Forecast Period 45w: [0.04237506 0.04912229 0.0521924  0.05394742 0.05276417]
#
# Debug: Returns for FTEC, Forecast Period 46w: [0.05141097 0.04925238 0.05150257 0.05020722 0.04218867]
#
# Debug: Returns for FTEC, Forecast Period 47w: [0.04161653 0.04317322 0.04359458 0.05212583 0.0515573 ]
#
# Debug: Returns for FTEC, Forecast Period 48w: [0.05054552 0.05097064 0.04629593 0.05114231]
#
# Debug: Returns for IGM, Forecast Period 1w: [0.03649708 0.03586805 0.03575871 0.03641132]
#
# Debug: Returns for IGM, Forecast Period 2w: [0.04260304 0.03821285 0.03975449 0.04059319 0.04080815]
#
# Debug: Returns for IGM, Forecast Period 3w: [0.04049914 0.03957479 0.04078994 0.04254966]
#
# Debug: Returns for IGM, Forecast Period 4w: [0.04321576 0.04347112 0.04341774 0.04404851 0.04353504]
#
# Debug: Returns for IGM, Forecast Period 5w: [0.04377903 0.04367416 0.04008273 0.04447942 0.04690561]
#
# Debug: Returns for IGM, Forecast Period 6w: [0.04026417 0.03940704 0.0444891  0.04174684 0.04351214]
#
# Debug: Returns for IGM, Forecast Period 7w: [0.03944394 0.03671903 0.04451311 0.04010154 0.03768148]
#
# Debug: Returns for IGM, Forecast Period 8w: [0.03986958 0.03951427 0.05039497 0.04086599]
#
# Debug: Returns for IGM, Forecast Period 9w: [0.04129913 0.04098525 0.03991107 0.0429705  0.04638539]
#
# Debug: Returns for IGM, Forecast Period 10w: [0.03998629 0.03929888 0.04296185 0.0457741  0.04052456]
#
# Debug: Returns for IGM, Forecast Period 11w: [0.04179437 0.04633595 0.04183526 0.04229808 0.04097379]
#
# Debug: Returns for IGM, Forecast Period 12w: [0.04350379 0.04374515 0.04520869 0.04024467 0.04105083]
#
# Debug: Returns for IGM, Forecast Period 13w: [0.04006615 0.03967609 0.03924418 0.03785562]
#
# Debug: Returns for IGM, Forecast Period 14w: [0.03852705 0.0386736  0.03852896 0.03879318 0.03858946]
#
# Debug: Returns for IGM, Forecast Period 15w: [0.03848636 0.03946967 0.03938763 0.03958286 0.03925817]
#
# Debug: Returns for IGM, Forecast Period 16w: [0.03646957 0.03849278 0.03496411 0.03330383 0.01371758]
#
# Debug: Returns for IGM, Forecast Period 17w: [0.0224448  0.02907551 0.03011571 0.02640254 0.03408118]
#
# Debug: Returns for IGM, Forecast Period 18w: [0.03418394 0.02208957 0.02222937 0.02917349 0.03919635]
#
# Debug: Returns for IGM, Forecast Period 19w: [0.04012509 0.04022334 0.03921524 0.03984589 0.03788867]
#
# Debug: Returns for IGM, Forecast Period 20w: [0.0399189  0.04112659 0.04558216 0.04007196 0.04067018]
#
# Debug: Returns for IGM, Forecast Period 21w: [0.04266611 0.04055847 0.04082987 0.04106255 0.04472117]
#
# Debug: Returns for IGM, Forecast Period 22w: [0.04331195 0.04042238 0.03836161 0.0427026 ]
#
# Debug: Returns for IGM, Forecast Period 23w: [0.0443524  0.04457628 0.04959249 0.04514252 0.04495546]
#
# Debug: Returns for IGM, Forecast Period 24w: [0.04512363 0.04546715 0.04745233 0.04437249 0.04576613]
#
# Debug: Returns for IGM, Forecast Period 25w: [0.04586354 0.04418469 0.04421149 0.04407785]
#
# Debug: Returns for IGM, Forecast Period 26w: [0.04313161 0.04591931 0.04353416 0.04421365 0.04489394]
#
# Debug: Returns for IGM, Forecast Period 27w: [0.04625579 0.04538814 0.04495218 0.04429299]
#
# Debug: Returns for IGM, Forecast Period 28w: [0.04419126 0.04235704 0.04223864 0.03999698 0.04030454]
#
# Debug: Returns for IGM, Forecast Period 29w: [0.04037736 0.03977755 0.041648   0.03982003 0.03776185]
#
# Debug: Returns for IGM, Forecast Period 30w: [0.04028179 0.04094264 0.03542018 0.0301106  0.03394511]
#
# Debug: Returns for IGM, Forecast Period 31w: [0.03109141 0.02351028 0.03223475 0.01942559 0.00668673]
#
# Debug: Returns for IGM, Forecast Period 32w: [-0.00333067  0.00556706  0.00075522  0.01218972  0.01237479]
#
# Debug: Returns for IGM, Forecast Period 33w: [0.0105675  0.01905651 0.01788615 0.04287656 0.04360741]
#
# Debug: Returns for IGM, Forecast Period 34w: [0.04842634 0.04367722 0.04505376 0.04548234 0.04874816]
#
# Debug: Returns for IGM, Forecast Period 35w: [0.04610652 0.04748935 0.04450542 0.04562388 0.04776305]
#
# Debug: Returns for IGM, Forecast Period 36w: [0.03926803 0.04302461 0.04404498 0.03915464]
#
# Debug: Returns for IGM, Forecast Period 37w: [0.04496655 0.04580586 0.05028638 0.04892932 0.04931471]
#
# Debug: Returns for IGM, Forecast Period 38w: [0.04418758 0.04409456 0.03974896 0.04800956 0.04610872]
#
# Debug: Returns for IGM, Forecast Period 39w: [0.0477862  0.04677754 0.04692037 0.04845362 0.04657184]
#
# Debug: Returns for IGM, Forecast Period 40w: [0.04676152 0.0453673  0.04606014 0.04504731 0.04547551]
#
# Debug: Returns for IGM, Forecast Period 41w: [0.0391748  0.04535829 0.04338499 0.04570826 0.04681067]
#
# Debug: Returns for IGM, Forecast Period 42w: [0.04657055 0.04493799 0.04476205 0.04265284 0.04318602]
#
# Debug: Returns for IGM, Forecast Period 43w: [0.04231807 0.04180515 0.04293667 0.04180476 0.0419163 ]
#
# Debug: Returns for IGM, Forecast Period 44w: [0.04151218 0.04148215 0.04040129 0.04277846 0.04082643]
#
# Debug: Returns for IGM, Forecast Period 45w: [0.04091778 0.04017603 0.04297727 0.04345636 0.04161283]
#
# Debug: Returns for IGM, Forecast Period 46w: [0.04144758 0.04158207 0.04067803 0.04072973 0.04252743]
#
# Debug: Returns for IGM, Forecast Period 47w: [0.04156916 0.04165846 0.04167812 0.04146143 0.04067676]
#
# Debug: Returns for IGM, Forecast Period 48w: [0.04069608 0.04004424 0.04156635 0.03979038]
#
# Debug: Returns for IXN, Forecast Period 1w: [-0.0571769  -0.05522096 -0.05324523 -0.05243321]
#
# Debug: Returns for IXN, Forecast Period 2w: [-0.04441661 -0.04934105 -0.04903488 -0.05060289 -0.04980699]
#
# Debug: Returns for IXN, Forecast Period 3w: [-0.04656878 -0.05400863 -0.04316359 -0.0404882 ]
#
# Debug: Returns for IXN, Forecast Period 4w: [-0.043934   -0.0403836  -0.04030479 -0.03181229 -0.04970245]
#
# Debug: Returns for IXN, Forecast Period 5w: [-0.0419704  -0.04796249 -0.06084291 -0.03562437 -0.02933335]
#
# Debug: Returns for IXN, Forecast Period 6w: [-0.02715747 -0.03088839 -0.03075881 -0.02894015 -0.02788189]
#
# Debug: Returns for IXN, Forecast Period 7w: [-0.0209302  -0.04697135 -0.0354461  -0.03239078 -0.04240867]
#
# Debug: Returns for IXN, Forecast Period 8w: [-0.05586079 -0.05814736 -0.04814504 -0.05379028]
#
# Debug: Returns for IXN, Forecast Period 9w: [-0.05469315 -0.05155015 -0.05422369 -0.04954133 -0.03496485]
#
# Debug: Returns for IXN, Forecast Period 10w: [-0.03864306 -0.05730399 -0.04976888 -0.04263445 -0.05915916]
#
# Debug: Returns for IXN, Forecast Period 11w: [-0.06006164 -0.05026062 -0.05939582 -0.04935627 -0.06480473]
#
# Debug: Returns for IXN, Forecast Period 12w: [-0.05463593 -0.05044743 -0.04050388 -0.03984611 -0.05074507]
#
# Debug: Returns for IXN, Forecast Period 13w: [-0.0527179  -0.054759   -0.05311019 -0.05205771]
#
# Debug: Returns for IXN, Forecast Period 14w: [-0.05527719 -0.06144503 -0.05887331 -0.06642026 -0.05573295]
#
# Debug: Returns for IXN, Forecast Period 15w: [-0.06350233 -0.0567043  -0.06513734 -0.05207765 -0.07053428]
#
# Debug: Returns for IXN, Forecast Period 16w: [-0.06989534 -0.06184149 -0.0664851  -0.05882177 -0.04357248]
#
# Debug: Returns for IXN, Forecast Period 17w: [-0.04204152 -0.04326048 -0.04742345 -0.04972304 -0.04954771]
#
# Debug: Returns for IXN, Forecast Period 18w: [-0.0562133  -0.04927372 -0.04679301 -0.04430459 -0.04138407]
#
# Debug: Returns for IXN, Forecast Period 19w: [-0.05198865 -0.06362574 -0.06116737 -0.06317032 -0.06323855]
#
# Debug: Returns for IXN, Forecast Period 20w: [-0.05856744 -0.04952948 -0.04185473 -0.04237666 -0.0413594 ]
#
# Debug: Returns for IXN, Forecast Period 21w: [-0.02276437 -0.02853077 -0.03162027 -0.03230397 -0.02841464]
#
# Debug: Returns for IXN, Forecast Period 22w: [-0.03037934 -0.03677672 -0.0437017  -0.03410849]
#
# Debug: Returns for IXN, Forecast Period 23w: [-0.03128649 -0.04042338 -0.03460308 -0.03788589 -0.03701941]
#
# Debug: Returns for IXN, Forecast Period 24w: [-0.03575293 -0.03190977 -0.01909709 -0.02349275 -0.03268825]
#
# Debug: Returns for IXN, Forecast Period 25w: [-0.02543786 -0.02087873 -0.03412836 -0.03577517]
#
# Debug: Returns for IXN, Forecast Period 26w: [-0.0486072  -0.03503976 -0.03873093 -0.041561   -0.03954985]
#
# Debug: Returns for IXN, Forecast Period 27w: [-0.02821653 -0.02463416 -0.02283039 -0.02146573]
#
# Debug: Returns for IXN, Forecast Period 28w: [-0.03093082 -0.03074265 -0.0240562  -0.04405303 -0.0375927 ]
#
# Debug: Returns for IXN, Forecast Period 29w: [-0.04655388 -0.05021349 -0.07204813 -0.06669758 -0.06102401]
#
# Debug: Returns for IXN, Forecast Period 30w: [-0.05286669 -0.06313148 -0.05546768 -0.04241818 -0.03879029]
#
# Debug: Returns for IXN, Forecast Period 31w: [-0.04138536 -0.03709415 -0.01919119 -0.03061622 -0.02990355]
#
# Debug: Returns for IXN, Forecast Period 32w: [-0.03613925 -0.03087894 -0.03419969 -0.02290759 -0.02744831]
#
# Debug: Returns for IXN, Forecast Period 33w: [-0.02815834 -0.0180155  -0.02793185 -0.02690475 -0.02774286]
#
# Debug: Returns for IXN, Forecast Period 34w: [-0.02928673 -0.04048863 -0.04651292 -0.04419317 -0.03365542]
#
# Debug: Returns for IXN, Forecast Period 35w: [-0.04249205 -0.03403961 -0.0377393  -0.04444391 -0.03269501]
#
# Debug: Returns for IXN, Forecast Period 36w: [-0.04532517 -0.02945026 -0.03002169 -0.03628815]
#
# Debug: Returns for IXN, Forecast Period 37w: [-0.02647718 -0.02657902 -0.02392951 -0.02248999 -0.02235912]
#
# Debug: Returns for IXN, Forecast Period 38w: [-0.03094886 -0.03458959 -0.04012578 -0.03227904 -0.05262852]
#
# Debug: Returns for IXN, Forecast Period 39w: [-0.04860606 -0.05271756 -0.05372999 -0.04513129 -0.05509873]
#
# Debug: Returns for IXN, Forecast Period 40w: [-0.0495817  -0.05976531 -0.04122253 -0.0425685  -0.03897509]
#
# Debug: Returns for IXN, Forecast Period 41w: [-0.04000404 -0.03532034 -0.03717837 -0.05129903 -0.05134911]
#
# Debug: Returns for IXN, Forecast Period 42w: [-0.04680733 -0.05873854 -0.05486901 -0.05161192 -0.06000765]
#
# Debug: Returns for IXN, Forecast Period 43w: [-0.05600062 -0.05731987 -0.0692068  -0.06106299 -0.06194661]
#
# Debug: Returns for IXN, Forecast Period 44w: [-0.06192302 -0.05538072 -0.06054789 -0.07320051 -0.06167491]
#
# Debug: Returns for IXN, Forecast Period 45w: [-0.06589153 -0.05586452 -0.05525074 -0.05533382 -0.061892  ]
#
# Debug: Returns for IXN, Forecast Period 46w: [-0.06662058 -0.06441434 -0.06055688 -0.05966744 -0.07444143]
#
# Debug: Returns for IXN, Forecast Period 47w: [-0.06387575 -0.06343672 -0.06712534 -0.05949511 -0.06102977]
#
# Debug: Returns for IXN, Forecast Period 48w: [-0.06210718 -0.06263849 -0.06798652 -0.0608609 ]

# %%
# Initialize an empty dictionary to hold DataFrames for each week
weekly_scores_dfs = {}

# Assuming weekly_scores is a dictionary with keys as week identifiers ('1w', '2w', ..., '48w') 
# and values as the respective scores
for week_key, scores in weekly_scores.items():
    # Convert scores for the current week into a DataFrame
    weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    
# Create DataFrame variables dynamically for 48 weeks
for week in range(1, 49):
    week_key = f'{week}w'
    globals()[f'df_scores_{week_key}'] = weekly_scores_dfs.get(week_key, pd.DataFrame())

# %%
# Initialize a dictionary to hold the top 2 ETFs for each week
top_etfs_weekly = {}

# Loop through the weekly DataFrames and select the top 2 ETFs for each week
for week_key, df_scores in weekly_scores_dfs.items():
    # Select the top 2 ETFs based on the 'Score' column
    top_etfs_weekly[week_key] = df_scores.nlargest(2, 'SmoothedScore')
    
    # Print the results for the current week
    print(f"\nTop 2 ETFs for {week_key} forecast:")
    print(top_etfs_weekly[week_key])
# Out:
# Top 2 ETFs for 1w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM   1w             0.1  7.991462       1.296970
# 9  IXN   1w             0.1 -4.509046       0.135767
#
# Top 2 ETFs for 2w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM   2w             0.1  5.403989       1.018020
# 7  FTEC   2w             0.1  4.648313      -0.078472
#
# Top 2 ETFs for 3w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM   3w             0.1   4.73923       0.864945
# 1  SOXX   3w             0.1   3.79871       0.310958
#
# Top 2 ETFs for 4w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM   4w             0.1  5.752882       0.700868
# 9  IXN   4w             0.1 -0.912540       0.378186
#
# Top 2 ETFs for 5w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM   5w             0.1  4.634972       0.720633
# 9  IXN   5w             0.1 -3.277212      -0.078936
#
# Top 2 ETFs for 6w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM   6w             0.1  3.260157       1.072713
# 7  FTEC   6w             0.1  5.852318       0.525852
#
# Top 2 ETFs for 7w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM   7w             0.1  2.853757       0.552768
# 1  SOXX   7w             0.1  5.228136       0.308866
#
# Top 2 ETFs for 8w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM   8w             0.1  4.778419       1.119275
# 7  FTEC   8w             0.1  7.324194       0.204489
#
# Top 2 ETFs for 9w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM   9w             0.1  3.517560       0.545808
# 7  FTEC   9w             0.1  3.935213      -0.197130
#
# Top 2 ETFs for 10w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  10w             0.1  2.487359       0.712016
# 7  FTEC  10w             0.1  6.142237       0.268180
#
# Top 2 ETFs for 11w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  11w             0.1  3.992553       0.730974
# 9  IXN  11w             0.1 -2.435494       0.097680
#
# Top 2 ETFs for 12w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  12w             0.1  4.349683       0.515567
# 9  IXN  12w             0.1 -3.561498      -0.299846
#
# Top 2 ETFs for 13w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  13w             0.1  2.891520       0.728188
# 7  FTEC  13w             0.1  5.333277       0.187355
#
# Top 2 ETFs for 14w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  14w             0.1  6.346663       0.853853
# 9  IXN  14w             0.1 -3.215331       0.040016
#
# Top 2 ETFs for 15w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  15w             0.1  3.640377       0.517273
# 9  IXN  15w             0.1 -2.227500      -0.031681
#
# Top 2 ETFs for 16w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 1  SOXX  16w             0.1  3.883153       1.387049
# 2   PSI  16w             0.1 -0.150163       1.079607
#
# Top 2 ETFs for 17w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 1  SOXX  17w             0.1  3.339304       1.387922
# 2   PSI  17w             0.1  0.243960       1.159129
#
# Top 2 ETFs for 18w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  18w             0.1  5.050912       1.101575
# 7  FTEC  18w             0.1  5.056241       0.114240
#
# Top 2 ETFs for 19w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  19w             0.1  4.373103       1.057945
# 1  SOXX  19w             0.1  2.647870       0.922624
#
# Top 2 ETFs for 20w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  20w             0.1  6.600452       1.218915
# 9  IXN  20w             0.1 -4.177666       0.139599
#
# Top 2 ETFs for 21w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  21w             0.1  4.151958       1.063739
# 7  FTEC  21w             0.1  6.274315       0.291684
#
# Top 2 ETFs for 22w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  22w             0.1  3.435724       0.840019
# 7  FTEC  22w             0.1  5.235840       0.191093
#
# Top 2 ETFs for 23w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  23w             0.1  2.916804       1.013349
# 7  FTEC  23w             0.1  7.489546       0.537485
#
# Top 2 ETFs for 24w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  24w             0.1  5.712112       1.278813
# 9  IXN  24w             0.1 -3.813598       0.260331
#
# Top 2 ETFs for 25w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  25w             0.1  4.989730       0.789074
# 9  IXN  25w             0.1 -3.366439      -0.042029
#
# Top 2 ETFs for 26w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  26w             0.1  6.563224       1.065195
# 9  IXN  26w             0.1 -3.386652       0.174826
#
# Top 2 ETFs for 27w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  27w             0.1  3.021358       0.880833
# 7  FTEC  27w             0.1  5.486073       0.345701
#
# Top 2 ETFs for 28w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  28w             0.1  1.624495       0.719924
# 7  FTEC  28w             0.1  5.385580       0.493781
#
# Top 2 ETFs for 29w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  29w             0.1  5.976173       0.948303
# 1  SOXX  29w             0.1  2.138676       0.023184
#
# Top 2 ETFs for 30w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  30w             0.1  3.393360       1.099698
# 1  SOXX  30w             0.1  1.652302       0.666819
#
# Top 2 ETFs for 31w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  31w             0.1  5.327746       0.745163
# 9  IXN  31w             0.1 -4.642712      -0.332412
#
# Top 2 ETFs for 32w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 5  XLK  32w             0.1  0.518377       0.414630
# 4  IYW  32w             0.1  7.418100       0.388693
#
# Top 2 ETFs for 33w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 1  SOXX  33w             0.1  3.270791       0.781324
# 2   PSI  33w             0.1 -0.822050       0.460649
#
# Top 2 ETFs for 34w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  34w             0.1  5.973798       0.982578
# 9  IXN  34w             0.1 -4.255679      -0.065073
#
# Top 2 ETFs for 35w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  35w             0.1  5.531497       1.132219
# 9  IXN  35w             0.1 -1.758223       0.554130
#
# Top 2 ETFs for 36w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  36w             0.1  5.797093       1.166780
# 9  IXN  36w             0.1 -3.000674       0.333289
#
# Top 2 ETFs for 37w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  37w             0.1  4.309531       1.042898
# 7  FTEC  37w             0.1  5.212374       0.226239
#
# Top 2 ETFs for 38w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  38w             0.1  5.318994       1.084746
# 9  IXN  38w             0.1 -3.818354       0.104126
#
# Top 2 ETFs for 39w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  39w             0.1  7.343838       0.937725
# 9  IXN  39w             0.1 -2.001111       0.349958
#
# Top 2 ETFs for 40w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  40w             0.1  7.070314       1.012314
# 9  IXN  40w             0.1 -3.442521       0.121347
#
# Top 2 ETFs for 41w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  41w             0.1  3.820831       0.744041
# 7  FTEC  41w             0.1  4.410019      -0.025156
#
# Top 2 ETFs for 42w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  42w             0.1  2.016471       0.707706
# 7  FTEC  42w             0.1  6.404977       0.380514
#
# Top 2 ETFs for 43w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  43w             0.1  7.571526       0.912436
# 9  IXN  43w             0.1 -2.903385       0.149271
#
# Top 2 ETFs for 44w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  44w             0.1  7.753423       1.317612
# 9  IXN  44w             0.1 -3.553136       0.343462
#
# Top 2 ETFs for 45w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  45w             0.1  4.817903       0.866558
# 9  IXN  45w             0.1 -3.374447       0.018357
#
# Top 2 ETFs for 46w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  46w             0.1  5.475384       0.996834
# 1  SOXX  46w             0.1  2.591518       0.825385
#
# Top 2 ETFs for 47w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  47w             0.1  5.436153       0.785515
# 9  IXN  47w             0.1 -3.123031       0.003806
#
# Top 2 ETFs for 48w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  48w             0.1  6.589408       1.097710
# 9  IXN  48w             0.1 -3.574751       0.163218

# %%
# Function to generate week ranges
def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []
    
    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)
    
    return week_ranges

# Function to gather ETF data for weeks
def gather_etf_data_for_weeks(tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date)
            if etf_data.empty:
                print(f"No data found for {ticker} in {week}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[week][ticker] = etf_data
            #print(f"Data for {ticker} in {week} gathered.")
    return etf_histories

# Function to initialize shares for the first week
def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]
    
    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)
        
        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]
            
            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st week: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares

# Function to manage ETF portfolio weekly
def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

# %%
# Generate Week Ranges
week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')
#print("Generated Week Ranges:", week_ranges)

# Assuming `tickers` is a list of ETF tickers
tickers = tickers

# Gather ETF Data
etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)
#print(f"ETF Histories Collected for {len(etf_histories)} weeks")

# Create a mapping between week numbers and date ranges
week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

# Debug: Print the week key mapping
print("Week Key Mapping:", week_key_mapping)

# Align `top_etfs_weekly` Keys with `etf_histories`
aligned_top_etfs_weekly = {}

for week_key, df_scores in weekly_scores_dfs.items():
    # Call the `select_top_etfs_weekly` function here
    forecast_period = week_key_mapping.get(week_key, None)
    if forecast_period:
        aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

# Portfolio initialization and management
ticker_shares = {}
ticker_shares_per_week = {}

for i, week_range in enumerate(etf_histories.keys()):
    current_week_key = week_range
    if i == 0:
        # First week initialization
        ticker_shares = initialize_shares_for_first_week(
            aligned_top_etfs_weekly[current_week_key],
            etf_histories,
            current_week_key
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()
    else:
        # Subsequent weeks' portfolio management
        prev_week_key = list(etf_histories.keys())[i - 1]
        ticker_shares = manage_etf_portfolio_weekly(
            aligned_top_etfs_weekly[prev_week_key],
            aligned_top_etfs_weekly[current_week_key],
            prev_week_key,
            current_week_key,
            ticker_shares,
            etf_histories
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()

print("\nFinal Ticker Shares per Week:")
for week, shares in ticker_shares_per_week.items():
    print(f"Week {week}: {shares}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Week Key Mapping: {'1w': '2024-01-01 to 2024-01-07', '2w': '2024-01-08 to 2024-01-14', '3w': '2024-01-15 to 2024-01-21', '4w': '2024-01-22 to 2024-01-28', '5w': '2024-01-29 to 2024-02-04', '6w': '2024-02-05 to 2024-02-11', '7w': '2024-02-12 to 2024-02-18', '8w': '2024-02-19 to 2024-02-25', '9w': '2024-02-26 to 2024-03-03', '10w': '2024-03-04 to 2024-03-10', '11w': '2024-03-11 to 2024-03-17', '12w': '2024-03-18 to 2024-03-24', '13w': '2024-03-25 to 2024-03-31', '14w': '2024-04-01 to 2024-04-07', '15w': '2024-04-08 to 2024-04-14', '16w': '2024-04-15 to 2024-04-21', '17w': '2024-04-22 to 2024-04-28', '18w': '2024-04-29 to 2024-05-05', '19w': '2024-05-06 to 2024-05-12', '20w': '2024-05-13 to 2024-05-19', '21w': '2024-05-20 to 2024-05-26', '22w': '2024-05-27 to 2024-06-02', '23w': '2024-06-03 to 2024-06-09', '24w': '2024-06-10 to 2024-06-16', '25w': '2024-06-17 to 2024-06-23', '26w': '2024-06-24 to 2024-06-30', '27w': '2024-07-01 to 2024-07-07', '28w': '2024-07-08 to 2024-07-14', '29w': '2024-07-15 to 2024-07-21', '30w': '2024-07-22 to 2024-07-28', '31w': '2024-07-29 to 2024-08-04', '32w': '2024-08-05 to 2024-08-11', '33w': '2024-08-12 to 2024-08-18', '34w': '2024-08-19 to 2024-08-25', '35w': '2024-08-26 to 2024-09-01', '36w': '2024-09-02 to 2024-09-08', '37w': '2024-09-09 to 2024-09-15', '38w': '2024-09-16 to 2024-09-22', '39w': '2024-09-23 to 2024-09-29', '40w': '2024-09-30 to 2024-10-06', '41w': '2024-10-07 to 2024-10-13', '42w': '2024-10-14 to 2024-10-20', '43w': '2024-10-21 to 2024-10-27', '44w': '2024-10-28 to 2024-11-03', '45w': '2024-11-04 to 2024-11-10', '46w': '2024-11-11 to 2024-11-17', '47w': '2024-11-18 to 2024-11-24', '48w': '2024-11-25 to 2024-12-01'}
# Shares 1st week: (50000 * 0.975) / 72.7249984741211
# Ticker: IGM, First trading day: 2024-01-02, Price: 72.7249984741211, Shares: 670.33
# Shares 1st week: (50000 * 0.975) / 66.30999755859375
# Ticker: IXN, First trading day: 2024-01-02, Price: 66.30999755859375, Shares: 735.18
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['IGM', 'IXN']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'FTEC']
# Sell IXN: 735.18 shares at 66.77. Total value: 47860.98
# Buy FTEC: 331.75 shares at 140.66.
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'IGM': 670.3334619848428, 'FTEC': 331.7535428969406}
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['IGM', 'SOXX']
# Sell FTEC: 331.75 shares at 143.25. Total value: 46335.60
# Buy SOXX: 239.76 shares at 188.43.
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'IGM': 670.3334619848428, 'SOXX': 239.75595358700815}
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IXN']
# Sell SOXX: 239.76 shares at 201.07. Total value: 47001.76
# Buy IXN: 647.64 shares at 70.76.
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'IGM': 670.3334619848428, 'IXN': 647.6358337665005}
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IXN']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'IXN']
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'IGM': 670.3334619848428, 'IXN': 647.6358337665005}
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'IXN']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['IGM', 'FTEC']
# Sell IXN: 647.64 shares at 71.68. Total value: 45261.97
# Buy FTEC: 293.77 shares at 150.22.
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'IGM': 670.3334619848428, 'FTEC': 293.7719587990425}
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['IGM', 'SOXX']
# Sell FTEC: 293.77 shares at 153.91. Total value: 44084.08
# Buy SOXX: 205.23 shares at 209.43.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'IGM': 670.3334619848428, 'SOXX': 205.23316440845673}
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['IGM', 'FTEC']
# Sell SOXX: 205.23 shares at 204.87. Total value: 40994.30
# Buy FTEC: 267.44 shares at 149.45.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'

# Updated ticker shares after 2024-07-15 to 2024-07-21: {'IGM': 616.9530567193484, 'SOXX': 106.96475437323136}
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['IGM', 'SOXX']
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'IGM': 616.9530567193484, 'SOXX': 106.96475437323136}
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IGM', 'IXN']
# Sell SOXX: 106.96 shares at 228.89. Total value: 23871.08
# Buy IXN: 294.95 shares at 78.91.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'IGM': 616.9530567193484, 'IXN': 294.9474760044958}
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IGM', 'IXN']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['XLK', 'IYW']
# Sell IGM: 616.95 shares at 84.03. Total value: 50546.50
# Buy XLK: 249.03 shares at 197.90.
# Sell IXN: 294.95 shares at 73.00. Total value: 20992.89
# Buy IYW: 153.53 shares at 133.32.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'XLK': 249.0290019994396, 'IYW': 153.52582744560263}
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['XLK', 'IYW']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SOXX', 'PSI']
# Sell XLK: 249.03 shares at 207.31. Total value: 50335.55
# Buy SOXX: 230.41 shares at 213.00.
# Sell IYW: 153.53 shares at 139.66. Total value: 20905.38
# Buy PSI: 384.15 shares at 53.06.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'SOXX': 230.40919287708704, 'PSI': 384.14525255538064}
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SOXX', 'PSI']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['IGM', 'IXN']
# Sell SOXX: 230.41 shares at 235.16. Total value: 52828.45
# Buy IGM: 547.72 shares at 94.04.
# Sell PSI: 384.15 shares at 58.30. Total value: 21835.78
# Buy IXN: 256.78 shares at 82.91.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'IGM': 547.7215993079312, 'IXN': 256.7830284217036}
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['IGM', 'IXN']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['IGM', 'IXN']
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'IGM': 547.7215993079312, 'IXN': 256.7830284217036}
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'IXN']
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'IGM': 547.7215993079312, 'IXN': 256.7830284217036}
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['IGM', 'FTEC']
# Sell IXN: 256.78 shares at 76.29. Total value: 19100.23
# Buy FTEC: 116.00 shares at 160.54.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'IGM': 547.7215993079312, 'FTEC': 116.00051771799801}
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IXN']
# Sell FTEC: 116.00 shares at 168.10. Total value: 19012.20
# Buy IXN: 230.87 shares at 80.29.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'IGM': 547.7215993079312, 'IXN': 230.8742115213565}
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['IGM', 'IXN']
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'IGM': 547.7215993079312, 'IXN': 230.8742115213565}
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IXN']
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'IGM': 547.7215993079312, 'IXN': 230.8742115213565}
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IXN']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['IGM', 'FTEC']
# Sell IXN: 230.87 shares at 81.20. Total value: 18278.31
# Buy FTEC: 103.13 shares at 172.81.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'IGM': 547.7215993079312, 'FTEC': 103.12686259465764}
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IGM', 'FTEC']
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'IGM': 547.7215993079312, 'FTEC': 103.12686259465764}
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['IGM', 'IXN']
# Sell FTEC: 103.13 shares at 180.45. Total value: 18144.01
# Buy IXN: 210.58 shares at 84.01.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'IGM': 547.7215993079312, 'IXN': 210.57505374243343}
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['IGM', 'IXN']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IXN']
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'IGM': 547.7215993079312, 'IXN': 210.57505374243343}
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IXN']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['IGM', 'IXN']
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'IGM': 547.7215993079312, 'IXN': 210.57505374243343}
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['IGM', 'IXN']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IGM', 'SOXX']
# Sell IXN: 210.58 shares at 83.99. Total value: 17244.04
# Buy SOXX: 74.54 shares at 225.57.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'IGM': 547.7215993079312, 'SOXX': 74.53536253191281}
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IGM', 'SOXX']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['IGM', 'IXN']
# Sell SOXX: 74.54 shares at 213.94. Total value: 15547.44
# Buy IXN: 184.19 shares at 82.30.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'IGM': 547.7215993079312, 'IXN': 184.18902317888325}
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['IGM', 'IXN']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['IGM', 'IXN']
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'
# Week 2024-07-29 to 2024-08-04: {'IGM': 616.9530567193484, 'IXN': 294.9474760044958}
# Week 2024-08-05 to 2024-08-11: {'XLK': 249.0290019994396, 'IYW': 153.52582744560263}
# Week 2024-08-12 to 2024-08-18: {'SOXX': 230.40919287708704, 'PSI': 384.14525255538064}
# Week 2024-08-19 to 2024-08-25: {'IGM': 547.7215993079312, 'IXN': 256.7830284217036}
# Week 2024-08-26 to 2024-09-01: {'IGM': 547.7215993079312, 'IXN': 256.7830284217036}
# Week 2024-09-02 to 2024-09-08: {'IGM': 547.7215993079312, 'IXN': 256.7830284217036}
# Week 2024-09-09 to 2024-09-15: {'IGM': 547.7215993079312, 'FTEC': 116.00051771799801}
# Week 2024-09-16 to 2024-09-22: {'IGM': 547.7215993079312, 'IXN': 230.8742115213565}
# Week 2024-09-23 to 2024-09-29: {'IGM': 547.7215993079312, 'IXN': 230.8742115213565}
# Week 2024-09-30 to 2024-10-06: {'IGM': 547.7215993079312, 'IXN': 230.8742115213565}
# Week 2024-10-07 to 2024-10-13: {'IGM': 547.7215993079312, 'FTEC': 103.12686259465764}
# Week 2024-10-14 to 2024-10-20: {'IGM': 547.7215993079312, 'FTEC': 103.12686259465764}
# Week 2024-10-21 to 2024-10-27: {'IGM': 547.7215993079312, 'IXN': 210.57505374243343}
# Week 2024-10-28 to 2024-11-03: {'IGM': 547.7215993079312, 'IXN': 210.57505374243343}
# Week 2024-11-04 to 2024-11-10: {'IGM': 547.7215993079312, 'IXN': 210.57505374243343}
# Week 2024-11-11 to 2024-11-17: {'IGM': 547.7215993079312, 'SOXX': 74.53536253191281}
# Week 2024-11-18 to 2024-11-24: {'IGM': 547.7215993079312, 'IXN': 184.18902317888325}
# Week 2024-11-25 to 2024-12-01: {'IGM': 547.7215993079312, 'IXN': 184.18902317888325}

# %%
# Define the first trading day of the 48th week
first_trading_day_49w = '2024-12-01'  # Adjust this to match the actual start date of the 48th week

# Identify the 48th and 49th week date range keys
week_48_range = list(ticker_shares_per_week.keys())[-1]  # Last key corresponds to the 48th week
week_49_start = first_trading_day_49w  # Replace with the actual start of the 49th week
print(f"Using data for the 48th week: {week_48_range}")

print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

week_49_end = '2024-12-06'
# Initialize a dictionary to store the values of shares
etf_values_49w = {}

# Ensure 48th week data exists
if week_48_range in ticker_shares_per_week:
    # Fetch ETF shares from the 48th week
    ticker_shares_48w = ticker_shares_per_week[week_48_range]
    
    # Fetch the first trading day price of the 49th week for each ETF
    for ticker, shares in ticker_shares_48w.items():
        print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
        # Download historical data for the 49th week
        data = yf.download(ticker, start=week_49_start, end=week_49_end)
        
        if not data.empty:
            # Get the closing price of the first trading day of the 49th week
            closing_price_49w = data['Close'].iloc[0]
            # Calculate the value of the shares
            total_value = shares * closing_price_49w
            etf_values_49w[ticker] = total_value
            print(f"{ticker}: {shares:.2f} shares at {closing_price_49w:.2f} each, total value: {total_value:.2f}")
        else:
            print(f"{ticker}: No data available for the 49th week's first trading day.")
else:
    print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker IGM starting from 2024-12-01...
# IGM: 547.72 shares at 102.51 each, total value: 56146.94
# Fetching data for ticker IXN starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# IXN: 184.19 shares at 84.80 each, total value: 15619.23

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 71766.17
# IGM: 56146.94
# IXN: 15619.23

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 71766.17
# IGM: 56146.94
# IXN: 15619.23
