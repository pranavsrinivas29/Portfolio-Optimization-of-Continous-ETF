# %%
#!pip install ace_tools

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler, Normalizer
import pandas_ta as ta
from pandas.tseries.offsets import MonthEnd, BDay, Week
from itertools import product
from sklearn.metrics import mean_absolute_error


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from datetime import datetime, timedelta

# %%
# Function for loading ETF data
def data_loading(ticker_symbol, start_date, end_date):
    etf_data = yf.Ticker(ticker_symbol)
    etf_history = etf_data.history(start=start_date, end=end_date)
    etf_history.index = etf_history.index.tz_localize(None)
    return etf_history, etf_data

#Function to derive the predictor columns
def etf_predictors(etf_history,  start_date, end_date, etf_data, benchmark_ticker = '^GSPC' ):
    
    # Calculate Daily Returns
    etf_history['Daily Return'] = etf_history['Close'].pct_change()

    # Calculate 21-Day Volatility (standard deviation of daily returns, annualized)
    etf_history['Volatility'] = etf_history['Daily Return'].rolling(window=21).std() * np.sqrt(252)
    #etf_history['Volatility_ta'] = ta.volatility(etf_history['Close'], window=21, annualize=True)
   
    # Get the ETF info
    etf_info = etf_data.info

    # Retrieve the net asset value price (NAV) and total net assets
    nav_price = etf_info['navPrice']
    total_assets = etf_info['totalAssets']

    # Calculate the number of shares outstanding
    shares_outstanding = total_assets / nav_price

    # Calculate Market Capitalization for each day
    # Market Capitalization = Closing Price * Total Number of Shares Outstanding
    etf_history['Market Cap'] = etf_history['Close'] * shares_outstanding

    total_assets = etf_info['totalAssets']
    total_liabilities = etf_info.get('totalLiabilities', 0)  # Handle the case where total liabilities might not be present
    
    # Calculate Book Value per Share
    book_value_per_share = (total_assets - total_liabilities) / shares_outstanding
    
    # Calculate Price to Book (P/B) Ratio
    etf_history['P/B Ratio'] = etf_history['Close'] / book_value_per_share
    
    # Calculate 1-Month Momentum (21 trading days)
    
    etf_history['Momentum'] = ta.mom(etf_history['Close'], length=21)
    
    benchmark_data = yf.download(benchmark_ticker, start=start_date, end=end_date)
    benchmark_data['Daily Return'] = benchmark_data['Close'].pct_change()
    #benchmark_data_history = benchmark_data.dropna()
    benchmark_data.head(10)
    
    # Ensure the indices are time zone-naive
    benchmark_data.index = benchmark_data.index.tz_localize(None)
    combined_data = etf_history[['Close']].join(benchmark_data[['Close']], lsuffix='_ETF', rsuffix='_Benchmark')
    combined_data = combined_data.dropna()
    
    # Calculate rolling beta with a 30-day window
    rolling_beta_21 = rolling_beta(combined_data, window=21)

    # Add the rolling beta to the dataframe
    combined_data.loc[:, 'Rolling Beta 21-day'] = rolling_beta_21
    etf_history['Rolling Beta']=combined_data['Rolling Beta 21-day']
    
    # Calculate daily profitability
    daily_profitabilities = []
    previous_nav = None
    for index, row in etf_history.iterrows():
        current_nav = row['Close']  # Current day's NAV
        #print(current_nav)
        if previous_nav is not None:
            daily_profitability = (current_nav - previous_nav) / previous_nav * 100
            daily_profitabilities.append(daily_profitability)
        else:
            daily_profitabilities.append(None)
        previous_nav = current_nav  # Update previous_nav for the next iteration

    # Add daily profitabilities to ETF dataset
    etf_history['Daily Profitability (%)'] = daily_profitabilities
    
    # Calculate the dividend yield for each day
    dividend_yields = []

    for index, row in etf_history.iterrows():
        # Get the dividend payment for the day
        dividend_payment = row['Dividends']

        # Get the current market price of the ETF for the day
        current_price = row['Close']

        # Calculate the dividend yield for the day
        dividend_yield = (dividend_payment / current_price) * 100

        # Append the dividend yield to the list
        dividend_yields.append(dividend_yield)
      
    etf_history['Div yield'] = dividend_yields

    #Volatility
    etf_history['ATR'] = ta.atr(etf_history['High'], etf_history['Low'], etf_history['Close'], length=21)    
    
    # Compute the Relative Volatility Index (RVI)
    rvi = ta.rvi(etf_history['Close'],length=21)
    etf_history['RVI'] = rvi
    
    #Momentum
    rsi_window = 14  # Window size for RSI calculation
    roc_window = 12  # Window size for ROC calculation
    #rsi_window = 21  
    #roc_window = 21  

    

    etf_history['RSI'] = ta.rsi(etf_history['Close'],length=rsi_window)
    # Calculate Rate of Change (ROC)
    etf_history['ROC'] = ta.roc(etf_history['Close'], length=roc_window)
        
    etf_history['log_returns'] = np.log(etf_history['Close'] / etf_history['Close'].shift(1))

    return etf_history

# Function to calculate rolling beta
def rolling_beta(df, window):
    rolling_cov = df['Close_Benchmark'].rolling(window=window).cov(df['Close_ETF'])
    rolling_var = df['Close_Benchmark'].rolling(window=window).var()
    rolling_beta = rolling_cov / rolling_var
    return rolling_beta

# %%
def pre_processing(
    etf_history, 
    train_start_date,
    train_end_date,
    test_start_date,
    test_end_date,
    prediction_dates_monthly,
    prediction_dates_weekly,
    feature_columns=None,
    scaling_strategy='StandardScaler', 
    final_end_date='2024-12-01'
):
    """
    Preprocess ETF history data and prepare train/test splits along with 
    dynamically scaled forecast data for both weekly & monthly horizons,
    stored in separate dictionaries.

    Parameters
    ----------
    etf_history : pd.DataFrame
        Full historical data with at least 'log_returns' column plus other features.
    train_start_date : str
        Start date (YYYY-MM-DD) for training data.
    train_end_date : str
        End date (YYYY-MM-DD) for training data.
    test_start_date : str
        Start date (YYYY-MM-DD) for test data.
    test_end_date : str
        End date (YYYY-MM-DD) for test data.
    prediction_dates_monthly : list of str
        List of start dates for each monthly forecast window.
    prediction_dates_weekly : list of str
        List of start dates for each weekly forecast window.
    feature_columns : list of str, optional
        Columns to be used as features. If None, defaults are used.
    scaling_strategy : str, optional
        'StandardScaler' or 'Normalizer'. Defaults to 'StandardScaler'.
    final_end_date : str, optional
        The final end date (YYYY-MM-DD) for the last forecast window.
        Defaults to '2024-12-01'.

    Returns
    -------
    dict
        A dictionary containing:
        - 'train_data_scaled': np.ndarray
        - 'test_data_scaled': np.ndarray
        - 'y_train': pd.Series
        - 'y_test': pd.Series
        - 'scaler': scaler object
        - 'X': pd.DataFrame (all feature columns before splitting)
        - 'etf_history': pd.DataFrame (original data with missing values handled)
        - 'forecast_data_weekly': dict of weekly forecast DataFrame slices
        - 'forecast_data_monthly': dict of monthly forecast DataFrame slices
        - 'forecast_data_weekly_scaled': dict of scaled weekly forecast slices
        - 'forecast_data_monthly_scaled': dict of scaled monthly forecast slices
    """

    # 1. Handle missing values and infinite values
    etf_history.fillna(etf_history.median(), inplace=True)
    etf_history.replace([np.inf, -np.inf], 0, inplace=True)

    # 2. Default feature columns if none are provided
    if feature_columns is None:
        feature_columns = [
            'Volatility', 'Volume', 'Daily Return', 'Market Cap', 
            'P/B Ratio', 'Momentum', 'Rolling Beta', 
            'Daily Profitability (%)', 'ATR', 'RVI', 'RSI', 'ROC'
        ]

    # 3. Select features (X) and target (y)
    X = etf_history.loc[:, feature_columns]
    y = etf_history['log_returns']

    # 4. Split train and test data
    train_data = X.loc[train_start_date : train_end_date]
    test_data  = X.loc[test_start_date  : test_end_date]
    y_train = y.loc[train_start_date : train_end_date]
    y_test  = y.loc[test_start_date  : test_end_date]

    # 5. Initialize and fit scaler
    if scaling_strategy == 'StandardScaler':
        scaler = StandardScaler()
    elif scaling_strategy == 'Normalizer':
        scaler = Normalizer()
    else:
        raise ValueError(f"Unsupported scaling strategy: {scaling_strategy}")

    train_data_scaled = scaler.fit_transform(train_data)
    test_data_scaled  = scaler.transform(test_data)

    # 6. Create separate dictionaries for weekly and monthly
    forecast_data_weekly = {}
    forecast_data_monthly = {}

    # ---- Weekly Forecast Slices ----
    for i, start_date in enumerate(prediction_dates_weekly):
        if i < len(prediction_dates_weekly) - 1:
            weekly_end = (pd.to_datetime(start_date) + Week(1) - pd.Timedelta(days=1)).strftime('%Y-%m-%d')
        else:
            weekly_end = final_end_date
        
        w_key = f'forecast_data_{i+1}w'
        forecast_data_weekly[w_key] = X.loc[start_date : weekly_end]

    # ---- Monthly Forecast Slices ----
    for i, start_date in enumerate(prediction_dates_monthly):
        if i < len(prediction_dates_monthly) - 1:
            monthly_end = (pd.to_datetime(start_date) + MonthEnd(0)).strftime('%Y-%m-%d')
        else:
            monthly_end = final_end_date
        
        m_key = f'forecast_data_{i+1}m'
        forecast_data_monthly[m_key] = X.loc[start_date : monthly_end]

    # 7. Scale forecast data (weekly & monthly) and add intercept
    forecast_data_weekly_scaled = {}
    for period_key, period_data in forecast_data_weekly.items():
        if not period_data.empty:
            data_scaled = scaler.transform(period_data)
            forecast_data_weekly_scaled[period_key] = sm.add_constant(data_scaled)

    forecast_data_monthly_scaled = {}
    for period_key, period_data in forecast_data_monthly.items():
        if not period_data.empty:
            data_scaled = scaler.transform(period_data)
            forecast_data_monthly_scaled[period_key] = sm.add_constant(data_scaled)

    # 8. Add a constant to train and test data
    train_data_scaled = sm.add_constant(train_data_scaled)
    test_data_scaled  = sm.add_constant(test_data_scaled)

    # 9. Return all objects in a dictionary
    return {
        'train_data_scaled': train_data_scaled,
        'test_data_scaled': test_data_scaled,
        'y_train': y_train,
        'y_test': y_test,
        'scaler': scaler,
        'X': X,
        'etf_history': etf_history,
        'forecast_data_weekly': forecast_data_weekly,
        'forecast_data_monthly': forecast_data_monthly,
        'forecast_data_weekly_scaled': forecast_data_weekly_scaled,
        'forecast_data_monthly_scaled': forecast_data_monthly_scaled
    }

# %%
# Function to train the model
def model_training(train_data_scaled, y_train):
    best_model = None
    best_score = float('-inf')
    hyperparameters = {
        'cov_type': ['HC0', 'HC1'],
        'use_t': [True, False],
        'method': ['pinv', 'qr']
    }

    for params in product(*hyperparameters.values()):
        try:
            model = sm.OLS(y_train, train_data_scaled)
            fitted_model = model.fit(cov_type=params[0], use_t=params[1], method=params[2])
            if fitted_model.rsquared_adj > best_score:
                best_model = fitted_model
                best_score = fitted_model.rsquared_adj
        except Exception as e:
            print(f"Error with params {params}: {e}")

    return best_model
def eval_model(best_model,test_data_scaled,y_test,y_train):
    
    test_predictions = best_model.predict((test_data_scaled))
    mae = mean_absolute_error(y_test, test_predictions)
    # Mean Absolute Scaled Error (MASE) - Example calculation assuming seasonal period m=1
    seasonal_naive = np.roll(y_test, 1)  # Shift y_test by 1 for seasonal naive forecast
    #seasonal_mae = np.mean(np.abs(y_test - seasonal_naive))
    seasonal_mae = np.mean(np.abs(y_test[1:] - seasonal_naive[1:]))
    mase = mae / seasonal_mae

    # Mean Absolute Percentage Error (MAPE)
    #mape = np.mean(np.abs((y_test - test_predictions) / y_test)) * 100

    #n = y_test.shape[0]
    #d = np.abs(  np.diff( y_test) ).sum()/(n-1)
    
    #errors = np.abs(y_test - test_predictions )
    #mase_value = errors.mean()/d

    print("Mean Absolute Error (MAE):", mae)
    print("Mean Absolute Scaled Error (MASE):", mase)
    #print("Mean Absolute Scaled Error-2 (MASE-2):", mase_value)
    #print("Mean Absolute Percentage Error (MAPE):", mape)
    
    return mae, mase

# Function to make predictions
def predictions(model, forecast_data_scaled):
    forecast_results = {}
    for key, data in forecast_data_scaled.items():
        # Extract the index from the original forecast data
        original_index = forecast_data_scaled[key][:, 1]  # Assuming the index is preserved here
        predictions = model.predict(data)
        forecast_results[key] = pd.DataFrame(
            predictions, 
            columns=["log_returns"], 
            index=original_index
        )
    return forecast_results

# %%
"""def combined_workflow(
    tickers,
    start_date, 
    end_date, 
    train_start_date, 
    train_end_date, 
    test_start_date, 
    test_end_date,
    prediction_dates_monthly, 
    prediction_dates_weekly
):
    etf_results = {}
    
    for ticker in tickers:
        # 1. Load and preprocess data
        etf_history, etf_data = data_loading(ticker, start_date, end_date)
        etf_history = etf_predictors(etf_history, start_date, end_date, etf_data)

        # 2. Single call to pre_processing for training/testing & both forecast horizons
        preprocessed = pre_processing(
            etf_history=etf_history, 
            train_start_date=train_start_date, 
            train_end_date=train_end_date,
            test_start_date=test_start_date, 
            test_end_date=test_end_date,
            prediction_dates_monthly=prediction_dates_monthly,
            prediction_dates_weekly=prediction_dates_weekly
        )
        
        # 3. Train the model
        model = model_training(preprocessed['train_data_scaled'], preprocessed['y_train'])
        
        # 4. Evaluate the model
        mae, mase = eval_model(
            model, 
            preprocessed['test_data_scaled'], 
            preprocessed['y_test'], 
            preprocessed['y_train']
        )
        
        # 5. Generate predictions for monthly forecasts
        monthly_forecast_results = predictions(
            model, 
            preprocessed['forecast_data_monthly_scaled']
        )
        
        # 6. Generate predictions for weekly forecasts (optional)
        weekly_forecast_results = predictions(
            model, 
            preprocessed['forecast_data_weekly_scaled']
        )

        # ---------------------------------------------------------------------
        # 7. Build your final dictionary in the desired format
        # ---------------------------------------------------------------------

        # A. Basic structure
        dict_data = {
            "etf_history": etf_history,              # The full ETF dataframe (with predictors, etc.)
            "X": preprocessed["X"],                 # All feature columns used
            "y_train_values": preprocessed["y_train"],  # Training target values

            # Store model performance
            "model results": {
                "mae": mae,
                "mase": mase
            },
        }

        # B. Store monthly forecast predictions in separate keys
        #    Suppose you want up to 12 monthly periods; adjust as needed
        for i_m in range(1, 13):
            # The keys produced by predictions(...) might look like 'forecast_data_1m', 'forecast_data_2m', etc.
            forecast_key = f"forecast_data_{i_m}m"

            if forecast_key in monthly_forecast_results:
                # monthly_forecast_results[forecast_key] might be a DataFrame with 'log_returns'
                df_forecast = monthly_forecast_results[forecast_key]
                
                # e.g. store array of predicted 'log_returns' (or your final target variable)
                dict_data[f"forecast_predictions_df_{i_m}m"] = df_forecast["log_returns"].values
            
            # If a given month's key doesn't exist, you might skip it or handle differently

        # C. Store weekly forecast predictions similarly, if desired
        #    For example, suppose you do up to 48 weekly windows
        for i_w in range(1, 49):
            forecast_key = f"forecast_data_{i_w}w"
            if forecast_key in weekly_forecast_results:
                df_forecast = weekly_forecast_results[forecast_key]
                dict_data[f"forecast_predictions_df_{i_w}w"] = df_forecast["log_returns"].values

        # Finally, store this dictionary per ticker
        etf_results[ticker] = dict_data
    
    return etf_results
"""
# Out:
# 'def combined_workflow(\n    tickers,\n    start_date, \n    end_date, \n    train_start_date, \n    train_end_date, \n    test_start_date, \n    test_end_date,\n    prediction_dates_monthly, \n    prediction_dates_weekly\n):\n    etf_results = {}\n    \n    for ticker in tickers:\n        # 1. Load and preprocess data\n        etf_history, etf_data = data_loading(ticker, start_date, end_date)\n        etf_history = etf_predictors(etf_history, start_date, end_date, etf_data)\n\n        # 2. Single call to pre_processing for training/testing & both forecast horizons\n        preprocessed = pre_processing(\n            etf_history=etf_history, \n            train_start_date=train_start_date, \n            train_end_date=train_end_date,\n            test_start_date=test_start_date, \n            test_end_date=test_end_date,\n            prediction_dates_monthly=prediction_dates_monthly,\n            prediction_dates_weekly=prediction_dates_weekly\n        )\n        \n        # 3. Train the model\n        model = model_training(preprocessed[\'train_data_scaled\'], preprocessed[\'y_train\'])\n        \n        # 4. Evaluate the model\n        mae, mase = eval_model(\n            model, \n            preprocessed[\'test_data_scaled\'], \n            preprocessed[\'y_test\'], \n            preprocessed[\'y_train\']\n        )\n        \n        # 5. Generate predictions for monthly forecasts\n        monthly_forecast_results = predictions(\n            model, \n            preprocessed[\'forecast_data_monthly_scaled\']\n        )\n        \n        # 6. Generate predictions for weekly forecasts (optional)\n        weekly_forecast_results = predictions(\n            model, \n            preprocessed[\'forecast_data_weekly_scaled\']\n        )\n\n        # ---------------------------------------------------------------------\n        # 7. Build your final dictionary in the desired format\n        # ---------------------------------------------------------------------\n\n        # A. Basic structure\n        dict_data = {\n            "etf_history": etf_history,              # The full ETF dataframe (with predictors, etc.)\n            "X": preprocessed["X"],                 # All feature columns used\n            "y_train_values": preprocessed["y_train"],  # Training target values\n\n            # Store model performance\n            "model results": {\n                "mae": mae,\n                "mase": mase\n            },\n        }\n\n        # B. Store monthly forecast predictions in separate keys\n        #    Suppose you want up to 12 monthly periods; adjust as needed\n        for i_m in range(1, 13):\n            # The keys produced by predictions(...) might look like \'forecast_data_1m\', \'forecast_data_2m\', etc.\n            forecast_key = f"forecast_data_{i_m}m"\n\n            if forecast_key in monthly_forecast_results:\n                # monthly_forecast_results[forecast_key] might be a DataFrame with \'log_returns\'\n                df_forecast = monthly_forecast_results[forecast_key]\n                \n                # e.g. store array of predicted \'log_returns\' (or your final target variable)\n                dict_data[f"forecast_predictions_df_{i_m}m"] = df_forecast["log_returns"].values\n            \n            # If a given month\'s key doesn\'t exist, you might skip it or handle differently\n\n        # C. Store weekly forecast predictions similarly, if desired\n        #    For example, suppose you do up to 48 weekly windows\n        for i_w in range(1, 49):\n            forecast_key = f"forecast_data_{i_w}w"\n            if forecast_key in weekly_forecast_results:\n                df_forecast = weekly_forecast_results[forecast_key]\n                dict_data[f"forecast_predictions_df_{i_w}w"] = df_forecast["log_returns"].values\n\n        # Finally, store this dictionary per ticker\n        etf_results[ticker] = dict_data\n    \n    return etf_results\n'

# %%
def combined_workflow(
    tickers,
    start_date, 
    end_date, 
    train_start_date, 
    train_end_date, 
    test_start_date, 
    test_end_date,
    prediction_dates_monthly, 
    prediction_dates_weekly
):
    # Combine data from all ETFs for training and testing
    combined_train_X = []
    combined_train_y = []
    combined_test_X = []
    combined_test_y = []
    etf_forecast_data = {}

    for ticker in tickers:
        # 1. Load and preprocess data for each ETF
        etf_history, etf_data = data_loading(ticker, start_date, end_date)
        etf_history = etf_predictors(etf_history, start_date, end_date, etf_data)
        
        preprocessed = pre_processing(
            etf_history=etf_history, 
            train_start_date=train_start_date, 
            train_end_date=train_end_date,
            test_start_date=test_start_date, 
            test_end_date=test_end_date,
            prediction_dates_monthly=prediction_dates_monthly,
            prediction_dates_weekly=prediction_dates_weekly
        )

        # Collect combined training data
        combined_train_X.append(preprocessed['train_data_scaled'])
        combined_train_y.append(preprocessed['y_train'])

        # Collect combined testing data
        combined_test_X.append(preprocessed['test_data_scaled'])
        combined_test_y.append(preprocessed['y_test'])

        # Store forecast data for later use
        etf_forecast_data[ticker] = {
            "forecast_data_monthly_scaled": preprocessed['forecast_data_monthly_scaled'],
            "forecast_data_weekly_scaled": preprocessed['forecast_data_weekly_scaled'],
        }

    # 2. Combine all training and testing data into single datasets
    combined_train_X = np.vstack(combined_train_X)
    combined_train_y = pd.concat(combined_train_y)
    combined_test_X = np.vstack(combined_test_X)
    combined_test_y = pd.concat(combined_test_y)

    # 3. Train a single model
    model = model_training(combined_train_X, combined_train_y)

    # 4. Evaluate the model on combined test data
    mae, mase = eval_model(model, combined_test_X, combined_test_y, combined_train_y)

    print(f"Combined Testing Results:\n  - MAE: {mae}\n  - MASE: {mase}")

    # 5. Generate ETF-specific forecasts
    etf_results = {}
    for ticker, forecast_data in etf_forecast_data.items():
        # Generate predictions for monthly forecasts
        monthly_forecast_results = predictions(
            model, 
            forecast_data["forecast_data_monthly_scaled"]
        )

        # Generate predictions for weekly forecasts (optional)
        weekly_forecast_results = predictions(
            model, 
            forecast_data["forecast_data_weekly_scaled"]
        )

        # Store results
        etf_results[ticker] = {
            "model results": {
                "mae": mae,
                "mase": mase
            },
            "monthly_forecast_results": monthly_forecast_results,
            "weekly_forecast_results": weekly_forecast_results
        }

    return etf_results

# %%
import pandas as pd

# Example usage
tickers = ['SMH', 'SOXX', 'PSI', 'XSD', 'IYW', 'XLK', 'VGT', 'FTEC', 'IGM', 'IXN', 
          ]
start_date, end_date = '2000-01-01', '2024-12-01'
train_start_date, train_end_date, test_start_date, test_end_date = (
    start_date,         # train_start_date
    '2014-01-01',       # train_end_date
    '2014-01-01',       # test_start_date
    '2024-01-01'        # test_end_date
)

# Generate prediction dates for monthly & weekly
prediction_dates_monthly = pd.date_range(
    start='2024-01-01', 
    periods=12, 
    freq='MS'
).strftime('%Y-%m-%d').tolist()

prediction_dates_weekly = pd.date_range(
    start='2024-01-01', 
    periods=48, 
    freq='W-MON'
).strftime('%Y-%m-%d').tolist()

# Run the workflow
results = combined_workflow(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date,
    train_start_date=train_start_date,
    train_end_date=train_end_date,
    test_start_date=test_start_date,
    test_end_date=test_end_date,
    prediction_dates_monthly=prediction_dates_monthly,
    prediction_dates_weekly=prediction_dates_weekly
)

# The 'results' object is a dictionary keyed by ticker.
# For each ticker (e.g. 'SMH' or 'SOXX'), you can inspect:
#   results[ticker]["etf_history"]
#   results[ticker]["X"]
#   results[ticker]["y_train_values"]
#   results[ticker]["model results"]
#   results[ticker]["forecast_predictions_df_1m"], etc.
#
# Example:
# results['SMH']['forecast_predictions_df_1m']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Mean Absolute Error (MAE): 0.004517556638449712
# Mean Absolute Scaled Error (MASE): 0.2708000500447591
# Combined Testing Results:
#   - MAE: 0.004517556638449712
#   - MASE: 0.2708000500447591

# %%
def print_results_with_metrics(results):
    """
    Print out results (model evaluation metrics and forecast predictions)
    from the results dictionary returned by combined_workflow.
    """
    for ticker, data in results.items():
        print(f"Ticker: {ticker}")
        print("=" * 50)
        
        # 1. Print evaluation metrics
        if "model results" in data:
            metrics_dict = data["model results"]
            mae = metrics_dict.get("mae", "N/A")
            mase = metrics_dict.get("mase", "N/A")
            
            print("Evaluation Metrics:")
            print(f"  Mean Absolute Error (MAE): {mae}")
            print(f"  Mean Absolute Scaled Error (MASE): {mase}")
            print("\n")
        else:
            print("No evaluation metrics found.\n")

        # 2. Print monthly forecast predictions
        print("Monthly Forecast Predictions (first 5 values for each period):")
        if "monthly_forecast_results" in data and isinstance(data["monthly_forecast_results"], dict):
            for period, forecast_df in data["monthly_forecast_results"].items():
                if isinstance(forecast_df, pd.DataFrame):
                    print(f"  {period}:\n{forecast_df.head(5)}\n")
                else:
                    print(f"  {period}: Invalid data structure (expected DataFrame).\n")
        else:
            print("No valid monthly forecast data found.\n")
        print("\n")

        # 3. Print weekly forecast predictions
        print("Weekly Forecast Predictions (first 5 values for each period):")
        if "weekly_forecast_results" in data and isinstance(data["weekly_forecast_results"], dict):
            for period, forecast_df in data["weekly_forecast_results"].items():
                if isinstance(forecast_df, pd.DataFrame):
                    print(f"  {period}:\n{forecast_df.head(5)}\n")
                else:
                    print(f"  {period}: Invalid data structure (expected DataFrame).\n")
        else:
            print("No valid weekly forecast data found.\n")
        print("\n")
        
        print("=" * 50)
        print("\n")
print_results_with_metrics(results)
# Out:
# Ticker: SMH
# ==================================================
# Evaluation Metrics:
#   Mean Absolute Error (MAE): 0.004517556638449712
#   Mean Absolute Scaled Error (MASE): 0.2708000500447591
#
#
# Monthly Forecast Predictions (first 5 values for each period):
#   forecast_data_1m:
#            log_returns
# -0.489125    -0.028478
# -0.435162    -0.016215
# -0.463565    -0.006936
# -0.461938     0.002337
# -0.348725     0.024434
#
#   forecast_data_2m:
#            log_returns
# -0.405888     0.003944
# -0.456244     0.011782
# -0.460929     0.011764
# -0.413370    -0.012292
# -0.498727     0.012099
#
#   forecast_data_3m:
#            log_returns
# -0.006222     0.027315
# -0.000575     0.008394
#  0.039208    -0.015712
#  0.057995     0.015740
#  0.085698     0.022505
#
#   forecast_data_4m:
#            log_returns
# -0.049494     0.006023
# -0.179465    -0.013349
# -0.204338    -0.000564
# -0.150989    -0.023930
# -0.208218     0.005872
#
#   forecast_data_5m:
#           log_returns
# 0.003082    -0.025781
# 0.051189     0.012021
# 0.068016     0.017309
# 0.102053     0.013934
# 0.108836    -0.010036
#
#   forecast_data_6m:
#            log_returns
# -0.556783     0.005326
# -0.607907    -0.007132
# -0.392946     0.032773
# -0.396172    -0.010446
# -0.390960    -0.004908
#
#   forecast_data_7m:
#            log_returns
# -0.185367    -0.003529
# -0.196307     0.003077
# -0.167209     0.012396
# -0.173140    -0.004502
# -0.386694     0.007476
#
#   forecast_data_8m:
#           log_returns
# 1.185928    -0.053566
# 1.261864    -0.045328
# 1.266338    -0.021488
# 1.275608     0.011528
# 1.281179    -0.024375
#
#   forecast_data_9m:
#           log_returns
# 0.799683    -0.062185
# 0.755064    -0.006465
# 0.735875    -0.005483
# 0.804528    -0.035778
# 0.552065     0.013217
#
#   forecast_data_10m:
#            log_returns
#  0.572887    -0.024722
#  0.094478     0.006640
#  0.093152     0.002370
#  0.096506     0.005883
# -0.126294    -0.003427
#
#   forecast_data_11m:
#            log_returns
# -0.188097     0.005663
# -0.208234    -0.005513
# -0.177425     0.008755
# -0.136145     0.016053
# -0.087369     0.014623
#
#
#
# Weekly Forecast Predictions (first 5 values for each period):
#   forecast_data_1w:
#            log_returns
# -0.489125    -0.028478
# -0.435162    -0.016215
# -0.463565    -0.006936
# -0.461938     0.002337
#
#   forecast_data_2w:
#            log_returns
# -0.348725     0.024434
# -0.392575    -0.000542
# -0.395066    -0.002015
# -0.452535     0.001860
# -0.458005    -0.005193
#
#   forecast_data_3w:
#            log_returns
# -0.444792     0.009680
# -0.476758    -0.007068
# -0.353034     0.022312
# -0.207233     0.026168
#
#   forecast_data_4w:
#            log_returns
# -0.207193     0.000563
# -0.331179     0.000987
# -0.358570     0.010812
# -0.358424    -0.002907
# -0.289595    -0.019290
#
#   forecast_data_5w:
#            log_returns
# -0.282751     0.006016
# -0.262670    -0.010788
# -0.235103    -0.013713
# -0.405888     0.003944
# -0.456244     0.011782
#
#   forecast_data_6w:
#            log_returns
# -0.460929     0.011764
# -0.413370    -0.012292
# -0.498727     0.012099
# -0.493390     0.007914
# -0.470302     0.013600
#
#   forecast_data_7w:
#            log_returns
# -0.452441    -0.006485
# -0.381064    -0.017587
# -0.369500     0.011933
# -0.377541    -0.006110
# -0.451379    -0.006890
#
#   forecast_data_8w:
#            log_returns
# -0.532682    -0.018516
# -0.522162    -0.008172
# -0.030481     0.049019
# -0.035979    -0.008401
#
#   forecast_data_9w:
#            log_returns
# -0.036180     0.002969
# -0.101042    -0.005961
# -0.079563    -0.012444
# -0.073117     0.013051
# -0.006222     0.027315
#
#   forecast_data_10w:
#            log_returns
# -0.000575     0.008394
#  0.039208    -0.015712
#  0.057995     0.015740
#  0.085698     0.022505
#  0.274989    -0.034075
#
#   forecast_data_11w:
#           log_returns
# 0.317343    -0.017522
# 0.351415     0.020125
# 0.396116    -0.019177
# 0.393797    -0.017673
# 0.384445    -0.009654
#
#   forecast_data_12w:
#            log_returns
#  0.380585    -0.002551
#  0.378127    -0.005524
#  0.338893     0.008136
#  0.347533     0.013016
# -0.010174     0.000763
#
#   forecast_data_13w:
#            log_returns
# -0.016629    -0.005701
# -0.001379    -0.011093
# -0.003968    -0.004046
# -0.025176    -0.003340
#
#   forecast_data_14w:
#            log_returns
# -0.049494     0.006023
# -0.179465    -0.013349
# -0.204338    -0.000564
# -0.150989    -0.023930
# -0.208218     0.005872
#
#   forecast_data_15w:
#            log_returns
# -0.360137    -0.001929
# -0.549732     0.000107
# -0.585509    -0.010083
# -0.655758     0.014266
# -0.586170    -0.025855
#
#   forecast_data_16w:
#            log_returns
# -0.599876    -0.014994
# -0.597797     0.003141
# -0.466770    -0.027201
# -0.431849    -0.016788
# -0.262467    -0.037704
#
#   forecast_data_17w:
#            log_returns
# -0.284108     0.011684
# -0.205357     0.014993
# -0.202570    -0.002093
# -0.146630     0.012177
# -0.066141     0.016042
#
#   forecast_data_18w:
#            log_returns
# -0.064178    -0.000955
# -0.055632    -0.018315
#  0.003082    -0.025781
#  0.051189     0.012021
#  0.068016     0.017309
#
#   forecast_data_19w:
#           log_returns
# 0.102053     0.013934
# 0.108836    -0.010036
# 0.107570    -0.001433
# 0.104443    -0.008515
# 0.074249     0.008272
#
#   forecast_data_20w:
#            log_returns
# -0.009337    -0.003638
# -0.012542     0.009427
#  0.057354     0.019080
# -0.050155    -0.009777
# -0.084510    -0.010526
#
#   forecast_data_21w:
#            log_returns
# -0.365429     0.011961
# -0.372227    -0.005459
# -0.408210     0.002469
# -0.405681     0.006280
# -0.410424     0.010190
#
#   forecast_data_22w:
#            log_returns
# -0.423284     0.013172
# -0.356992    -0.017265
# -0.390544    -0.014934
# -0.536114    -0.009785
#
#   forecast_data_23w:
#            log_returns
# -0.556783     0.005326
# -0.607907    -0.007132
# -0.392946     0.032773
# -0.396172    -0.010446
# -0.390960    -0.004908
#
#   forecast_data_24w:
#            log_returns
# -0.406081     0.006370
# -0.405452    -0.005674
# -0.348358     0.018223
# -0.351393     0.006793
# -0.414430    -0.002828
#
#   forecast_data_25w:
#            log_returns
# -0.428791     0.007936
# -0.458791     0.007062
# -0.314219    -0.026415
# -0.267460    -0.016185
#
#   forecast_data_26w:
#            log_returns
# -0.097135    -0.030832
# -0.067782     0.013573
# -0.084830    -0.006939
# -0.116328    -0.010152
# -0.153603     0.000802
#
#   forecast_data_27w:
#            log_returns
# -0.185367    -0.003529
# -0.196307     0.003077
# -0.167209     0.012396
# -0.173140    -0.004502
#
#   forecast_data_28w:
#            log_returns
# -0.386694     0.007476
# -0.404158    -0.002757
# -0.363434     0.013168
# -0.182352    -0.032397
# -0.175049     0.005014
#
#   forecast_data_29w:
#            log_returns
# -0.254451    -0.006086
# -0.276808    -0.005178
#  0.227564    -0.058770
#  0.198568    -0.000238
#  0.220664    -0.025894
#
#   forecast_data_30w:
#           log_returns
# 0.318480     0.025411
# 0.310978    -0.012690
# 0.450478    -0.045812
# 0.410163    -0.017884
# 0.441833     0.008140
#
#   forecast_data_31w:
#           log_returns
# 0.441369    -0.009520
# 0.519286    -0.033033
# 0.969062     0.054660
# 1.185928    -0.053566
# 1.261864    -0.045328
#
#   forecast_data_32w:
#           log_returns
# 1.266338    -0.021488
# 1.275608     0.011528
# 1.281179    -0.024375
# 1.523109     0.045398
# 1.486667    -0.004173
#
#   forecast_data_33w:
#           log_returns
# 1.479845     0.003551
# 1.600910     0.027203
# 1.601773    -0.003444
# 1.468573     0.027821
# 1.466844    -0.003518
#
#   forecast_data_34w:
#           log_returns
# 1.439359     0.009682
# 1.366427    -0.014665
# 1.367092     0.003797
# 1.257870    -0.029856
# 1.263966     0.014261
#
#   forecast_data_35w:
#           log_returns
# 1.290332    -0.022375
# 1.290306     0.002938
# 1.215386    -0.017462
# 0.868438    -0.013581
# 0.602488     0.013406
#
#   forecast_data_36w:
#           log_returns
# 0.799683    -0.062185
# 0.755064    -0.006465
# 0.735875    -0.005483
# 0.804528    -0.035778
#
#   forecast_data_37w:
#           log_returns
# 0.552065     0.013217
# 0.559548     0.002980
# 0.742584     0.035185
# 0.628888    -0.002632
# 0.640592     0.005530
#
#   forecast_data_38w:
#           log_returns
# 0.512886    -0.014245
# 0.512170    -0.004288
# 0.481106    -0.012637
# 0.630728     0.029329
# 0.630423    -0.013996
#
#   forecast_data_39w:
#           log_returns
# 0.558535    -0.000627
# 0.538377     0.010288
# 0.501244     0.002377
# 0.553294     0.017604
# 0.560812    -0.019117
#
#   forecast_data_40w:
#           log_returns
# 0.554849    -0.011419
# 0.572887    -0.024722
# 0.094478     0.006640
# 0.093152     0.002370
# 0.096506     0.005883
#
#   forecast_data_41w:
#            log_returns
# -0.126294    -0.003427
# -0.141129     0.008517
# -0.140484     0.003561
# -0.381678    -0.005934
# -0.380712     0.001629
#
#   forecast_data_42w:
#            log_returns
# -0.367192     0.008836
# -0.024541    -0.045828
# -0.025086    -0.003932
# -0.028926     0.008965
# -0.199415    -0.004581
#
#   forecast_data_43w:
#            log_returns
# -0.227075    -0.000088
# -0.221106    -0.007934
# -0.234768    -0.012302
# -0.240412    -0.001005
# -0.320300     0.004955
#
#   forecast_data_44w:
#            log_returns
# -0.361942    -0.009627
# -0.321078     0.013211
# -0.338001    -0.023157
# -0.196558    -0.031663
# -0.188097     0.005663
#
#   forecast_data_45w:
#            log_returns
# -0.208234    -0.005513
# -0.177425     0.008755
# -0.136145     0.016053
# -0.087369     0.014623
# -0.082343    -0.009279
#
#   forecast_data_46w:
#            log_returns
# -0.035141    -0.021471
# -0.068326    -0.008966
# -0.361646    -0.017357
# -0.361185    -0.002493
# -0.274771    -0.029222
#
#   forecast_data_47w:
#            log_returns
# -0.266482     0.001254
# -0.253654     0.004562
# -0.251601    -0.008898
# -0.233974     0.007328
# -0.233373    -0.008696
#
#   forecast_data_48w:
#            log_returns
# -0.251603    -0.006910
# -0.248241    -0.010793
# -0.310859    -0.013730
# -0.325884     0.008940
#
#
#
# ==================================================
#
#
# Ticker: SOXX
# ==================================================
# Evaluation Metrics:
#   Mean Absolute Error (MAE): 0.004517556638449712
#   Mean Absolute Scaled Error (MASE): 0.2708000500447591
#
#
# Monthly Forecast Predictions (first 5 values for each period):
#   forecast_data_1m:
#            log_returns
# -0.210931    -0.036310
# -0.122572    -0.023524
# -0.132471    -0.012485
# -0.142613    -0.001079
# -0.047177     0.021494
#
#   forecast_data_2m:
#            log_returns
# -0.254901    -0.001751
# -0.340781     0.004702
# -0.358151     0.005048
# -0.313205    -0.016219
# -0.421846     0.006699
#
#   forecast_data_3m:
#            log_returns
# -0.119793     0.028622
# -0.119772     0.000426
# -0.029781    -0.024163
#  0.007649     0.012958
#  0.052614     0.020743
#
#   forecast_data_4m:
#            log_returns
#  0.070154     0.002062
# -0.121632    -0.019940
# -0.134805    -0.004544
# -0.078468    -0.030902
# -0.147550     0.002803
#
#   forecast_data_5m:
#           log_returns
# 0.159971    -0.034967
# 0.235584     0.012220
# 0.220018     0.011663
# 0.254820     0.010777
# 0.262554    -0.014194
#
#   forecast_data_6m:
#            log_returns
# -0.655635    -0.006080
# -0.692161    -0.014148
# -0.455392     0.028546
# -0.458255    -0.014581
# -0.450733    -0.010493
#
#   forecast_data_7m:
#            log_returns
# -0.315242    -0.007807
# -0.314327     0.004723
# -0.289029     0.005715
# -0.310900    -0.006672
# -0.536732     0.007541
#
#   forecast_data_8m:
#           log_returns
# 1.590809    -0.068006
# 1.700898    -0.051952
# 1.695822    -0.021749
# 1.660751     0.000686
# 1.672497    -0.030002
#
#   forecast_data_9m:
#           log_returns
# 1.242782    -0.072488
# 1.209247    -0.005288
# 1.211178    -0.012474
# 1.302609    -0.044238
# 0.932037     0.008691
#
#   forecast_data_10m:
#            log_returns
#  0.855598    -0.031316
#  0.245689     0.003417
#  0.245696    -0.005252
#  0.247445     0.003085
# -0.033926    -0.010607
#
#   forecast_data_11m:
#            log_returns
# -0.068928     0.001916
# -0.100098    -0.011742
# -0.074484     0.002969
#  0.032123     0.017561
#  0.075279     0.009849
#
#
#
# Weekly Forecast Predictions (first 5 values for each period):
#   forecast_data_1w:
#            log_returns
# -0.210931    -0.036310
# -0.122572    -0.023524
# -0.132471    -0.012485
# -0.142613    -0.001079
#
#   forecast_data_2w:
#            log_returns
# -0.047177     0.021494
# -0.112478    -0.005692
# -0.107968    -0.008655
# -0.250503    -0.002367
# -0.249406    -0.009686
#
#   forecast_data_3w:
#            log_returns
# -0.254344     0.006157
# -0.354803    -0.013470
# -0.193614     0.022275
# -0.005685     0.026615
#
#   forecast_data_4w:
#            log_returns
# -0.006420    -0.003199
# -0.159050    -0.000450
# -0.223233     0.006149
# -0.216761    -0.008584
# -0.122797    -0.028712
#
#   forecast_data_5w:
#            log_returns
# -0.112482     0.002814
# -0.073729    -0.019414
# -0.050251    -0.017849
# -0.254901    -0.001751
# -0.340781     0.004702
#
#   forecast_data_6w:
#            log_returns
# -0.358151     0.005048
# -0.313205    -0.016219
# -0.421846     0.006699
# -0.397479     0.007736
# -0.375222     0.009834
#
#   forecast_data_7w:
#            log_returns
# -0.366667    -0.007805
# -0.277058    -0.024008
# -0.243158     0.012147
# -0.269221    -0.007204
# -0.377651    -0.010874
#
#   forecast_data_8w:
#            log_returns
# -0.542581    -0.020631
# -0.541533    -0.008256
# -0.184839     0.035001
# -0.181716    -0.015910
#
#   forecast_data_9w:
#            log_returns
# -0.176091     0.002053
# -0.307502    -0.007341
# -0.284450    -0.016420
# -0.254767     0.015638
# -0.119793     0.028622
#
#   forecast_data_10w:
#            log_returns
# -0.119772     0.000426
# -0.029781    -0.024163
#  0.007649     0.012958
#  0.052614     0.020743
#  0.321527    -0.042092
#
#   forecast_data_11w:
#           log_returns
# 0.344533    -0.018492
# 0.347498     0.009848
# 0.433394    -0.028155
# 0.416397    -0.021913
# 0.385213    -0.013350
#
#   forecast_data_12w:
#           log_returns
# 0.385090    -0.008353
# 0.390645    -0.014230
# 0.369127     0.006568
# 0.400912     0.011648
# 0.161096    -0.006405
#
#   forecast_data_13w:
#           log_returns
# 0.143904    -0.010569
# 0.149853    -0.013732
# 0.160904     0.003492
# 0.136113    -0.006717
#
#   forecast_data_14w:
#            log_returns
#  0.070154     0.002062
# -0.121632    -0.019940
# -0.134805    -0.004544
# -0.078468    -0.030902
# -0.147550     0.002803
#
#   forecast_data_15w:
#            log_returns
# -0.344831    -0.004343
# -0.571847     0.002358
# -0.544695    -0.022034
# -0.529914     0.011802
# -0.448921    -0.034885
#
#   forecast_data_16w:
#            log_returns
# -0.469754    -0.017734
# -0.465778    -0.000846
# -0.324515    -0.032045
# -0.291977    -0.021509
# -0.157243    -0.039430
#
#   forecast_data_17w:
#            log_returns
# -0.199787     0.007825
# -0.111706     0.011175
# -0.073047     0.004238
# -0.015000     0.008883
#  0.027364     0.010787
#
#   forecast_data_18w:
#           log_returns
# 0.037367    -0.000593
# 0.061941    -0.024504
# 0.159971    -0.034967
# 0.235584     0.012220
# 0.220018     0.011663
#
#   forecast_data_19w:
#           log_returns
# 0.254820     0.010777
# 0.262554    -0.014194
# 0.247336    -0.006340
# 0.211589    -0.009641
# 0.159588     0.001078
#
#   forecast_data_20w:
#            log_returns
#  0.024522    -0.005125
#  0.028546     0.007193
#  0.108163     0.016846
# -0.032764    -0.011197
# -0.086392    -0.011688
#
#   forecast_data_21w:
#            log_returns
# -0.368264     0.010941
# -0.363436    -0.010717
# -0.391820     0.002011
# -0.377500    -0.012510
# -0.371900     0.008658
#
#   forecast_data_22w:
#            log_returns
# -0.390418     0.006429
# -0.289189    -0.025212
# -0.369590    -0.013528
# -0.603593    -0.014344
#
#   forecast_data_23w:
#            log_returns
# -0.655635    -0.006080
# -0.692161    -0.014148
# -0.455392     0.028546
# -0.458255    -0.014581
# -0.450733    -0.010493
#
#   forecast_data_24w:
#            log_returns
# -0.448279     0.004178
# -0.448775    -0.007141
# -0.366400     0.015276
# -0.380726     0.001088
# -0.455174    -0.011699
#
#   forecast_data_25w:
#            log_returns
# -0.451291     0.005086
# -0.465605     0.002023
# -0.341672    -0.031475
# -0.320569    -0.015743
#
#   forecast_data_26w:
#            log_returns
# -0.186369    -0.031527
# -0.170040     0.004818
# -0.210428    -0.011299
# -0.242108    -0.012034
# -0.303145     0.000944
#
#   forecast_data_27w:
#            log_returns
# -0.315242    -0.007807
# -0.314327     0.004723
# -0.289029     0.005715
# -0.310900    -0.006672
#
#   forecast_data_28w:
#            log_returns
# -0.536732     0.007541
# -0.558687    -0.009397
# -0.505028     0.011668
# -0.301539    -0.035760
# -0.289237     0.002029
#
#   forecast_data_29w:
#            log_returns
# -0.392359    -0.007601
# -0.402573    -0.002935
#  0.286286    -0.068106
#  0.252944    -0.005826
#  0.311610    -0.033369
#
#   forecast_data_30w:
#           log_returns
# 0.458860     0.027995
# 0.471453    -0.020619
# 0.671011    -0.052117
# 0.673128    -0.026334
# 0.734324     0.010361
#
#   forecast_data_31w:
#           log_returns
# 0.733839    -0.009063
# 0.816402    -0.037377
# 1.251586     0.048726
# 1.590809    -0.068006
# 1.700898    -0.051952
#
#   forecast_data_32w:
#           log_returns
# 1.695822    -0.021749
# 1.660751     0.000686
# 1.672497    -0.030002
# 2.034536     0.050688
# 1.997291    -0.012176
#
#   forecast_data_33w:
#           log_returns
# 1.982148    -0.002208
# 2.131573     0.027166
# 2.121529    -0.009298
# 2.009738     0.032014
# 2.008277    -0.010009
#
#   forecast_data_34w:
#           log_returns
# 1.969200     0.005636
# 1.857208    -0.019782
# 1.861636     0.003390
# 1.745551    -0.037314
# 1.752166     0.014123
#
#   forecast_data_35w:
#           log_returns
# 1.773291    -0.029760
# 1.780610     0.000704
# 1.706178    -0.023710
# 1.367298    -0.010191
# 0.975226     0.013463
#
#   forecast_data_36w:
#           log_returns
# 1.242782    -0.072488
# 1.209247    -0.005288
# 1.211178    -0.012474
# 1.302609    -0.044238
#
#   forecast_data_37w:
#           log_returns
# 0.932037     0.008691
# 0.940005     0.000830
# 1.119816     0.031128
# 0.984419    -0.012057
# 1.011100     0.006770
#
#   forecast_data_38w:
#           log_returns
# 0.808100    -0.018665
# 0.809118    -0.006422
# 0.779105    -0.016939
# 0.951926     0.028301
# 0.946152    -0.019901
#
#   forecast_data_39w:
#           log_returns
# 0.847958    -0.004476
# 0.792471     0.002177
# 0.737212    -0.002241
# 0.841824     0.021765
# 0.834136    -0.021899
#
#   forecast_data_40w:
#           log_returns
# 0.842939    -0.015157
# 0.855598    -0.031316
# 0.245689     0.003417
# 0.245696    -0.005252
# 0.247445     0.003085
#
#   forecast_data_41w:
#            log_returns
# -0.033926    -0.010607
# -0.057794     0.000440
# -0.057911     0.000364
# -0.294788    -0.013578
# -0.300421    -0.000659
#
#   forecast_data_42w:
#            log_returns
# -0.297867     0.007256
#  0.082967    -0.051754
#  0.083362    -0.008083
#  0.064617    -0.000667
# -0.160664    -0.007146
#
#   forecast_data_43w:
#            log_returns
# -0.195057    -0.009599
# -0.192600    -0.010664
# -0.199187    -0.014547
# -0.201595    -0.002328
# -0.388446     0.001067
#
#   forecast_data_44w:
#            log_returns
# -0.425030    -0.006529
# -0.343226     0.013129
# -0.269899    -0.037064
# -0.085716    -0.039753
# -0.068928     0.001916
#
#   forecast_data_45w:
#            log_returns
# -0.100098    -0.011742
# -0.074484     0.002969
#  0.032123     0.017561
#  0.075279     0.009849
#  0.076080    -0.014024
#
#   forecast_data_46w:
#            log_returns
#  0.137237    -0.028565
#  0.091044    -0.016040
# -0.191613    -0.025012
# -0.191870    -0.006949
# -0.084877    -0.033786
#
#   forecast_data_47w:
#            log_returns
# -0.050949     0.003987
# -0.047806    -0.005226
# -0.044998    -0.013065
# -0.005228     0.006851
# -0.012176    -0.006555
#
#   forecast_data_48w:
#            log_returns
# -0.013045     0.001178
#  0.000047    -0.017756
# -0.096199    -0.017739
# -0.199142     0.004998
#
#
#
# ==================================================
#
#
# Ticker: PSI
# ==================================================
# Evaluation Metrics:
#   Mean Absolute Error (MAE): 0.004517556638449712
#   Mean Absolute Scaled Error (MASE): 0.2708000500447591
#
#
# Monthly Forecast Predictions (first 5 values for each period):
#   forecast_data_1m:
#           log_returns
# 0.166933    -0.041633
# 0.312043    -0.029478
# 0.340069    -0.020189
# 0.314420    -0.004220
# 0.411820     0.022547
#
#   forecast_data_2m:
#            log_returns
#  0.041288     0.002313
# -0.091270     0.005974
# -0.162075     0.002786
# -0.092386    -0.019312
# -0.232260     0.001245
#
#   forecast_data_3m:
#           log_returns
# 0.328362     0.034893
# 0.330746    -0.003587
# 0.512757    -0.033185
# 0.570511     0.017270
# 0.580161     0.021272
#
#   forecast_data_4m:
#           log_returns
# 0.465155     0.003505
# 0.179257    -0.016999
# 0.196877     0.003700
# 0.186872    -0.032007
# 0.105198     0.006003
#
#   forecast_data_5m:
#           log_returns
# 0.652728    -0.038993
# 0.797957     0.022987
# 0.796653     0.015435
# 0.849857     0.015274
# 0.852658    -0.011681
#
#   forecast_data_6m:
#            log_returns
# -0.758860    -0.006602
# -0.799662    -0.016976
# -0.400361     0.038508
# -0.382313    -0.016101
# -0.341573    -0.016854
#
#   forecast_data_7m:
#            log_returns
#  0.081097    -0.008603
#  0.057097     0.006139
#  0.066826     0.003890
#  0.020115    -0.005046
# -0.338876     0.007521
#
#   forecast_data_8m:
#           log_returns
# 2.785894    -0.085484
# 2.897264    -0.056112
# 2.879133    -0.021609
# 2.839046     0.000638
# 2.823006    -0.022807
#
#   forecast_data_9m:
#           log_returns
# 2.096503    -0.088792
# 2.058943    -0.001855
# 2.071499    -0.015265
# 2.248081    -0.048326
# 1.653377     0.003951
#
#   forecast_data_10m:
#           log_returns
# 1.817180    -0.043615
# 0.944101     0.010717
# 0.956390    -0.013877
# 0.986287     0.012792
# 0.654060    -0.007515
#
#   forecast_data_11m:
#           log_returns
# 0.325263    -0.000287
# 0.234941    -0.013905
# 0.398606     0.021254
# 0.602225     0.026320
# 0.664549     0.017418
#
#
#
# Weekly Forecast Predictions (first 5 values for each period):
#   forecast_data_1w:
#           log_returns
# 0.166933    -0.041633
# 0.312043    -0.029478
# 0.340069    -0.020189
# 0.314420    -0.004220
#
#   forecast_data_2w:
#           log_returns
# 0.411820     0.022547
# 0.355112    -0.004049
# 0.364016    -0.010171
# 0.203758    -0.002620
# 0.208151    -0.010685
#
#   forecast_data_3w:
#            log_returns
#  0.157042     0.008725
# -0.088106    -0.016907
#  0.137725     0.026300
#  0.401623     0.032785
#
#   forecast_data_4w:
#           log_returns
# 0.402138     0.002845
# 0.206529    -0.003001
# 0.048768     0.005041
# 0.050581    -0.006753
# 0.173994    -0.033525
#
#   forecast_data_5w:
#            log_returns
#  0.197660     0.005895
#  0.238989    -0.020092
#  0.301875    -0.025555
#  0.041288     0.002313
# -0.091270     0.005974
#
#   forecast_data_6w:
#            log_returns
# -0.162075     0.002786
# -0.092386    -0.019312
# -0.232260     0.001245
# -0.177535     0.012969
# -0.038650     0.025005
#
#   forecast_data_7w:
#            log_returns
# -0.036084    -0.004831
#  0.158201    -0.033476
#  0.276852     0.024485
#  0.221542    -0.001038
#  0.077739    -0.006960
#
#   forecast_data_8w:
#            log_returns
# -0.001461    -0.033326
#  0.014661    -0.017255
#  0.365071     0.037004
#  0.377880    -0.016922
#
#   forecast_data_9w:
#           log_returns
# 0.402091     0.006972
# 0.231430    -0.008660
# 0.216316    -0.003113
# 0.198704     0.011813
# 0.328362     0.034893
#
#   forecast_data_10w:
#           log_returns
# 0.330746    -0.003587
# 0.512757    -0.033185
# 0.570511     0.017270
# 0.580161     0.021272
# 0.908585    -0.045303
#
#   forecast_data_11w:
#           log_returns
# 0.941135    -0.022098
# 0.849110     0.009824
# 0.972279    -0.032479
# 0.883811    -0.022255
# 0.763275    -0.015556
#
#   forecast_data_12w:
#           log_returns
# 0.766329     0.000430
# 0.774385    -0.013062
# 0.720001     0.018188
# 0.783666     0.022106
# 0.522587    -0.005102
#
#   forecast_data_13w:
#           log_returns
# 0.490472    -0.007499
# 0.487915    -0.012963
# 0.494723     0.004515
# 0.497598    -0.007665
#
#   forecast_data_14w:
#           log_returns
# 0.465155     0.003505
# 0.179257    -0.016999
# 0.196877     0.003700
# 0.186872    -0.032007
# 0.105198     0.006003
#
#   forecast_data_15w:
#            log_returns
# -0.071991    -0.003738
# -0.388008     0.001542
# -0.334440    -0.027429
# -0.240261     0.019742
# -0.135935    -0.039418
#
#   forecast_data_16w:
#            log_returns
# -0.142196    -0.021279
# -0.143068     0.004676
#  0.085212    -0.038861
#  0.152283    -0.025952
#  0.278668    -0.045540
#
#   forecast_data_17w:
#           log_returns
# 0.142001     0.009780
# 0.284889     0.017549
# 0.311374     0.002902
# 0.377181     0.010195
# 0.445512     0.015214
#
#   forecast_data_18w:
#           log_returns
# 0.462186     0.002215
# 0.506716    -0.027928
# 0.652728    -0.038993
# 0.797957     0.022987
# 0.796653     0.015435
#
#   forecast_data_19w:
#           log_returns
# 0.849857     0.015274
# 0.852658    -0.011681
# 0.840715    -0.006790
# 0.770703    -0.004948
# 0.662323    -0.000416
#
#   forecast_data_20w:
#           log_returns
# 0.471036    -0.007362
# 0.459494     0.009294
# 0.547114     0.019172
# 0.336640    -0.015240
# 0.244311    -0.013081
#
#   forecast_data_21w:
#            log_returns
# -0.148066     0.013962
# -0.151159    -0.007053
# -0.210708    -0.005819
# -0.194570    -0.009686
# -0.193994     0.009730
#
#   forecast_data_22w:
#            log_returns
# -0.234994     0.007192
# -0.148071    -0.022583
# -0.294496    -0.009310
# -0.597668    -0.018714
#
#   forecast_data_23w:
#            log_returns
# -0.758860    -0.006602
# -0.799662    -0.016976
# -0.400361     0.038508
# -0.382313    -0.016101
# -0.341573    -0.016854
#
#   forecast_data_24w:
#            log_returns
# -0.281796     0.012316
# -0.277346    -0.007839
# -0.155965     0.020399
# -0.179739     0.000600
# -0.257311    -0.016246
#
#   forecast_data_25w:
#            log_returns
# -0.231553     0.012147
# -0.241455     0.006154
# -0.056324    -0.036298
# -0.011163    -0.019284
#
#   forecast_data_26w:
#           log_returns
# 0.122313    -0.030087
# 0.193071     0.014489
# 0.156277    -0.009690
# 0.122718    -0.005416
# 0.083796     0.004890
#
#   forecast_data_27w:
#           log_returns
# 0.081097    -0.008603
# 0.057097     0.006139
# 0.066826     0.003890
# 0.020115    -0.005046
#
#   forecast_data_28w:
#            log_returns
# -0.338876     0.007521
# -0.372872    -0.007753
# -0.390708     0.008714
# -0.183782    -0.036803
# -0.171379     0.004047
#
#   forecast_data_29w:
#            log_returns
# -0.302807     0.003924
# -0.304504    -0.000114
#  0.952470    -0.088445
#  0.888840    -0.017240
#  0.922295    -0.032506
#
#   forecast_data_30w:
#           log_returns
# 1.113950     0.034391
# 1.104732    -0.015766
# 1.451065    -0.062683
# 1.461021    -0.036739
# 1.517130     0.009258
#
#   forecast_data_31w:
#           log_returns
# 1.513258    -0.011352
# 1.693330    -0.053505
# 2.263653     0.056364
# 2.785894    -0.085484
# 2.897264    -0.056112
#
#   forecast_data_32w:
#           log_returns
# 2.879133    -0.021609
# 2.839046     0.000638
# 2.823006    -0.022807
# 3.412582     0.064361
# 3.394302    -0.003003
#
#   forecast_data_33w:
#           log_returns
# 3.370166    -0.003544
# 3.523141     0.029894
# 3.506223    -0.008424
# 3.276104     0.044011
# 3.271338    -0.013214
#
#   forecast_data_34w:
#           log_returns
# 3.232804     0.005314
# 3.074912    -0.022705
# 3.127520     0.014640
# 2.928147    -0.039688
# 2.894934     0.018452
#
#   forecast_data_35w:
#           log_returns
# 2.953692    -0.034832
# 2.961193     0.003139
# 2.752522    -0.022815
# 2.339644    -0.002078
# 1.565968     0.004165
#
#   forecast_data_36w:
#           log_returns
# 2.096503    -0.088792
# 2.058943    -0.001855
# 2.071499    -0.015265
# 2.248081    -0.048326
#
#   forecast_data_37w:
#           log_returns
# 1.653377     0.003951
# 1.658994     0.000084
# 1.869032     0.033446
# 1.704904    -0.015394
# 1.773999     0.015467
#
#   forecast_data_38w:
#           log_returns
# 1.456602    -0.029576
# 1.471560     0.000754
# 1.440901    -0.017327
# 1.696684     0.035828
# 1.635091    -0.019810
#
#   forecast_data_39w:
#           log_returns
# 1.526265    -0.002673
# 1.442783     0.004613
# 1.359214    -0.000603
# 1.659664     0.041743
# 1.667055    -0.023946
#
#   forecast_data_40w:
#           log_returns
# 1.672101    -0.014095
# 1.817180    -0.043615
# 0.944101     0.010717
# 0.956390    -0.013877
# 0.986287     0.012792
#
#   forecast_data_41w:
#           log_returns
# 0.654060    -0.007515
# 0.650504    -0.004803
# 0.663880     0.007150
# 0.440006    -0.009122
# 0.437548     0.008890
#
#   forecast_data_42w:
#           log_returns
# 0.408805     0.010249
# 0.892005    -0.063349
# 0.888938    -0.005871
# 0.859094    -0.005391
# 0.585152    -0.007631
#
#   forecast_data_43w:
#           log_returns
# 0.552831    -0.009904
# 0.561279    -0.012842
# 0.555879    -0.014940
# 0.550246    -0.004142
# 0.134010     0.008911
#
#   forecast_data_44w:
#           log_returns
# 0.085199    -0.007849
# 0.164538     0.014608
# 0.006762    -0.030906
# 0.320114    -0.050160
# 0.325263    -0.000287
#
#   forecast_data_45w:
#           log_returns
# 0.234941    -0.013905
# 0.398606     0.021254
# 0.602225     0.026320
# 0.664549     0.017418
# 0.667731    -0.011092
#
#   forecast_data_46w:
#           log_returns
# 0.700257    -0.028547
# 0.654149    -0.019004
# 0.197892    -0.027932
# 0.196633    -0.008718
# 0.448701    -0.045018
#
#   forecast_data_47w:
#           log_returns
# 0.503808     0.009053
# 0.523973     0.002453
# 0.521388    -0.005964
# 0.713188     0.027219
# 0.712501    -0.005983
#
#   forecast_data_48w:
#           log_returns
# 0.703125     0.006818
# 0.714464    -0.014740
# 0.680315    -0.023995
# 0.663143     0.013574
#
#
#
# ==================================================
#
#
# Ticker: XSD
# ==================================================
# Evaluation Metrics:
#   Mean Absolute Error (MAE): 0.004517556638449712
#   Mean Absolute Scaled Error (MASE): 0.2708000500447591
#
#
# Monthly Forecast Predictions (first 5 values for each period):
#   forecast_data_1m:
#           log_returns
# 0.107944    -0.033517
# 0.285897    -0.034270
# 0.342989    -0.021585
# 0.303820    -0.002814
# 0.420009     0.024360
#
#   forecast_data_2m:
#            log_returns
#  0.057217    -0.005995
# -0.103835    -0.004134
# -0.154741     0.002382
# -0.137415    -0.013334
# -0.268209     0.012130
#
#   forecast_data_3m:
#           log_returns
# 0.007942     0.029843
# 0.008879    -0.006744
# 0.142887    -0.027949
# 0.214803     0.017878
# 0.326663     0.027303
#
#   forecast_data_4m:
#            log_returns
#  0.252806     0.001749
#  0.113803    -0.025863
#  0.129409     0.003429
#  0.074681    -0.020346
# -0.033751    -0.000338
#
#   forecast_data_5m:
#           log_returns
# 0.573944    -0.035704
# 0.611123     0.010623
# 0.658691     0.016044
# 0.695876     0.010461
# 0.688078    -0.008260
#
#   forecast_data_6m:
#            log_returns
# -0.720670    -0.006221
# -0.711709    -0.020008
# -0.459675     0.030923
# -0.435364    -0.013932
# -0.322186    -0.024212
#
#   forecast_data_7m:
#            log_returns
# -0.392300    -0.009277
# -0.311144     0.013679
# -0.298230     0.003381
# -0.359259    -0.001486
# -0.579608     0.014477
#
#   forecast_data_8m:
#           log_returns
# 1.632682    -0.067791
# 1.907992    -0.062203
# 1.932028    -0.033453
# 1.852278    -0.001766
# 1.887646    -0.034172
#
#   forecast_data_9m:
#           log_returns
# 1.824698    -0.077332
# 1.714080    -0.003232
# 1.732167    -0.015665
# 1.828387    -0.046185
# 1.353717     0.009962
#
#   forecast_data_10m:
#           log_returns
# 1.251667    -0.038828
# 0.514198     0.004350
# 0.517134    -0.008141
# 0.527401     0.010925
# 0.203655    -0.012350
#
#   forecast_data_11m:
#           log_returns
# 0.183371     0.014368
# 0.129303    -0.010269
# 0.167786     0.009091
# 0.435257     0.033543
# 0.429385     0.004315
#
#
#
# Weekly Forecast Predictions (first 5 values for each period):
#   forecast_data_1w:
#           log_returns
# 0.107944    -0.033517
# 0.285897    -0.034270
# 0.342989    -0.021585
# 0.303820    -0.002814
#
#   forecast_data_2w:
#           log_returns
# 0.420009     0.024360
# 0.350200    -0.006781
# 0.340102    -0.011573
# 0.270417    -0.010521
# 0.283853    -0.013722
#
#   forecast_data_3w:
#            log_returns
#  0.185850    -0.003615
# -0.135908    -0.015509
#  0.066228     0.023747
#  0.243011     0.023914
#
#   forecast_data_4w:
#            log_returns
#  0.283921     0.010723
#  0.100709     0.003839
# -0.062493    -0.012850
# -0.049129    -0.014536
#  0.012691    -0.030712
#
#   forecast_data_5w:
#            log_returns
#  0.075831     0.010739
#  0.162395    -0.028255
#  0.185322    -0.023937
#  0.057217    -0.005995
# -0.103835    -0.004134
#
#   forecast_data_6w:
#            log_returns
# -0.154741     0.002382
# -0.137415    -0.013334
# -0.268209     0.012130
# -0.116318     0.021944
# -0.040342     0.017323
#
#   forecast_data_7w:
#            log_returns
# -0.053588    -0.002151
#  0.192081    -0.040033
#  0.271492     0.017758
#  0.237616    -0.006461
#  0.165903    -0.021317
#
#   forecast_data_8w:
#            log_returns
#  0.022189    -0.015126
# -0.036461    -0.007007
#  0.044339     0.016117
#  0.077345    -0.020486
#
#   forecast_data_9w:
#            log_returns
#  0.089231     0.006034
# -0.043208    -0.008037
# -0.083408    -0.011574
# -0.109706     0.016917
#  0.007942     0.029843
#
#   forecast_data_10w:
#           log_returns
# 0.008879    -0.006744
# 0.142887    -0.027949
# 0.214803     0.017878
# 0.326663     0.027303
# 0.490988    -0.033662
#
#   forecast_data_11w:
#           log_returns
# 0.409028    -0.011562
# 0.338979     0.002324
# 0.467044    -0.031380
# 0.347962    -0.028396
# 0.262459    -0.012636
#
#   forecast_data_12w:
#           log_returns
# 0.262486    -0.006686
# 0.225122    -0.011713
# 0.288912     0.016685
# 0.351835     0.015559
# 0.297272    -0.011892
#
#   forecast_data_13w:
#           log_returns
# 0.246266    -0.007080
# 0.235066    -0.009863
# 0.334588     0.020293
# 0.319131    -0.002060
#
#   forecast_data_14w:
#            log_returns
#  0.252806     0.001749
#  0.113803    -0.025863
#  0.129409     0.003429
#  0.074681    -0.020346
# -0.033751    -0.000338
#
#   forecast_data_15w:
#            log_returns
# -0.272449     0.002836
# -0.343201     0.015390
# -0.045727    -0.042803
#  0.045027     0.016902
#  0.132098    -0.039329
#
#   forecast_data_16w:
#           log_returns
# 0.103043    -0.024393
# 0.094235    -0.003219
# 0.172969    -0.026220
# 0.226964    -0.024232
# 0.246692    -0.034872
#
#   forecast_data_17w:
#           log_returns
# 0.190133     0.008840
# 0.281292     0.013332
# 0.386331     0.016116
# 0.481501     0.016844
# 0.418293     0.011930
#
#   forecast_data_18w:
#           log_returns
# 0.467409     0.011324
# 0.499849    -0.022621
# 0.573944    -0.035704
# 0.611123     0.010623
# 0.658691     0.016044
#
#   forecast_data_19w:
#           log_returns
# 0.695876     0.010461
# 0.688078    -0.008260
# 0.620192    -0.001575
# 0.385128    -0.002337
# 0.307917    -0.011085
#
#   forecast_data_20w:
#            log_returns
#  0.088317    -0.000521
#  0.036185     0.011164
#  0.084918     0.013747
# -0.025721    -0.010715
# -0.144861    -0.005245
#
#   forecast_data_21w:
#            log_returns
# -0.446757     0.006452
# -0.428783    -0.009108
# -0.426167     0.013031
# -0.317278    -0.026143
# -0.325909     0.015246
#
#   forecast_data_22w:
#            log_returns
# -0.347545     0.007023
# -0.273470    -0.023620
# -0.374963    -0.000826
# -0.693173    -0.005339
#
#   forecast_data_23w:
#            log_returns
# -0.720670    -0.006221
# -0.711709    -0.020008
# -0.459675     0.030923
# -0.435364    -0.013932
# -0.322186    -0.024212
#
#   forecast_data_24w:
#            log_returns
# -0.290555     0.008863
# -0.310093    -0.001928
# -0.202669     0.019760
# -0.225686    -0.008171
# -0.205635    -0.021672
#
#   forecast_data_25w:
#            log_returns
# -0.212570     0.001319
# -0.213059    -0.004790
# -0.124003    -0.026360
# -0.128688    -0.004677
#
#   forecast_data_26w:
#            log_returns
# -0.122265    -0.024302
# -0.201936     0.002752
# -0.299361    -0.004497
# -0.340029    -0.007499
# -0.391803     0.004795
#
#   forecast_data_27w:
#            log_returns
# -0.392300    -0.009277
# -0.311144     0.013679
# -0.298230     0.003381
# -0.359259    -0.001486
#
#   forecast_data_28w:
#            log_returns
# -0.579608     0.014477
# -0.592494    -0.010981
# -0.568632     0.019976
# -0.541064    -0.017820
# -0.523673     0.005668
#
#   forecast_data_29w:
#            log_returns
# -0.658348     0.003633
# -0.600018     0.012113
#  0.030442    -0.059286
#  0.040051    -0.014083
#  0.191067    -0.033594
#
#   forecast_data_30w:
#           log_returns
# 0.344092     0.030526
# 0.393502    -0.021160
# 0.650895    -0.049254
# 0.722370    -0.029601
# 0.792909     0.014277
#
#   forecast_data_31w:
#           log_returns
# 0.792468    -0.006056
# 0.979195    -0.044883
# 1.241531     0.035918
# 1.632682    -0.067791
# 1.907992    -0.062203
#
#   forecast_data_32w:
#           log_returns
# 1.932028    -0.033453
# 1.852278    -0.001766
# 1.887646    -0.034172
# 2.361882     0.059333
# 2.362311    -0.011269
#
#   forecast_data_33w:
#           log_returns
# 2.330737    -0.005003
# 2.519018     0.032234
# 2.448495    -0.016945
# 2.565363     0.044863
# 2.564065    -0.008933
#
#   forecast_data_34w:
#           log_returns
# 2.529100     0.006845
# 2.372797    -0.015021
# 2.420369     0.014923
# 2.316244    -0.033987
# 2.366882     0.025187
#
#   forecast_data_35w:
#           log_returns
# 2.352686    -0.023334
# 2.357582    -0.000232
# 2.215249    -0.018329
# 2.050583     0.008777
# 1.608250     0.006864
#
#   forecast_data_36w:
#           log_returns
# 1.824698    -0.077332
# 1.714080    -0.003232
# 1.732167    -0.015665
# 1.828387    -0.046185
#
#   forecast_data_37w:
#           log_returns
# 1.353717     0.009962
# 1.350451    -0.003529
# 1.520005     0.031427
# 1.355157    -0.012650
# 1.386475     0.014706
#
#   forecast_data_38w:
#           log_returns
# 1.061803    -0.017704
# 1.064581    -0.002141
# 1.035872    -0.009293
# 1.220168     0.030885
# 1.188125    -0.021495
#
#   forecast_data_39w:
#           log_returns
# 1.084992    -0.002341
# 0.953660     0.003464
# 0.915231    -0.009531
# 1.160293     0.036185
# 1.139741    -0.010972
#
#   forecast_data_40w:
#           log_returns
# 1.131053    -0.015839
# 1.251667    -0.038828
# 0.514198     0.004350
# 0.517134    -0.008141
# 0.527401     0.010925
#
#   forecast_data_41w:
#            log_returns
#  0.203655    -0.012350
#  0.179450    -0.002421
#  0.189626     0.005867
# -0.023236    -0.010960
#  0.005985     0.012811
#
#   forecast_data_42w:
#            log_returns
# -0.044530     0.004489
#  0.080172    -0.031675
#  0.081667    -0.000302
#  0.073644    -0.002980
# -0.171526    -0.006036
#
#   forecast_data_43w:
#            log_returns
# -0.230335    -0.009268
# -0.229975    -0.006067
# -0.219517    -0.014397
# -0.222919    -0.001707
# -0.634764     0.004788
#
#   forecast_data_44w:
#            log_returns
# -0.609165     0.005795
# -0.532951     0.015576
# -0.387363    -0.046676
#  0.102312    -0.053984
#  0.183371     0.014368
#   forecast_data_45w:
#           log_returns
# 0.129303    -0.010269
# 0.167786     0.009091
# 0.435257     0.033543
# 0.429385     0.004315
# 0.425859     0.001343
#
#   forecast_data_46w:
#           log_returns
# 0.501232    -0.032519
# 0.534034    -0.024039
# 0.498862    -0.026261
# 0.496611    -0.013209
# 0.623810    -0.036612
#
#   forecast_data_47w:
#           log_returns
# 0.670416     0.008793
# 0.690924     0.003452
# 0.691181    -0.004868
# 0.801934     0.021112
# 0.830538     0.008601
#
#   forecast_data_48w:
#           log_returns
# 0.945850     0.024034
# 0.947655    -0.016536
# 0.888522    -0.016901
# 0.688735     0.011685
#
#
#
# ==================================================
#
#
# Ticker: IYW
# ==================================================
# Evaluation Metrics:
#   Mean Absolute Error (MAE): 0.004517556638449712
#   Mean Absolute Scaled Error (MASE): 0.2708000500447591
#
#
# Monthly Forecast Predictions (first 5 values for each period):
#   forecast_data_1m:
#            log_returns
# -0.624734    -0.027993
# -0.596881    -0.012151
# -0.626558    -0.009152
# -0.632577    -0.001144
# -0.506431     0.023736
#
#   forecast_data_2m:
#            log_returns
# -0.394274     0.009298
# -0.390663     0.015720
# -0.416012    -0.001854
# -0.403662    -0.006470
# -0.483724     0.012163
#
#   forecast_data_3m:
#            log_returns
# -0.353659     0.012818
# -0.363609    -0.005508
# -0.296252    -0.025638
# -0.283750     0.006192
# -0.239510     0.014778
#
#   forecast_data_4m:
#            log_returns
# -0.491717     0.000871
# -0.532250    -0.010213
# -0.532696    -0.000528
# -0.598331    -0.019151
# -0.570634     0.011089
#
#   forecast_data_5m:
#            log_returns
# -0.150230    -0.011869
# -0.095350     0.013446
# -0.030243     0.021304
# -0.022963     0.012606
# -0.020402    -0.006931
#
#   forecast_data_6m:
#            log_returns
# -0.532987     0.004737
# -0.642920    -0.001440
# -0.541159     0.023499
# -0.546031    -0.005853
# -0.547290    -0.001382
#
#   forecast_data_7m:
#            log_returns
# -0.534511     0.006625
# -0.539564     0.003597
# -0.532742     0.007633
# -0.532027     0.005688
# -0.652716     0.001570
#
#   forecast_data_8m:
#           log_returns
# 0.325479    -0.033662
# 0.351862    -0.027573
# 0.427109    -0.037232
# 0.443029     0.006872
# 0.440908    -0.013129
#
#   forecast_data_9m:
#           log_returns
# 0.293973    -0.044448
# 0.105985    -0.007158
# 0.099922    -0.003319
# 0.172202    -0.026566
# 0.014458     0.008859
#
#   forecast_data_10m:
#            log_returns
#  0.020942    -0.025897
# -0.294927     0.002578
# -0.302704     0.001107
# -0.286525     0.009337
# -0.407476    -0.011945
#
#   forecast_data_11m:
#            log_returns
# -0.373026     0.003709
# -0.405081    -0.004873
# -0.380641     0.011322
# -0.297879     0.024373
# -0.239188     0.017093
#
#
#
# Weekly Forecast Predictions (first 5 values for each period):
#   forecast_data_1w:
#            log_returns
# -0.624734    -0.027993
# -0.596881    -0.012151
# -0.626558    -0.009152
# -0.632577    -0.001144
#
#   forecast_data_2w:
#            log_returns
# -0.506431     0.023736
# -0.560015     0.000734
# -0.552314     0.007000
# -0.554181     0.001933
# -0.558480     0.000345
#
#   forecast_data_3w:
#            log_returns
# -0.574296    -0.000655
# -0.565997    -0.007395
# -0.493296     0.016404
# -0.395255     0.020947
#
#   forecast_data_4w:
#            log_returns
# -0.395349     0.001752
# -0.447447     0.001344
# -0.462427     0.004613
# -0.462595     0.001767
# -0.432812    -0.011708
#
#   forecast_data_5w:
#            log_returns
# -0.419809     0.008211
# -0.394654    -0.011031
# -0.251665    -0.027809
# -0.394274     0.009298
# -0.390663     0.015720
#
#   forecast_data_6w:
#            log_returns
# -0.416012    -0.001854
# -0.403662    -0.006470
# -0.483724     0.012163
# -0.484019     0.001563
# -0.465061     0.011904
#
#   forecast_data_7w:
#            log_returns
# -0.433230    -0.010351
# -0.343125    -0.019789
# -0.327125     0.009712
# -0.336364    -0.005075
# -0.349335    -0.013556
#
#   forecast_data_8w:
#            log_returns
# -0.424538    -0.012392
# -0.413805    -0.010100
# -0.208436     0.030150
# -0.212802    -0.004726
#
#   forecast_data_9w:
#            log_returns
# -0.213138    -0.005004
# -0.231877    -0.000319
# -0.239802    -0.009294
# -0.236232     0.008482
# -0.353659     0.012818
#
#   forecast_data_10w:
#            log_returns
# -0.363609    -0.005508
# -0.296252    -0.025638
# -0.283750     0.006192
# -0.239510     0.014778
# -0.230493    -0.016574
#
#   forecast_data_11w:
#            log_returns
# -0.229339    -0.006808
# -0.199058     0.017167
# -0.196037    -0.011447
# -0.256841    -0.001826
# -0.234077    -0.017943
#
#   forecast_data_12w:
#            log_returns
# -0.223279     0.005662
# -0.246969     0.001762
# -0.250364     0.009671
# -0.270075    -0.000255
# -0.470266     0.000514
#
#   forecast_data_13w:
#            log_returns
# -0.463810    -0.007628
# -0.458065    -0.007669
# -0.458507    -0.001815
# -0.469794    -0.004630
#
#   forecast_data_14w:
#            log_returns
# -0.491717     0.000871
# -0.532250    -0.010213
# -0.532696    -0.000528
# -0.598331    -0.019151
# -0.570634     0.011089
#
#   forecast_data_15w:
#            log_returns
# -0.649057    -0.004219
# -0.701676    -0.000491
# -0.691927    -0.009435
# -0.677796     0.018223
# -0.621408    -0.019447
#
#   forecast_data_16w:
#            log_returns
# -0.521157    -0.023325
# -0.571718    -0.000856
# -0.540435    -0.017689
# -0.542681    -0.009589
# -0.451126    -0.030295
#
#   forecast_data_17w:
#            log_returns
# -0.407519     0.009385
# -0.324714     0.015362
# -0.320708     0.000043
# -0.320818    -0.007406
# -0.219361     0.018457
#
#   forecast_data_18w:
#            log_returns
# -0.218642    -0.001933
# -0.153789    -0.023843
# -0.150230    -0.011869
# -0.095350     0.013446
# -0.030243     0.021304
#
#   forecast_data_19w:
#            log_returns
# -0.022963     0.012606
# -0.020402    -0.006931
# -0.021081    -0.002431
# -0.029024    -0.003696
# -0.102250     0.000494
#
#   forecast_data_20w:
#            log_returns
# -0.147640     0.000851
# -0.222004     0.006033
# -0.149251     0.019285
# -0.204172    -0.005269
# -0.218370    -0.005291
#
#   forecast_data_21w:
#            log_returns
# -0.417269     0.009616
# -0.423199    -0.001805
# -0.458496    -0.002668
# -0.457954    -0.001172
# -0.472668     0.006296
#
#   forecast_data_22w:
#            log_returns
# -0.528551     0.007783
# -0.511244    -0.008024
# -0.465609    -0.028025
# -0.502152    -0.003564
#
#   forecast_data_23w:
#            log_returns
# -0.532987     0.004737
# -0.642920    -0.001440
# -0.541159     0.023499
# -0.546031    -0.005853
# -0.547290    -0.001382
#
#   forecast_data_24w:
#            log_returns
# -0.552245     0.000028
# -0.524717     0.011496
# -0.452773     0.019020
# -0.455451     0.002928
# -0.527605     0.001983
#
#   forecast_data_25w:
#            log_returns
# -0.528798     0.007896
# -0.541476     0.001461
# -0.480615    -0.016904
# -0.459490    -0.009307
#
#   forecast_data_26w:
#            log_returns
# -0.375582    -0.020124
# -0.336484     0.013752
# -0.343267     0.000181
# -0.355612    -0.001432
# -0.359139    -0.007094
#
#   forecast_data_27w:
#            log_returns
# -0.534511     0.006625
# -0.539564     0.003597
# -0.532742     0.007633
# -0.532027     0.005688
#
#   forecast_data_28w:
#            log_returns
# -0.652716     0.001570
# -0.656098    -0.005212
# -0.639251     0.009688
# -0.445173    -0.027165
# -0.470732     0.003497
#
#   forecast_data_29w:
#            log_returns
# -0.559533     0.001797
# -0.558205    -0.005854
# -0.251513    -0.039903
# -0.273554    -0.007779
# -0.262824    -0.013648
#
#   forecast_data_30w:
#            log_returns
# -0.211679     0.017278
# -0.218590    -0.005002
#  0.034435    -0.045184
# -0.011077    -0.011978
#  0.011393     0.007927
#
#   forecast_data_31w:
#           log_returns
# 0.009390    -0.005434
# 0.051326    -0.021724
# 0.228205     0.031224
# 0.325479    -0.033662
# 0.351862    -0.027573
#
#   forecast_data_32w:
#           log_returns
# 0.427109    -0.037232
# 0.443029     0.006872
# 0.440908    -0.013129
# 0.607558     0.032264
# 0.585715     0.003796
#
#   forecast_data_33w:
#           log_returns
# 0.582561     0.002626
# 0.690993     0.024478
# 0.696611     0.000158
# 0.638935     0.021429
# 0.637466    -0.001862
#
#   forecast_data_34w:
#           log_returns
# 0.643579     0.009964
# 0.599784    -0.006514
# 0.603226     0.002301
# 0.430522    -0.023147
# 0.433500     0.010369
#
#   forecast_data_35w:
#           log_returns
# 0.438544    -0.012805
# 0.437235     0.000495
# 0.408921    -0.015776
# 0.263681    -0.007206
# 0.133302     0.007464
#
#   forecast_data_36w:
#           log_returns
# 0.293973    -0.044448
# 0.105985    -0.007158
# 0.099922    -0.003319
# 0.172202    -0.026566
#
#   forecast_data_37w:
#           log_returns
# 0.014458     0.008859
# 0.024892     0.007595
# 0.128757     0.024325
# 0.030867     0.005172
# 0.032793     0.001964
#
#   forecast_data_38w:
#            log_returns
# -0.058156    -0.009079
# -0.058862    -0.002657
# -0.091432    -0.007512
#  0.061367     0.027209
#  0.057959    -0.006294
#
#   forecast_data_39w:
#            log_returns
# -0.005932    -0.004317
# -0.026439     0.003648
# -0.041981     0.000289
# -0.031650     0.006239
# -0.049408    -0.010940
#
#   forecast_data_40w:
#            log_returns
# -0.053990     0.000691
#  0.020942    -0.025897
# -0.294927     0.002578
# -0.302704     0.001107
# -0.286525     0.009337
#
#   forecast_data_41w:
#            log_returns
# -0.407476    -0.011945
# -0.379403     0.014715
# -0.384106     0.005512
# -0.509401    -0.002820
# -0.516503    -0.000797
#
#   forecast_data_42w:
#            log_returns
# -0.495312     0.009174
# -0.415975    -0.021221
# -0.415625    -0.003156
# -0.427548    -0.000756
# -0.612209     0.000414
#
#   forecast_data_43w:
#            log_returns
# -0.613162     0.003075
# -0.614875    -0.002882
# -0.546145    -0.018607
# -0.545603     0.000816
# -0.556519     0.003050
#
#   forecast_data_44w:
#            log_returns
# -0.576428    -0.001420
# -0.544059     0.010087
# -0.652138    -0.015041
# -0.377755    -0.035737
# -0.373026     0.003709
#
#   forecast_data_45w:
#            log_returns
# -0.405081    -0.004873
# -0.380641     0.011322
# -0.297879     0.024373
# -0.239188     0.017093
# -0.237155    -0.004855
#
#   forecast_data_46w:
#            log_returns
# -0.229767    -0.007901
# -0.253277     0.000214
# -0.319369    -0.007880
# -0.314958    -0.006534
# -0.187429    -0.028155
#
#   forecast_data_47w:
#            log_returns
# -0.186634     0.000924
# -0.168222     0.009023
# -0.167494    -0.004233
# -0.213251     0.003326
# -0.214001    -0.003142
#
#   forecast_data_48w:
#            log_returns
# -0.218462    -0.003051
# -0.216200     0.001535
# -0.216961    -0.014580
# -0.233517     0.005079
#
#
#
# ==================================================
#
#
# Ticker: XLK
# ==================================================
# Evaluation Metrics:
#   Mean Absolute Error (MAE): 0.004517556638449712
#   Mean Absolute Scaled Error (MASE): 0.2708000500447591
#
#
# Monthly Forecast Predictions (first 5 values for each period):
#   forecast_data_1m:
#            log_returns
# -0.590820    -0.029417
# -0.560475    -0.012716
# -0.587314    -0.009675
# -0.596657    -0.002205
# -0.464038     0.024357
#
#   forecast_data_2m:
#            log_returns
# -0.374976     0.010940
# -0.409812     0.008271
# -0.441996    -0.000185
# -0.427365    -0.007217
# -0.517016     0.011208
#
#   forecast_data_3m:
#            log_returns
# -0.362077     0.016660
# -0.382333    -0.002316
# -0.246560    -0.028216
# -0.236849     0.005918
# -0.203457     0.014043
#
#   forecast_data_4m:
# ...
# -0.269842    -0.010044
# -0.149419    -0.024159
# -0.110856     0.015429
# -0.128543    -0.005124
# -0.108518    -0.017364
#
#   forecast_data_8w:
#            log_returns
# -0.159015    -0.019736
# -0.128949    -0.015539
#  0.218565     0.043700
#  0.212595    -0.006349
#
#   forecast_data_9w:
#           log_returns
# 0.210635    -0.003044
# 0.186369    -0.001896
# 0.177614    -0.011470
# 0.181815     0.009857
# 0.084217     0.019404
#
#   forecast_data_10w:
#           log_returns
# 0.076255    -0.002669
# 0.059579    -0.026644
# 0.080382     0.009772
# 0.130343     0.018958
# 0.197115    -0.025577
#
#   forecast_data_11w:
#           log_returns
# 0.210672    -0.012565
# 0.258046     0.020400
# 0.271584    -0.014909
# 0.208858    -0.010518
# 0.206830    -0.020367
#
#   forecast_data_12w:
#            log_returns
#  0.224971     0.007825
#  0.190259    -0.002176
#  0.160785     0.010533
#  0.122471    -0.001848
# -0.229899    -0.000006
#
#   forecast_data_13w:
#            log_returns
# -0.223086    -0.009634
# -0.215883    -0.008480
# -0.215765    -0.003521
# -0.230269    -0.005790
#
#   forecast_data_14w:
#            log_returns
# -0.256174     0.002363
# -0.345704    -0.012426
# -0.342227     0.000182
# -0.373540    -0.022609
# -0.367605     0.010621
#
#   forecast_data_15w:
#            log_returns
# -0.492723    -0.004317
# -0.603964    -0.000198
# -0.593972    -0.014137
# -0.657325     0.015249
# -0.578776    -0.023754
#
#   forecast_data_16w:
#            log_returns
# -0.469555    -0.026647
# -0.523768    -0.001165
# -0.517832    -0.018284
# -0.517375    -0.009271
# -0.413042    -0.034506
#
#   forecast_data_17w:
#            log_returns
# -0.369147     0.008266
# -0.250241     0.018204
# -0.249768    -0.003114
# -0.237617    -0.014533
# -0.085374     0.022437
#
#   forecast_data_18w:
#            log_returns
# -0.084399    -0.008026
# -0.030859    -0.025686
# -0.029850    -0.012922
#  0.029441     0.013082
#  0.079674     0.018934
#
#   forecast_data_19w:
#           log_returns
# 0.098451     0.014100
# 0.098622    -0.005530
# 0.095388    -0.005433
# 0.079371    -0.005402
# 0.015103    -0.001253
#
#   forecast_data_20w:
#            log_returns
# -0.051781    -0.002204
# -0.138715     0.005355
# -0.035870     0.021960
# -0.083513    -0.007946
# -0.094622    -0.005218
#
#   forecast_data_21w:
#            log_returns
# -0.327668     0.007551
# -0.328363    -0.005616
# -0.390171    -0.002578
# -0.380209    -0.008200
# -0.422587     0.005363
#
#   forecast_data_22w:
#            log_returns
# -0.530634     0.004649
# -0.521712    -0.010411
# -0.444989    -0.031466
# -0.477297    -0.005429
#
#   forecast_data_23w:
#            log_returns
# -0.520032     0.000721
# -0.624221    -0.001528
# -0.508173     0.024773
# -0.504515    -0.007411
# -0.503146    -0.005513
#
#   forecast_data_24w:
#            log_returns
# -0.505441     0.001925
# -0.490177     0.007311
# -0.429619     0.016383
# -0.435872     0.000694
# -0.551086     0.002594
#
#   forecast_data_25w:
#            log_returns
# -0.551476     0.006957
# -0.558367    -0.001501
# -0.521722    -0.015163
# -0.512669    -0.008462
#
#   forecast_data_26w:
#            log_returns
# -0.428363    -0.020735
# -0.394623     0.012280
# -0.403980    -0.003983
# -0.410830     0.001569
# -0.418515    -0.008221
#
#   forecast_data_27w:
#            log_returns
# -0.650171     0.002738
# -0.655519     0.003176
# -0.647762     0.005765
# -0.635302     0.007982
#
#   forecast_data_28w:
#            log_returns
# -0.803758    -0.001528
# -0.801107    -0.007524
# -0.796292     0.007690
# -0.567936    -0.029017
# -0.582683     0.001789
#
#   forecast_data_29w:
#            log_returns
# -0.662401     0.001608
# -0.663322    -0.004763
# -0.254358    -0.045419
# -0.279760    -0.008151
# -0.260930    -0.015801
#
#   forecast_data_30w:
#            log_returns
# -0.181488     0.017878
# -0.184278    -0.006302
#  0.099758    -0.047836
#  0.056426    -0.014760
#  0.096106     0.009318
#
#   forecast_data_31w:
#           log_returns
# 0.085935    -0.007984
# 0.121042    -0.022011
# 0.319129     0.030318
# 0.401092    -0.033211
# 0.480330    -0.036711
#
#   forecast_data_32w:
#           log_returns
# 0.535152    -0.038814
# 0.577951     0.009300
# 0.577050    -0.014592
# 0.803904     0.035797
# 0.781499     0.003758
#
#   forecast_data_33w:
#           log_returns
# 0.771207    -0.003102
# 0.890235     0.024651
# 0.891587    -0.003433
# 0.819411     0.023506
# 0.817844    -0.004032
#
#   forecast_data_34w:
#           log_returns
# 0.823083     0.009259
# 0.770425    -0.006524
# 0.775174     0.002104
# 0.581131    -0.024915
# 0.578884     0.009112
#
#   forecast_data_35w:
#           log_returns
# 0.583661    -0.015712
# 0.580545    -0.000535
# 0.566384    -0.019009
# 0.413684    -0.005084
# 0.299855     0.006805
#
#   forecast_data_36w:
#           log_returns
# 0.417288    -0.048005
# 0.220891    -0.007069
# 0.205718    -0.004699
# 0.333659    -0.034521
#
#   forecast_data_37w:
#           log_returns
# 0.122364     0.007235
# 0.130843     0.006455
# 0.236460     0.022018
# 0.130547     0.005796
# 0.136471     0.002238
#
#   forecast_data_38w:
#            log_returns
#  0.008615    -0.006218
#  0.008745    -0.003760
# -0.026497    -0.010165
#  0.149775     0.027623
#  0.143605    -0.006207
#
#   forecast_data_39w:
#           log_returns
# 0.075224    -0.004147
# 0.052611     0.002335
# 0.028748    -0.003696
# 0.049503     0.008724
# 0.020527    -0.012930
#
#   forecast_data_40w:
#            log_returns
#  0.019901    -0.000660
#  0.081119    -0.025087
# -0.281606     0.001308
# -0.286771     0.000548
# -0.264602     0.009971
#
#   forecast_data_41w:
#            log_returns
# -0.463569    -0.016266
# -0.430686     0.013656
# -0.434989     0.003984
# -0.551094    -0.005261
# -0.563379    -0.000969
#
#   forecast_data_42w:
#            log_returns
# -0.553481     0.006204
# -0.440662    -0.023992
# -0.439146    -0.005172
# -0.453810    -0.004148
# -0.674429     0.001044
#
#   forecast_data_43w:
#            log_returns
# -0.677113    -0.001063
# -0.676444    -0.004232
# -0.586646    -0.022443
# -0.585195    -0.001070
# -0.613567     0.002822
#
#   forecast_data_44w:
#            log_returns
# -0.633038    -0.001309
# -0.571521     0.012614
# -0.649445    -0.016601
# -0.385842    -0.036732
# -0.382886     0.002234
#
#   forecast_data_45w:
#            log_returns
# -0.428362    -0.007959
# -0.404836     0.011220
# -0.259953     0.028297
# -0.174195     0.019356
# -0.171217    -0.007384
#
#   forecast_data_46w:
#            log_returns
# -0.168319    -0.007046
# -0.183302    -0.000883
# -0.260922    -0.009443
# -0.242070    -0.012323
# -0.087499    -0.032211
#
#   forecast_data_47w:
#            log_returns
# -0.086327     0.001940
# -0.064444     0.007903
# -0.064480    -0.004441
# -0.126842     0.002251
# -0.126786    -0.003527
#
#   forecast_data_48w:
#            log_returns
# -0.131141    -0.002042
# -0.130782    -0.000984
# -0.146371    -0.016136
# -0.165431     0.004729
#
#
#
# ==================================================
#
#
# Ticker: IXN
# ==================================================
# Evaluation Metrics:
#   Mean Absolute Error (MAE): 0.004517556638449712
#   Mean Absolute Scaled Error (MASE): 0.2708000500447591
#
#
# Monthly Forecast Predictions (first 5 values for each period):
#   forecast_data_1m:
#            log_returns
# -0.563398    -0.036066
# -0.513995    -0.017214
# -0.553798    -0.010075
# -0.558890    -0.002957
# -0.389173     0.026737
#
#   forecast_data_2m:
#            log_returns
# -0.298145     0.012082
# -0.358246     0.008330
# -0.389732    -0.001043
# -0.380497    -0.006928
# -0.492548     0.012541
#
#   forecast_data_3m:
#            log_returns
# -0.285729     0.018212
# -0.314315    -0.001586
# -0.162156    -0.030951
# -0.139165     0.009201
# -0.084225     0.017023
#
#   forecast_data_4m:
#            log_returns
# -0.284437     0.000068
# -0.361592    -0.013479
# -0.361218    -0.000899
# -0.434951    -0.023451
# -0.426199     0.010649
#
#   forecast_data_5m:
#           log_returns
# 0.023004    -0.014374
# 0.090949     0.014267
# 0.238061     0.029972
# 0.249621     0.012865
# 0.251146    -0.007783
#
#   forecast_data_6m:
#            log_returns
# -0.409142     0.007129
# -0.622392    -0.000914
# -0.474333     0.027046
# -0.480920    -0.006697
# -0.478502    -0.003414
#
#   forecast_data_7m:
#            log_returns
# -0.301029     0.006951
# -0.316168     0.002171
# -0.289783     0.013858
# -0.292115     0.001180
# -0.431198     0.004447
#
#   forecast_data_8m:
#           log_returns
# 1.040045    -0.049411
# 1.063655    -0.038183
# 1.152503    -0.043818
# 1.177228     0.011132
# 1.173027    -0.018048
#
#   forecast_data_9m:
#           log_returns
# 0.896563    -0.060508
# 0.682381    -0.008752
# 0.668443    -0.007925
# 0.791711    -0.038308
# 0.623825     0.014548
#
#   forecast_data_10m:
#            log_returns
#  0.567349    -0.029635
#  0.099326     0.000885
#  0.093781    -0.004297
#  0.098000     0.006357
# -0.098558    -0.016517
#
#   forecast_data_11m:
#            log_returns
# -0.259522    -0.000247
# -0.285969    -0.006648
# -0.253147     0.012780
# -0.258470     0.016655
# -0.189851     0.019239
#
#
#
# Weekly Forecast Predictions (first 5 values for each period):
#   forecast_data_1w:
#            log_returns
# -0.563398    -0.036066
# -0.513995    -0.017214
# -0.553798    -0.010075
# -0.558890    -0.002957
#
#   forecast_data_2w:
#            log_returns
# -0.389173     0.026737
# -0.423093    -0.004265
# -0.419540     0.007244
# -0.428105     0.001624
# -0.434323     0.001383
#
#   forecast_data_3w:
#            log_returns
# -0.462471    -0.003186
# -0.452228    -0.009659
# -0.319184     0.022482
# -0.187436     0.023781
#
#   forecast_data_4w:
#            log_returns
# -0.186951     0.001524
# -0.260214     0.001074
# -0.278059     0.006045
# -0.278215     0.001884
# -0.238105    -0.015216
#
#   forecast_data_5w:
#            log_returns
# -0.226806     0.006800
# -0.199562    -0.012792
# -0.084362    -0.027126
# -0.298145     0.012082
# -0.358246     0.008330
#
#   forecast_data_6w:
#            log_returns
# -0.389732    -0.001043
# -0.380497    -0.006928
# -0.492548     0.012541
# -0.500809     0.002177
# -0.489486     0.010200
#
#   forecast_data_7w:
#            log_returns
# -0.438423    -0.013486
# -0.299681    -0.025024
# -0.280991     0.010176
# -0.298598    -0.004625
# -0.361280    -0.014318
#
#   forecast_data_8w:
#            log_returns
# -0.470127    -0.015234
# -0.463144    -0.010453
# -0.164080     0.035343
# -0.175987    -0.003364
#
#   forecast_data_9w:
#            log_returns
# -0.179694    -0.002563
# -0.210355    -0.004766
# -0.219024    -0.008732
# -0.220522     0.007479
# -0.285729     0.018212
#
#   forecast_data_10w:
#            log_returns
# -0.314315    -0.001586
# -0.162156    -0.030951
# -0.139165     0.009201
# -0.084225     0.017023
# -0.049322    -0.021244
#
#   forecast_data_11w:
#            log_returns
# -0.038869    -0.011775
#  0.039680     0.022253
#  0.046655    -0.015155
# -0.045208    -0.004679
# -0.004839    -0.021906
#
#   forecast_data_12w:
#            log_returns
#  0.001405     0.003320
# -0.022899     0.000933
# -0.019670     0.013974
# -0.038855    -0.001289
# -0.284995    -0.001162
#
#   forecast_data_13w:
#            log_returns
# -0.269555    -0.010600
# -0.258382    -0.009919
# -0.259507    -0.001137
# -0.265611    -0.005986
#
#   forecast_data_14w:
#            log_returns
# -0.284437     0.000068
# -0.361592    -0.013479
# -0.361218    -0.000899
# -0.434951    -0.023451
# -0.426199     0.010649
#
#   forecast_data_15w:
#            log_returns
# -0.527678    -0.006055
# -0.590929     0.002357
# -0.559056    -0.017488
# -0.569000     0.021272
# -0.490096    -0.024979
#
#   forecast_data_16w:
#            log_returns
# -0.391731    -0.025417
# -0.454604    -0.001659
# -0.383025    -0.024445
# -0.373481    -0.015610
# -0.306943    -0.035184
#
#   forecast_data_17w:
#            log_returns
# -0.264397     0.008126
# -0.162324     0.016395
# -0.148427     0.001896
# -0.149308    -0.005047
# -0.076460     0.014678
#
#   forecast_data_18w:
#            log_returns
# -0.069094     0.000943
#  0.019552    -0.029971
#  0.023004    -0.014374
#  0.090949     0.014267
#  0.238061     0.029972
#
#   forecast_data_19w:
#           log_returns
# 0.249621     0.012865
# 0.251146    -0.007783
# 0.247160    -0.000289
# 0.220061    -0.006778
# 0.120549     0.000963
#
#   forecast_data_20w:
#            log_returns
#  0.048074     0.000671
# -0.020493     0.008669
#  0.072998     0.022143
# -0.017029    -0.009155
# -0.049241    -0.008823
#
#   forecast_data_21w:
#            log_returns
# -0.296717     0.010624
# -0.297697    -0.002614
# -0.334621    -0.003016
# -0.333149    -0.001372
# -0.334663     0.007480
#
#   forecast_data_22w:
#            log_returns
# -0.357715     0.007867
# -0.316193    -0.013190
# -0.341763    -0.028150
# -0.383194    -0.007369
#
#   forecast_data_23w:
#            log_returns
# -0.409142     0.007129
# -0.622392    -0.000914
# -0.474333     0.027046
# -0.480920    -0.006697
# -0.478502    -0.003414
#
#   forecast_data_24w:
#            log_returns
# -0.491061    -0.000595
# -0.459119     0.011935
# -0.304074     0.027685
# -0.311778     0.003343
# -0.400072    -0.001626
#
#   forecast_data_25w:
#            log_returns
# -0.400349     0.011628
# -0.428225     0.000962
# -0.351905    -0.019508
# -0.321293    -0.012160
#
#   forecast_data_26w:
#            log_returns
# -0.155006    -0.029317
# -0.105724     0.015777
# -0.113485    -0.004559
# -0.126449    -0.003252
# -0.149814    -0.006436
#
#   forecast_data_27w:
#            log_returns
# -0.301029     0.006951
# -0.316168     0.002171
# -0.289783     0.013858
# -0.292115     0.001180
#
#   forecast_data_28w:
#            log_returns
# -0.431198     0.004447
# -0.433937    -0.005792
# -0.400245     0.014223
# -0.157792    -0.033879
# -0.183790     0.002331
#
#   forecast_data_29w:
#            log_returns
# -0.351969    -0.004210
# -0.358177    -0.004511
#  0.111105    -0.053715
#  0.066144    -0.008871
#  0.092265    -0.021035
#
#   forecast_data_30w:
#           log_returns
# 0.161445     0.018674
# 0.153408    -0.006097
# 0.423844    -0.054561
# 0.371211    -0.018471
# 0.409639     0.009454
#
#   forecast_data_31w:
#           log_returns
# 0.408898    -0.009914
# 0.473781    -0.029030
# 0.848979     0.048355
# 1.040045    -0.049411
# 1.063655    -0.038183
#
#   forecast_data_32w:
#           log_returns
# 1.152503    -0.043818
# 1.177228     0.011132
# 1.173027    -0.018048
# 1.359762     0.037561
# 1.330479     0.001519
#
#   forecast_data_33w:
#           log_returns
# 1.333593     0.003756
# 1.507659     0.032120
# 1.514170     0.000220
# 1.420838     0.027184
# 1.421025    -0.000945
#
#   forecast_data_34w:
#           log_returns
# 1.422456     0.013108
# 1.375654    -0.009384
# 1.380464     0.002832
# 1.197709    -0.032421
# 1.202704     0.014811
#
#   forecast_data_35w:
#           log_returns
# 1.234099    -0.023475
# 1.233570     0.004280
# 1.182502    -0.018903
# 0.897875    -0.013825
# 0.648561     0.007465
#
#   forecast_data_36w:
#           log_returns
# 0.896563    -0.060508
# 0.682381    -0.008752
# 0.668443    -0.007925
# 0.791711    -0.038308
#
#   forecast_data_37w:
#           log_returns
# 0.623825     0.014548
# 0.639442     0.008198
# 0.813291     0.034450
# 0.668408     0.004708
# 0.669246     0.000403
#
#   forecast_data_38w:
#           log_returns
# 0.540236    -0.010964
# 0.537759    -0.007751
# 0.488373    -0.011590
# 0.665881     0.030559
# 0.663593    -0.012460
#
#   forecast_data_39w:
#           log_returns
# 0.571244    -0.003607
# 0.522732     0.002036
# 0.476908    -0.004744
# 0.514992     0.014799
# 0.511875    -0.017895
#
#   forecast_data_40w:
#           log_returns
# 0.497598    -0.003759
# 0.567349    -0.029635
# 0.099326     0.000885
# 0.093781    -0.004297
# 0.098000     0.006357
#
#   forecast_data_41w:
#            log_returns
# -0.098558    -0.016517
# -0.084689     0.016818
# -0.080891     0.009413
# -0.321352    -0.008981
# -0.332774    -0.001045
#
#   forecast_data_42w:
#            log_returns
# -0.312127     0.008254
# -0.192083    -0.028569
# -0.196491    -0.004470
# -0.206972     0.003159
# -0.443730    -0.000187
#
#   forecast_data_43w:
#            log_returns
# -0.461871    -0.000102
# -0.461091    -0.004904
# -0.380495    -0.022975
# -0.379071    -0.001401
# -0.455704     0.001088
#
#   forecast_data_44w:
#            log_returns
# -0.496710    -0.005443
# -0.451421     0.010713
# -0.532195    -0.022492
# -0.263008    -0.038848
# -0.259522    -0.000247
#
#   forecast_data_45w:
#            log_returns
# -0.285969    -0.006648
# -0.253147     0.012780
# -0.258470     0.016655
# -0.189851     0.019239
# -0.188496    -0.009344
#
#   forecast_data_46w:
#            log_returns
# -0.169159    -0.014087
# -0.201133    -0.003826
# -0.311554    -0.008428
# -0.309827    -0.006472
# -0.200500    -0.029391
#
#   forecast_data_47w:
#            log_returns
# -0.194679     0.002662
# -0.189997     0.002242
# -0.189670    -0.006605
# -0.240886     0.004137
# -0.240740    -0.000988
#
#   forecast_data_48w:
#            log_returns
# -0.245093    -0.001297
# -0.243152    -0.000413
# -0.254605    -0.017088
# -0.283922     0.008644
#
#
#
# ==================================================

# %% [markdown]
# ### Ratios

# %%
def calculate_sharpe_ratio(returns, annual_risk_free_rate=0.1,period='daily'):
    #excess_returns = rate_of_return(returns) - risk_free_rate
    
    # Convert annual risk-free rate to daily rate
    daily_risk_free_rate = (1 + annual_risk_free_rate) ** (1/252) - 1
    
    # Calculate mean daily log return
    mean_return = np.mean(returns)
    
    # Calculate excess daily log return
    excess_return = mean_return - daily_risk_free_rate
    
    # Calculate standard deviation of daily log returns
    std_return = np.std(returns)
    
    # Print diagnostic information
    #print(f"Mean Daily Log Return: {mean_return}")
    #print(f"Excess Daily Log Return: {excess_return}")
    #print(f"Standard Deviation of Daily Log Returns: {std_return}")
    
    # Check for zero standard deviation to avoid division by zero
    if std_return == 0:
        return 0
    
    # Calculate Sharpe ratio
    sharpe_ratio = (excess_return / std_return) * np.sqrt(252)  # Annualize the Sharpe ratio
    return sharpe_ratio
    #return excess_returns / np.std(returns)


def calculate_rachev_ratio(returns, lower_percentile=5, upper_percentile=95):
    # Step 1: Sort the returns
    sorted_returns = np.sort(returns)
    
    # Step 2: Determine the percentiles
    lower_threshold = np.percentile(sorted_returns, lower_percentile)
    upper_threshold = np.percentile(sorted_returns, upper_percentile)
    
    # Step 3: Calculate Expected Shortfall (ES)
    es = np.mean(sorted_returns[sorted_returns <= lower_threshold])
    
    # Step 4: Calculate Expected Gain (EG)
    eg = np.mean(sorted_returns[sorted_returns >= upper_threshold])
    
    # Step 5: Compute the Rachev Ratio
    rachev_ratio = eg / -es
    return rachev_ratio


"""def calculate_volatility_clustering(returns):
    squared_returns = returns ** 2
    n = len(squared_returns)
    
    # Mean of squared returns
    mean_squared_returns = np.mean(squared_returns)
    
    # Calculate the numerator and denominator for autocorrelation at lag 1
    numerator = np.sum((squared_returns[:-1] - mean_squared_returns) * (squared_returns[1:] - mean_squared_returns))
    denominator = np.sum((squared_returns - mean_squared_returns) ** 2)
    
    if denominator == 0:
        return 0  # Avoid division by zero
    
    rho_1 = numerator / denominator
    return rho_1"""
def calculate_volatility_clustering(returns):
    # Ensure returns is a NumPy array
    returns = np.array(returns)
    squared_returns = returns ** 2
    n = len(squared_returns)

    # Mean of squared returns
    mean_squared = np.mean(squared_returns)
    clustering = np.sum((squared_returns - mean_squared) ** 2) / (n - 1 if n > 1 else 1)
    return clustering

def calculate_sortino_ratio(log_returns, target_log_return=0.0):
    """
    Calculate the Sortino Ratio using log returns.
    
    Parameters:
    - log_returns (array-like): Array or list of log returns for the period.
    - target_log_return (float): The target log return. Default is 0, which is often used as a benchmark.
    
    Returns:
    - float: The Sortino Ratio.
    """
    # Convert input to a NumPy array for easier calculations
    log_returns = np.array(log_returns)
    
    # Calculate the average period log return (R)
    avg_log_return = np.mean(log_returns)
    
    # Calculate the Target Downside Deviation (TDD)
    downside_deviation = np.sqrt(
        np.mean(np.square(np.maximum(0, target_log_return - log_returns)))
    )
    
    # Calculate Sortino Ratio
    #sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
    epsilon = 1e-8
    
    # Add epsilon to downside_deviation to prevent division by zero
    #if downside_deviation == 0:
     #   return np.nan  # Return NaN if downside deviation is zero
    
    # Calculate Sortino Ratio
    sortino_ratio_value = (avg_log_return - target_log_return) / (downside_deviation + epsilon)
    
    return sortino_ratio_value

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, volatility_clustering, 
    mean_forecast, std_forecast, mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
    mean_volatility_clustering, std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    # Normalize the components with epsilon
    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    return score

def calculate_smoothing(data, alpha=0.1):
    if len(data) == 0:  # Explicitly check if the data is empty
        return []
    smoothed_data = []
    previous_value = data[0]
    for value in data:
        smoothed_value = alpha * value + (1 - alpha) * previous_value
        smoothed_data.append(smoothed_value)
        previous_value = smoothed_value
    return smoothed_data



def process_etf_data_weekly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = {}

    for etf_name in tickers:
        etf_data = etf_dict.get(etf_name, {})
        weekly_forecast_results = etf_data.get("weekly_forecast_results", {})
        etf_pred_dict[etf_name] = {}

        # Extract forecast periods from weekly_forecast_results
        forecast_periods = [key.split('_')[-1] for key in weekly_forecast_results.keys()]

        for period in forecast_periods:
            forecast_key = f"forecast_data_{period}"
            if forecast_key in weekly_forecast_results:
                # Extract the forecasted DataFrame
                forecast_df = weekly_forecast_results[forecast_key]
                returns = forecast_df["log_returns"].values  # Assuming 'log_returns' is the column of interest
                etf_pred_dict[etf_name][f"returns_{period}"] = returns

                if smoothing:
                    # Apply smoothing
                    smoothed_returns = calculate_smoothing(returns)
                    etf_pred_dict[etf_name][f"smoothed_returns_{period}"] = smoothed_returns

                    # Calculate metrics using smoothed returns
                    etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(smoothed_returns)
                    etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(smoothed_returns)
                    etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(smoothed_returns)
                    etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(smoothed_returns)
                else:
                    # Calculate metrics using raw returns
                    etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
                    etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
                    etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
                    etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict



def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )



def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

    return scores



def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()


def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []

    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)

    return week_ranges



def gather_etf_data_for_weeks(selected_tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in selected_tickers:
            print(f"Fetching data for {ticker} from {start_date} to {end_date}...")
            etf_data = yf.download(ticker, start=start_date, end=end_date, progress=False)
            if not etf_data.empty:
                etf_histories[week][ticker] = etf_data
            else:
                print(f"No data found for {ticker} in {week}")
    return etf_histories



def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]

    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)

        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]

            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            ticker_shares[ticker] = num_shares
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares


def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"\nTop 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares


def main_weekly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict, smoothing=smoothing)

    risk_percentage = 0.10
    weekly_scores = {}

    # Calculate scores for all weeks
    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores

    # Convert scores to DataFrames
    weekly_scores_dfs = {}
    for week_key, scores in weekly_scores.items():
        weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    # Select top ETFs for each week
    top_etfs_weekly = {}
    for week_key, df_scores in weekly_scores_dfs.items():
        top_etfs_weekly[week_key] = df_scores.nlargest(2, 'Score')

    # Generate week ranges for ETF data gathering
    week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')

    # Gather ETF historical data
    etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)

    # Map week keys to date ranges
    week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

    # Align top ETFs with historical data
    aligned_top_etfs_weekly = {}
    for week_key, df_scores in weekly_scores_dfs.items():
        forecast_period = week_key_mapping.get(week_key, None)
        if forecast_period:
            aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

    # Initialize and manage portfolio
    ticker_shares = {}
    ticker_shares_per_week = {}
    for i, week_range in enumerate(etf_histories.keys()):
        current_week_key = week_range
        if i == 0:
            # Initialize shares for the first week
            ticker_shares = initialize_shares_for_first_week(
                aligned_top_etfs_weekly[current_week_key],
                etf_histories,
                current_week_key
            )
            ticker_shares_per_week[current_week_key] = ticker_shares.copy()
        else:
            # Manage portfolio for subsequent weeks
            prev_week_key = list(etf_histories.keys())[i - 1]
            ticker_shares = manage_etf_portfolio_weekly(
                aligned_top_etfs_weekly[prev_week_key],
                aligned_top_etfs_weekly[current_week_key],
                prev_week_key,
                current_week_key,
                ticker_shares,
                etf_histories
            )
            ticker_shares_per_week[current_week_key] = ticker_shares.copy()

    # Define the first trading day of the 49th week
    first_trading_day_49w = '2024-12-01'

    # Identify the 48th and 49th week date ranges
    week_48_range = list(ticker_shares_per_week.keys())[-1]
    week_49_start = first_trading_day_49w
    print(f"Using data for the 48th week: {week_48_range}")
    print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

    week_49_end = '2024-12-06'
    etf_values_49w = {}

    # Ensure 48th week data exists
    if week_48_range in ticker_shares_per_week:
        ticker_shares_48w = ticker_shares_per_week[week_48_range]

        # Fetch the first trading day price of the 49th week for each ETF
        for ticker, shares in ticker_shares_48w.items():
            print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
            data = yf.download(ticker, start=week_49_start, end=week_49_end)

            if not data.empty:
                closing_price_49w = data['Close'].iloc[0]
                total_value = shares * closing_price_49w
                etf_values_49w[ticker] = total_value
                print(f"{ticker}: {shares:.2f} shares at ${closing_price_49w:.2f} each, total value: ${total_value:.2f}")
            else:
                print(f"{ticker}: No data available for the 49th week's first trading day.")
    else:
        print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")

    # Display total portfolio value for the 49th week's first trading day
    if etf_values_49w:
        print("\nETF values on the 49th week's first trading day:")
        total_value = sum(etf_values_49w.values())
        print(f"Total portfolio value: {total_value:.2f}")
        for ticker, value in etf_values_49w.items():
            print(f"{ticker}: {value:.2f}")
    else:
        print("No values could be calculated for the 49th week's first trading day.")

    return ticker_shares_per_week

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_week = main_weekly(tickers, results, smoothing=False)
# Out:
# Fetching data for SMH from 2024-01-01 to 2024-01-07...
# Fetching data for SOXX from 2024-01-01 to 2024-01-07...
# Fetching data for PSI from 2024-01-01 to 2024-01-07...
# Fetching data for XSD from 2024-01-01 to 2024-01-07...
# Fetching data for IYW from 2024-01-01 to 2024-01-07...
# Fetching data for XLK from 2024-01-01 to 2024-01-07...
# Fetching data for VGT from 2024-01-01 to 2024-01-07...
# Fetching data for FTEC from 2024-01-01 to 2024-01-07...
# Fetching data for IGM from 2024-01-01 to 2024-01-07...
# Fetching data for IXN from 2024-01-01 to 2024-01-07...
# Fetching data for SMH from 2024-01-08 to 2024-01-14...
# Fetching data for SOXX from 2024-01-08 to 2024-01-14...
# Fetching data for PSI from 2024-01-08 to 2024-01-14...
# Fetching data for XSD from 2024-01-08 to 2024-01-14...
# Fetching data for IYW from 2024-01-08 to 2024-01-14...
# Fetching data for XLK from 2024-01-08 to 2024-01-14...
# Fetching data for VGT from 2024-01-08 to 2024-01-14...
# Fetching data for FTEC from 2024-01-08 to 2024-01-14...
# Fetching data for IGM from 2024-01-08 to 2024-01-14...
# Fetching data for IXN from 2024-01-08 to 2024-01-14...
# Fetching data for SMH from 2024-01-15 to 2024-01-21...
# Fetching data for SOXX from 2024-01-15 to 2024-01-21...
# Fetching data for PSI from 2024-01-15 to 2024-01-21...
# Fetching data for XSD from 2024-01-15 to 2024-01-21...
# Fetching data for IYW from 2024-01-15 to 2024-01-21...
# Fetching data for XLK from 2024-01-15 to 2024-01-21...
# Fetching data for VGT from 2024-01-15 to 2024-01-21...
# Fetching data for FTEC from 2024-01-15 to 2024-01-21...
# Fetching data for IGM from 2024-01-15 to 2024-01-21...
# Fetching data for IXN from 2024-01-15 to 2024-01-21...
# Fetching data for SMH from 2024-01-22 to 2024-01-28...
# Fetching data for SOXX from 2024-01-22 to 2024-01-28...
# Fetching data for PSI from 2024-01-22 to 2024-01-28...
# Fetching data for XSD from 2024-01-22 to 2024-01-28...
# Fetching data for IYW from 2024-01-22 to 2024-01-28...
# Fetching data for XLK from 2024-01-22 to 2024-01-28...
# Fetching data for VGT from 2024-01-22 to 2024-01-28...
# Fetching data for FTEC from 2024-01-22 to 2024-01-28...
# Fetching data for IGM from 2024-01-22 to 2024-01-28...
# Fetching data for IXN from 2024-01-22 to 2024-01-28...
# Fetching data for SMH from 2024-01-29 to 2024-02-04...
# Fetching data for SOXX from 2024-01-29 to 2024-02-04...
# Fetching data for PSI from 2024-01-29 to 2024-02-04...
# Fetching data for XSD from 2024-01-29 to 2024-02-04...
# Fetching data for IYW from 2024-01-29 to 2024-02-04...
# Fetching data for XLK from 2024-01-29 to 2024-02-04...
# Fetching data for VGT from 2024-01-29 to 2024-02-04...
# Fetching data for FTEC from 2024-01-29 to 2024-02-04...
# Fetching data for IGM from 2024-01-29 to 2024-02-04...
# Fetching data for IXN from 2024-01-29 to 2024-02-04...
# Fetching data for SMH from 2024-02-05 to 2024-02-11...
# Fetching data for SOXX from 2024-02-05 to 2024-02-11...
# Fetching data for PSI from 2024-02-05 to 2024-02-11...
# Fetching data for XSD from 2024-02-05 to 2024-02-11...
# Fetching data for IYW from 2024-02-05 to 2024-02-11...
# Fetching data for XLK from 2024-02-05 to 2024-02-11...
# Fetching data for VGT from 2024-02-05 to 2024-02-11...
# Fetching data for FTEC from 2024-02-05 to 2024-02-11...
# Fetching data for IGM from 2024-02-05 to 2024-02-11...
# Fetching data for IXN from 2024-02-05 to 2024-02-11...
# Fetching data for SMH from 2024-02-12 to 2024-02-18...
# Fetching data for SOXX from 2024-02-12 to 2024-02-18...
# Fetching data for PSI from 2024-02-12 to 2024-02-18...
# Fetching data for XSD from 2024-02-12 to 2024-02-18...
# Fetching data for IYW from 2024-02-12 to 2024-02-18...
# Fetching data for XLK from 2024-02-12 to 2024-02-18...
# Fetching data for VGT from 2024-02-12 to 2024-02-18...
# Fetching data for FTEC from 2024-02-12 to 2024-02-18...
# Fetching data for IGM from 2024-02-12 to 2024-02-18...
# Fetching data for IXN from 2024-02-12 to 2024-02-18...
# Fetching data for SMH from 2024-02-19 to 2024-02-25...
# Fetching data for SOXX from 2024-02-19 to 2024-02-25...
# Fetching data for PSI from 2024-02-19 to 2024-02-25...
# Fetching data for XSD from 2024-02-19 to 2024-02-25...
# Fetching data for IYW from 2024-02-19 to 2024-02-25...
# Fetching data for XLK from 2024-02-19 to 2024-02-25...
# Fetching data for VGT from 2024-02-19 to 2024-02-25...
# Fetching data for FTEC from 2024-02-19 to 2024-02-25...
# Fetching data for IGM from 2024-02-19 to 2024-02-25...
# Fetching data for IXN from 2024-02-19 to 2024-02-25...
# Fetching data for SMH from 2024-02-26 to 2024-03-03...
# Fetching data for SOXX from 2024-02-26 to 2024-03-03...
# Fetching data for PSI from 2024-02-26 to 2024-03-03...
# Fetching data for XSD from 2024-02-26 to 2024-03-03...
# Fetching data for IYW from 2024-02-26 to 2024-03-03...
# Fetching data for XLK from 2024-02-26 to 2024-03-03...
# Fetching data for VGT from 2024-02-26 to 2024-03-03...
# Fetching data for FTEC from 2024-02-26 to 2024-03-03...
# Fetching data for IGM from 2024-02-26 to 2024-03-03...
# Fetching data for IXN from 2024-02-26 to 2024-03-03...
# Fetching data for SMH from 2024-03-04 to 2024-03-10...
# Fetching data for SOXX from 2024-03-04 to 2024-03-10...
# Fetching data for PSI from 2024-03-04 to 2024-03-10...
# Fetching data for XSD from 2024-03-04 to 2024-03-10...
# Fetching data for IYW from 2024-03-04 to 2024-03-10...
# Fetching data for XLK from 2024-03-04 to 2024-03-10...
# Fetching data for VGT from 2024-03-04 to 2024-03-10...
# Fetching data for FTEC from 2024-03-04 to 2024-03-10...
# Fetching data for IGM from 2024-03-04 to 2024-03-10...
# Fetching data for IXN from 2024-03-04 to 2024-03-10...
# Fetching data for SMH from 2024-03-11 to 2024-03-17...
# Fetching data for SOXX from 2024-03-11 to 2024-03-17...
# Fetching data for PSI from 2024-03-11 to 2024-03-17...
# Fetching data for XSD from 2024-03-11 to 2024-03-17...
# Fetching data for IYW from 2024-03-11 to 2024-03-17...
# Fetching data for XLK from 2024-03-11 to 2024-03-17...
# Fetching data for VGT from 2024-03-11 to 2024-03-17...
# Fetching data for FTEC from 2024-03-11 to 2024-03-17...
# Fetching data for IGM from 2024-03-11 to 2024-03-17...
# Fetching data for IXN from 2024-03-11 to 2024-03-17...
# Fetching data for SMH from 2024-03-18 to 2024-03-24...
# Fetching data for SOXX from 2024-03-18 to 2024-03-24...
# Fetching data for PSI from 2024-03-18 to 2024-03-24...
# Fetching data for XSD from 2024-03-18 to 2024-03-24...
# Fetching data for IYW from 2024-03-18 to 2024-03-24...
# Fetching data for XLK from 2024-03-18 to 2024-03-24...
# Fetching data for VGT from 2024-03-18 to 2024-03-24...
# Fetching data for FTEC from 2024-03-18 to 2024-03-24...
# Fetching data for IGM from 2024-03-18 to 2024-03-24...
# Fetching data for IXN from 2024-03-18 to 2024-03-24...
# Fetching data for SMH from 2024-03-25 to 2024-03-31...
# Fetching data for SOXX from 2024-03-25 to 2024-03-31...
# Fetching data for PSI from 2024-03-25 to 2024-03-31...
# Fetching data for XSD from 2024-03-25 to 2024-03-31...
# Fetching data for IYW from 2024-03-25 to 2024-03-31...
# Fetching data for XLK from 2024-03-25 to 2024-03-31...
# Fetching data for VGT from 2024-03-25 to 2024-03-31...
# Fetching data for FTEC from 2024-03-25 to 2024-03-31...
# Fetching data for IGM from 2024-03-25 to 2024-03-31...
# Fetching data for IXN from 2024-03-25 to 2024-03-31...
# Fetching data for SMH from 2024-04-01 to 2024-04-07...
# Fetching data for SOXX from 2024-04-01 to 2024-04-07...
# Fetching data for PSI from 2024-04-01 to 2024-04-07...
# Fetching data for XSD from 2024-04-01 to 2024-04-07...
# Fetching data for IYW from 2024-04-01 to 2024-04-07...
# Fetching data for XLK from 2024-04-01 to 2024-04-07...
# Fetching data for VGT from 2024-04-01 to 2024-04-07...
# Fetching data for FTEC from 2024-04-01 to 2024-04-07...
# Fetching data for IGM from 2024-04-01 to 2024-04-07...
# Fetching data for IXN from 2024-04-01 to 2024-04-07...
# Fetching data for SMH from 2024-04-08 to 2024-04-14...
# Fetching data for SOXX from 2024-04-08 to 2024-04-14...
# Fetching data for PSI from 2024-04-08 to 2024-04-14...
# Fetching data for XSD from 2024-04-08 to 2024-04-14...
# Fetching data for IYW from 2024-04-08 to 2024-04-14...
# Fetching data for XLK from 2024-04-08 to 2024-04-14...
# Fetching data for VGT from 2024-04-08 to 2024-04-14...
# Fetching data for FTEC from 2024-04-08 to 2024-04-14...
# Fetching data for IGM from 2024-04-08 to 2024-04-14...
# Fetching data for IXN from 2024-04-08 to 2024-04-14...
# Fetching data for SMH from 2024-04-15 to 2024-04-21...
# Fetching data for SOXX from 2024-04-15 to 2024-04-21...
# Fetching data for PSI from 2024-04-15 to 2024-04-21...
# Fetching data for XSD from 2024-04-15 to 2024-04-21...
# Fetching data for IYW from 2024-04-15 to 2024-04-21...
# Fetching data for XLK from 2024-04-15 to 2024-04-21...
# Fetching data for VGT from 2024-04-15 to 2024-04-21...
# Fetching data for FTEC from 2024-04-15 to 2024-04-21...
# Fetching data for IGM from 2024-04-15 to 2024-04-21...
# Fetching data for IXN from 2024-04-15 to 2024-04-21...
# Fetching data for SMH from 2024-04-22 to 2024-04-28...
# Fetching data for SOXX from 2024-04-22 to 2024-04-28...
# Fetching data for PSI from 2024-04-22 to 2024-04-28...
# Fetching data for XSD from 2024-04-22 to 2024-04-28...
# Fetching data for IYW from 2024-04-22 to 2024-04-28...
# Fetching data for XLK from 2024-04-22 to 2024-04-28...
# Fetching data for VGT from 2024-04-22 to 2024-04-28...
# Fetching data for FTEC from 2024-04-22 to 2024-04-28...
# Fetching data for IGM from 2024-04-22 to 2024-04-28...
# Fetching data for IXN from 2024-04-22 to 2024-04-28...
# Fetching data for SMH from 2024-04-29 to 2024-05-05...
# Fetching data for SOXX from 2024-04-29 to 2024-05-05...
# Fetching data for PSI from 2024-04-29 to 2024-05-05...
# Fetching data for XSD from 2024-04-29 to 2024-05-05...
# Fetching data for IYW from 2024-04-29 to 2024-05-05...
# Fetching data for XLK from 2024-04-29 to 2024-05-05...
# Fetching data for VGT from 2024-04-29 to 2024-05-05...
# Fetching data for FTEC from 2024-04-29 to 2024-05-05...
# Fetching data for IGM from 2024-04-29 to 2024-05-05...
# Fetching data for IXN from 2024-04-29 to 2024-05-05...
# Fetching data for SMH from 2024-05-06 to 2024-05-12...
# Fetching data for SOXX from 2024-05-06 to 2024-05-12...
# Fetching data for PSI from 2024-05-06 to 2024-05-12...
# Fetching data for XSD from 2024-05-06 to 2024-05-12...
# Fetching data for IYW from 2024-05-06 to 2024-05-12...
# Fetching data for XLK from 2024-05-06 to 2024-05-12...
# Fetching data for VGT from 2024-05-06 to 2024-05-12...
# Fetching data for FTEC from 2024-05-06 to 2024-05-12...
# Fetching data for IGM from 2024-05-06 to 2024-05-12...
# Fetching data for IXN from 2024-05-06 to 2024-05-12...
# Fetching data for SMH from 2024-05-13 to 2024-05-19...
# Fetching data for SOXX from 2024-05-13 to 2024-05-19...
# Fetching data for PSI from 2024-05-13 to 2024-05-19...
# Fetching data for XSD from 2024-05-13 to 2024-05-19...
# Fetching data for IYW from 2024-05-13 to 2024-05-19...
# Fetching data for XLK from 2024-05-13 to 2024-05-19...
# Fetching data for VGT from 2024-05-13 to 2024-05-19...
# Fetching data for FTEC from 2024-05-13 to 2024-05-19...
# Fetching data for IGM from 2024-05-13 to 2024-05-19...
# Fetching data for IXN from 2024-05-13 to 2024-05-19...
# Fetching data for SMH from 2024-05-20 to 2024-05-26...
# Fetching data for SOXX from 2024-05-20 to 2024-05-26...
# Fetching data for PSI from 2024-05-20 to 2024-05-26...
# Fetching data for XSD from 2024-05-20 to 2024-05-26...
# Fetching data for IYW from 2024-05-20 to 2024-05-26...
# Fetching data for XLK from 2024-05-20 to 2024-05-26...
# Fetching data for VGT from 2024-05-20 to 2024-05-26...
# Fetching data for FTEC from 2024-05-20 to 2024-05-26...
# Fetching data for IGM from 2024-05-20 to 2024-05-26...
# Fetching data for IXN from 2024-05-20 to 2024-05-26...
# Fetching data for SMH from 2024-05-27 to 2024-06-02...
# Fetching data for SOXX from 2024-05-27 to 2024-06-02...
# Fetching data for PSI from 2024-05-27 to 2024-06-02...
# Fetching data for XSD from 2024-05-27 to 2024-06-02...
# Fetching data for IYW from 2024-05-27 to 2024-06-02...
# Fetching data for XLK from 2024-05-27 to 2024-06-02...
# Fetching data for VGT from 2024-05-27 to 2024-06-02...
# Fetching data for FTEC from 2024-05-27 to 2024-06-02...
# Fetching data for IGM from 2024-05-27 to 2024-06-02...
# Fetching data for IXN from 2024-05-27 to 2024-06-02...
# Fetching data for SMH from 2024-06-03 to 2024-06-09...
# Fetching data for SOXX from 2024-06-03 to 2024-06-09...
# Fetching data for PSI from 2024-06-03 to 2024-06-09...
# Fetching data for XSD from 2024-06-03 to 2024-06-09...
# Fetching data for IYW from 2024-06-03 to 2024-06-09...
# Fetching data for XLK from 2024-06-03 to 2024-06-09...
# Fetching data for VGT from 2024-06-03 to 2024-06-09...
# Fetching data for FTEC from 2024-06-03 to 2024-06-09...
# Fetching data for IGM from 2024-06-03 to 2024-06-09...
# Fetching data for IXN from 2024-06-03 to 2024-06-09...
# Fetching data for SMH from 2024-06-10 to 2024-06-16...
# Fetching data for SOXX from 2024-06-10 to 2024-06-16...
# Fetching data for PSI from 2024-06-10 to 2024-06-16...
# Fetching data for XSD from 2024-06-10 to 2024-06-16...
# Fetching data for IYW from 2024-06-10 to 2024-06-16...
# Fetching data for XLK from 2024-06-10 to 2024-06-16...
# Fetching data for VGT from 2024-06-10 to 2024-06-16...
# Fetching data for FTEC from 2024-06-10 to 2024-06-16...
# Fetching data for IGM from 2024-06-10 to 2024-06-16...
# Fetching data for IXN from 2024-06-10 to 2024-06-16...
# Fetching data for SMH from 2024-06-17 to 2024-06-23...
# Fetching data for SOXX from 2024-06-17 to 2024-06-23...
# Fetching data for PSI from 2024-06-17 to 2024-06-23...
# Fetching data for XSD from 2024-06-17 to 2024-06-23...
# Fetching data for IYW from 2024-06-17 to 2024-06-23...
# Fetching data for XLK from 2024-06-17 to 2024-06-23...
# Fetching data for VGT from 2024-06-17 to 2024-06-23...
# Fetching data for FTEC from 2024-06-17 to 2024-06-23...
# Fetching data for IGM from 2024-06-17 to 2024-06-23...
# Fetching data for IXN from 2024-06-17 to 2024-06-23...
# Fetching data for SMH from 2024-06-24 to 2024-06-30...
# Fetching data for SOXX from 2024-06-24 to 2024-06-30...
# Fetching data for PSI from 2024-06-24 to 2024-06-30...
# Fetching data for XSD from 2024-06-24 to 2024-06-30...
# Fetching data for IYW from 2024-06-24 to 2024-06-30...
# Fetching data for XLK from 2024-06-24 to 2024-06-30...
# Fetching data for VGT from 2024-06-24 to 2024-06-30...
# Fetching data for FTEC from 2024-06-24 to 2024-06-30...
# Fetching data for IGM from 2024-06-24 to 2024-06-30...
# Fetching data for IXN from 2024-06-24 to 2024-06-30...
# Fetching data for SMH from 2024-07-01 to 2024-07-07...
# Fetching data for SOXX from 2024-07-01 to 2024-07-07...
# Fetching data for PSI from 2024-07-01 to 2024-07-07...
# Fetching data for XSD from 2024-07-01 to 2024-07-07...
# Fetching data for IYW from 2024-07-01 to 2024-07-07...
# Fetching data for XLK from 2024-07-01 to 2024-07-07...
# Fetching data for VGT from 2024-07-01 to 2024-07-07...
# Fetching data for FTEC from 2024-07-01 to 2024-07-07...
# Fetching data for IGM from 2024-07-01 to 2024-07-07...
# Fetching data for IXN from 2024-07-01 to 2024-07-07...
# Fetching data for SMH from 2024-07-08 to 2024-07-14...
# Fetching data for SOXX from 2024-07-08 to 2024-07-14...
# Fetching data for PSI from 2024-07-08 to 2024-07-14...
# Fetching data for XSD from 2024-07-08 to 2024-07-14...
# Fetching data for IYW from 2024-07-08 to 2024-07-14...
# Fetching data for XLK from 2024-07-08 to 2024-07-14...
# Fetching data for VGT from 2024-07-08 to 2024-07-14...
# Fetching data for FTEC from 2024-07-08 to 2024-07-14...
# Fetching data for IGM from 2024-07-08 to 2024-07-14...
# Fetching data for IXN from 2024-07-08 to 2024-07-14...
# Fetching data for SMH from 2024-07-15 to 2024-07-21...
# Fetching data for SOXX from 2024-07-15 to 2024-07-21...
# Fetching data for PSI from 2024-07-15 to 2024-07-21...
# Fetching data for XSD from 2024-07-15 to 2024-07-21...
# Fetching data for IYW from 2024-07-15 to 2024-07-21...
# Fetching data for XLK from 2024-07-15 to 2024-07-21...
# Fetching data for VGT from 2024-07-15 to 2024-07-21...
# Fetching data for FTEC from 2024-07-15 to 2024-07-21...
# Fetching data for IGM from 2024-07-15 to 2024-07-21...
# Fetching data for IXN from 2024-07-15 to 2024-07-21...
# Fetching data for SMH from 2024-07-22 to 2024-07-28...
# Fetching data for SOXX from 2024-07-22 to 2024-07-28...
# Fetching data for PSI from 2024-07-22 to 2024-07-28...
# Fetching data for XSD from 2024-07-22 to 2024-07-28...
# Fetching data for IYW from 2024-07-22 to 2024-07-28...
# Fetching data for XLK from 2024-07-22 to 2024-07-28...
# Fetching data for VGT from 2024-07-22 to 2024-07-28...
# Fetching data for FTEC from 2024-07-22 to 2024-07-28...
# Fetching data for IGM from 2024-07-22 to 2024-07-28...
# Fetching data for IXN from 2024-07-22 to 2024-07-28...
# Fetching data for SMH from 2024-07-29 to 2024-08-04...
# Fetching data for SOXX from 2024-07-29 to 2024-08-04...
# Fetching data for PSI from 2024-07-29 to 2024-08-04...
# Fetching data for XSD from 2024-07-29 to 2024-08-04...
# Fetching data for IYW from 2024-07-29 to 2024-08-04...
# Fetching data for XLK from 2024-07-29 to 2024-08-04...
# Fetching data for VGT from 2024-07-29 to 2024-08-04...
# Fetching data for FTEC from 2024-07-29 to 2024-08-04...
# Fetching data for IGM from 2024-07-29 to 2024-08-04...
# Fetching data for IXN from 2024-07-29 to 2024-08-04...
# Fetching data for SMH from 2024-08-05 to 2024-08-11...
# Fetching data for SOXX from 2024-08-05 to 2024-08-11...
# Fetching data for PSI from 2024-08-05 to 2024-08-11...
# Fetching data for XSD from 2024-08-05 to 2024-08-11...
# Fetching data for IYW from 2024-08-05 to 2024-08-11...
# Fetching data for XLK from 2024-08-05 to 2024-08-11...
# Fetching data for VGT from 2024-08-05 to 2024-08-11...
# Fetching data for FTEC from 2024-08-05 to 2024-08-11...
# Fetching data for IGM from 2024-08-05 to 2024-08-11...
# Fetching data for IXN from 2024-08-05 to 2024-08-11...
# Fetching data for SMH from 2024-08-12 to 2024-08-18...
# Fetching data for SOXX from 2024-08-12 to 2024-08-18...
# Fetching data for PSI from 2024-08-12 to 2024-08-18...
# Fetching data for XSD from 2024-08-12 to 2024-08-18...
# Fetching data for IYW from 2024-08-12 to 2024-08-18...
# Fetching data for XLK from 2024-08-12 to 2024-08-18...
# Fetching data for VGT from 2024-08-12 to 2024-08-18...
# Fetching data for FTEC from 2024-08-12 to 2024-08-18...
# Fetching data for IGM from 2024-08-12 to 2024-08-18...
# Fetching data for IXN from 2024-08-12 to 2024-08-18...
# Fetching data for SMH from 2024-08-19 to 2024-08-25...
# Fetching data for SOXX from 2024-08-19 to 2024-08-25...
# Fetching data for PSI from 2024-08-19 to 2024-08-25...
# Fetching data for XSD from 2024-08-19 to 2024-08-25...
# Fetching data for IYW from 2024-08-19 to 2024-08-25...
# Fetching data for XLK from 2024-08-19 to 2024-08-25...
# Fetching data for VGT from 2024-08-19 to 2024-08-25...
# Fetching data for FTEC from 2024-08-19 to 2024-08-25...
# Fetching data for IGM from 2024-08-19 to 2024-08-25...
# Fetching data for IXN from 2024-08-19 to 2024-08-25...
# Fetching data for SMH from 2024-08-26 to 2024-09-01...
# Fetching data for SOXX from 2024-08-26 to 2024-09-01...
# Fetching data for PSI from 2024-08-26 to 2024-09-01...
# Fetching data for XSD from 2024-08-26 to 2024-09-01...
# Fetching data for IYW from 2024-08-26 to 2024-09-01...
# Fetching data for XLK from 2024-08-26 to 2024-09-01...
# Fetching data for VGT from 2024-08-26 to 2024-09-01...
# Fetching data for FTEC from 2024-08-26 to 2024-09-01...
# Fetching data for IGM from 2024-08-26 to 2024-09-01...
# Fetching data for IXN from 2024-08-26 to 2024-09-01...
# Fetching data for SMH from 2024-09-02 to 2024-09-08...
# Fetching data for SOXX from 2024-09-02 to 2024-09-08...
# Fetching data for PSI from 2024-09-02 to 2024-09-08...
# Fetching data for XSD from 2024-09-02 to 2024-09-08...
# Fetching data for IYW from 2024-09-02 to 2024-09-08...
# Fetching data for XLK from 2024-09-02 to 2024-09-08...
# Fetching data for VGT from 2024-09-02 to 2024-09-08...
# Fetching data for FTEC from 2024-09-02 to 2024-09-08...
# Fetching data for IGM from 2024-09-02 to 2024-09-08...
# Fetching data for IXN from 2024-09-02 to 2024-09-08...
# Fetching data for SMH from 2024-09-09 to 2024-09-15...
# Fetching data for SOXX from 2024-09-09 to 2024-09-15...
# Fetching data for PSI from 2024-09-09 to 2024-09-15...
# Fetching data for XSD from 2024-09-09 to 2024-09-15...
# Fetching data for IYW from 2024-09-09 to 2024-09-15...
# Fetching data for XLK from 2024-09-09 to 2024-09-15...
# Fetching data for VGT from 2024-09-09 to 2024-09-15...
# Fetching data for FTEC from 2024-09-09 to 2024-09-15...
# Fetching data for IGM from 2024-09-09 to 2024-09-15...
# Fetching data for IXN from 2024-09-09 to 2024-09-15...
# Fetching data for SMH from 2024-09-16 to 2024-09-22...
# Fetching data for SOXX from 2024-09-16 to 2024-09-22...
# Fetching data for PSI from 2024-09-16 to 2024-09-22...
# Fetching data for XSD from 2024-09-16 to 2024-09-22...
# Fetching data for IYW from 2024-09-16 to 2024-09-22...
# Fetching data for XLK from 2024-09-16 to 2024-09-22...
# Fetching data for VGT from 2024-09-16 to 2024-09-22...
# Fetching data for FTEC from 2024-09-16 to 2024-09-22...
# Fetching data for IGM from 2024-09-16 to 2024-09-22...
# Fetching data for IXN from 2024-09-16 to 2024-09-22...
# Fetching data for SMH from 2024-09-23 to 2024-09-29...
# Fetching data for SOXX from 2024-09-23 to 2024-09-29...
# Fetching data for PSI from 2024-09-23 to 2024-09-29...
# Fetching data for XSD from 2024-09-23 to 2024-09-29...
# Fetching data for IYW from 2024-09-23 to 2024-09-29...
# Fetching data for XLK from 2024-09-23 to 2024-09-29...
# Fetching data for VGT from 2024-09-23 to 2024-09-29...
# Fetching data for FTEC from 2024-09-23 to 2024-09-29...
# Fetching data for IGM from 2024-09-23 to 2024-09-29...
# Fetching data for IXN from 2024-09-23 to 2024-09-29...
# Fetching data for SMH from 2024-09-30 to 2024-10-06...
# Fetching data for SOXX from 2024-09-30 to 2024-10-06...
# Fetching data for PSI from 2024-09-30 to 2024-10-06...
# Fetching data for XSD from 2024-09-30 to 2024-10-06...
# Fetching data for IYW from 2024-09-30 to 2024-10-06...
# Fetching data for XLK from 2024-09-30 to 2024-10-06...
# Fetching data for VGT from 2024-09-30 to 2024-10-06...
# Fetching data for FTEC from 2024-09-30 to 2024-10-06...
# Fetching data for IGM from 2024-09-30 to 2024-10-06...
# Fetching data for IXN from 2024-09-30 to 2024-10-06...
# Fetching data for SMH from 2024-10-07 to 2024-10-13...
# Fetching data for SOXX from 2024-10-07 to 2024-10-13...
# Fetching data for PSI from 2024-10-07 to 2024-10-13...
# Fetching data for XSD from 2024-10-07 to 2024-10-13...
# Fetching data for IYW from 2024-10-07 to 2024-10-13...
# Fetching data for XLK from 2024-10-07 to 2024-10-13...
# Fetching data for VGT from 2024-10-07 to 2024-10-13...
# Fetching data for FTEC from 2024-10-07 to 2024-10-13...
# Fetching data for IGM from 2024-10-07 to 2024-10-13...
# Fetching data for IXN from 2024-10-07 to 2024-10-13...
# Fetching data for SMH from 2024-10-14 to 2024-10-20...
# Fetching data for SOXX from 2024-10-14 to 2024-10-20...
# Fetching data for PSI from 2024-10-14 to 2024-10-20...
# Fetching data for XSD from 2024-10-14 to 2024-10-20...
# Fetching data for IYW from 2024-10-14 to 2024-10-20...
# Fetching data for XLK from 2024-10-14 to 2024-10-20...
# Fetching data for VGT from 2024-10-14 to 2024-10-20...
# Fetching data for FTEC from 2024-10-14 to 2024-10-20...
# Fetching data for IGM from 2024-10-14 to 2024-10-20...
# Fetching data for IXN from 2024-10-14 to 2024-10-20...
# Fetching data for SMH from 2024-10-21 to 2024-10-27...
# Fetching data for SOXX from 2024-10-21 to 2024-10-27...
# Fetching data for PSI from 2024-10-21 to 2024-10-27...
# Fetching data for XSD from 2024-10-21 to 2024-10-27...
# Fetching data for IYW from 2024-10-21 to 2024-10-27...
# Fetching data for XLK from 2024-10-21 to 2024-10-27...
# Fetching data for VGT from 2024-10-21 to 2024-10-27...
# Fetching data for FTEC from 2024-10-21 to 2024-10-27...
# Fetching data for IGM from 2024-10-21 to 2024-10-27...
# Fetching data for IXN from 2024-10-21 to 2024-10-27...
# Fetching data for SMH from 2024-10-28 to 2024-11-03...
# Fetching data for SOXX from 2024-10-28 to 2024-11-03...
# Fetching data for PSI from 2024-10-28 to 2024-11-03...
# Fetching data for XSD from 2024-10-28 to 2024-11-03...
# Fetching data for IYW from 2024-10-28 to 2024-11-03...
# Fetching data for XLK from 2024-10-28 to 2024-11-03...
# Fetching data for VGT from 2024-10-28 to 2024-11-03...
# Fetching data for FTEC from 2024-10-28 to 2024-11-03...
# Fetching data for IGM from 2024-10-28 to 2024-11-03...
# Fetching data for IXN from 2024-10-28 to 2024-11-03...
# Fetching data for SMH from 2024-11-04 to 2024-11-10...
# Fetching data for SOXX from 2024-11-04 to 2024-11-10...
# Fetching data for PSI from 2024-11-04 to 2024-11-10...
# Fetching data for XSD from 2024-11-04 to 2024-11-10...
# Fetching data for IYW from 2024-11-04 to 2024-11-10...
# Fetching data for XLK from 2024-11-04 to 2024-11-10...
# Fetching data for VGT from 2024-11-04 to 2024-11-10...
# Fetching data for FTEC from 2024-11-04 to 2024-11-10...
# Fetching data for IGM from 2024-11-04 to 2024-11-10...
# Fetching data for IXN from 2024-11-04 to 2024-11-10...
# Fetching data for SMH from 2024-11-11 to 2024-11-17...
# Fetching data for SOXX from 2024-11-11 to 2024-11-17...
# Fetching data for PSI from 2024-11-11 to 2024-11-17...
# Fetching data for XSD from 2024-11-11 to 2024-11-17...
# Fetching data for IYW from 2024-11-11 to 2024-11-17...
# Fetching data for XLK from 2024-11-11 to 2024-11-17...
# Fetching data for VGT from 2024-11-11 to 2024-11-17...
# Fetching data for FTEC from 2024-11-11 to 2024-11-17...
# Fetching data for IGM from 2024-11-11 to 2024-11-17...
# Fetching data for IXN from 2024-11-11 to 2024-11-17...
# Fetching data for SMH from 2024-11-18 to 2024-11-24...
# Fetching data for SOXX from 2024-11-18 to 2024-11-24...
# Fetching data for PSI from 2024-11-18 to 2024-11-24...
# Fetching data for XSD from 2024-11-18 to 2024-11-24...
# Fetching data for IYW from 2024-11-18 to 2024-11-24...
# Fetching data for XLK from 2024-11-18 to 2024-11-24...
# Fetching data for VGT from 2024-11-18 to 2024-11-24...
# Fetching data for FTEC from 2024-11-18 to 2024-11-24...
# Fetching data for IGM from 2024-11-18 to 2024-11-24...
# Fetching data for IXN from 2024-11-18 to 2024-11-24...
# Fetching data for SMH from 2024-11-25 to 2024-12-01...
# Fetching data for SOXX from 2024-11-25 to 2024-12-01...
# Fetching data for PSI from 2024-11-25 to 2024-12-01...
# Fetching data for XSD from 2024-11-25 to 2024-12-01...
# Fetching data for IYW from 2024-11-25 to 2024-12-01...
# Fetching data for XLK from 2024-11-25 to 2024-12-01...
# Fetching data for VGT from 2024-11-25 to 2024-12-01...
# Fetching data for FTEC from 2024-11-25 to 2024-12-01...
# Fetching data for IGM from 2024-11-25 to 2024-12-01...
# Fetching data for IXN from 2024-11-25 to 2024-12-01...
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1  4.166304
# 1  SOXX   1w             0.1  0.657543
# 2   PSI   1w             0.1 -2.372004
# 3   XSD   1w             0.1 -2.772048
# 4   IYW   1w             0.1  2.122121
# Top ETFs for 2024-01-01 to 2024-01-07: ['SMH', 'IGM']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1 -0.113054
# 1  SOXX   2w             0.1 -2.406361
# 2   PSI   2w             0.1 -2.402695
# 3   XSD   2w             0.1 -3.528146
# 4   IYW   2w             0.1  5.300155
# Top ETFs for 2024-01-08 to 2024-01-14: ['IYW', 'XLK']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  6.367116
# 1  SOXX   3w             0.1  1.098709
# 2   PSI   3w             0.1  1.905072
# 3   XSD   3w             0.1 -2.583749
# 4   IYW   3w             0.1 -0.112326
# [*********************100%%**********************]  1 of 1 completed
# Top ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'PSI']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1  1.653856
# 1  SOXX   4w             0.1 -2.082096
# 2   PSI   4w             0.1 -1.668639
# 3   XSD   4w             0.1 -2.613702
# 4   IYW   4w             0.1  3.113036
# Top ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IYW']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1  2.727982
# 1  SOXX   5w             0.1 -2.415676
# 2   PSI   5w             0.1 -1.297876
# 3   XSD   5w             0.1 -3.970633
# 4   IYW   5w             0.1  2.680771
# Top ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'SMH']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  3.974183
# 1  SOXX   6w             0.1 -1.467256
# 2   PSI   6w             0.1 -1.404866
# 3   XSD   6w             0.1  4.057230
# 4   IYW   6w             0.1  1.306064
# Top ETFs for 2024-02-05 to 2024-02-11: ['XSD', 'SMH']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1  1.919753
# 1  SOXX   7w             0.1  0.803828
# 2   PSI   7w             0.1  5.347421
# 3   XSD   7w             0.1  1.678623
# 4   IYW   7w             0.1 -0.322208
# Top ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SMH']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1  3.654670
# 1  SOXX   8w             0.1 -0.148075
# 2   PSI   8w             0.1 -2.751759
# 3   XSD   8w             0.1 -3.964009
# 4   IYW   8w             0.1  2.224908
# Top ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'XLK']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1  1.425858
# 1  SOXX   9w             0.1  0.421722
# 2   PSI   9w             0.1  4.519914
# 3   XSD   9w             0.1  2.557244
# 4   IYW   9w             0.1 -1.203559
# Top ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  5.609709
# 1  SOXX  10w             0.1  1.071211
# 2   PSI  10w             0.1 -0.009258
# 3   XSD  10w             0.1  2.218258
# 4   IYW  10w             0.1 -0.250648
# Top ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'XSD']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1  0.980795
# 1  SOXX  11w             0.1 -2.260558
# 2   PSI  11w             0.1 -2.833727
# 3   XSD  11w             0.1 -3.513257
# 4   IYW  11w             0.1  3.544720
# Top ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1  0.654537
# 1  SOXX  12w             0.1 -2.882439
# 2   PSI  12w             0.1 -0.537900
# 3   XSD  12w             0.1 -1.403525
# 4   IYW  12w             0.1  5.373802
# Top ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IXN']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1 -0.213060
# 1  SOXX  13w             0.1  1.202571
# 2   PSI  13w             0.1  1.619195
# 3   XSD  13w             0.1  5.685774
# 4   IYW  13w             0.1 -0.506842
# Top ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'XLK']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1  1.988401
# 1  SOXX  14w             0.1 -2.433080
# 2   PSI  14w             0.1  1.329223
# 3   XSD  14w             0.1 -1.156302
# 4   IYW  14w             0.1  3.114183
# Top ETFs for 2024-04-01 to 2024-04-07: ['IYW', 'IGM']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1  1.621054
# 1  SOXX  15w             0.1 -2.423600
# 2   PSI  15w             0.1 -1.181438
# 3   XSD  15w             0.1  0.980801
# 4   IYW  15w             0.1  3.470798
# Top ETFs for 2024-04-08 to 2024-04-14: ['XLK', 'IYW']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1  3.818547
# 1  SOXX  16w             0.1  0.777778
# 2   PSI  16w             0.1  2.399221
# 3   XSD  16w             0.1 -2.575082
# 4   IYW  16w             0.1  2.084975
# Top ETFs for 2024-04-15 to 2024-04-21: ['SMH', 'IGM']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1  0.048725
# 1  SOXX  17w             0.1  2.640779
# 2   PSI  17w             0.1  3.181594
# 3   XSD  17w             0.1  6.301609
# 4   IYW  17w             0.1 -1.871212
# Top ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'PSI']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1 -0.278524
# 1  SOXX  18w             0.1 -3.716286
# 2   PSI  18w             0.1 -1.127150
# 3   XSD  18w             0.1 -0.387325
# 4   IYW  18w             0.1  2.676874
# Top ETFs for 2024-04-29 to 2024-05-05: ['XLK', 'IXN']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1  3.019654
# 1  SOXX  19w             0.1 -2.371490
# 2   PSI  19w             0.1 -0.099149
# 3   XSD  19w             0.1 -1.611248
# 4   IYW  19w             0.1  2.223434
# Top ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'SMH']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1 -0.620967
# 1  SOXX  20w             0.1 -2.708799
# 2   PSI  20w             0.1 -3.249564
# 3   XSD  20w             0.1  0.742475
# 4   IYW  20w             0.1  3.411639
# Top ETFs for 2024-05-13 to 2024-05-19: ['XLK', 'IYW']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  5.883016
# 1  SOXX  21w             0.1 -0.799509
# 2   PSI  21w             0.1 -0.434079
# 3   XSD  21w             0.1 -2.405037
# 4   IYW  21w             0.1  2.708638
# Top ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IYW']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1  2.279549
# 1  SOXX  22w             0.1 -2.312585
# 2   PSI  22w             0.1 -1.514936
# 3   XSD  22w             0.1  4.606056
# 4   IYW  22w             0.1  2.841085
# Top ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'IYW']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1  1.610339
# 1  SOXX  23w             0.1 -2.641274
# 2   PSI  23w             0.1 -2.806215
# 3   XSD  23w             0.1 -4.141080
# 4   IYW  23w             0.1  3.953485
# Top ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1 -0.682749
# 1  SOXX  24w             0.1 -3.090093
# 2   PSI  24w             0.1 -2.431393
# 3   XSD  24w             0.1 -3.616614
# 4   IYW  24w             0.1  3.521503
# Top ETFs for 2024-06-10 to 2024-06-16: ['XLK', 'IYW']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1  1.369161
# 1  SOXX  25w             0.1 -1.216557
# 2   PSI  25w             0.1  0.776161
# 3   XSD  25w             0.1 -2.210309
# 4   IYW  25w             0.1  1.836721
# Top ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1  0.292604
# 1  SOXX  26w             0.1 -3.525908
# 2   PSI  26w             0.1  2.113139
# 3   XSD  26w             0.1 -0.483752
# 4   IYW  26w             0.1  3.275352
# Top ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'XLK']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1 -2.101896
# 1  SOXX  27w             0.1 -3.087387
# 2   PSI  27w             0.1 -3.070806
# 3   XSD  27w             0.1 -2.444222
# 4   IYW  27w             0.1  4.711481
# Top ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IGM']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1  2.020038
# 1  SOXX  28w             0.1 -0.260994
# 2   PSI  28w             0.1 -0.269956
# 3   XSD  28w             0.1  6.082972
# 4   IYW  28w             0.1 -0.014128
# Top ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1  1.034959
# 1  SOXX  29w             0.1 -0.342084
# 2   PSI  29w             0.1  1.531939
# 3   XSD  29w             0.1  4.071193
# 4   IYW  29w             0.1  1.012011
# Top ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'PSI']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1  1.661907
# 1  SOXX  30w             0.1 -1.227621
# 2   PSI  30w             0.1 -1.187423
# 3   XSD  30w             0.1  0.430590
# 4   IYW  30w             0.1  2.604437
# Top ETFs for 2024-07-22 to 2024-07-28: ['XLK', 'IYW']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1  3.115001
# 1  SOXX  31w             0.1  0.018755
# 2   PSI  31w             0.1 -1.453361
# 3   XSD  31w             0.1 -3.657192
# 4   IYW  31w             0.1  2.624288
# Top ETFs for 2024-07-29 to 2024-08-04: ['XLK', 'SMH']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1  3.450548
# 1  SOXX  32w             0.1 -0.335059
# 2   PSI  32w             0.1  5.236275
# 3   XSD  32w             0.1 -1.393326
# 4   IYW  32w             0.1  0.627190
# Top ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1  0.046489
# 1  SOXX  33w             0.1 -2.488592
# 2   PSI  33w             0.1 -2.063080
# 3   XSD  33w             0.1 -2.473270
# 4   IYW  33w             0.1  1.011317
# Top ETFs for 2024-08-12 to 2024-08-18: ['IXN', 'XLK']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1 -0.077134
# 1  SOXX  34w             0.1 -3.277835
# 2   PSI  34w             0.1 -0.539557
# 3   XSD  34w             0.1  3.716035
# 4   IYW  34w             0.1  1.948258
# Top ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'XLK']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1  1.785463
# 1  SOXX  35w             0.1  0.756001
# 2   PSI  35w             0.1  0.549991
# 3   XSD  35w             0.1  4.365798
# 4   IYW  35w             0.1  0.976940
# Top ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'XLK']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1  2.836651
# 1  SOXX  36w             0.1  0.456339
# 2   PSI  36w             0.1  2.501634
# 3   XSD  36w             0.1  0.591750
# 4   IYW  36w             0.1  1.586952
# Top ETFs for 2024-09-02 to 2024-09-08: ['SMH', 'XLK']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1 -1.012665
# 1  SOXX  37w             0.1 -3.081215
# 2   PSI  37w             0.1 -3.106071
# 3   XSD  37w             0.1 -2.715163
# 4   IYW  37w             0.1  1.800764
# Top ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'IXN']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1 -0.146830
# 1  SOXX  38w             0.1 -3.225542
# 2   PSI  38w             0.1 -1.549022
# 3   XSD  38w             0.1 -0.427089
# 4   IYW  38w             0.1  4.242549
# Top ETFs for 2024-09-16 to 2024-09-22: ['IYW', 'IGM']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1  3.234265
# 1  SOXX  39w             0.1  0.563080
# 2   PSI  39w             0.1  2.586643
# 3   XSD  39w             0.1  3.454164
# 4   IYW  39w             0.1 -0.103882
# Top ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'SMH']
# Processing scores for 2024-09-30 to 2024-10-06:
#     ETF Week  RiskPercentage     Score
# 0   SMH  40w             0.1  1.471886
# 1  SOXX  40w             0.1 -3.174790
# 2   PSI  40w             0.1 -0.988834
# 3   XSD  40w             0.1 -1.860163
# 4   IYW  40w             0.1  3.751723
# Top ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Processing scores for 2024-10-07 to 2024-10-13:
#     ETF Week  RiskPercentage     Score
# 0   SMH  41w             0.1  2.794940
# 1  SOXX  41w             0.1 -4.846669
# 2   PSI  41w             0.1 -0.219993
# 3   XSD  41w             0.1 -0.319932
# 4   IYW  41w             0.1  2.342834
# Top ETFs for 2024-10-07 to 2024-10-13: ['XLK', 'SMH']
# Processing scores for 2024-10-14 to 2024-10-20:
#     ETF Week  RiskPercentage     Score
# 0   SMH  42w             0.1  1.674520
# 1  SOXX  42w             0.1 -1.982302
# 2   PSI  42w             0.1 -2.785079
# 3   XSD  42w             0.1 -0.750408
# 4   IYW  42w             0.1  2.861657
# Top ETFs for 2024-10-14 to 2024-10-20: ['XLK', 'IYW']
# Processing scores for 2024-10-21 to 2024-10-27:
#     ETF Week  RiskPercentage     Score
# 0   SMH  43w             0.1  1.896828
# 1  SOXX  43w             0.1 -3.439372
# 2   PSI  43w             0.1 -0.703664
# 3   XSD  43w             0.1 -0.582457
# 4   IYW  43w             0.1  3.968216
# Top ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'XLK']
# Processing scores for 2024-10-28 to 2024-11-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH  44w             0.1  0.901293
# 1  SOXX  44w             0.1 -1.268021
# 2   PSI  44w             0.1 -1.452525
# 3   XSD  44w             0.1  3.366973
# 4   IYW  44w             0.1  2.844287
# Top ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IYW']
# Processing scores for 2024-11-04 to 2024-11-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  45w             0.1 -1.365207
# 1  SOXX  45w             0.1 -5.245555
# 2   PSI  45w             0.1 -0.585231
# 3   XSD  45w             0.1  0.012969
# 4   IYW  45w             0.1  2.384990
# Top ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'IYW']
# Processing scores for 2024-11-11 to 2024-11-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  46w             0.1  0.296714
# 1  SOXX  46w             0.1 -1.766664
# 2   PSI  46w             0.1 -1.750458
# 3   XSD  46w             0.1 -3.976736
# 4   IYW  46w             0.1  3.418997
# Top ETFs for 2024-11-11 to 2024-11-17: ['IYW', 'XLK']
# Processing scores for 2024-11-18 to 2024-11-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  47w             0.1 -1.592254
# 1  SOXX  47w             0.1 -3.037158
# 2   PSI  47w             0.1  0.353475
# 3   XSD  47w             0.1  5.550374
# 4   IYW  47w             0.1  0.420633
# Top ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'VGT']
# Processing scores for 2024-11-25 to 2024-12-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  48w             0.1 -1.311544
# 1  SOXX  48w             0.1 -1.575983
# 2   PSI  48w             0.1  1.533328
# 3   XSD  48w             0.1  5.139647
# 4   IYW  48w             0.1  1.301325
# Top ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'IXN']
#
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['SMH', 'IGM']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IYW', 'XLK']
# Sell SMH: 288.51 shares at 171.96. Total value: 48372.34
# Buy IYW: 390.62 shares at 120.74.
# Sell IGM: 670.33 shares at 73.74. Total value: 48191.36
# Buy XLK: 248.95 shares at 188.74.
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'IYW': 390.6164545331678, 'XLK': 248.94869581720206}
#
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IYW', 'XLK']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'PSI']
# Sell IYW: 390.62 shares at 123.36. Total value: 46981.78
# Buy SMH: 260.71 shares at 175.70.
# Sell XLK: 248.95 shares at 192.72. Total value: 46777.96
# Buy PSI: 955.95 shares at 47.71.
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'SMH': 260.71281212617856, 'PSI': 955.9528413225012}
#
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'PSI']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IYW']
# Sell SMH: 260.71 shares at 188.05. Total value: 47801.37
# Buy IGM: 592.59 shares at 78.65.
# Sell PSI: 955.95 shares at 51.02. Total value: 47553.40
# Buy IYW: 360.62 shares at 128.57.
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'IGM': 592.591531891069, 'IYW': 360.6172434241454}
#
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'IYW']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'SMH']
# Sell IYW: 360.62 shares at 130.81. Total value: 45993.03
# Buy SMH: 235.42 shares at 190.48.
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'IGM': 592.591531891069, 'SMH': 235.42213048138177}
#
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'SMH']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['XSD', 'SMH']
# Sell IGM: 592.59 shares at 81.27. Total value: 46953.99
# Buy XSD: 215.59 shares at 212.35.
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'SMH': 235.42213048138177, 'XSD': 215.58813736043336}
#
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['XSD', 'SMH']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SMH']
# Sell XSD: 215.59 shares at 226.52. Total value: 47614.15
# Buy PSI: 881.24 shares at 52.68.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'SMH': 235.42213048138177, 'PSI': 881.2413843653637}
#
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SMH']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'XLK']
# Sell PSI: 881.24 shares at 51.59. Total value: 44326.66
# Buy XLK: 215.54 shares at 200.51.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'SMH': 235.42213048138177, 'XLK': 215.54284927018844}
#
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'XLK']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Sell SMH: 235.42 shares at 210.35. Total value: 48283.02
# Buy PSI: 882.89 shares at 53.32.
# Sell XLK: 215.54 shares at 205.49. Total value: 43184.60
# Buy XSD: 190.75 shares at 220.73.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'PSI': 882.8946957620238, 'XSD': 190.75336143615604}
#
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'XSD']
# Sell PSI: 882.89 shares at 56.78. Total value: 48877.49
# Buy SMH: 212.66 shares at 224.09.
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'XSD': 190.75336143615604, 'SMH': 212.66256532585328}
#
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'XSD']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Sell SMH: 212.66 shares at 220.98. Total value: 45819.32
# Buy XLK: 216.05 shares at 206.78.
# Sell XSD: 190.75 shares at 231.52. Total value: 43059.14
# Buy IYW: 315.78 shares at 132.95.
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'XLK': 216.04524499454308, 'IYW': 315.7778193120533}
#
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IXN']
# Sell XLK: 216.05 shares at 206.30. Total value: 43455.88
# Buy IXN: 573.72 shares at 73.85.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'IYW': 315.7778193120533, 'IXN': 573.7235636591556}
#
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IXN']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'XLK']
# Sell IYW: 315.78 shares at 135.90. Total value: 41841.35
# Buy XSD: 180.35 shares at 226.20.
# Sell IXN: 573.72 shares at 75.16. Total value: 42043.04
# Buy XLK: 196.59 shares at 208.52.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'XSD': 180.35064305484184, 'XLK': 196.58527582097966}
#
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'XLK']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IYW', 'IGM']
# Sell XSD: 180.35 shares at 233.86. Total value: 41122.38
# Buy IYW: 295.79 shares at 135.55.
# Sell XLK: 196.59 shares at 208.85. Total value: 40030.42
# Buy IGM: 450.38 shares at 86.66.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'IYW': 295.78990054145066, 'IGM': 450.3767958172697}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IYW', 'IGM']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['XLK', 'IYW']
# Sell IGM: 450.38 shares at 85.96. Total value: 37746.53
# Buy XLK: 178.47 shares at 206.21.
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'IYW': 295.78990054145066, 'XLK': 178.4727452750569}
#
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['XLK', 'IYW']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['SMH', 'IGM']
# Sell XLK: 178.47 shares at 201.52. Total value: 35066.68
# Buy SMH: 157.30 shares at 217.36.
# Sell IYW: 295.79 shares at 131.14. Total value: 37820.14
# Buy IGM: 440.82 shares at 83.65.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'SMH': 157.29672210879463, 'IGM': 440.82051422137573}
#
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['SMH', 'IGM']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'PSI']
# Sell SMH: 157.30 shares at 203.02. Total value: 31136.02
# Buy XSD: 146.92 shares at 206.62.
# Sell IGM: 440.82 shares at 80.88. Total value: 34762.22
# Buy PSI: 666.01 shares at 50.89.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'XSD': 146.92489517227918, 'PSI': 666.0084056442887}
#
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'PSI']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['XLK', 'IXN']
# Sell XSD: 146.92 shares at 228.64. Total value: 32753.09
# Buy XLK: 159.12 shares at 200.69.
# Sell PSI: 666.01 shares at 55.04. Total value: 35740.68
# Buy IXN: 483.65 shares at 72.05.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'XLK': 159.1223166294794, 'IXN': 483.6524261920224}
#
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['XLK', 'IXN']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'SMH']
# Sell IXN: 483.65 shares at 73.87. Total value: 34834.22
# Buy SMH: 152.53 shares at 222.67.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'XLK': 159.1223166294794, 'SMH': 152.52780193427364}
#
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'SMH']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['XLK', 'IYW']
# Sell SMH: 152.53 shares at 223.26. Total value: 33202.02
# Buy IYW: 240.76 shares at 134.46.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'XLK': 159.1223166294794, 'IYW': 240.75539299513176}
#
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['XLK', 'IYW']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IYW']
# Sell XLK: 159.12 shares at 214.31. Total value: 33248.97
# Buy SMH: 137.95 shares at 235.00.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'IYW': 240.75539299513176, 'SMH': 137.94783644050077}
#
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IYW']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'IYW']
# Sell SMH: 137.95 shares at 249.83. Total value: 33601.92
# Buy XSD: 131.45 shares at 249.23.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'IYW': 240.75539299513176, 'XSD': 131.45236557903743}
#
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'IYW']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Sell XSD: 131.45 shares at 245.69. Total value: 31489.12
# Buy IXN: 398.42 shares at 77.06.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'IYW': 240.75539299513176, 'IXN': 398.4154129801015}
#
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['XLK', 'IYW']
# Sell IXN: 398.42 shares at 79.41. Total value: 30847.22
# Buy XLK: 139.14 shares at 216.15.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'IYW': 240.75539299513176, 'XLK': 139.14427776427382}
#
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['XLK', 'IYW']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Sell IYW: 240.76 shares at 152.76. Total value: 35858.35
# Buy IXN: 414.29 shares at 84.39.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'XLK': 139.14427776427382, 'IXN': 414.28948049576906}
#
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'XLK']
# Sell IXN: 414.29 shares at 81.49. Total value: 32916.44
# Buy IYW: 217.13 shares at 147.81.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'XLK': 139.14427776427382, 'IYW': 217.12690107028362}
#
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'XLK']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IGM']
# Sell XLK: 139.14 shares at 227.94. Total value: 30923.63
# Buy IGM: 317.61 shares at 94.93.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'IYW': 217.12690107028362, 'IGM': 317.6081576697404}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'IGM']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Sell IYW: 217.13 shares at 156.96. Total value: 33228.23
# Buy XSD: 124.28 shares at 260.69.
# Sell IGM: 317.61 shares at 97.87. Total value: 30307.20
# Buy SMH: 107.76 shares at 274.21.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 124.2760662233418, 'SMH': 107.76238764327155}
#
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'PSI']
# Sell SMH: 107.76 shares at 273.83. Total value: 28770.86
# Buy PSI: 423.48 shares at 66.24.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'XSD': 124.2760662233418, 'PSI': 423.48412237575855}
#
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'PSI']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['XLK', 'IYW']
# Sell XSD: 124.28 shares at 258.59. Total value: 31333.13
# Buy XLK: 135.12 shares at 226.10.
# Sell PSI: 423.48 shares at 61.60. Total value: 25434.46
# Buy IYW: 164.21 shares at 151.02.
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'XLK': 135.11634078554235, 'IYW': 164.2073477969229}
#
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['XLK', 'IYW']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['XLK', 'SMH']
# Sell IYW: 164.21 shares at 144.14. Total value: 23077.13
# Buy SMH: 94.30 shares at 238.60.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'XLK': 135.11634078554235, 'SMH': 94.3009099517099}
#
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['XLK', 'SMH']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Sell XLK: 135.12 shares at 197.90. Total value: 26071.03
# Buy PSI: 512.69 shares at 49.58.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'SMH': 94.3009099517099, 'PSI': 512.6917734783024}
#
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['IXN', 'XLK']
# Sell PSI: 512.69 shares at 53.06. Total value: 26523.34
# Buy IXN: 337.73 shares at 76.57.
# Sell SMH: 94.30 shares at 226.96. Total value: 20867.47
# Buy XLK: 98.14 shares at 207.31.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'IXN': 337.7335397549714, 'XLK': 98.14184179273613}
#
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['IXN', 'XLK']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'XLK']
# Sell IXN: 337.73 shares at 82.91. Total value: 27301.45
# Buy XSD: 113.30 shares at 234.95.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'XLK': 98.14184179273613, 'XSD': 113.29608786292894}
#
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['XSD', 'XLK']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'XLK']
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'XLK': 98.14184179273613, 'XSD': 113.29608786292894}
#
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'XLK']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['SMH', 'XLK']
# Sell XSD: 113.30 shares at 222.36. Total value: 24562.71
# Buy SMH: 106.35 shares at 225.19.
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'XLK': 98.14184179273613, 'SMH': 106.34858262910268}
#
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['SMH', 'XLK']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'IXN']
# Sell SMH: 106.35 shares at 219.86. Total value: 22797.25
# Buy IXN: 291.35 shares at 76.29.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'XLK': 98.14184179273613, 'IXN': 291.35303221348454}
#
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'IXN']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IYW', 'IGM']
# Sell XLK: 98.14 shares at 219.60. Total value: 21013.15
# Buy IYW: 140.29 shares at 146.04.
# Sell IXN: 291.35 shares at 80.29. Total value: 22807.92
# Buy IGM: 240.95 shares at 92.29.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'IYW': 140.2891160908196, 'IGM': 240.95480226371208}
#
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IYW', 'IGM']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'SMH']
# Sell IYW: 140.29 shares at 149.26. Total value: 20416.06
# Buy XSD: 85.86 shares at 231.84.
# Sell IGM: 240.95 shares at 94.58. Total value: 22219.77
# Buy SMH: 90.66 shares at 238.95.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'XSD': 85.85948325178083, 'SMH': 90.66446568340112}
#
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'SMH']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Sell XSD: 85.86 shares at 240.25. Total value: 20112.05
# Buy IYW: 129.33 shares at 151.62.
# Sell SMH: 90.66 shares at 245.45. Total value: 21697.25
# Buy XLK: 93.70 shares at 225.76.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'IYW': 129.33153131652796, 'XLK': 93.70491758633891}
#
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['XLK', 'SMH']
# Sell IYW: 129.33 shares at 150.36. Total value: 18960.13
# Buy SMH: 74.47 shares at 248.22.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'XLK': 93.70491758633891, 'SMH': 74.47477443839949}
#
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['XLK', 'SMH']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['XLK', 'IYW']
# Sell SMH: 74.47 shares at 261.28. Total value: 18972.30
# Buy IYW: 117.81 shares at 157.01.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'XLK': 93.70491758633891, 'IYW': 117.81410676655592}
#
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['XLK', 'IYW']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'XLK']
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'XLK': 93.70491758633891, 'IYW': 117.81410676655592}
#
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'XLK']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IYW']
# Sell XLK: 93.70 shares at 230.22. Total value: 21033.43
# Buy XSD: 83.08 shares at 246.83.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'IYW': 117.81410676655592, 'XSD': 83.08387045062095}
#
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IYW']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'IYW']
# Sell XSD: 83.08 shares at 233.24. Total value: 18894.02
# Buy XLK: 82.34 shares at 223.74.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'IYW': 117.81410676655592, 'XLK': 82.33516304416277}
#
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'IYW']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IYW', 'XLK']
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'IYW': 117.81410676655592, 'XLK': 82.33516304416277}
#
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IYW', 'XLK']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'VGT']
# Sell IYW: 117.81 shares at 156.19. Total value: 17941.35
# Buy XSD: 76.52 shares at 228.59.
# Sell XLK: 82.34 shares at 229.45. Total value: 18419.51
# Buy VGT: 29.70 shares at 604.72.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'XSD': 76.52485886776557, 'VGT': 29.69807681345824}
#
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'VGT']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'IXN']
# Sell VGT: 29.70 shares at 621.29. Total value: 17989.84
# Buy IXN: 209.81 shares at 83.60.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'XSD': 76.52485886776557, 'IXN': 209.8097354655443}
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker XSD starting from 2024-12-01...
# XSD: 76.52 shares at $252.68 each, total value: $19336.30
# Fetching data for ticker IXN starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# IXN: 209.81 shares at $84.80 each, total value: $17791.87
#
# ETF values on the 49th week's first trading day:
# Total portfolio value: 37128.17
# XSD: 19336.30
# IXN: 17791.87

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_week = main_weekly(tickers, results, smoothing=True)
# Out:
# Fetching data for SMH from 2024-01-01 to 2024-01-07...
# Fetching data for SOXX from 2024-01-01 to 2024-01-07...
# Fetching data for PSI from 2024-01-01 to 2024-01-07...
# Fetching data for XSD from 2024-01-01 to 2024-01-07...
# Fetching data for IYW from 2024-01-01 to 2024-01-07...
# Fetching data for XLK from 2024-01-01 to 2024-01-07...
# Fetching data for VGT from 2024-01-01 to 2024-01-07...
# Fetching data for FTEC from 2024-01-01 to 2024-01-07...
# Fetching data for IGM from 2024-01-01 to 2024-01-07...
# Fetching data for IXN from 2024-01-01 to 2024-01-07...
# Fetching data for SMH from 2024-01-08 to 2024-01-14...
# Fetching data for SOXX from 2024-01-08 to 2024-01-14...
# Fetching data for PSI from 2024-01-08 to 2024-01-14...
# Fetching data for XSD from 2024-01-08 to 2024-01-14...
# Fetching data for IYW from 2024-01-08 to 2024-01-14...
# Fetching data for XLK from 2024-01-08 to 2024-01-14...
# Fetching data for VGT from 2024-01-08 to 2024-01-14...
# Fetching data for FTEC from 2024-01-08 to 2024-01-14...
# Fetching data for IGM from 2024-01-08 to 2024-01-14...
# Fetching data for IXN from 2024-01-08 to 2024-01-14...
# Fetching data for SMH from 2024-01-15 to 2024-01-21...
# Fetching data for SOXX from 2024-01-15 to 2024-01-21...
# Fetching data for PSI from 2024-01-15 to 2024-01-21...
# Fetching data for XSD from 2024-01-15 to 2024-01-21...
# Fetching data for IYW from 2024-01-15 to 2024-01-21...
# Fetching data for XLK from 2024-01-15 to 2024-01-21...
# Fetching data for VGT from 2024-01-15 to 2024-01-21...
# Fetching data for FTEC from 2024-01-15 to 2024-01-21...
# Fetching data for IGM from 2024-01-15 to 2024-01-21...
# Fetching data for IXN from 2024-01-15 to 2024-01-21...
# Fetching data for SMH from 2024-01-22 to 2024-01-28...
# Fetching data for SOXX from 2024-01-22 to 2024-01-28...
# Fetching data for PSI from 2024-01-22 to 2024-01-28...
# Fetching data for XSD from 2024-01-22 to 2024-01-28...
# Fetching data for IYW from 2024-01-22 to 2024-01-28...
# Fetching data for XLK from 2024-01-22 to 2024-01-28...
# Fetching data for VGT from 2024-01-22 to 2024-01-28...
# Fetching data for FTEC from 2024-01-22 to 2024-01-28...
# Fetching data for IGM from 2024-01-22 to 2024-01-28...
# Fetching data for IXN from 2024-01-22 to 2024-01-28...
# Fetching data for SMH from 2024-01-29 to 2024-02-04...
# Fetching data for SOXX from 2024-01-29 to 2024-02-04...
# Fetching data for PSI from 2024-01-29 to 2024-02-04...
# Fetching data for XSD from 2024-01-29 to 2024-02-04...
# Fetching data for IYW from 2024-01-29 to 2024-02-04...
# Fetching data for XLK from 2024-01-29 to 2024-02-04...
# Fetching data for VGT from 2024-01-29 to 2024-02-04...
# Fetching data for FTEC from 2024-01-29 to 2024-02-04...
# Fetching data for IGM from 2024-01-29 to 2024-02-04...
# Fetching data for IXN from 2024-01-29 to 2024-02-04...
# Fetching data for SMH from 2024-02-05 to 2024-02-11...
# Fetching data for SOXX from 2024-02-05 to 2024-02-11...
# Fetching data for PSI from 2024-02-05 to 2024-02-11...
# Fetching data for XSD from 2024-02-05 to 2024-02-11...
# Fetching data for IYW from 2024-02-05 to 2024-02-11...
# Fetching data for XLK from 2024-02-05 to 2024-02-11...
# Fetching data for VGT from 2024-02-05 to 2024-02-11...
# Fetching data for FTEC from 2024-02-05 to 2024-02-11...
# Fetching data for IGM from 2024-02-05 to 2024-02-11...
# Fetching data for IXN from 2024-02-05 to 2024-02-11...
# Fetching data for SMH from 2024-02-12 to 2024-02-18...
# Fetching data for SOXX from 2024-02-12 to 2024-02-18...
# Fetching data for PSI from 2024-02-12 to 2024-02-18...
# Fetching data for XSD from 2024-02-12 to 2024-02-18...
# Fetching data for IYW from 2024-02-12 to 2024-02-18...
# Fetching data for XLK from 2024-02-12 to 2024-02-18...
# Fetching data for VGT from 2024-02-12 to 2024-02-18...
# Fetching data for FTEC from 2024-02-12 to 2024-02-18...
# Fetching data for IGM from 2024-02-12 to 2024-02-18...
# Fetching data for IXN from 2024-02-12 to 2024-02-18...
# Fetching data for SMH from 2024-02-19 to 2024-02-25...
# Fetching data for SOXX from 2024-02-19 to 2024-02-25...
# Fetching data for PSI from 2024-02-19 to 2024-02-25...
# Fetching data for XSD from 2024-02-19 to 2024-02-25...
# Fetching data for IYW from 2024-02-19 to 2024-02-25...
# Fetching data for XLK from 2024-02-19 to 2024-02-25...
# Fetching data for VGT from 2024-02-19 to 2024-02-25...
# Fetching data for FTEC from 2024-02-19 to 2024-02-25...
# Fetching data for IGM from 2024-02-19 to 2024-02-25...
# Fetching data for IXN from 2024-02-19 to 2024-02-25...
# Fetching data for SMH from 2024-02-26 to 2024-03-03...
# Fetching data for SOXX from 2024-02-26 to 2024-03-03...
# Fetching data for PSI from 2024-02-26 to 2024-03-03...
# Fetching data for XSD from 2024-02-26 to 2024-03-03...
# Fetching data for IYW from 2024-02-26 to 2024-03-03...
# Fetching data for XLK from 2024-02-26 to 2024-03-03...
# Fetching data for VGT from 2024-02-26 to 2024-03-03...
# Fetching data for FTEC from 2024-02-26 to 2024-03-03...
# Fetching data for IGM from 2024-02-26 to 2024-03-03...
# Fetching data for IXN from 2024-02-26 to 2024-03-03...
# Fetching data for SMH from 2024-03-04 to 2024-03-10...
# Fetching data for SOXX from 2024-03-04 to 2024-03-10...
# Fetching data for PSI from 2024-03-04 to 2024-03-10...
# Fetching data for XSD from 2024-03-04 to 2024-03-10...
# Fetching data for IYW from 2024-03-04 to 2024-03-10...
# Fetching data for XLK from 2024-03-04 to 2024-03-10...
# Fetching data for VGT from 2024-03-04 to 2024-03-10...
# Fetching data for FTEC from 2024-03-04 to 2024-03-10...
# Fetching data for IGM from 2024-03-04 to 2024-03-10...
# Fetching data for IXN from 2024-03-04 to 2024-03-10...
# Fetching data for SMH from 2024-03-11 to 2024-03-17...
# Fetching data for SOXX from 2024-03-11 to 2024-03-17...
# Fetching data for PSI from 2024-03-11 to 2024-03-17...
# Fetching data for XSD from 2024-03-11 to 2024-03-17...
# Fetching data for IYW from 2024-03-11 to 2024-03-17...
# Fetching data for XLK from 2024-03-11 to 2024-03-17...
# Fetching data for VGT from 2024-03-11 to 2024-03-17...
# Fetching data for FTEC from 2024-03-11 to 2024-03-17...
# Fetching data for IGM from 2024-03-11 to 2024-03-17...
# Fetching data for IXN from 2024-03-11 to 2024-03-17...
# Fetching data for SMH from 2024-03-18 to 2024-03-24...
# Fetching data for SOXX from 2024-03-18 to 2024-03-24...
# Fetching data for PSI from 2024-03-18 to 2024-03-24...
# Fetching data for XSD from 2024-03-18 to 2024-03-24...
# Fetching data for IYW from 2024-03-18 to 2024-03-24...
# Fetching data for XLK from 2024-03-18 to 2024-03-24...
# Fetching data for VGT from 2024-03-18 to 2024-03-24...
# Fetching data for FTEC from 2024-03-18 to 2024-03-24...
# Fetching data for IGM from 2024-03-18 to 2024-03-24...
# Fetching data for IXN from 2024-03-18 to 2024-03-24...
# Fetching data for SMH from 2024-03-25 to 2024-03-31...
# Fetching data for SOXX from 2024-03-25 to 2024-03-31...
# Fetching data for PSI from 2024-03-25 to 2024-03-31...
# Fetching data for XSD from 2024-03-25 to 2024-03-31...
# Fetching data for IYW from 2024-03-25 to 2024-03-31...
# Fetching data for XLK from 2024-03-25 to 2024-03-31...
# Fetching data for VGT from 2024-03-25 to 2024-03-31...
# Fetching data for FTEC from 2024-03-25 to 2024-03-31...
# Fetching data for IGM from 2024-03-25 to 2024-03-31...
# Fetching data for IXN from 2024-03-25 to 2024-03-31...
# Fetching data for SMH from 2024-04-01 to 2024-04-07...
# Fetching data for SOXX from 2024-04-01 to 2024-04-07...
# Fetching data for PSI from 2024-04-01 to 2024-04-07...
# Fetching data for XSD from 2024-04-01 to 2024-04-07...
# Fetching data for IYW from 2024-04-01 to 2024-04-07...
# Fetching data for XLK from 2024-04-01 to 2024-04-07...
# Fetching data for VGT from 2024-04-01 to 2024-04-07...
# Fetching data for FTEC from 2024-04-01 to 2024-04-07...
# Fetching data for IGM from 2024-04-01 to 2024-04-07...
# Fetching data for IXN from 2024-04-01 to 2024-04-07...
# Fetching data for SMH from 2024-04-08 to 2024-04-14...
# Fetching data for SOXX from 2024-04-08 to 2024-04-14...
# Fetching data for PSI from 2024-04-08 to 2024-04-14...
# Fetching data for XSD from 2024-04-08 to 2024-04-14...
# Fetching data for IYW from 2024-04-08 to 2024-04-14...
# Fetching data for XLK from 2024-04-08 to 2024-04-14...
# Fetching data for VGT from 2024-04-08 to 2024-04-14...
# Fetching data for FTEC from 2024-04-08 to 2024-04-14...
# Fetching data for IGM from 2024-04-08 to 2024-04-14...
# Fetching data for IXN from 2024-04-08 to 2024-04-14...
# Fetching data for SMH from 2024-04-15 to 2024-04-21...
# Fetching data for SOXX from 2024-04-15 to 2024-04-21...
# Fetching data for PSI from 2024-04-15 to 2024-04-21...
# Fetching data for XSD from 2024-04-15 to 2024-04-21...
# Fetching data for IYW from 2024-04-15 to 2024-04-21...
# Fetching data for XLK from 2024-04-15 to 2024-04-21...
# Fetching data for VGT from 2024-04-15 to 2024-04-21...
# Fetching data for FTEC from 2024-04-15 to 2024-04-21...
# Fetching data for IGM from 2024-04-15 to 2024-04-21...
# Fetching data for IXN from 2024-04-15 to 2024-04-21...
# Fetching data for SMH from 2024-04-22 to 2024-04-28...
# Fetching data for SOXX from 2024-04-22 to 2024-04-28...
# Fetching data for PSI from 2024-04-22 to 2024-04-28...
# Fetching data for XSD from 2024-04-22 to 2024-04-28...
# Fetching data for IYW from 2024-04-22 to 2024-04-28...
# Fetching data for XLK from 2024-04-22 to 2024-04-28...
# Fetching data for VGT from 2024-04-22 to 2024-04-28...
# Fetching data for FTEC from 2024-04-22 to 2024-04-28...
# Fetching data for IGM from 2024-04-22 to 2024-04-28...
# Fetching data for IXN from 2024-04-22 to 2024-04-28...
# Fetching data for SMH from 2024-04-29 to 2024-05-05...
# Fetching data for SOXX from 2024-04-29 to 2024-05-05...
# Fetching data for PSI from 2024-04-29 to 2024-05-05...
# Fetching data for XSD from 2024-04-29 to 2024-05-05...
# Fetching data for IYW from 2024-04-29 to 2024-05-05...
# Fetching data for XLK from 2024-04-29 to 2024-05-05...
# Fetching data for VGT from 2024-04-29 to 2024-05-05...
# Fetching data for FTEC from 2024-04-29 to 2024-05-05...
# Fetching data for IGM from 2024-04-29 to 2024-05-05...
# Fetching data for IXN from 2024-04-29 to 2024-05-05...
# Fetching data for SMH from 2024-05-06 to 2024-05-12...
# Fetching data for SOXX from 2024-05-06 to 2024-05-12...
# Fetching data for PSI from 2024-05-06 to 2024-05-12...
# Fetching data for XSD from 2024-05-06 to 2024-05-12...
# Fetching data for IYW from 2024-05-06 to 2024-05-12...
# Fetching data for XLK from 2024-05-06 to 2024-05-12...
# Fetching data for VGT from 2024-05-06 to 2024-05-12...
# Fetching data for FTEC from 2024-05-06 to 2024-05-12...
# Fetching data for IGM from 2024-05-06 to 2024-05-12...
# Fetching data for IXN from 2024-05-06 to 2024-05-12...
# Fetching data for SMH from 2024-05-13 to 2024-05-19...
# Fetching data for SOXX from 2024-05-13 to 2024-05-19...
# Fetching data for PSI from 2024-05-13 to 2024-05-19...
# Fetching data for XSD from 2024-05-13 to 2024-05-19...
# Fetching data for IYW from 2024-05-13 to 2024-05-19...
# Fetching data for XLK from 2024-05-13 to 2024-05-19...
# Fetching data for VGT from 2024-05-13 to 2024-05-19...
# Fetching data for FTEC from 2024-05-13 to 2024-05-19...
# Fetching data for IGM from 2024-05-13 to 2024-05-19...
# Fetching data for IXN from 2024-05-13 to 2024-05-19...
# Fetching data for SMH from 2024-05-20 to 2024-05-26...
# Fetching data for SOXX from 2024-05-20 to 2024-05-26...
# Fetching data for PSI from 2024-05-20 to 2024-05-26...
# Fetching data for XSD from 2024-05-20 to 2024-05-26...
# Fetching data for IYW from 2024-05-20 to 2024-05-26...
# Fetching data for XLK from 2024-05-20 to 2024-05-26...
# Fetching data for VGT from 2024-05-20 to 2024-05-26...
# Fetching data for FTEC from 2024-05-20 to 2024-05-26...
# Fetching data for IGM from 2024-05-20 to 2024-05-26...
# Fetching data for IXN from 2024-05-20 to 2024-05-26...
# Fetching data for SMH from 2024-05-27 to 2024-06-02...
# Fetching data for SOXX from 2024-05-27 to 2024-06-02...
# Fetching data for PSI from 2024-05-27 to 2024-06-02...
# Fetching data for XSD from 2024-05-27 to 2024-06-02...
# Fetching data for IYW from 2024-05-27 to 2024-06-02...
# Fetching data for XLK from 2024-05-27 to 2024-06-02...
# Fetching data for VGT from 2024-05-27 to 2024-06-02...
# Fetching data for FTEC from 2024-05-27 to 2024-06-02...
# Fetching data for IGM from 2024-05-27 to 2024-06-02...
# Fetching data for IXN from 2024-05-27 to 2024-06-02...
# Fetching data for SMH from 2024-06-03 to 2024-06-09...
# Fetching data for SOXX from 2024-06-03 to 2024-06-09...
# Fetching data for PSI from 2024-06-03 to 2024-06-09...
# Fetching data for XSD from 2024-06-03 to 2024-06-09...
# Fetching data for IYW from 2024-06-03 to 2024-06-09...
# Fetching data for XLK from 2024-06-03 to 2024-06-09...
# Fetching data for VGT from 2024-06-03 to 2024-06-09...
# Fetching data for FTEC from 2024-06-03 to 2024-06-09...
# Fetching data for IGM from 2024-06-03 to 2024-06-09...
# Fetching data for IXN from 2024-06-03 to 2024-06-09...
# Fetching data for SMH from 2024-06-10 to 2024-06-16...
# Fetching data for SOXX from 2024-06-10 to 2024-06-16...
# Fetching data for PSI from 2024-06-10 to 2024-06-16...
# Fetching data for XSD from 2024-06-10 to 2024-06-16...
# Fetching data for IYW from 2024-06-10 to 2024-06-16...
# Fetching data for XLK from 2024-06-10 to 2024-06-16...
# Fetching data for VGT from 2024-06-10 to 2024-06-16...
# Fetching data for FTEC from 2024-06-10 to 2024-06-16...
# Fetching data for IGM from 2024-06-10 to 2024-06-16...
# Fetching data for IXN from 2024-06-10 to 2024-06-16...
# Fetching data for SMH from 2024-06-17 to 2024-06-23...
# Fetching data for SOXX from 2024-06-17 to 2024-06-23...
# Fetching data for PSI from 2024-06-17 to 2024-06-23...
# Fetching data for XSD from 2024-06-17 to 2024-06-23...
# Fetching data for IYW from 2024-06-17 to 2024-06-23...
# Fetching data for XLK from 2024-06-17 to 2024-06-23...
# Fetching data for VGT from 2024-06-17 to 2024-06-23...
# Fetching data for FTEC from 2024-06-17 to 2024-06-23...
# Fetching data for IGM from 2024-06-17 to 2024-06-23...
# Fetching data for IXN from 2024-06-17 to 2024-06-23...
# Fetching data for SMH from 2024-06-24 to 2024-06-30...
# Fetching data for SOXX from 2024-06-24 to 2024-06-30...
# Fetching data for PSI from 2024-06-24 to 2024-06-30...
# Fetching data for XSD from 2024-06-24 to 2024-06-30...
# Fetching data for IYW from 2024-06-24 to 2024-06-30...
# Fetching data for XLK from 2024-06-24 to 2024-06-30...
# Fetching data for VGT from 2024-06-24 to 2024-06-30...
# Fetching data for FTEC from 2024-06-24 to 2024-06-30...
# Fetching data for IGM from 2024-06-24 to 2024-06-30...
# Fetching data for IXN from 2024-06-24 to 2024-06-30...
# Fetching data for SMH from 2024-07-01 to 2024-07-07...
# Fetching data for SOXX from 2024-07-01 to 2024-07-07...
# Fetching data for PSI from 2024-07-01 to 2024-07-07...
# Fetching data for XSD from 2024-07-01 to 2024-07-07...
# Fetching data for IYW from 2024-07-01 to 2024-07-07...
# Fetching data for XLK from 2024-07-01 to 2024-07-07...
# Fetching data for VGT from 2024-07-01 to 2024-07-07...
# Fetching data for FTEC from 2024-07-01 to 2024-07-07...
# Fetching data for IGM from 2024-07-01 to 2024-07-07...
# Fetching data for IXN from 2024-07-01 to 2024-07-07...
# Fetching data for SMH from 2024-07-08 to 2024-07-14...
# Fetching data for SOXX from 2024-07-08 to 2024-07-14...
# Fetching data for PSI from 2024-07-08 to 2024-07-14...
# Fetching data for XSD from 2024-07-08 to 2024-07-14...
# Fetching data for IYW from 2024-07-08 to 2024-07-14...
# Fetching data for XLK from 2024-07-08 to 2024-07-14...
# Fetching data for VGT from 2024-07-08 to 2024-07-14...
# Fetching data for FTEC from 2024-07-08 to 2024-07-14...
# Fetching data for IGM from 2024-07-08 to 2024-07-14...
# Fetching data for IXN from 2024-07-08 to 2024-07-14...
# Fetching data for SMH from 2024-07-15 to 2024-07-21...
# Fetching data for SOXX from 2024-07-15 to 2024-07-21...
# Fetching data for PSI from 2024-07-15 to 2024-07-21...
# Fetching data for XSD from 2024-07-15 to 2024-07-21...
# Fetching data for IYW from 2024-07-15 to 2024-07-21...
# Fetching data for XLK from 2024-07-15 to 2024-07-21...
# Fetching data for VGT from 2024-07-15 to 2024-07-21...
# Fetching data for FTEC from 2024-07-15 to 2024-07-21...
# Fetching data for IGM from 2024-07-15 to 2024-07-21...
# Fetching data for IXN from 2024-07-15 to 2024-07-21...
# Fetching data for SMH from 2024-07-22 to 2024-07-28...
# Fetching data for SOXX from 2024-07-22 to 2024-07-28...
# Fetching data for PSI from 2024-07-22 to 2024-07-28...
# Fetching data for XSD from 2024-07-22 to 2024-07-28...
# Fetching data for IYW from 2024-07-22 to 2024-07-28...
# Fetching data for XLK from 2024-07-22 to 2024-07-28...
# Fetching data for VGT from 2024-07-22 to 2024-07-28...
# Fetching data for FTEC from 2024-07-22 to 2024-07-28...
# Fetching data for IGM from 2024-07-22 to 2024-07-28...
# Fetching data for IXN from 2024-07-22 to 2024-07-28...
# Fetching data for SMH from 2024-07-29 to 2024-08-04...
# Fetching data for SOXX from 2024-07-29 to 2024-08-04...
# Fetching data for PSI from 2024-07-29 to 2024-08-04...
# Fetching data for XSD from 2024-07-29 to 2024-08-04...
# Fetching data for IYW from 2024-07-29 to 2024-08-04...
# Fetching data for XLK from 2024-07-29 to 2024-08-04...
# Fetching data for VGT from 2024-07-29 to 2024-08-04...
# Fetching data for FTEC from 2024-07-29 to 2024-08-04...
# Fetching data for IGM from 2024-07-29 to 2024-08-04...
# Fetching data for IXN from 2024-07-29 to 2024-08-04...
# Fetching data for SMH from 2024-08-05 to 2024-08-11...
# Fetching data for SOXX from 2024-08-05 to 2024-08-11...
# Fetching data for PSI from 2024-08-05 to 2024-08-11...
# Fetching data for XSD from 2024-08-05 to 2024-08-11...
# Fetching data for IYW from 2024-08-05 to 2024-08-11...
# Fetching data for XLK from 2024-08-05 to 2024-08-11...
# Fetching data for VGT from 2024-08-05 to 2024-08-11...
# Fetching data for FTEC from 2024-08-05 to 2024-08-11...
# Fetching data for IGM from 2024-08-05 to 2024-08-11...
# Fetching data for IXN from 2024-08-05 to 2024-08-11...
# Fetching data for SMH from 2024-08-12 to 2024-08-18...
# Fetching data for SOXX from 2024-08-12 to 2024-08-18...
# Fetching data for PSI from 2024-08-12 to 2024-08-18...
# Fetching data for XSD from 2024-08-12 to 2024-08-18...
# Fetching data for IYW from 2024-08-12 to 2024-08-18...
# Fetching data for XLK from 2024-08-12 to 2024-08-18...
# Fetching data for VGT from 2024-08-12 to 2024-08-18...
# Fetching data for FTEC from 2024-08-12 to 2024-08-18...
# Fetching data for IGM from 2024-08-12 to 2024-08-18...
# Fetching data for IXN from 2024-08-12 to 2024-08-18...
# Fetching data for SMH from 2024-08-19 to 2024-08-25...
# Fetching data for SOXX from 2024-08-19 to 2024-08-25...
# Fetching data for PSI from 2024-08-19 to 2024-08-25...
# Fetching data for XSD from 2024-08-19 to 2024-08-25...
# Fetching data for IYW from 2024-08-19 to 2024-08-25...
# Fetching data for XLK from 2024-08-19 to 2024-08-25...
# Fetching data for VGT from 2024-08-19 to 2024-08-25...
# Fetching data for FTEC from 2024-08-19 to 2024-08-25...
# Fetching data for IGM from 2024-08-19 to 2024-08-25...
# Fetching data for IXN from 2024-08-19 to 2024-08-25...
# Fetching data for SMH from 2024-08-26 to 2024-09-01...
# Fetching data for SOXX from 2024-08-26 to 2024-09-01...
# Fetching data for PSI from 2024-08-26 to 2024-09-01...
# Fetching data for XSD from 2024-08-26 to 2024-09-01...
# Fetching data for IYW from 2024-08-26 to 2024-09-01...
# Fetching data for XLK from 2024-08-26 to 2024-09-01...
# Fetching data for VGT from 2024-08-26 to 2024-09-01...
# Fetching data for FTEC from 2024-08-26 to 2024-09-01...
# Fetching data for IGM from 2024-08-26 to 2024-09-01...
# Fetching data for IXN from 2024-08-26 to 2024-09-01...
# Fetching data for SMH from 2024-09-02 to 2024-09-08...
# Fetching data for SOXX from 2024-09-02 to 2024-09-08...
# Fetching data for PSI from 2024-09-02 to 2024-09-08...
# Fetching data for XSD from 2024-09-02 to 2024-09-08...
# Fetching data for IYW from 2024-09-02 to 2024-09-08...
# Fetching data for XLK from 2024-09-02 to 2024-09-08...
# Fetching data for VGT from 2024-09-02 to 2024-09-08...
# Fetching data for FTEC from 2024-09-02 to 2024-09-08...
# Fetching data for IGM from 2024-09-02 to 2024-09-08...
# Fetching data for IXN from 2024-09-02 to 2024-09-08...
# Fetching data for SMH from 2024-09-09 to 2024-09-15...
# Fetching data for SOXX from 2024-09-09 to 2024-09-15...
# Fetching data for PSI from 2024-09-09 to 2024-09-15...
# Fetching data for XSD from 2024-09-09 to 2024-09-15...
# Fetching data for IYW from 2024-09-09 to 2024-09-15...
# Fetching data for XLK from 2024-09-09 to 2024-09-15...
# Fetching data for VGT from 2024-09-09 to 2024-09-15...
# Fetching data for FTEC from 2024-09-09 to 2024-09-15...
# Fetching data for IGM from 2024-09-09 to 2024-09-15...
# Fetching data for IXN from 2024-09-09 to 2024-09-15...
# Fetching data for SMH from 2024-09-16 to 2024-09-22...
# Fetching data for SOXX from 2024-09-16 to 2024-09-22...
# Fetching data for PSI from 2024-09-16 to 2024-09-22...
# Fetching data for XSD from 2024-09-16 to 2024-09-22...
# Fetching data for IYW from 2024-09-16 to 2024-09-22...
# Fetching data for XLK from 2024-09-16 to 2024-09-22...
# Fetching data for VGT from 2024-09-16 to 2024-09-22...
# Fetching data for FTEC from 2024-09-16 to 2024-09-22...
# Fetching data for IGM from 2024-09-16 to 2024-09-22...
# Fetching data for IXN from 2024-09-16 to 2024-09-22...
# Fetching data for SMH from 2024-09-23 to 2024-09-29...
# Fetching data for SOXX from 2024-09-23 to 2024-09-29...
# Fetching data for PSI from 2024-09-23 to 2024-09-29...
# Fetching data for XSD from 2024-09-23 to 2024-09-29...
# Fetching data for IYW from 2024-09-23 to 2024-09-29...
# Fetching data for XLK from 2024-09-23 to 2024-09-29...
# Fetching data for VGT from 2024-09-23 to 2024-09-29...
# Fetching data for FTEC from 2024-09-23 to 2024-09-29...
# Fetching data for IGM from 2024-09-23 to 2024-09-29...
# Fetching data for IXN from 2024-09-23 to 2024-09-29...
# Fetching data for SMH from 2024-09-30 to 2024-10-06...
# Fetching data for SOXX from 2024-09-30 to 2024-10-06...
# Fetching data for PSI from 2024-09-30 to 2024-10-06...
# Fetching data for XSD from 2024-09-30 to 2024-10-06...
# Fetching data for IYW from 2024-09-30 to 2024-10-06...
# Fetching data for XLK from 2024-09-30 to 2024-10-06...
# Fetching data for VGT from 2024-09-30 to 2024-10-06...
# Fetching data for FTEC from 2024-09-30 to 2024-10-06...
# Fetching data for IGM from 2024-09-30 to 2024-10-06...
# Fetching data for IXN from 2024-09-30 to 2024-10-06...
# Fetching data for SMH from 2024-10-07 to 2024-10-13...
# Fetching data for SOXX from 2024-10-07 to 2024-10-13...
# Fetching data for PSI from 2024-10-07 to 2024-10-13...
# Fetching data for XSD from 2024-10-07 to 2024-10-13...
# Fetching data for IYW from 2024-10-07 to 2024-10-13...
# Fetching data for XLK from 2024-10-07 to 2024-10-13...
# Fetching data for VGT from 2024-10-07 to 2024-10-13...
# Fetching data for FTEC from 2024-10-07 to 2024-10-13...
# Fetching data for IGM from 2024-10-07 to 2024-10-13...
# Fetching data for IXN from 2024-10-07 to 2024-10-13...
# Fetching data for SMH from 2024-10-14 to 2024-10-20...
# Fetching data for SOXX from 2024-10-14 to 2024-10-20...
# Fetching data for PSI from 2024-10-14 to 2024-10-20...
# Fetching data for XSD from 2024-10-14 to 2024-10-20...
# Fetching data for IYW from 2024-10-14 to 2024-10-20...
# Fetching data for XLK from 2024-10-14 to 2024-10-20...
# Fetching data for VGT from 2024-10-14 to 2024-10-20...
# Fetching data for FTEC from 2024-10-14 to 2024-10-20...
# Fetching data for IGM from 2024-10-14 to 2024-10-20...
# Fetching data for IXN from 2024-10-14 to 2024-10-20...
# Fetching data for SMH from 2024-10-21 to 2024-10-27...
# Fetching data for SOXX from 2024-10-21 to 2024-10-27...
# Fetching data for PSI from 2024-10-21 to 2024-10-27...
# Fetching data for XSD from 2024-10-21 to 2024-10-27...
# Fetching data for IYW from 2024-10-21 to 2024-10-27...
# Fetching data for XLK from 2024-10-21 to 2024-10-27...
# Fetching data for VGT from 2024-10-21 to 2024-10-27...
# Fetching data for FTEC from 2024-10-21 to 2024-10-27...
# Fetching data for IGM from 2024-10-21 to 2024-10-27...
# Fetching data for IXN from 2024-10-21 to 2024-10-27...
# Fetching data for SMH from 2024-10-28 to 2024-11-03...
# Fetching data for SOXX from 2024-10-28 to 2024-11-03...
# Fetching data for PSI from 2024-10-28 to 2024-11-03...
# Fetching data for XSD from 2024-10-28 to 2024-11-03...
# Fetching data for IYW from 2024-10-28 to 2024-11-03...
# Fetching data for XLK from 2024-10-28 to 2024-11-03...
# Fetching data for VGT from 2024-10-28 to 2024-11-03...
# Fetching data for FTEC from 2024-10-28 to 2024-11-03...
# Fetching data for IGM from 2024-10-28 to 2024-11-03...
# Fetching data for IXN from 2024-10-28 to 2024-11-03...
# Fetching data for SMH from 2024-11-04 to 2024-11-10...
# Fetching data for SOXX from 2024-11-04 to 2024-11-10...
# Fetching data for PSI from 2024-11-04 to 2024-11-10...
# Fetching data for XSD from 2024-11-04 to 2024-11-10...
# Fetching data for IYW from 2024-11-04 to 2024-11-10...
# Fetching data for XLK from 2024-11-04 to 2024-11-10...
# Fetching data for VGT from 2024-11-04 to 2024-11-10...
# Fetching data for FTEC from 2024-11-04 to 2024-11-10...
# Fetching data for IGM from 2024-11-04 to 2024-11-10...
# Fetching data for IXN from 2024-11-04 to 2024-11-10...
# Fetching data for SMH from 2024-11-11 to 2024-11-17...
# Fetching data for SOXX from 2024-11-11 to 2024-11-17...
# Fetching data for PSI from 2024-11-11 to 2024-11-17...
# Fetching data for XSD from 2024-11-11 to 2024-11-17...
# Fetching data for IYW from 2024-11-11 to 2024-11-17...
# Fetching data for XLK from 2024-11-11 to 2024-11-17...
# Fetching data for VGT from 2024-11-11 to 2024-11-17...
# Fetching data for FTEC from 2024-11-11 to 2024-11-17...
# Fetching data for IGM from 2024-11-11 to 2024-11-17...
# Fetching data for IXN from 2024-11-11 to 2024-11-17...
# Fetching data for SMH from 2024-11-18 to 2024-11-24...
# Fetching data for SOXX from 2024-11-18 to 2024-11-24...
# Fetching data for PSI from 2024-11-18 to 2024-11-24...
# Fetching data for XSD from 2024-11-18 to 2024-11-24...
# Fetching data for IYW from 2024-11-18 to 2024-11-24...
# Fetching data for XLK from 2024-11-18 to 2024-11-24...
# Fetching data for VGT from 2024-11-18 to 2024-11-24...
# Fetching data for FTEC from 2024-11-18 to 2024-11-24...
# Fetching data for IGM from 2024-11-18 to 2024-11-24...
# Fetching data for IXN from 2024-11-18 to 2024-11-24...
# Fetching data for SMH from 2024-11-25 to 2024-12-01...
# Fetching data for SOXX from 2024-11-25 to 2024-12-01...
# Fetching data for PSI from 2024-11-25 to 2024-12-01...
# Fetching data for XSD from 2024-11-25 to 2024-12-01...
# Fetching data for IYW from 2024-11-25 to 2024-12-01...
# Fetching data for XLK from 2024-11-25 to 2024-12-01...
# Fetching data for VGT from 2024-11-25 to 2024-12-01...
# Fetching data for FTEC from 2024-11-25 to 2024-12-01...
# Fetching data for IGM from 2024-11-25 to 2024-12-01...
# Fetching data for IXN from 2024-11-25 to 2024-12-01...
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1  3.055027
# 1  SOXX   1w             0.1  0.573012
# 2   PSI   1w             0.1 -1.850770
# 3   XSD   1w             0.1 -4.291484
# 4   IYW   1w             0.1  2.159904
# Top ETFs for 2024-01-01 to 2024-01-07: ['SMH', 'IGM']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1 -0.222739
# 1  SOXX   2w             0.1 -2.713105
# 2   PSI   2w             0.1 -2.646390
# 3   XSD   2w             0.1 -3.602561
# 4   IYW   2w             0.1  1.620345
# Top ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'XLK']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  5.983534
# 1  SOXX   3w             0.1  2.636896
# 2   PSI   3w             0.1  4.657212
# 3   XSD   3w             0.1 -2.323010
# 4   IYW   3w             0.1 -1.868476
# Top ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'PSI']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1 -0.793654
# 1  SOXX   4w             0.1 -3.633477
# 2   PSI   4w             0.1 -1.550412
# 3   XSD   4w             0.1  2.387163
# 4   IYW   4w             0.1  1.583787
# Top ETFs for 2024-01-22 to 2024-01-28: ['XSD', 'VGT']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1  1.781195
# 1  SOXX   5w             0.1 -3.785617
# 2   PSI   5w             0.1 -1.471594
# 3   XSD   5w             0.1 -0.581039
# 4   IYW   5w             0.1  1.945415
# Top ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'VGT']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  6.294524
# 1  SOXX   6w             0.1  1.329650
# 2   PSI   6w             0.1  0.825343
# 3   XSD   6w             0.1  2.512138
# 4   IYW   6w             0.1 -1.111198
# Top ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'XSD']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1  0.747962
# 1  SOXX   7w             0.1 -0.009723
# 2   PSI   7w             0.1  3.707763
# 3   XSD   7w             0.1  4.505752
# 4   IYW   7w             0.1 -0.310150
# Top ETFs for 2024-02-12 to 2024-02-18: ['XSD', 'PSI']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1  4.017574
# 1  SOXX   8w             0.1 -0.263040
# 2   PSI   8w             0.1 -3.020412
# 3   XSD   8w             0.1 -4.113931
# 4   IYW   8w             0.1  2.321739
# Top ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'XLK']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1  2.067090
# 1  SOXX   9w             0.1  0.134567
# 2   PSI   9w             0.1  5.482073
# 3   XSD   9w             0.1  4.176994
# 4   IYW   9w             0.1 -2.209433
# Top ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  6.758702
# 1  SOXX  10w             0.1  0.635069
# 2   PSI  10w             0.1 -0.247810
# 3   XSD  10w             0.1  0.024118
# 4   IYW  10w             0.1 -0.724982
# Top ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1 -0.119460
# 1  SOXX  11w             0.1 -2.815731
# 2   PSI  11w             0.1 -3.339035
# 3   XSD  11w             0.1 -0.298541
# 4   IYW  11w             0.1  2.805766
# Top ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1 -1.152143
# 1  SOXX  12w             0.1 -3.465632
# 2   PSI  12w             0.1 -0.422905
# 3   XSD  12w             0.1 -2.232770
# 4   IYW  12w             0.1  3.748586
# Top ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IGM']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1 -1.510700
# 1  SOXX  13w             0.1  0.571150
# 2   PSI  13w             0.1  0.590782
# 3   XSD  13w             0.1  5.785015
# 4   IYW  13w             0.1 -0.299627
# Top ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'XLK']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1  4.949159
# 1  SOXX  14w             0.1 -0.129405
# 2   PSI  14w             0.1  0.533619
# 3   XSD  14w             0.1  0.061038
# 4   IYW  14w             0.1  0.692325
# Top ETFs for 2024-04-01 to 2024-04-07: ['SMH', 'IGM']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1  1.158548
# 1  SOXX  15w             0.1 -0.133999
# 2   PSI  15w             0.1  0.182877
# 3   XSD  15w             0.1  4.630460
# 4   IYW  15w             0.1  0.529884
# Top ETFs for 2024-04-08 to 2024-04-14: ['XSD', 'SMH']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1  3.876207
# 1  SOXX  16w             0.1  2.437109
# 2   PSI  16w             0.1  2.401855
# 3   XSD  16w             0.1 -2.650248
# 4   IYW  16w             0.1  1.018936
# Top ETFs for 2024-04-15 to 2024-04-21: ['SMH', 'SOXX']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1  1.151190
# 1  SOXX  17w             0.1  1.505092
# 2   PSI  17w             0.1  1.782816
# 3   XSD  17w             0.1  1.219136
# 4   IYW  17w             0.1 -1.678033
# Top ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'PSI']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1 -0.297477
# 1  SOXX  18w             0.1 -1.207862
# 2   PSI  18w             0.1 -0.057495
# 3   XSD  18w             0.1  5.275427
# 4   IYW  18w             0.1  0.202766
# Top ETFs for 2024-04-29 to 2024-05-05: ['XSD', 'XLK']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1  1.477720
# 1  SOXX  19w             0.1 -2.544295
# 2   PSI  19w             0.1  0.329428
# 3   XSD  19w             0.1 -1.180705
# 4   IYW  19w             0.1  1.233163
# Top ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'SMH']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1 -1.611488
# 1  SOXX  20w             0.1 -2.909934
# 2   PSI  20w             0.1 -3.434573
# 3   XSD  20w             0.1 -0.561879
# 4   IYW  20w             0.1  2.409882
# Top ETFs for 2024-05-13 to 2024-05-19: ['XLK', 'VGT']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  4.644265
# 1  SOXX  21w             0.1 -0.550871
# 2   PSI  21w             0.1  0.824761
# 3   XSD  21w             0.1 -2.602699
# 4   IYW  21w             0.1  0.934092
# Top ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IXN']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1  4.414831
# 1  SOXX  22w             0.1 -1.408587
# 2   PSI  22w             0.1  0.698568
# 3   XSD  22w             0.1  2.283642
# 4   IYW  22w             0.1  1.724655
# Top ETFs for 2024-05-27 to 2024-06-02: ['SMH', 'XSD']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1  2.956534
# 1  SOXX  23w             0.1 -2.936830
# 2   PSI  23w             0.1 -2.796671
# 3   XSD  23w             0.1 -3.782718
# 4   IYW  23w             0.1  3.458113
# Top ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1  2.759985
# 1  SOXX  24w             0.1 -1.064829
# 2   PSI  24w             0.1  1.928089
# 3   XSD  24w             0.1 -0.250210
# 4   IYW  24w             0.1 -0.313301
# Top ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'PSI']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1  0.473513
# 1  SOXX  25w             0.1 -2.610103
# 2   PSI  25w             0.1  0.843269
# 3   XSD  25w             0.1 -3.246461
# 4   IYW  25w             0.1  1.453126
# Top ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1 -0.296387
# 1  SOXX  26w             0.1 -3.817290
# 2   PSI  26w             0.1  1.193072
# 3   XSD  26w             0.1 -0.649701
# 4   IYW  26w             0.1  3.693284
# Top ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'XLK']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1 -2.222766
# 1  SOXX  27w             0.1 -3.378266
# 2   PSI  27w             0.1 -3.354800
# 3   XSD  27w             0.1 -2.445513
# 4   IYW  27w             0.1  4.624155
# Top ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'VGT']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1  1.847299
# 1  SOXX  28w             0.1  0.825644
# 2   PSI  28w             0.1  0.766593
# 3   XSD  28w             0.1  5.541620
# 4   IYW  28w             0.1 -1.290203
# Top ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1 -1.822125
# 1  SOXX  29w             0.1 -2.204647
# 2   PSI  29w             0.1  1.724825
# 3   XSD  29w             0.1  3.878790
# 4   IYW  29w             0.1  2.397958
# Top ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'IYW']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1  2.106989
# 1  SOXX  30w             0.1  1.023018
# 2   PSI  30w             0.1  1.221712
# 3   XSD  30w             0.1  1.970510
# 4   IYW  30w             0.1  0.041552
# Top ETFs for 2024-07-22 to 2024-07-28: ['SMH', 'XSD']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1  1.199017
# 1  SOXX  31w             0.1  1.483689
# 2   PSI  31w             0.1  0.287204
# 3   XSD  31w             0.1  3.616209
# 4   IYW  31w             0.1  1.730373
# Top ETFs for 2024-07-29 to 2024-08-04: ['XSD', 'IYW']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1  3.079670
# 1  SOXX  32w             0.1  0.700341
# 2   PSI  32w             0.1  6.166867
# 3   XSD  32w             0.1 -0.550100
# 4   IYW  32w             0.1 -0.071635
# Top ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1  1.588516
# 1  SOXX  33w             0.1 -2.782911
# 2   PSI  33w             0.1 -2.330763
# 3   XSD  33w             0.1 -2.686977
# 4   IYW  33w             0.1  0.852308
# Top ETFs for 2024-08-12 to 2024-08-18: ['XLK', 'IXN']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1  0.384154
# 1  SOXX  34w             0.1 -3.899364
# 2   PSI  34w             0.1 -3.360724
# 3   XSD  34w             0.1  0.479472
# 4   IYW  34w             0.1  1.843999
# Top ETFs for 2024-08-19 to 2024-08-25: ['XLK', 'IXN']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1  1.459767
# 1  SOXX  35w             0.1  1.100430
# 2   PSI  35w             0.1  1.420886
# 3   XSD  35w             0.1  4.508542
# 4   IYW  35w             0.1  0.185389
# Top ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'SMH']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1  3.152919
# 1  SOXX  36w             0.1  0.134378
# 2   PSI  36w             0.1  2.379201
# 3   XSD  36w             0.1  0.077987
# 4   IYW  36w             0.1  2.100065
# Top ETFs for 2024-09-02 to 2024-09-08: ['SMH', 'XLK']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1  0.937642
# 1  SOXX  37w             0.1 -2.615176
# 2   PSI  37w             0.1 -4.440706
# 3   XSD  37w             0.1 -1.849484
# 4   IYW  37w             0.1 -0.255466
# Top ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'FTEC']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1 -0.319921
# 1  SOXX  38w             0.1 -2.990559
# 2   PSI  38w             0.1 -2.049663
# 3   XSD  38w             0.1 -0.666839
# 4   IYW  38w             0.1  3.386554
# Top ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1  4.923633
# 1  SOXX  39w             0.1  0.116162
# 2   PSI  39w             0.1  2.313981
# 3   XSD  39w             0.1  2.014054
# 4   IYW  39w             0.1 -0.662516
# Top ETFs for 2024-09-23 to 2024-09-29: ['SMH', 'PSI']
# Processing scores for 2024-09-30 to 2024-10-06:
#     ETF Week  RiskPercentage     Score
# 0   SMH  40w             0.1 -0.322595
# 1  SOXX  40w             0.1 -2.283109
# 2   PSI  40w             0.1 -1.955153
# 3   XSD  40w             0.1 -2.132410
# 4   IYW  40w             0.1  4.847400
# Top ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Processing scores for 2024-10-07 to 2024-10-13:
#     ETF Week  RiskPercentage     Score
# 0   SMH  41w             0.1  3.723424
# 1  SOXX  41w             0.1 -4.669566
# 2   PSI  41w             0.1 -0.423826
# 3   XSD  41w             0.1 -0.565061
# 4   IYW  41w             0.1  1.859868
# Top ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'XLK']
# Processing scores for 2024-10-14 to 2024-10-20:
#     ETF Week  RiskPercentage     Score
# 0   SMH  42w             0.1  0.367719
# 1  SOXX  42w             0.1 -3.053917
# 2   PSI  42w             0.1 -1.569878
# 3   XSD  42w             0.1 -2.263250
# 4   IYW  42w             0.1  3.047544
# Top ETFs for 2024-10-14 to 2024-10-20: ['XLK', 'IYW']
# Processing scores for 2024-10-21 to 2024-10-27:
#     ETF Week  RiskPercentage     Score
# 0   SMH  43w             0.1  0.802072
# 1  SOXX  43w             0.1 -2.203691
# 2   PSI  43w             0.1 -1.333517
# 3   XSD  43w             0.1 -1.234447
# 4   IYW  43w             0.1  5.008142
# Top ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'XLK']
# Processing scores for 2024-10-28 to 2024-11-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH  44w             0.1 -1.886383
# 1  SOXX  44w             0.1 -0.342239
# 2   PSI  44w             0.1 -0.600253
# 3   XSD  44w             0.1  4.689034
# 4   IYW  44w             0.1  1.498424
# Top ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IGM']
# Processing scores for 2024-11-04 to 2024-11-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  45w             0.1 -0.915754
# 1  SOXX  45w             0.1 -4.614090
# 2   PSI  45w             0.1 -1.253519
# 3   XSD  45w             0.1 -0.925735
# 4   IYW  45w             0.1  1.954012
# Top ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'VGT']
# Processing scores for 2024-11-11 to 2024-11-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  46w             0.1 -0.174000
# 1  SOXX  46w             0.1 -1.409027
# 2   PSI  46w             0.1 -2.759207
# 3   XSD  46w             0.1 -2.548022
# 4   IYW  46w             0.1  2.623807
# Top ETFs for 2024-11-11 to 2024-11-17: ['IGM', 'IYW']
# Processing scores for 2024-11-18 to 2024-11-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  47w             0.1 -1.047246
# 1  SOXX  47w             0.1 -1.146325
# 2   PSI  47w             0.1  4.369800
# 3   XSD  47w             0.1  5.480375
# 4   IYW  47w             0.1 -0.386459
# Top ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'PSI']
# Processing scores for 2024-11-25 to 2024-12-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  48w             0.1 -1.137776
# 1  SOXX  48w             0.1  0.183881
# 2   PSI  48w             0.1  2.107618
# 3   XSD  48w             0.1  4.493069
# 4   IYW  48w             0.1 -0.082742
# Top ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'PSI']
#
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['SMH', 'IGM']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'XLK']
# Sell SMH: 288.51 shares at 171.96. Total value: 48372.34
# Buy XLK: 249.88 shares at 188.74.
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'IGM': 670.3334619848428, 'XLK': 249.88358860462202}
#
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'XLK']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'PSI']
# Sell IGM: 670.33 shares at 75.45. Total value: 49311.15
# Buy SMH: 273.64 shares at 175.70.
# Sell XLK: 249.88 shares at 192.72. Total value: 46953.63
# Buy PSI: 959.54 shares at 47.71.
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'SMH': 273.63902201780513, 'PSI': 959.542791506945}
#
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'PSI']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['XSD', 'VGT']
# Sell SMH: 273.64 shares at 188.05. Total value: 50171.37
# Buy XSD: 217.72 shares at 224.68.
# Sell PSI: 959.54 shares at 51.02. Total value: 47731.98
# Buy VGT: 92.53 shares at 502.96.
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'XSD': 217.7189367576172, 'VGT': 92.52958125999781}
#
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['XSD', 'VGT']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'VGT']
# Sell XSD: 217.72 shares at 220.29. Total value: 46762.27
# Buy IGM: 565.66 shares at 80.60.
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'VGT': 92.52958125999781, 'IGM': 565.6609120463838}
#
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'VGT']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'XSD']
# Sell IGM: 565.66 shares at 81.27. Total value: 44820.14
# Buy SMH: 224.16 shares at 194.95.
# Sell VGT: 92.53 shares at 505.40. Total value: 45595.34
# Buy XSD: 209.35 shares at 212.35.
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'SMH': 224.15820161811865, 'XSD': 209.3499120188456}
#
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'XSD']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['XSD', 'PSI']
# Sell SMH: 224.16 shares at 203.06. Total value: 44379.62
# Buy PSI: 821.38 shares at 52.68.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'XSD': 209.3499120188456, 'PSI': 821.3768774943951}
#
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['XSD', 'PSI']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'XLK']
# Sell XSD: 209.35 shares at 217.39. Total value: 44372.81
# Buy SMH: 218.75 shares at 197.78.
# Sell PSI: 821.38 shares at 51.59. Total value: 41315.46
# Buy XLK: 200.90 shares at 200.51.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'SMH': 218.7455392936693, 'XLK': 200.90058823927254}
#
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'XLK']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Sell SMH: 218.75 shares at 210.35. Total value: 44862.80
# Buy PSI: 820.35 shares at 53.32.
# Sell XLK: 200.90 shares at 205.49. Total value: 40250.99
# Buy XSD: 177.80 shares at 220.73.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'PSI': 820.3531077094619, 'XSD': 177.79510037516545}
#
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Sell PSI: 820.35 shares at 56.78. Total value: 45415.16
# Buy SMH: 197.60 shares at 224.09.
# Sell XSD: 177.80 shares at 231.79. Total value: 40180.85
# Buy SOXX: 171.20 shares at 228.84.
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'SMH': 197.59819284898487, 'SOXX': 171.19527375585912}
#
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Sell SMH: 197.60 shares at 220.98. Total value: 42573.62
# Buy XLK: 200.74 shares at 206.78.
# Sell SOXX: 171.20 shares at 225.10. Total value: 37572.66
# Buy IYW: 275.54 shares at 132.95.
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'XLK': 200.7412537280631, 'IYW': 275.54223531844923}
#
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['XLK', 'IYW']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IGM']
# Sell XLK: 200.74 shares at 206.30. Total value: 40377.60
# Buy IGM: 462.12 shares at 85.19.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'IYW': 275.54223531844923, 'IGM': 462.1218117318442}
#
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'IGM']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'XLK']
# Sell IYW: 275.54 shares at 135.90. Total value: 36510.03
# Buy XSD: 157.37 shares at 226.20.
# Sell IGM: 462.12 shares at 86.60. Total value: 39019.25
# Buy XLK: 182.45 shares at 208.52.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'XSD': 157.3708357246675, 'XLK': 182.44663506818122}
#
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'XLK']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['SMH', 'IGM']
# Sell XSD: 157.37 shares at 233.86. Total value: 35882.68
# Buy SMH: 153.49 shares at 227.94.
# Sell XLK: 182.45 shares at 208.85. Total value: 37151.38
# Buy IGM: 417.99 shares at 86.66.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'SMH': 153.48603971135398, 'IGM': 417.98517496538256}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['SMH', 'IGM']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['XSD', 'SMH']
# Sell IGM: 417.99 shares at 85.96. Total value: 35031.76
# Buy XSD: 148.27 shares at 230.36.
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'SMH': 153.48603971135398, 'XSD': 148.2721008737098}
#
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['XSD', 'SMH']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['SMH', 'SOXX']
# Sell XSD: 148.27 shares at 218.68. Total value: 31613.54
# Buy SOXX: 143.16 shares at 215.31.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'SMH': 153.48603971135398, 'SOXX': 143.1573093430152}
#
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'PSI']
# Sell SMH: 153.49 shares at 203.02. Total value: 30381.72
# Buy FTEC: 205.35 shares at 144.25.
# Sell SOXX: 143.16 shares at 201.66. Total value: 28147.38
# Buy PSI: 539.27 shares at 50.89.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'FTEC': 205.35303345814773, 'PSI': 539.2747468835298}
#
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'PSI']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['XSD', 'XLK']
# Sell FTEC: 205.35 shares at 150.29. Total value: 30090.94
# Buy XSD: 128.32 shares at 228.64.
# Sell PSI: 539.27 shares at 55.04. Total value: 28939.64
# Buy XLK: 140.60 shares at 200.69.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'XSD': 128.31818519641337, 'XLK': 140.59569057965476}
#
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['XSD', 'XLK']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'SMH']
# Sell XSD: 128.32 shares at 230.00. Total value: 28775.35
# Buy SMH: 126.00 shares at 222.67.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'XLK': 140.59569057965476, 'SMH': 125.99797653589388}
#
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['XLK', 'SMH']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['XLK', 'VGT']
# Sell SMH: 126.00 shares at 223.26. Total value: 27427.05
# Buy VGT: 51.55 shares at 518.78.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'XLK': 140.59569057965476, 'VGT': 51.54665196012719}
#
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['XLK', 'VGT']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IXN']
# Sell XLK: 140.60 shares at 214.31. Total value: 29377.79
# Buy SMH: 121.89 shares at 235.00.
# Sell VGT: 51.55 shares at 539.30. Total value: 27104.13
# Buy IXN: 343.92 shares at 76.84.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'SMH': 121.88655707849546, 'IXN': 343.91630708828643}
#
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'IXN']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['SMH', 'XSD']
# Sell IXN: 343.92 shares at 78.68. Total value: 26382.85
# Buy XSD: 103.21 shares at 249.23.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'SMH': 121.88655707849546, 'XSD': 103.2110135808688}
#
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['SMH', 'XSD']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Sell SMH: 121.89 shares at 243.48. Total value: 28935.01
# Buy IXN: 366.10 shares at 77.06.
# Sell XSD: 103.21 shares at 245.69. Total value: 24723.97
# Buy IYW: 172.53 shares at 139.72.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'IXN': 366.09966853330724, 'IYW': 172.52982361497607}
#
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'IYW']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'PSI']
# Sell IXN: 366.10 shares at 79.41. Total value: 28345.18
# Buy SMH: 108.01 shares at 255.86.
# Sell IYW: 172.53 shares at 143.93. Total value: 24211.41
# Buy PSI: 387.05 shares at 60.99.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'SMH': 108.01433259229938, 'PSI': 387.0491051369271}
#
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'PSI']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Sell SMH: 108.01 shares at 272.48. Total value: 28695.95
# Buy XLK: 121.06 shares at 231.12.
# Sell PSI: 387.05 shares at 63.94. Total value: 24129.22
# Buy IXN: 278.78 shares at 84.39.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'XLK': 121.05639770481541, 'IXN': 278.77699855506177}
#
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['XLK', 'IXN']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'XLK']
# Sell IXN: 278.78 shares at 81.49. Total value: 22149.60
# Buy IYW: 146.11 shares at 147.81.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'XLK': 121.05639770481541, 'IYW': 146.10553401814812}
#
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'XLK']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'VGT']
# Sell XLK: 121.06 shares at 227.94. Total value: 26903.76
# Buy VGT: 45.05 shares at 582.25.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'IYW': 146.10553401814812, 'VGT': 45.05137278867675}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'VGT']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Sell IYW: 146.11 shares at 156.96. Total value: 22359.41
# Buy XSD: 83.63 shares at 260.69.
# Sell VGT: 45.05 shares at 599.91. Total value: 26351.10
# Buy SMH: 93.70 shares at 274.21.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 83.62584705871416, 'SMH': 93.69578782069733}
#
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'SMH']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'IYW']
# Sell SMH: 93.70 shares at 273.83. Total value: 25015.30
# Buy IYW: 155.67 shares at 156.68.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'XSD': 83.62584705871416, 'IYW': 155.66707360619506}
#
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'IYW']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['SMH', 'XSD']
# Sell IYW: 155.67 shares at 151.02. Total value: 22921.12
# Buy SMH: 86.71 shares at 257.72.
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'XSD': 83.62584705871416, 'SMH': 86.7146241483295}
#
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['SMH', 'XSD']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['XSD', 'IYW']
# Sell SMH: 86.71 shares at 238.60. Total value: 20172.86
# Buy IYW: 136.45 shares at 144.14.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'XSD': 83.62584705871416, 'IYW': 136.45438990179528}
#
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['XSD', 'IYW']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Sell XSD: 83.63 shares at 206.84. Total value: 16864.74
# Buy PSI: 331.65 shares at 49.58.
# Sell IYW: 136.45 shares at 133.32. Total value: 17737.30
# Buy SMH: 81.07 shares at 213.31.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'PSI': 331.64827608571085, 'SMH': 81.07386202555027}
#
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'SMH']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['XLK', 'IXN']
# Sell PSI: 331.65 shares at 53.06. Total value: 17157.33
# Buy XLK: 80.69 shares at 207.31.
# Sell SMH: 81.07 shares at 226.96. Total value: 17940.51
# Buy IXN: 228.44 shares at 76.57.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'XLK': 80.69265143299134, 'IXN': 228.44454033616807}
#
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['XLK', 'IXN']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['XLK', 'IXN']
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'XLK': 80.69265143299134, 'IXN': 228.44454033616807}
#
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['XLK', 'IXN']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'SMH']
# Sell XLK: 80.69 shares at 221.15. Total value: 17399.05
# Buy XSD: 72.34 shares at 234.52.
# Sell IXN: 228.44 shares at 81.40. Total value: 18130.50
# Buy SMH: 72.87 shares at 242.57.
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'XSD': 72.33529477810006, 'SMH': 72.87479167993648}
#
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'SMH']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['SMH', 'XLK']
# Sell XSD: 72.34 shares at 222.36. Total value: 15682.36
# Buy XLK: 72.74 shares at 210.21.
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'SMH': 72.87479167993648, 'XLK': 72.73823648124446}
#
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['SMH', 'XLK']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'FTEC']
# Sell SMH: 72.87 shares at 219.86. Total value: 15621.70
# Buy FTEC: 94.87 shares at 160.54.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'XLK': 72.73823648124446, 'FTEC': 94.87450915898185}
#
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['XLK', 'FTEC']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Sell XLK: 72.74 shares at 219.60. Total value: 15573.98
# Buy IGM: 164.53 shares at 92.29.
# Sell FTEC: 94.87 shares at 168.10. Total value: 15549.70
# Buy IYW: 103.81 shares at 146.04.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'IGM': 164.5317422156187, 'IYW': 103.81370679765904}
#
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IYW']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['SMH', 'PSI']
# Sell IGM: 164.53 shares at 94.58. Total value: 15172.38
# Buy SMH: 61.91 shares at 238.95.
# Sell IYW: 103.81 shares at 149.26. Total value: 15107.85
# Buy PSI: 267.29 shares at 55.11.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'SMH': 61.90863330298811, 'PSI': 267.28644526788224}
#
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['SMH', 'PSI']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Sell SMH: 61.91 shares at 245.45. Total value: 14815.59
# Buy IYW: 95.27 shares at 151.62.
# Sell PSI: 267.29 shares at 57.52. Total value: 14989.96
# Buy XLK: 64.74 shares at 225.76.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'IYW': 95.27237698773625, 'XLK': 64.73781863418583}
#
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'XLK']
# Sell IYW: 95.27 shares at 150.36. Total value: 13967.03
# Buy SMH: 54.86 shares at 248.22.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'XLK': 64.73781863418583, 'SMH': 54.86201790193341}
#
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'XLK']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['XLK', 'IYW']
# Sell SMH: 54.86 shares at 261.28. Total value: 13975.99
# Buy IYW: 86.79 shares at 157.01.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'XLK': 64.73781863418583, 'IYW': 86.78803908124989}
#
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['XLK', 'IYW']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'XLK']
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'XLK': 64.73781863418583, 'IYW': 86.78803908124989}
#
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'XLK']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IGM']
# Sell IYW: 86.79 shares at 155.65. Total value: 13170.84
# Buy XSD: 52.03 shares at 246.83.
# Sell XLK: 64.74 shares at 230.22. Total value: 14531.34
# Buy IGM: 144.65 shares at 97.95.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'XSD': 52.0259799009584, 'IGM': 144.6458300672862}
#
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['XSD', 'IGM']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'VGT']
# Sell XSD: 52.03 shares at 233.24. Total value: 11831.18
# Buy XLK: 51.56 shares at 223.74.
# Sell IGM: 144.65 shares at 95.86. Total value: 13519.11
# Buy VGT: 22.50 shares at 585.90.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'XLK': 51.55714959407901, 'VGT': 22.49723064466361}
#
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['XLK', 'VGT']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IGM', 'IYW']
# Sell XLK: 51.56 shares at 235.85. Total value: 11855.76
# Buy IGM: 113.48 shares at 101.86.
# Sell VGT: 22.50 shares at 621.92. Total value: 13641.69
# Buy IYW: 82.99 shares at 160.27.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'IGM': 113.48287964987047, 'IYW': 82.98900450425087}
#
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IGM', 'IYW']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'PSI']
# Sell IGM: 113.48 shares at 99.13. Total value: 10968.32
# Buy XSD: 46.78 shares at 228.59.
# Sell IYW: 82.99 shares at 156.19. Total value: 12638.00
# Buy PSI: 227.93 shares at 54.06.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'XSD': 46.782933703982074, 'PSI': 227.9328735722214}
#
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['XSD', 'PSI']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'PSI']
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'XSD': 46.782933703982074, 'PSI': 227.9328735722214}
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker XSD starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# XSD: 46.78 shares at $252.68 each, total value: $11821.11
# Fetching data for ticker PSI starting from 2024-12-01...
# PSI: 227.93 shares at $57.84 each, total value: $13183.64
#
# ETF values on the 49th week's first trading day:
# Total portfolio value: 25004.75
# XSD: 11821.11
# PSI: 13183.64

# %%
def process_etf_data_monthly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = {}

    # Process each ETF
    for etf_name in tickers:
        etf_data = etf_dict.get(etf_name, {})
        monthly_forecast_results = etf_data.get("monthly_forecast_results", {})
        etf_pred_dict[etf_name] = {}

        # Extract forecast periods from monthly_forecast_results
        forecast_periods = [key.split('_')[-1] for key in monthly_forecast_results.keys()]

        for period in forecast_periods:
            forecast_key = f"forecast_data_{period}"
            if forecast_key in monthly_forecast_results:
                # Extract the forecasted DataFrame
                forecast_df = monthly_forecast_results[forecast_key]
                returns = forecast_df["log_returns"].values  # Assuming 'log_returns' is the column of interest
                etf_pred_dict[etf_name][f"returns_{period}"] = returns

                if smoothing:
                    # Apply smoothing
                    smoothed_returns = calculate_smoothing(returns)
                    etf_pred_dict[etf_name][f"smoothed_returns_{period}"] = smoothed_returns

                    # Calculate metrics using smoothed returns
                    etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(smoothed_returns)
                    etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(smoothed_returns)
                    etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(smoothed_returns)
                    etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(smoothed_returns)
                else:
                    # Calculate metrics using raw returns
                    etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
                    etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
                    etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
                    etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict



def calculate_means_and_stds_monthly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )


def calculate_scores_for_etfs_monthly(etf_pred_dict, forecast_period, risk_percentage, smoothing=True):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_monthly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Month': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

    return scores


def select_top_etfs_monthly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()


def generate_month_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    month_ranges = []

    while start < end:
        month_start = start
        month_end = (start + timedelta(days=31)).replace(day=1) - timedelta(days=1)
        if month_end > end:
            month_end = end
        month_ranges.append((month_start.strftime('%Y-%m-%d'), month_end.strftime('%Y-%m-%d')))
        start = month_end + timedelta(days=1)

    return month_ranges

def gather_etf_data_for_months(tickers, month_ranges):
    etf_histories = {}
    for start_date, end_date in month_ranges:
        month = f"{start_date} to {end_date}"
        etf_histories[month] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date, progress=False)
            if etf_data.empty:
                print(f"No data found for {ticker} in {month}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[month][ticker] = etf_data
    return etf_histories

# Function to initialize shares for the first month
def initialize_shares_for_first_month(top_etfs_1m, etf_histories, month, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = month.split(" to ")[0]

    for ticker in top_etfs_1m:
        etf_history = etf_histories.get(month, {}).get(ticker)

        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]

            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st month: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {month}")
    return ticker_shares


def manage_etf_portfolio_monthly(
    top_etfs_previous, top_etfs_current, previous_month, current_month, ticker_shares, gathered_data_per_month
):
    etf_histories_for_current_month = gathered_data_per_month.get(current_month, {})

    # Extract ETFs as lists to preserve order
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_month}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_month}: {top2etfs_current}")

    # Step 1: Identify common ETFs (present in both months)
    etfs_common = [etf for etf in top2etfs_previous if etf in top2etfs_current]

    # Step 2: Identify ETFs to sell (present in the previous month but not in the current month)
    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]

    # Step 3: Identify ETFs to buy (present in the current month but not in the previous month)
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Step 4: Sell ETFs that are no longer in the current top ETFs
    selling_values = {}  # Track selling values for each ETF being sold
    for etf in etfs_to_sell:
        no_of_shares = ticker_shares.get(etf, 0)
        if no_of_shares > 0:
            # Check if data for the ETF is available in the current month
            if etf in etf_histories_for_current_month:
                first_trading_day_current_month = etf_histories_for_current_month[etf].loc[
                    etf_histories_for_current_month[etf].index[0], 'Close'
                ]
                
                selling_value = no_of_shares * first_trading_day_current_month * 0.975
                selling_values[etf] = selling_value  # Store selling value for this ETF
                print(f"Formula: {no_of_shares} * {first_trading_day_current_month} * 0.975")
                print(f"Sell {etf}: {no_of_shares:.2f} shares at {first_trading_day_current_month:.2f}. Total value: {selling_value:.2f}\n")
                del ticker_shares[etf]
            else:
                print(f"Data for {etf} is missing for {current_month}. Skipping sale.")
        else:
            print(f"No shares found for {etf} to sell.")

    # Step 5: Buy new ETFs that were not in the previous month's top ETFs
    for etf_to_buy, etf_to_sell in zip(etfs_to_buy, etfs_to_sell):
        selling_value = selling_values.get(etf_to_sell, 0)
        if selling_value > 0 and etf_to_buy in etf_histories_for_current_month:
            first_trading_day_new_etf = etf_histories_for_current_month[etf_to_buy].loc[
                etf_histories_for_current_month[etf_to_buy].index[0], 'Close'
            ]
            new_shares = (selling_value * 0.975) / first_trading_day_new_etf
            print(f"Formula: ({selling_value} * 0.975) / {first_trading_day_new_etf}")
            print(f"Buy {etf_to_buy}: {new_shares:.2f} shares at {first_trading_day_new_etf:.2f}.\n")
            ticker_shares[etf_to_buy] = new_shares
        else:
            print(f"Data for {etf_to_buy} is missing or no selling value available. Skipping purchase of {etf_to_buy}.")

    # Step 6: Maintain the order of ETFs in the ticker_shares dictionary based on the current top 2 ETFs
    ordered_ticker_shares = {etf: ticker_shares[etf] for etf in top2etfs_current if etf in ticker_shares}

    print(f"Updated ticker shares after {current_month}: {ordered_ticker_shares}")
    print("")
    return ordered_ticker_shares



def main_monthly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = process_etf_data_monthly(tickers, etf_dict, smoothing=smoothing)

    risk_percentage = 0.10
    monthly_scores = {}

    # Calculate scores for all months
    for month in range(1, 13):
        month_key = f"{month}m"
        if any(f"returns_{month_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, month_key, risk_percentage)  # Reusing weekly function
            monthly_scores[month_key] = scores

    # Convert scores to DataFrames
    monthly_scores_dfs = {}
    for month_key, scores in monthly_scores.items():
        monthly_scores_dfs[month_key] = pd.DataFrame(scores)

    # Select top ETFs for each month
    top_etfs_monthly = {}
    for month_key, df_scores in monthly_scores_dfs.items():
        top_etfs_monthly[month_key] = df_scores.nlargest(2, 'Score')

    # Generate month ranges for ETF data gathering
    month_ranges = generate_month_ranges('2024-01-01', '2024-12-01')

    # Gather ETF historical data
    etf_histories = gather_etf_data_for_weeks(tickers, month_ranges)

    # Map month keys to date ranges
    month_key_mapping = {f"{i+1}m": month_range for i, month_range in enumerate(etf_histories.keys())}

    # Align top ETFs with historical data
    aligned_top_etfs_monthly = {}
    for month_key, df_scores in monthly_scores_dfs.items():
        forecast_period = month_key_mapping.get(month_key, None)
        if forecast_period:
            aligned_top_etfs_monthly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

    # Initialize and manage portfolio
    ticker_shares = {}
    ticker_shares_per_month = {}
    for i, month_range in enumerate(etf_histories.keys()):
        current_month_key = month_range
        if i == 0:
            # Initialize shares for the first month
            ticker_shares = initialize_shares_for_first_week(
                aligned_top_etfs_monthly[current_month_key],
                etf_histories,
                current_month_key
            )
            ticker_shares_per_month[current_month_key] = ticker_shares.copy()
        else:
            # Manage portfolio for subsequent months
            prev_month_key = list(etf_histories.keys())[i - 1]
            ticker_shares = manage_etf_portfolio_monthly(
                aligned_top_etfs_monthly[prev_month_key],
                aligned_top_etfs_monthly[current_month_key],
                prev_month_key,
                current_month_key,
                ticker_shares,
                etf_histories
            )
            ticker_shares_per_month[current_month_key] = ticker_shares.copy()

    # Define the first trading day of the 13th month
    first_trading_day_13m = '2024-12-01'

    # Identify the 12th and 13th month date ranges
    month_12_range = list(ticker_shares_per_month.keys())[-1]
    month_13_start = first_trading_day_13m
    print(f"Using data for the 12th month: {month_12_range}")
    print(f"Fetching data starting from the first trading day of the 13th month: {month_13_start}")

    month_13_end = '2024-12-31'
    etf_values_13m = {}

    # Ensure 12th month data exists
    if month_12_range in ticker_shares_per_month:
        ticker_shares_12m = ticker_shares_per_month[month_12_range]

        # Fetch the first trading day price of the 13th month for each ETF
        for ticker, shares in ticker_shares_12m.items():
            print(f"Fetching data for ticker {ticker} starting from {month_13_start}...")
            data = yf.download(ticker, start=month_13_start, end=month_13_end)

            if not data.empty:
                closing_price_13m = data['Close'].iloc[0]
                total_value = shares * closing_price_13m
                etf_values_13m[ticker] = total_value
                print(f"{ticker}: {shares:.2f} shares at ${closing_price_13m:.2f} each, total value: ${total_value:.2f}")
            else:
                print(f"{ticker}: No data available for the 13th month's first trading day.")
    else:
        print(f"No data available in ticker_shares_per_month for the 12th month: {month_12_range}")

    # Display total portfolio value for the 13th month's first trading day
    if etf_values_13m:
        print("\nETF values on the 13th month's first trading day:")
        total_value = sum(etf_values_13m.values())
        print(f"Total portfolio value: {total_value:.2f}")
        for ticker, value in etf_values_13m.items():
            print(f"{ticker}: {value:.2f}")
    else:
        print("No values could be calculated for the 13th month's first trading day.")

    return ticker_shares_per_month

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_month = main_monthly(tickers, results,False)
# Out:
# Fetching data for SMH from 2024-01-01 to 2024-01-31...
# Fetching data for SOXX from 2024-01-01 to 2024-01-31...
# Fetching data for PSI from 2024-01-01 to 2024-01-31...
# Fetching data for XSD from 2024-01-01 to 2024-01-31...
# Fetching data for IYW from 2024-01-01 to 2024-01-31...
# Fetching data for XLK from 2024-01-01 to 2024-01-31...
# Fetching data for VGT from 2024-01-01 to 2024-01-31...
# Fetching data for FTEC from 2024-01-01 to 2024-01-31...
# Fetching data for IGM from 2024-01-01 to 2024-01-31...
# Fetching data for IXN from 2024-01-01 to 2024-01-31...
# Fetching data for SMH from 2024-02-01 to 2024-02-29...
# Fetching data for SOXX from 2024-02-01 to 2024-02-29...
# Fetching data for PSI from 2024-02-01 to 2024-02-29...
# Fetching data for XSD from 2024-02-01 to 2024-02-29...
# Fetching data for IYW from 2024-02-01 to 2024-02-29...
# Fetching data for XLK from 2024-02-01 to 2024-02-29...
# Fetching data for VGT from 2024-02-01 to 2024-02-29...
# Fetching data for FTEC from 2024-02-01 to 2024-02-29...
# Fetching data for IGM from 2024-02-01 to 2024-02-29...
# Fetching data for IXN from 2024-02-01 to 2024-02-29...
# Fetching data for SMH from 2024-03-01 to 2024-03-31...
# Fetching data for SOXX from 2024-03-01 to 2024-03-31...
# Fetching data for PSI from 2024-03-01 to 2024-03-31...
# Fetching data for XSD from 2024-03-01 to 2024-03-31...
# Fetching data for IYW from 2024-03-01 to 2024-03-31...
# Fetching data for XLK from 2024-03-01 to 2024-03-31...
# Fetching data for VGT from 2024-03-01 to 2024-03-31...
# Fetching data for FTEC from 2024-03-01 to 2024-03-31...
# Fetching data for IGM from 2024-03-01 to 2024-03-31...
# Fetching data for IXN from 2024-03-01 to 2024-03-31...
# Fetching data for SMH from 2024-04-01 to 2024-04-30...
# Fetching data for SOXX from 2024-04-01 to 2024-04-30...
# Fetching data for PSI from 2024-04-01 to 2024-04-30...
# Fetching data for XSD from 2024-04-01 to 2024-04-30...
# Fetching data for IYW from 2024-04-01 to 2024-04-30...
# Fetching data for XLK from 2024-04-01 to 2024-04-30...
# Fetching data for VGT from 2024-04-01 to 2024-04-30...
# Fetching data for FTEC from 2024-04-01 to 2024-04-30...
# Fetching data for IGM from 2024-04-01 to 2024-04-30...
# Fetching data for IXN from 2024-04-01 to 2024-04-30...
# Fetching data for SMH from 2024-05-01 to 2024-05-31...
# Fetching data for SOXX from 2024-05-01 to 2024-05-31...
# Fetching data for PSI from 2024-05-01 to 2024-05-31...
# Fetching data for XSD from 2024-05-01 to 2024-05-31...
# Fetching data for IYW from 2024-05-01 to 2024-05-31...
# Fetching data for XLK from 2024-05-01 to 2024-05-31...
# Fetching data for VGT from 2024-05-01 to 2024-05-31...
# Fetching data for FTEC from 2024-05-01 to 2024-05-31...
# Fetching data for IGM from 2024-05-01 to 2024-05-31...
# Fetching data for IXN from 2024-05-01 to 2024-05-31...
# Fetching data for SMH from 2024-06-01 to 2024-06-30...
# Fetching data for SOXX from 2024-06-01 to 2024-06-30...
# Fetching data for PSI from 2024-06-01 to 2024-06-30...
# Fetching data for XSD from 2024-06-01 to 2024-06-30...
# Fetching data for IYW from 2024-06-01 to 2024-06-30...
# Fetching data for XLK from 2024-06-01 to 2024-06-30...
# Fetching data for VGT from 2024-06-01 to 2024-06-30...
# Fetching data for FTEC from 2024-06-01 to 2024-06-30...
# Fetching data for IGM from 2024-06-01 to 2024-06-30...
# Fetching data for IXN from 2024-06-01 to 2024-06-30...
# Fetching data for SMH from 2024-07-01 to 2024-07-31...
# Fetching data for SOXX from 2024-07-01 to 2024-07-31...
# Fetching data for PSI from 2024-07-01 to 2024-07-31...
# Fetching data for XSD from 2024-07-01 to 2024-07-31...
# Fetching data for IYW from 2024-07-01 to 2024-07-31...
# Fetching data for XLK from 2024-07-01 to 2024-07-31...
# Fetching data for VGT from 2024-07-01 to 2024-07-31...
# Fetching data for FTEC from 2024-07-01 to 2024-07-31...
# Fetching data for IGM from 2024-07-01 to 2024-07-31...
# Fetching data for IXN from 2024-07-01 to 2024-07-31...
# Fetching data for SMH from 2024-08-01 to 2024-08-31...
# Fetching data for SOXX from 2024-08-01 to 2024-08-31...
# Fetching data for PSI from 2024-08-01 to 2024-08-31...
# Fetching data for XSD from 2024-08-01 to 2024-08-31...
# Fetching data for IYW from 2024-08-01 to 2024-08-31...
# Fetching data for XLK from 2024-08-01 to 2024-08-31...
# Fetching data for VGT from 2024-08-01 to 2024-08-31...
# Fetching data for FTEC from 2024-08-01 to 2024-08-31...
# Fetching data for IGM from 2024-08-01 to 2024-08-31...
# Fetching data for IXN from 2024-08-01 to 2024-08-31...
# Fetching data for SMH from 2024-09-01 to 2024-09-30...
# Fetching data for SOXX from 2024-09-01 to 2024-09-30...
# Fetching data for PSI from 2024-09-01 to 2024-09-30...
# Fetching data for XSD from 2024-09-01 to 2024-09-30...
# Fetching data for IYW from 2024-09-01 to 2024-09-30...
# Fetching data for XLK from 2024-09-01 to 2024-09-30...
# Fetching data for VGT from 2024-09-01 to 2024-09-30...
# Fetching data for FTEC from 2024-09-01 to 2024-09-30...
# Fetching data for IGM from 2024-09-01 to 2024-09-30...
# Fetching data for IXN from 2024-09-01 to 2024-09-30...
# Fetching data for SMH from 2024-10-01 to 2024-10-31...
# Fetching data for SOXX from 2024-10-01 to 2024-10-31...
# Fetching data for PSI from 2024-10-01 to 2024-10-31...
# Fetching data for XSD from 2024-10-01 to 2024-10-31...
# Fetching data for IYW from 2024-10-01 to 2024-10-31...
# Fetching data for XLK from 2024-10-01 to 2024-10-31...
# Fetching data for VGT from 2024-10-01 to 2024-10-31...
# Fetching data for FTEC from 2024-10-01 to 2024-10-31...
# Fetching data for IGM from 2024-10-01 to 2024-10-31...
# Fetching data for IXN from 2024-10-01 to 2024-10-31...
# Fetching data for SMH from 2024-11-01 to 2024-11-30...
# Fetching data for SOXX from 2024-11-01 to 2024-11-30...
# Fetching data for PSI from 2024-11-01 to 2024-11-30...
# Fetching data for XSD from 2024-11-01 to 2024-11-30...
# Fetching data for IYW from 2024-11-01 to 2024-11-30...
# Fetching data for XLK from 2024-11-01 to 2024-11-30...
# Fetching data for VGT from 2024-11-01 to 2024-11-30...
# Fetching data for FTEC from 2024-11-01 to 2024-11-30...
# Fetching data for IGM from 2024-11-01 to 2024-11-30...
# Fetching data for IXN from 2024-11-01 to 2024-11-30...
# Processing scores for 2024-01-01 to 2024-01-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1m             0.1  3.287515
# 1  SOXX   1m             0.1 -1.455265
# 2   PSI   1m             0.1 -1.588708
# 3   XSD   1m             0.1 -3.429777
# 4   IYW   1m             0.1  2.697002
# Top ETFs for 2024-01-01 to 2024-01-31: ['SMH', 'XLK']
# Processing scores for 2024-02-01 to 2024-02-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2m             0.1  4.151988
# 1  SOXX   2m             0.1 -0.767661
# 2   PSI   2m             0.1  1.047732
# 3   XSD   2m             0.1 -0.728455
# 4   IYW   2m             0.1  1.793272
# Top ETFs for 2024-02-01 to 2024-02-29: ['SMH', 'IGM']
# Processing scores for 2024-03-01 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3m             0.1  3.562113
# 1  SOXX   3m             0.1 -1.634436
# 2   PSI   3m             0.1  0.422133
# 3   XSD   3m             0.1  1.176781
# 4   IYW   3m             0.1  1.889342
# Top ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'XLK']
# Processing scores for 2024-04-01 to 2024-04-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4m             0.1  3.153962
# 1  SOXX   4m             0.1 -1.436856
# 2   PSI   4m             0.1  0.944601
# 3   XSD   4m             0.1  2.992206
# 4   IYW   4m             0.1  2.248531
# Top ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'XSD']
# Processing scores for 2024-05-01 to 2024-05-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5m             0.1  2.380381
# 1  SOXX   5m             0.1 -2.921069
# 2   PSI   5m             0.1 -1.385103
# 3   XSD   5m             0.1 -0.190114
# 4   IYW   5m             0.1  3.162864
# Top ETFs for 2024-05-01 to 2024-05-31: ['XLK', 'IYW']
# Processing scores for 2024-06-01 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6m             0.1  0.657995
# 1  SOXX   6m             0.1 -3.299002
# 2   PSI   6m             0.1 -1.378990
# 3   XSD   6m             0.1 -3.170550
# 4   IYW   6m             0.1  3.515196
# Top ETFs for 2024-06-01 to 2024-06-30: ['XLK', 'IYW']
# Processing scores for 2024-07-01 to 2024-07-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7m             0.1  1.802004
# 1  SOXX   7m             0.1 -1.576972
# 2   PSI   7m             0.1 -1.565181
# 3   XSD   7m             0.1  1.681011
# 4   IYW   7m             0.1  2.590522
# Top ETFs for 2024-07-01 to 2024-07-31: ['XLK', 'IYW']
# Processing scores for 2024-08-01 to 2024-08-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8m             0.1  1.439863
# 1  SOXX   8m             0.1 -2.641495
# 2   PSI   8m             0.1 -0.237878
# 3   XSD   8m             0.1  0.442968
# 4   IYW   8m             0.1  2.765628
# Top ETFs for 2024-08-01 to 2024-08-31: ['XLK', 'IYW']
# Processing scores for 2024-09-01 to 2024-09-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9m             0.1  1.669861
# 1  SOXX   9m             0.1 -2.482868
# 2   PSI   9m             0.1 -0.672307
# 3   XSD   9m             0.1 -0.271385
# 4   IYW   9m             0.1  3.171891
# Top ETFs for 2024-09-01 to 2024-09-30: ['XLK', 'IYW']
# Processing scores for 2024-10-01 to 2024-10-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10m             0.1  2.392063
# 1  SOXX  10m             0.1 -2.813708
# 2   PSI  10m             0.1 -0.757742
# 3   XSD  10m             0.1  0.198002
# 4   IYW  10m             0.1  3.245585
# Top ETFs for 2024-10-01 to 2024-10-31: ['XLK', 'IYW']
# Processing scores for 2024-11-01 to 2024-11-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11m             0.1 -1.171495
# 1  SOXX  11m             0.1 -4.389435
# 2   PSI  11m             0.1  0.073472
# 3   XSD  11m             0.1  1.712274
# 4   IYW  11m             0.1  3.004161
# Top ETFs for 2024-11-01 to 2024-11-30: ['XLK', 'IYW']
# Top 2 ETFs for 2024-01-01 to 2024-01-31: ['SMH', 'XLK']
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['SMH', 'IGM']
# Formula: 260.0832232449381 * 200.1699981689453 * 0.975
# Sell XLK: 260.08 shares at 200.17. Total value: 50759.34
#
# Formula: (50759.336862694836 * 0.975) / 78.93000030517578
# Buy IGM: 627.02 shares at 78.93.
#
# Updated ticker shares after 2024-02-01 to 2024-02-29: {'SMH': 288.51275165894293, 'IGM': 627.0157512957994}
#
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['SMH', 'IGM']
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'XLK']
# Formula: 627.0157512957994 * 86.03666687011719 * 0.975
# Sell IGM: 627.02 shares at 86.04. Total value: 52597.69
#
# Formula: (52597.68668363912 * 0.975) / 210.75999450683594
# Buy XLK: 243.32 shares at 210.76.
#
# Updated ticker shares after 2024-03-01 to 2024-03-31: {'SMH': 288.51275165894293, 'XLK': 243.3229543232162}
#
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'XLK']
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'XSD']
# Formula: 243.3229543232162 * 208.85000610351562 * 0.975
# Sell XLK: 243.32 shares at 208.85. Total value: 49547.55
#
# Formula: (49547.55048314093 * 0.975) / 233.86000061035156
# Buy XSD: 206.57 shares at 233.86.
#
# Updated ticker shares after 2024-04-01 to 2024-04-30: {'SMH': 288.51275165894293, 'XSD': 206.57171639006683}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'XSD']
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['XLK', 'IYW']
# Formula: 288.51275165894293 * 207.85000610351562 * 0.975
# Sell SMH: 288.51 shares at 207.85. Total value: 58468.19
#
# Formula: 206.57171639006683 * 217.32000732421875 * 0.975
# Sell XSD: 206.57 shares at 217.32. Total value: 43769.86
#
# Formula: (58468.19276342204 * 0.975) / 194.25999450683594
# Buy XLK: 293.45 shares at 194.26.
#
# Formula: (43769.86274589412 * 0.975) / 126.94999694824219
# Buy IYW: 336.16 shares at 126.95.
#
# Updated ticker shares after 2024-05-01 to 2024-05-31: {'XLK': 293.45459464805276, 'IYW': 336.16082869734703}
#
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['XLK', 'IYW']
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['XLK', 'IYW']
# Updated ticker shares after 2024-06-01 to 2024-06-30: {'XLK': 293.45459464805276, 'IYW': 336.16082869734703}
#
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['XLK', 'IYW']
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['XLK', 'IYW']
# Updated ticker shares after 2024-07-01 to 2024-07-31: {'XLK': 293.45459464805276, 'IYW': 336.16082869734703}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['XLK', 'IYW']
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['XLK', 'IYW']
# Updated ticker shares after 2024-08-01 to 2024-08-31: {'XLK': 293.45459464805276, 'IYW': 336.16082869734703}
#
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['XLK', 'IYW']
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['XLK', 'IYW']
# Updated ticker shares after 2024-09-01 to 2024-09-30: {'XLK': 293.45459464805276, 'IYW': 336.16082869734703}
#
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['XLK', 'IYW']
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['XLK', 'IYW']
# Updated ticker shares after 2024-10-01 to 2024-10-31: {'XLK': 293.45459464805276, 'IYW': 336.16082869734703}
#
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['XLK', 'IYW']
# Top 2 ETFs for 2024-11-01 to 2024-11-30: ['XLK', 'IYW']
# Updated ticker shares after 2024-11-01 to 2024-11-30: {'XLK': 293.45459464805276, 'IYW': 336.16082869734703}
#
# Using data for the 12th month: 2024-11-01 to 2024-11-30
# Fetching data starting from the first trading day of the 13th month: 2024-12-01
# Fetching data for ticker XLK starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# XLK: 293.45 shares at $235.95 each, total value: $69240.61
# Fetching data for ticker IYW starting from 2024-12-01...
# IYW: 336.16 shares at $161.02 each, total value: $54128.62
#
# ETF values on the 13th month's first trading day:
# Total portfolio value: 123369.23
# XLK: 69240.61
# IYW: 54128.62

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_month = main_monthly(tickers, results,True)
# Out:
# Fetching data for SMH from 2024-01-01 to 2024-01-31...
# Fetching data for SOXX from 2024-01-01 to 2024-01-31...
# Fetching data for PSI from 2024-01-01 to 2024-01-31...
# Fetching data for XSD from 2024-01-01 to 2024-01-31...
# Fetching data for IYW from 2024-01-01 to 2024-01-31...
# Fetching data for XLK from 2024-01-01 to 2024-01-31...
# Fetching data for VGT from 2024-01-01 to 2024-01-31...
# Fetching data for FTEC from 2024-01-01 to 2024-01-31...
# Fetching data for IGM from 2024-01-01 to 2024-01-31...
# Fetching data for IXN from 2024-01-01 to 2024-01-31...
# Fetching data for SMH from 2024-02-01 to 2024-02-29...
# Fetching data for SOXX from 2024-02-01 to 2024-02-29...
# Fetching data for PSI from 2024-02-01 to 2024-02-29...
# Fetching data for XSD from 2024-02-01 to 2024-02-29...
# Fetching data for IYW from 2024-02-01 to 2024-02-29...
# Fetching data for XLK from 2024-02-01 to 2024-02-29...
# Fetching data for VGT from 2024-02-01 to 2024-02-29...
# Fetching data for FTEC from 2024-02-01 to 2024-02-29...
# Fetching data for IGM from 2024-02-01 to 2024-02-29...
# Fetching data for IXN from 2024-02-01 to 2024-02-29...
# Fetching data for SMH from 2024-03-01 to 2024-03-31...
# Fetching data for SOXX from 2024-03-01 to 2024-03-31...
# Fetching data for PSI from 2024-03-01 to 2024-03-31...
# Fetching data for XSD from 2024-03-01 to 2024-03-31...
# Fetching data for IYW from 2024-03-01 to 2024-03-31...
# Fetching data for XLK from 2024-03-01 to 2024-03-31...
# Fetching data for VGT from 2024-03-01 to 2024-03-31...
# Fetching data for FTEC from 2024-03-01 to 2024-03-31...
# Fetching data for IGM from 2024-03-01 to 2024-03-31...
# Fetching data for IXN from 2024-03-01 to 2024-03-31...
# Fetching data for SMH from 2024-04-01 to 2024-04-30...
# Fetching data for SOXX from 2024-04-01 to 2024-04-30...
# Fetching data for PSI from 2024-04-01 to 2024-04-30...
# Fetching data for XSD from 2024-04-01 to 2024-04-30...
# Fetching data for IYW from 2024-04-01 to 2024-04-30...
# Fetching data for XLK from 2024-04-01 to 2024-04-30...
# Fetching data for VGT from 2024-04-01 to 2024-04-30...
# Fetching data for FTEC from 2024-04-01 to 2024-04-30...
# Fetching data for IGM from 2024-04-01 to 2024-04-30...
# Fetching data for IXN from 2024-04-01 to 2024-04-30...
# Fetching data for SMH from 2024-05-01 to 2024-05-31...
# Fetching data for SOXX from 2024-05-01 to 2024-05-31...
# Fetching data for PSI from 2024-05-01 to 2024-05-31...
# Fetching data for XSD from 2024-05-01 to 2024-05-31...
# Fetching data for IYW from 2024-05-01 to 2024-05-31...
# Fetching data for XLK from 2024-05-01 to 2024-05-31...
# Fetching data for VGT from 2024-05-01 to 2024-05-31...
# Fetching data for FTEC from 2024-05-01 to 2024-05-31...
# Fetching data for IGM from 2024-05-01 to 2024-05-31...
# Fetching data for IXN from 2024-05-01 to 2024-05-31...
# Fetching data for SMH from 2024-06-01 to 2024-06-30...
# Fetching data for SOXX from 2024-06-01 to 2024-06-30...
# Fetching data for PSI from 2024-06-01 to 2024-06-30...
# Fetching data for XSD from 2024-06-01 to 2024-06-30...
# Fetching data for IYW from 2024-06-01 to 2024-06-30...
# Fetching data for XLK from 2024-06-01 to 2024-06-30...
# Fetching data for VGT from 2024-06-01 to 2024-06-30...
# Fetching data for FTEC from 2024-06-01 to 2024-06-30...
# Fetching data for IGM from 2024-06-01 to 2024-06-30...
# Fetching data for IXN from 2024-06-01 to 2024-06-30...
# Fetching data for SMH from 2024-07-01 to 2024-07-31...
# Fetching data for SOXX from 2024-07-01 to 2024-07-31...
# Fetching data for PSI from 2024-07-01 to 2024-07-31...
# Fetching data for XSD from 2024-07-01 to 2024-07-31...
# Fetching data for IYW from 2024-07-01 to 2024-07-31...
# Fetching data for XLK from 2024-07-01 to 2024-07-31...
# Fetching data for VGT from 2024-07-01 to 2024-07-31...
# Fetching data for FTEC from 2024-07-01 to 2024-07-31...
# Fetching data for IGM from 2024-07-01 to 2024-07-31...
# Fetching data for IXN from 2024-07-01 to 2024-07-31...
# Fetching data for SMH from 2024-08-01 to 2024-08-31...
# Fetching data for SOXX from 2024-08-01 to 2024-08-31...
# Fetching data for PSI from 2024-08-01 to 2024-08-31...
# Fetching data for XSD from 2024-08-01 to 2024-08-31...
# Fetching data for IYW from 2024-08-01 to 2024-08-31...
# Fetching data for XLK from 2024-08-01 to 2024-08-31...
# Fetching data for VGT from 2024-08-01 to 2024-08-31...
# Fetching data for FTEC from 2024-08-01 to 2024-08-31...
# Fetching data for IGM from 2024-08-01 to 2024-08-31...
# Fetching data for IXN from 2024-08-01 to 2024-08-31...
# Fetching data for SMH from 2024-09-01 to 2024-09-30...
# Fetching data for SOXX from 2024-09-01 to 2024-09-30...
# Fetching data for PSI from 2024-09-01 to 2024-09-30...
# Fetching data for XSD from 2024-09-01 to 2024-09-30...
# Fetching data for IYW from 2024-09-01 to 2024-09-30...
# Fetching data for XLK from 2024-09-01 to 2024-09-30...
# Fetching data for VGT from 2024-09-01 to 2024-09-30...
# Fetching data for FTEC from 2024-09-01 to 2024-09-30...
# Fetching data for IGM from 2024-09-01 to 2024-09-30...
# Fetching data for IXN from 2024-09-01 to 2024-09-30...
# Fetching data for SMH from 2024-10-01 to 2024-10-31...
# Fetching data for SOXX from 2024-10-01 to 2024-10-31...
# Fetching data for PSI from 2024-10-01 to 2024-10-31...
# Fetching data for XSD from 2024-10-01 to 2024-10-31...
# Fetching data for IYW from 2024-10-01 to 2024-10-31...
# Fetching data for XLK from 2024-10-01 to 2024-10-31...
# Fetching data for VGT from 2024-10-01 to 2024-10-31...
# Fetching data for FTEC from 2024-10-01 to 2024-10-31...
# Fetching data for IGM from 2024-10-01 to 2024-10-31...
# Fetching data for IXN from 2024-10-01 to 2024-10-31...
# Fetching data for SMH from 2024-11-01 to 2024-11-30...
# Fetching data for SOXX from 2024-11-01 to 2024-11-30...
# Fetching data for PSI from 2024-11-01 to 2024-11-30...
# Fetching data for XSD from 2024-11-01 to 2024-11-30...
# Fetching data for IYW from 2024-11-01 to 2024-11-30...
# Fetching data for XLK from 2024-11-01 to 2024-11-30...
# Fetching data for VGT from 2024-11-01 to 2024-11-30...
# Fetching data for FTEC from 2024-11-01 to 2024-11-30...
# Fetching data for IGM from 2024-11-01 to 2024-11-30...
# Fetching data for IXN from 2024-11-01 to 2024-11-30...
# Processing scores for 2024-01-01 to 2024-01-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1m             0.1  3.242272
# 1  SOXX   1m             0.1 -1.405471
# 2   PSI   1m             0.1 -1.334368
# 3   XSD   1m             0.1 -3.759111
# 4   IYW   1m             0.1  2.703391
# Top ETFs for 2024-01-01 to 2024-01-31: ['SMH', 'XLK']
# Processing scores for 2024-02-01 to 2024-02-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2m             0.1  1.995896
# 1  SOXX   2m             0.1 -2.310529
# 2   PSI   2m             0.1 -0.496107
# 3   XSD   2m             0.1 -2.897664
# 4   IYW   2m             0.1  2.045825
# Top ETFs for 2024-02-01 to 2024-02-29: ['XLK', 'IYW']
# Processing scores for 2024-03-01 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3m             0.1  3.620411
# 1  SOXX   3m             0.1 -1.438998
# 2   PSI   3m             0.1  1.307677
# 3   XSD   3m             0.1 -0.622138
# 4   IYW   3m             0.1  1.011863
# Top ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'XLK']
# Processing scores for 2024-04-01 to 2024-04-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4m             0.1  4.404859
# 1  SOXX   4m             0.1  0.070944
# 2   PSI   4m             0.1  1.258287
# 3   XSD   4m             0.1  1.096421
# 4   IYW   4m             0.1  1.127963
# Top ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'IGM']
# Processing scores for 2024-05-01 to 2024-05-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5m             0.1  1.326602
# 1  SOXX   5m             0.1 -2.277850
# 2   PSI   5m             0.1 -1.745419
# 3   XSD   5m             0.1 -0.997537
# 4   IYW   5m             0.1  3.586117
# Top ETFs for 2024-05-01 to 2024-05-31: ['XLK', 'IYW']
# Processing scores for 2024-06-01 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6m             0.1  0.649300
# 1  SOXX   6m             0.1 -2.494786
# 2   PSI   6m             0.1 -1.903241
# 3   XSD   6m             0.1 -3.136463
# 4   IYW   6m             0.1  4.414687
# Top ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'IXN']
# Processing scores for 2024-07-01 to 2024-07-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7m             0.1 -0.544688
# 1  SOXX   7m             0.1 -2.388009
# 2   PSI   7m             0.1 -2.386337
# 3   XSD   7m             0.1 -1.386558
# 4   IYW   7m             0.1  3.485294
# Top ETFs for 2024-07-01 to 2024-07-31: ['IYW', 'XLK']
# Processing scores for 2024-08-01 to 2024-08-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8m             0.1  0.832152
# 1  SOXX   8m             0.1 -2.986822
# 2   PSI   8m             0.1 -0.828431
# 3   XSD   8m             0.1 -0.227170
# 4   IYW   8m             0.1  3.142116
# Top ETFs for 2024-08-01 to 2024-08-31: ['XLK', 'IYW']
# Processing scores for 2024-09-01 to 2024-09-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9m             0.1  1.669784
# 1  SOXX   9m             0.1 -2.614680
# 2   PSI   9m             0.1 -1.226715
# 3   XSD   9m             0.1 -0.589436
# 4   IYW   9m             0.1  3.316304
# Top ETFs for 2024-09-01 to 2024-09-30: ['XLK', 'IYW']
# Processing scores for 2024-10-01 to 2024-10-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10m             0.1  0.460299
# 1  SOXX  10m             0.1 -3.854004
# 2   PSI  10m             0.1 -1.166123
# 3   XSD  10m             0.1  0.725788
# 4   IYW  10m             0.1  3.300973
# Top ETFs for 2024-10-01 to 2024-10-31: ['XLK', 'IYW']
# Processing scores for 2024-11-01 to 2024-11-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11m             0.1 -0.186577
# 1  SOXX  11m             0.1 -2.887315
# 2   PSI  11m             0.1 -1.779238
# 3   XSD  11m             0.1  2.021660
# 4   IYW  11m             0.1  2.417797
# Top ETFs for 2024-11-01 to 2024-11-30: ['XLK', 'IYW']
# Top 2 ETFs for 2024-01-01 to 2024-01-31: ['SMH', 'XLK']
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['XLK', 'IYW']
# Formula: 288.51275165894293 * 187.57000732421875 * 0.975
# Sell SMH: 288.51 shares at 187.57. Total value: 52763.43
#
# Formula: (52763.430468253464 * 0.975) / 127.87999725341797
# Buy IYW: 402.29 shares at 127.88.
#
# Updated ticker shares after 2024-02-01 to 2024-02-29: {'XLK': 260.0832232449381, 'IYW': 402.2860948659594}
#
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['XLK', 'IYW']
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'XLK']
# Formula: 402.2860948659594 * 135.41000366210938 * 0.975
# Sell IYW: 402.29 shares at 135.41. Total value: 53111.72
#
# Formula: (53111.722539539864 * 0.975) / 220.5399932861328
# Buy SMH: 234.81 shares at 220.54.
#
# Updated ticker shares after 2024-03-01 to 2024-03-31: {'SMH': 234.80516483405304, 'XLK': 260.0832232449381}
#
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['SMH', 'XLK']
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'IGM']
# Formula: 260.0832232449381 * 208.85000610351562 * 0.975
# Sell XLK: 260.08 shares at 208.85. Total value: 52960.42
#
# Formula: (52960.42319307415 * 0.975) / 86.66000366210938
# Buy IGM: 595.85 shares at 86.66.
#
# Updated ticker shares after 2024-04-01 to 2024-04-30: {'SMH': 234.80516483405304, 'IGM': 595.8505704036157}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['SMH', 'IGM']
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['XLK', 'IYW']
# Formula: 234.80516483405304 * 207.85000610351562 * 0.975
# Sell SMH: 234.81 shares at 207.85. Total value: 47584.15
#
# Formula: 595.8505704036157 * 81.08000183105469 * 0.975
# Sell IGM: 595.85 shares at 81.08. Total value: 47103.78
#
# Formula: (47584.14857029755 * 0.975) / 194.25999450683594
# Buy XLK: 238.83 shares at 194.26.
#
# Formula: (47103.776205876144 * 0.975) / 126.94999694824219
# Buy IYW: 361.77 shares at 126.95.
#
# Updated ticker shares after 2024-05-01 to 2024-05-31: {'XLK': 238.8270676822628, 'IYW': 361.7659149645624}
#
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['XLK', 'IYW']
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'IXN']
# Formula: 238.8270676822628 * 210.69000244140625 * 0.975
# Sell XLK: 238.83 shares at 210.69. Total value: 49060.51
#
# Formula: (49060.5135862236 * 0.975) / 77.05999755859375
# Buy IXN: 620.74 shares at 77.06.
#
# Updated ticker shares after 2024-06-01 to 2024-06-30: {'IYW': 361.7659149645624, 'IXN': 620.7371173376523}
#
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'IXN']
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['IYW', 'XLK']
# Formula: 620.7371173376523 * 83.62000274658203 * 0.975
# Sell IXN: 620.74 shares at 83.62. Total value: 50608.39
#
# Formula: (50608.3884702629 * 0.975) / 227.94000244140625
# Buy XLK: 216.47 shares at 227.94.
#
# Updated ticker shares after 2024-07-01 to 2024-07-31: {'IYW': 361.7659149645624, 'XLK': 216.47441532861427}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['IYW', 'XLK']
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['XLK', 'IYW']
# Updated ticker shares after 2024-08-01 to 2024-08-31: {'XLK': 216.47441532861427, 'IYW': 361.7659149645624}
#
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['XLK', 'IYW']
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['XLK', 'IYW']
# Updated ticker shares after 2024-09-01 to 2024-09-30: {'XLK': 216.47441532861427, 'IYW': 361.7659149645624}
#
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['XLK', 'IYW']
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['XLK', 'IYW']
# Updated ticker shares after 2024-10-01 to 2024-10-31: {'XLK': 216.47441532861427, 'IYW': 361.7659149645624}
#
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['XLK', 'IYW']
# Top 2 ETFs for 2024-11-01 to 2024-11-30: ['XLK', 'IYW']
# Updated ticker shares after 2024-11-01 to 2024-11-30: {'XLK': 216.47441532861427, 'IYW': 361.7659149645624}
#
# Using data for the 12th month: 2024-11-01 to 2024-11-30
# Fetching data starting from the first trading day of the 13th month: 2024-12-01
# Fetching data for ticker XLK starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# XLK: 216.47 shares at $235.95 each, total value: $51077.14
# Fetching data for ticker IYW starting from 2024-12-01...
# IYW: 361.77 shares at $161.02 each, total value: $58251.55
#
# ETF values on the 13th month's first trading day:
# Total portfolio value: 109328.69
# XLK: 51077.14
# IYW: 58251.55
