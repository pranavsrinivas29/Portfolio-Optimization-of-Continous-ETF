# %%
#!pip install altair

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split,GridSearchCV
from skopt import BayesSearchCV

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tabulate import tabulate
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler,MinMaxScaler,Normalizer
import statsmodels.api as sm
import itertools

from pandas.tseries.offsets import MonthEnd
from pandas.tseries.offsets import BDay,Week

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

from datetime import datetime, timedelta

# %%
def data_loading(ticker_symbol, start_date, end_date):
    # Fetch the ETF data from Yahoo Finance for the period from 2010-01-01 to 2024-01-01
    etf_data = yf.Ticker(ticker_symbol)
    etf_history = etf_data.history(start=start_date, end=end_date)
    etf_history.index = etf_history.index.tz_localize(None)
    return etf_history, etf_data

# %%
#Function to derive the predictor columns
def etf_predictors(etf_history,  start_date, end_date, etf_data, benchmark_ticker = '^GSPC' ):
    
    # Calculate Daily Returns
    etf_history['Daily Return'] = etf_history['Close'].pct_change()

    # Calculate 21-Day Volatility (standard deviation of daily returns, annualized)
    etf_history['Volatility'] = etf_history['Daily Return'].rolling(window=21).std() * np.sqrt(252)
    #etf_history['Volatility_ta'] = ta.volatility(etf_history['Close'], window=21, annualize=True)
   
    # Get the ETF info
    etf_info = etf_data.info

    # Retrieve the net asset value price (NAV) and total net assets
    nav_price = etf_info['navPrice']
    total_assets = etf_info['totalAssets']

    # Calculate the number of shares outstanding
    shares_outstanding = total_assets / nav_price

    # Calculate Market Capitalization for each day
    # Market Capitalization = Closing Price * Total Number of Shares Outstanding
    etf_history['Market Cap'] = etf_history['Close'] * shares_outstanding

    total_assets = etf_info['totalAssets']
    total_liabilities = etf_info.get('totalLiabilities', 0)  # Handle the case where total liabilities might not be present
    
    # Calculate Book Value per Share
    book_value_per_share = (total_assets - total_liabilities) / shares_outstanding
    
    # Calculate Price to Book (P/B) Ratio
    etf_history['P/B Ratio'] = etf_history['Close'] / book_value_per_share
    
    # Calculate 1-Month Momentum (21 trading days)
    
    etf_history['Momentum'] = ta.mom(etf_history['Close'], length=21)
    
    benchmark_data = yf.download(benchmark_ticker, start=start_date, end=end_date)
    benchmark_data['Daily Return'] = benchmark_data['Close'].pct_change()
    #benchmark_data_history = benchmark_data.dropna()
    benchmark_data.head(10)
    
    # Ensure the indices are time zone-naive
    benchmark_data.index = benchmark_data.index.tz_localize(None)
    combined_data = etf_history[['Close']].join(benchmark_data[['Close']], lsuffix='_ETF', rsuffix='_Benchmark')
    combined_data = combined_data.dropna()
    
    # Calculate rolling beta with a 30-day window
    rolling_beta_21 = rolling_beta(combined_data, window=21)

    # Add the rolling beta to the dataframe
    combined_data.loc[:, 'Rolling Beta 21-day'] = rolling_beta_21
    etf_history['Rolling Beta']=combined_data['Rolling Beta 21-day']
    
    # Calculate daily profitability
    daily_profitabilities = []
    previous_nav = None
    for index, row in etf_history.iterrows():
        current_nav = row['Close']  # Current day's NAV
        #print(current_nav)
        if previous_nav is not None:
            daily_profitability = (current_nav - previous_nav) / previous_nav * 100
            daily_profitabilities.append(daily_profitability)
        else:
            daily_profitabilities.append(None)
        previous_nav = current_nav  # Update previous_nav for the next iteration

    # Add daily profitabilities to ETF dataset
    etf_history['Daily Profitability (%)'] = daily_profitabilities
    
    # Calculate the dividend yield for each day
    dividend_yields = []

    for index, row in etf_history.iterrows():
        # Get the dividend payment for the day
        dividend_payment = row['Dividends']

        # Get the current market price of the ETF for the day
        current_price = row['Close']

        # Calculate the dividend yield for the day
        dividend_yield = (dividend_payment / current_price) * 100

        # Append the dividend yield to the list
        dividend_yields.append(dividend_yield)
      
    etf_history['Div yield'] = dividend_yields

    #Volatility
    etf_history['ATR'] = ta.atr(etf_history['High'], etf_history['Low'], etf_history['Close'], length=21)    
    
    # Compute the Relative Volatility Index (RVI)
    rvi = ta.rvi(etf_history['Close'],length=21)
    etf_history['RVI'] = rvi
    
    #Momentum
    rsi_window = 14  # Window size for RSI calculation
    roc_window = 12  # Window size for ROC calculation
    #rsi_window = 21  
    #roc_window = 21  

    

    etf_history['RSI'] = ta.rsi(etf_history['Close'],length=rsi_window)
    # Calculate Rate of Change (ROC)
    etf_history['ROC'] = ta.roc(etf_history['Close'], length=roc_window)
        
    etf_history['log_returns'] = np.log(etf_history['Close'] / etf_history['Close'].shift(1))

    return etf_history

# Function to calculate rolling beta
def rolling_beta(df, window):
    rolling_cov = df['Close_Benchmark'].rolling(window=window).cov(df['Close_ETF'])
    rolling_var = df['Close_Benchmark'].rolling(window=window).var()
    rolling_beta = rolling_cov / rolling_var
    return rolling_beta

# %%
def pre_processing(etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_dates, feature_columns=None, scaling_strategy='StandardScaler', final_end_date='2024-12-01'):
    # Handle missing values and inf replacements
    etf_history.fillna(etf_history.median(), inplace=True)
    etf_history = etf_history.replace(-np.inf, 0)

    # Default feature columns if none are provided
    if feature_columns is None:
        feature_columns = ['Volatility', 'Volume', 'Daily Return', 'Market Cap', 'P/B Ratio', 'Momentum', 
                           'Rolling Beta', 'Daily Profitability (%)', 'ATR', 'RVI', 'RSI', 'ROC']

    # Selecting the features (X) and the target (y)
    X = etf_history.loc[:, feature_columns]
    y = etf_history['log_returns']

    # Split train and test data
    train_data = X.loc[train_start_date:train_end_date]
    test_data = X.loc[test_start_date:test_end_date]
    y_train = y.loc[train_start_date:train_end_date]
    y_test = y.loc[test_start_date:test_end_date]

    # Scaling strategy based on input parameter
    if scaling_strategy == 'StandardScaler':
        scaler = StandardScaler()
    elif scaling_strategy == 'Normalizer':
        scaler = Normalizer()
    else:
        raise ValueError(f"Unsupported scaling strategy: {scaling_strategy}")
    
    # Scaling the train and test data
    train_data_scaled = scaler.fit_transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    # Create a dictionary to store forecast data for each weekly prediction period
    forecast_data = {}
    for i, start_date in enumerate(prediction_dates):
        # Determine the end date for each forecast week
        if i < len(prediction_dates) - 1:
            end_date = (pd.to_datetime(start_date) + Week(1) - pd.Timedelta(days=1)).strftime('%Y-%m-%d')
        else:
            end_date = final_end_date  # The final end date provided or default

        # Store the forecast data for each week
        forecast_data[f'forecast_data_{i+1}w'] = X.loc[start_date:end_date]

    # Scale the forecast data dynamically
    forecast_data_scaled = {}
    for period_key, period_data in forecast_data.items():
        if not period_data.empty:
            forecast_data_scaled[period_key] = sm.add_constant(scaler.transform(period_data))

    # Add constant to scaled train and test data
    train_data_scaled = sm.add_constant(train_data_scaled)
    test_data_scaled = sm.add_constant(test_data_scaled)

    #print(f"Weekly forecast data keys: {forecast_data.keys()}")

    # Dynamically return the scaled forecast data along with train and test data
    return {
        'train_data_scaled': train_data_scaled,
        'test_data_scaled': test_data_scaled,
        'y_train': y_train,
        'y_test': y_test,
        'scaler': scaler,
        'X': X,
        'etf_history': etf_history,
        'forecast_data_scaled': forecast_data_scaled,
        'forecast_data': forecast_data
    }

# %%
def model_training(train_data_scaled, y_train):
    model = sm.OLS(endog=y_train, exog=sm.add_constant(train_data_scaled))
    
     # Define the hyperparameters
    cov_types = ['HC0', 'HC1', 'HC2', 'HC3']
    use_ts = [True, False]
    methods = ['pinv', 'qr']
    #missing = ['none', 'drop', 'raise']
    #hasconsts = [None, 'add', 'raise']
    tol_values = [1e-8, 1e-6, 1e-4]
    maxiter_values = [500, 1000, 5000]

    best_score = float('-inf')
    best_model = None

    # Loop through all combinations of hyperparameters
    for cov_type, use_t, method, tol, maxiter in itertools.product(cov_types, use_ts, methods,  tol_values, maxiter_values):
        try:
            # Define and fit the model
            model = sm.OLS(endog=y_train, exog=train_data_scaled)
            fitted_model = model.fit(cov_type=cov_type, use_t=use_t, method=method, tol=tol, maxiter=maxiter)

            # Evaluate on test data
            score = fitted_model.rsquared_adj  # Or any other metric you prefer

            # Update best model if necessary
            if score > best_score:
                best_score = score
                best_model = fitted_model
                best_params = {
                    'cov_type': cov_type,
                    'use_t': use_t,
                    'method': method,
                    #'missing': miss,
                    #'hasconst': hasconst,
                    'tol': tol,
                    'maxiter': maxiter
                }
        except:
            # Handle any errors that arise from invalid hyperparameter combinations
            continue
            
    # Display the best model parameters
    print("Best Model Parameters:")
    print(best_params)
    return best_model

# %%
#!pip install scikit-optimize

# %%
def eval_model(best_model,test_data_scaled,y_test,y_train):
    
    test_predictions = best_model.predict((test_data_scaled))
    mae = mean_absolute_error(y_test, test_predictions)
    # Mean Absolute Scaled Error (MASE) - Example calculation assuming seasonal period m=1
    seasonal_naive = np.roll(y_test, 1)  # Shift y_test by 1 for seasonal naive forecast
    #seasonal_mae = np.mean(np.abs(y_test - seasonal_naive))
    seasonal_mae = np.mean(np.abs(y_test[1:] - seasonal_naive[1:]))
    mase = mae / seasonal_mae

    # Mean Absolute Percentage Error (MAPE)
    #mape = np.mean(np.abs((y_test - test_predictions) / y_test)) * 100

    #n = y_test.shape[0]
    #d = np.abs(  np.diff( y_test) ).sum()/(n-1)
    
    #errors = np.abs(y_test - test_predictions )
    #mase_value = errors.mean()/d

    print("Mean Absolute Error (MAE):", mae)
    print("Mean Absolute Scaled Error (MASE):", mase)
    #print("Mean Absolute Scaled Error-2 (MASE-2):", mase_value)
    #print("Mean Absolute Percentage Error (MAPE):", mape)
    
    return mae, mase

# %%
# Ensured consistent feature handling and forecasting in predictions
def predictions(model, forecast_data_scaled, forecast_data):
    predictions_forecast = model.predict(forecast_data_scaled)
    forecast_predictions_df = pd.DataFrame(predictions_forecast, columns=["log_returns"], index=forecast_data.index)
    forecast_data_with_predictions = pd.concat([forecast_data, forecast_predictions_df], axis=1)
    return forecast_predictions_df, forecast_data_with_predictions

# %%
"""
# Ensured consistent feature handling and forecasting in predictions
def predictions(model, forecast_data_scaled, forecast_data):
    predictions_forecast = model.predict(forecast_data_scaled)
    forecast_predictions_df = pd.DataFrame(predictions_forecast, columns=["log_returns"], index=forecast_data.index)
    forecast_data_with_predictions = pd.concat([forecast_data, forecast_predictions_df], axis=1)
    return forecast_predictions_df, forecast_data_with_predictions
    """
# Out:
# '\n# Ensured consistent feature handling and forecasting in predictions\ndef predictions(model, forecast_data_scaled, forecast_data):\n    predictions_forecast = model.predict(forecast_data_scaled)\n    forecast_predictions_df = pd.DataFrame(predictions_forecast, columns=["log_returns"], index=forecast_data.index)\n    forecast_data_with_predictions = pd.concat([forecast_data, forecast_predictions_df], axis=1)\n    return forecast_predictions_df, forecast_data_with_predictions\n    '

# %%
#tickers = ['SPY', 'QQQ', 'VTI', 'IWM', 'EFA', 'EEM', 'GLD', 'SLV', 'USO', 'XLF']
#tickers = ['SMH', 'SOXX', 'PSI']

tickers = ['SMH', 'SOXX', 'PSI', 'XSD', 'IYW', 'XLK', 'VGT', 'FTEC', 'IGM', 'IXN', 
           #'FNGU','USD', 'FNGO', 'GBTC', 'ETHE', 'TECL', 'FNGS', 'TQQQ', 'ROM', 'QLD' No data available from 2000: 2019
          ]

#tickers = ['SPY', 'QQQ', 'VTI']
#tickers = ['SPY']
                                                           
start_date, end_date = '2000-01-01', '2024-12-01'
train_start_date, train_end_date, test_start_date, test_end_date, prediction_start_date = start_date,'2014-01-01', '2014-01-01', '2024-01-01', '2024-01-01'
#prediction_dates=['2024-01-01','2024-02-01','2024-03-01', '2024-04-01','2024-05-01','2024-06-01','2024-07-01','2024-08-01','2024-09-01','2024-10-01','2024-11-01']

# %%
#currently timeperiod is set to 48 weeks
prediction_dates = pd.date_range(start='2024-01-01', 
                                 periods=48, 
                                 freq='W-MON').strftime('%Y-%m-%d').tolist()

# %%
dict_data = {}
etf_dict = {}
data_with_predictors = []

# Loop through tickers
for i in tickers:
    etf_history, etf_data = data_loading(i, start_date, end_date)
    print(etf_data.info.get('longName'), ":", i)

    # Preprocess ETF data
    etf_history = etf_predictors(etf_history, start_date, end_date, etf_data, benchmark_ticker='^GSPC')
    preprocessed_data = pre_processing(
        etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_dates
    )

    # Extract components
    train_data_scaled = preprocessed_data['train_data_scaled']
    test_data_scaled = preprocessed_data['test_data_scaled']
    y_train = preprocessed_data['y_train']
    y_test = preprocessed_data['y_test']
    scaler = preprocessed_data['scaler']
    X = preprocessed_data['X']
    etf_history = preprocessed_data['etf_history']
    
    """for key in preprocessed_data['forecast_data']:
        print(key)"""  # Check if 'forecast_data_Xw' keys are present.

    # Train the model
    best_model = model_training(train_data_scaled, y_train)

    # Evaluate the model
    mae, mase = eval_model(best_model, test_data_scaled, y_test, y_train)
    print(f"Evaluation results for {i}: MAE = {mae}, MASE = {mase}")

    # Initialize dictionaries for forecast data and predictions
    # Step 5: Initialize forecast data storage
    forecast_predictions = {}
    forecast_data_dict = {}
    forecast_data_scaled_dict = {}

    # Step 6: Fetch weekly forecast data and generate predictions
    for week in range(1, 49):  # Generate weekly forecasts for up to 52 weeks
        week_key = f'forecast_data_{week}w'
        if week_key in preprocessed_data['forecast_data']:
            forecast_data = preprocessed_data['forecast_data'][week_key]
            forecast_data_scaled = preprocessed_data['forecast_data_scaled'].get(week_key)

            if forecast_data is not None and forecast_data_scaled is not None:
                try:
                    forecast_predictions_df, _ = predictions(
                        best_model, forecast_data_scaled, forecast_data
                    )
                    # Store predictions and forecast data
                    forecast_predictions[f'forecast_predictions_df_{week}w'] = forecast_predictions_df['log_returns'].values
                    forecast_data_dict[week_key] = forecast_data
                    forecast_data_scaled_dict[week_key] = forecast_data_scaled
                except Exception as e:
                    print(f"Error generating predictions for {week_key} for ETF {i}: {e}")
            else:
                print(f"Warning: Missing scaled data for {week_key} for ETF {i}")
        else:
            print(f"Warning: Missing forecast key {week_key} for ETF {i}")

    # Step 7: Construct `dict_data` for the current ETF
    dict_data = {
        "etf_history": etf_history,
        "X": X,
        "y_train_values": y_train,
        "model results": {"mae": mae, "mase": mase},
        **forecast_data_dict,  # Add raw forecast data
        **forecast_data_scaled_dict,  # Add scaled forecast data
        **forecast_predictions  # Add predictions
    }

    # Step 8: Store in the main `etf_dict`
    etf_dict[i] = dict_data

# Print completion message
print("Weekly forecast data and predictions stored successfully.")
# Out:
# VanEck Semiconductor ETF : SMH
# [*********************100%%**********************]  1 of 1 completed
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.000515255803487013
# Mean Absolute Scaled Error (MASE): 0.026726325044201048
# Evaluation results for SMH: MAE = 0.000515255803487013, MASE = 0.026726325044201048
# [*********************100%%**********************]  1 of 1 completed
# iShares Semiconductor ETF : SOXX
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.0002793632542918278
# Mean Absolute Scaled Error (MASE): 0.01431938820251765
# Evaluation results for SOXX: MAE = 0.0002793632542918278, MASE = 0.01431938820251765
# [*********************100%%**********************]  1 of 1 completed
# Invesco Semiconductors ETF : PSI
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'pinv', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00025178447453806234
# Mean Absolute Scaled Error (MASE): 0.012329240572303626
# Evaluation results for PSI: MAE = 0.00025178447453806234, MASE = 0.012329240572303626
# [*********************100%%**********************]  1 of 1 completed
# SPDR S&P Semiconductor ETF : XSD
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00024785822749194254
# Mean Absolute Scaled Error (MASE): 0.011868103458002351
# Evaluation results for XSD: MAE = 0.00024785822749194254, MASE = 0.011868103458002351
# [*********************100%%**********************]  1 of 1 completed
# iShares U.S. Technology ETF : IYW
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00021281112331116432
# Mean Absolute Scaled Error (MASE): 0.014277852348491936
# Evaluation results for IYW: MAE = 0.00021281112331116432, MASE = 0.014277852348491936
# [*********************100%%**********************]  1 of 1 completed
# The Technology Select Sector SPDR Fund : XLK
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.0001878080307407013
# Mean Absolute Scaled Error (MASE): 0.013236318096274461
# Evaluation results for XLK: MAE = 0.0001878080307407013, MASE = 0.013236318096274461
# [*********************100%%**********************]  1 of 1 completed
# Vanguard Information Technology Index Fund ETF Shares : VGT
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00019663469712892729
# Mean Absolute Scaled Error (MASE): 0.013604589794655276
# Evaluation results for VGT: MAE = 0.00019663469712892729, MASE = 0.013604589794655276
# [*********************100%%**********************]  1 of 1 completed
# Fidelity MSCI Information Technology Index ETF : FTEC
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.0005988749973086006
# Mean Absolute Scaled Error (MASE): 0.04141460117183243
# Evaluation results for FTEC: MAE = 0.0005988749973086006, MASE = 0.04141460117183243
# [*********************100%%**********************]  1 of 1 completed
# iShares Expanded Tech Sector ETF : IGM
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00018796241226408606
# Mean Absolute Scaled Error (MASE): 0.012888229273272113
# Evaluation results for IGM: MAE = 0.00018796241226408606, MASE = 0.012888229273272113
# [*********************100%%**********************]  1 of 1 completed
# iShares Global Tech ETF : IXN
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00017698125386024112
# Mean Absolute Scaled Error (MASE): 0.012486940532971167
# Evaluation results for IXN: MAE = 0.00017698125386024112, MASE = 0.012486940532971167
# Weekly forecast data and predictions stored successfully.

# %%
def calculate_sharpe_ratio(returns, annual_risk_free_rate=0.1,period='daily'):
    #excess_returns = rate_of_return(returns) - risk_free_rate
    
    # Convert annual risk-free rate to daily rate
    daily_risk_free_rate = (1 + annual_risk_free_rate) ** (1/252) - 1
    
    # Calculate mean daily log return
    mean_return = np.mean(returns)
    
    # Calculate excess daily log return
    excess_return = mean_return - daily_risk_free_rate
    
    # Calculate standard deviation of daily log returns
    std_return = np.std(returns)
    
    # Print diagnostic information
    #print(f"Mean Daily Log Return: {mean_return}")
    #print(f"Excess Daily Log Return: {excess_return}")
    #print(f"Standard Deviation of Daily Log Returns: {std_return}")
    
    # Check for zero standard deviation to avoid division by zero
    if std_return == 0:
        return 0
    
    # Calculate Sharpe ratio
    sharpe_ratio = (excess_return / std_return) * np.sqrt(252)  # Annualize the Sharpe ratio
    return sharpe_ratio
    #return excess_returns / np.std(returns)


def calculate_rachev_ratio(returns, lower_percentile=5, upper_percentile=95):
    # Step 1: Sort the returns
    sorted_returns = np.sort(returns)
    
    # Step 2: Determine the percentiles
    lower_threshold = np.percentile(sorted_returns, lower_percentile)
    upper_threshold = np.percentile(sorted_returns, upper_percentile)
    
    # Step 3: Calculate Expected Shortfall (ES)
    es = np.mean(sorted_returns[sorted_returns <= lower_threshold])
    
    # Step 4: Calculate Expected Gain (EG)
    eg = np.mean(sorted_returns[sorted_returns >= upper_threshold])
    
    # Step 5: Compute the Rachev Ratio
    rachev_ratio = eg / -es
    return rachev_ratio


def calculate_volatility_clustering(returns):
    squared_returns = returns ** 2
    n = len(squared_returns)
    
    # Mean of squared returns
    mean_squared_returns = np.mean(squared_returns)
    
    # Calculate the numerator and denominator for autocorrelation at lag 1
    numerator = np.sum((squared_returns[:-1] - mean_squared_returns) * (squared_returns[1:] - mean_squared_returns))
    denominator = np.sum((squared_returns - mean_squared_returns) ** 2)
    
    if denominator == 0:
        return 0  # Avoid division by zero
    
    rho_1 = numerator / denominator
    return rho_1

def calculate_sortino_ratio(log_returns, target_log_return=0.0):
    """
    Calculate the Sortino Ratio using log returns.
    
    Parameters:
    - log_returns (array-like): Array or list of log returns for the period.
    - target_log_return (float): The target log return. Default is 0, which is often used as a benchmark.
    
    Returns:
    - float: The Sortino Ratio.
    """
    # Convert input to a NumPy array for easier calculations
    log_returns = np.array(log_returns)
    
    # Calculate the average period log return (R)
    avg_log_return = np.mean(log_returns)
    
    # Calculate the Target Downside Deviation (TDD)
    downside_deviation = np.sqrt(
        np.mean(np.square(np.maximum(0, target_log_return - log_returns)))
    )
    
    # Calculate Sortino Ratio
    sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
    
    return sortino_ratio_value

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, volatility_clustering, 
    mean_forecast, std_forecast, mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
    mean_volatility_clustering, std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    # Debugging: Log raw input values
    print(f"\nDebug: Composite Score Calculation")
    print(f"Forecasted Mean: {forecasted_mean}, Risk Percentage: {risk_percentage}")
    print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
    print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")

    # Normalize the components with epsilon
    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Debugging: Log normalized values
    print(f"Normalized Values -> Forecasted Mean: {forecasted_mean_normalized}, Rachev: {rachev_normalized}")
    print(f"Sharpe: {sharpe_normalized}, Sortino: {sortino_normalized}, Volatility Clustering: {volatility_clustering_normalized}")

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    # Debugging: Log final score
    print(f"Final Composite Score: {score}")

    return score


def process_etf_data_weekly(tickers, etf_dict):
    etf_pred_dict = {}

    # Determine the forecast periods dynamically from the etf_dict
    sample_etf = next(iter(etf_dict.values()))
    forecast_periods = [key.split('_')[-1] for key in sample_etf.keys() if key.startswith('forecast_predictions_df')]

    for etf_name in tickers:
        etf_pred_dict[etf_name] = {
            f"returns_{period}": etf_dict[etf_name][f"forecast_predictions_df_{period}"]
            for period in forecast_periods
        }

        for period in forecast_periods:
            returns = etf_pred_dict[etf_name][f"returns_{period}"]

            # Log returns for debugging
            print(f"\nDebug: Returns for {etf_name}, Forecast Period {period}: {returns}")

            # Calculate metrics
            etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
            etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
            etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
            etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict



def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    print(f"\nDebug: Forecast Period = {forecast_period}")
    print(f"All Returns Means: {[np.mean(returns) for returns in returns_list]}")
    print(f"Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Rachev Ratios: {rachev_ratios}")
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sharpe Ratios: {sharpe_ratios}")
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sortino Ratios: {sortino_ratios}")
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Volatility Clustering: {volatility_clustering}")
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    print(f"Mean Rachev = {mean_rachev}, Std Rachev = {std_rachev}")
    print(f"Mean Sharpe = {mean_sharpe}, Std Sharpe = {std_sharpe}")
    print(f"Mean Sortino = {mean_sortino}, Std Sortino = {std_sortino}")
    print(f"Mean Volatility Clustering = {mean_volatility_clustering}, Std Volatility Clustering = {std_volatility_clustering}")

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )



def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Debugging: Log inputs to composite score calculation
        print(f"\nDebug: ETF = {etf}, Forecast Period = {forecast_period}")
        print(f"Forecasted Values Mean: {np.mean(forecasted_values)}")
        print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
        print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")
        print(f"Means and Stds: Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")
        
        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

        # Debugging: Log the calculated score
        print(f"Calculated Score for {etf} ({forecast_period}): {score}")

    return scores



def main_weekly(tickers, etf_dict):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict)
    
    risk_percentage = 0.10
    weekly_scores = {}

    # Iterate over 48 weeks
    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores
            print(f"Scores calculated for {week_key}:")
            for score in scores:
                print(score)
        else:
            print(f"Skipping score calculation for {week_key}: No ETFs have data for this week.")

    return etf_pred_dict, weekly_scores


# Example usage:
# Execute weekly scoring
etf_pred_dict, weekly_scores = main_weekly(tickers, etf_dict)
# Out:
# Debug: Returns for SMH, Forecast Period 1w: [-0.03485361 -0.01912074 -0.00725006  0.00524473]
#
# Debug: Returns for SMH, Forecast Period 2w: [ 0.03410818  0.00145585 -0.00038691  0.0042201  -0.00505355]
#
# Debug: Returns for SMH, Forecast Period 3w: [ 0.01424855 -0.00773638  0.03070864  0.03660772]
#
# Debug: Returns for SMH, Forecast Period 4w: [ 0.00337821  0.00421417  0.01679608 -0.00092453 -0.02244032]
#
# Debug: Returns for SMH, Forecast Period 5w: [ 0.01050558 -0.0111581  -0.01572589  0.00816453  0.01877359]
#
# Debug: Returns for SMH, Forecast Period 6w: [ 0.01896718 -0.01193738  0.01931408  0.01348086  0.02151389]
#
# Debug: Returns for SMH, Forecast Period 7w: [-0.00449048 -0.01913473  0.0192573  -0.00401081 -0.00524234]
#
# Debug: Returns for SMH, Forecast Period 8w: [-0.02100306 -0.00793366  0.0667203  -0.00762593]
#
# Debug: Returns for SMH, Forecast Period 9w: [ 0.00690416 -0.00405792 -0.01249986  0.02061292  0.03971843]
#
# Debug: Returns for SMH, Forecast Period 10w: [ 0.01546466 -0.01610479  0.02490666  0.03411755 -0.039832  ]
#
# Debug: Returns for SMH, Forecast Period 11w: [-0.01893526  0.03036965 -0.02096336 -0.01906807 -0.00884591]
#
# Debug: Returns for SMH, Forecast Period 12w: [ 0.00052795 -0.00372575  0.01472147  0.02160833  0.00432812]
#
# Debug: Returns for SMH, Forecast Period 13w: [-0.00399275 -0.01092407 -0.00202043 -0.00120651]
#
# Debug: Returns for SMH, Forecast Period 14w: [ 0.01130662 -0.01497789  0.00165874 -0.02885792  0.00994641]
#
# Debug: Returns for SMH, Forecast Period 15w: [-0.00097252  0.00237837 -0.01080373  0.02083255 -0.03128193]
#
# Debug: Returns for SMH, Forecast Period 16w: [-0.0171243   0.00618749 -0.03303697 -0.02015495 -0.04799288]
#
# Debug: Returns for SMH, Forecast Period 17w: [ 0.01593321  0.02041036 -0.00179513  0.01721308  0.02303897]
#
# Debug: Returns for SMH, Forecast Period 18w: [ 0.00090471 -0.02232318 -0.03187996  0.01719769  0.02451571]
#
# Debug: Returns for SMH, Forecast Period 19w: [ 0.02038484 -0.01092666  0.00070083 -0.00873324  0.01250916]
#
# Debug: Returns for SMH, Forecast Period 20w: [-0.00237653  0.01512189  0.02814176 -0.00863927 -0.00960629]
#
# Debug: Returns for SMH, Forecast Period 21w: [ 0.02003588 -0.00216569  0.00716197  0.01276008  0.01759693]
#
# Debug: Returns for SMH, Forecast Period 22w: [ 0.02180736 -0.01775278 -0.01466677 -0.00802812]
#
# Debug: Returns for SMH, Forecast Period 23w: [ 0.01163796 -0.00465338  0.04755979 -0.00871197 -0.00171333]
#
# Debug: Returns for SMH, Forecast Period 24w: [ 0.01371442 -0.00243295  0.02896365  0.01487779  0.00157513]
#
# Debug: Returns for SMH, Forecast Period 25w: [ 0.0163857   0.01528368 -0.02912427 -0.01597281]
#
# Debug: Returns for SMH, Forecast Period 26w: [-0.03585222  0.0217529  -0.00512813 -0.01005283  0.00514533]
#
# Debug: Returns for SMH, Forecast Period 27w: [-0.0005638   0.00840668  0.02107804 -0.00113987]
#
# Debug: Returns for SMH, Forecast Period 28w: [ 0.01467669  0.0004623   0.02191166 -0.03823897  0.01073645]
#
# Debug: Returns for SMH, Forecast Period 29w: [-0.00449654 -0.00292564 -0.07420184  0.00170297 -0.03282143]
#
# Debug: Returns for SMH, Forecast Period 30w: [ 0.03514292 -0.01421337 -0.05743576 -0.02192929  0.01229276]
#
# Debug: Returns for SMH, Forecast Period 31w: [-0.01048968 -0.04194348  0.07264038 -0.06844181 -0.0589956 ]
#
# Debug: Returns for SMH, Forecast Period 32w: [-0.02835432  0.01430618 -0.03275872  0.05803785 -0.00491528]
#
# Debug: Returns for SMH, Forecast Period 33w: [ 0.00458995  0.03605099 -0.00357199  0.03913026 -0.00170345]
#
# Debug: Returns for SMH, Forecast Period 34w: [ 0.01625221 -0.0159783   0.00760024 -0.03491439  0.02272818]
#
# Debug: Returns for SMH, Forecast Period 35w: [-0.02568152  0.00784351 -0.01862045 -0.01515423  0.02150104]
#
# Debug: Returns for SMH, Forecast Period 36w: [-0.07652519 -0.00399758 -0.00358076 -0.04300279]
#
# Debug: Returns for SMH, Forecast Period 37w: [ 0.02015154  0.00720237  0.04946275 -0.00014893  0.01062516]
#
# Debug: Returns for SMH, Forecast Period 38w: [-0.01585835 -0.00317924 -0.01458444  0.0405093  -0.01612886]
#
# Debug: Returns for SMH, Forecast Period 39w: [ 0.00188236  0.01593923  0.00650588  0.0265744  -0.02136446]
#
# Debug: Returns for SMH, Forecast Period 40w: [-0.0112981  -0.02928204  0.01295766  0.00787115  0.01218092]
#
# Debug: Returns for SMH, Forecast Period 41w: [ 0.0009951   0.01658194  0.00969043 -0.00317884  0.00677084]
#
# Debug: Returns for SMH, Forecast Period 42w: [ 0.01660347 -0.0553696  -0.0009588   0.01586481 -0.00208878]
#
# Debug: Returns for SMH, Forecast Period 43w: [ 0.0036012  -0.00637755 -0.01278769  0.00190739  0.0090167 ]
#
# Debug: Returns for SMH, Forecast Period 44w: [-0.00924831  0.0205831  -0.02611247 -0.03813115  0.01022081]
#
# Debug: Returns for SMH, Forecast Period 45w: [-0.00462627  0.01393326  0.02355035  0.02184848 -0.00891193]
#
# Debug: Returns for SMH, Forecast Period 46w: [-0.02513523 -0.00971471 -0.01921614 -0.00033945 -0.03604504]
#
# Debug: Returns for SMH, Forecast Period 47w: [ 0.00365789  0.00794369 -0.00966055  0.01190901 -0.00886057]
#
# Debug: Returns for SMH, Forecast Period 48w: [-0.0070254  -0.01227851 -0.0165479   0.01318923]
#
# Debug: Returns for SOXX, Forecast Period 1w: [-0.03626821 -0.0218027  -0.00883788  0.00510342]
#
# Debug: Returns for SOXX, Forecast Period 2w: [ 0.03228976  0.00012377 -0.00373466  0.00318493 -0.00491288]
#
# Debug: Returns for SOXX, Forecast Period 3w: [ 0.0133924  -0.00988799  0.03230065  0.03852232]
#
# Debug: Returns for SOXX, Forecast Period 4w: [ 0.00267683  0.00653529  0.01426594 -0.00291137 -0.02752242]
#
# Debug: Returns for SOXX, Forecast Period 5w: [ 0.00976734 -0.01604994 -0.01513655  0.00466534  0.01264672]
#
# Debug: Returns for SOXX, Forecast Period 6w: [ 0.01378515 -0.01167972  0.01512623  0.01716596  0.01975732]
#
# Debug: Returns for SOXX, Forecast Period 7w: [-0.00181396 -0.02068137  0.0224788  -0.00102939 -0.00596588]
#
# Debug: Returns for SOXX, Forecast Period 8w: [-0.01738836 -0.00294395  0.0485385  -0.0114349 ]
#
# Debug: Returns for SOXX, Forecast Period 9w: [ 0.00920662 -0.00135554 -0.01162496  0.02694453  0.04252604]
#
# Debug: Returns for SOXX, Forecast Period 10w: [ 0.00991072 -0.01955448  0.02473223  0.03468836 -0.04023261]
#
# Debug: Returns for SOXX, Forecast Period 11w: [-0.01348307  0.02055486 -0.02471413 -0.01739162 -0.00753789]
#
# Debug: Returns for SOXX, Forecast Period 12w: [-0.00118613 -0.00887164  0.016726    0.02237054  0.00078667]
#
# Debug: Returns for SOXX, Forecast Period 13w: [-0.00447132 -0.00802582  0.01211348  0.00048094]
#
# Debug: Returns for SOXX, Forecast Period 14w: [ 0.01003209 -0.01637936  0.00200751 -0.02904056  0.01093794]
#
# Debug: Returns for SOXX, Forecast Period 15w: [ 0.00137882  0.00996882 -0.01892572  0.02178407 -0.03354656]
#
# Debug: Returns for SOXX, Forecast Period 16w: [-0.01346062  0.0069287  -0.03115941 -0.01860168 -0.04128179]
#
# Debug: Returns for SOXX, Forecast Period 17w: [0.01495027 0.01957849 0.01165092 0.01752513 0.02024949]
#
# Debug: Returns for SOXX, Forecast Period 18w: [ 0.00667258 -0.02197478 -0.0349465   0.02140105  0.02155239]
#
# Debug: Returns for SOXX, Forecast Period 19w: [ 2.01743236e-02 -9.66881413e-03 -7.30230942e-05 -4.48395453e-03
#   8.76559291e-03]
#
# Debug: Returns for SOXX, Forecast Period 20w: [ 0.00116598  0.01602454  0.02768597 -0.00499344 -0.00559393]
#
# Debug: Returns for SOXX, Forecast Period 21w: [ 0.02239194 -0.00280203  0.01204845 -0.00567072  0.01995166]
#
# Debug: Returns for SOXX, Forecast Period 22w: [ 0.01690692 -0.02060845 -0.00684962 -0.00795796]
#
# Debug: Returns for SOXX, Forecast Period 23w: [ 0.0015388  -0.00779329  0.04357072 -0.00804536 -0.00300028]
#
# Debug: Returns for SOXX, Forecast Period 24w: [ 0.01454852  0.00086004  0.02816417  0.01093535 -0.00363711]
#
# Debug: Returns for SOXX, Forecast Period 25w: [ 0.01583068  0.01281036 -0.02735647 -0.01007297]
#
# Debug: Returns for SOXX, Forecast Period 26w: [-0.02920702  0.01484871 -0.00450512 -0.00604836  0.0096329 ]
#
# Debug: Returns for SOXX, Forecast Period 27w: [-0.00062143  0.01377651  0.01636165  0.00170502]
#
# Debug: Returns for SOXX, Forecast Period 28w: [ 0.01867745 -0.00077362  0.02305928 -0.03322806  0.01179748]
#
# Debug: Returns for SOXX, Forecast Period 29w: [ 0.00054972  0.00558521 -0.07210716  0.00186374 -0.03204865]
#
# Debug: Returns for SOXX, Forecast Period 30w: [ 0.0401427  -0.01598566 -0.05440375 -0.02372701  0.02010746]
#
# Debug: Returns for SOXX, Forecast Period 31w: [-0.00348785 -0.03806496  0.06573646 -0.07402392 -0.05565168]
#
# Debug: Returns for SOXX, Forecast Period 32w: [-0.02006487  0.00662173 -0.03047646  0.06612963 -0.00800166]
#
# Debug: Returns for SOXX, Forecast Period 33w: [ 0.00341263  0.03849513 -0.00480475  0.04690152 -0.00336748]
#
# Debug: Returns for SOXX, Forecast Period 34w: [ 0.01627316 -0.01461775  0.01322585 -0.0348106   0.02646954]
#
# Debug: Returns for SOXX, Forecast Period 35w: [-0.02566783  0.01024705 -0.01836377 -0.00394722  0.02604195]
#
# Debug: Returns for SOXX, Forecast Period 36w: [-0.07644905  0.00335071 -0.00575134 -0.0430334 ]
#
# Debug: Returns for SOXX, Forecast Period 37w: [ 0.01912242  0.01011351  0.04584413 -0.00506672  0.01721348]
#
# Debug: Returns for SOXX, Forecast Period 38w: [-0.01417409  0.00047042 -0.0121582   0.04166439 -0.01568975]
#
# Debug: Returns for SOXX, Forecast Period 39w: [ 0.00332397  0.01130208  0.0063912   0.03514099 -0.01633477]
#
# Debug: Returns for SOXX, Forecast Period 40w: [-0.0094172  -0.02881369  0.01358621  0.00358715  0.01389342]
#
# Debug: Returns for SOXX, Forecast Period 41w: [-0.00221839  0.01042356  0.01077654 -0.00707845  0.00845376]
#
# Debug: Returns for SOXX, Forecast Period 42w: [ 0.01844036 -0.05220522 -0.00041543  0.00779787  0.00054387]
#
# Debug: Returns for SOXX, Forecast Period 43w: [-0.00220737 -0.00413354 -0.0096122   0.0047641   0.00919084]
#
# Debug: Returns for SOXX, Forecast Period 44w: [-0.00010298  0.02403542 -0.03584148 -0.03961374  0.00971973]
#
# Debug: Returns for SOXX, Forecast Period 45w: [-0.00685925  0.0107068   0.02810868  0.01969639 -0.00823113]
#
# Debug: Returns for SOXX, Forecast Period 46w: [-0.02607641 -0.01240483 -0.02206065 -0.00171393 -0.03344118]
#
# Debug: Returns for SOXX, Forecast Period 47w: [ 0.01168012  0.00073562 -0.00892193  0.01484711 -0.00060714]
#
# Debug: Returns for SOXX, Forecast Period 48w: [ 0.00855968 -0.01423697 -0.01486922  0.01222353]
#
# Debug: Returns for PSI, Forecast Period 1w: [-0.03581048 -0.02346916 -0.01418647  0.00154702]
#
# Debug: Returns for PSI, Forecast Period 2w: [ 0.02883653  0.00220999 -0.00420602  0.0031341  -0.00518673]
#
# Debug: Returns for PSI, Forecast Period 3w: [ 0.01411725 -0.01155834  0.03253233  0.03886656]
#
# Debug: Returns for PSI, Forecast Period 4w: [ 0.00917281  0.00356665  0.0111468  -0.00082156 -0.02810002]
#
# Debug: Returns for PSI, Forecast Period 5w: [ 0.01176991 -0.01422174 -0.019868    0.0082489   0.011775  ]
#
# Debug: Returns for PSI, Forecast Period 6w: [ 0.00929917 -0.01328911  0.0069711   0.01916549  0.03167404]
#
# Debug: Returns for PSI, Forecast Period 7w: [ 1.63577452e-03 -2.71048852e-02  3.15362602e-02  5.48449677e-03
#  -7.30739946e-05]
#
# Debug: Returns for PSI, Forecast Period 8w: [-0.02725745 -0.0112485   0.04366012 -0.01067028]
#
# Debug: Returns for PSI, Forecast Period 9w: [ 0.01339962 -0.00244351  0.00369219  0.01862234  0.04271248]
#
# Debug: Returns for PSI, Forecast Period 10w: [ 0.00384451 -0.02575264  0.02446573  0.02925558 -0.03755563]
#
# Debug: Returns for PSI, Forecast Period 11w: [-0.01495017  0.01709598 -0.02526356 -0.01525236 -0.00875938]
#
# Debug: Returns for PSI, Forecast Period 12w: [ 0.00691234 -0.00644225  0.02487319  0.02942213  0.00176582]
#
# Debug: Returns for PSI, Forecast Period 13w: [-0.00036141 -0.00626762  0.0114862  -0.00073313]
#
# Debug: Returns for PSI, Forecast Period 14w: [ 0.01062021 -0.0101488   0.01035518 -0.02501434  0.01285416]
#
# Debug: Returns for PSI, Forecast Period 15w: [ 0.00244496  0.0085005  -0.0208116   0.02659776 -0.03280567]
#
# Debug: Returns for PSI, Forecast Period 16w: [-0.01437094  0.01141469 -0.03238066 -0.01961915 -0.03966028]
#
# Debug: Returns for PSI, Forecast Period 17w: [0.01562502 0.02348828 0.00876186 0.0167547  0.02158971]
#
# Debug: Returns for PSI, Forecast Period 18w: [ 0.00848943 -0.02167628 -0.03321343  0.02930502  0.02216376]
#
# Debug: Returns for PSI, Forecast Period 19w: [ 0.02229408 -0.00480541 -0.00022765  0.00163199  0.00621911]
#
# Debug: Returns for PSI, Forecast Period 20w: [-0.00064776  0.01622552  0.02692366 -0.00784893 -0.00505325]
#
# Debug: Returns for PSI, Forecast Period 21w: [ 0.02191592  0.00082517  0.00191099 -0.00253727  0.01757075]
#
# Debug: Returns for PSI, Forecast Period 22w: [ 0.01526747 -0.01477715 -0.00167485 -0.01096503]
#
# Debug: Returns for PSI, Forecast Period 23w: [ 0.00104525 -0.00977633  0.04653945 -0.00775769 -0.00920306]
#
# Debug: Returns for PSI, Forecast Period 24w: [ 0.02056323  0.0001275   0.02912116  0.00866798 -0.00781801]
#
# Debug: Returns for PSI, Forecast Period 25w: [ 0.02114837  0.01490489 -0.02794483 -0.01118971]
#
# Debug: Returns for PSI, Forecast Period 26w: [-0.02281272  0.02239451 -0.00199379  0.0019606   0.01290171]
#
# Debug: Returns for PSI, Forecast Period 27w: [-0.00034031  0.01443531  0.01273777  0.00314442]
#
# Debug: Returns for PSI, Forecast Period 28w: [ 0.01623749  0.00111671  0.01726669 -0.02865465  0.01223485]
#
# Debug: Returns for PSI, Forecast Period 29w: [ 0.01220981  0.00784368 -0.08133295 -0.00980835 -0.02593229]
#
# Debug: Returns for PSI, Forecast Period 30w: [ 0.04186195 -0.00838094 -0.05566981 -0.03036262  0.01614578]
#
# Debug: Returns for PSI, Forecast Period 31w: [-0.00469703 -0.04722564  0.06371854 -0.07959045 -0.05040016]
#
# Debug: Returns for PSI, Forecast Period 32w: [-0.01582187  0.0059444  -0.01723791  0.07081021  0.00310503]
#
# Debug: Returns for PSI, Forecast Period 33w: [ 0.00269858  0.03649663 -0.00215894  0.05188214 -0.00543612]
#
# Debug: Returns for PSI, Forecast Period 34w: [ 0.0134127  -0.01508065  0.02246648 -0.03141497  0.02712077]
#
# Debug: Returns for PSI, Forecast Period 35w: [-0.02681507  0.01141598 -0.01451657  0.00609289  0.01287055]
#
# Debug: Returns for PSI, Forecast Period 36w: [-0.08041607  0.00660407 -0.00703132 -0.0406635 ]
#
# Debug: Returns for PSI, Forecast Period 37w: [ 0.01124828  0.00745431  0.04153984 -0.00814847  0.02312547]
#
# Debug: Returns for PSI, Forecast Period 38w: [-0.02247698  0.00756053 -0.01081971  0.04345067 -0.01286497]
#
# Debug: Returns for PSI, Forecast Period 39w: [ 0.00434548  0.01167839  0.00664671  0.04971988 -0.01622547]
#
# Debug: Returns for PSI, Forecast Period 40w: [-0.00652921 -0.03657092  0.01858229 -0.00610754  0.02146443]
#
# Debug: Returns for PSI, Forecast Period 41w: [ 0.00125017  0.00349963  0.01554157 -0.00112749  0.01719998]
#
# Debug: Returns for PSI, Forecast Period 42w: [ 0.01856057 -0.05525561  0.00217439  0.00261118 -0.00018122]
#
# Debug: Returns for PSI, Forecast Period 43w: [-0.00260491 -0.00550964 -0.00792548  0.00268675  0.01559182]
#
# Debug: Returns for PSI, Forecast Period 44w: [-0.00088925  0.02130757 -0.02392935 -0.04377198  0.0062088 ]
#
# Debug: Returns for PSI, Forecast Period 45w: [-0.00766662  0.02796997  0.03395971  0.02473942 -0.00400131]
#
# Debug: Returns for PSI, Forecast Period 46w: [-0.02188941 -0.01259979 -0.02135832 -0.00206069 -0.03907071]
#
# Debug: Returns for PSI, Forecast Period 47w: [1.50482038e-02 8.74768742e-03 7.19393766e-05 3.41293386e-02
#  4.87243956e-04]
#
# Debug: Returns for PSI, Forecast Period 48w: [ 0.01358413 -0.00814974 -0.01769085  0.02046193]
#
# Debug: Returns for XSD, Forecast Period 1w: [-0.02928982 -0.03051557 -0.01733279  0.00253352]
#
# Debug: Returns for XSD, Forecast Period 2w: [ 0.03175567 -0.00170718 -0.00688941 -0.00556173 -0.00933331]
#
# Debug: Returns for XSD, Forecast Period 3w: [ 0.00081786 -0.01194014  0.03026452  0.03093483]
#
# Debug: Returns for XSD, Forecast Period 4w: [ 0.01676808  0.00953738 -0.0080898  -0.01044746 -0.02724476]
#
# Debug: Returns for XSD, Forecast Period 5w: [ 0.01649659 -0.02490732 -0.02023149 -0.00088591  0.00094224]
#
# Debug: Returns for XSD, Forecast Period 6w: [ 0.00802434 -0.0087423   0.01813482  0.02843828  0.02422643]
#
# Debug: Returns for XSD, Forecast Period 7w: [ 0.00343686 -0.03631751  0.02469481 -0.00049823 -0.0166178 ]
#
# Debug: Returns for XSD, Forecast Period 8w: [-0.01072686 -0.00232185  0.02229032 -0.01656145]
#
# Debug: Returns for XSD, Forecast Period 9w: [ 0.01167589 -0.00314247 -0.00712652  0.02346038  0.03810832]
#
# Debug: Returns for XSD, Forecast Period 10w: [-0.00084048 -0.02339152  0.02529301  0.03583651 -0.02931666]
#
# Debug: Returns for XSD, Forecast Period 11w: [-0.00636399  0.00843747 -0.02778699 -0.02397308 -0.00785069]
#
# Debug: Returns for XSD, Forecast Period 12w: [-0.00119287 -0.00657648  0.02350135  0.02247636 -0.00704244]
#
# Debug: Returns for XSD, Forecast Period 13w: [-0.00172268 -0.0046198   0.02727016  0.00357103]
#
# Debug: Returns for XSD, Forecast Period 14w: [ 0.00765876 -0.02223903  0.00920572 -0.01568359  0.00505246]
#
# Debug: Returns for XSD, Forecast Period 15w: [ 0.00853642  0.02184824 -0.03953231  0.02345651 -0.03567303]
#
# Debug: Returns for XSD, Forecast Period 16w: [-0.02014898  0.00250663 -0.02188323 -0.0200234  -0.03170487]
#
# Debug: Returns for XSD, Forecast Period 17w: [0.01456644 0.01950436 0.02280309 0.0233784  0.01821709]
#
# Debug: Returns for XSD, Forecast Period 18w: [ 0.01743012 -0.01839716 -0.03223052  0.01746123  0.02261051]
#
# Debug: Returns for XSD, Forecast Period 19w: [ 0.01731367 -0.00337861  0.00380961  0.00344855 -0.0060086 ]
#
# Debug: Returns for XSD, Forecast Period 20w: [ 0.00537644  0.01781416  0.02091071 -0.00459285  0.00107335]
#
# Debug: Returns for XSD, Forecast Period 21w: [ 0.01371701 -0.00305219  0.02084278 -0.0211082   0.02291774]
#
# Debug: Returns for XSD, Forecast Period 22w: [ 0.01411301 -0.0186787   0.00532493  0.00097527]
#
# Debug: Returns for XSD, Forecast Period 23w: [-2.63975903e-05 -1.46564431e-02  3.93796367e-02 -8.40607771e-03
#  -1.91772627e-02]
#
# Debug: Returns for XSD, Forecast Period 24w: [ 0.01586897  0.00474439  0.02810384 -0.00234923 -0.01656699]
#
# Debug: Returns for XSD, Forecast Period 25w: [ 0.00758954  0.00135476 -0.02177466  0.00102647]
#
# Debug: Returns for XSD, Forecast Period 26w: [-0.02010582  0.00877818  0.00054257 -0.00246998  0.01073094]
#
# Debug: Returns for XSD, Forecast Period 27w: [-0.00383491  0.02029612  0.00956141  0.00494405]
#
# Debug: Returns for XSD, Forecast Period 28w: [ 0.02144222 -0.00573157  0.0280317  -0.01243148  0.01208207]
#
# Debug: Returns for XSD, Forecast Period 29w: [ 0.01034853  0.01962422 -0.05591619 -0.0082923  -0.02957891]
#
# Debug: Returns for XSD, Forecast Period 30w: [ 0.03900119 -0.01583082 -0.04558158 -0.02513219  0.02170072]
#
# Debug: Returns for XSD, Forecast Period 31w: [ 1.97571570e-05 -4.13984920e-02  4.40992398e-02 -6.60673878e-02
#  -6.07707015e-02]
#
# Debug: Returns for XSD, Forecast Period 32w: [-0.03004984  0.00312865 -0.03119451  0.06845905 -0.0061789 ]
#
# Debug: Returns for XSD, Forecast Period 33w: [-0.00012972  0.03955419 -0.01289966  0.05339646 -0.00347455]
#
# Debug: Returns for XSD, Forecast Period 34w: [ 0.01374645 -0.009742    0.02230087 -0.02972962  0.03375432]
#
# Debug: Returns for XSD, Forecast Period 35w: [-0.01800749  0.006435   -0.01256929  0.01584456  0.01463259]
#
# Debug: Returns for XSD, Forecast Period 36w: [-0.07423541  0.00427214 -0.00900724 -0.04156752]
#
# Debug: Returns for XSD, Forecast Period 37w: [ 0.01746168  0.003487    0.04071228 -0.00648754  0.02260382]
#
# Debug: Returns for XSD, Forecast Period 38w: [-0.01194269  0.00418781 -0.00326082  0.03955497 -0.01586722]
#
# Debug: Returns for XSD, Forecast Period 39w: [ 0.00429544  0.01005495 -0.00358306  0.04566153 -0.00450234]
#
# Debug: Returns for XSD, Forecast Period 40w: [-0.00983761 -0.03489044  0.01148451 -0.0015326   0.01871618]
#
# Debug: Returns for XSD, Forecast Period 41w: [-0.00540455  0.00501359  0.01374305 -0.00474546  0.02076284]
#
# Debug: Returns for XSD, Forecast Period 42w: [ 0.01163054 -0.02660015  0.00674369  0.00398332  0.00022502]
#
# Debug: Returns for XSD, Forecast Period 43w: [-0.0029778   0.00027796 -0.00888538  0.00506923  0.01135757]
#
# Debug: Returns for XSD, Forecast Period 44w: [ 0.01217596  0.02332978 -0.0423681  -0.05075995  0.02161156]
#
# Debug: Returns for XSD, Forecast Period 45w: [-0.00508936  0.01583869  0.04213735  0.01148261  0.00798476]
#
# Debug: Returns for XSD, Forecast Period 46w: [-0.02792029 -0.01959297 -0.02204194 -0.00829151 -0.03284669]
#
# Debug: Returns for XSD, Forecast Period 47w: [0.01497557 0.00956291 0.00022016 0.02810902 0.01514455]
#
# Debug: Returns for XSD, Forecast Period 48w: [ 0.03185021 -0.01150391 -0.01151193  0.01890864]
#
# Debug: Returns for IYW, Forecast Period 1w: [-0.0264297  -0.01039916 -0.00711559  0.00068822]
#
# Debug: Returns for IYW, Forecast Period 2w: [0.02619522 0.00288489 0.00928094 0.00413298 0.00232601]
#
# Debug: Returns for IYW, Forecast Period 3w: [ 0.00148152 -0.00565041  0.0188661   0.02346741]
#
# Debug: Returns for IYW, Forecast Period 4w: [ 0.00406431  0.00408623  0.00711275  0.00436149 -0.00936267]
#
# Debug: Returns for IYW, Forecast Period 5w: [ 0.01074785 -0.00858919 -0.02599569  0.01198396  0.01870392]
#
# Debug: Returns for IYW, Forecast Period 6w: [ 0.00106483 -0.00357663  0.01512774  0.00443249  0.01502925]
#
# Debug: Returns for IYW, Forecast Period 7w: [-0.00777009 -0.01742263  0.01228509 -0.00222079 -0.01121996]
#
# Debug: Returns for IYW, Forecast Period 8w: [-0.01033623 -0.00815467  0.03296265 -0.00243923]
#
# Debug: Returns for IYW, Forecast Period 9w: [-0.00287894  0.00207692 -0.00719278  0.01085113  0.01573034]
#
# Debug: Returns for IYW, Forecast Period 10w: [-0.00291276 -0.02379871  0.0085126   0.01745666 -0.01446524]
#
# Debug: Returns for IYW, Forecast Period 11w: [-0.00470431  0.01931085 -0.00923374  0.00036699 -0.0160133 ]
#
# Debug: Returns for IYW, Forecast Period 12w: [0.00775334 0.00412273 0.01241271 0.00254132 0.00299021]
#
# Debug: Returns for IYW, Forecast Period 13w: [-0.00537123 -0.00539671  0.00060348 -0.00240357]
#
# Debug: Returns for IYW, Forecast Period 14w: [ 0.003236   -0.00828648  0.00162391 -0.01708009  0.01357104]
#
# Debug: Returns for IYW, Forecast Period 15w: [-0.0022857   0.00159588 -0.00753387  0.0206592  -0.01741778]
#
# Debug: Returns for IYW, Forecast Period 16w: [-0.02151889  0.00130549 -0.01613448 -0.00790887 -0.02940831]
#
# Debug: Returns for IYW, Forecast Period 17w: [ 0.01089508  0.01704182  0.0016244  -0.00582052  0.02056651]
#
# Debug: Returns for IYW, Forecast Period 18w: [-7.81095954e-05 -2.27014782e-02 -1.03812943e-02  1.52956506e-02
#   2.37666607e-02]
#
# Debug: Returns for IYW, Forecast Period 19w: [ 0.01493509 -0.0049204  -0.00025623 -0.00159781  0.00256115]
#
# Debug: Returns for IYW, Forecast Period 20w: [ 0.00315052  0.00849396  0.02216953 -0.0025937  -0.00241726]
#
# Debug: Returns for IYW, Forecast Period 21w: [0.01306915 0.00129656 0.00032039 0.0018885  0.00921962]
#
# Debug: Returns for IYW, Forecast Period 22w: [ 0.01092104 -0.00509058 -0.025425   -0.00046037]
#
# Debug: Returns for IYW, Forecast Period 23w: [ 0.00780938  0.00137881  0.02665577 -0.00299709  0.00125621]
#
# Debug: Returns for IYW, Forecast Period 24w: [0.00323149 0.01469988 0.02256353 0.0066518  0.00561394]
#
# Debug: Returns for IYW, Forecast Period 25w: [ 0.01124267  0.00481289 -0.0136979  -0.00639646]
#
# Debug: Returns for IYW, Forecast Period 26w: [-0.01710898  0.01687087  0.00334303  0.00149254 -0.00412908]
#
# Debug: Returns for IYW, Forecast Period 27w: [0.01011043 0.00692696 0.01111518 0.00931343]
#
# Debug: Returns for IYW, Forecast Period 28w: [ 0.00510764 -0.0018659   0.01340019 -0.02432895  0.00674566]
#
# Debug: Returns for IYW, Forecast Period 29w: [ 0.00474635 -0.00310531 -0.03810185 -0.00542744 -0.01161761]
#
# Debug: Returns for IYW, Forecast Period 30w: [ 0.01955931 -0.0025451  -0.04351554 -0.010167    0.01003209]
#
# Debug: Returns for IYW, Forecast Period 31w: [-0.00378923 -0.02015695  0.03366938 -0.0323818  -0.02682228]
#
# Debug: Returns for IYW, Forecast Period 32w: [-0.03695904  0.00753857 -0.01257724  0.03364841  0.00530645]
#
# Debug: Returns for IYW, Forecast Period 33w: [0.0039969  0.02643429 0.00204158 0.02412875 0.00088163]
#
# Debug: Returns for IYW, Forecast Period 34w: [ 0.012884   -0.00394262  0.00502394 -0.02056451  0.01326852]
#
# Debug: Returns for IYW, Forecast Period 35w: [-0.01000359  0.00366928 -0.01298153 -0.00480553  0.01081788]
#
# Debug: Returns for IYW, Forecast Period 36w: [-0.04222512 -0.00419106 -0.00051323 -0.02413586]
#
# Debug: Returns for IYW, Forecast Period 37w: [0.01166694 0.01036114 0.02741146 0.00796039 0.00471417]
#
# Debug: Returns for IYW, Forecast Period 38w: [-0.00686433 -0.00029293 -0.0055378   0.02984443 -0.00382844]
#
# Debug: Returns for IYW, Forecast Period 39w: [-0.00162939  0.00650727  0.00295253  0.00922754 -0.00821984]
#
# Debug: Returns for IYW, Forecast Period 40w: [ 0.0036209  -0.02349388  0.00587025  0.00423093  0.01287216]
#
# Debug: Returns for IYW, Forecast Period 41w: [-0.0085187   0.0185059   0.00894943  0.00054281  0.00230728]
#
# Debug: Returns for IYW, Forecast Period 42w: [ 1.27984515e-02 -1.82436109e-02 -5.71019328e-05  2.79999556e-03
#   3.42805763e-03]
#
# Debug: Returns for IYW, Forecast Period 43w: [ 6.49395956e-03  1.96638937e-05 -1.61184013e-02  3.53034912e-03
#   6.02990533e-03]
#
# Debug: Returns for IYW, Forecast Period 44w: [ 0.00135319  0.01322585 -0.0120147  -0.03358783  0.00625845]
#
# Debug: Returns for IYW, Forecast Period 45w: [-0.00252782  0.01423375  0.02750628  0.02047113 -0.0018675 ]
#
# Debug: Returns for IYW, Forecast Period 46w: [-0.00488203  0.00316386 -0.00516843 -0.00360035 -0.02570634]
#
# Debug: Returns for IYW, Forecast Period 47w: [ 3.75619085e-03  1.19245455e-02 -1.96120767e-03  6.31291243e-03
#   9.32814223e-05]
#
# Debug: Returns for IYW, Forecast Period 48w: [-0.00034934  0.00437336 -0.01244332  0.00828847]
#
# Debug: Returns for XLK, Forecast Period 1w: [-0.02638982 -0.01054477 -0.00766128 -0.00069176]
#
# Debug: Returns for XLK, Forecast Period 2w: [0.02466189 0.00125487 0.00815623 0.00470833 0.00286407]
#
# Debug: Returns for XLK, Forecast Period 3w: [ 0.00210283 -0.00529442  0.01984572  0.02273067]
#
# Debug: Returns for XLK, Forecast Period 4w: [ 0.00422744  0.00400056  0.00682043  0.00412399 -0.01157962]
#
# Debug: Returns for XLK, Forecast Period 5w: [ 0.00905855 -0.00837174 -0.02117598  0.01249206  0.01040538]
#
# Debug: Returns for XLK, Forecast Period 6w: [ 0.00240343 -0.0044897   0.01317539  0.00316     0.0134491 ]
#
# Debug: Returns for XLK, Forecast Period 7w: [-0.00760539 -0.01704356  0.01028378 -0.00219869 -0.0093931 ]
#
# Debug: Returns for XLK, Forecast Period 8w: [-0.01055396 -0.00677143  0.0321282  -0.00276976]
#
# Debug: Returns for XLK, Forecast Period 9w: [ 0.00048373  0.00048985 -0.00519564  0.01070391  0.01806593]
#
# Debug: Returns for XLK, Forecast Period 10w: [-0.00020353 -0.02485477  0.00754526  0.01547594 -0.01518372]
#
# Debug: Returns for XLK, Forecast Period 11w: [-0.00320572  0.01996686 -0.01120436 -0.00014038 -0.01549601]
#
# Debug: Returns for XLK, Forecast Period 12w: [ 4.45849459e-03  4.77920331e-03  1.08878546e-02  5.37833092e-04
#  -3.14400756e-06]
#
# Debug: Returns for XLK, Forecast Period 13w: [-0.00696666 -0.00449673  0.00469744 -0.00253338]
#
# Debug: Returns for XLK, Forecast Period 14w: [ 0.0023416  -0.01016458  0.00210437 -0.01619824  0.01094696]
#
# Debug: Returns for XLK, Forecast Period 15w: [-0.00171217  0.00457186 -0.01268582  0.01936181 -0.01663252]
#
# Debug: Returns for XLK, Forecast Period 16w: [-0.01953722  0.00065677 -0.01499822 -0.01211494 -0.02146589]
#
# Debug: Returns for XLK, Forecast Period 17w: [ 0.00800241  0.01393258  0.00381237 -0.00290982  0.0105159 ]
#
# Debug: Returns for XLK, Forecast Period 18w: [ 0.00360935 -0.02273926 -0.01101669  0.01358688  0.02718568]
#
# Debug: Returns for XLK, Forecast Period 19w: [ 0.01121481 -0.00375302  0.00231846 -0.00076399  0.0031212 ]
#
# Debug: Returns for XLK, Forecast Period 20w: [ 0.00428456  0.00858444  0.02224648 -0.00349889 -0.00217325]
#
# Debug: Returns for XLK, Forecast Period 21w: [ 0.01192479  0.00178702  0.00231774 -0.00807954  0.00848477]
#
# Debug: Returns for XLK, Forecast Period 22w: [ 0.0042515  -0.00634351 -0.0227204   0.00161587]
#
# Debug: Returns for XLK, Forecast Period 23w: [ 0.00248289  0.00195194  0.02200067 -0.00343678  0.00218841]
#
# Debug: Returns for XLK, Forecast Period 24w: [0.00242191 0.01846206 0.02206973 0.00792362 0.00372772]
#
# Debug: Returns for XLK, Forecast Period 25w: [ 0.01521165  0.00142934 -0.01115995 -0.00177385]
#
# Debug: Returns for XLK, Forecast Period 26w: [-0.0246359   0.01817106 -0.0012834   0.00030497 -0.00069451]
#
# Debug: Returns for XLK, Forecast Period 27w: [0.00756805 0.00506788 0.01358013 0.00319415]
#
# Debug: Returns for XLK, Forecast Period 28w: [ 0.00684638 -0.00074198  0.01457336 -0.02492669  0.00878847]
#
# Debug: Returns for XLK, Forecast Period 29w: [ 0.0015791  -0.00360557 -0.03929565 -0.00059774 -0.01637688]
#
# Debug: Returns for XLK, Forecast Period 30w: [ 0.02293262 -0.00461826 -0.04196038 -0.01162098  0.01172987]
#
# Debug: Returns for XLK, Forecast Period 31w: [-0.00530882 -0.02606693  0.04119956 -0.0383087  -0.0294103 ]
#
# Debug: Returns for XLK, Forecast Period 32w: [-0.03485938  0.01188708 -0.01787765  0.03547508  0.0030778 ]
#
# Debug: Returns for XLK, Forecast Period 33w: [0.00674051 0.02931964 0.00428301 0.027958   0.00095533]
#
# Debug: Returns for XLK, Forecast Period 34w: [ 0.01594942 -0.00408255  0.00537557 -0.02324162  0.01595707]
#
# Debug: Returns for XLK, Forecast Period 35w: [-0.01285955  0.0057239  -0.01398397 -0.00956637  0.01298447]
#
# Debug: Returns for XLK, Forecast Period 36w: [-0.04610308 -0.00274705 -0.00183618 -0.0261939 ]
#
# Debug: Returns for XLK, Forecast Period 37w: [0.01581647 0.01447974 0.03368165 0.00787056 0.00463517]
#
# Debug: Returns for XLK, Forecast Period 38w: [-0.00433774 -0.00252043 -0.00984769  0.02899986 -0.00546964]
#
# Debug: Returns for XLK, Forecast Period 39w: [-0.00062676  0.00632852  0.00246652  0.01281778 -0.00963405]
#
# Debug: Returns for XLK, Forecast Period 40w: [ 0.00262999 -0.02477853  0.00727299  0.00408026  0.01109476]
#
# Debug: Returns for XLK, Forecast Period 41w: [-0.00670305  0.0187485   0.0112587  -0.00030514  0.00161915]
#
# Debug: Returns for XLK, Forecast Period 42w: [ 0.01290275 -0.022062    0.00293768  0.00300721  0.00337235]
#
# Debug: Returns for XLK, Forecast Period 43w: [ 0.00452928 -0.00118354 -0.01454009  0.00259465  0.00479084]
#
# Debug: Returns for XLK, Forecast Period 44w: [-0.00061307  0.0131263  -0.01601342 -0.03239799  0.00701415]
#
# Debug: Returns for XLK, Forecast Period 45w: [-0.00129222  0.01359769  0.02794081  0.01701977 -0.00143568]
#
# Debug: Returns for XLK, Forecast Period 46w: [-0.00590759  0.00076906 -0.00380067 -0.00380318 -0.02528781]
#
# Debug: Returns for XLK, Forecast Period 47w: [ 2.67197578e-03  7.60566292e-03 -1.40367735e-03  9.71708555e-03
#   7.50954088e-05]
#
# Debug: Returns for XLK, Forecast Period 48w: [-0.00054786  0.00451989 -0.01411457  0.00879328]
#
# Debug: Returns for VGT, Forecast Period 1w: [-0.02597463 -0.01327681 -0.00579561  0.00047018]
#
# Debug: Returns for VGT, Forecast Period 2w: [0.02570465 0.0020729  0.0087568  0.00374217 0.00248359]
#
# Debug: Returns for VGT, Forecast Period 3w: [ 0.00171296 -0.00522986  0.01969153  0.02204414]
#
# Debug: Returns for VGT, Forecast Period 4w: [ 0.00691928  0.0046619   0.00526555  0.00285692 -0.00994093]
#
# Debug: Returns for VGT, Forecast Period 5w: [ 0.01212177 -0.00923755 -0.02044189  0.01337611  0.01033518]
#
# Debug: Returns for VGT, Forecast Period 6w: [ 0.00105548 -0.00115135  0.01342923  0.00558841  0.01568298]
#
# Debug: Returns for VGT, Forecast Period 7w: [-0.00574521 -0.01916037  0.01380288 -0.0002656  -0.01017513]
#
# Debug: Returns for VGT, Forecast Period 8w: [-0.01151392 -0.00832453  0.03276451 -0.00308145]
#
# Debug: Returns for VGT, Forecast Period 9w: [ 0.00288042  0.00177084 -0.00439982  0.00978929  0.01901849]
#
# Debug: Returns for VGT, Forecast Period 10w: [ 0.00230415 -0.02371308  0.01145698  0.0172537  -0.01599764]
#
# Debug: Returns for VGT, Forecast Period 11w: [-0.00398523  0.02099987 -0.01028109 -0.00337443 -0.01283587]
#
# Debug: Returns for VGT, Forecast Period 12w: [0.00498309 0.00454736 0.0139634  0.00331787 0.00199146]
#
# Debug: Returns for VGT, Forecast Period 13w: [-0.00367089 -0.00401922  0.00273327 -0.00105672]
#
# Debug: Returns for VGT, Forecast Period 14w: [ 0.00236669 -0.01103077  0.00232542 -0.01584229  0.01240432]
#
# Debug: Returns for VGT, Forecast Period 15w: [-0.00118343  0.00258478 -0.00881626  0.01954273 -0.01752832]
#
# Debug: Returns for VGT, Forecast Period 16w: [-0.01884117  0.0008176  -0.01466235 -0.00933695 -0.02661142]
#
# Debug: Returns for VGT, Forecast Period 17w: [0.01359111 0.01641684 0.00163138 0.00048822 0.01727771]
#
# Debug: Returns for VGT, Forecast Period 18w: [ 0.00406631 -0.02209349 -0.01076612  0.0137651   0.02729885]
#
# Debug: Returns for VGT, Forecast Period 19w: [ 0.01479613 -0.00381419  0.00181205 -0.00068198  0.00287867]
#
# Debug: Returns for VGT, Forecast Period 20w: [ 0.00523252  0.01071413  0.02339653 -0.00364029 -0.00177668]
#
# Debug: Returns for VGT, Forecast Period 21w: [0.01348018 0.00167736 0.00088462 0.00069363 0.01041154]
#
# Debug: Returns for VGT, Forecast Period 22w: [ 0.0092743  -0.00283973 -0.02293077 -0.00023387]
#
# Debug: Returns for VGT, Forecast Period 23w: [ 0.00585555  0.00119259  0.02605586 -0.00222783  0.00051615]
#
# Debug: Returns for VGT, Forecast Period 24w: [0.00404636 0.01462773 0.02218982 0.01058151 0.00455311]
#
# Debug: Returns for VGT, Forecast Period 25w: [ 0.01298606  0.00480717 -0.01297982 -0.00449919]
#
# Debug: Returns for VGT, Forecast Period 26w: [-0.01779222  0.01493794  0.00255922  0.00253151  0.00019168]
#
# Debug: Returns for VGT, Forecast Period 27w: [0.01048656 0.00734645 0.01228744 0.00580629]
#
# Debug: Returns for VGT, Forecast Period 28w: [ 0.00737193 -0.00144157  0.01448531 -0.01858405  0.00992385]
#
# Debug: Returns for VGT, Forecast Period 29w: [ 0.00571586  0.00177922 -0.03564566 -0.00497751 -0.01163552]
#
# Debug: Returns for VGT, Forecast Period 30w: [ 0.02024226 -0.00149875 -0.03903756 -0.00929323  0.01198296]
#
# Debug: Returns for VGT, Forecast Period 31w: [-0.00351519 -0.01901321  0.03511401 -0.03617842 -0.02469394]
#
# Debug: Returns for VGT, Forecast Period 32w: [-0.03542931  0.00959794 -0.01200508  0.03432191  0.00625089]
#
# Debug: Returns for VGT, Forecast Period 33w: [0.00506306 0.02879743 0.00436464 0.02715277 0.00255991]
#
# Debug: Returns for VGT, Forecast Period 34w: [ 0.01434164 -0.00297375  0.00614631 -0.02039838  0.01846748]
#
# Debug: Returns for VGT, Forecast Period 35w: [-0.00893226  0.00519956 -0.01263187 -0.00230057  0.01098477]
#
# Debug: Returns for VGT, Forecast Period 36w: [-0.04363095 -0.00159263 -0.00173582 -0.02361452]
#
# Debug: Returns for VGT, Forecast Period 37w: [0.01385502 0.0105184  0.02925976 0.00813759 0.00634908]
#
# Debug: Returns for VGT, Forecast Period 38w: [-0.00550977 -0.00016425 -0.00438226  0.02997494 -0.00310531]
#
# Debug: Returns for VGT, Forecast Period 39w: [ 0.00011465  0.00952462  0.00118329  0.01288872 -0.00689683]
#
# Debug: Returns for VGT, Forecast Period 40w: [ 0.00315345 -0.02480511  0.00693388  0.0045739   0.01351608]
#
# Debug: Returns for VGT, Forecast Period 41w: [-0.00642993  0.01899947  0.01195685  0.00157941  0.00376192]
#
# Debug: Returns for VGT, Forecast Period 42w: [ 0.01307522 -0.01737353  0.00438003  0.00468034  0.00411015]
#
# Debug: Returns for VGT, Forecast Period 43w: [ 6.25956344e-03 -4.89001799e-05 -1.49530035e-02  3.94747522e-03
#   5.23672578e-03]
#
# Debug: Returns for VGT, Forecast Period 44w: [ 0.00256473  0.01235466 -0.01247284 -0.03284046  0.00759148]
#
# Debug: Returns for VGT, Forecast Period 45w: [-0.00059216  0.01494029  0.03178381  0.02099348 -0.00120655]
#
# Debug: Returns for VGT, Forecast Period 46w: [-0.00356685  0.00221699 -0.00354963 -0.00359825 -0.02397522]
#
# Debug: Returns for VGT, Forecast Period 47w: [0.00333712 0.01272679 0.0014752  0.01105031 0.00418717]
#
# Debug: Returns for VGT, Forecast Period 48w: [-7.95570432e-05  3.46698100e-03 -9.93477341e-03  9.36007746e-03]
#
# Debug: Returns for FTEC, Forecast Period 1w: [-0.02531379 -0.01028307 -0.00588785  0.00219661]
#
# Debug: Returns for FTEC, Forecast Period 2w: [0.02672399 0.00273394 0.01021695 0.0057928  0.00412478]
#
# Debug: Returns for FTEC, Forecast Period 3w: [ 0.00304846 -0.00382318  0.02126768  0.02376348]
#
# Debug: Returns for FTEC, Forecast Period 4w: [ 0.00796644  0.00544607  0.00607029  0.00394787 -0.00850275]
#
# Debug: Returns for FTEC, Forecast Period 5w: [ 0.01276957 -0.00689392 -0.02014674  0.0140505   0.01102114]
#
# Debug: Returns for FTEC, Forecast Period 6w: [ 0.00200149 -0.00154674  0.01426346  0.00674968  0.01601598]
#
# Debug: Returns for FTEC, Forecast Period 7w: [-0.00538824 -0.01810415  0.01428767 -0.00060287 -0.00887196]
#
# Debug: Returns for FTEC, Forecast Period 8w: [-0.00933595 -0.00717532  0.03442725 -0.00155202]
#
# Debug: Returns for FTEC, Forecast Period 9w: [ 0.00370461  0.00220285 -0.00237738  0.01078973  0.02055817]
#
# Debug: Returns for FTEC, Forecast Period 10w: [ 0.00214605 -0.021837    0.01224206  0.01830768 -0.0148383 ]
#
# Debug: Returns for FTEC, Forecast Period 11w: [-0.0027743   0.02200518 -0.00851493 -0.00223288 -0.01215602]
#
# Debug: Returns for FTEC, Forecast Period 12w: [0.0067281  0.00633259 0.0143224  0.00365197 0.00358451]
#
# Debug: Returns for FTEC, Forecast Period 13w: [-0.00254278 -0.00385608  0.00486068 -0.00031815]
#
# Debug: Returns for FTEC, Forecast Period 14w: [ 0.00203706 -0.00782366  0.00382463 -0.01420827  0.01372387]
#
# Debug: Returns for FTEC, Forecast Period 15w: [ 0.0004267   0.00554931 -0.00908913  0.0227631  -0.01602471]
#
# Debug: Returns for FTEC, Forecast Period 16w: [-0.0193106   0.0046505  -0.01402714 -0.00658244 -0.02443427]
#
# Debug: Returns for FTEC, Forecast Period 17w: [0.01474695 0.02053296 0.00462535 0.00422579 0.01856218]
#
# Debug: Returns for FTEC, Forecast Period 18w: [ 0.0049249  -0.01935252 -0.00917457  0.01717887  0.02812445]
#
# Debug: Returns for FTEC, Forecast Period 19w: [ 0.01785273 -0.00377081  0.0024971   0.00136574  0.00505676]
#
# Debug: Returns for FTEC, Forecast Period 20w: [ 0.00648665  0.01090434  0.02502642 -0.00266632 -0.00233211]
#
# Debug: Returns for FTEC, Forecast Period 21w: [0.01323811 0.00229381 0.00210949 0.00129564 0.0106356 ]
#
# Debug: Returns for FTEC, Forecast Period 22w: [ 0.01091339 -0.00409147 -0.02230735 -0.0010292 ]
#
# Debug: Returns for FTEC, Forecast Period 23w: [ 0.00775522  0.00305865  0.0278929  -0.00243016  0.00087058]
#
# Debug: Returns for FTEC, Forecast Period 24w: [0.00583639 0.01489687 0.02460682 0.0103114  0.00527433]
#
# Debug: Returns for FTEC, Forecast Period 25w: [ 0.01325016  0.0051531  -0.01184989 -0.00393565]
#
# Debug: Returns for FTEC, Forecast Period 26w: [-0.01676126  0.01566605  0.00503624  0.00369546  0.00013998]
#
# Debug: Returns for FTEC, Forecast Period 27w: [0.01085999 0.0082813  0.01239118 0.00630977]
#
# Debug: Returns for FTEC, Forecast Period 28w: [ 0.01014208 -0.00228764  0.01477418 -0.01908822  0.01255501]
#
# Debug: Returns for FTEC, Forecast Period 29w: [ 0.00631231  0.00324086 -0.03405645 -0.00279249 -0.00949547]
#
# Debug: Returns for FTEC, Forecast Period 30w: [ 0.02111994  0.00078885 -0.03654858 -0.00661975  0.01342925]
#
# Debug: Returns for FTEC, Forecast Period 31w: [-0.00135604 -0.01699956  0.03871619 -0.03245415 -0.02311829]
#
# Debug: Returns for FTEC, Forecast Period 32w: [-0.03064006  0.0133045  -0.00902063  0.03919814  0.00731247]
#
# Debug: Returns for FTEC, Forecast Period 33w: [0.00925046 0.03216031 0.00705286 0.02904065 0.00447774]
#
# Debug: Returns for FTEC, Forecast Period 34w: [ 0.01533654 -0.00160334  0.00829716 -0.01755117  0.01805678]
#
# Debug: Returns for FTEC, Forecast Period 35w: [-0.00883062  0.00663664 -0.01110938 -0.00140682  0.01122659]
#
# Debug: Returns for FTEC, Forecast Period 36w: [-0.04155198 -0.00164499  0.00013167 -0.02180923]
#
# Debug: Returns for FTEC, Forecast Period 37w: [0.01451527 0.01290335 0.030412   0.0096063  0.00836811]
#
# Debug: Returns for FTEC, Forecast Period 38w: [-0.00478092  0.00301451 -0.00353176  0.03313296 -0.00131288]
#
# Debug: Returns for FTEC, Forecast Period 39w: [ 0.00071174  0.00985271  0.00372612  0.01465794 -0.00607697]
#
# Debug: Returns for FTEC, Forecast Period 40w: [ 0.00533213 -0.02361017  0.00835901  0.00553031  0.01382151]
#
# Debug: Returns for FTEC, Forecast Period 41w: [-0.00537105  0.0186454   0.01264895  0.00324312  0.00486916]
#
# Debug: Returns for FTEC, Forecast Period 42w: [ 0.01385464 -0.01476293  0.0035926   0.00472116  0.00594608]
#
# Debug: Returns for FTEC, Forecast Period 43w: [ 0.00737067  0.00055518 -0.01280864  0.00542133  0.00741394]
#
# Debug: Returns for FTEC, Forecast Period 44w: [ 0.00298949  0.01501739 -0.01296414 -0.03092666  0.00990321]
#
# Debug: Returns for FTEC, Forecast Period 45w: [0.00095384 0.01677927 0.03296311 0.02260613 0.00065407]
#
# Debug: Returns for FTEC, Forecast Period 46w: [-0.00220734  0.00287707 -0.00235708 -0.00218168 -0.02151765]
#
# Debug: Returns for FTEC, Forecast Period 47w: [0.00478475 0.01450146 0.00262088 0.0127082  0.00529852]
#
# Debug: Returns for FTEC, Forecast Period 48w: [ 0.00192827  0.00507838 -0.00914781  0.01186229]
#
# Debug: Returns for IGM, Forecast Period 1w: [-0.02649239 -0.01202693 -0.00415826  0.00221379]
#
# Debug: Returns for IGM, Forecast Period 2w: [0.027678   0.00336611 0.00989    0.0054952  0.00179023]
#
# Debug: Returns for IGM, Forecast Period 3w: [ 0.00184106 -0.00572134  0.01754578  0.02506179]
#
# Debug: Returns for IGM, Forecast Period 4w: [ 0.00462638  0.00488582  0.00998399  0.0056415  -0.00898385]
#
# Debug: Returns for IGM, Forecast Period 5w: [ 0.01335021 -0.00735224 -0.02484283  0.01166696  0.02832434]
#
# Debug: Returns for IGM, Forecast Period 6w: [ 0.00164641 -0.00511799  0.01567848  0.0056758   0.01517145]
#
# Debug: Returns for IGM, Forecast Period 7w: [-0.00488007 -0.01802115  0.01774745 -0.00051619 -0.01203449]
#
# Debug: Returns for IGM, Forecast Period 8w: [-0.01431859 -0.01078595  0.04290273 -0.00243969]
#
# Debug: Returns for IGM, Forecast Period 9w: [ 0.00080818  0.0016451  -0.00715549  0.01240144  0.02129549]
#
# Debug: Returns for IGM, Forecast Period 10w: [ 0.00121835 -0.02037201  0.01222722  0.02098063 -0.01977142]
#
# Debug: Returns for IGM, Forecast Period 11w: [-0.00780474  0.02209699 -0.00951329 -0.00615756 -0.01483402]
#
# Debug: Returns for IGM, Forecast Period 12w: [0.01053841 0.00158713 0.01347896 0.00267405 0.003213  ]
#
# Debug: Returns for IGM, Forecast Period 13w: [-0.00502516 -0.0040731   0.00055555 -0.00209535]
#
# Debug: Returns for IGM, Forecast Period 14w: [ 0.00525947 -0.00795831  0.00359386 -0.01731178  0.01294609]
#
# Debug: Returns for IGM, Forecast Period 15w: [-0.00094054  0.00336524 -0.00955078  0.0171796  -0.01851078]
#
# Debug: Returns for IGM, Forecast Period 16w: [-0.02091298  0.00185191 -0.01372789 -0.00563047 -0.02857274]
#
# Debug: Returns for IGM, Forecast Period 17w: [ 0.00988466  0.01886936 -0.00022725 -0.01029567  0.0231261 ]
#
# Debug: Returns for IGM, Forecast Period 18w: [-0.00425542 -0.02025992 -0.00882493  0.01472586  0.02039912]
#
# Debug: Returns for IGM, Forecast Period 19w: [ 0.01587602 -0.00166647 -0.00129679 -0.00187308  0.0020557 ]
#
# Debug: Returns for IGM, Forecast Period 20w: [ 0.00121399  0.00859069  0.02338966 -0.00348415 -0.00105233]
#
# Debug: Returns for IGM, Forecast Period 21w: [ 0.01107313 -0.00079914  0.00140658 -0.00326561  0.00907297]
#
# Debug: Returns for IGM, Forecast Period 22w: [ 0.00830264 -0.0053597  -0.02467584 -0.00089176]
#
# Debug: Returns for IGM, Forecast Period 23w: [ 0.00465535  0.00222731  0.0261715  -0.00264953 -0.00151653]
#
# Debug: Returns for IGM, Forecast Period 24w: [0.00583356 0.01039026 0.01851814 0.00506667 0.00638859]
#
# Debug: Returns for IGM, Forecast Period 25w: [ 0.0102459   0.00287977 -0.009793   -0.00380717]
#
# Debug: Returns for IGM, Forecast Period 26w: [-0.0148582   0.01492257  0.00039431  0.00530126 -0.00344848]
#
# Debug: Returns for IGM, Forecast Period 27w: [0.00665271 0.007398   0.0094835  0.01155307]
#
# Debug: Returns for IGM, Forecast Period 28w: [ 0.0027897  -0.00291627  0.01092039 -0.02216295  0.00565358]
#
# Debug: Returns for IGM, Forecast Period 29w: [ 0.00517325 -0.00047601 -0.03781544 -0.00408547 -0.01118434]
#
# Debug: Returns for IGM, Forecast Period 30w: [ 0.01914467 -0.00217514 -0.04009559 -0.01033935  0.01147324]
#
# Debug: Returns for IGM, Forecast Period 31w: [-0.00421936 -0.0165881   0.03072071 -0.02692822 -0.03060177]
#
# Debug: Returns for IGM, Forecast Period 32w: [-0.03265821  0.01059386 -0.01081763  0.03447831  0.00596348]
#
# Debug: Returns for IGM, Forecast Period 33w: [-0.00015348  0.0250523  -0.00017506  0.02491507 -0.00011642]
#
# Debug: Returns for IGM, Forecast Period 34w: [ 0.01233454 -0.00242292  0.00552548 -0.01840942  0.01234438]
#
# Debug: Returns for IGM, Forecast Period 35w: [-0.01026807  0.00342014 -0.01336337 -0.00081078  0.01019243]
#
# Debug: Returns for IGM, Forecast Period 36w: [-0.03918229 -0.00235175 -0.00032272 -0.02722797]
#
# Debug: Returns for IGM, Forecast Period 37w: [0.010058   0.00927124 0.0241535  0.00919959 0.00602435]
#
# Debug: Returns for IGM, Forecast Period 38w: [-0.00223191  0.00035874 -0.00545192  0.02863575 -0.00182837]
#
# Debug: Returns for IGM, Forecast Period 39w: [ 0.00029222  0.00582954  0.00064943  0.01139675 -0.00723886]
#
# Debug: Returns for IGM, Forecast Period 40w: [ 0.00301436 -0.01862237  0.00500296  0.00481318  0.01337881]
#
# Debug: Returns for IGM, Forecast Period 41w: [-0.00998892  0.01713897  0.00814451 -0.00038573  0.0038265 ]
#
# Debug: Returns for IGM, Forecast Period 42w: [ 0.00985608 -0.01719097 -0.0003529   0.00055472  0.00496356]
#
# Debug: Returns for IGM, Forecast Period 43w: [ 3.09907802e-03 -5.86883488e-05 -1.60754119e-02  2.81613859e-03
#   5.93039109e-03]
#
# Debug: Returns for IGM, Forecast Period 44w: [ 0.00231389  0.01525788 -0.01096516 -0.02905156  0.00568068]
#
# Debug: Returns for IGM, Forecast Period 45w: [-0.00333757  0.01390396  0.02936379  0.0215046  -0.00246939]
#
# Debug: Returns for IGM, Forecast Period 46w: [-0.00227445  0.00318807 -0.00433339 -0.00725881 -0.02494899]
#
# Debug: Returns for IGM, Forecast Period 47w: [ 5.28738558e-03  1.07480547e-02 -8.68366013e-05  5.97243323e-03
#   5.70347118e-04]
#
# Debug: Returns for IGM, Forecast Period 48w: [ 0.00217903  0.00297019 -0.01094016  0.00835357]
#
# Debug: Returns for IXN, Forecast Period 1w: [-2.72962277e-02 -1.16897177e-02 -5.72561275e-03  5.49354299e-05]
#
# Debug: Returns for IXN, Forecast Period 2w: [ 0.02501415 -0.00072199  0.00879246  0.00407462  0.00396639]
#
# Debug: Returns for IXN, Forecast Period 3w: [-3.42495501e-05 -5.29635037e-03  2.14169900e-02  2.30064672e-02]
#
# Debug: Returns for IXN, Forecast Period 4w: [ 0.00451244  0.00418838  0.00814609  0.00494257 -0.00927751]
#
# Debug: Returns for IXN, Forecast Period 5w: [ 0.00890811 -0.00729671 -0.01943985  0.01334713  0.01071347]
#
# Debug: Returns for IXN, Forecast Period 6w: [ 0.00300976 -0.00209424  0.01379748  0.00543334  0.01191422]
#
# Debug: Returns for IXN, Forecast Period 7w: [-0.00798967 -0.01742725  0.01203199 -0.00030699 -0.00869848]
#
# Debug: Returns for IXN, Forecast Period 8w: [-0.00978978 -0.00575803  0.03235428  0.00020332]
#
# Debug: Returns for IXN, Forecast Period 9w: [ 0.00089396 -0.00092981 -0.004214    0.00961767  0.01888154]
#
# Debug: Returns for IXN, Forecast Period 10w: [ 0.00218617 -0.02223486  0.01089352  0.01745347 -0.01429633]
#
# Debug: Returns for IXN, Forecast Period 11w: [-0.00656528  0.02174212 -0.00958081 -0.00039458 -0.01491235]
#
# Debug: Returns for IXN, Forecast Period 12w: [0.0060984  0.00420366 0.0148793  0.00275099 0.00254748]
#
# Debug: Returns for IXN, Forecast Period 13w: [-0.00565961 -0.00476572  0.00222763 -0.00163518]
#
# Debug: Returns for IXN, Forecast Period 14w: [ 0.00329028 -0.00801254  0.00213541 -0.01639929  0.01188534]
#
# Debug: Returns for IXN, Forecast Period 15w: [-0.002089    0.00478631 -0.01138226  0.02084314 -0.01796172]
#
# Debug: Returns for IXN, Forecast Period 16w: [-0.01836755  0.00173281 -0.01761933 -0.01022418 -0.02692997]
#
# Debug: Returns for IXN, Forecast Period 17w: [ 0.00915711  0.01599684  0.00448879 -0.00148697  0.01465953]
#
# Debug: Returns for IXN, Forecast Period 18w: [ 0.00336134 -0.02209505 -0.00946164  0.01443461  0.02815597]
#
# Debug: Returns for IXN, Forecast Period 19w: [ 0.01380119 -0.00336307  0.00263183 -0.00256254  0.00349094]
#
# Debug: Returns for IXN, Forecast Period 20w: [ 0.00349797  0.01077846  0.0219894  -0.00390889 -0.00352979]
#
# ...
# Sharpe: -0.4290352539140878, Sortino: nan, Volatility Clustering: 0.12184869210696754
# Final Composite Score: nan
# Calculated Score for IYW (47w): nan
#
# Debug: ETF = XLK, Forecast Period = 47w
# Forecasted Values Mean: 0.0037332284603600677
# Rachev Ratio: 6.922591952507086, Sharpe Ratio: 12.43625620699621
# Sortino Ratio: 5.947059410714523, Volatility Clustering: -0.7466023293511905
# Means and Stds: Mean Forecast = 0.006038519063912981, Std Forecast = 0.00376679930567386
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0037332284603600677, Risk Percentage: 0.1
# Rachev Ratio: 6.922591952507086, Sharpe Ratio: 12.43625620699621
# Sortino Ratio: 5.947059410714523, Volatility Clustering: -0.7466023293511905
# Normalized Values -> Forecasted Mean: -0.6120008783243968, Rachev: 0.353873580413783
# Sharpe: -0.35062046944851744, Sortino: nan, Volatility Clustering: -0.8945251945280386
# Final Composite Score: nan
# Calculated Score for XLK (47w): nan
#
# Debug: ETF = VGT, Forecast Period = 47w
# Forecasted Values Mean: 0.006555316974152725
# Rachev Ratio: -8.62716612623785, Sharpe Ratio: 21.919215439488696
# Sortino Ratio: inf, Volatility Clustering: -0.8017229783578729
# Means and Stds: Mean Forecast = 0.006038519063912981, Std Forecast = 0.00376679930567386
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.006555316974152725, Risk Percentage: 0.1
# Rachev Ratio: -8.62716612623785, Sharpe Ratio: 21.919215439488696
# Sortino Ratio: inf, Volatility Clustering: -0.8017229783578729
# Normalized Values -> Forecasted Mean: 0.13719778950882994, Rachev: 0.2523416948987413
# Sharpe: 0.9546971963086316, Sortino: nan, Volatility Clustering: -1.084337426543304
# Final Composite Score: nan
# Calculated Score for VGT (47w): nan
#
# Debug: ETF = FTEC, Forecast Period = 47w
# Forecasted Values Mean: 0.007982762437362798
# Rachev Ratio: -5.533045627755414, Sharpe Ratio: 25.62019562597783
# Sortino Ratio: inf, Volatility Clustering: -0.8063059969126678
# Means and Stds: Mean Forecast = 0.006038519063912981, Std Forecast = 0.00376679930567386
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.007982762437362798, Risk Percentage: 0.1
# Rachev Ratio: -5.533045627755414, Sharpe Ratio: 25.62019562597783
# Sortino Ratio: inf, Volatility Clustering: -0.8063059969126678
# Normalized Values -> Forecasted Mean: 0.5161512611008068, Rachev: 0.27254470298611977
# Sharpe: 1.4641325634341837, Sortino: nan, Volatility Clustering: -1.1001194065622173
# Final Composite Score: nan
# Calculated Score for FTEC (47w): nan
#
# Debug: ETF = IGM, Forecast Period = 47w
# Forecasted Values Mean: 0.004498276807584715
# Rachev Ratio: 123.77332305097369, Sharpe Ratio: 16.526463243632087
# Sortino Ratio: 115.83194842473988, Volatility Clustering: -0.3878371900173482
# Means and Stds: Mean Forecast = 0.006038519063912981, Std Forecast = 0.00376679930567386
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.004498276807584715, Risk Percentage: 0.1
# Rachev Ratio: 123.77332305097369, Sharpe Ratio: 16.526463243632087
# Sortino Ratio: 115.83194842473988, Volatility Clustering: -0.3878371900173482
# Normalized Values -> Forecasted Mean: -0.4088983888853183, Rachev: 1.1168484763676636
# Sharpe: 0.21239149449954525, Sortino: nan, Volatility Clustering: 0.3409104016306477
# Final Composite Score: nan
# Calculated Score for IGM (47w): nan
#
# Debug: ETF = IXN, Forecast Period = 47w
# Forecasted Values Mean: 0.0037464843946919965
# Rachev Ratio: 3.8417694217933445, Sharpe Ratio: 17.004307364412043
# Sortino Ratio: 4.5079631795239035, Volatility Clustering: -0.6979272395549891
# Means and Stds: Mean Forecast = 0.006038519063912981, Std Forecast = 0.00376679930567386
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0037464843946919965, Risk Percentage: 0.1
# Rachev Ratio: 3.8417694217933445, Sharpe Ratio: 17.004307364412043
# Sortino Ratio: 4.5079631795239035, Volatility Clustering: -0.6979272395549891
# Normalized Values -> Forecasted Mean: -0.6084817369885288, Rachev: 0.33375740118472097
# Sharpe: 0.27816614954552366, Sortino: nan, Volatility Clustering: -0.7269087458058839
# Final Composite Score: nan
# Calculated Score for IXN (47w): nan
# Scores calculated for 47w:
# {'ETF': 'SMH', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'SOXX', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'PSI', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'XSD', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'IYW', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'XLK', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'VGT', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'FTEC', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'IGM', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
# {'ETF': 'IXN', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': nan}
#
# Debug: Forecast Period = 48w
# All Returns Means: [-0.005665640807020625, -0.002080742943960279, 0.0020513682202549224, 0.0069357538397678276, -3.2706164293221356e-05, -0.0003373133902039786, 0.0007031820016997056, 0.002430284741912559, 0.0006406582038868758, 0.0013170873116056094]
# Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
# All Rachev Ratios: [0.79703386 0.82206958 1.15663951 2.76671296 0.66609809 0.62299345
#  0.94215309 1.29673598 0.76356933 0.93706959]
# All Sharpe Ratios: [-8.41885639 -3.11255462  1.70926846  5.47797274 -0.83744951 -1.31873016
#   0.73611945  4.29318644  0.58697532  1.93136495]
# All Sortino Ratios: [-0.52049005 -0.20215091  0.21063663  0.85233791 -0.00525475 -0.04776052
#   0.14155521  0.53133717  0.11712041  0.23950949]
# All Volatility Clustering: [ 0.05295702 -0.14505248  0.14983056 -0.14681938 -0.04481732 -0.09865414
#   0.24394652  0.26847124  0.03895182  0.21659544]
# Mean Rachev = 1.0771075432986899, Std Rachev = 0.5970001696610431
# Mean Sharpe = 0.10472966783006385, Std Sharpe = 3.726575415726984
# Mean Sortino = 0.13168405733415178, Std Sortino = 0.3584638624740276
# Mean Volatility Clustering = 0.05354092936116317, Std Volatility Clustering = 0.15196784402584262
#
# Debug: ETF = SMH, Forecast Period = 48w
# Forecasted Values Mean: -0.005665640807020625
# Rachev Ratio: 0.7970338566183719, Sharpe Ratio: -8.418856386366132
# Sortino Ratio: -0.5204900516501237, Volatility Clustering: 0.05295701874090535
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.005665640807020625, Risk Percentage: 0.1
# Rachev Ratio: 0.7970338566183719, Sharpe Ratio: -8.418856386366132
# Sortino Ratio: -0.5204900516501237, Volatility Clustering: 0.05295701874090535
# Normalized Values -> Forecasted Mean: -2.044030900661198, Rachev: -0.46913501238698874
# Sharpe: -2.287243670248109, Sortino: -1.819357985738238, Volatility Clustering: -0.0038423298400892167
# Final Composite Score: -6.099876725568756
# Calculated Score for SMH (48w): -6.099876725568756
#
# Debug: ETF = SOXX, Forecast Period = 48w
# Forecasted Values Mean: -0.002080742943960279
# Rachev Ratio: 0.8220695755409602, Sharpe Ratio: -3.1125546245336544
# Sortino Ratio: -0.20215091412595218, Volatility Clustering: -0.1450524809464362
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.002080742943960279, Risk Percentage: 0.1
# Rachev Ratio: 0.8220695755409602, Sharpe Ratio: -3.1125546245336544
# Sortino Ratio: -0.20215091412595218, Volatility Clustering: -0.1450524809464362
# Normalized Values -> Forecasted Mean: -0.8738238790414138, Rachev: -0.42719914741488313
# Sharpe: -0.863335348092703, Sortino: -0.931293212774997, Volatility Clustering: -1.3068119674429826
# Final Composite Score: -1.318920557724643
# Calculated Score for SOXX (48w): -1.318920557724643
#
# Debug: ETF = PSI, Forecast Period = 48w
# Forecasted Values Mean: 0.0020513682202549224
# Rachev Ratio: 1.1566395115548143, Sharpe Ratio: 1.7092684593832173
# Sortino Ratio: 0.21063662800125063, Volatility Clustering: 0.14983056389538882
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0020513682202549224, Risk Percentage: 0.1
# Rachev Ratio: 1.1566395115548143, Sharpe Ratio: 1.7092684593832173
# Sortino Ratio: 0.21063662800125063, Volatility Clustering: 0.14983056389538882
# Normalized Values -> Forecasted Mean: 0.4750082727204316, Rachev: 0.13321933722244442
# Sharpe: 0.43056656802810817, Sortino: 0.22025251839798538, Volatility Clustering: 0.6336184395803292
# Final Composite Score: 0.4788869858439516
# Calculated Score for PSI (48w): 0.4788869858439516
#
# Debug: ETF = XSD, Forecast Period = 48w
# Forecasted Values Mean: 0.0069357538397678276
# Rachev Ratio: 2.7667129632029326, Sharpe Ratio: 5.477972741603252
# Sortino Ratio: 0.8523379123421505, Volatility Clustering: -0.14681937829468858
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0069357538397678276, Risk Percentage: 0.1
# Rachev Ratio: 2.7667129632029326, Sharpe Ratio: 5.477972741603252
# Sortino Ratio: 0.8523379123421505, Volatility Clustering: -0.14681937829468858
# Normalized Values -> Forecasted Mean: 2.0694030272123487, Rachev: 2.83015898062802
# Sharpe: 1.4418715469109205, Sortino: 2.0103946599533917, Volatility Clustering: -1.318438751012302
# Final Composite Score: 6.55709208702616
# Calculated Score for XSD (48w): 6.55709208702616
#
# Debug: ETF = IYW, Forecast Period = 48w
# Forecasted Values Mean: -3.2706164293221356e-05
# Rachev Ratio: 0.6660980856301285, Sharpe Ratio: -0.8374495051279301
# Sortino Ratio: -0.005254750433708174, Volatility Clustering: -0.04481731514778581
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: -3.2706164293221356e-05, Risk Percentage: 0.1
# Rachev Ratio: 0.6660980856301285, Sharpe Ratio: -0.8374495051279301
# Sortino Ratio: -0.005254750433708174, Volatility Clustering: -0.04481731514778581
# Normalized Values -> Forecasted Mean: -0.20528962460772832, Rachev: -0.6884578458618201
# Sharpe: -0.25282707722846987, Sortino: -0.38201564588013487, Volatility Clustering: -0.6472305945191728
# Final Composite Score: -0.12405596861097834
# Calculated Score for IYW (48w): -0.12405596861097834
#
# Debug: ETF = XLK, Forecast Period = 48w
# Forecasted Values Mean: -0.0003373133902039786
# Rachev Ratio: 0.6229934484911783, Sharpe Ratio: -1.318730163171469
# Sortino Ratio: -0.04776051996993763, Volatility Clustering: -0.0986541360672275
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.0003373133902039786, Risk Percentage: 0.1
# Rachev Ratio: 0.6229934484911783, Sharpe Ratio: -1.318730163171469
# Sortino Ratio: -0.04776051996993763, Volatility Clustering: -0.0986541360672275
# Normalized Values -> Forecasted Mean: -0.3047216107376192, Rachev: -0.7606598963928997
# Sharpe: -0.3819753173850876, Sortino: -0.5005932008311131, Volatility Clustering: -1.0014951280585263
# Final Composite Score: -0.10972901125600387
# Calculated Score for XLK (48w): -0.10972901125600387
#
# Debug: ETF = VGT, Forecast Period = 48w
# Forecasted Values Mean: 0.0007031820016997056
# Rachev Ratio: 0.9421530897022568, Sharpe Ratio: 0.7361194546679656
# Sortino Ratio: 0.14155520762671758, Volatility Clustering: 0.24394651896284372
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0007031820016997056, Risk Percentage: 0.1
# Rachev Ratio: 0.9421530897022568, Sharpe Ratio: 0.7361194546679656
# Sortino Ratio: 0.14155520762671758, Volatility Clustering: 0.24394651896284372
# Normalized Values -> Forecasted Mean: 0.034924052843235694, Rachev: -0.22605429310432662
# Sharpe: 0.16942895680549108, Sortino: 0.02753736443351348, Volatility Clustering: 1.2529333313432292
# Final Composite Score: -0.9984375279505562
# Calculated Score for VGT (48w): -0.9984375279505562
#
# Debug: ETF = FTEC, Forecast Period = 48w
# Forecasted Values Mean: 0.002430284741912559
# Rachev Ratio: 1.2967359821755986, Sharpe Ratio: 4.293186440643864
# Sortino Ratio: 0.5313371653275595, Volatility Clustering: 0.2684712402902944
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.002430284741912559, Risk Percentage: 0.1
# Rachev Ratio: 1.2967359821755986, Sharpe Ratio: 4.293186440643864
# Sortino Ratio: 0.5313371653275595, Volatility Clustering: 0.2684712402902944
# Normalized Values -> Forecasted Mean: 0.5986968103550804, Rachev: 0.36788672157788377
# Sharpe: 1.1239425730922143, Sortino: 1.1149048444829386, Volatility Clustering: 1.4143143121082808
# Final Composite Score: 1.3864412436641638
# Calculated Score for FTEC (48w): 1.3864412436641638
#
# Debug: ETF = IGM, Forecast Period = 48w
# Forecasted Values Mean: 0.0006406582038868758
# Rachev Ratio: 0.7635693265641051, Sharpe Ratio: 0.5869753161568191
# Sortino Ratio: 0.11712040765715626, Volatility Clustering: 0.038951818780023455
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0006406582038868758, Risk Percentage: 0.1
# Rachev Ratio: 0.7635693265641051, Sharpe Ratio: 0.5869753161568191
# Sortino Ratio: 0.11712040765715626, Volatility Clustering: 0.038951818780023455
# Normalized Values -> Forecasted Mean: 0.014514604648678453, Rachev: -0.5251894847210955
# Sharpe: 0.12940718843297752, Sortino: -0.040627942717018806, Volatility Clustering: -0.09600129365950506
# Final Composite Score: 0.2518140924962518
# Calculated Score for IGM (48w): 0.2518140924962518
#
# Debug: ETF = IXN, Forecast Period = 48w
# Forecasted Values Mean: 0.0013170873116056094
# Rachev Ratio: 0.9370695935065508, Sharpe Ratio: 1.9313649450447055
# Sortino Ratio: 0.23950948856640514, Volatility Clustering: 0.216595443398314
# Means and Stds: Mean Forecast = 0.0005961931013649397, Std Forecast = 0.0030634632118580027
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0013170873116056094, Risk Percentage: 0.1
# Rachev Ratio: 0.9370695935065508, Sharpe Ratio: 1.9313649450447055
# Sortino Ratio: 0.23950948856640514, Volatility Clustering: 0.216595443398314
# Normalized Values -> Forecasted Mean: 0.2353192472681835, Rachev: -0.234569359546337
# Sharpe: 0.49016457968465776, Sortino: 0.30079860067367264, Volatility Clustering: 1.0729539815007383
# Final Composite Score: -0.023214617919590674
# Calculated Score for IXN (48w): -0.023214617919590674
# Scores calculated for 48w:
# {'ETF': 'SMH', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -6.099876725568756}
# {'ETF': 'SOXX', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -1.318920557724643}
# {'ETF': 'PSI', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 0.4788869858439516}
# {'ETF': 'XSD', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 6.55709208702616}
# {'ETF': 'IYW', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.12405596861097834}
# {'ETF': 'XLK', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.10972901125600387}
# {'ETF': 'VGT', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.9984375279505562}
# {'ETF': 'FTEC', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 1.3864412436641638}
# {'ETF': 'IGM', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 0.2518140924962518}
# {'ETF': 'IXN', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.023214617919590674}
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_32548/1341513019.py:90: RuntimeWarning: divide by zero encountered in scalar divide
#   sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
# /Users/pranavsrinivasvenkatesh/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_32548/4081099987.py:19: RuntimeWarning: invalid value encountered in scalar subtract
#   sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)

# %%
# Initialize an empty dictionary to hold DataFrames for each week
weekly_scores_dfs = {}

# Assuming weekly_scores is a dictionary with keys as week identifiers ('1w', '2w', ..., '48w') 
# and values as the respective scores
for week_key, scores in weekly_scores.items():
    # Convert scores for the current week into a DataFrame
    weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    
# Create DataFrame variables dynamically for 48 weeks
for week in range(1, 49):
    week_key = f'{week}w'
    globals()[f'df_scores_{week_key}'] = weekly_scores_dfs.get(week_key, pd.DataFrame())

# %%
# Initialize a dictionary to hold the top 2 ETFs for each week
top_etfs_weekly = {}

# Loop through the weekly DataFrames and select the top 2 ETFs for each week
for week_key, df_scores in weekly_scores_dfs.items():
    # Select the top 2 ETFs based on the 'Score' column
    top_etfs_weekly[week_key] = df_scores.nlargest(2, 'Score')
    
    # Print the results for the current week
    print(f"\nTop 2 ETFs for {week_key} forecast:")
    print(top_etfs_weekly[week_key])
# Out:
# Top 2 ETFs for 1w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   1w             0.1  3.689738
# 8   IGM   1w             0.1  3.670090
#
# Top 2 ETFs for 2w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH   2w             0.1    NaN
# 1  SOXX   2w             0.1    NaN
#
# Top 2 ETFs for 3w forecast:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  5.630022
# 1  SOXX   3w             0.1  2.999985
#
# Top 2 ETFs for 4w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM   4w             0.1  4.862167
# 7  FTEC   4w             0.1  4.483061
#
# Top 2 ETFs for 5w forecast:
#    ETF Week  RiskPercentage     Score
# 8  IGM   5w             0.1  4.665209
# 0  SMH   5w             0.1  3.093095
#
# Top 2 ETFs for 6w forecast:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  2.406587
# 7  FTEC   6w             0.1  2.319029
#
# Top 2 ETFs for 7w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI   7w             0.1  5.606255
# 1  SOXX   7w             0.1  1.516837
#
# Top 2 ETFs for 8w forecast:
#    ETF Week  RiskPercentage     Score
# 0  SMH   8w             0.1  3.470734
# 9  IXN   8w             0.1  2.770994
#
# Top 2 ETFs for 9w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI   9w             0.1  7.988909
# 7  FTEC   9w             0.1  2.020769
#
# Top 2 ETFs for 10w forecast:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  3.982058
# 1  SOXX  10w             0.1  1.934335
#
# Top 2 ETFs for 11w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  11w             0.1  4.176206
# 4   IYW  11w             0.1  3.205912
#
# Top 2 ETFs for 12w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  12w             0.1    NaN
# 1  SOXX  12w             0.1    NaN
#
# Top 2 ETFs for 13w forecast:
#    ETF Week  RiskPercentage     Score
# 3  XSD  13w             0.1  7.811311
# 2  PSI  13w             0.1  3.184629
#
# Top 2 ETFs for 14w forecast:
#    ETF Week  RiskPercentage     Score
# 2  PSI  14w             0.1  4.716999
# 8  IGM  14w             0.1  2.142797
#
# Top 2 ETFs for 15w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  15w             0.1  7.195694
# 4   IYW  15w             0.1  1.222992
#
# Top 2 ETFs for 16w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  16w             0.1  4.039720
# 8   IGM  16w             0.1  2.279101
#
# Top 2 ETFs for 17w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  17w             0.1    NaN
# 1  SOXX  17w             0.1    NaN
#
# Top 2 ETFs for 18w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  18w             0.1  4.561377
# 9   IXN  18w             0.1  2.796207
#
# Top 2 ETFs for 19w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  19w             0.1  5.972657
# 2   PSI  19w             0.1  4.952542
#
# Top 2 ETFs for 20w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  20w             0.1  4.260661
# 6   VGT  20w             0.1  2.262267
#
# Top 2 ETFs for 21w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  21w             0.1    NaN
# 1  SOXX  21w             0.1    NaN
#
# Top 2 ETFs for 22w forecast:
#     ETF Week  RiskPercentage    Score
# 3   XSD  22w             0.1  6.88718
# 7  FTEC  22w             0.1  0.88945
#
# Top 2 ETFs for 23w forecast:
#     ETF Week  RiskPercentage     Score
# 9   IXN  23w             0.1  6.239764
# 7  FTEC  23w             0.1  2.773589
#
# Top 2 ETFs for 24w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  24w             0.1    NaN
# 1  SOXX  24w             0.1    NaN
#
# Top 2 ETFs for 25w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  25w             0.1  3.225875
# 5   XLK  25w             0.1  2.875750
#
# Top 2 ETFs for 26w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI  26w             0.1  4.243530
# 7  FTEC  26w             0.1  2.638395
#
# Top 2 ETFs for 27w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  27w             0.1    NaN
# 1  SOXX  27w             0.1    NaN
#
# Top 2 ETFs for 28w forecast:
#    ETF Week  RiskPercentage     Score
# 3  XSD  28w             0.1  9.750974
# 2  PSI  28w             0.1  1.128033
#
# Top 2 ETFs for 29w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  29w             0.1  4.745920
# 7  FTEC  29w             0.1  3.079117
#
# Top 2 ETFs for 30w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  30w             0.1  7.735650
# 3   XSD  30w             0.1  2.942913
#
# Top 2 ETFs for 31w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  31w             0.1  6.464473
# 9   IXN  31w             0.1  3.823469
#
# Top 2 ETFs for 32w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI  32w             0.1  6.596728
# 7  FTEC  32w             0.1  3.582929
#
# Top 2 ETFs for 33w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  33w             0.1    NaN
# 1  SOXX  33w             0.1    NaN
#
# Top 2 ETFs for 34w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  34w             0.1  4.344034
# 3   XSD  34w             0.1  2.317444
#
# Top 2 ETFs for 35w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  35w             0.1  5.569125
# 7  FTEC  35w             0.1  3.178197
#
# Top 2 ETFs for 36w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  36w             0.1  2.082193
# 8   IGM  36w             0.1  2.006703
#
# Top 2 ETFs for 37w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  37w             0.1    NaN
# 1  SOXX  37w             0.1    NaN
#
# Top 2 ETFs for 38w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  38w             0.1  6.251244
# 8   IGM  38w             0.1  3.743500
#
# Top 2 ETFs for 39w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  39w             0.1  5.789379
# 7  FTEC  39w             0.1  3.435958
#
# Top 2 ETFs for 40w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM  40w             0.1  5.777533
# 7  FTEC  40w             0.1  5.147580
#
# Top 2 ETFs for 41w forecast:
#    ETF Week  RiskPercentage     Score
# 2  PSI  41w             0.1  8.016191
# 0  SMH  41w             0.1  3.190669
#
# Top 2 ETFs for 42w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  42w             0.1  3.199555
# 6   VGT  42w             0.1  2.208202
#
# Top 2 ETFs for 43w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  43w             0.1  7.733907
# 3   XSD  43w             0.1  2.362027
#
# Top 2 ETFs for 44w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  44w             0.1  5.268138
# 8   IGM  44w             0.1  4.960828
#
# Top 2 ETFs for 45w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  45w             0.1    NaN
# 1  SOXX  45w             0.1    NaN
#
# Top 2 ETFs for 46w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  46w             0.1  2.549998
# 6   VGT  46w             0.1  1.636878
#
# Top 2 ETFs for 47w forecast:
#     ETF Week  RiskPercentage  Score
# 0   SMH  47w             0.1    NaN
# 1  SOXX  47w             0.1    NaN
#
# Top 2 ETFs for 48w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  48w             0.1  6.557092
# 7  FTEC  48w             0.1  1.386441

# %%
def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()

# %%
# Function to generate week ranges
def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []
    
    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)
    
    return week_ranges

# Function to gather ETF data for weeks
def gather_etf_data_for_weeks(tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date)
            if etf_data.empty:
                print(f"No data found for {ticker} in {week}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[week][ticker] = etf_data
            #print(f"Data for {ticker} in {week} gathered.")
    return etf_histories

# Function to initialize shares for the first week
def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]
    
    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)
        
        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]
            
            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st week: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares

# Function to manage ETF portfolio weekly
def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

# %%
# Generate Week Ranges
week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')
#print("Generated Week Ranges:", week_ranges)

# Assuming `tickers` is a list of ETF tickers
tickers = tickers

# Gather ETF Data
etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)
#print(f"ETF Histories Collected for {len(etf_histories)} weeks")

# Create a mapping between week numbers and date ranges
week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

# Debug: Print the week key mapping
print("Week Key Mapping:", week_key_mapping)

# Align `top_etfs_weekly` Keys with `etf_histories`
aligned_top_etfs_weekly = {}

for week_key, df_scores in weekly_scores_dfs.items():
    # Call the `select_top_etfs_weekly` function here
    forecast_period = week_key_mapping.get(week_key, None)
    if forecast_period:
        aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

# Portfolio initialization and management
ticker_shares = {}
ticker_shares_per_week = {}

for i, week_range in enumerate(etf_histories.keys()):
    current_week_key = week_range
    if i == 0:
        # First week initialization
        ticker_shares = initialize_shares_for_first_week(
            aligned_top_etfs_weekly[current_week_key],
            etf_histories,
            current_week_key
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()
    else:
        # Subsequent weeks' portfolio management
        prev_week_key = list(etf_histories.keys())[i - 1]
        ticker_shares = manage_etf_portfolio_weekly(
            aligned_top_etfs_weekly[prev_week_key],
            aligned_top_etfs_weekly[current_week_key],
            prev_week_key,
            current_week_key,
            ticker_shares,
            etf_histories
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()

print("\nFinal Ticker Shares per Week:")
for week, shares in ticker_shares_per_week.items():
    print(f"Week {week}: {shares}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Week Key Mapping: {'1w': '2024-01-01 to 2024-01-07', '2w': '2024-01-08 to 2024-01-14', '3w': '2024-01-15 to 2024-01-21', '4w': '2024-01-22 to 2024-01-28', '5w': '2024-01-29 to 2024-02-04', '6w': '2024-02-05 to 2024-02-11', '7w': '2024-02-12 to 2024-02-18', '8w': '2024-02-19 to 2024-02-25', '9w': '2024-02-26 to 2024-03-03', '10w': '2024-03-04 to 2024-03-10', '11w': '2024-03-11 to 2024-03-17', '12w': '2024-03-18 to 2024-03-24', '13w': '2024-03-25 to 2024-03-31', '14w': '2024-04-01 to 2024-04-07', '15w': '2024-04-08 to 2024-04-14', '16w': '2024-04-15 to 2024-04-21', '17w': '2024-04-22 to 2024-04-28', '18w': '2024-04-29 to 2024-05-05', '19w': '2024-05-06 to 2024-05-12', '20w': '2024-05-13 to 2024-05-19', '21w': '2024-05-20 to 2024-05-26', '22w': '2024-05-27 to 2024-06-02', '23w': '2024-06-03 to 2024-06-09', '24w': '2024-06-10 to 2024-06-16', '25w': '2024-06-17 to 2024-06-23', '26w': '2024-06-24 to 2024-06-30', '27w': '2024-07-01 to 2024-07-07', '28w': '2024-07-08 to 2024-07-14', '29w': '2024-07-15 to 2024-07-21', '30w': '2024-07-22 to 2024-07-28', '31w': '2024-07-29 to 2024-08-04', '32w': '2024-08-05 to 2024-08-11', '33w': '2024-08-12 to 2024-08-18', '34w': '2024-08-19 to 2024-08-25', '35w': '2024-08-26 to 2024-09-01', '36w': '2024-09-02 to 2024-09-08', '37w': '2024-09-09 to 2024-09-15', '38w': '2024-09-16 to 2024-09-22', '39w': '2024-09-23 to 2024-09-29', '40w': '2024-09-30 to 2024-10-06', '41w': '2024-10-07 to 2024-10-13', '42w': '2024-10-14 to 2024-10-20', '43w': '2024-10-21 to 2024-10-27', '44w': '2024-10-28 to 2024-11-03', '45w': '2024-11-04 to 2024-11-10', '46w': '2024-11-11 to 2024-11-17', '47w': '2024-11-18 to 2024-11-24', '48w': '2024-11-25 to 2024-12-01'}
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1  1.523621
# 1  SOXX   1w             0.1 -0.336284
# 2   PSI   1w             0.1 -5.294914
# 3   XSD   1w             0.1 -7.641737
# 4   IYW   1w             0.1  2.044199
# Top ETFs for 2024-01-01 to 2024-01-07: ['FTEC', 'IGM']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage  Score
# 0   SMH   2w             0.1    NaN
# 1  SOXX   2w             0.1    NaN
# 2   PSI   2w             0.1    NaN
# 3   XSD   2w             0.1    NaN
# 4   IYW   2w             0.1    NaN
# Top ETFs for 2024-01-08 to 2024-01-14: ['SMH', 'SOXX']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  5.630022
# 1  SOXX   3w             0.1  2.999985
# 2   PSI   3w             0.1  1.955450
# 3   XSD   3w             0.1 -3.798154
# 4   IYW   3w             0.1 -2.448857
# Top ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1 -0.724403
# 1  SOXX   4w             0.1 -3.717706
# 2   PSI   4w             0.1 -3.651714
# 3   XSD   4w             0.1 -7.351413
# 4   IYW   4w             0.1  1.716202
# Top ETFs for 2024-01-22 to 2024-01-28: ['IGM', 'FTEC']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage      Score
# 0   SMH   5w             0.1   3.093095
# 1  SOXX   5w             0.1  -2.101163
# 2   PSI   5w             0.1  -1.299712
# 3   XSD   5w             0.1 -10.010932
# 4   IYW   5w             0.1   1.715778
# Top ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'SMH']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  2.406587
# 1  SOXX   6w             0.1 -1.422457
# 2   PSI   6w             0.1 -2.660382
# 3   XSD   6w             0.1  0.817378
# 4   IYW   6w             0.1 -1.222550
# Top ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'FTEC']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1 -0.689497
# 1  SOXX   7w             0.1  1.516837
# 2   PSI   7w             0.1  5.606255
# 3   XSD   7w             0.1  0.830049
# 4   IYW   7w             0.1 -1.768832
# Top ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'SOXX']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1  3.470734
# 1  SOXX   8w             0.1  0.950044
# 2   PSI   8w             0.1 -2.902289
# 3   XSD   8w             0.1 -8.432839
# 4   IYW   8w             0.1  0.536473
# Top ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'IXN']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1 -0.014312
# 1  SOXX   9w             0.1 -0.034712
# 2   PSI   9w             0.1  7.988909
# 3   XSD   9w             0.1  0.945228
# 4   IYW   9w             0.1 -5.269526
# Top ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'FTEC']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  3.982058
# 1  SOXX  10w             0.1  1.934335
# 2   PSI  10w             0.1 -0.914763
# 3   XSD  10w             0.1  1.806662
# 4   IYW  10w             0.1 -2.805365
# Top ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1 -2.466612
# 1  SOXX  11w             0.1 -4.261864
# 2   PSI  11w             0.1 -4.583498
# 3   XSD  11w             0.1 -6.597840
# 4   IYW  11w             0.1  3.205912
# Top ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage  Score
# 0   SMH  12w             0.1    NaN
# 1  SOXX  12w             0.1    NaN
# 2   PSI  12w             0.1    NaN
# 3   XSD  12w             0.1    NaN
# 4   IYW  12w             0.1    NaN
# Top ETFs for 2024-03-18 to 2024-03-24: ['SMH', 'SOXX']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1 -2.047216
# 1  SOXX  13w             0.1  2.401094
# 2   PSI  13w             0.1  3.184629
# 3   XSD  13w             0.1  7.811311
# 4   IYW  13w             0.1 -3.618169
# Top ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1 -2.413853
# 1  SOXX  14w             0.1 -2.874995
# 2   PSI  14w             0.1  4.716999
# 3   XSD  14w             0.1 -1.022429
# 4   IYW  14w             0.1 -0.118489
# Top ETFs for 2024-04-01 to 2024-04-07: ['PSI', 'IGM']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1 -4.029489
# 1  SOXX  15w             0.1 -2.538070
# 2   PSI  15w             0.1 -2.060117
# 3   XSD  15w             0.1  0.710327
# 4   IYW  15w             0.1  1.222992
# Top ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1 -1.701696
# 1  SOXX  16w             0.1 -0.075047
# 2   PSI  16w             0.1  1.512477
# 3   XSD  16w             0.1 -5.325526
# 4   IYW  16w             0.1  0.808687
# Top ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'IGM']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage  Score
# 0   SMH  17w             0.1    NaN
# 1  SOXX  17w             0.1    NaN
# 2   PSI  17w             0.1    NaN
# 3   XSD  17w             0.1    NaN
# 4   IYW  17w             0.1    NaN
# Top ETFs for 2024-04-22 to 2024-04-28: ['SMH', 'SOXX']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1 -5.291947
# 1  SOXX  18w             0.1 -4.703084
# 2   PSI  18w             0.1 -2.872612
# 3   XSD  18w             0.1  0.757815
# 4   IYW  18w             0.1  0.897149
# Top ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IXN']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1 -4.601824
# 1  SOXX  19w             0.1 -4.319644
# 2   PSI  19w             0.1  4.952542
# 3   XSD  19w             0.1  0.238486
# 4   IYW  19w             0.1 -3.423462
# Top ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'PSI']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1 -5.456063
# 1  SOXX  20w             0.1 -0.984139
# 2   PSI  20w             0.1 -3.507403
# 3   XSD  20w             0.1  1.933376
# 4   IYW  20w             0.1  0.933390
# Top ETFs for 2024-05-13 to 2024-05-19: ['FTEC', 'VGT']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage  Score
# 0   SMH  21w             0.1    NaN
# 1  SOXX  21w             0.1    NaN
# 2   PSI  21w             0.1    NaN
# 3   XSD  21w             0.1    NaN
# 4   IYW  21w             0.1    NaN
# Top ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1 -2.005339
# 1  SOXX  22w             0.1 -1.823378
# 2   PSI  22w             0.1  0.287573
# 3   XSD  22w             0.1  6.887180
# 4   IYW  22w             0.1 -0.127662
# Top ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'FTEC']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1  0.381794
# 1  SOXX  23w             0.1 -3.508793
# 2   PSI  23w             0.1 -3.834614
# 3   XSD  23w             0.1 -5.043189
# 4   IYW  23w             0.1  2.232438
# Top ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'FTEC']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage  Score
# 0   SMH  24w             0.1    NaN
# 1  SOXX  24w             0.1    NaN
# 2   PSI  24w             0.1    NaN
# 3   XSD  24w             0.1    NaN
# 4   IYW  24w             0.1    NaN
# Top ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'SOXX']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1 -5.380839
# 1  SOXX  25w             0.1 -2.670872
# 2   PSI  25w             0.1  1.011099
# 3   XSD  25w             0.1 -5.960252
# 4   IYW  25w             0.1  0.137986
# Top ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'XLK']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1 -4.664648
# 1  SOXX  26w             0.1 -2.289154
# 2   PSI  26w             0.1  4.243530
# 3   XSD  26w             0.1  1.808400
# 4   IYW  26w             0.1 -0.195799
# Top ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'FTEC']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage  Score
# 0   SMH  27w             0.1    NaN
# 1  SOXX  27w             0.1    NaN
# 2   PSI  27w             0.1    NaN
# 3   XSD  27w             0.1    NaN
# 4   IYW  27w             0.1    NaN
# Top ETFs for 2024-07-01 to 2024-07-07: ['SMH', 'SOXX']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1 -0.780063
# 1  SOXX  28w             0.1  1.073167
# 2   PSI  28w             0.1  1.128033
# 3   XSD  28w             0.1  9.750974
# 4   IYW  28w             0.1 -2.850767
# Top ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'PSI']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1 -2.934176
# 1  SOXX  29w             0.1  0.199029
# 2   PSI  29w             0.1 -0.476496
# 3   XSD  29w             0.1  4.745920
# 4   IYW  29w             0.1 -2.314875
# Top ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'FTEC']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1 -6.383894
# 1  SOXX  30w             0.1 -0.279568
# 2   PSI  30w             0.1 -1.171677
# 3   XSD  30w             0.1  2.942913
# 4   IYW  30w             0.1 -2.517666
# Top ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'XSD']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1 -2.035624
# 1  SOXX  31w             0.1 -2.508559
# 2   PSI  31w             0.1 -1.220744
# 3   XSD  31w             0.1 -6.548077
# 4   IYW  31w             0.1 -0.203737
# Top ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IXN']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1 -1.892365
# 1  SOXX  32w             0.1 -1.149762
# 2   PSI  32w             0.1  6.596728
# 3   XSD  32w             0.1 -2.400588
# 4   IYW  32w             0.1 -2.282561
# Top ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'FTEC']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage  Score
# 0   SMH  33w             0.1    NaN
# 1  SOXX  33w             0.1    NaN
# 2   PSI  33w             0.1    NaN
# 3   XSD  33w             0.1    NaN
# 4   IYW  33w             0.1    NaN
# Top ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'SOXX']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1 -4.183539
# 1  SOXX  34w             0.1 -2.523209
# 2   PSI  34w             0.1 -1.370156
# 3   XSD  34w             0.1  2.317444
# 4   IYW  34w             0.1 -0.741268
# Top ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'XSD']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1 -4.520345
# 1  SOXX  35w             0.1  0.432661
# 2   PSI  35w             0.1 -0.745921
# 3   XSD  35w             0.1  5.569125
# 4   IYW  35w             0.1 -0.935474
# Top ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'FTEC']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1 -2.726145
# 1  SOXX  36w             0.1  0.635585
# 2   PSI  36w             0.1  1.481608
# 3   XSD  36w             0.1 -0.349174
# 4   IYW  36w             0.1 -1.518622
# Top ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage  Score
# 0   SMH  37w             0.1    NaN
# 1  SOXX  37w             0.1    NaN
# 2   PSI  37w             0.1    NaN
# 3   XSD  37w             0.1    NaN
# 4   IYW  37w             0.1    NaN
# Top ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1 -6.205244
# 1  SOXX  38w             0.1 -4.134893
# 2   PSI  38w             0.1 -0.074483
# 3   XSD  38w             0.1 -1.119534
# 4   IYW  38w             0.1  1.342932
# Top ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'IGM']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1 -1.587049
# 1  SOXX  39w             0.1  1.108892
# 2   PSI  39w             0.1  3.191717
# 3   XSD  39w             0.1  5.789379
# 4   IYW  39w             0.1 -3.791124
# Top ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Processing scores for 2024-09-30 to 2024-10-06:
#     ETF Week  RiskPercentage     Score
# 0   SMH  40w             0.1 -3.956139
# 1  SOXX  40w             0.1 -3.610660
# ...
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'IGM']
# Sell IYW: 271.35 shares at 131.14. Total value: 34694.83
# Buy IGM: 404.39 shares at 83.65.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'FTEC': 222.01030889510088, 'IGM': 404.3928481875349}
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SMH', 'SOXX']
# Sell FTEC: 222.01 shares at 144.25. Total value: 31224.36
# Buy SMH: 149.95 shares at 203.02.
# Sell IGM: 404.39 shares at 80.88. Total value: 31889.61
# Buy SOXX: 154.18 shares at 201.66.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'SMH': 149.95445119421325, 'SOXX': 154.1821348870577}
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IXN']
# Sell SMH: 149.95 shares at 218.38. Total value: 31928.38
# Buy FTEC: 207.13 shares at 150.29.
# Sell SOXX: 154.18 shares at 218.55. Total value: 32854.09
# Buy IXN: 444.59 shares at 72.05.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'FTEC': 207.13400355364533, 'IXN': 444.59041925173307}
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'PSI']
# Sell IXN: 444.59 shares at 73.87. Total value: 32020.85
# Buy PSI: 557.61 shares at 55.99.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'FTEC': 207.13400355364533, 'PSI': 557.6053932028573}
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'PSI']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['FTEC', 'VGT']
# Sell PSI: 557.61 shares at 56.06. Total value: 30477.88
# Buy VGT: 57.28 shares at 518.78.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'FTEC': 207.13400355364533, 'VGT': 57.280401277183984}
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Sell FTEC: 207.13 shares at 160.26. Total value: 32365.41
# Buy SMH: 134.28 shares at 235.00.
# Sell VGT: 57.28 shares at 539.30. Total value: 30119.04
# Buy SOXX: 125.89 shares at 233.26.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'SMH': 134.28202815753886, 'SOXX': 125.89411596698578}
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'FTEC']
# Sell SMH: 134.28 shares at 249.83. Total value: 32708.99
# Buy XSD: 127.96 shares at 249.23.
# Sell SOXX: 125.89 shares at 242.59. Total value: 29777.14
# Buy FTEC: 177.28 shares at 163.77.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'XSD': 127.959167113671, 'FTEC': 177.2773256739334}
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'FTEC']
# Sell XSD: 127.96 shares at 245.69. Total value: 30652.33
# Buy IXN: 387.83 shares at 77.06.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'FTEC': 177.2773256739334, 'IXN': 387.8279724036623}
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'SOXX']
# Sell IXN: 387.83 shares at 79.41. Total value: 30027.49
# Buy SMH: 114.43 shares at 255.86.
# Sell FTEC: 177.28 shares at 164.09. Total value: 28362.20
# Buy SOXX: 113.57 shares at 243.48.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'SMH': 114.42506836357624, 'SOXX': 113.57460701973017}
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'XLK']
# Sell SMH: 114.43 shares at 272.48. Total value: 30399.08
# Buy FTEC: 169.91 shares at 174.44.
# Sell SOXX: 113.57 shares at 256.02. Total value: 28350.44
# Buy XLK: 119.60 shares at 231.12.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'FTEC': 169.91001413486765, 'XLK': 119.59880191829639}
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'FTEC']
# Sell XLK: 119.60 shares at 222.42. Total value: 25936.14
# Buy PSI: 416.19 shares at 60.76.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'FTEC': 169.91001413486765, 'PSI': 416.1904783635361}
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'FTEC']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['SMH', 'SOXX']
# Sell PSI: 416.19 shares at 62.76. Total value: 25467.11
# Buy SMH: 95.13 shares at 261.01.
# Sell FTEC: 169.91 shares at 173.13. Total value: 28681.11
# Buy SOXX: 113.39 shares at 246.62.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'SMH': 95.13211056821439, 'SOXX': 113.3893495159046}
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'PSI']
# Sell SMH: 95.13 shares at 274.21. Total value: 25434.02
# Buy XSD: 95.13 shares at 260.69.
# Sell SOXX: 113.39 shares at 259.59. Total value: 28698.87
# Buy PSI: 426.74 shares at 65.57.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 95.12512981698609, 'PSI': 426.7408971718313}
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'PSI']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'FTEC']
# Sell PSI: 426.74 shares at 66.24. Total value: 27560.63
# Buy FTEC: 149.72 shares at 179.48.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'XSD': 95.12512981698609, 'FTEC': 149.71928918785326}
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'XSD']
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'XSD': 95.12512981698609, 'FTEC': 149.71928918785326}
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IXN']
# Sell XSD: 95.13 shares at 242.03. Total value: 22447.56
# Buy IXN: 277.36 shares at 78.91.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'FTEC': 149.71928918785326, 'IXN': 277.3585951654066}
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'FTEC']
# Sell IXN: 277.36 shares at 73.00. Total value: 19741.00
# Buy PSI: 388.21 shares at 49.58.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'FTEC': 149.71928918785326, 'PSI': 388.2104144774278}
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'FTEC']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'SOXX']
# Sell PSI: 388.21 shares at 53.06. Total value: 20083.48
# Buy SMH: 86.28 shares at 226.96.
# Sell FTEC: 149.72 shares at 160.03. Total value: 23360.59
# Buy SOXX: 106.93 shares at 213.00.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'SMH': 86.27686075954006, 'SOXX': 106.93227004090195}
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'XSD']
# Sell SMH: 86.28 shares at 251.34. Total value: 21142.71
# Buy FTEC: 119.46 shares at 172.56.
# Sell SOXX: 106.93 shares at 235.16. Total value: 24517.54
# Buy XSD: 101.74 shares at 234.95.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'FTEC': 119.46069704334322, 'XSD': 101.74334983964857}
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'FTEC']
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'FTEC': 119.46069704334322, 'XSD': 101.74334983964857}
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Sell XSD: 101.74 shares at 222.36. Total value: 22058.06
# Buy IGM: 240.24 shares at 89.52.
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'FTEC': 119.46069704334322, 'IGM': 240.2436254958218}
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Sell FTEC: 119.46 shares at 160.54. Total value: 18698.76
# Buy SMH: 82.92 shares at 219.86.
# Sell IGM: 240.24 shares at 87.89. Total value: 20587.14
# Buy SOXX: 96.52 shares at 207.96.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'SMH': 82.92229083419845, 'SOXX': 96.52076229957089}
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'IGM']
# Sell SMH: 82.92 shares at 233.80. Total value: 18902.55
# Buy FTEC: 109.64 shares at 168.10.
# Sell SOXX: 96.52 shares at 219.88. Total value: 20692.41
# Buy IGM: 218.61 shares at 92.29.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'FTEC': 109.63704109651721, 'IGM': 218.6054888649971}
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Sell IGM: 218.61 shares at 94.58. Total value: 20158.81
# Buy XSD: 84.78 shares at 231.84.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'FTEC': 109.63704109651721, 'XSD': 84.77762589695124}
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'FTEC']
# Sell XSD: 84.78 shares at 240.25. Total value: 19858.63
# Buy IGM: 201.82 shares at 95.94.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'FTEC': 109.63704109651721, 'IGM': 201.81533029321224}
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['PSI', 'SMH']
# Sell IGM: 201.82 shares at 95.46. Total value: 18783.66
# Buy PSI: 319.90 shares at 57.25.
# Sell FTEC: 109.64 shares at 172.81. Total value: 18472.72
# Buy SMH: 72.56 shares at 248.22.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'PSI': 319.89637536767856, 'SMH': 72.56022625468412}
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['PSI', 'SMH']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['FTEC', 'VGT']
# Sell PSI: 319.90 shares at 60.18. Total value: 18770.08
# Buy FTEC: 101.20 shares at 180.83.
# Sell SMH: 72.56 shares at 261.28. Total value: 18484.57
# Buy VGT: 29.65 shares at 607.88.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'FTEC': 101.20459927034962, 'VGT': 29.648052207694043}
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'XSD']
# Sell VGT: 29.65 shares at 606.93. Total value: 17544.43
# Buy XSD: 70.62 shares at 242.23.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'FTEC': 101.20459927034962, 'XSD': 70.61810774092794}
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IGM']
# Sell XSD: 70.62 shares at 246.83. Total value: 16994.90
# Buy IGM: 169.17 shares at 97.95.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'FTEC': 101.20459927034962, 'IGM': 169.1682385237242}
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['SMH', 'SOXX']
# Sell FTEC: 101.20 shares at 174.13. Total value: 17182.19
# Buy SMH: 68.58 shares at 244.27.
# Sell IGM: 169.17 shares at 95.86. Total value: 15811.06
# Buy SOXX: 70.29 shares at 219.31.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'SMH': 68.58244330941577, 'SOXX': 70.2921870388781}
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'VGT']
# Sell SMH: 68.58 shares at 253.53. Total value: 16953.01
# Buy FTEC: 89.31 shares at 185.07.
# Sell SOXX: 70.29 shares at 225.57. Total value: 15459.41
# Buy VGT: 24.24 shares at 621.92.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'FTEC': 89.31316849123384, 'VGT': 24.23612198167387}
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['SMH', 'SOXX']
# Sell FTEC: 89.31 shares at 179.88. Total value: 15664.01
# Buy SMH: 63.23 shares at 241.54.
# Sell VGT: 24.24 shares at 604.72. Total value: 14289.67
# Buy SOXX: 65.12 shares at 213.94.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'SMH': 63.22932840457469, 'SOXX': 65.12304154831646}
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'FTEC']
# Sell SMH: 63.23 shares at 243.66. Total value: 15021.30
# Buy XSD: 58.87 shares at 248.77.
# Sell SOXX: 65.12 shares at 218.28. Total value: 13859.68
# Buy FTEC: 73.08 shares at 184.91.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'XSD': 58.87271076111906, 'FTEC': 73.07981559382593}
#
# Final Ticker Shares per Week:
# Week 2024-01-01 to 2024-01-07: {'FTEC': 348.73740855123145, 'IGM': 670.3334619848428}
# Week 2024-01-08 to 2024-01-14: {'SMH': 271.175805206579, 'SOXX': 251.9432508531872}
# Week 2024-01-15 to 2024-01-21: {'SMH': 271.175805206579, 'SOXX': 251.9432508531872}
# Week 2024-01-22 to 2024-01-28: {'IGM': 616.3735664106435, 'FTEC': 322.2658311017679}
# Week 2024-01-29 to 2024-02-04: {'IGM': 616.3735664106435, 'SMH': 243.29150160507234}
# Week 2024-02-05 to 2024-02-11: {'SMH': 243.29150160507234, 'FTEC': 316.9844377939799}
# Week 2024-02-12 to 2024-02-18: {'PSI': 891.4865147327466, 'SOXX': 221.4497241419699}
# Week 2024-02-19 to 2024-02-25: {'SMH': 221.05847455647196, 'IXN': 605.980607108306}
# Week 2024-02-26 to 2024-03-03: {'PSI': 829.0272211880624, 'FTEC': 275.5562712280971}
# Week 2024-03-04 to 2024-03-10: {'SMH': 199.68752381126302, 'SOXX': 179.61319204951002}
# Week 2024-03-11 to 2024-03-17: {'FTEC': 271.86117474833225, 'IYW': 289.09104407042713}
# Week 2024-03-18 to 2024-03-24: {'SMH': 181.9295800912476, 'SOXX': 167.87747606363567}
# Week 2024-03-25 to 2024-03-31: {'XSD': 173.61963659124257, 'PSI': 637.2474273096107}
# Week 2024-04-01 to 2024-04-07: {'PSI': 637.2474273096107, 'IGM': 445.39497983327396}
# Week 2024-04-08 to 2024-04-14: {'FTEC': 222.01030889510088, 'IYW': 271.34699154448896}
# Week 2024-04-15 to 2024-04-21: {'FTEC': 222.01030889510088, 'IGM': 404.3928481875349}
# Week 2024-04-22 to 2024-04-28: {'SMH': 149.95445119421325, 'SOXX': 154.1821348870577}
# Week 2024-04-29 to 2024-05-05: {'FTEC': 207.13400355364533, 'IXN': 444.59041925173307}
# Week 2024-05-06 to 2024-05-12: {'FTEC': 207.13400355364533, 'PSI': 557.6053932028573}
# Week 2024-05-13 to 2024-05-19: {'FTEC': 207.13400355364533, 'VGT': 57.280401277183984}
# Week 2024-05-20 to 2024-05-26: {'SMH': 134.28202815753886, 'SOXX': 125.89411596698578}
# Week 2024-05-27 to 2024-06-02: {'XSD': 127.959167113671, 'FTEC': 177.2773256739334}
# Week 2024-06-03 to 2024-06-09: {'FTEC': 177.2773256739334, 'IXN': 387.8279724036623}
# Week 2024-06-10 to 2024-06-16: {'SMH': 114.42506836357624, 'SOXX': 113.57460701973017}
# Week 2024-06-17 to 2024-06-23: {'FTEC': 169.91001413486765, 'XLK': 119.59880191829639}
# Week 2024-06-24 to 2024-06-30: {'FTEC': 169.91001413486765, 'PSI': 416.1904783635361}
# Week 2024-07-01 to 2024-07-07: {'SMH': 95.13211056821439, 'SOXX': 113.3893495159046}
# Week 2024-07-08 to 2024-07-14: {'XSD': 95.12512981698609, 'PSI': 426.7408971718313}
# Week 2024-07-15 to 2024-07-21: {'XSD': 95.12512981698609, 'FTEC': 149.71928918785326}
# Week 2024-07-22 to 2024-07-28: {'XSD': 95.12512981698609, 'FTEC': 149.71928918785326}
# Week 2024-07-29 to 2024-08-04: {'FTEC': 149.71928918785326, 'IXN': 277.3585951654066}
# Week 2024-08-05 to 2024-08-11: {'FTEC': 149.71928918785326, 'PSI': 388.2104144774278}
# Week 2024-08-12 to 2024-08-18: {'SMH': 86.27686075954006, 'SOXX': 106.93227004090195}
# Week 2024-08-19 to 2024-08-25: {'FTEC': 119.46069704334322, 'XSD': 101.74334983964857}
# Week 2024-08-26 to 2024-09-01: {'FTEC': 119.46069704334322, 'XSD': 101.74334983964857}
# Week 2024-09-02 to 2024-09-08: {'FTEC': 119.46069704334322, 'IGM': 240.2436254958218}
# Week 2024-09-09 to 2024-09-15: {'SMH': 82.92229083419845, 'SOXX': 96.52076229957089}
# Week 2024-09-16 to 2024-09-22: {'FTEC': 109.63704109651721, 'IGM': 218.6054888649971}
# Week 2024-09-23 to 2024-09-29: {'FTEC': 109.63704109651721, 'XSD': 84.77762589695124}
# Week 2024-09-30 to 2024-10-06: {'FTEC': 109.63704109651721, 'IGM': 201.81533029321224}
# Week 2024-10-07 to 2024-10-13: {'PSI': 319.89637536767856, 'SMH': 72.56022625468412}
# Week 2024-10-14 to 2024-10-20: {'FTEC': 101.20459927034962, 'VGT': 29.648052207694043}
# Week 2024-10-21 to 2024-10-27: {'FTEC': 101.20459927034962, 'XSD': 70.61810774092794}
# Week 2024-10-28 to 2024-11-03: {'FTEC': 101.20459927034962, 'IGM': 169.1682385237242}
# Week 2024-11-04 to 2024-11-10: {'SMH': 68.58244330941577, 'SOXX': 70.2921870388781}
# Week 2024-11-11 to 2024-11-17: {'FTEC': 89.31316849123384, 'VGT': 24.23612198167387}
# Week 2024-11-18 to 2024-11-24: {'SMH': 63.22932840457469, 'SOXX': 65.12304154831646}
# Week 2024-11-25 to 2024-12-01: {'XSD': 58.87271076111906, 'FTEC': 73.07981559382593}

# %%
# Define the first trading day of the 48th week
first_trading_day_49w = '2024-12-01'  # Adjust this to match the actual start date of the 48th week

# Identify the 48th and 49th week date range keys
week_48_range = list(ticker_shares_per_week.keys())[-1]  # Last key corresponds to the 48th week
week_49_start = first_trading_day_49w  # Replace with the actual start of the 49th week
print(f"Using data for the 48th week: {week_48_range}")

print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

week_49_end = '2024-12-06'
# Initialize a dictionary to store the values of shares
etf_values_49w = {}

# Ensure 48th week data exists
if week_48_range in ticker_shares_per_week:
    # Fetch ETF shares from the 48th week
    ticker_shares_48w = ticker_shares_per_week[week_48_range]
    
    # Fetch the first trading day price of the 49th week for each ETF
    for ticker, shares in ticker_shares_48w.items():
        print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
        # Download historical data for the 49th week
        data = yf.download(ticker, start=week_49_start, end=week_49_end)
        
        if not data.empty:
            # Get the closing price of the first trading day of the 49th week
            closing_price_49w = data['Close'].iloc[0]
            # Calculate the value of the shares
            total_value = shares * closing_price_49w
            etf_values_49w[ticker] = total_value
            print(f"{ticker}: {shares:.2f} shares at ${closing_price_49w:.2f} each, total value: ${total_value:.2f}")
        else:
            print(f"{ticker}: No data available for the 49th week's first trading day.")
else:
    print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker XSD starting from 2024-12-01...
# XSD: 58.87 shares at $252.68 each, total value: $14875.96
# Fetching data for ticker FTEC starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# FTEC: 73.08 shares at $186.99 each, total value: $13665.20

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 28541.15
# XSD: 14875.96
# FTEC: 13665.20

# %% [markdown]
# ### WIth Smoothing

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, 
    volatility_clustering, mean_forecast, std_forecast, mean_rachev, std_rachev, 
    mean_sharpe, std_sharpe, mean_sortino, std_sortino, mean_volatility_clustering, 
    std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    return score

def smooth_scores(scores, alpha=0.2):
    """
    Smooth scores using Exponential Moving Average (EMA).
    """
    if not isinstance(scores, (list, np.ndarray)):
        raise ValueError("Scores must be a list or numpy array of numerical values.")
    
    scores = np.array(scores)
    smoothed_scores = np.zeros_like(scores)
    smoothed_scores[0] = scores[0]  # Initialize EMA
    
    for t in range(1, len(scores)):
        smoothed_scores[t] = alpha * scores[t] + (1 - alpha) * smoothed_scores[t - 1]
    
    return smoothed_scores.tolist()

def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )

def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage, alpha=0.2):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    raw_scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        raw_scores.append(score)

    # Apply smoothing to the raw scores
    smoothed_scores = smooth_scores(raw_scores, alpha=alpha)

    results = []
    for idx, etf in enumerate(etf_pred_dict):
        results.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'RawScore': raw_scores[idx],
            'SmoothedScore': smoothed_scores[idx]
        })

    return results

def main_weekly(tickers, etf_dict):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict)
    risk_percentage = 0.10
    weekly_scores = {}

    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores
        else:
            print(f"Skipping score calculation for {week_key}: No ETFs have data for this week.")

    return etf_pred_dict, weekly_scores

# Select top ETFs for weekly portfolio management
def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    top_etfs = df_scores.nlargest(2, 'SmoothedScore')
    return top_etfs['ETF'].tolist()

# %%
etf_pred_dict, weekly_scores = main_weekly(tickers, etf_dict)
# Out:
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_32548/1341513019.py:90: RuntimeWarning: divide by zero encountered in scalar divide
#   sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
# /Users/pranavsrinivasvenkatesh/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_32548/3832686525.py:13: RuntimeWarning: invalid value encountered in scalar subtract
#   sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
# Debug: Returns for SMH, Forecast Period 1w: [-0.03485361 -0.01912074 -0.00725006  0.00524473]
#
# Debug: Returns for SMH, Forecast Period 2w: [ 0.03410818  0.00145585 -0.00038691  0.0042201  -0.00505355]
#
# Debug: Returns for SMH, Forecast Period 3w: [ 0.01424855 -0.00773638  0.03070864  0.03660772]
#
# Debug: Returns for SMH, Forecast Period 4w: [ 0.00337821  0.00421417  0.01679608 -0.00092453 -0.02244032]
#
# Debug: Returns for SMH, Forecast Period 5w: [ 0.01050558 -0.0111581  -0.01572589  0.00816453  0.01877359]
#
# Debug: Returns for SMH, Forecast Period 6w: [ 0.01896718 -0.01193738  0.01931408  0.01348086  0.02151389]
#
# Debug: Returns for SMH, Forecast Period 7w: [-0.00449048 -0.01913473  0.0192573  -0.00401081 -0.00524234]
#
# Debug: Returns for SMH, Forecast Period 8w: [-0.02100306 -0.00793366  0.0667203  -0.00762593]
#
# Debug: Returns for SMH, Forecast Period 9w: [ 0.00690416 -0.00405792 -0.01249986  0.02061292  0.03971843]
#
# Debug: Returns for SMH, Forecast Period 10w: [ 0.01546466 -0.01610479  0.02490666  0.03411755 -0.039832  ]
#
# Debug: Returns for SMH, Forecast Period 11w: [-0.01893526  0.03036965 -0.02096336 -0.01906807 -0.00884591]
#
# Debug: Returns for SMH, Forecast Period 12w: [ 0.00052795 -0.00372575  0.01472147  0.02160833  0.00432812]
#
# Debug: Returns for SMH, Forecast Period 13w: [-0.00399275 -0.01092407 -0.00202043 -0.00120651]
#
# Debug: Returns for SMH, Forecast Period 14w: [ 0.01130662 -0.01497789  0.00165874 -0.02885792  0.00994641]
#
# Debug: Returns for SMH, Forecast Period 15w: [-0.00097252  0.00237837 -0.01080373  0.02083255 -0.03128193]
#
# Debug: Returns for SMH, Forecast Period 16w: [-0.0171243   0.00618749 -0.03303697 -0.02015495 -0.04799288]
#
# Debug: Returns for SMH, Forecast Period 17w: [ 0.01593321  0.02041036 -0.00179513  0.01721308  0.02303897]
#
# Debug: Returns for SMH, Forecast Period 18w: [ 0.00090471 -0.02232318 -0.03187996  0.01719769  0.02451571]
#
# Debug: Returns for SMH, Forecast Period 19w: [ 0.02038484 -0.01092666  0.00070083 -0.00873324  0.01250916]
#
# Debug: Returns for SMH, Forecast Period 20w: [-0.00237653  0.01512189  0.02814176 -0.00863927 -0.00960629]
#
# Debug: Returns for SMH, Forecast Period 21w: [ 0.02003588 -0.00216569  0.00716197  0.01276008  0.01759693]
#
# Debug: Returns for SMH, Forecast Period 22w: [ 0.02180736 -0.01775278 -0.01466677 -0.00802812]
#
# Debug: Returns for SMH, Forecast Period 23w: [ 0.01163796 -0.00465338  0.04755979 -0.00871197 -0.00171333]
#
# Debug: Returns for SMH, Forecast Period 24w: [ 0.01371442 -0.00243295  0.02896365  0.01487779  0.00157513]
#
# Debug: Returns for SMH, Forecast Period 25w: [ 0.0163857   0.01528368 -0.02912427 -0.01597281]
#
# Debug: Returns for SMH, Forecast Period 26w: [-0.03585222  0.0217529  -0.00512813 -0.01005283  0.00514533]
#
# Debug: Returns for SMH, Forecast Period 27w: [-0.0005638   0.00840668  0.02107804 -0.00113987]
#
# Debug: Returns for SMH, Forecast Period 28w: [ 0.01467669  0.0004623   0.02191166 -0.03823897  0.01073645]
#
# Debug: Returns for SMH, Forecast Period 29w: [-0.00449654 -0.00292564 -0.07420184  0.00170297 -0.03282143]
#
# Debug: Returns for SMH, Forecast Period 30w: [ 0.03514292 -0.01421337 -0.05743576 -0.02192929  0.01229276]
#
# Debug: Returns for SMH, Forecast Period 31w: [-0.01048968 -0.04194348  0.07264038 -0.06844181 -0.0589956 ]
#
# Debug: Returns for SMH, Forecast Period 32w: [-0.02835432  0.01430618 -0.03275872  0.05803785 -0.00491528]
#
# Debug: Returns for SMH, Forecast Period 33w: [ 0.00458995  0.03605099 -0.00357199  0.03913026 -0.00170345]
#
# Debug: Returns for SMH, Forecast Period 34w: [ 0.01625221 -0.0159783   0.00760024 -0.03491439  0.02272818]
#
# Debug: Returns for SMH, Forecast Period 35w: [-0.02568152  0.00784351 -0.01862045 -0.01515423  0.02150104]
#
# Debug: Returns for SMH, Forecast Period 36w: [-0.07652519 -0.00399758 -0.00358076 -0.04300279]
#
# Debug: Returns for SMH, Forecast Period 37w: [ 0.02015154  0.00720237  0.04946275 -0.00014893  0.01062516]
#
# Debug: Returns for SMH, Forecast Period 38w: [-0.01585835 -0.00317924 -0.01458444  0.0405093  -0.01612886]
#
# Debug: Returns for SMH, Forecast Period 39w: [ 0.00188236  0.01593923  0.00650588  0.0265744  -0.02136446]
#
# Debug: Returns for SMH, Forecast Period 40w: [-0.0112981  -0.02928204  0.01295766  0.00787115  0.01218092]
#
# Debug: Returns for SMH, Forecast Period 41w: [ 0.0009951   0.01658194  0.00969043 -0.00317884  0.00677084]
#
# Debug: Returns for SMH, Forecast Period 42w: [ 0.01660347 -0.0553696  -0.0009588   0.01586481 -0.00208878]
#
# Debug: Returns for SMH, Forecast Period 43w: [ 0.0036012  -0.00637755 -0.01278769  0.00190739  0.0090167 ]
#
# Debug: Returns for SMH, Forecast Period 44w: [-0.00924831  0.0205831  -0.02611247 -0.03813115  0.01022081]
#
# Debug: Returns for SMH, Forecast Period 45w: [-0.00462627  0.01393326  0.02355035  0.02184848 -0.00891193]
#
# Debug: Returns for SMH, Forecast Period 46w: [-0.02513523 -0.00971471 -0.01921614 -0.00033945 -0.03604504]
#
# Debug: Returns for SMH, Forecast Period 47w: [ 0.00365789  0.00794369 -0.00966055  0.01190901 -0.00886057]
#
# Debug: Returns for SMH, Forecast Period 48w: [-0.0070254  -0.01227851 -0.0165479   0.01318923]
#
# Debug: Returns for SOXX, Forecast Period 1w: [-0.03626821 -0.0218027  -0.00883788  0.00510342]
#
# Debug: Returns for SOXX, Forecast Period 2w: [ 0.03228976  0.00012377 -0.00373466  0.00318493 -0.00491288]
#
# Debug: Returns for SOXX, Forecast Period 3w: [ 0.0133924  -0.00988799  0.03230065  0.03852232]
#
# Debug: Returns for SOXX, Forecast Period 4w: [ 0.00267683  0.00653529  0.01426594 -0.00291137 -0.02752242]
#
# Debug: Returns for SOXX, Forecast Period 5w: [ 0.00976734 -0.01604994 -0.01513655  0.00466534  0.01264672]
#
# Debug: Returns for SOXX, Forecast Period 6w: [ 0.01378515 -0.01167972  0.01512623  0.01716596  0.01975732]
#
# Debug: Returns for SOXX, Forecast Period 7w: [-0.00181396 -0.02068137  0.0224788  -0.00102939 -0.00596588]
#
# Debug: Returns for SOXX, Forecast Period 8w: [-0.01738836 -0.00294395  0.0485385  -0.0114349 ]
#
# Debug: Returns for SOXX, Forecast Period 9w: [ 0.00920662 -0.00135554 -0.01162496  0.02694453  0.04252604]
#
# Debug: Returns for SOXX, Forecast Period 10w: [ 0.00991072 -0.01955448  0.02473223  0.03468836 -0.04023261]
#
# Debug: Returns for SOXX, Forecast Period 11w: [-0.01348307  0.02055486 -0.02471413 -0.01739162 -0.00753789]
#
# Debug: Returns for SOXX, Forecast Period 12w: [-0.00118613 -0.00887164  0.016726    0.02237054  0.00078667]
#
# Debug: Returns for SOXX, Forecast Period 13w: [-0.00447132 -0.00802582  0.01211348  0.00048094]
#
# Debug: Returns for SOXX, Forecast Period 14w: [ 0.01003209 -0.01637936  0.00200751 -0.02904056  0.01093794]
#
# Debug: Returns for SOXX, Forecast Period 15w: [ 0.00137882  0.00996882 -0.01892572  0.02178407 -0.03354656]
#
# Debug: Returns for SOXX, Forecast Period 16w: [-0.01346062  0.0069287  -0.03115941 -0.01860168 -0.04128179]
#
# Debug: Returns for SOXX, Forecast Period 17w: [0.01495027 0.01957849 0.01165092 0.01752513 0.02024949]
#
# Debug: Returns for SOXX, Forecast Period 18w: [ 0.00667258 -0.02197478 -0.0349465   0.02140105  0.02155239]
#
# Debug: Returns for SOXX, Forecast Period 19w: [ 2.01743236e-02 -9.66881413e-03 -7.30230942e-05 -4.48395453e-03
#   8.76559291e-03]
#
# Debug: Returns for SOXX, Forecast Period 20w: [ 0.00116598  0.01602454  0.02768597 -0.00499344 -0.00559393]
#
# Debug: Returns for SOXX, Forecast Period 21w: [ 0.02239194 -0.00280203  0.01204845 -0.00567072  0.01995166]
#
# Debug: Returns for SOXX, Forecast Period 22w: [ 0.01690692 -0.02060845 -0.00684962 -0.00795796]
#
# Debug: Returns for SOXX, Forecast Period 23w: [ 0.0015388  -0.00779329  0.04357072 -0.00804536 -0.00300028]
#
# Debug: Returns for SOXX, Forecast Period 24w: [ 0.01454852  0.00086004  0.02816417  0.01093535 -0.00363711]
#
# Debug: Returns for SOXX, Forecast Period 25w: [ 0.01583068  0.01281036 -0.02735647 -0.01007297]
#
# Debug: Returns for SOXX, Forecast Period 26w: [-0.02920702  0.01484871 -0.00450512 -0.00604836  0.0096329 ]
#
# Debug: Returns for SOXX, Forecast Period 27w: [-0.00062143  0.01377651  0.01636165  0.00170502]
#
# Debug: Returns for SOXX, Forecast Period 28w: [ 0.01867745 -0.00077362  0.02305928 -0.03322806  0.01179748]
#
# Debug: Returns for SOXX, Forecast Period 29w: [ 0.00054972  0.00558521 -0.07210716  0.00186374 -0.03204865]
#
# Debug: Returns for SOXX, Forecast Period 30w: [ 0.0401427  -0.01598566 -0.05440375 -0.02372701  0.02010746]
#
# Debug: Returns for SOXX, Forecast Period 31w: [-0.00348785 -0.03806496  0.06573646 -0.07402392 -0.05565168]
#
# Debug: Returns for SOXX, Forecast Period 32w: [-0.02006487  0.00662173 -0.03047646  0.06612963 -0.00800166]
#
# Debug: Returns for SOXX, Forecast Period 33w: [ 0.00341263  0.03849513 -0.00480475  0.04690152 -0.00336748]
#
# Debug: Returns for SOXX, Forecast Period 34w: [ 0.01627316 -0.01461775  0.01322585 -0.0348106   0.02646954]
#
# Debug: Returns for SOXX, Forecast Period 35w: [-0.02566783  0.01024705 -0.01836377 -0.00394722  0.02604195]
#
# Debug: Returns for SOXX, Forecast Period 36w: [-0.07644905  0.00335071 -0.00575134 -0.0430334 ]
#
# Debug: Returns for SOXX, Forecast Period 37w: [ 0.01912242  0.01011351  0.04584413 -0.00506672  0.01721348]
#
# Debug: Returns for SOXX, Forecast Period 38w: [-0.01417409  0.00047042 -0.0121582   0.04166439 -0.01568975]
#
# Debug: Returns for SOXX, Forecast Period 39w: [ 0.00332397  0.01130208  0.0063912   0.03514099 -0.01633477]
#
# Debug: Returns for SOXX, Forecast Period 40w: [-0.0094172  -0.02881369  0.01358621  0.00358715  0.01389342]
#
# Debug: Returns for SOXX, Forecast Period 41w: [-0.00221839  0.01042356  0.01077654 -0.00707845  0.00845376]
#
# Debug: Returns for SOXX, Forecast Period 42w: [ 0.01844036 -0.05220522 -0.00041543  0.00779787  0.00054387]
#
# Debug: Returns for SOXX, Forecast Period 43w: [-0.00220737 -0.00413354 -0.0096122   0.0047641   0.00919084]
#
# Debug: Returns for SOXX, Forecast Period 44w: [-0.00010298  0.02403542 -0.03584148 -0.03961374  0.00971973]
#
# Debug: Returns for SOXX, Forecast Period 45w: [-0.00685925  0.0107068   0.02810868  0.01969639 -0.00823113]
#
# Debug: Returns for SOXX, Forecast Period 46w: [-0.02607641 -0.01240483 -0.02206065 -0.00171393 -0.03344118]
#
# Debug: Returns for SOXX, Forecast Period 47w: [ 0.01168012  0.00073562 -0.00892193  0.01484711 -0.00060714]
#
# Debug: Returns for SOXX, Forecast Period 48w: [ 0.00855968 -0.01423697 -0.01486922  0.01222353]
#
# Debug: Returns for PSI, Forecast Period 1w: [-0.03581048 -0.02346916 -0.01418647  0.00154702]
#
# Debug: Returns for PSI, Forecast Period 2w: [ 0.02883653  0.00220999 -0.00420602  0.0031341  -0.00518673]
#
# Debug: Returns for PSI, Forecast Period 3w: [ 0.01411725 -0.01155834  0.03253233  0.03886656]
#
# Debug: Returns for PSI, Forecast Period 4w: [ 0.00917281  0.00356665  0.0111468  -0.00082156 -0.02810002]
#
# Debug: Returns for PSI, Forecast Period 5w: [ 0.01176991 -0.01422174 -0.019868    0.0082489   0.011775  ]
#
# Debug: Returns for PSI, Forecast Period 6w: [ 0.00929917 -0.01328911  0.0069711   0.01916549  0.03167404]
#
# Debug: Returns for PSI, Forecast Period 7w: [ 1.63577452e-03 -2.71048852e-02  3.15362602e-02  5.48449677e-03
#  -7.30739946e-05]
#
# Debug: Returns for PSI, Forecast Period 8w: [-0.02725745 -0.0112485   0.04366012 -0.01067028]
#
# Debug: Returns for PSI, Forecast Period 9w: [ 0.01339962 -0.00244351  0.00369219  0.01862234  0.04271248]
#
# Debug: Returns for PSI, Forecast Period 10w: [ 0.00384451 -0.02575264  0.02446573  0.02925558 -0.03755563]
#
# Debug: Returns for PSI, Forecast Period 11w: [-0.01495017  0.01709598 -0.02526356 -0.01525236 -0.00875938]
#
# Debug: Returns for PSI, Forecast Period 12w: [ 0.00691234 -0.00644225  0.02487319  0.02942213  0.00176582]
#
# Debug: Returns for PSI, Forecast Period 13w: [-0.00036141 -0.00626762  0.0114862  -0.00073313]
#
# Debug: Returns for PSI, Forecast Period 14w: [ 0.01062021 -0.0101488   0.01035518 -0.02501434  0.01285416]
#
# Debug: Returns for PSI, Forecast Period 15w: [ 0.00244496  0.0085005  -0.0208116   0.02659776 -0.03280567]
#
# Debug: Returns for PSI, Forecast Period 16w: [-0.01437094  0.01141469 -0.03238066 -0.01961915 -0.03966028]
#
# Debug: Returns for PSI, Forecast Period 17w: [0.01562502 0.02348828 0.00876186 0.0167547  0.02158971]
#
# Debug: Returns for PSI, Forecast Period 18w: [ 0.00848943 -0.02167628 -0.03321343  0.02930502  0.02216376]
#
# Debug: Returns for PSI, Forecast Period 19w: [ 0.02229408 -0.00480541 -0.00022765  0.00163199  0.00621911]
#
# Debug: Returns for PSI, Forecast Period 20w: [-0.00064776  0.01622552  0.02692366 -0.00784893 -0.00505325]
#
# Debug: Returns for PSI, Forecast Period 21w: [ 0.02191592  0.00082517  0.00191099 -0.00253727  0.01757075]
#
# Debug: Returns for PSI, Forecast Period 22w: [ 0.01526747 -0.01477715 -0.00167485 -0.01096503]
#
# Debug: Returns for PSI, Forecast Period 23w: [ 0.00104525 -0.00977633  0.04653945 -0.00775769 -0.00920306]
#
# Debug: Returns for PSI, Forecast Period 24w: [ 0.02056323  0.0001275   0.02912116  0.00866798 -0.00781801]
#
# Debug: Returns for PSI, Forecast Period 25w: [ 0.02114837  0.01490489 -0.02794483 -0.01118971]
#
# Debug: Returns for PSI, Forecast Period 26w: [-0.02281272  0.02239451 -0.00199379  0.0019606   0.01290171]
#
# Debug: Returns for PSI, Forecast Period 27w: [-0.00034031  0.01443531  0.01273777  0.00314442]
#
# Debug: Returns for PSI, Forecast Period 28w: [ 0.01623749  0.00111671  0.01726669 -0.02865465  0.01223485]
#
# Debug: Returns for PSI, Forecast Period 29w: [ 0.01220981  0.00784368 -0.08133295 -0.00980835 -0.02593229]
#
# Debug: Returns for PSI, Forecast Period 30w: [ 0.04186195 -0.00838094 -0.05566981 -0.03036262  0.01614578]
#
# Debug: Returns for PSI, Forecast Period 31w: [-0.00469703 -0.04722564  0.06371854 -0.07959045 -0.05040016]
#
# Debug: Returns for PSI, Forecast Period 32w: [-0.01582187  0.0059444  -0.01723791  0.07081021  0.00310503]
#
# Debug: Returns for PSI, Forecast Period 33w: [ 0.00269858  0.03649663 -0.00215894  0.05188214 -0.00543612]
#
# Debug: Returns for PSI, Forecast Period 34w: [ 0.0134127  -0.01508065  0.02246648 -0.03141497  0.02712077]
#
# Debug: Returns for PSI, Forecast Period 35w: [-0.02681507  0.01141598 -0.01451657  0.00609289  0.01287055]
#
# Debug: Returns for PSI, Forecast Period 36w: [-0.08041607  0.00660407 -0.00703132 -0.0406635 ]
#
# Debug: Returns for PSI, Forecast Period 37w: [ 0.01124828  0.00745431  0.04153984 -0.00814847  0.02312547]
#
# Debug: Returns for PSI, Forecast Period 38w: [-0.02247698  0.00756053 -0.01081971  0.04345067 -0.01286497]
#
# Debug: Returns for PSI, Forecast Period 39w: [ 0.00434548  0.01167839  0.00664671  0.04971988 -0.01622547]
#
# Debug: Returns for PSI, Forecast Period 40w: [-0.00652921 -0.03657092  0.01858229 -0.00610754  0.02146443]
#
# Debug: Returns for PSI, Forecast Period 41w: [ 0.00125017  0.00349963  0.01554157 -0.00112749  0.01719998]
#
# Debug: Returns for PSI, Forecast Period 42w: [ 0.01856057 -0.05525561  0.00217439  0.00261118 -0.00018122]
#
# Debug: Returns for PSI, Forecast Period 43w: [-0.00260491 -0.00550964 -0.00792548  0.00268675  0.01559182]
#
# Debug: Returns for PSI, Forecast Period 44w: [-0.00088925  0.02130757 -0.02392935 -0.04377198  0.0062088 ]
#
# Debug: Returns for PSI, Forecast Period 45w: [-0.00766662  0.02796997  0.03395971  0.02473942 -0.00400131]
#
# Debug: Returns for PSI, Forecast Period 46w: [-0.02188941 -0.01259979 -0.02135832 -0.00206069 -0.03907071]
#
# Debug: Returns for PSI, Forecast Period 47w: [1.50482038e-02 8.74768742e-03 7.19393766e-05 3.41293386e-02
#  4.87243956e-04]
#
# Debug: Returns for PSI, Forecast Period 48w: [ 0.01358413 -0.00814974 -0.01769085  0.02046193]
#
# Debug: Returns for XSD, Forecast Period 1w: [-0.02928982 -0.03051557 -0.01733279  0.00253352]
#
# Debug: Returns for XSD, Forecast Period 2w: [ 0.03175567 -0.00170718 -0.00688941 -0.00556173 -0.00933331]
#
# Debug: Returns for XSD, Forecast Period 3w: [ 0.00081786 -0.01194014  0.03026452  0.03093483]
#
# Debug: Returns for XSD, Forecast Period 4w: [ 0.01676808  0.00953738 -0.0080898  -0.01044746 -0.02724476]
#
# Debug: Returns for XSD, Forecast Period 5w: [ 0.01649659 -0.02490732 -0.02023149 -0.00088591  0.00094224]
#
# Debug: Returns for XSD, Forecast Period 6w: [ 0.00802434 -0.0087423   0.01813482  0.02843828  0.02422643]
#
# Debug: Returns for XSD, Forecast Period 7w: [ 0.00343686 -0.03631751  0.02469481 -0.00049823 -0.0166178 ]
#
# Debug: Returns for XSD, Forecast Period 8w: [-0.01072686 -0.00232185  0.02229032 -0.01656145]
#
# Debug: Returns for XSD, Forecast Period 9w: [ 0.01167589 -0.00314247 -0.00712652  0.02346038  0.03810832]
#
# Debug: Returns for XSD, Forecast Period 10w: [-0.00084048 -0.02339152  0.02529301  0.03583651 -0.02931666]
#
# Debug: Returns for XSD, Forecast Period 11w: [-0.00636399  0.00843747 -0.02778699 -0.02397308 -0.00785069]
#
# Debug: Returns for XSD, Forecast Period 12w: [-0.00119287 -0.00657648  0.02350135  0.02247636 -0.00704244]
#
# Debug: Returns for XSD, Forecast Period 13w: [-0.00172268 -0.0046198   0.02727016  0.00357103]
#
# Debug: Returns for XSD, Forecast Period 14w: [ 0.00765876 -0.02223903  0.00920572 -0.01568359  0.00505246]
#
# Debug: Returns for XSD, Forecast Period 15w: [ 0.00853642  0.02184824 -0.03953231  0.02345651 -0.03567303]
#
# Debug: Returns for XSD, Forecast Period 16w: [-0.02014898  0.00250663 -0.02188323 -0.0200234  -0.03170487]
#
# Debug: Returns for XSD, Forecast Period 17w: [0.01456644 0.01950436 0.02280309 0.0233784  0.01821709]
#
# Debug: Returns for XSD, Forecast Period 18w: [ 0.01743012 -0.01839716 -0.03223052  0.01746123  0.02261051]
#
# Debug: Returns for XSD, Forecast Period 19w: [ 0.01731367 -0.00337861  0.00380961  0.00344855 -0.0060086 ]
#
# Debug: Returns for XSD, Forecast Period 20w: [ 0.00537644  0.01781416  0.02091071 -0.00459285  0.00107335]
#
# Debug: Returns for XSD, Forecast Period 21w: [ 0.01371701 -0.00305219  0.02084278 -0.0211082   0.02291774]
#
# Debug: Returns for XSD, Forecast Period 22w: [ 0.01411301 -0.0186787   0.00532493  0.00097527]
#
# Debug: Returns for XSD, Forecast Period 23w: [-2.63975903e-05 -1.46564431e-02  3.93796367e-02 -8.40607771e-03
#  -1.91772627e-02]
#
# Debug: Returns for XSD, Forecast Period 24w: [ 0.01586897  0.00474439  0.02810384 -0.00234923 -0.01656699]
#
# Debug: Returns for XSD, Forecast Period 25w: [ 0.00758954  0.00135476 -0.02177466  0.00102647]
#
# Debug: Returns for XSD, Forecast Period 26w: [-0.02010582  0.00877818  0.00054257 -0.00246998  0.01073094]
#
# Debug: Returns for XSD, Forecast Period 27w: [-0.00383491  0.02029612  0.00956141  0.00494405]
#
# Debug: Returns for XSD, Forecast Period 28w: [ 0.02144222 -0.00573157  0.0280317  -0.01243148  0.01208207]
#
# Debug: Returns for XSD, Forecast Period 29w: [ 0.01034853  0.01962422 -0.05591619 -0.0082923  -0.02957891]
#
# Debug: Returns for XSD, Forecast Period 30w: [ 0.03900119 -0.01583082 -0.04558158 -0.02513219  0.02170072]
#
# Debug: Returns for XSD, Forecast Period 31w: [ 1.97571570e-05 -4.13984920e-02  4.40992398e-02 -6.60673878e-02
#  -6.07707015e-02]
#
# Debug: Returns for XSD, Forecast Period 32w: [-0.03004984  0.00312865 -0.03119451  0.06845905 -0.0061789 ]
#
# Debug: Returns for XSD, Forecast Period 33w: [-0.00012972  0.03955419 -0.01289966  0.05339646 -0.00347455]
#
# Debug: Returns for XSD, Forecast Period 34w: [ 0.01374645 -0.009742    0.02230087 -0.02972962  0.03375432]
#
# Debug: Returns for XSD, Forecast Period 35w: [-0.01800749  0.006435   -0.01256929  0.01584456  0.01463259]
#
# Debug: Returns for XSD, Forecast Period 36w: [-0.07423541  0.00427214 -0.00900724 -0.04156752]
#
# Debug: Returns for XSD, Forecast Period 37w: [ 0.01746168  0.003487    0.04071228 -0.00648754  0.02260382]
#
# Debug: Returns for XSD, Forecast Period 38w: [-0.01194269  0.00418781 -0.00326082  0.03955497 -0.01586722]
#
# Debug: Returns for XSD, Forecast Period 39w: [ 0.00429544  0.01005495 -0.00358306  0.04566153 -0.00450234]
#
# Debug: Returns for XSD, Forecast Period 40w: [-0.00983761 -0.03489044  0.01148451 -0.0015326   0.01871618]
#
# Debug: Returns for XSD, Forecast Period 41w: [-0.00540455  0.00501359  0.01374305 -0.00474546  0.02076284]
#
# Debug: Returns for XSD, Forecast Period 42w: [ 0.01163054 -0.02660015  0.00674369  0.00398332  0.00022502]
#
# Debug: Returns for XSD, Forecast Period 43w: [-0.0029778   0.00027796 -0.00888538  0.00506923  0.01135757]
#
# Debug: Returns for XSD, Forecast Period 44w: [ 0.01217596  0.02332978 -0.0423681  -0.05075995  0.02161156]
#
# Debug: Returns for XSD, Forecast Period 45w: [-0.00508936  0.01583869  0.04213735  0.01148261  0.00798476]
#
# Debug: Returns for XSD, Forecast Period 46w: [-0.02792029 -0.01959297 -0.02204194 -0.00829151 -0.03284669]
#
# Debug: Returns for XSD, Forecast Period 47w: [0.01497557 0.00956291 0.00022016 0.02810902 0.01514455]
#
# Debug: Returns for XSD, Forecast Period 48w: [ 0.03185021 -0.01150391 -0.01151193  0.01890864]
#
# Debug: Returns for IYW, Forecast Period 1w: [-0.0264297  -0.01039916 -0.00711559  0.00068822]
#
# Debug: Returns for IYW, Forecast Period 2w: [0.02619522 0.00288489 0.00928094 0.00413298 0.00232601]
#
# Debug: Returns for IYW, Forecast Period 3w: [ 0.00148152 -0.00565041  0.0188661   0.02346741]
#
# Debug: Returns for IYW, Forecast Period 4w: [ 0.00406431  0.00408623  0.00711275  0.00436149 -0.00936267]
#
# Debug: Returns for IYW, Forecast Period 5w: [ 0.01074785 -0.00858919 -0.02599569  0.01198396  0.01870392]
#
# Debug: Returns for IYW, Forecast Period 6w: [ 0.00106483 -0.00357663  0.01512774  0.00443249  0.01502925]
#
# Debug: Returns for IYW, Forecast Period 7w: [-0.00777009 -0.01742263  0.01228509 -0.00222079 -0.01121996]
#
# Debug: Returns for IYW, Forecast Period 8w: [-0.01033623 -0.00815467  0.03296265 -0.00243923]
#
# Debug: Returns for IYW, Forecast Period 9w: [-0.00287894  0.00207692 -0.00719278  0.01085113  0.01573034]
#
# Debug: Returns for IYW, Forecast Period 10w: [-0.00291276 -0.02379871  0.0085126   0.01745666 -0.01446524]
#
# Debug: Returns for IYW, Forecast Period 11w: [-0.00470431  0.01931085 -0.00923374  0.00036699 -0.0160133 ]
#
# Debug: Returns for IYW, Forecast Period 12w: [0.00775334 0.00412273 0.01241271 0.00254132 0.00299021]
#
# Debug: Returns for IYW, Forecast Period 13w: [-0.00537123 -0.00539671  0.00060348 -0.00240357]
#
# Debug: Returns for IYW, Forecast Period 14w: [ 0.003236   -0.00828648  0.00162391 -0.01708009  0.01357104]
#
# Debug: Returns for IYW, Forecast Period 15w: [-0.0022857   0.00159588 -0.00753387  0.0206592  -0.01741778]
#
# Debug: Returns for IYW, Forecast Period 16w: [-0.02151889  0.00130549 -0.01613448 -0.00790887 -0.02940831]
#
# Debug: Returns for IYW, Forecast Period 17w: [ 0.01089508  0.01704182  0.0016244  -0.00582052  0.02056651]
#
# Debug: Returns for IYW, Forecast Period 18w: [-7.81095954e-05 -2.27014782e-02 -1.03812943e-02  1.52956506e-02
#   2.37666607e-02]
#
# Debug: Returns for IYW, Forecast Period 19w: [ 0.01493509 -0.0049204  -0.00025623 -0.00159781  0.00256115]
#
# Debug: Returns for IYW, Forecast Period 20w: [ 0.00315052  0.00849396  0.02216953 -0.0025937  -0.00241726]
#
# Debug: Returns for IYW, Forecast Period 21w: [0.01306915 0.00129656 0.00032039 0.0018885  0.00921962]
#
# Debug: Returns for IYW, Forecast Period 22w: [ 0.01092104 -0.00509058 -0.025425   -0.00046037]
#
# Debug: Returns for IYW, Forecast Period 23w: [ 0.00780938  0.00137881  0.02665577 -0.00299709  0.00125621]
#
# Debug: Returns for IYW, Forecast Period 24w: [0.00323149 0.01469988 0.02256353 0.0066518  0.00561394]
#
# Debug: Returns for IYW, Forecast Period 25w: [ 0.01124267  0.00481289 -0.0136979  -0.00639646]
#
# Debug: Returns for IYW, Forecast Period 26w: [-0.01710898  0.01687087  0.00334303  0.00149254 -0.00412908]
#
# Debug: Returns for IYW, Forecast Period 27w: [0.01011043 0.00692696 0.01111518 0.00931343]
#
# Debug: Returns for IYW, Forecast Period 28w: [ 0.00510764 -0.0018659   0.01340019 -0.02432895  0.00674566]
#
# Debug: Returns for IYW, Forecast Period 29w: [ 0.00474635 -0.00310531 -0.03810185 -0.00542744 -0.01161761]
#
# Debug: Returns for IYW, Forecast Period 30w: [ 0.01955931 -0.0025451  -0.04351554 -0.010167    0.01003209]
#
# Debug: Returns for IYW, Forecast Period 31w: [-0.00378923 -0.02015695  0.03366938 -0.0323818  -0.02682228]
#
# Debug: Returns for IYW, Forecast Period 32w: [-0.03695904  0.00753857 -0.01257724  0.03364841  0.00530645]
#
# Debug: Returns for IYW, Forecast Period 33w: [0.0039969  0.02643429 0.00204158 0.02412875 0.00088163]
#
# Debug: Returns for IYW, Forecast Period 34w: [ 0.012884   -0.00394262  0.00502394 -0.02056451  0.01326852]
#
# Debug: Returns for IYW, Forecast Period 35w: [-0.01000359  0.00366928 -0.01298153 -0.00480553  0.01081788]
#
# Debug: Returns for IYW, Forecast Period 36w: [-0.04222512 -0.00419106 -0.00051323 -0.02413586]
#
# Debug: Returns for IYW, Forecast Period 37w: [0.01166694 0.01036114 0.02741146 0.00796039 0.00471417]
#
# Debug: Returns for IYW, Forecast Period 38w: [-0.00686433 -0.00029293 -0.0055378   0.02984443 -0.00382844]
#
# Debug: Returns for IYW, Forecast Period 39w: [-0.00162939  0.00650727  0.00295253  0.00922754 -0.00821984]
#
# Debug: Returns for IYW, Forecast Period 40w: [ 0.0036209  -0.02349388  0.00587025  0.00423093  0.01287216]
#
# Debug: Returns for IYW, Forecast Period 41w: [-0.0085187   0.0185059   0.00894943  0.00054281  0.00230728]
#
# Debug: Returns for IYW, Forecast Period 42w: [ 1.27984515e-02 -1.82436109e-02 -5.71019328e-05  2.79999556e-03
#   3.42805763e-03]
#
# Debug: Returns for IYW, Forecast Period 43w: [ 6.49395956e-03  1.96638937e-05 -1.61184013e-02  3.53034912e-03
#   6.02990533e-03]
#
# Debug: Returns for IYW, Forecast Period 44w: [ 0.00135319  0.01322585 -0.0120147  -0.03358783  0.00625845]
#
# Debug: Returns for IYW, Forecast Period 45w: [-0.00252782  0.01423375  0.02750628  0.02047113 -0.0018675 ]
#
# Debug: Returns for IYW, Forecast Period 46w: [-0.00488203  0.00316386 -0.00516843 -0.00360035 -0.02570634]
#
# Debug: Returns for IYW, Forecast Period 47w: [ 3.75619085e-03  1.19245455e-02 -1.96120767e-03  6.31291243e-03
#   9.32814223e-05]
#
# Debug: Returns for IYW, Forecast Period 48w: [-0.00034934  0.00437336 -0.01244332  0.00828847]
#
# Debug: Returns for XLK, Forecast Period 1w: [-0.02638982 -0.01054477 -0.00766128 -0.00069176]
#
# Debug: Returns for XLK, Forecast Period 2w: [0.02466189 0.00125487 0.00815623 0.00470833 0.00286407]
#
# Debug: Returns for XLK, Forecast Period 3w: [ 0.00210283 -0.00529442  0.01984572  0.02273067]
#
# Debug: Returns for XLK, Forecast Period 4w: [ 0.00422744  0.00400056  0.00682043  0.00412399 -0.01157962]
#
# Debug: Returns for XLK, Forecast Period 5w: [ 0.00905855 -0.00837174 -0.02117598  0.01249206  0.01040538]
#
# Debug: Returns for XLK, Forecast Period 6w: [ 0.00240343 -0.0044897   0.01317539  0.00316     0.0134491 ]
#
# Debug: Returns for XLK, Forecast Period 7w: [-0.00760539 -0.01704356  0.01028378 -0.00219869 -0.0093931 ]
#
# Debug: Returns for XLK, Forecast Period 8w: [-0.01055396 -0.00677143  0.0321282  -0.00276976]
#
# Debug: Returns for XLK, Forecast Period 9w: [ 0.00048373  0.00048985 -0.00519564  0.01070391  0.01806593]
#
# Debug: Returns for XLK, Forecast Period 10w: [-0.00020353 -0.02485477  0.00754526  0.01547594 -0.01518372]
#
# Debug: Returns for XLK, Forecast Period 11w: [-0.00320572  0.01996686 -0.01120436 -0.00014038 -0.01549601]
#
# Debug: Returns for XLK, Forecast Period 12w: [ 4.45849459e-03  4.77920331e-03  1.08878546e-02  5.37833092e-04
#  -3.14400756e-06]
#
# Debug: Returns for XLK, Forecast Period 13w: [-0.00696666 -0.00449673  0.00469744 -0.00253338]
#
# Debug: Returns for XLK, Forecast Period 14w: [ 0.0023416  -0.01016458  0.00210437 -0.01619824  0.01094696]
#
# Debug: Returns for XLK, Forecast Period 15w: [-0.00171217  0.00457186 -0.01268582  0.01936181 -0.01663252]
#
# Debug: Returns for XLK, Forecast Period 16w: [-0.01953722  0.00065677 -0.01499822 -0.01211494 -0.02146589]
#
# Debug: Returns for XLK, Forecast Period 17w: [ 0.00800241  0.01393258  0.00381237 -0.00290982  0.0105159 ]
#
# Debug: Returns for XLK, Forecast Period 18w: [ 0.00360935 -0.02273926 -0.01101669  0.01358688  0.02718568]
#
# Debug: Returns for XLK, Forecast Period 19w: [ 0.01121481 -0.00375302  0.00231846 -0.00076399  0.0031212 ]
#
# Debug: Returns for XLK, Forecast Period 20w: [ 0.00428456  0.00858444  0.02224648 -0.00349889 -0.00217325]
#
# Debug: Returns for XLK, Forecast Period 21w: [ 0.01192479  0.00178702  0.00231774 -0.00807954  0.00848477]
#
# Debug: Returns for XLK, Forecast Period 22w: [ 0.0042515  -0.00634351 -0.0227204   0.00161587]
#
# Debug: Returns for XLK, Forecast Period 23w: [ 0.00248289  0.00195194  0.02200067 -0.00343678  0.00218841]
#
# Debug: Returns for XLK, Forecast Period 24w: [0.00242191 0.01846206 0.02206973 0.00792362 0.00372772]
#
# Debug: Returns for XLK, Forecast Period 25w: [ 0.01521165  0.00142934 -0.01115995 -0.00177385]
#
# Debug: Returns for XLK, Forecast Period 26w: [-0.0246359   0.01817106 -0.0012834   0.00030497 -0.00069451]
#
# Debug: Returns for XLK, Forecast Period 27w: [0.00756805 0.00506788 0.01358013 0.00319415]
#
# Debug: Returns for XLK, Forecast Period 28w: [ 0.00684638 -0.00074198  0.01457336 -0.02492669  0.00878847]
#
# Debug: Returns for XLK, Forecast Period 29w: [ 0.0015791  -0.00360557 -0.03929565 -0.00059774 -0.01637688]
#
# Debug: Returns for XLK, Forecast Period 30w: [ 0.02293262 -0.00461826 -0.04196038 -0.01162098  0.01172987]
#
# Debug: Returns for XLK, Forecast Period 31w: [-0.00530882 -0.02606693  0.04119956 -0.0383087  -0.0294103 ]
#
# Debug: Returns for XLK, Forecast Period 32w: [-0.03485938  0.01188708 -0.01787765  0.03547508  0.0030778 ]
#
# Debug: Returns for XLK, Forecast Period 33w: [0.00674051 0.02931964 0.00428301 0.027958   0.00095533]
#
# Debug: Returns for XLK, Forecast Period 34w: [ 0.01594942 -0.00408255  0.00537557 -0.02324162  0.01595707]
#
# Debug: Returns for XLK, Forecast Period 35w: [-0.01285955  0.0057239  -0.01398397 -0.00956637  0.01298447]
#
# Debug: Returns for XLK, Forecast Period 36w: [-0.04610308 -0.00274705 -0.00183618 -0.0261939 ]
#
# Debug: Returns for XLK, Forecast Period 37w: [0.01581647 0.01447974 0.03368165 0.00787056 0.00463517]
#
# Debug: Returns for XLK, Forecast Period 38w: [-0.00433774 -0.00252043 -0.00984769  0.02899986 -0.00546964]
#
# Debug: Returns for XLK, Forecast Period 39w: [-0.00062676  0.00632852  0.00246652  0.01281778 -0.00963405]
#
# Debug: Returns for XLK, Forecast Period 40w: [ 0.00262999 -0.02477853  0.00727299  0.00408026  0.01109476]
#
# Debug: Returns for XLK, Forecast Period 41w: [-0.00670305  0.0187485   0.0112587  -0.00030514  0.00161915]
#
# Debug: Returns for XLK, Forecast Period 42w: [ 0.01290275 -0.022062    0.00293768  0.00300721  0.00337235]
#
# Debug: Returns for XLK, Forecast Period 43w: [ 0.00452928 -0.00118354 -0.01454009  0.00259465  0.00479084]
#
# Debug: Returns for XLK, Forecast Period 44w: [-0.00061307  0.0131263  -0.01601342 -0.03239799  0.00701415]
#
# Debug: Returns for XLK, Forecast Period 45w: [-0.00129222  0.01359769  0.02794081  0.01701977 -0.00143568]
#
# Debug: Returns for XLK, Forecast Period 46w: [-0.00590759  0.00076906 -0.00380067 -0.00380318 -0.02528781]
#
# Debug: Returns for XLK, Forecast Period 47w: [ 2.67197578e-03  7.60566292e-03 -1.40367735e-03  9.71708555e-03
#   7.50954088e-05]
#
# Debug: Returns for XLK, Forecast Period 48w: [-0.00054786  0.00451989 -0.01411457  0.00879328]
#
# Debug: Returns for VGT, Forecast Period 1w: [-0.02597463 -0.01327681 -0.00579561  0.00047018]
#
# Debug: Returns for VGT, Forecast Period 2w: [0.02570465 0.0020729  0.0087568  0.00374217 0.00248359]
#
# Debug: Returns for VGT, Forecast Period 3w: [ 0.00171296 -0.00522986  0.01969153  0.02204414]
#
# Debug: Returns for VGT, Forecast Period 4w: [ 0.00691928  0.0046619   0.00526555  0.00285692 -0.00994093]
#
# Debug: Returns for VGT, Forecast Period 5w: [ 0.01212177 -0.00923755 -0.02044189  0.01337611  0.01033518]
#
# Debug: Returns for VGT, Forecast Period 6w: [ 0.00105548 -0.00115135  0.01342923  0.00558841  0.01568298]
#
# Debug: Returns for VGT, Forecast Period 7w: [-0.00574521 -0.01916037  0.01380288 -0.0002656  -0.01017513]
#
# Debug: Returns for VGT, Forecast Period 8w: [-0.01151392 -0.00832453  0.03276451 -0.00308145]
#
# Debug: Returns for VGT, Forecast Period 9w: [ 0.00288042  0.00177084 -0.00439982  0.00978929  0.01901849]
#
# Debug: Returns for VGT, Forecast Period 10w: [ 0.00230415 -0.02371308  0.01145698  0.0172537  -0.01599764]
#
# Debug: Returns for VGT, Forecast Period 11w: [-0.00398523  0.02099987 -0.01028109 -0.00337443 -0.01283587]
#
# Debug: Returns for VGT, Forecast Period 12w: [0.00498309 0.00454736 0.0139634  0.00331787 0.00199146]
#
# Debug: Returns for VGT, Forecast Period 13w: [-0.00367089 -0.00401922  0.00273327 -0.00105672]
#
# Debug: Returns for VGT, Forecast Period 14w: [ 0.00236669 -0.01103077  0.00232542 -0.01584229  0.01240432]
#
# Debug: Returns for VGT, Forecast Period 15w: [-0.00118343  0.00258478 -0.00881626  0.01954273 -0.01752832]
#
# Debug: Returns for VGT, Forecast Period 16w: [-0.01884117  0.0008176  -0.01466235 -0.00933695 -0.02661142]
#
# Debug: Returns for VGT, Forecast Period 17w: [0.01359111 0.01641684 0.00163138 0.00048822 0.01727771]
#
# Debug: Returns for VGT, Forecast Period 18w: [ 0.00406631 -0.02209349 -0.01076612  0.0137651   0.02729885]
#
# Debug: Returns for VGT, Forecast Period 19w: [ 0.01479613 -0.00381419  0.00181205 -0.00068198  0.00287867]
#
# Debug: Returns for VGT, Forecast Period 20w: [ 0.00523252  0.01071413  0.02339653 -0.00364029 -0.00177668]
#
# Debug: Returns for VGT, Forecast Period 21w: [0.01348018 0.00167736 0.00088462 0.00069363 0.01041154]
#
# Debug: Returns for VGT, Forecast Period 22w: [ 0.0092743  -0.00283973 -0.02293077 -0.00023387]
#
# Debug: Returns for VGT, Forecast Period 23w: [ 0.00585555  0.00119259  0.02605586 -0.00222783  0.00051615]
#
# Debug: Returns for VGT, Forecast Period 24w: [0.00404636 0.01462773 0.02218982 0.01058151 0.00455311]
#
# Debug: Returns for VGT, Forecast Period 25w: [ 0.01298606  0.00480717 -0.01297982 -0.00449919]
#
# Debug: Returns for VGT, Forecast Period 26w: [-0.01779222  0.01493794  0.00255922  0.00253151  0.00019168]
#
# Debug: Returns for VGT, Forecast Period 27w: [0.01048656 0.00734645 0.01228744 0.00580629]
#
# Debug: Returns for VGT, Forecast Period 28w: [ 0.00737193 -0.00144157  0.01448531 -0.01858405  0.00992385]
#
# Debug: Returns for VGT, Forecast Period 29w: [ 0.00571586  0.00177922 -0.03564566 -0.00497751 -0.01163552]
#
# Debug: Returns for VGT, Forecast Period 30w: [ 0.02024226 -0.00149875 -0.03903756 -0.00929323  0.01198296]
#
# Debug: Returns for VGT, Forecast Period 31w: [-0.00351519 -0.01901321  0.03511401 -0.03617842 -0.02469394]
#
# Debug: Returns for VGT, Forecast Period 32w: [-0.03542931  0.00959794 -0.01200508  0.03432191  0.00625089]
#
# Debug: Returns for VGT, Forecast Period 33w: [0.00506306 0.02879743 0.00436464 0.02715277 0.00255991]
#
# Debug: Returns for VGT, Forecast Period 34w: [ 0.01434164 -0.00297375  0.00614631 -0.02039838  0.01846748]
#
# Debug: Returns for VGT, Forecast Period 35w: [-0.00893226  0.00519956 -0.01263187 -0.00230057  0.01098477]
#
# Debug: Returns for VGT, Forecast Period 36w: [-0.04363095 -0.00159263 -0.00173582 -0.02361452]
#
# Debug: Returns for VGT, Forecast Period 37w: [0.01385502 0.0105184  0.02925976 0.00813759 0.00634908]
#
# Debug: Returns for VGT, Forecast Period 38w: [-0.00550977 -0.00016425 -0.00438226  0.02997494 -0.00310531]
#
# Debug: Returns for VGT, Forecast Period 39w: [ 0.00011465  0.00952462  0.00118329  0.01288872 -0.00689683]
#
# Debug: Returns for VGT, Forecast Period 40w: [ 0.00315345 -0.02480511  0.00693388  0.0045739   0.01351608]
#
# Debug: Returns for VGT, Forecast Period 41w: [-0.00642993  0.01899947  0.01195685  0.00157941  0.00376192]
#
# Debug: Returns for VGT, Forecast Period 42w: [ 0.01307522 -0.01737353  0.00438003  0.00468034  0.00411015]
#
# Debug: Returns for VGT, Forecast Period 43w: [ 6.25956344e-03 -4.89001799e-05 -1.49530035e-02  3.94747522e-03
#   5.23672578e-03]
#
# Debug: Returns for VGT, Forecast Period 44w: [ 0.00256473  0.01235466 -0.01247284 -0.03284046  0.00759148]
#
# Debug: Returns for VGT, Forecast Period 45w: [-0.00059216  0.01494029  0.03178381  0.02099348 -0.00120655]
#
# Debug: Returns for VGT, Forecast Period 46w: [-0.00356685  0.00221699 -0.00354963 -0.00359825 -0.02397522]
#
# Debug: Returns for VGT, Forecast Period 47w: [0.00333712 0.01272679 0.0014752  0.01105031 0.00418717]
#
# Debug: Returns for VGT, Forecast Period 48w: [-7.95570432e-05  3.46698100e-03 -9.93477341e-03  9.36007746e-03]
#
# Debug: Returns for FTEC, Forecast Period 1w: [-0.02531379 -0.01028307 -0.00588785  0.00219661]
#
# Debug: Returns for FTEC, Forecast Period 2w: [0.02672399 0.00273394 0.01021695 0.0057928  0.00412478]
#
# Debug: Returns for FTEC, Forecast Period 3w: [ 0.00304846 -0.00382318  0.02126768  0.02376348]
#
# Debug: Returns for FTEC, Forecast Period 4w: [ 0.00796644  0.00544607  0.00607029  0.00394787 -0.00850275]
#
# Debug: Returns for FTEC, Forecast Period 5w: [ 0.01276957 -0.00689392 -0.02014674  0.0140505   0.01102114]
#
# Debug: Returns for FTEC, Forecast Period 6w: [ 0.00200149 -0.00154674  0.01426346  0.00674968  0.01601598]
#
# Debug: Returns for FTEC, Forecast Period 7w: [-0.00538824 -0.01810415  0.01428767 -0.00060287 -0.00887196]
#
# Debug: Returns for FTEC, Forecast Period 8w: [-0.00933595 -0.00717532  0.03442725 -0.00155202]
#
# Debug: Returns for FTEC, Forecast Period 9w: [ 0.00370461  0.00220285 -0.00237738  0.01078973  0.02055817]
#
# Debug: Returns for FTEC, Forecast Period 10w: [ 0.00214605 -0.021837    0.01224206  0.01830768 -0.0148383 ]
#
# Debug: Returns for FTEC, Forecast Period 11w: [-0.0027743   0.02200518 -0.00851493 -0.00223288 -0.01215602]
#
# Debug: Returns for FTEC, Forecast Period 12w: [0.0067281  0.00633259 0.0143224  0.00365197 0.00358451]
#
# Debug: Returns for FTEC, Forecast Period 13w: [-0.00254278 -0.00385608  0.00486068 -0.00031815]
#
# Debug: Returns for FTEC, Forecast Period 14w: [ 0.00203706 -0.00782366  0.00382463 -0.01420827  0.01372387]
#
# Debug: Returns for FTEC, Forecast Period 15w: [ 0.0004267   0.00554931 -0.00908913  0.0227631  -0.01602471]
#
# Debug: Returns for FTEC, Forecast Period 16w: [-0.0193106   0.0046505  -0.01402714 -0.00658244 -0.02443427]
#
# Debug: Returns for FTEC, Forecast Period 17w: [0.01474695 0.02053296 0.00462535 0.00422579 0.01856218]
#
# Debug: Returns for FTEC, Forecast Period 18w: [ 0.0049249  -0.01935252 -0.00917457  0.01717887  0.02812445]
#
# Debug: Returns for FTEC, Forecast Period 19w: [ 0.01785273 -0.00377081  0.0024971   0.00136574  0.00505676]
#
# Debug: Returns for FTEC, Forecast Period 20w: [ 0.00648665  0.01090434  0.02502642 -0.00266632 -0.00233211]
#
# Debug: Returns for FTEC, Forecast Period 21w: [0.01323811 0.00229381 0.00210949 0.00129564 0.0106356 ]
#
# Debug: Returns for FTEC, Forecast Period 22w: [ 0.01091339 -0.00409147 -0.02230735 -0.0010292 ]
#
# Debug: Returns for FTEC, Forecast Period 23w: [ 0.00775522  0.00305865  0.0278929  -0.00243016  0.00087058]
#
# Debug: Returns for FTEC, Forecast Period 24w: [0.00583639 0.01489687 0.02460682 0.0103114  0.00527433]
#
# Debug: Returns for FTEC, Forecast Period 25w: [ 0.01325016  0.0051531  -0.01184989 -0.00393565]
#
# Debug: Returns for FTEC, Forecast Period 26w: [-0.01676126  0.01566605  0.00503624  0.00369546  0.00013998]
#
# Debug: Returns for FTEC, Forecast Period 27w: [0.01085999 0.0082813  0.01239118 0.00630977]
#
# Debug: Returns for FTEC, Forecast Period 28w: [ 0.01014208 -0.00228764  0.01477418 -0.01908822  0.01255501]
#
# Debug: Returns for FTEC, Forecast Period 29w: [ 0.00631231  0.00324086 -0.03405645 -0.00279249 -0.00949547]
#
# Debug: Returns for FTEC, Forecast Period 30w: [ 0.02111994  0.00078885 -0.03654858 -0.00661975  0.01342925]
#
# Debug: Returns for FTEC, Forecast Period 31w: [-0.00135604 -0.01699956  0.03871619 -0.03245415 -0.02311829]
#
# Debug: Returns for FTEC, Forecast Period 32w: [-0.03064006  0.0133045  -0.00902063  0.03919814  0.00731247]
#
# Debug: Returns for FTEC, Forecast Period 33w: [0.00925046 0.03216031 0.00705286 0.02904065 0.00447774]
#
# Debug: Returns for FTEC, Forecast Period 34w: [ 0.01533654 -0.00160334  0.00829716 -0.01755117  0.01805678]
#
# Debug: Returns for FTEC, Forecast Period 35w: [-0.00883062  0.00663664 -0.01110938 -0.00140682  0.01122659]
#
# Debug: Returns for FTEC, Forecast Period 36w: [-0.04155198 -0.00164499  0.00013167 -0.02180923]
#
# Debug: Returns for FTEC, Forecast Period 37w: [0.01451527 0.01290335 0.030412   0.0096063  0.00836811]
#
# Debug: Returns for FTEC, Forecast Period 38w: [-0.00478092  0.00301451 -0.00353176  0.03313296 -0.00131288]
#
# Debug: Returns for FTEC, Forecast Period 39w: [ 0.00071174  0.00985271  0.00372612  0.01465794 -0.00607697]
#
# Debug: Returns for FTEC, Forecast Period 40w: [ 0.00533213 -0.02361017  0.00835901  0.00553031  0.01382151]
#
# Debug: Returns for FTEC, Forecast Period 41w: [-0.00537105  0.0186454   0.01264895  0.00324312  0.00486916]
#
# Debug: Returns for FTEC, Forecast Period 42w: [ 0.01385464 -0.01476293  0.0035926   0.00472116  0.00594608]
#
# Debug: Returns for FTEC, Forecast Period 43w: [ 0.00737067  0.00055518 -0.01280864  0.00542133  0.00741394]
#
# Debug: Returns for FTEC, Forecast Period 44w: [ 0.00298949  0.01501739 -0.01296414 -0.03092666  0.00990321]
#
# Debug: Returns for FTEC, Forecast Period 45w: [0.00095384 0.01677927 0.03296311 0.02260613 0.00065407]
#
# Debug: Returns for FTEC, Forecast Period 46w: [-0.00220734  0.00287707 -0.00235708 -0.00218168 -0.02151765]
#
# Debug: Returns for FTEC, Forecast Period 47w: [0.00478475 0.01450146 0.00262088 0.0127082  0.00529852]
#
# Debug: Returns for FTEC, Forecast Period 48w: [ 0.00192827  0.00507838 -0.00914781  0.01186229]
#
# Debug: Returns for IGM, Forecast Period 1w: [-0.02649239 -0.01202693 -0.00415826  0.00221379]
#
# Debug: Returns for IGM, Forecast Period 2w: [0.027678   0.00336611 0.00989    0.0054952  0.00179023]
#
# Debug: Returns for IGM, Forecast Period 3w: [ 0.00184106 -0.00572134  0.01754578  0.02506179]
#
# Debug: Returns for IGM, Forecast Period 4w: [ 0.00462638  0.00488582  0.00998399  0.0056415  -0.00898385]
#
# Debug: Returns for IGM, Forecast Period 5w: [ 0.01335021 -0.00735224 -0.02484283  0.01166696  0.02832434]
#
# Debug: Returns for IGM, Forecast Period 6w: [ 0.00164641 -0.00511799  0.01567848  0.0056758   0.01517145]
#
# Debug: Returns for IGM, Forecast Period 7w: [-0.00488007 -0.01802115  0.01774745 -0.00051619 -0.01203449]
#
# Debug: Returns for IGM, Forecast Period 8w: [-0.01431859 -0.01078595  0.04290273 -0.00243969]
#
# Debug: Returns for IGM, Forecast Period 9w: [ 0.00080818  0.0016451  -0.00715549  0.01240144  0.02129549]
#
# Debug: Returns for IGM, Forecast Period 10w: [ 0.00121835 -0.02037201  0.01222722  0.02098063 -0.01977142]
#
# Debug: Returns for IGM, Forecast Period 11w: [-0.00780474  0.02209699 -0.00951329 -0.00615756 -0.01483402]
#
# Debug: Returns for IGM, Forecast Period 12w: [0.01053841 0.00158713 0.01347896 0.00267405 0.003213  ]
#
# Debug: Returns for IGM, Forecast Period 13w: [-0.00502516 -0.0040731   0.00055555 -0.00209535]
#
# Debug: Returns for IGM, Forecast Period 14w: [ 0.00525947 -0.00795831  0.00359386 -0.01731178  0.01294609]
#
# Debug: Returns for IGM, Forecast Period 15w: [-0.00094054  0.00336524 -0.00955078  0.0171796  -0.01851078]
#
# Debug: Returns for IGM, Forecast Period 16w: [-0.02091298  0.00185191 -0.01372789 -0.00563047 -0.02857274]
#
# Debug: Returns for IGM, Forecast Period 17w: [ 0.00988466  0.01886936 -0.00022725 -0.01029567  0.0231261 ]
#
# Debug: Returns for IGM, Forecast Period 18w: [-0.00425542 -0.02025992 -0.00882493  0.01472586  0.02039912]
#
# Debug: Returns for IGM, Forecast Period 19w: [ 0.01587602 -0.00166647 -0.00129679 -0.00187308  0.0020557 ]
#
# Debug: Returns for IGM, Forecast Period 20w: [ 0.00121399  0.00859069  0.02338966 -0.00348415 -0.00105233]
#
# Debug: Returns for IGM, Forecast Period 21w: [ 0.01107313 -0.00079914  0.00140658 -0.00326561  0.00907297]
#
# Debug: Returns for IGM, Forecast Period 22w: [ 0.00830264 -0.0053597  -0.02467584 -0.00089176]
#
# Debug: Returns for IGM, Forecast Period 23w: [ 0.00465535  0.00222731  0.0261715  -0.00264953 -0.00151653]
#
# Debug: Returns for IGM, Forecast Period 24w: [0.00583356 0.01039026 0.01851814 0.00506667 0.00638859]
#
# Debug: Returns for IGM, Forecast Period 25w: [ 0.0102459   0.00287977 -0.009793   -0.00380717]
#
# Debug: Returns for IGM, Forecast Period 26w: [-0.0148582   0.01492257  0.00039431  0.00530126 -0.00344848]
#
# Debug: Returns for IGM, Forecast Period 27w: [0.00665271 0.007398   0.0094835  0.01155307]
#
# Debug: Returns for IGM, Forecast Period 28w: [ 0.0027897  -0.00291627  0.01092039 -0.02216295  0.00565358]
#
# Debug: Returns for IGM, Forecast Period 29w: [ 0.00517325 -0.00047601 -0.03781544 -0.00408547 -0.01118434]
#
# Debug: Returns for IGM, Forecast Period 30w: [ 0.01914467 -0.00217514 -0.04009559 -0.01033935  0.01147324]
#
# Debug: Returns for IGM, Forecast Period 31w: [-0.00421936 -0.0165881   0.03072071 -0.02692822 -0.03060177]
#
# Debug: Returns for IGM, Forecast Period 32w: [-0.03265821  0.01059386 -0.01081763  0.03447831  0.00596348]
#
# Debug: Returns for IGM, Forecast Period 33w: [-0.00015348  0.0250523  -0.00017506  0.02491507 -0.00011642]
#
# Debug: Returns for IGM, Forecast Period 34w: [ 0.01233454 -0.00242292  0.00552548 -0.01840942  0.01234438]
#
# Debug: Returns for IGM, Forecast Period 35w: [-0.01026807  0.00342014 -0.01336337 -0.00081078  0.01019243]
#
# Debug: Returns for IGM, Forecast Period 36w: [-0.03918229 -0.00235175 -0.00032272 -0.02722797]
#
# Debug: Returns for IGM, Forecast Period 37w: [0.010058   0.00927124 0.0241535  0.00919959 0.00602435]
#
# Debug: Returns for IGM, Forecast Period 38w: [-0.00223191  0.00035874 -0.00545192  0.02863575 -0.00182837]
#
# Debug: Returns for IGM, Forecast Period 39w: [ 0.00029222  0.00582954  0.00064943  0.01139675 -0.00723886]
#
# Debug: Returns for IGM, Forecast Period 40w: [ 0.00301436 -0.01862237  0.00500296  0.00481318  0.01337881]
#
# Debug: Returns for IGM, Forecast Period 41w: [-0.00998892  0.01713897  0.00814451 -0.00038573  0.0038265 ]
#
# Debug: Returns for IGM, Forecast Period 42w: [ 0.00985608 -0.01719097 -0.0003529   0.00055472  0.00496356]
#
# Debug: Returns for IGM, Forecast Period 43w: [ 3.09907802e-03 -5.86883488e-05 -1.60754119e-02  2.81613859e-03
#   5.93039109e-03]
#
# Debug: Returns for IGM, Forecast Period 44w: [ 0.00231389  0.01525788 -0.01096516 -0.02905156  0.00568068]
#
# Debug: Returns for IGM, Forecast Period 45w: [-0.00333757  0.01390396  0.02936379  0.0215046  -0.00246939]
#
# Debug: Returns for IGM, Forecast Period 46w: [-0.00227445  0.00318807 -0.00433339 -0.00725881 -0.02494899]
#
# Debug: Returns for IGM, Forecast Period 47w: [ 5.28738558e-03  1.07480547e-02 -8.68366013e-05  5.97243323e-03
#   5.70347118e-04]
#
# Debug: Returns for IGM, Forecast Period 48w: [ 0.00217903  0.00297019 -0.01094016  0.00835357]
#
# Debug: Returns for IXN, Forecast Period 1w: [-2.72962277e-02 -1.16897177e-02 -5.72561275e-03  5.49354299e-05]
#
# Debug: Returns for IXN, Forecast Period 2w: [ 0.02501415 -0.00072199  0.00879246  0.00407462  0.00396639]
#
# Debug: Returns for IXN, Forecast Period 3w: [-3.42495501e-05 -5.29635037e-03  2.14169900e-02  2.30064672e-02]
#
# Debug: Returns for IXN, Forecast Period 4w: [ 0.00451244  0.00418838  0.00814609  0.00494257 -0.00927751]
#
# Debug: Returns for IXN, Forecast Period 5w: [ 0.00890811 -0.00729671 -0.01943985  0.01334713  0.01071347]
#
# Debug: Returns for IXN, Forecast Period 6w: [ 0.00300976 -0.00209424  0.01379748  0.00543334  0.01191422]
#
# Debug: Returns for IXN, Forecast Period 7w: [-0.00798967 -0.01742725  0.01203199 -0.00030699 -0.00869848]
#
# Debug: Returns for IXN, Forecast Period 8w: [-0.00978978 -0.00575803  0.03235428  0.00020332]
#
# Debug: Returns for IXN, Forecast Period 9w: [ 0.00089396 -0.00092981 -0.004214    0.00961767  0.01888154]
#
# Debug: Returns for IXN, Forecast Period 10w: [ 0.00218617 -0.02223486  0.01089352  0.01745347 -0.01429633]
#
# Debug: Returns for IXN, Forecast Period 11w: [-0.00656528  0.02174212 -0.00958081 -0.00039458 -0.01491235]
#
# Debug: Returns for IXN, Forecast Period 12w: [0.0060984  0.00420366 0.0148793  0.00275099 0.00254748]
#
# Debug: Returns for IXN, Forecast Period 13w: [-0.00565961 -0.00476572  0.00222763 -0.00163518]
#
# Debug: Returns for IXN, Forecast Period 14w: [ 0.00329028 -0.00801254  0.00213541 -0.01639929  0.01188534]
#
# Debug: Returns for IXN, Forecast Period 15w: [-0.002089    0.00478631 -0.01138226  0.02084314 -0.01796172]
#
# Debug: Returns for IXN, Forecast Period 16w: [-0.01836755  0.00173281 -0.01761933 -0.01022418 -0.02692997]
#
# Debug: Returns for IXN, Forecast Period 17w: [ 0.00915711  0.01599684  0.00448879 -0.00148697  0.01465953]
#
# Debug: Returns for IXN, Forecast Period 18w: [ 0.00336134 -0.02209505 -0.00946164  0.01443461  0.02815597]
#
# Debug: Returns for IXN, Forecast Period 19w: [ 0.01380119 -0.00336307  0.00263183 -0.00256254  0.00349094]
#
# Debug: Returns for IXN, Forecast Period 20w: [ 0.00349797  0.01077846  0.0219894  -0.00390889 -0.00352979]
#
# Debug: Returns for IXN, Forecast Period 21w: [0.01318739 0.00187589 0.00144213 0.00250963 0.01028276]
#
# Debug: Returns for IXN, Forecast Period 22w: [ 0.01070864 -0.00696996 -0.01950447 -0.00202854]
#
# Debug: Returns for IXN, Forecast Period 23w: [ 0.01020862  0.00280396  0.0266316  -0.0013278   0.00111711]
#
# Debug: Returns for IXN, Forecast Period 24w: [0.00356855 0.01413098 0.02760087 0.00764785 0.00311968]
#
# Debug: Returns for IXN, Forecast Period 25w: [ 0.01420013  0.00564406 -0.01167494 -0.00571401]
#
# Debug: Returns for IXN, Forecast Period 26w: [-0.02026104  0.01735134  0.00067139  0.00136787 -0.00116931]
#
# Debug: Returns for IXN, Forecast Period 27w: [0.01024441 0.00658596 0.0161824  0.00584712]
#
# Debug: Returns for IXN, Forecast Period 28w: [ 0.00875764 -0.00035637  0.01645996 -0.02378719  0.00663259]
#
# Debug: Returns for IXN, Forecast Period 29w: [ 0.00066189  0.00027043 -0.04091592 -0.00394725 -0.01393023]
#
# Debug: Returns for IXN, Forecast Period 30w: [ 0.01927665 -0.00138043 -0.04161495 -0.01185554  0.01119477]
#
# Debug: Returns for IXN, Forecast Period 31w: [-0.00485686 -0.02110467  0.04414685 -0.03801774 -0.0287875 ]
#
# Debug: Returns for IXN, Forecast Period 32w: [-0.03409623  0.01147796 -0.01241146  0.03395893  0.00416201]
#
# Debug: Returns for IXN, Forecast Period 33w: [0.00619931 0.03004687 0.00333314 0.02670895 0.0031976 ]
#
# Debug: Returns for IXN, Forecast Period 34w: [ 0.01524657 -0.00356488  0.00632997 -0.02246202  0.01715179]
#
# Debug: Returns for IXN, Forecast Period 35w: [-0.01485885  0.00792425 -0.01121078 -0.00746504  0.01066612]
#
# Debug: Returns for IXN, Forecast Period 36w: [-0.04601204 -0.00261078 -0.00219587 -0.02730283]
#
# Debug: Returns for IXN, Forecast Period 37w: [0.01602019 0.01089661 0.0331789  0.00819193 0.00487652]
#
# Debug: Returns for IXN, Forecast Period 38w: [-0.00535077 -0.0027928  -0.00578209  0.02958033 -0.00660797]
#
# Debug: Returns for IXN, Forecast Period 39w: [ 0.00089905  0.00576582  0.00030851  0.01648455 -0.01067205]
#
# Debug: Returns for IXN, Forecast Period 40w: [ 0.00100308 -0.02085283  0.00496957  0.00088392  0.00966675]
#
# Debug: Returns for IXN, Forecast Period 41w: [-0.0089708   0.01860322  0.01236595 -0.00300581  0.0032641 ]
#
# Debug: Returns for IXN, Forecast Period 42w: [ 0.01106347 -0.01934141  0.00043159  0.00680023  0.00397127]
#
# Debug: Returns for IXN, Forecast Period 43w: [ 3.81762566e-03  8.37354368e-05 -1.52668080e-02  2.85272768e-03
#   4.89748036e-03]
#
# Debug: Returns for IXN, Forecast Period 44w: [-0.00054979  0.01253146 -0.01435983 -0.02874177  0.00335738]
#
# Debug: Returns for IXN, Forecast Period 45w: [-0.00182947  0.01423674  0.01763136  0.01986946 -0.00371825]
#
# Debug: Returns for IXN, Forecast Period 46w: [-0.00808601  0.00031296 -0.00323499 -0.00182911 -0.02080001]
#
# Debug: Returns for IXN, Forecast Period 47w: [ 0.00559345  0.00516039 -0.00185835  0.00713937  0.00269757]
#
# Debug: Returns for IXN, Forecast Period 48w: [ 0.00269318  0.00326729 -0.01099821  0.01030608]

# %%
# Initialize an empty dictionary to hold DataFrames for each week
weekly_scores_dfs = {}

# Assuming weekly_scores is a dictionary with keys as week identifiers ('1w', '2w', ..., '48w') 
# and values as the respective scores
for week_key, scores in weekly_scores.items():
    # Convert scores for the current week into a DataFrame
    weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    
# Create DataFrame variables dynamically for 48 weeks
for week in range(1, 49):
    week_key = f'{week}w'
    globals()[f'df_scores_{week_key}'] = weekly_scores_dfs.get(week_key, pd.DataFrame())

# %%
# Initialize a dictionary to hold the top 2 ETFs for each week
top_etfs_weekly = {}

# Loop through the weekly DataFrames and select the top 2 ETFs for each week
for week_key, df_scores in weekly_scores_dfs.items():
    # Select the top 2 ETFs based on the 'Score' column
    top_etfs_weekly[week_key] = df_scores.nlargest(2, 'SmoothedScore')
    
    # Print the results for the current week
    print(f"\nTop 2 ETFs for {week_key} forecast:")
    print(top_etfs_weekly[week_key])
# Out:
# Top 2 ETFs for 1w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   1w             0.1  1.523621       1.523621
# 1  SOXX   1w             0.1 -0.336284       1.151640
#
# Top 2 ETFs for 2w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   2w             0.1       NaN            NaN
# 1  SOXX   2w             0.1       NaN            NaN
#
# Top 2 ETFs for 3w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   3w             0.1  5.630022       5.630022
# 1  SOXX   3w             0.1  2.999985       5.104015
#
# Top 2 ETFs for 4w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN   4w             0.1  3.076670       1.458699
# 8  IGM   4w             0.1  4.862167       1.054207
#
# Top 2 ETFs for 5w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   5w             0.1  3.093095       3.093095
# 1  SOXX   5w             0.1 -2.101163       2.054244
#
# Top 2 ETFs for 6w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   6w             0.1  2.406587       2.406587
# 1  SOXX   6w             0.1 -1.422457       1.640779
#
# Top 2 ETFs for 7w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 2  PSI   7w             0.1  5.606255       0.922667
# 3  XSD   7w             0.1  0.830049       0.904143
#
# Top 2 ETFs for 8w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   8w             0.1  3.470734       3.470734
# 1  SOXX   8w             0.1  0.950044       2.966596
#
# Top 2 ETFs for 9w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 2  PSI   9w             0.1  7.988909       1.583069
# 3  XSD   9w             0.1  0.945228       1.455500
#
# Top 2 ETFs for 10w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  10w             0.1  3.982058       3.982058
# 1  SOXX  10w             0.1  1.934335       3.572513
#
# Top 2 ETFs for 11w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  11w             0.1  2.964511       1.127005
# 8  IGM  11w             0.1  1.606349       0.667628
#
# Top 2 ETFs for 12w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  12w             0.1       NaN            NaN
# 1  SOXX  12w             0.1       NaN            NaN
#
# Top 2 ETFs for 13w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3  XSD  13w             0.1  7.811311       1.330968
# 4  IYW  13w             0.1 -3.618169       0.341141
#
# Top 2 ETFs for 14w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  14w             0.1  2.142797       0.111591
# 9  IXN  14w             0.1 -0.023881       0.084497
#
# Top 2 ETFs for 15w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  15w             0.1  7.195694       0.562627
# 9   IXN  15w             0.1  0.632021       0.265259
#
# Top 2 ETFs for 16w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  16w             0.1  2.279101       0.420108
# 9  IXN  16w             0.1  0.206229       0.377332
#
# Top 2 ETFs for 17w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  17w             0.1       NaN            NaN
# 1  SOXX  17w             0.1       NaN            NaN
#
# Top 2 ETFs for 18w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9   IXN  18w             0.1  2.796207       0.594193
# 7  FTEC  18w             0.1  4.561377       0.121916
#
# Top 2 ETFs for 19w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  19w             0.1  0.545799       0.228993
# 8  IGM  19w             0.1  0.700642       0.149792
#
# Top 2 ETFs for 20w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  20w             0.1  0.520072       0.223892
# 7  FTEC  20w             0.1  4.260661       0.149847
#
# Top 2 ETFs for 21w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  21w             0.1       NaN            NaN
# 1  SOXX  21w             0.1       NaN            NaN
#
# Top 2 ETFs for 22w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3  XSD  22w             0.1  6.887180       0.163322
# 4  IYW  22w             0.1 -0.127662       0.105125
#
# Top 2 ETFs for 23w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  23w             0.1  6.239764       1.356931
# 0  SMH  23w             0.1  0.381794       0.381794
#
# Top 2 ETFs for 24w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  24w             0.1       NaN            NaN
# 1  SOXX  24w             0.1       NaN            NaN
#
# Top 2 ETFs for 25w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  25w             0.1  2.418387       0.606179
# 8  IGM  25w             0.1  1.773607       0.153127
#
# Top 2 ETFs for 26w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  26w             0.1  1.304352      -0.038790
# 9  IXN  26w             0.1 -1.034910      -0.238014
#
# Top 2 ETFs for 27w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  27w             0.1       NaN            NaN
# 1  SOXX  27w             0.1       NaN            NaN
#
# Top 2 ETFs for 28w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3  XSD  28w             0.1  9.750974       1.868653
# 4  IYW  28w             0.1 -2.850767       0.924769
#
# Top 2 ETFs for 29w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  29w             0.1  3.079117       0.139139
# 8   IGM  29w             0.1 -0.134311       0.084449
#
# Top 2 ETFs for 30w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  30w             0.1  7.735650       0.392446
# 8   IGM  30w             0.1 -0.490788       0.215800
#
# Top 2 ETFs for 31w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9   IXN  31w             0.1  3.823469       1.054338
# 7  FTEC  31w             0.1  6.464473       0.387519
#
# Top 2 ETFs for 32w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  32w             0.1  0.526413       0.047841
# 7  FTEC  32w             0.1  3.582929      -0.071802
#
# Top 2 ETFs for 33w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  33w             0.1       NaN            NaN
# 1  SOXX  33w             0.1       NaN            NaN
#
# Top 2 ETFs for 34w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  34w             0.1  0.555140       0.224492
# 8  IGM  34w             0.1  0.469297       0.141829
#
# Top 2 ETFs for 35w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  35w             0.1  0.208779       0.035560
# 7  FTEC  35w             0.1  3.178197      -0.007744
#
# Top 2 ETFs for 36w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  36w             0.1  2.006703       0.173452
# 9  IXN  36w             0.1 -0.952153      -0.051669
#
# Top 2 ETFs for 37w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  37w             0.1       NaN            NaN
# 1  SOXX  37w             0.1       NaN            NaN
#
# Top 2 ETFs for 38w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  38w             0.1  3.743500       0.715003
# 9  IXN  38w             0.1 -0.587047       0.454593
#
# Top 2 ETFs for 39w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3   XSD  39w             0.1  5.789379       0.997920
# 7  FTEC  39w             0.1  3.435958       0.462098
#
# Top 2 ETFs for 40w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  40w             0.1  5.777533       1.305646
# 9  IXN  40w             0.1 -1.507327       0.743051
#
# Top 2 ETFs for 41w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 2  PSI  41w             0.1  8.016191       3.416782
# 0  SMH  41w             0.1  3.190669       3.190669
#
# Top 2 ETFs for 42w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9   IXN  42w             0.1  1.978726       0.567349
# 7  FTEC  42w             0.1  3.199555       0.316637
#
# Top 2 ETFs for 43w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  43w             0.1  7.733907       1.085802
# 8   IGM  43w             0.1 -2.734064       0.321828
#
# Top 2 ETFs for 44w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  44w             0.1  4.960828       1.066891
# 9  IXN  44w             0.1 -1.706719       0.512169
#
# Top 2 ETFs for 45w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  45w             0.1       NaN            NaN
# 1  SOXX  45w             0.1       NaN            NaN
#
# Top 2 ETFs for 46w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  46w             0.1  0.990943       0.516143
# 8  IGM  46w             0.1  1.043955       0.397443
#
# Top 2 ETFs for 47w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  47w             0.1       NaN            NaN
# 1  SOXX  47w             0.1       NaN            NaN
#
# Top 2 ETFs for 48w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  48w             0.1 -0.023215      -0.405348
# 8  IGM  48w             0.1  0.251814      -0.500881

# %%
# Function to generate week ranges
def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []
    
    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)
    
    return week_ranges

# Function to gather ETF data for weeks
def gather_etf_data_for_weeks(tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date)
            if etf_data.empty:
                print(f"No data found for {ticker} in {week}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[week][ticker] = etf_data
            #print(f"Data for {ticker} in {week} gathered.")
    return etf_histories

# Function to initialize shares for the first week
def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]
    
    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)
        
        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]
            
            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st week: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares

# Function to manage ETF portfolio weekly
def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

# %%
# Generate Week Ranges
week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')
#print("Generated Week Ranges:", week_ranges)

# Assuming `tickers` is a list of ETF tickers
tickers = tickers

# Gather ETF Data
etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)
#print(f"ETF Histories Collected for {len(etf_histories)} weeks")

# Create a mapping between week numbers and date ranges
week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

# Debug: Print the week key mapping
print("Week Key Mapping:", week_key_mapping)

# Align `top_etfs_weekly` Keys with `etf_histories`
aligned_top_etfs_weekly = {}

for week_key, df_scores in weekly_scores_dfs.items():
    # Call the `select_top_etfs_weekly` function here
    forecast_period = week_key_mapping.get(week_key, None)
    if forecast_period:
        aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

# Portfolio initialization and management
ticker_shares = {}
ticker_shares_per_week = {}

for i, week_range in enumerate(etf_histories.keys()):
    current_week_key = week_range
    if i == 0:
        # First week initialization
        ticker_shares = initialize_shares_for_first_week(
            aligned_top_etfs_weekly[current_week_key],
            etf_histories,
            current_week_key
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()
    else:
        # Subsequent weeks' portfolio management
        prev_week_key = list(etf_histories.keys())[i - 1]
        ticker_shares = manage_etf_portfolio_weekly(
            aligned_top_etfs_weekly[prev_week_key],
            aligned_top_etfs_weekly[current_week_key],
            prev_week_key,
            current_week_key,
            ticker_shares,
            etf_histories
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()

print("\nFinal Ticker Shares per Week:")
for week, shares in ticker_shares_per_week.items():
    print(f"Week {week}: {shares}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Week Key Mapping: {'1w': '2024-01-01 to 2024-01-07', '2w': '2024-01-08 to 2024-01-14', '3w': '2024-01-15 to 2024-01-21', '4w': '2024-01-22 to 2024-01-28', '5w': '2024-01-29 to 2024-02-04', '6w': '2024-02-05 to 2024-02-11', '7w': '2024-02-12 to 2024-02-18', '8w': '2024-02-19 to 2024-02-25', '9w': '2024-02-26 to 2024-03-03', '10w': '2024-03-04 to 2024-03-10', '11w': '2024-03-11 to 2024-03-17', '12w': '2024-03-18 to 2024-03-24', '13w': '2024-03-25 to 2024-03-31', '14w': '2024-04-01 to 2024-04-07', '15w': '2024-04-08 to 2024-04-14', '16w': '2024-04-15 to 2024-04-21', '17w': '2024-04-22 to 2024-04-28', '18w': '2024-04-29 to 2024-05-05', '19w': '2024-05-06 to 2024-05-12', '20w': '2024-05-13 to 2024-05-19', '21w': '2024-05-20 to 2024-05-26', '22w': '2024-05-27 to 2024-06-02', '23w': '2024-06-03 to 2024-06-09', '24w': '2024-06-10 to 2024-06-16', '25w': '2024-06-17 to 2024-06-23', '26w': '2024-06-24 to 2024-06-30', '27w': '2024-07-01 to 2024-07-07', '28w': '2024-07-08 to 2024-07-14', '29w': '2024-07-15 to 2024-07-21', '30w': '2024-07-22 to 2024-07-28', '31w': '2024-07-29 to 2024-08-04', '32w': '2024-08-05 to 2024-08-11', '33w': '2024-08-12 to 2024-08-18', '34w': '2024-08-19 to 2024-08-25', '35w': '2024-08-26 to 2024-09-01', '36w': '2024-09-02 to 2024-09-08', '37w': '2024-09-09 to 2024-09-15', '38w': '2024-09-16 to 2024-09-22', '39w': '2024-09-23 to 2024-09-29', '40w': '2024-09-30 to 2024-10-06', '41w': '2024-10-07 to 2024-10-13', '42w': '2024-10-14 to 2024-10-20', '43w': '2024-10-21 to 2024-10-27', '44w': '2024-10-28 to 2024-11-03', '45w': '2024-11-04 to 2024-11-10', '46w': '2024-11-11 to 2024-11-17', '47w': '2024-11-18 to 2024-11-24', '48w': '2024-11-25 to 2024-12-01'}
# Shares 1st week: (50000 * 0.975) / 168.97000122070312
# Ticker: SMH, First trading day: 2024-01-02, Price: 168.97000122070312, Shares: 288.51
# Shares 1st week: (50000 * 0.975) / 185.11666870117188
# Ticker: SOXX, First trading day: 2024-01-02, Price: 185.11666870117188, Shares: 263.35
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['SMH', 'SOXX']
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'SMH': 288.51275165894293, 'SOXX': 263.3474356579721}
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'SMH': 288.51275165894293, 'SOXX': 263.3474356579721}
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IXN', 'IGM']
# Sell SMH: 288.51 shares at 188.05. Total value: 52898.45
# Buy IXN: 728.89 shares at 70.76.
# Sell SOXX: 263.35 shares at 201.07. Total value: 51626.63
# Buy IGM: 640.01 shares at 78.65.
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'IXN': 728.8862400545959, 'IGM': 640.013142159933}
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IXN', 'IGM']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'SOXX']
# Sell IXN: 728.89 shares at 71.84. Total value: 51054.11
# Buy SMH: 261.33 shares at 190.48.
# Sell IGM: 640.01 shares at 80.60. Total value: 50296.47
# Buy SOXX: 243.58 shares at 201.33.
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'SMH': 261.3279802733711, 'SOXX': 243.5755334088723}
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'SMH': 261.3279802733711, 'SOXX': 243.5755334088723}
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'XSD']
# Sell SMH: 261.33 shares at 203.06. Total value: 51738.63
# Buy PSI: 957.58 shares at 52.68.
# Sell SOXX: 243.58 shares at 209.43. Total value: 49736.72
# Buy XSD: 214.08 shares at 226.52.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'PSI': 957.5770990728203, 'XSD': 214.07956325332515}
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'XSD']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'SOXX']
# Sell PSI: 957.58 shares at 51.59. Total value: 48166.37
# Buy SMH: 237.45 shares at 197.78.
# Sell XSD: 214.08 shares at 217.39. Total value: 45375.29
# Buy SOXX: 215.95 shares at 204.87.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'SMH': 237.4467019893259, 'SOXX': 215.94974586050256}
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Sell SMH: 237.45 shares at 210.35. Total value: 48698.24
# Buy PSI: 890.49 shares at 53.32.
# Sell SOXX: 215.95 shares at 214.25. Total value: 45110.55
# Buy XSD: 199.26 shares at 220.73.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'PSI': 890.4873695769272, 'XSD': 199.26058655403315}
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Sell PSI: 890.49 shares at 56.78. Total value: 49297.82
# Buy SMH: 214.49 shares at 224.09.
# Sell XSD: 199.26 shares at 231.79. Total value: 45031.94
# Buy SOXX: 191.86 shares at 228.84.
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'SMH': 214.49141025935486, 'SOXX': 191.86395233552577}
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['IXN', 'IGM']
# Sell SMH: 214.49 shares at 220.98. Total value: 46213.35
# Buy IXN: 611.20 shares at 73.72.
# Sell SOXX: 191.86 shares at 225.10. Total value: 42108.86
# Buy IGM: 483.53 shares at 84.91.
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'IXN': 611.2048097503774, 'IGM': 483.52536909063986}
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['IXN', 'IGM']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['SMH', 'SOXX']
# Sell IXN: 611.20 shares at 73.85. Total value: 44009.04
# Buy SMH: 196.58 shares at 218.28.
# Sell IGM: 483.53 shares at 85.19. Total value: 40161.74
# Buy SOXX: 179.14 shares at 218.59.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'SMH': 196.57692741180148, 'SOXX': 179.13763834245728}
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'IYW']
# Sell SMH: 196.58 shares at 227.08. Total value: 43522.72
# Buy XSD: 187.60 shares at 226.20.
# Sell SOXX: 179.14 shares at 224.57. Total value: 39223.22
# Buy IYW: 281.40 shares at 135.90.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'XSD': 187.5979413701839, 'IYW': 281.4027853009299}
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'IYW']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'IXN']
# Sell XSD: 187.60 shares at 233.86. Total value: 42774.86
# Buy IGM: 481.25 shares at 86.66.
# Sell IYW: 281.40 shares at 135.55. Total value: 37190.54
# Buy IXN: 483.15 shares at 75.05.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'IGM': 481.2542115270809, 'IXN': 483.1549580850169}
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'IXN']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IXN']
# Sell IGM: 481.25 shares at 85.96. Total value: 40334.40
# Buy FTEC: 255.63 shares at 153.84.
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'IXN': 483.1549580850169, 'FTEC': 255.62946776868918}
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'IXN']
# Sell FTEC: 255.63 shares at 149.81. Total value: 37338.45
# Buy IGM: 435.21 shares at 83.65.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'IXN': 483.1549580850169, 'IGM': 435.2061170036757}
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'IXN']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SMH', 'SOXX']
# Sell IGM: 435.21 shares at 80.88. Total value: 34319.48
# Buy SMH: 164.82 shares at 203.02.
# Sell IXN: 483.15 shares at 69.38. Total value: 32683.26
# Buy SOXX: 158.02 shares at 201.66.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'SMH': 164.81871261362198, 'SOXX': 158.01931671637712}
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'FTEC']
# Sell SMH: 164.82 shares at 218.38. Total value: 35093.28
# Buy IXN: 474.89 shares at 72.05.
# Sell SOXX: 158.02 shares at 218.55. Total value: 33671.74
# Buy FTEC: 218.44 shares at 150.29.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'IXN': 474.8917411153479, 'FTEC': 218.44402129894956}
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['IXN', 'IGM']
# Sell FTEC: 218.44 shares at 153.83. Total value: 32763.16
# Buy IGM: 373.83 shares at 85.45.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'IXN': 474.8917411153479, 'IGM': 373.83364722121524}
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['IXN', 'IGM']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IGM', 'FTEC']
# Sell IXN: 474.89 shares at 74.14. Total value: 34328.26
# Buy FTEC: 216.96 shares at 154.27.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'IGM': 373.83364722121524, 'FTEC': 216.95763334121145}
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Sell IGM: 373.83 shares at 88.89. Total value: 32399.32
# Buy SMH: 134.42 shares at 235.00.
# Sell FTEC: 216.96 shares at 160.26. Total value: 33900.39
# Buy SOXX: 141.70 shares at 233.26.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'SMH': 134.42271419182342, 'SOXX': 141.69973192012895}
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'IYW']
# Sell SMH: 134.42 shares at 249.83. Total value: 32743.26
# Buy XSD: 128.09 shares at 249.23.
# Sell SOXX: 141.70 shares at 242.59. Total value: 33515.56
# Buy IYW: 228.39 shares at 143.08.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'XSD': 128.09322874513862, 'IYW': 228.3874370486428}
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'IYW']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'SMH']
# Sell XSD: 128.09 shares at 245.69. Total value: 30684.45
# Buy IXN: 388.23 shares at 77.06.
# Sell IYW: 228.39 shares at 139.72. Total value: 31112.54
# Buy SMH: 124.59 shares at 243.48.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'IXN': 388.23429616992297, 'SMH': 124.58815015393738}
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'SMH']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'SOXX']
# Sell IXN: 388.23 shares at 79.41. Total value: 30058.94
# Buy SOXX: 120.37 shares at 243.48.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'SMH': 124.58815015393738, 'SOXX': 120.36911288464042}
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['IXN', 'IGM']
# Sell SMH: 124.59 shares at 272.48. Total value: 33099.09
# Buy IXN: 382.41 shares at 84.39.
# Sell SOXX: 120.37 shares at 256.02. Total value: 30046.48
# Buy IGM: 307.98 shares at 95.12.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'IXN': 382.41034592732603, 'IGM': 307.98269266552495}
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['IXN', 'IGM']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IGM', 'IXN']
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'IXN': 382.41034592732603, 'IGM': 307.98269266552495}
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IGM', 'IXN']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['SMH', 'SOXX']
# Sell IGM: 307.98 shares at 94.93. Total value: 28505.88
# Buy SMH: 106.48 shares at 261.01.
# Sell IXN: 382.41 shares at 83.62. Total value: 31177.73
# Buy SOXX: 123.26 shares at 246.62.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'SMH': 106.48338842039347, 'SOXX': 123.25960096967059}
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'IYW']
# Sell SMH: 106.48 shares at 274.21. Total value: 28468.84
# Buy XSD: 106.48 shares at 260.69.
# Sell SOXX: 123.26 shares at 259.59. Total value: 31197.04
# Buy IYW: 193.79 shares at 156.96.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 106.47557471753258, 'IYW': 193.78891561314973}
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'IYW']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'IGM']
# Sell XSD: 106.48 shares at 268.80. Total value: 27905.12
# Buy FTEC: 151.59 shares at 179.48.
# Sell IYW: 193.79 shares at 156.68. Total value: 29603.77
# Buy IGM: 296.07 shares at 97.49.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'FTEC': 151.59065115060912, 'IGM': 296.0681197673008}
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'IGM']
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'FTEC': 151.59065115060912, 'IGM': 296.0681197673008}
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IXN', 'FTEC']
# Sell IGM: 296.07 shares at 90.35. Total value: 26081.01
# Buy IXN: 322.25 shares at 78.91.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'FTEC': 151.59065115060912, 'IXN': 322.2529955263084}
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['IGM', 'FTEC']
# Sell IXN: 322.25 shares at 73.00. Total value: 22936.36
# Buy IGM: 266.13 shares at 84.03.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'FTEC': 151.59065115060912, 'IGM': 266.1305290674371}
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'SOXX']
# Sell IGM: 266.13 shares at 88.03. Total value: 22841.78
# Buy SMH: 98.13 shares at 226.96.
# Sell FTEC: 151.59 shares at 160.03. Total value: 23652.58
# Buy SOXX: 108.27 shares at 213.00.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'SMH': 98.12626961371811, 'SOXX': 108.26883117361348}
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['IXN', 'IGM']
# Sell SMH: 98.13 shares at 251.34. Total value: 24046.48
# Buy IXN: 282.78 shares at 82.91.
# Sell SOXX: 108.27 shares at 235.16. Total value: 24823.99
# Buy IGM: 257.37 shares at 94.04.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'IXN': 282.78032574690036, 'IGM': 257.37331321344675}
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['IXN', 'IGM']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['IGM', 'FTEC']
# Sell IXN: 282.78 shares at 81.40. Total value: 22442.86
# Buy FTEC: 128.17 shares at 170.72.
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'IGM': 257.37331321344675, 'FTEC': 128.1735549016056}
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'IXN']
# Sell FTEC: 128.17 shares at 163.10. Total value: 20382.48
# Buy IXN: 256.09 shares at 77.60.
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'IGM': 257.37331321344675, 'IXN': 256.09430786641417}
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Sell IGM: 257.37 shares at 87.89. Total value: 22055.03
# Buy SMH: 97.81 shares at 219.86.
# Sell IXN: 256.09 shares at 76.29. Total value: 19049.00
# Buy SOXX: 89.31 shares at 207.96.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'SMH': 97.80610889746526, 'SOXX': 89.30935530757318}
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IXN']
# Sell SMH: 97.81 shares at 233.80. Total value: 22295.39
# Buy IGM: 235.54 shares at 92.29.
# Sell SOXX: 89.31 shares at 219.88. Total value: 19146.41
# Buy IXN: 232.50 shares at 80.29.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'IGM': 235.54021923261695, 'IXN': 232.50401709573336}
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Sell IGM: 235.54 shares at 94.58. Total value: 21720.46
# Buy XSD: 91.35 shares at 231.84.
# Sell IXN: 232.50 shares at 81.54. Total value: 18484.42
# Buy FTEC: 105.17 shares at 171.37.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'XSD': 91.34510159587315, 'FTEC': 105.16606394420168}
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IXN']
# Sell XSD: 91.35 shares at 240.25. Total value: 21397.02
# Buy IGM: 217.45 shares at 95.94.
# Sell FTEC: 105.17 shares at 174.50. Total value: 17892.69
# Buy IXN: 211.38 shares at 82.53.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'IGM': 217.44937599038292, 'IXN': 211.38221473687}
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IXN']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['PSI', 'SMH']
# Sell IGM: 217.45 shares at 95.46. Total value: 20238.77
# Buy PSI: 344.68 shares at 57.25.
# Sell IXN: 211.38 shares at 81.20. Total value: 16735.13
# Buy SMH: 65.74 shares at 248.22.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'PSI': 344.67781562591523, 'SMH': 65.73503746161045}
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['PSI', 'SMH']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IXN', 'FTEC']
# Sell PSI: 344.68 shares at 60.18. Total value: 20224.14
# Buy IXN: 233.33 shares at 84.51.
# Sell SMH: 65.74 shares at 261.28. Total value: 16745.87
# Buy FTEC: 90.29 shares at 180.83.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'IXN': 233.32788064182935, 'FTEC': 90.29045152121249}
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'IGM']
# Sell IXN: 233.33 shares at 84.01. Total value: 19111.83
# Buy IGM: 189.49 shares at 98.34.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'FTEC': 90.29045152121249, 'IGM': 189.48580262219147}
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IXN']
# Sell FTEC: 90.29 shares at 179.26. Total value: 15780.83
# Buy IXN: 184.80 shares at 83.26.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'IGM': 189.48580262219147, 'IXN': 184.79831939595476}
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IXN']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['SMH', 'SOXX']
# Sell IGM: 189.49 shares at 95.86. Total value: 17710.01
# Buy SMH: 70.69 shares at 244.27.
# Sell IXN: 184.80 shares at 80.79. Total value: 14556.61
# Buy SOXX: 64.72 shares at 219.31.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'SMH': 70.68922079449122, 'SOXX': 64.71521997067907}
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IXN', 'IGM']
# Sell SMH: 70.69 shares at 253.53. Total value: 17473.79
# Buy IXN: 202.84 shares at 83.99.
# Sell SOXX: 64.72 shares at 225.57. Total value: 14232.87
# Buy IGM: 136.24 shares at 101.86.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'IXN': 202.8449546465308, 'IGM': 136.2364574944569}
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IXN', 'IGM']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['SMH', 'SOXX']
# Sell IXN: 202.84 shares at 82.30. Total value: 16276.79
# Buy SMH: 65.70 shares at 241.54.
# Sell IGM: 136.24 shares at 99.13. Total value: 13167.49
# Buy SOXX: 60.01 shares at 213.94.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'SMH': 65.70285520403566, 'SOXX': 60.00890075562555}
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['IXN', 'IGM']
# Sell SMH: 65.70 shares at 243.66. Total value: 15608.93
# Buy IXN: 182.04 shares at 83.60.
# Sell SOXX: 60.01 shares at 218.28. Total value: 12771.27
# Buy IGM: 123.04 shares at 101.20.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'IXN': 182.04193832692908, 'IGM': 123.04340646481349}
#
# Final Ticker Shares per Week:
# Week 2024-01-01 to 2024-01-07: {'SMH': 288.51275165894293, 'SOXX': 263.3474356579721}
# Week 2024-01-08 to 2024-01-14: {'SMH': 288.51275165894293, 'SOXX': 263.3474356579721}
# Week 2024-01-15 to 2024-01-21: {'SMH': 288.51275165894293, 'SOXX': 263.3474356579721}
# Week 2024-01-22 to 2024-01-28: {'IXN': 728.8862400545959, 'IGM': 640.013142159933}
# Week 2024-01-29 to 2024-02-04: {'SMH': 261.3279802733711, 'SOXX': 243.5755334088723}
# Week 2024-02-05 to 2024-02-11: {'SMH': 261.3279802733711, 'SOXX': 243.5755334088723}
# Week 2024-02-12 to 2024-02-18: {'PSI': 957.5770990728203, 'XSD': 214.07956325332515}
# Week 2024-02-19 to 2024-02-25: {'SMH': 237.4467019893259, 'SOXX': 215.94974586050256}
# Week 2024-02-26 to 2024-03-03: {'PSI': 890.4873695769272, 'XSD': 199.26058655403315}
# Week 2024-03-04 to 2024-03-10: {'SMH': 214.49141025935486, 'SOXX': 191.86395233552577}
# Week 2024-03-11 to 2024-03-17: {'IXN': 611.2048097503774, 'IGM': 483.52536909063986}
# Week 2024-03-18 to 2024-03-24: {'SMH': 196.57692741180148, 'SOXX': 179.13763834245728}
# Week 2024-03-25 to 2024-03-31: {'XSD': 187.5979413701839, 'IYW': 281.4027853009299}
# Week 2024-04-01 to 2024-04-07: {'IGM': 481.2542115270809, 'IXN': 483.1549580850169}
# Week 2024-04-08 to 2024-04-14: {'IXN': 483.1549580850169, 'FTEC': 255.62946776868918}
# Week 2024-04-15 to 2024-04-21: {'IXN': 483.1549580850169, 'IGM': 435.2061170036757}
# Week 2024-04-22 to 2024-04-28: {'SMH': 164.81871261362198, 'SOXX': 158.01931671637712}
# Week 2024-04-29 to 2024-05-05: {'IXN': 474.8917411153479, 'FTEC': 218.44402129894956}
# Week 2024-05-06 to 2024-05-12: {'IXN': 474.8917411153479, 'IGM': 373.83364722121524}
# Week 2024-05-13 to 2024-05-19: {'IGM': 373.83364722121524, 'FTEC': 216.95763334121145}
# Week 2024-05-20 to 2024-05-26: {'SMH': 134.42271419182342, 'SOXX': 141.69973192012895}
# Week 2024-05-27 to 2024-06-02: {'XSD': 128.09322874513862, 'IYW': 228.3874370486428}
# Week 2024-06-03 to 2024-06-09: {'IXN': 388.23429616992297, 'SMH': 124.58815015393738}
# Week 2024-06-10 to 2024-06-16: {'SMH': 124.58815015393738, 'SOXX': 120.36911288464042}
# Week 2024-06-17 to 2024-06-23: {'IXN': 382.41034592732603, 'IGM': 307.98269266552495}
# Week 2024-06-24 to 2024-06-30: {'IXN': 382.41034592732603, 'IGM': 307.98269266552495}
# Week 2024-07-01 to 2024-07-07: {'SMH': 106.48338842039347, 'SOXX': 123.25960096967059}
# Week 2024-07-08 to 2024-07-14: {'XSD': 106.47557471753258, 'IYW': 193.78891561314973}
# Week 2024-07-15 to 2024-07-21: {'FTEC': 151.59065115060912, 'IGM': 296.0681197673008}
# Week 2024-07-22 to 2024-07-28: {'FTEC': 151.59065115060912, 'IGM': 296.0681197673008}
# Week 2024-07-29 to 2024-08-04: {'FTEC': 151.59065115060912, 'IXN': 322.2529955263084}
# Week 2024-08-05 to 2024-08-11: {'FTEC': 151.59065115060912, 'IGM': 266.1305290674371}
# Week 2024-08-12 to 2024-08-18: {'SMH': 98.12626961371811, 'SOXX': 108.26883117361348}
# Week 2024-08-19 to 2024-08-25: {'IXN': 282.78032574690036, 'IGM': 257.37331321344675}
# Week 2024-08-26 to 2024-09-01: {'IGM': 257.37331321344675, 'FTEC': 128.1735549016056}
# Week 2024-09-02 to 2024-09-08: {'IGM': 257.37331321344675, 'IXN': 256.09430786641417}
# Week 2024-09-09 to 2024-09-15: {'SMH': 97.80610889746526, 'SOXX': 89.30935530757318}
# Week 2024-09-16 to 2024-09-22: {'IGM': 235.54021923261695, 'IXN': 232.50401709573336}
# Week 2024-09-23 to 2024-09-29: {'XSD': 91.34510159587315, 'FTEC': 105.16606394420168}
# Week 2024-09-30 to 2024-10-06: {'IGM': 217.44937599038292, 'IXN': 211.38221473687}
# Week 2024-10-07 to 2024-10-13: {'PSI': 344.67781562591523, 'SMH': 65.73503746161045}
# Week 2024-10-14 to 2024-10-20: {'IXN': 233.32788064182935, 'FTEC': 90.29045152121249}
# Week 2024-10-21 to 2024-10-27: {'FTEC': 90.29045152121249, 'IGM': 189.48580262219147}
# Week 2024-10-28 to 2024-11-03: {'IGM': 189.48580262219147, 'IXN': 184.79831939595476}
# Week 2024-11-04 to 2024-11-10: {'SMH': 70.68922079449122, 'SOXX': 64.71521997067907}
# Week 2024-11-11 to 2024-11-17: {'IXN': 202.8449546465308, 'IGM': 136.2364574944569}
# Week 2024-11-18 to 2024-11-24: {'SMH': 65.70285520403566, 'SOXX': 60.00890075562555}
# Week 2024-11-25 to 2024-12-01: {'IXN': 182.04193832692908, 'IGM': 123.04340646481349}

# %%
# Define the first trading day of the 48th week
first_trading_day_49w = '2024-12-01'  # Adjust this to match the actual start date of the 48th week

# Identify the 48th and 49th week date range keys
week_48_range = list(ticker_shares_per_week.keys())[-1]  # Last key corresponds to the 48th week
week_49_start = first_trading_day_49w  # Replace with the actual start of the 49th week
print(f"Using data for the 48th week: {week_48_range}")

print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

week_49_end = '2024-12-06'
# Initialize a dictionary to store the values of shares
etf_values_49w = {}

# Ensure 48th week data exists
if week_48_range in ticker_shares_per_week:
    # Fetch ETF shares from the 48th week
    ticker_shares_48w = ticker_shares_per_week[week_48_range]
    
    # Fetch the first trading day price of the 49th week for each ETF
    for ticker, shares in ticker_shares_48w.items():
        print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
        # Download historical data for the 49th week
        data = yf.download(ticker, start=week_49_start, end=week_49_end)
        
        if not data.empty:
            # Get the closing price of the first trading day of the 49th week
            closing_price_49w = data['Close'].iloc[0]
            # Calculate the value of the shares
            total_value = shares * closing_price_49w
            etf_values_49w[ticker] = total_value
            print(f"{ticker}: {shares:.2f} shares at {closing_price_49w:.2f} each, total value: {total_value:.2f}")
        else:
            print(f"{ticker}: No data available for the 49th week's first trading day.")
else:
    print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")
# Out:
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker IXN starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# IXN: 182.04 shares at 84.80 each, total value: 15437.16
# Fetching data for ticker IGM starting from 2024-12-01...
# IGM: 123.04 shares at 102.51 each, total value: 12613.18

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 28050.34
# IXN: 15437.16
# IGM: 12613.18
