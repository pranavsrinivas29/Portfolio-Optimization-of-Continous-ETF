# %%
#!pip install altair

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split,GridSearchCV
from skopt import BayesSearchCV

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tabulate import tabulate
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler,MinMaxScaler,Normalizer
import statsmodels.api as sm
import itertools

from pandas.tseries.offsets import MonthEnd
from pandas.tseries.offsets import BDay,Week

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

from datetime import datetime, timedelta

# %%
def data_loading(ticker_symbol, start_date, end_date):
    # Fetch the ETF data from Yahoo Finance for the period from 2010-01-01 to 2024-01-01
    etf_data = yf.Ticker(ticker_symbol)
    etf_history = etf_data.history(start=start_date, end=end_date)
    etf_history.index = etf_history.index.tz_localize(None)
    return etf_history, etf_data

# %%
#Function to derive the predictor columns
def etf_predictors(etf_history,  start_date, end_date, etf_data, benchmark_ticker = '^GSPC' ):
    
    # Calculate Daily Returns
    etf_history['Daily Return'] = etf_history['Close'].pct_change()

    # Calculate 21-Day Volatility (standard deviation of daily returns, annualized)
    etf_history['Volatility'] = etf_history['Daily Return'].rolling(window=21).std() * np.sqrt(252)
    #etf_history['Volatility_ta'] = ta.volatility(etf_history['Close'], window=21, annualize=True)
   
    # Get the ETF info
    etf_info = etf_data.info

    # Retrieve the net asset value price (NAV) and total net assets
    nav_price = etf_info['navPrice']
    total_assets = etf_info['totalAssets']

    # Calculate the number of shares outstanding
    shares_outstanding = total_assets / nav_price

    # Calculate Market Capitalization for each day
    # Market Capitalization = Closing Price * Total Number of Shares Outstanding
    etf_history['Market Cap'] = etf_history['Close'] * shares_outstanding

    total_assets = etf_info['totalAssets']
    total_liabilities = etf_info.get('totalLiabilities', 0)  # Handle the case where total liabilities might not be present
    
    # Calculate Book Value per Share
    book_value_per_share = (total_assets - total_liabilities) / shares_outstanding
    
    # Calculate Price to Book (P/B) Ratio
    etf_history['P/B Ratio'] = etf_history['Close'] / book_value_per_share
    
    # Calculate 1-Month Momentum (21 trading days)
    
    etf_history['Momentum'] = ta.mom(etf_history['Close'], length=21)
    
    benchmark_data = yf.download(benchmark_ticker, start=start_date, end=end_date)
    benchmark_data['Daily Return'] = benchmark_data['Close'].pct_change()
    #benchmark_data_history = benchmark_data.dropna()
    benchmark_data.head(10)
    
    # Ensure the indices are time zone-naive
    benchmark_data.index = benchmark_data.index.tz_localize(None)
    combined_data = etf_history[['Close']].join(benchmark_data[['Close']], lsuffix='_ETF', rsuffix='_Benchmark')
    combined_data = combined_data.dropna()
    
    # Calculate rolling beta with a 30-day window
    rolling_beta_21 = rolling_beta(combined_data, window=21)

    # Add the rolling beta to the dataframe
    combined_data.loc[:, 'Rolling Beta 21-day'] = rolling_beta_21
    etf_history['Rolling Beta']=combined_data['Rolling Beta 21-day']
    
    # Calculate daily profitability
    daily_profitabilities = []
    previous_nav = None
    for index, row in etf_history.iterrows():
        current_nav = row['Close']  # Current day's NAV
        #print(current_nav)
        if previous_nav is not None:
            daily_profitability = (current_nav - previous_nav) / previous_nav * 100
            daily_profitabilities.append(daily_profitability)
        else:
            daily_profitabilities.append(None)
        previous_nav = current_nav  # Update previous_nav for the next iteration

    # Add daily profitabilities to ETF dataset
    etf_history['Daily Profitability (%)'] = daily_profitabilities
    
    # Calculate the dividend yield for each day
    dividend_yields = []

    for index, row in etf_history.iterrows():
        # Get the dividend payment for the day
        dividend_payment = row['Dividends']

        # Get the current market price of the ETF for the day
        current_price = row['Close']

        # Calculate the dividend yield for the day
        dividend_yield = (dividend_payment / current_price) * 100

        # Append the dividend yield to the list
        dividend_yields.append(dividend_yield)
      
    etf_history['Div yield'] = dividend_yields

    #Volatility
    etf_history['ATR'] = ta.atr(etf_history['High'], etf_history['Low'], etf_history['Close'], length=21)    
    
    # Compute the Relative Volatility Index (RVI)
    rvi = ta.rvi(etf_history['Close'],length=21)
    etf_history['RVI'] = rvi
    
    #Momentum
    rsi_window = 14  # Window size for RSI calculation
    roc_window = 12  # Window size for ROC calculation
    #rsi_window = 21  
    #roc_window = 21  

    

    etf_history['RSI'] = ta.rsi(etf_history['Close'],length=rsi_window)
    # Calculate Rate of Change (ROC)
    etf_history['ROC'] = ta.roc(etf_history['Close'], length=roc_window)
        
    etf_history['log_returns'] = np.log(etf_history['Close'] / etf_history['Close'].shift(1))

    return etf_history

# Function to calculate rolling beta
def rolling_beta(df, window):
    rolling_cov = df['Close_Benchmark'].rolling(window=window).cov(df['Close_ETF'])
    rolling_var = df['Close_Benchmark'].rolling(window=window).var()
    rolling_beta = rolling_cov / rolling_var
    return rolling_beta

# %%
def pre_processing(etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_dates, feature_columns=None, scaling_strategy='StandardScaler', final_end_date='2024-12-01'):
    # Handle missing values and inf replacements
    etf_history.fillna(etf_history.median(), inplace=True)
    etf_history = etf_history.replace(-np.inf, 0)

    # Default feature columns if none are provided
    if feature_columns is None:
        feature_columns = ['Volatility', 'Volume', 'Daily Return', 'Market Cap', 'P/B Ratio', 'Momentum', 
                           'Rolling Beta', 'Daily Profitability (%)', 'ATR', 'RVI', 'RSI', 'ROC']

    # Selecting the features (X) and the target (y)
    X = etf_history.loc[:, feature_columns]
    y = etf_history['log_returns']

    # Split train and test data
    train_data = X.loc[train_start_date:train_end_date]
    test_data = X.loc[test_start_date:test_end_date]
    y_train = y.loc[train_start_date:train_end_date]
    y_test = y.loc[test_start_date:test_end_date]

    # Scaling strategy based on input parameter
    if scaling_strategy == 'StandardScaler':
        scaler = StandardScaler()
    elif scaling_strategy == 'Normalizer':
        scaler = Normalizer()
    else:
        raise ValueError(f"Unsupported scaling strategy: {scaling_strategy}")
    
    # Scaling the train and test data
    train_data_scaled = scaler.fit_transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    # Create a dictionary to store forecast data for each weekly prediction period
    forecast_data = {}
    for i, start_date in enumerate(prediction_dates):
        # Determine the end date for each forecast week
        if i < len(prediction_dates) - 1:
            end_date = (pd.to_datetime(start_date) + Week(1) - pd.Timedelta(days=1)).strftime('%Y-%m-%d')
        else:
            end_date = final_end_date  # The final end date provided or default

        # Store the forecast data for each week
        forecast_data[f'forecast_data_{i+1}w'] = X.loc[start_date:end_date]

    # Scale the forecast data dynamically
    forecast_data_scaled = {}
    for period_key, period_data in forecast_data.items():
        if not period_data.empty:
            forecast_data_scaled[period_key] = sm.add_constant(scaler.transform(period_data))

    # Add constant to scaled train and test data
    train_data_scaled = sm.add_constant(train_data_scaled)
    test_data_scaled = sm.add_constant(test_data_scaled)

    #print(f"Weekly forecast data keys: {forecast_data.keys()}")

    # Dynamically return the scaled forecast data along with train and test data
    return {
        'train_data_scaled': train_data_scaled,
        'test_data_scaled': test_data_scaled,
        'y_train': y_train,
        'y_test': y_test,
        'scaler': scaler,
        'X': X,
        'etf_history': etf_history,
        'forecast_data_scaled': forecast_data_scaled,
        'forecast_data': forecast_data
    }

# %%
def model_training(train_data_scaled, y_train):
    model = sm.OLS(endog=y_train, exog=sm.add_constant(train_data_scaled))
    
     # Define the hyperparameters
    cov_types = ['HC0', 'HC1', 'HC2', 'HC3']
    use_ts = [True, False]
    methods = ['pinv', 'qr']
    #missing = ['none', 'drop', 'raise']
    #hasconsts = [None, 'add', 'raise']
    tol_values = [1e-8, 1e-6, 1e-4]
    maxiter_values = [500, 1000, 5000]

    best_score = float('-inf')
    best_model = None

    # Loop through all combinations of hyperparameters
    for cov_type, use_t, method, tol, maxiter in itertools.product(cov_types, use_ts, methods,  tol_values, maxiter_values):
        try:
            # Define and fit the model
            model = sm.OLS(endog=y_train, exog=train_data_scaled)
            fitted_model = model.fit(cov_type=cov_type, use_t=use_t, method=method, tol=tol, maxiter=maxiter)

            # Evaluate on test data
            score = fitted_model.rsquared_adj  # Or any other metric you prefer

            # Update best model if necessary
            if score > best_score:
                best_score = score
                best_model = fitted_model
                best_params = {
                    'cov_type': cov_type,
                    'use_t': use_t,
                    'method': method,
                    #'missing': miss,
                    #'hasconst': hasconst,
                    'tol': tol,
                    'maxiter': maxiter
                }
        except:
            # Handle any errors that arise from invalid hyperparameter combinations
            continue
            
    # Display the best model parameters
    print("Best Model Parameters:")
    print(best_params)
    return best_model

# %%
#!pip install scikit-optimize

# %%
def eval_model(best_model,test_data_scaled,y_test,y_train):
    
    test_predictions = best_model.predict((test_data_scaled))
    mae = mean_absolute_error(y_test, test_predictions)
    # Mean Absolute Scaled Error (MASE) - Example calculation assuming seasonal period m=1
    seasonal_naive = np.roll(y_test, 1)  # Shift y_test by 1 for seasonal naive forecast
    #seasonal_mae = np.mean(np.abs(y_test - seasonal_naive))
    seasonal_mae = np.mean(np.abs(y_test[1:] - seasonal_naive[1:]))
    mase = mae / seasonal_mae

    # Mean Absolute Percentage Error (MAPE)
    #mape = np.mean(np.abs((y_test - test_predictions) / y_test)) * 100

    #n = y_test.shape[0]
    #d = np.abs(  np.diff( y_test) ).sum()/(n-1)
    
    #errors = np.abs(y_test - test_predictions )
    #mase_value = errors.mean()/d

    print("Mean Absolute Error (MAE):", mae)
    print("Mean Absolute Scaled Error (MASE):", mase)
    #print("Mean Absolute Scaled Error-2 (MASE-2):", mase_value)
    #print("Mean Absolute Percentage Error (MAPE):", mape)
    
    return mae, mase

# %%
# Ensured consistent feature handling and forecasting in predictions
def predictions(model, forecast_data_scaled, forecast_data):
    predictions_forecast = model.predict(forecast_data_scaled)
    forecast_predictions_df = pd.DataFrame(predictions_forecast, columns=["log_returns"], index=forecast_data.index)
    forecast_data_with_predictions = pd.concat([forecast_data, forecast_predictions_df], axis=1)
    return forecast_predictions_df, forecast_data_with_predictions

# %%
"""
# Ensured consistent feature handling and forecasting in predictions
def predictions(model, forecast_data_scaled, forecast_data):
    predictions_forecast = model.predict(forecast_data_scaled)
    forecast_predictions_df = pd.DataFrame(predictions_forecast, columns=["log_returns"], index=forecast_data.index)
    forecast_data_with_predictions = pd.concat([forecast_data, forecast_predictions_df], axis=1)
    return forecast_predictions_df, forecast_data_with_predictions
    """
# Out:
# '\n# Ensured consistent feature handling and forecasting in predictions\ndef predictions(model, forecast_data_scaled, forecast_data):\n    predictions_forecast = model.predict(forecast_data_scaled)\n    forecast_predictions_df = pd.DataFrame(predictions_forecast, columns=["log_returns"], index=forecast_data.index)\n    forecast_data_with_predictions = pd.concat([forecast_data, forecast_predictions_df], axis=1)\n    return forecast_predictions_df, forecast_data_with_predictions\n    '

# %%
#tickers = ['SPY', 'QQQ', 'VTI', 'IWM', 'EFA', 'EEM', 'GLD', 'SLV', 'USO', 'XLF']
#tickers = ['SMH', 'SOXX', 'PSI']

tickers = ['SMH', 'SOXX', 'PSI', 'XSD', 'IYW', 'XLK', 'VGT', 'FTEC', 'IGM', 'IXN', 
           #'FNGU','USD', 'FNGO', 'GBTC', 'ETHE', 'TECL', 'FNGS', 'TQQQ', 'ROM', 'QLD' No data available from 2000: 2019
          ]

#tickers = ['SPY', 'QQQ', 'VTI']
#tickers = ['SPY']
                                                           
start_date, end_date = '2000-01-01', '2024-12-01'
train_start_date, train_end_date, test_start_date, test_end_date, prediction_start_date = start_date,'2014-01-01', '2014-01-01', '2024-01-01', '2024-01-01'
#prediction_dates=['2024-01-01','2024-02-01','2024-03-01', '2024-04-01','2024-05-01','2024-06-01','2024-07-01','2024-08-01','2024-09-01','2024-10-01','2024-11-01']

# %%
#currently timeperiod is set to 48 weeks
prediction_dates = pd.date_range(start='2024-01-01', 
                                 periods=48, 
                                 freq='W-MON').strftime('%Y-%m-%d').tolist()

# %%
dict_data = {}
etf_dict = {}
data_with_predictors = []

# Loop through tickers
for i in tickers:
    etf_history, etf_data = data_loading(i, start_date, end_date)
    print(etf_data.info.get('longName'), ":", i)

    # Preprocess ETF data
    etf_history = etf_predictors(etf_history, start_date, end_date, etf_data, benchmark_ticker='^GSPC')
    preprocessed_data = pre_processing(
        etf_history, train_start_date, train_end_date, test_start_date, test_end_date, prediction_dates
    )

    # Extract components
    train_data_scaled = preprocessed_data['train_data_scaled']
    test_data_scaled = preprocessed_data['test_data_scaled']
    y_train = preprocessed_data['y_train']
    y_test = preprocessed_data['y_test']
    scaler = preprocessed_data['scaler']
    X = preprocessed_data['X']
    etf_history = preprocessed_data['etf_history']
    
    """for key in preprocessed_data['forecast_data']:
        print(key)"""  # Check if 'forecast_data_Xw' keys are present.

    # Train the model
    best_model = model_training(train_data_scaled, y_train)

    # Evaluate the model
    mae, mase = eval_model(best_model, test_data_scaled, y_test, y_train)
    print(f"Evaluation results for {i}: MAE = {mae}, MASE = {mase}")

    # Initialize dictionaries for forecast data and predictions
    # Step 5: Initialize forecast data storage
    forecast_predictions = {}
    forecast_data_dict = {}
    forecast_data_scaled_dict = {}

    # Step 6: Fetch weekly forecast data and generate predictions
    for week in range(1, 49):  # Generate weekly forecasts for up to 52 weeks
        week_key = f'forecast_data_{week}w'
        if week_key in preprocessed_data['forecast_data']:
            forecast_data = preprocessed_data['forecast_data'][week_key]
            forecast_data_scaled = preprocessed_data['forecast_data_scaled'].get(week_key)

            if forecast_data is not None and forecast_data_scaled is not None:
                try:
                    forecast_predictions_df, _ = predictions(
                        best_model, forecast_data_scaled, forecast_data
                    )
                    # Store predictions and forecast data
                    forecast_predictions[f'forecast_predictions_df_{week}w'] = forecast_predictions_df['log_returns'].values
                    forecast_data_dict[week_key] = forecast_data
                    forecast_data_scaled_dict[week_key] = forecast_data_scaled
                except Exception as e:
                    print(f"Error generating predictions for {week_key} for ETF {i}: {e}")
            else:
                print(f"Warning: Missing scaled data for {week_key} for ETF {i}")
        else:
            print(f"Warning: Missing forecast key {week_key} for ETF {i}")

    # Step 7: Construct `dict_data` for the current ETF
    dict_data = {
        "etf_history": etf_history,
        "X": X,
        "y_train_values": y_train,
        "model results": {"mae": mae, "mase": mase},
        **forecast_data_dict,  # Add raw forecast data
        **forecast_data_scaled_dict,  # Add scaled forecast data
        **forecast_predictions  # Add predictions
    }

    # Step 8: Store in the main `etf_dict`
    etf_dict[i] = dict_data

# Print completion message
print("Weekly forecast data and predictions stored successfully.")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# VanEck Semiconductor ETF : SMH
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.0004958027292883956
# Mean Absolute Scaled Error (MASE): 0.025717292384648413
# Evaluation results for SMH: MAE = 0.0004958027292883956, MASE = 0.025717292384648413
# [*********************100%%**********************]  1 of 1 completed
# iShares Semiconductor ETF : SOXX
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'pinv', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00043861149568094664
# Mean Absolute Scaled Error (MASE): 0.02248201783048627
# Evaluation results for SOXX: MAE = 0.00043861149568094664, MASE = 0.02248201783048627
# [*********************100%%**********************]  1 of 1 completed
# Invesco Semiconductors ETF : PSI
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00027221648202699914
# Mean Absolute Scaled Error (MASE): 0.01332974143771139
# Evaluation results for PSI: MAE = 0.00027221648202699914, MASE = 0.01332974143771139
# [*********************100%%**********************]  1 of 1 completed
# SPDR S&P Semiconductor ETF : XSD
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.0002343537637621655
# Mean Absolute Scaled Error (MASE): 0.011221480284356395
# Evaluation results for XSD: MAE = 0.0002343537637621655, MASE = 0.011221480284356395
# [*********************100%%**********************]  1 of 1 completed
# iShares U.S. Technology ETF : IYW
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00023121462549368981
# Mean Absolute Scaled Error (MASE): 0.015512563329453498
# Evaluation results for IYW: MAE = 0.00023121462549368981, MASE = 0.015512563329453498
# [*********************100%%**********************]  1 of 1 completed
# The Technology Select Sector SPDR Fund : XLK
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00018973567534454123
# Mean Absolute Scaled Error (MASE): 0.013372176896293293
# Evaluation results for XLK: MAE = 0.00018973567534454123, MASE = 0.013372176896293293
# [*********************100%%**********************]  1 of 1 completed
# Vanguard Information Technology Index Fund ETF Shares : VGT
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.0001878578114437768
# Mean Absolute Scaled Error (MASE): 0.012997347885433698
# Evaluation results for VGT: MAE = 0.0001878578114437768, MASE = 0.012997347885433698
# [*********************100%%**********************]  1 of 1 completed
# Fidelity MSCI Information Technology Index ETF : FTEC
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.0007518364167056398
# Mean Absolute Scaled Error (MASE): 0.05199246800644897
# Evaluation results for FTEC: MAE = 0.0007518364167056398, MASE = 0.05199246800644897
# [*********************100%%**********************]  1 of 1 completed
# iShares Expanded Tech Sector ETF : IGM
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00023297892638845106
# Mean Absolute Scaled Error (MASE): 0.015974942917354157
# Evaluation results for IGM: MAE = 0.00023297892638845106, MASE = 0.015974942917354157
# [*********************100%%**********************]  1 of 1 completed
# iShares Global Tech ETF : IXN
# Best Model Parameters:
# {'cov_type': 'HC0', 'use_t': True, 'method': 'qr', 'tol': 1e-08, 'maxiter': 500}
# Mean Absolute Error (MAE): 0.00015533922183411802
# Mean Absolute Scaled Error (MASE): 0.01095997929752199
# Evaluation results for IXN: MAE = 0.00015533922183411802, MASE = 0.01095997929752199
# Weekly forecast data and predictions stored successfully.

# %%
def calculate_sharpe_ratio(returns, annual_risk_free_rate=0.1,period='daily'):
    #excess_returns = rate_of_return(returns) - risk_free_rate
    
    # Convert annual risk-free rate to daily rate
    daily_risk_free_rate = (1 + annual_risk_free_rate) ** (1/252) - 1
    
    # Calculate mean daily log return
    mean_return = np.mean(returns)
    
    # Calculate excess daily log return
    excess_return = mean_return - daily_risk_free_rate
    
    # Calculate standard deviation of daily log returns
    std_return = np.std(returns)
    
    # Print diagnostic information
    #print(f"Mean Daily Log Return: {mean_return}")
    #print(f"Excess Daily Log Return: {excess_return}")
    #print(f"Standard Deviation of Daily Log Returns: {std_return}")
    
    # Check for zero standard deviation to avoid division by zero
    if std_return == 0:
        return 0
    
    # Calculate Sharpe ratio
    sharpe_ratio = (excess_return / std_return) * np.sqrt(252)  # Annualize the Sharpe ratio
    return sharpe_ratio
    #return excess_returns / np.std(returns)


def calculate_rachev_ratio(returns, lower_percentile=5, upper_percentile=95):
    # Step 1: Sort the returns
    sorted_returns = np.sort(returns)
    
    # Step 2: Determine the percentiles
    lower_threshold = np.percentile(sorted_returns, lower_percentile)
    upper_threshold = np.percentile(sorted_returns, upper_percentile)
    
    # Step 3: Calculate Expected Shortfall (ES)
    es = np.mean(sorted_returns[sorted_returns <= lower_threshold])
    
    # Step 4: Calculate Expected Gain (EG)
    eg = np.mean(sorted_returns[sorted_returns >= upper_threshold])
    
    # Step 5: Compute the Rachev Ratio
    rachev_ratio = eg / -es
    return rachev_ratio


def calculate_volatility_clustering(returns):
    squared_returns = returns ** 2
    n = len(squared_returns)
    
    # Mean of squared returns
    mean_squared_returns = np.mean(squared_returns)
    
    # Calculate the numerator and denominator for autocorrelation at lag 1
    numerator = np.sum((squared_returns[:-1] - mean_squared_returns) * (squared_returns[1:] - mean_squared_returns))
    denominator = np.sum((squared_returns - mean_squared_returns) ** 2)
    
    if denominator == 0:
        return 0  # Avoid division by zero
    
    rho_1 = numerator / denominator
    return rho_1

def calculate_sortino_ratio(log_returns, target_log_return=0.0):
    """
    Calculate the Sortino Ratio using log returns.
    
    Parameters:
    - log_returns (array-like): Array or list of log returns for the period.
    - target_log_return (float): The target log return. Default is 0, which is often used as a benchmark.
    
    Returns:
    - float: The Sortino Ratio.
    """
    # Convert input to a NumPy array for easier calculations
    log_returns = np.array(log_returns)
    
    # Calculate the average period log return (R)
    avg_log_return = np.mean(log_returns)
    
    # Calculate the Target Downside Deviation (TDD)
    downside_deviation = np.sqrt(
        np.mean(np.square(np.maximum(0, target_log_return - log_returns)))
    )
    
    # Calculate Sortino Ratio
    #sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
    epsilon = 1e-8
    
    # Add epsilon to downside_deviation to prevent division by zero
    #if downside_deviation == 0:
     #   return np.nan  # Return NaN if downside deviation is zero
    
    # Calculate Sortino Ratio
    sortino_ratio_value = (avg_log_return - target_log_return) / (downside_deviation + epsilon)
    
    return sortino_ratio_value

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, volatility_clustering, 
    mean_forecast, std_forecast, mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
    mean_volatility_clustering, std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    # Debugging: Log raw input values
    print(f"\nDebug: Composite Score Calculation")
    print(f"Forecasted Mean: {forecasted_mean}, Risk Percentage: {risk_percentage}")
    print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
    print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")

    # Normalize the components with epsilon
    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Debugging: Log normalized values
    print(f"Normalized Values -> Forecasted Mean: {forecasted_mean_normalized}, Rachev: {rachev_normalized}")
    print(f"Sharpe: {sharpe_normalized}, Sortino: {sortino_normalized}, Volatility Clustering: {volatility_clustering_normalized}")

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    # Debugging: Log final score
    print(f"Final Composite Score: {score}")

    return score


def process_etf_data_weekly(tickers, etf_dict):
    etf_pred_dict = {}

    # Determine the forecast periods dynamically from the etf_dict
    sample_etf = next(iter(etf_dict.values()))
    forecast_periods = [key.split('_')[-1] for key in sample_etf.keys() if key.startswith('forecast_predictions_df')]

    for etf_name in tickers:
        etf_pred_dict[etf_name] = {
            f"returns_{period}": etf_dict[etf_name][f"forecast_predictions_df_{period}"]
            for period in forecast_periods
        }

        for period in forecast_periods:
            returns = etf_pred_dict[etf_name][f"returns_{period}"]

            # Log returns for debugging
            print(f"\nDebug: Returns for {etf_name}, Forecast Period {period}: {returns}")

            # Calculate metrics
            etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
            etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
            etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
            etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict



def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    print(f"\nDebug: Forecast Period = {forecast_period}")
    print(f"All Returns Means: {[np.mean(returns) for returns in returns_list]}")
    print(f"Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Rachev Ratios: {rachev_ratios}")
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sharpe Ratios: {sharpe_ratios}")
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sortino Ratios: {sortino_ratios}")
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Volatility Clustering: {volatility_clustering}")
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    print(f"Mean Rachev = {mean_rachev}, Std Rachev = {std_rachev}")
    print(f"Mean Sharpe = {mean_sharpe}, Std Sharpe = {std_sharpe}")
    print(f"Mean Sortino = {mean_sortino}, Std Sortino = {std_sortino}")
    print(f"Mean Volatility Clustering = {mean_volatility_clustering}, Std Volatility Clustering = {std_volatility_clustering}")

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )



def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Debugging: Log inputs to composite score calculation
        print(f"\nDebug: ETF = {etf}, Forecast Period = {forecast_period}")
        print(f"Forecasted Values Mean: {np.mean(forecasted_values)}")
        print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
        print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")
        print(f"Means and Stds: Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")
        
        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

        # Debugging: Log the calculated score
        print(f"Calculated Score for {etf} ({forecast_period}): {score}")

    return scores



def main_weekly(tickers, etf_dict):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict)
    
    risk_percentage = 0.10
    weekly_scores = {}

    # Iterate over 48 weeks
    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores
            print(f"Scores calculated for {week_key}:")
            for score in scores:
                print(score)
        else:
            print(f"Skipping score calculation for {week_key}: No ETFs have data for this week.")

    return etf_pred_dict, weekly_scores


# Example usage:
# Execute weekly scoring
etf_pred_dict, weekly_scores = main_weekly(tickers, etf_dict)
# Out:
# Debug: Returns for SMH, Forecast Period 1w: [-0.03475353 -0.0190482  -0.0071898   0.00528752]
#
# Debug: Returns for SMH, Forecast Period 2w: [ 0.03416537  0.00151172 -0.00033629  0.00427034 -0.00496809]
#
# Debug: Returns for SMH, Forecast Period 3w: [ 0.01433271 -0.00766895  0.03076492  0.03667688]
#
# Debug: Returns for SMH, Forecast Period 4w: [ 0.00348621  0.00429403  0.01685095 -0.00086758 -0.02236661]
#
# Debug: Returns for SMH, Forecast Period 5w: [ 0.01060041 -0.01112131 -0.01565295  0.00825322  0.0188383 ]
#
# Debug: Returns for SMH, Forecast Period 6w: [ 0.01905304 -0.01181881  0.01939125  0.01357168  0.02159133]
#
# Debug: Returns for SMH, Forecast Period 7w: [-0.00440405 -0.01907772  0.01932874 -0.0039811  -0.00517776]
#
# Debug: Returns for SMH, Forecast Period 8w: [-0.02093725 -0.00787031  0.06679589 -0.00756042]
#
# Debug: Returns for SMH, Forecast Period 9w: [ 0.00700177 -0.00401006 -0.01240139  0.02075349  0.03982313]
#
# Debug: Returns for SMH, Forecast Period 10w: [ 0.01556183 -0.01599483  0.02496596  0.03426345 -0.03971584]
#
# Debug: Returns for SMH, Forecast Period 11w: [-0.01881184  0.03043654 -0.02089047 -0.01896297 -0.00879408]
#
# Debug: Returns for SMH, Forecast Period 12w: [ 0.00060954 -0.00361611  0.01484325  0.0216747   0.0044631 ]
#
# Debug: Returns for SMH, Forecast Period 13w: [-0.00386971 -0.01087328 -0.00190671 -0.00110633]
#
# Debug: Returns for SMH, Forecast Period 14w: [ 0.01139291 -0.0148928   0.00178686 -0.02875395  0.01006397]
#
# Debug: Returns for SMH, Forecast Period 15w: [-0.00082906  0.00245061 -0.01072277  0.02095471 -0.03119942]
#
# Debug: Returns for SMH, Forecast Period 16w: [-0.01701592  0.00632571 -0.03296947 -0.02002575 -0.04788204]
#
# Debug: Returns for SMH, Forecast Period 17w: [ 0.01603219  0.02053301 -0.00167794  0.01728666  0.02310984]
#
# Debug: Returns for SMH, Forecast Period 18w: [ 0.00098301 -0.02224212 -0.03180419  0.01733003  0.02462374]
#
# Debug: Returns for SMH, Forecast Period 19w: [ 0.02051387 -0.01082541  0.00081489 -0.00862645  0.01259416]
#
# Debug: Returns for SMH, Forecast Period 20w: [-0.00225749  0.01524053  0.02824172 -0.00857972 -0.00951918]
#
# Debug: Returns for SMH, Forecast Period 21w: [ 0.02014952 -0.00205841  0.00729344  0.01283704  0.01769291]
#
# Debug: Returns for SMH, Forecast Period 22w: [ 0.02195417 -0.01765531 -0.01460742 -0.00792603]
#
# Debug: Returns for SMH, Forecast Period 23w: [ 0.01175155 -0.00459944  0.04767903 -0.00857145 -0.00160543]
#
# Debug: Returns for SMH, Forecast Period 24w: [ 0.01378696 -0.00233435  0.02909238  0.01495168  0.00165067]
#
# Debug: Returns for SMH, Forecast Period 25w: [ 0.0165266   0.01541194 -0.02902163 -0.0158658 ]
#
# Debug: Returns for SMH, Forecast Period 26w: [-0.0357127   0.02187228 -0.00495165 -0.00997711  0.00529264]
#
# Debug: Returns for SMH, Forecast Period 27w: [-0.00041164  0.00850131  0.02124501 -0.00102407]
#
# Debug: Returns for SMH, Forecast Period 28w: [ 0.01479817  0.00059183  0.02208727 -0.03813676  0.01088341]
#
# Debug: Returns for SMH, Forecast Period 29w: [-0.00438513 -0.0028077  -0.0740794   0.00176369 -0.03265745]
#
# Debug: Returns for SMH, Forecast Period 30w: [ 0.03529198 -0.01412942 -0.05734872 -0.0218232   0.0124235 ]
#
# Debug: Returns for SMH, Forecast Period 31w: [-0.01038216 -0.04183898  0.07276394 -0.06830741 -0.05889014]
#
# Debug: Returns for SMH, Forecast Period 32w: [-0.02822868  0.01444023 -0.03262373  0.05814527 -0.00479738]
#
# Debug: Returns for SMH, Forecast Period 33w: [ 0.00471112  0.03615981 -0.00345475  0.03929308 -0.00158929]
#
# Debug: Returns for SMH, Forecast Period 34w: [ 0.01643422 -0.01581505  0.00769736 -0.03479516  0.02279981]
#
# Debug: Returns for SMH, Forecast Period 35w: [-0.02555219  0.00797398 -0.01848236 -0.01505124  0.02157825]
#
# Debug: Returns for SMH, Forecast Period 36w: [-0.07639906 -0.00386207 -0.00346599 -0.04293836]
#
# Debug: Returns for SMH, Forecast Period 37w: [ 2.02473546e-02  7.30812612e-03  4.95853993e-02 -4.61663974e-05
#   1.07019204e-02]
#
# Debug: Returns for SMH, Forecast Period 38w: [-0.01576164 -0.00308194 -0.01445587  0.04059817 -0.01602336]
#
# Debug: Returns for SMH, Forecast Period 39w: [ 0.00200012  0.01604219  0.00665197  0.02672869 -0.02125326]
#
# Debug: Returns for SMH, Forecast Period 40w: [-0.01116492 -0.02916673  0.01305655  0.00799714  0.01233678]
#
# Debug: Returns for SMH, Forecast Period 41w: [ 0.00112501  0.01665747  0.00982372 -0.00310951  0.006867  ]
#
# Debug: Returns for SMH, Forecast Period 42w: [ 0.01672328 -0.05530161 -0.00088641  0.0159369  -0.00198349]
#
# Debug: Returns for SMH, Forecast Period 43w: [ 0.00375238 -0.00622687 -0.01267165  0.00208946  0.00914913]
#
# Debug: Returns for SMH, Forecast Period 44w: [-0.00910838  0.02066369 -0.02595689 -0.03806881  0.01036679]
#
# Debug: Returns for SMH, Forecast Period 45w: [-0.00447779  0.01401443  0.02363963  0.02196605 -0.00876894]
#
# Debug: Returns for SMH, Forecast Period 46w: [-0.0250345  -0.00958595 -0.01911194 -0.00021678 -0.03592342]
#
# Debug: Returns for SMH, Forecast Period 47w: [ 0.00376817  0.00806672 -0.00956289  0.0120334  -0.00875518]
#
# Debug: Returns for SMH, Forecast Period 48w: [-0.00694426 -0.01218338 -0.01644849  0.01331397]
#
# Debug: Returns for SOXX, Forecast Period 1w: [-0.03689163 -0.02257334 -0.00949502  0.00449957]
#
# Debug: Returns for SOXX, Forecast Period 2w: [ 0.03165869 -0.0006159  -0.00441572  0.00245992 -0.00569379]
#
# Debug: Returns for SOXX, Forecast Period 3w: [ 0.01278226 -0.01071176  0.0315337   0.03782708]
#
# Debug: Returns for SOXX, Forecast Period 4w: [ 0.00207852  0.00577362  0.01354899 -0.0037803  -0.02821928]
#
# Debug: Returns for SOXX, Forecast Period 5w: [ 0.00915868 -0.01672918 -0.01586164  0.00391795  0.01192779]
#
# Debug: Returns for SOXX, Forecast Period 6w: [ 0.01291843 -0.01248033  0.01428566  0.01630734  0.01911821]
#
# Debug: Returns for SOXX, Forecast Period 7w: [-0.00263017 -0.02142718  0.02171478 -0.00172177 -0.00665572]
#
# Debug: Returns for SOXX, Forecast Period 8w: [-0.0181239  -0.00365373  0.047934   -0.01212945]
#
# Debug: Returns for SOXX, Forecast Period 9w: [ 0.00857491 -0.0021038  -0.01246746  0.02606181  0.04183688]
#
# Debug: Returns for SOXX, Forecast Period 10w: [ 0.00915589 -0.02042626  0.02380533  0.03388512 -0.04123376]
#
# Debug: Returns for SOXX, Forecast Period 11w: [-0.01423729  0.01974943 -0.02544434 -0.01813899 -0.00843693]
#
# Debug: Returns for SOXX, Forecast Period 12w: [-0.00207926 -0.00973085  0.01582954  0.02145307 -0.00010408]
#
# Debug: Returns for SOXX, Forecast Period 13w: [-0.00517569 -0.00894345  0.01119169 -0.00018634]
#
# Debug: Returns for SOXX, Forecast Period 14w: [ 0.00913945 -0.01709063  0.00106152 -0.02998747  0.01003917]
#
# Debug: Returns for SOXX, Forecast Period 15w: [ 0.00052618  0.00911485 -0.01984213  0.02091088 -0.03438017]
#
# Debug: Returns for SOXX, Forecast Period 16w: [-0.01417877  0.00610548 -0.03197648 -0.01945259 -0.04194084]
#
# Debug: Returns for SOXX, Forecast Period 17w: [0.01431321 0.01878423 0.0109852  0.01671432 0.01931972]
#
# Debug: Returns for SOXX, Forecast Period 18w: [ 0.00582451 -0.02278937 -0.03582782  0.02048647  0.02091746]
#
# Debug: Returns for SOXX, Forecast Period 19w: [ 0.0192258  -0.01040592 -0.00074982 -0.00534873  0.00802275]
#
# Debug: Returns for SOXX, Forecast Period 20w: [ 0.0006147   0.01528668  0.02678312 -0.00588981 -0.00648511]
#
# Debug: Returns for SOXX, Forecast Period 21w: [ 0.02160664 -0.0037439   0.01105229 -0.00639619  0.01904918]
#
# Debug: Returns for SOXX, Forecast Period 22w: [ 0.01606835 -0.02160768 -0.00778571 -0.00870729]
#
# Debug: Returns for SOXX, Forecast Period 23w: [ 0.00093189 -0.00870805  0.04278307 -0.00903848 -0.00388808]
#
# Debug: Returns for SOXX, Forecast Period 24w: [ 1.36057452e-02 -3.35891160e-05  2.73841971e-02  1.00135927e-02
#  -4.63807594e-03]
#
# Debug: Returns for SOXX, Forecast Period 25w: [ 0.01486902  0.01196612 -0.02821029 -0.01086296]
#
# Debug: Returns for SOXX, Forecast Period 26w: [-0.02998318  0.01402817 -0.00538491 -0.00683587  0.0086367 ]
#
# Debug: Returns for SOXX, Forecast Period 27w: [-0.00144571  0.01279964  0.01549925  0.00085847]
#
# Debug: Returns for SOXX, Forecast Period 28w: [ 0.01761847 -0.00167941  0.02211803 -0.03419288  0.01091671]
#
# Debug: Returns for SOXX, Forecast Period 29w: [-0.00034847  0.00467709 -0.07315167  0.00084142 -0.03301079]
#
# Debug: Returns for SOXX, Forecast Period 30w: [ 0.03936693 -0.01686559 -0.0552435  -0.02470751  0.01921307]
#
# Debug: Returns for SOXX, Forecast Period 31w: [-0.00423131 -0.03881362  0.06474587 -0.07475143 -0.05638249]
#
# Debug: Returns for SOXX, Forecast Period 32w: [-0.02093868  0.00571075 -0.03126285  0.06548977 -0.00892886]
#
# Debug: Returns for SOXX, Forecast Period 33w: [ 0.00263024  0.0375736  -0.00556875  0.04599026 -0.00427112]
#
# Debug: Returns for SOXX, Forecast Period 34w: [ 0.01530827 -0.01525373  0.01232795 -0.03566158  0.02555484]
#
# Debug: Returns for SOXX, Forecast Period 35w: [-0.0266621   0.00954491 -0.01936636 -0.00476827  0.02510001]
#
# Debug: Returns for SOXX, Forecast Period 36w: [-0.07735431  0.00232234 -0.00644773 -0.04389421]
#
# Debug: Returns for SOXX, Forecast Period 37w: [ 0.01827677  0.00922387  0.0451643  -0.00586     0.01644076]
#
# Debug: Returns for SOXX, Forecast Period 38w: [-0.01504132 -0.00050111 -0.01304631  0.04089456 -0.01643976]
#
# Debug: Returns for SOXX, Forecast Period 39w: [ 0.00239743  0.01045488  0.00551104  0.03435146 -0.0171048 ]
#
# Debug: Returns for SOXX, Forecast Period 40w: [-0.01030223 -0.02972195  0.01264823  0.00273909  0.01294894]
#
# Debug: Returns for SOXX, Forecast Period 41w: [-0.00311126  0.00935041  0.00991545 -0.00786631  0.00751938]
#
# Debug: Returns for SOXX, Forecast Period 42w: [ 0.01751595 -0.05298179 -0.00117626  0.00687186 -0.00036897]
#
# Debug: Returns for SOXX, Forecast Period 43w: [-0.00309061 -0.00504889 -0.01042113  0.00400694  0.00825983]
#
# Debug: Returns for SOXX, Forecast Period 44w: [-0.00098984  0.02310829 -0.03665024 -0.04050338  0.00895018]
#
# Debug: Returns for SOXX, Forecast Period 45w: [-0.00756607  0.00988861  0.02736683  0.01909281 -0.00915047]
#
# Debug: Returns for SOXX, Forecast Period 46w: [-0.02696483 -0.01308209 -0.02300599 -0.00244232 -0.0342847 ]
#
# Debug: Returns for SOXX, Forecast Period 47w: [ 1.09096315e-02 -8.11064921e-05 -9.69860969e-03  1.38938175e-02
#  -1.55640947e-03]
#
# Debug: Returns for SOXX, Forecast Period 48w: [ 0.00771204 -0.0150432  -0.01572181  0.01143279]
#
# Debug: Returns for PSI, Forecast Period 1w: [-0.03572751 -0.0233738  -0.01411056  0.00163373]
#
# Debug: Returns for PSI, Forecast Period 2w: [ 0.02893141  0.00230535 -0.00412341  0.00320059 -0.00509092]
#
# Debug: Returns for PSI, Forecast Period 3w: [ 0.01419195 -0.01146352  0.03262948  0.03892016]
#
# Debug: Returns for PSI, Forecast Period 4w: [ 0.00927172  0.0036478   0.01122554 -0.00070354 -0.02800797]
#
# Debug: Returns for PSI, Forecast Period 5w: [ 0.01185896 -0.01412854 -0.01978293  0.00834546  0.01186122]
#
# Debug: Returns for PSI, Forecast Period 6w: [ 0.00938137 -0.01320083  0.00707538  0.01924628  0.03176965]
#
# Debug: Returns for PSI, Forecast Period 7w: [ 1.72285123e-03 -2.69929825e-02  3.16277199e-02  5.55130800e-03
#   4.17636558e-05]
#
# Debug: Returns for PSI, Forecast Period 8w: [-0.02715366 -0.0111586   0.04373763 -0.01057059]
#
# Debug: Returns for PSI, Forecast Period 9w: [ 0.01351072 -0.00235462  0.00377698  0.01868289  0.04281038]
#
# Debug: Returns for PSI, Forecast Period 10w: [ 0.00394705 -0.0256396   0.02453925  0.02937002 -0.03743977]
#
# Debug: Returns for PSI, Forecast Period 11w: [-0.01485463  0.01717658 -0.02517141 -0.01514009 -0.00867115]
#
# Debug: Returns for PSI, Forecast Period 12w: [ 0.00701109 -0.00636287  0.02496465  0.02949343  0.00189463]
#
# Debug: Returns for PSI, Forecast Period 13w: [-0.0002852  -0.00616409  0.0115654  -0.00062937]
#
# Debug: Returns for PSI, Forecast Period 14w: [ 0.01070813 -0.01005417  0.01045979 -0.02489765  0.01294475]
#
# Debug: Returns for PSI, Forecast Period 15w: [ 0.00256657  0.00859553 -0.02072608  0.02670833 -0.03269839]
#
# Debug: Returns for PSI, Forecast Period 16w: [-0.01428726  0.0115021  -0.03228727 -0.01953562 -0.03955058]
#
# Debug: Returns for PSI, Forecast Period 17w: [0.01570808 0.02356149 0.00886301 0.01682243 0.02169939]
#
# Debug: Returns for PSI, Forecast Period 18w: [ 0.00858711 -0.02159178 -0.03309002  0.02939114  0.02225692]
#
# Debug: Returns for PSI, Forecast Period 19w: [ 0.02239109 -0.00470723 -0.00012932  0.00174771  0.00630808]
#
# Debug: Returns for PSI, Forecast Period 20w: [-0.00057371  0.01630927  0.0270034  -0.00773392 -0.00497093]
#
# Debug: Returns for PSI, Forecast Period 21w: [ 0.02198142  0.00091176  0.00199    -0.00245133  0.01770645]
#
# Debug: Returns for PSI, Forecast Period 22w: [ 0.01535932 -0.01465475 -0.00158554 -0.01086056]
#
# Debug: Returns for PSI, Forecast Period 23w: [ 0.00112553 -0.00969879  0.04660678 -0.00765796 -0.00909134]
#
# Debug: Returns for PSI, Forecast Period 24w: [ 0.02070641  0.00022278  0.02924262  0.00878373 -0.00773085]
#
# Debug: Returns for PSI, Forecast Period 25w: [ 0.02125068  0.0150217  -0.02786409 -0.01111163]
#
# Debug: Returns for PSI, Forecast Period 26w: [-0.02269166  0.02248778 -0.00190963  0.00207781  0.01299165]
#
# Debug: Returns for PSI, Forecast Period 27w: [-0.00024108  0.01456045  0.01283182  0.00326149]
#
# Debug: Returns for PSI, Forecast Period 28w: [ 0.0163484   0.00121408  0.01740401 -0.02854195  0.0123474 ]
#
# Debug: Returns for PSI, Forecast Period 29w: [ 0.01232254  0.00792763 -0.08122292 -0.00975154 -0.02580321]
#
# Debug: Returns for PSI, Forecast Period 30w: [ 0.04194219 -0.00827891 -0.05557272 -0.03027299  0.0162352 ]
#
# Debug: Returns for PSI, Forecast Period 31w: [-0.0046188  -0.04709653  0.06379405 -0.07949176 -0.05029296]
#
# Debug: Returns for PSI, Forecast Period 32w: [-0.01572712  0.006024   -0.01713503  0.07087952  0.00320789]
#
# Debug: Returns for PSI, Forecast Period 33w: [ 0.0027878   0.03657329 -0.00207724  0.05199786 -0.00532849]
#
# Debug: Returns for PSI, Forecast Period 34w: [ 0.01354306 -0.01500248  0.02256117 -0.03132413  0.02719955]
#
# Debug: Returns for PSI, Forecast Period 35w: [-0.02671637  0.01149675 -0.01444647  0.00618571  0.01294775]
#
# Debug: Returns for PSI, Forecast Period 36w: [-0.08031199  0.00665541 -0.00698134 -0.04057163]
#
# Debug: Returns for PSI, Forecast Period 37w: [ 0.01132047  0.00753709  0.0416114  -0.008063    0.02318884]
#
# Debug: Returns for PSI, Forecast Period 38w: [-0.02238894  0.00765069 -0.01073746  0.04352917 -0.01276752]
#
# Debug: Returns for PSI, Forecast Period 39w: [ 0.00443646  0.0117688   0.00673423  0.04979855 -0.0161139 ]
#
# Debug: Returns for PSI, Forecast Period 40w: [-0.00642485 -0.03645988  0.01867955 -0.00600203  0.0215183 ]
#
# Debug: Returns for PSI, Forecast Period 41w: [ 0.00135389  0.00356448  0.01562126 -0.00102165  0.01727534]
#
# Debug: Returns for PSI, Forecast Period 42w: [ 1.86544494e-02 -5.51468269e-02  2.26716495e-03  2.71261744e-03
#  -9.03941687e-05]
#
# Debug: Returns for PSI, Forecast Period 43w: [-0.0025137  -0.00541476 -0.00782591  0.0027837   0.01567696]
#
# Debug: Returns for PSI, Forecast Period 44w: [-0.00081184  0.02142148 -0.02382707 -0.0436684   0.00632577]
#
# Debug: Returns for PSI, Forecast Period 45w: [-0.00757802  0.02806317  0.03404061  0.02483254 -0.00388419]
#
# Debug: Returns for PSI, Forecast Period 46w: [-0.02175833 -0.01251328 -0.02125879 -0.00195096 -0.03895513]
#
# Debug: Returns for PSI, Forecast Period 47w: [0.01514658 0.00886655 0.00017981 0.03423536 0.00059583]
#
# Debug: Returns for PSI, Forecast Period 48w: [ 0.01371001 -0.00805153 -0.01758262  0.02057408]
#
# Debug: Returns for XSD, Forecast Period 1w: [-0.02940431 -0.03062788 -0.01751607  0.00241074]
#
# Debug: Returns for XSD, Forecast Period 2w: [ 0.03165309 -0.00179138 -0.00696586 -0.00566373 -0.00932593]
#
# Debug: Returns for XSD, Forecast Period 3w: [ 0.00071101 -0.01205286  0.03024572  0.03078099]
#
# Debug: Returns for XSD, Forecast Period 4w: [ 0.01664859  0.00939919 -0.00820513 -0.01051667 -0.02743386]
#
# Debug: Returns for XSD, Forecast Period 5w: [ 0.01641267 -0.02497041 -0.02023731 -0.00091807  0.00086792]
#
# Debug: Returns for XSD, Forecast Period 6w: [ 0.0079087  -0.00887068  0.01812825  0.02841883  0.02411816]
#
# Debug: Returns for XSD, Forecast Period 7w: [ 0.00331587 -0.03644486  0.02451878 -0.00067661 -0.01669635]
#
# Debug: Returns for XSD, Forecast Period 8w: [-0.01088872 -0.00238704  0.02216866 -0.01669157]
#
# Debug: Returns for XSD, Forecast Period 9w: [ 0.01157346 -0.00327972 -0.00732984  0.02343993  0.03791717]
#
# Debug: Returns for XSD, Forecast Period 10w: [-0.00100634 -0.0235475   0.02516895  0.03559057 -0.02948119]
#
# Debug: Returns for XSD, Forecast Period 11w: [-0.00650929  0.00828408 -0.02789763 -0.024065   -0.00792643]
#
# Debug: Returns for XSD, Forecast Period 12w: [-0.00124475 -0.00669963  0.02330792  0.02232968 -0.00711381]
#
# Debug: Returns for XSD, Forecast Period 13w: [-0.00184026 -0.0047101   0.02710215  0.00357138]
#
# Debug: Returns for XSD, Forecast Period 14w: [ 0.00750324 -0.02233379  0.00910267 -0.01571996  0.00503836]
#
# Debug: Returns for XSD, Forecast Period 15w: [ 0.00831857  0.02177188 -0.03968276  0.0233525  -0.03583458]
#
# Debug: Returns for XSD, Forecast Period 16w: [-0.02021894  0.00237992 -0.02204226 -0.02016156 -0.03175393]
#
# Debug: Returns for XSD, Forecast Period 17w: [0.01445531 0.01938858 0.02272103 0.02340282 0.01816361]
#
# Debug: Returns for XSD, Forecast Period 18w: [ 0.01735526 -0.01849664 -0.03235664  0.01723838  0.02244963]
#
# Debug: Returns for XSD, Forecast Period 19w: [ 0.01716773 -0.00353353  0.00369885  0.00333309 -0.00609061]
#
# Debug: Returns for XSD, Forecast Period 20w: [ 0.00524269  0.01773157  0.02077688 -0.00466244  0.00101525]
#
# Debug: Returns for XSD, Forecast Period 21w: [ 0.01369197 -0.00303581  0.02071644 -0.02124539  0.02283044]
#
# Debug: Returns for XSD, Forecast Period 22w: [ 0.01401964 -0.01876656  0.00517334  0.00085836]
#
# Debug: Returns for XSD, Forecast Period 23w: [-0.00023733 -0.01483505  0.03915529 -0.00855409 -0.01925909]
#
# Debug: Returns for XSD, Forecast Period 24w: [ 0.01577553  0.00466956  0.02786191 -0.00250217 -0.0167606 ]
#
# Debug: Returns for XSD, Forecast Period 25w: [ 0.00742702  0.00128955 -0.02192032  0.00090676]
#
# Debug: Returns for XSD, Forecast Period 26w: [-0.02019388  0.00870779  0.00051385 -0.00246677  0.01067848]
#
# Debug: Returns for XSD, Forecast Period 27w: [-0.00399464  0.02007973  0.00949658  0.00484278]
#
# Debug: Returns for XSD, Forecast Period 28w: [ 0.02122476 -0.00591983  0.02780469 -0.01259756  0.01187704]
#
# Debug: Returns for XSD, Forecast Period 29w: [ 0.01021092  0.01942485 -0.05616085 -0.00845023 -0.02969144]
#
# Debug: Returns for XSD, Forecast Period 30w: [ 0.03894958 -0.01591626 -0.04578669 -0.02526598  0.02149328]
#
# Debug: Returns for XSD, Forecast Period 31w: [-0.00018918 -0.04145117  0.04412418 -0.06614949 -0.06076708]
#
# Debug: Returns for XSD, Forecast Period 32w: [-0.03015532  0.00301073 -0.03126848  0.06836344 -0.00625929]
#
# Debug: Returns for XSD, Forecast Period 33w: [-0.00017177  0.03953225 -0.01298479  0.0533467  -0.00353215]
#
# Debug: Returns for XSD, Forecast Period 34w: [ 0.01369788 -0.00976965  0.02216513 -0.02973903  0.0336878 ]
#
# Debug: Returns for XSD, Forecast Period 35w: [-0.01801296  0.00637382 -0.01253167  0.01575354  0.014527  ]
#
# Debug: Returns for XSD, Forecast Period 36w: [-0.07427355  0.00425664 -0.00904636 -0.04166573]
#
# Debug: Returns for XSD, Forecast Period 37w: [ 0.01733868  0.00342036  0.04057556 -0.0066132   0.02241158]
#
# Debug: Returns for XSD, Forecast Period 38w: [-0.01198139  0.00413472 -0.00346628  0.03938447 -0.01600146]
#
# Debug: Returns for XSD, Forecast Period 39w: [ 0.00418039  0.00994179 -0.00375147  0.04543547 -0.00466043]
#
# Debug: Returns for XSD, Forecast Period 40w: [-0.00988452 -0.03491933  0.01132191 -0.00158755  0.01852781]
#
# Debug: Returns for XSD, Forecast Period 41w: [-0.00557835  0.00484727  0.0135816  -0.00486478  0.02076005]
#
# Debug: Returns for XSD, Forecast Period 42w: [ 1.15800182e-02 -2.66572515e-02  6.66058221e-03  3.92527430e-03
#   7.78728695e-05]
#
# Debug: Returns for XSD, Forecast Period 43w: [-0.00308394  0.0002303  -0.00893201  0.0049408   0.0112456 ]
#
# Debug: Returns for XSD, Forecast Period 44w: [ 0.01207571  0.02311149 -0.04240226 -0.05085198  0.02156597]
#
# Debug: Returns for XSD, Forecast Period 45w: [-0.00512292  0.01574463  0.04205758  0.01138687  0.00788562]
#
# Debug: Returns for XSD, Forecast Period 46w: [-0.02791182 -0.01967038 -0.02212646 -0.00833499 -0.03293858]
#
# Debug: Returns for XSD, Forecast Period 47w: [0.01496939 0.0094397  0.00016498 0.02800296 0.01501709]
#
# Debug: Returns for XSD, Forecast Period 48w: [ 0.03180689 -0.01155476 -0.01161202  0.01885178]
#
# Debug: Returns for IYW, Forecast Period 1w: [-0.02656827 -0.01046256 -0.00723689  0.00059937]
#
# Debug: Returns for IYW, Forecast Period 2w: [0.02608176 0.00273929 0.0091814  0.004045   0.00223806]
#
# Debug: Returns for IYW, Forecast Period 3w: [ 0.0013812  -0.00580949  0.01875127  0.02342881]
#
# Debug: Returns for IYW, Forecast Period 4w: [ 0.00397523  0.00400893  0.00700762  0.00429532 -0.00941404]
#
# Debug: Returns for IYW, Forecast Period 5w: [ 0.0106899  -0.00874038 -0.02611687  0.01184421  0.01859105]
#
# Debug: Returns for IYW, Forecast Period 6w: [ 0.00099281 -0.00368884  0.01506512  0.00432304  0.01487322]
#
# Debug: Returns for IYW, Forecast Period 7w: [-0.00783326 -0.01747676  0.0121834  -0.00238134 -0.01133   ]
#
# Debug: Returns for IYW, Forecast Period 8w: [-0.01035226 -0.00823323  0.03287058 -0.00256632]
#
# Debug: Returns for IYW, Forecast Period 9w: [-0.00294534  0.00199294 -0.007334    0.01076524  0.01561633]
#
# Debug: Returns for IYW, Forecast Period 10w: [-0.002995   -0.0239177   0.00839124  0.01745728 -0.0145429 ]
#
# Debug: Returns for IYW, Forecast Period 11w: [-0.00481575  0.01913906 -0.00934622  0.00022385 -0.01609468]
#
# Debug: Returns for IYW, Forecast Period 12w: [0.00767134 0.00404476 0.01230413 0.00250685 0.00291438]
#
# Debug: Returns for IYW, Forecast Period 13w: [-0.00545221 -0.00550666  0.00053633 -0.00252275]
#
# Debug: Returns for IYW, Forecast Period 14w: [ 0.00320142 -0.00841896  0.00155591 -0.0172193   0.01353167]
#
# Debug: Returns for IYW, Forecast Period 15w: [-0.00243202  0.00149449 -0.00760624  0.02056694 -0.01757355]
#
# Debug: Returns for IYW, Forecast Period 16w: [-0.02160941  0.00123394 -0.01625698 -0.00798284 -0.02946034]
#
# Debug: Returns for IYW, Forecast Period 17w: [ 0.01084049  0.01689141  0.00151702 -0.00593122  0.0204386 ]
#
# Debug: Returns for IYW, Forecast Period 18w: [-0.00018328 -0.02278804 -0.01044355  0.0152229   0.0237698 ]
#
# Debug: Returns for IYW, Forecast Period 19w: [ 0.01485447 -0.0050589  -0.00034425 -0.00175273  0.00248625]
#
# Debug: Returns for IYW, Forecast Period 20w: [ 0.00310277  0.00837905  0.02205731 -0.00273144 -0.00252198]
#
# Debug: Returns for IYW, Forecast Period 21w: [0.01289789 0.00112489 0.0002689  0.00172333 0.00907724]
#
# Debug: Returns for IYW, Forecast Period 22w: [ 0.01063679 -0.0052137  -0.02555305 -0.00060048]
#
# Debug: Returns for IYW, Forecast Period 23w: [ 0.00776251  0.00122687  0.026489   -0.00318605  0.00106533]
#
# Debug: Returns for IYW, Forecast Period 24w: [0.00307397 0.01454511 0.0225312  0.00647138 0.00549931]
#
# Debug: Returns for IYW, Forecast Period 25w: [ 0.01108846  0.0046581  -0.01375487 -0.00651496]
#
# Debug: Returns for IYW, Forecast Period 26w: [-0.01719185  0.01689524  0.00329836  0.00140617 -0.00428324]
#
# Debug: Returns for IYW, Forecast Period 27w: [0.00994358 0.00673988 0.01101441 0.00927337]
#
# Debug: Returns for IYW, Forecast Period 28w: [ 0.00503289 -0.00207418  0.01333343 -0.02451956  0.00663224]
#
# Debug: Returns for IYW, Forecast Period 29w: [ 0.00472902 -0.00322589 -0.03822925 -0.00564164 -0.01165358]
#
# Debug: Returns for IYW, Forecast Period 30w: [ 0.01945528 -0.00256473 -0.04353788 -0.01014486  0.0101069 ]
#
# Debug: Returns for IYW, Forecast Period 31w: [-0.00391817 -0.0202699   0.03349717 -0.03252096 -0.0268917 ]
#
# Debug: Returns for IYW, Forecast Period 32w: [-0.03706084  0.00749316 -0.01264019  0.03353505  0.00524768]
#
# Debug: Returns for IYW, Forecast Period 33w: [0.00393245 0.02637344 0.00202807 0.02396216 0.00068795]
#
# Debug: Returns for IYW, Forecast Period 34w: [ 0.01279438 -0.00396354  0.00482236 -0.02056024  0.01313518]
#
# Debug: Returns for IYW, Forecast Period 35w: [-0.01012392  0.00351879 -0.01310244 -0.00486396  0.01060308]
#
# Debug: Returns for IYW, Forecast Period 36w: [-0.04225389 -0.00432159 -0.0006319  -0.02421907]
#
# Debug: Returns for IYW, Forecast Period 37w: [0.01167799 0.01020683 0.02733147 0.00795836 0.00468575]
#
# Debug: Returns for IYW, Forecast Period 38w: [-0.00696585 -0.00037038 -0.00575453  0.02986155 -0.00389422]
#
# Debug: Returns for IYW, Forecast Period 39w: [-0.00170105  0.00634297  0.00309468  0.00903759 -0.00834324]
#
# Debug: Returns for IYW, Forecast Period 40w: [ 0.00359188 -0.02365622  0.00571383  0.00402279  0.01287103]
#
# Debug: Returns for IYW, Forecast Period 41w: [-0.00868504  0.01853914  0.00880891  0.00039353  0.00213596]
#
# Debug: Returns for IYW, Forecast Period 42w: [ 0.01274708 -0.01845657 -0.00013522  0.00271238  0.00329322]
#
# Debug: Returns for IYW, Forecast Period 43w: [ 6.43044343e-03 -8.22194573e-05 -1.61052208e-02  3.45368237e-03
#   6.01384983e-03]
#
# Debug: Returns for IYW, Forecast Period 44w: [ 0.00131753  0.01300776 -0.01215814 -0.03376354  0.00616836]
#
# Debug: Returns for IYW, Forecast Period 45w: [-0.00263451  0.01411072  0.02731347  0.02037761 -0.00196978]
#
# Debug: Returns for IYW, Forecast Period 46w: [-0.00499209  0.00306041 -0.00527519 -0.00381781 -0.02589665]
#
# Debug: Returns for IYW, Forecast Period 47w: [ 3.62173343e-03  1.17546432e-02 -1.97172861e-03  6.31344585e-03
#  -6.56298305e-05]
#
# Debug: Returns for IYW, Forecast Period 48w: [-0.00046112  0.00430917 -0.01256244  0.00806075]
#
# Debug: Returns for XLK, Forecast Period 1w: [-0.02644247 -0.01057752 -0.00770121 -0.00071984]
#
# Debug: Returns for XLK, Forecast Period 2w: [0.02465829 0.00124192 0.00812018 0.00469494 0.00285041]
#
# Debug: Returns for XLK, Forecast Period 3w: [ 0.00208105 -0.00533099  0.01983251  0.02273045]
#
# Debug: Returns for XLK, Forecast Period 4w: [ 0.00418963  0.00397581  0.00680738  0.00410504 -0.01161699]
#
# Debug: Returns for XLK, Forecast Period 5w: [ 0.0090257  -0.00840923 -0.02121694  0.0124839   0.01037075]
#
# Debug: Returns for XLK, Forecast Period 6w: [ 0.00239406 -0.00451489  0.01318078  0.00312032  0.01341147]
#
# Debug: Returns for XLK, Forecast Period 7w: [-0.00763267 -0.01708522  0.01025564 -0.00222496 -0.0094231 ]
#
# Debug: Returns for XLK, Forecast Period 8w: [-0.01059298 -0.00680048  0.03213536 -0.00280194]
#
# Debug: Returns for XLK, Forecast Period 9w: [ 0.00044265  0.00044653 -0.00522049  0.01067971  0.01804815]
#
# Debug: Returns for XLK, Forecast Period 10w: [-0.00023011 -0.02490542  0.00750843  0.01546599 -0.01521062]
#
# Debug: Returns for XLK, Forecast Period 11w: [-0.00323688  0.0199488  -0.01123525 -0.00016502 -0.0155362 ]
#
# Debug: Returns for XLK, Forecast Period 12w: [ 4.41812228e-03  4.77624429e-03  1.08754725e-02  5.17646730e-04
#  -2.10190342e-05]
#
# Debug: Returns for XLK, Forecast Period 13w: [-0.00699238 -0.00452798  0.00467396 -0.0025715 ]
#
# Debug: Returns for XLK, Forecast Period 14w: [ 0.00230818 -0.01019331  0.00206932 -0.01623793  0.01092755]
#
# Debug: Returns for XLK, Forecast Period 15w: [-0.00175187  0.00456246 -0.01272031  0.0193676  -0.0166696 ]
#
# Debug: Returns for XLK, Forecast Period 16w: [-0.01958544  0.000631   -0.01503792 -0.01214329 -0.02150428]
#
# Debug: Returns for XLK, Forecast Period 17w: [ 0.00798933  0.01391625  0.00377757 -0.00293987  0.01050539]
#
# Debug: Returns for XLK, Forecast Period 18w: [ 0.00357767 -0.02278675 -0.0110531   0.01355606  0.02719999]
#
# Debug: Returns for XLK, Forecast Period 19w: [ 0.01118188 -0.00377547  0.00229047 -0.00079046  0.00310351]
#
# Debug: Returns for XLK, Forecast Period 20w: [ 0.00425777  0.00854624  0.02224781 -0.00352885 -0.00220533]
#
# Debug: Returns for XLK, Forecast Period 21w: [ 0.01191159  0.00177569  0.00228256 -0.00810877  0.00846368]
#
# Debug: Returns for XLK, Forecast Period 22w: [ 0.00422637 -0.00636924 -0.02277034  0.0015953 ]
#
# Debug: Returns for XLK, Forecast Period 23w: [ 0.00245891  0.00192355  0.02199689 -0.00346238  0.00217015]
#
# Debug: Returns for XLK, Forecast Period 24w: [0.00240831 0.01845247 0.02204814 0.00790973 0.00369002]
#
# Debug: Returns for XLK, Forecast Period 25w: [ 0.0151984   0.00139834 -0.01120799 -0.00180415]
#
# Debug: Returns for XLK, Forecast Period 26w: [-0.02468926  0.01816894 -0.0013196   0.00029649 -0.00072045]
#
# Debug: Returns for XLK, Forecast Period 27w: [0.00756034 0.00502892 0.01355236 0.00314937]
#
# Debug: Returns for XLK, Forecast Period 28w: [ 0.00682213 -0.00076459  0.0145744  -0.02497324  0.00877666]
#
# Debug: Returns for XLK, Forecast Period 29w: [ 0.00155417 -0.00363051 -0.03935886 -0.00064409 -0.01641528]
#
# Debug: Returns for XLK, Forecast Period 30w: [ 0.02291237 -0.00464103 -0.0420148  -0.01165405  0.01172393]
#
# Debug: Returns for XLK, Forecast Period 31w: [-0.00532949 -0.02610019  0.04122762 -0.03835196 -0.02943901]
#
# Debug: Returns for XLK, Forecast Period 32w: [-0.03489409  0.01187276 -0.01789228  0.03551385  0.0030836 ]
#
# Debug: Returns for XLK, Forecast Period 33w: [0.00674697 0.02933571 0.00425766 0.0279443  0.0009457 ]
#
# Debug: Returns for XLK, Forecast Period 34w: [ 0.01593675 -0.00411353  0.00534998 -0.02327844  0.01595277]
#
# Debug: Returns for XLK, Forecast Period 35w: [-0.0128858   0.0057018  -0.01400349 -0.00960228  0.01299055]
#
# Debug: Returns for XLK, Forecast Period 36w: [-0.04615331 -0.00277151 -0.00184455 -0.02621961]
#
# Debug: Returns for XLK, Forecast Period 37w: [0.01580314 0.01447507 0.03368759 0.00785901 0.00460886]
#
# Debug: Returns for XLK, Forecast Period 38w: [-0.00436061 -0.0025434  -0.00987413  0.02902686 -0.00548172]
#
# Debug: Returns for XLK, Forecast Period 39w: [-0.00065098  0.00633066  0.00245109  0.01281662 -0.00966794]
#
# Debug: Returns for XLK, Forecast Period 40w: [ 0.00261886 -0.02482675  0.00723757  0.00405471  0.01109867]
#
# Debug: Returns for XLK, Forecast Period 41w: [-0.0067243   0.01872932  0.01125797 -0.00034135  0.00160547]
#
# Debug: Returns for XLK, Forecast Period 42w: [ 0.01289303 -0.02209347  0.00292258  0.00298717  0.00334557]
#
# Debug: Returns for XLK, Forecast Period 43w: [ 0.00450765 -0.00120839 -0.01457925  0.0025872   0.00476928]
#
# Debug: Returns for XLK, Forecast Period 44w: [-0.00064792  0.01311628 -0.01605359 -0.03244229  0.0070108 ]
#
# Debug: Returns for XLK, Forecast Period 45w: [-0.00130633  0.01358092  0.0279298   0.01698049 -0.00145627]
#
# Debug: Returns for XLK, Forecast Period 46w: [-0.00593744  0.0007413  -0.00383213 -0.00383442 -0.02534016]
#
# Debug: Returns for XLK, Forecast Period 47w: [ 2.63315138e-03  7.59074701e-03 -1.44266810e-03  9.69837226e-03
#   5.42666897e-05]
#
# Debug: Returns for XLK, Forecast Period 48w: [-0.00058216  0.00449427 -0.01414184  0.00876212]
#
# Debug: Returns for VGT, Forecast Period 1w: [-0.02599743 -0.01330442 -0.00582275  0.00042485]
#
# Debug: Returns for VGT, Forecast Period 2w: [0.02567243 0.00205593 0.00871964 0.00370082 0.00243256]
#
# Debug: Returns for VGT, Forecast Period 3w: [ 0.00166255 -0.00527715  0.0196692   0.02199401]
#
# Debug: Returns for VGT, Forecast Period 4w: [ 0.0068653   0.0046529   0.00525754  0.00283166 -0.00998791]
#
# Debug: Returns for VGT, Forecast Period 5w: [ 0.01207709 -0.00926712 -0.02048558  0.01332675  0.01028617]
#
# Debug: Returns for VGT, Forecast Period 6w: [ 0.00103819 -0.00117734  0.01338765  0.00552622  0.01564919]
#
# Debug: Returns for VGT, Forecast Period 7w: [-0.00577473 -0.01919443  0.01376617 -0.00031431 -0.01019478]
#
# Debug: Returns for VGT, Forecast Period 8w: [-0.01155172 -0.00836223  0.03273653 -0.00312424]
#
# Debug: Returns for VGT, Forecast Period 9w: [ 0.00283229  0.00173312 -0.00444627  0.0097618   0.01895873]
#
# Debug: Returns for VGT, Forecast Period 10w: [ 0.00223493 -0.02375506  0.01143185  0.01721987 -0.01601413]
#
# Debug: Returns for VGT, Forecast Period 11w: [-0.00401351  0.02095614 -0.01033111 -0.00343416 -0.01289628]
#
# Debug: Returns for VGT, Forecast Period 12w: [0.00495422 0.00452544 0.01390132 0.00327064 0.00195778]
#
# Debug: Returns for VGT, Forecast Period 13w: [-0.00371637 -0.00406768  0.0026774  -0.00111647]
#
# Debug: Returns for VGT, Forecast Period 14w: [ 0.00235155 -0.01107998  0.00229752 -0.01586939  0.01238875]
#
# Debug: Returns for VGT, Forecast Period 15w: [-0.00123749  0.00255096 -0.00885376  0.01953342 -0.01755112]
#
# Debug: Returns for VGT, Forecast Period 16w: [-0.01887509  0.00077238 -0.01469772 -0.00939592 -0.02663935]
#
# Debug: Returns for VGT, Forecast Period 17w: [0.01354313 0.01638253 0.00158461 0.00044232 0.01724126]
#
# Debug: Returns for VGT, Forecast Period 18w: [ 0.00402982 -0.02211673 -0.01079188  0.01374214  0.02723505]
#
# Debug: Returns for VGT, Forecast Period 19w: [ 0.01474346 -0.00384672  0.00174476 -0.00071455  0.00286214]
#
# Debug: Returns for VGT, Forecast Period 20w: [ 0.00518436  0.01066552  0.02334699 -0.00367946 -0.00183678]
#
# Debug: Returns for VGT, Forecast Period 21w: [0.01344691 0.00163719 0.00080824 0.00064607 0.01037691]
#
# Debug: Returns for VGT, Forecast Period 22w: [ 0.00923171 -0.0028948  -0.02297674 -0.00027046]
#
# Debug: Returns for VGT, Forecast Period 23w: [ 0.00583077  0.00115055  0.02601606 -0.00228606  0.00046428]
#
# Debug: Returns for VGT, Forecast Period 24w: [0.00401908 0.01460985 0.02213294 0.01053404 0.00448663]
#
# Debug: Returns for VGT, Forecast Period 25w: [ 0.01293955  0.00477895 -0.01304359 -0.00453928]
#
# Debug: Returns for VGT, Forecast Period 26w: [-0.01781927  0.01488125  0.00250876  0.00249277  0.00015458]
#
# Debug: Returns for VGT, Forecast Period 27w: [0.01041691 0.00730733 0.01224177 0.00576773]
#
# Debug: Returns for VGT, Forecast Period 28w: [ 0.00733965 -0.00146734  0.01445902 -0.01862195  0.00989267]
#
# Debug: Returns for VGT, Forecast Period 29w: [ 0.00569734  0.00173601 -0.03570266 -0.00502052 -0.01167664]
#
# Debug: Returns for VGT, Forecast Period 30w: [ 0.02019546 -0.00155202 -0.03908491 -0.0093306   0.01191729]
#
# Debug: Returns for VGT, Forecast Period 31w: [-0.0035486  -0.01905056  0.03508907 -0.0362298  -0.02474121]
#
# Debug: Returns for VGT, Forecast Period 32w: [-0.03544337  0.00955239 -0.01203852  0.03427527  0.00620273]
#
# Debug: Returns for VGT, Forecast Period 33w: [0.00503287 0.02875234 0.00432234 0.02713075 0.00250456]
#
# Debug: Returns for VGT, Forecast Period 34w: [ 0.01428461 -0.00301294  0.00610146 -0.02046051  0.01844188]
#
# Debug: Returns for VGT, Forecast Period 35w: [-0.00897709  0.00514935 -0.01268238 -0.00234821  0.01091747]
#
# Debug: Returns for VGT, Forecast Period 36w: [-0.04366816 -0.0016415  -0.00178887 -0.02366281]
#
# Debug: Returns for VGT, Forecast Period 37w: [0.01380619 0.0104752  0.02923249 0.00807009 0.00631918]
#
# Debug: Returns for VGT, Forecast Period 38w: [-0.00555947 -0.00020838 -0.00442502  0.02992271 -0.0031381 ]
#
# Debug: Returns for VGT, Forecast Period 39w: [ 8.78935212e-05  9.49135056e-03  1.13773828e-03  1.28489851e-02
#  -6.95117778e-03]
#
# Debug: Returns for VGT, Forecast Period 40w: [ 0.003114   -0.02485498  0.00687509  0.00452459  0.01348669]
#
# Debug: Returns for VGT, Forecast Period 41w: [-0.00647834  0.01895894  0.01191198  0.00150766  0.00372805]
#
# Debug: Returns for VGT, Forecast Period 42w: [ 0.0130268  -0.01743364  0.00433431  0.00464677  0.00405525]
#
# Debug: Returns for VGT, Forecast Period 43w: [ 0.00620674 -0.00010008 -0.01501638  0.00390068  0.00516071]
#
# Debug: Returns for VGT, Forecast Period 44w: [ 0.0025091   0.01230472 -0.01253274 -0.03286506  0.00753862]
#
# Debug: Returns for VGT, Forecast Period 45w: [-0.00064724  0.01489601  0.03171656  0.02095163 -0.00124943]
#
# Debug: Returns for VGT, Forecast Period 46w: [-0.00362241  0.00217927 -0.00358842 -0.00363676 -0.02402559]
#
# Debug: Returns for VGT, Forecast Period 47w: [0.00328027 0.01269383 0.00144503 0.01100589 0.00412333]
#
# Debug: Returns for VGT, Forecast Period 48w: [-0.00013043  0.00338906 -0.00998919  0.00931882]
#
# Debug: Returns for FTEC, Forecast Period 1w: [-0.0249032  -0.00985293 -0.00545547  0.00260761]
#
# Debug: Returns for FTEC, Forecast Period 2w: [0.02707662 0.00315949 0.01061689 0.00618995 0.00450386]
#
# Debug: Returns for FTEC, Forecast Period 3w: [ 0.00344854 -0.00340841  0.02177631  0.02422573]
#
# Debug: Returns for FTEC, Forecast Period 4w: [ 0.00838341  0.00585685  0.00651598  0.00437326 -0.00806995]
#
# Debug: Returns for FTEC, Forecast Period 5w: [ 0.01317555 -0.00647424 -0.01972131  0.01440885  0.01138493]
#
# Debug: Returns for FTEC, Forecast Period 6w: [ 0.00228401 -0.00112628  0.01464618  0.00706031  0.01639063]
#
# Debug: Returns for FTEC, Forecast Period 7w: [-0.00497602 -0.0177259   0.01459859 -0.00023264 -0.00844735]
#
# Debug: Returns for FTEC, Forecast Period 8w: [-0.00884197 -0.00669996  0.03491164 -0.00115868]
#
# Debug: Returns for FTEC, Forecast Period 9w: [ 0.00416436  0.00257501 -0.00194658  0.01118548  0.02095815]
#
# Debug: Returns for FTEC, Forecast Period 10w: [ 0.00254402 -0.02138419  0.01272371  0.01871595 -0.0144017 ]
#
# Debug: Returns for FTEC, Forecast Period 11w: [-0.0023288   0.02242927 -0.00805849 -0.00176469 -0.01168465]
#
# Debug: Returns for FTEC, Forecast Period 12w: [0.00720241 0.00680638 0.01481871 0.00405588 0.00401105]
#
# Debug: Returns for FTEC, Forecast Period 13w: [-0.00207417 -0.00341078  0.00532137  0.00016095]
#
# Debug: Returns for FTEC, Forecast Period 14w: [ 0.00250149 -0.00729576  0.00428076 -0.01378031  0.0142301 ]
#
# Debug: Returns for FTEC, Forecast Period 15w: [ 0.00091564  0.00598072 -0.0086977   0.02328466 -0.01551321]
#
# Debug: Returns for FTEC, Forecast Period 16w: [-0.01882421  0.00516577 -0.01355961 -0.00613928 -0.02384704]
#
# Debug: Returns for FTEC, Forecast Period 17w: [0.01528984 0.02108551 0.00513424 0.00472291 0.01908091]
#
# Debug: Returns for FTEC, Forecast Period 18w: [ 0.00541313 -0.01887729 -0.00866214  0.01776929  0.02860928]
#
# Debug: Returns for FTEC, Forecast Period 19w: [ 0.01833658 -0.00330865  0.00305984  0.00182652  0.00558883]
#
# Debug: Returns for FTEC, Forecast Period 20w: [ 0.00689952  0.01128142  0.02542343 -0.00227679 -0.00197988]
#
# Debug: Returns for FTEC, Forecast Period 21w: [0.01357624 0.00264766 0.00254647 0.00172537 0.01099316]
#
# Debug: Returns for FTEC, Forecast Period 22w: [ 0.01128066 -0.0036281  -0.02189701 -0.00068146]
#
# Debug: Returns for FTEC, Forecast Period 23w: [ 0.00815656  0.00343574  0.02832021 -0.00204549  0.00127271]
#
# Debug: Returns for FTEC, Forecast Period 24w: [0.00620268 0.01523201 0.0250129  0.01076743 0.00571247]
#
# Debug: Returns for FTEC, Forecast Period 25w: [ 0.01363056  0.00554216 -0.01143223 -0.00348511]
#
# Debug: Returns for FTEC, Forecast Period 26w: [-0.01634702  0.0161886   0.00546481  0.0041917   0.00061384]
#
# Debug: Returns for FTEC, Forecast Period 27w: [0.01125162 0.00865602 0.01282234 0.00669929]
#
# Debug: Returns for FTEC, Forecast Period 28w: [ 0.01053478 -0.00190927  0.01520789 -0.01865231  0.01291115]
#
# Debug: Returns for FTEC, Forecast Period 29w: [ 0.00682031  0.00380697 -0.03341141 -0.00222799 -0.00892992]
#
# Debug: Returns for FTEC, Forecast Period 30w: [ 0.02170864  0.00132789 -0.03589399 -0.00592264  0.01397208]
#
# Debug: Returns for FTEC, Forecast Period 31w: [-0.00084259 -0.01635797  0.03928708 -0.03182648 -0.02247141]
#
# Debug: Returns for FTEC, Forecast Period 32w: [-0.02998976  0.01401786 -0.00836797  0.03982866  0.00796815]
#
# Debug: Returns for FTEC, Forecast Period 33w: [0.00987903 0.03283648 0.00777595 0.0296444  0.00504991]
#
# Debug: Returns for FTEC, Forecast Period 34w: [ 0.01592363 -0.00102214  0.00885472 -0.01698345  0.018585  ]
#
# Debug: Returns for FTEC, Forecast Period 35w: [-0.00832566  0.00720873 -0.0106669  -0.00084098  0.01165704]
#
# Debug: Returns for FTEC, Forecast Period 36w: [-0.04110824 -0.00118857  0.0006011  -0.02142112]
#
# Debug: Returns for FTEC, Forecast Period 37w: [0.01491445 0.01329573 0.03079508 0.01008189 0.00882118]
#
# Debug: Returns for FTEC, Forecast Period 38w: [-0.00428155  0.00355269 -0.00296307  0.03366616 -0.00078854]
#
# Debug: Returns for FTEC, Forecast Period 39w: [ 0.00118359  0.01032163  0.00423455  0.01517348 -0.00567712]
#
# Debug: Returns for FTEC, Forecast Period 40w: [ 0.00576317 -0.02308993  0.0088798   0.00597129  0.01424208]
#
# Debug: Returns for FTEC, Forecast Period 41w: [-0.00492633  0.01903114  0.01308815  0.00368136  0.00534817]
#
# Debug: Returns for FTEC, Forecast Period 42w: [ 0.01428432 -0.01434605  0.00399663  0.00525444  0.00643969]
#
# Debug: Returns for FTEC, Forecast Period 43w: [ 0.00788414  0.00100324 -0.01231875  0.00590364  0.00793219]
#
# Debug: Returns for FTEC, Forecast Period 44w: [ 0.00352897  0.01549418 -0.01249841 -0.03034138  0.01041015]
#
# Debug: Returns for FTEC, Forecast Period 45w: [0.00147581 0.01732124 0.03343763 0.02307444 0.00115488]
#
# Debug: Returns for FTEC, Forecast Period 46w: [-0.00162764  0.00334926 -0.00186924 -0.00163485 -0.02100597]
#
# Debug: Returns for FTEC, Forecast Period 47w: [0.00534348 0.01507181 0.00318326 0.01319912 0.00587046]
#
# Debug: Returns for FTEC, Forecast Period 48w: [ 0.00247466  0.00558244 -0.00856369  0.01240122]
#
# Debug: Returns for IGM, Forecast Period 1w: [-0.02647361 -0.01217534 -0.00434332  0.00212565]
#
# Debug: Returns for IGM, Forecast Period 2w: [0.02754998 0.00330298 0.00974982 0.00557712 0.00161472]
#
# Debug: Returns for IGM, Forecast Period 3w: [ 0.00166257 -0.00579941  0.01729842  0.02499536]
#
# Debug: Returns for IGM, Forecast Period 4w: [ 0.00462334  0.00473366  0.0097966   0.0054462  -0.00913371]
#
# Debug: Returns for IGM, Forecast Period 5w: [ 0.01307035 -0.00751157 -0.02497544  0.01152191  0.02807722]
#
# Debug: Returns for IGM, Forecast Period 6w: [ 0.00150251 -0.0052059   0.01568614  0.00549628  0.01503763]
#
# Debug: Returns for IGM, Forecast Period 7w: [-0.00506675 -0.01817153  0.01765228 -0.00076351 -0.01220774]
#
# Debug: Returns for IGM, Forecast Period 8w: [-0.0144819  -0.01110208  0.04280913 -0.00261173]
#
# Debug: Returns for IGM, Forecast Period 9w: [ 0.0006965   0.0014813  -0.0073843   0.01231445  0.02119302]
#
# Debug: Returns for IGM, Forecast Period 10w: [ 0.00090418 -0.02060121  0.01208935  0.02088497 -0.01987139]
#
# Debug: Returns for IGM, Forecast Period 11w: [-0.00797663  0.02195261 -0.00959714 -0.00640756 -0.01520094]
#
# Debug: Returns for IGM, Forecast Period 12w: [0.01039866 0.00146608 0.0131739  0.00237789 0.00304692]
#
# Debug: Returns for IGM, Forecast Period 13w: [-0.00537588 -0.00418166  0.00036968 -0.00219752]
#
# Debug: Returns for IGM, Forecast Period 14w: [ 0.00502681 -0.00797885  0.00346329 -0.01758778  0.01287339]
#
# Debug: Returns for IGM, Forecast Period 15w: [-0.00102057  0.00308895 -0.00986258  0.01698684 -0.01863126]
#
# Debug: Returns for IGM, Forecast Period 16w: [-0.02113259  0.00177306 -0.01386291 -0.0057579  -0.0287059 ]
#
# Debug: Returns for IGM, Forecast Period 17w: [ 0.00976359  0.01874098 -0.00030943 -0.01039163  0.02280781]
#
# Debug: Returns for IGM, Forecast Period 18w: [-0.00448131 -0.02037503 -0.00914608  0.01465928  0.02012454]
#
# Debug: Returns for IGM, Forecast Period 19w: [ 0.01561572 -0.00179843 -0.00142422 -0.00202202  0.0018105 ]
#
# Debug: Returns for IGM, Forecast Period 20w: [ 0.00095052  0.00832079  0.02315645 -0.00379172 -0.00114889]
#
# Debug: Returns for IGM, Forecast Period 21w: [ 0.01094743 -0.00088772  0.00140248 -0.00335101  0.00890288]
#
# Debug: Returns for IGM, Forecast Period 22w: [ 0.00810214 -0.00549775 -0.02497295 -0.00101298]
#
# Debug: Returns for IGM, Forecast Period 23w: [ 0.00450172  0.00219031  0.02587214 -0.00283548 -0.00180304]
#
# Debug: Returns for IGM, Forecast Period 24w: [0.00553223 0.01020014 0.01820082 0.0049868  0.00629773]
#
# Debug: Returns for IGM, Forecast Period 25w: [ 0.01015624  0.00263832 -0.01015763 -0.00414326]
#
# Debug: Returns for IGM, Forecast Period 26w: [-0.01498501  0.01457018  0.00025141  0.0050312  -0.00361944]
#
# Debug: Returns for IGM, Forecast Period 27w: [0.00663877 0.00726434 0.00927711 0.01140517]
#
# Debug: Returns for IGM, Forecast Period 28w: [ 0.00249844 -0.0030483   0.0106491  -0.0224492   0.00540164]
#
# Debug: Returns for IGM, Forecast Period 29w: [ 0.00491148 -0.00076097 -0.03791703 -0.00441929 -0.01151652]
#
# Debug: Returns for IGM, Forecast Period 30w: [ 0.01917514 -0.00227919 -0.04039955 -0.010332    0.01120083]
#
# Debug: Returns for IGM, Forecast Period 31w: [-0.00435409 -0.01663866  0.03057449 -0.02723684 -0.03069534]
#
# Debug: Returns for IGM, Forecast Period 32w: [-0.03270276  0.01042211 -0.01113529  0.03421569  0.00587403]
#
# Debug: Returns for IGM, Forecast Period 33w: [-0.00025026  0.02493083 -0.00039598  0.02478459 -0.00037249]
#
# Debug: Returns for IGM, Forecast Period 34w: [ 0.01213785 -0.00263503  0.00527022 -0.01855631  0.01217218]
#
# Debug: Returns for IGM, Forecast Period 35w: [-0.01049737  0.00326249 -0.01347639 -0.00094747  0.01009144]
#
# Debug: Returns for IGM, Forecast Period 36w: [-0.03926601 -0.00235203 -0.00038864 -0.02733441]
#
# Debug: Returns for IGM, Forecast Period 37w: [0.00978184 0.00897622 0.02410484 0.00904392 0.00589064]
#
# Debug: Returns for IGM, Forecast Period 38w: [-0.00246534  0.0001255  -0.0054944   0.02835104 -0.00199111]
#
# Debug: Returns for IGM, Forecast Period 39w: [ 5.58506255e-05  5.63431372e-03  2.97969691e-04  1.11218120e-02
#  -7.52725465e-03]
#
# Debug: Returns for IGM, Forecast Period 40w: [ 0.00296087 -0.018866    0.00472074  0.00473213  0.01306564]
#
# Debug: Returns for IGM, Forecast Period 41w: [-0.0101161   0.01688041  0.00794128 -0.00070131  0.00388413]
#
# Debug: Returns for IGM, Forecast Period 42w: [ 0.00963526 -0.01750254 -0.00048247  0.00044386  0.00468272]
#
# Debug: Returns for IGM, Forecast Period 43w: [ 0.00299753 -0.00019385 -0.01624598  0.00255598  0.00565013]
#
# Debug: Returns for IGM, Forecast Period 44w: [ 0.00219198  0.0149917  -0.01117135 -0.02925268  0.00543736]
#
# Debug: Returns for IGM, Forecast Period 45w: [-0.00346312  0.0138075   0.02907303  0.02112576 -0.00257094]
#
# Debug: Returns for IGM, Forecast Period 46w: [-0.00247225  0.00301921 -0.00469164 -0.00758606 -0.02517678]
#
# Debug: Returns for IGM, Forecast Period 47w: [ 0.0049523   0.01043825 -0.00028455  0.00585437  0.00047412]
#
# Debug: Returns for IGM, Forecast Period 48w: [ 0.00184748  0.00279056 -0.01125106  0.0080733 ]
#
# Debug: Returns for IXN, Forecast Period 1w: [-2.74315249e-02 -1.18396504e-02 -5.82747311e-03 -4.15645763e-05]
#
# Debug: Returns for IXN, Forecast Period 2w: [ 0.02480499 -0.00094102  0.00860226  0.00395254  0.00382214]
#
# Debug: Returns for IXN, Forecast Period 3w: [-0.00030774 -0.00542301  0.02125601  0.02285022]
#
# Debug: Returns for IXN, Forecast Period 4w: [ 0.00436327  0.00402198  0.00808758  0.00477851 -0.00942628]
#
# Debug: Returns for IXN, Forecast Period 5w: [ 0.00867267 -0.00754375 -0.01958819  0.0131673   0.01054967]
#
# Debug: Returns for IXN, Forecast Period 6w: [ 0.00278148 -0.0021424   0.01372887  0.0053255   0.01184339]
#
# Debug: Returns for IXN, Forecast Period 7w: [-0.00808527 -0.01762484  0.01175038 -0.00046978 -0.00883586]
#
# Debug: Returns for IXN, Forecast Period 8w: [-9.95936812e-03 -5.88846195e-03  3.22283137e-02  4.55810084e-05]
#
# Debug: Returns for IXN, Forecast Period 9w: [ 0.00075704 -0.00104209 -0.00438835  0.00946713  0.01867751]
#
# Debug: Returns for IXN, Forecast Period 10w: [ 0.00198607 -0.02242697  0.01064968  0.01723988 -0.01448681]
#
# Debug: Returns for IXN, Forecast Period 11w: [-0.00671274  0.0214391  -0.00974463 -0.00063612 -0.01510158]
#
# Debug: Returns for IXN, Forecast Period 12w: [0.00591693 0.00403266 0.01483233 0.00267161 0.00232105]
#
# Debug: Returns for IXN, Forecast Period 13w: [-0.00581599 -0.00495036  0.00215971 -0.00189485]
#
# Debug: Returns for IXN, Forecast Period 14w: [ 0.00310066 -0.00815435  0.00192649 -0.01659662  0.01171866]
#
# Debug: Returns for IXN, Forecast Period 15w: [-0.00226253  0.00468678 -0.01153441  0.02074896 -0.01813493]
#
# Debug: Returns for IXN, Forecast Period 16w: [-0.01843766  0.00148001 -0.01779297 -0.01048684 -0.02708432]
#
# Debug: Returns for IXN, Forecast Period 17w: [ 0.00899769  0.01576586  0.0041941  -0.00170739  0.01446624]
#
# Debug: Returns for IXN, Forecast Period 18w: [ 0.00312011 -0.02226775 -0.00972465  0.01426397  0.02795786]
#
# Debug: Returns for IXN, Forecast Period 19w: [ 0.01366529 -0.00356631  0.00238632 -0.00274686  0.00338591]
#
# Debug: Returns for IXN, Forecast Period 20w: [ 0.00323749  0.01053124  0.02168597 -0.00404747 -0.0037612 ]
#
# Debug: Returns for IXN, Forecast Period 21w: [0.01285995 0.00161983 0.00126816 0.00229903 0.01001583]
#
# ...
# Sortino Ratio: 4.454915783504523, Volatility Clustering: -0.4610551632064226
# Normalized Values -> Forecasted Mean: -0.5239161447081412, Rachev: 0.5032211579764159
# Sharpe: -0.41367405854006206, Sortino: -0.7706679977702124, Volatility Clustering: 0.10725269540684249
# Final Composite Score: -1.8658330122228997
# Calculated Score for IYW (47w): -1.8658330122228997
#
# Debug: ETF = XLK, Forecast Period = 47w
# Forecasted Values Mean: 0.0037067738459183657
# Rachev Ratio: 6.722524902837702, Sharpe Ratio: 12.31829826141159
# Sortino Ratio: 5.745236760885726, Volatility Clustering: -0.7454721033556044
# Means and Stds: Mean Forecast = 0.005961927767011555, Std Forecast = 0.00387739477628236
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0037067738459183657, Risk Percentage: 0.1
# Rachev Ratio: 6.722524902837702, Sharpe Ratio: 12.31829826141159
# Sortino Ratio: 5.745236760885726, Volatility Clustering: -0.7454721033556044
# Normalized Values -> Forecasted Mean: -0.5816142629440462, Rachev: 0.5133483997630535
# Sharpe: -0.32246402352227765, Sortino: -0.770665534348393, Volatility Clustering: -0.90462489416319
# Final Composite Score: -0.8214537666278321
# Calculated Score for XLK (47w): -0.8214537666278321
#
# Debug: ETF = VGT, Forecast Period = 47w
# Forecasted Values Mean: 0.006509667898427554
# Rachev Ratio: -8.78448040540275, Sharpe Ratio: 21.738818817421777
# Sortino Ratio: 650966.7898427554, Volatility Clustering: -0.800638908393135
# Means and Stds: Mean Forecast = 0.005961927767011555, Std Forecast = 0.00387739477628236
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.006509667898427554, Risk Percentage: 0.1
# Rachev Ratio: -8.78448040540275, Sharpe Ratio: 21.738818817421777
# Sortino Ratio: 650966.7898427554, Volatility Clustering: -0.800638908393135
# Normalized Values -> Forecasted Mean: 0.14126462492811243, Rachev: 0.3069657252784094
# Sharpe: 0.9038599839047726, Sortino: 0.47211953148475677, Volatility Clustering: -1.1008932798520898
# Final Composite Score: 2.587440847641891
# Calculated Score for VGT (47w): 2.587440847641891
#
# Debug: ETF = FTEC, Forecast Period = 47w
# Forecasted Values Mean: 0.008533626261209739
# Rachev Ratio: -4.73470106730951, Sharpe Ratio: 27.55002978463062
# Sortino Ratio: 853362.6261209738, Volatility Clustering: -0.8073033446006254
# Means and Stds: Mean Forecast = 0.005961927767011555, Std Forecast = 0.00387739477628236
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.008533626261209739, Risk Percentage: 0.1
# Rachev Ratio: -4.73470106730951, Sharpe Ratio: 27.55002978463062
# Sortino Ratio: 853362.6261209738, Volatility Clustering: -0.8073033446006254
# Normalized Values -> Forecasted Mean: 0.6632525213588657, Rachev: 0.3608642230382693
# Sharpe: 1.6603391486113335, Sortino: 0.8585244090079989, Volatility Clustering: -1.1246035189185164
# Final Composite Score: 4.270633175592888
# Calculated Score for FTEC (47w): 4.270633175592888
#
# Debug: ETF = IGM, Forecast Period = 47w
# Forecasted Values Mean: 0.004286899562970843
# Rachev Ratio: 36.68373028353499, Sharpe Ratio: 15.896578502185424
# Sortino Ratio: 33.68525508164026, Volatility Clustering: -0.40697100030036926
# Means and Stds: Mean Forecast = 0.005961927767011555, Std Forecast = 0.00387739477628236
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.004286899562970843, Risk Percentage: 0.1
# Rachev Ratio: 36.68373028353499, Sharpe Ratio: 15.896578502185424
# Sortino Ratio: 33.68525508164026, Volatility Clustering: -0.40697100030036926
# Normalized Values -> Forecasted Mean: -0.43199725091552654, Rachev: 0.9121019678659871
# Sharpe: 0.14334154831135312, Sortino: -0.7706121925427721, Volatility Clustering: 0.2996693368578937
# Final Composite Score: -1.450147428791438
# Calculated Score for IGM (47w): -1.450147428791438
#
# Debug: ETF = IXN, Forecast Period = 47w
# Forecasted Values Mean: 0.0035246540065256926
# Rachev Ratio: 3.1006184208073106, Sharpe Ratio: 15.70206055058414
# Sortino Ratio: 3.5435586237763714, Volatility Clustering: -0.7028795965368306
# Means and Stds: Mean Forecast = 0.005961927767011555, Std Forecast = 0.00387739477628236
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0035246540065256926, Risk Percentage: 0.1
# Rachev Ratio: 3.1006184208073106, Sharpe Ratio: 15.70206055058414
# Sortino Ratio: 3.5435586237763714, Volatility Clustering: -0.7028795965368306
# Normalized Values -> Forecasted Mean: -0.6285837824811032, Rachev: 0.46514446021210226
# Sharpe: 0.11802001406004248, Sortino: -0.7706697376916365, Volatility Clustering: -0.7530924182462488
# Final Composite Score: -0.5746555338876587
# Calculated Score for IXN (47w): -0.5746555338876587
# Scores calculated for 47w:
# {'ETF': 'SMH', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -6.140284482157542}
# {'ETF': 'SOXX', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -3.254869010956273}
# {'ETF': 'PSI', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 2.986263891666833}
# {'ETF': 'XSD', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 4.262905319742032}
# {'ETF': 'IYW', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -1.8658330122228997}
# {'ETF': 'XLK', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -0.8214537666278321}
# {'ETF': 'VGT', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 2.587440847641891}
# {'ETF': 'FTEC', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': 4.270633175592888}
# {'ETF': 'IGM', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -1.450147428791438}
# {'ETF': 'IXN', 'Week': '47w', 'RiskPercentage': 0.1, 'Score': -0.5746555338876587}
#
# Debug: Forecast Period = 48w
# All Returns Means: [-0.005565541672405456, -0.002905043907881465, 0.0021624864083655965, 0.006872971781241714, -0.00016340779289475155, -0.0003668987890536211, 0.000647066080112885, 0.0029736585602331855, 0.00036507113753685367, 0.0011145723094492356]
# Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
# All Rachev Ratios: [0.80943401 0.72719305 1.17013758 2.73913401 0.64165509 0.61958884
#  0.93289077 1.44811599 0.71755916 0.91587717]
# All Sharpe Ratios: [-8.27097154 -4.1534495   1.82207682  5.42168063 -1.10676932 -1.37337137
#   0.60883251  5.44465335 -0.02948975  1.50825571]
# All Sortino Ratios: [-0.51496868 -0.26701436  0.22364609  0.83911608 -0.02599775 -0.05184444
#   0.12954196  0.69447874  0.06489532  0.19910056]
# All Volatility Clustering: [ 0.07201153 -0.19200324  0.14391121 -0.14673498 -0.07465817 -0.10286421
#   0.23626997  0.19723645 -0.01293563  0.19758275]
# Mean Rachev = 1.072158568019374, Std Rachev = 0.6064230467951442
# Mean Sharpe = -0.01285524559482223, Std Sharpe = 3.921412558345612
# Mean Sortino = 0.12909535196235572, Std Sortino = 0.38344030585824296
# Mean Volatility Clustering = 0.03178156768103034, Std Volatility Clustering = 0.14975936917382685
#
# Debug: ETF = SMH, Forecast Period = 48w
# Forecasted Values Mean: -0.005565541672405456
# Rachev Ratio: 0.8094340143216852, Sharpe Ratio: -8.27097153885657
# Sortino Ratio: -0.51496867629307, Volatility Clustering: 0.07201152884387757
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.005565541672405456, Risk Percentage: 0.1
# Rachev Ratio: 0.8094340143216852, Sharpe Ratio: -8.27097153885657
# Sortino Ratio: -0.51496867629307, Volatility Clustering: 0.07201152884387757
# Normalized Values -> Forecasted Mean: -1.9272737153835924, Rachev: -0.4332364192848289
# Sharpe: -2.1059034593612598, Sortino: -1.679698251900916, Volatility Clustering: 0.26863066196443036
# Final Composite Score: -5.938182446681716
# Calculated Score for SMH (48w): -5.938182446681716
#
# Debug: ETF = SOXX, Forecast Period = 48w
# Forecasted Values Mean: -0.002905043907881465
# Rachev Ratio: 0.7271930481659872, Sharpe Ratio: -4.1534495047909115
# Sortino Ratio: -0.26701436224447694, Volatility Clustering: -0.19200323649376497
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.002905043907881465, Risk Percentage: 0.1
# Rachev Ratio: 0.7271930481659872, Sharpe Ratio: -4.1534495047909115
# Sortino Ratio: -0.26701436224447694, Volatility Clustering: -0.19200323649376497
# Normalized Values -> Forecasted Mean: -1.0837998185139766, Rachev: -0.5688529088529025
# Sharpe: -1.055893555454928, Sortino: -1.0330413830382759, Volatility Clustering: -1.4942957523551603
# Final Composite Score: -1.62155371376673
# Calculated Score for SOXX (48w): -1.62155371376673
#
# Debug: ETF = PSI, Forecast Period = 48w
# Forecasted Values Mean: 0.0021624864083655965
# Rachev Ratio: 1.1701375777281737, Sharpe Ratio: 1.8220768232160556
# Sortino Ratio: 0.22364609274722413, Volatility Clustering: 0.14391120759514134
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0021624864083655965, Risk Percentage: 0.1
# Rachev Ratio: 1.1701375777281737, Sharpe Ratio: 1.8220768232160556
# Sortino Ratio: 0.22364609274722413, Volatility Clustering: 0.14391120759514134
# Normalized Values -> Forecasted Mean: 0.5227903468096826, Rachev: 0.1615687408500005
# Sharpe: 0.4679262987074603, Sortino: 0.2465852881777398, Volatility Clustering: 0.748732002848124
# Final Composite Score: 0.4724130567617587
# Calculated Score for PSI (48w): 0.4724130567617587
#
# Debug: ETF = XSD, Forecast Period = 48w
# Forecasted Values Mean: 0.006872971781241714
# Rachev Ratio: 2.739134007883243, Sharpe Ratio: 5.4216806264093655
# Sortino Ratio: 0.8391160809370283, Volatility Clustering: -0.14673497722485385
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.006872971781241714, Risk Percentage: 0.1
# Rachev Ratio: 2.739134007883243, Sharpe Ratio: 5.4216806264093655
# Sortino Ratio: 0.8391160809370283, Volatility Clustering: -0.14673497722485385
# Normalized Values -> Forecasted Mean: 2.016184367502653, Rachev: 2.748865534027658
# Sharpe: 1.385861797830913, Sortino: 1.8517112040904056, Volatility Clustering: -1.1920224689144758
# Final Composite Score: 6.170893284935682
# Calculated Score for XSD (48w): 6.170893284935682
#
# Debug: ETF = IYW, Forecast Period = 48w
# Forecasted Values Mean: -0.00016340779289475155
# Rachev Ratio: 0.6416550932684876, Sharpe Ratio: -1.1067693167407957
# Sortino Ratio: -0.025997748725680555, Volatility Clustering: -0.0746581712258017
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.00016340779289475155, Risk Percentage: 0.1
# Rachev Ratio: 0.6416550932684876, Sharpe Ratio: -1.1067693167407957
# Sortino Ratio: -0.025997748725680555, Volatility Clustering: -0.0746581712258017
# Normalized Values -> Forecasted Mean: -0.2146021335762249, Rachev: -0.7099061784128612
# Sharpe: -0.2789591893432116, Sortino: -0.4044778138180281, Volatility Clustering: -0.710738382424026
# Final Composite Score: -0.11631013647215249
# Calculated Score for IYW (48w): -0.11631013647215249
#
# Debug: ETF = XLK, Forecast Period = 48w
# Forecasted Values Mean: -0.0003668987890536211
# Rachev Ratio: 0.619588843950223, Sharpe Ratio: -1.3733713737867044
# Sortino Ratio: -0.05184443811926027, Volatility Clustering: -0.10286420975050185
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: -0.0003668987890536211, Risk Percentage: 0.1
# Rachev Ratio: 0.619588843950223, Sharpe Ratio: -1.3733713737867044
# Sortino Ratio: -0.05184443811926027, Volatility Clustering: -0.10286420975050185
# Normalized Values -> Forecasted Mean: -0.2791161300909752, Rachev: -0.7462937284425079
# Sharpe: -0.3469454194068298, Sortino: -0.4718851476966471, Volatility Clustering: -0.8990807665892353
# Final Composite Score: -0.12423655776096587
# Calculated Score for XLK (48w): -0.12423655776096587
#
# Debug: ETF = VGT, Forecast Period = 48w
# Forecasted Values Mean: 0.000647066080112885
# Rachev Ratio: 0.9328907748332015, Sharpe Ratio: 0.6088325146583176
# Sortino Ratio: 0.12954195699955176, Volatility Clustering: 0.23626996543841558
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.000647066080112885, Risk Percentage: 0.1
# Rachev Ratio: 0.9328907748332015, Sharpe Ratio: 0.6088325146583176
# Sortino Ratio: 0.12954195699955176, Volatility Clustering: 0.23626996543841558
# Normalized Values -> Forecasted Mean: 0.04234736102298273, Rachev: -0.2296545153183687
# Sharpe: 0.15853668784343725, Sortino: 0.0011647315598424177, Volatility Clustering: 1.365446350575706
# Final Composite Score: -1.1404321186176067
# Calculated Score for VGT (48w): -1.1404321186176067
#
# Debug: ETF = FTEC, Forecast Period = 48w
# Forecasted Values Mean: 0.0029736585602331855
# Rachev Ratio: 1.4481159880372527, Sharpe Ratio: 5.4446533546358555
# Sortino Ratio: 0.6944787395924313, Volatility Clustering: 0.1972364521495025
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0029736585602331855, Risk Percentage: 0.1
# Rachev Ratio: 1.4481159880372527, Sharpe Ratio: 5.4446533546358555
# Sortino Ratio: 0.6944787395924313, Volatility Clustering: 0.1972364521495025
# Normalized Values -> Forecasted Mean: 0.7799612210315156, Rachev: 0.6199589804595457
# Sharpe: 1.3917200766592948, Sortino: 1.4745016740469632, Volatility Clustering: 1.1048048234523424
# Final Composite Score: 2.4793822502394764
# Calculated Score for FTEC (48w): 2.4793822502394764
#
# Debug: ETF = IGM, Forecast Period = 48w
# Forecasted Values Mean: 0.00036507113753685367
# Rachev Ratio: 0.7175591582930625, Sharpe Ratio: -0.029489745809366797
# Sortino Ratio: 0.06489531728064367, Volatility Clustering: -0.012935628207153126
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.00036507113753685367, Risk Percentage: 0.1
# Rachev Ratio: 0.7175591582930625, Sharpe Ratio: -0.029489745809366797
# Sortino Ratio: 0.06489531728064367, Volatility Clustering: -0.012935628207153126
# Normalized Values -> Forecasted Mean: -0.04705522231453235, Rachev: -0.5847393263711255
# Sharpe: -0.0042419663640651875, Sortino: -0.16743162371441053, Volatility Clustering: -0.2985936248859571
# Final Composite Score: 0.13833874513006156
# Calculated Score for IGM (48w): 0.13833874513006156
#
# Debug: ETF = IXN, Forecast Period = 48w
# Forecasted Values Mean: 0.0011145723094492356
# Rachev Ratio: 0.9158771737124238, Sharpe Ratio: 1.5082557051165317
# Sortino Ratio: 0.19910055744916577, Volatility Clustering: 0.19758274568544193
# Means and Stds: Mean Forecast = 0.0005134934114704176, Std Forecast = 0.0031542046999425773
#
# Debug: Composite Score Calculation
# Forecasted Mean: 0.0011145723094492356, Risk Percentage: 0.1
# Rachev Ratio: 0.9158771737124238, Sharpe Ratio: 1.5082557051165317
# Sortino Ratio: 0.19910055744916577, Volatility Clustering: 0.19758274568544193
# Normalized Values -> Forecasted Mean: 0.19056372351246753, Rachev: -0.25771017865460794
# Sharpe: 0.3878987288891893, Sortino: 0.18257132229332615, Volatility Clustering: 1.1071171563282518
# Final Composite Score: -0.32031236376780803
# Calculated Score for IXN (48w): -0.32031236376780803
# Scores calculated for 48w:
# {'ETF': 'SMH', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -5.938182446681716}
# {'ETF': 'SOXX', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -1.62155371376673}
# {'ETF': 'PSI', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 0.4724130567617587}
# {'ETF': 'XSD', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 6.170893284935682}
# {'ETF': 'IYW', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.11631013647215249}
# {'ETF': 'XLK', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.12423655776096587}
# {'ETF': 'VGT', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -1.1404321186176067}
# {'ETF': 'FTEC', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 2.4793822502394764}
# {'ETF': 'IGM', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': 0.13833874513006156}
# {'ETF': 'IXN', 'Week': '48w', 'RiskPercentage': 0.1, 'Score': -0.32031236376780803}

# %%
# Initialize an empty dictionary to hold DataFrames for each week
weekly_scores_dfs = {}

# Assuming weekly_scores is a dictionary with keys as week identifiers ('1w', '2w', ..., '48w') 
# and values as the respective scores
for week_key, scores in weekly_scores.items():
    # Convert scores for the current week into a DataFrame
    weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    
# Create DataFrame variables dynamically for 48 weeks
for week in range(1, 49):
    week_key = f'{week}w'
    globals()[f'df_scores_{week_key}'] = weekly_scores_dfs.get(week_key, pd.DataFrame())

# %%
# Initialize a dictionary to hold the top 2 ETFs for each week
top_etfs_weekly = {}

# Loop through the weekly DataFrames and select the top 2 ETFs for each week
for week_key, df_scores in weekly_scores_dfs.items():
    # Select the top 2 ETFs based on the 'Score' column
    top_etfs_weekly[week_key] = df_scores.nlargest(2, 'Score')
    
    # Print the results for the current week
    print(f"\nTop 2 ETFs for {week_key} forecast:")
    print(top_etfs_weekly[week_key])
# Out:
# Top 2 ETFs for 1w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   1w             0.1  4.493329
# 8   IGM   1w             0.1  3.396828
#
# Top 2 ETFs for 2w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   2w             0.1  5.327491
# 8   IGM   2w             0.1  3.465493
#
# Top 2 ETFs for 3w forecast:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  5.433687
# 7  FTEC   3w             0.1  2.606728
#
# Top 2 ETFs for 4w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   4w             0.1  5.189820
# 8   IGM   4w             0.1  4.603237
#
# Top 2 ETFs for 5w forecast:
#     ETF Week  RiskPercentage     Score
# 8   IGM   5w             0.1  4.461813
# 7  FTEC   5w             0.1  3.290580
#
# Top 2 ETFs for 6w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC   6w             0.1  3.428748
# 0   SMH   6w             0.1  2.617966
#
# Top 2 ETFs for 7w forecast:
#    ETF Week  RiskPercentage     Score
# 2  PSI   7w             0.1  5.849144
# 3  XSD   7w             0.1  0.831802
#
# Top 2 ETFs for 8w forecast:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1  3.545373
# 7  FTEC   8w             0.1  2.834658
#
# Top 2 ETFs for 9w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI   9w             0.1  7.869714
# 7  FTEC   9w             0.1  2.641893
#
# Top 2 ETFs for 10w forecast:
#    ETF Week  RiskPercentage     Score
# 0  SMH  10w             0.1  4.269780
# 3  XSD  10w             0.1  1.730265
#
# Top 2 ETFs for 11w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  11w             0.1  4.623915
# 5   XLK  11w             0.1  3.136967
#
# Top 2 ETFs for 12w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  12w             0.1  3.964300
# 8   IGM  12w             0.1  2.886512
#
# Top 2 ETFs for 13w forecast:
#    ETF Week  RiskPercentage     Score
# 3  XSD  13w             0.1  7.750681
# 2  PSI  13w             0.1  3.323801
#
# Top 2 ETFs for 14w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI  14w             0.1  4.335167
# 7  FTEC  14w             0.1  2.453303
#
# Top 2 ETFs for 15w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  15w             0.1  7.764005
# 4   IYW  15w             0.1  0.784210
#
# Top 2 ETFs for 16w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  16w             0.1  4.619178
# 8   IGM  16w             0.1  2.165835
#
# Top 2 ETFs for 17w forecast:
#     ETF Week  RiskPercentage     Score
# 1  SOXX  17w             0.1  4.489330
# 2   PSI  17w             0.1  4.417587
#
# Top 2 ETFs for 18w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  18w             0.1  4.814870
# 9   IXN  18w             0.1  2.376939
#
# Top 2 ETFs for 19w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  19w             0.1  7.095056
# 2   PSI  19w             0.1  4.568449
#
# Top 2 ETFs for 20w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  20w             0.1  5.490372
# 6   VGT  20w             0.1  2.160261
#
# Top 2 ETFs for 21w forecast:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  3.150564
# 7  FTEC  21w             0.1  2.820210
#
# Top 2 ETFs for 22w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  22w             0.1  6.623854
# 7  FTEC  22w             0.1  1.741676
#
# Top 2 ETFs for 23w forecast:
#     ETF Week  RiskPercentage     Score
# 9   IXN  23w             0.1  5.830799
# 7  FTEC  23w             0.1  3.640276
#
# Top 2 ETFs for 24w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  24w             0.1  2.973407
# 6   VGT  24w             0.1  1.401487
#
# Top 2 ETFs for 25w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  25w             0.1  3.576830
# 5   XLK  25w             0.1  2.781507
#
# Top 2 ETFs for 26w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI  26w             0.1  4.123261
# 7  FTEC  26w             0.1  3.374318
#
# Top 2 ETFs for 27w forecast:
#     ETF Week  RiskPercentage     Score
# 4   IYW  27w             0.1  4.479090
# 7  FTEC  27w             0.1  4.459188
#
# Top 2 ETFs for 28w forecast:
#    ETF Week  RiskPercentage     Score
# 3  XSD  28w             0.1  9.566700
# 2  PSI  28w             0.1  1.323334
#
# Top 2 ETFs for 29w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  29w             0.1  4.408933
# 7  FTEC  29w             0.1  3.814459
#
# Top 2 ETFs for 30w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  30w             0.1  8.766210
# 3   XSD  30w             0.1  2.519765
#
# Top 2 ETFs for 31w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  31w             0.1  7.328494
# 9   IXN  31w             0.1  3.175030
#
# Top 2 ETFs for 32w forecast:
#     ETF Week  RiskPercentage     Score
# 2   PSI  32w             0.1  6.467862
# 7  FTEC  32w             0.1  4.276658
#
# Top 2 ETFs for 33w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  33w             0.1  5.069220
# 5   XLK  33w             0.1  2.375093
#
# Top 2 ETFs for 34w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  34w             0.1  5.097162
# 3   XSD  34w             0.1  1.893105
#
# Top 2 ETFs for 35w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  35w             0.1  5.301946
# 7  FTEC  35w             0.1  4.072812
#
# Top 2 ETFs for 36w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  36w             0.1  2.997775
# 8   IGM  36w             0.1  2.032933
#
# Top 2 ETFs for 37w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  37w             0.1  2.485364
# 5   XLK  37w             0.1  0.699918
#
# Top 2 ETFs for 38w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  38w             0.1  6.959698
# 8   IGM  38w             0.1  3.121245
#
# Top 2 ETFs for 39w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  39w             0.1  5.542619
# 7  FTEC  39w             0.1  4.322647
#
# Top 2 ETFs for 40w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  40w             0.1  5.992596
# 8   IGM  40w             0.1  5.044265
#
# Top 2 ETFs for 41w forecast:
#    ETF Week  RiskPercentage     Score
# 2  PSI  41w             0.1  7.867317
# 0  SMH  41w             0.1  3.208480
#
# Top 2 ETFs for 42w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  42w             0.1  3.573826
# 6   VGT  42w             0.1  2.006003
#
# Top 2 ETFs for 43w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  43w             0.1  8.440887
# 3   XSD  43w             0.1  1.590299
#
# Top 2 ETFs for 44w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  44w             0.1  6.210837
# 8   IGM  44w             0.1  4.255979
#
# Top 2 ETFs for 45w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  45w             0.1  6.036689
# 3   XSD  45w             0.1  3.318759
#
# Top 2 ETFs for 46w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  46w             0.1  2.965865
# 6   VGT  46w             0.1  1.588319
#
# Top 2 ETFs for 47w forecast:
#     ETF Week  RiskPercentage     Score
# 7  FTEC  47w             0.1  4.270633
# 3   XSD  47w             0.1  4.262905
#
# Top 2 ETFs for 48w forecast:
#     ETF Week  RiskPercentage     Score
# 3   XSD  48w             0.1  6.170893
# 7  FTEC  48w             0.1  2.479382

# %%
def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()

# %%
# Function to generate week ranges
def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []
    
    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)
    
    return week_ranges

# Function to gather ETF data for weeks
def gather_etf_data_for_weeks(tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date)
            if etf_data.empty:
                print(f"No data found for {ticker} in {week}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[week][ticker] = etf_data
            #print(f"Data for {ticker} in {week} gathered.")
    return etf_histories

# Function to initialize shares for the first week
def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]
    
    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)
        
        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]
            
            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st week: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares

# Function to manage ETF portfolio weekly
def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

# %%
# Generate Week Ranges
week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')
#print("Generated Week Ranges:", week_ranges)

# Assuming `tickers` is a list of ETF tickers
tickers = tickers

# Gather ETF Data
etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)
#print(f"ETF Histories Collected for {len(etf_histories)} weeks")

# Create a mapping between week numbers and date ranges
week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

# Debug: Print the week key mapping
print("Week Key Mapping:", week_key_mapping)

# Align `top_etfs_weekly` Keys with `etf_histories`
aligned_top_etfs_weekly = {}

for week_key, df_scores in weekly_scores_dfs.items():
    # Call the `select_top_etfs_weekly` function here
    forecast_period = week_key_mapping.get(week_key, None)
    if forecast_period:
        aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

# Portfolio initialization and management
ticker_shares = {}
ticker_shares_per_week = {}

for i, week_range in enumerate(etf_histories.keys()):
    current_week_key = week_range
    if i == 0:
        # First week initialization
        ticker_shares = initialize_shares_for_first_week(
            aligned_top_etfs_weekly[current_week_key],
            etf_histories,
            current_week_key
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()
    else:
        # Subsequent weeks' portfolio management
        prev_week_key = list(etf_histories.keys())[i - 1]
        ticker_shares = manage_etf_portfolio_weekly(
            aligned_top_etfs_weekly[prev_week_key],
            aligned_top_etfs_weekly[current_week_key],
            prev_week_key,
            current_week_key,
            ticker_shares,
            etf_histories
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()

print("\nFinal Ticker Shares per Week:")
for week, shares in ticker_shares_per_week.items():
    print(f"Week {week}: {shares}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Week Key Mapping: {'1w': '2024-01-01 to 2024-01-07', '2w': '2024-01-08 to 2024-01-14', '3w': '2024-01-15 to 2024-01-21', '4w': '2024-01-22 to 2024-01-28', '5w': '2024-01-29 to 2024-02-04', '6w': '2024-02-05 to 2024-02-11', '7w': '2024-02-12 to 2024-02-18', '8w': '2024-02-19 to 2024-02-25', '9w': '2024-02-26 to 2024-03-03', '10w': '2024-03-04 to 2024-03-10', '11w': '2024-03-11 to 2024-03-17', '12w': '2024-03-18 to 2024-03-24', '13w': '2024-03-25 to 2024-03-31', '14w': '2024-04-01 to 2024-04-07', '15w': '2024-04-08 to 2024-04-14', '16w': '2024-04-15 to 2024-04-21', '17w': '2024-04-22 to 2024-04-28', '18w': '2024-04-29 to 2024-05-05', '19w': '2024-05-06 to 2024-05-12', '20w': '2024-05-13 to 2024-05-19', '21w': '2024-05-20 to 2024-05-26', '22w': '2024-05-27 to 2024-06-02', '23w': '2024-06-03 to 2024-06-09', '24w': '2024-06-10 to 2024-06-16', '25w': '2024-06-17 to 2024-06-23', '26w': '2024-06-24 to 2024-06-30', '27w': '2024-07-01 to 2024-07-07', '28w': '2024-07-08 to 2024-07-14', '29w': '2024-07-15 to 2024-07-21', '30w': '2024-07-22 to 2024-07-28', '31w': '2024-07-29 to 2024-08-04', '32w': '2024-08-05 to 2024-08-11', '33w': '2024-08-12 to 2024-08-18', '34w': '2024-08-19 to 2024-08-25', '35w': '2024-08-26 to 2024-09-01', '36w': '2024-09-02 to 2024-09-08', '37w': '2024-09-09 to 2024-09-15', '38w': '2024-09-16 to 2024-09-22', '39w': '2024-09-23 to 2024-09-29', '40w': '2024-09-30 to 2024-10-06', '41w': '2024-10-07 to 2024-10-13', '42w': '2024-10-14 to 2024-10-20', '43w': '2024-10-21 to 2024-10-27', '44w': '2024-10-28 to 2024-11-03', '45w': '2024-11-04 to 2024-11-10', '46w': '2024-11-11 to 2024-11-17', '47w': '2024-11-18 to 2024-11-24', '48w': '2024-11-25 to 2024-12-01'}
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1  1.646795
# 1  SOXX   1w             0.1 -1.108471
# 2   PSI   1w             0.1 -5.022176
# 3   XSD   1w             0.1 -7.590392
# 4   IYW   1w             0.1  1.953719
# Top ETFs for 2024-01-01 to 2024-01-07: ['FTEC', 'IGM']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1 -3.404349
# 1  SOXX   2w             0.1 -4.447092
# 2   PSI   2w             0.1 -4.238454
# 3   XSD   2w             0.1 -5.189685
# 4   IYW   2w             0.1  2.781875
# Top ETFs for 2024-01-08 to 2024-01-14: ['FTEC', 'IGM']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  5.433687
# 1  SOXX   3w             0.1  1.873097
# 2   PSI   3w             0.1  2.181196
# 3   XSD   3w             0.1 -3.379969
# 4   IYW   3w             0.1 -2.477218
# Top ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'FTEC']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1 -0.485580
# 1  SOXX   4w             0.1 -4.408905
# 2   PSI   4w             0.1 -3.290493
# 3   XSD   4w             0.1 -7.047861
# 4   IYW   4w             0.1  1.471120
# Top ETFs for 2024-01-22 to 2024-01-28: ['FTEC', 'IGM']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1  3.185559
# 1  SOXX   5w             0.1 -3.127433
# 2   PSI   5w             0.1 -0.989831
# 3   XSD   5w             0.1 -9.690981
# 4   IYW   5w             0.1  1.662184
# Top ETFs for 2024-01-29 to 2024-02-04: ['IGM', 'FTEC']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  2.617966
# 1  SOXX   6w             0.1 -2.141076
# 2   PSI   6w             0.1 -2.345869
# 3   XSD   6w             0.1  0.740553
# 4   IYW   6w             0.1 -1.292533
# Top ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'SMH']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1 -0.508320
# 1  SOXX   7w             0.1  0.738231
# 2   PSI   7w             0.1  5.849144
# 3   XSD   7w             0.1  0.831802
# 4   IYW   7w             0.1 -1.764977
# Top ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'XSD']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1  3.545373
# 1  SOXX   8w             0.1  0.333994
# 2   PSI   8w             0.1 -2.702178
# 3   XSD   8w             0.1 -8.411046
# 4   IYW   8w             0.1  0.476644
# Top ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'FTEC']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1  0.124233
# 1  SOXX   9w             0.1 -0.368138
# 2   PSI   9w             0.1  7.869714
# 3   XSD   9w             0.1  0.754468
# 4   IYW   9w             0.1 -5.246963
# Top ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'FTEC']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  4.269780
# 1  SOXX  10w             0.1  1.174955
# 2   PSI  10w             0.1 -0.733109
# 3   XSD  10w             0.1  1.730265
# 4   IYW  10w             0.1 -2.868326
# Top ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'XSD']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1 -2.324182
# 1  SOXX  11w             0.1 -4.550961
# 2   PSI  11w             0.1 -4.400817
# 3   XSD  11w             0.1 -6.476213
# 4   IYW  11w             0.1  3.053626
# Top ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'XLK']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1 -1.993556
# 1  SOXX  12w             0.1 -3.820322
# 2   PSI  12w             0.1  0.001624
# 3   XSD  12w             0.1 -4.267768
# 4   IYW  12w             0.1  2.771955
# Top ETFs for 2024-03-18 to 2024-03-24: ['FTEC', 'IGM']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1 -1.888155
# 1  SOXX  13w             0.1  1.673902
# 2   PSI  13w             0.1  3.323801
# 3   XSD  13w             0.1  7.750681
# 4   IYW  13w             0.1 -3.620125
# Top ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1 -1.685487
# 1  SOXX  14w             0.1 -3.684045
# 2   PSI  14w             0.1  4.335167
# 3   XSD  14w             0.1 -0.779758
# 4   IYW  14w             0.1 -0.228825
# Top ETFs for 2024-04-01 to 2024-04-07: ['PSI', 'FTEC']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1 -3.191482
# 1  SOXX  15w             0.1 -3.182406
# 2   PSI  15w             0.1 -1.607551
# 3   XSD  15w             0.1  0.754337
# 4   IYW  15w             0.1  0.784210
# Top ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1 -1.486770
# 1  SOXX  16w             0.1 -0.800701
# 2   PSI  16w             0.1  1.615076
# 3   XSD  16w             0.1 -5.290355
# 4   IYW  16w             0.1  0.801645
# Top ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'IGM']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1 -0.825610
# 1  SOXX  17w             0.1  4.489330
# 2   PSI  17w             0.1  4.417587
# 3   XSD  17w             0.1  2.822176
# 4   IYW  17w             0.1 -2.465043
# Top ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'PSI']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1 -4.631791
# 1  SOXX  18w             0.1 -5.078665
# 2   PSI  18w             0.1 -2.562223
# 3   XSD  18w             0.1  0.643308
# 4   IYW  18w             0.1  0.874911
# Top ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IXN']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1 -3.324744
# 1  SOXX  19w             0.1 -5.545598
# 2   PSI  19w             0.1  4.568449
# 3   XSD  19w             0.1  0.104430
# 4   IYW  19w             0.1 -3.004914
# Top ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'PSI']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1 -4.764213
# 1  SOXX  20w             0.1 -2.148237
# 2   PSI  20w             0.1 -2.948240
# 3   XSD  20w             0.1  1.614540
# 4   IYW  20w             0.1  0.737733
# Top ETFs for 2024-05-13 to 2024-05-19: ['FTEC', 'VGT']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  3.150564
# 1  SOXX  21w             0.1  1.020784
# 2   PSI  21w             0.1 -0.127624
# 3   XSD  21w             0.1 -4.943807
# 4   IYW  21w             0.1  1.030392
# Top ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'FTEC']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1 -1.793095
# 1  SOXX  22w             0.1 -2.599847
# 2   PSI  22w             0.1  0.431777
# 3   XSD  22w             0.1  6.623854
# 4   IYW  22w             0.1 -0.254358
# Top ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'FTEC']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1  0.570429
# 1  SOXX  23w             0.1 -4.184992
# 2   PSI  23w             0.1 -3.564059
# 3   XSD  23w             0.1 -4.982838
# 4   IYW  23w             0.1  2.023267
# Top ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'FTEC']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1 -0.866477
# 1  SOXX  24w             0.1 -2.055316
# 2   PSI  24w             0.1 -0.924488
# 3   XSD  24w             0.1 -3.668711
# 4   IYW  24w             0.1  0.752190
# Top ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'VGT']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1 -4.543572
# 1  SOXX  25w             0.1 -3.919568
# 2   PSI  25w             0.1  1.323540
# 3   XSD  25w             0.1 -5.564319
# 4   IYW  25w             0.1  0.042744
# Top ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'XLK']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1 -4.073184
# 1  SOXX  26w             0.1 -2.704799
# 2   PSI  26w             0.1  4.123261
# 3   XSD  26w             0.1  1.764840
# 4   IYW  26w             0.1 -0.281540
# Top ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'FTEC']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1 -3.720158
# 1  SOXX  27w             0.1 -4.110596
# 2   PSI  27w             0.1 -3.571193
# 3   XSD  27w             0.1 -3.048475
# 4   IYW  27w             0.1  4.479090
# Top ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'FTEC']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1 -0.588468
# 1  SOXX  28w             0.1  0.385045
# 2   PSI  28w             0.1  1.323334
# 3   XSD  28w             0.1  9.566700
# 4   IYW  28w             0.1 -2.848481
# Top ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'PSI']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1 -2.639188
# 1  SOXX  29w             0.1 -0.319641
# 2   PSI  29w             0.1 -0.393262
# 3   XSD  29w             0.1  4.408933
# 4   IYW  29w             0.1 -2.307373
# Top ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'FTEC']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1 -5.450711
# 1  SOXX  30w             0.1 -1.883605
# 2   PSI  30w             0.1 -0.776064
# 3   XSD  30w             0.1  2.519765
# 4   IYW  30w             0.1 -2.222837
# Top ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'XSD']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1 -1.786972
# 1  SOXX  31w             0.1 -2.906350
# 2   PSI  31w             0.1 -1.121831
# 3   XSD  31w             0.1 -6.160188
# 4   IYW  31w             0.1 -0.340183
# Top ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IXN']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1 -1.686811
# 1  SOXX  32w             0.1 -1.900698
# 2   PSI  32w             0.1  6.467862
# 3   XSD  32w             0.1 -2.367628
# 4   IYW  32w             0.1 -2.223044
# Top ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'FTEC']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1 -0.545824
# 1  SOXX  33w             0.1 -1.813157
# 2   PSI  33w             0.1 -2.553900
# 3   XSD  33w             0.1 -3.798692
# 4   IYW  33w             0.1  0.246066
# Top ETFs for 2024-08-12 to 2024-08-18: ['FTEC', 'XLK']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1 -3.541521
# 1  SOXX  34w             0.1 -2.927470
# 2   PSI  34w             0.1 -1.254973
# 3   XSD  34w             0.1  1.893105
# 4   IYW  34w             0.1 -0.693713
# Top ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'XSD']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1 -4.176835
# 1  SOXX  35w             0.1 -0.497712
# 2   PSI  35w             0.1 -0.667754
# 3   XSD  35w             0.1  5.301946
# 4   IYW  35w             0.1 -1.000108
# Top ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'FTEC']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1 -2.425314
# 1  SOXX  36w             0.1 -0.325694
# 2   PSI  36w             0.1  1.361934
# 3   XSD  36w             0.1 -0.357690
# 4   IYW  36w             0.1 -1.621959
# Top ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1 -0.481174
# 1  SOXX  37w             0.1 -0.339175
# 2   PSI  37w             0.1 -1.178631
# 3   XSD  37w             0.1  0.108615
# 4   IYW  37w             0.1 -1.095047
# Top ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'XLK']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1 -5.522244
# 1  SOXX  38w             0.1 -4.798242
# 2   PSI  38w             0.1  0.199796
# 3   XSD  38w             0.1 -1.147211
# 4   IYW  38w             0.1  1.182645
# Top ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'IGM']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1 -1.160295
# 1  SOXX  39w             0.1  0.290628
# 2   PSI  39w             0.1  3.358816
# 3   XSD  39w             0.1  5.542619
# 4   IYW  39w             0.1 -3.836625
# Top ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Processing scores for 2024-09-30 to 2024-10-06:
# ...
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['FTEC', 'IGM']
# Sell XLK: 198.93 shares at 206.30. Total value: 40013.61
# Buy IGM: 457.96 shares at 85.19.
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'FTEC': 295.36651457870454, 'IGM': 457.95597628439043}
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Sell FTEC: 295.37 shares at 156.45. Total value: 45054.84
# Buy XSD: 194.20 shares at 226.20.
# Sell IGM: 457.96 shares at 86.60. Total value: 38667.51
# Buy PSI: 670.36 shares at 56.24.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'XSD': 194.201890752989, 'PSI': 670.3560321244668}
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'PSI']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['PSI', 'FTEC']
# Sell XSD: 194.20 shares at 233.86. Total value: 44280.65
# Buy FTEC: 276.90 shares at 155.92.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'PSI': 670.3560321244668, 'FTEC': 276.896082070724}
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['PSI', 'FTEC']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Sell PSI: 670.36 shares at 56.38. Total value: 36849.81
# Buy IYW: 267.86 shares at 134.13.
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'FTEC': 276.896082070724, 'IYW': 267.8637178859045}
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'IGM']
# Sell IYW: 267.86 shares at 131.14. Total value: 34249.46
# Buy IGM: 399.20 shares at 83.65.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'FTEC': 276.896082070724, 'IGM': 399.2016686288677}
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'PSI']
# Sell FTEC: 276.90 shares at 144.25. Total value: 38943.70
# Buy SOXX: 188.29 shares at 201.66.
# Sell IGM: 399.20 shares at 80.88. Total value: 31480.24
# Buy PSI: 603.13 shares at 50.89.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'SOXX': 188.28776192420736, 'PSI': 603.1290701696648}
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['SOXX', 'PSI']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IXN']
# Sell SOXX: 188.29 shares at 218.55. Total value: 40121.53
# Buy FTEC: 260.29 shares at 150.29.
# Sell PSI: 603.13 shares at 55.04. Total value: 32366.32
# Buy IXN: 437.99 shares at 72.05.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'FTEC': 260.2867594341417, 'IXN': 437.9897244874937}
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'PSI']
# Sell IXN: 437.99 shares at 73.87. Total value: 31545.44
# Buy PSI: 549.33 shares at 55.99.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'FTEC': 260.2867594341417, 'PSI': 549.3268005025909}
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'PSI']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['FTEC', 'VGT']
# Sell PSI: 549.33 shares at 56.06. Total value: 30025.38
# Buy VGT: 56.43 shares at 518.78.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'FTEC': 260.2867594341417, 'VGT': 56.4299770925149}
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'FTEC']
# Sell VGT: 56.43 shares at 539.30. Total value: 29671.87
# Buy SMH: 123.11 shares at 235.00.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'FTEC': 260.2867594341417, 'SMH': 123.1066897362403}
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'FTEC']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'FTEC']
# Sell SMH: 123.11 shares at 249.83. Total value: 29986.85
# Buy XSD: 117.31 shares at 249.23.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'FTEC': 260.2867594341417, 'XSD': 117.31003545976779}
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'FTEC']
# Sell XSD: 117.31 shares at 245.69. Total value: 28101.36
# Buy IXN: 355.55 shares at 77.06.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'FTEC': 260.2867594341417, 'IXN': 355.55180782434707}
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'VGT']
# Sell IXN: 355.55 shares at 79.41. Total value: 27528.51
# Buy VGT: 48.65 shares at 551.75.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'FTEC': 260.2867594341417, 'VGT': 48.64576044369158}
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'XLK']
# Sell VGT: 48.65 shares at 586.47. Total value: 27816.05
# Buy XLK: 117.34 shares at 231.12.
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'FTEC': 260.2867594341417, 'XLK': 117.3444322804848}
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'FTEC']
# Sell XLK: 117.34 shares at 222.42. Total value: 25447.25
# Buy PSI: 408.35 shares at 60.76.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'FTEC': 260.2867594341417, 'PSI': 408.3455237074686}
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['PSI', 'FTEC']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'FTEC']
# Sell PSI: 408.35 shares at 62.76. Total value: 24987.07
# Buy IYW: 160.26 shares at 152.02.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'FTEC': 260.2867594341417, 'IYW': 160.25781365218927}
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'PSI']
# Sell IYW: 160.26 shares at 156.96. Total value: 24525.22
# Buy XSD: 91.73 shares at 260.69.
# Sell FTEC: 260.29 shares at 178.66. Total value: 45340.26
# Buy PSI: 674.19 shares at 65.57.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 91.72613141934266, 'PSI': 674.1917980880781}
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'PSI']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'FTEC']
# Sell PSI: 674.19 shares at 66.24. Total value: 43542.00
# Buy FTEC: 236.54 shares at 179.48.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'XSD': 91.72613141934266, 'FTEC': 236.5358404947616}
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'XSD']
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'XSD': 91.72613141934266, 'FTEC': 236.5358404947616}
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IXN']
# Sell XSD: 91.73 shares at 242.03. Total value: 21645.46
# Buy IXN: 267.45 shares at 78.91.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'FTEC': 236.5358404947616, 'IXN': 267.44805499212526}
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'FTEC']
# Sell IXN: 267.45 shares at 73.00. Total value: 19035.62
# Buy PSI: 374.34 shares at 49.58.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'FTEC': 236.5358404947616, 'PSI': 374.33893194388554}
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['PSI', 'FTEC']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['FTEC', 'XLK']
# Sell PSI: 374.34 shares at 53.06. Total value: 19365.86
# Buy XLK: 91.08 shares at 207.31.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'FTEC': 236.5358404947616, 'XLK': 91.07962601120144}
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'XSD']
# Sell XLK: 91.08 shares at 225.05. Total value: 19985.03
# Buy XSD: 82.93 shares at 234.95.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'FTEC': 236.5358404947616, 'XSD': 82.93427443328507}
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'FTEC']
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'FTEC': 236.5358404947616, 'XSD': 82.93427443328507}
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Sell XSD: 82.93 shares at 222.36. Total value: 17980.23
# Buy IGM: 195.83 shares at 89.52.
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'FTEC': 236.5358404947616, 'IGM': 195.83030044832924}
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'XLK']
# Sell IGM: 195.83 shares at 87.89. Total value: 16781.24
# Buy XLK: 78.94 shares at 207.26.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'FTEC': 236.5358404947616, 'XLK': 78.94290444030463}
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'IGM']
# Sell XLK: 78.94 shares at 219.60. Total value: 16902.47
# Buy IGM: 178.57 shares at 92.29.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'FTEC': 236.5358404947616, 'IGM': 178.56651785163274}
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Sell IGM: 178.57 shares at 94.58. Total value: 16466.60
# Buy XSD: 69.25 shares at 231.84.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'FTEC': 236.5358404947616, 'XSD': 69.25007019149433}
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['FTEC', 'IGM']
# Sell XSD: 69.25 shares at 240.25. Total value: 16221.40
# Buy IGM: 164.85 shares at 95.94.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'FTEC': 236.5358404947616, 'IGM': 164.85158248607144}
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['PSI', 'SMH']
# Sell FTEC: 236.54 shares at 172.81. Total value: 39853.86
# Buy PSI: 678.73 shares at 57.25.
# Sell IGM: 164.85 shares at 95.46. Total value: 15343.31
# Buy SMH: 60.27 shares at 248.22.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'PSI': 678.7339295416629, 'SMH': 60.26803118770006}
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['PSI', 'SMH']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['FTEC', 'VGT']
# Sell PSI: 678.73 shares at 60.18. Total value: 39825.05
# Buy FTEC: 214.73 shares at 180.83.
# Sell SMH: 60.27 shares at 261.28. Total value: 15353.16
# Buy VGT: 24.63 shares at 607.88.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'FTEC': 214.7288954790516, 'VGT': 24.625470830757166}
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'XSD']
# Sell VGT: 24.63 shares at 606.93. Total value: 14572.29
# Buy XSD: 58.65 shares at 242.23.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'FTEC': 214.7288954790516, 'XSD': 58.65492073864449}
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IGM']
# Sell XSD: 58.65 shares at 246.83. Total value: 14115.85
# Buy IGM: 140.51 shares at 97.95.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'FTEC': 214.7288954790516, 'IGM': 140.509990136062}
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['FTEC', 'XSD']
# Sell IGM: 140.51 shares at 95.86. Total value: 13132.56
# Buy XSD: 54.90 shares at 233.24.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'FTEC': 214.7288954790516, 'XSD': 54.89727901076611}
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'VGT']
# Sell XSD: 54.90 shares at 244.57. Total value: 13090.57
# Buy VGT: 20.52 shares at 621.92.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'FTEC': 214.7288954790516, 'VGT': 20.522427766331337}
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'VGT']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['FTEC', 'XSD']
# Sell VGT: 20.52 shares at 604.72. Total value: 12100.06
# Buy XSD: 51.61 shares at 228.59.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'FTEC': 214.7288954790516, 'XSD': 51.6101424468819}
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XSD', 'FTEC']
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'FTEC': 214.7288954790516, 'XSD': 51.6101424468819}
#
# Final Ticker Shares per Week:
# Week 2024-01-01 to 2024-01-07: {'FTEC': 348.73740855123145, 'IGM': 670.3334619848428}
# Week 2024-01-08 to 2024-01-14: {'FTEC': 348.73740855123145, 'IGM': 670.3334619848428}
# Week 2024-01-15 to 2024-01-21: {'FTEC': 348.73740855123145, 'SMH': 273.63902201780513}
# Week 2024-01-22 to 2024-01-28: {'FTEC': 348.73740855123145, 'IGM': 621.9723761186908}
# Week 2024-01-29 to 2024-02-04: {'FTEC': 348.73740855123145, 'IGM': 621.9723761186908}
# Week 2024-02-05 to 2024-02-11: {'FTEC': 348.73740855123145, 'SMH': 246.47311899727208}
# Week 2024-02-12 to 2024-02-18: {'PSI': 968.5651689480301, 'XSD': 210.0373875009488}
# Week 2024-02-19 to 2024-02-25: {'SMH': 240.17137131947496, 'FTEC': 290.4353601013995}
# Week 2024-02-26 to 2024-03-03: {'FTEC': 290.4353601013995, 'PSI': 900.7055937276272}
# Week 2024-03-04 to 2024-03-10: {'SMH': 216.95267066945038, 'XSD': 186.90231086105445}
# Week 2024-03-11 to 2024-03-17: {'FTEC': 295.36651457870454, 'XLK': 198.93165502634255}
# Week 2024-03-18 to 2024-03-24: {'FTEC': 295.36651457870454, 'IGM': 457.95597628439043}
# Week 2024-03-25 to 2024-03-31: {'XSD': 194.201890752989, 'PSI': 670.3560321244668}
# Week 2024-04-01 to 2024-04-07: {'PSI': 670.3560321244668, 'FTEC': 276.896082070724}
# Week 2024-04-08 to 2024-04-14: {'FTEC': 276.896082070724, 'IYW': 267.8637178859045}
# Week 2024-04-15 to 2024-04-21: {'FTEC': 276.896082070724, 'IGM': 399.2016686288677}
# Week 2024-04-22 to 2024-04-28: {'SOXX': 188.28776192420736, 'PSI': 603.1290701696648}
# Week 2024-04-29 to 2024-05-05: {'FTEC': 260.2867594341417, 'IXN': 437.9897244874937}
# Week 2024-05-06 to 2024-05-12: {'FTEC': 260.2867594341417, 'PSI': 549.3268005025909}
# Week 2024-05-13 to 2024-05-19: {'FTEC': 260.2867594341417, 'VGT': 56.4299770925149}
# Week 2024-05-20 to 2024-05-26: {'FTEC': 260.2867594341417, 'SMH': 123.1066897362403}
# Week 2024-05-27 to 2024-06-02: {'FTEC': 260.2867594341417, 'XSD': 117.31003545976779}
# Week 2024-06-03 to 2024-06-09: {'FTEC': 260.2867594341417, 'IXN': 355.55180782434707}
# Week 2024-06-10 to 2024-06-16: {'FTEC': 260.2867594341417, 'VGT': 48.64576044369158}
# Week 2024-06-17 to 2024-06-23: {'FTEC': 260.2867594341417, 'XLK': 117.3444322804848}
# Week 2024-06-24 to 2024-06-30: {'FTEC': 260.2867594341417, 'PSI': 408.3455237074686}
# Week 2024-07-01 to 2024-07-07: {'FTEC': 260.2867594341417, 'IYW': 160.25781365218927}
# Week 2024-07-08 to 2024-07-14: {'XSD': 91.72613141934266, 'PSI': 674.1917980880781}
# Week 2024-07-15 to 2024-07-21: {'XSD': 91.72613141934266, 'FTEC': 236.5358404947616}
# Week 2024-07-22 to 2024-07-28: {'XSD': 91.72613141934266, 'FTEC': 236.5358404947616}
# Week 2024-07-29 to 2024-08-04: {'FTEC': 236.5358404947616, 'IXN': 267.44805499212526}
# Week 2024-08-05 to 2024-08-11: {'FTEC': 236.5358404947616, 'PSI': 374.33893194388554}
# Week 2024-08-12 to 2024-08-18: {'FTEC': 236.5358404947616, 'XLK': 91.07962601120144}
# Week 2024-08-19 to 2024-08-25: {'FTEC': 236.5358404947616, 'XSD': 82.93427443328507}
# Week 2024-08-26 to 2024-09-01: {'FTEC': 236.5358404947616, 'XSD': 82.93427443328507}
# Week 2024-09-02 to 2024-09-08: {'FTEC': 236.5358404947616, 'IGM': 195.83030044832924}
# Week 2024-09-09 to 2024-09-15: {'FTEC': 236.5358404947616, 'XLK': 78.94290444030463}
# Week 2024-09-16 to 2024-09-22: {'FTEC': 236.5358404947616, 'IGM': 178.56651785163274}
# Week 2024-09-23 to 2024-09-29: {'FTEC': 236.5358404947616, 'XSD': 69.25007019149433}
# Week 2024-09-30 to 2024-10-06: {'FTEC': 236.5358404947616, 'IGM': 164.85158248607144}
# Week 2024-10-07 to 2024-10-13: {'PSI': 678.7339295416629, 'SMH': 60.26803118770006}
# Week 2024-10-14 to 2024-10-20: {'FTEC': 214.7288954790516, 'VGT': 24.625470830757166}
# Week 2024-10-21 to 2024-10-27: {'FTEC': 214.7288954790516, 'XSD': 58.65492073864449}
# Week 2024-10-28 to 2024-11-03: {'FTEC': 214.7288954790516, 'IGM': 140.509990136062}
# Week 2024-11-04 to 2024-11-10: {'FTEC': 214.7288954790516, 'XSD': 54.89727901076611}
# Week 2024-11-11 to 2024-11-17: {'FTEC': 214.7288954790516, 'VGT': 20.522427766331337}
# Week 2024-11-18 to 2024-11-24: {'FTEC': 214.7288954790516, 'XSD': 51.6101424468819}
# Week 2024-11-25 to 2024-12-01: {'FTEC': 214.7288954790516, 'XSD': 51.6101424468819}

# %%
# Define the first trading day of the 48th week
first_trading_day_49w = '2024-12-01'  # Adjust this to match the actual start date of the 48th week

# Identify the 48th and 49th week date range keys
week_48_range = list(ticker_shares_per_week.keys())[-1]  # Last key corresponds to the 48th week
week_49_start = first_trading_day_49w  # Replace with the actual start of the 49th week
print(f"Using data for the 48th week: {week_48_range}")

print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

week_49_end = '2024-12-06'
# Initialize a dictionary to store the values of shares
etf_values_49w = {}

# Ensure 48th week data exists
if week_48_range in ticker_shares_per_week:
    # Fetch ETF shares from the 48th week
    ticker_shares_48w = ticker_shares_per_week[week_48_range]
    
    # Fetch the first trading day price of the 49th week for each ETF
    for ticker, shares in ticker_shares_48w.items():
        print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
        # Download historical data for the 49th week
        data = yf.download(ticker, start=week_49_start, end=week_49_end)
        
        if not data.empty:
            # Get the closing price of the first trading day of the 49th week
            closing_price_49w = data['Close'].iloc[0]
            # Calculate the value of the shares
            total_value = shares * closing_price_49w
            etf_values_49w[ticker] = total_value
            print(f"{ticker}: {shares:.2f} shares at ${closing_price_49w:.2f} each, total value: ${total_value:.2f}")
        else:
            print(f"{ticker}: No data available for the 49th week's first trading day.")
else:
    print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker FTEC starting from 2024-12-01...
# FTEC: 214.73 shares at $186.99 each, total value: $40152.16
# Fetching data for ticker XSD starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# XSD: 51.61 shares at $252.68 each, total value: $13040.85

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 53193.01
# FTEC: 40152.16
# XSD: 13040.85

# %% [markdown]
# ### WIth Smoothing

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, 
    volatility_clustering, mean_forecast, std_forecast, mean_rachev, std_rachev, 
    mean_sharpe, std_sharpe, mean_sortino, std_sortino, mean_volatility_clustering, 
    std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    return score

def smooth_scores(scores, alpha=0.2):
    """
    Smooth scores using Exponential Moving Average (EMA).
    """
    if not isinstance(scores, (list, np.ndarray)):
        raise ValueError("Scores must be a list or numpy array of numerical values.")
    
    scores = np.array(scores)
    smoothed_scores = np.zeros_like(scores)
    smoothed_scores[0] = scores[0]  # Initialize EMA
    
    for t in range(1, len(scores)):
        smoothed_scores[t] = alpha * scores[t] + (1 - alpha) * smoothed_scores[t - 1]
    
    return smoothed_scores.tolist()

def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )

def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage, alpha=0.2):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    raw_scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        raw_scores.append(score)

    # Apply smoothing to the raw scores
    smoothed_scores = smooth_scores(raw_scores, alpha=alpha)

    results = []
    for idx, etf in enumerate(etf_pred_dict):
        results.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'RawScore': raw_scores[idx],
            'SmoothedScore': smoothed_scores[idx]
        })

    return results

def main_weekly(tickers, etf_dict):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict)
    risk_percentage = 0.10
    weekly_scores = {}

    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores
        else:
            print(f"Skipping score calculation for {week_key}: No ETFs have data for this week.")

    return etf_pred_dict, weekly_scores

# Select top ETFs for weekly portfolio management
def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    top_etfs = df_scores.nlargest(2, 'SmoothedScore')
    return top_etfs['ETF'].tolist()

# %%
etf_pred_dict, weekly_scores = main_weekly(tickers, etf_dict)
# Out:
# Debug: Returns for SMH, Forecast Period 1w: [-0.03475353 -0.0190482  -0.0071898   0.00528752]
#
# Debug: Returns for SMH, Forecast Period 2w: [ 0.03416537  0.00151172 -0.00033629  0.00427034 -0.00496809]
#
# Debug: Returns for SMH, Forecast Period 3w: [ 0.01433271 -0.00766895  0.03076492  0.03667688]
#
# Debug: Returns for SMH, Forecast Period 4w: [ 0.00348621  0.00429403  0.01685095 -0.00086758 -0.02236661]
#
# Debug: Returns for SMH, Forecast Period 5w: [ 0.01060041 -0.01112131 -0.01565295  0.00825322  0.0188383 ]
#
# Debug: Returns for SMH, Forecast Period 6w: [ 0.01905304 -0.01181881  0.01939125  0.01357168  0.02159133]
#
# Debug: Returns for SMH, Forecast Period 7w: [-0.00440405 -0.01907772  0.01932874 -0.0039811  -0.00517776]
#
# Debug: Returns for SMH, Forecast Period 8w: [-0.02093725 -0.00787031  0.06679589 -0.00756042]
#
# Debug: Returns for SMH, Forecast Period 9w: [ 0.00700177 -0.00401006 -0.01240139  0.02075349  0.03982313]
#
# Debug: Returns for SMH, Forecast Period 10w: [ 0.01556183 -0.01599483  0.02496596  0.03426345 -0.03971584]
#
# Debug: Returns for SMH, Forecast Period 11w: [-0.01881184  0.03043654 -0.02089047 -0.01896297 -0.00879408]
#
# Debug: Returns for SMH, Forecast Period 12w: [ 0.00060954 -0.00361611  0.01484325  0.0216747   0.0044631 ]
#
# Debug: Returns for SMH, Forecast Period 13w: [-0.00386971 -0.01087328 -0.00190671 -0.00110633]
#
# Debug: Returns for SMH, Forecast Period 14w: [ 0.01139291 -0.0148928   0.00178686 -0.02875395  0.01006397]
#
# Debug: Returns for SMH, Forecast Period 15w: [-0.00082906  0.00245061 -0.01072277  0.02095471 -0.03119942]
#
# Debug: Returns for SMH, Forecast Period 16w: [-0.01701592  0.00632571 -0.03296947 -0.02002575 -0.04788204]
#
# Debug: Returns for SMH, Forecast Period 17w: [ 0.01603219  0.02053301 -0.00167794  0.01728666  0.02310984]
#
# Debug: Returns for SMH, Forecast Period 18w: [ 0.00098301 -0.02224212 -0.03180419  0.01733003  0.02462374]
#
# Debug: Returns for SMH, Forecast Period 19w: [ 0.02051387 -0.01082541  0.00081489 -0.00862645  0.01259416]
#
# Debug: Returns for SMH, Forecast Period 20w: [-0.00225749  0.01524053  0.02824172 -0.00857972 -0.00951918]
#
# Debug: Returns for SMH, Forecast Period 21w: [ 0.02014952 -0.00205841  0.00729344  0.01283704  0.01769291]
#
# Debug: Returns for SMH, Forecast Period 22w: [ 0.02195417 -0.01765531 -0.01460742 -0.00792603]
#
# Debug: Returns for SMH, Forecast Period 23w: [ 0.01175155 -0.00459944  0.04767903 -0.00857145 -0.00160543]
#
# Debug: Returns for SMH, Forecast Period 24w: [ 0.01378696 -0.00233435  0.02909238  0.01495168  0.00165067]
#
# Debug: Returns for SMH, Forecast Period 25w: [ 0.0165266   0.01541194 -0.02902163 -0.0158658 ]
#
# Debug: Returns for SMH, Forecast Period 26w: [-0.0357127   0.02187228 -0.00495165 -0.00997711  0.00529264]
#
# Debug: Returns for SMH, Forecast Period 27w: [-0.00041164  0.00850131  0.02124501 -0.00102407]
#
# Debug: Returns for SMH, Forecast Period 28w: [ 0.01479817  0.00059183  0.02208727 -0.03813676  0.01088341]
#
# Debug: Returns for SMH, Forecast Period 29w: [-0.00438513 -0.0028077  -0.0740794   0.00176369 -0.03265745]
#
# Debug: Returns for SMH, Forecast Period 30w: [ 0.03529198 -0.01412942 -0.05734872 -0.0218232   0.0124235 ]
#
# Debug: Returns for SMH, Forecast Period 31w: [-0.01038216 -0.04183898  0.07276394 -0.06830741 -0.05889014]
#
# Debug: Returns for SMH, Forecast Period 32w: [-0.02822868  0.01444023 -0.03262373  0.05814527 -0.00479738]
#
# Debug: Returns for SMH, Forecast Period 33w: [ 0.00471112  0.03615981 -0.00345475  0.03929308 -0.00158929]
#
# Debug: Returns for SMH, Forecast Period 34w: [ 0.01643422 -0.01581505  0.00769736 -0.03479516  0.02279981]
#
# Debug: Returns for SMH, Forecast Period 35w: [-0.02555219  0.00797398 -0.01848236 -0.01505124  0.02157825]
#
# Debug: Returns for SMH, Forecast Period 36w: [-0.07639906 -0.00386207 -0.00346599 -0.04293836]
#
# Debug: Returns for SMH, Forecast Period 37w: [ 2.02473546e-02  7.30812612e-03  4.95853993e-02 -4.61663974e-05
#   1.07019204e-02]
#
# Debug: Returns for SMH, Forecast Period 38w: [-0.01576164 -0.00308194 -0.01445587  0.04059817 -0.01602336]
#
# Debug: Returns for SMH, Forecast Period 39w: [ 0.00200012  0.01604219  0.00665197  0.02672869 -0.02125326]
#
# Debug: Returns for SMH, Forecast Period 40w: [-0.01116492 -0.02916673  0.01305655  0.00799714  0.01233678]
#
# Debug: Returns for SMH, Forecast Period 41w: [ 0.00112501  0.01665747  0.00982372 -0.00310951  0.006867  ]
#
# Debug: Returns for SMH, Forecast Period 42w: [ 0.01672328 -0.05530161 -0.00088641  0.0159369  -0.00198349]
#
# Debug: Returns for SMH, Forecast Period 43w: [ 0.00375238 -0.00622687 -0.01267165  0.00208946  0.00914913]
#
# Debug: Returns for SMH, Forecast Period 44w: [-0.00910838  0.02066369 -0.02595689 -0.03806881  0.01036679]
#
# Debug: Returns for SMH, Forecast Period 45w: [-0.00447779  0.01401443  0.02363963  0.02196605 -0.00876894]
#
# Debug: Returns for SMH, Forecast Period 46w: [-0.0250345  -0.00958595 -0.01911194 -0.00021678 -0.03592342]
#
# Debug: Returns for SMH, Forecast Period 47w: [ 0.00376817  0.00806672 -0.00956289  0.0120334  -0.00875518]
#
# Debug: Returns for SMH, Forecast Period 48w: [-0.00694426 -0.01218338 -0.01644849  0.01331397]
#
# Debug: Returns for SOXX, Forecast Period 1w: [-0.03689163 -0.02257334 -0.00949502  0.00449957]
#
# Debug: Returns for SOXX, Forecast Period 2w: [ 0.03165869 -0.0006159  -0.00441572  0.00245992 -0.00569379]
#
# Debug: Returns for SOXX, Forecast Period 3w: [ 0.01278226 -0.01071176  0.0315337   0.03782708]
#
# Debug: Returns for SOXX, Forecast Period 4w: [ 0.00207852  0.00577362  0.01354899 -0.0037803  -0.02821928]
#
# Debug: Returns for SOXX, Forecast Period 5w: [ 0.00915868 -0.01672918 -0.01586164  0.00391795  0.01192779]
#
# Debug: Returns for SOXX, Forecast Period 6w: [ 0.01291843 -0.01248033  0.01428566  0.01630734  0.01911821]
#
# Debug: Returns for SOXX, Forecast Period 7w: [-0.00263017 -0.02142718  0.02171478 -0.00172177 -0.00665572]
#
# Debug: Returns for SOXX, Forecast Period 8w: [-0.0181239  -0.00365373  0.047934   -0.01212945]
#
# Debug: Returns for SOXX, Forecast Period 9w: [ 0.00857491 -0.0021038  -0.01246746  0.02606181  0.04183688]
#
# Debug: Returns for SOXX, Forecast Period 10w: [ 0.00915589 -0.02042626  0.02380533  0.03388512 -0.04123376]
#
# Debug: Returns for SOXX, Forecast Period 11w: [-0.01423729  0.01974943 -0.02544434 -0.01813899 -0.00843693]
#
# Debug: Returns for SOXX, Forecast Period 12w: [-0.00207926 -0.00973085  0.01582954  0.02145307 -0.00010408]
#
# Debug: Returns for SOXX, Forecast Period 13w: [-0.00517569 -0.00894345  0.01119169 -0.00018634]
#
# Debug: Returns for SOXX, Forecast Period 14w: [ 0.00913945 -0.01709063  0.00106152 -0.02998747  0.01003917]
#
# Debug: Returns for SOXX, Forecast Period 15w: [ 0.00052618  0.00911485 -0.01984213  0.02091088 -0.03438017]
#
# Debug: Returns for SOXX, Forecast Period 16w: [-0.01417877  0.00610548 -0.03197648 -0.01945259 -0.04194084]
#
# Debug: Returns for SOXX, Forecast Period 17w: [0.01431321 0.01878423 0.0109852  0.01671432 0.01931972]
#
# Debug: Returns for SOXX, Forecast Period 18w: [ 0.00582451 -0.02278937 -0.03582782  0.02048647  0.02091746]
#
# Debug: Returns for SOXX, Forecast Period 19w: [ 0.0192258  -0.01040592 -0.00074982 -0.00534873  0.00802275]
#
# Debug: Returns for SOXX, Forecast Period 20w: [ 0.0006147   0.01528668  0.02678312 -0.00588981 -0.00648511]
#
# Debug: Returns for SOXX, Forecast Period 21w: [ 0.02160664 -0.0037439   0.01105229 -0.00639619  0.01904918]
#
# Debug: Returns for SOXX, Forecast Period 22w: [ 0.01606835 -0.02160768 -0.00778571 -0.00870729]
#
# Debug: Returns for SOXX, Forecast Period 23w: [ 0.00093189 -0.00870805  0.04278307 -0.00903848 -0.00388808]
#
# Debug: Returns for SOXX, Forecast Period 24w: [ 1.36057452e-02 -3.35891160e-05  2.73841971e-02  1.00135927e-02
#  -4.63807594e-03]
#
# Debug: Returns for SOXX, Forecast Period 25w: [ 0.01486902  0.01196612 -0.02821029 -0.01086296]
#
# Debug: Returns for SOXX, Forecast Period 26w: [-0.02998318  0.01402817 -0.00538491 -0.00683587  0.0086367 ]
#
# Debug: Returns for SOXX, Forecast Period 27w: [-0.00144571  0.01279964  0.01549925  0.00085847]
#
# Debug: Returns for SOXX, Forecast Period 28w: [ 0.01761847 -0.00167941  0.02211803 -0.03419288  0.01091671]
#
# Debug: Returns for SOXX, Forecast Period 29w: [-0.00034847  0.00467709 -0.07315167  0.00084142 -0.03301079]
#
# Debug: Returns for SOXX, Forecast Period 30w: [ 0.03936693 -0.01686559 -0.0552435  -0.02470751  0.01921307]
#
# Debug: Returns for SOXX, Forecast Period 31w: [-0.00423131 -0.03881362  0.06474587 -0.07475143 -0.05638249]
#
# Debug: Returns for SOXX, Forecast Period 32w: [-0.02093868  0.00571075 -0.03126285  0.06548977 -0.00892886]
#
# Debug: Returns for SOXX, Forecast Period 33w: [ 0.00263024  0.0375736  -0.00556875  0.04599026 -0.00427112]
#
# Debug: Returns for SOXX, Forecast Period 34w: [ 0.01530827 -0.01525373  0.01232795 -0.03566158  0.02555484]
#
# Debug: Returns for SOXX, Forecast Period 35w: [-0.0266621   0.00954491 -0.01936636 -0.00476827  0.02510001]
#
# Debug: Returns for SOXX, Forecast Period 36w: [-0.07735431  0.00232234 -0.00644773 -0.04389421]
#
# Debug: Returns for SOXX, Forecast Period 37w: [ 0.01827677  0.00922387  0.0451643  -0.00586     0.01644076]
#
# Debug: Returns for SOXX, Forecast Period 38w: [-0.01504132 -0.00050111 -0.01304631  0.04089456 -0.01643976]
#
# Debug: Returns for SOXX, Forecast Period 39w: [ 0.00239743  0.01045488  0.00551104  0.03435146 -0.0171048 ]
#
# Debug: Returns for SOXX, Forecast Period 40w: [-0.01030223 -0.02972195  0.01264823  0.00273909  0.01294894]
#
# Debug: Returns for SOXX, Forecast Period 41w: [-0.00311126  0.00935041  0.00991545 -0.00786631  0.00751938]
#
# Debug: Returns for SOXX, Forecast Period 42w: [ 0.01751595 -0.05298179 -0.00117626  0.00687186 -0.00036897]
#
# Debug: Returns for SOXX, Forecast Period 43w: [-0.00309061 -0.00504889 -0.01042113  0.00400694  0.00825983]
#
# Debug: Returns for SOXX, Forecast Period 44w: [-0.00098984  0.02310829 -0.03665024 -0.04050338  0.00895018]
#
# Debug: Returns for SOXX, Forecast Period 45w: [-0.00756607  0.00988861  0.02736683  0.01909281 -0.00915047]
#
# Debug: Returns for SOXX, Forecast Period 46w: [-0.02696483 -0.01308209 -0.02300599 -0.00244232 -0.0342847 ]
#
# Debug: Returns for SOXX, Forecast Period 47w: [ 1.09096315e-02 -8.11064921e-05 -9.69860969e-03  1.38938175e-02
#  -1.55640947e-03]
#
# Debug: Returns for SOXX, Forecast Period 48w: [ 0.00771204 -0.0150432  -0.01572181  0.01143279]
#
# Debug: Returns for PSI, Forecast Period 1w: [-0.03572751 -0.0233738  -0.01411056  0.00163373]
#
# Debug: Returns for PSI, Forecast Period 2w: [ 0.02893141  0.00230535 -0.00412341  0.00320059 -0.00509092]
#
# Debug: Returns for PSI, Forecast Period 3w: [ 0.01419195 -0.01146352  0.03262948  0.03892016]
#
# Debug: Returns for PSI, Forecast Period 4w: [ 0.00927172  0.0036478   0.01122554 -0.00070354 -0.02800797]
#
# Debug: Returns for PSI, Forecast Period 5w: [ 0.01185896 -0.01412854 -0.01978293  0.00834546  0.01186122]
#
# Debug: Returns for PSI, Forecast Period 6w: [ 0.00938137 -0.01320083  0.00707538  0.01924628  0.03176965]
#
# Debug: Returns for PSI, Forecast Period 7w: [ 1.72285123e-03 -2.69929825e-02  3.16277199e-02  5.55130800e-03
#   4.17636558e-05]
#
# Debug: Returns for PSI, Forecast Period 8w: [-0.02715366 -0.0111586   0.04373763 -0.01057059]
#
# Debug: Returns for PSI, Forecast Period 9w: [ 0.01351072 -0.00235462  0.00377698  0.01868289  0.04281038]
#
# Debug: Returns for PSI, Forecast Period 10w: [ 0.00394705 -0.0256396   0.02453925  0.02937002 -0.03743977]
#
# Debug: Returns for PSI, Forecast Period 11w: [-0.01485463  0.01717658 -0.02517141 -0.01514009 -0.00867115]
#
# Debug: Returns for PSI, Forecast Period 12w: [ 0.00701109 -0.00636287  0.02496465  0.02949343  0.00189463]
#
# Debug: Returns for PSI, Forecast Period 13w: [-0.0002852  -0.00616409  0.0115654  -0.00062937]
#
# Debug: Returns for PSI, Forecast Period 14w: [ 0.01070813 -0.01005417  0.01045979 -0.02489765  0.01294475]
#
# Debug: Returns for PSI, Forecast Period 15w: [ 0.00256657  0.00859553 -0.02072608  0.02670833 -0.03269839]
#
# Debug: Returns for PSI, Forecast Period 16w: [-0.01428726  0.0115021  -0.03228727 -0.01953562 -0.03955058]
#
# Debug: Returns for PSI, Forecast Period 17w: [0.01570808 0.02356149 0.00886301 0.01682243 0.02169939]
#
# Debug: Returns for PSI, Forecast Period 18w: [ 0.00858711 -0.02159178 -0.03309002  0.02939114  0.02225692]
#
# Debug: Returns for PSI, Forecast Period 19w: [ 0.02239109 -0.00470723 -0.00012932  0.00174771  0.00630808]
#
# Debug: Returns for PSI, Forecast Period 20w: [-0.00057371  0.01630927  0.0270034  -0.00773392 -0.00497093]
#
# Debug: Returns for PSI, Forecast Period 21w: [ 0.02198142  0.00091176  0.00199    -0.00245133  0.01770645]
#
# Debug: Returns for PSI, Forecast Period 22w: [ 0.01535932 -0.01465475 -0.00158554 -0.01086056]
#
# Debug: Returns for PSI, Forecast Period 23w: [ 0.00112553 -0.00969879  0.04660678 -0.00765796 -0.00909134]
#
# Debug: Returns for PSI, Forecast Period 24w: [ 0.02070641  0.00022278  0.02924262  0.00878373 -0.00773085]
#
# Debug: Returns for PSI, Forecast Period 25w: [ 0.02125068  0.0150217  -0.02786409 -0.01111163]
#
# Debug: Returns for PSI, Forecast Period 26w: [-0.02269166  0.02248778 -0.00190963  0.00207781  0.01299165]
#
# Debug: Returns for PSI, Forecast Period 27w: [-0.00024108  0.01456045  0.01283182  0.00326149]
#
# Debug: Returns for PSI, Forecast Period 28w: [ 0.0163484   0.00121408  0.01740401 -0.02854195  0.0123474 ]
#
# Debug: Returns for PSI, Forecast Period 29w: [ 0.01232254  0.00792763 -0.08122292 -0.00975154 -0.02580321]
#
# Debug: Returns for PSI, Forecast Period 30w: [ 0.04194219 -0.00827891 -0.05557272 -0.03027299  0.0162352 ]
#
# Debug: Returns for PSI, Forecast Period 31w: [-0.0046188  -0.04709653  0.06379405 -0.07949176 -0.05029296]
#
# Debug: Returns for PSI, Forecast Period 32w: [-0.01572712  0.006024   -0.01713503  0.07087952  0.00320789]
#
# Debug: Returns for PSI, Forecast Period 33w: [ 0.0027878   0.03657329 -0.00207724  0.05199786 -0.00532849]
#
# Debug: Returns for PSI, Forecast Period 34w: [ 0.01354306 -0.01500248  0.02256117 -0.03132413  0.02719955]
#
# Debug: Returns for PSI, Forecast Period 35w: [-0.02671637  0.01149675 -0.01444647  0.00618571  0.01294775]
#
# Debug: Returns for PSI, Forecast Period 36w: [-0.08031199  0.00665541 -0.00698134 -0.04057163]
#
# Debug: Returns for PSI, Forecast Period 37w: [ 0.01132047  0.00753709  0.0416114  -0.008063    0.02318884]
#
# Debug: Returns for PSI, Forecast Period 38w: [-0.02238894  0.00765069 -0.01073746  0.04352917 -0.01276752]
#
# Debug: Returns for PSI, Forecast Period 39w: [ 0.00443646  0.0117688   0.00673423  0.04979855 -0.0161139 ]
#
# Debug: Returns for PSI, Forecast Period 40w: [-0.00642485 -0.03645988  0.01867955 -0.00600203  0.0215183 ]
#
# Debug: Returns for PSI, Forecast Period 41w: [ 0.00135389  0.00356448  0.01562126 -0.00102165  0.01727534]
#
# Debug: Returns for PSI, Forecast Period 42w: [ 1.86544494e-02 -5.51468269e-02  2.26716495e-03  2.71261744e-03
#  -9.03941687e-05]
#
# Debug: Returns for PSI, Forecast Period 43w: [-0.0025137  -0.00541476 -0.00782591  0.0027837   0.01567696]
#
# Debug: Returns for PSI, Forecast Period 44w: [-0.00081184  0.02142148 -0.02382707 -0.0436684   0.00632577]
#
# Debug: Returns for PSI, Forecast Period 45w: [-0.00757802  0.02806317  0.03404061  0.02483254 -0.00388419]
#
# Debug: Returns for PSI, Forecast Period 46w: [-0.02175833 -0.01251328 -0.02125879 -0.00195096 -0.03895513]
#
# Debug: Returns for PSI, Forecast Period 47w: [0.01514658 0.00886655 0.00017981 0.03423536 0.00059583]
#
# Debug: Returns for PSI, Forecast Period 48w: [ 0.01371001 -0.00805153 -0.01758262  0.02057408]
#
# Debug: Returns for XSD, Forecast Period 1w: [-0.02940431 -0.03062788 -0.01751607  0.00241074]
#
# Debug: Returns for XSD, Forecast Period 2w: [ 0.03165309 -0.00179138 -0.00696586 -0.00566373 -0.00932593]
#
# Debug: Returns for XSD, Forecast Period 3w: [ 0.00071101 -0.01205286  0.03024572  0.03078099]
#
# Debug: Returns for XSD, Forecast Period 4w: [ 0.01664859  0.00939919 -0.00820513 -0.01051667 -0.02743386]
#
# Debug: Returns for XSD, Forecast Period 5w: [ 0.01641267 -0.02497041 -0.02023731 -0.00091807  0.00086792]
#
# Debug: Returns for XSD, Forecast Period 6w: [ 0.0079087  -0.00887068  0.01812825  0.02841883  0.02411816]
#
# Debug: Returns for XSD, Forecast Period 7w: [ 0.00331587 -0.03644486  0.02451878 -0.00067661 -0.01669635]
#
# Debug: Returns for XSD, Forecast Period 8w: [-0.01088872 -0.00238704  0.02216866 -0.01669157]
#
# Debug: Returns for XSD, Forecast Period 9w: [ 0.01157346 -0.00327972 -0.00732984  0.02343993  0.03791717]
#
# Debug: Returns for XSD, Forecast Period 10w: [-0.00100634 -0.0235475   0.02516895  0.03559057 -0.02948119]
#
# Debug: Returns for XSD, Forecast Period 11w: [-0.00650929  0.00828408 -0.02789763 -0.024065   -0.00792643]
#
# Debug: Returns for XSD, Forecast Period 12w: [-0.00124475 -0.00669963  0.02330792  0.02232968 -0.00711381]
#
# Debug: Returns for XSD, Forecast Period 13w: [-0.00184026 -0.0047101   0.02710215  0.00357138]
#
# Debug: Returns for XSD, Forecast Period 14w: [ 0.00750324 -0.02233379  0.00910267 -0.01571996  0.00503836]
#
# Debug: Returns for XSD, Forecast Period 15w: [ 0.00831857  0.02177188 -0.03968276  0.0233525  -0.03583458]
#
# Debug: Returns for XSD, Forecast Period 16w: [-0.02021894  0.00237992 -0.02204226 -0.02016156 -0.03175393]
#
# Debug: Returns for XSD, Forecast Period 17w: [0.01445531 0.01938858 0.02272103 0.02340282 0.01816361]
#
# Debug: Returns for XSD, Forecast Period 18w: [ 0.01735526 -0.01849664 -0.03235664  0.01723838  0.02244963]
#
# Debug: Returns for XSD, Forecast Period 19w: [ 0.01716773 -0.00353353  0.00369885  0.00333309 -0.00609061]
#
# Debug: Returns for XSD, Forecast Period 20w: [ 0.00524269  0.01773157  0.02077688 -0.00466244  0.00101525]
#
# Debug: Returns for XSD, Forecast Period 21w: [ 0.01369197 -0.00303581  0.02071644 -0.02124539  0.02283044]
#
# Debug: Returns for XSD, Forecast Period 22w: [ 0.01401964 -0.01876656  0.00517334  0.00085836]
#
# Debug: Returns for XSD, Forecast Period 23w: [-0.00023733 -0.01483505  0.03915529 -0.00855409 -0.01925909]
#
# Debug: Returns for XSD, Forecast Period 24w: [ 0.01577553  0.00466956  0.02786191 -0.00250217 -0.0167606 ]
#
# Debug: Returns for XSD, Forecast Period 25w: [ 0.00742702  0.00128955 -0.02192032  0.00090676]
#
# Debug: Returns for XSD, Forecast Period 26w: [-0.02019388  0.00870779  0.00051385 -0.00246677  0.01067848]
#
# Debug: Returns for XSD, Forecast Period 27w: [-0.00399464  0.02007973  0.00949658  0.00484278]
#
# Debug: Returns for XSD, Forecast Period 28w: [ 0.02122476 -0.00591983  0.02780469 -0.01259756  0.01187704]
#
# Debug: Returns for XSD, Forecast Period 29w: [ 0.01021092  0.01942485 -0.05616085 -0.00845023 -0.02969144]
#
# Debug: Returns for XSD, Forecast Period 30w: [ 0.03894958 -0.01591626 -0.04578669 -0.02526598  0.02149328]
#
# Debug: Returns for XSD, Forecast Period 31w: [-0.00018918 -0.04145117  0.04412418 -0.06614949 -0.06076708]
#
# Debug: Returns for XSD, Forecast Period 32w: [-0.03015532  0.00301073 -0.03126848  0.06836344 -0.00625929]
#
# Debug: Returns for XSD, Forecast Period 33w: [-0.00017177  0.03953225 -0.01298479  0.0533467  -0.00353215]
#
# Debug: Returns for XSD, Forecast Period 34w: [ 0.01369788 -0.00976965  0.02216513 -0.02973903  0.0336878 ]
#
# Debug: Returns for XSD, Forecast Period 35w: [-0.01801296  0.00637382 -0.01253167  0.01575354  0.014527  ]
#
# Debug: Returns for XSD, Forecast Period 36w: [-0.07427355  0.00425664 -0.00904636 -0.04166573]
#
# Debug: Returns for XSD, Forecast Period 37w: [ 0.01733868  0.00342036  0.04057556 -0.0066132   0.02241158]
#
# Debug: Returns for XSD, Forecast Period 38w: [-0.01198139  0.00413472 -0.00346628  0.03938447 -0.01600146]
#
# Debug: Returns for XSD, Forecast Period 39w: [ 0.00418039  0.00994179 -0.00375147  0.04543547 -0.00466043]
#
# Debug: Returns for XSD, Forecast Period 40w: [-0.00988452 -0.03491933  0.01132191 -0.00158755  0.01852781]
#
# Debug: Returns for XSD, Forecast Period 41w: [-0.00557835  0.00484727  0.0135816  -0.00486478  0.02076005]
#
# Debug: Returns for XSD, Forecast Period 42w: [ 1.15800182e-02 -2.66572515e-02  6.66058221e-03  3.92527430e-03
#   7.78728695e-05]
#
# Debug: Returns for XSD, Forecast Period 43w: [-0.00308394  0.0002303  -0.00893201  0.0049408   0.0112456 ]
#
# Debug: Returns for XSD, Forecast Period 44w: [ 0.01207571  0.02311149 -0.04240226 -0.05085198  0.02156597]
#
# Debug: Returns for XSD, Forecast Period 45w: [-0.00512292  0.01574463  0.04205758  0.01138687  0.00788562]
#
# Debug: Returns for XSD, Forecast Period 46w: [-0.02791182 -0.01967038 -0.02212646 -0.00833499 -0.03293858]
#
# Debug: Returns for XSD, Forecast Period 47w: [0.01496939 0.0094397  0.00016498 0.02800296 0.01501709]
#
# Debug: Returns for XSD, Forecast Period 48w: [ 0.03180689 -0.01155476 -0.01161202  0.01885178]
#
# Debug: Returns for IYW, Forecast Period 1w: [-0.02656827 -0.01046256 -0.00723689  0.00059937]
#
# Debug: Returns for IYW, Forecast Period 2w: [0.02608176 0.00273929 0.0091814  0.004045   0.00223806]
#
# Debug: Returns for IYW, Forecast Period 3w: [ 0.0013812  -0.00580949  0.01875127  0.02342881]
#
# Debug: Returns for IYW, Forecast Period 4w: [ 0.00397523  0.00400893  0.00700762  0.00429532 -0.00941404]
#
# Debug: Returns for IYW, Forecast Period 5w: [ 0.0106899  -0.00874038 -0.02611687  0.01184421  0.01859105]
#
# Debug: Returns for IYW, Forecast Period 6w: [ 0.00099281 -0.00368884  0.01506512  0.00432304  0.01487322]
#
# Debug: Returns for IYW, Forecast Period 7w: [-0.00783326 -0.01747676  0.0121834  -0.00238134 -0.01133   ]
#
# Debug: Returns for IYW, Forecast Period 8w: [-0.01035226 -0.00823323  0.03287058 -0.00256632]
#
# Debug: Returns for IYW, Forecast Period 9w: [-0.00294534  0.00199294 -0.007334    0.01076524  0.01561633]
#
# Debug: Returns for IYW, Forecast Period 10w: [-0.002995   -0.0239177   0.00839124  0.01745728 -0.0145429 ]
#
# Debug: Returns for IYW, Forecast Period 11w: [-0.00481575  0.01913906 -0.00934622  0.00022385 -0.01609468]
#
# Debug: Returns for IYW, Forecast Period 12w: [0.00767134 0.00404476 0.01230413 0.00250685 0.00291438]
#
# Debug: Returns for IYW, Forecast Period 13w: [-0.00545221 -0.00550666  0.00053633 -0.00252275]
#
# Debug: Returns for IYW, Forecast Period 14w: [ 0.00320142 -0.00841896  0.00155591 -0.0172193   0.01353167]
#
# Debug: Returns for IYW, Forecast Period 15w: [-0.00243202  0.00149449 -0.00760624  0.02056694 -0.01757355]
#
# Debug: Returns for IYW, Forecast Period 16w: [-0.02160941  0.00123394 -0.01625698 -0.00798284 -0.02946034]
#
# Debug: Returns for IYW, Forecast Period 17w: [ 0.01084049  0.01689141  0.00151702 -0.00593122  0.0204386 ]
#
# Debug: Returns for IYW, Forecast Period 18w: [-0.00018328 -0.02278804 -0.01044355  0.0152229   0.0237698 ]
#
# Debug: Returns for IYW, Forecast Period 19w: [ 0.01485447 -0.0050589  -0.00034425 -0.00175273  0.00248625]
#
# Debug: Returns for IYW, Forecast Period 20w: [ 0.00310277  0.00837905  0.02205731 -0.00273144 -0.00252198]
#
# Debug: Returns for IYW, Forecast Period 21w: [0.01289789 0.00112489 0.0002689  0.00172333 0.00907724]
#
# Debug: Returns for IYW, Forecast Period 22w: [ 0.01063679 -0.0052137  -0.02555305 -0.00060048]
#
# Debug: Returns for IYW, Forecast Period 23w: [ 0.00776251  0.00122687  0.026489   -0.00318605  0.00106533]
#
# Debug: Returns for IYW, Forecast Period 24w: [0.00307397 0.01454511 0.0225312  0.00647138 0.00549931]
#
# Debug: Returns for IYW, Forecast Period 25w: [ 0.01108846  0.0046581  -0.01375487 -0.00651496]
#
# Debug: Returns for IYW, Forecast Period 26w: [-0.01719185  0.01689524  0.00329836  0.00140617 -0.00428324]
#
# Debug: Returns for IYW, Forecast Period 27w: [0.00994358 0.00673988 0.01101441 0.00927337]
#
# Debug: Returns for IYW, Forecast Period 28w: [ 0.00503289 -0.00207418  0.01333343 -0.02451956  0.00663224]
#
# Debug: Returns for IYW, Forecast Period 29w: [ 0.00472902 -0.00322589 -0.03822925 -0.00564164 -0.01165358]
#
# Debug: Returns for IYW, Forecast Period 30w: [ 0.01945528 -0.00256473 -0.04353788 -0.01014486  0.0101069 ]
#
# Debug: Returns for IYW, Forecast Period 31w: [-0.00391817 -0.0202699   0.03349717 -0.03252096 -0.0268917 ]
#
# Debug: Returns for IYW, Forecast Period 32w: [-0.03706084  0.00749316 -0.01264019  0.03353505  0.00524768]
#
# Debug: Returns for IYW, Forecast Period 33w: [0.00393245 0.02637344 0.00202807 0.02396216 0.00068795]
#
# Debug: Returns for IYW, Forecast Period 34w: [ 0.01279438 -0.00396354  0.00482236 -0.02056024  0.01313518]
#
# Debug: Returns for IYW, Forecast Period 35w: [-0.01012392  0.00351879 -0.01310244 -0.00486396  0.01060308]
#
# Debug: Returns for IYW, Forecast Period 36w: [-0.04225389 -0.00432159 -0.0006319  -0.02421907]
#
# Debug: Returns for IYW, Forecast Period 37w: [0.01167799 0.01020683 0.02733147 0.00795836 0.00468575]
#
# Debug: Returns for IYW, Forecast Period 38w: [-0.00696585 -0.00037038 -0.00575453  0.02986155 -0.00389422]
#
# Debug: Returns for IYW, Forecast Period 39w: [-0.00170105  0.00634297  0.00309468  0.00903759 -0.00834324]
#
# Debug: Returns for IYW, Forecast Period 40w: [ 0.00359188 -0.02365622  0.00571383  0.00402279  0.01287103]
#
# Debug: Returns for IYW, Forecast Period 41w: [-0.00868504  0.01853914  0.00880891  0.00039353  0.00213596]
#
# Debug: Returns for IYW, Forecast Period 42w: [ 0.01274708 -0.01845657 -0.00013522  0.00271238  0.00329322]
#
# Debug: Returns for IYW, Forecast Period 43w: [ 6.43044343e-03 -8.22194573e-05 -1.61052208e-02  3.45368237e-03
#   6.01384983e-03]
#
# Debug: Returns for IYW, Forecast Period 44w: [ 0.00131753  0.01300776 -0.01215814 -0.03376354  0.00616836]
#
# Debug: Returns for IYW, Forecast Period 45w: [-0.00263451  0.01411072  0.02731347  0.02037761 -0.00196978]
#
# Debug: Returns for IYW, Forecast Period 46w: [-0.00499209  0.00306041 -0.00527519 -0.00381781 -0.02589665]
#
# Debug: Returns for IYW, Forecast Period 47w: [ 3.62173343e-03  1.17546432e-02 -1.97172861e-03  6.31344585e-03
#  -6.56298305e-05]
#
# Debug: Returns for IYW, Forecast Period 48w: [-0.00046112  0.00430917 -0.01256244  0.00806075]
#
# Debug: Returns for XLK, Forecast Period 1w: [-0.02644247 -0.01057752 -0.00770121 -0.00071984]
#
# Debug: Returns for XLK, Forecast Period 2w: [0.02465829 0.00124192 0.00812018 0.00469494 0.00285041]
#
# Debug: Returns for XLK, Forecast Period 3w: [ 0.00208105 -0.00533099  0.01983251  0.02273045]
#
# Debug: Returns for XLK, Forecast Period 4w: [ 0.00418963  0.00397581  0.00680738  0.00410504 -0.01161699]
#
# Debug: Returns for XLK, Forecast Period 5w: [ 0.0090257  -0.00840923 -0.02121694  0.0124839   0.01037075]
#
# Debug: Returns for XLK, Forecast Period 6w: [ 0.00239406 -0.00451489  0.01318078  0.00312032  0.01341147]
#
# Debug: Returns for XLK, Forecast Period 7w: [-0.00763267 -0.01708522  0.01025564 -0.00222496 -0.0094231 ]
#
# Debug: Returns for XLK, Forecast Period 8w: [-0.01059298 -0.00680048  0.03213536 -0.00280194]
#
# Debug: Returns for XLK, Forecast Period 9w: [ 0.00044265  0.00044653 -0.00522049  0.01067971  0.01804815]
#
# Debug: Returns for XLK, Forecast Period 10w: [-0.00023011 -0.02490542  0.00750843  0.01546599 -0.01521062]
#
# Debug: Returns for XLK, Forecast Period 11w: [-0.00323688  0.0199488  -0.01123525 -0.00016502 -0.0155362 ]
#
# Debug: Returns for XLK, Forecast Period 12w: [ 4.41812228e-03  4.77624429e-03  1.08754725e-02  5.17646730e-04
#  -2.10190342e-05]
#
# Debug: Returns for XLK, Forecast Period 13w: [-0.00699238 -0.00452798  0.00467396 -0.0025715 ]
#
# Debug: Returns for XLK, Forecast Period 14w: [ 0.00230818 -0.01019331  0.00206932 -0.01623793  0.01092755]
#
# Debug: Returns for XLK, Forecast Period 15w: [-0.00175187  0.00456246 -0.01272031  0.0193676  -0.0166696 ]
#
# Debug: Returns for XLK, Forecast Period 16w: [-0.01958544  0.000631   -0.01503792 -0.01214329 -0.02150428]
#
# Debug: Returns for XLK, Forecast Period 17w: [ 0.00798933  0.01391625  0.00377757 -0.00293987  0.01050539]
#
# Debug: Returns for XLK, Forecast Period 18w: [ 0.00357767 -0.02278675 -0.0110531   0.01355606  0.02719999]
#
# Debug: Returns for XLK, Forecast Period 19w: [ 0.01118188 -0.00377547  0.00229047 -0.00079046  0.00310351]
#
# Debug: Returns for XLK, Forecast Period 20w: [ 0.00425777  0.00854624  0.02224781 -0.00352885 -0.00220533]
#
# Debug: Returns for XLK, Forecast Period 21w: [ 0.01191159  0.00177569  0.00228256 -0.00810877  0.00846368]
#
# Debug: Returns for XLK, Forecast Period 22w: [ 0.00422637 -0.00636924 -0.02277034  0.0015953 ]
#
# Debug: Returns for XLK, Forecast Period 23w: [ 0.00245891  0.00192355  0.02199689 -0.00346238  0.00217015]
#
# Debug: Returns for XLK, Forecast Period 24w: [0.00240831 0.01845247 0.02204814 0.00790973 0.00369002]
#
# Debug: Returns for XLK, Forecast Period 25w: [ 0.0151984   0.00139834 -0.01120799 -0.00180415]
#
# Debug: Returns for XLK, Forecast Period 26w: [-0.02468926  0.01816894 -0.0013196   0.00029649 -0.00072045]
#
# Debug: Returns for XLK, Forecast Period 27w: [0.00756034 0.00502892 0.01355236 0.00314937]
#
# Debug: Returns for XLK, Forecast Period 28w: [ 0.00682213 -0.00076459  0.0145744  -0.02497324  0.00877666]
#
# Debug: Returns for XLK, Forecast Period 29w: [ 0.00155417 -0.00363051 -0.03935886 -0.00064409 -0.01641528]
#
# Debug: Returns for XLK, Forecast Period 30w: [ 0.02291237 -0.00464103 -0.0420148  -0.01165405  0.01172393]
#
# Debug: Returns for XLK, Forecast Period 31w: [-0.00532949 -0.02610019  0.04122762 -0.03835196 -0.02943901]
#
# Debug: Returns for XLK, Forecast Period 32w: [-0.03489409  0.01187276 -0.01789228  0.03551385  0.0030836 ]
#
# Debug: Returns for XLK, Forecast Period 33w: [0.00674697 0.02933571 0.00425766 0.0279443  0.0009457 ]
#
# Debug: Returns for XLK, Forecast Period 34w: [ 0.01593675 -0.00411353  0.00534998 -0.02327844  0.01595277]
#
# Debug: Returns for XLK, Forecast Period 35w: [-0.0128858   0.0057018  -0.01400349 -0.00960228  0.01299055]
#
# Debug: Returns for XLK, Forecast Period 36w: [-0.04615331 -0.00277151 -0.00184455 -0.02621961]
#
# Debug: Returns for XLK, Forecast Period 37w: [0.01580314 0.01447507 0.03368759 0.00785901 0.00460886]
#
# Debug: Returns for XLK, Forecast Period 38w: [-0.00436061 -0.0025434  -0.00987413  0.02902686 -0.00548172]
#
# Debug: Returns for XLK, Forecast Period 39w: [-0.00065098  0.00633066  0.00245109  0.01281662 -0.00966794]
#
# Debug: Returns for XLK, Forecast Period 40w: [ 0.00261886 -0.02482675  0.00723757  0.00405471  0.01109867]
#
# Debug: Returns for XLK, Forecast Period 41w: [-0.0067243   0.01872932  0.01125797 -0.00034135  0.00160547]
#
# Debug: Returns for XLK, Forecast Period 42w: [ 0.01289303 -0.02209347  0.00292258  0.00298717  0.00334557]
#
# Debug: Returns for XLK, Forecast Period 43w: [ 0.00450765 -0.00120839 -0.01457925  0.0025872   0.00476928]
#
# Debug: Returns for XLK, Forecast Period 44w: [-0.00064792  0.01311628 -0.01605359 -0.03244229  0.0070108 ]
#
# Debug: Returns for XLK, Forecast Period 45w: [-0.00130633  0.01358092  0.0279298   0.01698049 -0.00145627]
#
# Debug: Returns for XLK, Forecast Period 46w: [-0.00593744  0.0007413  -0.00383213 -0.00383442 -0.02534016]
#
# Debug: Returns for XLK, Forecast Period 47w: [ 2.63315138e-03  7.59074701e-03 -1.44266810e-03  9.69837226e-03
#   5.42666897e-05]
#
# Debug: Returns for XLK, Forecast Period 48w: [-0.00058216  0.00449427 -0.01414184  0.00876212]
#
# Debug: Returns for VGT, Forecast Period 1w: [-0.02599743 -0.01330442 -0.00582275  0.00042485]
#
# Debug: Returns for VGT, Forecast Period 2w: [0.02567243 0.00205593 0.00871964 0.00370082 0.00243256]
#
# Debug: Returns for VGT, Forecast Period 3w: [ 0.00166255 -0.00527715  0.0196692   0.02199401]
#
# Debug: Returns for VGT, Forecast Period 4w: [ 0.0068653   0.0046529   0.00525754  0.00283166 -0.00998791]
#
# Debug: Returns for VGT, Forecast Period 5w: [ 0.01207709 -0.00926712 -0.02048558  0.01332675  0.01028617]
#
# Debug: Returns for VGT, Forecast Period 6w: [ 0.00103819 -0.00117734  0.01338765  0.00552622  0.01564919]
#
# Debug: Returns for VGT, Forecast Period 7w: [-0.00577473 -0.01919443  0.01376617 -0.00031431 -0.01019478]
#
# Debug: Returns for VGT, Forecast Period 8w: [-0.01155172 -0.00836223  0.03273653 -0.00312424]
#
# Debug: Returns for VGT, Forecast Period 9w: [ 0.00283229  0.00173312 -0.00444627  0.0097618   0.01895873]
#
# Debug: Returns for VGT, Forecast Period 10w: [ 0.00223493 -0.02375506  0.01143185  0.01721987 -0.01601413]
#
# Debug: Returns for VGT, Forecast Period 11w: [-0.00401351  0.02095614 -0.01033111 -0.00343416 -0.01289628]
#
# Debug: Returns for VGT, Forecast Period 12w: [0.00495422 0.00452544 0.01390132 0.00327064 0.00195778]
#
# Debug: Returns for VGT, Forecast Period 13w: [-0.00371637 -0.00406768  0.0026774  -0.00111647]
#
# Debug: Returns for VGT, Forecast Period 14w: [ 0.00235155 -0.01107998  0.00229752 -0.01586939  0.01238875]
#
# Debug: Returns for VGT, Forecast Period 15w: [-0.00123749  0.00255096 -0.00885376  0.01953342 -0.01755112]
#
# Debug: Returns for VGT, Forecast Period 16w: [-0.01887509  0.00077238 -0.01469772 -0.00939592 -0.02663935]
#
# Debug: Returns for VGT, Forecast Period 17w: [0.01354313 0.01638253 0.00158461 0.00044232 0.01724126]
#
# Debug: Returns for VGT, Forecast Period 18w: [ 0.00402982 -0.02211673 -0.01079188  0.01374214  0.02723505]
#
# Debug: Returns for VGT, Forecast Period 19w: [ 0.01474346 -0.00384672  0.00174476 -0.00071455  0.00286214]
#
# Debug: Returns for VGT, Forecast Period 20w: [ 0.00518436  0.01066552  0.02334699 -0.00367946 -0.00183678]
#
# Debug: Returns for VGT, Forecast Period 21w: [0.01344691 0.00163719 0.00080824 0.00064607 0.01037691]
#
# Debug: Returns for VGT, Forecast Period 22w: [ 0.00923171 -0.0028948  -0.02297674 -0.00027046]
#
# Debug: Returns for VGT, Forecast Period 23w: [ 0.00583077  0.00115055  0.02601606 -0.00228606  0.00046428]
#
# Debug: Returns for VGT, Forecast Period 24w: [0.00401908 0.01460985 0.02213294 0.01053404 0.00448663]
#
# Debug: Returns for VGT, Forecast Period 25w: [ 0.01293955  0.00477895 -0.01304359 -0.00453928]
#
# Debug: Returns for VGT, Forecast Period 26w: [-0.01781927  0.01488125  0.00250876  0.00249277  0.00015458]
#
# Debug: Returns for VGT, Forecast Period 27w: [0.01041691 0.00730733 0.01224177 0.00576773]
#
# Debug: Returns for VGT, Forecast Period 28w: [ 0.00733965 -0.00146734  0.01445902 -0.01862195  0.00989267]
#
# Debug: Returns for VGT, Forecast Period 29w: [ 0.00569734  0.00173601 -0.03570266 -0.00502052 -0.01167664]
#
# Debug: Returns for VGT, Forecast Period 30w: [ 0.02019546 -0.00155202 -0.03908491 -0.0093306   0.01191729]
#
# Debug: Returns for VGT, Forecast Period 31w: [-0.0035486  -0.01905056  0.03508907 -0.0362298  -0.02474121]
#
# Debug: Returns for VGT, Forecast Period 32w: [-0.03544337  0.00955239 -0.01203852  0.03427527  0.00620273]
#
# Debug: Returns for VGT, Forecast Period 33w: [0.00503287 0.02875234 0.00432234 0.02713075 0.00250456]
#
# Debug: Returns for VGT, Forecast Period 34w: [ 0.01428461 -0.00301294  0.00610146 -0.02046051  0.01844188]
#
# Debug: Returns for VGT, Forecast Period 35w: [-0.00897709  0.00514935 -0.01268238 -0.00234821  0.01091747]
#
# Debug: Returns for VGT, Forecast Period 36w: [-0.04366816 -0.0016415  -0.00178887 -0.02366281]
#
# Debug: Returns for VGT, Forecast Period 37w: [0.01380619 0.0104752  0.02923249 0.00807009 0.00631918]
#
# Debug: Returns for VGT, Forecast Period 38w: [-0.00555947 -0.00020838 -0.00442502  0.02992271 -0.0031381 ]
#
# Debug: Returns for VGT, Forecast Period 39w: [ 8.78935212e-05  9.49135056e-03  1.13773828e-03  1.28489851e-02
#  -6.95117778e-03]
#
# Debug: Returns for VGT, Forecast Period 40w: [ 0.003114   -0.02485498  0.00687509  0.00452459  0.01348669]
#
# Debug: Returns for VGT, Forecast Period 41w: [-0.00647834  0.01895894  0.01191198  0.00150766  0.00372805]
#
# Debug: Returns for VGT, Forecast Period 42w: [ 0.0130268  -0.01743364  0.00433431  0.00464677  0.00405525]
#
# Debug: Returns for VGT, Forecast Period 43w: [ 0.00620674 -0.00010008 -0.01501638  0.00390068  0.00516071]
#
# Debug: Returns for VGT, Forecast Period 44w: [ 0.0025091   0.01230472 -0.01253274 -0.03286506  0.00753862]
#
# Debug: Returns for VGT, Forecast Period 45w: [-0.00064724  0.01489601  0.03171656  0.02095163 -0.00124943]
#
# Debug: Returns for VGT, Forecast Period 46w: [-0.00362241  0.00217927 -0.00358842 -0.00363676 -0.02402559]
#
# Debug: Returns for VGT, Forecast Period 47w: [0.00328027 0.01269383 0.00144503 0.01100589 0.00412333]
#
# Debug: Returns for VGT, Forecast Period 48w: [-0.00013043  0.00338906 -0.00998919  0.00931882]
#
# Debug: Returns for FTEC, Forecast Period 1w: [-0.0249032  -0.00985293 -0.00545547  0.00260761]
#
# Debug: Returns for FTEC, Forecast Period 2w: [0.02707662 0.00315949 0.01061689 0.00618995 0.00450386]
#
# Debug: Returns for FTEC, Forecast Period 3w: [ 0.00344854 -0.00340841  0.02177631  0.02422573]
#
# Debug: Returns for FTEC, Forecast Period 4w: [ 0.00838341  0.00585685  0.00651598  0.00437326 -0.00806995]
#
# Debug: Returns for FTEC, Forecast Period 5w: [ 0.01317555 -0.00647424 -0.01972131  0.01440885  0.01138493]
#
# Debug: Returns for FTEC, Forecast Period 6w: [ 0.00228401 -0.00112628  0.01464618  0.00706031  0.01639063]
#
# Debug: Returns for FTEC, Forecast Period 7w: [-0.00497602 -0.0177259   0.01459859 -0.00023264 -0.00844735]
#
# Debug: Returns for FTEC, Forecast Period 8w: [-0.00884197 -0.00669996  0.03491164 -0.00115868]
#
# Debug: Returns for FTEC, Forecast Period 9w: [ 0.00416436  0.00257501 -0.00194658  0.01118548  0.02095815]
#
# Debug: Returns for FTEC, Forecast Period 10w: [ 0.00254402 -0.02138419  0.01272371  0.01871595 -0.0144017 ]
#
# Debug: Returns for FTEC, Forecast Period 11w: [-0.0023288   0.02242927 -0.00805849 -0.00176469 -0.01168465]
#
# Debug: Returns for FTEC, Forecast Period 12w: [0.00720241 0.00680638 0.01481871 0.00405588 0.00401105]
#
# Debug: Returns for FTEC, Forecast Period 13w: [-0.00207417 -0.00341078  0.00532137  0.00016095]
#
# Debug: Returns for FTEC, Forecast Period 14w: [ 0.00250149 -0.00729576  0.00428076 -0.01378031  0.0142301 ]
#
# Debug: Returns for FTEC, Forecast Period 15w: [ 0.00091564  0.00598072 -0.0086977   0.02328466 -0.01551321]
#
# Debug: Returns for FTEC, Forecast Period 16w: [-0.01882421  0.00516577 -0.01355961 -0.00613928 -0.02384704]
#
# Debug: Returns for FTEC, Forecast Period 17w: [0.01528984 0.02108551 0.00513424 0.00472291 0.01908091]
#
# Debug: Returns for FTEC, Forecast Period 18w: [ 0.00541313 -0.01887729 -0.00866214  0.01776929  0.02860928]
#
# Debug: Returns for FTEC, Forecast Period 19w: [ 0.01833658 -0.00330865  0.00305984  0.00182652  0.00558883]
#
# Debug: Returns for FTEC, Forecast Period 20w: [ 0.00689952  0.01128142  0.02542343 -0.00227679 -0.00197988]
#
# Debug: Returns for FTEC, Forecast Period 21w: [0.01357624 0.00264766 0.00254647 0.00172537 0.01099316]
#
# Debug: Returns for FTEC, Forecast Period 22w: [ 0.01128066 -0.0036281  -0.02189701 -0.00068146]
#
# Debug: Returns for FTEC, Forecast Period 23w: [ 0.00815656  0.00343574  0.02832021 -0.00204549  0.00127271]
#
# Debug: Returns for FTEC, Forecast Period 24w: [0.00620268 0.01523201 0.0250129  0.01076743 0.00571247]
#
# Debug: Returns for FTEC, Forecast Period 25w: [ 0.01363056  0.00554216 -0.01143223 -0.00348511]
#
# Debug: Returns for FTEC, Forecast Period 26w: [-0.01634702  0.0161886   0.00546481  0.0041917   0.00061384]
#
# Debug: Returns for FTEC, Forecast Period 27w: [0.01125162 0.00865602 0.01282234 0.00669929]
#
# Debug: Returns for FTEC, Forecast Period 28w: [ 0.01053478 -0.00190927  0.01520789 -0.01865231  0.01291115]
#
# Debug: Returns for FTEC, Forecast Period 29w: [ 0.00682031  0.00380697 -0.03341141 -0.00222799 -0.00892992]
#
# Debug: Returns for FTEC, Forecast Period 30w: [ 0.02170864  0.00132789 -0.03589399 -0.00592264  0.01397208]
#
# Debug: Returns for FTEC, Forecast Period 31w: [-0.00084259 -0.01635797  0.03928708 -0.03182648 -0.02247141]
#
# Debug: Returns for FTEC, Forecast Period 32w: [-0.02998976  0.01401786 -0.00836797  0.03982866  0.00796815]
#
# Debug: Returns for FTEC, Forecast Period 33w: [0.00987903 0.03283648 0.00777595 0.0296444  0.00504991]
#
# Debug: Returns for FTEC, Forecast Period 34w: [ 0.01592363 -0.00102214  0.00885472 -0.01698345  0.018585  ]
#
# Debug: Returns for FTEC, Forecast Period 35w: [-0.00832566  0.00720873 -0.0106669  -0.00084098  0.01165704]
#
# Debug: Returns for FTEC, Forecast Period 36w: [-0.04110824 -0.00118857  0.0006011  -0.02142112]
#
# Debug: Returns for FTEC, Forecast Period 37w: [0.01491445 0.01329573 0.03079508 0.01008189 0.00882118]
#
# Debug: Returns for FTEC, Forecast Period 38w: [-0.00428155  0.00355269 -0.00296307  0.03366616 -0.00078854]
#
# Debug: Returns for FTEC, Forecast Period 39w: [ 0.00118359  0.01032163  0.00423455  0.01517348 -0.00567712]
#
# Debug: Returns for FTEC, Forecast Period 40w: [ 0.00576317 -0.02308993  0.0088798   0.00597129  0.01424208]
#
# Debug: Returns for FTEC, Forecast Period 41w: [-0.00492633  0.01903114  0.01308815  0.00368136  0.00534817]
#
# Debug: Returns for FTEC, Forecast Period 42w: [ 0.01428432 -0.01434605  0.00399663  0.00525444  0.00643969]
#
# Debug: Returns for FTEC, Forecast Period 43w: [ 0.00788414  0.00100324 -0.01231875  0.00590364  0.00793219]
#
# Debug: Returns for FTEC, Forecast Period 44w: [ 0.00352897  0.01549418 -0.01249841 -0.03034138  0.01041015]
#
# Debug: Returns for FTEC, Forecast Period 45w: [0.00147581 0.01732124 0.03343763 0.02307444 0.00115488]
#
# Debug: Returns for FTEC, Forecast Period 46w: [-0.00162764  0.00334926 -0.00186924 -0.00163485 -0.02100597]
#
# Debug: Returns for FTEC, Forecast Period 47w: [0.00534348 0.01507181 0.00318326 0.01319912 0.00587046]
#
# Debug: Returns for FTEC, Forecast Period 48w: [ 0.00247466  0.00558244 -0.00856369  0.01240122]
#
# Debug: Returns for IGM, Forecast Period 1w: [-0.02647361 -0.01217534 -0.00434332  0.00212565]
#
# Debug: Returns for IGM, Forecast Period 2w: [0.02754998 0.00330298 0.00974982 0.00557712 0.00161472]
#
# Debug: Returns for IGM, Forecast Period 3w: [ 0.00166257 -0.00579941  0.01729842  0.02499536]
#
# Debug: Returns for IGM, Forecast Period 4w: [ 0.00462334  0.00473366  0.0097966   0.0054462  -0.00913371]
#
# Debug: Returns for IGM, Forecast Period 5w: [ 0.01307035 -0.00751157 -0.02497544  0.01152191  0.02807722]
#
# Debug: Returns for IGM, Forecast Period 6w: [ 0.00150251 -0.0052059   0.01568614  0.00549628  0.01503763]
#
# Debug: Returns for IGM, Forecast Period 7w: [-0.00506675 -0.01817153  0.01765228 -0.00076351 -0.01220774]
#
# Debug: Returns for IGM, Forecast Period 8w: [-0.0144819  -0.01110208  0.04280913 -0.00261173]
#
# Debug: Returns for IGM, Forecast Period 9w: [ 0.0006965   0.0014813  -0.0073843   0.01231445  0.02119302]
#
# Debug: Returns for IGM, Forecast Period 10w: [ 0.00090418 -0.02060121  0.01208935  0.02088497 -0.01987139]
#
# Debug: Returns for IGM, Forecast Period 11w: [-0.00797663  0.02195261 -0.00959714 -0.00640756 -0.01520094]
#
# Debug: Returns for IGM, Forecast Period 12w: [0.01039866 0.00146608 0.0131739  0.00237789 0.00304692]
#
# Debug: Returns for IGM, Forecast Period 13w: [-0.00537588 -0.00418166  0.00036968 -0.00219752]
#
# Debug: Returns for IGM, Forecast Period 14w: [ 0.00502681 -0.00797885  0.00346329 -0.01758778  0.01287339]
#
# Debug: Returns for IGM, Forecast Period 15w: [-0.00102057  0.00308895 -0.00986258  0.01698684 -0.01863126]
#
# Debug: Returns for IGM, Forecast Period 16w: [-0.02113259  0.00177306 -0.01386291 -0.0057579  -0.0287059 ]
#
# Debug: Returns for IGM, Forecast Period 17w: [ 0.00976359  0.01874098 -0.00030943 -0.01039163  0.02280781]
#
# Debug: Returns for IGM, Forecast Period 18w: [-0.00448131 -0.02037503 -0.00914608  0.01465928  0.02012454]
#
# Debug: Returns for IGM, Forecast Period 19w: [ 0.01561572 -0.00179843 -0.00142422 -0.00202202  0.0018105 ]
#
# Debug: Returns for IGM, Forecast Period 20w: [ 0.00095052  0.00832079  0.02315645 -0.00379172 -0.00114889]
#
# Debug: Returns for IGM, Forecast Period 21w: [ 0.01094743 -0.00088772  0.00140248 -0.00335101  0.00890288]
#
# Debug: Returns for IGM, Forecast Period 22w: [ 0.00810214 -0.00549775 -0.02497295 -0.00101298]
#
# Debug: Returns for IGM, Forecast Period 23w: [ 0.00450172  0.00219031  0.02587214 -0.00283548 -0.00180304]
#
# Debug: Returns for IGM, Forecast Period 24w: [0.00553223 0.01020014 0.01820082 0.0049868  0.00629773]
#
# Debug: Returns for IGM, Forecast Period 25w: [ 0.01015624  0.00263832 -0.01015763 -0.00414326]
#
# Debug: Returns for IGM, Forecast Period 26w: [-0.01498501  0.01457018  0.00025141  0.0050312  -0.00361944]
#
# Debug: Returns for IGM, Forecast Period 27w: [0.00663877 0.00726434 0.00927711 0.01140517]
#
# Debug: Returns for IGM, Forecast Period 28w: [ 0.00249844 -0.0030483   0.0106491  -0.0224492   0.00540164]
#
# Debug: Returns for IGM, Forecast Period 29w: [ 0.00491148 -0.00076097 -0.03791703 -0.00441929 -0.01151652]
#
# Debug: Returns for IGM, Forecast Period 30w: [ 0.01917514 -0.00227919 -0.04039955 -0.010332    0.01120083]
#
# Debug: Returns for IGM, Forecast Period 31w: [-0.00435409 -0.01663866  0.03057449 -0.02723684 -0.03069534]
#
# Debug: Returns for IGM, Forecast Period 32w: [-0.03270276  0.01042211 -0.01113529  0.03421569  0.00587403]
#
# Debug: Returns for IGM, Forecast Period 33w: [-0.00025026  0.02493083 -0.00039598  0.02478459 -0.00037249]
#
# Debug: Returns for IGM, Forecast Period 34w: [ 0.01213785 -0.00263503  0.00527022 -0.01855631  0.01217218]
#
# Debug: Returns for IGM, Forecast Period 35w: [-0.01049737  0.00326249 -0.01347639 -0.00094747  0.01009144]
#
# Debug: Returns for IGM, Forecast Period 36w: [-0.03926601 -0.00235203 -0.00038864 -0.02733441]
#
# Debug: Returns for IGM, Forecast Period 37w: [0.00978184 0.00897622 0.02410484 0.00904392 0.00589064]
#
# Debug: Returns for IGM, Forecast Period 38w: [-0.00246534  0.0001255  -0.0054944   0.02835104 -0.00199111]
#
# Debug: Returns for IGM, Forecast Period 39w: [ 5.58506255e-05  5.63431372e-03  2.97969691e-04  1.11218120e-02
#  -7.52725465e-03]
#
# Debug: Returns for IGM, Forecast Period 40w: [ 0.00296087 -0.018866    0.00472074  0.00473213  0.01306564]
#
# Debug: Returns for IGM, Forecast Period 41w: [-0.0101161   0.01688041  0.00794128 -0.00070131  0.00388413]
#
# Debug: Returns for IGM, Forecast Period 42w: [ 0.00963526 -0.01750254 -0.00048247  0.00044386  0.00468272]
#
# Debug: Returns for IGM, Forecast Period 43w: [ 0.00299753 -0.00019385 -0.01624598  0.00255598  0.00565013]
#
# Debug: Returns for IGM, Forecast Period 44w: [ 0.00219198  0.0149917  -0.01117135 -0.02925268  0.00543736]
#
# Debug: Returns for IGM, Forecast Period 45w: [-0.00346312  0.0138075   0.02907303  0.02112576 -0.00257094]
#
# Debug: Returns for IGM, Forecast Period 46w: [-0.00247225  0.00301921 -0.00469164 -0.00758606 -0.02517678]
#
# Debug: Returns for IGM, Forecast Period 47w: [ 0.0049523   0.01043825 -0.00028455  0.00585437  0.00047412]
#
# Debug: Returns for IGM, Forecast Period 48w: [ 0.00184748  0.00279056 -0.01125106  0.0080733 ]
#
# Debug: Returns for IXN, Forecast Period 1w: [-2.74315249e-02 -1.18396504e-02 -5.82747311e-03 -4.15645763e-05]
#
# Debug: Returns for IXN, Forecast Period 2w: [ 0.02480499 -0.00094102  0.00860226  0.00395254  0.00382214]
#
# Debug: Returns for IXN, Forecast Period 3w: [-0.00030774 -0.00542301  0.02125601  0.02285022]
#
# Debug: Returns for IXN, Forecast Period 4w: [ 0.00436327  0.00402198  0.00808758  0.00477851 -0.00942628]
#
# Debug: Returns for IXN, Forecast Period 5w: [ 0.00867267 -0.00754375 -0.01958819  0.0131673   0.01054967]
#
# Debug: Returns for IXN, Forecast Period 6w: [ 0.00278148 -0.0021424   0.01372887  0.0053255   0.01184339]
#
# Debug: Returns for IXN, Forecast Period 7w: [-0.00808527 -0.01762484  0.01175038 -0.00046978 -0.00883586]
#
# Debug: Returns for IXN, Forecast Period 8w: [-9.95936812e-03 -5.88846195e-03  3.22283137e-02  4.55810084e-05]
#
# Debug: Returns for IXN, Forecast Period 9w: [ 0.00075704 -0.00104209 -0.00438835  0.00946713  0.01867751]
#
# Debug: Returns for IXN, Forecast Period 10w: [ 0.00198607 -0.02242697  0.01064968  0.01723988 -0.01448681]
#
# Debug: Returns for IXN, Forecast Period 11w: [-0.00671274  0.0214391  -0.00974463 -0.00063612 -0.01510158]
#
# Debug: Returns for IXN, Forecast Period 12w: [0.00591693 0.00403266 0.01483233 0.00267161 0.00232105]
#
# Debug: Returns for IXN, Forecast Period 13w: [-0.00581599 -0.00495036  0.00215971 -0.00189485]
#
# Debug: Returns for IXN, Forecast Period 14w: [ 0.00310066 -0.00815435  0.00192649 -0.01659662  0.01171866]
#
# Debug: Returns for IXN, Forecast Period 15w: [-0.00226253  0.00468678 -0.01153441  0.02074896 -0.01813493]
#
# Debug: Returns for IXN, Forecast Period 16w: [-0.01843766  0.00148001 -0.01779297 -0.01048684 -0.02708432]
#
# Debug: Returns for IXN, Forecast Period 17w: [ 0.00899769  0.01576586  0.0041941  -0.00170739  0.01446624]
#
# Debug: Returns for IXN, Forecast Period 18w: [ 0.00312011 -0.02226775 -0.00972465  0.01426397  0.02795786]
#
# Debug: Returns for IXN, Forecast Period 19w: [ 0.01366529 -0.00356631  0.00238632 -0.00274686  0.00338591]
#
# Debug: Returns for IXN, Forecast Period 20w: [ 0.00323749  0.01053124  0.02168597 -0.00404747 -0.0037612 ]
#
# Debug: Returns for IXN, Forecast Period 21w: [0.01285995 0.00161983 0.00126816 0.00229903 0.01001583]
#
# Debug: Returns for IXN, Forecast Period 22w: [ 0.01053714 -0.00711351 -0.01973993 -0.00221045]
#
# Debug: Returns for IXN, Forecast Period 23w: [ 0.00999531  0.00260991  0.02644366 -0.00138784  0.00094219]
#
# Debug: Returns for IXN, Forecast Period 24w: [0.00335975 0.01404565 0.02739419 0.00744068 0.0029425 ]
#
# Debug: Returns for IXN, Forecast Period 25w: [ 0.01399457  0.00550636 -0.01185368 -0.00591742]
#
# Debug: Returns for IXN, Forecast Period 26w: [-0.02048481  0.0171594   0.00055352  0.00118665 -0.00144917]
#
# Debug: Returns for IXN, Forecast Period 27w: [0.01007162 0.00634999 0.01600671 0.00569007]
#
# Debug: Returns for IXN, Forecast Period 28w: [ 0.00849012 -0.00061114  0.01622942 -0.02384579  0.00633355]
#
# Debug: Returns for IXN, Forecast Period 29w: [ 0.0004915   0.00011309 -0.04117231 -0.00418917 -0.0141479 ]
#
# Debug: Returns for IXN, Forecast Period 30w: [ 0.01903487 -0.00169601 -0.04174236 -0.01203521  0.01107121]
#
# Debug: Returns for IXN, Forecast Period 31w: [-0.00502981 -0.02125811  0.04383051 -0.03834024 -0.02907765]
#
# Debug: Returns for IXN, Forecast Period 32w: [-0.03439658  0.01130144 -0.01260762  0.03366008  0.00406574]
#
# Debug: Returns for IXN, Forecast Period 33w: [0.00591878 0.02985657 0.00315213 0.02657352 0.00304972]
#
# Debug: Returns for IXN, Forecast Period 34w: [ 0.01498997 -0.00376567  0.0061991  -0.02251689  0.01693852]
#
# Debug: Returns for IXN, Forecast Period 35w: [-0.01516755  0.00782944 -0.01142575 -0.00763915  0.01060851]
#
# Debug: Returns for IXN, Forecast Period 36w: [-0.04622597 -0.00276843 -0.00233712 -0.02757248]
#
# Debug: Returns for IXN, Forecast Period 37w: [0.01581056 0.01064808 0.03300044 0.00817534 0.00460228]
#
# Debug: Returns for IXN, Forecast Period 38w: [-0.00543371 -0.00291552 -0.00610422  0.02932411 -0.00679236]
#
# Debug: Returns for IXN, Forecast Period 39w: [ 0.00081142  0.00540118  0.00011789  0.01620233 -0.01088522]
#
# Debug: Returns for IXN, Forecast Period 40w: [ 0.00077861 -0.0210623   0.00483953  0.00061628  0.00944554]
#
# Debug: Returns for IXN, Forecast Period 41w: [-0.00918549  0.01842346  0.01217024 -0.00334304  0.00312925]
#
# Debug: Returns for IXN, Forecast Period 42w: [ 0.01086438 -0.01959704  0.00020262  0.00668249  0.00372407]
#
# Debug: Returns for IXN, Forecast Period 43w: [ 3.67329296e-03 -2.63693419e-05 -1.55313997e-02  2.57303419e-03
#   4.70041158e-03]
#
# Debug: Returns for IXN, Forecast Period 44w: [-0.00076228  0.01236897 -0.01453127 -0.02888291  0.00321535]
#
# Debug: Returns for IXN, Forecast Period 45w: [-0.00204624  0.01403183  0.01743981  0.01971025 -0.00407827]
#
# Debug: Returns for IXN, Forecast Period 46w: [-0.00829985  0.00012717 -0.0035653  -0.00203931 -0.02100167]
#
# Debug: Returns for IXN, Forecast Period 47w: [ 0.00533418  0.00497911 -0.00222412  0.00689614  0.00263795]
#
# Debug: Returns for IXN, Forecast Period 48w: [ 0.00247125  0.00292889 -0.01119605  0.01025421]

# %%
# Initialize an empty dictionary to hold DataFrames for each week
weekly_scores_dfs = {}

# Assuming weekly_scores is a dictionary with keys as week identifiers ('1w', '2w', ..., '48w') 
# and values as the respective scores
for week_key, scores in weekly_scores.items():
    # Convert scores for the current week into a DataFrame
    weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    
# Create DataFrame variables dynamically for 48 weeks
for week in range(1, 49):
    week_key = f'{week}w'
    globals()[f'df_scores_{week_key}'] = weekly_scores_dfs.get(week_key, pd.DataFrame())

# %%
# Initialize a dictionary to hold the top 2 ETFs for each week
top_etfs_weekly = {}

# Loop through the weekly DataFrames and select the top 2 ETFs for each week
for week_key, df_scores in weekly_scores_dfs.items():
    # Select the top 2 ETFs based on the 'Score' column
    top_etfs_weekly[week_key] = df_scores.nlargest(2, 'SmoothedScore')
    
    # Print the results for the current week
    print(f"\nTop 2 ETFs for {week_key} forecast:")
    print(top_etfs_weekly[week_key])
# Out:
# Top 2 ETFs for 1w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0  SMH   1w             0.1  1.646795       1.646795
# 9  IXN   1w             0.1  1.394608       1.175217
#
# Top 2 ETFs for 2w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM   2w             0.1  3.465493       1.051561
# 9  IXN   2w             0.1  0.479823       0.937214
#
# Top 2 ETFs for 3w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   3w             0.1  5.433687       5.433687
# 1  SOXX   3w             0.1  1.873097       4.721569
#
# Top 2 ETFs for 4w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN   4w             0.1  2.694837       1.451195
# 8  IGM   4w             0.1  4.603237       1.140285
#
# Top 2 ETFs for 5w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   5w             0.1  3.185559       3.185559
# 1  SOXX   5w             0.1 -3.127433       1.922961
#
# Top 2 ETFs for 6w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   6w             0.1  2.617966       2.617966
# 1  SOXX   6w             0.1 -2.141076       1.666158
#
# Top 2 ETFs for 7w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 2  PSI   7w             0.1  5.849144       0.962621
# 3  XSD   7w             0.1  0.831802       0.936457
#
# Top 2 ETFs for 8w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH   8w             0.1  3.545373       3.545373
# 1  SOXX   8w             0.1  0.333994       2.903098
#
# Top 2 ETFs for 9w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 2  PSI   9w             0.1  7.869714       1.594550
# 3  XSD   9w             0.1  0.754468       1.426533
#
# Top 2 ETFs for 10w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  10w             0.1  4.269780       4.269780
# 1  SOXX  10w             0.1  1.174955       3.650815
#
# Top 2 ETFs for 11w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  11w             0.1  2.733137       1.124204
# 8  IGM  11w             0.1  1.507710       0.721971
#
# Top 2 ETFs for 12w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  12w             0.1  1.690988       0.796544
# 8  IGM  12w             0.1  2.886512       0.572934
#
# Top 2 ETFs for 13w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3  XSD  13w             0.1  7.750681       1.329468
# 4  IYW  13w             0.1 -3.620125       0.339550
#
# Top 2 ETFs for 14w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  14w             0.1  1.568151       0.243569
# 9  IXN  14w             0.1 -0.326715       0.129512
#
# Top 2 ETFs for 15w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  15w             0.1  7.764005       0.785817
# 8   IGM  15w             0.1 -1.642138       0.300226
#
# Top 2 ETFs for 16w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  16w             0.1  2.165835       0.517374
# 9  IXN  16w             0.1 -0.016467       0.410606
#
# Top 2 ETFs for 17w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3  XSD  17w             0.1  2.822176       1.423171
# 2  PSI  17w             0.1  4.417587       1.073420
#
# Top 2 ETFs for 18w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9   IXN  18w             0.1  2.376939       0.593494
# 7  FTEC  18w             0.1  4.814870       0.264293
#
# Top 2 ETFs for 19w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  19w             0.1  7.095056       0.459646
# 8   IGM  19w             0.1  0.083122       0.384341
#
# Top 2 ETFs for 20w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  20w             0.1  5.490372       0.464010
# 8   IGM  20w             0.1 -0.018431       0.367521
#
# Top 2 ETFs for 21w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0   SMH  21w             0.1  3.150564       3.150564
# 1  SOXX  21w             0.1  1.020784       2.724608
#
# Top 2 ETFs for 22w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  22w             0.1  1.741676       0.147917
# 3   XSD  22w             0.1  6.623854       0.143010
#
# Top 2 ETFs for 23w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  23w             0.1  5.830799       1.367487
# 0  SMH  23w             0.1  0.570429       0.570429
#
# Top 2 ETFs for 24w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  24w             0.1  0.954158       0.541006
# 8  IGM  24w             0.1  0.969537       0.437718
#
# Top 2 ETFs for 25w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  25w             0.1  2.315795       0.664742
# 8  IGM  25w             0.1  1.430153       0.251978
#
# Top 2 ETFs for 26w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  26w             0.1  0.680700       0.031190
# 7  FTEC  26w             0.1  3.374318      -0.131188
#
# Top 2 ETFs for 27w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9   IXN  27w             0.1  2.785437       0.754228
# 7  FTEC  27w             0.1  4.459188       0.329757
#
# Top 2 ETFs for 28w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3  XSD  28w             0.1  9.566700       1.873064
# 4  IYW  28w             0.1 -2.848481       0.928755
#
# Top 2 ETFs for 29w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  29w             0.1  3.814459       0.313133
# 8   IGM  29w             0.1 -0.477278       0.155051
#
# Top 2 ETFs for 30w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  30w             0.1   8.76621       0.698375
# 8   IGM  30w             0.1  -0.66262       0.426176
#
# Top 2 ETFs for 31w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9   IXN  31w             0.1  3.175030       1.006482
# 7  FTEC  31w             0.1  7.328494       0.608761
#
# Top 2 ETFs for 32w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8   IGM  32w             0.1  0.383631       0.157133
# 7  FTEC  32w             0.1  4.276658       0.100508
#
# Top 2 ETFs for 33w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  33w             0.1  5.069220       0.994661
# 9   IXN  33w             0.1  2.015913       0.540912
#
# Top 2 ETFs for 34w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  34w             0.1  5.097162       0.271785
# 9   IXN  34w             0.1  0.298199       0.261736
#
# Top 2 ETFs for 35w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  35w             0.1  4.072812       0.193715
# 8   IGM  35w             0.1  0.062562       0.167485
#
# Top 2 ETFs for 36w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  36w             0.1  2.032933       0.323555
# 9  IXN  36w             0.1 -1.049156       0.049013
#
# Top 2 ETFs for 37w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  37w             0.1  2.485364       0.357762
# 9   IXN  37w             0.1  0.593081       0.150442
#
# Top 2 ETFs for 38w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  38w             0.1  3.121245       0.784037
# 9  IXN  38w             0.1 -0.772916       0.472646
#
# Top 2 ETFs for 39w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 3   XSD  39w             0.1  5.542619       1.089064
# 7  FTEC  39w             0.1  4.322647       0.702631
#
# Top 2 ETFs for 40w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  40w             0.1  5.044265       1.388872
# 9  IXN  40w             0.1 -1.690527       0.772992
#
# Top 2 ETFs for 41w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 0  SMH  41w             0.1  3.208480       3.208480
# 2  PSI  41w             0.1  7.867317       3.157873
#
# Top 2 ETFs for 42w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9   IXN  42w             0.1  1.681082       0.552417
# 7  FTEC  42w             0.1  3.573826       0.419286
#
# Top 2 ETFs for 43w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  43w             0.1  8.440887       1.351545
# 8   IGM  43w             0.1 -2.660952       0.549045
#
# Top 2 ETFs for 44w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 8  IGM  44w             0.1  4.255979       1.145932
# 9  IXN  44w             0.1 -1.805978       0.555550
#
# Top 2 ETFs for 45w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  45w             0.1  6.036689       0.486831
# 8   IGM  45w             0.1 -0.891087       0.211247
#
# Top 2 ETFs for 46w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  46w             0.1   0.83250       0.506994
# 8  IGM  46w             0.1   0.84563       0.425617
#
# Top 2 ETFs for 47w forecast:
#     ETF Week  RiskPercentage  RawScore  SmoothedScore
# 7  FTEC  47w             0.1  4.270633       0.058475
# 8   IGM  47w             0.1 -1.450147      -0.243250
#
# Top 2 ETFs for 48w forecast:
#    ETF Week  RiskPercentage  RawScore  SmoothedScore
# 9  IXN  48w             0.1 -0.320312      -0.367220
# 8  IGM  48w             0.1  0.138339      -0.378947

# %%
# Function to generate week ranges
def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []
    
    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)
    
    return week_ranges

# Function to gather ETF data for weeks
def gather_etf_data_for_weeks(tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date)
            if etf_data.empty:
                print(f"No data found for {ticker} in {week}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[week][ticker] = etf_data
            #print(f"Data for {ticker} in {week} gathered.")
    return etf_histories

# Function to initialize shares for the first week
def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]
    
    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)
        
        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]
            
            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st week: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares

# Function to manage ETF portfolio weekly
def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares

# %%
# Generate Week Ranges
week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')
#print("Generated Week Ranges:", week_ranges)

# Assuming `tickers` is a list of ETF tickers
tickers = tickers

# Gather ETF Data
etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)
#print(f"ETF Histories Collected for {len(etf_histories)} weeks")

# Create a mapping between week numbers and date ranges
week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

# Debug: Print the week key mapping
print("Week Key Mapping:", week_key_mapping)

# Align `top_etfs_weekly` Keys with `etf_histories`
aligned_top_etfs_weekly = {}

for week_key, df_scores in weekly_scores_dfs.items():
    # Call the `select_top_etfs_weekly` function here
    forecast_period = week_key_mapping.get(week_key, None)
    if forecast_period:
        aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

# Portfolio initialization and management
ticker_shares = {}
ticker_shares_per_week = {}

for i, week_range in enumerate(etf_histories.keys()):
    current_week_key = week_range
    if i == 0:
        # First week initialization
        ticker_shares = initialize_shares_for_first_week(
            aligned_top_etfs_weekly[current_week_key],
            etf_histories,
            current_week_key
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()
    else:
        # Subsequent weeks' portfolio management
        prev_week_key = list(etf_histories.keys())[i - 1]
        ticker_shares = manage_etf_portfolio_weekly(
            aligned_top_etfs_weekly[prev_week_key],
            aligned_top_etfs_weekly[current_week_key],
            prev_week_key,
            current_week_key,
            ticker_shares,
            etf_histories
        )
        ticker_shares_per_week[current_week_key] = ticker_shares.copy()

print("\nFinal Ticker Shares per Week:")
for week, shares in ticker_shares_per_week.items():
    print(f"Week {week}: {shares}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Week Key Mapping: {'1w': '2024-01-01 to 2024-01-07', '2w': '2024-01-08 to 2024-01-14', '3w': '2024-01-15 to 2024-01-21', '4w': '2024-01-22 to 2024-01-28', '5w': '2024-01-29 to 2024-02-04', '6w': '2024-02-05 to 2024-02-11', '7w': '2024-02-12 to 2024-02-18', '8w': '2024-02-19 to 2024-02-25', '9w': '2024-02-26 to 2024-03-03', '10w': '2024-03-04 to 2024-03-10', '11w': '2024-03-11 to 2024-03-17', '12w': '2024-03-18 to 2024-03-24', '13w': '2024-03-25 to 2024-03-31', '14w': '2024-04-01 to 2024-04-07', '15w': '2024-04-08 to 2024-04-14', '16w': '2024-04-15 to 2024-04-21', '17w': '2024-04-22 to 2024-04-28', '18w': '2024-04-29 to 2024-05-05', '19w': '2024-05-06 to 2024-05-12', '20w': '2024-05-13 to 2024-05-19', '21w': '2024-05-20 to 2024-05-26', '22w': '2024-05-27 to 2024-06-02', '23w': '2024-06-03 to 2024-06-09', '24w': '2024-06-10 to 2024-06-16', '25w': '2024-06-17 to 2024-06-23', '26w': '2024-06-24 to 2024-06-30', '27w': '2024-07-01 to 2024-07-07', '28w': '2024-07-08 to 2024-07-14', '29w': '2024-07-15 to 2024-07-21', '30w': '2024-07-22 to 2024-07-28', '31w': '2024-07-29 to 2024-08-04', '32w': '2024-08-05 to 2024-08-11', '33w': '2024-08-12 to 2024-08-18', '34w': '2024-08-19 to 2024-08-25', '35w': '2024-08-26 to 2024-09-01', '36w': '2024-09-02 to 2024-09-08', '37w': '2024-09-09 to 2024-09-15', '38w': '2024-09-16 to 2024-09-22', '39w': '2024-09-23 to 2024-09-29', '40w': '2024-09-30 to 2024-10-06', '41w': '2024-10-07 to 2024-10-13', '42w': '2024-10-14 to 2024-10-20', '43w': '2024-10-21 to 2024-10-27', '44w': '2024-10-28 to 2024-11-03', '45w': '2024-11-04 to 2024-11-10', '46w': '2024-11-11 to 2024-11-17', '47w': '2024-11-18 to 2024-11-24', '48w': '2024-11-25 to 2024-12-01'}
# Shares 1st week: (50000 * 0.975) / 168.97000122070312
# Ticker: SMH, First trading day: 2024-01-02, Price: 168.97000122070312, Shares: 288.51
# Shares 1st week: (50000 * 0.975) / 66.30999755859375
# Ticker: IXN, First trading day: 2024-01-02, Price: 66.30999755859375, Shares: 735.18
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['SMH', 'IXN']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'IXN']
# Sell SMH: 288.51 shares at 171.96. Total value: 48372.34
# Buy IGM: 639.63 shares at 73.74.
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'IXN': 735.1832573500377, 'IGM': 639.6287990166064}
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['IGM', 'IXN']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Sell IGM: 639.63 shares at 75.45. Total value: 47052.45
# Buy SMH: 261.10 shares at 175.70.
# Sell IXN: 735.18 shares at 67.81. Total value: 48606.46
# Buy SOXX: 251.51 shares at 188.43.
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'SMH': 261.1049707992722, 'SOXX': 251.50610819993273}
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IXN', 'IGM']
# Sell SMH: 261.10 shares at 188.05. Total value: 47873.27
# Buy IXN: 659.64 shares at 70.76.
# Sell SOXX: 251.51 shares at 201.07. Total value: 49305.26
# Buy IGM: 611.24 shares at 78.65.
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'IXN': 659.6443981457811, 'IGM': 611.2351699164236}
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IXN', 'IGM']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'SOXX']
# Sell IXN: 659.64 shares at 71.84. Total value: 46204.13
# Buy SMH: 236.50 shares at 190.48.
# Sell IGM: 611.24 shares at 80.60. Total value: 48034.91
# Buy SOXX: 232.62 shares at 201.33.
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'SMH': 236.5026650155563, 'SOXX': 232.62324277936696}
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'SMH': 236.5026650155563, 'SOXX': 232.62324277936696}
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'XSD']
# Sell SMH: 236.50 shares at 203.06. Total value: 46823.62
# Buy PSI: 866.61 shares at 52.68.
# Sell SOXX: 232.62 shares at 209.43. Total value: 47500.33
# Buy XSD: 204.45 shares at 226.52.
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'PSI': 866.6103631600455, 'XSD': 204.45354884303475}
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['PSI', 'XSD']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'SOXX']
# Sell PSI: 866.61 shares at 51.59. Total value: 43590.72
# Buy SMH: 214.89 shares at 197.78.
# Sell XSD: 204.45 shares at 217.39. Total value: 43335.00
# Buy SOXX: 206.24 shares at 204.87.
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'SMH': 214.89003114356692, 'SOXX': 206.23963932832538}
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Sell SMH: 214.89 shares at 210.35. Total value: 44072.07
# Buy PSI: 805.89 shares at 53.32.
# Sell SOXX: 206.24 shares at 214.25. Total value: 43082.17
# Buy XSD: 190.30 shares at 220.73.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'PSI': 805.8939415799555, 'XSD': 190.30090236735379}
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['PSI', 'XSD']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Sell PSI: 805.89 shares at 56.78. Total value: 44614.69
# Buy SMH: 194.12 shares at 224.09.
# Sell XSD: 190.30 shares at 231.79. Total value: 43007.10
# Buy SOXX: 183.24 shares at 228.84.
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'SMH': 194.11541808962406, 'SOXX': 183.23685527903754}
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['IXN', 'IGM']
# Sell SMH: 194.12 shares at 220.98. Total value: 41823.23
# Buy IXN: 553.14 shares at 73.72.
# Sell SOXX: 183.24 shares at 225.10. Total value: 40215.45
# Buy IGM: 461.78 shares at 84.91.
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'IXN': 553.1423241593849, 'IGM': 461.78381609102064}
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['IXN', 'IGM']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IXN', 'IGM']
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'IXN': 553.1423241593849, 'IGM': 461.78381609102064}
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IXN', 'IGM']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'IYW']
# Sell IXN: 553.14 shares at 75.16. Total value: 40534.82
# Buy XSD: 174.72 shares at 226.20.
# Sell IGM: 461.78 shares at 86.60. Total value: 38990.72
# Buy IYW: 279.73 shares at 135.90.
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'XSD': 174.7190740457844, 'IYW': 279.73472874454905}
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['XSD', 'IYW']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'IXN']
# Sell XSD: 174.72 shares at 233.86. Total value: 39838.31
# Buy IGM: 448.22 shares at 86.66.
# Sell IYW: 279.73 shares at 135.55. Total value: 36970.09
# Buy IXN: 480.29 shares at 75.05.
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'IGM': 448.2154207264114, 'IXN': 480.29098573762246}
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['IGM', 'IXN']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IGM']
# Sell IXN: 480.29 shares at 74.10. Total value: 34699.82
# Buy FTEC: 219.92 shares at 153.84.
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'IGM': 448.2154207264114, 'FTEC': 219.91892567578932}
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'IXN']
# Sell FTEC: 219.92 shares at 149.81. Total value: 32122.40
# Buy IXN: 432.23 shares at 72.46.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'IGM': 448.2154207264114, 'IXN': 432.22940535387215}
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['IGM', 'IXN']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'PSI']
# Sell IGM: 448.22 shares at 80.88. Total value: 35345.37
# Buy XSD: 166.79 shares at 206.62.
# Sell IXN: 432.23 shares at 69.38. Total value: 29238.37
# Buy PSI: 560.18 shares at 50.89.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'XSD': 166.78800213227177, 'PSI': 560.1771290476694}
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['XSD', 'PSI']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'FTEC']
# Sell XSD: 166.79 shares at 228.64. Total value: 37181.05
# Buy IXN: 503.14 shares at 72.05.
# Sell PSI: 560.18 shares at 55.04. Total value: 30061.35
# Buy FTEC: 195.02 shares at 150.29.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'IXN': 503.14393810416044, 'FTEC': 195.02171544193766}
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'IGM']
# Sell IXN: 503.14 shares at 73.87. Total value: 36238.06
# Buy IGM: 413.48 shares at 85.45.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'FTEC': 195.02171544193766, 'IGM': 413.48288677123566}
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['FTEC', 'IGM']
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'FTEC': 195.02171544193766, 'IGM': 413.48288677123566}
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Sell FTEC: 195.02 shares at 160.26. Total value: 30472.82
# Buy SMH: 126.43 shares at 235.00.
# Sell IGM: 413.48 shares at 88.89. Total value: 35835.63
# Buy SOXX: 149.79 shares at 233.26.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'SMH': 126.42980406412815, 'SOXX': 149.7888247293749}
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['SMH', 'SOXX']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'XSD']
# Sell SMH: 126.43 shares at 249.83. Total value: 30796.31
# Buy FTEC: 183.34 shares at 163.77.
# Sell SOXX: 149.79 shares at 242.59. Total value: 35428.84
# Buy XSD: 138.60 shares at 249.23.
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'FTEC': 183.3449393193375, 'XSD': 138.59935925295972}
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'XSD']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'SMH']
# Sell FTEC: 183.34 shares at 159.71. Total value: 28549.97
# Buy IXN: 361.23 shares at 77.06.
# Sell XSD: 138.60 shares at 245.69. Total value: 33201.16
# Buy SMH: 132.95 shares at 243.48.
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'IXN': 361.22790761092415, 'SMH': 132.95193212451892}
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['IXN', 'SMH']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['IXN', 'IGM']
# Sell SMH: 132.95 shares at 255.86. Total value: 33166.65
# Buy IGM: 357.32 shares at 90.50.
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'IXN': 361.22790761092415, 'IGM': 357.32030981985713}
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['IXN', 'IGM']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['IXN', 'IGM']
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'IXN': 361.22790761092415, 'IGM': 357.32030981985713}
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['IXN', 'IGM']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IGM', 'FTEC']
# Sell IXN: 361.23 shares at 81.49. Total value: 28700.55
# Buy FTEC: 166.11 shares at 168.46.
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'IGM': 357.32030981985713, 'FTEC': 166.11085730566143}
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IXN', 'FTEC']
# Sell IGM: 357.32 shares at 94.93. Total value: 33072.41
# Buy IXN: 385.62 shares at 83.62.
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'FTEC': 166.11085730566143, 'IXN': 385.62061068875664}
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'IYW']
# Sell IXN: 385.62 shares at 86.54. Total value: 32537.32
# Buy XSD: 121.69 shares at 260.69.
# Sell FTEC: 166.11 shares at 178.66. Total value: 28935.43
# Buy IYW: 179.74 shares at 156.96.
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'XSD': 121.69198879838257, 'IYW': 179.74034915296622}
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['XSD', 'IYW']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'IGM']
# Sell XSD: 121.69 shares at 268.80. Total value: 31893.03
# Buy FTEC: 173.25 shares at 179.48.
# Sell IYW: 179.74 shares at 156.68. Total value: 27457.67
# Buy IGM: 274.60 shares at 97.49.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'FTEC': 173.25445643940574, 'IGM': 274.6049073635762}
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'IGM']
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'FTEC': 173.25445643940574, 'IGM': 274.6049073635762}
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IXN', 'FTEC']
# Sell IGM: 274.60 shares at 90.35. Total value: 24190.29
# Buy IXN: 298.89 shares at 78.91.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'FTEC': 173.25445643940574, 'IXN': 298.8915323057703}
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['IGM', 'FTEC']
# Sell IXN: 298.89 shares at 73.00. Total value: 21273.60
# Buy IGM: 246.84 shares at 84.03.
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'FTEC': 173.25445643940574, 'IGM': 246.83761743284626}
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['IGM', 'FTEC']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['FTEC', 'IXN']
# Sell IGM: 246.84 shares at 88.03. Total value: 21185.89
# Buy IXN: 269.77 shares at 76.57.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'FTEC': 173.25445643940574, 'IXN': 269.7693637525923}
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'IXN']
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'FTEC': 173.25445643940574, 'IXN': 269.7693637525923}
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IGM']
# Sell IXN: 269.77 shares at 81.40. Total value: 21410.25
# Buy IGM: 224.41 shares at 93.02.
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'FTEC': 173.25445643940574, 'IGM': 224.41400301034903}
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'IXN']
# Sell FTEC: 173.25 shares at 163.10. Total value: 27551.36
# Buy IXN: 346.17 shares at 77.60.
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'IGM': 224.41400301034903, 'IXN': 346.1671960388578}
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'IXN']
# Sell IGM: 224.41 shares at 87.89. Total value: 19230.65
# Buy FTEC: 116.79 shares at 160.54.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'IXN': 346.1671960388578, 'FTEC': 116.79262105378805}
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'IXN']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IXN']
# Sell FTEC: 116.79 shares at 168.10. Total value: 19142.02
# Buy IGM: 202.23 shares at 92.29.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'IXN': 346.1671960388578, 'IGM': 202.22633694267245}
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['IGM', 'IXN']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Sell IGM: 202.23 shares at 94.58. Total value: 18648.40
# Buy XSD: 78.43 shares at 231.84.
# Sell IXN: 346.17 shares at 81.54. Total value: 27520.81
# Buy FTEC: 156.58 shares at 171.37.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'XSD': 78.42560966263927, 'FTEC': 156.57811821383615}
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['XSD', 'FTEC']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IXN']
# Sell XSD: 78.43 shares at 240.25. Total value: 18370.71
# Buy IGM: 186.69 shares at 95.94.
# Sell FTEC: 156.58 shares at 174.50. Total value: 26639.81
# Buy IXN: 314.72 shares at 82.53.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'IGM': 186.6941914220468, 'IXN': 314.71967444681536}
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IGM', 'IXN']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'PSI']
# Sell IGM: 186.69 shares at 95.46. Total value: 17376.28
# Buy SMH: 68.25 shares at 248.22.
# Sell IXN: 314.72 shares at 81.20. Total value: 24916.36
# Buy PSI: 424.34 shares at 57.25.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'SMH': 68.25346279061066, 'PSI': 424.33968204854875}
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['SMH', 'PSI']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IXN', 'FTEC']
# Sell SMH: 68.25 shares at 261.28. Total value: 17387.43
# Buy IXN: 200.60 shares at 84.51.
# Sell PSI: 424.34 shares at 60.18. Total value: 24898.34
# Buy FTEC: 134.25 shares at 180.83.
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'IXN': 200.60048281594635, 'FTEC': 134.24699616202653}
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IXN', 'FTEC']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'IGM']
# Sell IXN: 200.60 shares at 84.01. Total value: 16431.14
# Buy IGM: 162.91 shares at 98.34.
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'FTEC': 134.24699616202653, 'IGM': 162.90785048156135}
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IXN']
# Sell FTEC: 134.25 shares at 179.26. Total value: 23463.49
# Buy IXN: 274.76 shares at 83.26.
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'IGM': 162.90785048156135, 'IXN': 274.7645942258828}
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['IGM', 'IXN']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['FTEC', 'IGM']
# Sell IXN: 274.76 shares at 80.79. Total value: 21643.28
# Buy FTEC: 121.19 shares at 174.13.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'IGM': 162.90785048156135, 'FTEC': 121.18643272995276}
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IXN', 'IGM']
# Sell FTEC: 121.19 shares at 185.07. Total value: 21867.27
# Buy IXN: 253.85 shares at 83.99.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'IGM': 162.90785048156135, 'IXN': 253.84680699253184}
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['IXN', 'IGM']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['FTEC', 'IGM']
# Sell IXN: 253.85 shares at 82.30. Total value: 20369.30
# Buy FTEC: 110.41 shares at 179.88.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'IGM': 162.90785048156135, 'FTEC': 110.40732736922784}
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['FTEC', 'IGM']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['IXN', 'IGM']
# Sell FTEC: 110.41 shares at 184.91. Total value: 19905.03
# Buy IXN: 232.15 shares at 83.60.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'IGM': 162.90785048156135, 'IXN': 232.14603270399024}
#
# Final Ticker Shares per Week:
# Week 2024-01-01 to 2024-01-07: {'SMH': 288.51275165894293, 'IXN': 735.1832573500377}
# Week 2024-01-08 to 2024-01-14: {'IXN': 735.1832573500377, 'IGM': 639.6287990166064}
# Week 2024-01-15 to 2024-01-21: {'SMH': 261.1049707992722, 'SOXX': 251.50610819993273}
# Week 2024-01-22 to 2024-01-28: {'IXN': 659.6443981457811, 'IGM': 611.2351699164236}
# Week 2024-01-29 to 2024-02-04: {'SMH': 236.5026650155563, 'SOXX': 232.62324277936696}
# Week 2024-02-05 to 2024-02-11: {'SMH': 236.5026650155563, 'SOXX': 232.62324277936696}
# Week 2024-02-12 to 2024-02-18: {'PSI': 866.6103631600455, 'XSD': 204.45354884303475}
# Week 2024-02-19 to 2024-02-25: {'SMH': 214.89003114356692, 'SOXX': 206.23963932832538}
# Week 2024-02-26 to 2024-03-03: {'PSI': 805.8939415799555, 'XSD': 190.30090236735379}
# Week 2024-03-04 to 2024-03-10: {'SMH': 194.11541808962406, 'SOXX': 183.23685527903754}
# Week 2024-03-11 to 2024-03-17: {'IXN': 553.1423241593849, 'IGM': 461.78381609102064}
# Week 2024-03-18 to 2024-03-24: {'IXN': 553.1423241593849, 'IGM': 461.78381609102064}
# Week 2024-03-25 to 2024-03-31: {'XSD': 174.7190740457844, 'IYW': 279.73472874454905}
# Week 2024-04-01 to 2024-04-07: {'IGM': 448.2154207264114, 'IXN': 480.29098573762246}
# Week 2024-04-08 to 2024-04-14: {'IGM': 448.2154207264114, 'FTEC': 219.91892567578932}
# Week 2024-04-15 to 2024-04-21: {'IGM': 448.2154207264114, 'IXN': 432.22940535387215}
# Week 2024-04-22 to 2024-04-28: {'XSD': 166.78800213227177, 'PSI': 560.1771290476694}
# Week 2024-04-29 to 2024-05-05: {'IXN': 503.14393810416044, 'FTEC': 195.02171544193766}
# Week 2024-05-06 to 2024-05-12: {'FTEC': 195.02171544193766, 'IGM': 413.48288677123566}
# Week 2024-05-13 to 2024-05-19: {'FTEC': 195.02171544193766, 'IGM': 413.48288677123566}
# Week 2024-05-20 to 2024-05-26: {'SMH': 126.42980406412815, 'SOXX': 149.7888247293749}
# Week 2024-05-27 to 2024-06-02: {'FTEC': 183.3449393193375, 'XSD': 138.59935925295972}
# Week 2024-06-03 to 2024-06-09: {'IXN': 361.22790761092415, 'SMH': 132.95193212451892}
# Week 2024-06-10 to 2024-06-16: {'IXN': 361.22790761092415, 'IGM': 357.32030981985713}
# Week 2024-06-17 to 2024-06-23: {'IXN': 361.22790761092415, 'IGM': 357.32030981985713}
# Week 2024-06-24 to 2024-06-30: {'IGM': 357.32030981985713, 'FTEC': 166.11085730566143}
# Week 2024-07-01 to 2024-07-07: {'FTEC': 166.11085730566143, 'IXN': 385.62061068875664}
# Week 2024-07-08 to 2024-07-14: {'XSD': 121.69198879838257, 'IYW': 179.74034915296622}
# Week 2024-07-15 to 2024-07-21: {'FTEC': 173.25445643940574, 'IGM': 274.6049073635762}
# Week 2024-07-22 to 2024-07-28: {'FTEC': 173.25445643940574, 'IGM': 274.6049073635762}
# Week 2024-07-29 to 2024-08-04: {'FTEC': 173.25445643940574, 'IXN': 298.8915323057703}
# Week 2024-08-05 to 2024-08-11: {'FTEC': 173.25445643940574, 'IGM': 246.83761743284626}
# Week 2024-08-12 to 2024-08-18: {'FTEC': 173.25445643940574, 'IXN': 269.7693637525923}
# Week 2024-08-19 to 2024-08-25: {'FTEC': 173.25445643940574, 'IXN': 269.7693637525923}
# Week 2024-08-26 to 2024-09-01: {'FTEC': 173.25445643940574, 'IGM': 224.41400301034903}
# Week 2024-09-02 to 2024-09-08: {'IGM': 224.41400301034903, 'IXN': 346.1671960388578}
# Week 2024-09-09 to 2024-09-15: {'IXN': 346.1671960388578, 'FTEC': 116.79262105378805}
# Week 2024-09-16 to 2024-09-22: {'IXN': 346.1671960388578, 'IGM': 202.22633694267245}
# Week 2024-09-23 to 2024-09-29: {'XSD': 78.42560966263927, 'FTEC': 156.57811821383615}
# Week 2024-09-30 to 2024-10-06: {'IGM': 186.6941914220468, 'IXN': 314.71967444681536}
# Week 2024-10-07 to 2024-10-13: {'SMH': 68.25346279061066, 'PSI': 424.33968204854875}
# Week 2024-10-14 to 2024-10-20: {'IXN': 200.60048281594635, 'FTEC': 134.24699616202653}
# Week 2024-10-21 to 2024-10-27: {'FTEC': 134.24699616202653, 'IGM': 162.90785048156135}
# Week 2024-10-28 to 2024-11-03: {'IGM': 162.90785048156135, 'IXN': 274.7645942258828}
# Week 2024-11-04 to 2024-11-10: {'IGM': 162.90785048156135, 'FTEC': 121.18643272995276}
# Week 2024-11-11 to 2024-11-17: {'IGM': 162.90785048156135, 'IXN': 253.84680699253184}
# Week 2024-11-18 to 2024-11-24: {'IGM': 162.90785048156135, 'FTEC': 110.40732736922784}
# Week 2024-11-25 to 2024-12-01: {'IGM': 162.90785048156135, 'IXN': 232.14603270399024}

# %%
# Define the first trading day of the 48th week
first_trading_day_49w = '2024-12-01'  # Adjust this to match the actual start date of the 48th week

# Identify the 48th and 49th week date range keys
week_48_range = list(ticker_shares_per_week.keys())[-1]  # Last key corresponds to the 48th week
week_49_start = first_trading_day_49w  # Replace with the actual start of the 49th week
print(f"Using data for the 48th week: {week_48_range}")

print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

week_49_end = '2024-12-06'
# Initialize a dictionary to store the values of shares
etf_values_49w = {}

# Ensure 48th week data exists
if week_48_range in ticker_shares_per_week:
    # Fetch ETF shares from the 48th week
    ticker_shares_48w = ticker_shares_per_week[week_48_range]
    
    # Fetch the first trading day price of the 49th week for each ETF
    for ticker, shares in ticker_shares_48w.items():
        print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
        # Download historical data for the 49th week
        data = yf.download(ticker, start=week_49_start, end=week_49_end)
        
        if not data.empty:
            # Get the closing price of the first trading day of the 49th week
            closing_price_49w = data['Close'].iloc[0]
            # Calculate the value of the shares
            total_value = shares * closing_price_49w
            etf_values_49w[ticker] = total_value
            print(f"{ticker}: {shares:.2f} shares at {closing_price_49w:.2f} each, total value: {total_value:.2f}")
        else:
            print(f"{ticker}: No data available for the 49th week's first trading day.")
else:
    print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker IGM starting from 2024-12-01...
# IGM: 162.91 shares at 102.51 each, total value: 16699.68
# Fetching data for ticker IXN starting from 2024-12-01...
# IXN: 232.15 shares at 84.80 each, total value: 19685.98

# %%
# Check if there are any values in the dictionary
if etf_values_49w:
    print("\nETF values on the 49th week's first trading day:")
    # Sum all the values (total portfolio value)
    total_value = sum(etf_values_49w.values())
    print(f"Total portfolio value: {total_value:.2f}")
    # Optionally display individual ETF values
    for ticker, value in etf_values_49w.items():
        print(f"{ticker}: {value:.2f}")
else:
    print("No values could be calculated for the 49th week's first trading day.")
# Out:
# ETF values on the 49th week's first trading day:
# Total portfolio value: 36385.67
# IGM: 16699.68
# IXN: 19685.98
