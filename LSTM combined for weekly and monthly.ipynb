# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
#import os
#os.environ["TF_USE_LEGACY_KERAS"] = "True"

# %%
#!pip uninstall tensorflow tensorflow-macos tensorflow-metal -y
#!pip uninstall tensorflow -y
#!pip install --upgrade tensorflow

# %%
#!pip install tensorflow==2.13.0
#!pip install tensorflow
#!pip install tf_keras

# %%
#pip show tensorflow
#!pip show tensorflow

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler, Normalizer
import pandas_ta as ta
from pandas.tseries.offsets import MonthEnd, BDay, Week
from itertools import product
from sklearn.metrics import mean_absolute_error

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from datetime import datetime, timedelta
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from xgboost import XGBRegressor
#from skopt import BayesSearchCV

from skopt.space import Real, Integer, Categorical


from tensorflow.keras.models import Sequential

#from tensorflow.keras.optimizers.legacy import Adam as LegacyAdam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from skopt import gp_minimize

from sklearn.metrics import mean_squared_error
from bayes_opt import BayesianOptimization

import tensorflow as tf
#from tensorflow.keras.optimizers.legacy import Adam
import time
#from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.optimizers.legacy import RMSprop

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, Bidirectional

# %%
# Function for loading ETF data
def data_loading(ticker_symbol, start_date, end_date):
    etf_data = yf.Ticker(ticker_symbol)
    etf_history = etf_data.history(start=start_date, end=end_date)
    etf_history.index = etf_history.index.tz_localize(None)
    return etf_history, etf_data

#Function to derive the predictor columns
def etf_predictors(etf_history,  start_date, end_date, etf_data, benchmark_ticker = '^GSPC' ):
    
    # Calculate Daily Returns
    etf_history['Daily Return'] = etf_history['Close'].pct_change()

    # Calculate 21-Day Volatility (standard deviation of daily returns, annualized)
    etf_history['Volatility'] = etf_history['Daily Return'].rolling(window=21).std() * np.sqrt(252)
    #etf_history['Volatility_ta'] = ta.volatility(etf_history['Close'], window=21, annualize=True)
   
    # Get the ETF info
    etf_info = etf_data.info

    # Retrieve the net asset value price (NAV) and total net assets
    nav_price = etf_info['navPrice']
    total_assets = etf_info['totalAssets']

    # Calculate the number of shares outstanding
    shares_outstanding = total_assets / nav_price

    # Calculate Market Capitalization for each day
    # Market Capitalization = Closing Price * Total Number of Shares Outstanding
    etf_history['Market Cap'] = etf_history['Close'] * shares_outstanding

    total_assets = etf_info['totalAssets']
    total_liabilities = etf_info.get('totalLiabilities', 0)  # Handle the case where total liabilities might not be present
    
    # Calculate Book Value per Share
    book_value_per_share = (total_assets - total_liabilities) / shares_outstanding
    
    # Calculate Price to Book (P/B) Ratio
    etf_history['P/B Ratio'] = etf_history['Close'] / book_value_per_share
    
    # Calculate 1-Month Momentum (21 trading days)
    
    etf_history['Momentum'] = ta.mom(etf_history['Close'], length=21)
    
    benchmark_data = yf.download(benchmark_ticker, start=start_date, end=end_date)
    benchmark_data['Daily Return'] = benchmark_data['Close'].pct_change()
    #benchmark_data_history = benchmark_data.dropna()
    benchmark_data.head(10)
    
    # Ensure the indices are time zone-naive
    benchmark_data.index = benchmark_data.index.tz_localize(None)
    combined_data = etf_history[['Close']].join(benchmark_data[['Close']], lsuffix='_ETF', rsuffix='_Benchmark')
    combined_data = combined_data.dropna()
    
    # Calculate rolling beta with a 30-day window
    rolling_beta_21 = rolling_beta(combined_data, window=21)

    # Add the rolling beta to the dataframe
    combined_data.loc[:, 'Rolling Beta 21-day'] = rolling_beta_21
    etf_history['Rolling Beta']=combined_data['Rolling Beta 21-day']
    
    # Calculate daily profitability
    daily_profitabilities = []
    previous_nav = None
    for index, row in etf_history.iterrows():
        current_nav = row['Close']  # Current day's NAV
        #print(current_nav)
        if previous_nav is not None:
            daily_profitability = (current_nav - previous_nav) / previous_nav * 100
            daily_profitabilities.append(daily_profitability)
        else:
            daily_profitabilities.append(None)
        previous_nav = current_nav  # Update previous_nav for the next iteration

    # Add daily profitabilities to ETF dataset
    etf_history['Daily Profitability (%)'] = daily_profitabilities
    
    # Calculate the dividend yield for each day
    dividend_yields = []

    for index, row in etf_history.iterrows():
        # Get the dividend payment for the day
        dividend_payment = row['Dividends']

        # Get the current market price of the ETF for the day
        current_price = row['Close']

        # Calculate the dividend yield for the day
        dividend_yield = (dividend_payment / current_price) * 100

        # Append the dividend yield to the list
        dividend_yields.append(dividend_yield)
      
    etf_history['Div yield'] = dividend_yields

    #Volatility
    etf_history['ATR'] = ta.atr(etf_history['High'], etf_history['Low'], etf_history['Close'], length=21)    
    
    # Compute the Relative Volatility Index (RVI)
    rvi = ta.rvi(etf_history['Close'],length=21)
    etf_history['RVI'] = rvi
    
    #Momentum
    rsi_window = 14  # Window size for RSI calculation
    roc_window = 12  # Window size for ROC calculation
    #rsi_window = 21  
    #roc_window = 21  

    

    etf_history['RSI'] = ta.rsi(etf_history['Close'],length=rsi_window)
    # Calculate Rate of Change (ROC)
    etf_history['ROC'] = ta.roc(etf_history['Close'], length=roc_window)
        
    etf_history['log_returns'] = np.log(etf_history['Close'] / etf_history['Close'].shift(1))

    return etf_history

# Function to calculate rolling beta
def rolling_beta(df, window):
    rolling_cov = df['Close_Benchmark'].rolling(window=window).cov(df['Close_ETF'])
    rolling_var = df['Close_Benchmark'].rolling(window=window).var()
    rolling_beta = rolling_cov / rolling_var
    return rolling_beta

# %%
def pre_processing(
    etf_history, 
    train_start_date,
    train_end_date,
    test_start_date,
    test_end_date,
    prediction_dates_monthly,
    prediction_dates_weekly,
    feature_columns=None,
    scaling_strategy='StandardScaler', 
    final_end_date='2024-12-01'
):
    """
    Preprocess ETF history data and prepare train/test splits along with 
    dynamically scaled forecast data for both weekly & monthly horizons,
    stored in separate dictionaries.

    Parameters
    ----------
    etf_history : pd.DataFrame
        Full historical data with at least 'log_returns' column plus other features.
    train_start_date : str
        Start date (YYYY-MM-DD) for training data.
    train_end_date : str
        End date (YYYY-MM-DD) for training data.
    test_start_date : str
        Start date (YYYY-MM-DD) for test data.
    test_end_date : str
        End date (YYYY-MM-DD) for test data.
    prediction_dates_monthly : list of str
        List of start dates for each monthly forecast window.
    prediction_dates_weekly : list of str
        List of start dates for each weekly forecast window.
    feature_columns : list of str, optional
        Columns to be used as features. If None, defaults are used.
    scaling_strategy : str, optional
        'StandardScaler' or 'Normalizer'. Defaults to 'StandardScaler'.
    final_end_date : str, optional
        The final end date (YYYY-MM-DD) for the last forecast window.
        Defaults to '2024-12-01'.

    Returns
    -------
    dict
        A dictionary containing:
        - 'train_data_scaled': np.ndarray
        - 'test_data_scaled': np.ndarray
        - 'y_train': pd.Series
        - 'y_test': pd.Series
        - 'scaler': scaler object
        - 'X': pd.DataFrame (all feature columns before splitting)
        - 'etf_history': pd.DataFrame (original data with missing values handled)
        - 'forecast_data_weekly': dict of weekly forecast DataFrame slices
        - 'forecast_data_monthly': dict of monthly forecast DataFrame slices
        - 'forecast_data_weekly_scaled': dict of scaled weekly forecast slices
        - 'forecast_data_monthly_scaled': dict of scaled monthly forecast slices
    """

    # 1. Handle missing values and infinite values
    etf_history.fillna(etf_history.median(), inplace=True)
    etf_history.replace([np.inf, -np.inf], 0, inplace=True)

    # 2. Default feature columns if none are provided
    if feature_columns is None:
        feature_columns = [
            'Volatility', 'Volume', 'Daily Return', 'Market Cap', 
            'P/B Ratio', 'Momentum', 'Rolling Beta', 
            'Daily Profitability (%)', 'ATR', 'RVI', 'RSI', 'ROC'
        ]

    # 3. Select features (X) and target (y)
    X = etf_history.loc[:, feature_columns]
    y = etf_history['log_returns']

    # 4. Split train and test data
    train_data = X.loc[train_start_date : train_end_date]
    test_data  = X.loc[test_start_date  : test_end_date]
    y_train = y.loc[train_start_date : train_end_date]
    y_test  = y.loc[test_start_date  : test_end_date]

    # 5. Initialize and fit scaler
    if scaling_strategy == 'StandardScaler':
        scaler = StandardScaler()
    elif scaling_strategy == 'Normalizer':
        scaler = Normalizer()
    else:
        raise ValueError(f"Unsupported scaling strategy: {scaling_strategy}")

    train_data_scaled = scaler.fit_transform(train_data)
    test_data_scaled  = scaler.transform(test_data)

    # 6. Create separate dictionaries for weekly and monthly
    forecast_data_weekly = {}
    forecast_data_monthly = {}

    # ---- Weekly Forecast Slices ----
    for i, start_date in enumerate(prediction_dates_weekly):
        if i < len(prediction_dates_weekly) - 1:
            weekly_end = (pd.to_datetime(start_date) + Week(1) - pd.Timedelta(days=1)).strftime('%Y-%m-%d')
        else:
            weekly_end = final_end_date
        
        w_key = f'forecast_data_{i+1}w'
        forecast_data_weekly[w_key] = X.loc[start_date : weekly_end]

    # ---- Monthly Forecast Slices ----
    for i, start_date in enumerate(prediction_dates_monthly):
        if i < len(prediction_dates_monthly) - 1:
            monthly_end = (pd.to_datetime(start_date) + MonthEnd(0)).strftime('%Y-%m-%d')
        else:
            monthly_end = final_end_date
        
        m_key = f'forecast_data_{i+1}m'
        forecast_data_monthly[m_key] = X.loc[start_date : monthly_end]

    # 7. Scale forecast data (weekly & monthly) and add intercept
    forecast_data_weekly_scaled = {}
    for period_key, period_data in forecast_data_weekly.items():
        if not period_data.empty:
            data_scaled = scaler.transform(period_data)
            forecast_data_weekly_scaled[period_key] = sm.add_constant(data_scaled)

    forecast_data_monthly_scaled = {}
    for period_key, period_data in forecast_data_monthly.items():
        if not period_data.empty:
            data_scaled = scaler.transform(period_data)
            forecast_data_monthly_scaled[period_key] = sm.add_constant(data_scaled)

    # 8. Add a constant to train and test data
    train_data_scaled = sm.add_constant(train_data_scaled)
    test_data_scaled  = sm.add_constant(test_data_scaled)

    # 9. Return all objects in a dictionary
    return {
        'train_data_scaled': train_data_scaled,
        'test_data_scaled': test_data_scaled,
        'y_train': y_train,
        'y_test': y_test,
        'scaler': scaler,
        'X': X,
        'etf_history': etf_history,
        'forecast_data_weekly': forecast_data_weekly,
        'forecast_data_monthly': forecast_data_monthly,
        'forecast_data_weekly_scaled': forecast_data_weekly_scaled,
        'forecast_data_monthly_scaled': forecast_data_monthly_scaled
    }

# %%
def build_and_train_lstm_model(epochs, batch_size, units, dropout_rate, learning_rate, train_data_scaled, y_train, validation_split=0.2):
    train_data_reshaped = reshape_for_lstm(train_data_scaled)
    
    # Debug data shapes
    print("train_data_reshaped shape:", train_data_reshaped.shape)
    print("y_train shape:", y_train.shape)

    # Ensure y_train is a NumPy array and reshape to 2D if necessary
    if isinstance(y_train, pd.Series):
        y_train = y_train.to_numpy()
    if len(y_train.shape) == 1:
        y_train = y_train.reshape(-1, 1)

    # Ensure the number of samples matches
    assert train_data_reshaped.shape[0] == y_train.shape[0], "Mismatch in samples between train_data_reshaped and y_train"
    
    model = Sequential()
    
    # First LSTM layer
    model.add(Bidirectional(LSTM(units=int(units), return_sequences=True, input_shape=(train_data_reshaped.shape[1], train_data_reshaped.shape[2]))))
    model.add(Dropout(dropout_rate))
    
    """# Second Bidirectional LSTM layer
    model.add(Bidirectional(LSTM(units=int(units / 2), return_sequences=True)))
    model.add(Dropout(dropout_rate))"""
    
    # Third Bidirectional LSTM layer
    model.add(Bidirectional(LSTM(units=int(units / 2), return_sequences=False)))
    model.add(Dropout(dropout_rate))
    
    
    model.add(Dense(units=int(units / 2), activation='relu'))
    model.add(Dropout(dropout_rate))
    
    # Additional Dense hidden layer
    model.add(Dense(units=int(units / 4), activation='relu'))
    model.add(Dropout(dropout_rate))
    
    # Output layer
    model.add(Dense(1, activation='linear'))
    
    optimizer = RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    # Early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    
     # Track the start time
    #start_time = time.time()
    
    model.fit(train_data_reshaped, y_train, 
              epochs=int(epochs), 
              batch_size=int(batch_size), 
              validation_split=validation_split, 
              callbacks=[early_stopping],
              verbose=0)
    
    # Calculate time consumed
    #time_consumed = time.time() - start_time
    
    return model



def optimize_hyperparameters(train_data_scaled, y_train, test_data_scaled, y_test):
    def objective_function(epochs, batch_size, units, dropout_rate, learning_rate):
        # Build and train the LSTM model
        model = build_and_train_lstm_model(epochs, batch_size, units, dropout_rate, learning_rate, train_data_scaled, y_train)
        test_data_reshaped = reshape_for_lstm(test_data_scaled)
        test_predictions = make_predictions(model, test_data_reshaped)
        mse = mean_squared_error(y_test, test_predictions)
        return -mse  # Negative MSE because we maximize in Bayesian Optimization

    # Define parameter bounds
    
    param_bounds = {
        
        'batch_size': (16, 64),
        'dropout_rate': (0.1, 0.5),
        'epochs': (10, 50),
        'learning_rate': (1e-4, 5e-3),
        'units': (32, 128),
    }#change in bounds

    # Initialize Bayesian optimizer
    optimizer = BayesianOptimization(
        f=objective_function,
        pbounds=param_bounds,
        verbose=2,
        random_state=42,
    )

    # Manual initialization points
    """manual_init_points = [
        {"batch_size":36.99,"dropout_rate":0.1174,"epochs":44.65,"learning_rate":0.000641,"units":85.4},
        {"batch_size":54.8,"dropout_rate":0.2914,"epochs":11.95,"learning_rate":0.003453,"units":74.25},
        {"batch_size":44.44,"dropout_rate":0.1814,"epochs":43.15,"learning_rate":0.0004211,"units":64.05},
        {"batch_size":63.03,"dropout_rate":0.3325,"epochs":47.58,"learning_rate":0.0009053,"units":79.89},
        {"batch_size":51.58,"dropout_rate":0.1418,"epochs":21.69,"learning_rate":0.0004297,"units":72.8},
        {"batch_size":51.44,"dropout_rate":0.1512,"epochs":12.6,"learning_rate":0.000954,"units":98.28},
        {"batch_size":49.37,"dropout_rate":0.1423,"epochs":42.09,"learning_rate":0.0001671,"units":99.34},
        {"batch_size":36.99,"dropout_rate":0.1174,"epochs":44.65,"learning_rate":0.000641,"units":85.4},
        {"batch_size":37.87,"dropout_rate":0.1913,"epochs":30.99,"learning_rate":0.0004888,"units":64.56},
        {"batch_size":51.58,"dropout_rate":0.1418,"epochs":21.69,"learning_rate":0.0004297,"units":72.8},
        {"batch_size":51.44,"dropout_rate":0.1512,"epochs":12.6,"learning_rate":0.000954,"units":98.28},
        {"batch_size":56.71,"dropout_rate":0.1596,"epochs":10.22,"learning_rate":0.0008339,"units":85.34},
        {"batch_size":63.03,"dropout_rate":0.3325,"epochs":47.58,"learning_rate":0.0009053,"units":79.89},
        {"batch_size":51.58,"dropout_rate":0.1418,"epochs":21.69,"learning_rate":0.0004297,"units":72.8},
        {"batch_size":36.99,"dropout_rate":0.1174,"epochs":44.65,"learning_rate":0.000641,"units":85.4}
    ]"""
    
    manual_init_points = [
    {"batch_size": 18.29, "dropout_rate": 0.1512, "epochs": 20.78, "learning_rate": 0.0008453, "units": 64.32},
    {"batch_size": 24.47, "dropout_rate": 0.2516, "epochs": 30.12, "learning_rate": 0.0020432, "units": 96.87},
    {"batch_size": 32.94, "dropout_rate": 0.3518, "epochs": 40.56, "learning_rate": 0.0035234, "units": 128.00},  # Clipped units to 128
    {"batch_size": 48.11, "dropout_rate": 0.1021, "epochs": 15.34, "learning_rate": 0.0010457, "units": 72.23},
    {"batch_size": 52.76, "dropout_rate": 0.2049, "epochs": 50.00, "learning_rate": 0.0041342, "units": 85.92},  # Clipped epochs to 50
    {"batch_size": 60.84, "dropout_rate": 0.3012, "epochs": 35.21, "learning_rate": 0.0025347, "units": 100.65},
    {"batch_size": 64.00, "dropout_rate": 0.1814, "epochs": 25.89, "learning_rate": 0.0007346, "units": 80.47},  # Clipped batch_size to 64
    {"batch_size": 36.12, "dropout_rate": 0.2217, "epochs": 45.33, "learning_rate": 0.0012678, "units": 68.55},
    {"batch_size": 40.75, "dropout_rate": 0.2835, "epochs": 28.16, "learning_rate": 0.0031432, "units": 120.43},
    {"batch_size": 42.67, "dropout_rate": 0.3214, "epochs": 18.44, "learning_rate": 0.0045123, "units": 60.34},
    {"batch_size": 56.89, "dropout_rate": 0.1637, "epochs": 38.27, "learning_rate": 0.0022345, "units": 90.21},
    {"batch_size": 44.92, "dropout_rate": 0.1219, "epochs": 12.78, "learning_rate": 0.0015124, "units": 77.36},
    {"batch_size": 50.47, "dropout_rate": 0.2418, "epochs": 42.55, "learning_rate": 0.0009567, "units": 92.78},
    {"batch_size": 58.64, "dropout_rate": 0.2612, "epochs": 33.12, "learning_rate": 0.0038346, "units": 104.56},
    {"batch_size": 30.11, "dropout_rate": 0.1412, "epochs": 22.78, "learning_rate": 0.0018234, "units": 74.62},
]


    # Add manual initialization points
    for point in manual_init_points:
        optimizer.probe(params=point, lazy=False)

    # Run the optimization process
    n_iter = 50  # Number of additional iterations
    optimizer.maximize(init_points=0, n_iter=n_iter)  # Set init_points=0 since we added manual points

    # Display initialization points results
    print("\nInitialization Points Results:")
    for i, result in enumerate(optimizer.res[:len(manual_init_points)]):
        print(f"Point {i + 1}: {result}")

    # Return the best parameters found
    best_params = optimizer.max['params']
    return best_params
def make_predictions(model, data_scaled):
    if len(data_scaled.shape) == 2:
        data_scaled = np.reshape(data_scaled, (data_scaled.shape[0], 1, data_scaled.shape[1]))
    elif len(data_scaled.shape) != 3:
        raise ValueError(f"Unexpected shape for input data: {data_scaled.shape}")
    
    predictions = model.predict(data_scaled)
    return predictions

"""def eval_model(best_model,test_data_scaled,y_test,y_train):
    
    test_predictions = best_model.predict((test_data_scaled))
    mae = mean_absolute_error(y_test, test_predictions)
    # Mean Absolute Scaled Error (MASE) - Example calculation assuming seasonal period m=1
    seasonal_naive = np.roll(y_test, 1)  # Shift y_test by 1 for seasonal naive forecast
    #seasonal_mae = np.mean(np.abs(y_test - seasonal_naive))
    seasonal_mae = np.mean(np.abs(y_test[1:] - seasonal_naive[1:]))
    mase = mae / seasonal_mae

    # Mean Absolute Percentage Error (MAPE)
    #mape = np.mean(np.abs((y_test - test_predictions) / y_test)) * 100

    #n = y_test.shape[0]
    #d = np.abs(  np.diff( y_test) ).sum()/(n-1)
    
    #errors = np.abs(y_test - test_predictions )
    #mase_value = errors.mean()/d

    print("Mean Absolute Error (MAE):", mae)
    print("Mean Absolute Scaled Error (MASE):", mase)
    #print("Mean Absolute Scaled Error-2 (MASE-2):", mase_value)
    #print("Mean Absolute Percentage Error (MAPE):", mape)
    
    return mae, mase"""

def eval_model(best_model, test_data_scaled, y_test, y_train=None):
    # Reshape test data to match LSTM input requirements
    test_data_reshaped = test_data_scaled.reshape((test_data_scaled.shape[0], 1, test_data_scaled.shape[1]))
    
    # Make predictions
    test_predictions = best_model.predict(test_data_reshaped)
    
    # Calculate Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_test, test_predictions)
    
    # Calculate Mean Absolute Scaled Error (MASE) - Example calculation assuming seasonal period m=1
    naive_forecast = y_test.shift(1).fillna(method='bfill')
    mase = mae / mean_absolute_error(y_test, naive_forecast)
    print("mae: ",mae)
    print("mase: ",mase)
    return mae, mase

# Function to make predictions
def predictions(model, forecast_data_scaled, original_forecast_data):
    forecast_results = {}
    for key, data in forecast_data_scaled.items():
        # Reshape data for compatibility with the LSTM model
        if len(data.shape) == 2:
            data = data.reshape((data.shape[0], 1, data.shape[1]))
        
        # Make predictions
        predictions = model.predict(data)
        
        # Use the index from the corresponding original forecast DataFrame
        original_index = original_forecast_data[key].index
        
        # Create a DataFrame for the predictions
        forecast_results[key] = pd.DataFrame(
            predictions, 
            columns=["log_returns"], 
            index=original_index
        )
    return forecast_results



def calculate_mase(y_true, y_pred, naive_forecast):
    # Calculate the MAE of the model's predictions
    mae_model = mean_absolute_error(y_true, y_pred)
    
    # Calculate the MAE of the naive forecast
    mae_naive = mean_absolute_error(y_true, naive_forecast)
    
    # Calculate MASE
    mase = mae_model / mae_naive
    return mase

def reshape_for_lstm(data):
    return np.reshape(data, (data.shape[0], 1, data.shape[1]))  # Reshape into (samples, time_steps, features)

# %%
def combined_workflow(
    tickers,
    start_date, 
    end_date, 
    train_start_date, 
    train_end_date, 
    test_start_date, 
    test_end_date,
    prediction_dates_monthly, 
    prediction_dates_weekly
):
    etf_results = {}
    
    for ticker in tickers:
        
        print(ticker)
        # 1. Load and preprocess data
        etf_history, etf_data = data_loading(ticker, start_date, end_date)
        etf_history = etf_predictors(etf_history, start_date, end_date, etf_data)

        # 2. Single call to pre_processing for training/testing & both forecast horizons
        preprocessed = pre_processing(
            etf_history=etf_history, 
            train_start_date=train_start_date, 
            train_end_date=train_end_date,
            test_start_date=test_start_date, 
            test_end_date=test_end_date,
            prediction_dates_monthly=prediction_dates_monthly,
            prediction_dates_weekly=prediction_dates_weekly
        )
        
        # 3. Train the model
        #model = model_training(preprocessed['train_data_scaled'], preprocessed['y_train'])
        
        # Track the start time
        start_time = time.time()


        # Optimize hyperparameters
        best_params = optimize_hyperparameters(preprocessed['train_data_scaled'], preprocessed['y_train'], preprocessed['test_data_scaled'], preprocessed['y_test'])

        # Extract the best hyperparameters
        best_epochs = int(best_params['epochs'])
        best_batch_size = int(best_params['batch_size'])
        best_units = int(best_params['units'])
        best_dropout_rate = best_params['dropout_rate']
        best_learning_rate = best_params['learning_rate']

        # Train the final model using the best hyperparameters
        model = build_and_train_lstm_model(
            epochs=best_epochs, 
            batch_size=best_batch_size, 
            units=best_units, 
            dropout_rate=best_dropout_rate, 
            learning_rate=best_learning_rate, 
            train_data_scaled=preprocessed['train_data_scaled'], 
            y_train=preprocessed['y_train']
        )


        # Calculate time consumed
        time_consumed = time.time() - start_time

        # Print the time consumed
        print(f"Time consumed for training: {time_consumed:.2f} seconds")
        
        # 4. Evaluate the model
        mae, mase = eval_model(
            model, 
            preprocessed['test_data_scaled'], 
            preprocessed['y_test'], 
            preprocessed['y_train']
        )
        
        # 5. Generate predictions for monthly forecasts
        monthly_forecast_results = predictions(
            model,
            preprocessed['forecast_data_monthly_scaled'],
            preprocessed['forecast_data_monthly']  # Pass unscaled forecast data for index preservation
        )
        # 6. Generate predictions for weekly forecasts

        weekly_forecast_results = predictions(
            model,
            preprocessed['forecast_data_weekly_scaled'],
            preprocessed['forecast_data_weekly']  # Pass unscaled forecast data for index preservation
        )


        # ---------------------------------------------------------------------
        # 7. Build your final dictionary in the desired format
        # ---------------------------------------------------------------------

        # A. Basic structure
        dict_data = {
            "etf_history": etf_history,              # The full ETF dataframe (with predictors, etc.)
            "X": preprocessed["X"],                 # All feature columns used
            "y_train_values": preprocessed["y_train"],  # Training target values

            # Store model performance
            "model results": {
                "mae": mae,
                "mase": mase
            },
        }

        # B. Store monthly forecast predictions in separate keys
        #    Suppose you want up to 12 monthly periods; adjust as needed
        for i_m in range(1, 13):
            # The keys produced by predictions(...) might look like 'forecast_data_1m', 'forecast_data_2m', etc.
            forecast_key = f"forecast_data_{i_m}m"

            if forecast_key in monthly_forecast_results:
                # monthly_forecast_results[forecast_key] might be a DataFrame with 'log_returns'
                df_forecast = monthly_forecast_results[forecast_key]
                
                # e.g. store array of predicted 'log_returns' (or your final target variable)
                dict_data[f"forecast_predictions_df_{i_m}m"] = df_forecast["log_returns"].values
            
            # If a given month's key doesn't exist, you might skip it or handle differently

        # C. Store weekly forecast predictions similarly, if desired
        #    For example, suppose you do up to 48 weekly windows
        for i_w in range(1, 49):
            forecast_key = f"forecast_data_{i_w}w"
            if forecast_key in weekly_forecast_results:
                df_forecast = weekly_forecast_results[forecast_key]
                dict_data[f"forecast_predictions_df_{i_w}w"] = df_forecast["log_returns"].values

        # Finally, store this dictionary per ticker
        etf_results[ticker] = dict_data
    
    return etf_results

# %%
import pandas as pd

# Example usage
tickers = ['SMH', 'SOXX', 'PSI', 'XSD', 'IYW', 'XLK', 'VGT', 'FTEC', 'IGM', 'IXN']
start_date, end_date = '2000-01-01', '2024-12-01'
train_start_date, train_end_date, test_start_date, test_end_date = (
    start_date,         # train_start_date
    '2014-01-01',       # train_end_date
    '2014-01-01',       # test_start_date
    '2024-01-01'        # test_end_date
)

# Generate prediction dates for monthly & weekly
prediction_dates_monthly = pd.date_range(
    start='2024-01-01', 
    periods=12, 
    freq='MS'
).strftime('%Y-%m-%d').tolist()

prediction_dates_weekly = pd.date_range(
    start='2024-01-01', 
    periods=48, 
    freq='W-MON'
).strftime('%Y-%m-%d').tolist()

# Run the workflow
results = combined_workflow(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date,
    train_start_date=train_start_date,
    train_end_date=train_end_date,
    test_start_date=test_start_date,
    test_end_date=test_end_date,
    prediction_dates_monthly=prediction_dates_monthly,
    prediction_dates_weekly=prediction_dates_weekly
)

# The 'results' object is a dictionary keyed by ticker.
# For each ticker (e.g. 'SMH' or 'SOXX'), to inspect:
#   results[ticker]["etf_history"]
#   results[ticker]["X"]
#   results[ticker]["y_train_values"]
#   results[ticker]["model results"]
#   results[ticker]["forecast_predictions_df_1m"], etc.
#
# Example:
# Print the first monthly forecast predictions for 'SMH'
#print(results['SMH']['forecast_predictions_df_1m'])
# Out:
# SMH
# [*********************100%%**********************]  1 of 1 completed
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 560us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 1ms/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 730us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 470us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 554us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 588us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 496us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 592us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 582us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 434us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 553us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 504us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 533us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 598us/step
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 485us/step
# |   iter    |  target   | batch_... | dropou... |  epochs   | learni... |   units   |
# -------------------------------------------------------------------------------------
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 574us/step
# | 1         | -0.000759 | 50.77     | 0.3444    | 42.25     | 0.002758  | 92.44     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 696us/step
# | 2         | -8.468e-0 | 40.98     | 0.1807    | 26.68     | 0.003147  | 116.6     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 606us/step
# | 3         | -0.000119 | 23.7      | 0.4625    | 48.23     | 0.001397  | 91.2      |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 583us/step
# | 4         | -0.000117 | 23.58     | 0.1499    | 41.97     | 0.000571  | 80.55     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 894us/step
# | 5         | -8.864e-0 | 56.64     | 0.2846    | 12.46     | 0.001727  | 126.2     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 540us/step
# | 6         | -0.000102 | 34.64     | 0.3653    | 33.95     | 0.00402   | 93.7      |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 571us/step
# | 7         | -5.097e-0 | 22.14     | 0.2963    | 27.68     | 0.00356   | 81.25     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 550us/step
# | 8         | -0.000221 | 62.5      | 0.211     | 29.76     | 0.001373  | 78.25     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 594us/step
# | 9         | -8.454e-0 | 21.27     | 0.1766    | 26.36     | 0.004788  | 93.74     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 529us/step
# | 10        | -0.000225 | 19.59     | 0.4225    | 38.99     | 0.003259  | 66.1      |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 478us/step
# | 11        | -0.000151 | 61.22     | 0.4277    | 15.32     | 0.002863  | 44.9      |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 695us/step
# | 12        | -0.000285 | 51.62     | 0.21      | 18.31     | 0.00478   | 112.0     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 661us/step
# | 13        | -0.000286 | 60.59     | 0.3742    | 28.84     | 0.004825  | 122.0     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 433us/step
# | 14        | -5.208e-0 | 49.84     | 0.1676    | 17.99     | 0.001629  | 52.25     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 667us/step
# | 15        | -0.000125 | 60.33     | 0.3046    | 36.15     | 0.002675  | 121.1     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 477us/step
# | 16        | -2.791e-0 | 58.72     | 0.1273    | 26.89     | 0.004178  | 65.65     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 669us/step
# | 17        | -4.149e-0 | 34.37     | 0.4911    | 12.35     | 0.004214  | 96.73     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 463us/step
# | 18        | -0.000369 | 37.82     | 0.4885    | 14.73     | 0.0007024 | 52.87     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 465us/step
# | 19        | -8.019e-0 | 52.84     | 0.178     | 13.81     | 0.004506  | 34.44     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 453us/step
# | 20        | -0.000114 | 60.05     | 0.2543    | 36.47     | 0.001503  | 46.91     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 458us/step
# | 21        | -7.187e-0 | 33.87     | 0.2605    | 46.74     | 0.003675  | 43.71     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 678us/step
# | 22        | -0.001053 | 43.18     | 0.304     | 30.67     | 0.004477  | 124.9     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 727us/step
# | 23        | -3.558e-0 | 37.93     | 0.4872    | 38.1      | 0.002079  | 121.9     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 1ms/step
# | 24        | -0.000306 | 41.92     | 0.3976    | 17.22     | 0.003848  | 61.17     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 460us/step
# | 25        | -0.000152 | 16.35     | 0.1541    | 37.46     | 0.00447   | 56.12     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 548us/step
# | 26        | -0.000139 | 54.91     | 0.2827    | 24.41     | 0.001897  | 84.53     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 542us/step
# | 27        | -0.000157 | 31.21     | 0.1942    | 21.29     | 0.002387  | 93.95     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 443us/step
# | 28        | -0.000113 | 21.3      | 0.2445    | 14.62     | 0.001593  | 36.56     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 471us/step
# | 29        | -3.761e-0 | 17.97     | 0.1445    | 20.53     | 0.002958  | 51.55     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 613us/step
# | 30        | -5.501e-0 | 54.42     | 0.1196    | 49.53     | 0.0005651 | 109.3     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 559us/step
# | 31        | -0.000148 | 44.51     | 0.1632    | 37.05     | 0.001539  | 94.92     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 627us/step
# | 32        | -0.000122 | 23.08     | 0.3362    | 20.29     | 0.003318  | 118.2     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 445us/step
# | 33        | -0.000107 | 40.69     | 0.2751    | 11.95     | 0.002147  | 32.07     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 454us/step
# | 34        | -0.000124 | 33.71     | 0.1512    | 25.35     | 0.003452  | 61.71     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 433us/step
# | 35        | -0.000150 | 56.53     | 0.2296    | 12.7      | 0.0009344 | 44.76     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 454us/step
# | 36        | -0.000115 | 44.2      | 0.349     | 39.33     | 0.003539  | 57.72     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 555us/step
# | 37        | -9.71e-05 | 57.01     | 0.447     | 33.56     | 0.003401  | 77.78     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 486us/step
# | 38        | -0.000121 | 53.68     | 0.1222    | 13.56     | 0.004297  | 58.2      |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 709us/step
# | 39        | -0.000165 | 19.29     | 0.3033    | 11.37     | 0.0007013 | 106.0     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 685us/step
# | 40        | -0.000147 | 35.52     | 0.2786    | 17.37     | 0.004601  | 109.3     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 1s 704us/step
# | 41        | -0.000141 | 18.16     | 0.2602    | 43.46     | 0.004801  | 70.33     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 673us/step
# | 42        | -0.000491 | 62.3      | 0.1479    | 28.71     | 0.003839  | 116.5     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 429us/step
# | 43        | -0.000187 | 34.69     | 0.3437    | 21.83     | 0.0006633 | 37.14     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 477us/step
# | 44        | -0.000102 | 40.77     | 0.3775    | 19.2      | 0.002849  | 71.58     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 592us/step
# | 45        | -0.000158 | 27.17     | 0.2619    | 30.27     | 0.0009099 | 116.7     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 479us/step
# | 46        | -0.00011  | 45.1      | 0.2971    | 40.9      | 0.00344   | 46.49     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 463us/step
# | 47        | -0.000741 | 20.0      | 0.4223    | 34.17     | 0.004721  | 63.01     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 464us/step
# | 48        | -0.000171 | 34.23     | 0.3448    | 46.45     | 0.004163  | 42.62     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 464us/step
# | 49        | -0.000137 | 27.59     | 0.4357    | 20.26     | 0.001218  | 44.62     |
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# 79/79 [==============================] - 0s 528us/step
# | 50        | -0.000171 | 51.28     | 0.4533    | 16.02     | 0.0007108 | 90.08     |
# =====================================================================================
#
# Initialization Points Results:
# Point 1: {'target': -7.077345183487497e-05, 'params': {'batch_size': 18.29, 'dropout_rate': 0.1512, 'epochs': 20.78, 'learning_rate': 0.0008453, 'units': 64.32}}
# Point 2: {'target': -3.259540457203845e-05, 'params': {'batch_size': 24.47, 'dropout_rate': 0.2516, 'epochs': 30.12, 'learning_rate': 0.0020432, 'units': 96.87}}
# Point 3: {'target': -0.00010560178253506882, 'params': {'batch_size': 32.94, 'dropout_rate': 0.3518, 'epochs': 40.56, 'learning_rate': 0.0035234, 'units': 128.0}}
# Point 4: {'target': -5.836399494128257e-05, 'params': {'batch_size': 48.11, 'dropout_rate': 0.1021, 'epochs': 15.34, 'learning_rate': 0.0010457, 'units': 72.23}}
# Point 5: {'target': -0.00010562574392507078, 'params': {'batch_size': 52.76, 'dropout_rate': 0.2049, 'epochs': 50.0, 'learning_rate': 0.0041342, 'units': 85.92}}
# Point 6: {'target': -8.613317336553094e-05, 'params': {'batch_size': 60.84, 'dropout_rate': 0.3012, 'epochs': 35.21, 'learning_rate': 0.0025347, 'units': 100.65}}
# Point 7: {'target': -9.975724642188839e-05, 'params': {'batch_size': 64.0, 'dropout_rate': 0.1814, 'epochs': 25.89, 'learning_rate': 0.0007346, 'units': 80.47}}
# Point 8: {'target': -6.978417510826884e-05, 'params': {'batch_size': 36.12, 'dropout_rate': 0.2217, 'epochs': 45.33, 'learning_rate': 0.0012678, 'units': 68.55}}
# Point 9: {'target': -0.00017789684770273513, 'params': {'batch_size': 40.75, 'dropout_rate': 0.2835, 'epochs': 28.16, 'learning_rate': 0.0031432, 'units': 120.43}}
# Point 10: {'target': -4.687876824623117e-05, 'params': {'batch_size': 42.67, 'dropout_rate': 0.3214, 'epochs': 18.44, 'learning_rate': 0.0045123, 'units': 60.34}}
# Point 11: {'target': -3.1572430610076075e-05, 'params': {'batch_size': 56.89, 'dropout_rate': 0.1637, 'epochs': 38.27, 'learning_rate': 0.0022345, 'units': 90.21}}
# Point 12: {'target': -0.00011271456726562767, 'params': {'batch_size': 44.92, 'dropout_rate': 0.1219, 'epochs': 12.78, 'learning_rate': 0.0015124, 'units': 77.36}}
# Point 13: {'target': -9.646332518041786e-05, 'params': {'batch_size': 50.47, 'dropout_rate': 0.2418, 'epochs': 42.55, 'learning_rate': 0.0009567, 'units': 92.78}}
# Point 14: {'target': -0.00018289693309224035, 'params': {'batch_size': 58.64, 'dropout_rate': 0.2612, 'epochs': 33.12, 'learning_rate': 0.0038346, 'units': 104.56}}
# Point 15: {'target': -0.00025222805315134635, 'params': {'batch_size': 30.11, 'dropout_rate': 0.1412, 'epochs': 22.78, 'learning_rate': 0.0018234, 'units': 74.62}}
# train_data_reshaped shape: (3415, 1, 13)
# y_train shape: (3415,)
# Time consumed for training: 333.91 seconds
# 79/79 [==============================] - 1s 583us/step
# mae:  0.010801158283040095
# mase:  0.5604789568542173
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_75238/440322928.py:193: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   naive_forecast = y_test.shift(1).fillna(method='bfill')
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# SOXX
# [*********************100%%**********************]  1 of 1 completed
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 568us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 710us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 801us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 746us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 539us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 580us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 513us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 535us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 708us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 456us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 615us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 518us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 547us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 594us/step
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 562us/step
# |   iter    |  target   | batch_... | dropou... |  epochs   | learni... |   units   |
# -------------------------------------------------------------------------------------
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 571us/step
# | 1         | -0.000451 | 16.88     | 0.1206    | 10.64     | 0.003134  | 85.77     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 695us/step
# | 2         | -0.000230 | 64.0      | 0.5       | 50.0      | 0.005     | 109.6     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 611us/step
# | 3         | -0.000206 | 16.47     | 0.2242    | 42.02     | 0.002899  | 115.4     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 735us/step
# | 4         | -0.000583 | 16.02     | 0.4051    | 19.92     | 0.003836  | 120.1     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 546us/step
# | 5         | -0.000259 | 27.64     | 0.2383    | 10.35     | 0.002444  | 48.04     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 650us/step
# | 6         | -0.000792 | 36.68     | 0.1515    | 49.51     | 0.004301  | 112.6     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 830us/step
# | 7         | -0.000227 | 63.79     | 0.2809    | 34.21     | 0.003405  | 127.8     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 566us/step
# | 8         | -0.000321 | 28.4      | 0.5       | 10.0      | 0.005     | 67.68     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 439us/step
# | 9         | -0.000305 | 48.39     | 0.4829    | 10.08     | 0.0006879 | 33.77     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 698us/step
# | 10        | -0.000265 | 62.0      | 0.1103    | 10.37     | 0.003636  | 127.6     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 631us/step
# | 11        | -0.000174 | 36.17     | 0.4665    | 11.69     | 0.004543  | 101.1     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 577us/step
# | 12        | -0.000149 | 64.0      | 0.5       | 50.0      | 0.005     | 92.76     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 454us/step
# | 13        | -0.000319 | 18.44     | 0.4599    | 24.78     | 0.004917  | 32.07     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 444us/step
# | 14        | -0.00086  | 63.96     | 0.2393    | 33.96     | 0.004204  | 32.12     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 448us/step
# | 15        | -0.000347 | 18.3      | 0.1992    | 48.58     | 0.00435   | 32.29     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 663us/step
# | 16        | -0.000219 | 19.82     | 0.4199    | 49.35     | 0.002842  | 127.9     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 731us/step
# | 17        | -0.000163 | 50.12     | 0.1       | 50.0      | 0.005     | 128.0     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 611us/step
# | 18        | -0.000240 | 52.86     | 0.2759    | 10.46     | 0.0018    | 109.2     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 427us/step
# | 19        | -0.000277 | 38.12     | 0.5       | 27.19     | 0.005     | 32.0      |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 699us/step
# | 20        | -0.000175 | 39.13     | 0.1238    | 10.03     | 0.003569  | 127.3     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 552us/step
# | 21        | -7.96e-05 | 16.43     | 0.2984    | 49.3      | 0.003645  | 99.01     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 463us/step
# | 22        | -0.000245 | 32.11     | 0.2443    | 11.08     | 0.001384  | 32.15     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 579us/step
# | 23        | -0.001103 | 64.0      | 0.1       | 10.0      | 0.0001    | 46.92     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 445us/step
# | 24        | -0.000280 | 40.91     | 0.4588    | 49.12     | 0.002204  | 33.35     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 453us/step
# | 25        | -0.000271 | 16.0      | 0.1       | 10.0      | 0.005     | 32.0      |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 502us/step
# | 26        | -0.000583 | 16.19     | 0.3653    | 27.03     | 0.001861  | 80.86     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 533us/step
# | 27        | -0.000283 | 16.3      | 0.1292    | 27.76     | 0.004118  | 48.3      |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 640us/step
# | 28        | -0.000203 | 20.28     | 0.2573    | 10.48     | 0.002344  | 104.3     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 763us/step
# | 29        | -0.000249 | 63.87     | 0.2718    | 48.87     | 0.001098  | 125.3     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 655us/step
# | 30        | -0.000222 | 31.86     | 0.4999    | 10.34     | 0.001974  | 85.41     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 487us/step
# | 31        | -0.000162 | 16.0      | 0.1       | 10.0      | 0.005     | 53.2      |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 632us/step
# | 32        | -0.000528 | 64.0      | 0.5       | 19.17     | 0.005     | 116.2     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 656us/step
# | 33        | -0.000740 | 32.56     | 0.3052    | 10.03     | 0.0004907 | 113.9     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 728us/step
# | 34        | -0.000124 | 16.05     | 0.311     | 34.87     | 0.004038  | 128.0     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 776us/step
# | 35        | -0.000179 | 51.48     | 0.1326    | 19.2      | 0.002895  | 127.6     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 561us/step
# | 36        | -0.000202 | 38.74     | 0.2206    | 23.18     | 0.002479  | 94.88     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 626us/step
# | 37        | -0.000379 | 16.22     | 0.1312    | 29.92     | 0.00158   | 105.3     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 455us/step
# | 38        | -0.000344 | 57.35     | 0.1444    | 49.6      | 0.0002428 | 32.59     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 893us/step
# | 39        | -0.000200 | 48.95     | 0.1185    | 36.46     | 0.00109   | 127.8     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 570us/step
# | 40        | -0.000334 | 42.13     | 0.5       | 10.0      | 0.005     | 49.06     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 586us/step
# | 41        | -0.001127 | 24.95     | 0.4805    | 19.25     | 0.002649  | 96.49     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 545us/step
# | 42        | -0.000236 | 46.0      | 0.5       | 10.0      | 0.005     | 93.8      |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 543us/step
# | 43        | -0.000163 | 26.26     | 0.2334    | 42.32     | 0.003195  | 98.76     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 526us/step
# | 44        | -0.000517 | 16.12     | 0.2676    | 36.93     | 0.0007027 | 92.39     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 459us/step
# | 45        | -0.000728 | 64.0      | 0.5       | 50.0      | 0.0001    | 51.03     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 458us/step
# | 46        | -0.000307 | 31.23     | 0.341     | 23.81     | 0.001472  | 44.74     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 589us/step
# | 47        | -0.000310 | 35.37     | 0.4866    | 32.03     | 0.001223  | 102.6     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 437us/step
# | 48        | -0.000379 | 26.95     | 0.2489    | 38.91     | 0.0008698 | 32.98     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 0s 635us/step
# | 49        | -0.000284 | 46.78     | 0.1618    | 21.26     | 0.00197   | 103.9     |
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# 79/79 [==============================] - 1s 776us/step
# | 50        | -0.000255 | 28.97     | 0.2538    | 27.79     | 0.001104  | 127.3     |
# =====================================================================================
#
# Initialization Points Results:
# Point 1: {'target': -0.0002401340516945694, 'params': {'batch_size': 18.29, 'dropout_rate': 0.1512, 'epochs': 20.78, 'learning_rate': 0.0008453, 'units': 64.32}}
# Point 2: {'target': -0.00020026618277207766, 'params': {'batch_size': 24.47, 'dropout_rate': 0.2516, 'epochs': 30.12, 'learning_rate': 0.0020432, 'units': 96.87}}
# Point 3: {'target': -0.0001153483758494349, 'params': {'batch_size': 32.94, 'dropout_rate': 0.3518, 'epochs': 40.56, 'learning_rate': 0.0035234, 'units': 128.0}}
# Point 4: {'target': -0.000798427644069376, 'params': {'batch_size': 48.11, 'dropout_rate': 0.1021, 'epochs': 15.34, 'learning_rate': 0.0010457, 'units': 72.23}}
# Point 5: {'target': -0.00015304973538823497, 'params': {'batch_size': 52.76, 'dropout_rate': 0.2049, 'epochs': 50.0, 'learning_rate': 0.0041342, 'units': 85.92}}
# Point 6: {'target': -0.00022356016269869383, 'params': {'batch_size': 60.84, 'dropout_rate': 0.3012, 'epochs': 35.21, 'learning_rate': 0.0025347, 'units': 100.65}}
# Point 7: {'target': -0.003032582090881605, 'params': {'batch_size': 64.0, 'dropout_rate': 0.1814, 'epochs': 25.89, 'learning_rate': 0.0007346, 'units': 80.47}}
# Point 8: {'target': -0.0032991197170245726, 'params': {'batch_size': 36.12, 'dropout_rate': 0.2217, 'epochs': 45.33, 'learning_rate': 0.0012678, 'units': 68.55}}
# Point 9: {'target': -0.00045801956149924916, 'params': {'batch_size': 40.75, 'dropout_rate': 0.2835, 'epochs': 28.16, 'learning_rate': 0.0031432, 'units': 120.43}}
# Point 10: {'target': -0.0003815967718274183, 'params': {'batch_size': 42.67, 'dropout_rate': 0.3214, 'epochs': 18.44, 'learning_rate': 0.0045123, 'units': 60.34}}
# Point 11: {'target': -0.000340372985581669, 'params': {'batch_size': 56.89, 'dropout_rate': 0.1637, 'epochs': 38.27, 'learning_rate': 0.0022345, 'units': 90.21}}
# Point 12: {'target': -0.00047364581031274553, 'params': {'batch_size': 44.92, 'dropout_rate': 0.1219, 'epochs': 12.78, 'learning_rate': 0.0015124, 'units': 77.36}}
# Point 13: {'target': -0.00038514321776860307, 'params': {'batch_size': 50.47, 'dropout_rate': 0.2418, 'epochs': 42.55, 'learning_rate': 0.0009567, 'units': 92.78}}
# Point 14: {'target': -0.00024093434210092075, 'params': {'batch_size': 58.64, 'dropout_rate': 0.2612, 'epochs': 33.12, 'learning_rate': 0.0038346, 'units': 104.56}}
# Point 15: {'target': -0.00026825551562963015, 'params': {'batch_size': 30.11, 'dropout_rate': 0.1412, 'epochs': 22.78, 'learning_rate': 0.0018234, 'units': 74.62}}
# train_data_reshaped shape: (3136, 1, 13)
# y_train shape: (3136,)
# Time consumed for training: 341.03 seconds
# 79/79 [==============================] - 1s 641us/step
# mae:  0.00911199816718438
# mase:  0.4672415567981035
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_75238/440322928.py:193: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   naive_forecast = y_test.shift(1).fillna(method='bfill')
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# PSI
# [*********************100%%**********************]  1 of 1 completed
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 479us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 641us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 691us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 522us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 2ms/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 2ms/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 552us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 614us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 812us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 526us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 533us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 495us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 636us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 585us/step
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 522us/step
# |   iter    |  target   | batch_... | dropou... |  epochs   | learni... |   units   |
# -------------------------------------------------------------------------------------
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 658us/step
# | 1         | -0.000226 | 39.52     | 0.2421    | 21.17     | 0.003406  | 106.7     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 661us/step
# | 2         | -0.000195 | 52.95     | 0.3474    | 16.05     | 0.002881  | 118.7     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 723us/step
# | 3         | -0.000363 | 34.3      | 0.157     | 10.28     | 0.003238  | 121.7     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 652us/step
# | 4         | -0.000279 | 58.75     | 0.172     | 31.7      | 0.0007226 | 124.3     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 563us/step
# | 5         | -0.000238 | 20.07     | 0.2267    | 10.54     | 0.002513  | 101.5     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 660us/step
# | 6         | -0.000249 | 18.16     | 0.2801    | 23.19     | 0.003204  | 114.2     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 579us/step
# | 7         | -0.000402 | 59.63     | 0.4826    | 48.69     | 0.0001597 | 115.0     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 484us/step
# | 8         | -0.000400 | 53.28     | 0.4804    | 10.44     | 0.001351  | 43.49     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 695us/step
# | 9         | -0.001916 | 39.9      | 0.1068    | 36.59     | 0.001127  | 107.8     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 720us/step
# | 10        | -0.000670 | 46.68     | 0.1795    | 21.15     | 0.0004067 | 127.9     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 629us/step
# | 11        | -0.000272 | 28.75     | 0.3309    | 15.76     | 0.001673  | 109.1     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 607us/step
# | 12        | -0.000494 | 44.63     | 0.4328    | 12.34     | 0.004433  | 111.8     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 591us/step
# | 13        | -0.000259 | 59.97     | 0.2315    | 22.76     | 0.0001322 | 113.6     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 552us/step
# | 14        | -0.000207 | 30.27     | 0.1974    | 17.59     | 0.00189   | 93.33     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 586us/step
# | 15        | -0.000225 | 16.82     | 0.1576    | 19.87     | 0.002299  | 89.9      |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 573us/step
# | 16        | -0.000304 | 16.31     | 0.1082    | 22.08     | 0.003671  | 101.8     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 465us/step
# | 17        | -0.000306 | 51.89     | 0.5       | 10.0      | 0.005     | 61.41     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 800us/step
# | 18        | -0.000465 | 23.98     | 0.1521    | 31.96     | 0.00359   | 83.24     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 832us/step
# | 19        | -0.000546 | 29.38     | 0.285     | 23.63     | 0.004261  | 122.5     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 600us/step
# | 20        | -0.000284 | 22.88     | 0.4983    | 10.67     | 0.002047  | 80.72     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 830us/step
# | 21        | -0.000271 | 63.21     | 0.1817    | 10.89     | 0.002654  | 125.3     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 536us/step
# | 22        | -0.000233 | 34.91     | 0.435     | 11.14     | 0.001999  | 67.21     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 483us/step
# | 23        | -0.000326 | 36.41     | 0.4349    | 10.16     | 0.001577  | 49.75     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 906us/step
# | 24        | -0.000313 | 17.11     | 0.1045    | 10.33     | 0.002417  | 118.3     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 604us/step
# | 25        | -0.000357 | 63.81     | 0.1146    | 10.4      | 0.00399   | 109.7     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 463us/step
# | 26        | -0.000232 | 39.98     | 0.3396    | 30.18     | 0.004889  | 47.77     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 436us/step
# | 27        | -0.000383 | 33.03     | 0.3392    | 24.25     | 0.0002846 | 36.47     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 451us/step
# | 28        | -0.000293 | 52.25     | 0.2196    | 36.44     | 0.004398  | 42.1      |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 471us/step
# | 29        | -0.000286 | 39.3      | 0.2897    | 43.77     | 0.003363  | 45.97     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 456us/step
# | 30        | -0.000471 | 49.01     | 0.1514    | 37.18     | 0.003357  | 56.79     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 502us/step
# | 31        | -0.000431 | 42.21     | 0.3201    | 37.92     | 0.001726  | 32.76     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 462us/step
# | 32        | -0.000280 | 26.34     | 0.4122    | 35.79     | 0.004596  | 51.28     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 442us/step
# | 33        | -0.000319 | 23.05     | 0.1589    | 48.49     | 0.003882  | 43.41     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 698us/step
# | 34        | -0.000202 | 41.72     | 0.4181    | 28.49     | 0.002192  | 122.0     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 447us/step
# | 35        | -0.000409 | 63.52     | 0.1935    | 49.84     | 0.003235  | 38.97     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 484us/step
# | 36        | -0.000311 | 16.69     | 0.4288    | 34.67     | 0.001479  | 36.2      |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 545us/step
# | 37        | -0.002029 | 62.13     | 0.1464    | 49.31     | 0.0002579 | 95.3      |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 535us/step
# | 38        | -0.000588 | 44.93     | 0.3219    | 44.71     | 0.00379   | 81.88     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 581us/step
# | 39        | -0.000254 | 39.91     | 0.3853    | 20.38     | 0.00201   | 69.99     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 485us/step
# | 40        | -0.000218 | 32.81     | 0.2205    | 24.88     | 0.002628  | 56.15     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 730us/step
# | 41        | -0.000184 | 37.46     | 0.4302    | 11.01     | 0.003135  | 98.37     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 540us/step
# | 42        | -0.000198 | 23.18     | 0.122     | 22.96     | 0.004136  | 46.31     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 456us/step
# | 43        | -0.000239 | 17.16     | 0.4925    | 17.58     | 0.002509  | 35.8      |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 0s 468us/step
# | 44        | -0.000247 | 22.24     | 0.3042    | 11.06     | 0.004185  | 46.81     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# 79/79 [==============================] - 1s 712us/step
# | 45        | -0.000268 | 30.0      | 0.1618    | 10.67     | 0.003786  | 34.13     |
# train_data_reshaped shape: (2146, 1, 13)
# y_train shape: (2146,)
# ...
# | 2         | -0.000292 | 58.35     | 0.1393    | 33.36     | 0.001013  | 104.8     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 626us/step
# | 3         | -8.397e-0 | 23.7      | 0.4625    | 48.23     | 0.001397  | 91.2      |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 916us/step
# | 4         | -0.000202 | 23.71     | 0.4733    | 48.24     | 0.00499   | 91.21     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 562us/step
# | 5         | -0.001083 | 23.66     | 0.4238    | 48.19     | 0.0001    | 91.16     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 595us/step
# | 6         | -0.000115 | 34.64     | 0.3653    | 33.95     | 0.00402   | 93.7      |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 524us/step
# | 7         | -0.000161 | 22.14     | 0.2963    | 27.68     | 0.00356   | 81.25     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 573us/step
# | 8         | -0.000172 | 62.5      | 0.211     | 29.76     | 0.001373  | 78.25     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 502us/step
# | 9         | -0.000103 | 52.87     | 0.2997    | 49.94     | 0.00352   | 86.38     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 476us/step
# | 10        | -0.000166 | 62.41     | 0.1883    | 29.85     | 0.0006113 | 78.0      |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 461us/step
# | 11        | -0.000145 | 61.22     | 0.4277    | 15.32     | 0.002863  | 44.9      |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 597us/step
# | 12        | -0.000183 | 51.62     | 0.21      | 18.31     | 0.00478   | 112.0     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 738us/step
# | 13        | -0.000155 | 60.59     | 0.3742    | 28.84     | 0.004825  | 122.0     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 468us/step
# | 14        | -0.000146 | 49.84     | 0.1676    | 17.99     | 0.001629  | 52.25     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 591us/step
# | 15        | -9.764e-0 | 23.7      | 0.4641    | 48.23     | 0.002707  | 91.2      |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 527us/step
# | 16        | -0.000115 | 58.72     | 0.1273    | 26.89     | 0.004178  | 65.65     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 531us/step
# | 17        | -0.000137 | 23.72     | 0.4881    | 48.25     | 0.0001    | 91.15     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 461us/step
# | 18        | -0.000244 | 37.82     | 0.4885    | 14.73     | 0.0007024 | 52.87     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 617us/step
# | 19        | -0.000171 | 52.84     | 0.178     | 13.81     | 0.004506  | 34.44     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 448us/step
# | 20        | -0.000148 | 60.05     | 0.2543    | 36.47     | 0.001503  | 46.91     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 609us/step
# | 21        | -0.000124 | 23.76     | 0.4973    | 48.3      | 0.0001    | 91.12     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 557us/step
# | 22        | -0.005733 | 23.73     | 0.5       | 48.26     | 0.0001    | 91.08     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 656us/step
# | 23        | -0.000171 | 23.76     | 0.4895    | 48.3      | 0.0001    | 91.17     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 493us/step
# | 24        | -0.000102 | 41.92     | 0.3976    | 17.22     | 0.003848  | 61.17     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 640us/step
# | 25        | -0.000166 | 23.73     | 0.4452    | 48.26     | 0.0001    | 91.18     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 636us/step
# | 26        | -0.000260 | 23.76     | 0.4527    | 48.29     | 0.0001    | 91.23     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 688us/step
# | 27        | -0.000371 | 31.21     | 0.1942    | 21.29     | 0.002387  | 93.95     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 916us/step
# | 28        | -0.001075 | 23.79     | 0.4986    | 48.33     | 0.0001    | 91.13     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 563us/step
# | 29        | -0.000462 | 23.77     | 0.426     | 48.3      | 0.0001    | 91.17     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 514us/step
# | 30        | -0.000379 | 23.72     | 0.4184    | 48.24     | 0.0001    | 91.22     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 502us/step
# | 31        | -0.000395 | 34.76     | 0.4882    | 33.82     | 0.004873  | 93.75     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 710us/step
# | 32        | -0.008467 | 23.08     | 0.3362    | 20.29     | 0.003318  | 118.2     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 460us/step
# | 33        | -0.000210 | 40.69     | 0.2751    | 11.95     | 0.002147  | 32.07     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 458us/step
# | 34        | -0.000128 | 33.71     | 0.1512    | 25.35     | 0.003452  | 61.71     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 525us/step
# | 35        | -0.000147 | 63.97     | 0.2327    | 25.21     | 0.004717  | 80.52     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 611us/step
# | 36        | -0.00015  | 58.48     | 0.3201    | 32.61     | 0.004737  | 104.3     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 613us/step
# | 37        | -0.001946 | 23.78     | 0.4948    | 48.22     | 0.0001    | 91.18     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 676us/step
# | 38        | -0.000137 | 23.69     | 0.4871    | 48.3      | 0.0001    | 91.19     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 669us/step
# | 39        | -9.292e-0 | 19.29     | 0.3033    | 11.37     | 0.0007013 | 106.0     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 541us/step
# | 40        | -0.000127 | 23.68     | 0.4601    | 48.31     | 0.0001    | 91.26     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 534us/step
# | 41        | -0.000389 | 23.69     | 0.4171    | 48.34     | 0.0001    | 91.21     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 513us/step
# | 42        | -0.001584 | 23.64     | 0.4865    | 48.26     | 0.0001    | 91.23     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 524us/step
# | 43        | -0.000229 | 23.67     | 0.3644    | 48.41     | 0.0001    | 91.15     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 1s 673us/step
# | 44        | -0.000243 | 23.69     | 0.3223    | 48.35     | 0.0001    | 91.16     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 567us/step
# | 45        | -0.000381 | 27.17     | 0.2619    | 30.27     | 0.0009099 | 116.7     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 567us/step
# | 46        | -0.000989 | 23.7      | 0.3172    | 48.4      | 0.0001    | 91.1      |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 464us/step
# | 47        | -0.000114 | 20.0      | 0.4223    | 34.17     | 0.004721  | 63.01     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 440us/step
# | 48        | -0.000224 | 34.23     | 0.3448    | 46.45     | 0.004163  | 42.62     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 474us/step
# | 49        | -0.000173 | 27.59     | 0.4357    | 20.26     | 0.001218  | 44.62     |
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# 79/79 [==============================] - 0s 676us/step
# | 50        | -0.000190 | 23.64     | 0.4357    | 48.4      | 0.0001    | 91.16     |
# =====================================================================================
#
# Initialization Points Results:
# Point 1: {'target': -0.0001356979030843113, 'params': {'batch_size': 18.29, 'dropout_rate': 0.1512, 'epochs': 20.78, 'learning_rate': 0.0008453, 'units': 64.32}}
# Point 2: {'target': -0.00032191037425577585, 'params': {'batch_size': 24.47, 'dropout_rate': 0.2516, 'epochs': 30.12, 'learning_rate': 0.0020432, 'units': 96.87}}
# Point 3: {'target': -0.00014751275124351017, 'params': {'batch_size': 32.94, 'dropout_rate': 0.3518, 'epochs': 40.56, 'learning_rate': 0.0035234, 'units': 128.0}}
# Point 4: {'target': -0.0006647785248628046, 'params': {'batch_size': 48.11, 'dropout_rate': 0.1021, 'epochs': 15.34, 'learning_rate': 0.0010457, 'units': 72.23}}
# Point 5: {'target': -0.00011354906354597125, 'params': {'batch_size': 52.76, 'dropout_rate': 0.2049, 'epochs': 50.0, 'learning_rate': 0.0041342, 'units': 85.92}}
# Point 6: {'target': -9.984466355962997e-05, 'params': {'batch_size': 60.84, 'dropout_rate': 0.3012, 'epochs': 35.21, 'learning_rate': 0.0025347, 'units': 100.65}}
# Point 7: {'target': -0.0004050662574118882, 'params': {'batch_size': 64.0, 'dropout_rate': 0.1814, 'epochs': 25.89, 'learning_rate': 0.0007346, 'units': 80.47}}
# Point 8: {'target': -0.00010767756122942627, 'params': {'batch_size': 36.12, 'dropout_rate': 0.2217, 'epochs': 45.33, 'learning_rate': 0.0012678, 'units': 68.55}}
# Point 9: {'target': -0.00010684637128713507, 'params': {'batch_size': 40.75, 'dropout_rate': 0.2835, 'epochs': 28.16, 'learning_rate': 0.0031432, 'units': 120.43}}
# Point 10: {'target': -0.0001339330217450619, 'params': {'batch_size': 42.67, 'dropout_rate': 0.3214, 'epochs': 18.44, 'learning_rate': 0.0045123, 'units': 60.34}}
# Point 11: {'target': -0.00035240081309005736, 'params': {'batch_size': 56.89, 'dropout_rate': 0.1637, 'epochs': 38.27, 'learning_rate': 0.0022345, 'units': 90.21}}
# Point 12: {'target': -0.00010291797912092325, 'params': {'batch_size': 44.92, 'dropout_rate': 0.1219, 'epochs': 12.78, 'learning_rate': 0.0015124, 'units': 77.36}}
# Point 13: {'target': -0.00025696028471450336, 'params': {'batch_size': 50.47, 'dropout_rate': 0.2418, 'epochs': 42.55, 'learning_rate': 0.0009567, 'units': 92.78}}
# Point 14: {'target': -0.00018613770652263812, 'params': {'batch_size': 58.64, 'dropout_rate': 0.2612, 'epochs': 33.12, 'learning_rate': 0.0038346, 'units': 104.56}}
# Point 15: {'target': -0.00017504026730196862, 'params': {'batch_size': 30.11, 'dropout_rate': 0.1412, 'epochs': 22.78, 'learning_rate': 0.0018234, 'units': 74.62}}
# train_data_reshaped shape: (3046, 1, 13)
# y_train shape: (3046,)
# Time consumed for training: 413.08 seconds
# 79/79 [==============================] - 1s 569us/step
# mae:  0.005234004592644498
# mase:  0.3694326518494145
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# /var/folders/14/ljpzpqp91g1dpqy4sw00h0vm0000gn/T/ipykernel_75238/440322928.py:193: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   naive_forecast = y_test.shift(1).fillna(method='bfill')
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step

# %%
def print_results_with_metrics(results):
    """
    Print out results (model summary, evaluation metrics, and some forecast predictions)
    from the results dictionary returned by combined_workflow.
    """
    for ticker, data in results.items():
        print(f"Ticker: {ticker}")
        print("=" * 50)
        
        # 1. Print model summary (if the model is a statsmodels object)
        if "model" in data and hasattr(data["model"], "summary"):
            print("Model Summary:")
            print(data["model"].summary())
            print("\n")
        else:
            print("No statsmodels summary available for this model.\n")
        
        # 2. Print evaluation metrics (stored in "model results")
        if "model results" in data:
            metrics_dict = data["model results"]
            mae = metrics_dict.get("mae", None)
            mase = metrics_dict.get("mase", None)
            
            print("Evaluation Metrics:")
            print(f"Mean Absolute Error (MAE): {mae}")
            print(f"Mean Absolute Scaled Error (MASE): {mase}")
            print("\n")
        else:
            print("No evaluation metrics found.\n")

        # 3. Print monthly forecast predictions
        print("Monthly Forecast Predictions (first 5 values for each period):")
        # Let's assume you have up to 12 monthly periods
        for i_m in range(1, 13):
            key_m = f"forecast_predictions_df_{i_m}m"
            if key_m in data:
                # Each is a NumPy array of predicted values
                preds_array = data[key_m]
                print(f"{key_m}: {preds_array[:5]}")  # Print first 5 predictions
        print("\n")

        # 4. Print weekly forecast predictions (first 5 values)
        print("Weekly Forecast Predictions (first 5 values for each period):")
        # Assume up to 48 weekly periods
        for i_w in range(1, 49):
            key_w = f"forecast_predictions_df_{i_w}w"
            if key_w in data:
                preds_array = data[key_w]
                print(f"{key_w}: {preds_array[:5]}")
        print("\n")
        
        print("=" * 50)
        print("\n")
print_results_with_metrics(results)
# Out:
# Ticker: SMH
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.010801158283040095
# Mean Absolute Scaled Error (MASE): 0.5604789568542173
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.00044336  0.00611194  0.00966225  0.01449859  0.01882011]
# forecast_predictions_df_2m: [0.01098081 0.01112711 0.00992792 0.00183367 0.01212188]
# forecast_predictions_df_3m: [0.01325065 0.0076483  0.00064398 0.01204465 0.01050749]
# forecast_predictions_df_4m: [0.01442791 0.01064704 0.01919361 0.00776826 0.02850124]
# forecast_predictions_df_5m: [0.02493041 0.03916331 0.03256536 0.03034929 0.02283556]
# forecast_predictions_df_6m: [0.00963966 0.00742381 0.0167551  0.0027356  0.00459963]
# forecast_predictions_df_7m: [0.01239845 0.01306342 0.01510535 0.01063514 0.01613129]
# forecast_predictions_df_8m: [0.03069568 0.04093222 0.04587754 0.05096995 0.04334025]
# forecast_predictions_df_9m: [-0.00145553  0.00922544  0.01132339  0.00468247  0.03190083]
# forecast_predictions_df_10m: [0.01107603 0.01449758 0.01267937 0.0131447  0.00751008]
# forecast_predictions_df_11m: [0.024604   0.02180623 0.0265089  0.02755008 0.02431304]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.00044336  0.00611194  0.00966225  0.01449859]
# forecast_predictions_df_2w: [0.01882011 0.01201699 0.01233439 0.01632683 0.01429422]
# forecast_predictions_df_3w: [0.02144583 0.01604873 0.02609481 0.0234171 ]
# forecast_predictions_df_4w: [0.01441709 0.0113116  0.01575798 0.0111526  0.00555503]
# forecast_predictions_df_5w: [0.01596346 0.00916931 0.00736815 0.01098081 0.01112711]
# forecast_predictions_df_6w: [0.00992792 0.00183367 0.01212188 0.01045862 0.01086043]
# forecast_predictions_df_7w: [ 0.00400488 -0.00020257  0.01111805  0.00377594  0.00698097]
# forecast_predictions_df_8w: [0.0053718  0.01117239 0.02371171 0.00935658]
# forecast_predictions_df_9w: [0.01248292 0.00800395 0.00647301 0.01302742 0.01325065]
# forecast_predictions_df_10w: [ 0.0076483   0.00064398  0.01204465  0.01050749 -0.00822677]
# forecast_predictions_df_11w: [0.00367182 0.01632134 0.004046   0.00370426 0.00956244]
# forecast_predictions_df_12w: [0.01207358 0.01041299 0.01225743 0.01189462 0.0126209 ]
# forecast_predictions_df_13w: [0.01008281 0.00906565 0.01109045 0.01054333]
# forecast_predictions_df_14w: [0.01442791 0.01064704 0.01919361 0.00776826 0.02850124]
# forecast_predictions_df_15w: [0.03172135 0.02250928 0.01491065 0.02906461 0.00830162]
# forecast_predictions_df_16w: [0.01407035 0.02141252 0.00911617 0.02032418 0.01401236]
# forecast_predictions_df_17w: [0.04367521 0.04311074 0.03676648 0.03848152 0.03606182]
# forecast_predictions_df_18w: [0.03073975 0.02649432 0.02493041 0.03916331 0.03256536]
# forecast_predictions_df_19w: [0.03034929 0.02283556 0.02848841 0.02264705 0.03116452]
# forecast_predictions_df_20w: [0.02015817 0.02054892 0.02116836 0.00962075 0.00779933]
# forecast_predictions_df_21w: [0.00965205 0.00408167 0.00977669 0.01032753 0.01138195]
# forecast_predictions_df_22w: [0.01285329 0.00352354 0.0027098  0.00180042]
# forecast_predictions_df_23w: [0.00963966 0.00742381 0.0167551  0.0027356  0.00459963]
# forecast_predictions_df_24w: [0.00788122 0.00396886 0.01035779 0.00787858 0.00790425]
# forecast_predictions_df_25w: [ 0.00924096  0.00613603 -0.0016376   0.00285471]
# forecast_predictions_df_26w: [0.00135687 0.01600691 0.01210525 0.0136414  0.01518196]
# forecast_predictions_df_27w: [0.01239845 0.01306342 0.01510535 0.01063514]
# forecast_predictions_df_28w: [0.01613129 0.01247239 0.01546343 0.00433712 0.01604213]
# forecast_predictions_df_29w: [0.0148689  0.01718025 0.00187008 0.03549137 0.03111384]
# forecast_predictions_df_30w: [0.03927248 0.02445029 0.0050607  0.0348338  0.04151507]
# forecast_predictions_df_31w: [0.03528597 0.03448231 0.04909164 0.03069568 0.04093222]
# forecast_predictions_df_32w: [0.04587754 0.05096995 0.04334025 0.05667172 0.04861591]
# forecast_predictions_df_33w: [0.04933184 0.0539515  0.04512886 0.03845327 0.02741923]
# forecast_predictions_df_34w: [0.02428379 0.02433638 0.02971501 0.00777168 0.02098867]
# forecast_predictions_df_35w: [0.00973962 0.01880672 0.00814706 0.02163091 0.01765584]
# forecast_predictions_df_36w: [-0.00145553  0.00922544  0.01132339  0.00468247]
# forecast_predictions_df_37w: [0.03190083 0.02428565 0.02955285 0.02191938 0.02487374]
# forecast_predictions_df_38w: [0.02771747 0.03270849 0.03468118 0.03806902 0.02633745]
# forecast_predictions_df_39w: [0.02420549 0.03144155 0.02154739 0.02472308 0.00898931]
# forecast_predictions_df_40w: [0.01183684 0.01107603 0.01449758 0.01267937 0.0131447 ]
# forecast_predictions_df_41w: [0.00751008 0.01183475 0.01082588 0.01087345 0.01292186]
# forecast_predictions_df_42w: [ 0.01501548 -0.00164824  0.01352389  0.01561693  0.01404715]
# forecast_predictions_df_43w: [0.01398413 0.01153746 0.01212049 0.018081   0.02383478]
# forecast_predictions_df_44w: [0.01499304 0.01964779 0.00562926 0.0059548  0.024604  ]
# forecast_predictions_df_45w: [0.02180623 0.0265089  0.02755008 0.02431304 0.01558993]
# forecast_predictions_df_46w: [0.0121034  0.02506517 0.01104111 0.01889268 0.01267814]
# forecast_predictions_df_47w: [0.03198325 0.03215661 0.02524091 0.02766352 0.02068181]
# forecast_predictions_df_48w: [0.02484337 0.02261517 0.02939682 0.03219143]
#
#
# ==================================================
#
#
# Ticker: SOXX
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.00911199816718438
# Mean Absolute Scaled Error (MASE): 0.4672415567981035
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.01013443 -0.00574099 -0.00308893 -0.00132152  0.00285855]
# forecast_predictions_df_2m: [-0.00028882 -0.00329406 -0.00437526 -0.00656509  0.00053227]
# forecast_predictions_df_3m: [-0.00024504 -0.00873452 -0.01233707 -0.00337293 -0.00218393]
# forecast_predictions_df_4m: [0.00988405 0.01844833 0.025908   0.0221937  0.0323507 ]
# forecast_predictions_df_5m: [0.03039214 0.04013469 0.0302275  0.02796571 0.02364268]
# forecast_predictions_df_6m: [-0.00302938 -0.00155307  0.00480943 -0.00407418 -0.00296123]
# forecast_predictions_df_7m: [0.00581076 0.00465573 0.00283165 0.00030687 0.00446646]
# forecast_predictions_df_8m: [0.02530959 0.02893553 0.03410668 0.03904356 0.03483876]
# forecast_predictions_df_9m: [-0.00625342  0.02411927  0.02450421  0.01611688  0.03735975]
# forecast_predictions_df_10m: [ 0.02547906  0.02029534  0.01660266  0.01353184 -0.00366009]
# forecast_predictions_df_11m: [0.03296546 0.03154594 0.0319328  0.03227509 0.02870386]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.01013443 -0.00574099 -0.00308893 -0.00132152]
# forecast_predictions_df_2w: [ 0.00285854 -0.00351686 -0.00219887  0.00283964  0.0038326 ]
# forecast_predictions_df_3w: [0.00754933 0.01066326 0.01654768 0.00626661]
# forecast_predictions_df_4w: [-0.00237819 -0.00465699 -0.00292064 -0.00445411 -0.00478361]
# forecast_predictions_df_5w: [ 0.00365336  0.00093569 -0.00041296 -0.00028882 -0.00329406]
# forecast_predictions_df_6w: [-0.00437526 -0.00656509  0.00053227 -0.0005728  -0.00195692]
# forecast_predictions_df_7w: [-0.0061415  -0.00871572 -0.00056833 -0.0057292  -0.00291339]
# forecast_predictions_df_8w: [0.00186704 0.00704342 0.00993428 0.0011225 ]
# forecast_predictions_df_9w: [ 0.00378412 -0.00245876 -0.00034561  0.00084973 -0.00024504]
# forecast_predictions_df_10w: [-0.00873452 -0.01233707 -0.00337294 -0.00218393 -0.01807396]
# forecast_predictions_df_11w: [-0.00619885  0.00227356 -0.0042072  -0.00436765  0.00473483]
# forecast_predictions_df_12w: [0.00776144 0.0065598  0.00601068 0.00143167 0.00756423]
# forecast_predictions_df_13w: [0.00598644 0.00652713 0.00846245 0.00570043]
# forecast_predictions_df_14w: [0.00988405 0.01844833 0.025908   0.0221937  0.0323507 ]
# forecast_predictions_df_15w: [0.0359531  0.0267877  0.02200308 0.02887229 0.02028798]
# forecast_predictions_df_16w: [0.02424072 0.0256384  0.0232604  0.0260928  0.02993774]
# forecast_predictions_df_17w: [0.04457795 0.04250811 0.03935575 0.0363596  0.034974  ]
# forecast_predictions_df_18w: [0.03064504 0.03104834 0.03039214 0.04013469 0.03022751]
# forecast_predictions_df_19w: [0.02796571 0.02364268 0.02732244 0.02304547 0.02848101]
# forecast_predictions_df_20w: [ 0.01507514  0.00903975  0.00619775 -0.0029869  -0.00493473]
# forecast_predictions_df_21w: [-0.00478155 -0.00841418 -0.00512849 -0.00705113 -0.00279381]
# forecast_predictions_df_22w: [-0.00337147 -0.00488663 -0.00461579 -0.00821539]
# forecast_predictions_df_23w: [-0.00302938 -0.00155307  0.00480943 -0.00407418 -0.00296123]
# forecast_predictions_df_24w: [-0.00193788 -0.00313119 -0.00179751 -0.00416297 -0.00302028]
# forecast_predictions_df_25w: [-0.00303925 -0.00505814 -0.00524362 -0.00187456]
# forecast_predictions_df_26w: [0.00143254 0.00607201 0.00830655 0.01342095 0.00732076]
# forecast_predictions_df_27w: [0.00581076 0.00465573 0.00283165 0.00030687]
# forecast_predictions_df_28w: [ 0.00446646  0.00073527  0.00012559 -0.00248407  0.00398426]
# forecast_predictions_df_29w: [0.00616449 0.00757215 0.00827888 0.03460003 0.03596538]
# forecast_predictions_df_30w: [0.03558063 0.02533712 0.02168749 0.03428265 0.03872586]
# forecast_predictions_df_31w: [0.03310334 0.03097103 0.04540719 0.02530959 0.02893553]
# forecast_predictions_df_32w: [0.03410668 0.03904356 0.03483876 0.04688516 0.03817664]
# forecast_predictions_df_33w: [0.03911815 0.04279634 0.03911067 0.04706815 0.03754021]
# forecast_predictions_df_34w: [0.03534167 0.03573627 0.03780834 0.02478806 0.03032142]
# forecast_predictions_df_35w: [0.02590063 0.03044356 0.02339294 0.03389237 0.02684311]
# forecast_predictions_df_36w: [-0.00625342  0.02411927  0.02450421  0.01611688]
# forecast_predictions_df_37w: [0.03735975 0.03375961 0.03587031 0.03194502 0.03410405]
# forecast_predictions_df_38w: [0.03308159 0.03636891 0.03599415 0.04317563 0.03255483]
# forecast_predictions_df_39w: [0.0305994  0.03533052 0.02667866 0.02932177 0.01787466]
# forecast_predictions_df_40w: [0.0209262  0.02547906 0.02029534 0.01660266 0.01353184]
# forecast_predictions_df_41w: [-0.00366009  0.000214   -0.00018259  0.00587044  0.00470495]
# forecast_predictions_df_42w: [ 0.00882751 -0.00317204  0.01787692  0.01404115  0.02276511]
# forecast_predictions_df_43w: [0.01713563 0.01882666 0.02393909 0.0263226  0.03163243]
# forecast_predictions_df_44w: [0.02650748 0.02285621 0.00823518 0.02474046 0.03296546]
# forecast_predictions_df_45w: [0.03154594 0.0319328  0.03227509 0.02870386 0.02335961]
# forecast_predictions_df_46w: [0.02673416 0.03665102 0.02674742 0.03046393 0.03211984]
# forecast_predictions_df_47w: [0.04106855 0.03767479 0.03648547 0.03706701 0.03437078]
# forecast_predictions_df_48w: [0.03678205 0.03382291 0.04249572 0.03765894]
#
#
# ==================================================
#
#
# Ticker: PSI
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.012605596552065222
# Mean Absolute Scaled Error (MASE): 0.6175090910903899
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.02788597 -0.02597896 -0.02348261 -0.0197486  -0.01817491]
# forecast_predictions_df_2m: [-0.00928225 -0.00699125 -0.00679628 -0.01205403 -0.00788925]
# forecast_predictions_df_3m: [-0.00356402 -0.00690386 -0.01499682 -0.0081382  -0.00573776]
# forecast_predictions_df_4m: [-0.0044777  -0.00673983 -0.00251157 -0.01899092 -0.00741438]
# forecast_predictions_df_5m: [-0.0193206  -0.01346251 -0.01636868 -0.01499107 -0.01891957]
# forecast_predictions_df_6m: [-0.01354869 -0.01825198 -0.00683819 -0.01705101 -0.01843085]
# forecast_predictions_df_7m: [-0.01699216 -0.01131798 -0.01003414 -0.01052889 -0.01164362]
# forecast_predictions_df_8m: [-0.02212918 -0.01384503 -0.00889978 -0.00633944 -0.00685037]
# forecast_predictions_df_9m: [-0.02195495 -0.01637475 -0.01830347 -0.01995872 -0.02010936]
# forecast_predictions_df_10m: [-0.02145894 -0.01859481 -0.02289284 -0.0176282  -0.01376894]
# forecast_predictions_df_11m: [-0.01489562 -0.01707103 -0.01145555 -0.01173836 -0.01258541]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.02788597 -0.02597898 -0.02348258 -0.01974859]
# forecast_predictions_df_2w: [-0.01817491 -0.01648184 -0.01700642 -0.01571668 -0.01752296]
# forecast_predictions_df_3w: [-0.01189956 -0.01402986 -0.00828247 -0.01252592]
# forecast_predictions_df_4w: [-0.01147987 -0.01686102 -0.01695078 -0.014777   -0.01763872]
# forecast_predictions_df_5w: [-0.0064193  -0.01096866 -0.01119211 -0.00928223 -0.00699123]
# forecast_predictions_df_6w: [-0.00679628 -0.01205402 -0.00788927 -0.00409968 -0.00020698]
# forecast_predictions_df_7w: [-0.00259963 -0.00897591  0.00385033  0.00449199 -0.00099948]
# forecast_predictions_df_8w: [-0.01397371 -0.00886717  0.00178504 -0.01199883]
# forecast_predictions_df_9w: [-0.00558094 -0.01012678 -0.01005912 -0.00670536 -0.00356402]
# forecast_predictions_df_10w: [-0.00690384 -0.01499682 -0.00813821 -0.00573776 -0.0142864 ]
# forecast_predictions_df_11w: [-0.01923515 -0.01112525 -0.02518298 -0.02409892 -0.02267018]
# forecast_predictions_df_12w: [-0.0177559  -0.02104049 -0.00776871  0.00162379 -0.01183867]
# forecast_predictions_df_13w: [-0.01105789 -0.01347172 -0.00610458 -0.00850443]
# forecast_predictions_df_14w: [-0.00447771 -0.00673985 -0.00251158 -0.0189909  -0.00741436]
# forecast_predictions_df_15w: [-0.00597749 -0.01191495 -0.02309041 -0.00986345 -0.02718917]
# forecast_predictions_df_16w: [-0.02263012 -0.01362279 -0.02343144 -0.0189643  -0.0194917 ]
# forecast_predictions_df_17w: [-0.01764138 -0.01668829 -0.01579444 -0.01254404 -0.0124482 ]
# forecast_predictions_df_18w: [-0.01849093 -0.01625883 -0.01932059 -0.01346251 -0.01636866]
# forecast_predictions_df_19w: [-0.01499107 -0.01891958 -0.01368325 -0.01423176 -0.00861734]
# forecast_predictions_df_20w: [-0.01168344 -0.00742574 -0.00559666 -0.00958839 -0.00637528]
# forecast_predictions_df_21w: [ 0.00423208  0.0009047  -0.00562234 -0.00695764 -0.0049096 ]
# forecast_predictions_df_22w: [-0.0068881  -0.01510745 -0.0125786  -0.0096214 ]
# forecast_predictions_df_23w: [-0.01354872 -0.01825198 -0.0068382  -0.017051   -0.01843085]
# forecast_predictions_df_24w: [-0.00909715 -0.01359306 -0.00521014 -0.01037702 -0.01730377]
# forecast_predictions_df_25w: [-0.00882453 -0.00749872 -0.02144868 -0.01992694]
# forecast_predictions_df_26w: [-0.02529767 -0.01071816 -0.01626973 -0.01379241 -0.01261677]
# forecast_predictions_df_27w: [-0.01699218 -0.01131798 -0.01003416 -0.01052888]
# forecast_predictions_df_28w: [-0.01164363 -0.01318198 -0.00916202 -0.02133364 -0.01121886]
# forecast_predictions_df_29w: [-0.01216536 -0.01285343 -0.02773948 -0.01667775 -0.01927727]
# forecast_predictions_df_30w: [-0.01587473 -0.024019   -0.02318893 -0.02007714 -0.02025571]
# forecast_predictions_df_31w: [-0.01995579 -0.02127775 -0.01846837 -0.02212919 -0.01384504]
# forecast_predictions_df_32w: [-0.00889977 -0.00633945 -0.00685037 -0.00402702 -0.01246577]
# forecast_predictions_df_33w: [-0.01139056 -0.01074367 -0.01500171 -0.01671046 -0.02072202]
# forecast_predictions_df_34w: [-0.01776384 -0.0198687  -0.01818259 -0.01894282 -0.01434904]
# forecast_predictions_df_35w: [-0.01819632 -0.01590772 -0.01979301 -0.01916864 -0.01685194]
# forecast_predictions_df_36w: [-0.02195495 -0.01637476 -0.01830346 -0.01995872]
# forecast_predictions_df_37w: [-0.02010936 -0.02037746 -0.01579618 -0.02147393 -0.0185698 ]
# forecast_predictions_df_38w: [-0.02183775 -0.02084906 -0.02009715 -0.01808211 -0.02084641]
# forecast_predictions_df_39w: [-0.02134599 -0.01728917 -0.01954217 -0.01159133 -0.02418901]
# forecast_predictions_df_40w: [-0.02382716 -0.02145895 -0.01859479 -0.02289285 -0.0176282 ]
# forecast_predictions_df_41w: [-0.01376896 -0.01308688 -0.00544185 -0.02298548 -0.01022323]
# forecast_predictions_df_42w: [-0.00955797 -0.02948914 -0.02161333 -0.02036634 -0.02233587]
# forecast_predictions_df_43w: [-0.02094518 -0.01945793 -0.018357   -0.01238501 -0.01185028]
# forecast_predictions_df_44w: [-0.0102488  -0.00872724 -0.02059788 -0.01704652 -0.01489562]
# forecast_predictions_df_45w: [-0.01707103 -0.01145555 -0.01173836 -0.01258538 -0.01747195]
# forecast_predictions_df_46w: [-0.01664677 -0.01570232 -0.01850972 -0.0156045  -0.02358008]
# forecast_predictions_df_47w: [-0.01911483 -0.01589522 -0.01507374 -0.00420956 -0.01141264]
# forecast_predictions_df_48w: [-0.00832985 -0.01380918 -0.01554115 -0.00867338]
#
#
# ==================================================
#
#
# Ticker: XSD
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.025394435014870757
# Mean Absolute Scaled Error (MASE): 1.2164356099790223
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.06376256 -0.05702572 -0.05064353 -0.05055032 -0.05097714]
# forecast_predictions_df_2m: [-0.02804457 -0.0296989  -0.03085036 -0.03197144 -0.02799749]
# forecast_predictions_df_3m: [-0.04834544 -0.0530807  -0.0489572  -0.04471919 -0.04949287]
# forecast_predictions_df_4m: [-0.03402514 -0.03062501 -0.02653835 -0.02704145 -0.02438705]
# forecast_predictions_df_5m: [-0.02526233 -0.01572431 -0.01442332 -0.02007088 -0.02566161]
# forecast_predictions_df_6m: [-0.05573418 -0.05287859 -0.04984201 -0.05531753 -0.05067011]
# forecast_predictions_df_7m: [-0.03991918 -0.03903923 -0.04272295 -0.0486308  -0.04461763]
# forecast_predictions_df_8m: [-0.01209214  0.00928937  0.03527675  0.04709027  0.04381838]
# forecast_predictions_df_9m: [-0.01213335 -0.01107552 -0.009177   -0.00727155  0.00472231]
# forecast_predictions_df_10m: [-0.01168254 -0.01298406 -0.01390152 -0.01792963 -0.0316578 ]
# forecast_predictions_df_11m: [-0.01232045 -0.01611691 -0.01608338 -0.01561643 -0.02093942]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.06376256 -0.05702569 -0.05064354 -0.05055034]
# forecast_predictions_df_2w: [-0.05097713 -0.05094048 -0.04645442 -0.04046418 -0.03786753]
# forecast_predictions_df_3w: [-0.03320806 -0.03351102 -0.02429922 -0.02650252]
# forecast_predictions_df_4w: [-0.03078612 -0.0423381  -0.04177011 -0.03971468 -0.03917687]
# forecast_predictions_df_5w: [-0.02781595 -0.03571142 -0.03207985 -0.02804457 -0.02969891]
# forecast_predictions_df_6w: [-0.03085038 -0.03197143 -0.02799748 -0.03006898 -0.03604396]
# forecast_predictions_df_7w: [-0.04088339 -0.03472314 -0.03202443 -0.03774893 -0.0328108 ]
# forecast_predictions_df_8w: [-0.02928999 -0.02907307 -0.02469951 -0.03473667]
# forecast_predictions_df_9w: [-0.03026259 -0.03701793 -0.03979639 -0.04072274 -0.04834544]
# forecast_predictions_df_10w: [-0.0530807  -0.04895719 -0.0447192  -0.04949291 -0.04370677]
# forecast_predictions_df_11w: [-0.03630596 -0.03288055 -0.03406458 -0.02923512 -0.02724772]
# forecast_predictions_df_12w: [-0.02754646 -0.02868722 -0.02688042 -0.02747323 -0.02905956]
# forecast_predictions_df_13w: [-0.03122802 -0.03004046 -0.03109932 -0.03620423]
# forecast_predictions_df_14w: [-0.03402514 -0.03062503 -0.02653835 -0.02704146 -0.02438705]
# forecast_predictions_df_15w: [-0.02420058 -0.02755323 -0.0331587  -0.02197585 -0.02815391]
# forecast_predictions_df_16w: [-0.02274204 -0.02148925 -0.02284748 -0.0221566  -0.02019265]
# forecast_predictions_df_17w: [-0.01035141 -0.01339509 -0.01522755 -0.01479298 -0.01604882]
# forecast_predictions_df_18w: [-0.01886751 -0.02621176 -0.02526234 -0.0157243  -0.01442331]
# forecast_predictions_df_19w: [-0.02007088 -0.02566162 -0.02734142 -0.03015647 -0.03398753]
# forecast_predictions_df_20w: [-0.03471878 -0.04347212 -0.04937898 -0.05530079 -0.05631998]
# forecast_predictions_df_21w: [-0.05963295 -0.05882329 -0.05890939 -0.05188024 -0.05199137]
# forecast_predictions_df_22w: [-0.05246895 -0.05037129 -0.05503303 -0.05623762]
# forecast_predictions_df_23w: [-0.05573419 -0.05287859 -0.04984199 -0.05531752 -0.0506701 ]
# forecast_predictions_df_24w: [-0.04660664 -0.04820026 -0.04894284 -0.04848097 -0.04215313]
# forecast_predictions_df_25w: [-0.0416781  -0.04614508 -0.04079432 -0.03744529]
# forecast_predictions_df_26w: [-0.03874607 -0.03612179 -0.03726669 -0.03863923 -0.0377875 ]
# forecast_predictions_df_27w: [-0.03991921 -0.03903923 -0.04272295 -0.04863081]
# forecast_predictions_df_28w: [-0.04461762 -0.05068008 -0.05551738 -0.05433305 -0.05543675]
# forecast_predictions_df_29w: [-0.05439807 -0.058097   -0.05263131 -0.03843457 -0.03845872]
# forecast_predictions_df_30w: [-0.03124327 -0.03741965 -0.03151412 -0.02466562 -0.01610738]
# forecast_predictions_df_31w: [-0.02088967 -0.0226417  -0.01122074 -0.01209214  0.00928937]
# forecast_predictions_df_32w: [0.03527675 0.04709027 0.04381837 0.06085538 0.04048231]
# forecast_predictions_df_33w: [0.04195308 0.04469301 0.03566217 0.03534019 0.01316695]
# forecast_predictions_df_34w: [ 0.00520975  0.00496724  0.0019833  -0.00630501  0.00162664]
# forecast_predictions_df_35w: [-0.00396324 -0.00146012 -0.00561778 -0.00110333 -0.01216147]
# forecast_predictions_df_36w: [-0.01213335 -0.01107552 -0.009177   -0.00727154]
# forecast_predictions_df_37w: [ 0.0047223   0.00119024  0.00164191 -0.00215374 -0.00144441]
# forecast_predictions_df_38w: [-0.00688544 -0.00503907 -0.00555441  0.00163917 -0.00575977]
# forecast_predictions_df_39w: [-0.00414855 -0.00496199 -0.00988942 -0.00684479 -0.01315896]
# forecast_predictions_df_40w: [-0.01262525 -0.01168254 -0.01298406 -0.01390151 -0.01792962]
# forecast_predictions_df_41w: [-0.03165778 -0.0288432  -0.03296325 -0.02514213 -0.02804397]
# forecast_predictions_df_42w: [-0.03040326 -0.02707225 -0.02495251 -0.02663865 -0.02267509]
# forecast_predictions_df_43w: [-0.0252344  -0.02606532 -0.02418355 -0.02514882 -0.02205569]
# forecast_predictions_df_44w: [-0.02581884 -0.02894213 -0.031097   -0.02065403 -0.01232046]
# forecast_predictions_df_45w: [-0.0161169  -0.01608338 -0.01561644 -0.02093943 -0.02468793]
# forecast_predictions_df_46w: [-0.02214208 -0.01805184 -0.01810562 -0.0170773  -0.01908231]
# forecast_predictions_df_47w: [-0.01201922 -0.01349918 -0.01745623 -0.01206368 -0.01862571]
# forecast_predictions_df_48w: [-0.01788375 -0.02067492 -0.01765852 -0.0179223 ]
#
#
# ==================================================
#
#
# Ticker: IYW
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.00966099017068619
# Mean Absolute Scaled Error (MASE): 0.6483832016583855
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [0.01329387 0.02118225 0.02220116 0.02349004 0.02821817]
# forecast_predictions_df_2m: [0.0263462  0.02604752 0.02224274 0.02154065 0.02510964]
# forecast_predictions_df_3m: [0.02656969 0.02394413 0.01592485 0.02649197 0.02816952]
# forecast_predictions_df_4m: [0.02565124 0.02288114 0.02516166 0.02127264 0.02775275]
# forecast_predictions_df_5m: [0.02066158 0.02867697 0.0319632  0.02997129 0.02561063]
# forecast_predictions_df_6m: [0.02531621 0.02483075 0.02934822 0.0244544  0.0245179 ]
# forecast_predictions_df_7m: [0.02508981 0.02402438 0.02464189 0.02364647 0.02413124]
# forecast_predictions_df_8m: [9.7565050e-04 9.0279272e-03 3.1092728e-05 2.6451036e-02 1.6762331e-02]
# forecast_predictions_df_9m: [0.00613792 0.0245764  0.02725511 0.01773636 0.02760528]
# forecast_predictions_df_10m: [0.02111693 0.02684271 0.02612925 0.02746745 0.02307664]
# forecast_predictions_df_11m: [0.02736296 0.0249333  0.0280093  0.03059869 0.02903185]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [0.01329387 0.02118225 0.02220116 0.02349004]
# forecast_predictions_df_2w: [0.02821817 0.02480126 0.02576637 0.02530641 0.02393649]
# forecast_predictions_df_3w: [0.02386616 0.02237897 0.02816165 0.02919326]
# forecast_predictions_df_4w: [0.02524067 0.02416686 0.02600436 0.02557521 0.02208997]
# forecast_predictions_df_5w: [0.02589999 0.0221969  0.01407889 0.0263462  0.02604752]
# forecast_predictions_df_6w: [0.02224274 0.02154065 0.02510964 0.02320953 0.02472761]
# forecast_predictions_df_7w: [0.02192866 0.02106671 0.02601405 0.0233381  0.02288871]
# forecast_predictions_df_8w: [0.0229704  0.02250656 0.03093679 0.02449993]
# forecast_predictions_df_9w: [0.02386618 0.02481266 0.02245442 0.02650502 0.02656969]
# forecast_predictions_df_10w: [0.02394413 0.01592485 0.02649196 0.02816952 0.02278448]
# forecast_predictions_df_11w: [0.0237511  0.02961184 0.02299148 0.02829611 0.02192223]
# forecast_predictions_df_12w: [0.02732786 0.02620026 0.02685082 0.02516679 0.02569843]
# forecast_predictions_df_13w: [0.02399221 0.02404595 0.02558724 0.02463176]
# forecast_predictions_df_14w: [0.02565124 0.02288114 0.02516166 0.02127264 0.02775275]
# forecast_predictions_df_15w: [0.02361629 0.02496774 0.02301479 0.02919916 0.02036444]
# forecast_predictions_df_16w: [0.01489171 0.02475232 0.01910788 0.02159832 0.00412348]
# forecast_predictions_df_17w: [0.02697314 0.02874331 0.02425786 0.02244461 0.03007259]
# forecast_predictions_df_18w: [0.02392762 0.01060969 0.02066158 0.02867697 0.0319632 ]
# forecast_predictions_df_19w: [0.02997129 0.02561063 0.0261079  0.02569969 0.02612213]
# forecast_predictions_df_20w: [0.0266917  0.02716074 0.02908894 0.02475281 0.02458097]
# forecast_predictions_df_21w: [0.02442086 0.02309169 0.02378395 0.02414775 0.02431163]
# forecast_predictions_df_22w: [0.02558051 0.02327633 0.02027286 0.02432634]
# forecast_predictions_df_23w: [0.02531621 0.02483075 0.02934822 0.0244544  0.0245179 ]
# forecast_predictions_df_24w: [0.0243735  0.02587337 0.02622391 0.02395659 0.02442031]
# forecast_predictions_df_25w: [0.02531865 0.02354242 0.02277487 0.02440303]
# forecast_predictions_df_26w: [0.0224307  0.02830828 0.02568081 0.02584992 0.02475347]
# forecast_predictions_df_27w: [0.02508981 0.02402438 0.02464189 0.02364647]
# forecast_predictions_df_28w: [0.02413124 0.02342804 0.0251399  0.02225569 0.02611317]
# forecast_predictions_df_29w: [0.02647551 0.02582069 0.00726819 0.02403217 0.02152667]
# forecast_predictions_df_30w: [ 0.03039291  0.02502082 -0.00387397  0.02084883  0.02615597]
# forecast_predictions_df_31w: [0.02251867 0.01168105 0.03438305 0.00097565 0.00902793]
# forecast_predictions_df_32w: [3.1092728e-05 2.6451036e-02 1.6762331e-02 3.3130694e-02 2.6422378e-02]
# forecast_predictions_df_33w: [0.02613042 0.0325548  0.02580242 0.03232423 0.02667007]
# forecast_predictions_df_34w: [0.02931495 0.02679065 0.02934048 0.02367666 0.030414  ]
# forecast_predictions_df_35w: [0.02570556 0.02782424 0.02443701 0.0254567  0.02816435]
# forecast_predictions_df_36w: [0.00613792 0.0245764  0.02725511 0.01773636]
# forecast_predictions_df_37w: [0.02760528 0.02772042 0.03097963 0.02799588 0.02720176]
# forecast_predictions_df_38w: [0.02458032 0.0261297  0.02449092 0.03447727 0.02640525]
# forecast_predictions_df_39w: [0.02710114 0.02930619 0.02803044 0.03039284 0.02505922]
# forecast_predictions_df_40w: [0.02740338 0.02111693 0.02684271 0.02612925 0.02746745]
# forecast_predictions_df_41w: [0.02307664 0.02651364 0.02528429 0.02527452 0.02565303]
# forecast_predictions_df_42w: [0.02715892 0.02278152 0.02543718 0.0260274  0.02670424]
# forecast_predictions_df_43w: [0.02698901 0.02565844 0.02340678 0.02643522 0.02786385]
# forecast_predictions_df_44w: [0.02605252 0.02777278 0.02351855 0.01286787 0.02736296]
# forecast_predictions_df_45w: [0.0249333  0.0280093  0.03059869 0.02903185 0.02664339]
# forecast_predictions_df_46w: [0.02565361 0.02704296 0.02611158 0.02540224 0.01811412]
# forecast_predictions_df_47w: [0.02709413 0.02856812 0.02611247 0.02732721 0.02591814]
# forecast_predictions_df_48w: [0.0257511  0.02632803 0.02310609 0.02674844]
#
#
# ==================================================
#
#
# Ticker: XLK
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.006604502669998792
# Mean Absolute Scaled Error (MASE): 0.46565712072293725
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [0.00684873 0.01191368 0.01129092 0.01380921 0.01911473]
# forecast_predictions_df_2m: [0.01874982 0.01937323 0.01630767 0.01217452 0.01753102]
# forecast_predictions_df_3m: [0.0185551  0.01326121 0.00974004 0.01683358 0.01775565]
# forecast_predictions_df_4m: [0.01782104 0.01930077 0.02174708 0.01507155 0.02150188]
# forecast_predictions_df_5m: [0.01678525 0.02092951 0.02186874 0.01958846 0.01781037]
# forecast_predictions_df_6m: [0.01345546 0.01436935 0.01997414 0.01329465 0.01441465]
# forecast_predictions_df_7m: [0.01994637 0.01920907 0.02298686 0.01823549 0.01778953]
# forecast_predictions_df_8m: [-0.00581608 -0.01667892 -0.02342977 -0.01142563 -0.02295271]
# forecast_predictions_df_9m: [0.00386514 0.01311132 0.01327449 0.00673254 0.01687615]
# forecast_predictions_df_10m: [0.0140713  0.01678235 0.01546143 0.017445   0.01243775]
# forecast_predictions_df_11m: [0.01855    0.01759506 0.01890944 0.02129675 0.01960933]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [0.00684872 0.01191368 0.01129092 0.01380921]
# forecast_predictions_df_2w: [0.01911473 0.01344004 0.01546752 0.01496031 0.01466882]
# forecast_predictions_df_3w: [0.01506887 0.01328682 0.01968727 0.02342237]
# forecast_predictions_df_4w: [0.01911877 0.02066992 0.02206611 0.02071003 0.01431906]
# forecast_predictions_df_5w: [0.01966961 0.01399674 0.01050223 0.01874982 0.01937324]
# forecast_predictions_df_6w: [0.01630768 0.01217451 0.01753103 0.01384713 0.01804721]
# forecast_predictions_df_7w: [0.00989152 0.00792616 0.01449161 0.0107364  0.01092662]
# forecast_predictions_df_8w: [0.01480843 0.01721063 0.02348764 0.01670899]
# forecast_predictions_df_9w: [0.01761067 0.0151993  0.01546163 0.01718881 0.0185551 ]
# forecast_predictions_df_10w: [0.01326122 0.00974004 0.01683358 0.01775565 0.01323646]
# forecast_predictions_df_11w: [0.01621991 0.0206618  0.01459009 0.01465603 0.01402289]
# forecast_predictions_df_12w: [0.0166516  0.01515464 0.01505923 0.01231915 0.0148606 ]
# forecast_predictions_df_13w: [0.01320461 0.01483922 0.01706984 0.01459289]
# forecast_predictions_df_14w: [0.01782103 0.01930076 0.02174708 0.01507156 0.02150187]
# forecast_predictions_df_15w: [0.02085642 0.01921598 0.01577878 0.02349991 0.01643342]
# forecast_predictions_df_16w: [0.01675228 0.01851164 0.01652501 0.01812434 0.01510566]
# forecast_predictions_df_17w: [0.02306577 0.02330927 0.02000914 0.01846905 0.02078998]
# forecast_predictions_df_18w: [0.01831545 0.01334846 0.01678525 0.02092951 0.02186874]
# forecast_predictions_df_19w: [0.01958846 0.01781037 0.01868287 0.01737643 0.01979179]
# forecast_predictions_df_20w: [0.01781298 0.01651052 0.0201398  0.0141274  0.0149752 ]
# forecast_predictions_df_21w: [0.02110058 0.01650066 0.01552699 0.012218   0.0179022 ]
# forecast_predictions_df_22w: [0.01665296 0.01299105 0.00753679 0.01374193]
# forecast_predictions_df_23w: [0.01345547 0.01436936 0.01997414 0.01329465 0.01441465]
# forecast_predictions_df_24w: [0.01393931 0.01945903 0.02306162 0.01948968 0.01856975]
# forecast_predictions_df_25w: [0.02438389 0.02060162 0.01552829 0.01820357]
# forecast_predictions_df_26w: [0.01184007 0.02088757 0.01645266 0.01665229 0.01643131]
# forecast_predictions_df_27w: [0.01994637 0.01920908 0.02298686 0.01823549]
# forecast_predictions_df_28w: [0.01778952 0.01550179 0.02040583 0.00646081 0.01481502]
# forecast_predictions_df_29w: [0.01515553 0.01539554 0.01254359 0.02173169 0.01871927]
# forecast_predictions_df_30w: [0.02234065 0.01778693 0.00947303 0.01602396 0.01829419]
# forecast_predictions_df_31w: [ 0.01426878  0.0065992   0.02103209 -0.0058161  -0.01667892]
# forecast_predictions_df_32w: [-0.02342978 -0.01142564 -0.02295271 -0.00265126 -0.00987766]
# forecast_predictions_df_33w: [-0.00929879  0.00917976  0.00495892  0.01857875  0.01550799]
# forecast_predictions_df_34w: [0.01746823 0.01610339 0.01749098 0.01230211 0.01970478]
# forecast_predictions_df_35w: [0.01461772 0.01697054 0.0128478  0.01622132 0.0180879 ]
# forecast_predictions_df_36w: [0.00386514 0.01311131 0.01327448 0.00673255]
# forecast_predictions_df_37w: [0.01687615 0.01663215 0.02231185 0.01660138 0.01638204]
# forecast_predictions_df_38w: [0.01610414 0.01676766 0.01508729 0.02097802 0.01796407]
# forecast_predictions_df_39w: [0.0182398  0.01980705 0.01848722 0.01975163 0.01615269]
# forecast_predictions_df_40w: [0.01714361 0.01407129 0.01678235 0.01546143 0.017445  ]
# forecast_predictions_df_41w: [0.01243775 0.02009116 0.01779466 0.01499238 0.01589085]
# forecast_predictions_df_42w: [0.01888685 0.01142014 0.01596963 0.01526628 0.01697493]
# forecast_predictions_df_43w: [0.01638214 0.01518164 0.01424957 0.01688261 0.0180528 ]
# forecast_predictions_df_44w: [0.01627684 0.01843635 0.01114688 0.01139606 0.01855   ]
# forecast_predictions_df_45w: [0.01759507 0.01890945 0.02129675 0.01960933 0.01724543]
# forecast_predictions_df_46w: [0.01748864 0.0196427  0.01648806 0.01717402 0.0168337 ]
# forecast_predictions_df_47w: [0.02111369 0.02171019 0.02079732 0.01916545 0.01707308]
# forecast_predictions_df_48w: [0.01805241 0.01768807 0.01803281 0.01817488]
#
#
# ==================================================
#
#
# Ticker: VGT
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.007106084636658296
# Mean Absolute Scaled Error (MASE): 0.49184508378880815
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.00772037 -0.003142   -0.00268397 -0.0009963   0.00269009]
# forecast_predictions_df_2m: [-0.00374521 -0.00478957 -0.00635326 -0.00592836 -0.00333804]
# forecast_predictions_df_3m: [ 0.00397034 -0.00474228 -0.00693888 -0.0020473   0.00130244]
# forecast_predictions_df_4m: [-0.0034488  -0.00092338  0.00099117 -0.00320529  0.00368882]
# forecast_predictions_df_5m: [0.00876444 0.01050393 0.0068039  0.00246572 0.00043585]
# forecast_predictions_df_6m: [-0.00408567 -0.00518217  0.0012261  -0.00509613 -0.00396098]
# forecast_predictions_df_7m: [-0.00460001 -0.00522406 -0.00541133 -0.00663792 -0.00508606]
# forecast_predictions_df_8m: [0.0010272  0.00798793 0.00542493 0.02135872 0.01762238]
# forecast_predictions_df_9m: [-0.0079679   0.00044687  0.00111633 -0.00330855  0.00498714]
# forecast_predictions_df_10m: [-0.00218685  0.00061677 -0.00021988  0.00308658 -0.00264311]
# forecast_predictions_df_11m: [-0.0023849  -0.00216922 -0.00203444  0.00589788  0.00213192]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.00772037 -0.003142   -0.00268396 -0.0009963 ]
# forecast_predictions_df_2w: [ 0.00269009 -0.00491874 -0.00359785 -0.00373853 -0.00412351]
# forecast_predictions_df_3w: [-0.00264258 -0.00211352 -0.00020782 -0.00077848]
# forecast_predictions_df_4w: [-0.00436536 -0.00568742 -0.00544589 -0.0059904  -0.00651947]
# forecast_predictions_df_5w: [-0.0042389  -0.00629496 -0.00640259 -0.00374521 -0.00478957]
# forecast_predictions_df_6w: [-0.00635326 -0.00592836 -0.00333804 -0.00494393 -0.00307648]
# forecast_predictions_df_7w: [-0.00623456 -0.00728698 -0.00072054 -0.00491615 -0.00651703]
# forecast_predictions_df_8w: [-0.00341758 -0.00032703  0.00739152 -0.00313007]
# forecast_predictions_df_9w: [-0.00256111 -0.00415058 -0.00344888  0.00068724  0.00397034]
# forecast_predictions_df_10w: [-0.00474228 -0.00693888 -0.0020473   0.00130244 -0.00515987]
# forecast_predictions_df_11w: [-0.00316351  0.00240352 -0.00389618 -0.00366871 -0.00224162]
# forecast_predictions_df_12w: [-9.8192622e-04 -2.7751566e-03 -5.5821962e-05 -2.7611011e-03
#  -4.9603209e-03]
# forecast_predictions_df_13w: [-0.00556972 -0.00471997 -0.00370824 -0.00479658]
# forecast_predictions_df_14w: [-0.0034488  -0.00092338  0.00099117 -0.00320529  0.00368882]
# forecast_predictions_df_15w: [ 0.00091862 -0.00175208 -0.00194399  0.00437296 -0.00143301]
# forecast_predictions_df_16w: [0.00134659 0.00184816 0.00273713 0.00724585 0.00852038]
# forecast_predictions_df_17w: [0.0154441  0.01448229 0.01066911 0.00955791 0.00926438]
# forecast_predictions_df_18w: [0.0053236  0.00732649 0.00876444 0.01050393 0.0068039 ]
# forecast_predictions_df_19w: [ 0.00246572  0.00043585  0.00090581 -0.00065424  0.00199389]
# forecast_predictions_df_20w: [-0.00152327 -0.00327919  0.00283614 -0.00480788 -0.00309556]
# forecast_predictions_df_21w: [-0.00423278 -0.00563938 -0.00536927 -0.00556214 -0.00491827]
# forecast_predictions_df_22w: [-0.00477144 -0.00543416 -0.00793482 -0.00538211]
# forecast_predictions_df_23w: [-0.00408567 -0.00518217  0.0012261  -0.00509613 -0.00396098]
# forecast_predictions_df_24w: [-0.00342661 -0.00104712 -0.00114776 -0.004509   -0.00449237]
# forecast_predictions_df_25w: [-0.00458427 -0.00638351 -0.00665467 -0.00496726]
# forecast_predictions_df_26w: [-0.00630523  0.00057851 -0.00419111 -0.00463802 -0.00437984]
# forecast_predictions_df_27w: [-0.00460001 -0.00522406 -0.00541133 -0.00663792]
# forecast_predictions_df_28w: [-0.00508606 -0.00533841 -0.00409623 -0.00692569 -0.00081354]
# forecast_predictions_df_29w: [-0.00389771 -0.00502408 -0.00521001  0.00120929  0.0020599 ]
# forecast_predictions_df_30w: [ 0.00053311 -0.00309432 -0.00339386  0.00303704  0.00328127]
# forecast_predictions_df_31w: [0.00282034 0.00377463 0.00922553 0.0010272  0.00798793]
# forecast_predictions_df_32w: [0.00542493 0.02135872 0.01762238 0.02567323 0.01854866]
# forecast_predictions_df_33w: [0.01841015 0.01908033 0.01357711 0.0116288  0.00135237]
# forecast_predictions_df_34w: [ 0.00398974  0.00241656  0.00452193 -0.00020452  0.00578695]
# forecast_predictions_df_35w: [ 0.00056997  0.00199965 -0.00087507  0.00193209  0.00255575]
# forecast_predictions_df_36w: [-0.0079679   0.00044687  0.00111633 -0.00330855]
# forecast_predictions_df_37w: [0.00498714 0.0037313  0.00781754 0.00258034 0.0014848 ]
# forecast_predictions_df_38w: [0.00116191 0.00223525 0.00278114 0.00990682 0.00232058]
# forecast_predictions_df_39w: [ 0.00199788  0.0037123   0.00096327  0.00296187 -0.0015818 ]
# forecast_predictions_df_40w: [-0.00028923 -0.00218685  0.00061676 -0.00021988  0.00308658]
# forecast_predictions_df_41w: [-0.00264311  0.00418592  0.00192592 -0.00220998 -0.00218999]
# forecast_predictions_df_42w: [-0.00024724 -0.0061604  -0.00198354 -0.00188641 -0.00362662]
# forecast_predictions_df_43w: [-0.00325656 -0.00422941 -0.00553429 -0.00416729 -0.00381356]
# forecast_predictions_df_44w: [-0.00492813 -0.00340461 -0.00649358 -0.0060077  -0.0023849 ]
# forecast_predictions_df_45w: [-0.00216922 -0.00203444  0.00589788  0.00213192 -0.00382249]
# forecast_predictions_df_46w: [-0.00411426 -0.0039662  -0.00345587 -0.00447885 -0.00309044]
# forecast_predictions_df_47w: [-5.2202900e-05  1.5682750e-04 -2.0572341e-03 -1.2621093e-03
#  -3.8619833e-03]
# forecast_predictions_df_48w: [-0.00389214 -0.00471013 -0.00420171 -0.00364332]
#
#
# ==================================================
#
#
# Ticker: FTEC
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.0362838165266677
# Mean Absolute Scaled Error (MASE): 2.5101668959197214
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [0.06146086 0.06639218 0.06219465 0.06331413 0.06043958]
# forecast_predictions_df_2m: [0.04426065 0.03592163 0.03655091 0.0372396  0.03615642]
# forecast_predictions_df_3m: [0.03872648 0.04615375 0.06553574 0.06624806 0.05096817]
# forecast_predictions_df_4m: [0.06938271 0.07036316 0.07377099 0.06587088 0.07359469]
# forecast_predictions_df_5m: [0.08101194 0.08368397 0.08290184 0.08221146 0.08017413]
# forecast_predictions_df_6m: [0.03644899 0.04272497 0.03828863 0.03864764 0.03873197]
# forecast_predictions_df_7m: [0.03596011 0.03693377 0.03660156 0.03786333 0.03582829]
# forecast_predictions_df_8m: [0.07523842 0.06662174 0.05540057 0.05696093 0.05464173]
# forecast_predictions_df_9m: [0.05834675 0.04007359 0.04282807 0.05453767 0.0648289 ]
# forecast_predictions_df_10m: [0.06800798 0.04623635 0.04150441 0.03646688 0.03688303]
# forecast_predictions_df_11m: [0.06718008 0.06701715 0.06660125 0.06347378 0.05297543]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [0.06146085 0.06639218 0.06219465 0.06331411]
# forecast_predictions_df_2w: [0.06043958 0.06616481 0.06511857 0.06585228 0.06380342]
# forecast_predictions_df_3w: [0.06833751 0.06744346 0.0729489  0.06587225]
# forecast_predictions_df_4w: [0.06673503 0.04986732 0.05715698 0.05429874 0.06207309]
# forecast_predictions_df_5w: [0.0542272  0.06468862 0.06594573 0.04426065 0.03592163]
# forecast_predictions_df_6w: [0.0365509  0.03723959 0.03615643 0.03628936 0.03475672]
# forecast_predictions_df_7w: [0.03762208 0.05065345 0.03927889 0.03897339 0.05808182]
# forecast_predictions_df_8w: [0.06861983 0.06898236 0.07619853 0.06954779]
# forecast_predictions_df_9w: [0.07045083 0.06421916 0.06563318 0.06619817 0.03872648]
# forecast_predictions_df_10w: [0.04615375 0.06553575 0.06624806 0.05096817 0.07044539]
# forecast_predictions_df_11w: [0.06869784 0.07609321 0.06910722 0.06430921 0.06885128]
# forecast_predictions_df_12w: [0.07087067 0.06695165 0.04945704 0.04304628 0.0616454 ]
# forecast_predictions_df_13w: [0.07488438 0.0651571  0.06755055 0.06331223]
# forecast_predictions_df_14w: [0.06938271 0.07036316 0.07377099 0.06587088 0.07359469]
# forecast_predictions_df_15w: [0.07113519 0.06926113 0.06494834 0.0781619  0.06703457]
# forecast_predictions_df_16w: [0.07500634 0.06962028 0.07497366 0.0782719  0.0704142 ]
# forecast_predictions_df_17w: [0.08032587 0.07871532 0.07869618 0.07761861 0.07569966]
# forecast_predictions_df_18w: [0.07576297 0.079273   0.08101197 0.08368398 0.08290184]
# forecast_predictions_df_19w: [0.08221145 0.08017413 0.0807485  0.07583022 0.07865588]
# forecast_predictions_df_20w: [0.07557054 0.0569869  0.0434241  0.04034878 0.0387796 ]
# forecast_predictions_df_21w: [0.03385285 0.0359451  0.03594727 0.03591163 0.03477012]
# forecast_predictions_df_22w: [0.03472801 0.03734603 0.03803142 0.03683225]
# forecast_predictions_df_23w: [0.03644899 0.04272498 0.03828864 0.03864763 0.03873197]
# forecast_predictions_df_24w: [0.03755309 0.03524352 0.03318094 0.03515127 0.03659436]
# forecast_predictions_df_25w: [0.03385042 0.03422678 0.03863044 0.04052525]
# forecast_predictions_df_26w: [0.05315609 0.04054388 0.04484541 0.05007813 0.04677665]
# forecast_predictions_df_27w: [0.03596012 0.03693378 0.03660156 0.03786331]
# forecast_predictions_df_28w: [0.0358283  0.03665906 0.03499696 0.03798458 0.03638111]
# forecast_predictions_df_29w: [0.04784406 0.05073663 0.06563604 0.07321624 0.07147934]
# forecast_predictions_df_30w: [0.07476982 0.06523314 0.07897051 0.0139737  0.07236938]
# forecast_predictions_df_31w: [0.07124028 0.07668513 0.07819553 0.07523841 0.06662174]
# forecast_predictions_df_32w: [0.05540057 0.05696092 0.05464173 0.061498   0.07012963]
# forecast_predictions_df_33w: [0.06836475 0.07797341 0.08016337 0.08475447 0.07765961]
# forecast_predictions_df_34w: [0.08199219 0.08438244 0.08689234 0.07559071 0.06099786]
# forecast_predictions_df_35w: [0.07575168 0.07064539 0.05735547 0.07740998 0.05212992]
# forecast_predictions_df_36w: [0.05834675 0.04007358 0.04282808 0.05453767]
# forecast_predictions_df_37w: [0.0648289  0.06438497 0.04922358 0.0676087  0.06483451]
# forecast_predictions_df_38w: [0.0725628  0.07617933 0.07379822 0.08569789 0.08188021]
# forecast_predictions_df_39w: [0.07819274 0.08392003 0.07713336 0.07533582 0.0637648 ]
# forecast_predictions_df_40w: [0.06075809 0.06800796 0.04623635 0.04150441 0.03646689]
# forecast_predictions_df_41w: [0.03688302 0.03437975 0.03463042 0.03787777 0.03964761]
# forecast_predictions_df_42w: [0.03730224 0.0425375  0.0408804  0.03846796 0.0546213 ]
# forecast_predictions_df_43w: [0.04868055 0.04963988 0.06311479 0.06126746 0.06637833]
# forecast_predictions_df_44w: [0.06177056 0.05927165 0.04452436 0.05974331 0.06718008]
# forecast_predictions_df_45w: [0.06701715 0.06660125 0.06347378 0.05297542 0.0551758 ]
# forecast_predictions_df_46w: [0.06493029 0.06822769 0.05698012 0.06169172 0.06702717]
# forecast_predictions_df_47w: [0.07840696 0.07798544 0.07443915 0.05912194 0.06598116]
# forecast_predictions_df_48w: [0.06281964 0.05873966 0.0671356  0.05575385]
#
#
# ==================================================
#
#
# Ticker: IGM
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.0044145731449876
# Mean Absolute Scaled Error (MASE): 0.3028194384635616
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.00756704  0.00297855  0.00622519  0.00948475  0.009638  ]
# forecast_predictions_df_2m: [-0.00298603  0.01729406  0.00376025 -0.00261219  0.00660306]
# forecast_predictions_df_3m: [ 0.00986625 -0.00582944 -0.00395253  0.00110733  0.00250042]
# forecast_predictions_df_4m: [0.012848   0.00854551 0.0145991  0.0035846  0.01809733]
# forecast_predictions_df_5m: [0.01344236 0.02271763 0.01625621 0.01312418 0.00823279]
# forecast_predictions_df_6m: [-0.00697251 -0.00411233 -0.00173135 -0.00769451 -0.00755173]
# forecast_predictions_df_7m: [-0.01043944 -0.00626904 -0.00218805  0.00442002 -0.01239302]
# forecast_predictions_df_8m: [0.00394244 0.00265378 0.00463188 0.0246096  0.00969436]
# forecast_predictions_df_9m: [-0.00247315 -0.00338318 -0.00136344 -0.00107593  0.01271244]
# forecast_predictions_df_10m: [-0.00191053 -0.00396817 -0.00493899 -0.00198884 -0.00778396]
# forecast_predictions_df_11m: [0.01689994 0.01435763 0.01817474 0.01766266 0.00819905]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.00756703  0.00297856  0.00622519  0.00948474]
# forecast_predictions_df_2w: [ 0.00963801  0.00299239  0.00393807  0.00158712 -0.00076536]
# forecast_predictions_df_3w: [0.00067356 0.00178546 0.00236423 0.00461825]
# forecast_predictions_df_4w: [-0.00589066 -0.00805131 -0.00554826 -0.00821171 -0.01042946]
# forecast_predictions_df_5w: [-0.005041   -0.01166985 -0.00831284 -0.00298602  0.01729406]
# forecast_predictions_df_6w: [ 0.00376024 -0.00261218  0.00660306  0.00277826  0.00912841]
# forecast_predictions_df_7w: [-0.00794146 -0.01172269  0.0066701  -0.00294942 -0.00992091]
# forecast_predictions_df_8w: [-0.00310911  0.00054909  0.01138668 -0.00193571]
# forecast_predictions_df_9w: [-5.2120921e-04 -2.1942789e-03  1.6496866e-05  8.9059677e-04
#   9.8662423e-03]
# forecast_predictions_df_10w: [-0.00582943 -0.00395253  0.00110733  0.00250041 -0.00513797]
# forecast_predictions_df_11w: [-0.00100173  0.00421168 -0.00227685 -0.00325682 -0.00148692]
# forecast_predictions_df_12w: [ 0.00190152 -0.00094858 -0.00327889 -0.00218973  0.00308987]
# forecast_predictions_df_13w: [0.00189513 0.00395755 0.00791949 0.00860198]
# forecast_predictions_df_14w: [0.012848   0.00854551 0.0145991  0.00358462 0.01809734]
# forecast_predictions_df_15w: [0.01328914 0.01337119 0.00691161 0.01885559 0.00542821]
# forecast_predictions_df_16w: [0.00644887 0.01416585 0.00987478 0.01456445 0.01357461]
# forecast_predictions_df_17w: [0.02850868 0.02780286 0.01718956 0.01281017 0.02667982]
# forecast_predictions_df_18w: [0.01126469 0.00743391 0.01344234 0.02271762 0.01625621]
# forecast_predictions_df_19w: [0.01312417 0.00823279 0.00959052 0.00810422 0.01341709]
# forecast_predictions_df_20w: [ 0.01109175  0.00583111  0.00445987 -0.00583523 -0.00696142]
# forecast_predictions_df_21w: [ 0.00650731 -0.00650857 -0.01016625 -0.01019447 -0.00394237]
# forecast_predictions_df_22w: [-0.00886239 -0.01239884 -0.01166371 -0.00935139]
# forecast_predictions_df_23w: [-0.00697252 -0.00411233 -0.00173136 -0.00769453 -0.00755172]
# forecast_predictions_df_24w: [-0.00739649 -0.00761115 -0.00183634 -0.01166708 -0.00954533]
# forecast_predictions_df_25w: [-0.00937166 -0.01255368 -0.01420459 -0.01118986]
# forecast_predictions_df_26w: [-0.00871851 -0.00506525 -0.006791   -0.00431312 -0.00875854]
# forecast_predictions_df_27w: [-0.01043946 -0.00626904 -0.00218807  0.00442001]
# forecast_predictions_df_28w: [-0.01239303 -0.0150169  -0.00168062 -0.01390474 -0.0044039 ]
# forecast_predictions_df_29w: [ 0.00193194  0.00391291 -0.00136229  0.01406432  0.0122079 ]
# forecast_predictions_df_30w: [ 0.01919067  0.01077207 -0.00170722  0.01444305  0.02145493]
# forecast_predictions_df_31w: [0.01464956 0.01117143 0.02280648 0.00394244 0.00265378]
# forecast_predictions_df_32w: [0.00463188 0.02460959 0.00969437 0.03465879 0.01540151]
# forecast_predictions_df_33w: [0.0124403  0.02740208 0.01537    0.02609655 0.01206336]
# forecast_predictions_df_34w: [0.01070905 0.01041747 0.01183846 0.00121076 0.00267113]
# forecast_predictions_df_35w: [0.00261739 0.0032038  0.00058165 0.00811906 0.00198637]
# forecast_predictions_df_36w: [-0.00247315 -0.00338319 -0.00136343 -0.00107593]
# forecast_predictions_df_37w: [0.01271244 0.00944109 0.00962141 0.00522488 0.00216661]
# forecast_predictions_df_38w: [0.00448637 0.00561265 0.00802346 0.01515183 0.00564541]
# forecast_predictions_df_39w: [ 0.00209561  0.00664152  0.00170599  0.00295819 -0.00438301]
# forecast_predictions_df_40w: [-0.00202554 -0.00191054 -0.00396816 -0.00493899 -0.00198882]
# forecast_predictions_df_41w: [-0.00778398  0.00659509 -0.00063171 -0.01118329 -0.01003836]
# forecast_predictions_df_42w: [-0.00927243 -0.01151411 -0.00671051 -0.00639069  0.00353563]
# forecast_predictions_df_43w: [0.00294973 0.00294047 0.00238596 0.01134999 0.0134004 ]
# forecast_predictions_df_44w: [ 0.01044893  0.00972441  0.00068339 -0.00020628  0.01689993]
# forecast_predictions_df_45w: [0.0143576  0.01817475 0.01766268 0.00819904 0.0001532 ]
# forecast_predictions_df_46w: [ 0.00128704  0.00582215 -0.00097523 -0.00027188  0.00061007]
# forecast_predictions_df_47w: [0.01256293 0.01286113 0.00911538 0.00579067 0.00604599]
# forecast_predictions_df_48w: [0.00775158 0.00901304 0.00929229 0.01295859]
#
#
# ==================================================
#
#
# Ticker: IXN
# ==================================================
# No statsmodels summary available for this model.
#
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.005234004592644498
# Mean Absolute Scaled Error (MASE): 0.3694326518494145
#
#
# Monthly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1m: [-0.00042094  0.00440442  0.0057903   0.01040821  0.02286921]
# forecast_predictions_df_2m: [0.01913604 0.01487348 0.00695499 0.00188309 0.01494262]
# forecast_predictions_df_3m: [0.01840211 0.01185083 0.00199655 0.01958635 0.02148521]
# forecast_predictions_df_4m: [0.01203527 0.01147051 0.01706122 0.00460422 0.02071442]
# forecast_predictions_df_5m: [0.00796765 0.01979025 0.03112855 0.02536127 0.01603266]
# forecast_predictions_df_6m: [0.01040991 0.01459752 0.02588339 0.01146667 0.01407471]
# forecast_predictions_df_7m: [0.01424958 0.00835121 0.01457138 0.00638953 0.01434884]
# forecast_predictions_df_8m: [-0.01297699 -0.02234593 -0.04146773 -0.02184415 -0.03594111]
# forecast_predictions_df_9m: [-1.1306764e-02 -5.1047560e-04 -9.9902623e-05 -8.3539458e-03
#   1.4304760e-02]
# forecast_predictions_df_10m: [ 0.00502375  0.01492893  0.01159407  0.01398864 -0.00055527]
# forecast_predictions_df_11m: [0.01760734 0.01604843 0.02327174 0.02596941 0.0272192 ]
#
#
# Weekly Forecast Predictions (first 5 values for each period):
# forecast_predictions_df_1w: [-0.00042094  0.00440442  0.0057903   0.01040821]
# forecast_predictions_df_2w: [0.02286921 0.010797   0.01669829 0.01605085 0.01683106]
# forecast_predictions_df_3w: [0.00600359 0.01282253 0.02558782 0.02703531]
# forecast_predictions_df_4w: [0.01900233 0.01978394 0.02107532 0.01171761 0.0129946 ]
# forecast_predictions_df_5w: [0.02121255 0.01245392 0.00305434 0.01913604 0.01487348]
# forecast_predictions_df_6w: [0.00695499 0.00188309 0.01494262 0.00918611 0.01327624]
# forecast_predictions_df_7w: [-0.00210872  0.00037643  0.01305643  0.00291655  0.00414238]
# forecast_predictions_df_8w: [0.00782048 0.01095272 0.02844737 0.0155655 ]
# forecast_predictions_df_9w: [0.01621112 0.01366006 0.0126329  0.01857542 0.01840211]
# forecast_predictions_df_10w: [0.01185083 0.00199655 0.01958635 0.02148521 0.00704042]
# forecast_predictions_df_11w: [0.01253532 0.02629914 0.01054684 0.01283942 0.006293  ]
# forecast_predictions_df_12w: [0.01789494 0.01621464 0.01827399 0.00855695 0.01622886]
# forecast_predictions_df_13w: [0.00887489 0.01190813 0.01570112 0.01116119]
# forecast_predictions_df_14w: [0.01203527 0.01147051 0.01706122 0.00460422 0.02071442]
# forecast_predictions_df_15w: [0.01536637 0.01789721 0.00890207 0.02685639 0.00649447]
# forecast_predictions_df_16w: [ 0.00463705  0.01416694  0.00389659  0.00246733 -0.00236767]
# forecast_predictions_df_17w: [0.01085792 0.01829198 0.01511866 0.01272765 0.02222567]
# forecast_predictions_df_18w: [0.01772683 0.00346186 0.00796765 0.01979025 0.03112856]
# forecast_predictions_df_19w: [0.02536127 0.01603266 0.01960921 0.01603713 0.0201906 ]
# forecast_predictions_df_20w: [0.01922099 0.021054   0.02422135 0.00766445 0.00578058]
# forecast_predictions_df_21w: [0.00638582 0.00120269 0.00505963 0.00725013 0.01130814]
# forecast_predictions_df_22w: [ 0.01420623  0.003279   -0.00085     0.000534  ]
# forecast_predictions_df_23w: [0.01040991 0.01459752 0.02588339 0.01146667 0.01407471]
# forecast_predictions_df_24w: [0.01390933 0.01855811 0.02294849 0.0137348  0.01683126]
# forecast_predictions_df_25w: [0.02134365 0.01640565 0.00480523 0.00942854]
# forecast_predictions_df_26w: [0.00280157 0.02158448 0.01507747 0.01715735 0.01473727]
# forecast_predictions_df_27w: [0.01424958 0.00835121 0.01457138 0.00638953]
# forecast_predictions_df_28w: [ 0.01434884  0.00789054  0.01482251 -0.00039866  0.01287428]
# forecast_predictions_df_29w: [0.01697741 0.01804464 0.00093602 0.01590836 0.01134862]
# forecast_predictions_df_30w: [ 0.02785963  0.01762837 -0.00295512  0.00659841  0.01879528]
# forecast_predictions_df_31w: [ 1.1780147e-02 -8.1219128e-05  3.4615532e-02 -1.2976996e-02
#  -2.2345927e-02]
# forecast_predictions_df_32w: [-0.04146773 -0.02184415 -0.03594111 -0.0132793  -0.01433284]
# forecast_predictions_df_33w: [-0.01072704  0.0052514  -0.00158864  0.02013154  0.01264669]
# forecast_predictions_df_34w: [0.02007828 0.01322782 0.01223936 0.00022747 0.02055628]
# forecast_predictions_df_35w: [0.00235723 0.01776308 0.00082339 0.00900217 0.0169084 ]
# forecast_predictions_df_36w: [-1.13067655e-02 -5.10475598e-04 -9.99025069e-05 -8.35394394e-03]
# forecast_predictions_df_37w: [0.01430476 0.01446821 0.02435571 0.01704853 0.0169569 ]
# forecast_predictions_df_38w: [0.01200905 0.0128859  0.00951232 0.03050914 0.01176201]
# forecast_predictions_df_39w: [0.01677912 0.02045842 0.01913266 0.02743084 0.01406145]
# forecast_predictions_df_40w: [0.01831856 0.00502375 0.01492893 0.01159407 0.01398864]
# forecast_predictions_df_41w: [-0.00055527  0.01159271  0.00776362  0.01228591  0.01773995]
# forecast_predictions_df_42w: [0.01975521 0.0062773  0.01574206 0.01639246 0.01952171]
# forecast_predictions_df_43w: [0.01853486 0.01725157 0.01164449 0.01885192 0.02183364]
# forecast_predictions_df_44w: [0.01820765 0.02306441 0.00797749 0.0021796  0.01760734]
# forecast_predictions_df_45w: [0.01604843 0.02327174 0.02596941 0.02721919 0.0171017 ]
# forecast_predictions_df_46w: [0.01520401 0.01944536 0.01578335 0.01588529 0.00728363]
# forecast_predictions_df_47w: [0.01987278 0.02031532 0.01692614 0.01957587 0.01813132]
# forecast_predictions_df_48w: [0.01846712 0.01859957 0.01379008 0.02137893]
#
#
# ==================================================

# %% [markdown]
# ### Ratios

# %%
def calculate_sharpe_ratio(returns, annual_risk_free_rate=0.1,period='daily'):
    #excess_returns = rate_of_return(returns) - risk_free_rate
    
    # Convert annual risk-free rate to daily rate
    daily_risk_free_rate = (1 + annual_risk_free_rate) ** (1/252) - 1
    
    # Calculate mean daily log return
    mean_return = np.mean(returns)
    
    # Calculate excess daily log return
    excess_return = mean_return - daily_risk_free_rate
    
    # Calculate standard deviation of daily log returns
    std_return = np.std(returns)
    
    # Print diagnostic information
    #print(f"Mean Daily Log Return: {mean_return}")
    #print(f"Excess Daily Log Return: {excess_return}")
    #print(f"Standard Deviation of Daily Log Returns: {std_return}")
    
    # Check for zero standard deviation to avoid division by zero
    if std_return == 0:
        return 0
    
    # Calculate Sharpe ratio
    sharpe_ratio = (excess_return / std_return) * np.sqrt(252)  # Annualize the Sharpe ratio
    return sharpe_ratio
    #return excess_returns / np.std(returns)


def calculate_rachev_ratio(returns, lower_percentile=5, upper_percentile=95):
    # Step 1: Sort the returns
    sorted_returns = np.sort(returns)
    
    # Step 2: Determine the percentiles
    lower_threshold = np.percentile(sorted_returns, lower_percentile)
    upper_threshold = np.percentile(sorted_returns, upper_percentile)
    
    # Step 3: Calculate Expected Shortfall (ES)
    es = np.mean(sorted_returns[sorted_returns <= lower_threshold])
    
    # Step 4: Calculate Expected Gain (EG)
    eg = np.mean(sorted_returns[sorted_returns >= upper_threshold])
    
    # Step 5: Compute the Rachev Ratio
    rachev_ratio = eg / -es
    return rachev_ratio


"""def calculate_volatility_clustering(returns):
    squared_returns = returns ** 2
    n = len(squared_returns)
    
    # Mean of squared returns
    mean_squared_returns = np.mean(squared_returns)
    
    # Calculate the numerator and denominator for autocorrelation at lag 1
    numerator = np.sum((squared_returns[:-1] - mean_squared_returns) * (squared_returns[1:] - mean_squared_returns))
    denominator = np.sum((squared_returns - mean_squared_returns) ** 2)
    
    if denominator == 0:
        return 0  # Avoid division by zero
    
    rho_1 = numerator / denominator
    return rho_1"""
def calculate_volatility_clustering(returns):
    # Ensure returns is a NumPy array
    returns = np.array(returns)
    squared_returns = returns ** 2
    n = len(squared_returns)

    # Mean of squared returns
    mean_squared = np.mean(squared_returns)
    clustering = np.sum((squared_returns - mean_squared) ** 2) / (n - 1 if n > 1 else 1)
    return clustering

def calculate_sortino_ratio(log_returns, target_log_return=0.0):
    """
    Calculate the Sortino Ratio using log returns.
    
    Parameters:
    - log_returns (array-like): Array or list of log returns for the period.
    - target_log_return (float): The target log return. Default is 0, which is often used as a benchmark.
    
    Returns:
    - float: The Sortino Ratio.
    """
    # Convert input to a NumPy array for easier calculations
    log_returns = np.array(log_returns)
    
    # Calculate the average period log return (R)
    avg_log_return = np.mean(log_returns)
    
    # Calculate the Target Downside Deviation (TDD)
    downside_deviation = np.sqrt(
        np.mean(np.square(np.maximum(0, target_log_return - log_returns)))
    )
    
    # Calculate Sortino Ratio
    #sortino_ratio_value = (avg_log_return - target_log_return) / downside_deviation
    epsilon = 1e-8
    
    # Add epsilon to downside_deviation to prevent division by zero
    #if downside_deviation == 0:
     #   return np.nan  # Return NaN if downside deviation is zero
    
    # Calculate Sortino Ratio
    sortino_ratio_value = (avg_log_return - target_log_return) / (downside_deviation + epsilon)
    
    return sortino_ratio_value

# %%
def calculate_composite_score(
    forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, sortino_ratio, volatility_clustering, 
    mean_forecast, std_forecast, mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
    mean_volatility_clustering, std_volatility_clustering
):
    epsilon = 1e-8  # To prevent division by zero
    forecasted_mean = np.mean(forecasted_values)

    # Normalize the components with epsilon
    forecasted_mean_normalized = (forecasted_mean - mean_forecast) / (std_forecast + epsilon)
    rachev_normalized = (rachev_ratio - mean_rachev) / (std_rachev + epsilon)
    sharpe_normalized = (sharpe_ratio - mean_sharpe) / (std_sharpe + epsilon)
    sortino_normalized = (sortino_ratio - mean_sortino) / (std_sortino + epsilon)
    volatility_clustering_normalized = (volatility_clustering - mean_volatility_clustering) / (std_volatility_clustering + epsilon)

    # Composite score calculation
    score = (
        forecasted_mean_normalized
        - (risk_percentage * rachev_normalized)
        + sharpe_normalized
        + sortino_normalized
        - volatility_clustering_normalized
    )

    return score

def calculate_smoothing(data, alpha=0.1):
    if len(data) == 0:  # Explicitly check if the data is empty
        return []
    smoothed_data = []
    previous_value = data[0]
    for value in data:
        smoothed_value = alpha * value + (1 - alpha) * previous_value
        smoothed_data.append(smoothed_value)
        previous_value = smoothed_value
    return smoothed_data



def process_etf_data_weekly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = {}

    # Determine the forecast periods dynamically from the etf_dict
    sample_etf = next(iter(etf_dict.values()))
    forecast_periods = [key.split('_')[-1] for key in sample_etf.keys() if key.startswith('forecast_predictions_df')]

    for etf_name in tickers:
        etf_pred_dict[etf_name] = {
            f"returns_{period}": etf_dict[etf_name][f"forecast_predictions_df_{period}"]
            for period in forecast_periods
        }

        for period in forecast_periods:
            returns = etf_pred_dict[etf_name][f"returns_{period}"]

            if smoothing:
                # Apply smoothing to returns
                smoothed_returns = calculate_smoothing(returns)
                etf_pred_dict[etf_name][f"smoothed_returns_{period}"] = smoothed_returns

                # Calculate metrics using smoothed returns
                etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(smoothed_returns)
            else:
                # Calculate metrics using raw returns
                etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
                etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
                etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
                etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict


def calculate_means_and_stds_weekly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )


def calculate_scores_for_etfs_weekly(etf_pred_dict, forecast_period, risk_percentage):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_weekly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Week': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

    return scores


def select_top_etfs_weekly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()


def generate_week_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    week_ranges = []

    while start < end:
        week_start = start
        week_end = start + timedelta(days=6)
        if week_end > end:
            week_end = end
        week_ranges.append((week_start.strftime('%Y-%m-%d'), week_end.strftime('%Y-%m-%d')))
        start += timedelta(days=7)

    return week_ranges



def gather_etf_data_for_weeks(selected_tickers, week_ranges):
    etf_histories = {}
    for start_date, end_date in week_ranges:
        week = f"{start_date} to {end_date}"
        etf_histories[week] = {}
        for ticker in selected_tickers:
            print(f"Fetching data for {ticker} from {start_date} to {end_date}...")
            etf_data = yf.download(ticker, start=start_date, end=end_date, progress=False)
            if not etf_data.empty:
                etf_histories[week][ticker] = etf_data
            else:
                print(f"No data found for {ticker} in {week}")
    return etf_histories



def initialize_shares_for_first_week(top_etfs_1w, etf_histories, week, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = week.split(" to ")[0]

    for ticker in top_etfs_1w:
        etf_history = etf_histories.get(week, {}).get(ticker)

        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]

            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            ticker_shares[ticker] = num_shares
        else:
            print(f"No data found for {ticker} in {week}")
    return ticker_shares


def manage_etf_portfolio_weekly(
    top_etfs_previous, top_etfs_current, previous_week, current_week, ticker_shares, gathered_data_per_week
):
    etf_histories_for_current_week = gathered_data_per_week.get(current_week, {})
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"\nTop 2 ETFs for {previous_week}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_week}: {top2etfs_current}")

    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Ensure one-to-one mapping between sell and buy ETFs
    if len(etfs_to_sell) != len(etfs_to_buy):
        print("Mismatch between ETFs to sell and buy. Adjusting allocation...")
        return ticker_shares  # Abort if mismatched for now, you can implement custom logic

    # Allocate funds ETF-by-ETF
    for etf_sell, etf_buy in zip(etfs_to_sell, etfs_to_buy):
        no_of_shares = ticker_shares.get(etf_sell, 0)
        if no_of_shares > 0:
            # Selling old ETF
            if etf_sell in etf_histories_for_current_week:
                first_trading_day_sell_price = etf_histories_for_current_week[etf_sell].loc[
                    etf_histories_for_current_week[etf_sell].index[0], 'Close'
                ]
                selling_value = no_of_shares * first_trading_day_sell_price * 0.975
                print(f"Sell {etf_sell}: {no_of_shares:.2f} shares at {first_trading_day_sell_price:.2f}. Total value: {selling_value:.2f}")

                # Remove sold ETF from portfolio
                del ticker_shares[etf_sell]

                # Buying new ETF
                if etf_buy in etf_histories_for_current_week:
                    first_trading_day_buy_price = etf_histories_for_current_week[etf_buy].loc[
                        etf_histories_for_current_week[etf_buy].index[0], 'Close'
                    ]
                    new_shares = (selling_value * 0.975) / first_trading_day_buy_price
                    print(f"Buy {etf_buy}: {new_shares:.2f} shares at {first_trading_day_buy_price:.2f}.")
                    ticker_shares[etf_buy] = new_shares
                else:
                    print(f"Data for {etf_buy} is missing for {current_week}. Skipping purchase.")
            else:
                print(f"Data for {etf_sell} is missing for {current_week}. Skipping sale.")
        else:
            print(f"No shares found for {etf_sell} to sell.")

    print(f"Updated ticker shares after {current_week}: {ticker_shares}")
    return ticker_shares


def main_weekly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = process_etf_data_weekly(tickers, etf_dict, smoothing=smoothing)

    risk_percentage = 0.10
    weekly_scores = {}

    # Calculate scores for all weeks
    for week in range(1, 49):
        week_key = f"{week}w"
        if any(f"returns_{week_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, week_key, risk_percentage)
            weekly_scores[week_key] = scores

    # Convert scores to DataFrames
    weekly_scores_dfs = {}
    for week_key, scores in weekly_scores.items():
        weekly_scores_dfs[week_key] = pd.DataFrame(scores)

    # Select top ETFs for each week
    top_etfs_weekly = {}
    for week_key, df_scores in weekly_scores_dfs.items():
        top_etfs_weekly[week_key] = df_scores.nlargest(2, 'Score')

    # Generate week ranges for ETF data gathering
    week_ranges = generate_week_ranges('2024-01-01', '2024-12-01')

    # Gather ETF historical data
    etf_histories = gather_etf_data_for_weeks(tickers, week_ranges)

    # Map week keys to date ranges
    week_key_mapping = {f"{i+1}w": week_range for i, week_range in enumerate(etf_histories.keys())}

    # Align top ETFs with historical data
    aligned_top_etfs_weekly = {}
    for week_key, df_scores in weekly_scores_dfs.items():
        forecast_period = week_key_mapping.get(week_key, None)
        if forecast_period:
            aligned_top_etfs_weekly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

    # Initialize and manage portfolio
    ticker_shares = {}
    ticker_shares_per_week = {}
    for i, week_range in enumerate(etf_histories.keys()):
        current_week_key = week_range
        if i == 0:
            # Initialize shares for the first week
            ticker_shares = initialize_shares_for_first_week(
                aligned_top_etfs_weekly[current_week_key],
                etf_histories,
                current_week_key
            )
            ticker_shares_per_week[current_week_key] = ticker_shares.copy()
        else:
            # Manage portfolio for subsequent weeks
            prev_week_key = list(etf_histories.keys())[i - 1]
            ticker_shares = manage_etf_portfolio_weekly(
                aligned_top_etfs_weekly[prev_week_key],
                aligned_top_etfs_weekly[current_week_key],
                prev_week_key,
                current_week_key,
                ticker_shares,
                etf_histories
            )
            ticker_shares_per_week[current_week_key] = ticker_shares.copy()

    # Define the first trading day of the 49th week
    first_trading_day_49w = '2024-12-01'

    # Identify the 48th and 49th week date ranges
    week_48_range = list(ticker_shares_per_week.keys())[-1]
    week_49_start = first_trading_day_49w
    print(f"Using data for the 48th week: {week_48_range}")
    print(f"Fetching data starting from the first trading day of the 49th week: {week_49_start}")

    week_49_end = '2024-12-06'
    etf_values_49w = {}

    # Ensure 48th week data exists
    if week_48_range in ticker_shares_per_week:
        ticker_shares_48w = ticker_shares_per_week[week_48_range]

        # Fetch the first trading day price of the 49th week for each ETF
        for ticker, shares in ticker_shares_48w.items():
            print(f"Fetching data for ticker {ticker} starting from {week_49_start}...")
            data = yf.download(ticker, start=week_49_start, end=week_49_end)

            if not data.empty:
                closing_price_49w = data['Close'].iloc[0]
                total_value = shares * closing_price_49w
                etf_values_49w[ticker] = total_value
                print(f"{ticker}: {shares:.2f} shares at ${closing_price_49w:.2f} each, total value: ${total_value:.2f}")
            else:
                print(f"{ticker}: No data available for the 49th week's first trading day.")
    else:
        print(f"No data available in ticker_shares_per_week for the 48th week: {week_48_range}")

    # Display total portfolio value for the 49th week's first trading day
    if etf_values_49w:
        print("\nETF values on the 49th week's first trading day:")
        total_value = sum(etf_values_49w.values())
        print(f"Total portfolio value: {total_value:.2f}")
        for ticker, value in etf_values_49w.items():
            print(f"{ticker}: {value:.2f}")
    else:
        print("No values could be calculated for the 49th week's first trading day.")

    return ticker_shares_per_week

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_week_wo_smoothing = main_weekly(tickers, results, smoothing=False)
# Out:
# Fetching data for SMH from 2024-01-01 to 2024-01-07...
# Fetching data for SOXX from 2024-01-01 to 2024-01-07...
# Fetching data for PSI from 2024-01-01 to 2024-01-07...
# Fetching data for XSD from 2024-01-01 to 2024-01-07...
# Fetching data for IYW from 2024-01-01 to 2024-01-07...
# Fetching data for XLK from 2024-01-01 to 2024-01-07...
# Fetching data for VGT from 2024-01-01 to 2024-01-07...
# Fetching data for FTEC from 2024-01-01 to 2024-01-07...
# Fetching data for IGM from 2024-01-01 to 2024-01-07...
# Fetching data for IXN from 2024-01-01 to 2024-01-07...
# Fetching data for SMH from 2024-01-08 to 2024-01-14...
# Fetching data for SOXX from 2024-01-08 to 2024-01-14...
# Fetching data for PSI from 2024-01-08 to 2024-01-14...
# Fetching data for XSD from 2024-01-08 to 2024-01-14...
# Fetching data for IYW from 2024-01-08 to 2024-01-14...
# Fetching data for XLK from 2024-01-08 to 2024-01-14...
# Fetching data for VGT from 2024-01-08 to 2024-01-14...
# Fetching data for FTEC from 2024-01-08 to 2024-01-14...
# Fetching data for IGM from 2024-01-08 to 2024-01-14...
# Fetching data for IXN from 2024-01-08 to 2024-01-14...
# Fetching data for SMH from 2024-01-15 to 2024-01-21...
# Fetching data for SOXX from 2024-01-15 to 2024-01-21...
# Fetching data for PSI from 2024-01-15 to 2024-01-21...
# Fetching data for XSD from 2024-01-15 to 2024-01-21...
# Fetching data for IYW from 2024-01-15 to 2024-01-21...
# Fetching data for XLK from 2024-01-15 to 2024-01-21...
# Fetching data for VGT from 2024-01-15 to 2024-01-21...
# Fetching data for FTEC from 2024-01-15 to 2024-01-21...
# Fetching data for IGM from 2024-01-15 to 2024-01-21...
# Fetching data for IXN from 2024-01-15 to 2024-01-21...
# Fetching data for SMH from 2024-01-22 to 2024-01-28...
# Fetching data for SOXX from 2024-01-22 to 2024-01-28...
# Fetching data for PSI from 2024-01-22 to 2024-01-28...
# Fetching data for XSD from 2024-01-22 to 2024-01-28...
# Fetching data for IYW from 2024-01-22 to 2024-01-28...
# Fetching data for XLK from 2024-01-22 to 2024-01-28...
# Fetching data for VGT from 2024-01-22 to 2024-01-28...
# Fetching data for FTEC from 2024-01-22 to 2024-01-28...
# Fetching data for IGM from 2024-01-22 to 2024-01-28...
# Fetching data for IXN from 2024-01-22 to 2024-01-28...
# Fetching data for SMH from 2024-01-29 to 2024-02-04...
# Fetching data for SOXX from 2024-01-29 to 2024-02-04...
# Fetching data for PSI from 2024-01-29 to 2024-02-04...
# Fetching data for XSD from 2024-01-29 to 2024-02-04...
# Fetching data for IYW from 2024-01-29 to 2024-02-04...
# Fetching data for XLK from 2024-01-29 to 2024-02-04...
# Fetching data for VGT from 2024-01-29 to 2024-02-04...
# Fetching data for FTEC from 2024-01-29 to 2024-02-04...
# Fetching data for IGM from 2024-01-29 to 2024-02-04...
# Fetching data for IXN from 2024-01-29 to 2024-02-04...
# Fetching data for SMH from 2024-02-05 to 2024-02-11...
# Fetching data for SOXX from 2024-02-05 to 2024-02-11...
# Fetching data for PSI from 2024-02-05 to 2024-02-11...
# Fetching data for XSD from 2024-02-05 to 2024-02-11...
# Fetching data for IYW from 2024-02-05 to 2024-02-11...
# Fetching data for XLK from 2024-02-05 to 2024-02-11...
# Fetching data for VGT from 2024-02-05 to 2024-02-11...
# Fetching data for FTEC from 2024-02-05 to 2024-02-11...
# Fetching data for IGM from 2024-02-05 to 2024-02-11...
# Fetching data for IXN from 2024-02-05 to 2024-02-11...
# Fetching data for SMH from 2024-02-12 to 2024-02-18...
# Fetching data for SOXX from 2024-02-12 to 2024-02-18...
# Fetching data for PSI from 2024-02-12 to 2024-02-18...
# Fetching data for XSD from 2024-02-12 to 2024-02-18...
# Fetching data for IYW from 2024-02-12 to 2024-02-18...
# Fetching data for XLK from 2024-02-12 to 2024-02-18...
# Fetching data for VGT from 2024-02-12 to 2024-02-18...
# Fetching data for FTEC from 2024-02-12 to 2024-02-18...
# Fetching data for IGM from 2024-02-12 to 2024-02-18...
# Fetching data for IXN from 2024-02-12 to 2024-02-18...
# Fetching data for SMH from 2024-02-19 to 2024-02-25...
# Fetching data for SOXX from 2024-02-19 to 2024-02-25...
# Fetching data for PSI from 2024-02-19 to 2024-02-25...
# Fetching data for XSD from 2024-02-19 to 2024-02-25...
# Fetching data for IYW from 2024-02-19 to 2024-02-25...
# Fetching data for XLK from 2024-02-19 to 2024-02-25...
# Fetching data for VGT from 2024-02-19 to 2024-02-25...
# Fetching data for FTEC from 2024-02-19 to 2024-02-25...
# Fetching data for IGM from 2024-02-19 to 2024-02-25...
# Fetching data for IXN from 2024-02-19 to 2024-02-25...
# Fetching data for SMH from 2024-02-26 to 2024-03-03...
# Fetching data for SOXX from 2024-02-26 to 2024-03-03...
# Fetching data for PSI from 2024-02-26 to 2024-03-03...
# Fetching data for XSD from 2024-02-26 to 2024-03-03...
# Fetching data for IYW from 2024-02-26 to 2024-03-03...
# Fetching data for XLK from 2024-02-26 to 2024-03-03...
# Fetching data for VGT from 2024-02-26 to 2024-03-03...
# Fetching data for FTEC from 2024-02-26 to 2024-03-03...
# Fetching data for IGM from 2024-02-26 to 2024-03-03...
# Fetching data for IXN from 2024-02-26 to 2024-03-03...
# Fetching data for SMH from 2024-03-04 to 2024-03-10...
# Fetching data for SOXX from 2024-03-04 to 2024-03-10...
# Fetching data for PSI from 2024-03-04 to 2024-03-10...
# Fetching data for XSD from 2024-03-04 to 2024-03-10...
# Fetching data for IYW from 2024-03-04 to 2024-03-10...
# Fetching data for XLK from 2024-03-04 to 2024-03-10...
# Fetching data for VGT from 2024-03-04 to 2024-03-10...
# Fetching data for FTEC from 2024-03-04 to 2024-03-10...
# Fetching data for IGM from 2024-03-04 to 2024-03-10...
# Fetching data for IXN from 2024-03-04 to 2024-03-10...
# Fetching data for SMH from 2024-03-11 to 2024-03-17...
# Fetching data for SOXX from 2024-03-11 to 2024-03-17...
# Fetching data for PSI from 2024-03-11 to 2024-03-17...
# Fetching data for XSD from 2024-03-11 to 2024-03-17...
# Fetching data for IYW from 2024-03-11 to 2024-03-17...
# Fetching data for XLK from 2024-03-11 to 2024-03-17...
# Fetching data for VGT from 2024-03-11 to 2024-03-17...
# Fetching data for FTEC from 2024-03-11 to 2024-03-17...
# Fetching data for IGM from 2024-03-11 to 2024-03-17...
# Fetching data for IXN from 2024-03-11 to 2024-03-17...
# Fetching data for SMH from 2024-03-18 to 2024-03-24...
# Fetching data for SOXX from 2024-03-18 to 2024-03-24...
# Fetching data for PSI from 2024-03-18 to 2024-03-24...
# Fetching data for XSD from 2024-03-18 to 2024-03-24...
# Fetching data for IYW from 2024-03-18 to 2024-03-24...
# Fetching data for XLK from 2024-03-18 to 2024-03-24...
# Fetching data for VGT from 2024-03-18 to 2024-03-24...
# Fetching data for FTEC from 2024-03-18 to 2024-03-24...
# Fetching data for IGM from 2024-03-18 to 2024-03-24...
# Fetching data for IXN from 2024-03-18 to 2024-03-24...
# Fetching data for SMH from 2024-03-25 to 2024-03-31...
# Fetching data for SOXX from 2024-03-25 to 2024-03-31...
# Fetching data for PSI from 2024-03-25 to 2024-03-31...
# Fetching data for XSD from 2024-03-25 to 2024-03-31...
# Fetching data for IYW from 2024-03-25 to 2024-03-31...
# Fetching data for XLK from 2024-03-25 to 2024-03-31...
# Fetching data for VGT from 2024-03-25 to 2024-03-31...
# Fetching data for FTEC from 2024-03-25 to 2024-03-31...
# Fetching data for IGM from 2024-03-25 to 2024-03-31...
# Fetching data for IXN from 2024-03-25 to 2024-03-31...
# Fetching data for SMH from 2024-04-01 to 2024-04-07...
# Fetching data for SOXX from 2024-04-01 to 2024-04-07...
# Fetching data for PSI from 2024-04-01 to 2024-04-07...
# Fetching data for XSD from 2024-04-01 to 2024-04-07...
# Fetching data for IYW from 2024-04-01 to 2024-04-07...
# Fetching data for XLK from 2024-04-01 to 2024-04-07...
# Fetching data for VGT from 2024-04-01 to 2024-04-07...
# Fetching data for FTEC from 2024-04-01 to 2024-04-07...
# Fetching data for IGM from 2024-04-01 to 2024-04-07...
# Fetching data for IXN from 2024-04-01 to 2024-04-07...
# Fetching data for SMH from 2024-04-08 to 2024-04-14...
# Fetching data for SOXX from 2024-04-08 to 2024-04-14...
# Fetching data for PSI from 2024-04-08 to 2024-04-14...
# Fetching data for XSD from 2024-04-08 to 2024-04-14...
# Fetching data for IYW from 2024-04-08 to 2024-04-14...
# Fetching data for XLK from 2024-04-08 to 2024-04-14...
# Fetching data for VGT from 2024-04-08 to 2024-04-14...
# Fetching data for FTEC from 2024-04-08 to 2024-04-14...
# Fetching data for IGM from 2024-04-08 to 2024-04-14...
# Fetching data for IXN from 2024-04-08 to 2024-04-14...
# Fetching data for SMH from 2024-04-15 to 2024-04-21...
# Fetching data for SOXX from 2024-04-15 to 2024-04-21...
# Fetching data for PSI from 2024-04-15 to 2024-04-21...
# Fetching data for XSD from 2024-04-15 to 2024-04-21...
# Fetching data for IYW from 2024-04-15 to 2024-04-21...
# Fetching data for XLK from 2024-04-15 to 2024-04-21...
# Fetching data for VGT from 2024-04-15 to 2024-04-21...
# Fetching data for FTEC from 2024-04-15 to 2024-04-21...
# Fetching data for IGM from 2024-04-15 to 2024-04-21...
# Fetching data for IXN from 2024-04-15 to 2024-04-21...
# Fetching data for SMH from 2024-04-22 to 2024-04-28...
# Fetching data for SOXX from 2024-04-22 to 2024-04-28...
# Fetching data for PSI from 2024-04-22 to 2024-04-28...
# Fetching data for XSD from 2024-04-22 to 2024-04-28...
# Fetching data for IYW from 2024-04-22 to 2024-04-28...
# Fetching data for XLK from 2024-04-22 to 2024-04-28...
# Fetching data for VGT from 2024-04-22 to 2024-04-28...
# Fetching data for FTEC from 2024-04-22 to 2024-04-28...
# Fetching data for IGM from 2024-04-22 to 2024-04-28...
# Fetching data for IXN from 2024-04-22 to 2024-04-28...
# Fetching data for SMH from 2024-04-29 to 2024-05-05...
# Fetching data for SOXX from 2024-04-29 to 2024-05-05...
# Fetching data for PSI from 2024-04-29 to 2024-05-05...
# Fetching data for XSD from 2024-04-29 to 2024-05-05...
# Fetching data for IYW from 2024-04-29 to 2024-05-05...
# Fetching data for XLK from 2024-04-29 to 2024-05-05...
# Fetching data for VGT from 2024-04-29 to 2024-05-05...
# Fetching data for FTEC from 2024-04-29 to 2024-05-05...
# Fetching data for IGM from 2024-04-29 to 2024-05-05...
# Fetching data for IXN from 2024-04-29 to 2024-05-05...
# Fetching data for SMH from 2024-05-06 to 2024-05-12...
# Fetching data for SOXX from 2024-05-06 to 2024-05-12...
# Fetching data for PSI from 2024-05-06 to 2024-05-12...
# Fetching data for XSD from 2024-05-06 to 2024-05-12...
# Fetching data for IYW from 2024-05-06 to 2024-05-12...
# Fetching data for XLK from 2024-05-06 to 2024-05-12...
# Fetching data for VGT from 2024-05-06 to 2024-05-12...
# Fetching data for FTEC from 2024-05-06 to 2024-05-12...
# Fetching data for IGM from 2024-05-06 to 2024-05-12...
# Fetching data for IXN from 2024-05-06 to 2024-05-12...
# Fetching data for SMH from 2024-05-13 to 2024-05-19...
# Fetching data for SOXX from 2024-05-13 to 2024-05-19...
# Fetching data for PSI from 2024-05-13 to 2024-05-19...
# Fetching data for XSD from 2024-05-13 to 2024-05-19...
# Fetching data for IYW from 2024-05-13 to 2024-05-19...
# Fetching data for XLK from 2024-05-13 to 2024-05-19...
# Fetching data for VGT from 2024-05-13 to 2024-05-19...
# Fetching data for FTEC from 2024-05-13 to 2024-05-19...
# Fetching data for IGM from 2024-05-13 to 2024-05-19...
# Fetching data for IXN from 2024-05-13 to 2024-05-19...
# Fetching data for SMH from 2024-05-20 to 2024-05-26...
# Fetching data for SOXX from 2024-05-20 to 2024-05-26...
# Fetching data for PSI from 2024-05-20 to 2024-05-26...
# Fetching data for XSD from 2024-05-20 to 2024-05-26...
# Fetching data for IYW from 2024-05-20 to 2024-05-26...
# Fetching data for XLK from 2024-05-20 to 2024-05-26...
# Fetching data for VGT from 2024-05-20 to 2024-05-26...
# Fetching data for FTEC from 2024-05-20 to 2024-05-26...
# Fetching data for IGM from 2024-05-20 to 2024-05-26...
# Fetching data for IXN from 2024-05-20 to 2024-05-26...
# Fetching data for SMH from 2024-05-27 to 2024-06-02...
# Fetching data for SOXX from 2024-05-27 to 2024-06-02...
# Fetching data for PSI from 2024-05-27 to 2024-06-02...
# Fetching data for XSD from 2024-05-27 to 2024-06-02...
# Fetching data for IYW from 2024-05-27 to 2024-06-02...
# Fetching data for XLK from 2024-05-27 to 2024-06-02...
# Fetching data for VGT from 2024-05-27 to 2024-06-02...
# Fetching data for FTEC from 2024-05-27 to 2024-06-02...
# Fetching data for IGM from 2024-05-27 to 2024-06-02...
# Fetching data for IXN from 2024-05-27 to 2024-06-02...
# Fetching data for SMH from 2024-06-03 to 2024-06-09...
# Fetching data for SOXX from 2024-06-03 to 2024-06-09...
# Fetching data for PSI from 2024-06-03 to 2024-06-09...
# Fetching data for XSD from 2024-06-03 to 2024-06-09...
# Fetching data for IYW from 2024-06-03 to 2024-06-09...
# Fetching data for XLK from 2024-06-03 to 2024-06-09...
# Fetching data for VGT from 2024-06-03 to 2024-06-09...
# Fetching data for FTEC from 2024-06-03 to 2024-06-09...
# Fetching data for IGM from 2024-06-03 to 2024-06-09...
# Fetching data for IXN from 2024-06-03 to 2024-06-09...
# Fetching data for SMH from 2024-06-10 to 2024-06-16...
# Fetching data for SOXX from 2024-06-10 to 2024-06-16...
# Fetching data for PSI from 2024-06-10 to 2024-06-16...
# Fetching data for XSD from 2024-06-10 to 2024-06-16...
# Fetching data for IYW from 2024-06-10 to 2024-06-16...
# Fetching data for XLK from 2024-06-10 to 2024-06-16...
# Fetching data for VGT from 2024-06-10 to 2024-06-16...
# Fetching data for FTEC from 2024-06-10 to 2024-06-16...
# Fetching data for IGM from 2024-06-10 to 2024-06-16...
# Fetching data for IXN from 2024-06-10 to 2024-06-16...
# Fetching data for SMH from 2024-06-17 to 2024-06-23...
# Fetching data for SOXX from 2024-06-17 to 2024-06-23...
# Fetching data for PSI from 2024-06-17 to 2024-06-23...
# Fetching data for XSD from 2024-06-17 to 2024-06-23...
# Fetching data for IYW from 2024-06-17 to 2024-06-23...
# Fetching data for XLK from 2024-06-17 to 2024-06-23...
# Fetching data for VGT from 2024-06-17 to 2024-06-23...
# Fetching data for FTEC from 2024-06-17 to 2024-06-23...
# Fetching data for IGM from 2024-06-17 to 2024-06-23...
# Fetching data for IXN from 2024-06-17 to 2024-06-23...
# Fetching data for SMH from 2024-06-24 to 2024-06-30...
# Fetching data for SOXX from 2024-06-24 to 2024-06-30...
# Fetching data for PSI from 2024-06-24 to 2024-06-30...
# Fetching data for XSD from 2024-06-24 to 2024-06-30...
# Fetching data for IYW from 2024-06-24 to 2024-06-30...
# Fetching data for XLK from 2024-06-24 to 2024-06-30...
# Fetching data for VGT from 2024-06-24 to 2024-06-30...
# Fetching data for FTEC from 2024-06-24 to 2024-06-30...
# Fetching data for IGM from 2024-06-24 to 2024-06-30...
# Fetching data for IXN from 2024-06-24 to 2024-06-30...
# Fetching data for SMH from 2024-07-01 to 2024-07-07...
# Fetching data for SOXX from 2024-07-01 to 2024-07-07...
# Fetching data for PSI from 2024-07-01 to 2024-07-07...
# Fetching data for XSD from 2024-07-01 to 2024-07-07...
# Fetching data for IYW from 2024-07-01 to 2024-07-07...
# Fetching data for XLK from 2024-07-01 to 2024-07-07...
# Fetching data for VGT from 2024-07-01 to 2024-07-07...
# Fetching data for FTEC from 2024-07-01 to 2024-07-07...
# Fetching data for IGM from 2024-07-01 to 2024-07-07...
# Fetching data for IXN from 2024-07-01 to 2024-07-07...
# Fetching data for SMH from 2024-07-08 to 2024-07-14...
# Fetching data for SOXX from 2024-07-08 to 2024-07-14...
# Fetching data for PSI from 2024-07-08 to 2024-07-14...
# Fetching data for XSD from 2024-07-08 to 2024-07-14...
# Fetching data for IYW from 2024-07-08 to 2024-07-14...
# Fetching data for XLK from 2024-07-08 to 2024-07-14...
# Fetching data for VGT from 2024-07-08 to 2024-07-14...
# Fetching data for FTEC from 2024-07-08 to 2024-07-14...
# Fetching data for IGM from 2024-07-08 to 2024-07-14...
# Fetching data for IXN from 2024-07-08 to 2024-07-14...
# Fetching data for SMH from 2024-07-15 to 2024-07-21...
# Fetching data for SOXX from 2024-07-15 to 2024-07-21...
# Fetching data for PSI from 2024-07-15 to 2024-07-21...
# Fetching data for XSD from 2024-07-15 to 2024-07-21...
# Fetching data for IYW from 2024-07-15 to 2024-07-21...
# Fetching data for XLK from 2024-07-15 to 2024-07-21...
# Fetching data for VGT from 2024-07-15 to 2024-07-21...
# Fetching data for FTEC from 2024-07-15 to 2024-07-21...
# Fetching data for IGM from 2024-07-15 to 2024-07-21...
# Fetching data for IXN from 2024-07-15 to 2024-07-21...
# Fetching data for SMH from 2024-07-22 to 2024-07-28...
# Fetching data for SOXX from 2024-07-22 to 2024-07-28...
# Fetching data for PSI from 2024-07-22 to 2024-07-28...
# Fetching data for XSD from 2024-07-22 to 2024-07-28...
# Fetching data for IYW from 2024-07-22 to 2024-07-28...
# Fetching data for XLK from 2024-07-22 to 2024-07-28...
# Fetching data for VGT from 2024-07-22 to 2024-07-28...
# Fetching data for FTEC from 2024-07-22 to 2024-07-28...
# Fetching data for IGM from 2024-07-22 to 2024-07-28...
# Fetching data for IXN from 2024-07-22 to 2024-07-28...
# Fetching data for SMH from 2024-07-29 to 2024-08-04...
# Fetching data for SOXX from 2024-07-29 to 2024-08-04...
# Fetching data for PSI from 2024-07-29 to 2024-08-04...
# Fetching data for XSD from 2024-07-29 to 2024-08-04...
# Fetching data for IYW from 2024-07-29 to 2024-08-04...
# Fetching data for XLK from 2024-07-29 to 2024-08-04...
# Fetching data for VGT from 2024-07-29 to 2024-08-04...
# Fetching data for FTEC from 2024-07-29 to 2024-08-04...
# Fetching data for IGM from 2024-07-29 to 2024-08-04...
# Fetching data for IXN from 2024-07-29 to 2024-08-04...
# Fetching data for SMH from 2024-08-05 to 2024-08-11...
# Fetching data for SOXX from 2024-08-05 to 2024-08-11...
# Fetching data for PSI from 2024-08-05 to 2024-08-11...
# Fetching data for XSD from 2024-08-05 to 2024-08-11...
# Fetching data for IYW from 2024-08-05 to 2024-08-11...
# Fetching data for XLK from 2024-08-05 to 2024-08-11...
# Fetching data for VGT from 2024-08-05 to 2024-08-11...
# Fetching data for FTEC from 2024-08-05 to 2024-08-11...
# Fetching data for IGM from 2024-08-05 to 2024-08-11...
# Fetching data for IXN from 2024-08-05 to 2024-08-11...
# Fetching data for SMH from 2024-08-12 to 2024-08-18...
# Fetching data for SOXX from 2024-08-12 to 2024-08-18...
# Fetching data for PSI from 2024-08-12 to 2024-08-18...
# Fetching data for XSD from 2024-08-12 to 2024-08-18...
# Fetching data for IYW from 2024-08-12 to 2024-08-18...
# Fetching data for XLK from 2024-08-12 to 2024-08-18...
# Fetching data for VGT from 2024-08-12 to 2024-08-18...
# Fetching data for FTEC from 2024-08-12 to 2024-08-18...
# Fetching data for IGM from 2024-08-12 to 2024-08-18...
# Fetching data for IXN from 2024-08-12 to 2024-08-18...
# Fetching data for SMH from 2024-08-19 to 2024-08-25...
# Fetching data for SOXX from 2024-08-19 to 2024-08-25...
# Fetching data for PSI from 2024-08-19 to 2024-08-25...
# Fetching data for XSD from 2024-08-19 to 2024-08-25...
# Fetching data for IYW from 2024-08-19 to 2024-08-25...
# Fetching data for XLK from 2024-08-19 to 2024-08-25...
# Fetching data for VGT from 2024-08-19 to 2024-08-25...
# Fetching data for FTEC from 2024-08-19 to 2024-08-25...
# Fetching data for IGM from 2024-08-19 to 2024-08-25...
# Fetching data for IXN from 2024-08-19 to 2024-08-25...
# Fetching data for SMH from 2024-08-26 to 2024-09-01...
# Fetching data for SOXX from 2024-08-26 to 2024-09-01...
# Fetching data for PSI from 2024-08-26 to 2024-09-01...
# Fetching data for XSD from 2024-08-26 to 2024-09-01...
# Fetching data for IYW from 2024-08-26 to 2024-09-01...
# Fetching data for XLK from 2024-08-26 to 2024-09-01...
# Fetching data for VGT from 2024-08-26 to 2024-09-01...
# Fetching data for FTEC from 2024-08-26 to 2024-09-01...
# Fetching data for IGM from 2024-08-26 to 2024-09-01...
# Fetching data for IXN from 2024-08-26 to 2024-09-01...
# Fetching data for SMH from 2024-09-02 to 2024-09-08...
# Fetching data for SOXX from 2024-09-02 to 2024-09-08...
# Fetching data for PSI from 2024-09-02 to 2024-09-08...
# Fetching data for XSD from 2024-09-02 to 2024-09-08...
# Fetching data for IYW from 2024-09-02 to 2024-09-08...
# Fetching data for XLK from 2024-09-02 to 2024-09-08...
# Fetching data for VGT from 2024-09-02 to 2024-09-08...
# Fetching data for FTEC from 2024-09-02 to 2024-09-08...
# Fetching data for IGM from 2024-09-02 to 2024-09-08...
# Fetching data for IXN from 2024-09-02 to 2024-09-08...
# Fetching data for SMH from 2024-09-09 to 2024-09-15...
# Fetching data for SOXX from 2024-09-09 to 2024-09-15...
# Fetching data for PSI from 2024-09-09 to 2024-09-15...
# Fetching data for XSD from 2024-09-09 to 2024-09-15...
# Fetching data for IYW from 2024-09-09 to 2024-09-15...
# Fetching data for XLK from 2024-09-09 to 2024-09-15...
# Fetching data for VGT from 2024-09-09 to 2024-09-15...
# Fetching data for FTEC from 2024-09-09 to 2024-09-15...
# Fetching data for IGM from 2024-09-09 to 2024-09-15...
# Fetching data for IXN from 2024-09-09 to 2024-09-15...
# Fetching data for SMH from 2024-09-16 to 2024-09-22...
# Fetching data for SOXX from 2024-09-16 to 2024-09-22...
# Fetching data for PSI from 2024-09-16 to 2024-09-22...
# Fetching data for XSD from 2024-09-16 to 2024-09-22...
# Fetching data for IYW from 2024-09-16 to 2024-09-22...
# Fetching data for XLK from 2024-09-16 to 2024-09-22...
# Fetching data for VGT from 2024-09-16 to 2024-09-22...
# Fetching data for FTEC from 2024-09-16 to 2024-09-22...
# Fetching data for IGM from 2024-09-16 to 2024-09-22...
# Fetching data for IXN from 2024-09-16 to 2024-09-22...
# Fetching data for SMH from 2024-09-23 to 2024-09-29...
# Fetching data for SOXX from 2024-09-23 to 2024-09-29...
# Fetching data for PSI from 2024-09-23 to 2024-09-29...
# Fetching data for XSD from 2024-09-23 to 2024-09-29...
# Fetching data for IYW from 2024-09-23 to 2024-09-29...
# Fetching data for XLK from 2024-09-23 to 2024-09-29...
# Fetching data for VGT from 2024-09-23 to 2024-09-29...
# Fetching data for FTEC from 2024-09-23 to 2024-09-29...
# Fetching data for IGM from 2024-09-23 to 2024-09-29...
# Fetching data for IXN from 2024-09-23 to 2024-09-29...
# Fetching data for SMH from 2024-09-30 to 2024-10-06...
# Fetching data for SOXX from 2024-09-30 to 2024-10-06...
# Fetching data for PSI from 2024-09-30 to 2024-10-06...
# Fetching data for XSD from 2024-09-30 to 2024-10-06...
# Fetching data for IYW from 2024-09-30 to 2024-10-06...
# Fetching data for XLK from 2024-09-30 to 2024-10-06...
# Fetching data for VGT from 2024-09-30 to 2024-10-06...
# Fetching data for FTEC from 2024-09-30 to 2024-10-06...
# Fetching data for IGM from 2024-09-30 to 2024-10-06...
# Fetching data for IXN from 2024-09-30 to 2024-10-06...
# Fetching data for SMH from 2024-10-07 to 2024-10-13...
# Fetching data for SOXX from 2024-10-07 to 2024-10-13...
# Fetching data for PSI from 2024-10-07 to 2024-10-13...
# Fetching data for XSD from 2024-10-07 to 2024-10-13...
# Fetching data for IYW from 2024-10-07 to 2024-10-13...
# Fetching data for XLK from 2024-10-07 to 2024-10-13...
# Fetching data for VGT from 2024-10-07 to 2024-10-13...
# Fetching data for FTEC from 2024-10-07 to 2024-10-13...
# Fetching data for IGM from 2024-10-07 to 2024-10-13...
# Fetching data for IXN from 2024-10-07 to 2024-10-13...
# Fetching data for SMH from 2024-10-14 to 2024-10-20...
# Fetching data for SOXX from 2024-10-14 to 2024-10-20...
# Fetching data for PSI from 2024-10-14 to 2024-10-20...
# Fetching data for XSD from 2024-10-14 to 2024-10-20...
# Fetching data for IYW from 2024-10-14 to 2024-10-20...
# Fetching data for XLK from 2024-10-14 to 2024-10-20...
# Fetching data for VGT from 2024-10-14 to 2024-10-20...
# Fetching data for FTEC from 2024-10-14 to 2024-10-20...
# Fetching data for IGM from 2024-10-14 to 2024-10-20...
# Fetching data for IXN from 2024-10-14 to 2024-10-20...
# Fetching data for SMH from 2024-10-21 to 2024-10-27...
# Fetching data for SOXX from 2024-10-21 to 2024-10-27...
# Fetching data for PSI from 2024-10-21 to 2024-10-27...
# Fetching data for XSD from 2024-10-21 to 2024-10-27...
# Fetching data for IYW from 2024-10-21 to 2024-10-27...
# Fetching data for XLK from 2024-10-21 to 2024-10-27...
# Fetching data for VGT from 2024-10-21 to 2024-10-27...
# Fetching data for FTEC from 2024-10-21 to 2024-10-27...
# Fetching data for IGM from 2024-10-21 to 2024-10-27...
# Fetching data for IXN from 2024-10-21 to 2024-10-27...
# Fetching data for SMH from 2024-10-28 to 2024-11-03...
# Fetching data for SOXX from 2024-10-28 to 2024-11-03...
# Fetching data for PSI from 2024-10-28 to 2024-11-03...
# Fetching data for XSD from 2024-10-28 to 2024-11-03...
# Fetching data for IYW from 2024-10-28 to 2024-11-03...
# Fetching data for XLK from 2024-10-28 to 2024-11-03...
# Fetching data for VGT from 2024-10-28 to 2024-11-03...
# Fetching data for FTEC from 2024-10-28 to 2024-11-03...
# Fetching data for IGM from 2024-10-28 to 2024-11-03...
# Fetching data for IXN from 2024-10-28 to 2024-11-03...
# Fetching data for SMH from 2024-11-04 to 2024-11-10...
# Fetching data for SOXX from 2024-11-04 to 2024-11-10...
# Fetching data for PSI from 2024-11-04 to 2024-11-10...
# Fetching data for XSD from 2024-11-04 to 2024-11-10...
# Fetching data for IYW from 2024-11-04 to 2024-11-10...
# Fetching data for XLK from 2024-11-04 to 2024-11-10...
# Fetching data for VGT from 2024-11-04 to 2024-11-10...
# Fetching data for FTEC from 2024-11-04 to 2024-11-10...
# Fetching data for IGM from 2024-11-04 to 2024-11-10...
# Fetching data for IXN from 2024-11-04 to 2024-11-10...
# Fetching data for SMH from 2024-11-11 to 2024-11-17...
# Fetching data for SOXX from 2024-11-11 to 2024-11-17...
# Fetching data for PSI from 2024-11-11 to 2024-11-17...
# Fetching data for XSD from 2024-11-11 to 2024-11-17...
# Fetching data for IYW from 2024-11-11 to 2024-11-17...
# Fetching data for XLK from 2024-11-11 to 2024-11-17...
# Fetching data for VGT from 2024-11-11 to 2024-11-17...
# Fetching data for FTEC from 2024-11-11 to 2024-11-17...
# Fetching data for IGM from 2024-11-11 to 2024-11-17...
# Fetching data for IXN from 2024-11-11 to 2024-11-17...
# Fetching data for SMH from 2024-11-18 to 2024-11-24...
# Fetching data for SOXX from 2024-11-18 to 2024-11-24...
# Fetching data for PSI from 2024-11-18 to 2024-11-24...
# Fetching data for XSD from 2024-11-18 to 2024-11-24...
# Fetching data for IYW from 2024-11-18 to 2024-11-24...
# Fetching data for XLK from 2024-11-18 to 2024-11-24...
# Fetching data for VGT from 2024-11-18 to 2024-11-24...
# Fetching data for FTEC from 2024-11-18 to 2024-11-24...
# Fetching data for IGM from 2024-11-18 to 2024-11-24...
# Fetching data for IXN from 2024-11-18 to 2024-11-24...
# Fetching data for SMH from 2024-11-25 to 2024-12-01...
# Fetching data for SOXX from 2024-11-25 to 2024-12-01...
# Fetching data for PSI from 2024-11-25 to 2024-12-01...
# Fetching data for XSD from 2024-11-25 to 2024-12-01...
# Fetching data for IYW from 2024-11-25 to 2024-12-01...
# Fetching data for XLK from 2024-11-25 to 2024-12-01...
# Fetching data for VGT from 2024-11-25 to 2024-12-01...
# Fetching data for FTEC from 2024-11-25 to 2024-12-01...
# Fetching data for IGM from 2024-11-25 to 2024-12-01...
# Fetching data for IXN from 2024-11-25 to 2024-12-01...
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1 -0.273633
# 1  SOXX   1w             0.1 -0.653833
# 2   PSI   1w             0.1 -2.046420
# 3   XSD   1w             0.1 -6.342072
# 4   IYW   1w             0.1  1.704523
# Top ETFs for 2024-01-01 to 2024-01-07: ['FTEC', 'IYW']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1  0.877758
# 1  SOXX   2w             0.1 -0.816590
# 2   PSI   2w             0.1 -3.012088
# 3   XSD   2w             0.1 -6.144272
# 4   IYW   2w             0.1  2.748177
# Top ETFs for 2024-01-08 to 2024-01-14: ['FTEC', 'IYW']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  1.120987
# 1  SOXX   3w             0.1  0.051249
# 2   PSI   3w             0.1 -2.262608
# 3   XSD   3w             0.1 -4.229718
# 4   IYW   3w             0.1  1.879964
# Top ETFs for 2024-01-15 to 2024-01-21: ['FTEC', 'IYW']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1  1.037115
# 1  SOXX   4w             0.1 -1.423059
# 2   PSI   4w             0.1 -2.232598
# 3   XSD   4w             0.1 -4.009009
# 4   IYW   4w             0.1  3.735438
# Top ETFs for 2024-01-22 to 2024-01-28: ['IYW', 'FTEC']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1  1.283540
# 1  SOXX   5w             0.1 -0.821762
# 2   PSI   5w             0.1 -2.119268
# 3   XSD   5w             0.1 -4.393784
# 4   IYW   5w             0.1  2.751580
# Top ETFs for 2024-01-29 to 2024-02-04: ['FTEC', 'IYW']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  0.331714
# 1  SOXX   6w             0.1 -1.422122
# 2   PSI   6w             0.1 -1.801717
# 3   XSD   6w             0.1 -5.577382
# 4   IYW   6w             0.1  3.057427
# Top ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IYW']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1 -0.366085
# 1  SOXX   7w             0.1 -1.048297
# 2   PSI   7w             0.1 -0.585695
# 3   XSD   7w             0.1 -4.429455
# 4   IYW   7w             0.1  4.506262
# Top ETFs for 2024-02-12 to 2024-02-18: ['IYW', 'FTEC']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1 -0.157113
# 1  SOXX   8w             0.1 -0.104222
# 2   PSI   8w             0.1 -1.558730
# 3   XSD   8w             0.1 -3.902357
# 4   IYW   8w             0.1  1.801791
# Top ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IYW']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1  0.480121
# 1  SOXX   9w             0.1 -1.268444
# 2   PSI   9w             0.1 -1.929694
# 3   XSD   9w             0.1 -4.293065
# 4   IYW   9w             0.1  3.610984
# Top ETFs for 2024-02-26 to 2024-03-03: ['IYW', 'XLK']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1 -0.170948
# 1  SOXX  10w             0.1 -1.055067
# 2   PSI  10w             0.1 -1.266176
# 3   XSD  10w             0.1 -5.050478
# 4   IYW  10w             0.1  2.749374
# Top ETFs for 2024-03-04 to 2024-03-10: ['FTEC', 'IYW']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1  0.220710
# 1  SOXX  11w             0.1 -0.927141
# 2   PSI  11w             0.1 -2.461472
# 3   XSD  11w             0.1 -3.787995
# 4   IYW  11w             0.1  2.364383
# Top ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1  1.110698
# 1  SOXX  12w             0.1 -0.039911
# 2   PSI  12w             0.1 -1.800020
# 3   XSD  12w             0.1 -4.499218
# 4   IYW  12w             0.1  3.720047
# Top ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'FTEC']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1  0.646046
# 1  SOXX  13w             0.1 -0.198935
# 2   PSI  13w             0.1 -2.035435
# 3   XSD  13w             0.1 -3.835175
# 4   IYW  13w             0.1  3.758910
# Top ETFs for 2024-03-25 to 2024-03-31: ['IYW', 'FTEC']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1 -0.620062
# 1  SOXX  14w             0.1 -0.523304
# 2   PSI  14w             0.1 -2.117642
# 3   XSD  14w             0.1 -4.164348
# 4   IYW  14w             0.1  2.111223
# Top ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1  0.064426
# 1  SOXX  15w             0.1  1.087519
# 2   PSI  15w             0.1 -3.052737
# 3   XSD  15w             0.1 -4.130383
# 4   IYW  15w             0.1  2.037361
# Top ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1  0.314213
# 1  SOXX  16w             0.1  1.909062
# 2   PSI  16w             0.1 -2.653785
# 3   XSD  16w             0.1 -4.013131
# 4   IYW  16w             0.1  0.135416
# Top ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'SOXX']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1  0.649643
# 1  SOXX  17w             0.1  0.106821
# 2   PSI  17w             0.1 -3.063183
# 3   XSD  17w             0.1 -2.999608
# 4   IYW  17w             0.1  0.497636
# Top ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'SMH']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1  0.423522
# 1  SOXX  18w             0.1  1.250835
# 2   PSI  18w             0.1 -2.930362
# 3   XSD  18w             0.1 -3.112110
# 4   IYW  18w             0.1 -0.396615
# Top ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'SOXX']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1  0.314356
# 1  SOXX  19w             0.1  1.118033
# 2   PSI  19w             0.1 -2.763284
# 3   XSD  19w             0.1 -4.644545
# 4   IYW  19w             0.1  1.679737
# Top ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'IYW']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1  1.115495
# 1  SOXX  20w             0.1 -0.976874
# 2   PSI  20w             0.1 -2.069622
# 3   XSD  20w             0.1 -4.787862
# 4   IYW  20w             0.1  4.426660
# Top ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'XLK']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  0.466790
# 1  SOXX  21w             0.1 -1.325260
# 2   PSI  21w             0.1 -1.097973
# 3   XSD  21w             0.1 -6.980148
# 4   IYW  21w             0.1  4.596168
# Top ETFs for 2024-05-20 to 2024-05-26: ['FTEC', 'IYW']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1  0.433261
# 1  SOXX  22w             0.1 -0.721576
# 2   PSI  22w             0.1 -1.189392
# 3   XSD  22w             0.1 -6.826568
# 4   IYW  22w             0.1  3.296291
# Top ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1  0.638350
# 1  SOXX  23w             0.1 -0.648922
# 2   PSI  23w             0.1 -1.852115
# 3   XSD  23w             0.1 -7.047758
# 4   IYW  23w             0.1  3.616118
# Top ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IYW']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1  0.591851
# 1  SOXX  24w             0.1 -1.312059
# 2   PSI  24w             0.1 -2.029742
# 3   XSD  24w             0.1 -6.701603
# 4   IYW  24w             0.1  4.383089
# Top ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IYW']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1 -0.321888
# 1  SOXX  25w             0.1 -0.779378
# 2   PSI  25w             0.1 -2.330176
# 3   XSD  25w             0.1 -5.806336
# 4   IYW  25w             0.1  5.039830
# Top ETFs for 2024-06-17 to 2024-06-23: ['IYW', 'FTEC']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1  0.990062
# 1  SOXX  26w             0.1  0.485978
# 2   PSI  26w             0.1 -2.222650
# 3   XSD  26w             0.1 -5.279422
# 4   IYW  26w             0.1  3.100400
# Top ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'FTEC']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1  0.742273
# 1  SOXX  27w             0.1 -0.424020
# 2   PSI  27w             0.1 -2.218164
# 3   XSD  27w             0.1 -6.604262
# 4   IYW  27w             0.1  3.988664
# Top ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IYW']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1  1.011209
# 1  SOXX  28w             0.1 -0.621963
# 2   PSI  28w             0.1 -1.822796
# 3   XSD  28w             0.1 -6.901887
# 4   IYW  28w             0.1  3.635499
# Top ETFs for 2024-07-08 to 2024-07-14: ['FTEC', 'IYW']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1  1.198350
# 1  SOXX  29w             0.1  0.575316
# 2   PSI  29w             0.1 -2.619946
# 3   XSD  29w             0.1 -5.693769
# 4   IYW  29w             0.1  1.839334
# Top ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'XLK']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1  2.106246
# 1  SOXX  30w             0.1  3.121188
# 2   PSI  30w             0.1 -3.972166
# 3   XSD  30w             0.1 -3.399343
# 4   IYW  30w             0.1  0.064499
# Top ETFs for 2024-07-22 to 2024-07-28: ['SOXX', 'SMH']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1  1.340672
# 1  SOXX  31w             0.1  0.867545
# 2   PSI  31w             0.1 -2.761092
# 3   XSD  31w             0.1 -1.677583
# 4   IYW  31w             0.1 -0.389874
# Top ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'SMH']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1  3.808952
# 1  SOXX  32w             0.1  2.789116
# 2   PSI  32w             0.1 -2.482257
# 3   XSD  32w             0.1  0.166890
# 4   IYW  32w             0.1  0.193221
# Top ETFs for 2024-08-05 to 2024-08-11: ['SMH', 'FTEC']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1 -0.053500
# 1  SOXX  33w             0.1  3.055992
# 2   PSI  33w             0.1 -3.682235
# 3   XSD  33w             0.1 -0.348815
# 4   IYW  33w             0.1  1.743712
# Top ETFs for 2024-08-12 to 2024-08-18: ['FTEC', 'SOXX']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1  0.374380
# 1  SOXX  34w             0.1  2.057768
# 2   PSI  34w             0.1 -4.383196
# 3   XSD  34w             0.1 -1.767314
# 4   IYW  34w             0.1  2.568407
# Top ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'IYW']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1  0.201114
# 1  SOXX  35w             0.1  2.023798
# 2   PSI  35w             0.1 -4.147677
# 3   XSD  35w             0.1 -2.035845
# 4   IYW  35w             0.1  3.317199
# Top ETFs for 2024-08-26 to 2024-09-01: ['IYW', 'FTEC']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1  0.075041
# 1  SOXX  36w             0.1  0.375006
# 2   PSI  36w             0.1 -3.602127
# 3   XSD  36w             0.1 -2.129739
# 4   IYW  36w             0.1  2.289881
# Top ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1  1.028100
# 1  SOXX  37w             0.1  3.320518
# 2   PSI  37w             0.1 -4.493850
# 3   XSD  37w             0.1 -2.432494
# 4   IYW  37w             0.1  2.971945
# Top ETFs for 2024-09-09 to 2024-09-15: ['SOXX', 'IYW']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1  1.466146
# 1  SOXX  38w             0.1  2.069121
# 2   PSI  38w             0.1 -4.536425
# 3   XSD  38w             0.1 -2.114252
# 4   IYW  38w             0.1  1.224659
# Top ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'SOXX']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1  0.378405
# 1  SOXX  39w             0.1  1.042165
# 2   PSI  39w             0.1 -3.434205
# 3   XSD  39w             0.1 -2.606872
# 4   IYW  39w             0.1  2.895475
# Top ETFs for 2024-09-23 to 2024-09-29: ['FTEC', 'IYW']
# Processing scores for 2024-09-30 to 2024-10-06:
#     ETF Week  RiskPercentage     Score
# 0   SMH  40w             0.1  1.537078
# 1  SOXX  40w             0.1  1.480360
# 2   PSI  40w             0.1 -3.860993
# 3   XSD  40w             0.1 -3.163846
# 4   IYW  40w             0.1  3.067843
# Top ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Processing scores for 2024-10-07 to 2024-10-13:
#     ETF Week  RiskPercentage     Score
# 0   SMH  41w             0.1  1.170868
# 1  SOXX  41w             0.1 -0.779428
# 2   PSI  41w             0.1 -3.410885
# 3   XSD  41w             0.1 -5.037841
# 4   IYW  41w             0.1  4.761975
# Top ETFs for 2024-10-07 to 2024-10-13: ['FTEC', 'IYW']
# Processing scores for 2024-10-14 to 2024-10-20:
#     ETF Week  RiskPercentage     Score
# 0   SMH  42w             0.1 -0.341622
# 1  SOXX  42w             0.1 -0.539260
# 2   PSI  42w             0.1 -2.945571
# 3   XSD  42w             0.1 -3.871621
# 4   IYW  42w             0.1  4.667637
# Top ETFs for 2024-10-14 to 2024-10-20: ['IYW', 'FTEC']
# Processing scores for 2024-10-21 to 2024-10-27:
#     ETF Week  RiskPercentage     Score
# 0   SMH  43w             0.1  0.568228
# 1  SOXX  43w             0.1  1.285721
# 2   PSI  43w             0.1 -2.744294
# 3   XSD  43w             0.1 -4.473330
# 4   IYW  43w             0.1  3.112015
# Top ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'FTEC']
# Processing scores for 2024-10-28 to 2024-11-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH  44w             0.1  0.544124
# 1  SOXX  44w             0.1  1.442682
# 2   PSI  44w             0.1 -2.908453
# 3   XSD  44w             0.1 -3.746567
# 4   IYW  44w             0.1  2.157486
# Top ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IYW']
# Processing scores for 2024-11-04 to 2024-11-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  45w             0.1  0.815047
# 1  SOXX  45w             0.1  1.971660
# 2   PSI  45w             0.1 -3.643658
# 3   XSD  45w             0.1 -3.931180
# 4   IYW  45w             0.1  2.764139
# Top ETFs for 2024-11-04 to 2024-11-10: ['IYW', 'FTEC']
# Processing scores for 2024-11-11 to 2024-11-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  46w             0.1  0.225559
# 1  SOXX  46w             0.1  1.956702
# 2   PSI  46w             0.1 -2.891580
# 3   XSD  46w             0.1 -3.366558
# 4   IYW  46w             0.1  1.715857
# Top ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'XLK']
# Processing scores for 2024-11-18 to 2024-11-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  47w             0.1  0.788168
# 1  SOXX  47w             0.1  2.784517
# 2   PSI  47w             0.1 -3.225743
# 3   XSD  47w             0.1 -3.488527
# 4   IYW  47w             0.1  3.047098
# Top ETFs for 2024-11-18 to 2024-11-24: ['IYW', 'SOXX']
# Processing scores for 2024-11-25 to 2024-12-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  48w             0.1  0.756839
# 1  SOXX  48w             0.1  1.726361
# 2   PSI  48w             0.1 -2.653588
# 3   XSD  48w             0.1 -3.213223
# 4   IYW  48w             0.1  1.275507
# Top ETFs for 2024-11-25 to 2024-12-01: ['XLK', 'SOXX']
#
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['FTEC', 'IYW']
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['FTEC', 'IYW']
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IYW', 'FTEC']
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['FTEC', 'IYW']
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IYW']
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['IYW', 'FTEC']
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IYW']
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['IYW', 'XLK']
# Sell FTEC: 348.74 shares at 152.86. Total value: 51975.30
# Buy XLK: 246.61 shares at 205.49.
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'IYW': 407.8815375605023, 'XLK': 246.61013482615476}
#
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['IYW', 'XLK']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['FTEC', 'IYW']
# Sell XLK: 246.61 shares at 210.76. Total value: 50676.16
# Buy FTEC: 314.89 shares at 156.91.
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'IYW': 407.8815375605023, 'FTEC': 314.8891510689613}
#
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'IYW': 407.8815375605023, 'FTEC': 314.8891510689613}
#
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'FTEC']
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'IYW': 407.8815375605023, 'FTEC': 314.8891510689613}
#
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['IYW', 'FTEC']
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'IYW': 407.8815375605023, 'FTEC': 314.8891510689613}
#
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'IYW': 407.8815375605023, 'FTEC': 314.8891510689613}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'IYW': 407.8815375605023, 'FTEC': 314.8891510689613}
#
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'SOXX']
# Sell IYW: 407.88 shares at 131.14. Total value: 52152.34
# Buy SOXX: 236.16 shares at 215.31.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'FTEC': 314.8891510689613, 'SOXX': 236.16430692646045}
#
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'SMH']
# Sell SOXX: 236.16 shares at 201.66. Total value: 46434.27
# Buy SMH: 223.00 shares at 203.02.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'FTEC': 314.8891510689613, 'SMH': 222.99977763907003}
#
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'SMH']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'SOXX']
# Sell SMH: 223.00 shares at 218.38. Total value: 47481.23
# Buy SOXX: 211.82 shares at 218.55.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'FTEC': 314.8891510689613, 'SOXX': 211.82426876960233}
#
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'IYW']
# Sell SOXX: 211.82 shares at 220.66. Total value: 45572.62
# Buy IYW: 331.02 shares at 134.23.
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'FTEC': 314.8891510689613, 'IYW': 331.0236262798175}
#
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'XLK']
# Sell FTEC: 314.89 shares at 154.27. Total value: 47363.50
# Buy XLK: 223.62 shares at 206.51.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'IYW': 331.0236262798175, 'XLK': 223.61830223364362}
#
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'XLK']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['FTEC', 'IYW']
# Sell XLK: 223.62 shares at 214.31. Total value: 46725.55
# Buy FTEC: 284.27 shares at 160.26.
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'IYW': 331.0236262798175, 'FTEC': 284.2718691541383}
#
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'IYW': 331.0236262798175, 'FTEC': 284.2718691541383}
#
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IYW']
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'IYW': 331.0236262798175, 'FTEC': 284.2718691541383}
#
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IYW']
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'IYW': 331.0236262798175, 'FTEC': 284.2718691541383}
#
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['IYW', 'FTEC']
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'IYW': 331.0236262798175, 'FTEC': 284.2718691541383}
#
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'FTEC']
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'IYW': 331.0236262798175, 'FTEC': 284.2718691541383}
#
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IYW']
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'IYW': 331.0236262798175, 'FTEC': 284.2718691541383}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['FTEC', 'IYW']
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'IYW': 331.0236262798175, 'FTEC': 284.2718691541383}
#
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'XLK']
# Sell IYW: 331.02 shares at 156.68. Total value: 50568.16
# Buy XLK: 210.50 shares at 234.22.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'FTEC': 284.2718691541383, 'XLK': 210.50275640042486}
#
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['SOXX', 'SMH']
# Sell FTEC: 284.27 shares at 173.59. Total value: 48113.08
# Buy SOXX: 190.51 shares at 246.24.
# Sell XLK: 210.50 shares at 226.10. Total value: 46404.81
# Buy SMH: 175.56 shares at 257.72.
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'SOXX': 190.5062368548244, 'SMH': 175.5575323562742}
#
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['SOXX', 'SMH']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'SMH']
# Sell SOXX: 190.51 shares at 228.89. Total value: 42514.85
# Buy FTEC: 249.20 shares at 166.34.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'SMH': 175.5575323562742, 'FTEC': 249.20029960277668}
#
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'SMH']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['SMH', 'FTEC']
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'SMH': 175.5575323562742, 'FTEC': 249.20029960277668}
#
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['SMH', 'FTEC']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['FTEC', 'SOXX']
# Sell SMH: 175.56 shares at 226.96. Total value: 38848.43
# Buy SOXX: 177.83 shares at 213.00.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'FTEC': 249.20029960277668, 'SOXX': 177.82729869877397}
#
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'IYW']
# Sell SOXX: 177.83 shares at 235.16. Total value: 40772.42
# Buy IYW: 265.02 shares at 150.00.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'FTEC': 249.20029960277668, 'IYW': 265.0207398013242}
#
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['IYW', 'FTEC']
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'FTEC': 249.20029960277668, 'IYW': 265.0207398013242}
#
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'FTEC': 249.20029960277668, 'IYW': 265.0207398013242}
#
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SOXX', 'IYW']
# Sell FTEC: 249.20 shares at 160.54. Total value: 39006.45
# Buy SOXX: 182.88 shares at 207.96.
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'IYW': 265.0207398013242, 'SOXX': 182.87789291245082}
#
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['SOXX', 'IYW']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'SOXX']
# Sell IYW: 265.02 shares at 146.04. Total value: 37736.04
# Buy FTEC: 218.87 shares at 168.10.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'SOXX': 182.87789291245082, 'FTEC': 218.87349279728306}
#
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['FTEC', 'IYW']
# Sell SOXX: 182.88 shares at 224.54. Total value: 40036.82
# Buy IYW: 261.53 shares at 149.26.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'FTEC': 218.87349279728306, 'IYW': 261.52952476591474}
#
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Sell FTEC: 218.87 shares at 174.50. Total value: 37238.59
# Buy XLK: 160.82 shares at 225.76.
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'IYW': 261.52952476591474, 'XLK': 160.8239946944117}
#
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'XLK']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['FTEC', 'IYW']
# Sell XLK: 160.82 shares at 223.74. Total value: 35083.19
# Buy FTEC: 197.94 shares at 172.81.
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'IYW': 261.52952476591474, 'FTEC': 197.9405884654005}
#
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IYW', 'FTEC']
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'IYW': 261.52952476591474, 'FTEC': 197.9405884654005}
#
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'FTEC']
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'IYW': 261.52952476591474, 'FTEC': 197.9405884654005}
#
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IYW']
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'IYW': 261.52952476591474, 'FTEC': 197.9405884654005}
#
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['IYW', 'FTEC']
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'IYW': 261.52952476591474, 'FTEC': 197.9405884654005}
#
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'XLK']
# Sell IYW: 261.53 shares at 160.27. Total value: 40867.45
# Buy XLK: 168.95 shares at 235.85.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'FTEC': 197.9405884654005, 'XLK': 168.94537716408288}
#
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['IYW', 'SOXX']
# Sell FTEC: 197.94 shares at 179.88. Total value: 34715.42
# Buy IYW: 216.71 shares at 156.19.
# Sell XLK: 168.95 shares at 229.45. Total value: 37795.40
# Buy SOXX: 172.25 shares at 213.94.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'IYW': 216.707402912295, 'SOXX': 172.2469751478423}
#
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['IYW', 'SOXX']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['XLK', 'SOXX']
# Sell IYW: 216.71 shares at 159.07. Total value: 33609.86
# Buy XLK: 140.29 shares at 233.59.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'SOXX': 172.2469751478423, 'XLK': 140.2868746688591}
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker SOXX starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# SOXX: 172.25 shares at $221.06 each, total value: $38076.92
# Fetching data for ticker XLK starting from 2024-12-01...
# XLK: 140.29 shares at $235.95 each, total value: $33100.69
#
# ETF values on the 49th week's first trading day:
# Total portfolio value: 71177.60
# SOXX: 38076.92
# XLK: 33100.69

# %%
ticker_shares_per_week_with_smoothing = main_weekly(tickers, results, smoothing=True)
# Out:
# Fetching data for SMH from 2024-01-01 to 2024-01-07...
# Fetching data for SOXX from 2024-01-01 to 2024-01-07...
# Fetching data for PSI from 2024-01-01 to 2024-01-07...
# Fetching data for XSD from 2024-01-01 to 2024-01-07...
# Fetching data for IYW from 2024-01-01 to 2024-01-07...
# Fetching data for XLK from 2024-01-01 to 2024-01-07...
# Fetching data for VGT from 2024-01-01 to 2024-01-07...
# Fetching data for FTEC from 2024-01-01 to 2024-01-07...
# Fetching data for IGM from 2024-01-01 to 2024-01-07...
# Fetching data for IXN from 2024-01-01 to 2024-01-07...
# Fetching data for SMH from 2024-01-08 to 2024-01-14...
# Fetching data for SOXX from 2024-01-08 to 2024-01-14...
# Fetching data for PSI from 2024-01-08 to 2024-01-14...
# Fetching data for XSD from 2024-01-08 to 2024-01-14...
# Fetching data for IYW from 2024-01-08 to 2024-01-14...
# Fetching data for XLK from 2024-01-08 to 2024-01-14...
# Fetching data for VGT from 2024-01-08 to 2024-01-14...
# Fetching data for FTEC from 2024-01-08 to 2024-01-14...
# Fetching data for IGM from 2024-01-08 to 2024-01-14...
# Fetching data for IXN from 2024-01-08 to 2024-01-14...
# Fetching data for SMH from 2024-01-15 to 2024-01-21...
# Fetching data for SOXX from 2024-01-15 to 2024-01-21...
# Fetching data for PSI from 2024-01-15 to 2024-01-21...
# Fetching data for XSD from 2024-01-15 to 2024-01-21...
# Fetching data for IYW from 2024-01-15 to 2024-01-21...
# Fetching data for XLK from 2024-01-15 to 2024-01-21...
# Fetching data for VGT from 2024-01-15 to 2024-01-21...
# Fetching data for FTEC from 2024-01-15 to 2024-01-21...
# Fetching data for IGM from 2024-01-15 to 2024-01-21...
# Fetching data for IXN from 2024-01-15 to 2024-01-21...
# Fetching data for SMH from 2024-01-22 to 2024-01-28...
# Fetching data for SOXX from 2024-01-22 to 2024-01-28...
# Fetching data for PSI from 2024-01-22 to 2024-01-28...
# Fetching data for XSD from 2024-01-22 to 2024-01-28...
# Fetching data for IYW from 2024-01-22 to 2024-01-28...
# Fetching data for XLK from 2024-01-22 to 2024-01-28...
# Fetching data for VGT from 2024-01-22 to 2024-01-28...
# Fetching data for FTEC from 2024-01-22 to 2024-01-28...
# Fetching data for IGM from 2024-01-22 to 2024-01-28...
# Fetching data for IXN from 2024-01-22 to 2024-01-28...
# Fetching data for SMH from 2024-01-29 to 2024-02-04...
# Fetching data for SOXX from 2024-01-29 to 2024-02-04...
# Fetching data for PSI from 2024-01-29 to 2024-02-04...
# Fetching data for XSD from 2024-01-29 to 2024-02-04...
# Fetching data for IYW from 2024-01-29 to 2024-02-04...
# Fetching data for XLK from 2024-01-29 to 2024-02-04...
# Fetching data for VGT from 2024-01-29 to 2024-02-04...
# Fetching data for FTEC from 2024-01-29 to 2024-02-04...
# Fetching data for IGM from 2024-01-29 to 2024-02-04...
# Fetching data for IXN from 2024-01-29 to 2024-02-04...
# Fetching data for SMH from 2024-02-05 to 2024-02-11...
# Fetching data for SOXX from 2024-02-05 to 2024-02-11...
# Fetching data for PSI from 2024-02-05 to 2024-02-11...
# Fetching data for XSD from 2024-02-05 to 2024-02-11...
# Fetching data for IYW from 2024-02-05 to 2024-02-11...
# Fetching data for XLK from 2024-02-05 to 2024-02-11...
# Fetching data for VGT from 2024-02-05 to 2024-02-11...
# Fetching data for FTEC from 2024-02-05 to 2024-02-11...
# Fetching data for IGM from 2024-02-05 to 2024-02-11...
# Fetching data for IXN from 2024-02-05 to 2024-02-11...
# Fetching data for SMH from 2024-02-12 to 2024-02-18...
# Fetching data for SOXX from 2024-02-12 to 2024-02-18...
# Fetching data for PSI from 2024-02-12 to 2024-02-18...
# Fetching data for XSD from 2024-02-12 to 2024-02-18...
# Fetching data for IYW from 2024-02-12 to 2024-02-18...
# Fetching data for XLK from 2024-02-12 to 2024-02-18...
# Fetching data for VGT from 2024-02-12 to 2024-02-18...
# Fetching data for FTEC from 2024-02-12 to 2024-02-18...
# Fetching data for IGM from 2024-02-12 to 2024-02-18...
# Fetching data for IXN from 2024-02-12 to 2024-02-18...
# Fetching data for SMH from 2024-02-19 to 2024-02-25...
# Fetching data for SOXX from 2024-02-19 to 2024-02-25...
# Fetching data for PSI from 2024-02-19 to 2024-02-25...
# Fetching data for XSD from 2024-02-19 to 2024-02-25...
# Fetching data for IYW from 2024-02-19 to 2024-02-25...
# Fetching data for XLK from 2024-02-19 to 2024-02-25...
# Fetching data for VGT from 2024-02-19 to 2024-02-25...
# Fetching data for FTEC from 2024-02-19 to 2024-02-25...
# Fetching data for IGM from 2024-02-19 to 2024-02-25...
# Fetching data for IXN from 2024-02-19 to 2024-02-25...
# Fetching data for SMH from 2024-02-26 to 2024-03-03...
# Fetching data for SOXX from 2024-02-26 to 2024-03-03...
# Fetching data for PSI from 2024-02-26 to 2024-03-03...
# Fetching data for XSD from 2024-02-26 to 2024-03-03...
# Fetching data for IYW from 2024-02-26 to 2024-03-03...
# Fetching data for XLK from 2024-02-26 to 2024-03-03...
# Fetching data for VGT from 2024-02-26 to 2024-03-03...
# Fetching data for FTEC from 2024-02-26 to 2024-03-03...
# Fetching data for IGM from 2024-02-26 to 2024-03-03...
# Fetching data for IXN from 2024-02-26 to 2024-03-03...
# Fetching data for SMH from 2024-03-04 to 2024-03-10...
# Fetching data for SOXX from 2024-03-04 to 2024-03-10...
# Fetching data for PSI from 2024-03-04 to 2024-03-10...
# Fetching data for XSD from 2024-03-04 to 2024-03-10...
# Fetching data for IYW from 2024-03-04 to 2024-03-10...
# Fetching data for XLK from 2024-03-04 to 2024-03-10...
# Fetching data for VGT from 2024-03-04 to 2024-03-10...
# Fetching data for FTEC from 2024-03-04 to 2024-03-10...
# Fetching data for IGM from 2024-03-04 to 2024-03-10...
# Fetching data for IXN from 2024-03-04 to 2024-03-10...
# Fetching data for SMH from 2024-03-11 to 2024-03-17...
# Fetching data for SOXX from 2024-03-11 to 2024-03-17...
# Fetching data for PSI from 2024-03-11 to 2024-03-17...
# Fetching data for XSD from 2024-03-11 to 2024-03-17...
# Fetching data for IYW from 2024-03-11 to 2024-03-17...
# Fetching data for XLK from 2024-03-11 to 2024-03-17...
# Fetching data for VGT from 2024-03-11 to 2024-03-17...
# Fetching data for FTEC from 2024-03-11 to 2024-03-17...
# Fetching data for IGM from 2024-03-11 to 2024-03-17...
# Fetching data for IXN from 2024-03-11 to 2024-03-17...
# Fetching data for SMH from 2024-03-18 to 2024-03-24...
# Fetching data for SOXX from 2024-03-18 to 2024-03-24...
# Fetching data for PSI from 2024-03-18 to 2024-03-24...
# Fetching data for XSD from 2024-03-18 to 2024-03-24...
# Fetching data for IYW from 2024-03-18 to 2024-03-24...
# Fetching data for XLK from 2024-03-18 to 2024-03-24...
# Fetching data for VGT from 2024-03-18 to 2024-03-24...
# Fetching data for FTEC from 2024-03-18 to 2024-03-24...
# Fetching data for IGM from 2024-03-18 to 2024-03-24...
# Fetching data for IXN from 2024-03-18 to 2024-03-24...
# Fetching data for SMH from 2024-03-25 to 2024-03-31...
# Fetching data for SOXX from 2024-03-25 to 2024-03-31...
# Fetching data for PSI from 2024-03-25 to 2024-03-31...
# Fetching data for XSD from 2024-03-25 to 2024-03-31...
# Fetching data for IYW from 2024-03-25 to 2024-03-31...
# Fetching data for XLK from 2024-03-25 to 2024-03-31...
# Fetching data for VGT from 2024-03-25 to 2024-03-31...
# Fetching data for FTEC from 2024-03-25 to 2024-03-31...
# Fetching data for IGM from 2024-03-25 to 2024-03-31...
# Fetching data for IXN from 2024-03-25 to 2024-03-31...
# Fetching data for SMH from 2024-04-01 to 2024-04-07...
# Fetching data for SOXX from 2024-04-01 to 2024-04-07...
# Fetching data for PSI from 2024-04-01 to 2024-04-07...
# Fetching data for XSD from 2024-04-01 to 2024-04-07...
# Fetching data for IYW from 2024-04-01 to 2024-04-07...
# Fetching data for XLK from 2024-04-01 to 2024-04-07...
# Fetching data for VGT from 2024-04-01 to 2024-04-07...
# Fetching data for FTEC from 2024-04-01 to 2024-04-07...
# Fetching data for IGM from 2024-04-01 to 2024-04-07...
# Fetching data for IXN from 2024-04-01 to 2024-04-07...
# Fetching data for SMH from 2024-04-08 to 2024-04-14...
# Fetching data for SOXX from 2024-04-08 to 2024-04-14...
# Fetching data for PSI from 2024-04-08 to 2024-04-14...
# Fetching data for XSD from 2024-04-08 to 2024-04-14...
# Fetching data for IYW from 2024-04-08 to 2024-04-14...
# Fetching data for XLK from 2024-04-08 to 2024-04-14...
# Fetching data for VGT from 2024-04-08 to 2024-04-14...
# Fetching data for FTEC from 2024-04-08 to 2024-04-14...
# Fetching data for IGM from 2024-04-08 to 2024-04-14...
# Fetching data for IXN from 2024-04-08 to 2024-04-14...
# Fetching data for SMH from 2024-04-15 to 2024-04-21...
# Fetching data for SOXX from 2024-04-15 to 2024-04-21...
# Fetching data for PSI from 2024-04-15 to 2024-04-21...
# Fetching data for XSD from 2024-04-15 to 2024-04-21...
# Fetching data for IYW from 2024-04-15 to 2024-04-21...
# Fetching data for XLK from 2024-04-15 to 2024-04-21...
# Fetching data for VGT from 2024-04-15 to 2024-04-21...
# Fetching data for FTEC from 2024-04-15 to 2024-04-21...
# Fetching data for IGM from 2024-04-15 to 2024-04-21...
# Fetching data for IXN from 2024-04-15 to 2024-04-21...
# Fetching data for SMH from 2024-04-22 to 2024-04-28...
# Fetching data for SOXX from 2024-04-22 to 2024-04-28...
# Fetching data for PSI from 2024-04-22 to 2024-04-28...
# Fetching data for XSD from 2024-04-22 to 2024-04-28...
# Fetching data for IYW from 2024-04-22 to 2024-04-28...
# Fetching data for XLK from 2024-04-22 to 2024-04-28...
# Fetching data for VGT from 2024-04-22 to 2024-04-28...
# Fetching data for FTEC from 2024-04-22 to 2024-04-28...
# Fetching data for IGM from 2024-04-22 to 2024-04-28...
# Fetching data for IXN from 2024-04-22 to 2024-04-28...
# Fetching data for SMH from 2024-04-29 to 2024-05-05...
# Fetching data for SOXX from 2024-04-29 to 2024-05-05...
# Fetching data for PSI from 2024-04-29 to 2024-05-05...
# Fetching data for XSD from 2024-04-29 to 2024-05-05...
# Fetching data for IYW from 2024-04-29 to 2024-05-05...
# Fetching data for XLK from 2024-04-29 to 2024-05-05...
# Fetching data for VGT from 2024-04-29 to 2024-05-05...
# Fetching data for FTEC from 2024-04-29 to 2024-05-05...
# Fetching data for IGM from 2024-04-29 to 2024-05-05...
# Fetching data for IXN from 2024-04-29 to 2024-05-05...
# Fetching data for SMH from 2024-05-06 to 2024-05-12...
# Fetching data for SOXX from 2024-05-06 to 2024-05-12...
# Fetching data for PSI from 2024-05-06 to 2024-05-12...
# Fetching data for XSD from 2024-05-06 to 2024-05-12...
# Fetching data for IYW from 2024-05-06 to 2024-05-12...
# Fetching data for XLK from 2024-05-06 to 2024-05-12...
# Fetching data for VGT from 2024-05-06 to 2024-05-12...
# Fetching data for FTEC from 2024-05-06 to 2024-05-12...
# Fetching data for IGM from 2024-05-06 to 2024-05-12...
# Fetching data for IXN from 2024-05-06 to 2024-05-12...
# Fetching data for SMH from 2024-05-13 to 2024-05-19...
# Fetching data for SOXX from 2024-05-13 to 2024-05-19...
# Fetching data for PSI from 2024-05-13 to 2024-05-19...
# Fetching data for XSD from 2024-05-13 to 2024-05-19...
# Fetching data for IYW from 2024-05-13 to 2024-05-19...
# Fetching data for XLK from 2024-05-13 to 2024-05-19...
# Fetching data for VGT from 2024-05-13 to 2024-05-19...
# Fetching data for FTEC from 2024-05-13 to 2024-05-19...
# Fetching data for IGM from 2024-05-13 to 2024-05-19...
# Fetching data for IXN from 2024-05-13 to 2024-05-19...
# Fetching data for SMH from 2024-05-20 to 2024-05-26...
# Fetching data for SOXX from 2024-05-20 to 2024-05-26...
# Fetching data for PSI from 2024-05-20 to 2024-05-26...
# Fetching data for XSD from 2024-05-20 to 2024-05-26...
# Fetching data for IYW from 2024-05-20 to 2024-05-26...
# Fetching data for XLK from 2024-05-20 to 2024-05-26...
# Fetching data for VGT from 2024-05-20 to 2024-05-26...
# Fetching data for FTEC from 2024-05-20 to 2024-05-26...
# Fetching data for IGM from 2024-05-20 to 2024-05-26...
# Fetching data for IXN from 2024-05-20 to 2024-05-26...
# Fetching data for SMH from 2024-05-27 to 2024-06-02...
# Fetching data for SOXX from 2024-05-27 to 2024-06-02...
# Fetching data for PSI from 2024-05-27 to 2024-06-02...
# Fetching data for XSD from 2024-05-27 to 2024-06-02...
# Fetching data for IYW from 2024-05-27 to 2024-06-02...
# Fetching data for XLK from 2024-05-27 to 2024-06-02...
# Fetching data for VGT from 2024-05-27 to 2024-06-02...
# Fetching data for FTEC from 2024-05-27 to 2024-06-02...
# Fetching data for IGM from 2024-05-27 to 2024-06-02...
# Fetching data for IXN from 2024-05-27 to 2024-06-02...
# Fetching data for SMH from 2024-06-03 to 2024-06-09...
# Fetching data for SOXX from 2024-06-03 to 2024-06-09...
# Fetching data for PSI from 2024-06-03 to 2024-06-09...
# Fetching data for XSD from 2024-06-03 to 2024-06-09...
# Fetching data for IYW from 2024-06-03 to 2024-06-09...
# Fetching data for XLK from 2024-06-03 to 2024-06-09...
# Fetching data for VGT from 2024-06-03 to 2024-06-09...
# Fetching data for FTEC from 2024-06-03 to 2024-06-09...
# Fetching data for IGM from 2024-06-03 to 2024-06-09...
# Fetching data for IXN from 2024-06-03 to 2024-06-09...
# Fetching data for SMH from 2024-06-10 to 2024-06-16...
# Fetching data for SOXX from 2024-06-10 to 2024-06-16...
# Fetching data for PSI from 2024-06-10 to 2024-06-16...
# Fetching data for XSD from 2024-06-10 to 2024-06-16...
# Fetching data for IYW from 2024-06-10 to 2024-06-16...
# Fetching data for XLK from 2024-06-10 to 2024-06-16...
# Fetching data for VGT from 2024-06-10 to 2024-06-16...
# Fetching data for FTEC from 2024-06-10 to 2024-06-16...
# Fetching data for IGM from 2024-06-10 to 2024-06-16...
# Fetching data for IXN from 2024-06-10 to 2024-06-16...
# Fetching data for SMH from 2024-06-17 to 2024-06-23...
# Fetching data for SOXX from 2024-06-17 to 2024-06-23...
# Fetching data for PSI from 2024-06-17 to 2024-06-23...
# Fetching data for XSD from 2024-06-17 to 2024-06-23...
# Fetching data for IYW from 2024-06-17 to 2024-06-23...
# Fetching data for XLK from 2024-06-17 to 2024-06-23...
# Fetching data for VGT from 2024-06-17 to 2024-06-23...
# Fetching data for FTEC from 2024-06-17 to 2024-06-23...
# Fetching data for IGM from 2024-06-17 to 2024-06-23...
# Fetching data for IXN from 2024-06-17 to 2024-06-23...
# Fetching data for SMH from 2024-06-24 to 2024-06-30...
# Fetching data for SOXX from 2024-06-24 to 2024-06-30...
# Fetching data for PSI from 2024-06-24 to 2024-06-30...
# Fetching data for XSD from 2024-06-24 to 2024-06-30...
# Fetching data for IYW from 2024-06-24 to 2024-06-30...
# Fetching data for XLK from 2024-06-24 to 2024-06-30...
# Fetching data for VGT from 2024-06-24 to 2024-06-30...
# Fetching data for FTEC from 2024-06-24 to 2024-06-30...
# Fetching data for IGM from 2024-06-24 to 2024-06-30...
# Fetching data for IXN from 2024-06-24 to 2024-06-30...
# Fetching data for SMH from 2024-07-01 to 2024-07-07...
# Fetching data for SOXX from 2024-07-01 to 2024-07-07...
# Fetching data for PSI from 2024-07-01 to 2024-07-07...
# Fetching data for XSD from 2024-07-01 to 2024-07-07...
# Fetching data for IYW from 2024-07-01 to 2024-07-07...
# Fetching data for XLK from 2024-07-01 to 2024-07-07...
# Fetching data for VGT from 2024-07-01 to 2024-07-07...
# Fetching data for FTEC from 2024-07-01 to 2024-07-07...
# Fetching data for IGM from 2024-07-01 to 2024-07-07...
# Fetching data for IXN from 2024-07-01 to 2024-07-07...
# Fetching data for SMH from 2024-07-08 to 2024-07-14...
# Fetching data for SOXX from 2024-07-08 to 2024-07-14...
# Fetching data for PSI from 2024-07-08 to 2024-07-14...
# Fetching data for XSD from 2024-07-08 to 2024-07-14...
# Fetching data for IYW from 2024-07-08 to 2024-07-14...
# Fetching data for XLK from 2024-07-08 to 2024-07-14...
# Fetching data for VGT from 2024-07-08 to 2024-07-14...
# Fetching data for FTEC from 2024-07-08 to 2024-07-14...
# Fetching data for IGM from 2024-07-08 to 2024-07-14...
# Fetching data for IXN from 2024-07-08 to 2024-07-14...
# Fetching data for SMH from 2024-07-15 to 2024-07-21...
# Fetching data for SOXX from 2024-07-15 to 2024-07-21...
# Fetching data for PSI from 2024-07-15 to 2024-07-21...
# Fetching data for XSD from 2024-07-15 to 2024-07-21...
# Fetching data for IYW from 2024-07-15 to 2024-07-21...
# Fetching data for XLK from 2024-07-15 to 2024-07-21...
# Fetching data for VGT from 2024-07-15 to 2024-07-21...
# Fetching data for FTEC from 2024-07-15 to 2024-07-21...
# Fetching data for IGM from 2024-07-15 to 2024-07-21...
# Fetching data for IXN from 2024-07-15 to 2024-07-21...
# Fetching data for SMH from 2024-07-22 to 2024-07-28...
# Fetching data for SOXX from 2024-07-22 to 2024-07-28...
# Fetching data for PSI from 2024-07-22 to 2024-07-28...
# Fetching data for XSD from 2024-07-22 to 2024-07-28...
# Fetching data for IYW from 2024-07-22 to 2024-07-28...
# Fetching data for XLK from 2024-07-22 to 2024-07-28...
# Fetching data for VGT from 2024-07-22 to 2024-07-28...
# Fetching data for FTEC from 2024-07-22 to 2024-07-28...
# Fetching data for IGM from 2024-07-22 to 2024-07-28...
# Fetching data for IXN from 2024-07-22 to 2024-07-28...
# Fetching data for SMH from 2024-07-29 to 2024-08-04...
# Fetching data for SOXX from 2024-07-29 to 2024-08-04...
# Fetching data for PSI from 2024-07-29 to 2024-08-04...
# Fetching data for XSD from 2024-07-29 to 2024-08-04...
# Fetching data for IYW from 2024-07-29 to 2024-08-04...
# Fetching data for XLK from 2024-07-29 to 2024-08-04...
# Fetching data for VGT from 2024-07-29 to 2024-08-04...
# Fetching data for FTEC from 2024-07-29 to 2024-08-04...
# Fetching data for IGM from 2024-07-29 to 2024-08-04...
# Fetching data for IXN from 2024-07-29 to 2024-08-04...
# Fetching data for SMH from 2024-08-05 to 2024-08-11...
# Fetching data for SOXX from 2024-08-05 to 2024-08-11...
# Fetching data for PSI from 2024-08-05 to 2024-08-11...
# Fetching data for XSD from 2024-08-05 to 2024-08-11...
# Fetching data for IYW from 2024-08-05 to 2024-08-11...
# Fetching data for XLK from 2024-08-05 to 2024-08-11...
# Fetching data for VGT from 2024-08-05 to 2024-08-11...
# Fetching data for FTEC from 2024-08-05 to 2024-08-11...
# Fetching data for IGM from 2024-08-05 to 2024-08-11...
# Fetching data for IXN from 2024-08-05 to 2024-08-11...
# Fetching data for SMH from 2024-08-12 to 2024-08-18...
# Fetching data for SOXX from 2024-08-12 to 2024-08-18...
# Fetching data for PSI from 2024-08-12 to 2024-08-18...
# Fetching data for XSD from 2024-08-12 to 2024-08-18...
# Fetching data for IYW from 2024-08-12 to 2024-08-18...
# Fetching data for XLK from 2024-08-12 to 2024-08-18...
# Fetching data for VGT from 2024-08-12 to 2024-08-18...
# Fetching data for FTEC from 2024-08-12 to 2024-08-18...
# Fetching data for IGM from 2024-08-12 to 2024-08-18...
# Fetching data for IXN from 2024-08-12 to 2024-08-18...
# Fetching data for SMH from 2024-08-19 to 2024-08-25...
# Fetching data for SOXX from 2024-08-19 to 2024-08-25...
# Fetching data for PSI from 2024-08-19 to 2024-08-25...
# Fetching data for XSD from 2024-08-19 to 2024-08-25...
# Fetching data for IYW from 2024-08-19 to 2024-08-25...
# Fetching data for XLK from 2024-08-19 to 2024-08-25...
# Fetching data for VGT from 2024-08-19 to 2024-08-25...
# Fetching data for FTEC from 2024-08-19 to 2024-08-25...
# Fetching data for IGM from 2024-08-19 to 2024-08-25...
# Fetching data for IXN from 2024-08-19 to 2024-08-25...
# Fetching data for SMH from 2024-08-26 to 2024-09-01...
# Fetching data for SOXX from 2024-08-26 to 2024-09-01...
# Fetching data for PSI from 2024-08-26 to 2024-09-01...
# Fetching data for XSD from 2024-08-26 to 2024-09-01...
# Fetching data for IYW from 2024-08-26 to 2024-09-01...
# Fetching data for XLK from 2024-08-26 to 2024-09-01...
# Fetching data for VGT from 2024-08-26 to 2024-09-01...
# Fetching data for FTEC from 2024-08-26 to 2024-09-01...
# Fetching data for IGM from 2024-08-26 to 2024-09-01...
# Fetching data for IXN from 2024-08-26 to 2024-09-01...
# Fetching data for SMH from 2024-09-02 to 2024-09-08...
# Fetching data for SOXX from 2024-09-02 to 2024-09-08...
# Fetching data for PSI from 2024-09-02 to 2024-09-08...
# Fetching data for XSD from 2024-09-02 to 2024-09-08...
# Fetching data for IYW from 2024-09-02 to 2024-09-08...
# Fetching data for XLK from 2024-09-02 to 2024-09-08...
# Fetching data for VGT from 2024-09-02 to 2024-09-08...
# Fetching data for FTEC from 2024-09-02 to 2024-09-08...
# Fetching data for IGM from 2024-09-02 to 2024-09-08...
# Fetching data for IXN from 2024-09-02 to 2024-09-08...
# Fetching data for SMH from 2024-09-09 to 2024-09-15...
# Fetching data for SOXX from 2024-09-09 to 2024-09-15...
# Fetching data for PSI from 2024-09-09 to 2024-09-15...
# Fetching data for XSD from 2024-09-09 to 2024-09-15...
# Fetching data for IYW from 2024-09-09 to 2024-09-15...
# Fetching data for XLK from 2024-09-09 to 2024-09-15...
# Fetching data for VGT from 2024-09-09 to 2024-09-15...
# Fetching data for FTEC from 2024-09-09 to 2024-09-15...
# Fetching data for IGM from 2024-09-09 to 2024-09-15...
# Fetching data for IXN from 2024-09-09 to 2024-09-15...
# Fetching data for SMH from 2024-09-16 to 2024-09-22...
# Fetching data for SOXX from 2024-09-16 to 2024-09-22...
# Fetching data for PSI from 2024-09-16 to 2024-09-22...
# Fetching data for XSD from 2024-09-16 to 2024-09-22...
# Fetching data for IYW from 2024-09-16 to 2024-09-22...
# Fetching data for XLK from 2024-09-16 to 2024-09-22...
# Fetching data for VGT from 2024-09-16 to 2024-09-22...
# Fetching data for FTEC from 2024-09-16 to 2024-09-22...
# Fetching data for IGM from 2024-09-16 to 2024-09-22...
# Fetching data for IXN from 2024-09-16 to 2024-09-22...
# Fetching data for SMH from 2024-09-23 to 2024-09-29...
# Fetching data for SOXX from 2024-09-23 to 2024-09-29...
# Fetching data for PSI from 2024-09-23 to 2024-09-29...
# Fetching data for XSD from 2024-09-23 to 2024-09-29...
# Fetching data for IYW from 2024-09-23 to 2024-09-29...
# Fetching data for XLK from 2024-09-23 to 2024-09-29...
# Fetching data for VGT from 2024-09-23 to 2024-09-29...
# Fetching data for FTEC from 2024-09-23 to 2024-09-29...
# Fetching data for IGM from 2024-09-23 to 2024-09-29...
# Fetching data for IXN from 2024-09-23 to 2024-09-29...
# Fetching data for SMH from 2024-09-30 to 2024-10-06...
# Fetching data for SOXX from 2024-09-30 to 2024-10-06...
# Fetching data for PSI from 2024-09-30 to 2024-10-06...
# Fetching data for XSD from 2024-09-30 to 2024-10-06...
# Fetching data for IYW from 2024-09-30 to 2024-10-06...
# Fetching data for XLK from 2024-09-30 to 2024-10-06...
# Fetching data for VGT from 2024-09-30 to 2024-10-06...
# Fetching data for FTEC from 2024-09-30 to 2024-10-06...
# Fetching data for IGM from 2024-09-30 to 2024-10-06...
# Fetching data for IXN from 2024-09-30 to 2024-10-06...
# Fetching data for SMH from 2024-10-07 to 2024-10-13...
# Fetching data for SOXX from 2024-10-07 to 2024-10-13...
# Fetching data for PSI from 2024-10-07 to 2024-10-13...
# Fetching data for XSD from 2024-10-07 to 2024-10-13...
# Fetching data for IYW from 2024-10-07 to 2024-10-13...
# Fetching data for XLK from 2024-10-07 to 2024-10-13...
# Fetching data for VGT from 2024-10-07 to 2024-10-13...
# Fetching data for FTEC from 2024-10-07 to 2024-10-13...
# Fetching data for IGM from 2024-10-07 to 2024-10-13...
# Fetching data for IXN from 2024-10-07 to 2024-10-13...
# Fetching data for SMH from 2024-10-14 to 2024-10-20...
# Fetching data for SOXX from 2024-10-14 to 2024-10-20...
# Fetching data for PSI from 2024-10-14 to 2024-10-20...
# Fetching data for XSD from 2024-10-14 to 2024-10-20...
# Fetching data for IYW from 2024-10-14 to 2024-10-20...
# Fetching data for XLK from 2024-10-14 to 2024-10-20...
# Fetching data for VGT from 2024-10-14 to 2024-10-20...
# Fetching data for FTEC from 2024-10-14 to 2024-10-20...
# Fetching data for IGM from 2024-10-14 to 2024-10-20...
# Fetching data for IXN from 2024-10-14 to 2024-10-20...
# Fetching data for SMH from 2024-10-21 to 2024-10-27...
# Fetching data for SOXX from 2024-10-21 to 2024-10-27...
# Fetching data for PSI from 2024-10-21 to 2024-10-27...
# Fetching data for XSD from 2024-10-21 to 2024-10-27...
# Fetching data for IYW from 2024-10-21 to 2024-10-27...
# Fetching data for XLK from 2024-10-21 to 2024-10-27...
# Fetching data for VGT from 2024-10-21 to 2024-10-27...
# Fetching data for FTEC from 2024-10-21 to 2024-10-27...
# Fetching data for IGM from 2024-10-21 to 2024-10-27...
# Fetching data for IXN from 2024-10-21 to 2024-10-27...
# Fetching data for SMH from 2024-10-28 to 2024-11-03...
# Fetching data for SOXX from 2024-10-28 to 2024-11-03...
# Fetching data for PSI from 2024-10-28 to 2024-11-03...
# Fetching data for XSD from 2024-10-28 to 2024-11-03...
# Fetching data for IYW from 2024-10-28 to 2024-11-03...
# Fetching data for XLK from 2024-10-28 to 2024-11-03...
# Fetching data for VGT from 2024-10-28 to 2024-11-03...
# Fetching data for FTEC from 2024-10-28 to 2024-11-03...
# Fetching data for IGM from 2024-10-28 to 2024-11-03...
# Fetching data for IXN from 2024-10-28 to 2024-11-03...
# Fetching data for SMH from 2024-11-04 to 2024-11-10...
# Fetching data for SOXX from 2024-11-04 to 2024-11-10...
# Fetching data for PSI from 2024-11-04 to 2024-11-10...
# Fetching data for XSD from 2024-11-04 to 2024-11-10...
# Fetching data for IYW from 2024-11-04 to 2024-11-10...
# Fetching data for XLK from 2024-11-04 to 2024-11-10...
# Fetching data for VGT from 2024-11-04 to 2024-11-10...
# Fetching data for FTEC from 2024-11-04 to 2024-11-10...
# Fetching data for IGM from 2024-11-04 to 2024-11-10...
# Fetching data for IXN from 2024-11-04 to 2024-11-10...
# Fetching data for SMH from 2024-11-11 to 2024-11-17...
# Fetching data for SOXX from 2024-11-11 to 2024-11-17...
# Fetching data for PSI from 2024-11-11 to 2024-11-17...
# Fetching data for XSD from 2024-11-11 to 2024-11-17...
# Fetching data for IYW from 2024-11-11 to 2024-11-17...
# Fetching data for XLK from 2024-11-11 to 2024-11-17...
# Fetching data for VGT from 2024-11-11 to 2024-11-17...
# Fetching data for FTEC from 2024-11-11 to 2024-11-17...
# Fetching data for IGM from 2024-11-11 to 2024-11-17...
# Fetching data for IXN from 2024-11-11 to 2024-11-17...
# Fetching data for SMH from 2024-11-18 to 2024-11-24...
# Fetching data for SOXX from 2024-11-18 to 2024-11-24...
# Fetching data for PSI from 2024-11-18 to 2024-11-24...
# Fetching data for XSD from 2024-11-18 to 2024-11-24...
# Fetching data for IYW from 2024-11-18 to 2024-11-24...
# Fetching data for XLK from 2024-11-18 to 2024-11-24...
# Fetching data for VGT from 2024-11-18 to 2024-11-24...
# Fetching data for FTEC from 2024-11-18 to 2024-11-24...
# Fetching data for IGM from 2024-11-18 to 2024-11-24...
# Fetching data for IXN from 2024-11-18 to 2024-11-24...
# Fetching data for SMH from 2024-11-25 to 2024-12-01...
# Fetching data for SOXX from 2024-11-25 to 2024-12-01...
# Fetching data for PSI from 2024-11-25 to 2024-12-01...
# Fetching data for XSD from 2024-11-25 to 2024-12-01...
# Fetching data for IYW from 2024-11-25 to 2024-12-01...
# Fetching data for XLK from 2024-11-25 to 2024-12-01...
# Fetching data for VGT from 2024-11-25 to 2024-12-01...
# Fetching data for FTEC from 2024-11-25 to 2024-12-01...
# Fetching data for IGM from 2024-11-25 to 2024-12-01...
# Fetching data for IXN from 2024-11-25 to 2024-12-01...
# Processing scores for 2024-01-01 to 2024-01-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1w             0.1 -0.496480
# 1  SOXX   1w             0.1 -0.837427
# 2   PSI   1w             0.1 -2.026694
# 3   XSD   1w             0.1 -4.600662
# 4   IYW   1w             0.1  1.156502
# Top ETFs for 2024-01-01 to 2024-01-07: ['FTEC', 'IYW']
# Processing scores for 2024-01-08 to 2024-01-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2w             0.1  0.763339
# 1  SOXX   2w             0.1 -1.016882
# 2   PSI   2w             0.1 -3.709593
# 3   XSD   2w             0.1 -4.812505
# 4   IYW   2w             0.1  2.492902
# Top ETFs for 2024-01-08 to 2024-01-14: ['FTEC', 'IYW']
# Processing scores for 2024-01-15 to 2024-01-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3w             0.1  1.001090
# 1  SOXX   3w             0.1 -0.584508
# 2   PSI   3w             0.1 -2.758801
# 3   XSD   3w             0.1 -3.417212
# 4   IYW   3w             0.1  1.183499
# Top ETFs for 2024-01-15 to 2024-01-21: ['FTEC', 'IYW']
# Processing scores for 2024-01-22 to 2024-01-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4w             0.1  0.562156
# 1  SOXX   4w             0.1 -1.704162
# 2   PSI   4w             0.1 -2.203817
# 3   XSD   4w             0.1 -3.536325
# 4   IYW   4w             0.1  4.139052
# Top ETFs for 2024-01-22 to 2024-01-28: ['IYW', 'FTEC']
# Processing scores for 2024-01-29 to 2024-02-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5w             0.1  0.807553
# 1  SOXX   5w             0.1 -0.555281
# 2   PSI   5w             0.1 -2.137183
# 3   XSD   5w             0.1 -4.590123
# 4   IYW   5w             0.1  2.612142
# Top ETFs for 2024-01-29 to 2024-02-04: ['FTEC', 'IYW']
# Processing scores for 2024-02-05 to 2024-02-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6w             0.1  0.181413
# 1  SOXX   6w             0.1 -1.836227
# 2   PSI   6w             0.1 -2.044767
# 3   XSD   6w             0.1 -4.394032
# 4   IYW   6w             0.1  2.560359
# Top ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IYW']
# Processing scores for 2024-02-12 to 2024-02-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7w             0.1  0.133862
# 1  SOXX   7w             0.1 -1.631897
# 2   PSI   7w             0.1 -1.110484
# 3   XSD   7w             0.1 -4.323299
# 4   IYW   7w             0.1  4.502664
# Top ETFs for 2024-02-12 to 2024-02-18: ['FTEC', 'IYW']
# Processing scores for 2024-02-19 to 2024-02-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8w             0.1 -0.185005
# 1  SOXX   8w             0.1 -0.625818
# 2   PSI   8w             0.1 -1.850010
# 3   XSD   8w             0.1 -4.254844
# 4   IYW   8w             0.1  1.723869
# Top ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IYW']
# Processing scores for 2024-02-26 to 2024-03-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9w             0.1  0.244851
# 1  SOXX   9w             0.1 -1.075948
# 2   PSI   9w             0.1 -2.155335
# 3   XSD   9w             0.1 -3.920036
# 4   IYW   9w             0.1  3.294952
# Top ETFs for 2024-02-26 to 2024-03-03: ['FTEC', 'IYW']
# Processing scores for 2024-03-04 to 2024-03-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10w             0.1  0.388682
# 1  SOXX  10w             0.1 -1.742552
# 2   PSI  10w             0.1 -1.721774
# 3   XSD  10w             0.1 -4.735959
# 4   IYW  10w             0.1  3.756002
# Top ETFs for 2024-03-04 to 2024-03-10: ['IYW', 'FTEC']
# Processing scores for 2024-03-11 to 2024-03-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11w             0.1 -0.424592
# 1  SOXX  11w             0.1 -1.524544
# 2   PSI  11w             0.1 -2.566790
# 3   XSD  11w             0.1 -3.387037
# 4   IYW  11w             0.1  2.007809
# Top ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Processing scores for 2024-03-18 to 2024-03-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  12w             0.1  1.418848
# 1  SOXX  12w             0.1 -0.163407
# 2   PSI  12w             0.1 -1.638189
# 3   XSD  12w             0.1 -4.936843
# 4   IYW  12w             0.1  2.587768
# Top ETFs for 2024-03-18 to 2024-03-24: ['FTEC', 'IYW']
# Processing scores for 2024-03-25 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  13w             0.1  1.187387
# 1  SOXX  13w             0.1 -0.275993
# 2   PSI  13w             0.1 -2.102352
# 3   XSD  13w             0.1 -4.040816
# 4   IYW  13w             0.1  3.193921
# Top ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'IYW']
# Processing scores for 2024-04-01 to 2024-04-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  14w             0.1 -0.208306
# 1  SOXX  14w             0.1 -0.345248
# 2   PSI  14w             0.1 -2.467051
# 3   XSD  14w             0.1 -3.911667
# 4   IYW  14w             0.1  1.544563
# Top ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Processing scores for 2024-04-08 to 2024-04-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  15w             0.1 -0.246495
# 1  SOXX  15w             0.1  0.221088
# 2   PSI  15w             0.1 -2.927547
# 3   XSD  15w             0.1 -3.928659
# 4   IYW  15w             0.1  1.484846
# Top ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Processing scores for 2024-04-15 to 2024-04-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  16w             0.1  0.013679
# 1  SOXX  16w             0.1  1.211074
# 2   PSI  16w             0.1 -2.918659
# 3   XSD  16w             0.1 -3.955099
# 4   IYW  16w             0.1 -0.046765
# Top ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'XLK']
# Processing scores for 2024-04-22 to 2024-04-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  17w             0.1  1.301080
# 1  SOXX  17w             0.1  1.026228
# 2   PSI  17w             0.1 -3.863154
# 3   XSD  17w             0.1 -3.633433
# 4   IYW  17w             0.1  1.049714
# Top ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'SMH']
# Processing scores for 2024-04-29 to 2024-05-05:
#     ETF Week  RiskPercentage     Score
# 0   SMH  18w             0.1  1.881090
# 1  SOXX  18w             0.1  1.890366
# 2   PSI  18w             0.1 -4.175074
# 3   XSD  18w             0.1 -3.963096
# 4   IYW  18w             0.1  0.477858
# Top ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'SOXX']
# Processing scores for 2024-05-06 to 2024-05-12:
#     ETF Week  RiskPercentage     Score
# 0   SMH  19w             0.1  0.793618
# 1  SOXX  19w             0.1  1.235301
# 2   PSI  19w             0.1 -3.650816
# 3   XSD  19w             0.1 -3.985456
# 4   IYW  19w             0.1  0.837903
# Top ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'SOXX']
# Processing scores for 2024-05-13 to 2024-05-19:
#     ETF Week  RiskPercentage     Score
# 0   SMH  20w             0.1  0.679314
# 1  SOXX  20w             0.1 -0.256658
# 2   PSI  20w             0.1 -2.126177
# 3   XSD  20w             0.1 -3.966758
# 4   IYW  20w             0.1  4.228576
# Top ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'FTEC']
# Processing scores for 2024-05-20 to 2024-05-26:
#     ETF Week  RiskPercentage     Score
# 0   SMH  21w             0.1  0.290734
# 1  SOXX  21w             0.1 -1.822096
# 2   PSI  21w             0.1 -0.920097
# 3   XSD  21w             0.1 -5.114864
# 4   IYW  21w             0.1  4.762893
# Top ETFs for 2024-05-20 to 2024-05-26: ['IYW', 'FTEC']
# Processing scores for 2024-05-27 to 2024-06-02:
#     ETF Week  RiskPercentage     Score
# 0   SMH  22w             0.1  0.709166
# 1  SOXX  22w             0.1 -1.217612
# 2   PSI  22w             0.1 -1.469949
# 3   XSD  22w             0.1 -5.730062
# 4   IYW  22w             0.1  3.268206
# Top ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Processing scores for 2024-06-03 to 2024-06-09:
#     ETF Week  RiskPercentage     Score
# 0   SMH  23w             0.1  0.513041
# 1  SOXX  23w             0.1 -1.395599
# 2   PSI  23w             0.1 -2.272324
# 3   XSD  23w             0.1 -5.159269
# 4   IYW  23w             0.1  4.334405
# Top ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IYW']
# Processing scores for 2024-06-10 to 2024-06-16:
#     ETF Week  RiskPercentage     Score
# 0   SMH  24w             0.1  0.520064
# 1  SOXX  24w             0.1 -1.467795
# 2   PSI  24w             0.1 -1.865839
# 3   XSD  24w             0.1 -5.294317
# 4   IYW  24w             0.1  4.157476
# Top ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IYW']
# Processing scores for 2024-06-17 to 2024-06-23:
#     ETF Week  RiskPercentage     Score
# 0   SMH  25w             0.1  0.267665
# 1  SOXX  25w             0.1 -1.496779
# 2   PSI  25w             0.1 -1.914027
# 3   XSD  25w             0.1 -5.225434
# 4   IYW  25w             0.1  3.926446
# Top ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'IYW']
# Processing scores for 2024-06-24 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  26w             0.1  0.451948
# 1  SOXX  26w             0.1  0.071825
# 2   PSI  26w             0.1 -1.942271
# 3   XSD  26w             0.1 -5.390779
# 4   IYW  26w             0.1  2.603660
# Top ETFs for 2024-06-24 to 2024-06-30: ['FTEC', 'IYW']
# Processing scores for 2024-07-01 to 2024-07-07:
#     ETF Week  RiskPercentage     Score
# 0   SMH  27w             0.1  0.787651
# 1  SOXX  27w             0.1 -0.774709
# 2   PSI  27w             0.1 -2.605908
# 3   XSD  27w             0.1 -4.606367
# 4   IYW  27w             0.1  3.606183
# Top ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IYW']
# Processing scores for 2024-07-08 to 2024-07-14:
#     ETF Week  RiskPercentage     Score
# 0   SMH  28w             0.1  0.706380
# 1  SOXX  28w             0.1 -0.674389
# 2   PSI  28w             0.1 -2.233975
# 3   XSD  28w             0.1 -5.002565
# 4   IYW  28w             0.1  3.985828
# Top ETFs for 2024-07-08 to 2024-07-14: ['FTEC', 'IYW']
# Processing scores for 2024-07-15 to 2024-07-21:
#     ETF Week  RiskPercentage     Score
# 0   SMH  29w             0.1  1.125009
# 1  SOXX  29w             0.1  0.323525
# 2   PSI  29w             0.1 -2.521762
# 3   XSD  29w             0.1 -5.569865
# 4   IYW  29w             0.1  2.258977
# Top ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'XLK']
# Processing scores for 2024-07-22 to 2024-07-28:
#     ETF Week  RiskPercentage     Score
# 0   SMH  30w             0.1  1.822284
# 1  SOXX  30w             0.1  3.024893
# 2   PSI  30w             0.1 -3.567133
# 3   XSD  30w             0.1 -4.548022
# 4   IYW  30w             0.1  0.944330
# Top ETFs for 2024-07-22 to 2024-07-28: ['SOXX', 'FTEC']
# Processing scores for 2024-07-29 to 2024-08-04:
#     ETF Week  RiskPercentage     Score
# 0   SMH  31w             0.1  2.276804
# 1  SOXX  31w             0.1  2.165529
# 2   PSI  31w             0.1 -4.196081
# 3   XSD  31w             0.1 -2.965354
# 4   IYW  31w             0.1 -0.119141
# Top ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'SMH']
# Processing scores for 2024-08-05 to 2024-08-11:
#     ETF Week  RiskPercentage     Score
# 0   SMH  32w             0.1  4.386836
# 1  SOXX  32w             0.1  2.408759
# 2   PSI  32w             0.1 -2.939637
# 3   XSD  32w             0.1  1.381768
# 4   IYW  32w             0.1 -0.498361
# Top ETFs for 2024-08-05 to 2024-08-11: ['FTEC', 'SMH']
# Processing scores for 2024-08-12 to 2024-08-18:
#     ETF Week  RiskPercentage     Score
# 0   SMH  33w             0.1  1.659972
# 1  SOXX  33w             0.1  3.755120
# 2   PSI  33w             0.1 -3.843127
# 3   XSD  33w             0.1  0.798540
# 4   IYW  33w             0.1  1.664163
# Top ETFs for 2024-08-12 to 2024-08-18: ['SOXX', 'FTEC']
# Processing scores for 2024-08-19 to 2024-08-25:
#     ETF Week  RiskPercentage     Score
# 0   SMH  34w             0.1  0.333696
# 1  SOXX  34w             0.1  1.714052
# 2   PSI  34w             0.1 -4.947053
# 3   XSD  34w             0.1 -1.409586
# 4   IYW  34w             0.1  2.040283
# Top ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'IYW']
# Processing scores for 2024-08-26 to 2024-09-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  35w             0.1 -0.122215
# 1  SOXX  35w             0.1  1.671880
# 2   PSI  35w             0.1 -4.234880
# 3   XSD  35w             0.1 -1.902062
# 4   IYW  35w             0.1  3.274475
# Top ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IYW']
# Processing scores for 2024-09-02 to 2024-09-08:
#     ETF Week  RiskPercentage     Score
# 0   SMH  36w             0.1 -0.115540
# 1  SOXX  36w             0.1  0.413989
# 2   PSI  36w             0.1 -3.461550
# 3   XSD  36w             0.1 -2.183794
# 4   IYW  36w             0.1  1.616268
# Top ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Processing scores for 2024-09-09 to 2024-09-15:
#     ETF Week  RiskPercentage     Score
# 0   SMH  37w             0.1  0.676150
# 1  SOXX  37w             0.1  2.198803
# 2   PSI  37w             0.1 -5.110065
# 3   XSD  37w             0.1 -1.895626
# 4   IYW  37w             0.1  2.732445
# Top ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'IYW']
# Processing scores for 2024-09-16 to 2024-09-22:
#     ETF Week  RiskPercentage     Score
# 0   SMH  38w             0.1  1.297802
# 1  SOXX  38w             0.1  2.158288
# 2   PSI  38w             0.1 -4.708265
# 3   XSD  38w             0.1 -2.568229
# 4   IYW  38w             0.1  1.257629
# Top ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'SOXX']
# Processing scores for 2024-09-23 to 2024-09-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH  39w             0.1  0.233874
# 1  SOXX  39w             0.1  0.882461
# 2   PSI  39w             0.1 -3.724179
# 3   XSD  39w             0.1 -2.879099
# 4   IYW  39w             0.1  2.242037
# Top ETFs for 2024-09-23 to 2024-09-29: ['FTEC', 'IYW']
# Processing scores for 2024-09-30 to 2024-10-06:
#     ETF Week  RiskPercentage     Score
# 0   SMH  40w             0.1  1.048207
# 1  SOXX  40w             0.1  1.420335
# 2   PSI  40w             0.1 -3.656092
# 3   XSD  40w             0.1 -3.265227
# 4   IYW  40w             0.1  3.168240
# Top ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'FTEC']
# Processing scores for 2024-10-07 to 2024-10-13:
#     ETF Week  RiskPercentage     Score
# 0   SMH  41w             0.1  0.336451
# 1  SOXX  41w             0.1 -1.163637
# 2   PSI  41w             0.1 -2.439157
# 3   XSD  41w             0.1 -3.959093
# 4   IYW  41w             0.1  3.198234
# Top ETFs for 2024-10-07 to 2024-10-13: ['FTEC', 'IYW']
# Processing scores for 2024-10-14 to 2024-10-20:
#     ETF Week  RiskPercentage     Score
# 0   SMH  42w             0.1  0.547092
# 1  SOXX  42w             0.1 -0.017226
# 2   PSI  42w             0.1 -3.146495
# 3   XSD  42w             0.1 -4.306296
# 4   IYW  42w             0.1  4.512313
# Top ETFs for 2024-10-14 to 2024-10-20: ['IYW', 'FTEC']
# Processing scores for 2024-10-21 to 2024-10-27:
#     ETF Week  RiskPercentage     Score
# 0   SMH  43w             0.1  0.430505
# 1  SOXX  43w             0.1  0.866439
# 2   PSI  43w             0.1 -2.781420
# 3   XSD  43w             0.1 -4.787286
# 4   IYW  43w             0.1  3.006684
# Top ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'IYW']
# Processing scores for 2024-10-28 to 2024-11-03:
#     ETF Week  RiskPercentage     Score
# 0   SMH  44w             0.1  0.479398
# 1  SOXX  44w             0.1  1.445268
# 2   PSI  44w             0.1 -2.988770
# 3   XSD  44w             0.1 -4.122362
# 4   IYW  44w             0.1  1.836431
# Top ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IYW']
# Processing scores for 2024-11-04 to 2024-11-10:
#     ETF Week  RiskPercentage     Score
# 0   SMH  45w             0.1  1.297896
# 1  SOXX  45w             0.1  2.652802
# 2   PSI  45w             0.1 -3.855464
# 3   XSD  45w             0.1 -4.084306
# 4   IYW  45w             0.1  1.655949
# Top ETFs for 2024-11-04 to 2024-11-10: ['FTEC', 'SOXX']
# Processing scores for 2024-11-11 to 2024-11-17:
#     ETF Week  RiskPercentage     Score
# 0   SMH  46w             0.1 -0.136212
# 1  SOXX  46w             0.1  1.461837
# 2   PSI  46w             0.1 -3.335584
# 3   XSD  46w             0.1 -3.226275
# 4   IYW  46w             0.1  1.483187
# Top ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'XLK']
# Processing scores for 2024-11-18 to 2024-11-24:
#     ETF Week  RiskPercentage     Score
# 0   SMH  47w             0.1  0.657615
# 1  SOXX  47w             0.1  1.723361
# 2   PSI  47w             0.1 -2.959501
# 3   XSD  47w             0.1 -3.061296
# 4   IYW  47w             0.1  3.576932
# Top ETFs for 2024-11-18 to 2024-11-24: ['IYW', 'FTEC']
# Processing scores for 2024-11-25 to 2024-12-01:
#     ETF Week  RiskPercentage     Score
# 0   SMH  48w             0.1  0.525187
# 1  SOXX  48w             0.1  1.803812
# 2   PSI  48w             0.1 -3.000148
# 3   XSD  48w             0.1 -3.514259
# 4   IYW  48w             0.1  0.995322
# Top ETFs for 2024-11-25 to 2024-12-01: ['FTEC', 'XLK']
#
# Top 2 ETFs for 2024-01-01 to 2024-01-07: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['FTEC', 'IYW']
# Updated ticker shares after 2024-01-08 to 2024-01-14: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-01-08 to 2024-01-14: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['FTEC', 'IYW']
# Updated ticker shares after 2024-01-15 to 2024-01-21: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-01-15 to 2024-01-21: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IYW', 'FTEC']
# Updated ticker shares after 2024-01-22 to 2024-01-28: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-01-22 to 2024-01-28: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['FTEC', 'IYW']
# Updated ticker shares after 2024-01-29 to 2024-02-04: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-01-29 to 2024-02-04: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IYW']
# Updated ticker shares after 2024-02-05 to 2024-02-11: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-02-05 to 2024-02-11: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['FTEC', 'IYW']
# Updated ticker shares after 2024-02-12 to 2024-02-18: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-02-12 to 2024-02-18: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IYW']
# Updated ticker shares after 2024-02-19 to 2024-02-25: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-02-19 to 2024-02-25: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['FTEC', 'IYW']
# Updated ticker shares after 2024-02-26 to 2024-03-03: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-02-26 to 2024-03-03: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['IYW', 'FTEC']
# Updated ticker shares after 2024-03-04 to 2024-03-10: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-03-04 to 2024-03-10: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Updated ticker shares after 2024-03-11 to 2024-03-17: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-03-11 to 2024-03-17: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['FTEC', 'IYW']
# Updated ticker shares after 2024-03-18 to 2024-03-24: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-03-18 to 2024-03-24: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'IYW']
# Updated ticker shares after 2024-03-25 to 2024-03-31: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-03-25 to 2024-03-31: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Updated ticker shares after 2024-04-01 to 2024-04-07: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-07: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Updated ticker shares after 2024-04-08 to 2024-04-14: {'FTEC': 348.73740855123145, 'IYW': 407.8815375605023}
#
# Top 2 ETFs for 2024-04-08 to 2024-04-14: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'XLK']
# Sell IYW: 407.88 shares at 131.14. Total value: 52152.34
# Buy XLK: 252.33 shares at 201.52.
# Updated ticker shares after 2024-04-15 to 2024-04-21: {'FTEC': 348.73740855123145, 'XLK': 252.32500630068702}
#
# Top 2 ETFs for 2024-04-15 to 2024-04-21: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'SMH']
# Sell XLK: 252.33 shares at 194.25. Total value: 47788.78
# Buy SMH: 229.50 shares at 203.02.
# Updated ticker shares after 2024-04-22 to 2024-04-28: {'FTEC': 348.73740855123145, 'SMH': 229.5047714632009}
#
# Top 2 ETFs for 2024-04-22 to 2024-04-28: ['FTEC', 'SMH']
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'SOXX']
# Sell SMH: 229.50 shares at 218.38. Total value: 48866.27
# Buy SOXX: 218.00 shares at 218.55.
# Updated ticker shares after 2024-04-29 to 2024-05-05: {'FTEC': 348.73740855123145, 'SOXX': 218.00326847415582}
#
# Top 2 ETFs for 2024-04-29 to 2024-05-05: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'SOXX']
# Updated ticker shares after 2024-05-06 to 2024-05-12: {'FTEC': 348.73740855123145, 'SOXX': 218.00326847415582}
#
# Top 2 ETFs for 2024-05-06 to 2024-05-12: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'FTEC']
# Sell SOXX: 218.00 shares at 220.70. Total value: 46910.49
# Buy IYW: 340.16 shares at 134.46.
# Updated ticker shares after 2024-05-13 to 2024-05-19: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-05-13 to 2024-05-19: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['IYW', 'FTEC']
# Updated ticker shares after 2024-05-20 to 2024-05-26: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-05-20 to 2024-05-26: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Updated ticker shares after 2024-05-27 to 2024-06-02: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-05-27 to 2024-06-02: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IYW']
# Updated ticker shares after 2024-06-03 to 2024-06-09: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-06-03 to 2024-06-09: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IYW']
# Updated ticker shares after 2024-06-10 to 2024-06-16: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-06-10 to 2024-06-16: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'IYW']
# Updated ticker shares after 2024-06-17 to 2024-06-23: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-06-17 to 2024-06-23: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['FTEC', 'IYW']
# Updated ticker shares after 2024-06-24 to 2024-06-30: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-06-24 to 2024-06-30: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IYW']
# Updated ticker shares after 2024-07-01 to 2024-07-07: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-07: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['FTEC', 'IYW']
# Updated ticker shares after 2024-07-08 to 2024-07-14: {'FTEC': 348.73740855123145, 'IYW': 340.15858392276624}
#
# Top 2 ETFs for 2024-07-08 to 2024-07-14: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'XLK']
# Sell IYW: 340.16 shares at 156.68. Total value: 51963.64
# Buy XLK: 216.31 shares at 234.22.
# Updated ticker shares after 2024-07-15 to 2024-07-21: {'FTEC': 348.73740855123145, 'XLK': 216.31180932227392}
#
# Top 2 ETFs for 2024-07-15 to 2024-07-21: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['SOXX', 'FTEC']
# Sell XLK: 216.31 shares at 226.10. Total value: 47685.40
# Buy SOXX: 188.81 shares at 246.24.
# Updated ticker shares after 2024-07-22 to 2024-07-28: {'FTEC': 348.73740855123145, 'SOXX': 188.81279590573246}
#
# Top 2 ETFs for 2024-07-22 to 2024-07-28: ['SOXX', 'FTEC']
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'SMH']
# Sell SOXX: 188.81 shares at 228.89. Total value: 42136.93
# Buy SMH: 172.19 shares at 238.60.
# Updated ticker shares after 2024-07-29 to 2024-08-04: {'FTEC': 348.73740855123145, 'SMH': 172.18567687411638}
#
# Top 2 ETFs for 2024-07-29 to 2024-08-04: ['FTEC', 'SMH']
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['FTEC', 'SMH']
# Updated ticker shares after 2024-08-05 to 2024-08-11: {'FTEC': 348.73740855123145, 'SMH': 172.18567687411638}
#
# Top 2 ETFs for 2024-08-05 to 2024-08-11: ['FTEC', 'SMH']
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SOXX', 'FTEC']
# Sell SMH: 172.19 shares at 226.96. Total value: 38102.28
# Buy SOXX: 174.41 shares at 213.00.
# Updated ticker shares after 2024-08-12 to 2024-08-18: {'FTEC': 348.73740855123145, 'SOXX': 174.41184882347073}
#
# Top 2 ETFs for 2024-08-12 to 2024-08-18: ['SOXX', 'FTEC']
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'IYW']
# Sell SOXX: 174.41 shares at 235.16. Total value: 39989.32
# Buy IYW: 259.93 shares at 150.00.
# Updated ticker shares after 2024-08-19 to 2024-08-25: {'FTEC': 348.73740855123145, 'IYW': 259.93060426347023}
#
# Top 2 ETFs for 2024-08-19 to 2024-08-25: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IYW']
# Updated ticker shares after 2024-08-26 to 2024-09-01: {'FTEC': 348.73740855123145, 'IYW': 259.93060426347023}
#
# Top 2 ETFs for 2024-08-26 to 2024-09-01: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Updated ticker shares after 2024-09-02 to 2024-09-08: {'FTEC': 348.73740855123145, 'IYW': 259.93060426347023}
#
# Top 2 ETFs for 2024-09-02 to 2024-09-08: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'IYW']
# Updated ticker shares after 2024-09-09 to 2024-09-15: {'FTEC': 348.73740855123145, 'IYW': 259.93060426347023}
#
# Top 2 ETFs for 2024-09-09 to 2024-09-15: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'SOXX']
# Sell IYW: 259.93 shares at 146.04. Total value: 37011.26
# Buy SOXX: 164.12 shares at 219.88.
# Updated ticker shares after 2024-09-16 to 2024-09-22: {'FTEC': 348.73740855123145, 'SOXX': 164.11667673224136}
#
# Top 2 ETFs for 2024-09-16 to 2024-09-22: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['FTEC', 'IYW']
# Sell SOXX: 164.12 shares at 224.54. Total value: 35929.49
# Buy IYW: 234.70 shares at 149.26.
# Updated ticker shares after 2024-09-23 to 2024-09-29: {'FTEC': 348.73740855123145, 'IYW': 234.6995352384779}
#
# Top 2 ETFs for 2024-09-23 to 2024-09-29: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'FTEC']
# Updated ticker shares after 2024-09-30 to 2024-10-06: {'FTEC': 348.73740855123145, 'IYW': 234.6995352384779}
#
# Top 2 ETFs for 2024-09-30 to 2024-10-06: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['FTEC', 'IYW']
# Updated ticker shares after 2024-10-07 to 2024-10-13: {'FTEC': 348.73740855123145, 'IYW': 234.6995352384779}
#
# Top 2 ETFs for 2024-10-07 to 2024-10-13: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IYW', 'FTEC']
# Updated ticker shares after 2024-10-14 to 2024-10-20: {'FTEC': 348.73740855123145, 'IYW': 234.6995352384779}
#
# Top 2 ETFs for 2024-10-14 to 2024-10-20: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'IYW']
# Updated ticker shares after 2024-10-21 to 2024-10-27: {'FTEC': 348.73740855123145, 'IYW': 234.6995352384779}
#
# Top 2 ETFs for 2024-10-21 to 2024-10-27: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IYW']
# Updated ticker shares after 2024-10-28 to 2024-11-03: {'FTEC': 348.73740855123145, 'IYW': 234.6995352384779}
#
# Top 2 ETFs for 2024-10-28 to 2024-11-03: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['FTEC', 'SOXX']
# Sell IYW: 234.70 shares at 151.41. Total value: 34647.46
# Buy SOXX: 154.03 shares at 219.31.
# Updated ticker shares after 2024-11-04 to 2024-11-10: {'FTEC': 348.73740855123145, 'SOXX': 154.03435731360767}
#
# Top 2 ETFs for 2024-11-04 to 2024-11-10: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'XLK']
# Sell SOXX: 154.03 shares at 225.57. Total value: 33876.89
# Buy XLK: 140.05 shares at 235.85.
# Updated ticker shares after 2024-11-11 to 2024-11-17: {'FTEC': 348.73740855123145, 'XLK': 140.04651114779426}
#
# Top 2 ETFs for 2024-11-11 to 2024-11-17: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['IYW', 'FTEC']
# Sell XLK: 140.05 shares at 229.45. Total value: 31330.33
# Buy IYW: 195.58 shares at 156.19.
# Updated ticker shares after 2024-11-18 to 2024-11-24: {'FTEC': 348.73740855123145, 'IYW': 195.57635600832654}
#
# Top 2 ETFs for 2024-11-18 to 2024-11-24: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-11-25 to 2024-12-01: ['FTEC', 'XLK']
# Sell IYW: 195.58 shares at 159.07. Total value: 30332.57
# Buy XLK: 126.61 shares at 233.59.
# Updated ticker shares after 2024-11-25 to 2024-12-01: {'FTEC': 348.73740855123145, 'XLK': 126.60756104689416}
# Using data for the 48th week: 2024-11-25 to 2024-12-01
# Fetching data starting from the first trading day of the 49th week: 2024-12-01
# Fetching data for ticker FTEC starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# FTEC: 348.74 shares at $186.99 each, total value: $65210.41
# Fetching data for ticker XLK starting from 2024-12-01...
# XLK: 126.61 shares at $235.95 each, total value: $29873.05
#
# ETF values on the 49th week's first trading day:
# Total portfolio value: 95083.46
# FTEC: 65210.41
# XLK: 29873.05

# %%
def process_etf_data_monthly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = {}

    # Determine forecast periods dynamically from the etf_dict
    sample_etf = next(iter(etf_dict.values()))
    forecast_periods = [key.split('_')[-1] for key in sample_etf.keys() if key.startswith('forecast_predictions_df')]

    for etf_name in tickers:
        etf_pred_dict[etf_name] = {
            f"returns_{period}": etf_dict[etf_name][f"forecast_predictions_df_{period}"]
            for period in forecast_periods
        }

        for period in forecast_periods:
            returns = etf_pred_dict[etf_name][f"returns_{period}"]

            if smoothing:
                # Apply smoothing
                smoothed_returns = calculate_smoothing(returns)
                etf_pred_dict[etf_name][f"smoothed_returns_{period}"] = smoothed_returns

                # Calculate metrics using smoothed returns
                etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(smoothed_returns)
                etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(smoothed_returns)
            else:
                # Calculate metrics using raw returns
                etf_pred_dict[etf_name][f"rachev_ratio_{period}"] = calculate_rachev_ratio(returns)
                etf_pred_dict[etf_name][f"sharpe_ratio_{period}"] = calculate_sharpe_ratio(returns)
                etf_pred_dict[etf_name][f"sortino_ratio_{period}"] = calculate_sortino_ratio(returns)
                etf_pred_dict[etf_name][f"volatility_clustering_{period}"] = calculate_volatility_clustering(returns)

    return etf_pred_dict


def calculate_means_and_stds_monthly(etf_pred_dict, forecast_period):
    returns_list = [etf_pred_dict[etf][f'returns_{forecast_period}'] for etf in etf_pred_dict]

    # Compute global means and standard deviations
    mean_forecast = np.mean([np.mean(returns) for returns in returns_list])
    std_forecast = np.std([np.mean(returns) for returns in returns_list])

    print(f"\nDebug: Forecast Period = {forecast_period}")
    print(f"All Returns Means: {[np.mean(returns) for returns in returns_list]}")
    print(f"Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")

    rachev_ratios = np.array([etf_pred_dict[etf][f'rachev_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Rachev Ratios: {rachev_ratios}")
    mean_rachev = np.mean(rachev_ratios)
    std_rachev = np.std(rachev_ratios)

    sharpe_ratios = np.array([etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sharpe Ratios: {sharpe_ratios}")
    mean_sharpe = np.mean(sharpe_ratios)
    std_sharpe = np.std(sharpe_ratios)

    sortino_ratios = np.array([etf_pred_dict[etf][f'sortino_ratio_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Sortino Ratios: {sortino_ratios}")
    mean_sortino = np.mean(sortino_ratios)
    std_sortino = np.std(sortino_ratios)

    volatility_clustering = np.array([etf_pred_dict[etf][f'volatility_clustering_{forecast_period}'] for etf in etf_pred_dict])
    print(f"All Volatility Clustering: {volatility_clustering}")
    mean_volatility_clustering = np.mean(volatility_clustering)
    std_volatility_clustering = np.std(volatility_clustering)

    print(f"Mean Rachev = {mean_rachev}, Std Rachev = {std_rachev}")
    print(f"Mean Sharpe = {mean_sharpe}, Std Sharpe = {std_sharpe}")
    print(f"Mean Sortino = {mean_sortino}, Std Sortino = {std_sortino}")
    print(f"Mean Volatility Clustering = {mean_volatility_clustering}, Std Volatility Clustering = {std_volatility_clustering}")

    return (
        mean_forecast, std_forecast, mean_rachev, std_rachev,
        mean_sharpe, std_sharpe, mean_sortino, std_sortino,
        mean_volatility_clustering, std_volatility_clustering
    )

def calculate_scores_for_etfs_monthly(etf_pred_dict, forecast_period, risk_percentage, smoothing = True):
    (mean_forecast, std_forecast, mean_rachev, std_rachev, 
     mean_sharpe, std_sharpe, mean_sortino, std_sortino, 
     mean_volatility_clustering, std_volatility_clustering) = calculate_means_and_stds_monthly(etf_pred_dict, forecast_period)

    scores = []
    for etf in etf_pred_dict:
        forecasted_values = etf_pred_dict[etf][f'returns_{forecast_period}']
        rachev_ratio = etf_pred_dict[etf][f'rachev_ratio_{forecast_period}']
        sharpe_ratio = etf_pred_dict[etf][f'sharpe_ratio_{forecast_period}']
        volatility_clustering = etf_pred_dict[etf][f'volatility_clustering_{forecast_period}']
        sortino_ratio = etf_pred_dict[etf][f'sortino_ratio_{forecast_period}']

        # Debugging: Log inputs to composite score calculation
        print(f"\nDebug: ETF = {etf}, Forecast Period = {forecast_period}")
        print(f"Forecasted Values Mean: {np.mean(forecasted_values)}")
        print(f"Rachev Ratio: {rachev_ratio}, Sharpe Ratio: {sharpe_ratio}")
        print(f"Sortino Ratio: {sortino_ratio}, Volatility Clustering: {volatility_clustering}")
        print(f"Means and Stds: Mean Forecast = {mean_forecast}, Std Forecast = {std_forecast}")
        
        # Calculate the composite score
        score = calculate_composite_score(
            forecasted_values, risk_percentage, rachev_ratio, sharpe_ratio, 
            sortino_ratio, volatility_clustering, mean_forecast, std_forecast, 
            mean_rachev, std_rachev, mean_sharpe, std_sharpe, mean_sortino, 
            std_sortino, mean_volatility_clustering, std_volatility_clustering
        )

        scores.append({
            'ETF': etf,
            'Month': forecast_period,
            'RiskPercentage': risk_percentage,
            'Score': score
        })

        # Debugging: Log the calculated score
        print(f"Calculated Score for {etf} ({forecast_period}): {score}")

    return scores

def select_top_etfs_monthly(df_scores, forecast_period):
    if df_scores.empty:
        print(f"No scores available for {forecast_period}. Skipping.")
        return []
    print(f"Processing scores for {forecast_period}:")
    print(df_scores.head())  # Check the top rows of the DataFrame
    top_etfs = df_scores.nlargest(2, 'Score')
    print(f"Top ETFs for {forecast_period}: {top_etfs['ETF'].tolist()}")
    return top_etfs['ETF'].tolist()


def generate_month_ranges(start_date, end_date):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    month_ranges = []

    while start < end:
        month_start = start
        month_end = (start + timedelta(days=31)).replace(day=1) - timedelta(days=1)
        if month_end > end:
            month_end = end
        month_ranges.append((month_start.strftime('%Y-%m-%d'), month_end.strftime('%Y-%m-%d')))
        start = month_end + timedelta(days=1)

    return month_ranges

def gather_etf_data_for_months(tickers, month_ranges):
    etf_histories = {}
    for start_date, end_date in month_ranges:
        month = f"{start_date} to {end_date}"
        etf_histories[month] = {}
        for ticker in tickers:
            etf_data = yf.download(ticker, start=start_date, end=end_date, progress=False)
            if etf_data.empty:
                print(f"No data found for {ticker} in {month}")
                continue
            etf_data.index = pd.to_datetime(etf_data.index)
            etf_histories[month][ticker] = etf_data
    return etf_histories

# Function to initialize shares for the first month
def initialize_shares_for_first_month(top_etfs_1m, etf_histories, month, investment_amount=50000):
    ticker_shares = {}
    first_trading_day_start = month.split(" to ")[0]

    for ticker in top_etfs_1m:
        etf_history = etf_histories.get(month, {}).get(ticker)

        if etf_history is not None:
            first_trading_day = pd.to_datetime(first_trading_day_start) + BDay(1)
            if first_trading_day not in etf_history.index:
                first_trading_day = etf_history.index[etf_history.index.searchsorted(first_trading_day)]

            price_on_first_trading_day = etf_history.loc[first_trading_day, 'Close']
            num_shares = (investment_amount * 0.975) / price_on_first_trading_day
            print(f"Shares 1st month: ({investment_amount} * 0.975) / {price_on_first_trading_day}")
            ticker_shares[ticker] = num_shares
            print(f"Ticker: {ticker}, First trading day: {first_trading_day.date()}, Price: {price_on_first_trading_day}, Shares: {num_shares:.2f}")
        else:
            print(f"No data found for {ticker} in {month}")
    return ticker_shares


def manage_etf_portfolio_monthly(
    top_etfs_previous, top_etfs_current, previous_month, current_month, ticker_shares, gathered_data_per_month
):
    etf_histories_for_current_month = gathered_data_per_month.get(current_month, {})

    # Extract ETFs as lists to preserve order
    top2etfs_previous = list(top_etfs_previous)
    top2etfs_current = list(top_etfs_current)

    print(f"Top 2 ETFs for {previous_month}: {top2etfs_previous}")
    print(f"Top 2 ETFs for {current_month}: {top2etfs_current}")

    # Step 1: Identify common ETFs (present in both months)
    etfs_common = [etf for etf in top2etfs_previous if etf in top2etfs_current]

    # Step 2: Identify ETFs to sell (present in the previous month but not in the current month)
    etfs_to_sell = [etf for etf in top2etfs_previous if etf not in top2etfs_current]

    # Step 3: Identify ETFs to buy (present in the current month but not in the previous month)
    etfs_to_buy = [etf for etf in top2etfs_current if etf not in top2etfs_previous]

    # Step 4: Sell ETFs that are no longer in the current top ETFs
    selling_values = {}  # Track selling values for each ETF being sold
    for etf in etfs_to_sell:
        no_of_shares = ticker_shares.get(etf, 0)
        if no_of_shares > 0:
            # Check if data for the ETF is available in the current month
            if etf in etf_histories_for_current_month:
                first_trading_day_current_month = etf_histories_for_current_month[etf].loc[
                    etf_histories_for_current_month[etf].index[0], 'Close'
                ]
                
                selling_value = no_of_shares * first_trading_day_current_month * 0.975
                selling_values[etf] = selling_value  # Store selling value for this ETF
                print(f"Formula: {no_of_shares} * {first_trading_day_current_month} * 0.975")
                print(f"Sell {etf}: {no_of_shares:.2f} shares at {first_trading_day_current_month:.2f}. Total value: {selling_value:.2f}\n")
                del ticker_shares[etf]
            else:
                print(f"Data for {etf} is missing for {current_month}. Skipping sale.")
        else:
            print(f"No shares found for {etf} to sell.")

    # Step 5: Buy new ETFs that were not in the previous month's top ETFs
    for etf_to_buy, etf_to_sell in zip(etfs_to_buy, etfs_to_sell):
        selling_value = selling_values.get(etf_to_sell, 0)
        if selling_value > 0 and etf_to_buy in etf_histories_for_current_month:
            first_trading_day_new_etf = etf_histories_for_current_month[etf_to_buy].loc[
                etf_histories_for_current_month[etf_to_buy].index[0], 'Close'
            ]
            new_shares = (selling_value * 0.975) / first_trading_day_new_etf
            print(f"Formula: ({selling_value} * 0.975) / {first_trading_day_new_etf}")
            print(f"Buy {etf_to_buy}: {new_shares:.2f} shares at {first_trading_day_new_etf:.2f}.\n")
            ticker_shares[etf_to_buy] = new_shares
        else:
            print(f"Data for {etf_to_buy} is missing or no selling value available. Skipping purchase of {etf_to_buy}.")

    # Step 6: Maintain the order of ETFs in the ticker_shares dictionary based on the current top 2 ETFs
    ordered_ticker_shares = {etf: ticker_shares[etf] for etf in top2etfs_current if etf in ticker_shares}

    print(f"Updated ticker shares after {current_month}: {ordered_ticker_shares}")
    print("")
    return ordered_ticker_shares



def main_monthly(tickers, etf_dict, smoothing=True):
    etf_pred_dict = process_etf_data_monthly(tickers, etf_dict, smoothing=smoothing)

    risk_percentage = 0.10
    monthly_scores = {}

    # Calculate scores for all months
    for month in range(1, 13):
        month_key = f"{month}m"
        if any(f"returns_{month_key}" in etf_pred_dict[etf] for etf in etf_pred_dict):
            scores = calculate_scores_for_etfs_weekly(etf_pred_dict, month_key, risk_percentage)  # Reusing weekly function
            monthly_scores[month_key] = scores

    # Convert scores to DataFrames
    monthly_scores_dfs = {}
    for month_key, scores in monthly_scores.items():
        monthly_scores_dfs[month_key] = pd.DataFrame(scores)

    # Select top ETFs for each month
    top_etfs_monthly = {}
    for month_key, df_scores in monthly_scores_dfs.items():
        top_etfs_monthly[month_key] = df_scores.nlargest(2, 'Score')

    # Generate month ranges for ETF data gathering
    month_ranges = generate_month_ranges('2024-01-01', '2024-12-01')

    # Gather ETF historical data
    etf_histories = gather_etf_data_for_weeks(tickers, month_ranges)

    # Map month keys to date ranges
    month_key_mapping = {f"{i+1}m": month_range for i, month_range in enumerate(etf_histories.keys())}

    # Align top ETFs with historical data
    aligned_top_etfs_monthly = {}
    for month_key, df_scores in monthly_scores_dfs.items():
        forecast_period = month_key_mapping.get(month_key, None)
        if forecast_period:
            aligned_top_etfs_monthly[forecast_period] = select_top_etfs_weekly(df_scores, forecast_period)

    # Initialize and manage portfolio
    ticker_shares = {}
    ticker_shares_per_month = {}
    for i, month_range in enumerate(etf_histories.keys()):
        current_month_key = month_range
        if i == 0:
            # Initialize shares for the first month
            ticker_shares = initialize_shares_for_first_week(
                aligned_top_etfs_monthly[current_month_key],
                etf_histories,
                current_month_key
            )
            ticker_shares_per_month[current_month_key] = ticker_shares.copy()
        else:
            # Manage portfolio for subsequent months
            prev_month_key = list(etf_histories.keys())[i - 1]
            ticker_shares = manage_etf_portfolio_monthly(
                aligned_top_etfs_monthly[prev_month_key],
                aligned_top_etfs_monthly[current_month_key],
                prev_month_key,
                current_month_key,
                ticker_shares,
                etf_histories
            )
            ticker_shares_per_month[current_month_key] = ticker_shares.copy()

    # Define the first trading day of the 13th month
    first_trading_day_13m = '2024-12-01'

    # Identify the 12th and 13th month date ranges
    month_12_range = list(ticker_shares_per_month.keys())[-1]
    month_13_start = first_trading_day_13m
    print(f"Using data for the 12th month: {month_12_range}")
    print(f"Fetching data starting from the first trading day of the 13th month: {month_13_start}")

    month_13_end = '2024-12-31'
    etf_values_13m = {}

    # Ensure 12th month data exists
    if month_12_range in ticker_shares_per_month:
        ticker_shares_12m = ticker_shares_per_month[month_12_range]

        # Fetch the first trading day price of the 13th month for each ETF
        for ticker, shares in ticker_shares_12m.items():
            print(f"Fetching data for ticker {ticker} starting from {month_13_start}...")
            data = yf.download(ticker, start=month_13_start, end=month_13_end)

            if not data.empty:
                closing_price_13m = data['Close'].iloc[0]
                total_value = shares * closing_price_13m
                etf_values_13m[ticker] = total_value
                print(f"{ticker}: {shares:.2f} shares at ${closing_price_13m:.2f} each, total value: ${total_value:.2f}")
            else:
                print(f"{ticker}: No data available for the 13th month's first trading day.")
    else:
        print(f"No data available in ticker_shares_per_month for the 12th month: {month_12_range}")

    # Display total portfolio value for the 13th month's first trading day
    if etf_values_13m:
        print("\nETF values on the 13th month's first trading day:")
        total_value = sum(etf_values_13m.values())
        print(f"Total portfolio value: {total_value:.2f}")
        for ticker, value in etf_values_13m.items():
            print(f"{ticker}: {value:.2f}")
    else:
        print("No values could be calculated for the 13th month's first trading day.")

    return ticker_shares_per_month

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_month_wo_smoothing = main_monthly(tickers, results,False)
# Out:
# Fetching data for SMH from 2024-01-01 to 2024-01-31...
# Fetching data for SOXX from 2024-01-01 to 2024-01-31...
# Fetching data for PSI from 2024-01-01 to 2024-01-31...
# Fetching data for XSD from 2024-01-01 to 2024-01-31...
# Fetching data for IYW from 2024-01-01 to 2024-01-31...
# Fetching data for XLK from 2024-01-01 to 2024-01-31...
# Fetching data for VGT from 2024-01-01 to 2024-01-31...
# Fetching data for FTEC from 2024-01-01 to 2024-01-31...
# Fetching data for IGM from 2024-01-01 to 2024-01-31...
# Fetching data for IXN from 2024-01-01 to 2024-01-31...
# Fetching data for SMH from 2024-02-01 to 2024-02-29...
# Fetching data for SOXX from 2024-02-01 to 2024-02-29...
# Fetching data for PSI from 2024-02-01 to 2024-02-29...
# Fetching data for XSD from 2024-02-01 to 2024-02-29...
# Fetching data for IYW from 2024-02-01 to 2024-02-29...
# Fetching data for XLK from 2024-02-01 to 2024-02-29...
# Fetching data for VGT from 2024-02-01 to 2024-02-29...
# Fetching data for FTEC from 2024-02-01 to 2024-02-29...
# Fetching data for IGM from 2024-02-01 to 2024-02-29...
# Fetching data for IXN from 2024-02-01 to 2024-02-29...
# Fetching data for SMH from 2024-03-01 to 2024-03-31...
# Fetching data for SOXX from 2024-03-01 to 2024-03-31...
# Fetching data for PSI from 2024-03-01 to 2024-03-31...
# Fetching data for XSD from 2024-03-01 to 2024-03-31...
# Fetching data for IYW from 2024-03-01 to 2024-03-31...
# Fetching data for XLK from 2024-03-01 to 2024-03-31...
# Fetching data for VGT from 2024-03-01 to 2024-03-31...
# Fetching data for FTEC from 2024-03-01 to 2024-03-31...
# Fetching data for IGM from 2024-03-01 to 2024-03-31...
# Fetching data for IXN from 2024-03-01 to 2024-03-31...
# Fetching data for SMH from 2024-04-01 to 2024-04-30...
# Fetching data for SOXX from 2024-04-01 to 2024-04-30...
# Fetching data for PSI from 2024-04-01 to 2024-04-30...
# Fetching data for XSD from 2024-04-01 to 2024-04-30...
# Fetching data for IYW from 2024-04-01 to 2024-04-30...
# Fetching data for XLK from 2024-04-01 to 2024-04-30...
# Fetching data for VGT from 2024-04-01 to 2024-04-30...
# Fetching data for FTEC from 2024-04-01 to 2024-04-30...
# Fetching data for IGM from 2024-04-01 to 2024-04-30...
# Fetching data for IXN from 2024-04-01 to 2024-04-30...
# Fetching data for SMH from 2024-05-01 to 2024-05-31...
# Fetching data for SOXX from 2024-05-01 to 2024-05-31...
# Fetching data for PSI from 2024-05-01 to 2024-05-31...
# Fetching data for XSD from 2024-05-01 to 2024-05-31...
# Fetching data for IYW from 2024-05-01 to 2024-05-31...
# Fetching data for XLK from 2024-05-01 to 2024-05-31...
# Fetching data for VGT from 2024-05-01 to 2024-05-31...
# Fetching data for FTEC from 2024-05-01 to 2024-05-31...
# Fetching data for IGM from 2024-05-01 to 2024-05-31...
# Fetching data for IXN from 2024-05-01 to 2024-05-31...
# Fetching data for SMH from 2024-06-01 to 2024-06-30...
# Fetching data for SOXX from 2024-06-01 to 2024-06-30...
# Fetching data for PSI from 2024-06-01 to 2024-06-30...
# Fetching data for XSD from 2024-06-01 to 2024-06-30...
# Fetching data for IYW from 2024-06-01 to 2024-06-30...
# Fetching data for XLK from 2024-06-01 to 2024-06-30...
# Fetching data for VGT from 2024-06-01 to 2024-06-30...
# Fetching data for FTEC from 2024-06-01 to 2024-06-30...
# Fetching data for IGM from 2024-06-01 to 2024-06-30...
# Fetching data for IXN from 2024-06-01 to 2024-06-30...
# Fetching data for SMH from 2024-07-01 to 2024-07-31...
# Fetching data for SOXX from 2024-07-01 to 2024-07-31...
# Fetching data for PSI from 2024-07-01 to 2024-07-31...
# Fetching data for XSD from 2024-07-01 to 2024-07-31...
# Fetching data for IYW from 2024-07-01 to 2024-07-31...
# Fetching data for XLK from 2024-07-01 to 2024-07-31...
# Fetching data for VGT from 2024-07-01 to 2024-07-31...
# Fetching data for FTEC from 2024-07-01 to 2024-07-31...
# Fetching data for IGM from 2024-07-01 to 2024-07-31...
# Fetching data for IXN from 2024-07-01 to 2024-07-31...
# Fetching data for SMH from 2024-08-01 to 2024-08-31...
# Fetching data for SOXX from 2024-08-01 to 2024-08-31...
# Fetching data for PSI from 2024-08-01 to 2024-08-31...
# Fetching data for XSD from 2024-08-01 to 2024-08-31...
# Fetching data for IYW from 2024-08-01 to 2024-08-31...
# Fetching data for XLK from 2024-08-01 to 2024-08-31...
# Fetching data for VGT from 2024-08-01 to 2024-08-31...
# Fetching data for FTEC from 2024-08-01 to 2024-08-31...
# Fetching data for IGM from 2024-08-01 to 2024-08-31...
# Fetching data for IXN from 2024-08-01 to 2024-08-31...
# Fetching data for SMH from 2024-09-01 to 2024-09-30...
# Fetching data for SOXX from 2024-09-01 to 2024-09-30...
# Fetching data for PSI from 2024-09-01 to 2024-09-30...
# Fetching data for XSD from 2024-09-01 to 2024-09-30...
# Fetching data for IYW from 2024-09-01 to 2024-09-30...
# Fetching data for XLK from 2024-09-01 to 2024-09-30...
# Fetching data for VGT from 2024-09-01 to 2024-09-30...
# Fetching data for FTEC from 2024-09-01 to 2024-09-30...
# Fetching data for IGM from 2024-09-01 to 2024-09-30...
# Fetching data for IXN from 2024-09-01 to 2024-09-30...
# Fetching data for SMH from 2024-10-01 to 2024-10-31...
# Fetching data for SOXX from 2024-10-01 to 2024-10-31...
# Fetching data for PSI from 2024-10-01 to 2024-10-31...
# Fetching data for XSD from 2024-10-01 to 2024-10-31...
# Fetching data for IYW from 2024-10-01 to 2024-10-31...
# Fetching data for XLK from 2024-10-01 to 2024-10-31...
# Fetching data for VGT from 2024-10-01 to 2024-10-31...
# Fetching data for FTEC from 2024-10-01 to 2024-10-31...
# Fetching data for IGM from 2024-10-01 to 2024-10-31...
# Fetching data for IXN from 2024-10-01 to 2024-10-31...
# Fetching data for SMH from 2024-11-01 to 2024-11-30...
# Fetching data for SOXX from 2024-11-01 to 2024-11-30...
# Fetching data for PSI from 2024-11-01 to 2024-11-30...
# Fetching data for XSD from 2024-11-01 to 2024-11-30...
# Fetching data for IYW from 2024-11-01 to 2024-11-30...
# Fetching data for XLK from 2024-11-01 to 2024-11-30...
# Fetching data for VGT from 2024-11-01 to 2024-11-30...
# Fetching data for FTEC from 2024-11-01 to 2024-11-30...
# Fetching data for IGM from 2024-11-01 to 2024-11-30...
# Fetching data for IXN from 2024-11-01 to 2024-11-30...
# Processing scores for 2024-01-01 to 2024-01-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1m             0.1  0.346841
# 1  SOXX   1m             0.1 -0.713679
# 2   PSI   1m             0.1 -2.136137
# 3   XSD   1m             0.1 -6.221624
# 4   IYW   1m             0.1  2.731079
# Top ETFs for 2024-01-01 to 2024-01-31: ['FTEC', 'IYW']
# Processing scores for 2024-02-01 to 2024-02-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2m             0.1 -0.272443
# 1  SOXX   2m             0.1 -0.878713
# 2   PSI   2m             0.1 -1.319005
# 3   XSD   2m             0.1 -4.147958
# 4   IYW   2m             0.1  4.283592
# Top ETFs for 2024-02-01 to 2024-02-29: ['IYW', 'FTEC']
# Processing scores for 2024-03-01 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3m             0.1 -0.270151
# 1  SOXX   3m             0.1 -0.991802
# 2   PSI   3m             0.1 -2.045182
# 3   XSD   3m             0.1 -4.530731
# 4   IYW   3m             0.1  3.621650
# Top ETFs for 2024-03-01 to 2024-03-31: ['IYW', 'FTEC']
# Processing scores for 2024-04-01 to 2024-04-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4m             0.1 -0.946487
# 1  SOXX   4m             0.1  0.453404
# 2   PSI   4m             0.1 -2.580624
# 3   XSD   4m             0.1 -3.444251
# 4   IYW   4m             0.1  1.075510
# Top ETFs for 2024-04-01 to 2024-04-30: ['FTEC', 'XLK']
# Processing scores for 2024-05-01 to 2024-05-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5m             0.1  1.084467
# 1  SOXX   5m             0.1 -0.588706
# 2   PSI   5m             0.1 -1.986415
# 3   XSD   5m             0.1 -4.411279
# 4   IYW   5m             0.1  4.301832
# Top ETFs for 2024-05-01 to 2024-05-31: ['IYW', 'XLK']
# Processing scores for 2024-06-01 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6m             0.1 -0.306004
# 1  SOXX   6m             0.1 -0.718116
# 2   PSI   6m             0.1 -1.928259
# 3   XSD   6m             0.1 -6.648796
# 4   IYW   6m             0.1  4.869346
# Top ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'FTEC']
# Processing scores for 2024-07-01 to 2024-07-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7m             0.1  1.997525
# 1  SOXX   7m             0.1 -0.079161
# 2   PSI   7m             0.1 -2.941699
# 3   XSD   7m             0.1 -4.533387
# 4   IYW   7m             0.1  1.571315
# Top ETFs for 2024-07-01 to 2024-07-31: ['FTEC', 'XLK']
# Processing scores for 2024-08-01 to 2024-08-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8m             0.1  0.761921
# 1  SOXX   8m             0.1  3.188786
# 2   PSI   8m             0.1 -3.452887
# 3   XSD   8m             0.1 -2.034275
# 4   IYW   8m             0.1  1.712275
# Top ETFs for 2024-08-01 to 2024-08-31: ['FTEC', 'SOXX']
# Processing scores for 2024-09-01 to 2024-09-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9m             0.1 -0.084291
# 1  SOXX   9m             0.1  0.611974
# 2   PSI   9m             0.1 -4.159194
# 3   XSD   9m             0.1 -1.754469
# 4   IYW   9m             0.1  2.661002
# Top ETFs for 2024-09-01 to 2024-09-30: ['FTEC', 'IYW']
# Processing scores for 2024-10-01 to 2024-10-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10m             0.1  0.285539
# 1  SOXX  10m             0.1 -0.249550
# 2   PSI  10m             0.1 -2.841098
# 3   XSD  10m             0.1 -3.666560
# 4   IYW  10m             0.1  3.908612
# Top ETFs for 2024-10-01 to 2024-10-31: ['IYW', 'XLK']
# Processing scores for 2024-11-01 to 2024-11-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11m             0.1  0.721339
# 1  SOXX  11m             0.1  2.176219
# 2   PSI  11m             0.1 -3.166633
# 3   XSD  11m             0.1 -3.641696
# 4   IYW  11m             0.1  2.477894
# Top ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-01-01 to 2024-01-31: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['IYW', 'FTEC']
# Updated ticker shares after 2024-02-01 to 2024-02-29: {'IYW': 407.8815375605023, 'FTEC': 348.73740855123145}
#
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['IYW', 'FTEC']
# Updated ticker shares after 2024-03-01 to 2024-03-31: {'IYW': 407.8815375605023, 'FTEC': 348.73740855123145}
#
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['FTEC', 'XLK']
# Formula: 407.8815375605023 * 135.5500030517578 * 0.975
# Sell IYW: 407.88 shares at 135.55. Total value: 53906.14
#
# Formula: (53906.13506955471 * 0.975) / 208.85000610351562
# Buy XLK: 251.66 shares at 208.85.
#
# Updated ticker shares after 2024-04-01 to 2024-04-30: {'FTEC': 348.73740855123145, 'XLK': 251.6565963937078}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['IYW', 'XLK']
# Formula: 348.73740855123145 * 145.33999633789062 * 0.975
# Sell FTEC: 348.74 shares at 145.34. Total value: 49418.36
#
# Formula: (49418.35633967841 * 0.975) / 126.94999694824219
# Buy IYW: 379.54 shares at 126.95.
#
# Updated ticker shares after 2024-05-01 to 2024-05-31: {'IYW': 379.542328392735, 'XLK': 251.6565963937078}
#
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['IYW', 'XLK']
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'FTEC']
# Formula: 251.6565963937078 * 210.69000244140625 * 0.975
# Sell XLK: 251.66 shares at 210.69. Total value: 51695.99
#
# Formula: (51695.99068587163 * 0.975) / 159.7100067138672
# Buy FTEC: 315.59 shares at 159.71.
#
# Updated ticker shares after 2024-06-01 to 2024-06-30: {'IYW': 379.542328392735, 'FTEC': 315.594444930597}
#
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['FTEC', 'XLK']
# Formula: 379.542328392735 * 152.02000427246094 * 0.975
# Sell IYW: 379.54 shares at 152.02. Total value: 56255.58
#
# Formula: (56255.57572424726 * 0.975) / 227.94000244140625
# Buy XLK: 240.63 shares at 227.94.
#
# Updated ticker shares after 2024-07-01 to 2024-07-31: {'FTEC': 315.594444930597, 'XLK': 240.62992780409613}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['FTEC', 'SOXX']
# Formula: 240.62992780409613 * 210.63999938964844 * 0.975
# Sell XLK: 240.63 shares at 210.64. Total value: 49419.13
#
# Formula: (49419.1306496413 * 0.975) / 218.4199981689453
# Buy SOXX: 220.60 shares at 218.42.
#
# Updated ticker shares after 2024-08-01 to 2024-08-31: {'FTEC': 315.594444930597, 'SOXX': 220.60091927173616}
#
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['FTEC', 'IYW']
# Formula: 220.60091927173616 * 213.5 * 0.975
# Sell SOXX: 220.60 shares at 213.50. Total value: 45920.84
#
# Formula: (45920.83885790278 * 0.975) / 141.5800018310547
# Buy IYW: 316.24 shares at 141.58.
#
# Updated ticker shares after 2024-09-01 to 2024-09-30: {'FTEC': 315.594444930597, 'IYW': 316.2368788487653}
#
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['IYW', 'XLK']
# Formula: 315.594444930597 * 170.02999877929688 * 0.975
# Sell FTEC: 315.59 shares at 170.03. Total value: 52319.01
#
# Formula: (52319.010009144724 * 0.975) / 220.25999450683594
# Buy XLK: 231.59 shares at 220.26.
#
# Updated ticker shares after 2024-10-01 to 2024-10-31: {'IYW': 316.2368788487653, 'XLK': 231.59464283620935}
#
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['IYW', 'XLK']
# Top 2 ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'IYW']
# Formula: 231.59464283620935 * 223.91000366210938 * 0.975
# Sell XLK: 231.59 shares at 223.91. Total value: 50559.95
#
# Formula: (50559.94839244103 * 0.975) / 174.35000610351562
# Buy FTEC: 282.74 shares at 174.35.
#
# Updated ticker shares after 2024-11-01 to 2024-11-30: {'FTEC': 282.7413132028333, 'IYW': 316.2368788487653}
#
# Using data for the 12th month: 2024-11-01 to 2024-11-30
# Fetching data starting from the first trading day of the 13th month: 2024-12-01
# Fetching data for ticker FTEC starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# FTEC: 282.74 shares at $186.99 each, total value: $52869.80
# Fetching data for ticker IYW starting from 2024-12-01...
# IYW: 316.24 shares at $161.02 each, total value: $50920.46
#
# ETF values on the 13th month's first trading day:
# Total portfolio value: 103790.26
# FTEC: 52869.80
# IYW: 50920.46

# %%
# Now call the weekly workflow using the 'results' as etf_dict
ticker_shares_per_month_with_smoothing = main_monthly(tickers, results,True)
# Out:
# Fetching data for SMH from 2024-01-01 to 2024-01-31...
# Fetching data for SOXX from 2024-01-01 to 2024-01-31...
# Fetching data for PSI from 2024-01-01 to 2024-01-31...
# Fetching data for XSD from 2024-01-01 to 2024-01-31...
# Fetching data for IYW from 2024-01-01 to 2024-01-31...
# Fetching data for XLK from 2024-01-01 to 2024-01-31...
# Fetching data for VGT from 2024-01-01 to 2024-01-31...
# Fetching data for FTEC from 2024-01-01 to 2024-01-31...
# Fetching data for IGM from 2024-01-01 to 2024-01-31...
# Fetching data for IXN from 2024-01-01 to 2024-01-31...
# Fetching data for SMH from 2024-02-01 to 2024-02-29...
# Fetching data for SOXX from 2024-02-01 to 2024-02-29...
# Fetching data for PSI from 2024-02-01 to 2024-02-29...
# Fetching data for XSD from 2024-02-01 to 2024-02-29...
# Fetching data for IYW from 2024-02-01 to 2024-02-29...
# Fetching data for XLK from 2024-02-01 to 2024-02-29...
# Fetching data for VGT from 2024-02-01 to 2024-02-29...
# Fetching data for FTEC from 2024-02-01 to 2024-02-29...
# Fetching data for IGM from 2024-02-01 to 2024-02-29...
# Fetching data for IXN from 2024-02-01 to 2024-02-29...
# Fetching data for SMH from 2024-03-01 to 2024-03-31...
# Fetching data for SOXX from 2024-03-01 to 2024-03-31...
# Fetching data for PSI from 2024-03-01 to 2024-03-31...
# Fetching data for XSD from 2024-03-01 to 2024-03-31...
# Fetching data for IYW from 2024-03-01 to 2024-03-31...
# Fetching data for XLK from 2024-03-01 to 2024-03-31...
# Fetching data for VGT from 2024-03-01 to 2024-03-31...
# Fetching data for FTEC from 2024-03-01 to 2024-03-31...
# Fetching data for IGM from 2024-03-01 to 2024-03-31...
# Fetching data for IXN from 2024-03-01 to 2024-03-31...
# Fetching data for SMH from 2024-04-01 to 2024-04-30...
# Fetching data for SOXX from 2024-04-01 to 2024-04-30...
# Fetching data for PSI from 2024-04-01 to 2024-04-30...
# Fetching data for XSD from 2024-04-01 to 2024-04-30...
# Fetching data for IYW from 2024-04-01 to 2024-04-30...
# Fetching data for XLK from 2024-04-01 to 2024-04-30...
# Fetching data for VGT from 2024-04-01 to 2024-04-30...
# Fetching data for FTEC from 2024-04-01 to 2024-04-30...
# Fetching data for IGM from 2024-04-01 to 2024-04-30...
# Fetching data for IXN from 2024-04-01 to 2024-04-30...
# Fetching data for SMH from 2024-05-01 to 2024-05-31...
# Fetching data for SOXX from 2024-05-01 to 2024-05-31...
# Fetching data for PSI from 2024-05-01 to 2024-05-31...
# Fetching data for XSD from 2024-05-01 to 2024-05-31...
# Fetching data for IYW from 2024-05-01 to 2024-05-31...
# Fetching data for XLK from 2024-05-01 to 2024-05-31...
# Fetching data for VGT from 2024-05-01 to 2024-05-31...
# Fetching data for FTEC from 2024-05-01 to 2024-05-31...
# Fetching data for IGM from 2024-05-01 to 2024-05-31...
# Fetching data for IXN from 2024-05-01 to 2024-05-31...
# Fetching data for SMH from 2024-06-01 to 2024-06-30...
# Fetching data for SOXX from 2024-06-01 to 2024-06-30...
# Fetching data for PSI from 2024-06-01 to 2024-06-30...
# Fetching data for XSD from 2024-06-01 to 2024-06-30...
# Fetching data for IYW from 2024-06-01 to 2024-06-30...
# Fetching data for XLK from 2024-06-01 to 2024-06-30...
# Fetching data for VGT from 2024-06-01 to 2024-06-30...
# Fetching data for FTEC from 2024-06-01 to 2024-06-30...
# Fetching data for IGM from 2024-06-01 to 2024-06-30...
# Fetching data for IXN from 2024-06-01 to 2024-06-30...
# Fetching data for SMH from 2024-07-01 to 2024-07-31...
# Fetching data for SOXX from 2024-07-01 to 2024-07-31...
# Fetching data for PSI from 2024-07-01 to 2024-07-31...
# Fetching data for XSD from 2024-07-01 to 2024-07-31...
# Fetching data for IYW from 2024-07-01 to 2024-07-31...
# Fetching data for XLK from 2024-07-01 to 2024-07-31...
# Fetching data for VGT from 2024-07-01 to 2024-07-31...
# Fetching data for FTEC from 2024-07-01 to 2024-07-31...
# Fetching data for IGM from 2024-07-01 to 2024-07-31...
# Fetching data for IXN from 2024-07-01 to 2024-07-31...
# Fetching data for SMH from 2024-08-01 to 2024-08-31...
# Fetching data for SOXX from 2024-08-01 to 2024-08-31...
# Fetching data for PSI from 2024-08-01 to 2024-08-31...
# Fetching data for XSD from 2024-08-01 to 2024-08-31...
# Fetching data for IYW from 2024-08-01 to 2024-08-31...
# Fetching data for XLK from 2024-08-01 to 2024-08-31...
# Fetching data for VGT from 2024-08-01 to 2024-08-31...
# Fetching data for FTEC from 2024-08-01 to 2024-08-31...
# Fetching data for IGM from 2024-08-01 to 2024-08-31...
# Fetching data for IXN from 2024-08-01 to 2024-08-31...
# Fetching data for SMH from 2024-09-01 to 2024-09-30...
# Fetching data for SOXX from 2024-09-01 to 2024-09-30...
# Fetching data for PSI from 2024-09-01 to 2024-09-30...
# Fetching data for XSD from 2024-09-01 to 2024-09-30...
# Fetching data for IYW from 2024-09-01 to 2024-09-30...
# Fetching data for XLK from 2024-09-01 to 2024-09-30...
# Fetching data for VGT from 2024-09-01 to 2024-09-30...
# Fetching data for FTEC from 2024-09-01 to 2024-09-30...
# Fetching data for IGM from 2024-09-01 to 2024-09-30...
# Fetching data for IXN from 2024-09-01 to 2024-09-30...
# Fetching data for SMH from 2024-10-01 to 2024-10-31...
# Fetching data for SOXX from 2024-10-01 to 2024-10-31...
# Fetching data for PSI from 2024-10-01 to 2024-10-31...
# Fetching data for XSD from 2024-10-01 to 2024-10-31...
# Fetching data for IYW from 2024-10-01 to 2024-10-31...
# Fetching data for XLK from 2024-10-01 to 2024-10-31...
# Fetching data for VGT from 2024-10-01 to 2024-10-31...
# Fetching data for FTEC from 2024-10-01 to 2024-10-31...
# Fetching data for IGM from 2024-10-01 to 2024-10-31...
# Fetching data for IXN from 2024-10-01 to 2024-10-31...
# Fetching data for SMH from 2024-11-01 to 2024-11-30...
# Fetching data for SOXX from 2024-11-01 to 2024-11-30...
# Fetching data for PSI from 2024-11-01 to 2024-11-30...
# Fetching data for XSD from 2024-11-01 to 2024-11-30...
# Fetching data for IYW from 2024-11-01 to 2024-11-30...
# Fetching data for XLK from 2024-11-01 to 2024-11-30...
# Fetching data for VGT from 2024-11-01 to 2024-11-30...
# Fetching data for FTEC from 2024-11-01 to 2024-11-30...
# Fetching data for IGM from 2024-11-01 to 2024-11-30...
# Fetching data for IXN from 2024-11-01 to 2024-11-30...
# [*********************100%%**********************]  1 of 1 completed
# Processing scores for 2024-01-01 to 2024-01-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   1m             0.1 -0.328869
# 1  SOXX   1m             0.1 -0.701118
# 2   PSI   1m             0.1 -1.721067
# 3   XSD   1m             0.1 -5.824924
# 4   IYW   1m             0.1  1.616070
# Top ETFs for 2024-01-01 to 2024-01-31: ['FTEC', 'IYW']
# Processing scores for 2024-02-01 to 2024-02-29:
#     ETF Week  RiskPercentage     Score
# 0   SMH   2m             0.1  0.840428
# 1  SOXX   2m             0.1 -1.342671
# 2   PSI   2m             0.1 -1.732105
# 3   XSD   2m             0.1 -4.113408
# 4   IYW   2m             0.1  4.463464
# Top ETFs for 2024-02-01 to 2024-02-29: ['IYW', 'FTEC']
# Processing scores for 2024-03-01 to 2024-03-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   3m             0.1  0.174276
# 1  SOXX   3m             0.1 -1.259153
# 2   PSI   3m             0.1 -1.862861
# 3   XSD   3m             0.1 -4.281140
# 4   IYW   3m             0.1  4.806005
# Top ETFs for 2024-03-01 to 2024-03-31: ['IYW', 'FTEC']
# Processing scores for 2024-04-01 to 2024-04-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   4m             0.1 -0.158503
# 1  SOXX   4m             0.1 -0.775523
# 2   PSI   4m             0.1 -2.644614
# 3   XSD   4m             0.1 -4.439467
# 4   IYW   4m             0.1  1.461874
# Top ETFs for 2024-04-01 to 2024-04-30: ['FTEC', 'XLK']
# Processing scores for 2024-05-01 to 2024-05-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   5m             0.1  0.904917
# 1  SOXX   5m             0.1  0.201621
# 2   PSI   5m             0.1 -2.259619
# 3   XSD   5m             0.1 -4.058874
# 4   IYW   5m             0.1  3.198881
# Top ETFs for 2024-05-01 to 2024-05-31: ['IYW', 'XLK']
# Processing scores for 2024-06-01 to 2024-06-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   6m             0.1  0.478403
# 1  SOXX   6m             0.1 -1.279530
# 2   PSI   6m             0.1 -2.219014
# 3   XSD   6m             0.1 -6.212696
# 4   IYW   6m             0.1  5.197179
# Top ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'FTEC']
# Processing scores for 2024-07-01 to 2024-07-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   7m             0.1  1.201660
# 1  SOXX   7m             0.1  0.536518
# 2   PSI   7m             0.1 -3.205394
# 3   XSD   7m             0.1 -4.699078
# 4   IYW   7m             0.1  3.187996
# Top ETFs for 2024-07-01 to 2024-07-31: ['IYW', 'XLK']
# Processing scores for 2024-08-01 to 2024-08-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH   8m             0.1  0.043814
# 1  SOXX   8m             0.1  1.873076
# 2   PSI   8m             0.1 -3.084548
# 3   XSD   8m             0.1 -0.994950
# 4   IYW   8m             0.1  0.045367
# Top ETFs for 2024-08-01 to 2024-08-31: ['FTEC', 'SOXX']
# Processing scores for 2024-09-01 to 2024-09-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH   9m             0.1  0.043545
# 1  SOXX   9m             0.1  0.332289
# 2   PSI   9m             0.1 -4.467217
# 3   XSD   9m             0.1 -1.122414
# 4   IYW   9m             0.1  1.670484
# Top ETFs for 2024-09-01 to 2024-09-30: ['FTEC', 'IYW']
# Processing scores for 2024-10-01 to 2024-10-31:
#     ETF Week  RiskPercentage     Score
# 0   SMH  10m             0.1  1.018470
# 1  SOXX  10m             0.1  0.795818
# 2   PSI  10m             0.1 -3.401909
# 3   XSD  10m             0.1 -3.280851
# 4   IYW  10m             0.1  3.072641
# Top ETFs for 2024-10-01 to 2024-10-31: ['IYW', 'XLK']
# Processing scores for 2024-11-01 to 2024-11-30:
#     ETF Week  RiskPercentage     Score
# 0   SMH  11m             0.1  0.518578
# 1  SOXX  11m             0.1  1.490095
# 2   PSI  11m             0.1 -3.526891
# 3   XSD  11m             0.1 -3.495686
# 4   IYW  11m             0.1  1.850206
# Top ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-01-01 to 2024-01-31: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['IYW', 'FTEC']
# Updated ticker shares after 2024-02-01 to 2024-02-29: {'IYW': 407.8815375605023, 'FTEC': 348.73740855123145}
#
# Top 2 ETFs for 2024-02-01 to 2024-02-29: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['IYW', 'FTEC']
# Updated ticker shares after 2024-03-01 to 2024-03-31: {'IYW': 407.8815375605023, 'FTEC': 348.73740855123145}
#
# Top 2 ETFs for 2024-03-01 to 2024-03-31: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['FTEC', 'XLK']
# Formula: 407.8815375605023 * 135.5500030517578 * 0.975
# Sell IYW: 407.88 shares at 135.55. Total value: 53906.14
#
# Formula: (53906.13506955471 * 0.975) / 208.85000610351562
# Buy XLK: 251.66 shares at 208.85.
#
# Updated ticker shares after 2024-04-01 to 2024-04-30: {'FTEC': 348.73740855123145, 'XLK': 251.6565963937078}
#
# Top 2 ETFs for 2024-04-01 to 2024-04-30: ['FTEC', 'XLK']
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['IYW', 'XLK']
# Formula: 348.73740855123145 * 145.33999633789062 * 0.975
# Sell FTEC: 348.74 shares at 145.34. Total value: 49418.36
#
# Formula: (49418.35633967841 * 0.975) / 126.94999694824219
# Buy IYW: 379.54 shares at 126.95.
#
# Updated ticker shares after 2024-05-01 to 2024-05-31: {'IYW': 379.542328392735, 'XLK': 251.6565963937078}
#
# Top 2 ETFs for 2024-05-01 to 2024-05-31: ['IYW', 'XLK']
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'FTEC']
# Formula: 251.6565963937078 * 210.69000244140625 * 0.975
# Sell XLK: 251.66 shares at 210.69. Total value: 51695.99
#
# Formula: (51695.99068587163 * 0.975) / 159.7100067138672
# Buy FTEC: 315.59 shares at 159.71.
#
# Updated ticker shares after 2024-06-01 to 2024-06-30: {'IYW': 379.542328392735, 'FTEC': 315.594444930597}
#
# Top 2 ETFs for 2024-06-01 to 2024-06-30: ['IYW', 'FTEC']
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['IYW', 'XLK']
# Formula: 315.594444930597 * 173.1300048828125 * 0.975
# Sell FTEC: 315.59 shares at 173.13. Total value: 53272.90
#
# Formula: (53272.89609702719 * 0.975) / 227.94000244140625
# Buy XLK: 227.87 shares at 227.94.
#
# Updated ticker shares after 2024-07-01 to 2024-07-31: {'IYW': 379.542328392735, 'XLK': 227.87169052502475}
#
# Top 2 ETFs for 2024-07-01 to 2024-07-31: ['IYW', 'XLK']
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['FTEC', 'SOXX']
# Formula: 379.542328392735 * 141.77000427246094 * 0.975
# Sell IYW: 379.54 shares at 141.77. Total value: 52462.52
#
# Formula: 227.87169052502475 * 210.63999938964844 * 0.975
# Sell XLK: 227.87 shares at 210.64. Total value: 46798.92
#
# Formula: (52462.52457987236 * 0.975) / 163.02000427246094
# Buy FTEC: 313.77 shares at 163.02.
#
# Formula: (46798.92043428164 * 0.975) / 218.4199981689453
# Buy SOXX: 208.90 shares at 218.42.
#
# Updated ticker shares after 2024-08-01 to 2024-08-31: {'FTEC': 313.7710717997847, 'SOXX': 208.90462323020046}
#
# Top 2 ETFs for 2024-08-01 to 2024-08-31: ['FTEC', 'SOXX']
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['FTEC', 'IYW']
# Formula: 208.90462323020046 * 213.5 * 0.975
# Sell SOXX: 208.90 shares at 213.50. Total value: 43486.11
#
# Formula: (43486.108633156604 * 0.975) / 141.5800018310547
# Buy IYW: 299.47 shares at 141.58.
#
# Updated ticker shares after 2024-09-01 to 2024-09-30: {'FTEC': 313.7710717997847, 'IYW': 299.46994892627373}
#
# Top 2 ETFs for 2024-09-01 to 2024-09-30: ['FTEC', 'IYW']
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['IYW', 'XLK']
# Formula: 313.7710717997847 * 170.02999877929688 * 0.975
# Sell FTEC: 313.77 shares at 170.03. Total value: 52016.73
#
# Formula: (52016.73258121866 * 0.975) / 220.25999450683594
# Buy XLK: 230.26 shares at 220.26.
#
# Updated ticker shares after 2024-10-01 to 2024-10-31: {'IYW': 299.46994892627373, 'XLK': 230.2565855422019}
#
# Top 2 ETFs for 2024-10-01 to 2024-10-31: ['IYW', 'XLK']
# Top 2 ETFs for 2024-11-01 to 2024-11-30: ['FTEC', 'XLK']
# Formula: 299.46994892627373 * 151.7100067138672 * 0.975
# Sell IYW: 299.47 shares at 151.71. Total value: 44296.77
#
# Formula: (44296.77326315129 * 0.975) / 174.35000610351562
# Buy FTEC: 247.72 shares at 174.35.
#
# Updated ticker shares after 2024-11-01 to 2024-11-30: {'FTEC': 247.71638898555582, 'XLK': 230.2565855422019}
#
# Using data for the 12th month: 2024-11-01 to 2024-11-30
# Fetching data starting from the first trading day of the 13th month: 2024-12-01
# Fetching data for ticker FTEC starting from 2024-12-01...
# FTEC: 247.72 shares at $186.99 each, total value: $46320.49
# Fetching data for ticker XLK starting from 2024-12-01...
# [*********************100%%**********************]  1 of 1 completed
# XLK: 230.26 shares at $235.95 each, total value: $54329.04
#
# ETF values on the 13th month's first trading day:
# Total portfolio value: 100649.53
# FTEC: 46320.49
# XLK: 54329.04
